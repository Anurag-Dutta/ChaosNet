# %% [markdown]
# # Time Series Prediction with Duffing Equation Inspired Deep Learning ($DPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-09 18:36:46

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Duffing Intermittency_

# %% [markdown]
# The `duffing_intermittency.dat` is generated from the Runge Kutta Method.

# %% [markdown]
# This feeds the model with the dynamics of the Duffing Equations

# %%
data = np.genfromtxt('datasets/duffing_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 0.0416 # Hourly Data (1/24)
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 1.73753853
# 1         0.474759
# 2         0.468784
# 3         0.462842
# 4         0.456930
# 5         0.451048
#             ...
# 139867    0.000000
# 139868    0.000000
# 139869    0.000000
# 139870    0.000000
# 139871    0.000000
# Name: 1, Length: 139871, dtype: float64
# 2        -0.143636
# 3        -0.142850
# 4        -0.142104
# 5        -0.141399
# 6        -0.140769
#             ...
# 139867    0.000000
# 139868    0.000000
# 139869    0.000000
# 139870    0.000000
# 139871    0.000000
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _KYOTO DST_

# %%
data = pd.read_csv("datasets/dst.csv")
training_set = data.iloc[:, 1]
print(training_set)
# Out:
# 0         -7
# 1        -10
# 2        -10
# 3         -6
# 4         -2
#           ..
# 139867   -16
# 139868   -14
# 139869   -14
# 139870   -15
# 139871   -14
# Name: dst, Length: 139872, dtype: int64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0         0.474759
# 1         0.468784
# 2         0.462842
# 3         0.456930
# 4         0.451048
#             ...
# 139866    0.000000
# 139867    0.000000
# 139868    0.000000
# 139869    0.000000
# 139870    0.000000
# Name: 1, Length: 139871, dtype: float64
# 0        -0.143636
# 1        -0.142850
# 2        -0.142104
# 3        -0.141399
# 4        -0.140769
#             ...
# 139865    0.000000
# 139866    0.000000
# 139867    0.000000
# 139868    0.000000
# 139869    0.000000
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Duffing Equation_)

# %% [markdown]
# _Parameters_: $\alpha=0.5, \beta=1, \gamma=3, \delta=1\\$

# %%
a=0.5
b=1
c=3
d=1
L = df.iloc[:, 2] -c + d*df.iloc[:, 1] - a*df.iloc[:, 0] - b*df.iloc[:, 0]**3
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10        -7.0      -10.0      -10.0       -6.0       -2.0        3.0
# 11       -10.0      -10.0       -6.0       -2.0        3.0        5.0
# 12       -10.0       -6.0       -2.0        3.0        5.0        5.0
# 13        -6.0       -2.0        3.0        5.0        5.0        3.0
# 14        -2.0        3.0        5.0        5.0        3.0        1.0
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)   var2(t)   var3(t)
# 10        5.0        5.0        3.0        1.0      1.0  0.416224 -0.138262
# 11        5.0        3.0        1.0        1.0      2.0  0.410472 -0.138123
# 12        3.0        1.0        1.0        2.0      2.0  0.404726 -0.138054
# 13        1.0        1.0        2.0        2.0      3.0  0.398983 -0.138082
# 14        1.0        2.0        2.0        3.0      3.0  0.393239 -0.138210
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (139860, 13)
# (139860, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (111888, 1, 10) (111888, 3) (27972, 1, 10) (27972, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
a = tf.Variable(0.5, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(1, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(3, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(1, name="delta", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] -c + d*y_true[:, 1] - a*y_true[:, 0] - b*y_true[:, 0]**3), (y_pred[:, 2] -c + d*y_pred[:, 1] - a*y_pred[:, 0] - b*y_pred[:, 0]**3))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] -c + d*(y_pred[1:-1]-y_pred[:-2]) - a*y_pred[:-2] - b*y_pred[:-2]**3
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] -c + d*(y_real[1:-1]-y_real[:-2]) - a*y_real[:-2] - b*y_real[:-2]**3
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($DPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square(y_pred[:, 2] -c + d*y_pred[:, 1] - a*y_pred[:, 0] - b*y_pred[:, 0]**3)
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 1749/1749 - 22s - loss: 0.0090 - val_loss: 2.4731e-04 - 22s/epoch - 13ms/step
# Epoch 2/500
# 1749/1749 - 10s - loss: 6.1867e-04 - val_loss: 1.4719e-04 - 10s/epoch - 6ms/step
# Epoch 3/500
# 1749/1749 - 10s - loss: 3.1840e-04 - val_loss: 1.8058e-04 - 10s/epoch - 6ms/step
# Epoch 4/500
# 1749/1749 - 10s - loss: 2.3266e-04 - val_loss: 1.6460e-04 - 10s/epoch - 6ms/step
# Epoch 5/500
# 1749/1749 - 10s - loss: 2.0094e-04 - val_loss: 1.2798e-04 - 10s/epoch - 6ms/step
# Epoch 6/500
# 1749/1749 - 10s - loss: 1.7468e-04 - val_loss: 8.5568e-05 - 10s/epoch - 6ms/step
# Epoch 7/500
# 1749/1749 - 10s - loss: 1.4608e-04 - val_loss: 6.1349e-05 - 10s/epoch - 6ms/step
# Epoch 8/500
# 1749/1749 - 11s - loss: 1.3557e-04 - val_loss: 5.1879e-05 - 11s/epoch - 6ms/step
# Epoch 9/500
# 1749/1749 - 11s - loss: 1.2756e-04 - val_loss: 5.1112e-05 - 11s/epoch - 6ms/step
# Epoch 10/500
# 1749/1749 - 11s - loss: 1.2232e-04 - val_loss: 5.0678e-05 - 11s/epoch - 6ms/step
# Epoch 11/500
# 1749/1749 - 11s - loss: 1.1849e-04 - val_loss: 4.9445e-05 - 11s/epoch - 6ms/step
# Epoch 12/500
# 1749/1749 - 11s - loss: 1.1538e-04 - val_loss: 4.8534e-05 - 11s/epoch - 6ms/step
# Epoch 13/500
# 1749/1749 - 11s - loss: 1.1281e-04 - val_loss: 4.7905e-05 - 11s/epoch - 6ms/step
# Epoch 14/500
# 1749/1749 - 11s - loss: 1.1076e-04 - val_loss: 4.7398e-05 - 11s/epoch - 6ms/step
# Epoch 15/500
# 1749/1749 - 11s - loss: 1.0906e-04 - val_loss: 4.6954e-05 - 11s/epoch - 6ms/step
# Epoch 16/500
# 1749/1749 - 11s - loss: 1.0761e-04 - val_loss: 4.6550e-05 - 11s/epoch - 6ms/step
# Epoch 17/500
# 1749/1749 - 12s - loss: 1.0635e-04 - val_loss: 4.6180e-05 - 12s/epoch - 7ms/step
# Epoch 18/500
# 1749/1749 - 12s - loss: 1.0524e-04 - val_loss: 4.5853e-05 - 12s/epoch - 7ms/step
# Epoch 19/500
# 1749/1749 - 12s - loss: 1.0425e-04 - val_loss: 4.5566e-05 - 12s/epoch - 7ms/step
# Epoch 20/500
# 1749/1749 - 12s - loss: 1.0337e-04 - val_loss: 4.5313e-05 - 12s/epoch - 7ms/step
# Epoch 21/500
# 1749/1749 - 12s - loss: 1.0259e-04 - val_loss: 4.5087e-05 - 12s/epoch - 7ms/step
# Epoch 22/500
# 1749/1749 - 12s - loss: 1.0189e-04 - val_loss: 4.4877e-05 - 12s/epoch - 7ms/step
# Epoch 23/500
# 1749/1749 - 12s - loss: 1.0125e-04 - val_loss: 4.4684e-05 - 12s/epoch - 7ms/step
# Epoch 24/500
# 1749/1749 - 11s - loss: 1.0067e-04 - val_loss: 4.4512e-05 - 11s/epoch - 6ms/step
# Epoch 25/500
# 1749/1749 - 11s - loss: 1.0016e-04 - val_loss: 4.4352e-05 - 11s/epoch - 6ms/step
# Epoch 26/500
# 1749/1749 - 11s - loss: 9.9684e-05 - val_loss: 4.4205e-05 - 11s/epoch - 6ms/step
# Epoch 27/500
# 1749/1749 - 11s - loss: 9.9252e-05 - val_loss: 4.4068e-05 - 11s/epoch - 6ms/step
# Epoch 28/500
# 1749/1749 - 11s - loss: 9.8854e-05 - val_loss: 4.3941e-05 - 11s/epoch - 6ms/step
# Epoch 29/500
# 1749/1749 - 11s - loss: 9.8489e-05 - val_loss: 4.3825e-05 - 11s/epoch - 6ms/step
# Epoch 30/500
# 1749/1749 - 11s - loss: 9.8151e-05 - val_loss: 4.3717e-05 - 11s/epoch - 6ms/step
# Epoch 31/500
# 1749/1749 - 11s - loss: 9.7838e-05 - val_loss: 4.3618e-05 - 11s/epoch - 6ms/step
# Epoch 32/500
# 1749/1749 - 11s - loss: 9.7547e-05 - val_loss: 4.3525e-05 - 11s/epoch - 6ms/step
# Epoch 33/500
# 1749/1749 - 11s - loss: 9.7276e-05 - val_loss: 4.3439e-05 - 11s/epoch - 6ms/step
# Epoch 34/500
# 1749/1749 - 11s - loss: 9.7022e-05 - val_loss: 4.3355e-05 - 11s/epoch - 6ms/step
# Epoch 35/500
# 1749/1749 - 11s - loss: 9.6784e-05 - val_loss: 4.3276e-05 - 11s/epoch - 6ms/step
# Epoch 36/500
# 1749/1749 - 15s - loss: 9.6562e-05 - val_loss: 4.3197e-05 - 15s/epoch - 8ms/step
# Epoch 37/500
# 1749/1749 - 15s - loss: 9.6356e-05 - val_loss: 4.3117e-05 - 15s/epoch - 8ms/step
# Epoch 38/500
# 1749/1749 - 21s - loss: 9.6166e-05 - val_loss: 4.3029e-05 - 21s/epoch - 12ms/step
# Epoch 39/500
# 1749/1749 - 11s - loss: 9.5991e-05 - val_loss: 4.2931e-05 - 11s/epoch - 6ms/step
# Epoch 40/500
# 1749/1749 - 11s - loss: 9.5832e-05 - val_loss: 4.2821e-05 - 11s/epoch - 6ms/step
# Epoch 41/500
# 1749/1749 - 11s - loss: 9.5688e-05 - val_loss: 4.2691e-05 - 11s/epoch - 6ms/step
# Epoch 42/500
# 1749/1749 - 11s - loss: 9.5562e-05 - val_loss: 4.2537e-05 - 11s/epoch - 6ms/step
# Epoch 43/500
# 1749/1749 - 11s - loss: 9.5449e-05 - val_loss: 4.2361e-05 - 11s/epoch - 6ms/step
# Epoch 44/500
# 1749/1749 - 11s - loss: 9.5347e-05 - val_loss: 4.2167e-05 - 11s/epoch - 6ms/step
# Epoch 45/500
# 1749/1749 - 11s - loss: 9.5256e-05 - val_loss: 4.1958e-05 - 11s/epoch - 6ms/step
# Epoch 46/500
# 1749/1749 - 12s - loss: 9.5179e-05 - val_loss: 4.1733e-05 - 12s/epoch - 7ms/step
# Epoch 47/500
# 1749/1749 - 12s - loss: 9.5123e-05 - val_loss: 4.1494e-05 - 12s/epoch - 7ms/step
# Epoch 48/500
# 1749/1749 - 12s - loss: 9.5089e-05 - val_loss: 4.1244e-05 - 12s/epoch - 7ms/step
# Epoch 49/500
# 1749/1749 - 11s - loss: 9.5083e-05 - val_loss: 4.0989e-05 - 11s/epoch - 6ms/step
# Epoch 50/500
# 1749/1749 - 11s - loss: 9.5112e-05 - val_loss: 4.0738e-05 - 11s/epoch - 6ms/step
# Epoch 51/500
# 1749/1749 - 11s - loss: 9.5190e-05 - val_loss: 4.0516e-05 - 11s/epoch - 6ms/step
# Epoch 52/500
# 1749/1749 - 11s - loss: 9.5340e-05 - val_loss: 4.0390e-05 - 11s/epoch - 6ms/step
# Epoch 53/500
# 1749/1749 - 11s - loss: 9.5606e-05 - val_loss: 4.0567e-05 - 11s/epoch - 6ms/step
# Epoch 54/500
# 1749/1749 - 12s - loss: 9.6054e-05 - val_loss: 4.1624e-05 - 12s/epoch - 7ms/step
# Epoch 55/500
# 1749/1749 - 11s - loss: 9.6686e-05 - val_loss: 4.4290e-05 - 11s/epoch - 7ms/step
# Epoch 56/500
# 1749/1749 - 11s - loss: 9.7229e-05 - val_loss: 4.6888e-05 - 11s/epoch - 7ms/step
# Epoch 57/500
# 1749/1749 - 11s - loss: 9.7448e-05 - val_loss: 4.7620e-05 - 11s/epoch - 7ms/step
# Epoch 58/500
# 1749/1749 - 12s - loss: 9.7526e-05 - val_loss: 4.7535e-05 - 12s/epoch - 7ms/step
# Epoch 59/500
# 1749/1749 - 11s - loss: 9.7584e-05 - val_loss: 4.7344e-05 - 11s/epoch - 6ms/step
# Epoch 60/500
# 1749/1749 - 11s - loss: 9.7633e-05 - val_loss: 4.7330e-05 - 11s/epoch - 6ms/step
# Epoch 61/500
# 1749/1749 - 11s - loss: 9.7674e-05 - val_loss: 4.7588e-05 - 11s/epoch - 6ms/step
# Epoch 62/500
# 1749/1749 - 11s - loss: 9.7707e-05 - val_loss: 4.8113e-05 - 11s/epoch - 7ms/step
# Epoch 63/500
# 1749/1749 - 12s - loss: 9.7734e-05 - val_loss: 4.8850e-05 - 12s/epoch - 7ms/step
# Epoch 64/500
# 1749/1749 - 11s - loss: 9.7760e-05 - val_loss: 4.9760e-05 - 11s/epoch - 6ms/step
# Epoch 65/500
# 1749/1749 - 11s - loss: 9.7791e-05 - val_loss: 5.0825e-05 - 11s/epoch - 6ms/step
# Epoch 66/500
# 1749/1749 - 11s - loss: 9.7836e-05 - val_loss: 5.2059e-05 - 11s/epoch - 6ms/step
# Epoch 67/500
# 1749/1749 - 11s - loss: 9.7898e-05 - val_loss: 5.3474e-05 - 11s/epoch - 6ms/step
# Epoch 68/500
# 1749/1749 - 11s - loss: 9.7987e-05 - val_loss: 5.5097e-05 - 11s/epoch - 6ms/step
# Epoch 69/500
# 1749/1749 - 11s - loss: 9.8114e-05 - val_loss: 5.6970e-05 - 11s/epoch - 6ms/step
# Epoch 70/500
# 1749/1749 - 11s - loss: 9.8294e-05 - val_loss: 5.9167e-05 - 11s/epoch - 6ms/step
# Epoch 71/500
# 1749/1749 - 11s - loss: 9.8562e-05 - val_loss: 6.1831e-05 - 11s/epoch - 6ms/step
# Epoch 72/500
# 1749/1749 - 11s - loss: 9.8984e-05 - val_loss: 6.5259e-05 - 11s/epoch - 7ms/step
# Epoch 73/500
# 1749/1749 - 11s - loss: 9.9748e-05 - val_loss: 7.0166e-05 - 11s/epoch - 6ms/step
# Epoch 74/500
# 1749/1749 - 11s - loss: 1.0153e-04 - val_loss: 7.8926e-05 - 11s/epoch - 6ms/step
# Epoch 75/500
# 1749/1749 - 11s - loss: 1.0577e-04 - val_loss: 9.4932e-05 - 11s/epoch - 6ms/step
# Epoch 76/500
# 1749/1749 - 11s - loss: 1.0612e-04 - val_loss: 9.4628e-05 - 11s/epoch - 7ms/step
# Epoch 77/500
# 1749/1749 - 11s - loss: 1.0550e-04 - val_loss: 9.4257e-05 - 11s/epoch - 6ms/step
# Epoch 78/500
# 1749/1749 - 11s - loss: 1.0538e-04 - val_loss: 9.3748e-05 - 11s/epoch - 6ms/step
# Epoch 79/500
# 1749/1749 - 11s - loss: 1.0519e-04 - val_loss: 9.2968e-05 - 11s/epoch - 6ms/step
# Epoch 80/500
# 1749/1749 - 12s - loss: 1.0499e-04 - val_loss: 9.1991e-05 - 12s/epoch - 7ms/step
# Epoch 81/500
# 1749/1749 - 11s - loss: 1.0478e-04 - val_loss: 9.0846e-05 - 11s/epoch - 6ms/step
# Epoch 82/500
# 1749/1749 - 11s - loss: 1.0456e-04 - val_loss: 8.9575e-05 - 11s/epoch - 6ms/step
# Epoch 83/500
# 1749/1749 - 11s - loss: 1.0435e-04 - val_loss: 8.8199e-05 - 11s/epoch - 6ms/step
# Epoch 84/500
# 1749/1749 - 11s - loss: 1.0413e-04 - val_loss: 8.6747e-05 - 11s/epoch - 6ms/step
# Epoch 85/500
# 1749/1749 - 11s - loss: 1.0391e-04 - val_loss: 8.5226e-05 - 11s/epoch - 7ms/step
# Epoch 86/500
# 1749/1749 - 11s - loss: 1.0369e-04 - val_loss: 8.3655e-05 - 11s/epoch - 6ms/step
# Epoch 87/500
# 1749/1749 - 11s - loss: 1.0347e-04 - val_loss: 8.2043e-05 - 11s/epoch - 6ms/step
# Epoch 88/500
# 1749/1749 - 11s - loss: 1.0326e-04 - val_loss: 8.0399e-05 - 11s/epoch - 6ms/step
# Epoch 89/500
# 1749/1749 - 11s - loss: 1.0304e-04 - val_loss: 7.8736e-05 - 11s/epoch - 6ms/step
# Epoch 90/500
# 1749/1749 - 11s - loss: 1.0284e-04 - val_loss: 7.7062e-05 - 11s/epoch - 6ms/step
# Epoch 91/500
# 1749/1749 - 11s - loss: 1.0263e-04 - val_loss: 7.5376e-05 - 11s/epoch - 6ms/step
# Epoch 92/500
# 1749/1749 - 11s - loss: 1.0243e-04 - val_loss: 7.3659e-05 - 11s/epoch - 6ms/step
# Epoch 93/500
# 1749/1749 - 11s - loss: 1.0224e-04 - val_loss: 7.1917e-05 - 11s/epoch - 6ms/step
# Epoch 94/500
# 1749/1749 - 11s - loss: 1.0205e-04 - val_loss: 7.0147e-05 - 11s/epoch - 6ms/step
# Epoch 95/500
# 1749/1749 - 9s - loss: 1.0187e-04 - val_loss: 6.8372e-05 - 9s/epoch - 5ms/step
# Epoch 96/500
# 1749/1749 - 8s - loss: 1.0169e-04 - val_loss: 6.6615e-05 - 8s/epoch - 5ms/step
# Epoch 97/500
# 1749/1749 - 8s - loss: 1.0152e-04 - val_loss: 6.4913e-05 - 8s/epoch - 5ms/step
# Epoch 98/500
# 1749/1749 - 8s - loss: 1.0135e-04 - val_loss: 6.3270e-05 - 8s/epoch - 5ms/step
# Epoch 99/500
# 1749/1749 - 8s - loss: 1.0119e-04 - val_loss: 6.1662e-05 - 8s/epoch - 4ms/step
# Epoch 100/500
# 1749/1749 - 8s - loss: 1.0102e-04 - val_loss: 6.0068e-05 - 8s/epoch - 5ms/step
# Epoch 101/500
# 1749/1749 - 8s - loss: 1.0086e-04 - val_loss: 5.8481e-05 - 8s/epoch - 5ms/step
# Epoch 102/500
# 1749/1749 - 8s - loss: 1.0070e-04 - val_loss: 5.6910e-05 - 8s/epoch - 5ms/step
# Epoch 103/500
# 1749/1749 - 8s - loss: 1.0054e-04 - val_loss: 5.5408e-05 - 8s/epoch - 5ms/step
# Epoch 104/500
# 1749/1749 - 8s - loss: 1.0039e-04 - val_loss: 5.4051e-05 - 8s/epoch - 5ms/step
# Epoch 105/500
# 1749/1749 - 10s - loss: 1.0023e-04 - val_loss: 5.2875e-05 - 10s/epoch - 6ms/step
# Epoch 106/500
# 1749/1749 - 10s - loss: 1.0008e-04 - val_loss: 5.1835e-05 - 10s/epoch - 6ms/step
# Epoch 107/500
# 1749/1749 - 11s - loss: 9.9925e-05 - val_loss: 5.0874e-05 - 11s/epoch - 6ms/step
# Epoch 108/500
# 1749/1749 - 10s - loss: 9.9780e-05 - val_loss: 4.9967e-05 - 10s/epoch - 6ms/step
# Epoch 109/500
# 1749/1749 - 10s - loss: 9.9638e-05 - val_loss: 4.9111e-05 - 10s/epoch - 6ms/step
# Epoch 110/500
# 1749/1749 - 12s - loss: 9.9500e-05 - val_loss: 4.8313e-05 - 12s/epoch - 7ms/step
# Epoch 111/500
# 1749/1749 - 12s - loss: 9.9365e-05 - val_loss: 4.7572e-05 - 12s/epoch - 7ms/step
# Epoch 112/500
# 1749/1749 - 9s - loss: 9.9233e-05 - val_loss: 4.6888e-05 - 9s/epoch - 5ms/step
# Epoch 113/500
# 1749/1749 - 10s - loss: 9.9104e-05 - val_loss: 4.6248e-05 - 10s/epoch - 6ms/step
# Epoch 114/500
# 1749/1749 - 10s - loss: 9.8978e-05 - val_loss: 4.5644e-05 - 10s/epoch - 5ms/step
# Epoch 115/500
# 1749/1749 - 10s - loss: 9.8854e-05 - val_loss: 4.5065e-05 - 10s/epoch - 6ms/step
# Epoch 116/500
# 1749/1749 - 10s - loss: 9.8734e-05 - val_loss: 4.4508e-05 - 10s/epoch - 6ms/step
# Epoch 117/500
# 1749/1749 - 10s - loss: 9.8615e-05 - val_loss: 4.3969e-05 - 10s/epoch - 6ms/step
# Epoch 118/500
# 1749/1749 - 14s - loss: 9.8500e-05 - val_loss: 4.3447e-05 - 14s/epoch - 8ms/step
# Epoch 119/500
# 1749/1749 - 10s - loss: 9.8387e-05 - val_loss: 4.2942e-05 - 10s/epoch - 6ms/step
# Epoch 120/500
# 1749/1749 - 16s - loss: 9.8276e-05 - val_loss: 4.2451e-05 - 16s/epoch - 9ms/step
# Epoch 121/500
# 1749/1749 - 14s - loss: 9.8167e-05 - val_loss: 4.1975e-05 - 14s/epoch - 8ms/step
# Epoch 122/500
# 1749/1749 - 10s - loss: 9.8061e-05 - val_loss: 4.1514e-05 - 10s/epoch - 5ms/step
# Epoch 123/500
# 1749/1749 - 11s - loss: 9.7956e-05 - val_loss: 4.1069e-05 - 11s/epoch - 6ms/step
# Epoch 124/500
# 1749/1749 - 11s - loss: 9.7854e-05 - val_loss: 4.0639e-05 - 11s/epoch - 6ms/step
# Epoch 125/500
# 1749/1749 - 11s - loss: 9.7753e-05 - val_loss: 4.0226e-05 - 11s/epoch - 6ms/step
# Epoch 126/500
# 1749/1749 - 10s - loss: 9.7654e-05 - val_loss: 3.9831e-05 - 10s/epoch - 6ms/step
# Epoch 127/500
# 1749/1749 - 12s - loss: 9.7556e-05 - val_loss: 3.9453e-05 - 12s/epoch - 7ms/step
# Epoch 128/500
# 1749/1749 - 10s - loss: 9.7461e-05 - val_loss: 3.9095e-05 - 10s/epoch - 6ms/step
# Epoch 129/500
# 1749/1749 - 9s - loss: 9.7367e-05 - val_loss: 3.8756e-05 - 9s/epoch - 5ms/step
# Epoch 130/500
# 1749/1749 - 9s - loss: 9.7275e-05 - val_loss: 3.8438e-05 - 9s/epoch - 5ms/step
# Epoch 131/500
# 1749/1749 - 9s - loss: 9.7184e-05 - val_loss: 3.8139e-05 - 9s/epoch - 5ms/step
# Epoch 132/500
# 1749/1749 - 9s - loss: 9.7095e-05 - val_loss: 3.7863e-05 - 9s/epoch - 5ms/step
# Epoch 133/500
# 1749/1749 - 9s - loss: 9.7008e-05 - val_loss: 3.7609e-05 - 9s/epoch - 5ms/step
# Epoch 134/500
# 1749/1749 - 12s - loss: 9.6922e-05 - val_loss: 3.7378e-05 - 12s/epoch - 7ms/step
# Epoch 135/500
# 1749/1749 - 10s - loss: 9.6839e-05 - val_loss: 3.7170e-05 - 10s/epoch - 6ms/step
# Epoch 136/500
# 1749/1749 - 11s - loss: 9.6756e-05 - val_loss: 3.6987e-05 - 11s/epoch - 7ms/step
# Epoch 137/500
# 1749/1749 - 9s - loss: 9.6675e-05 - val_loss: 3.6829e-05 - 9s/epoch - 5ms/step
# Epoch 138/500
# 1749/1749 - 9s - loss: 9.6595e-05 - val_loss: 3.6695e-05 - 9s/epoch - 5ms/step
# Epoch 139/500
# 1749/1749 - 8s - loss: 9.6516e-05 - val_loss: 3.6585e-05 - 8s/epoch - 5ms/step
# Epoch 140/500
# 1749/1749 - 8s - loss: 9.6437e-05 - val_loss: 3.6497e-05 - 8s/epoch - 5ms/step
# Epoch 141/500
# 1749/1749 - 9s - loss: 9.6358e-05 - val_loss: 3.6427e-05 - 9s/epoch - 5ms/step
# Epoch 142/500
# 1749/1749 - 8s - loss: 9.6279e-05 - val_loss: 3.6372e-05 - 8s/epoch - 4ms/step
# Epoch 143/500
# 1749/1749 - 7s - loss: 9.6200e-05 - val_loss: 3.6326e-05 - 7s/epoch - 4ms/step
# Epoch 144/500
# 1749/1749 - 8s - loss: 9.6120e-05 - val_loss: 3.6287e-05 - 8s/epoch - 4ms/step
# Epoch 145/500
# 1749/1749 - 7s - loss: 9.6040e-05 - val_loss: 3.6251e-05 - 7s/epoch - 4ms/step
# Epoch 146/500
# 1749/1749 - 7s - loss: 9.5961e-05 - val_loss: 3.6217e-05 - 7s/epoch - 4ms/step
# Epoch 147/500
# 1749/1749 - 7s - loss: 9.5883e-05 - val_loss: 3.6185e-05 - 7s/epoch - 4ms/step
# Epoch 148/500
# 1749/1749 - 7s - loss: 9.5805e-05 - val_loss: 3.6154e-05 - 7s/epoch - 4ms/step
# Epoch 149/500
# 1749/1749 - 9s - loss: 9.5729e-05 - val_loss: 3.6125e-05 - 9s/epoch - 5ms/step
# Epoch 150/500
# 1749/1749 - 10s - loss: 9.5654e-05 - val_loss: 3.6098e-05 - 10s/epoch - 6ms/step
# Epoch 151/500
# 1749/1749 - 9s - loss: 9.5581e-05 - val_loss: 3.6072e-05 - 9s/epoch - 5ms/step
# Epoch 152/500
# 1749/1749 - 10s - loss: 9.5508e-05 - val_loss: 3.6048e-05 - 10s/epoch - 6ms/step
# Epoch 153/500
# 1749/1749 - 10s - loss: 9.5437e-05 - val_loss: 3.6026e-05 - 10s/epoch - 6ms/step
# Epoch 154/500
# 1749/1749 - 11s - loss: 9.5367e-05 - val_loss: 3.6006e-05 - 11s/epoch - 6ms/step
# Epoch 155/500
# 1749/1749 - 10s - loss: 9.5298e-05 - val_loss: 3.5987e-05 - 10s/epoch - 6ms/step
# Epoch 156/500
# 1749/1749 - 12s - loss: 9.5230e-05 - val_loss: 3.5970e-05 - 12s/epoch - 7ms/step
# Epoch 157/500
# 1749/1749 - 9s - loss: 9.5163e-05 - val_loss: 3.5955e-05 - 9s/epoch - 5ms/step
# Epoch 158/500
# 1749/1749 - 9s - loss: 9.5097e-05 - val_loss: 3.5940e-05 - 9s/epoch - 5ms/step
# Epoch 159/500
# 1749/1749 - 10s - loss: 9.5032e-05 - val_loss: 3.5926e-05 - 10s/epoch - 6ms/step
# Epoch 160/500
# 1749/1749 - 9s - loss: 9.4968e-05 - val_loss: 3.5913e-05 - 9s/epoch - 5ms/step
# Epoch 161/500
# 1749/1749 - 11s - loss: 9.4905e-05 - val_loss: 3.5900e-05 - 11s/epoch - 7ms/step
# Epoch 162/500
# 1749/1749 - 9s - loss: 9.4842e-05 - val_loss: 3.5886e-05 - 9s/epoch - 5ms/step
# Epoch 163/500
# 1749/1749 - 9s - loss: 9.4781e-05 - val_loss: 3.5871e-05 - 9s/epoch - 5ms/step
# Epoch 164/500
# 1749/1749 - 9s - loss: 9.4720e-05 - val_loss: 3.5853e-05 - 9s/epoch - 5ms/step
# Epoch 165/500
# 1749/1749 - 9s - loss: 9.4660e-05 - val_loss: 3.5832e-05 - 9s/epoch - 5ms/step
# Epoch 166/500
# 1749/1749 - 10s - loss: 9.4601e-05 - val_loss: 3.5803e-05 - 10s/epoch - 6ms/step
# Epoch 167/500
# 1749/1749 - 11s - loss: 9.4541e-05 - val_loss: 3.5759e-05 - 11s/epoch - 6ms/step
# Epoch 168/500
# 1749/1749 - 12s - loss: 9.4483e-05 - val_loss: 3.5691e-05 - 12s/epoch - 7ms/step
# Epoch 169/500
# 1749/1749 - 11s - loss: 9.4425e-05 - val_loss: 3.5579e-05 - 11s/epoch - 6ms/step
# Epoch 170/500
# 1749/1749 - 11s - loss: 9.4367e-05 - val_loss: 3.5429e-05 - 11s/epoch - 6ms/step
# Epoch 171/500
# 1749/1749 - 9s - loss: 9.4313e-05 - val_loss: 3.5315e-05 - 9s/epoch - 5ms/step
# Epoch 172/500
# 1749/1749 - 9s - loss: 9.4257e-05 - val_loss: 3.5205e-05 - 9s/epoch - 5ms/step
# Epoch 173/500
# 1749/1749 - 9s - loss: 9.4183e-05 - val_loss: 3.5153e-05 - 9s/epoch - 5ms/step
# Epoch 174/500
# 1749/1749 - 9s - loss: 9.4107e-05 - val_loss: 3.5182e-05 - 9s/epoch - 5ms/step
# Epoch 175/500
# 1749/1749 - 9s - loss: 9.4045e-05 - val_loss: 3.5204e-05 - 9s/epoch - 5ms/step
# Epoch 176/500
# 1749/1749 - 9s - loss: 9.3993e-05 - val_loss: 3.5223e-05 - 9s/epoch - 5ms/step
# Epoch 177/500
# 1749/1749 - 9s - loss: 9.3940e-05 - val_loss: 3.5243e-05 - 9s/epoch - 5ms/step
# Epoch 178/500
# 1749/1749 - 9s - loss: 9.3890e-05 - val_loss: 3.5263e-05 - 9s/epoch - 5ms/step
# Epoch 179/500
# 1749/1749 - 9s - loss: 9.3840e-05 - val_loss: 3.5284e-05 - 9s/epoch - 5ms/step
# Epoch 180/500
# 1749/1749 - 9s - loss: 9.3791e-05 - val_loss: 3.5304e-05 - 9s/epoch - 5ms/step
# Epoch 181/500
# 1749/1749 - 10s - loss: 9.3742e-05 - val_loss: 3.5324e-05 - 10s/epoch - 6ms/step
# Epoch 182/500
# 1749/1749 - 9s - loss: 9.3694e-05 - val_loss: 3.5344e-05 - 9s/epoch - 5ms/step
# Epoch 183/500
# 1749/1749 - 11s - loss: 9.3646e-05 - val_loss: 3.5363e-05 - 11s/epoch - 6ms/step
# Epoch 184/500
# 1749/1749 - 11s - loss: 9.3599e-05 - val_loss: 3.5382e-05 - 11s/epoch - 6ms/step
# Epoch 185/500
# 1749/1749 - 9s - loss: 9.3552e-05 - val_loss: 3.5400e-05 - 9s/epoch - 5ms/step
# Epoch 186/500
# 1749/1749 - 9s - loss: 9.3506e-05 - val_loss: 3.5417e-05 - 9s/epoch - 5ms/step
# Epoch 187/500
# 1749/1749 - 9s - loss: 9.3460e-05 - val_loss: 3.5433e-05 - 9s/epoch - 5ms/step
# Epoch 188/500
# 1749/1749 - 9s - loss: 9.3415e-05 - val_loss: 3.5449e-05 - 9s/epoch - 5ms/step
# Epoch 189/500
# 1749/1749 - 9s - loss: 9.3370e-05 - val_loss: 3.5464e-05 - 9s/epoch - 5ms/step
# Epoch 190/500
# 1749/1749 - 9s - loss: 9.3326e-05 - val_loss: 3.5479e-05 - 9s/epoch - 5ms/step
# Epoch 191/500
# 1749/1749 - 8s - loss: 9.3282e-05 - val_loss: 3.5492e-05 - 8s/epoch - 5ms/step
# Epoch 192/500
# 1749/1749 - 10s - loss: 9.3239e-05 - val_loss: 3.5505e-05 - 10s/epoch - 5ms/step
# Epoch 193/500
# 1749/1749 - 12s - loss: 9.3196e-05 - val_loss: 3.5519e-05 - 12s/epoch - 7ms/step
# Epoch 194/500
# 1749/1749 - 13s - loss: 9.3158e-05 - val_loss: 3.5537e-05 - 13s/epoch - 8ms/step
# Epoch 195/500
# 1749/1749 - 9s - loss: 9.3117e-05 - val_loss: 3.5552e-05 - 9s/epoch - 5ms/step
# Epoch 196/500
# 1749/1749 - 10s - loss: 9.3076e-05 - val_loss: 3.5566e-05 - 10s/epoch - 6ms/step
# Epoch 197/500
# 1749/1749 - 9s - loss: 9.3037e-05 - val_loss: 3.5579e-05 - 9s/epoch - 5ms/step
# Epoch 198/500
# 1749/1749 - 9s - loss: 9.3001e-05 - val_loss: 3.5592e-05 - 9s/epoch - 5ms/step
# Epoch 199/500
# 1749/1749 - 8s - loss: 9.2965e-05 - val_loss: 3.5602e-05 - 8s/epoch - 5ms/step
# Epoch 200/500
# 1749/1749 - 10s - loss: 9.2923e-05 - val_loss: 3.5608e-05 - 10s/epoch - 6ms/step
# Epoch 201/500
# 1749/1749 - 11s - loss: 9.2884e-05 - val_loss: 3.5616e-05 - 11s/epoch - 6ms/step
# Epoch 202/500
# 1749/1749 - 11s - loss: 9.2846e-05 - val_loss: 3.5623e-05 - 11s/epoch - 7ms/step
# Epoch 203/500
# 1749/1749 - 10s - loss: 9.2807e-05 - val_loss: 3.5629e-05 - 10s/epoch - 5ms/step
# Epoch 204/500
# 1749/1749 - 9s - loss: 9.2770e-05 - val_loss: 3.5636e-05 - 9s/epoch - 5ms/step
# Epoch 205/500
# 1749/1749 - 10s - loss: 9.2732e-05 - val_loss: 3.5642e-05 - 10s/epoch - 5ms/step
# Epoch 206/500
# 1749/1749 - 11s - loss: 9.2695e-05 - val_loss: 3.5647e-05 - 11s/epoch - 7ms/step
# Epoch 207/500
# 1749/1749 - 12s - loss: 9.2658e-05 - val_loss: 3.5652e-05 - 12s/epoch - 7ms/step
# Epoch 208/500
# 1749/1749 - 11s - loss: 9.2622e-05 - val_loss: 3.5657e-05 - 11s/epoch - 6ms/step
# Epoch 209/500
# 1749/1749 - 9s - loss: 9.2586e-05 - val_loss: 3.5661e-05 - 9s/epoch - 5ms/step
# Epoch 210/500
# 1749/1749 - 15s - loss: 9.2550e-05 - val_loss: 3.5665e-05 - 15s/epoch - 9ms/step
# Epoch 211/500
# 1749/1749 - 11s - loss: 9.2514e-05 - val_loss: 3.5668e-05 - 11s/epoch - 6ms/step
# Epoch 212/500
# 1749/1749 - 21s - loss: 9.2479e-05 - val_loss: 3.5669e-05 - 21s/epoch - 12ms/step
# Epoch 213/500
# 1749/1749 - 12s - loss: 9.2445e-05 - val_loss: 3.5671e-05 - 12s/epoch - 7ms/step
# Epoch 214/500
# 1749/1749 - 10s - loss: 9.2410e-05 - val_loss: 3.5671e-05 - 10s/epoch - 5ms/step
# Epoch 215/500
# 1749/1749 - 11s - loss: 9.2376e-05 - val_loss: 3.5671e-05 - 11s/epoch - 6ms/step
# Epoch 216/500
# 1749/1749 - 9s - loss: 9.2342e-05 - val_loss: 3.5671e-05 - 9s/epoch - 5ms/step
# Epoch 217/500
# 1749/1749 - 11s - loss: 9.2309e-05 - val_loss: 3.5670e-05 - 11s/epoch - 6ms/step
# Epoch 218/500
# 1749/1749 - 9s - loss: 9.2276e-05 - val_loss: 3.5669e-05 - 9s/epoch - 5ms/step
# Epoch 219/500
# 1749/1749 - 11s - loss: 9.2243e-05 - val_loss: 3.5670e-05 - 11s/epoch - 6ms/step
# Epoch 220/500
# 1749/1749 - 10s - loss: 9.2211e-05 - val_loss: 3.5670e-05 - 10s/epoch - 6ms/step
# Epoch 221/500
# 1749/1749 - 10s - loss: 9.2179e-05 - val_loss: 3.5671e-05 - 10s/epoch - 6ms/step
# Epoch 222/500
# 1749/1749 - 9s - loss: 9.2148e-05 - val_loss: 3.5673e-05 - 9s/epoch - 5ms/step
# Epoch 223/500
# 1749/1749 - 9s - loss: 9.2116e-05 - val_loss: 3.5675e-05 - 9s/epoch - 5ms/step
# Epoch 224/500
# 1749/1749 - 9s - loss: 9.2086e-05 - val_loss: 3.5679e-05 - 9s/epoch - 5ms/step
# Epoch 225/500
# 1749/1749 - 11s - loss: 9.2055e-05 - val_loss: 3.5682e-05 - 11s/epoch - 6ms/step
# Epoch 226/500
# 1749/1749 - 11s - loss: 9.2024e-05 - val_loss: 3.5688e-05 - 11s/epoch - 6ms/step
# Epoch 227/500
# 1749/1749 - 11s - loss: 9.1993e-05 - val_loss: 3.5697e-05 - 11s/epoch - 6ms/step
# Epoch 228/500
# 1749/1749 - 10s - loss: 9.1960e-05 - val_loss: 3.5700e-05 - 10s/epoch - 6ms/step
# Epoch 229/500
# 1749/1749 - 9s - loss: 9.1932e-05 - val_loss: 3.5702e-05 - 9s/epoch - 5ms/step
# Epoch 230/500
# 1749/1749 - 9s - loss: 9.1903e-05 - val_loss: 3.5700e-05 - 9s/epoch - 5ms/step
# Epoch 231/500
# 1749/1749 - 9s - loss: 9.1875e-05 - val_loss: 3.5708e-05 - 9s/epoch - 5ms/step
# Epoch 232/500
# 1749/1749 - 9s - loss: 9.1848e-05 - val_loss: 3.5732e-05 - 9s/epoch - 5ms/step
# Epoch 233/500
# 1749/1749 - 12s - loss: 9.1821e-05 - val_loss: 3.5769e-05 - 12s/epoch - 7ms/step
# Epoch 234/500
# 1749/1749 - 11s - loss: 9.1795e-05 - val_loss: 3.5809e-05 - 11s/epoch - 6ms/step
# Epoch 235/500
# 1749/1749 - 9s - loss: 9.1768e-05 - val_loss: 3.5838e-05 - 9s/epoch - 5ms/step
# Epoch 236/500
# 1749/1749 - 10s - loss: 9.1740e-05 - val_loss: 3.5839e-05 - 10s/epoch - 6ms/step
# Epoch 237/500
# 1749/1749 - 9s - loss: 9.1710e-05 - val_loss: 3.5814e-05 - 9s/epoch - 5ms/step
# Epoch 238/500
# 1749/1749 - 9s - loss: 9.1681e-05 - val_loss: 3.5807e-05 - 9s/epoch - 5ms/step
# Epoch 239/500
# 1749/1749 - 10s - loss: 9.1657e-05 - val_loss: 3.5873e-05 - 10s/epoch - 6ms/step
# Epoch 240/500
# 1749/1749 - 10s - loss: 9.1634e-05 - val_loss: 3.5996e-05 - 10s/epoch - 6ms/step
# Epoch 241/500
# 1749/1749 - 10s - loss: 9.1611e-05 - val_loss: 3.6147e-05 - 10s/epoch - 6ms/step
# Epoch 242/500
# 1749/1749 - 9s - loss: 9.1588e-05 - val_loss: 3.6297e-05 - 9s/epoch - 5ms/step
# Epoch 243/500
# 1749/1749 - 9s - loss: 9.1558e-05 - val_loss: 3.6374e-05 - 9s/epoch - 5ms/step
# Epoch 244/500
# 1749/1749 - 9s - loss: 9.1538e-05 - val_loss: 3.6327e-05 - 9s/epoch - 5ms/step
# Epoch 245/500
# 1749/1749 - 9s - loss: 9.1526e-05 - val_loss: 3.5855e-05 - 9s/epoch - 5ms/step
# Epoch 246/500
# 1749/1749 - 10s - loss: 9.1462e-05 - val_loss: 3.5486e-05 - 10s/epoch - 6ms/step
# Epoch 247/500
# 1749/1749 - 10s - loss: 9.1444e-05 - val_loss: 3.5606e-05 - 10s/epoch - 6ms/step
# Epoch 248/500
# 1749/1749 - 9s - loss: 9.1424e-05 - val_loss: 3.5782e-05 - 9s/epoch - 5ms/step
# Epoch 249/500
# 1749/1749 - 10s - loss: 9.1423e-05 - val_loss: 3.6157e-05 - 10s/epoch - 6ms/step
# Epoch 250/500
# 1749/1749 - 9s - loss: 9.1398e-05 - val_loss: 3.6502e-05 - 9s/epoch - 5ms/step
# Epoch 251/500
# 1749/1749 - 10s - loss: 9.1390e-05 - val_loss: 3.6714e-05 - 10s/epoch - 5ms/step
# Epoch 252/500
# 1749/1749 - 9s - loss: 9.1361e-05 - val_loss: 3.6815e-05 - 9s/epoch - 5ms/step
# Epoch 253/500
# 1749/1749 - 11s - loss: 9.1327e-05 - val_loss: 3.6769e-05 - 11s/epoch - 6ms/step
# Epoch 254/500
# 1749/1749 - 11s - loss: 9.1344e-05 - val_loss: 3.6412e-05 - 11s/epoch - 6ms/step
# Epoch 255/500
# 1749/1749 - 11s - loss: 9.1226e-05 - val_loss: 3.5759e-05 - 11s/epoch - 6ms/step
# Epoch 256/500
# 1749/1749 - 10s - loss: 9.1218e-05 - val_loss: 3.5742e-05 - 10s/epoch - 6ms/step
# Epoch 257/500
# 1749/1749 - 10s - loss: 9.1191e-05 - val_loss: 3.5905e-05 - 10s/epoch - 6ms/step
# Epoch 258/500
# 1749/1749 - 9s - loss: 9.1207e-05 - val_loss: 3.6388e-05 - 9s/epoch - 5ms/step
# Epoch 259/500
# 1749/1749 - 9s - loss: 9.1178e-05 - val_loss: 3.6768e-05 - 9s/epoch - 5ms/step
# Epoch 260/500
# 1749/1749 - 9s - loss: 9.1178e-05 - val_loss: 3.6930e-05 - 9s/epoch - 5ms/step
# Epoch 261/500
# 1749/1749 - 10s - loss: 9.1156e-05 - val_loss: 3.6943e-05 - 10s/epoch - 6ms/step
# Epoch 262/500
# 1749/1749 - 12s - loss: 9.1151e-05 - val_loss: 3.6526e-05 - 12s/epoch - 7ms/step
# Epoch 263/500
# 1749/1749 - 10s - loss: 9.1007e-05 - val_loss: 3.5932e-05 - 10s/epoch - 6ms/step
# Epoch 264/500
# 1749/1749 - 10s - loss: 9.1043e-05 - val_loss: 3.6176e-05 - 10s/epoch - 6ms/step
# Epoch 265/500
# 1749/1749 - 10s - loss: 9.1021e-05 - val_loss: 3.6404e-05 - 10s/epoch - 6ms/step
# Epoch 266/500
# 1749/1749 - 9s - loss: 9.1011e-05 - val_loss: 3.6941e-05 - 9s/epoch - 5ms/step
# Epoch 267/500
# 1749/1749 - 10s - loss: 9.1025e-05 - val_loss: 3.7239e-05 - 10s/epoch - 6ms/step
# Epoch 268/500
# 1749/1749 - 10s - loss: 9.1000e-05 - val_loss: 3.7399e-05 - 10s/epoch - 6ms/step
# Epoch 269/500
# 1749/1749 - 10s - loss: 9.0952e-05 - val_loss: 3.7365e-05 - 10s/epoch - 6ms/step
# Epoch 270/500
# 1749/1749 - 11s - loss: 9.0963e-05 - val_loss: 3.7240e-05 - 11s/epoch - 6ms/step
# Epoch 271/500
# 1749/1749 - 10s - loss: 9.0916e-05 - val_loss: 3.6350e-05 - 10s/epoch - 6ms/step
# Epoch 272/500
# 1749/1749 - 9s - loss: 9.0825e-05 - val_loss: 3.5991e-05 - 9s/epoch - 5ms/step
# Epoch 273/500
# 1749/1749 - 10s - loss: 9.0817e-05 - val_loss: 3.6253e-05 - 10s/epoch - 6ms/step
# Epoch 274/500
# 1749/1749 - 11s - loss: 9.0834e-05 - val_loss: 3.6715e-05 - 11s/epoch - 6ms/step
# Epoch 275/500
# 1749/1749 - 11s - loss: 9.0816e-05 - val_loss: 3.7165e-05 - 11s/epoch - 6ms/step
# Epoch 276/500
# 1749/1749 - 11s - loss: 9.0836e-05 - val_loss: 3.7257e-05 - 11s/epoch - 6ms/step
# Epoch 277/500
# 1749/1749 - 11s - loss: 9.0728e-05 - val_loss: 3.6899e-05 - 11s/epoch - 6ms/step
# Epoch 278/500
# 1749/1749 - 10s - loss: 9.0766e-05 - val_loss: 3.7334e-05 - 10s/epoch - 6ms/step
# Epoch 279/500
# 1749/1749 - 11s - loss: 9.0747e-05 - val_loss: 3.7682e-05 - 11s/epoch - 6ms/step
# Epoch 280/500
# 1749/1749 - 9s - loss: 9.0706e-05 - val_loss: 3.7682e-05 - 9s/epoch - 5ms/step
# Epoch 281/500
# 1749/1749 - 9s - loss: 9.0688e-05 - val_loss: 3.7638e-05 - 9s/epoch - 5ms/step
# Epoch 282/500
# 1749/1749 - 6s - loss: 9.0794e-05 - val_loss: 3.7100e-05 - 6s/epoch - 4ms/step
# Epoch 283/500
# 1749/1749 - 7s - loss: 9.0597e-05 - val_loss: 3.6293e-05 - 7s/epoch - 4ms/step
# Epoch 284/500
# 1749/1749 - 6s - loss: 9.0597e-05 - val_loss: 3.6421e-05 - 6s/epoch - 3ms/step
# Epoch 285/500
# 1749/1749 - 6s - loss: 9.0563e-05 - val_loss: 3.6667e-05 - 6s/epoch - 4ms/step
# Epoch 286/500
# 1749/1749 - 6s - loss: 9.0604e-05 - val_loss: 3.7284e-05 - 6s/epoch - 3ms/step
# Epoch 287/500
# 1749/1749 - 7s - loss: 9.0575e-05 - val_loss: 3.7663e-05 - 7s/epoch - 4ms/step
# Epoch 288/500
# 1749/1749 - 7s - loss: 9.0613e-05 - val_loss: 3.7807e-05 - 7s/epoch - 4ms/step
# Epoch 289/500
# 1749/1749 - 9s - loss: 9.0566e-05 - val_loss: 3.7371e-05 - 9s/epoch - 5ms/step
# Epoch 290/500
# 1749/1749 - 7s - loss: 9.0380e-05 - val_loss: 3.6820e-05 - 7s/epoch - 4ms/step
# Epoch 291/500
# 1749/1749 - 7s - loss: 9.0537e-05 - val_loss: 3.7835e-05 - 7s/epoch - 4ms/step
# Epoch 292/500
# 1749/1749 - 6s - loss: 9.0488e-05 - val_loss: 3.8073e-05 - 6s/epoch - 4ms/step
# Epoch 293/500
# 1749/1749 - 6s - loss: 9.0455e-05 - val_loss: 3.8079e-05 - 6s/epoch - 3ms/step
# Epoch 294/500
# 1749/1749 - 6s - loss: 9.0437e-05 - val_loss: 3.8113e-05 - 6s/epoch - 3ms/step
# Epoch 295/500
# 1749/1749 - 7s - loss: 9.0529e-05 - val_loss: 3.7717e-05 - 7s/epoch - 4ms/step
# Epoch 296/500
# 1749/1749 - 6s - loss: 9.0302e-05 - val_loss: 3.6770e-05 - 6s/epoch - 3ms/step
# Epoch 297/500
# 1749/1749 - 6s - loss: 9.0332e-05 - val_loss: 3.6841e-05 - 6s/epoch - 3ms/step
# Epoch 298/500
# 1749/1749 - 6s - loss: 9.0283e-05 - val_loss: 3.7088e-05 - 6s/epoch - 3ms/step
# Epoch 299/500
# 1749/1749 - 7s - loss: 9.0338e-05 - val_loss: 3.7760e-05 - 7s/epoch - 4ms/step
# Epoch 300/500
# 1749/1749 - 6s - loss: 9.0300e-05 - val_loss: 3.8093e-05 - 6s/epoch - 3ms/step
# Epoch 301/500
# 1749/1749 - 6s - loss: 9.0316e-05 - val_loss: 3.8260e-05 - 6s/epoch - 3ms/step
# Epoch 302/500
# 1749/1749 - 6s - loss: 9.0283e-05 - val_loss: 3.8369e-05 - 6s/epoch - 4ms/step
# Epoch 303/500
# 1749/1749 - 6s - loss: 9.0195e-05 - val_loss: 3.8288e-05 - 6s/epoch - 3ms/step
# Epoch 304/500
# 1749/1749 - 7s - loss: 9.0238e-05 - val_loss: 3.8353e-05 - 7s/epoch - 4ms/step
# Epoch 305/500
# 1749/1749 - 8s - loss: 9.0168e-05 - val_loss: 3.7459e-05 - 8s/epoch - 4ms/step
# Epoch 306/500
# 1749/1749 - 6s - loss: 9.0057e-05 - val_loss: 3.7029e-05 - 6s/epoch - 3ms/step
# Epoch 307/500
# 1749/1749 - 8s - loss: 9.0049e-05 - val_loss: 3.7296e-05 - 8s/epoch - 5ms/step
# Epoch 308/500
# 1749/1749 - 7s - loss: 9.0057e-05 - val_loss: 3.7739e-05 - 7s/epoch - 4ms/step
# Epoch 309/500
# 1749/1749 - 12s - loss: 9.0045e-05 - val_loss: 3.8138e-05 - 12s/epoch - 7ms/step
# Epoch 310/500
# 1749/1749 - 6s - loss: 9.0018e-05 - val_loss: 3.8082e-05 - 6s/epoch - 4ms/step
# Epoch 311/500
# 1749/1749 - 9s - loss: 8.9922e-05 - val_loss: 3.7806e-05 - 9s/epoch - 5ms/step
# Epoch 312/500
# 1749/1749 - 14s - loss: 8.9985e-05 - val_loss: 3.8099e-05 - 14s/epoch - 8ms/step
# Epoch 313/500
# 1749/1749 - 5s - loss: 8.9898e-05 - val_loss: 3.8070e-05 - 5s/epoch - 3ms/step
# Epoch 314/500
# 1749/1749 - 6s - loss: 8.9829e-05 - val_loss: 3.8070e-05 - 6s/epoch - 3ms/step
# Epoch 315/500
# 1749/1749 - 6s - loss: 8.9836e-05 - val_loss: 3.8075e-05 - 6s/epoch - 3ms/step
# Epoch 316/500
# 1749/1749 - 6s - loss: 8.9700e-05 - val_loss: 3.7423e-05 - 6s/epoch - 3ms/step
# Epoch 317/500
# 1749/1749 - 6s - loss: 8.9608e-05 - val_loss: 3.7160e-05 - 6s/epoch - 3ms/step
# Epoch 318/500
# 1749/1749 - 6s - loss: 8.9599e-05 - val_loss: 3.7338e-05 - 6s/epoch - 3ms/step
# Epoch 319/500
# 1749/1749 - 5s - loss: 8.9574e-05 - val_loss: 3.7615e-05 - 5s/epoch - 3ms/step
# Epoch 320/500
# 1749/1749 - 5s - loss: 8.9557e-05 - val_loss: 3.7663e-05 - 5s/epoch - 3ms/step
# Epoch 321/500
# 1749/1749 - 6s - loss: 8.9548e-05 - val_loss: 3.7399e-05 - 6s/epoch - 4ms/step
# Epoch 322/500
# 1749/1749 - 6s - loss: 8.9478e-05 - val_loss: 3.7605e-05 - 6s/epoch - 3ms/step
# Epoch 323/500
# 1749/1749 - 6s - loss: 8.9513e-05 - val_loss: 3.7872e-05 - 6s/epoch - 3ms/step
# Epoch 324/500
# 1749/1749 - 6s - loss: 8.9538e-05 - val_loss: 3.7509e-05 - 6s/epoch - 3ms/step
# Epoch 325/500
# 1749/1749 - 6s - loss: 8.9369e-05 - val_loss: 3.7218e-05 - 6s/epoch - 3ms/step
# Epoch 326/500
# 1749/1749 - 6s - loss: 8.9384e-05 - val_loss: 3.7389e-05 - 6s/epoch - 3ms/step
# Epoch 327/500
# 1749/1749 - 6s - loss: 8.9366e-05 - val_loss: 3.7473e-05 - 6s/epoch - 3ms/step
# Epoch 328/500
# 1749/1749 - 6s - loss: 8.9360e-05 - val_loss: 3.7712e-05 - 6s/epoch - 4ms/step
# Epoch 329/500
# 1749/1749 - 7s - loss: 8.9484e-05 - val_loss: 3.7761e-05 - 7s/epoch - 4ms/step
# Epoch 330/500
# 1749/1749 - 6s - loss: 8.9204e-05 - val_loss: 3.7260e-05 - 6s/epoch - 4ms/step
# Epoch 331/500
# 1749/1749 - 6s - loss: 8.9292e-05 - val_loss: 3.7475e-05 - 6s/epoch - 4ms/step
# Epoch 332/500
# 1749/1749 - 6s - loss: 8.9214e-05 - val_loss: 3.7275e-05 - 6s/epoch - 3ms/step
# Epoch 333/500
# 1749/1749 - 6s - loss: 8.9228e-05 - val_loss: 3.7382e-05 - 6s/epoch - 3ms/step
# Epoch 334/500
# 1749/1749 - 6s - loss: 8.9238e-05 - val_loss: 3.7407e-05 - 6s/epoch - 4ms/step
# Epoch 335/500
# 1749/1749 - 6s - loss: 8.9166e-05 - val_loss: 3.7484e-05 - 6s/epoch - 3ms/step
# Epoch 336/500
# 1749/1749 - 7s - loss: 8.9203e-05 - val_loss: 3.7531e-05 - 7s/epoch - 4ms/step
# Epoch 337/500
# 1749/1749 - 7s - loss: 8.9118e-05 - val_loss: 3.7227e-05 - 7s/epoch - 4ms/step
# Epoch 338/500
# 1749/1749 - 6s - loss: 8.9084e-05 - val_loss: 3.7056e-05 - 6s/epoch - 3ms/step
# Epoch 339/500
# 1749/1749 - 6s - loss: 8.9040e-05 - val_loss: 3.7134e-05 - 6s/epoch - 3ms/step
# Epoch 340/500
# 1749/1749 - 6s - loss: 8.9033e-05 - val_loss: 3.7197e-05 - 6s/epoch - 3ms/step
# Epoch 341/500
# 1749/1749 - 6s - loss: 8.9021e-05 - val_loss: 3.7374e-05 - 6s/epoch - 3ms/step
# Epoch 342/500
# 1749/1749 - 6s - loss: 8.8957e-05 - val_loss: 3.7206e-05 - 6s/epoch - 3ms/step
# Epoch 343/500
# 1749/1749 - 6s - loss: 8.8958e-05 - val_loss: 3.6876e-05 - 6s/epoch - 4ms/step
# Epoch 344/500
# 1749/1749 - 6s - loss: 8.9009e-05 - val_loss: 3.7056e-05 - 6s/epoch - 3ms/step
# Epoch 345/500
# 1749/1749 - 5s - loss: 8.8894e-05 - val_loss: 3.7066e-05 - 5s/epoch - 3ms/step
# Epoch 346/500
# 1749/1749 - 6s - loss: 8.8867e-05 - val_loss: 3.7139e-05 - 6s/epoch - 3ms/step
# Epoch 347/500
# 1749/1749 - 6s - loss: 8.8956e-05 - val_loss: 3.7161e-05 - 6s/epoch - 4ms/step
# Epoch 348/500
# 1749/1749 - 6s - loss: 8.8714e-05 - val_loss: 3.6849e-05 - 6s/epoch - 3ms/step
# Epoch 349/500
# 1749/1749 - 5s - loss: 8.8738e-05 - val_loss: 3.6918e-05 - 5s/epoch - 3ms/step
# Epoch 350/500
# 1749/1749 - 6s - loss: 8.8704e-05 - val_loss: 3.6723e-05 - 6s/epoch - 3ms/step
# Epoch 351/500
# 1749/1749 - 5s - loss: 8.8697e-05 - val_loss: 3.6817e-05 - 5s/epoch - 3ms/step
# Epoch 352/500
# 1749/1749 - 6s - loss: 8.8661e-05 - val_loss: 3.6785e-05 - 6s/epoch - 3ms/step
# Epoch 353/500
# 1749/1749 - 6s - loss: 8.8637e-05 - val_loss: 3.6847e-05 - 6s/epoch - 3ms/step
# Epoch 354/500
# 1749/1749 - 6s - loss: 8.8797e-05 - val_loss: 3.6999e-05 - 6s/epoch - 3ms/step
# Epoch 355/500
# 1749/1749 - 6s - loss: 8.8622e-05 - val_loss: 3.6601e-05 - 6s/epoch - 3ms/step
# Epoch 356/500
# 1749/1749 - 6s - loss: 8.8568e-05 - val_loss: 3.6666e-05 - 6s/epoch - 3ms/step
# Epoch 357/500
# 1749/1749 - 6s - loss: 8.8548e-05 - val_loss: 3.6770e-05 - 6s/epoch - 3ms/step
# Epoch 358/500
# 1749/1749 - 6s - loss: 8.8495e-05 - val_loss: 3.6632e-05 - 6s/epoch - 3ms/step
# Epoch 359/500
# 1749/1749 - 6s - loss: 8.8505e-05 - val_loss: 3.6906e-05 - 6s/epoch - 3ms/step
# Epoch 360/500
# 1749/1749 - 6s - loss: 8.8671e-05 - val_loss: 3.6910e-05 - 6s/epoch - 3ms/step
# Epoch 361/500
# 1749/1749 - 6s - loss: 8.8396e-05 - val_loss: 3.6555e-05 - 6s/epoch - 3ms/step
# Epoch 362/500
# 1749/1749 - 6s - loss: 8.8409e-05 - val_loss: 3.6736e-05 - 6s/epoch - 3ms/step
# Epoch 363/500
# 1749/1749 - 6s - loss: 8.8437e-05 - val_loss: 3.6747e-05 - 6s/epoch - 3ms/step
# Epoch 364/500
# 1749/1749 - 6s - loss: 8.8312e-05 - val_loss: 3.6451e-05 - 6s/epoch - 3ms/step
# Epoch 365/500
# 1749/1749 - 6s - loss: 8.8414e-05 - val_loss: 3.6563e-05 - 6s/epoch - 3ms/step
# Epoch 366/500
# 1749/1749 - 6s - loss: 8.8368e-05 - val_loss: 3.6641e-05 - 6s/epoch - 3ms/step
# Epoch 367/500
# 1749/1749 - 6s - loss: 8.8326e-05 - val_loss: 3.6681e-05 - 6s/epoch - 4ms/step
# Epoch 368/500
# 1749/1749 - 7s - loss: 8.8479e-05 - val_loss: 3.6850e-05 - 7s/epoch - 4ms/step
# Epoch 369/500
# 1749/1749 - 6s - loss: 8.8264e-05 - val_loss: 3.6596e-05 - 6s/epoch - 3ms/step
# Epoch 370/500
# 1749/1749 - 6s - loss: 8.8304e-05 - val_loss: 3.6730e-05 - 6s/epoch - 4ms/step
# Epoch 371/500
# 1749/1749 - 6s - loss: 8.8249e-05 - val_loss: 3.6596e-05 - 6s/epoch - 3ms/step
# Epoch 372/500
# 1749/1749 - 6s - loss: 8.8273e-05 - val_loss: 3.6771e-05 - 6s/epoch - 3ms/step
# Epoch 373/500
# 1749/1749 - 6s - loss: 8.8191e-05 - val_loss: 3.6587e-05 - 6s/epoch - 3ms/step
# Epoch 374/500
# 1749/1749 - 6s - loss: 8.8288e-05 - val_loss: 3.6422e-05 - 6s/epoch - 3ms/step
# Epoch 375/500
# 1749/1749 - 6s - loss: 8.8251e-05 - val_loss: 3.6660e-05 - 6s/epoch - 3ms/step
# Epoch 376/500
# 1749/1749 - 6s - loss: 8.8268e-05 - val_loss: 3.6773e-05 - 6s/epoch - 3ms/step
# Epoch 377/500
# 1749/1749 - 6s - loss: 8.8335e-05 - val_loss: 3.6663e-05 - 6s/epoch - 3ms/step
# Epoch 378/500
# 1749/1749 - 5s - loss: 8.8156e-05 - val_loss: 3.6550e-05 - 5s/epoch - 3ms/step
# Epoch 379/500
# 1749/1749 - 5s - loss: 8.8140e-05 - val_loss: 3.6569e-05 - 5s/epoch - 3ms/step
# Epoch 380/500
# 1749/1749 - 5s - loss: 8.8197e-05 - val_loss: 3.6734e-05 - 5s/epoch - 3ms/step
# Epoch 381/500
# 1749/1749 - 6s - loss: 8.8089e-05 - val_loss: 3.6638e-05 - 6s/epoch - 3ms/step
# Epoch 382/500
# 1749/1749 - 6s - loss: 8.8125e-05 - val_loss: 3.6577e-05 - 6s/epoch - 3ms/step
# Epoch 383/500
# 1749/1749 - 6s - loss: 8.8048e-05 - val_loss: 3.6368e-05 - 6s/epoch - 3ms/step
# Epoch 384/500
# 1749/1749 - 6s - loss: 8.8144e-05 - val_loss: 3.6462e-05 - 6s/epoch - 3ms/step
# Epoch 385/500
# 1749/1749 - 6s - loss: 8.8097e-05 - val_loss: 3.6572e-05 - 6s/epoch - 3ms/step
# Epoch 386/500
# 1749/1749 - 6s - loss: 8.8276e-05 - val_loss: 3.6770e-05 - 6s/epoch - 4ms/step
# Epoch 387/500
# 1749/1749 - 6s - loss: 8.8091e-05 - val_loss: 3.6466e-05 - 6s/epoch - 3ms/step
# Epoch 388/500
# 1749/1749 - 6s - loss: 8.8022e-05 - val_loss: 3.6500e-05 - 6s/epoch - 3ms/step
# Epoch 389/500
# 1749/1749 - 5s - loss: 8.8012e-05 - val_loss: 3.6363e-05 - 5s/epoch - 3ms/step
# Epoch 390/500
# 1749/1749 - 6s - loss: 8.8041e-05 - val_loss: 3.6630e-05 - 6s/epoch - 3ms/step
# Epoch 391/500
# 1749/1749 - 6s - loss: 8.8164e-05 - val_loss: 3.6660e-05 - 6s/epoch - 3ms/step
# Epoch 392/500
# 1749/1749 - 6s - loss: 8.7951e-05 - val_loss: 3.6367e-05 - 6s/epoch - 3ms/step
# Epoch 393/500
# 1749/1749 - 6s - loss: 8.7971e-05 - val_loss: 3.6475e-05 - 6s/epoch - 3ms/step
# Epoch 394/500
# 1749/1749 - 5s - loss: 8.7978e-05 - val_loss: 3.6471e-05 - 5s/epoch - 3ms/step
# Epoch 395/500
# 1749/1749 - 5s - loss: 8.7930e-05 - val_loss: 3.6496e-05 - 5s/epoch - 3ms/step
# Epoch 396/500
# 1749/1749 - 5s - loss: 8.7969e-05 - val_loss: 3.6122e-05 - 5s/epoch - 3ms/step
# Epoch 397/500
# 1749/1749 - 5s - loss: 8.8043e-05 - val_loss: 3.6392e-05 - 5s/epoch - 3ms/step
# Epoch 398/500
# 1749/1749 - 5s - loss: 8.7950e-05 - val_loss: 3.6428e-05 - 5s/epoch - 3ms/step
# Epoch 399/500
# 1749/1749 - 5s - loss: 8.8022e-05 - val_loss: 3.6569e-05 - 5s/epoch - 3ms/step
# Epoch 400/500
# 1749/1749 - 5s - loss: 8.7927e-05 - val_loss: 3.6371e-05 - 5s/epoch - 3ms/step
# Epoch 401/500
# 1749/1749 - 5s - loss: 8.7848e-05 - val_loss: 3.6288e-05 - 5s/epoch - 3ms/step
# Epoch 402/500
# 1749/1749 - 5s - loss: 8.7902e-05 - val_loss: 3.6479e-05 - 5s/epoch - 3ms/step
# Epoch 403/500
# 1749/1749 - 5s - loss: 8.7775e-05 - val_loss: 3.6263e-05 - 5s/epoch - 3ms/step
# Epoch 404/500
# 1749/1749 - 6s - loss: 8.7832e-05 - val_loss: 3.6170e-05 - 6s/epoch - 3ms/step
# Epoch 405/500
# 1749/1749 - 5s - loss: 8.7848e-05 - val_loss: 3.6278e-05 - 5s/epoch - 3ms/step
# Epoch 406/500
# 1749/1749 - 5s - loss: 8.7843e-05 - val_loss: 3.6409e-05 - 5s/epoch - 3ms/step
# Epoch 407/500
# 1749/1749 - 6s - loss: 8.8060e-05 - val_loss: 3.6498e-05 - 6s/epoch - 3ms/step
# Epoch 408/500
# 1749/1749 - 5s - loss: 8.7746e-05 - val_loss: 3.6194e-05 - 5s/epoch - 3ms/step
# Epoch 409/500
# 1749/1749 - 6s - loss: 8.7753e-05 - val_loss: 3.6307e-05 - 6s/epoch - 3ms/step
# Epoch 410/500
# 1749/1749 - 5s - loss: 8.7730e-05 - val_loss: 3.6245e-05 - 5s/epoch - 3ms/step
# Epoch 411/500
# 1749/1749 - 5s - loss: 8.7711e-05 - val_loss: 3.6036e-05 - 5s/epoch - 3ms/step
# Epoch 412/500
# 1749/1749 - 5s - loss: 8.7765e-05 - val_loss: 3.6273e-05 - 5s/epoch - 3ms/step
# Epoch 413/500
# 1749/1749 - 6s - loss: 8.7866e-05 - val_loss: 3.6459e-05 - 6s/epoch - 3ms/step
# Epoch 414/500
# 1749/1749 - 5s - loss: 8.7773e-05 - val_loss: 3.6242e-05 - 5s/epoch - 3ms/step
# Epoch 415/500
# 1749/1749 - 5s - loss: 8.7675e-05 - val_loss: 3.6255e-05 - 5s/epoch - 3ms/step
# Epoch 416/500
# 1749/1749 - 5s - loss: 8.7664e-05 - val_loss: 3.6087e-05 - 5s/epoch - 3ms/step
# Epoch 417/500
# 1749/1749 - 5s - loss: 8.7697e-05 - val_loss: 3.6360e-05 - 5s/epoch - 3ms/step
# Epoch 418/500
# 1749/1749 - 5s - loss: 8.8048e-05 - val_loss: 3.6563e-05 - 5s/epoch - 3ms/step
# Epoch 419/500
# 1749/1749 - 5s - loss: 8.7606e-05 - val_loss: 3.6094e-05 - 5s/epoch - 3ms/step
# Epoch 420/500
# 1749/1749 - 5s - loss: 8.7601e-05 - val_loss: 3.6245e-05 - 5s/epoch - 3ms/step
# Epoch 421/500
# 1749/1749 - 6s - loss: 8.7697e-05 - val_loss: 3.6293e-05 - 6s/epoch - 4ms/step
# Epoch 422/500
# 1749/1749 - 6s - loss: 8.7559e-05 - val_loss: 3.5934e-05 - 6s/epoch - 3ms/step
# Epoch 423/500
# 1749/1749 - 6s - loss: 8.7652e-05 - val_loss: 3.6094e-05 - 6s/epoch - 3ms/step
# Epoch 424/500
# 1749/1749 - 5s - loss: 8.7616e-05 - val_loss: 3.6163e-05 - 5s/epoch - 3ms/step
# Epoch 425/500
# 1749/1749 - 5s - loss: 8.7650e-05 - val_loss: 3.6303e-05 - 5s/epoch - 3ms/step
# Epoch 426/500
# 1749/1749 - 5s - loss: 8.7632e-05 - val_loss: 3.6221e-05 - 5s/epoch - 3ms/step
# Epoch 427/500
# 1749/1749 - 5s - loss: 8.7539e-05 - val_loss: 3.6054e-05 - 5s/epoch - 3ms/step
# Epoch 428/500
# 1749/1749 - 5s - loss: 8.7583e-05 - val_loss: 3.6261e-05 - 5s/epoch - 3ms/step
# Epoch 429/500
# 1749/1749 - 5s - loss: 8.7468e-05 - val_loss: 3.6046e-05 - 5s/epoch - 3ms/step
# Epoch 430/500
# 1749/1749 - 5s - loss: 8.7519e-05 - val_loss: 3.5985e-05 - 5s/epoch - 3ms/step
# Epoch 431/500
# 1749/1749 - 6s - loss: 8.7529e-05 - val_loss: 3.6088e-05 - 6s/epoch - 4ms/step
# Epoch 432/500
# 1749/1749 - 6s - loss: 8.7535e-05 - val_loss: 3.6219e-05 - 6s/epoch - 3ms/step
# Epoch 433/500
# 1749/1749 - 5s - loss: 8.7660e-05 - val_loss: 3.6289e-05 - 5s/epoch - 3ms/step
# Epoch 434/500
# 1749/1749 - 5s - loss: 8.7450e-05 - val_loss: 3.6065e-05 - 5s/epoch - 3ms/step
# Epoch 435/500
# 1749/1749 - 6s - loss: 8.7456e-05 - val_loss: 3.6121e-05 - 6s/epoch - 4ms/step
# Epoch 436/500
# 1749/1749 - 5s - loss: 8.7412e-05 - val_loss: 3.6055e-05 - 5s/epoch - 3ms/step
# Epoch 437/500
# 1749/1749 - 6s - loss: 8.7637e-05 - val_loss: 3.5768e-05 - 6s/epoch - 3ms/step
# Epoch 438/500
# 1749/1749 - 5s - loss: 8.7403e-05 - val_loss: 3.6068e-05 - 5s/epoch - 3ms/step
# Epoch 439/500
# 1749/1749 - 5s - loss: 8.7525e-05 - val_loss: 3.6236e-05 - 5s/epoch - 3ms/step
# Epoch 440/500
# 1749/1749 - 5s - loss: 8.7468e-05 - val_loss: 3.6086e-05 - 5s/epoch - 3ms/step
# Epoch 441/500
# 1749/1749 - 5s - loss: 8.7370e-05 - val_loss: 3.6111e-05 - 5s/epoch - 3ms/step
# Epoch 442/500
# 1749/1749 - 5s - loss: 8.7360e-05 - val_loss: 3.5923e-05 - 5s/epoch - 3ms/step
# Epoch 443/500
# 1749/1749 - 6s - loss: 8.7408e-05 - val_loss: 3.6204e-05 - 6s/epoch - 3ms/step
# Epoch 444/500
# 1749/1749 - 5s - loss: 8.7864e-05 - val_loss: 3.6497e-05 - 5s/epoch - 3ms/step
# Epoch 445/500
# 1749/1749 - 6s - loss: 8.7313e-05 - val_loss: 3.5978e-05 - 6s/epoch - 3ms/step
# Epoch 446/500
# 1749/1749 - 5s - loss: 8.7316e-05 - val_loss: 3.6164e-05 - 5s/epoch - 3ms/step
# Epoch 447/500
# 1749/1749 - 5s - loss: 8.7401e-05 - val_loss: 3.6215e-05 - 5s/epoch - 3ms/step
# Epoch 448/500
# 1749/1749 - 6s - loss: 8.7323e-05 - val_loss: 3.5819e-05 - 6s/epoch - 3ms/step
# Epoch 449/500
# 1749/1749 - 6s - loss: 8.7388e-05 - val_loss: 3.5996e-05 - 6s/epoch - 3ms/step
# Epoch 450/500
# 1749/1749 - 6s - loss: 8.7340e-05 - val_loss: 3.6071e-05 - 6s/epoch - 3ms/step
# Epoch 451/500
# 1749/1749 - 6s - loss: 8.7477e-05 - val_loss: 3.6279e-05 - 6s/epoch - 3ms/step
# Epoch 452/500
# 1749/1749 - 6s - loss: 8.7295e-05 - val_loss: 3.5987e-05 - 6s/epoch - 3ms/step
# Epoch 453/500
# 1749/1749 - 6s - loss: 8.7235e-05 - val_loss: 3.5968e-05 - 6s/epoch - 3ms/step
# Epoch 454/500
# 1749/1749 - 7s - loss: 8.7220e-05 - val_loss: 3.5963e-05 - 7s/epoch - 4ms/step
# Epoch 455/500
# 1749/1749 - 6s - loss: 8.7430e-05 - val_loss: 3.5668e-05 - 6s/epoch - 3ms/step
# Epoch 456/500
# 1749/1749 - 6s - loss: 8.7205e-05 - val_loss: 3.5963e-05 - 6s/epoch - 4ms/step
# Epoch 457/500
# 1749/1749 - 7s - loss: 8.7327e-05 - val_loss: 3.6154e-05 - 7s/epoch - 4ms/step
# Epoch 458/500
# 1749/1749 - 6s - loss: 8.7272e-05 - val_loss: 3.6013e-05 - 6s/epoch - 3ms/step
# Epoch 459/500
# 1749/1749 - 6s - loss: 8.7180e-05 - val_loss: 3.6042e-05 - 6s/epoch - 3ms/step
# Epoch 460/500
# 1749/1749 - 6s - loss: 8.7170e-05 - val_loss: 3.5841e-05 - 6s/epoch - 3ms/step
# Epoch 461/500
# 1749/1749 - 5s - loss: 8.7220e-05 - val_loss: 3.6115e-05 - 5s/epoch - 3ms/step
# Epoch 462/500
# 1749/1749 - 6s - loss: 8.7704e-05 - val_loss: 3.6471e-05 - 6s/epoch - 3ms/step
# Epoch 463/500
# 1749/1749 - 6s - loss: 8.7125e-05 - val_loss: 3.5915e-05 - 6s/epoch - 3ms/step
# Epoch 464/500
# 1749/1749 - 7s - loss: 8.7127e-05 - val_loss: 3.6095e-05 - 7s/epoch - 4ms/step
# Epoch 465/500
# 1749/1749 - 10s - loss: 8.7204e-05 - val_loss: 3.6158e-05 - 10s/epoch - 6ms/step
# Epoch 466/500
# 1749/1749 - 7s - loss: 8.7130e-05 - val_loss: 3.5787e-05 - 7s/epoch - 4ms/step
# Epoch 467/500
# 1749/1749 - 8s - loss: 8.7186e-05 - val_loss: 3.5940e-05 - 8s/epoch - 5ms/step
# Epoch 468/500
# 1749/1749 - 16s - loss: 8.7152e-05 - val_loss: 3.6024e-05 - 16s/epoch - 9ms/step
# Epoch 469/500
# 1749/1749 - 6s - loss: 8.7430e-05 - val_loss: 3.6338e-05 - 6s/epoch - 3ms/step
# Epoch 470/500
# 1749/1749 - 7s - loss: 8.7083e-05 - val_loss: 3.5890e-05 - 7s/epoch - 4ms/step
# Epoch 471/500
# 1749/1749 - 6s - loss: 8.7040e-05 - val_loss: 3.5947e-05 - 6s/epoch - 3ms/step
# Epoch 472/500
# 1749/1749 - 7s - loss: 8.7029e-05 - val_loss: 3.5814e-05 - 7s/epoch - 4ms/step
# Epoch 473/500
# 1749/1749 - 7s - loss: 8.7052e-05 - val_loss: 3.5788e-05 - 7s/epoch - 4ms/step
# Epoch 474/500
# 1749/1749 - 6s - loss: 8.7087e-05 - val_loss: 3.5981e-05 - 6s/epoch - 3ms/step
# Epoch 475/500
# 1749/1749 - 7s - loss: 8.7611e-05 - val_loss: 3.6434e-05 - 7s/epoch - 4ms/step
# Epoch 476/500
# 1749/1749 - 6s - loss: 8.6994e-05 - val_loss: 3.5862e-05 - 6s/epoch - 3ms/step
# Epoch 477/500
# 1749/1749 - 6s - loss: 8.6985e-05 - val_loss: 3.6014e-05 - 6s/epoch - 3ms/step
# Epoch 478/500
# 1749/1749 - 6s - loss: 8.6979e-05 - val_loss: 3.5922e-05 - 6s/epoch - 3ms/step
# Epoch 479/500
# 1749/1749 - 5s - loss: 8.6977e-05 - val_loss: 3.5723e-05 - 5s/epoch - 3ms/step
# Epoch 480/500
# 1749/1749 - 5s - loss: 8.7033e-05 - val_loss: 3.5971e-05 - 5s/epoch - 3ms/step
# Epoch 481/500
# 1749/1749 - 5s - loss: 8.7312e-05 - val_loss: 3.6338e-05 - 5s/epoch - 3ms/step
# Epoch 482/500
# 1749/1749 - 6s - loss: 8.6996e-05 - val_loss: 3.5912e-05 - 6s/epoch - 3ms/step
# Epoch 483/500
# 1749/1749 - 6s - loss: 8.6956e-05 - val_loss: 3.6039e-05 - 6s/epoch - 3ms/step
# Epoch 484/500
# 1749/1749 - 7s - loss: 8.6925e-05 - val_loss: 3.5860e-05 - 7s/epoch - 4ms/step
# Epoch 485/500
# 1749/1749 - 6s - loss: 8.6935e-05 - val_loss: 3.5958e-05 - 6s/epoch - 4ms/step
# Epoch 486/500
# 1749/1749 - 6s - loss: 8.7255e-05 - val_loss: 3.6376e-05 - 6s/epoch - 4ms/step
# Epoch 487/500
# 1749/1749 - 6s - loss: 8.6933e-05 - val_loss: 3.5962e-05 - 6s/epoch - 3ms/step
# Epoch 488/500
# 1749/1749 - 5s - loss: 8.6913e-05 - val_loss: 3.6093e-05 - 5s/epoch - 3ms/step
# Epoch 489/500
# 1749/1749 - 6s - loss: 8.6938e-05 - val_loss: 3.6079e-05 - 6s/epoch - 3ms/step
# Epoch 490/500
# 1749/1749 - 6s - loss: 8.7049e-05 - val_loss: 3.5642e-05 - 6s/epoch - 3ms/step
# Epoch 491/500
# 1749/1749 - 5s - loss: 8.7020e-05 - val_loss: 3.5897e-05 - 5s/epoch - 3ms/step
# Epoch 492/500
# 1749/1749 - 5s - loss: 8.6915e-05 - val_loss: 3.5947e-05 - 5s/epoch - 3ms/step
# Epoch 493/500
# 1749/1749 - 6s - loss: 8.7067e-05 - val_loss: 3.6178e-05 - 6s/epoch - 3ms/step
# Epoch 494/500
# 1749/1749 - 6s - loss: 8.6880e-05 - val_loss: 3.5896e-05 - 6s/epoch - 3ms/step
# Epoch 495/500
# 1749/1749 - 6s - loss: 8.6820e-05 - val_loss: 3.5869e-05 - 6s/epoch - 3ms/step
# Epoch 496/500
# 1749/1749 - 5s - loss: 8.6823e-05 - val_loss: 3.5694e-05 - 5s/epoch - 3ms/step
# Epoch 497/500
# 1749/1749 - 5s - loss: 8.6875e-05 - val_loss: 3.5894e-05 - 5s/epoch - 3ms/step
# Epoch 498/500
# 1749/1749 - 5s - loss: 8.7088e-05 - val_loss: 3.6227e-05 - 5s/epoch - 3ms/step
# Epoch 499/500
# 1749/1749 - 5s - loss: 8.6838e-05 - val_loss: 3.5875e-05 - 5s/epoch - 3ms/step
# Epoch 500/500
# 1749/1749 - 5s - loss: 8.6790e-05 - val_loss: 3.5963e-05 - 5s/epoch - 3ms/step

# %% [markdown]
# ## Metrics ($DPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 875/875 [==============================] - 1s 1ms/step
# (27972, 3)
# (27972, 10)
# Test RMSE: 2.723
# Test MAE: 1.912

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('Kyoto DST Index', fontsize=20)
plt.legend(fontsize=20)
plt.show()
