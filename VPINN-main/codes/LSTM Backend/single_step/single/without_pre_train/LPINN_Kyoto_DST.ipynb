# %% [markdown]
# # Time Series Prediction with Lorrenz Attractor Inspired Deep Learning ($LPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-11 20:17:19

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _KYOTO DST_

# %%
data = pd.read_csv("datasets/dst.csv")
training_set = data.iloc[:, 1]
print(training_set)
# Out:
# 0         -7
# 1        -10
# 2        -10
# 3         -6
# 4         -2
#           ..
# 139867   -16
# 139868   -14
# 139869   -14
# 139870   -15
# 139871   -14
# Name: dst, Length: 139872, dtype: int64

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 0.0416 # Hourly Data (1/24)
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 67
# 1         -72.115385
# 2           0.000000
# 3          96.153846
# 4          96.153846
# 5         120.192308
#              ...
# 139867     96.153846
# 139868     48.076923
# 139869      0.000000
# 139870    -24.038462
# 139871     24.038462
# Name: dst, Length: 139871, dtype: float64
# 2         1733.542899
# 3         2311.390533
# 4            0.000000
# 5          577.847633
# 6        -1733.542899
#              ...
# 139867       0.000000
# 139868   -1155.695266
# 139869   -1155.695266
# 139870    -577.847633
# 139871    1155.695266
# Name: dst, Length: 139870, dtype: float64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0         -72.115385
# 1           0.000000
# 2          96.153846
# 3          96.153846
# 4         120.192308
#              ...
# 139866     96.153846
# 139867     48.076923
# 139868      0.000000
# 139869    -24.038462
# 139870     24.038462
# Name: dst, Length: 139871, dtype: float64
# 0         1733.542899
# 1         2311.390533
# 2            0.000000
# 3          577.847633
# 4        -1733.542899
#              ...
# 139865       0.000000
# 139866   -1155.695266
# 139867   -1155.695266
# 139868    -577.847633
# 139869    1155.695266
# Name: dst, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lorrenz Equation_)

# %% [markdown]
# _Parameters_: $\sigma=10, \rho=28$

# %%
s=10
r=28
L = df.iloc[:, 2] + df.iloc[:, 1]*(1 + s) - df.iloc[:, 0] * s * (r - 1)
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10        -7.0      -10.0      -10.0       -6.0       -2.0        3.0
# 11       -10.0      -10.0       -6.0       -2.0        3.0        5.0
# 12       -10.0       -6.0       -2.0        3.0        5.0        5.0
# 13        -6.0       -2.0        3.0        5.0        5.0        3.0
# 14        -2.0        3.0        5.0        5.0        3.0        1.0
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)    var2(t)     var3(t)
# 10        5.0        5.0        3.0        1.0      1.0  24.038462 -577.847633
# 11        5.0        3.0        1.0        1.0      2.0   0.000000  577.847633
# 12        3.0        1.0        1.0        2.0      2.0  24.038462 -577.847633
# 13        1.0        1.0        2.0        2.0      3.0   0.000000  577.847633
# 14        1.0        2.0        2.0        3.0      3.0  24.038462  577.847633
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (139860, 13)
# (139860, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (111888, 1, 10) (111888, 3) (27972, 1, 10) (27972, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
s = tf.Variable(10, name="sigma", trainable=True, dtype=tf.float32)
r = tf.Variable(28, name="rhow", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] + y_true[:, 1]*(1 + s) - y_true[:, 0] * s * (r - 1)), (y_pred[:, 2] + y_pred[:, 1]*(1 + s) - y_pred[:, 0] * s * (r - 1)))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] + (y_pred[1:-1]-y_pred[:-2])*(1 + s) - y_pred[:-2] * s * (r - 1)
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] + (y_real[1:-1]-y_real[:-2])*(1 + s) - y_real[:-2] * s * (r - 1)
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($LPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square((y_pred[:, 2] + y_pred[:, 1]*(1 + s) - y_pred[:, 0] * s * (r - 1)))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 1749/1749 - 16s - loss: 1.4388 - val_loss: 0.6950 - 16s/epoch - 9ms/step
# Epoch 2/500
# 1749/1749 - 8s - loss: 0.6531 - val_loss: 0.6298 - 8s/epoch - 5ms/step
# Epoch 3/500
# 1749/1749 - 12s - loss: 0.5624 - val_loss: 0.5029 - 12s/epoch - 7ms/step
# Epoch 4/500
# 1749/1749 - 10s - loss: 0.4446 - val_loss: 0.4232 - 10s/epoch - 6ms/step
# Epoch 5/500
# 1749/1749 - 13s - loss: 0.3536 - val_loss: 0.3098 - 13s/epoch - 8ms/step
# Epoch 6/500
# 1749/1749 - 11s - loss: 0.2785 - val_loss: 0.2400 - 11s/epoch - 6ms/step
# Epoch 7/500
# 1749/1749 - 11s - loss: 0.2159 - val_loss: 0.1822 - 11s/epoch - 6ms/step
# Epoch 8/500
# 1749/1749 - 11s - loss: 0.1640 - val_loss: 0.1418 - 11s/epoch - 7ms/step
# Epoch 9/500
# 1749/1749 - 9s - loss: 0.1222 - val_loss: 0.2142 - 9s/epoch - 5ms/step
# Epoch 10/500
# 1749/1749 - 10s - loss: 0.0921 - val_loss: 0.0688 - 10s/epoch - 6ms/step
# Epoch 11/500
# 1749/1749 - 11s - loss: 0.0690 - val_loss: 0.0486 - 11s/epoch - 6ms/step
# Epoch 12/500
# 1749/1749 - 13s - loss: 0.0526 - val_loss: 0.0414 - 13s/epoch - 7ms/step
# Epoch 13/500
# 1749/1749 - 14s - loss: 0.0419 - val_loss: 0.0282 - 14s/epoch - 8ms/step
# Epoch 14/500
# 1749/1749 - 11s - loss: 0.0335 - val_loss: 0.0177 - 11s/epoch - 6ms/step
# Epoch 15/500
# 1749/1749 - 11s - loss: 0.0269 - val_loss: 0.0187 - 11s/epoch - 6ms/step
# Epoch 16/500
# 1749/1749 - 11s - loss: 0.0243 - val_loss: 0.1029 - 11s/epoch - 6ms/step
# Epoch 17/500
# 1749/1749 - 11s - loss: 0.0198 - val_loss: 0.0209 - 11s/epoch - 6ms/step
# Epoch 18/500
# 1749/1749 - 11s - loss: 0.0206 - val_loss: 0.0045 - 11s/epoch - 6ms/step
# Epoch 19/500
# 1749/1749 - 11s - loss: 0.0179 - val_loss: 0.0039 - 11s/epoch - 6ms/step
# Epoch 20/500
# 1749/1749 - 11s - loss: 0.0229 - val_loss: 0.0028 - 11s/epoch - 6ms/step
# Epoch 21/500
# 1749/1749 - 11s - loss: 0.0128 - val_loss: 0.0020 - 11s/epoch - 6ms/step
# Epoch 22/500
# 1749/1749 - 12s - loss: 0.0156 - val_loss: 0.0020 - 12s/epoch - 7ms/step
# Epoch 23/500
# 1749/1749 - 11s - loss: 0.0175 - val_loss: 0.0013 - 11s/epoch - 7ms/step
# Epoch 24/500
# 1749/1749 - 10s - loss: 0.0129 - val_loss: 0.0134 - 10s/epoch - 5ms/step
# Epoch 25/500
# 1749/1749 - 9s - loss: 0.0144 - val_loss: 0.0010 - 9s/epoch - 5ms/step
# Epoch 26/500
# 1749/1749 - 10s - loss: 0.0147 - val_loss: 0.0147 - 10s/epoch - 5ms/step
# Epoch 27/500
# 1749/1749 - 9s - loss: 0.0141 - val_loss: 0.0013 - 9s/epoch - 5ms/step
# Epoch 28/500
# 1749/1749 - 8s - loss: 0.0144 - val_loss: 0.0032 - 8s/epoch - 5ms/step
# Epoch 29/500
# 1749/1749 - 8s - loss: 0.0132 - val_loss: 0.0029 - 8s/epoch - 4ms/step
# Epoch 30/500
# 1749/1749 - 8s - loss: 0.0141 - val_loss: 0.0149 - 8s/epoch - 5ms/step
# Epoch 31/500
# 1749/1749 - 8s - loss: 0.0153 - val_loss: 0.0031 - 8s/epoch - 4ms/step
# Epoch 32/500
# 1749/1749 - 8s - loss: 0.0122 - val_loss: 0.0126 - 8s/epoch - 5ms/step
# Epoch 33/500
# 1749/1749 - 8s - loss: 0.0132 - val_loss: 0.0148 - 8s/epoch - 4ms/step
# Epoch 34/500
# 1749/1749 - 9s - loss: 0.0159 - val_loss: 6.4065e-04 - 9s/epoch - 5ms/step
# Epoch 35/500
# 1749/1749 - 8s - loss: 0.0117 - val_loss: 0.0014 - 8s/epoch - 5ms/step
# Epoch 36/500
# 1749/1749 - 9s - loss: 0.0117 - val_loss: 0.0015 - 9s/epoch - 5ms/step
# Epoch 37/500
# 1749/1749 - 8s - loss: 0.0121 - val_loss: 0.0107 - 8s/epoch - 5ms/step
# Epoch 38/500
# 1749/1749 - 8s - loss: 0.0132 - val_loss: 8.6319e-04 - 8s/epoch - 4ms/step
# Epoch 39/500
# 1749/1749 - 8s - loss: 0.0117 - val_loss: 0.0085 - 8s/epoch - 5ms/step
# Epoch 40/500
# 1749/1749 - 8s - loss: 0.0122 - val_loss: 7.3195e-04 - 8s/epoch - 5ms/step
# Epoch 41/500
# 1749/1749 - 8s - loss: 0.0144 - val_loss: 0.0030 - 8s/epoch - 5ms/step
# Epoch 42/500
# 1749/1749 - 8s - loss: 0.0090 - val_loss: 0.0239 - 8s/epoch - 5ms/step
# Epoch 43/500
# 1749/1749 - 8s - loss: 0.0117 - val_loss: 0.0014 - 8s/epoch - 5ms/step
# Epoch 44/500
# 1749/1749 - 8s - loss: 0.0114 - val_loss: 0.0041 - 8s/epoch - 4ms/step
# Epoch 45/500
# 1749/1749 - 8s - loss: 0.0119 - val_loss: 0.0132 - 8s/epoch - 4ms/step
# Epoch 46/500
# 1749/1749 - 8s - loss: 0.0122 - val_loss: 0.0012 - 8s/epoch - 4ms/step
# Epoch 47/500
# 1749/1749 - 8s - loss: 0.0110 - val_loss: 0.0112 - 8s/epoch - 5ms/step
# Epoch 48/500
# 1749/1749 - 8s - loss: 0.0117 - val_loss: 8.5145e-04 - 8s/epoch - 4ms/step
# Epoch 49/500
# 1749/1749 - 7s - loss: 0.0109 - val_loss: 0.0083 - 7s/epoch - 4ms/step
# Epoch 50/500
# 1749/1749 - 8s - loss: 0.0106 - val_loss: 0.0312 - 8s/epoch - 5ms/step
# Epoch 51/500
# 1749/1749 - 10s - loss: 0.0116 - val_loss: 5.4924e-04 - 10s/epoch - 5ms/step
# Epoch 52/500
# 1749/1749 - 9s - loss: 0.0105 - val_loss: 6.8177e-04 - 9s/epoch - 5ms/step
# Epoch 53/500
# 1749/1749 - 13s - loss: 0.0116 - val_loss: 5.9277e-04 - 13s/epoch - 8ms/step
# Epoch 54/500
# 1749/1749 - 11s - loss: 0.0109 - val_loss: 0.0026 - 11s/epoch - 6ms/step
# Epoch 55/500
# 1749/1749 - 12s - loss: 0.0105 - val_loss: 0.0138 - 12s/epoch - 7ms/step
# Epoch 56/500
# 1749/1749 - 13s - loss: 0.0108 - val_loss: 0.0040 - 13s/epoch - 8ms/step
# Epoch 57/500
# 1749/1749 - 12s - loss: 0.0118 - val_loss: 9.7254e-04 - 12s/epoch - 7ms/step
# Epoch 58/500
# 1749/1749 - 12s - loss: 0.0090 - val_loss: 0.0043 - 12s/epoch - 7ms/step
# Epoch 59/500
# 1749/1749 - 11s - loss: 0.0115 - val_loss: 7.0655e-04 - 11s/epoch - 6ms/step
# Epoch 60/500
# 1749/1749 - 10s - loss: 0.0098 - val_loss: 0.0020 - 10s/epoch - 6ms/step
# Epoch 61/500
# 1749/1749 - 10s - loss: 0.0100 - val_loss: 0.0052 - 10s/epoch - 6ms/step
# Epoch 62/500
# 1749/1749 - 9s - loss: 0.0107 - val_loss: 0.0018 - 9s/epoch - 5ms/step
# Epoch 63/500
# 1749/1749 - 8s - loss: 0.0100 - val_loss: 8.2248e-04 - 8s/epoch - 5ms/step
# Epoch 64/500
# 1749/1749 - 8s - loss: 0.0104 - val_loss: 0.0051 - 8s/epoch - 5ms/step
# Epoch 65/500
# 1749/1749 - 8s - loss: 0.0099 - val_loss: 0.0028 - 8s/epoch - 5ms/step
# Epoch 66/500
# 1749/1749 - 8s - loss: 0.0097 - val_loss: 0.0012 - 8s/epoch - 5ms/step
# Epoch 67/500
# 1749/1749 - 10s - loss: 0.0116 - val_loss: 6.7338e-04 - 10s/epoch - 6ms/step
# Epoch 68/500
# 1749/1749 - 10s - loss: 0.0097 - val_loss: 0.0053 - 10s/epoch - 6ms/step
# Epoch 69/500
# 1749/1749 - 10s - loss: 0.0091 - val_loss: 0.0021 - 10s/epoch - 6ms/step
# Epoch 70/500
# 1749/1749 - 12s - loss: 0.0095 - val_loss: 8.5931e-04 - 12s/epoch - 7ms/step
# Epoch 71/500
# 1749/1749 - 12s - loss: 0.0096 - val_loss: 0.0032 - 12s/epoch - 7ms/step
# Epoch 72/500
# 1749/1749 - 15s - loss: 0.0095 - val_loss: 0.0032 - 15s/epoch - 9ms/step
# Epoch 73/500
# 1749/1749 - 15s - loss: 0.0108 - val_loss: 0.0035 - 15s/epoch - 9ms/step
# Epoch 74/500
# 1749/1749 - 19s - loss: 0.0094 - val_loss: 0.0049 - 19s/epoch - 11ms/step
# Epoch 75/500
# 1749/1749 - 12s - loss: 0.0086 - val_loss: 5.1276e-04 - 12s/epoch - 7ms/step
# Epoch 76/500
# 1749/1749 - 11s - loss: 0.0091 - val_loss: 6.3679e-04 - 11s/epoch - 6ms/step
# Epoch 77/500
# 1749/1749 - 12s - loss: 0.0092 - val_loss: 0.0010 - 12s/epoch - 7ms/step
# Epoch 78/500
# 1749/1749 - 12s - loss: 0.0093 - val_loss: 0.0030 - 12s/epoch - 7ms/step
# Epoch 79/500
# 1749/1749 - 10s - loss: 0.0102 - val_loss: 4.7264e-04 - 10s/epoch - 6ms/step
# Epoch 80/500
# 1749/1749 - 10s - loss: 0.0093 - val_loss: 0.0012 - 10s/epoch - 6ms/step
# Epoch 81/500
# 1749/1749 - 9s - loss: 0.0098 - val_loss: 0.0017 - 9s/epoch - 5ms/step
# Epoch 82/500
# 1749/1749 - 10s - loss: 0.0085 - val_loss: 0.0024 - 10s/epoch - 6ms/step
# Epoch 83/500
# 1749/1749 - 11s - loss: 0.0093 - val_loss: 0.0012 - 11s/epoch - 6ms/step
# Epoch 84/500
# 1749/1749 - 12s - loss: 0.0145 - val_loss: 9.1810e-04 - 12s/epoch - 7ms/step
# Epoch 85/500
# 1749/1749 - 11s - loss: 0.0063 - val_loss: 0.0012 - 11s/epoch - 6ms/step
# Epoch 86/500
# 1749/1749 - 11s - loss: 0.0097 - val_loss: 4.4243e-04 - 11s/epoch - 7ms/step
# Epoch 87/500
# 1749/1749 - 12s - loss: 0.0087 - val_loss: 0.0078 - 12s/epoch - 7ms/step
# Epoch 88/500
# 1749/1749 - 11s - loss: 0.0100 - val_loss: 0.0071 - 11s/epoch - 6ms/step
# Epoch 89/500
# 1749/1749 - 11s - loss: 0.0075 - val_loss: 0.0016 - 11s/epoch - 6ms/step
# Epoch 90/500
# 1749/1749 - 11s - loss: 0.0090 - val_loss: 9.8853e-04 - 11s/epoch - 6ms/step
# Epoch 91/500
# 1749/1749 - 8s - loss: 0.0084 - val_loss: 5.1661e-04 - 8s/epoch - 5ms/step
# Epoch 92/500
# 1749/1749 - 8s - loss: 0.0090 - val_loss: 0.0046 - 8s/epoch - 5ms/step
# Epoch 93/500
# 1749/1749 - 8s - loss: 0.0082 - val_loss: 0.0034 - 8s/epoch - 5ms/step
# Epoch 94/500
# 1749/1749 - 9s - loss: 0.0089 - val_loss: 0.0030 - 9s/epoch - 5ms/step
# Epoch 95/500
# 1749/1749 - 9s - loss: 0.0080 - val_loss: 0.0014 - 9s/epoch - 5ms/step
# Epoch 96/500
# 1749/1749 - 9s - loss: 0.0088 - val_loss: 0.0109 - 9s/epoch - 5ms/step
# Epoch 97/500
# 1749/1749 - 11s - loss: 0.0093 - val_loss: 3.5345e-04 - 11s/epoch - 6ms/step
# Epoch 98/500
# 1749/1749 - 11s - loss: 0.0082 - val_loss: 0.0159 - 11s/epoch - 6ms/step
# Epoch 99/500
# 1749/1749 - 11s - loss: 0.0084 - val_loss: 4.8310e-04 - 11s/epoch - 6ms/step
# Epoch 100/500
# 1749/1749 - 10s - loss: 0.0077 - val_loss: 0.0042 - 10s/epoch - 6ms/step
# Epoch 101/500
# 1749/1749 - 12s - loss: 0.0082 - val_loss: 0.0016 - 12s/epoch - 7ms/step
# Epoch 102/500
# 1749/1749 - 10s - loss: 0.0090 - val_loss: 3.8221e-04 - 10s/epoch - 6ms/step
# Epoch 103/500
# 1749/1749 - 10s - loss: 0.0077 - val_loss: 0.0015 - 10s/epoch - 6ms/step
# Epoch 104/500
# 1749/1749 - 11s - loss: 0.0087 - val_loss: 3.4552e-04 - 11s/epoch - 6ms/step
# Epoch 105/500
# 1749/1749 - 11s - loss: 0.0077 - val_loss: 0.0029 - 11s/epoch - 6ms/step
# Epoch 106/500
# 1749/1749 - 11s - loss: 0.0082 - val_loss: 0.0018 - 11s/epoch - 6ms/step
# Epoch 107/500
# 1749/1749 - 11s - loss: 0.0084 - val_loss: 6.1966e-04 - 11s/epoch - 6ms/step
# Epoch 108/500
# 1749/1749 - 11s - loss: 0.0090 - val_loss: 3.4353e-04 - 11s/epoch - 6ms/step
# Epoch 109/500
# 1749/1749 - 8s - loss: 0.0071 - val_loss: 0.0010 - 8s/epoch - 5ms/step
# Epoch 110/500
# 1749/1749 - 9s - loss: 0.0076 - val_loss: 4.2814e-04 - 9s/epoch - 5ms/step
# Epoch 111/500
# 1749/1749 - 9s - loss: 0.0078 - val_loss: 0.0010 - 9s/epoch - 5ms/step
# Epoch 112/500
# 1749/1749 - 8s - loss: 0.0081 - val_loss: 3.4100e-04 - 8s/epoch - 5ms/step
# Epoch 113/500
# 1749/1749 - 8s - loss: 0.0074 - val_loss: 0.0031 - 8s/epoch - 4ms/step
# Epoch 114/500
# 1749/1749 - 8s - loss: 0.0088 - val_loss: 0.0238 - 8s/epoch - 5ms/step
# Epoch 115/500
# 1749/1749 - 8s - loss: 0.0075 - val_loss: 0.0090 - 8s/epoch - 5ms/step
# Epoch 116/500
# 1749/1749 - 8s - loss: 0.0077 - val_loss: 4.8158e-04 - 8s/epoch - 5ms/step
# Epoch 117/500
# 1749/1749 - 8s - loss: 0.0078 - val_loss: 0.0011 - 8s/epoch - 5ms/step
# Epoch 118/500
# 1749/1749 - 8s - loss: 0.0083 - val_loss: 0.0014 - 8s/epoch - 5ms/step
# Epoch 119/500
# 1749/1749 - 8s - loss: 0.0076 - val_loss: 3.1782e-04 - 8s/epoch - 4ms/step
# Epoch 120/500
# 1749/1749 - 8s - loss: 0.0081 - val_loss: 0.0079 - 8s/epoch - 5ms/step
# Epoch 121/500
# 1749/1749 - 8s - loss: 0.0070 - val_loss: 0.0018 - 8s/epoch - 5ms/step
# Epoch 122/500
# 1749/1749 - 8s - loss: 0.0077 - val_loss: 2.8600e-04 - 8s/epoch - 5ms/step
# Epoch 123/500
# 1749/1749 - 10s - loss: 0.0078 - val_loss: 4.0397e-04 - 10s/epoch - 5ms/step
# Epoch 124/500
# 1749/1749 - 11s - loss: 0.0076 - val_loss: 8.6460e-04 - 11s/epoch - 6ms/step
# Epoch 125/500
# 1749/1749 - 10s - loss: 0.0078 - val_loss: 2.6745e-04 - 10s/epoch - 6ms/step
# Epoch 126/500
# 1749/1749 - 10s - loss: 0.0079 - val_loss: 2.6103e-04 - 10s/epoch - 6ms/step
# Epoch 127/500
# 1749/1749 - 10s - loss: 0.0085 - val_loss: 8.6228e-04 - 10s/epoch - 6ms/step
# Epoch 128/500
# 1749/1749 - 10s - loss: 0.0071 - val_loss: 0.0083 - 10s/epoch - 6ms/step
# Epoch 129/500
# 1749/1749 - 10s - loss: 0.0080 - val_loss: 3.4683e-04 - 10s/epoch - 6ms/step
# Epoch 130/500
# 1749/1749 - 10s - loss: 0.0098 - val_loss: 3.1118e-04 - 10s/epoch - 6ms/step
# Epoch 131/500
# 1749/1749 - 12s - loss: 0.0071 - val_loss: 0.0026 - 12s/epoch - 7ms/step
# Epoch 132/500
# 1749/1749 - 12s - loss: 0.0063 - val_loss: 9.8281e-04 - 12s/epoch - 7ms/step
# Epoch 133/500
# 1749/1749 - 11s - loss: 0.0079 - val_loss: 0.0028 - 11s/epoch - 6ms/step
# Epoch 134/500
# 1749/1749 - 11s - loss: 0.0077 - val_loss: 0.0018 - 11s/epoch - 6ms/step
# Epoch 135/500
# 1749/1749 - 11s - loss: 0.0074 - val_loss: 9.7239e-04 - 11s/epoch - 6ms/step
# Epoch 136/500
# 1749/1749 - 8s - loss: 0.0077 - val_loss: 6.3808e-04 - 8s/epoch - 5ms/step
# Epoch 137/500
# 1749/1749 - 8s - loss: 0.0083 - val_loss: 5.7786e-04 - 8s/epoch - 4ms/step
# Epoch 138/500
# 1749/1749 - 8s - loss: 0.0071 - val_loss: 2.3445e-04 - 8s/epoch - 5ms/step
# Epoch 139/500
# 1749/1749 - 8s - loss: 0.0108 - val_loss: 2.7856e-04 - 8s/epoch - 5ms/step
# Epoch 140/500
# 1749/1749 - 8s - loss: 0.0056 - val_loss: 4.7144e-04 - 8s/epoch - 5ms/step
# Epoch 141/500
# 1749/1749 - 8s - loss: 0.0084 - val_loss: 5.1657e-04 - 8s/epoch - 5ms/step
# Epoch 142/500
# 1749/1749 - 8s - loss: 0.0074 - val_loss: 2.5162e-04 - 8s/epoch - 5ms/step
# Epoch 143/500
# 1749/1749 - 8s - loss: 0.0074 - val_loss: 0.0017 - 8s/epoch - 5ms/step
# Epoch 144/500
# 1749/1749 - 8s - loss: 0.0067 - val_loss: 0.0070 - 8s/epoch - 5ms/step
# Epoch 145/500
# 1749/1749 - 8s - loss: 0.0069 - val_loss: 0.0037 - 8s/epoch - 5ms/step
# Epoch 146/500
# 1749/1749 - 8s - loss: 0.0072 - val_loss: 0.0023 - 8s/epoch - 5ms/step
# Epoch 147/500
# 1749/1749 - 8s - loss: 0.0063 - val_loss: 0.0189 - 8s/epoch - 5ms/step
# Epoch 148/500
# 1749/1749 - 8s - loss: 0.0078 - val_loss: 2.7324e-04 - 8s/epoch - 5ms/step
# Epoch 149/500
# 1749/1749 - 8s - loss: 0.0066 - val_loss: 0.0023 - 8s/epoch - 5ms/step
# Epoch 150/500
# 1749/1749 - 8s - loss: 0.0067 - val_loss: 0.0043 - 8s/epoch - 5ms/step
# Epoch 151/500
# 1749/1749 - 12s - loss: 0.0071 - val_loss: 0.0037 - 12s/epoch - 7ms/step
# Epoch 152/500
# 1749/1749 - 11s - loss: 0.0071 - val_loss: 2.4042e-04 - 11s/epoch - 6ms/step
# Epoch 153/500
# 1749/1749 - 11s - loss: 0.0069 - val_loss: 9.4596e-04 - 11s/epoch - 6ms/step
# Epoch 154/500
# 1749/1749 - 11s - loss: 0.0067 - val_loss: 0.0011 - 11s/epoch - 6ms/step
# Epoch 155/500
# 1749/1749 - 10s - loss: 0.0061 - val_loss: 0.0066 - 10s/epoch - 6ms/step
# Epoch 156/500
# 1749/1749 - 10s - loss: 0.0084 - val_loss: 1.9831e-04 - 10s/epoch - 6ms/step
# Epoch 157/500
# 1749/1749 - 10s - loss: 0.0061 - val_loss: 7.9180e-04 - 10s/epoch - 6ms/step
# Epoch 158/500
# 1749/1749 - 10s - loss: 0.0064 - val_loss: 0.0069 - 10s/epoch - 6ms/step
# Epoch 159/500
# 1749/1749 - 10s - loss: 0.0070 - val_loss: 2.0182e-04 - 10s/epoch - 6ms/step
# Epoch 160/500
# 1749/1749 - 10s - loss: 0.0080 - val_loss: 6.7952e-04 - 10s/epoch - 6ms/step
# Epoch 161/500
# 1749/1749 - 10s - loss: 0.0053 - val_loss: 0.0152 - 10s/epoch - 5ms/step
# Epoch 162/500
# 1749/1749 - 12s - loss: 0.0067 - val_loss: 0.0016 - 12s/epoch - 7ms/step
# Epoch 163/500
# 1749/1749 - 20s - loss: 0.0067 - val_loss: 0.0032 - 20s/epoch - 11ms/step
# Epoch 164/500
# 1749/1749 - 20s - loss: 0.0069 - val_loss: 0.0017 - 20s/epoch - 12ms/step
# Epoch 165/500
# 1749/1749 - 10s - loss: 0.0069 - val_loss: 5.2610e-04 - 10s/epoch - 6ms/step
# Epoch 166/500
# 1749/1749 - 16s - loss: 0.0057 - val_loss: 3.7070e-04 - 16s/epoch - 9ms/step
# Epoch 167/500
# 1749/1749 - 15s - loss: 0.0069 - val_loss: 0.0011 - 15s/epoch - 8ms/step
# Epoch 168/500
# 1749/1749 - 11s - loss: 0.0060 - val_loss: 0.0074 - 11s/epoch - 6ms/step
# Epoch 169/500
# 1749/1749 - 10s - loss: 0.0101 - val_loss: 2.9261e-04 - 10s/epoch - 6ms/step
# Epoch 170/500
# 1749/1749 - 10s - loss: 0.0058 - val_loss: 1.9516e-04 - 10s/epoch - 6ms/step
# Epoch 171/500
# 1749/1749 - 8s - loss: 0.0070 - val_loss: 1.7357e-04 - 8s/epoch - 5ms/step
# Epoch 172/500
# 1749/1749 - 10s - loss: 0.0060 - val_loss: 2.2332e-04 - 10s/epoch - 6ms/step
# Epoch 173/500
# 1749/1749 - 12s - loss: 0.0079 - val_loss: 7.2927e-04 - 12s/epoch - 7ms/step
# Epoch 174/500
# 1749/1749 - 12s - loss: 0.0050 - val_loss: 1.5929e-04 - 12s/epoch - 7ms/step
# Epoch 175/500
# 1749/1749 - 13s - loss: 0.0067 - val_loss: 2.0824e-04 - 13s/epoch - 7ms/step
# Epoch 176/500
# 1749/1749 - 11s - loss: 0.0055 - val_loss: 0.0032 - 11s/epoch - 6ms/step
# Epoch 177/500
# 1749/1749 - 17s - loss: 0.0062 - val_loss: 0.0017 - 17s/epoch - 9ms/step
# Epoch 178/500
# 1749/1749 - 10s - loss: 0.0066 - val_loss: 3.3246e-04 - 10s/epoch - 6ms/step
# Epoch 179/500
# 1749/1749 - 10s - loss: 0.0065 - val_loss: 0.0029 - 10s/epoch - 6ms/step
# Epoch 180/500
# 1749/1749 - 11s - loss: 0.0064 - val_loss: 0.0074 - 11s/epoch - 7ms/step
# Epoch 181/500
# 1749/1749 - 12s - loss: 0.0075 - val_loss: 0.0013 - 12s/epoch - 7ms/step
# Epoch 182/500
# 1749/1749 - 11s - loss: 0.0059 - val_loss: 2.8076e-04 - 11s/epoch - 6ms/step
# Epoch 183/500
# 1749/1749 - 11s - loss: 0.0068 - val_loss: 1.6824e-04 - 11s/epoch - 6ms/step
# Epoch 184/500
# 1749/1749 - 11s - loss: 0.0061 - val_loss: 0.0040 - 11s/epoch - 6ms/step
# Epoch 185/500
# 1749/1749 - 11s - loss: 0.0067 - val_loss: 0.0010 - 11s/epoch - 6ms/step
# Epoch 186/500
# 1749/1749 - 11s - loss: 0.0059 - val_loss: 0.0061 - 11s/epoch - 6ms/step
# Epoch 187/500
# 1749/1749 - 11s - loss: 0.0069 - val_loss: 9.8531e-04 - 11s/epoch - 6ms/step
# Epoch 188/500
# 1749/1749 - 11s - loss: 0.0078 - val_loss: 0.0011 - 11s/epoch - 6ms/step
# Epoch 189/500
# 1749/1749 - 10s - loss: 0.0056 - val_loss: 0.0112 - 10s/epoch - 6ms/step
# Epoch 190/500
# 1749/1749 - 8s - loss: 0.0102 - val_loss: 2.0393e-04 - 8s/epoch - 5ms/step
# Epoch 191/500
# 1749/1749 - 8s - loss: 0.0049 - val_loss: 3.7599e-04 - 8s/epoch - 5ms/step
# Epoch 192/500
# 1749/1749 - 8s - loss: 0.0075 - val_loss: 5.4666e-04 - 8s/epoch - 5ms/step
# Epoch 193/500
# 1749/1749 - 8s - loss: 0.0053 - val_loss: 7.6089e-04 - 8s/epoch - 5ms/step
# Epoch 194/500
# 1749/1749 - 8s - loss: 0.0104 - val_loss: 2.7457e-04 - 8s/epoch - 5ms/step
# Epoch 195/500
# 1749/1749 - 8s - loss: 0.0057 - val_loss: 0.0043 - 8s/epoch - 5ms/step
# Epoch 196/500
# 1749/1749 - 8s - loss: 0.0109 - val_loss: 0.0024 - 8s/epoch - 5ms/step
# Epoch 197/500
# 1749/1749 - 8s - loss: 0.0039 - val_loss: 0.0018 - 8s/epoch - 5ms/step
# Epoch 198/500
# 1749/1749 - 8s - loss: 0.0060 - val_loss: 5.9554e-04 - 8s/epoch - 5ms/step
# Epoch 199/500
# 1749/1749 - 8s - loss: 0.0062 - val_loss: 1.5804e-04 - 8s/epoch - 5ms/step
# Epoch 200/500
# 1749/1749 - 10s - loss: 0.0054 - val_loss: 0.0143 - 10s/epoch - 6ms/step
# Epoch 201/500
# 1749/1749 - 9s - loss: 0.0066 - val_loss: 3.0153e-04 - 9s/epoch - 5ms/step
# Epoch 202/500
# 1749/1749 - 8s - loss: 0.0078 - val_loss: 3.4094e-04 - 8s/epoch - 5ms/step
# Epoch 203/500
# 1749/1749 - 8s - loss: 0.0091 - val_loss: 4.2448e-04 - 8s/epoch - 5ms/step
# Epoch 204/500
# 1749/1749 - 8s - loss: 0.0141 - val_loss: 3.0124e-04 - 8s/epoch - 5ms/step
# Epoch 205/500
# 1749/1749 - 7s - loss: 0.0033 - val_loss: 0.0029 - 7s/epoch - 4ms/step
# Epoch 206/500
# 1749/1749 - 5s - loss: 0.0063 - val_loss: 0.0029 - 5s/epoch - 3ms/step
# Epoch 207/500
# 1749/1749 - 6s - loss: 0.0043 - val_loss: 0.0022 - 6s/epoch - 3ms/step
# Epoch 208/500
# 1749/1749 - 7s - loss: 0.0059 - val_loss: 5.3510e-04 - 7s/epoch - 4ms/step
# Epoch 209/500
# 1749/1749 - 6s - loss: 0.0093 - val_loss: 0.0014 - 6s/epoch - 3ms/step
# Epoch 210/500
# 1749/1749 - 7s - loss: 0.0125 - val_loss: 2.2191e-04 - 7s/epoch - 4ms/step
# Epoch 211/500
# 1749/1749 - 7s - loss: 0.0032 - val_loss: 2.7642e-04 - 7s/epoch - 4ms/step
# Epoch 212/500
# 1749/1749 - 7s - loss: 0.0063 - val_loss: 0.0083 - 7s/epoch - 4ms/step
# Epoch 213/500
# 1749/1749 - 8s - loss: 0.0049 - val_loss: 6.9368e-04 - 8s/epoch - 5ms/step
# Epoch 214/500
# 1749/1749 - 8s - loss: 0.0057 - val_loss: 1.3282e-04 - 8s/epoch - 5ms/step
# Epoch 215/500
# 1749/1749 - 8s - loss: 0.0066 - val_loss: 3.1892e-04 - 8s/epoch - 4ms/step
# Epoch 216/500
# 1749/1749 - 8s - loss: 0.0082 - val_loss: 2.4001e-04 - 8s/epoch - 4ms/step
# Epoch 217/500
# 1749/1749 - 8s - loss: 0.0055 - val_loss: 2.0438e-04 - 8s/epoch - 4ms/step
# Epoch 218/500
# 1749/1749 - 9s - loss: 0.0069 - val_loss: 5.8363e-04 - 9s/epoch - 5ms/step
# Epoch 219/500
# 1749/1749 - 8s - loss: 0.0042 - val_loss: 2.4594e-04 - 8s/epoch - 4ms/step
# Epoch 220/500
# 1749/1749 - 7s - loss: 0.0061 - val_loss: 3.1199e-04 - 7s/epoch - 4ms/step
# Epoch 221/500
# 1749/1749 - 7s - loss: 0.0054 - val_loss: 3.2267e-04 - 7s/epoch - 4ms/step
# Epoch 222/500
# 1749/1749 - 5s - loss: 0.0055 - val_loss: 0.0019 - 5s/epoch - 3ms/step
# Epoch 223/500
# 1749/1749 - 5s - loss: 0.0088 - val_loss: 2.4737e-04 - 5s/epoch - 3ms/step
# Epoch 224/500
# 1749/1749 - 5s - loss: 0.0056 - val_loss: 2.5711e-04 - 5s/epoch - 3ms/step
# Epoch 225/500
# 1749/1749 - 5s - loss: 0.0062 - val_loss: 1.6307e-04 - 5s/epoch - 3ms/step
# Epoch 226/500
# 1749/1749 - 5s - loss: 0.0052 - val_loss: 0.0021 - 5s/epoch - 3ms/step
# Epoch 227/500
# 1749/1749 - 5s - loss: 0.0070 - val_loss: 2.8407e-04 - 5s/epoch - 3ms/step
# Epoch 228/500
# 1749/1749 - 5s - loss: 0.0074 - val_loss: 3.0116e-04 - 5s/epoch - 3ms/step
# Epoch 229/500
# 1749/1749 - 5s - loss: 0.0049 - val_loss: 5.8452e-04 - 5s/epoch - 3ms/step
# Epoch 230/500
# 1749/1749 - 5s - loss: 0.0057 - val_loss: 0.0016 - 5s/epoch - 3ms/step
# Epoch 231/500
# 1749/1749 - 5s - loss: 0.0067 - val_loss: 4.8878e-04 - 5s/epoch - 3ms/step
# Epoch 232/500
# 1749/1749 - 5s - loss: 0.0086 - val_loss: 1.8366e-04 - 5s/epoch - 3ms/step
# Epoch 233/500
# 1749/1749 - 5s - loss: 0.0047 - val_loss: 2.4902e-04 - 5s/epoch - 3ms/step
# Epoch 234/500
# 1749/1749 - 5s - loss: 0.0048 - val_loss: 0.0019 - 5s/epoch - 3ms/step
# Epoch 235/500
# 1749/1749 - 5s - loss: 0.0055 - val_loss: 2.1812e-04 - 5s/epoch - 3ms/step
# Epoch 236/500
# 1749/1749 - 5s - loss: 0.0104 - val_loss: 0.0015 - 5s/epoch - 3ms/step
# Epoch 237/500
# 1749/1749 - 5s - loss: 0.0029 - val_loss: 9.5881e-04 - 5s/epoch - 3ms/step
# Epoch 238/500
# 1749/1749 - 5s - loss: 0.0052 - val_loss: 0.0084 - 5s/epoch - 3ms/step
# Epoch 239/500
# 1749/1749 - 5s - loss: 0.0070 - val_loss: 0.0042 - 5s/epoch - 3ms/step
# Epoch 240/500
# 1749/1749 - 5s - loss: 0.0098 - val_loss: 1.5881e-04 - 5s/epoch - 3ms/step
# Epoch 241/500
# 1749/1749 - 5s - loss: 0.0054 - val_loss: 1.8608e-04 - 5s/epoch - 3ms/step
# Epoch 242/500
# 1749/1749 - 7s - loss: 0.0082 - val_loss: 2.6859e-04 - 7s/epoch - 4ms/step
# Epoch 243/500
# 1749/1749 - 6s - loss: 0.0070 - val_loss: 0.0053 - 6s/epoch - 3ms/step
# Epoch 244/500
# 1749/1749 - 6s - loss: 0.0050 - val_loss: 2.4770e-04 - 6s/epoch - 3ms/step
# Epoch 245/500
# 1749/1749 - 8s - loss: 0.0069 - val_loss: 0.0013 - 8s/epoch - 5ms/step
# Epoch 246/500
# 1749/1749 - 7s - loss: 0.0081 - val_loss: 4.4660e-04 - 7s/epoch - 4ms/step
# Epoch 247/500
# 1749/1749 - 7s - loss: 0.0069 - val_loss: 0.0039 - 7s/epoch - 4ms/step
# Epoch 248/500
# 1749/1749 - 7s - loss: 0.0058 - val_loss: 1.4562e-04 - 7s/epoch - 4ms/step
# Epoch 249/500
# 1749/1749 - 7s - loss: 0.0082 - val_loss: 1.7295e-04 - 7s/epoch - 4ms/step
# Epoch 250/500
# 1749/1749 - 7s - loss: 0.0038 - val_loss: 1.3296e-04 - 7s/epoch - 4ms/step
# Epoch 251/500
# 1749/1749 - 8s - loss: 0.0078 - val_loss: 1.8006e-04 - 8s/epoch - 4ms/step
# Epoch 252/500
# 1749/1749 - 8s - loss: 0.0047 - val_loss: 2.6517e-04 - 8s/epoch - 5ms/step
# Epoch 253/500
# 1749/1749 - 7s - loss: 0.0074 - val_loss: 0.0015 - 7s/epoch - 4ms/step
# Epoch 254/500
# 1749/1749 - 8s - loss: 0.0075 - val_loss: 6.1487e-04 - 8s/epoch - 4ms/step
# Epoch 255/500
# 1749/1749 - 7s - loss: 0.0049 - val_loss: 0.0018 - 7s/epoch - 4ms/step
# Epoch 256/500
# 1749/1749 - 5s - loss: 0.0093 - val_loss: 1.6778e-04 - 5s/epoch - 3ms/step
# Epoch 257/500
# 1749/1749 - 5s - loss: 0.0040 - val_loss: 0.0013 - 5s/epoch - 3ms/step
# Epoch 258/500
# 1749/1749 - 5s - loss: 0.0066 - val_loss: 0.0032 - 5s/epoch - 3ms/step
# Epoch 259/500
# 1749/1749 - 6s - loss: 0.0059 - val_loss: 4.4011e-04 - 6s/epoch - 3ms/step
# Epoch 260/500
# 1749/1749 - 5s - loss: 0.0046 - val_loss: 1.7664e-04 - 5s/epoch - 3ms/step
# Epoch 261/500
# 1749/1749 - 5s - loss: 0.0050 - val_loss: 0.0013 - 5s/epoch - 3ms/step
# Epoch 262/500
# 1749/1749 - 5s - loss: 0.0049 - val_loss: 0.0062 - 5s/epoch - 3ms/step
# Epoch 263/500
# 1749/1749 - 5s - loss: 0.0054 - val_loss: 1.6842e-04 - 5s/epoch - 3ms/step
# Epoch 264/500
# 1749/1749 - 5s - loss: 0.0042 - val_loss: 2.0291e-04 - 5s/epoch - 3ms/step
# Epoch 265/500
# 1749/1749 - 5s - loss: 0.0049 - val_loss: 0.0012 - 5s/epoch - 3ms/step
# Epoch 266/500
# 1749/1749 - 5s - loss: 0.0057 - val_loss: 7.1226e-04 - 5s/epoch - 3ms/step
# Epoch 267/500
# 1749/1749 - 5s - loss: 0.0048 - val_loss: 6.7696e-04 - 5s/epoch - 3ms/step
# Epoch 268/500
# 1749/1749 - 5s - loss: 0.0045 - val_loss: 6.4805e-04 - 5s/epoch - 3ms/step
# Epoch 269/500
# 1749/1749 - 5s - loss: 0.0045 - val_loss: 1.2218e-04 - 5s/epoch - 3ms/step
# Epoch 270/500
# 1749/1749 - 5s - loss: 0.0075 - val_loss: 0.0012 - 5s/epoch - 3ms/step
# Epoch 271/500
# 1749/1749 - 5s - loss: 0.0057 - val_loss: 3.5040e-04 - 5s/epoch - 3ms/step
# Epoch 272/500
# 1749/1749 - 5s - loss: 0.0040 - val_loss: 8.2513e-04 - 5s/epoch - 3ms/step
# Epoch 273/500
# 1749/1749 - 5s - loss: 0.0075 - val_loss: 1.7743e-04 - 5s/epoch - 3ms/step
# Epoch 274/500
# 1749/1749 - 5s - loss: 0.0062 - val_loss: 0.0014 - 5s/epoch - 3ms/step
# Epoch 275/500
# 1749/1749 - 5s - loss: 0.0073 - val_loss: 2.4153e-04 - 5s/epoch - 3ms/step
# Epoch 276/500
# 1749/1749 - 5s - loss: 0.0056 - val_loss: 0.0017 - 5s/epoch - 3ms/step
# Epoch 277/500
# 1749/1749 - 5s - loss: 0.0039 - val_loss: 0.0048 - 5s/epoch - 3ms/step
# Epoch 278/500
# 1749/1749 - 11s - loss: 0.0045 - val_loss: 2.1004e-04 - 11s/epoch - 6ms/step
# Epoch 279/500
# 1749/1749 - 5s - loss: 0.0061 - val_loss: 1.6347e-04 - 5s/epoch - 3ms/step
# Epoch 280/500
# 1749/1749 - 5s - loss: 0.0071 - val_loss: 8.2057e-04 - 5s/epoch - 3ms/step
# Epoch 281/500
# 1749/1749 - 8s - loss: 0.0034 - val_loss: 4.4875e-04 - 8s/epoch - 4ms/step
# Epoch 282/500
# 1749/1749 - 13s - loss: 0.0050 - val_loss: 1.2951e-04 - 13s/epoch - 7ms/step
# Epoch 283/500
# 1749/1749 - 5s - loss: 0.0042 - val_loss: 3.9649e-04 - 5s/epoch - 3ms/step
# Epoch 284/500
# 1749/1749 - 5s - loss: 0.0067 - val_loss: 5.4602e-04 - 5s/epoch - 3ms/step
# Epoch 285/500
# 1749/1749 - 6s - loss: 0.0063 - val_loss: 1.8946e-04 - 6s/epoch - 3ms/step
# Epoch 286/500
# 1749/1749 - 6s - loss: 0.0042 - val_loss: 1.1443e-04 - 6s/epoch - 3ms/step
# Epoch 287/500
# 1749/1749 - 5s - loss: 0.0062 - val_loss: 2.1050e-04 - 5s/epoch - 3ms/step
# Epoch 288/500
# 1749/1749 - 6s - loss: 0.0041 - val_loss: 1.1289e-04 - 6s/epoch - 3ms/step
# Epoch 289/500
# 1749/1749 - 6s - loss: 0.0040 - val_loss: 1.3120e-04 - 6s/epoch - 3ms/step
# Epoch 290/500
# 1749/1749 - 5s - loss: 0.0050 - val_loss: 4.4496e-04 - 5s/epoch - 3ms/step
# Epoch 291/500
# 1749/1749 - 5s - loss: 0.0046 - val_loss: 1.5032e-04 - 5s/epoch - 3ms/step
# Epoch 292/500
# 1749/1749 - 5s - loss: 0.0043 - val_loss: 1.8484e-04 - 5s/epoch - 3ms/step
# Epoch 293/500
# 1749/1749 - 5s - loss: 0.0044 - val_loss: 1.3037e-04 - 5s/epoch - 3ms/step
# Epoch 294/500
# 1749/1749 - 5s - loss: 0.0068 - val_loss: 2.6413e-04 - 5s/epoch - 3ms/step
# Epoch 295/500
# 1749/1749 - 5s - loss: 0.0044 - val_loss: 1.3355e-04 - 5s/epoch - 3ms/step
# Epoch 296/500
# 1749/1749 - 5s - loss: 0.0055 - val_loss: 2.0952e-04 - 5s/epoch - 3ms/step
# Epoch 297/500
# 1749/1749 - 5s - loss: 0.0068 - val_loss: 1.8021e-04 - 5s/epoch - 3ms/step
# Epoch 298/500
# 1749/1749 - 5s - loss: 0.0059 - val_loss: 1.1506e-04 - 5s/epoch - 3ms/step
# Epoch 299/500
# 1749/1749 - 5s - loss: 0.0033 - val_loss: 4.4033e-04 - 5s/epoch - 3ms/step
# Epoch 300/500
# 1749/1749 - 8s - loss: 0.0061 - val_loss: 1.8234e-04 - 8s/epoch - 4ms/step
# Epoch 301/500
# 1749/1749 - 8s - loss: 0.0117 - val_loss: 1.1275e-04 - 8s/epoch - 5ms/step
# Epoch 302/500
# 1749/1749 - 8s - loss: 0.0054 - val_loss: 1.7156e-04 - 8s/epoch - 4ms/step
# Epoch 303/500
# 1749/1749 - 8s - loss: 0.0029 - val_loss: 0.0020 - 8s/epoch - 5ms/step
# Epoch 304/500
# 1749/1749 - 8s - loss: 0.0039 - val_loss: 5.1685e-04 - 8s/epoch - 5ms/step
# Epoch 305/500
# 1749/1749 - 8s - loss: 0.0053 - val_loss: 1.1402e-04 - 8s/epoch - 5ms/step
# Epoch 306/500
# 1749/1749 - 8s - loss: 0.0068 - val_loss: 1.8575e-04 - 8s/epoch - 5ms/step
# Epoch 307/500
# 1749/1749 - 9s - loss: 0.0042 - val_loss: 1.7742e-04 - 9s/epoch - 5ms/step
# Epoch 308/500
# 1749/1749 - 9s - loss: 0.0045 - val_loss: 1.2210e-04 - 9s/epoch - 5ms/step
# Epoch 309/500
# 1749/1749 - 9s - loss: 0.0047 - val_loss: 2.0278e-04 - 9s/epoch - 5ms/step
# Epoch 310/500
# 1749/1749 - 8s - loss: 0.0065 - val_loss: 3.3510e-04 - 8s/epoch - 5ms/step
# Epoch 311/500
# 1749/1749 - 6s - loss: 0.0081 - val_loss: 1.1638e-04 - 6s/epoch - 4ms/step
# Epoch 312/500
# 1749/1749 - 5s - loss: 0.0026 - val_loss: 9.0926e-04 - 5s/epoch - 3ms/step
# Epoch 313/500
# 1749/1749 - 5s - loss: 0.0057 - val_loss: 3.6331e-04 - 5s/epoch - 3ms/step
# Epoch 314/500
# 1749/1749 - 5s - loss: 0.0042 - val_loss: 1.0561e-04 - 5s/epoch - 3ms/step
# Epoch 315/500
# 1749/1749 - 6s - loss: 0.0075 - val_loss: 5.0448e-04 - 6s/epoch - 4ms/step
# Epoch 316/500
# 1749/1749 - 6s - loss: 0.0048 - val_loss: 0.0011 - 6s/epoch - 3ms/step
# Epoch 317/500
# 1749/1749 - 6s - loss: 0.0040 - val_loss: 0.0026 - 6s/epoch - 3ms/step
# Epoch 318/500
# 1749/1749 - 5s - loss: 0.0044 - val_loss: 4.7632e-04 - 5s/epoch - 3ms/step
# Epoch 319/500
# 1749/1749 - 6s - loss: 0.0055 - val_loss: 1.0205e-04 - 6s/epoch - 3ms/step
# Epoch 320/500
# 1749/1749 - 6s - loss: 0.0041 - val_loss: 1.0848e-04 - 6s/epoch - 3ms/step
# Epoch 321/500
# 1749/1749 - 6s - loss: 0.0065 - val_loss: 1.5180e-04 - 6s/epoch - 3ms/step
# Epoch 322/500
# 1749/1749 - 7s - loss: 0.0057 - val_loss: 2.0108e-04 - 7s/epoch - 4ms/step
# Epoch 323/500
# 1749/1749 - 8s - loss: 0.0040 - val_loss: 1.1361e-04 - 8s/epoch - 5ms/step
# Epoch 324/500
# 1749/1749 - 11s - loss: 0.0039 - val_loss: 3.7172e-04 - 11s/epoch - 6ms/step
# Epoch 325/500
# 1749/1749 - 10s - loss: 0.0081 - val_loss: 2.0553e-04 - 10s/epoch - 6ms/step
# Epoch 326/500
# 1749/1749 - 13s - loss: 0.0091 - val_loss: 1.1910e-04 - 13s/epoch - 7ms/step
# Epoch 327/500
# 1749/1749 - 12s - loss: 0.0023 - val_loss: 1.2429e-04 - 12s/epoch - 7ms/step
# Epoch 328/500
# 1749/1749 - 8s - loss: 0.0042 - val_loss: 1.4779e-04 - 8s/epoch - 5ms/step
# Epoch 329/500
# 1749/1749 - 10s - loss: 0.0049 - val_loss: 1.7100e-04 - 10s/epoch - 5ms/step
# Epoch 330/500
# 1749/1749 - 12s - loss: 0.0042 - val_loss: 0.0018 - 12s/epoch - 7ms/step
# Epoch 331/500
# 1749/1749 - 9s - loss: 0.0072 - val_loss: 2.0588e-04 - 9s/epoch - 5ms/step
# Epoch 332/500
# 1749/1749 - 10s - loss: 0.0045 - val_loss: 1.7642e-04 - 10s/epoch - 6ms/step
# Epoch 333/500
# 1749/1749 - 8s - loss: 0.0046 - val_loss: 1.0811e-04 - 8s/epoch - 5ms/step
# Epoch 334/500
# 1749/1749 - 7s - loss: 0.0053 - val_loss: 1.0335e-04 - 7s/epoch - 4ms/step
# Epoch 335/500
# 1749/1749 - 9s - loss: 0.0039 - val_loss: 1.1276e-04 - 9s/epoch - 5ms/step
# Epoch 336/500
# 1749/1749 - 8s - loss: 0.0060 - val_loss: 1.0660e-04 - 8s/epoch - 4ms/step
# Epoch 337/500
# 1749/1749 - 10s - loss: 0.0051 - val_loss: 1.1013e-04 - 10s/epoch - 6ms/step
# Epoch 338/500
# 1749/1749 - 11s - loss: 0.0036 - val_loss: 1.0448e-04 - 11s/epoch - 6ms/step
# Epoch 339/500
# 1749/1749 - 13s - loss: 0.0049 - val_loss: 6.7044e-04 - 13s/epoch - 7ms/step
# Epoch 340/500
# 1749/1749 - 10s - loss: 0.0039 - val_loss: 2.1241e-04 - 10s/epoch - 5ms/step
# Epoch 341/500
# 1749/1749 - 10s - loss: 0.0054 - val_loss: 1.2445e-04 - 10s/epoch - 6ms/step
# Epoch 342/500
# 1749/1749 - 8s - loss: 0.0055 - val_loss: 1.0038e-04 - 8s/epoch - 5ms/step
# Epoch 343/500
# 1749/1749 - 8s - loss: 0.0037 - val_loss: 9.6421e-05 - 8s/epoch - 5ms/step
# Epoch 344/500
# 1749/1749 - 8s - loss: 0.0048 - val_loss: 2.0204e-04 - 8s/epoch - 5ms/step
# Epoch 345/500
# 1749/1749 - 9s - loss: 0.0056 - val_loss: 1.2157e-04 - 9s/epoch - 5ms/step
# Epoch 346/500
# 1749/1749 - 8s - loss: 0.0056 - val_loss: 0.0126 - 8s/epoch - 4ms/step
# Epoch 347/500
# 1749/1749 - 7s - loss: 0.0034 - val_loss: 1.0304e-04 - 7s/epoch - 4ms/step
# Epoch 348/500
# 1749/1749 - 7s - loss: 0.0041 - val_loss: 1.1512e-04 - 7s/epoch - 4ms/step
# Epoch 349/500
# 1749/1749 - 7s - loss: 0.0061 - val_loss: 5.3785e-04 - 7s/epoch - 4ms/step
# Epoch 350/500
# 1749/1749 - 7s - loss: 0.0105 - val_loss: 1.3269e-04 - 7s/epoch - 4ms/step
# Epoch 351/500
# 1749/1749 - 7s - loss: 0.0017 - val_loss: 1.0064e-04 - 7s/epoch - 4ms/step
# Epoch 352/500
# 1749/1749 - 7s - loss: 0.0056 - val_loss: 1.0857e-04 - 7s/epoch - 4ms/step
# Epoch 353/500
# 1749/1749 - 7s - loss: 0.0056 - val_loss: 6.7464e-04 - 7s/epoch - 4ms/step
# Epoch 354/500
# 1749/1749 - 8s - loss: 0.0024 - val_loss: 1.3796e-04 - 8s/epoch - 4ms/step
# Epoch 355/500
# 1749/1749 - 8s - loss: 0.0036 - val_loss: 8.4109e-04 - 8s/epoch - 5ms/step
# Epoch 356/500
# 1749/1749 - 8s - loss: 0.0041 - val_loss: 2.4190e-04 - 8s/epoch - 5ms/step
# Epoch 357/500
# 1749/1749 - 9s - loss: 0.0037 - val_loss: 8.1482e-04 - 9s/epoch - 5ms/step
# Epoch 358/500
# 1749/1749 - 7s - loss: 0.0042 - val_loss: 9.2538e-05 - 7s/epoch - 4ms/step
# Epoch 359/500
# 1749/1749 - 7s - loss: 0.0101 - val_loss: 1.0010e-04 - 7s/epoch - 4ms/step
# Epoch 360/500
# 1749/1749 - 7s - loss: 0.0135 - val_loss: 9.3160e-05 - 7s/epoch - 4ms/step
# Epoch 361/500
# 1749/1749 - 7s - loss: 0.0026 - val_loss: 0.0017 - 7s/epoch - 4ms/step
# Epoch 362/500
# 1749/1749 - 7s - loss: 0.0066 - val_loss: 2.1187e-04 - 7s/epoch - 4ms/step
# Epoch 363/500
# 1749/1749 - 7s - loss: 0.0056 - val_loss: 1.3461e-04 - 7s/epoch - 4ms/step
# Epoch 364/500
# 1749/1749 - 7s - loss: 0.0049 - val_loss: 1.0503e-04 - 7s/epoch - 4ms/step
# Epoch 365/500
# 1749/1749 - 7s - loss: 0.0034 - val_loss: 5.2063e-04 - 7s/epoch - 4ms/step
# Epoch 366/500
# 1749/1749 - 7s - loss: 0.0040 - val_loss: 1.4771e-04 - 7s/epoch - 4ms/step
# Epoch 367/500
# 1749/1749 - 8s - loss: 0.0049 - val_loss: 8.7937e-05 - 8s/epoch - 5ms/step
# Epoch 368/500
# 1749/1749 - 7s - loss: 0.0068 - val_loss: 1.0336e-04 - 7s/epoch - 4ms/step
# Epoch 369/500
# 1749/1749 - 8s - loss: 0.0051 - val_loss: 1.0798e-04 - 8s/epoch - 4ms/step
# Epoch 370/500
# 1749/1749 - 6s - loss: 0.0032 - val_loss: 0.0080 - 6s/epoch - 3ms/step
# Epoch 371/500
# 1749/1749 - 6s - loss: 0.0059 - val_loss: 0.0011 - 6s/epoch - 3ms/step
# Epoch 372/500
# 1749/1749 - 5s - loss: 0.0023 - val_loss: 9.5700e-05 - 5s/epoch - 3ms/step
# Epoch 373/500
# 1749/1749 - 5s - loss: 0.0039 - val_loss: 2.7697e-04 - 5s/epoch - 3ms/step
# Epoch 374/500
# 1749/1749 - 6s - loss: 0.0121 - val_loss: 8.7070e-05 - 6s/epoch - 3ms/step
# Epoch 375/500
# 1749/1749 - 6s - loss: 0.0028 - val_loss: 3.8831e-04 - 6s/epoch - 4ms/step
# Epoch 376/500
# 1749/1749 - 8s - loss: 0.0050 - val_loss: 8.6023e-05 - 8s/epoch - 4ms/step
# Epoch 377/500
# 1749/1749 - 7s - loss: 0.0028 - val_loss: 2.1902e-04 - 7s/epoch - 4ms/step
# Epoch 378/500
# 1749/1749 - 10s - loss: 0.0055 - val_loss: 1.1194e-04 - 10s/epoch - 6ms/step
# Epoch 379/500
# 1749/1749 - 12s - loss: 0.0031 - val_loss: 2.1616e-04 - 12s/epoch - 7ms/step
# Epoch 380/500
# 1749/1749 - 12s - loss: 0.0046 - val_loss: 8.5442e-05 - 12s/epoch - 7ms/step
# Epoch 381/500
# 1749/1749 - 9s - loss: 0.0039 - val_loss: 2.6904e-04 - 9s/epoch - 5ms/step
# Epoch 382/500
# 1749/1749 - 9s - loss: 0.0031 - val_loss: 3.4657e-04 - 9s/epoch - 5ms/step
# Epoch 383/500
# 1749/1749 - 8s - loss: 0.0050 - val_loss: 1.8062e-04 - 8s/epoch - 5ms/step
# Epoch 384/500
# 1749/1749 - 8s - loss: 0.0029 - val_loss: 1.2335e-04 - 8s/epoch - 4ms/step
# Epoch 385/500
# 1749/1749 - 7s - loss: 0.0047 - val_loss: 3.3710e-04 - 7s/epoch - 4ms/step
# Epoch 386/500
# 1749/1749 - 7s - loss: 0.0045 - val_loss: 8.7212e-05 - 7s/epoch - 4ms/step
# Epoch 387/500
# 1749/1749 - 7s - loss: 0.0037 - val_loss: 1.0986e-04 - 7s/epoch - 4ms/step
# Epoch 388/500
# 1749/1749 - 5s - loss: 0.0057 - val_loss: 9.0569e-05 - 5s/epoch - 3ms/step
# Epoch 389/500
# 1749/1749 - 5s - loss: 0.0035 - val_loss: 3.1834e-04 - 5s/epoch - 3ms/step
# Epoch 390/500
# 1749/1749 - 5s - loss: 0.0052 - val_loss: 8.8869e-05 - 5s/epoch - 3ms/step
# Epoch 391/500
# 1749/1749 - 6s - loss: 0.0056 - val_loss: 2.8733e-04 - 6s/epoch - 4ms/step
# Epoch 392/500
# 1749/1749 - 5s - loss: 0.0051 - val_loss: 1.5900e-04 - 5s/epoch - 3ms/step
# Epoch 393/500
# 1749/1749 - 6s - loss: 0.0063 - val_loss: 1.1016e-04 - 6s/epoch - 3ms/step
# Epoch 394/500
# 1749/1749 - 5s - loss: 0.0050 - val_loss: 2.3179e-04 - 5s/epoch - 3ms/step
# Epoch 395/500
# 1749/1749 - 8s - loss: 0.0041 - val_loss: 1.5263e-04 - 8s/epoch - 4ms/step
# Epoch 396/500
# 1749/1749 - 8s - loss: 0.0031 - val_loss: 1.2813e-04 - 8s/epoch - 5ms/step
# Epoch 397/500
# 1749/1749 - 12s - loss: 0.0028 - val_loss: 3.3422e-04 - 12s/epoch - 7ms/step
# Epoch 398/500
# 1749/1749 - 9s - loss: 0.0051 - val_loss: 1.1067e-04 - 9s/epoch - 5ms/step
# Epoch 399/500
# 1749/1749 - 14s - loss: 0.0040 - val_loss: 1.1836e-04 - 14s/epoch - 8ms/step
# Epoch 400/500
# 1749/1749 - 9s - loss: 0.0046 - val_loss: 1.2717e-04 - 9s/epoch - 5ms/step
# Epoch 401/500
# 1749/1749 - 11s - loss: 0.0029 - val_loss: 8.5183e-05 - 11s/epoch - 6ms/step
# Epoch 402/500
# 1749/1749 - 11s - loss: 0.0035 - val_loss: 4.3615e-04 - 11s/epoch - 6ms/step
# Epoch 403/500
# 1749/1749 - 8s - loss: 0.0034 - val_loss: 9.7400e-05 - 8s/epoch - 4ms/step
# Epoch 404/500
# 1749/1749 - 7s - loss: 0.0030 - val_loss: 1.1146e-04 - 7s/epoch - 4ms/step
# Epoch 405/500
# 1749/1749 - 7s - loss: 0.0034 - val_loss: 2.6583e-04 - 7s/epoch - 4ms/step
# Epoch 406/500
# 1749/1749 - 8s - loss: 0.0037 - val_loss: 3.1751e-04 - 8s/epoch - 4ms/step
# Epoch 407/500
# 1749/1749 - 9s - loss: 0.0049 - val_loss: 8.9824e-05 - 9s/epoch - 5ms/step
# Epoch 408/500
# 1749/1749 - 12s - loss: 0.0032 - val_loss: 1.1827e-04 - 12s/epoch - 7ms/step
# Epoch 409/500
# 1749/1749 - 11s - loss: 0.0049 - val_loss: 8.2283e-04 - 11s/epoch - 6ms/step
# Epoch 410/500
# 1749/1749 - 10s - loss: 0.0052 - val_loss: 6.6125e-04 - 10s/epoch - 6ms/step
# Epoch 411/500
# 1749/1749 - 9s - loss: 0.0061 - val_loss: 1.3924e-04 - 9s/epoch - 5ms/step
# Epoch 412/500
# 1749/1749 - 9s - loss: 0.0033 - val_loss: 1.4452e-04 - 9s/epoch - 5ms/step
# Epoch 413/500
# 1749/1749 - 10s - loss: 0.0036 - val_loss: 9.7442e-05 - 10s/epoch - 6ms/step
# Epoch 414/500
# 1749/1749 - 11s - loss: 0.0036 - val_loss: 1.3138e-04 - 11s/epoch - 6ms/step
# Epoch 415/500
# 1749/1749 - 12s - loss: 0.0038 - val_loss: 1.2123e-04 - 12s/epoch - 7ms/step
# Epoch 416/500
# 1749/1749 - 11s - loss: 0.0034 - val_loss: 2.3283e-04 - 11s/epoch - 6ms/step
# Epoch 417/500
# 1749/1749 - 12s - loss: 0.0049 - val_loss: 0.0014 - 12s/epoch - 7ms/step
# Epoch 418/500
# 1749/1749 - 13s - loss: 0.0049 - val_loss: 8.9054e-05 - 13s/epoch - 7ms/step
# Epoch 419/500
# 1749/1749 - 13s - loss: 0.0026 - val_loss: 3.9986e-04 - 13s/epoch - 7ms/step
# Epoch 420/500
# 1749/1749 - 14s - loss: 0.0032 - val_loss: 8.6481e-05 - 14s/epoch - 8ms/step
# Epoch 421/500
# 1749/1749 - 13s - loss: 0.0036 - val_loss: 9.4868e-05 - 13s/epoch - 7ms/step
# Epoch 422/500
# 1749/1749 - 14s - loss: 0.0065 - val_loss: 2.4188e-04 - 14s/epoch - 8ms/step
# Epoch 423/500
# 1749/1749 - 13s - loss: 0.0039 - val_loss: 1.0869e-04 - 13s/epoch - 7ms/step
# Epoch 424/500
# 1749/1749 - 14s - loss: 0.0035 - val_loss: 9.4571e-05 - 14s/epoch - 8ms/step
# Epoch 425/500
# 1749/1749 - 15s - loss: 0.0035 - val_loss: 9.1154e-05 - 15s/epoch - 8ms/step
# Epoch 426/500
# 1749/1749 - 13s - loss: 0.0037 - val_loss: 7.6603e-04 - 13s/epoch - 7ms/step
# Epoch 427/500
# 1749/1749 - 14s - loss: 0.0031 - val_loss: 9.1944e-05 - 14s/epoch - 8ms/step
# Epoch 428/500
# 1749/1749 - 14s - loss: 0.0036 - val_loss: 1.6415e-04 - 14s/epoch - 8ms/step
# Epoch 429/500
# 1749/1749 - 13s - loss: 0.0031 - val_loss: 8.8466e-05 - 13s/epoch - 7ms/step
# Epoch 430/500
# 1749/1749 - 13s - loss: 0.0047 - val_loss: 8.8531e-05 - 13s/epoch - 7ms/step
# Epoch 431/500
# 1749/1749 - 13s - loss: 0.0067 - val_loss: 9.1698e-05 - 13s/epoch - 7ms/step
# Epoch 432/500
# 1749/1749 - 13s - loss: 0.0023 - val_loss: 2.2573e-04 - 13s/epoch - 7ms/step
# Epoch 433/500
# 1749/1749 - 12s - loss: 0.0035 - val_loss: 8.8616e-05 - 12s/epoch - 7ms/step
# Epoch 434/500
# 1749/1749 - 10s - loss: 0.0030 - val_loss: 1.3025e-04 - 10s/epoch - 6ms/step
# Epoch 435/500
# 1749/1749 - 13s - loss: 0.0031 - val_loss: 3.0126e-04 - 13s/epoch - 8ms/step
# Epoch 436/500
# 1749/1749 - 14s - loss: 0.0039 - val_loss: 8.5513e-05 - 14s/epoch - 8ms/step
# Epoch 437/500
# 1749/1749 - 12s - loss: 0.0030 - val_loss: 9.1214e-05 - 12s/epoch - 7ms/step
# Epoch 438/500
# 1749/1749 - 11s - loss: 0.0032 - val_loss: 8.4345e-05 - 11s/epoch - 6ms/step
# Epoch 439/500
# 1749/1749 - 12s - loss: 0.0031 - val_loss: 1.1711e-04 - 12s/epoch - 7ms/step
# Epoch 440/500
# 1749/1749 - 13s - loss: 0.0041 - val_loss: 0.0010 - 13s/epoch - 7ms/step
# Epoch 441/500
# 1749/1749 - 11s - loss: 0.0041 - val_loss: 8.8898e-05 - 11s/epoch - 6ms/step
# Epoch 442/500
# 1749/1749 - 12s - loss: 0.0030 - val_loss: 6.6798e-04 - 12s/epoch - 7ms/step
# Epoch 443/500
# 1749/1749 - 13s - loss: 0.0032 - val_loss: 3.3352e-04 - 13s/epoch - 7ms/step
# Epoch 444/500
# 1749/1749 - 14s - loss: 0.0026 - val_loss: 4.1886e-04 - 14s/epoch - 8ms/step
# Epoch 445/500
# 1749/1749 - 15s - loss: 0.0033 - val_loss: 1.1700e-04 - 15s/epoch - 9ms/step
# Epoch 446/500
# 1749/1749 - 14s - loss: 0.0027 - val_loss: 9.4985e-05 - 14s/epoch - 8ms/step
# Epoch 447/500
# 1749/1749 - 18s - loss: 0.0033 - val_loss: 2.6250e-04 - 18s/epoch - 10ms/step
# Epoch 448/500
# 1749/1749 - 17s - loss: 0.0028 - val_loss: 2.4057e-04 - 17s/epoch - 10ms/step
# Epoch 449/500
# 1749/1749 - 14s - loss: 0.0029 - val_loss: 1.4885e-04 - 14s/epoch - 8ms/step
# Epoch 450/500
# 1749/1749 - 13s - loss: 0.0059 - val_loss: 8.1840e-05 - 13s/epoch - 8ms/step
# Epoch 451/500
# 1749/1749 - 12s - loss: 0.0022 - val_loss: 1.0511e-04 - 12s/epoch - 7ms/step
# Epoch 452/500
# 1749/1749 - 11s - loss: 0.0056 - val_loss: 1.1200e-04 - 11s/epoch - 6ms/step
# Epoch 453/500
# 1749/1749 - 11s - loss: 0.0018 - val_loss: 0.0018 - 11s/epoch - 6ms/step
# Epoch 454/500
# 1749/1749 - 10s - loss: 0.0046 - val_loss: 9.9322e-05 - 10s/epoch - 6ms/step
# Epoch 455/500
# 1749/1749 - 11s - loss: 0.0025 - val_loss: 9.4591e-04 - 11s/epoch - 6ms/step
# Epoch 456/500
# 1749/1749 - 12s - loss: 0.0027 - val_loss: 1.1341e-04 - 12s/epoch - 7ms/step
# Epoch 457/500
# 1749/1749 - 10s - loss: 0.0027 - val_loss: 1.2941e-04 - 10s/epoch - 6ms/step
# Epoch 458/500
# 1749/1749 - 10s - loss: 0.0030 - val_loss: 9.6525e-05 - 10s/epoch - 6ms/step
# Epoch 459/500
# 1749/1749 - 10s - loss: 0.0031 - val_loss: 2.3897e-04 - 10s/epoch - 6ms/step
# Epoch 460/500
# 1749/1749 - 10s - loss: 0.0033 - val_loss: 1.0170e-04 - 10s/epoch - 6ms/step
# Epoch 461/500
# 1749/1749 - 10s - loss: 0.0032 - val_loss: 9.9787e-05 - 10s/epoch - 6ms/step
# Epoch 462/500
# 1749/1749 - 10s - loss: 0.0031 - val_loss: 1.6046e-04 - 10s/epoch - 6ms/step
# Epoch 463/500
# 1749/1749 - 12s - loss: 0.0032 - val_loss: 2.3578e-04 - 12s/epoch - 7ms/step
# Epoch 464/500
# 1749/1749 - 12s - loss: 0.0031 - val_loss: 3.8939e-04 - 12s/epoch - 7ms/step
# Epoch 465/500
# 1749/1749 - 10s - loss: 0.0026 - val_loss: 1.2197e-04 - 10s/epoch - 6ms/step
# Epoch 466/500
# 1749/1749 - 10s - loss: 0.0040 - val_loss: 9.7970e-04 - 10s/epoch - 6ms/step
# Epoch 467/500
# 1749/1749 - 11s - loss: 0.0033 - val_loss: 8.3533e-05 - 11s/epoch - 6ms/step
# Epoch 468/500
# 1749/1749 - 10s - loss: 0.0031 - val_loss: 0.0023 - 10s/epoch - 6ms/step
# Epoch 469/500
# 1749/1749 - 11s - loss: 0.0039 - val_loss: 8.4010e-05 - 11s/epoch - 6ms/step
# Epoch 470/500
# 1749/1749 - 10s - loss: 0.0023 - val_loss: 8.0581e-05 - 10s/epoch - 6ms/step
# Epoch 471/500
# 1749/1749 - 10s - loss: 0.0028 - val_loss: 4.3750e-04 - 10s/epoch - 6ms/step
# Epoch 472/500
# 1749/1749 - 10s - loss: 0.0024 - val_loss: 0.0019 - 10s/epoch - 5ms/step
# Epoch 473/500
# 1749/1749 - 8s - loss: 0.0029 - val_loss: 1.7315e-04 - 8s/epoch - 4ms/step
# Epoch 474/500
# 1749/1749 - 8s - loss: 0.0031 - val_loss: 1.0901e-04 - 8s/epoch - 5ms/step
# Epoch 475/500
# 1749/1749 - 8s - loss: 0.0063 - val_loss: 7.3216e-05 - 8s/epoch - 4ms/step
# Epoch 476/500
# 1749/1749 - 8s - loss: 0.0024 - val_loss: 5.4771e-04 - 8s/epoch - 5ms/step
# Epoch 477/500
# 1749/1749 - 9s - loss: 0.0026 - val_loss: 6.5772e-04 - 9s/epoch - 5ms/step
# Epoch 478/500
# 1749/1749 - 14s - loss: 0.0038 - val_loss: 8.2612e-05 - 14s/epoch - 8ms/step
# Epoch 479/500
# 1749/1749 - 11s - loss: 0.0030 - val_loss: 7.7839e-05 - 11s/epoch - 6ms/step
# Epoch 480/500
# 1749/1749 - 17s - loss: 0.0054 - val_loss: 7.8561e-05 - 17s/epoch - 10ms/step
# Epoch 481/500
# 1749/1749 - 9s - loss: 0.0018 - val_loss: 4.8167e-04 - 9s/epoch - 5ms/step
# Epoch 482/500
# 1749/1749 - 9s - loss: 0.0027 - val_loss: 4.0984e-04 - 9s/epoch - 5ms/step
# Epoch 483/500
# 1749/1749 - 8s - loss: 0.0026 - val_loss: 0.0070 - 8s/epoch - 5ms/step
# Epoch 484/500
# 1749/1749 - 8s - loss: 0.0054 - val_loss: 8.0215e-05 - 8s/epoch - 4ms/step
# Epoch 485/500
# 1749/1749 - 11s - loss: 0.0042 - val_loss: 2.1857e-04 - 11s/epoch - 6ms/step
# Epoch 486/500
# 1749/1749 - 12s - loss: 0.0016 - val_loss: 9.0905e-05 - 12s/epoch - 7ms/step
# Epoch 487/500
# 1749/1749 - 12s - loss: 0.0027 - val_loss: 2.0855e-04 - 12s/epoch - 7ms/step
# Epoch 488/500
# 1749/1749 - 12s - loss: 0.0026 - val_loss: 4.2948e-04 - 12s/epoch - 7ms/step
# Epoch 489/500
# 1749/1749 - 11s - loss: 0.0035 - val_loss: 1.8934e-04 - 11s/epoch - 6ms/step
# Epoch 490/500
# 1749/1749 - 11s - loss: 0.0029 - val_loss: 7.6472e-05 - 11s/epoch - 6ms/step
# Epoch 491/500
# 1749/1749 - 12s - loss: 0.0024 - val_loss: 1.2683e-04 - 12s/epoch - 7ms/step
# Epoch 492/500
# 1749/1749 - 14s - loss: 0.0026 - val_loss: 0.0038 - 14s/epoch - 8ms/step
# Epoch 493/500
# 1749/1749 - 12s - loss: 0.0055 - val_loss: 8.5634e-05 - 12s/epoch - 7ms/step
# Epoch 494/500
# 1749/1749 - 14s - loss: 0.0052 - val_loss: 8.2451e-05 - 14s/epoch - 8ms/step
# Epoch 495/500
# 1749/1749 - 13s - loss: 0.0020 - val_loss: 2.1470e-04 - 13s/epoch - 7ms/step
# Epoch 496/500
# 1749/1749 - 13s - loss: 0.0109 - val_loss: 7.9271e-05 - 13s/epoch - 8ms/step
# Epoch 497/500
# 1749/1749 - 15s - loss: 0.0012 - val_loss: 8.2951e-05 - 15s/epoch - 8ms/step
# Epoch 498/500
# 1749/1749 - 14s - loss: 0.0041 - val_loss: 3.2715e-04 - 14s/epoch - 8ms/step
# Epoch 499/500
# 1749/1749 - 12s - loss: 0.0032 - val_loss: 1.0155e-04 - 12s/epoch - 7ms/step
# Epoch 500/500
# 1749/1749 - 13s - loss: 0.0026 - val_loss: 8.9097e-05 - 13s/epoch - 7ms/step

# %% [markdown]
# ## Metrics ($LPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 875/875 [==============================] - 5s 3ms/step
# (27972, 3)
# (27972, 10)
# Test RMSE: 3.763
# Test MAE: 2.692

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('Kyoto DST Index', fontsize=20)
plt.legend(fontsize=20)
plt.show()
