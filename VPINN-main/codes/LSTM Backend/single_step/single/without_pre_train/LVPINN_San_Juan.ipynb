# %% [markdown]
# # Time Series Prediction with Lotka Volterra Equation Inspired Deep Learning ($LVPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-11 20:27:04

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _SAN JUAN_

# %%
data = pd.read_csv("datasets/sanjuan.csv")
training_set = data.iloc[:, 3]
print(training_set)
# Out:
# 0        4
# 1        5
# 2        4
# 3        3
# 4        6
#         ..
# 1191    56
# 1192    46
# 1193    52
# 1194    34
# 1195    25
# Name: Cases, Length: 1196, dtype: int64

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 7 # Weekly Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 461
# 1       0.142857
# 2      -0.142857
# 3      -0.142857
# 4       0.428571
# 5      -0.571429
#           ...
# 1191   -1.000000
# 1192   -1.428571
# 1193    0.857143
# 1194   -2.571429
# 1195   -1.285714
# Name: Cases, Length: 1195, dtype: float64
# 2      -0.040816
# 3       0.000000
# 4       0.081633
# 5      -0.142857
# 6       0.122449
#           ...
# 1191   -0.081633
# 1192   -0.061224
# 1193    0.326531
# 1194   -0.489796
# 1195    0.183673
# Name: Cases, Length: 1194, dtype: float64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0       0.142857
# 1      -0.142857
# 2      -0.142857
# 3       0.428571
# 4      -0.571429
#           ...
# 1190   -1.000000
# 1191   -1.428571
# 1192    0.857143
# 1193   -2.571429
# 1194   -1.285714
# Name: Cases, Length: 1195, dtype: float64
# 0      -0.040816
# 1       0.000000
# 2       0.081633
# 3      -0.142857
# 4       0.122449
#           ...
# 1189   -0.081633
# 1190   -0.061224
# 1191    0.326531
# 1192   -0.489796
# 1193    0.183673
# Name: Cases, Length: 1194, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (1195,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lotka Volterra Equation_)

# %% [markdown]
# _Parameters_: $\alpha=0.1, \beta=0.05, \gamma=1.1, \delta=0.1\\$

# %%
a=0.1
b=0.05
c=1.1
d=0.1
L = df.iloc[:, 2] - a*a*df.iloc[:, 0] + 2*a*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*d*(df.iloc[:,0]**2)*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - c*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10         4.0        5.0        4.0        3.0        6.0        2.0
# 11         5.0        4.0        3.0        6.0        2.0        4.0
# 12         4.0        3.0        6.0        2.0        4.0        5.0
# 13         3.0        6.0        2.0        4.0        5.0       10.0
# 14         6.0        2.0        4.0        5.0       10.0        6.0
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)   var2(t)   var3(t)
# 10        4.0        5.0       10.0        6.0      8.0 -0.857143  0.204082
# 11        5.0       10.0        6.0        8.0      2.0  0.571429  0.142857
# 12       10.0        6.0        8.0        2.0      6.0  1.571429 -0.102041
# 13        6.0        8.0        2.0        6.0     17.0  0.857143 -0.326531
# 14        8.0        2.0        6.0       17.0     23.0 -1.428571  0.367347
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (1184, 13)
# (1184, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (947, 1, 10) (947, 3) (237, 1, 10) (237, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] - a*a*y_true[:, 0] + 2*a*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*d*(y_true[:,0]**2)*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - c*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))), (y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] - a*a*y_pred[:-2] + 2*a*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*d*(y_pred[:-2]**2)*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - c*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] - a*a*y_real[:-2] + 2*a*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*d*(y_real[:-2]**2)*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - c*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($LVPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square(y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 15/15 - 15s - loss: 0.0334 - val_loss: 0.0589 - 15s/epoch - 982ms/step
# Epoch 2/500
# 15/15 - 0s - loss: 0.0284 - val_loss: 0.0273 - 155ms/epoch - 10ms/step
# Epoch 3/500
# 15/15 - 0s - loss: 0.0231 - val_loss: 0.0220 - 154ms/epoch - 10ms/step
# Epoch 4/500
# 15/15 - 0s - loss: 0.0111 - val_loss: 0.0190 - 165ms/epoch - 11ms/step
# Epoch 5/500
# 15/15 - 0s - loss: 0.0102 - val_loss: 0.0183 - 150ms/epoch - 10ms/step
# Epoch 6/500
# 15/15 - 0s - loss: 0.0099 - val_loss: 0.0181 - 162ms/epoch - 11ms/step
# Epoch 7/500
# 15/15 - 0s - loss: 0.0099 - val_loss: 0.0181 - 156ms/epoch - 10ms/step
# Epoch 8/500
# 15/15 - 0s - loss: 0.0099 - val_loss: 0.0181 - 175ms/epoch - 12ms/step
# Epoch 9/500
# 15/15 - 0s - loss: 0.0099 - val_loss: 0.0180 - 166ms/epoch - 11ms/step
# Epoch 10/500
# 15/15 - 0s - loss: 0.0099 - val_loss: 0.0180 - 171ms/epoch - 11ms/step
# Epoch 11/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0180 - 180ms/epoch - 12ms/step
# Epoch 12/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0180 - 174ms/epoch - 12ms/step
# Epoch 13/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0180 - 158ms/epoch - 11ms/step
# Epoch 14/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0180 - 157ms/epoch - 10ms/step
# Epoch 15/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0180 - 156ms/epoch - 10ms/step
# Epoch 16/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0180 - 149ms/epoch - 10ms/step
# Epoch 17/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0179 - 159ms/epoch - 11ms/step
# Epoch 18/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0179 - 164ms/epoch - 11ms/step
# Epoch 19/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0179 - 168ms/epoch - 11ms/step
# Epoch 20/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0179 - 166ms/epoch - 11ms/step
# Epoch 21/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0179 - 163ms/epoch - 11ms/step
# Epoch 22/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0179 - 164ms/epoch - 11ms/step
# Epoch 23/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0179 - 155ms/epoch - 10ms/step
# Epoch 24/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0179 - 155ms/epoch - 10ms/step
# Epoch 25/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0179 - 159ms/epoch - 11ms/step
# Epoch 26/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0179 - 158ms/epoch - 11ms/step
# Epoch 27/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0179 - 142ms/epoch - 9ms/step
# Epoch 28/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0179 - 147ms/epoch - 10ms/step
# Epoch 29/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0178 - 166ms/epoch - 11ms/step
# Epoch 30/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0178 - 159ms/epoch - 11ms/step
# Epoch 31/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0178 - 138ms/epoch - 9ms/step
# Epoch 32/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0178 - 147ms/epoch - 10ms/step
# Epoch 33/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0178 - 144ms/epoch - 10ms/step
# Epoch 34/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0178 - 147ms/epoch - 10ms/step
# Epoch 35/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0178 - 147ms/epoch - 10ms/step
# Epoch 36/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0178 - 139ms/epoch - 9ms/step
# Epoch 37/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0178 - 133ms/epoch - 9ms/step
# Epoch 38/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0178 - 151ms/epoch - 10ms/step
# Epoch 39/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0178 - 164ms/epoch - 11ms/step
# Epoch 40/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0178 - 158ms/epoch - 11ms/step
# Epoch 41/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0178 - 152ms/epoch - 10ms/step
# Epoch 42/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0178 - 170ms/epoch - 11ms/step
# Epoch 43/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0178 - 152ms/epoch - 10ms/step
# Epoch 44/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0178 - 177ms/epoch - 12ms/step
# Epoch 45/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0178 - 158ms/epoch - 11ms/step
# Epoch 46/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0178 - 178ms/epoch - 12ms/step
# Epoch 47/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0177 - 286ms/epoch - 19ms/step
# Epoch 48/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0177 - 194ms/epoch - 13ms/step
# Epoch 49/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0177 - 152ms/epoch - 10ms/step
# Epoch 50/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0177 - 139ms/epoch - 9ms/step
# Epoch 51/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0177 - 130ms/epoch - 9ms/step
# Epoch 52/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0177 - 126ms/epoch - 8ms/step
# Epoch 53/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0177 - 127ms/epoch - 8ms/step
# Epoch 54/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0177 - 138ms/epoch - 9ms/step
# Epoch 55/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0177 - 143ms/epoch - 10ms/step
# Epoch 56/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0177 - 141ms/epoch - 9ms/step
# Epoch 57/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0177 - 135ms/epoch - 9ms/step
# Epoch 58/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0177 - 158ms/epoch - 11ms/step
# Epoch 59/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0177 - 168ms/epoch - 11ms/step
# Epoch 60/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0177 - 153ms/epoch - 10ms/step
# Epoch 61/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0177 - 153ms/epoch - 10ms/step
# Epoch 62/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0177 - 150ms/epoch - 10ms/step
# Epoch 63/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0176 - 157ms/epoch - 10ms/step
# Epoch 64/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0176 - 165ms/epoch - 11ms/step
# Epoch 65/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0176 - 157ms/epoch - 10ms/step
# Epoch 66/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0176 - 166ms/epoch - 11ms/step
# Epoch 67/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0176 - 171ms/epoch - 11ms/step
# Epoch 68/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0176 - 159ms/epoch - 11ms/step
# Epoch 69/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0176 - 176ms/epoch - 12ms/step
# Epoch 70/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0176 - 171ms/epoch - 11ms/step
# Epoch 71/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0176 - 172ms/epoch - 11ms/step
# Epoch 72/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0176 - 164ms/epoch - 11ms/step
# Epoch 73/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0176 - 162ms/epoch - 11ms/step
# Epoch 74/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0176 - 152ms/epoch - 10ms/step
# Epoch 75/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0176 - 151ms/epoch - 10ms/step
# Epoch 76/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0176 - 158ms/epoch - 11ms/step
# Epoch 77/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0175 - 160ms/epoch - 11ms/step
# Epoch 78/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0175 - 150ms/epoch - 10ms/step
# Epoch 79/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0175 - 161ms/epoch - 11ms/step
# Epoch 80/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0175 - 164ms/epoch - 11ms/step
# Epoch 81/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0175 - 170ms/epoch - 11ms/step
# Epoch 82/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0175 - 164ms/epoch - 11ms/step
# Epoch 83/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0175 - 170ms/epoch - 11ms/step
# Epoch 84/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0175 - 170ms/epoch - 11ms/step
# Epoch 85/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0175 - 156ms/epoch - 10ms/step
# Epoch 86/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0175 - 165ms/epoch - 11ms/step
# Epoch 87/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0175 - 155ms/epoch - 10ms/step
# Epoch 88/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0175 - 160ms/epoch - 11ms/step
# Epoch 89/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0175 - 150ms/epoch - 10ms/step
# Epoch 90/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0174 - 157ms/epoch - 10ms/step
# Epoch 91/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0174 - 153ms/epoch - 10ms/step
# Epoch 92/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0174 - 139ms/epoch - 9ms/step
# Epoch 93/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0174 - 146ms/epoch - 10ms/step
# Epoch 94/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0174 - 137ms/epoch - 9ms/step
# Epoch 95/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0174 - 145ms/epoch - 10ms/step
# Epoch 96/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0174 - 146ms/epoch - 10ms/step
# Epoch 97/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0174 - 140ms/epoch - 9ms/step
# Epoch 98/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0174 - 143ms/epoch - 10ms/step
# Epoch 99/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0174 - 135ms/epoch - 9ms/step
# Epoch 100/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0174 - 155ms/epoch - 10ms/step
# Epoch 101/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0173 - 154ms/epoch - 10ms/step
# Epoch 102/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0173 - 178ms/epoch - 12ms/step
# Epoch 103/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0173 - 167ms/epoch - 11ms/step
# Epoch 104/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0173 - 164ms/epoch - 11ms/step
# Epoch 105/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0173 - 231ms/epoch - 15ms/step
# Epoch 106/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0173 - 194ms/epoch - 13ms/step
# Epoch 107/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0173 - 171ms/epoch - 11ms/step
# Epoch 108/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0173 - 172ms/epoch - 11ms/step
# Epoch 109/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0173 - 162ms/epoch - 11ms/step
# Epoch 110/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0172 - 157ms/epoch - 10ms/step
# Epoch 111/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0172 - 167ms/epoch - 11ms/step
# Epoch 112/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0172 - 145ms/epoch - 10ms/step
# Epoch 113/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0172 - 132ms/epoch - 9ms/step
# Epoch 114/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0172 - 142ms/epoch - 9ms/step
# Epoch 115/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0172 - 133ms/epoch - 9ms/step
# Epoch 116/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0172 - 133ms/epoch - 9ms/step
# Epoch 117/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0172 - 138ms/epoch - 9ms/step
# Epoch 118/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0172 - 144ms/epoch - 10ms/step
# Epoch 119/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0172 - 138ms/epoch - 9ms/step
# Epoch 120/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0171 - 141ms/epoch - 9ms/step
# Epoch 121/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0171 - 183ms/epoch - 12ms/step
# Epoch 122/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0171 - 162ms/epoch - 11ms/step
# Epoch 123/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0171 - 166ms/epoch - 11ms/step
# Epoch 124/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0171 - 153ms/epoch - 10ms/step
# Epoch 125/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0171 - 163ms/epoch - 11ms/step
# Epoch 126/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0171 - 152ms/epoch - 10ms/step
# Epoch 127/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0171 - 172ms/epoch - 11ms/step
# Epoch 128/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0170 - 161ms/epoch - 11ms/step
# Epoch 129/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0170 - 175ms/epoch - 12ms/step
# Epoch 130/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0170 - 163ms/epoch - 11ms/step
# Epoch 131/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0170 - 163ms/epoch - 11ms/step
# Epoch 132/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0170 - 158ms/epoch - 11ms/step
# Epoch 133/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0170 - 161ms/epoch - 11ms/step
# Epoch 134/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0170 - 175ms/epoch - 12ms/step
# Epoch 135/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0170 - 150ms/epoch - 10ms/step
# Epoch 136/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0169 - 162ms/epoch - 11ms/step
# Epoch 137/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0169 - 155ms/epoch - 10ms/step
# Epoch 138/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0169 - 155ms/epoch - 10ms/step
# Epoch 139/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0169 - 160ms/epoch - 11ms/step
# Epoch 140/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0169 - 145ms/epoch - 10ms/step
# Epoch 141/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0169 - 161ms/epoch - 11ms/step
# Epoch 142/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0169 - 175ms/epoch - 12ms/step
# Epoch 143/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0168 - 173ms/epoch - 12ms/step
# Epoch 144/500
# 15/15 - 0s - loss: 0.0092 - val_loss: 0.0168 - 163ms/epoch - 11ms/step
# Epoch 145/500
# 15/15 - 0s - loss: 0.0092 - val_loss: 0.0168 - 161ms/epoch - 11ms/step
# Epoch 146/500
# 15/15 - 0s - loss: 0.0092 - val_loss: 0.0168 - 173ms/epoch - 12ms/step
# Epoch 147/500
# 15/15 - 0s - loss: 0.0092 - val_loss: 0.0168 - 158ms/epoch - 11ms/step
# Epoch 148/500
# 15/15 - 0s - loss: 0.0092 - val_loss: 0.0168 - 161ms/epoch - 11ms/step
# Epoch 149/500
# 15/15 - 0s - loss: 0.0092 - val_loss: 0.0168 - 152ms/epoch - 10ms/step
# Epoch 150/500
# 15/15 - 0s - loss: 0.0092 - val_loss: 0.0167 - 159ms/epoch - 11ms/step
# Epoch 151/500
# 15/15 - 0s - loss: 0.0092 - val_loss: 0.0167 - 157ms/epoch - 10ms/step
# Epoch 152/500
# 15/15 - 0s - loss: 0.0092 - val_loss: 0.0167 - 162ms/epoch - 11ms/step
# Epoch 153/500
# 15/15 - 0s - loss: 0.0092 - val_loss: 0.0167 - 178ms/epoch - 12ms/step
# Epoch 154/500
# 15/15 - 0s - loss: 0.0092 - val_loss: 0.0167 - 140ms/epoch - 9ms/step
# Epoch 155/500
# 15/15 - 0s - loss: 0.0092 - val_loss: 0.0167 - 153ms/epoch - 10ms/step
# Epoch 156/500
# 15/15 - 0s - loss: 0.0092 - val_loss: 0.0167 - 151ms/epoch - 10ms/step
# Epoch 157/500
# 15/15 - 0s - loss: 0.0092 - val_loss: 0.0166 - 145ms/epoch - 10ms/step
# Epoch 158/500
# 15/15 - 0s - loss: 0.0091 - val_loss: 0.0166 - 153ms/epoch - 10ms/step
# Epoch 159/500
# 15/15 - 0s - loss: 0.0091 - val_loss: 0.0166 - 145ms/epoch - 10ms/step
# Epoch 160/500
# 15/15 - 0s - loss: 0.0091 - val_loss: 0.0166 - 144ms/epoch - 10ms/step
# Epoch 161/500
# 15/15 - 0s - loss: 0.0091 - val_loss: 0.0166 - 135ms/epoch - 9ms/step
# Epoch 162/500
# 15/15 - 0s - loss: 0.0091 - val_loss: 0.0166 - 152ms/epoch - 10ms/step
# Epoch 163/500
# 15/15 - 0s - loss: 0.0091 - val_loss: 0.0165 - 162ms/epoch - 11ms/step
# Epoch 164/500
# 15/15 - 0s - loss: 0.0091 - val_loss: 0.0165 - 147ms/epoch - 10ms/step
# Epoch 165/500
# 15/15 - 0s - loss: 0.0091 - val_loss: 0.0165 - 168ms/epoch - 11ms/step
# Epoch 166/500
# 15/15 - 0s - loss: 0.0091 - val_loss: 0.0165 - 166ms/epoch - 11ms/step
# Epoch 167/500
# 15/15 - 0s - loss: 0.0091 - val_loss: 0.0165 - 156ms/epoch - 10ms/step
# Epoch 168/500
# 15/15 - 0s - loss: 0.0091 - val_loss: 0.0165 - 266ms/epoch - 18ms/step
# Epoch 169/500
# 15/15 - 0s - loss: 0.0091 - val_loss: 0.0164 - 204ms/epoch - 14ms/step
# Epoch 170/500
# 15/15 - 0s - loss: 0.0091 - val_loss: 0.0164 - 200ms/epoch - 13ms/step
# Epoch 171/500
# 15/15 - 0s - loss: 0.0090 - val_loss: 0.0164 - 171ms/epoch - 11ms/step
# Epoch 172/500
# 15/15 - 0s - loss: 0.0090 - val_loss: 0.0164 - 157ms/epoch - 10ms/step
# Epoch 173/500
# 15/15 - 0s - loss: 0.0090 - val_loss: 0.0164 - 141ms/epoch - 9ms/step
# Epoch 174/500
# 15/15 - 0s - loss: 0.0090 - val_loss: 0.0164 - 141ms/epoch - 9ms/step
# Epoch 175/500
# 15/15 - 0s - loss: 0.0090 - val_loss: 0.0163 - 142ms/epoch - 9ms/step
# Epoch 176/500
# 15/15 - 0s - loss: 0.0090 - val_loss: 0.0163 - 125ms/epoch - 8ms/step
# Epoch 177/500
# 15/15 - 0s - loss: 0.0090 - val_loss: 0.0163 - 138ms/epoch - 9ms/step
# Epoch 178/500
# 15/15 - 0s - loss: 0.0090 - val_loss: 0.0163 - 131ms/epoch - 9ms/step
# Epoch 179/500
# 15/15 - 0s - loss: 0.0090 - val_loss: 0.0163 - 134ms/epoch - 9ms/step
# Epoch 180/500
# 15/15 - 0s - loss: 0.0090 - val_loss: 0.0163 - 138ms/epoch - 9ms/step
# Epoch 181/500
# 15/15 - 0s - loss: 0.0090 - val_loss: 0.0162 - 140ms/epoch - 9ms/step
# Epoch 182/500
# 15/15 - 0s - loss: 0.0089 - val_loss: 0.0162 - 142ms/epoch - 9ms/step
# Epoch 183/500
# 15/15 - 0s - loss: 0.0089 - val_loss: 0.0162 - 144ms/epoch - 10ms/step
# Epoch 184/500
# 15/15 - 0s - loss: 0.0089 - val_loss: 0.0162 - 167ms/epoch - 11ms/step
# Epoch 185/500
# 15/15 - 0s - loss: 0.0089 - val_loss: 0.0162 - 167ms/epoch - 11ms/step
# Epoch 186/500
# 15/15 - 0s - loss: 0.0089 - val_loss: 0.0161 - 162ms/epoch - 11ms/step
# Epoch 187/500
# 15/15 - 0s - loss: 0.0089 - val_loss: 0.0161 - 154ms/epoch - 10ms/step
# Epoch 188/500
# 15/15 - 0s - loss: 0.0089 - val_loss: 0.0161 - 163ms/epoch - 11ms/step
# Epoch 189/500
# 15/15 - 0s - loss: 0.0089 - val_loss: 0.0161 - 161ms/epoch - 11ms/step
# Epoch 190/500
# 15/15 - 0s - loss: 0.0089 - val_loss: 0.0161 - 160ms/epoch - 11ms/step
# Epoch 191/500
# 15/15 - 0s - loss: 0.0089 - val_loss: 0.0160 - 165ms/epoch - 11ms/step
# Epoch 192/500
# 15/15 - 0s - loss: 0.0089 - val_loss: 0.0160 - 160ms/epoch - 11ms/step
# Epoch 193/500
# 15/15 - 0s - loss: 0.0088 - val_loss: 0.0160 - 157ms/epoch - 10ms/step
# Epoch 194/500
# 15/15 - 0s - loss: 0.0088 - val_loss: 0.0160 - 170ms/epoch - 11ms/step
# Epoch 195/500
# 15/15 - 0s - loss: 0.0088 - val_loss: 0.0160 - 169ms/epoch - 11ms/step
# Epoch 196/500
# 15/15 - 0s - loss: 0.0088 - val_loss: 0.0159 - 163ms/epoch - 11ms/step
# Epoch 197/500
# 15/15 - 0s - loss: 0.0088 - val_loss: 0.0159 - 165ms/epoch - 11ms/step
# Epoch 198/500
# 15/15 - 0s - loss: 0.0088 - val_loss: 0.0159 - 155ms/epoch - 10ms/step
# Epoch 199/500
# 15/15 - 0s - loss: 0.0088 - val_loss: 0.0159 - 156ms/epoch - 10ms/step
# Epoch 200/500
# 15/15 - 0s - loss: 0.0088 - val_loss: 0.0159 - 156ms/epoch - 10ms/step
# Epoch 201/500
# 15/15 - 0s - loss: 0.0088 - val_loss: 0.0158 - 162ms/epoch - 11ms/step
# Epoch 202/500
# 15/15 - 0s - loss: 0.0088 - val_loss: 0.0158 - 164ms/epoch - 11ms/step
# Epoch 203/500
# 15/15 - 0s - loss: 0.0087 - val_loss: 0.0158 - 164ms/epoch - 11ms/step
# Epoch 204/500
# 15/15 - 0s - loss: 0.0087 - val_loss: 0.0158 - 184ms/epoch - 12ms/step
# Epoch 205/500
# 15/15 - 0s - loss: 0.0087 - val_loss: 0.0157 - 179ms/epoch - 12ms/step
# Epoch 206/500
# 15/15 - 0s - loss: 0.0087 - val_loss: 0.0157 - 167ms/epoch - 11ms/step
# Epoch 207/500
# 15/15 - 0s - loss: 0.0087 - val_loss: 0.0157 - 184ms/epoch - 12ms/step
# Epoch 208/500
# 15/15 - 0s - loss: 0.0087 - val_loss: 0.0157 - 174ms/epoch - 12ms/step
# Epoch 209/500
# 15/15 - 0s - loss: 0.0087 - val_loss: 0.0157 - 163ms/epoch - 11ms/step
# Epoch 210/500
# 15/15 - 0s - loss: 0.0087 - val_loss: 0.0156 - 148ms/epoch - 10ms/step
# Epoch 211/500
# 15/15 - 0s - loss: 0.0087 - val_loss: 0.0156 - 141ms/epoch - 9ms/step
# Epoch 212/500
# 15/15 - 0s - loss: 0.0086 - val_loss: 0.0156 - 144ms/epoch - 10ms/step
# Epoch 213/500
# 15/15 - 0s - loss: 0.0086 - val_loss: 0.0156 - 143ms/epoch - 10ms/step
# Epoch 214/500
# 15/15 - 0s - loss: 0.0086 - val_loss: 0.0155 - 161ms/epoch - 11ms/step
# Epoch 215/500
# 15/15 - 0s - loss: 0.0086 - val_loss: 0.0155 - 154ms/epoch - 10ms/step
# Epoch 216/500
# 15/15 - 0s - loss: 0.0086 - val_loss: 0.0155 - 147ms/epoch - 10ms/step
# Epoch 217/500
# 15/15 - 0s - loss: 0.0086 - val_loss: 0.0155 - 145ms/epoch - 10ms/step
# Epoch 218/500
# 15/15 - 0s - loss: 0.0086 - val_loss: 0.0154 - 142ms/epoch - 9ms/step
# Epoch 219/500
# 15/15 - 0s - loss: 0.0086 - val_loss: 0.0154 - 145ms/epoch - 10ms/step
# Epoch 220/500
# 15/15 - 0s - loss: 0.0086 - val_loss: 0.0154 - 140ms/epoch - 9ms/step
# Epoch 221/500
# 15/15 - 0s - loss: 0.0085 - val_loss: 0.0154 - 149ms/epoch - 10ms/step
# Epoch 222/500
# 15/15 - 0s - loss: 0.0085 - val_loss: 0.0154 - 139ms/epoch - 9ms/step
# Epoch 223/500
# 15/15 - 0s - loss: 0.0085 - val_loss: 0.0153 - 134ms/epoch - 9ms/step
# Epoch 224/500
# 15/15 - 0s - loss: 0.0085 - val_loss: 0.0153 - 147ms/epoch - 10ms/step
# Epoch 225/500
# 15/15 - 0s - loss: 0.0085 - val_loss: 0.0153 - 157ms/epoch - 10ms/step
# Epoch 226/500
# 15/15 - 0s - loss: 0.0085 - val_loss: 0.0153 - 152ms/epoch - 10ms/step
# Epoch 227/500
# 15/15 - 0s - loss: 0.0085 - val_loss: 0.0152 - 276ms/epoch - 18ms/step
# Epoch 228/500
# 15/15 - 0s - loss: 0.0085 - val_loss: 0.0152 - 175ms/epoch - 12ms/step
# Epoch 229/500
# 15/15 - 0s - loss: 0.0084 - val_loss: 0.0152 - 163ms/epoch - 11ms/step
# Epoch 230/500
# 15/15 - 0s - loss: 0.0084 - val_loss: 0.0151 - 187ms/epoch - 12ms/step
# Epoch 231/500
# 15/15 - 0s - loss: 0.0084 - val_loss: 0.0151 - 189ms/epoch - 13ms/step
# Epoch 232/500
# 15/15 - 0s - loss: 0.0084 - val_loss: 0.0151 - 176ms/epoch - 12ms/step
# Epoch 233/500
# 15/15 - 0s - loss: 0.0084 - val_loss: 0.0151 - 155ms/epoch - 10ms/step
# Epoch 234/500
# 15/15 - 0s - loss: 0.0084 - val_loss: 0.0150 - 154ms/epoch - 10ms/step
# Epoch 235/500
# 15/15 - 0s - loss: 0.0084 - val_loss: 0.0150 - 140ms/epoch - 9ms/step
# Epoch 236/500
# 15/15 - 0s - loss: 0.0084 - val_loss: 0.0150 - 156ms/epoch - 10ms/step
# Epoch 237/500
# 15/15 - 0s - loss: 0.0083 - val_loss: 0.0150 - 145ms/epoch - 10ms/step
# Epoch 238/500
# 15/15 - 0s - loss: 0.0083 - val_loss: 0.0149 - 159ms/epoch - 11ms/step
# Epoch 239/500
# 15/15 - 0s - loss: 0.0083 - val_loss: 0.0149 - 142ms/epoch - 9ms/step
# Epoch 240/500
# 15/15 - 0s - loss: 0.0083 - val_loss: 0.0149 - 137ms/epoch - 9ms/step
# Epoch 241/500
# 15/15 - 0s - loss: 0.0083 - val_loss: 0.0149 - 145ms/epoch - 10ms/step
# Epoch 242/500
# 15/15 - 0s - loss: 0.0083 - val_loss: 0.0148 - 140ms/epoch - 9ms/step
# Epoch 243/500
# 15/15 - 0s - loss: 0.0083 - val_loss: 0.0148 - 155ms/epoch - 10ms/step
# Epoch 244/500
# 15/15 - 0s - loss: 0.0083 - val_loss: 0.0148 - 149ms/epoch - 10ms/step
# Epoch 245/500
# 15/15 - 0s - loss: 0.0082 - val_loss: 0.0147 - 152ms/epoch - 10ms/step
# Epoch 246/500
# 15/15 - 0s - loss: 0.0082 - val_loss: 0.0147 - 151ms/epoch - 10ms/step
# Epoch 247/500
# 15/15 - 0s - loss: 0.0082 - val_loss: 0.0147 - 172ms/epoch - 11ms/step
# Epoch 248/500
# 15/15 - 0s - loss: 0.0082 - val_loss: 0.0147 - 212ms/epoch - 14ms/step
# Epoch 249/500
# 15/15 - 0s - loss: 0.0082 - val_loss: 0.0146 - 198ms/epoch - 13ms/step
# Epoch 250/500
# 15/15 - 0s - loss: 0.0082 - val_loss: 0.0146 - 201ms/epoch - 13ms/step
# Epoch 251/500
# 15/15 - 0s - loss: 0.0082 - val_loss: 0.0146 - 235ms/epoch - 16ms/step
# Epoch 252/500
# 15/15 - 0s - loss: 0.0081 - val_loss: 0.0145 - 222ms/epoch - 15ms/step
# Epoch 253/500
# 15/15 - 0s - loss: 0.0081 - val_loss: 0.0145 - 230ms/epoch - 15ms/step
# Epoch 254/500
# 15/15 - 0s - loss: 0.0081 - val_loss: 0.0145 - 234ms/epoch - 16ms/step
# Epoch 255/500
# 15/15 - 0s - loss: 0.0081 - val_loss: 0.0144 - 191ms/epoch - 13ms/step
# Epoch 256/500
# 15/15 - 0s - loss: 0.0081 - val_loss: 0.0144 - 173ms/epoch - 12ms/step
# Epoch 257/500
# 15/15 - 0s - loss: 0.0081 - val_loss: 0.0144 - 215ms/epoch - 14ms/step
# Epoch 258/500
# 15/15 - 0s - loss: 0.0081 - val_loss: 0.0144 - 206ms/epoch - 14ms/step
# Epoch 259/500
# 15/15 - 0s - loss: 0.0080 - val_loss: 0.0143 - 214ms/epoch - 14ms/step
# Epoch 260/500
# 15/15 - 0s - loss: 0.0080 - val_loss: 0.0143 - 216ms/epoch - 14ms/step
# Epoch 261/500
# 15/15 - 0s - loss: 0.0080 - val_loss: 0.0143 - 177ms/epoch - 12ms/step
# Epoch 262/500
# 15/15 - 0s - loss: 0.0080 - val_loss: 0.0142 - 365ms/epoch - 24ms/step
# Epoch 263/500
# 15/15 - 0s - loss: 0.0080 - val_loss: 0.0142 - 225ms/epoch - 15ms/step
# Epoch 264/500
# 15/15 - 0s - loss: 0.0080 - val_loss: 0.0142 - 227ms/epoch - 15ms/step
# Epoch 265/500
# 15/15 - 0s - loss: 0.0079 - val_loss: 0.0141 - 278ms/epoch - 19ms/step
# Epoch 266/500
# 15/15 - 0s - loss: 0.0079 - val_loss: 0.0141 - 244ms/epoch - 16ms/step
# Epoch 267/500
# 15/15 - 0s - loss: 0.0079 - val_loss: 0.0141 - 222ms/epoch - 15ms/step
# Epoch 268/500
# 15/15 - 0s - loss: 0.0079 - val_loss: 0.0140 - 187ms/epoch - 12ms/step
# Epoch 269/500
# 15/15 - 0s - loss: 0.0079 - val_loss: 0.0140 - 203ms/epoch - 14ms/step
# Epoch 270/500
# 15/15 - 0s - loss: 0.0079 - val_loss: 0.0140 - 284ms/epoch - 19ms/step
# Epoch 271/500
# 15/15 - 0s - loss: 0.0079 - val_loss: 0.0139 - 321ms/epoch - 21ms/step
# Epoch 272/500
# 15/15 - 0s - loss: 0.0078 - val_loss: 0.0139 - 250ms/epoch - 17ms/step
# Epoch 273/500
# 15/15 - 0s - loss: 0.0078 - val_loss: 0.0139 - 227ms/epoch - 15ms/step
# Epoch 274/500
# 15/15 - 0s - loss: 0.0078 - val_loss: 0.0138 - 196ms/epoch - 13ms/step
# Epoch 275/500
# 15/15 - 0s - loss: 0.0078 - val_loss: 0.0138 - 200ms/epoch - 13ms/step
# Epoch 276/500
# 15/15 - 0s - loss: 0.0078 - val_loss: 0.0138 - 156ms/epoch - 10ms/step
# Epoch 277/500
# 15/15 - 0s - loss: 0.0078 - val_loss: 0.0137 - 156ms/epoch - 10ms/step
# Epoch 278/500
# 15/15 - 0s - loss: 0.0077 - val_loss: 0.0137 - 156ms/epoch - 10ms/step
# Epoch 279/500
# 15/15 - 0s - loss: 0.0077 - val_loss: 0.0137 - 219ms/epoch - 15ms/step
# Epoch 280/500
# 15/15 - 0s - loss: 0.0077 - val_loss: 0.0136 - 246ms/epoch - 16ms/step
# Epoch 281/500
# 15/15 - 0s - loss: 0.0077 - val_loss: 0.0136 - 181ms/epoch - 12ms/step
# Epoch 282/500
# 15/15 - 0s - loss: 0.0077 - val_loss: 0.0136 - 153ms/epoch - 10ms/step
# Epoch 283/500
# 15/15 - 0s - loss: 0.0077 - val_loss: 0.0135 - 161ms/epoch - 11ms/step
# Epoch 284/500
# 15/15 - 0s - loss: 0.0076 - val_loss: 0.0135 - 216ms/epoch - 14ms/step
# Epoch 285/500
# 15/15 - 0s - loss: 0.0076 - val_loss: 0.0134 - 210ms/epoch - 14ms/step
# Epoch 286/500
# 15/15 - 0s - loss: 0.0076 - val_loss: 0.0134 - 219ms/epoch - 15ms/step
# Epoch 287/500
# 15/15 - 0s - loss: 0.0076 - val_loss: 0.0134 - 206ms/epoch - 14ms/step
# Epoch 288/500
# 15/15 - 0s - loss: 0.0076 - val_loss: 0.0133 - 233ms/epoch - 16ms/step
# Epoch 289/500
# 15/15 - 0s - loss: 0.0076 - val_loss: 0.0133 - 178ms/epoch - 12ms/step
# Epoch 290/500
# 15/15 - 0s - loss: 0.0075 - val_loss: 0.0133 - 222ms/epoch - 15ms/step
# Epoch 291/500
# 15/15 - 0s - loss: 0.0075 - val_loss: 0.0132 - 191ms/epoch - 13ms/step
# Epoch 292/500
# 15/15 - 0s - loss: 0.0075 - val_loss: 0.0132 - 200ms/epoch - 13ms/step
# Epoch 293/500
# 15/15 - 0s - loss: 0.0075 - val_loss: 0.0132 - 152ms/epoch - 10ms/step
# Epoch 294/500
# 15/15 - 0s - loss: 0.0075 - val_loss: 0.0131 - 228ms/epoch - 15ms/step
# Epoch 295/500
# 15/15 - 0s - loss: 0.0074 - val_loss: 0.0131 - 301ms/epoch - 20ms/step
# Epoch 296/500
# 15/15 - 0s - loss: 0.0074 - val_loss: 0.0130 - 215ms/epoch - 14ms/step
# Epoch 297/500
# 15/15 - 0s - loss: 0.0074 - val_loss: 0.0130 - 235ms/epoch - 16ms/step
# Epoch 298/500
# 15/15 - 0s - loss: 0.0074 - val_loss: 0.0130 - 199ms/epoch - 13ms/step
# Epoch 299/500
# 15/15 - 0s - loss: 0.0074 - val_loss: 0.0129 - 187ms/epoch - 12ms/step
# Epoch 300/500
# 15/15 - 0s - loss: 0.0074 - val_loss: 0.0129 - 197ms/epoch - 13ms/step
# Epoch 301/500
# 15/15 - 0s - loss: 0.0073 - val_loss: 0.0128 - 176ms/epoch - 12ms/step
# Epoch 302/500
# 15/15 - 0s - loss: 0.0073 - val_loss: 0.0128 - 158ms/epoch - 11ms/step
# Epoch 303/500
# 15/15 - 0s - loss: 0.0073 - val_loss: 0.0128 - 155ms/epoch - 10ms/step
# Epoch 304/500
# 15/15 - 0s - loss: 0.0073 - val_loss: 0.0127 - 139ms/epoch - 9ms/step
# Epoch 305/500
# 15/15 - 0s - loss: 0.0073 - val_loss: 0.0127 - 147ms/epoch - 10ms/step
# Epoch 306/500
# 15/15 - 0s - loss: 0.0072 - val_loss: 0.0127 - 161ms/epoch - 11ms/step
# Epoch 307/500
# 15/15 - 0s - loss: 0.0072 - val_loss: 0.0126 - 206ms/epoch - 14ms/step
# Epoch 308/500
# 15/15 - 0s - loss: 0.0072 - val_loss: 0.0126 - 202ms/epoch - 13ms/step
# Epoch 309/500
# 15/15 - 0s - loss: 0.0072 - val_loss: 0.0125 - 170ms/epoch - 11ms/step
# Epoch 310/500
# 15/15 - 0s - loss: 0.0072 - val_loss: 0.0125 - 169ms/epoch - 11ms/step
# Epoch 311/500
# 15/15 - 0s - loss: 0.0071 - val_loss: 0.0125 - 162ms/epoch - 11ms/step
# Epoch 312/500
# 15/15 - 0s - loss: 0.0071 - val_loss: 0.0124 - 204ms/epoch - 14ms/step
# Epoch 313/500
# 15/15 - 0s - loss: 0.0071 - val_loss: 0.0124 - 375ms/epoch - 25ms/step
# Epoch 314/500
# 15/15 - 0s - loss: 0.0071 - val_loss: 0.0123 - 183ms/epoch - 12ms/step
# Epoch 315/500
# 15/15 - 0s - loss: 0.0071 - val_loss: 0.0123 - 169ms/epoch - 11ms/step
# Epoch 316/500
# 15/15 - 0s - loss: 0.0071 - val_loss: 0.0122 - 171ms/epoch - 11ms/step
# Epoch 317/500
# 15/15 - 0s - loss: 0.0070 - val_loss: 0.0122 - 173ms/epoch - 12ms/step
# Epoch 318/500
# 15/15 - 0s - loss: 0.0070 - val_loss: 0.0122 - 218ms/epoch - 15ms/step
# Epoch 319/500
# 15/15 - 0s - loss: 0.0070 - val_loss: 0.0121 - 208ms/epoch - 14ms/step
# Epoch 320/500
# 15/15 - 0s - loss: 0.0070 - val_loss: 0.0121 - 201ms/epoch - 13ms/step
# Epoch 321/500
# 15/15 - 0s - loss: 0.0070 - val_loss: 0.0120 - 186ms/epoch - 12ms/step
# Epoch 322/500
# 15/15 - 0s - loss: 0.0069 - val_loss: 0.0120 - 179ms/epoch - 12ms/step
# Epoch 323/500
# 15/15 - 0s - loss: 0.0069 - val_loss: 0.0119 - 172ms/epoch - 11ms/step
# Epoch 324/500
# 15/15 - 0s - loss: 0.0069 - val_loss: 0.0119 - 176ms/epoch - 12ms/step
# Epoch 325/500
# 15/15 - 0s - loss: 0.0069 - val_loss: 0.0119 - 222ms/epoch - 15ms/step
# Epoch 326/500
# 15/15 - 0s - loss: 0.0069 - val_loss: 0.0118 - 197ms/epoch - 13ms/step
# Epoch 327/500
# 15/15 - 0s - loss: 0.0068 - val_loss: 0.0118 - 177ms/epoch - 12ms/step
# Epoch 328/500
# 15/15 - 0s - loss: 0.0068 - val_loss: 0.0117 - 187ms/epoch - 12ms/step
# Epoch 329/500
# 15/15 - 0s - loss: 0.0068 - val_loss: 0.0117 - 179ms/epoch - 12ms/step
# Epoch 330/500
# 15/15 - 0s - loss: 0.0068 - val_loss: 0.0116 - 181ms/epoch - 12ms/step
# Epoch 331/500
# 15/15 - 0s - loss: 0.0067 - val_loss: 0.0116 - 185ms/epoch - 12ms/step
# Epoch 332/500
# 15/15 - 0s - loss: 0.0067 - val_loss: 0.0116 - 227ms/epoch - 15ms/step
# Epoch 333/500
# 15/15 - 0s - loss: 0.0067 - val_loss: 0.0115 - 189ms/epoch - 13ms/step
# Epoch 334/500
# 15/15 - 0s - loss: 0.0067 - val_loss: 0.0115 - 169ms/epoch - 11ms/step
# Epoch 335/500
# 15/15 - 0s - loss: 0.0067 - val_loss: 0.0114 - 185ms/epoch - 12ms/step
# Epoch 336/500
# 15/15 - 0s - loss: 0.0066 - val_loss: 0.0114 - 148ms/epoch - 10ms/step
# Epoch 337/500
# 15/15 - 0s - loss: 0.0066 - val_loss: 0.0113 - 158ms/epoch - 11ms/step
# Epoch 338/500
# 15/15 - 0s - loss: 0.0066 - val_loss: 0.0113 - 165ms/epoch - 11ms/step
# Epoch 339/500
# 15/15 - 0s - loss: 0.0066 - val_loss: 0.0112 - 158ms/epoch - 11ms/step
# Epoch 340/500
# 15/15 - 0s - loss: 0.0066 - val_loss: 0.0112 - 146ms/epoch - 10ms/step
# Epoch 341/500
# 15/15 - 0s - loss: 0.0065 - val_loss: 0.0112 - 141ms/epoch - 9ms/step
# Epoch 342/500
# 15/15 - 0s - loss: 0.0065 - val_loss: 0.0111 - 149ms/epoch - 10ms/step
# Epoch 343/500
# 15/15 - 0s - loss: 0.0065 - val_loss: 0.0111 - 145ms/epoch - 10ms/step
# Epoch 344/500
# 15/15 - 0s - loss: 0.0065 - val_loss: 0.0110 - 209ms/epoch - 14ms/step
# Epoch 345/500
# 15/15 - 0s - loss: 0.0065 - val_loss: 0.0110 - 172ms/epoch - 11ms/step
# Epoch 346/500
# 15/15 - 0s - loss: 0.0064 - val_loss: 0.0109 - 175ms/epoch - 12ms/step
# Epoch 347/500
# 15/15 - 0s - loss: 0.0064 - val_loss: 0.0109 - 160ms/epoch - 11ms/step
# Epoch 348/500
# 15/15 - 0s - loss: 0.0064 - val_loss: 0.0108 - 145ms/epoch - 10ms/step
# Epoch 349/500
# 15/15 - 0s - loss: 0.0064 - val_loss: 0.0108 - 150ms/epoch - 10ms/step
# Epoch 350/500
# 15/15 - 0s - loss: 0.0063 - val_loss: 0.0107 - 188ms/epoch - 13ms/step
# Epoch 351/500
# 15/15 - 0s - loss: 0.0063 - val_loss: 0.0107 - 264ms/epoch - 18ms/step
# Epoch 352/500
# 15/15 - 0s - loss: 0.0063 - val_loss: 0.0107 - 231ms/epoch - 15ms/step
# Epoch 353/500
# 15/15 - 0s - loss: 0.0063 - val_loss: 0.0106 - 213ms/epoch - 14ms/step
# Epoch 354/500
# 15/15 - 0s - loss: 0.0063 - val_loss: 0.0106 - 224ms/epoch - 15ms/step
# Epoch 355/500
# 15/15 - 0s - loss: 0.0062 - val_loss: 0.0105 - 180ms/epoch - 12ms/step
# Epoch 356/500
# 15/15 - 0s - loss: 0.0062 - val_loss: 0.0105 - 209ms/epoch - 14ms/step
# Epoch 357/500
# 15/15 - 0s - loss: 0.0062 - val_loss: 0.0104 - 170ms/epoch - 11ms/step
# Epoch 358/500
# 15/15 - 0s - loss: 0.0062 - val_loss: 0.0104 - 170ms/epoch - 11ms/step
# Epoch 359/500
# 15/15 - 0s - loss: 0.0062 - val_loss: 0.0103 - 170ms/epoch - 11ms/step
# Epoch 360/500
# 15/15 - 0s - loss: 0.0061 - val_loss: 0.0103 - 181ms/epoch - 12ms/step
# Epoch 361/500
# 15/15 - 0s - loss: 0.0061 - val_loss: 0.0102 - 160ms/epoch - 11ms/step
# Epoch 362/500
# 15/15 - 0s - loss: 0.0061 - val_loss: 0.0102 - 149ms/epoch - 10ms/step
# Epoch 363/500
# 15/15 - 0s - loss: 0.0061 - val_loss: 0.0101 - 163ms/epoch - 11ms/step
# Epoch 364/500
# 15/15 - 0s - loss: 0.0060 - val_loss: 0.0101 - 166ms/epoch - 11ms/step
# Epoch 365/500
# 15/15 - 0s - loss: 0.0060 - val_loss: 0.0100 - 325ms/epoch - 22ms/step
# Epoch 366/500
# 15/15 - 0s - loss: 0.0060 - val_loss: 0.0100 - 192ms/epoch - 13ms/step
# Epoch 367/500
# 15/15 - 0s - loss: 0.0060 - val_loss: 0.0099 - 157ms/epoch - 10ms/step
# Epoch 368/500
# 15/15 - 0s - loss: 0.0060 - val_loss: 0.0099 - 160ms/epoch - 11ms/step
# Epoch 369/500
# 15/15 - 0s - loss: 0.0059 - val_loss: 0.0099 - 154ms/epoch - 10ms/step
# Epoch 370/500
# 15/15 - 0s - loss: 0.0059 - val_loss: 0.0098 - 163ms/epoch - 11ms/step
# Epoch 371/500
# 15/15 - 0s - loss: 0.0059 - val_loss: 0.0098 - 166ms/epoch - 11ms/step
# Epoch 372/500
# 15/15 - 0s - loss: 0.0059 - val_loss: 0.0097 - 186ms/epoch - 12ms/step
# Epoch 373/500
# 15/15 - 0s - loss: 0.0059 - val_loss: 0.0097 - 177ms/epoch - 12ms/step
# Epoch 374/500
# 15/15 - 0s - loss: 0.0058 - val_loss: 0.0096 - 185ms/epoch - 12ms/step
# Epoch 375/500
# 15/15 - 0s - loss: 0.0058 - val_loss: 0.0096 - 175ms/epoch - 12ms/step
# Epoch 376/500
# 15/15 - 0s - loss: 0.0058 - val_loss: 0.0095 - 224ms/epoch - 15ms/step
# Epoch 377/500
# 15/15 - 0s - loss: 0.0058 - val_loss: 0.0095 - 184ms/epoch - 12ms/step
# Epoch 378/500
# 15/15 - 0s - loss: 0.0057 - val_loss: 0.0094 - 165ms/epoch - 11ms/step
# Epoch 379/500
# 15/15 - 0s - loss: 0.0057 - val_loss: 0.0094 - 147ms/epoch - 10ms/step
# Epoch 380/500
# 15/15 - 0s - loss: 0.0057 - val_loss: 0.0093 - 165ms/epoch - 11ms/step
# Epoch 381/500
# 15/15 - 0s - loss: 0.0057 - val_loss: 0.0093 - 156ms/epoch - 10ms/step
# Epoch 382/500
# 15/15 - 0s - loss: 0.0057 - val_loss: 0.0092 - 169ms/epoch - 11ms/step
# Epoch 383/500
# 15/15 - 0s - loss: 0.0056 - val_loss: 0.0092 - 170ms/epoch - 11ms/step
# Epoch 384/500
# 15/15 - 0s - loss: 0.0056 - val_loss: 0.0091 - 209ms/epoch - 14ms/step
# Epoch 385/500
# 15/15 - 0s - loss: 0.0056 - val_loss: 0.0091 - 182ms/epoch - 12ms/step
# Epoch 386/500
# 15/15 - 0s - loss: 0.0056 - val_loss: 0.0090 - 191ms/epoch - 13ms/step
# Epoch 387/500
# 15/15 - 0s - loss: 0.0056 - val_loss: 0.0090 - 205ms/epoch - 14ms/step
# Epoch 388/500
# 15/15 - 0s - loss: 0.0055 - val_loss: 0.0090 - 164ms/epoch - 11ms/step
# Epoch 389/500
# 15/15 - 0s - loss: 0.0055 - val_loss: 0.0089 - 180ms/epoch - 12ms/step
# Epoch 390/500
# 15/15 - 0s - loss: 0.0055 - val_loss: 0.0089 - 182ms/epoch - 12ms/step
# Epoch 391/500
# 15/15 - 0s - loss: 0.0055 - val_loss: 0.0088 - 166ms/epoch - 11ms/step
# Epoch 392/500
# 15/15 - 0s - loss: 0.0054 - val_loss: 0.0088 - 173ms/epoch - 12ms/step
# Epoch 393/500
# 15/15 - 0s - loss: 0.0054 - val_loss: 0.0087 - 172ms/epoch - 11ms/step
# Epoch 394/500
# 15/15 - 0s - loss: 0.0054 - val_loss: 0.0087 - 167ms/epoch - 11ms/step
# Epoch 395/500
# 15/15 - 0s - loss: 0.0054 - val_loss: 0.0086 - 195ms/epoch - 13ms/step
# Epoch 396/500
# 15/15 - 0s - loss: 0.0054 - val_loss: 0.0086 - 197ms/epoch - 13ms/step
# Epoch 397/500
# 15/15 - 0s - loss: 0.0053 - val_loss: 0.0085 - 179ms/epoch - 12ms/step
# Epoch 398/500
# 15/15 - 0s - loss: 0.0053 - val_loss: 0.0085 - 167ms/epoch - 11ms/step
# Epoch 399/500
# 15/15 - 0s - loss: 0.0053 - val_loss: 0.0084 - 157ms/epoch - 10ms/step
# Epoch 400/500
# 15/15 - 0s - loss: 0.0053 - val_loss: 0.0084 - 153ms/epoch - 10ms/step
# Epoch 401/500
# 15/15 - 0s - loss: 0.0053 - val_loss: 0.0084 - 147ms/epoch - 10ms/step
# Epoch 402/500
# 15/15 - 0s - loss: 0.0052 - val_loss: 0.0083 - 150ms/epoch - 10ms/step
# Epoch 403/500
# 15/15 - 0s - loss: 0.0052 - val_loss: 0.0083 - 152ms/epoch - 10ms/step
# Epoch 404/500
# 15/15 - 0s - loss: 0.0052 - val_loss: 0.0082 - 150ms/epoch - 10ms/step
# Epoch 405/500
# 15/15 - 0s - loss: 0.0052 - val_loss: 0.0082 - 166ms/epoch - 11ms/step
# Epoch 406/500
# 15/15 - 0s - loss: 0.0052 - val_loss: 0.0081 - 190ms/epoch - 13ms/step
# Epoch 407/500
# 15/15 - 0s - loss: 0.0051 - val_loss: 0.0081 - 180ms/epoch - 12ms/step
# Epoch 408/500
# 15/15 - 0s - loss: 0.0051 - val_loss: 0.0080 - 172ms/epoch - 11ms/step
# Epoch 409/500
# 15/15 - 0s - loss: 0.0051 - val_loss: 0.0080 - 175ms/epoch - 12ms/step
# Epoch 410/500
# 15/15 - 0s - loss: 0.0051 - val_loss: 0.0080 - 180ms/epoch - 12ms/step
# Epoch 411/500
# 15/15 - 0s - loss: 0.0051 - val_loss: 0.0079 - 363ms/epoch - 24ms/step
# Epoch 412/500
# 15/15 - 0s - loss: 0.0050 - val_loss: 0.0079 - 178ms/epoch - 12ms/step
# Epoch 413/500
# 15/15 - 0s - loss: 0.0050 - val_loss: 0.0078 - 184ms/epoch - 12ms/step
# Epoch 414/500
# 15/15 - 0s - loss: 0.0050 - val_loss: 0.0078 - 197ms/epoch - 13ms/step
# Epoch 415/500
# 15/15 - 0s - loss: 0.0050 - val_loss: 0.0077 - 181ms/epoch - 12ms/step
# Epoch 416/500
# 15/15 - 0s - loss: 0.0050 - val_loss: 0.0077 - 172ms/epoch - 11ms/step
# Epoch 417/500
# 15/15 - 0s - loss: 0.0050 - val_loss: 0.0077 - 165ms/epoch - 11ms/step
# Epoch 418/500
# 15/15 - 0s - loss: 0.0049 - val_loss: 0.0076 - 160ms/epoch - 11ms/step
# Epoch 419/500
# 15/15 - 0s - loss: 0.0049 - val_loss: 0.0076 - 175ms/epoch - 12ms/step
# Epoch 420/500
# 15/15 - 0s - loss: 0.0049 - val_loss: 0.0075 - 187ms/epoch - 12ms/step
# Epoch 421/500
# 15/15 - 0s - loss: 0.0049 - val_loss: 0.0075 - 167ms/epoch - 11ms/step
# Epoch 422/500
# 15/15 - 0s - loss: 0.0049 - val_loss: 0.0074 - 170ms/epoch - 11ms/step
# Epoch 423/500
# 15/15 - 0s - loss: 0.0048 - val_loss: 0.0074 - 146ms/epoch - 10ms/step
# Epoch 424/500
# 15/15 - 0s - loss: 0.0048 - val_loss: 0.0074 - 144ms/epoch - 10ms/step
# Epoch 425/500
# 15/15 - 0s - loss: 0.0048 - val_loss: 0.0073 - 141ms/epoch - 9ms/step
# Epoch 426/500
# 15/15 - 0s - loss: 0.0048 - val_loss: 0.0073 - 173ms/epoch - 12ms/step
# Epoch 427/500
# 15/15 - 0s - loss: 0.0048 - val_loss: 0.0072 - 155ms/epoch - 10ms/step
# Epoch 428/500
# 15/15 - 0s - loss: 0.0048 - val_loss: 0.0072 - 144ms/epoch - 10ms/step
# Epoch 429/500
# 15/15 - 0s - loss: 0.0047 - val_loss: 0.0072 - 155ms/epoch - 10ms/step
# Epoch 430/500
# 15/15 - 0s - loss: 0.0047 - val_loss: 0.0071 - 152ms/epoch - 10ms/step
# Epoch 431/500
# 15/15 - 0s - loss: 0.0047 - val_loss: 0.0071 - 176ms/epoch - 12ms/step
# Epoch 432/500
# 15/15 - 0s - loss: 0.0047 - val_loss: 0.0070 - 187ms/epoch - 12ms/step
# Epoch 433/500
# 15/15 - 0s - loss: 0.0047 - val_loss: 0.0070 - 166ms/epoch - 11ms/step
# Epoch 434/500
# 15/15 - 0s - loss: 0.0047 - val_loss: 0.0070 - 171ms/epoch - 11ms/step
# Epoch 435/500
# 15/15 - 0s - loss: 0.0046 - val_loss: 0.0069 - 167ms/epoch - 11ms/step
# Epoch 436/500
# 15/15 - 0s - loss: 0.0046 - val_loss: 0.0069 - 195ms/epoch - 13ms/step
# Epoch 437/500
# 15/15 - 0s - loss: 0.0046 - val_loss: 0.0069 - 162ms/epoch - 11ms/step
# Epoch 438/500
# 15/15 - 0s - loss: 0.0046 - val_loss: 0.0068 - 161ms/epoch - 11ms/step
# Epoch 439/500
# 15/15 - 0s - loss: 0.0046 - val_loss: 0.0068 - 183ms/epoch - 12ms/step
# Epoch 440/500
# 15/15 - 0s - loss: 0.0046 - val_loss: 0.0067 - 194ms/epoch - 13ms/step
# Epoch 441/500
# 15/15 - 0s - loss: 0.0045 - val_loss: 0.0067 - 176ms/epoch - 12ms/step
# Epoch 442/500
# 15/15 - 0s - loss: 0.0045 - val_loss: 0.0067 - 176ms/epoch - 12ms/step
# Epoch 443/500
# 15/15 - 0s - loss: 0.0045 - val_loss: 0.0066 - 164ms/epoch - 11ms/step
# Epoch 444/500
# 15/15 - 0s - loss: 0.0045 - val_loss: 0.0066 - 167ms/epoch - 11ms/step
# Epoch 445/500
# 15/15 - 0s - loss: 0.0045 - val_loss: 0.0066 - 159ms/epoch - 11ms/step
# Epoch 446/500
# 15/15 - 0s - loss: 0.0045 - val_loss: 0.0065 - 161ms/epoch - 11ms/step
# Epoch 447/500
# 15/15 - 0s - loss: 0.0045 - val_loss: 0.0065 - 160ms/epoch - 11ms/step
# Epoch 448/500
# 15/15 - 0s - loss: 0.0044 - val_loss: 0.0065 - 175ms/epoch - 12ms/step
# Epoch 449/500
# 15/15 - 0s - loss: 0.0044 - val_loss: 0.0064 - 156ms/epoch - 10ms/step
# Epoch 450/500
# 15/15 - 0s - loss: 0.0044 - val_loss: 0.0064 - 162ms/epoch - 11ms/step
# Epoch 451/500
# 15/15 - 0s - loss: 0.0044 - val_loss: 0.0064 - 176ms/epoch - 12ms/step
# Epoch 452/500
# 15/15 - 0s - loss: 0.0044 - val_loss: 0.0063 - 165ms/epoch - 11ms/step
# Epoch 453/500
# 15/15 - 0s - loss: 0.0044 - val_loss: 0.0063 - 172ms/epoch - 11ms/step
# Epoch 454/500
# 15/15 - 0s - loss: 0.0044 - val_loss: 0.0063 - 176ms/epoch - 12ms/step
# Epoch 455/500
# 15/15 - 0s - loss: 0.0043 - val_loss: 0.0062 - 178ms/epoch - 12ms/step
# Epoch 456/500
# 15/15 - 0s - loss: 0.0043 - val_loss: 0.0062 - 174ms/epoch - 12ms/step
# Epoch 457/500
# 15/15 - 0s - loss: 0.0043 - val_loss: 0.0062 - 162ms/epoch - 11ms/step
# Epoch 458/500
# 15/15 - 0s - loss: 0.0043 - val_loss: 0.0061 - 141ms/epoch - 9ms/step
# Epoch 459/500
# 15/15 - 0s - loss: 0.0043 - val_loss: 0.0061 - 140ms/epoch - 9ms/step
# Epoch 460/500
# 15/15 - 0s - loss: 0.0043 - val_loss: 0.0061 - 148ms/epoch - 10ms/step
# Epoch 461/500
# 15/15 - 0s - loss: 0.0043 - val_loss: 0.0061 - 173ms/epoch - 12ms/step
# Epoch 462/500
# 15/15 - 0s - loss: 0.0042 - val_loss: 0.0060 - 148ms/epoch - 10ms/step
# Epoch 463/500
# 15/15 - 0s - loss: 0.0042 - val_loss: 0.0060 - 140ms/epoch - 9ms/step
# Epoch 464/500
# 15/15 - 0s - loss: 0.0042 - val_loss: 0.0060 - 150ms/epoch - 10ms/step
# Epoch 465/500
# 15/15 - 0s - loss: 0.0042 - val_loss: 0.0059 - 158ms/epoch - 11ms/step
# Epoch 466/500
# 15/15 - 0s - loss: 0.0042 - val_loss: 0.0059 - 171ms/epoch - 11ms/step
# Epoch 467/500
# 15/15 - 0s - loss: 0.0042 - val_loss: 0.0059 - 177ms/epoch - 12ms/step
# Epoch 468/500
# 15/15 - 0s - loss: 0.0042 - val_loss: 0.0059 - 176ms/epoch - 12ms/step
# Epoch 469/500
# 15/15 - 0s - loss: 0.0042 - val_loss: 0.0058 - 168ms/epoch - 11ms/step
# Epoch 470/500
# 15/15 - 0s - loss: 0.0041 - val_loss: 0.0058 - 275ms/epoch - 18ms/step
# Epoch 471/500
# 15/15 - 0s - loss: 0.0041 - val_loss: 0.0058 - 170ms/epoch - 11ms/step
# Epoch 472/500
# 15/15 - 0s - loss: 0.0041 - val_loss: 0.0057 - 171ms/epoch - 11ms/step
# Epoch 473/500
# 15/15 - 0s - loss: 0.0041 - val_loss: 0.0057 - 174ms/epoch - 12ms/step
# Epoch 474/500
# 15/15 - 0s - loss: 0.0041 - val_loss: 0.0057 - 204ms/epoch - 14ms/step
# Epoch 475/500
# 15/15 - 0s - loss: 0.0041 - val_loss: 0.0057 - 195ms/epoch - 13ms/step
# Epoch 476/500
# 15/15 - 0s - loss: 0.0041 - val_loss: 0.0056 - 193ms/epoch - 13ms/step
# Epoch 477/500
# 15/15 - 0s - loss: 0.0041 - val_loss: 0.0056 - 194ms/epoch - 13ms/step
# Epoch 478/500
# 15/15 - 0s - loss: 0.0040 - val_loss: 0.0056 - 161ms/epoch - 11ms/step
# Epoch 479/500
# 15/15 - 0s - loss: 0.0040 - val_loss: 0.0056 - 149ms/epoch - 10ms/step
# Epoch 480/500
# 15/15 - 0s - loss: 0.0040 - val_loss: 0.0055 - 152ms/epoch - 10ms/step
# Epoch 481/500
# 15/15 - 0s - loss: 0.0040 - val_loss: 0.0055 - 178ms/epoch - 12ms/step
# Epoch 482/500
# 15/15 - 0s - loss: 0.0040 - val_loss: 0.0055 - 189ms/epoch - 13ms/step
# Epoch 483/500
# 15/15 - 0s - loss: 0.0040 - val_loss: 0.0055 - 177ms/epoch - 12ms/step
# Epoch 484/500
# 15/15 - 0s - loss: 0.0040 - val_loss: 0.0054 - 192ms/epoch - 13ms/step
# Epoch 485/500
# 15/15 - 0s - loss: 0.0040 - val_loss: 0.0054 - 161ms/epoch - 11ms/step
# Epoch 486/500
# 15/15 - 0s - loss: 0.0040 - val_loss: 0.0054 - 166ms/epoch - 11ms/step
# Epoch 487/500
# 15/15 - 0s - loss: 0.0039 - val_loss: 0.0054 - 187ms/epoch - 12ms/step
# Epoch 488/500
# 15/15 - 0s - loss: 0.0039 - val_loss: 0.0054 - 170ms/epoch - 11ms/step
# Epoch 489/500
# 15/15 - 0s - loss: 0.0039 - val_loss: 0.0053 - 165ms/epoch - 11ms/step
# Epoch 490/500
# 15/15 - 0s - loss: 0.0039 - val_loss: 0.0053 - 166ms/epoch - 11ms/step
# Epoch 491/500
# 15/15 - 0s - loss: 0.0039 - val_loss: 0.0053 - 154ms/epoch - 10ms/step
# Epoch 492/500
# 15/15 - 0s - loss: 0.0039 - val_loss: 0.0053 - 146ms/epoch - 10ms/step
# Epoch 493/500
# 15/15 - 0s - loss: 0.0039 - val_loss: 0.0052 - 198ms/epoch - 13ms/step
# Epoch 494/500
# 15/15 - 0s - loss: 0.0039 - val_loss: 0.0052 - 188ms/epoch - 13ms/step
# Epoch 495/500
# 15/15 - 0s - loss: 0.0039 - val_loss: 0.0052 - 181ms/epoch - 12ms/step
# Epoch 496/500
# 15/15 - 0s - loss: 0.0038 - val_loss: 0.0052 - 205ms/epoch - 14ms/step
# Epoch 497/500
# 15/15 - 0s - loss: 0.0038 - val_loss: 0.0052 - 197ms/epoch - 13ms/step
# Epoch 498/500
# 15/15 - 0s - loss: 0.0038 - val_loss: 0.0051 - 242ms/epoch - 16ms/step
# Epoch 499/500
# 15/15 - 0s - loss: 0.0038 - val_loss: 0.0051 - 270ms/epoch - 18ms/step
# Epoch 500/500
# 15/15 - 0s - loss: 0.0038 - val_loss: 0.0051 - 209ms/epoch - 14ms/step

# %% [markdown]
# ## Metrics ($LVPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
phy = phys2(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 8/8 [==============================] - 2s 3ms/step
# (237, 3)
# (237, 10)
# Test RMSE: 32.895
# Test MAE: 21.349

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('San Juan Dengue Spread', fontsize=20)
plt.legend(fontsize=20)
plt.show()
