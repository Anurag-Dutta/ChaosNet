# %% [markdown]
# # Time Series Prediction with Lotka Volterra Equation Inspired Deep Learning ($LVPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-11 20:47:17

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _दिल्ली WIND SPEED_

# %%
data = pd.read_csv("datasets/delhi.csv")
training_set = data.iloc[:, 3]
print(training_set)
# Out:
# 0       0.000000
# 1       2.980000
# 2       4.633333
# 3       1.233333
# 4       3.700000
#           ...
# 1457    3.547826
# 1458    6.000000
# 1459    6.266667
# 1460    7.325000
# 1461    0.000000
# Name: wind_speed, Length: 1462, dtype: float64

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 1 # Daily Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 42.22
# 1       2.980000
# 2       1.653333
# 3      -3.400000
# 4       2.466667
# 5      -2.220000
#           ...
# 1457   -4.787174
# 1458    2.452174
# 1459    0.266667
# 1460    1.058333
# 1461   -7.325000
# Name: wind_speed, Length: 1461, dtype: float64
# 2      -1.326667
# 3      -5.053333
# 4       5.866667
# 5      -4.686667
# 6       7.040000
#           ...
# 1457   -4.337963
# 1458    7.239348
# 1459   -2.185507
# 1460    0.791667
# 1461   -8.383333
# Name: wind_speed, Length: 1460, dtype: float64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0       2.980000
# 1       1.653333
# 2      -3.400000
# 3       2.466667
# 4      -2.220000
#           ...
# 1456   -4.787174
# 1457    2.452174
# 1458    0.266667
# 1459    1.058333
# 1460   -7.325000
# Name: wind_speed, Length: 1461, dtype: float64
# 0      -1.326667
# 1      -5.053333
# 2       5.866667
# 3      -4.686667
# 4       7.040000
#           ...
# 1455   -4.337963
# 1456    7.239348
# 1457   -2.185507
# 1458    0.791667
# 1459   -8.383333
# Name: wind_speed, Length: 1460, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (1461,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lotka Volterra Equation_)

# %% [markdown]
# _Parameters_: $\alpha=0.1, \beta=0.05, \gamma=1.1, \delta=0.1\\$

# %%
a=0.1
b=0.05
c=1.1
d=0.1
L = df.iloc[:, 2] - a*a*df.iloc[:, 0] + 2*a*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*d*(df.iloc[:,0]**2)*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - c*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10    0.000000   2.980000   4.633333   1.233333   3.700000   1.480000
# 11    2.980000   4.633333   1.233333   3.700000   1.480000   6.300000
# 12    4.633333   1.233333   3.700000   1.480000   6.300000   7.142857
# 13    1.233333   3.700000   1.480000   6.300000   7.142857  12.500000
# 14    3.700000   1.480000   6.300000   7.142857  12.500000   7.400000
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)    var1(t)   var2(t)    var3(t)
# 10   6.300000   7.142857  12.500000   7.400000  10.571429  2.657143 -11.252381
# 11   7.142857  12.500000   7.400000  10.571429  13.228571 -8.595238   4.578571
# 12  12.500000   7.400000  10.571429  13.228571   4.633333 -4.016667   3.928571
# 13   7.400000  10.571429  13.228571   4.633333   0.616667 -0.088095  -0.440476
# 14  10.571429  13.228571   4.633333   0.616667   0.528571 -0.528571   5.778571
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (1450, 13)
# (1450, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (1160, 1, 10) (1160, 3) (290, 1, 10) (290, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] - a*a*y_true[:, 0] + 2*a*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*d*(y_true[:,0]**2)*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - c*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))), (y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] - a*a*y_pred[:-2] + 2*a*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*d*(y_pred[:-2]**2)*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - c*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] - a*a*y_real[:-2] + 2*a*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*d*(y_real[:-2]**2)*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - c*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($LVPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square(y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 19/19 - 10s - loss: 0.2703 - val_loss: 0.0301 - 10s/epoch - 531ms/step
# Epoch 2/500
# 19/19 - 0s - loss: 0.0258 - val_loss: 0.0267 - 145ms/epoch - 8ms/step
# Epoch 3/500
# 19/19 - 0s - loss: 0.0243 - val_loss: 0.0261 - 159ms/epoch - 8ms/step
# Epoch 4/500
# 19/19 - 0s - loss: 0.0240 - val_loss: 0.0260 - 173ms/epoch - 9ms/step
# Epoch 5/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 200ms/epoch - 11ms/step
# Epoch 6/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 221ms/epoch - 12ms/step
# Epoch 7/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 179ms/epoch - 9ms/step
# Epoch 8/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 167ms/epoch - 9ms/step
# Epoch 9/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 173ms/epoch - 9ms/step
# Epoch 10/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 229ms/epoch - 12ms/step
# Epoch 11/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 179ms/epoch - 9ms/step
# Epoch 12/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 151ms/epoch - 8ms/step
# Epoch 13/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 172ms/epoch - 9ms/step
# Epoch 14/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 177ms/epoch - 9ms/step
# Epoch 15/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 173ms/epoch - 9ms/step
# Epoch 16/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 207ms/epoch - 11ms/step
# Epoch 17/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 263ms/epoch - 14ms/step
# Epoch 18/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 207ms/epoch - 11ms/step
# Epoch 19/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 163ms/epoch - 9ms/step
# Epoch 20/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 193ms/epoch - 10ms/step
# Epoch 21/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 171ms/epoch - 9ms/step
# Epoch 22/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 171ms/epoch - 9ms/step
# Epoch 23/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 176ms/epoch - 9ms/step
# Epoch 24/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 168ms/epoch - 9ms/step
# Epoch 25/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0259 - 187ms/epoch - 10ms/step
# Epoch 26/500
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0258 - 266ms/epoch - 14ms/step
# Epoch 27/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 225ms/epoch - 12ms/step
# Epoch 28/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 314ms/epoch - 17ms/step
# Epoch 29/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 193ms/epoch - 10ms/step
# Epoch 30/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 201ms/epoch - 11ms/step
# Epoch 31/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 159ms/epoch - 8ms/step
# Epoch 32/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 129ms/epoch - 7ms/step
# Epoch 33/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 122ms/epoch - 6ms/step
# Epoch 34/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 115ms/epoch - 6ms/step
# Epoch 35/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 108ms/epoch - 6ms/step
# Epoch 36/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 181ms/epoch - 10ms/step
# Epoch 37/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 169ms/epoch - 9ms/step
# Epoch 38/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 239ms/epoch - 13ms/step
# Epoch 39/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 321ms/epoch - 17ms/step
# Epoch 40/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 203ms/epoch - 11ms/step
# Epoch 41/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 201ms/epoch - 11ms/step
# Epoch 42/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 285ms/epoch - 15ms/step
# Epoch 43/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 253ms/epoch - 13ms/step
# Epoch 44/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 213ms/epoch - 11ms/step
# Epoch 45/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 298ms/epoch - 16ms/step
# Epoch 46/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 257ms/epoch - 14ms/step
# Epoch 47/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 292ms/epoch - 15ms/step
# Epoch 48/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 173ms/epoch - 9ms/step
# Epoch 49/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 166ms/epoch - 9ms/step
# Epoch 50/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 189ms/epoch - 10ms/step
# Epoch 51/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 193ms/epoch - 10ms/step
# Epoch 52/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 216ms/epoch - 11ms/step
# Epoch 53/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 346ms/epoch - 18ms/step
# Epoch 54/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 315ms/epoch - 17ms/step
# Epoch 55/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0258 - 290ms/epoch - 15ms/step
# Epoch 56/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0257 - 266ms/epoch - 14ms/step
# Epoch 57/500
# 19/19 - 0s - loss: 0.0238 - val_loss: 0.0257 - 193ms/epoch - 10ms/step
# Epoch 58/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 167ms/epoch - 9ms/step
# Epoch 59/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 189ms/epoch - 10ms/step
# Epoch 60/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 237ms/epoch - 12ms/step
# Epoch 61/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 230ms/epoch - 12ms/step
# Epoch 62/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 228ms/epoch - 12ms/step
# Epoch 63/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 184ms/epoch - 10ms/step
# Epoch 64/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 195ms/epoch - 10ms/step
# Epoch 65/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 239ms/epoch - 13ms/step
# Epoch 66/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 219ms/epoch - 12ms/step
# Epoch 67/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 203ms/epoch - 11ms/step
# Epoch 68/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 213ms/epoch - 11ms/step
# Epoch 69/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 215ms/epoch - 11ms/step
# Epoch 70/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 237ms/epoch - 12ms/step
# Epoch 71/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 195ms/epoch - 10ms/step
# Epoch 72/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 213ms/epoch - 11ms/step
# Epoch 73/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 337ms/epoch - 18ms/step
# Epoch 74/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 260ms/epoch - 14ms/step
# Epoch 75/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 191ms/epoch - 10ms/step
# Epoch 76/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 196ms/epoch - 10ms/step
# Epoch 77/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 347ms/epoch - 18ms/step
# Epoch 78/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 219ms/epoch - 12ms/step
# Epoch 79/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0257 - 304ms/epoch - 16ms/step
# Epoch 80/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0256 - 364ms/epoch - 19ms/step
# Epoch 81/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0256 - 257ms/epoch - 14ms/step
# Epoch 82/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0256 - 236ms/epoch - 12ms/step
# Epoch 83/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0256 - 172ms/epoch - 9ms/step
# Epoch 84/500
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0256 - 146ms/epoch - 8ms/step
# Epoch 85/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0256 - 156ms/epoch - 8ms/step
# Epoch 86/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0256 - 193ms/epoch - 10ms/step
# Epoch 87/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0256 - 204ms/epoch - 11ms/step
# Epoch 88/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0256 - 205ms/epoch - 11ms/step
# Epoch 89/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0256 - 235ms/epoch - 12ms/step
# Epoch 90/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0256 - 257ms/epoch - 14ms/step
# Epoch 91/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0256 - 258ms/epoch - 14ms/step
# Epoch 92/500
# 19/19 - 1s - loss: 0.0236 - val_loss: 0.0256 - 523ms/epoch - 28ms/step
# Epoch 93/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0256 - 298ms/epoch - 16ms/step
# Epoch 94/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0256 - 334ms/epoch - 18ms/step
# Epoch 95/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0256 - 288ms/epoch - 15ms/step
# Epoch 96/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0256 - 270ms/epoch - 14ms/step
# Epoch 97/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0256 - 275ms/epoch - 14ms/step
# Epoch 98/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0256 - 283ms/epoch - 15ms/step
# Epoch 99/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0256 - 218ms/epoch - 11ms/step
# Epoch 100/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0255 - 239ms/epoch - 13ms/step
# Epoch 101/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0255 - 367ms/epoch - 19ms/step
# Epoch 102/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0255 - 269ms/epoch - 14ms/step
# Epoch 103/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0255 - 223ms/epoch - 12ms/step
# Epoch 104/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0255 - 306ms/epoch - 16ms/step
# Epoch 105/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0255 - 253ms/epoch - 13ms/step
# Epoch 106/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0255 - 259ms/epoch - 14ms/step
# Epoch 107/500
# 19/19 - 0s - loss: 0.0236 - val_loss: 0.0255 - 232ms/epoch - 12ms/step
# Epoch 108/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0255 - 206ms/epoch - 11ms/step
# Epoch 109/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0255 - 194ms/epoch - 10ms/step
# Epoch 110/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0255 - 255ms/epoch - 13ms/step
# Epoch 111/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0255 - 250ms/epoch - 13ms/step
# Epoch 112/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0255 - 217ms/epoch - 11ms/step
# Epoch 113/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0255 - 336ms/epoch - 18ms/step
# Epoch 114/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0255 - 237ms/epoch - 12ms/step
# Epoch 115/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0255 - 198ms/epoch - 10ms/step
# Epoch 116/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0255 - 167ms/epoch - 9ms/step
# Epoch 117/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0254 - 191ms/epoch - 10ms/step
# Epoch 118/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0254 - 228ms/epoch - 12ms/step
# Epoch 119/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0254 - 246ms/epoch - 13ms/step
# Epoch 120/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0254 - 304ms/epoch - 16ms/step
# Epoch 121/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0254 - 248ms/epoch - 13ms/step
# Epoch 122/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0254 - 198ms/epoch - 10ms/step
# Epoch 123/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0254 - 184ms/epoch - 10ms/step
# Epoch 124/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0254 - 186ms/epoch - 10ms/step
# Epoch 125/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0254 - 216ms/epoch - 11ms/step
# Epoch 126/500
# 19/19 - 0s - loss: 0.0235 - val_loss: 0.0254 - 222ms/epoch - 12ms/step
# Epoch 127/500
# 19/19 - 0s - loss: 0.0234 - val_loss: 0.0254 - 283ms/epoch - 15ms/step
# Epoch 128/500
# 19/19 - 0s - loss: 0.0234 - val_loss: 0.0254 - 225ms/epoch - 12ms/step
# Epoch 129/500
# 19/19 - 0s - loss: 0.0234 - val_loss: 0.0254 - 160ms/epoch - 8ms/step
# Epoch 130/500
# 19/19 - 0s - loss: 0.0234 - val_loss: 0.0254 - 205ms/epoch - 11ms/step
# Epoch 131/500
# 19/19 - 0s - loss: 0.0234 - val_loss: 0.0254 - 195ms/epoch - 10ms/step
# Epoch 132/500
# 19/19 - 0s - loss: 0.0234 - val_loss: 0.0253 - 190ms/epoch - 10ms/step
# Epoch 133/500
# 19/19 - 0s - loss: 0.0234 - val_loss: 0.0253 - 169ms/epoch - 9ms/step
# Epoch 134/500
# 19/19 - 0s - loss: 0.0234 - val_loss: 0.0253 - 135ms/epoch - 7ms/step
# Epoch 135/500
# 19/19 - 0s - loss: 0.0234 - val_loss: 0.0253 - 126ms/epoch - 7ms/step
# Epoch 136/500
# 19/19 - 0s - loss: 0.0234 - val_loss: 0.0253 - 134ms/epoch - 7ms/step
# Epoch 137/500
# 19/19 - 0s - loss: 0.0234 - val_loss: 0.0253 - 147ms/epoch - 8ms/step
# Epoch 138/500
# 19/19 - 0s - loss: 0.0234 - val_loss: 0.0253 - 144ms/epoch - 8ms/step
# Epoch 139/500
# 19/19 - 0s - loss: 0.0234 - val_loss: 0.0253 - 158ms/epoch - 8ms/step
# Epoch 140/500
# 19/19 - 0s - loss: 0.0234 - val_loss: 0.0253 - 143ms/epoch - 8ms/step
# Epoch 141/500
# 19/19 - 0s - loss: 0.0234 - val_loss: 0.0253 - 143ms/epoch - 8ms/step
# Epoch 142/500
# 19/19 - 0s - loss: 0.0234 - val_loss: 0.0253 - 149ms/epoch - 8ms/step
# Epoch 143/500
# 19/19 - 0s - loss: 0.0234 - val_loss: 0.0253 - 164ms/epoch - 9ms/step
# Epoch 144/500
# 19/19 - 0s - loss: 0.0233 - val_loss: 0.0252 - 213ms/epoch - 11ms/step
# Epoch 145/500
# 19/19 - 0s - loss: 0.0233 - val_loss: 0.0252 - 165ms/epoch - 9ms/step
# Epoch 146/500
# 19/19 - 0s - loss: 0.0233 - val_loss: 0.0252 - 144ms/epoch - 8ms/step
# Epoch 147/500
# 19/19 - 0s - loss: 0.0233 - val_loss: 0.0252 - 211ms/epoch - 11ms/step
# Epoch 148/500
# 19/19 - 0s - loss: 0.0233 - val_loss: 0.0252 - 155ms/epoch - 8ms/step
# Epoch 149/500
# 19/19 - 0s - loss: 0.0233 - val_loss: 0.0252 - 144ms/epoch - 8ms/step
# Epoch 150/500
# 19/19 - 0s - loss: 0.0233 - val_loss: 0.0252 - 139ms/epoch - 7ms/step
# Epoch 151/500
# 19/19 - 0s - loss: 0.0233 - val_loss: 0.0252 - 132ms/epoch - 7ms/step
# Epoch 152/500
# 19/19 - 0s - loss: 0.0233 - val_loss: 0.0252 - 141ms/epoch - 7ms/step
# Epoch 153/500
# 19/19 - 0s - loss: 0.0233 - val_loss: 0.0252 - 157ms/epoch - 8ms/step
# Epoch 154/500
# 19/19 - 0s - loss: 0.0233 - val_loss: 0.0252 - 148ms/epoch - 8ms/step
# Epoch 155/500
# 19/19 - 0s - loss: 0.0233 - val_loss: 0.0252 - 156ms/epoch - 8ms/step
# Epoch 156/500
# 19/19 - 0s - loss: 0.0233 - val_loss: 0.0251 - 147ms/epoch - 8ms/step
# Epoch 157/500
# 19/19 - 0s - loss: 0.0233 - val_loss: 0.0251 - 141ms/epoch - 7ms/step
# Epoch 158/500
# 19/19 - 0s - loss: 0.0232 - val_loss: 0.0251 - 125ms/epoch - 7ms/step
# Epoch 159/500
# 19/19 - 0s - loss: 0.0232 - val_loss: 0.0251 - 161ms/epoch - 8ms/step
# Epoch 160/500
# 19/19 - 0s - loss: 0.0232 - val_loss: 0.0251 - 158ms/epoch - 8ms/step
# Epoch 161/500
# 19/19 - 0s - loss: 0.0232 - val_loss: 0.0251 - 152ms/epoch - 8ms/step
# Epoch 162/500
# 19/19 - 0s - loss: 0.0232 - val_loss: 0.0251 - 139ms/epoch - 7ms/step
# Epoch 163/500
# 19/19 - 0s - loss: 0.0232 - val_loss: 0.0251 - 137ms/epoch - 7ms/step
# Epoch 164/500
# 19/19 - 0s - loss: 0.0232 - val_loss: 0.0251 - 146ms/epoch - 8ms/step
# Epoch 165/500
# 19/19 - 0s - loss: 0.0232 - val_loss: 0.0251 - 134ms/epoch - 7ms/step
# Epoch 166/500
# 19/19 - 0s - loss: 0.0232 - val_loss: 0.0250 - 135ms/epoch - 7ms/step
# Epoch 167/500
# 19/19 - 0s - loss: 0.0232 - val_loss: 0.0250 - 193ms/epoch - 10ms/step
# Epoch 168/500
# 19/19 - 0s - loss: 0.0232 - val_loss: 0.0250 - 142ms/epoch - 7ms/step
# Epoch 169/500
# 19/19 - 0s - loss: 0.0232 - val_loss: 0.0250 - 139ms/epoch - 7ms/step
# Epoch 170/500
# 19/19 - 0s - loss: 0.0231 - val_loss: 0.0250 - 143ms/epoch - 8ms/step
# Epoch 171/500
# 19/19 - 0s - loss: 0.0231 - val_loss: 0.0250 - 149ms/epoch - 8ms/step
# Epoch 172/500
# 19/19 - 0s - loss: 0.0231 - val_loss: 0.0250 - 153ms/epoch - 8ms/step
# Epoch 173/500
# 19/19 - 0s - loss: 0.0231 - val_loss: 0.0250 - 136ms/epoch - 7ms/step
# Epoch 174/500
# 19/19 - 0s - loss: 0.0231 - val_loss: 0.0250 - 138ms/epoch - 7ms/step
# Epoch 175/500
# 19/19 - 0s - loss: 0.0231 - val_loss: 0.0249 - 138ms/epoch - 7ms/step
# Epoch 176/500
# 19/19 - 0s - loss: 0.0231 - val_loss: 0.0249 - 115ms/epoch - 6ms/step
# Epoch 177/500
# 19/19 - 0s - loss: 0.0231 - val_loss: 0.0249 - 146ms/epoch - 8ms/step
# Epoch 178/500
# 19/19 - 0s - loss: 0.0231 - val_loss: 0.0249 - 193ms/epoch - 10ms/step
# Epoch 179/500
# 19/19 - 0s - loss: 0.0231 - val_loss: 0.0249 - 204ms/epoch - 11ms/step
# Epoch 180/500
# 19/19 - 0s - loss: 0.0231 - val_loss: 0.0249 - 171ms/epoch - 9ms/step
# Epoch 181/500
# 19/19 - 0s - loss: 0.0230 - val_loss: 0.0249 - 155ms/epoch - 8ms/step
# Epoch 182/500
# 19/19 - 0s - loss: 0.0230 - val_loss: 0.0249 - 178ms/epoch - 9ms/step
# Epoch 183/500
# 19/19 - 0s - loss: 0.0230 - val_loss: 0.0249 - 178ms/epoch - 9ms/step
# Epoch 184/500
# 19/19 - 0s - loss: 0.0230 - val_loss: 0.0248 - 199ms/epoch - 10ms/step
# Epoch 185/500
# 19/19 - 0s - loss: 0.0230 - val_loss: 0.0248 - 162ms/epoch - 9ms/step
# Epoch 186/500
# 19/19 - 0s - loss: 0.0230 - val_loss: 0.0248 - 153ms/epoch - 8ms/step
# Epoch 187/500
# 19/19 - 0s - loss: 0.0230 - val_loss: 0.0248 - 158ms/epoch - 8ms/step
# Epoch 188/500
# 19/19 - 0s - loss: 0.0230 - val_loss: 0.0248 - 159ms/epoch - 8ms/step
# Epoch 189/500
# 19/19 - 0s - loss: 0.0230 - val_loss: 0.0248 - 139ms/epoch - 7ms/step
# Epoch 190/500
# 19/19 - 0s - loss: 0.0230 - val_loss: 0.0248 - 137ms/epoch - 7ms/step
# Epoch 191/500
# 19/19 - 0s - loss: 0.0229 - val_loss: 0.0247 - 152ms/epoch - 8ms/step
# Epoch 192/500
# 19/19 - 0s - loss: 0.0229 - val_loss: 0.0247 - 136ms/epoch - 7ms/step
# Epoch 193/500
# 19/19 - 0s - loss: 0.0229 - val_loss: 0.0247 - 146ms/epoch - 8ms/step
# Epoch 194/500
# 19/19 - 0s - loss: 0.0229 - val_loss: 0.0247 - 132ms/epoch - 7ms/step
# Epoch 195/500
# 19/19 - 0s - loss: 0.0229 - val_loss: 0.0247 - 139ms/epoch - 7ms/step
# Epoch 196/500
# 19/19 - 0s - loss: 0.0229 - val_loss: 0.0247 - 146ms/epoch - 8ms/step
# Epoch 197/500
# 19/19 - 0s - loss: 0.0229 - val_loss: 0.0247 - 172ms/epoch - 9ms/step
# Epoch 198/500
# 19/19 - 0s - loss: 0.0229 - val_loss: 0.0247 - 191ms/epoch - 10ms/step
# Epoch 199/500
# 19/19 - 0s - loss: 0.0229 - val_loss: 0.0246 - 182ms/epoch - 10ms/step
# Epoch 200/500
# 19/19 - 0s - loss: 0.0229 - val_loss: 0.0246 - 166ms/epoch - 9ms/step
# Epoch 201/500
# 19/19 - 0s - loss: 0.0228 - val_loss: 0.0246 - 195ms/epoch - 10ms/step
# Epoch 202/500
# 19/19 - 0s - loss: 0.0228 - val_loss: 0.0246 - 209ms/epoch - 11ms/step
# Epoch 203/500
# 19/19 - 0s - loss: 0.0228 - val_loss: 0.0246 - 315ms/epoch - 17ms/step
# Epoch 204/500
# 19/19 - 0s - loss: 0.0228 - val_loss: 0.0246 - 194ms/epoch - 10ms/step
# Epoch 205/500
# 19/19 - 0s - loss: 0.0228 - val_loss: 0.0246 - 203ms/epoch - 11ms/step
# Epoch 206/500
# 19/19 - 0s - loss: 0.0228 - val_loss: 0.0245 - 191ms/epoch - 10ms/step
# Epoch 207/500
# 19/19 - 0s - loss: 0.0228 - val_loss: 0.0245 - 157ms/epoch - 8ms/step
# Epoch 208/500
# 19/19 - 0s - loss: 0.0228 - val_loss: 0.0245 - 146ms/epoch - 8ms/step
# Epoch 209/500
# 19/19 - 0s - loss: 0.0227 - val_loss: 0.0245 - 137ms/epoch - 7ms/step
# Epoch 210/500
# 19/19 - 0s - loss: 0.0227 - val_loss: 0.0245 - 177ms/epoch - 9ms/step
# Epoch 211/500
# 19/19 - 0s - loss: 0.0227 - val_loss: 0.0245 - 195ms/epoch - 10ms/step
# Epoch 212/500
# 19/19 - 0s - loss: 0.0227 - val_loss: 0.0244 - 210ms/epoch - 11ms/step
# Epoch 213/500
# 19/19 - 0s - loss: 0.0227 - val_loss: 0.0244 - 174ms/epoch - 9ms/step
# Epoch 214/500
# 19/19 - 0s - loss: 0.0227 - val_loss: 0.0244 - 157ms/epoch - 8ms/step
# Epoch 215/500
# 19/19 - 0s - loss: 0.0227 - val_loss: 0.0244 - 137ms/epoch - 7ms/step
# Epoch 216/500
# 19/19 - 0s - loss: 0.0227 - val_loss: 0.0244 - 121ms/epoch - 6ms/step
# Epoch 217/500
# 19/19 - 0s - loss: 0.0226 - val_loss: 0.0244 - 135ms/epoch - 7ms/step
# Epoch 218/500
# 19/19 - 0s - loss: 0.0226 - val_loss: 0.0243 - 120ms/epoch - 6ms/step
# Epoch 219/500
# 19/19 - 0s - loss: 0.0226 - val_loss: 0.0243 - 122ms/epoch - 6ms/step
# Epoch 220/500
# 19/19 - 0s - loss: 0.0226 - val_loss: 0.0243 - 133ms/epoch - 7ms/step
# Epoch 221/500
# 19/19 - 0s - loss: 0.0226 - val_loss: 0.0243 - 135ms/epoch - 7ms/step
# Epoch 222/500
# 19/19 - 0s - loss: 0.0226 - val_loss: 0.0243 - 122ms/epoch - 6ms/step
# Epoch 223/500
# 19/19 - 0s - loss: 0.0226 - val_loss: 0.0243 - 129ms/epoch - 7ms/step
# Epoch 224/500
# 19/19 - 0s - loss: 0.0226 - val_loss: 0.0242 - 129ms/epoch - 7ms/step
# Epoch 225/500
# 19/19 - 0s - loss: 0.0225 - val_loss: 0.0242 - 246ms/epoch - 13ms/step
# Epoch 226/500
# 19/19 - 0s - loss: 0.0225 - val_loss: 0.0242 - 189ms/epoch - 10ms/step
# Epoch 227/500
# 19/19 - 0s - loss: 0.0225 - val_loss: 0.0242 - 142ms/epoch - 7ms/step
# Epoch 228/500
# 19/19 - 0s - loss: 0.0225 - val_loss: 0.0242 - 158ms/epoch - 8ms/step
# Epoch 229/500
# 19/19 - 0s - loss: 0.0225 - val_loss: 0.0242 - 152ms/epoch - 8ms/step
# Epoch 230/500
# 19/19 - 0s - loss: 0.0225 - val_loss: 0.0241 - 149ms/epoch - 8ms/step
# Epoch 231/500
# 19/19 - 0s - loss: 0.0225 - val_loss: 0.0241 - 144ms/epoch - 8ms/step
# Epoch 232/500
# 19/19 - 0s - loss: 0.0224 - val_loss: 0.0241 - 135ms/epoch - 7ms/step
# Epoch 233/500
# 19/19 - 0s - loss: 0.0224 - val_loss: 0.0241 - 141ms/epoch - 7ms/step
# Epoch 234/500
# 19/19 - 0s - loss: 0.0224 - val_loss: 0.0241 - 168ms/epoch - 9ms/step
# Epoch 235/500
# 19/19 - 0s - loss: 0.0224 - val_loss: 0.0240 - 151ms/epoch - 8ms/step
# Epoch 236/500
# 19/19 - 0s - loss: 0.0224 - val_loss: 0.0240 - 126ms/epoch - 7ms/step
# Epoch 237/500
# 19/19 - 0s - loss: 0.0224 - val_loss: 0.0240 - 125ms/epoch - 7ms/step
# Epoch 238/500
# 19/19 - 0s - loss: 0.0223 - val_loss: 0.0240 - 129ms/epoch - 7ms/step
# Epoch 239/500
# 19/19 - 0s - loss: 0.0223 - val_loss: 0.0240 - 130ms/epoch - 7ms/step
# Epoch 240/500
# 19/19 - 0s - loss: 0.0223 - val_loss: 0.0239 - 128ms/epoch - 7ms/step
# Epoch 241/500
# 19/19 - 0s - loss: 0.0223 - val_loss: 0.0239 - 141ms/epoch - 7ms/step
# Epoch 242/500
# 19/19 - 0s - loss: 0.0223 - val_loss: 0.0239 - 249ms/epoch - 13ms/step
# Epoch 243/500
# 19/19 - 0s - loss: 0.0223 - val_loss: 0.0239 - 202ms/epoch - 11ms/step
# Epoch 244/500
# 19/19 - 0s - loss: 0.0222 - val_loss: 0.0239 - 161ms/epoch - 8ms/step
# Epoch 245/500
# 19/19 - 0s - loss: 0.0222 - val_loss: 0.0238 - 129ms/epoch - 7ms/step
# Epoch 246/500
# 19/19 - 0s - loss: 0.0222 - val_loss: 0.0238 - 170ms/epoch - 9ms/step
# Epoch 247/500
# 19/19 - 0s - loss: 0.0222 - val_loss: 0.0238 - 138ms/epoch - 7ms/step
# Epoch 248/500
# 19/19 - 0s - loss: 0.0222 - val_loss: 0.0238 - 140ms/epoch - 7ms/step
# Epoch 249/500
# 19/19 - 0s - loss: 0.0222 - val_loss: 0.0238 - 126ms/epoch - 7ms/step
# Epoch 250/500
# 19/19 - 0s - loss: 0.0221 - val_loss: 0.0237 - 167ms/epoch - 9ms/step
# Epoch 251/500
# 19/19 - 0s - loss: 0.0221 - val_loss: 0.0237 - 145ms/epoch - 8ms/step
# Epoch 252/500
# 19/19 - 0s - loss: 0.0221 - val_loss: 0.0237 - 154ms/epoch - 8ms/step
# Epoch 253/500
# 19/19 - 0s - loss: 0.0221 - val_loss: 0.0237 - 161ms/epoch - 8ms/step
# Epoch 254/500
# 19/19 - 0s - loss: 0.0221 - val_loss: 0.0236 - 150ms/epoch - 8ms/step
# Epoch 255/500
# 19/19 - 0s - loss: 0.0221 - val_loss: 0.0236 - 142ms/epoch - 7ms/step
# Epoch 256/500
# 19/19 - 0s - loss: 0.0220 - val_loss: 0.0236 - 276ms/epoch - 15ms/step
# Epoch 257/500
# 19/19 - 0s - loss: 0.0220 - val_loss: 0.0236 - 149ms/epoch - 8ms/step
# Epoch 258/500
# 19/19 - 0s - loss: 0.0220 - val_loss: 0.0236 - 135ms/epoch - 7ms/step
# Epoch 259/500
# 19/19 - 0s - loss: 0.0220 - val_loss: 0.0235 - 140ms/epoch - 7ms/step
# Epoch 260/500
# 19/19 - 0s - loss: 0.0220 - val_loss: 0.0235 - 132ms/epoch - 7ms/step
# Epoch 261/500
# 19/19 - 0s - loss: 0.0219 - val_loss: 0.0235 - 135ms/epoch - 7ms/step
# Epoch 262/500
# 19/19 - 0s - loss: 0.0219 - val_loss: 0.0235 - 127ms/epoch - 7ms/step
# Epoch 263/500
# 19/19 - 0s - loss: 0.0219 - val_loss: 0.0234 - 117ms/epoch - 6ms/step
# Epoch 264/500
# 19/19 - 0s - loss: 0.0219 - val_loss: 0.0234 - 124ms/epoch - 7ms/step
# Epoch 265/500
# 19/19 - 0s - loss: 0.0219 - val_loss: 0.0234 - 244ms/epoch - 13ms/step
# Epoch 266/500
# 19/19 - 0s - loss: 0.0219 - val_loss: 0.0234 - 198ms/epoch - 10ms/step
# Epoch 267/500
# 19/19 - 0s - loss: 0.0218 - val_loss: 0.0233 - 149ms/epoch - 8ms/step
# Epoch 268/500
# 19/19 - 0s - loss: 0.0218 - val_loss: 0.0233 - 123ms/epoch - 6ms/step
# Epoch 269/500
# 19/19 - 0s - loss: 0.0218 - val_loss: 0.0233 - 128ms/epoch - 7ms/step
# Epoch 270/500
# 19/19 - 0s - loss: 0.0218 - val_loss: 0.0233 - 202ms/epoch - 11ms/step
# Epoch 271/500
# 19/19 - 0s - loss: 0.0218 - val_loss: 0.0232 - 140ms/epoch - 7ms/step
# Epoch 272/500
# 19/19 - 0s - loss: 0.0217 - val_loss: 0.0232 - 129ms/epoch - 7ms/step
# Epoch 273/500
# 19/19 - 0s - loss: 0.0217 - val_loss: 0.0232 - 122ms/epoch - 6ms/step
# Epoch 274/500
# 19/19 - 0s - loss: 0.0217 - val_loss: 0.0231 - 126ms/epoch - 7ms/step
# Epoch 275/500
# 19/19 - 0s - loss: 0.0217 - val_loss: 0.0231 - 121ms/epoch - 6ms/step
# Epoch 276/500
# 19/19 - 0s - loss: 0.0216 - val_loss: 0.0231 - 123ms/epoch - 6ms/step
# Epoch 277/500
# 19/19 - 0s - loss: 0.0216 - val_loss: 0.0231 - 123ms/epoch - 6ms/step
# Epoch 278/500
# 19/19 - 0s - loss: 0.0216 - val_loss: 0.0230 - 140ms/epoch - 7ms/step
# Epoch 279/500
# 19/19 - 0s - loss: 0.0216 - val_loss: 0.0230 - 151ms/epoch - 8ms/step
# Epoch 280/500
# 19/19 - 0s - loss: 0.0216 - val_loss: 0.0230 - 192ms/epoch - 10ms/step
# Epoch 281/500
# 19/19 - 0s - loss: 0.0215 - val_loss: 0.0230 - 175ms/epoch - 9ms/step
# Epoch 282/500
# 19/19 - 0s - loss: 0.0215 - val_loss: 0.0229 - 154ms/epoch - 8ms/step
# Epoch 283/500
# 19/19 - 0s - loss: 0.0215 - val_loss: 0.0229 - 134ms/epoch - 7ms/step
# Epoch 284/500
# 19/19 - 0s - loss: 0.0215 - val_loss: 0.0229 - 121ms/epoch - 6ms/step
# Epoch 285/500
# 19/19 - 0s - loss: 0.0214 - val_loss: 0.0228 - 119ms/epoch - 6ms/step
# Epoch 286/500
# 19/19 - 0s - loss: 0.0214 - val_loss: 0.0228 - 153ms/epoch - 8ms/step
# Epoch 287/500
# 19/19 - 0s - loss: 0.0214 - val_loss: 0.0228 - 144ms/epoch - 8ms/step
# Epoch 288/500
# 19/19 - 0s - loss: 0.0214 - val_loss: 0.0228 - 266ms/epoch - 14ms/step
# Epoch 289/500
# 19/19 - 0s - loss: 0.0214 - val_loss: 0.0227 - 163ms/epoch - 9ms/step
# Epoch 290/500
# 19/19 - 0s - loss: 0.0213 - val_loss: 0.0227 - 156ms/epoch - 8ms/step
# Epoch 291/500
# 19/19 - 0s - loss: 0.0213 - val_loss: 0.0227 - 139ms/epoch - 7ms/step
# Epoch 292/500
# 19/19 - 0s - loss: 0.0213 - val_loss: 0.0226 - 134ms/epoch - 7ms/step
# Epoch 293/500
# 19/19 - 0s - loss: 0.0213 - val_loss: 0.0226 - 152ms/epoch - 8ms/step
# Epoch 294/500
# 19/19 - 0s - loss: 0.0212 - val_loss: 0.0226 - 190ms/epoch - 10ms/step
# Epoch 295/500
# 19/19 - 0s - loss: 0.0212 - val_loss: 0.0225 - 169ms/epoch - 9ms/step
# Epoch 296/500
# 19/19 - 0s - loss: 0.0212 - val_loss: 0.0225 - 150ms/epoch - 8ms/step
# Epoch 297/500
# 19/19 - 0s - loss: 0.0212 - val_loss: 0.0225 - 128ms/epoch - 7ms/step
# Epoch 298/500
# 19/19 - 0s - loss: 0.0211 - val_loss: 0.0224 - 130ms/epoch - 7ms/step
# Epoch 299/500
# 19/19 - 0s - loss: 0.0211 - val_loss: 0.0224 - 136ms/epoch - 7ms/step
# Epoch 300/500
# 19/19 - 0s - loss: 0.0211 - val_loss: 0.0224 - 133ms/epoch - 7ms/step
# Epoch 301/500
# 19/19 - 0s - loss: 0.0211 - val_loss: 0.0223 - 131ms/epoch - 7ms/step
# Epoch 302/500
# 19/19 - 0s - loss: 0.0210 - val_loss: 0.0223 - 166ms/epoch - 9ms/step
# Epoch 303/500
# 19/19 - 0s - loss: 0.0210 - val_loss: 0.0223 - 202ms/epoch - 11ms/step
# Epoch 304/500
# 19/19 - 0s - loss: 0.0210 - val_loss: 0.0222 - 172ms/epoch - 9ms/step
# Epoch 305/500
# 19/19 - 0s - loss: 0.0210 - val_loss: 0.0222 - 150ms/epoch - 8ms/step
# Epoch 306/500
# 19/19 - 0s - loss: 0.0209 - val_loss: 0.0222 - 173ms/epoch - 9ms/step
# Epoch 307/500
# 19/19 - 0s - loss: 0.0209 - val_loss: 0.0221 - 135ms/epoch - 7ms/step
# Epoch 308/500
# 19/19 - 0s - loss: 0.0209 - val_loss: 0.0221 - 269ms/epoch - 14ms/step
# Epoch 309/500
# 19/19 - 0s - loss: 0.0208 - val_loss: 0.0221 - 196ms/epoch - 10ms/step
# Epoch 310/500
# 19/19 - 0s - loss: 0.0208 - val_loss: 0.0220 - 151ms/epoch - 8ms/step
# Epoch 311/500
# 19/19 - 0s - loss: 0.0208 - val_loss: 0.0220 - 154ms/epoch - 8ms/step
# Epoch 312/500
# 19/19 - 0s - loss: 0.0208 - val_loss: 0.0220 - 127ms/epoch - 7ms/step
# Epoch 313/500
# 19/19 - 0s - loss: 0.0207 - val_loss: 0.0219 - 132ms/epoch - 7ms/step
# Epoch 314/500
# 19/19 - 0s - loss: 0.0207 - val_loss: 0.0219 - 124ms/epoch - 7ms/step
# Epoch 315/500
# 19/19 - 0s - loss: 0.0207 - val_loss: 0.0218 - 127ms/epoch - 7ms/step
# Epoch 316/500
# 19/19 - 0s - loss: 0.0206 - val_loss: 0.0218 - 132ms/epoch - 7ms/step
# Epoch 317/500
# 19/19 - 0s - loss: 0.0206 - val_loss: 0.0218 - 130ms/epoch - 7ms/step
# Epoch 318/500
# 19/19 - 0s - loss: 0.0206 - val_loss: 0.0217 - 131ms/epoch - 7ms/step
# Epoch 319/500
# 19/19 - 0s - loss: 0.0206 - val_loss: 0.0217 - 135ms/epoch - 7ms/step
# Epoch 320/500
# 19/19 - 0s - loss: 0.0205 - val_loss: 0.0217 - 122ms/epoch - 6ms/step
# Epoch 321/500
# 19/19 - 0s - loss: 0.0205 - val_loss: 0.0216 - 128ms/epoch - 7ms/step
# Epoch 322/500
# 19/19 - 0s - loss: 0.0205 - val_loss: 0.0216 - 127ms/epoch - 7ms/step
# Epoch 323/500
# 19/19 - 0s - loss: 0.0204 - val_loss: 0.0215 - 124ms/epoch - 7ms/step
# Epoch 324/500
# 19/19 - 0s - loss: 0.0204 - val_loss: 0.0215 - 119ms/epoch - 6ms/step
# Epoch 325/500
# 19/19 - 0s - loss: 0.0204 - val_loss: 0.0215 - 127ms/epoch - 7ms/step
# Epoch 326/500
# 19/19 - 0s - loss: 0.0203 - val_loss: 0.0214 - 140ms/epoch - 7ms/step
# Epoch 327/500
# 19/19 - 0s - loss: 0.0203 - val_loss: 0.0214 - 122ms/epoch - 6ms/step
# Epoch 328/500
# 19/19 - 0s - loss: 0.0203 - val_loss: 0.0213 - 121ms/epoch - 6ms/step
# Epoch 329/500
# 19/19 - 0s - loss: 0.0202 - val_loss: 0.0213 - 163ms/epoch - 9ms/step
# Epoch 330/500
# 19/19 - 0s - loss: 0.0202 - val_loss: 0.0213 - 158ms/epoch - 8ms/step
# Epoch 331/500
# 19/19 - 0s - loss: 0.0202 - val_loss: 0.0212 - 194ms/epoch - 10ms/step
# Epoch 332/500
# 19/19 - 0s - loss: 0.0202 - val_loss: 0.0212 - 154ms/epoch - 8ms/step
# Epoch 333/500
# 19/19 - 0s - loss: 0.0201 - val_loss: 0.0211 - 147ms/epoch - 8ms/step
# Epoch 334/500
# 19/19 - 0s - loss: 0.0201 - val_loss: 0.0211 - 162ms/epoch - 9ms/step
# Epoch 335/500
# 19/19 - 0s - loss: 0.0201 - val_loss: 0.0210 - 142ms/epoch - 7ms/step
# Epoch 336/500
# 19/19 - 0s - loss: 0.0200 - val_loss: 0.0210 - 119ms/epoch - 6ms/step
# Epoch 337/500
# 19/19 - 0s - loss: 0.0200 - val_loss: 0.0210 - 121ms/epoch - 6ms/step
# Epoch 338/500
# 19/19 - 0s - loss: 0.0200 - val_loss: 0.0209 - 119ms/epoch - 6ms/step
# Epoch 339/500
# 19/19 - 0s - loss: 0.0199 - val_loss: 0.0209 - 122ms/epoch - 6ms/step
# Epoch 340/500
# 19/19 - 0s - loss: 0.0199 - val_loss: 0.0208 - 118ms/epoch - 6ms/step
# Epoch 341/500
# 19/19 - 0s - loss: 0.0198 - val_loss: 0.0208 - 120ms/epoch - 6ms/step
# Epoch 342/500
# 19/19 - 0s - loss: 0.0198 - val_loss: 0.0207 - 117ms/epoch - 6ms/step
# Epoch 343/500
# 19/19 - 0s - loss: 0.0198 - val_loss: 0.0207 - 115ms/epoch - 6ms/step
# Epoch 344/500
# 19/19 - 0s - loss: 0.0197 - val_loss: 0.0206 - 118ms/epoch - 6ms/step
# Epoch 345/500
# 19/19 - 0s - loss: 0.0197 - val_loss: 0.0206 - 127ms/epoch - 7ms/step
# Epoch 346/500
# 19/19 - 0s - loss: 0.0197 - val_loss: 0.0206 - 123ms/epoch - 6ms/step
# Epoch 347/500
# 19/19 - 0s - loss: 0.0196 - val_loss: 0.0205 - 128ms/epoch - 7ms/step
# Epoch 348/500
# 19/19 - 0s - loss: 0.0196 - val_loss: 0.0205 - 142ms/epoch - 7ms/step
# Epoch 349/500
# 19/19 - 0s - loss: 0.0196 - val_loss: 0.0204 - 125ms/epoch - 7ms/step
# Epoch 350/500
# 19/19 - 0s - loss: 0.0195 - val_loss: 0.0204 - 124ms/epoch - 7ms/step
# Epoch 351/500
# 19/19 - 0s - loss: 0.0195 - val_loss: 0.0203 - 127ms/epoch - 7ms/step
# Epoch 352/500
# 19/19 - 0s - loss: 0.0195 - val_loss: 0.0203 - 179ms/epoch - 9ms/step
# Epoch 353/500
# 19/19 - 0s - loss: 0.0194 - val_loss: 0.0202 - 111ms/epoch - 6ms/step
# Epoch 354/500
# 19/19 - 0s - loss: 0.0194 - val_loss: 0.0202 - 110ms/epoch - 6ms/step
# Epoch 355/500
# 19/19 - 0s - loss: 0.0193 - val_loss: 0.0201 - 110ms/epoch - 6ms/step
# Epoch 356/500
# 19/19 - 0s - loss: 0.0193 - val_loss: 0.0201 - 106ms/epoch - 6ms/step
# Epoch 357/500
# 19/19 - 0s - loss: 0.0193 - val_loss: 0.0200 - 103ms/epoch - 5ms/step
# Epoch 358/500
# 19/19 - 0s - loss: 0.0192 - val_loss: 0.0200 - 103ms/epoch - 5ms/step
# Epoch 359/500
# 19/19 - 0s - loss: 0.0192 - val_loss: 0.0199 - 116ms/epoch - 6ms/step
# Epoch 360/500
# 19/19 - 0s - loss: 0.0191 - val_loss: 0.0199 - 115ms/epoch - 6ms/step
# Epoch 361/500
# 19/19 - 0s - loss: 0.0191 - val_loss: 0.0198 - 119ms/epoch - 6ms/step
# Epoch 362/500
# 19/19 - 0s - loss: 0.0191 - val_loss: 0.0198 - 119ms/epoch - 6ms/step
# Epoch 363/500
# 19/19 - 0s - loss: 0.0190 - val_loss: 0.0197 - 126ms/epoch - 7ms/step
# Epoch 364/500
# 19/19 - 0s - loss: 0.0190 - val_loss: 0.0197 - 151ms/epoch - 8ms/step
# Epoch 365/500
# 19/19 - 0s - loss: 0.0190 - val_loss: 0.0196 - 160ms/epoch - 8ms/step
# Epoch 366/500
# 19/19 - 0s - loss: 0.0189 - val_loss: 0.0196 - 145ms/epoch - 8ms/step
# Epoch 367/500
# 19/19 - 0s - loss: 0.0189 - val_loss: 0.0195 - 146ms/epoch - 8ms/step
# Epoch 368/500
# 19/19 - 0s - loss: 0.0188 - val_loss: 0.0195 - 143ms/epoch - 8ms/step
# Epoch 369/500
# 19/19 - 0s - loss: 0.0188 - val_loss: 0.0194 - 133ms/epoch - 7ms/step
# Epoch 370/500
# 19/19 - 0s - loss: 0.0187 - val_loss: 0.0193 - 199ms/epoch - 10ms/step
# Epoch 371/500
# 19/19 - 0s - loss: 0.0187 - val_loss: 0.0193 - 124ms/epoch - 7ms/step
# Epoch 372/500
# 19/19 - 0s - loss: 0.0187 - val_loss: 0.0192 - 126ms/epoch - 7ms/step
# Epoch 373/500
# 19/19 - 0s - loss: 0.0186 - val_loss: 0.0192 - 124ms/epoch - 7ms/step
# Epoch 374/500
# 19/19 - 0s - loss: 0.0186 - val_loss: 0.0191 - 120ms/epoch - 6ms/step
# Epoch 375/500
# 19/19 - 0s - loss: 0.0185 - val_loss: 0.0191 - 121ms/epoch - 6ms/step
# Epoch 376/500
# 19/19 - 0s - loss: 0.0185 - val_loss: 0.0190 - 121ms/epoch - 6ms/step
# Epoch 377/500
# 19/19 - 0s - loss: 0.0184 - val_loss: 0.0190 - 121ms/epoch - 6ms/step
# Epoch 378/500
# 19/19 - 0s - loss: 0.0184 - val_loss: 0.0189 - 120ms/epoch - 6ms/step
# Epoch 379/500
# 19/19 - 0s - loss: 0.0184 - val_loss: 0.0188 - 118ms/epoch - 6ms/step
# Epoch 380/500
# 19/19 - 0s - loss: 0.0183 - val_loss: 0.0188 - 137ms/epoch - 7ms/step
# Epoch 381/500
# 19/19 - 0s - loss: 0.0183 - val_loss: 0.0187 - 120ms/epoch - 6ms/step
# Epoch 382/500
# 19/19 - 0s - loss: 0.0182 - val_loss: 0.0187 - 124ms/epoch - 7ms/step
# Epoch 383/500
# 19/19 - 0s - loss: 0.0182 - val_loss: 0.0186 - 117ms/epoch - 6ms/step
# Epoch 384/500
# 19/19 - 0s - loss: 0.0181 - val_loss: 0.0186 - 118ms/epoch - 6ms/step
# Epoch 385/500
# 19/19 - 0s - loss: 0.0181 - val_loss: 0.0185 - 115ms/epoch - 6ms/step
# Epoch 386/500
# 19/19 - 0s - loss: 0.0180 - val_loss: 0.0184 - 117ms/epoch - 6ms/step
# Epoch 387/500
# 19/19 - 0s - loss: 0.0180 - val_loss: 0.0184 - 118ms/epoch - 6ms/step
# Epoch 388/500
# 19/19 - 0s - loss: 0.0180 - val_loss: 0.0183 - 110ms/epoch - 6ms/step
# Epoch 389/500
# 19/19 - 0s - loss: 0.0179 - val_loss: 0.0183 - 114ms/epoch - 6ms/step
# Epoch 390/500
# 19/19 - 0s - loss: 0.0179 - val_loss: 0.0182 - 111ms/epoch - 6ms/step
# Epoch 391/500
# 19/19 - 0s - loss: 0.0178 - val_loss: 0.0181 - 116ms/epoch - 6ms/step
# Epoch 392/500
# 19/19 - 0s - loss: 0.0178 - val_loss: 0.0181 - 121ms/epoch - 6ms/step
# Epoch 393/500
# 19/19 - 0s - loss: 0.0177 - val_loss: 0.0180 - 120ms/epoch - 6ms/step
# Epoch 394/500
# 19/19 - 0s - loss: 0.0177 - val_loss: 0.0179 - 123ms/epoch - 6ms/step
# Epoch 395/500
# 19/19 - 0s - loss: 0.0176 - val_loss: 0.0179 - 122ms/epoch - 6ms/step
# Epoch 396/500
# 19/19 - 0s - loss: 0.0176 - val_loss: 0.0178 - 122ms/epoch - 6ms/step
# Epoch 397/500
# 19/19 - 0s - loss: 0.0175 - val_loss: 0.0178 - 121ms/epoch - 6ms/step
# Epoch 398/500
# 19/19 - 0s - loss: 0.0175 - val_loss: 0.0177 - 124ms/epoch - 7ms/step
# Epoch 399/500
# 19/19 - 0s - loss: 0.0174 - val_loss: 0.0176 - 121ms/epoch - 6ms/step
# Epoch 400/500
# 19/19 - 0s - loss: 0.0174 - val_loss: 0.0176 - 119ms/epoch - 6ms/step
# Epoch 401/500
# 19/19 - 0s - loss: 0.0173 - val_loss: 0.0175 - 108ms/epoch - 6ms/step
# Epoch 402/500
# 19/19 - 0s - loss: 0.0173 - val_loss: 0.0174 - 111ms/epoch - 6ms/step
# Epoch 403/500
# 19/19 - 0s - loss: 0.0172 - val_loss: 0.0174 - 114ms/epoch - 6ms/step
# Epoch 404/500
# 19/19 - 0s - loss: 0.0172 - val_loss: 0.0173 - 110ms/epoch - 6ms/step
# Epoch 405/500
# 19/19 - 0s - loss: 0.0171 - val_loss: 0.0172 - 117ms/epoch - 6ms/step
# Epoch 406/500
# 19/19 - 0s - loss: 0.0171 - val_loss: 0.0172 - 112ms/epoch - 6ms/step
# Epoch 407/500
# 19/19 - 0s - loss: 0.0170 - val_loss: 0.0171 - 102ms/epoch - 5ms/step
# Epoch 408/500
# 19/19 - 0s - loss: 0.0170 - val_loss: 0.0170 - 103ms/epoch - 5ms/step
# Epoch 409/500
# 19/19 - 0s - loss: 0.0169 - val_loss: 0.0170 - 106ms/epoch - 6ms/step
# Epoch 410/500
# 19/19 - 0s - loss: 0.0169 - val_loss: 0.0169 - 102ms/epoch - 5ms/step
# Epoch 411/500
# 19/19 - 0s - loss: 0.0168 - val_loss: 0.0168 - 105ms/epoch - 6ms/step
# Epoch 412/500
# 19/19 - 0s - loss: 0.0168 - val_loss: 0.0168 - 106ms/epoch - 6ms/step
# Epoch 413/500
# 19/19 - 0s - loss: 0.0167 - val_loss: 0.0167 - 104ms/epoch - 5ms/step
# Epoch 414/500
# 19/19 - 0s - loss: 0.0167 - val_loss: 0.0166 - 117ms/epoch - 6ms/step
# Epoch 415/500
# 19/19 - 0s - loss: 0.0166 - val_loss: 0.0166 - 124ms/epoch - 7ms/step
# Epoch 416/500
# 19/19 - 0s - loss: 0.0166 - val_loss: 0.0165 - 121ms/epoch - 6ms/step
# Epoch 417/500
# 19/19 - 0s - loss: 0.0165 - val_loss: 0.0164 - 214ms/epoch - 11ms/step
# Epoch 418/500
# 19/19 - 0s - loss: 0.0165 - val_loss: 0.0164 - 125ms/epoch - 7ms/step
# Epoch 419/500
# 19/19 - 0s - loss: 0.0164 - val_loss: 0.0163 - 121ms/epoch - 6ms/step
# Epoch 420/500
# 19/19 - 0s - loss: 0.0164 - val_loss: 0.0162 - 122ms/epoch - 6ms/step
# Epoch 421/500
# 19/19 - 0s - loss: 0.0163 - val_loss: 0.0161 - 114ms/epoch - 6ms/step
# Epoch 422/500
# 19/19 - 0s - loss: 0.0163 - val_loss: 0.0161 - 117ms/epoch - 6ms/step
# Epoch 423/500
# 19/19 - 0s - loss: 0.0162 - val_loss: 0.0160 - 120ms/epoch - 6ms/step
# Epoch 424/500
# 19/19 - 0s - loss: 0.0162 - val_loss: 0.0159 - 118ms/epoch - 6ms/step
# Epoch 425/500
# 19/19 - 0s - loss: 0.0161 - val_loss: 0.0159 - 120ms/epoch - 6ms/step
# Epoch 426/500
# 19/19 - 0s - loss: 0.0161 - val_loss: 0.0158 - 121ms/epoch - 6ms/step
# Epoch 427/500
# 19/19 - 0s - loss: 0.0160 - val_loss: 0.0157 - 120ms/epoch - 6ms/step
# Epoch 428/500
# 19/19 - 0s - loss: 0.0160 - val_loss: 0.0156 - 122ms/epoch - 6ms/step
# Epoch 429/500
# 19/19 - 0s - loss: 0.0159 - val_loss: 0.0156 - 128ms/epoch - 7ms/step
# Epoch 430/500
# 19/19 - 0s - loss: 0.0159 - val_loss: 0.0155 - 125ms/epoch - 7ms/step
# Epoch 431/500
# 19/19 - 0s - loss: 0.0158 - val_loss: 0.0154 - 127ms/epoch - 7ms/step
# Epoch 432/500
# 19/19 - 0s - loss: 0.0157 - val_loss: 0.0154 - 123ms/epoch - 6ms/step
# Epoch 433/500
# 19/19 - 0s - loss: 0.0157 - val_loss: 0.0153 - 117ms/epoch - 6ms/step
# Epoch 434/500
# 19/19 - 0s - loss: 0.0156 - val_loss: 0.0152 - 119ms/epoch - 6ms/step
# Epoch 435/500
# 19/19 - 0s - loss: 0.0156 - val_loss: 0.0151 - 115ms/epoch - 6ms/step
# Epoch 436/500
# 19/19 - 0s - loss: 0.0155 - val_loss: 0.0151 - 113ms/epoch - 6ms/step
# Epoch 437/500
# 19/19 - 0s - loss: 0.0155 - val_loss: 0.0150 - 122ms/epoch - 6ms/step
# Epoch 438/500
# 19/19 - 0s - loss: 0.0154 - val_loss: 0.0149 - 127ms/epoch - 7ms/step
# Epoch 439/500
# 19/19 - 0s - loss: 0.0154 - val_loss: 0.0148 - 115ms/epoch - 6ms/step
# Epoch 440/500
# 19/19 - 0s - loss: 0.0153 - val_loss: 0.0148 - 121ms/epoch - 6ms/step
# Epoch 441/500
# 19/19 - 0s - loss: 0.0153 - val_loss: 0.0147 - 134ms/epoch - 7ms/step
# Epoch 442/500
# 19/19 - 0s - loss: 0.0152 - val_loss: 0.0146 - 129ms/epoch - 7ms/step
# Epoch 443/500
# 19/19 - 0s - loss: 0.0152 - val_loss: 0.0145 - 126ms/epoch - 7ms/step
# Epoch 444/500
# 19/19 - 0s - loss: 0.0151 - val_loss: 0.0145 - 126ms/epoch - 7ms/step
# Epoch 445/500
# 19/19 - 0s - loss: 0.0150 - val_loss: 0.0144 - 122ms/epoch - 6ms/step
# Epoch 446/500
# 19/19 - 0s - loss: 0.0150 - val_loss: 0.0143 - 127ms/epoch - 7ms/step
# Epoch 447/500
# 19/19 - 0s - loss: 0.0149 - val_loss: 0.0142 - 124ms/epoch - 7ms/step
# Epoch 448/500
# 19/19 - 0s - loss: 0.0149 - val_loss: 0.0142 - 119ms/epoch - 6ms/step
# Epoch 449/500
# 19/19 - 0s - loss: 0.0148 - val_loss: 0.0141 - 119ms/epoch - 6ms/step
# Epoch 450/500
# 19/19 - 0s - loss: 0.0148 - val_loss: 0.0140 - 122ms/epoch - 6ms/step
# Epoch 451/500
# 19/19 - 0s - loss: 0.0147 - val_loss: 0.0139 - 117ms/epoch - 6ms/step
# Epoch 452/500
# 19/19 - 0s - loss: 0.0147 - val_loss: 0.0139 - 120ms/epoch - 6ms/step
# Epoch 453/500
# 19/19 - 0s - loss: 0.0146 - val_loss: 0.0138 - 115ms/epoch - 6ms/step
# Epoch 454/500
# 19/19 - 0s - loss: 0.0146 - val_loss: 0.0137 - 112ms/epoch - 6ms/step
# Epoch 455/500
# 19/19 - 0s - loss: 0.0145 - val_loss: 0.0136 - 116ms/epoch - 6ms/step
# Epoch 456/500
# 19/19 - 0s - loss: 0.0144 - val_loss: 0.0136 - 121ms/epoch - 6ms/step
# Epoch 457/500
# 19/19 - 0s - loss: 0.0144 - val_loss: 0.0135 - 133ms/epoch - 7ms/step
# Epoch 458/500
# 19/19 - 0s - loss: 0.0143 - val_loss: 0.0134 - 121ms/epoch - 6ms/step
# Epoch 459/500
# 19/19 - 0s - loss: 0.0143 - val_loss: 0.0133 - 121ms/epoch - 6ms/step
# Epoch 460/500
# 19/19 - 0s - loss: 0.0142 - val_loss: 0.0133 - 121ms/epoch - 6ms/step
# Epoch 461/500
# 19/19 - 0s - loss: 0.0142 - val_loss: 0.0132 - 124ms/epoch - 7ms/step
# Epoch 462/500
# 19/19 - 0s - loss: 0.0141 - val_loss: 0.0131 - 111ms/epoch - 6ms/step
# Epoch 463/500
# 19/19 - 0s - loss: 0.0141 - val_loss: 0.0130 - 109ms/epoch - 6ms/step
# Epoch 464/500
# 19/19 - 0s - loss: 0.0140 - val_loss: 0.0130 - 108ms/epoch - 6ms/step
# Epoch 465/500
# 19/19 - 0s - loss: 0.0140 - val_loss: 0.0129 - 106ms/epoch - 6ms/step
# Epoch 466/500
# 19/19 - 0s - loss: 0.0139 - val_loss: 0.0128 - 107ms/epoch - 6ms/step
# Epoch 467/500
# 19/19 - 0s - loss: 0.0139 - val_loss: 0.0127 - 103ms/epoch - 5ms/step
# Epoch 468/500
# 19/19 - 0s - loss: 0.0138 - val_loss: 0.0127 - 121ms/epoch - 6ms/step
# Epoch 469/500
# 19/19 - 0s - loss: 0.0138 - val_loss: 0.0126 - 265ms/epoch - 14ms/step
# Epoch 470/500
# 19/19 - 0s - loss: 0.0137 - val_loss: 0.0125 - 138ms/epoch - 7ms/step
# Epoch 471/500
# 19/19 - 0s - loss: 0.0137 - val_loss: 0.0125 - 131ms/epoch - 7ms/step
# Epoch 472/500
# 19/19 - 0s - loss: 0.0136 - val_loss: 0.0124 - 127ms/epoch - 7ms/step
# Epoch 473/500
# 19/19 - 0s - loss: 0.0136 - val_loss: 0.0123 - 130ms/epoch - 7ms/step
# Epoch 474/500
# 19/19 - 0s - loss: 0.0135 - val_loss: 0.0122 - 127ms/epoch - 7ms/step
# Epoch 475/500
# 19/19 - 0s - loss: 0.0135 - val_loss: 0.0122 - 129ms/epoch - 7ms/step
# Epoch 476/500
# 19/19 - 0s - loss: 0.0134 - val_loss: 0.0121 - 128ms/epoch - 7ms/step
# Epoch 477/500
# 19/19 - 0s - loss: 0.0134 - val_loss: 0.0120 - 128ms/epoch - 7ms/step
# Epoch 478/500
# 19/19 - 0s - loss: 0.0133 - val_loss: 0.0120 - 122ms/epoch - 6ms/step
# Epoch 479/500
# 19/19 - 0s - loss: 0.0133 - val_loss: 0.0119 - 124ms/epoch - 7ms/step
# Epoch 480/500
# 19/19 - 0s - loss: 0.0132 - val_loss: 0.0118 - 125ms/epoch - 7ms/step
# Epoch 481/500
# 19/19 - 0s - loss: 0.0132 - val_loss: 0.0118 - 115ms/epoch - 6ms/step
# Epoch 482/500
# 19/19 - 0s - loss: 0.0132 - val_loss: 0.0117 - 119ms/epoch - 6ms/step
# Epoch 483/500
# 19/19 - 0s - loss: 0.0131 - val_loss: 0.0116 - 121ms/epoch - 6ms/step
# Epoch 484/500
# 19/19 - 0s - loss: 0.0131 - val_loss: 0.0116 - 114ms/epoch - 6ms/step
# Epoch 485/500
# 19/19 - 0s - loss: 0.0130 - val_loss: 0.0115 - 113ms/epoch - 6ms/step
# Epoch 486/500
# 19/19 - 0s - loss: 0.0130 - val_loss: 0.0114 - 155ms/epoch - 8ms/step
# Epoch 487/500
# 19/19 - 0s - loss: 0.0129 - val_loss: 0.0114 - 135ms/epoch - 7ms/step
# Epoch 488/500
# 19/19 - 0s - loss: 0.0129 - val_loss: 0.0113 - 178ms/epoch - 9ms/step
# Epoch 489/500
# 19/19 - 0s - loss: 0.0129 - val_loss: 0.0112 - 138ms/epoch - 7ms/step
# Epoch 490/500
# 19/19 - 0s - loss: 0.0128 - val_loss: 0.0112 - 151ms/epoch - 8ms/step
# Epoch 491/500
# 19/19 - 0s - loss: 0.0128 - val_loss: 0.0111 - 186ms/epoch - 10ms/step
# Epoch 492/500
# 19/19 - 0s - loss: 0.0127 - val_loss: 0.0111 - 165ms/epoch - 9ms/step
# Epoch 493/500
# 19/19 - 0s - loss: 0.0127 - val_loss: 0.0110 - 143ms/epoch - 8ms/step
# Epoch 494/500
# 19/19 - 0s - loss: 0.0127 - val_loss: 0.0109 - 142ms/epoch - 7ms/step
# Epoch 495/500
# 19/19 - 0s - loss: 0.0126 - val_loss: 0.0109 - 128ms/epoch - 7ms/step
# Epoch 496/500
# 19/19 - 0s - loss: 0.0126 - val_loss: 0.0108 - 133ms/epoch - 7ms/step
# Epoch 497/500
# 19/19 - 0s - loss: 0.0126 - val_loss: 0.0108 - 134ms/epoch - 7ms/step
# Epoch 498/500
# 19/19 - 0s - loss: 0.0125 - val_loss: 0.0107 - 134ms/epoch - 7ms/step
# Epoch 499/500
# 19/19 - 0s - loss: 0.0125 - val_loss: 0.0107 - 136ms/epoch - 7ms/step
# Epoch 500/500
# 19/19 - 0s - loss: 0.0125 - val_loss: 0.0106 - 169ms/epoch - 9ms/step

# %% [markdown]
# ## Metrics ($LVPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
phy = phys2(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 10/10 [==============================] - 1s 2ms/step
# (290, 3)
# (290, 10)
# Test RMSE: 4.350
# Test MAE: 3.283

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('New Delhi Daily Wind Speed', fontsize=20)
plt.legend(fontsize=20)
plt.show()
