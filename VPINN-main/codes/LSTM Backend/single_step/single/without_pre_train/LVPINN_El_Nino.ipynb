# %% [markdown]
# # Time Series Prediction with Lotka Volterra Equation Inspired Deep Learning ($LVPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-11 20:19:02

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _EL NINO_

# %%
data = pd.read_csv("datasets/elnino.csv")
training_set = data.iloc[:, 1]
print(training_set)
# Out:
# 0       23.4
# 1       23.4
# 2       24.2
# 3       24.4
# 4       25.1
#         ...
# 1629    25.4
# 1630    24.9
# 1631    25.3
# 1632    24.7
# 1633    24.6
# Name: SST1, Length: 1634, dtype: float64

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 7 # Weekly Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 29.2
# 1       0.000000
# 2       0.114286
# 3       0.028571
# 4       0.100000
# 5       0.100000
#           ...
# 1629   -0.242857
# 1630   -0.071429
# 1631    0.057143
# 1632   -0.085714
# 1633   -0.014286
# Name: SST1, Length: 1633, dtype: float64
# 2       1.632653e-02
# 3      -1.224490e-02
# 4       1.020408e-02
# 5      -7.335402e-17
# 6      -1.224490e-02
#             ...
# 1629   -2.857143e-02
# 1630    2.448980e-02
# 1631    1.836735e-02
# 1632   -2.040816e-02
# 1633    1.020408e-02
# Name: SST1, Length: 1632, dtype: float64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0       0.000000
# 1       0.114286
# 2       0.028571
# 3       0.100000
# 4       0.100000
#           ...
# 1628   -0.242857
# 1629   -0.071429
# 1630    0.057143
# 1631   -0.085714
# 1632   -0.014286
# Name: SST1, Length: 1633, dtype: float64
# 0       1.632653e-02
# 1      -1.224490e-02
# 2       1.020408e-02
# 3      -7.335402e-17
# 4      -1.224490e-02
#             ...
# 1627   -2.857143e-02
# 1628    2.448980e-02
# 1629    1.836735e-02
# 1630   -2.040816e-02
# 1631    1.020408e-02
# Name: SST1, Length: 1632, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (1633,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lotka Volterra Equation_)

# %% [markdown]
# _Parameters_: $\alpha=0.1, \beta=0.05, \gamma=1.1, \delta=0.1\\$

# %%
a=0.1
b=0.05
c=1.1
d=0.1
L = df.iloc[:, 2] - a*a*df.iloc[:, 0] + 2*a*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*d*(df.iloc[:,0]**2)*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - c*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10        23.4       23.4       24.2       24.4       25.1       25.8
# 11        23.4       24.2       24.4       25.1       25.8       25.9
# 12        24.2       24.4       25.1       25.8       25.9       26.1
# 13        24.4       25.1       25.8       25.9       26.1       26.1
# 14        25.1       25.8       25.9       26.1       26.1       26.7
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)   var2(t)   var3(t)
# 10       25.9       26.1       26.1       26.7     26.1  0.000000 -0.008163
# 11       26.1       26.1       26.7       26.1     26.1 -0.057143  0.006122
# 12       26.1       26.7       26.1       26.1     25.7 -0.014286 -0.008163
# 13       26.7       26.1       26.1       25.7     25.6 -0.071429  0.014286
# 14       26.1       26.1       25.7       25.6     25.1  0.028571 -0.008163
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (1622, 13)
# (1622, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (1297, 1, 10) (1297, 3) (325, 1, 10) (325, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] - a*a*y_true[:, 0] + 2*a*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*d*(y_true[:,0]**2)*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - c*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))), (y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] - a*a*y_pred[:-2] + 2*a*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*d*(y_pred[:-2]**2)*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - c*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] - a*a*y_real[:-2] + 2*a*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*d*(y_real[:-2]**2)*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - c*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($LVPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square(y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 21/21 - 27s - loss: 0.2529 - val_loss: 0.2226 - 27s/epoch - 1s/step
# Epoch 2/500
# 21/21 - 0s - loss: 0.1864 - val_loss: 0.2090 - 240ms/epoch - 11ms/step
# Epoch 3/500
# 21/21 - 0s - loss: 0.1804 - val_loss: 0.2066 - 229ms/epoch - 11ms/step
# Epoch 4/500
# 21/21 - 0s - loss: 0.1790 - val_loss: 0.2056 - 230ms/epoch - 11ms/step
# Epoch 5/500
# 21/21 - 0s - loss: 0.1782 - val_loss: 0.2047 - 238ms/epoch - 11ms/step
# Epoch 6/500
# 21/21 - 0s - loss: 0.1775 - val_loss: 0.2038 - 267ms/epoch - 13ms/step
# Epoch 7/500
# 21/21 - 0s - loss: 0.1766 - val_loss: 0.2028 - 208ms/epoch - 10ms/step
# Epoch 8/500
# 21/21 - 0s - loss: 0.1757 - val_loss: 0.2017 - 214ms/epoch - 10ms/step
# Epoch 9/500
# 21/21 - 0s - loss: 0.1747 - val_loss: 0.2006 - 247ms/epoch - 12ms/step
# Epoch 10/500
# 21/21 - 0s - loss: 0.1737 - val_loss: 0.1993 - 237ms/epoch - 11ms/step
# Epoch 11/500
# 21/21 - 0s - loss: 0.1726 - val_loss: 0.1981 - 214ms/epoch - 10ms/step
# Epoch 12/500
# 21/21 - 0s - loss: 0.1714 - val_loss: 0.1967 - 244ms/epoch - 12ms/step
# Epoch 13/500
# 21/21 - 0s - loss: 0.1702 - val_loss: 0.1953 - 238ms/epoch - 11ms/step
# Epoch 14/500
# 21/21 - 0s - loss: 0.1690 - val_loss: 0.1938 - 247ms/epoch - 12ms/step
# Epoch 15/500
# 21/21 - 0s - loss: 0.1677 - val_loss: 0.1923 - 239ms/epoch - 11ms/step
# Epoch 16/500
# 21/21 - 0s - loss: 0.1663 - val_loss: 0.1908 - 284ms/epoch - 14ms/step
# Epoch 17/500
# 21/21 - 0s - loss: 0.1650 - val_loss: 0.1891 - 219ms/epoch - 10ms/step
# Epoch 18/500
# 21/21 - 0s - loss: 0.1635 - val_loss: 0.1875 - 222ms/epoch - 11ms/step
# Epoch 19/500
# 21/21 - 0s - loss: 0.1620 - val_loss: 0.1857 - 244ms/epoch - 12ms/step
# Epoch 20/500
# 21/21 - 0s - loss: 0.1605 - val_loss: 0.1840 - 232ms/epoch - 11ms/step
# Epoch 21/500
# 21/21 - 0s - loss: 0.1590 - val_loss: 0.1822 - 257ms/epoch - 12ms/step
# Epoch 22/500
# 21/21 - 0s - loss: 0.1574 - val_loss: 0.1803 - 266ms/epoch - 13ms/step
# Epoch 23/500
# 21/21 - 0s - loss: 0.1557 - val_loss: 0.1784 - 265ms/epoch - 13ms/step
# Epoch 24/500
# 21/21 - 0s - loss: 0.1540 - val_loss: 0.1764 - 235ms/epoch - 11ms/step
# Epoch 25/500
# 21/21 - 0s - loss: 0.1523 - val_loss: 0.1744 - 236ms/epoch - 11ms/step
# Epoch 26/500
# 21/21 - 0s - loss: 0.1505 - val_loss: 0.1724 - 223ms/epoch - 11ms/step
# Epoch 27/500
# 21/21 - 0s - loss: 0.1488 - val_loss: 0.1703 - 276ms/epoch - 13ms/step
# Epoch 28/500
# 21/21 - 0s - loss: 0.1469 - val_loss: 0.1682 - 197ms/epoch - 9ms/step
# Epoch 29/500
# 21/21 - 0s - loss: 0.1450 - val_loss: 0.1660 - 213ms/epoch - 10ms/step
# Epoch 30/500
# 21/21 - 0s - loss: 0.1431 - val_loss: 0.1638 - 219ms/epoch - 10ms/step
# Epoch 31/500
# 21/21 - 0s - loss: 0.1412 - val_loss: 0.1616 - 221ms/epoch - 11ms/step
# Epoch 32/500
# 21/21 - 0s - loss: 0.1392 - val_loss: 0.1593 - 264ms/epoch - 13ms/step
# Epoch 33/500
# 21/21 - 0s - loss: 0.1372 - val_loss: 0.1569 - 219ms/epoch - 10ms/step
# Epoch 34/500
# 21/21 - 0s - loss: 0.1351 - val_loss: 0.1545 - 226ms/epoch - 11ms/step
# Epoch 35/500
# 21/21 - 0s - loss: 0.1331 - val_loss: 0.1521 - 216ms/epoch - 10ms/step
# Epoch 36/500
# 21/21 - 0s - loss: 0.1309 - val_loss: 0.1497 - 217ms/epoch - 10ms/step
# Epoch 37/500
# 21/21 - 0s - loss: 0.1288 - val_loss: 0.1472 - 261ms/epoch - 12ms/step
# Epoch 38/500
# 21/21 - 0s - loss: 0.1266 - val_loss: 0.1446 - 257ms/epoch - 12ms/step
# Epoch 39/500
# 21/21 - 0s - loss: 0.1243 - val_loss: 0.1420 - 233ms/epoch - 11ms/step
# Epoch 40/500
# 21/21 - 0s - loss: 0.1221 - val_loss: 0.1394 - 208ms/epoch - 10ms/step
# Epoch 41/500
# 21/21 - 0s - loss: 0.1198 - val_loss: 0.1367 - 238ms/epoch - 11ms/step
# Epoch 42/500
# 21/21 - 0s - loss: 0.1175 - val_loss: 0.1340 - 228ms/epoch - 11ms/step
# Epoch 43/500
# 21/21 - 0s - loss: 0.1151 - val_loss: 0.1313 - 209ms/epoch - 10ms/step
# Epoch 44/500
# 21/21 - 0s - loss: 0.1127 - val_loss: 0.1285 - 202ms/epoch - 10ms/step
# Epoch 45/500
# 21/21 - 0s - loss: 0.1103 - val_loss: 0.1257 - 193ms/epoch - 9ms/step
# Epoch 46/500
# 21/21 - 0s - loss: 0.1078 - val_loss: 0.1228 - 173ms/epoch - 8ms/step
# Epoch 47/500
# 21/21 - 0s - loss: 0.1053 - val_loss: 0.1200 - 187ms/epoch - 9ms/step
# Epoch 48/500
# 21/21 - 0s - loss: 0.1028 - val_loss: 0.1170 - 196ms/epoch - 9ms/step
# Epoch 49/500
# 21/21 - 0s - loss: 0.1003 - val_loss: 0.1141 - 205ms/epoch - 10ms/step
# Epoch 50/500
# 21/21 - 0s - loss: 0.0977 - val_loss: 0.1111 - 196ms/epoch - 9ms/step
# Epoch 51/500
# 21/21 - 0s - loss: 0.0951 - val_loss: 0.1081 - 217ms/epoch - 10ms/step
# Epoch 52/500
# 21/21 - 0s - loss: 0.0925 - val_loss: 0.1050 - 191ms/epoch - 9ms/step
# Epoch 53/500
# 21/21 - 0s - loss: 0.0899 - val_loss: 0.1020 - 186ms/epoch - 9ms/step
# Epoch 54/500
# 21/21 - 0s - loss: 0.0872 - val_loss: 0.0989 - 215ms/epoch - 10ms/step
# Epoch 55/500
# 21/21 - 0s - loss: 0.0845 - val_loss: 0.0958 - 222ms/epoch - 11ms/step
# Epoch 56/500
# 21/21 - 0s - loss: 0.0819 - val_loss: 0.0927 - 221ms/epoch - 11ms/step
# Epoch 57/500
# 21/21 - 0s - loss: 0.0792 - val_loss: 0.0896 - 203ms/epoch - 10ms/step
# Epoch 58/500
# 21/21 - 0s - loss: 0.0765 - val_loss: 0.0865 - 200ms/epoch - 10ms/step
# Epoch 59/500
# 21/21 - 0s - loss: 0.0738 - val_loss: 0.0834 - 247ms/epoch - 12ms/step
# Epoch 60/500
# 21/21 - 0s - loss: 0.0711 - val_loss: 0.0803 - 242ms/epoch - 12ms/step
# Epoch 61/500
# 21/21 - 0s - loss: 0.0685 - val_loss: 0.0772 - 253ms/epoch - 12ms/step
# Epoch 62/500
# 21/21 - 0s - loss: 0.0658 - val_loss: 0.0741 - 227ms/epoch - 11ms/step
# Epoch 63/500
# 21/21 - 0s - loss: 0.0632 - val_loss: 0.0710 - 204ms/epoch - 10ms/step
# Epoch 64/500
# 21/21 - 0s - loss: 0.0605 - val_loss: 0.0680 - 203ms/epoch - 10ms/step
# Epoch 65/500
# 21/21 - 0s - loss: 0.0580 - val_loss: 0.0650 - 206ms/epoch - 10ms/step
# Epoch 66/500
# 21/21 - 0s - loss: 0.0554 - val_loss: 0.0621 - 410ms/epoch - 20ms/step
# Epoch 67/500
# 21/21 - 0s - loss: 0.0529 - val_loss: 0.0592 - 262ms/epoch - 12ms/step
# Epoch 68/500
# 21/21 - 0s - loss: 0.0505 - val_loss: 0.0564 - 304ms/epoch - 14ms/step
# Epoch 69/500
# 21/21 - 0s - loss: 0.0481 - val_loss: 0.0536 - 236ms/epoch - 11ms/step
# Epoch 70/500
# 21/21 - 0s - loss: 0.0457 - val_loss: 0.0509 - 245ms/epoch - 12ms/step
# Epoch 71/500
# 21/21 - 0s - loss: 0.0435 - val_loss: 0.0483 - 203ms/epoch - 10ms/step
# Epoch 72/500
# 21/21 - 0s - loss: 0.0413 - val_loss: 0.0458 - 213ms/epoch - 10ms/step
# Epoch 73/500
# 21/21 - 0s - loss: 0.0392 - val_loss: 0.0434 - 225ms/epoch - 11ms/step
# Epoch 74/500
# 21/21 - 0s - loss: 0.0371 - val_loss: 0.0411 - 219ms/epoch - 10ms/step
# Epoch 75/500
# 21/21 - 0s - loss: 0.0352 - val_loss: 0.0389 - 207ms/epoch - 10ms/step
# Epoch 76/500
# 21/21 - 0s - loss: 0.0334 - val_loss: 0.0368 - 231ms/epoch - 11ms/step
# Epoch 77/500
# 21/21 - 0s - loss: 0.0316 - val_loss: 0.0348 - 208ms/epoch - 10ms/step
# Epoch 78/500
# 21/21 - 0s - loss: 0.0300 - val_loss: 0.0329 - 210ms/epoch - 10ms/step
# Epoch 79/500
# 21/21 - 0s - loss: 0.0285 - val_loss: 0.0312 - 218ms/epoch - 10ms/step
# Epoch 80/500
# 21/21 - 0s - loss: 0.0271 - val_loss: 0.0296 - 258ms/epoch - 12ms/step
# Epoch 81/500
# 21/21 - 0s - loss: 0.0257 - val_loss: 0.0281 - 240ms/epoch - 11ms/step
# Epoch 82/500
# 21/21 - 0s - loss: 0.0245 - val_loss: 0.0267 - 207ms/epoch - 10ms/step
# Epoch 83/500
# 21/21 - 0s - loss: 0.0234 - val_loss: 0.0255 - 221ms/epoch - 11ms/step
# Epoch 84/500
# 21/21 - 0s - loss: 0.0224 - val_loss: 0.0243 - 220ms/epoch - 10ms/step
# Epoch 85/500
# 21/21 - 0s - loss: 0.0215 - val_loss: 0.0233 - 221ms/epoch - 11ms/step
# Epoch 86/500
# 21/21 - 0s - loss: 0.0207 - val_loss: 0.0224 - 199ms/epoch - 9ms/step
# Epoch 87/500
# 21/21 - 0s - loss: 0.0200 - val_loss: 0.0216 - 213ms/epoch - 10ms/step
# Epoch 88/500
# 21/21 - 0s - loss: 0.0194 - val_loss: 0.0209 - 312ms/epoch - 15ms/step
# Epoch 89/500
# 21/21 - 0s - loss: 0.0188 - val_loss: 0.0203 - 217ms/epoch - 10ms/step
# Epoch 90/500
# 21/21 - 0s - loss: 0.0184 - val_loss: 0.0197 - 216ms/epoch - 10ms/step
# Epoch 91/500
# 21/21 - 0s - loss: 0.0179 - val_loss: 0.0192 - 241ms/epoch - 11ms/step
# Epoch 92/500
# 21/21 - 0s - loss: 0.0176 - val_loss: 0.0188 - 226ms/epoch - 11ms/step
# Epoch 93/500
# 21/21 - 0s - loss: 0.0173 - val_loss: 0.0185 - 198ms/epoch - 9ms/step
# Epoch 94/500
# 21/21 - 0s - loss: 0.0170 - val_loss: 0.0182 - 226ms/epoch - 11ms/step
# Epoch 95/500
# 21/21 - 0s - loss: 0.0168 - val_loss: 0.0179 - 200ms/epoch - 10ms/step
# Epoch 96/500
# 21/21 - 0s - loss: 0.0166 - val_loss: 0.0176 - 183ms/epoch - 9ms/step
# Epoch 97/500
# 21/21 - 0s - loss: 0.0164 - val_loss: 0.0174 - 178ms/epoch - 8ms/step
# Epoch 98/500
# 21/21 - 0s - loss: 0.0162 - val_loss: 0.0173 - 175ms/epoch - 8ms/step
# Epoch 99/500
# 21/21 - 0s - loss: 0.0161 - val_loss: 0.0171 - 206ms/epoch - 10ms/step
# Epoch 100/500
# 21/21 - 0s - loss: 0.0160 - val_loss: 0.0170 - 219ms/epoch - 10ms/step
# Epoch 101/500
# 21/21 - 0s - loss: 0.0159 - val_loss: 0.0168 - 200ms/epoch - 10ms/step
# Epoch 102/500
# 21/21 - 0s - loss: 0.0158 - val_loss: 0.0167 - 199ms/epoch - 9ms/step
# Epoch 103/500
# 21/21 - 0s - loss: 0.0157 - val_loss: 0.0166 - 239ms/epoch - 11ms/step
# Epoch 104/500
# 21/21 - 0s - loss: 0.0156 - val_loss: 0.0165 - 242ms/epoch - 12ms/step
# Epoch 105/500
# 21/21 - 0s - loss: 0.0155 - val_loss: 0.0164 - 350ms/epoch - 17ms/step
# Epoch 106/500
# 21/21 - 0s - loss: 0.0155 - val_loss: 0.0163 - 227ms/epoch - 11ms/step
# Epoch 107/500
# 21/21 - 0s - loss: 0.0154 - val_loss: 0.0162 - 209ms/epoch - 10ms/step
# Epoch 108/500
# 21/21 - 0s - loss: 0.0153 - val_loss: 0.0161 - 263ms/epoch - 13ms/step
# Epoch 109/500
# 21/21 - 0s - loss: 0.0152 - val_loss: 0.0161 - 390ms/epoch - 19ms/step
# Epoch 110/500
# 21/21 - 0s - loss: 0.0152 - val_loss: 0.0160 - 282ms/epoch - 13ms/step
# Epoch 111/500
# 21/21 - 0s - loss: 0.0151 - val_loss: 0.0159 - 226ms/epoch - 11ms/step
# Epoch 112/500
# 21/21 - 0s - loss: 0.0150 - val_loss: 0.0158 - 325ms/epoch - 15ms/step
# Epoch 113/500
# 21/21 - 0s - loss: 0.0150 - val_loss: 0.0158 - 215ms/epoch - 10ms/step
# Epoch 114/500
# 21/21 - 0s - loss: 0.0149 - val_loss: 0.0157 - 217ms/epoch - 10ms/step
# Epoch 115/500
# 21/21 - 0s - loss: 0.0148 - val_loss: 0.0156 - 230ms/epoch - 11ms/step
# Epoch 116/500
# 21/21 - 0s - loss: 0.0148 - val_loss: 0.0155 - 251ms/epoch - 12ms/step
# Epoch 117/500
# 21/21 - 0s - loss: 0.0147 - val_loss: 0.0154 - 219ms/epoch - 10ms/step
# Epoch 118/500
# 21/21 - 0s - loss: 0.0146 - val_loss: 0.0154 - 202ms/epoch - 10ms/step
# Epoch 119/500
# 21/21 - 0s - loss: 0.0145 - val_loss: 0.0153 - 201ms/epoch - 10ms/step
# Epoch 120/500
# 21/21 - 0s - loss: 0.0145 - val_loss: 0.0152 - 200ms/epoch - 10ms/step
# Epoch 121/500
# 21/21 - 0s - loss: 0.0144 - val_loss: 0.0151 - 238ms/epoch - 11ms/step
# Epoch 122/500
# 21/21 - 0s - loss: 0.0143 - val_loss: 0.0151 - 219ms/epoch - 10ms/step
# Epoch 123/500
# 21/21 - 0s - loss: 0.0143 - val_loss: 0.0150 - 201ms/epoch - 10ms/step
# Epoch 124/500
# 21/21 - 0s - loss: 0.0142 - val_loss: 0.0149 - 193ms/epoch - 9ms/step
# Epoch 125/500
# 21/21 - 0s - loss: 0.0141 - val_loss: 0.0148 - 216ms/epoch - 10ms/step
# Epoch 126/500
# 21/21 - 0s - loss: 0.0140 - val_loss: 0.0148 - 233ms/epoch - 11ms/step
# Epoch 127/500
# 21/21 - 0s - loss: 0.0140 - val_loss: 0.0147 - 224ms/epoch - 11ms/step
# Epoch 128/500
# 21/21 - 0s - loss: 0.0139 - val_loss: 0.0146 - 223ms/epoch - 11ms/step
# Epoch 129/500
# 21/21 - 0s - loss: 0.0138 - val_loss: 0.0145 - 227ms/epoch - 11ms/step
# Epoch 130/500
# 21/21 - 0s - loss: 0.0137 - val_loss: 0.0144 - 219ms/epoch - 10ms/step
# Epoch 131/500
# 21/21 - 0s - loss: 0.0137 - val_loss: 0.0144 - 216ms/epoch - 10ms/step
# Epoch 132/500
# 21/21 - 0s - loss: 0.0136 - val_loss: 0.0143 - 248ms/epoch - 12ms/step
# Epoch 133/500
# 21/21 - 0s - loss: 0.0135 - val_loss: 0.0142 - 250ms/epoch - 12ms/step
# Epoch 134/500
# 21/21 - 0s - loss: 0.0134 - val_loss: 0.0141 - 249ms/epoch - 12ms/step
# Epoch 135/500
# 21/21 - 0s - loss: 0.0134 - val_loss: 0.0140 - 253ms/epoch - 12ms/step
# Epoch 136/500
# 21/21 - 0s - loss: 0.0133 - val_loss: 0.0140 - 241ms/epoch - 11ms/step
# Epoch 137/500
# 21/21 - 0s - loss: 0.0132 - val_loss: 0.0139 - 222ms/epoch - 11ms/step
# Epoch 138/500
# 21/21 - 0s - loss: 0.0131 - val_loss: 0.0138 - 204ms/epoch - 10ms/step
# Epoch 139/500
# 21/21 - 0s - loss: 0.0130 - val_loss: 0.0137 - 216ms/epoch - 10ms/step
# Epoch 140/500
# 21/21 - 0s - loss: 0.0130 - val_loss: 0.0136 - 209ms/epoch - 10ms/step
# Epoch 141/500
# 21/21 - 0s - loss: 0.0129 - val_loss: 0.0135 - 215ms/epoch - 10ms/step
# Epoch 142/500
# 21/21 - 0s - loss: 0.0128 - val_loss: 0.0134 - 189ms/epoch - 9ms/step
# Epoch 143/500
# 21/21 - 0s - loss: 0.0127 - val_loss: 0.0133 - 203ms/epoch - 10ms/step
# Epoch 144/500
# 21/21 - 0s - loss: 0.0126 - val_loss: 0.0133 - 189ms/epoch - 9ms/step
# Epoch 145/500
# 21/21 - 0s - loss: 0.0126 - val_loss: 0.0132 - 190ms/epoch - 9ms/step
# Epoch 146/500
# 21/21 - 0s - loss: 0.0125 - val_loss: 0.0131 - 181ms/epoch - 9ms/step
# Epoch 147/500
# 21/21 - 0s - loss: 0.0124 - val_loss: 0.0130 - 171ms/epoch - 8ms/step
# Epoch 148/500
# 21/21 - 0s - loss: 0.0123 - val_loss: 0.0129 - 191ms/epoch - 9ms/step
# Epoch 149/500
# 21/21 - 0s - loss: 0.0122 - val_loss: 0.0128 - 197ms/epoch - 9ms/step
# Epoch 150/500
# 21/21 - 0s - loss: 0.0121 - val_loss: 0.0127 - 198ms/epoch - 9ms/step
# Epoch 151/500
# 21/21 - 0s - loss: 0.0120 - val_loss: 0.0126 - 217ms/epoch - 10ms/step
# Epoch 152/500
# 21/21 - 0s - loss: 0.0119 - val_loss: 0.0125 - 231ms/epoch - 11ms/step
# Epoch 153/500
# 21/21 - 0s - loss: 0.0118 - val_loss: 0.0124 - 256ms/epoch - 12ms/step
# Epoch 154/500
# 21/21 - 0s - loss: 0.0117 - val_loss: 0.0123 - 252ms/epoch - 12ms/step
# Epoch 155/500
# 21/21 - 0s - loss: 0.0116 - val_loss: 0.0122 - 426ms/epoch - 20ms/step
# Epoch 156/500
# 21/21 - 0s - loss: 0.0115 - val_loss: 0.0121 - 238ms/epoch - 11ms/step
# Epoch 157/500
# 21/21 - 0s - loss: 0.0114 - val_loss: 0.0120 - 241ms/epoch - 11ms/step
# Epoch 158/500
# 21/21 - 0s - loss: 0.0113 - val_loss: 0.0119 - 263ms/epoch - 13ms/step
# Epoch 159/500
# 21/21 - 0s - loss: 0.0112 - val_loss: 0.0118 - 249ms/epoch - 12ms/step
# Epoch 160/500
# 21/21 - 0s - loss: 0.0111 - val_loss: 0.0117 - 246ms/epoch - 12ms/step
# Epoch 161/500
# 21/21 - 0s - loss: 0.0110 - val_loss: 0.0115 - 241ms/epoch - 11ms/step
# Epoch 162/500
# 21/21 - 0s - loss: 0.0109 - val_loss: 0.0114 - 257ms/epoch - 12ms/step
# Epoch 163/500
# 21/21 - 0s - loss: 0.0108 - val_loss: 0.0113 - 215ms/epoch - 10ms/step
# Epoch 164/500
# 21/21 - 0s - loss: 0.0107 - val_loss: 0.0112 - 198ms/epoch - 9ms/step
# Epoch 165/500
# 21/21 - 0s - loss: 0.0106 - val_loss: 0.0111 - 191ms/epoch - 9ms/step
# Epoch 166/500
# 21/21 - 0s - loss: 0.0105 - val_loss: 0.0110 - 188ms/epoch - 9ms/step
# Epoch 167/500
# 21/21 - 0s - loss: 0.0104 - val_loss: 0.0109 - 203ms/epoch - 10ms/step
# Epoch 168/500
# 21/21 - 0s - loss: 0.0103 - val_loss: 0.0108 - 207ms/epoch - 10ms/step
# Epoch 169/500
# 21/21 - 0s - loss: 0.0102 - val_loss: 0.0107 - 225ms/epoch - 11ms/step
# Epoch 170/500
# 21/21 - 0s - loss: 0.0101 - val_loss: 0.0105 - 229ms/epoch - 11ms/step
# Epoch 171/500
# 21/21 - 0s - loss: 0.0100 - val_loss: 0.0104 - 231ms/epoch - 11ms/step
# Epoch 172/500
# 21/21 - 0s - loss: 0.0099 - val_loss: 0.0103 - 254ms/epoch - 12ms/step
# Epoch 173/500
# 21/21 - 0s - loss: 0.0098 - val_loss: 0.0102 - 226ms/epoch - 11ms/step
# Epoch 174/500
# 21/21 - 0s - loss: 0.0097 - val_loss: 0.0101 - 205ms/epoch - 10ms/step
# Epoch 175/500
# 21/21 - 0s - loss: 0.0096 - val_loss: 0.0100 - 210ms/epoch - 10ms/step
# Epoch 176/500
# 21/21 - 0s - loss: 0.0095 - val_loss: 0.0099 - 195ms/epoch - 9ms/step
# Epoch 177/500
# 21/21 - 0s - loss: 0.0094 - val_loss: 0.0097 - 216ms/epoch - 10ms/step
# Epoch 178/500
# 21/21 - 0s - loss: 0.0093 - val_loss: 0.0096 - 215ms/epoch - 10ms/step
# Epoch 179/500
# 21/21 - 0s - loss: 0.0091 - val_loss: 0.0095 - 244ms/epoch - 12ms/step
# Epoch 180/500
# 21/21 - 0s - loss: 0.0090 - val_loss: 0.0094 - 243ms/epoch - 12ms/step
# Epoch 181/500
# 21/21 - 0s - loss: 0.0089 - val_loss: 0.0092 - 204ms/epoch - 10ms/step
# Epoch 182/500
# 21/21 - 0s - loss: 0.0088 - val_loss: 0.0091 - 176ms/epoch - 8ms/step
# Epoch 183/500
# 21/21 - 0s - loss: 0.0087 - val_loss: 0.0090 - 196ms/epoch - 9ms/step
# Epoch 184/500
# 21/21 - 0s - loss: 0.0086 - val_loss: 0.0088 - 199ms/epoch - 9ms/step
# Epoch 185/500
# 21/21 - 0s - loss: 0.0084 - val_loss: 0.0087 - 206ms/epoch - 10ms/step
# Epoch 186/500
# 21/21 - 0s - loss: 0.0083 - val_loss: 0.0086 - 207ms/epoch - 10ms/step
# Epoch 187/500
# 21/21 - 0s - loss: 0.0082 - val_loss: 0.0084 - 237ms/epoch - 11ms/step
# Epoch 188/500
# 21/21 - 0s - loss: 0.0081 - val_loss: 0.0083 - 223ms/epoch - 11ms/step
# Epoch 189/500
# 21/21 - 0s - loss: 0.0079 - val_loss: 0.0082 - 218ms/epoch - 10ms/step
# Epoch 190/500
# 21/21 - 0s - loss: 0.0078 - val_loss: 0.0080 - 217ms/epoch - 10ms/step
# Epoch 191/500
# 21/21 - 0s - loss: 0.0077 - val_loss: 0.0079 - 209ms/epoch - 10ms/step
# Epoch 192/500
# 21/21 - 0s - loss: 0.0075 - val_loss: 0.0077 - 196ms/epoch - 9ms/step
# Epoch 193/500
# 21/21 - 0s - loss: 0.0074 - val_loss: 0.0076 - 162ms/epoch - 8ms/step
# Epoch 194/500
# 21/21 - 0s - loss: 0.0073 - val_loss: 0.0074 - 161ms/epoch - 8ms/step
# Epoch 195/500
# 21/21 - 0s - loss: 0.0071 - val_loss: 0.0073 - 158ms/epoch - 8ms/step
# Epoch 196/500
# 21/21 - 0s - loss: 0.0070 - val_loss: 0.0071 - 162ms/epoch - 8ms/step
# Epoch 197/500
# 21/21 - 0s - loss: 0.0068 - val_loss: 0.0070 - 196ms/epoch - 9ms/step
# Epoch 198/500
# 21/21 - 0s - loss: 0.0067 - val_loss: 0.0068 - 187ms/epoch - 9ms/step
# Epoch 199/500
# 21/21 - 0s - loss: 0.0066 - val_loss: 0.0067 - 205ms/epoch - 10ms/step
# Epoch 200/500
# 21/21 - 0s - loss: 0.0064 - val_loss: 0.0065 - 238ms/epoch - 11ms/step
# Epoch 201/500
# 21/21 - 0s - loss: 0.0063 - val_loss: 0.0064 - 206ms/epoch - 10ms/step
# Epoch 202/500
# 21/21 - 0s - loss: 0.0061 - val_loss: 0.0062 - 205ms/epoch - 10ms/step
# Epoch 203/500
# 21/21 - 0s - loss: 0.0060 - val_loss: 0.0061 - 317ms/epoch - 15ms/step
# Epoch 204/500
# 21/21 - 0s - loss: 0.0058 - val_loss: 0.0059 - 217ms/epoch - 10ms/step
# Epoch 205/500
# 21/21 - 0s - loss: 0.0057 - val_loss: 0.0058 - 237ms/epoch - 11ms/step
# Epoch 206/500
# 21/21 - 0s - loss: 0.0055 - val_loss: 0.0056 - 242ms/epoch - 12ms/step
# Epoch 207/500
# 21/21 - 0s - loss: 0.0054 - val_loss: 0.0055 - 251ms/epoch - 12ms/step
# Epoch 208/500
# 21/21 - 0s - loss: 0.0053 - val_loss: 0.0053 - 273ms/epoch - 13ms/step
# Epoch 209/500
# 21/21 - 0s - loss: 0.0051 - val_loss: 0.0052 - 288ms/epoch - 14ms/step
# Epoch 210/500
# 21/21 - 0s - loss: 0.0050 - val_loss: 0.0050 - 226ms/epoch - 11ms/step
# Epoch 211/500
# 21/21 - 0s - loss: 0.0048 - val_loss: 0.0049 - 193ms/epoch - 9ms/step
# Epoch 212/500
# 21/21 - 0s - loss: 0.0047 - val_loss: 0.0047 - 200ms/epoch - 10ms/step
# Epoch 213/500
# 21/21 - 0s - loss: 0.0046 - val_loss: 0.0046 - 202ms/epoch - 10ms/step
# Epoch 214/500
# 21/21 - 0s - loss: 0.0045 - val_loss: 0.0045 - 212ms/epoch - 10ms/step
# Epoch 215/500
# 21/21 - 0s - loss: 0.0043 - val_loss: 0.0043 - 223ms/epoch - 11ms/step
# Epoch 216/500
# 21/21 - 0s - loss: 0.0042 - val_loss: 0.0042 - 213ms/epoch - 10ms/step
# Epoch 217/500
# 21/21 - 0s - loss: 0.0041 - val_loss: 0.0041 - 227ms/epoch - 11ms/step
# Epoch 218/500
# 21/21 - 0s - loss: 0.0040 - val_loss: 0.0040 - 228ms/epoch - 11ms/step
# Epoch 219/500
# 21/21 - 0s - loss: 0.0039 - val_loss: 0.0038 - 208ms/epoch - 10ms/step
# Epoch 220/500
# 21/21 - 0s - loss: 0.0038 - val_loss: 0.0037 - 232ms/epoch - 11ms/step
# Epoch 221/500
# 21/21 - 0s - loss: 0.0037 - val_loss: 0.0036 - 228ms/epoch - 11ms/step
# Epoch 222/500
# 21/21 - 0s - loss: 0.0036 - val_loss: 0.0035 - 222ms/epoch - 11ms/step
# Epoch 223/500
# 21/21 - 0s - loss: 0.0035 - val_loss: 0.0034 - 216ms/epoch - 10ms/step
# Epoch 224/500
# 21/21 - 0s - loss: 0.0034 - val_loss: 0.0033 - 229ms/epoch - 11ms/step
# Epoch 225/500
# 21/21 - 0s - loss: 0.0033 - val_loss: 0.0033 - 234ms/epoch - 11ms/step
# Epoch 226/500
# 21/21 - 0s - loss: 0.0032 - val_loss: 0.0032 - 241ms/epoch - 11ms/step
# Epoch 227/500
# 21/21 - 0s - loss: 0.0032 - val_loss: 0.0031 - 222ms/epoch - 11ms/step
# Epoch 228/500
# 21/21 - 0s - loss: 0.0031 - val_loss: 0.0030 - 221ms/epoch - 11ms/step
# Epoch 229/500
# 21/21 - 0s - loss: 0.0030 - val_loss: 0.0030 - 214ms/epoch - 10ms/step
# Epoch 230/500
# 21/21 - 0s - loss: 0.0030 - val_loss: 0.0029 - 207ms/epoch - 10ms/step
# Epoch 231/500
# 21/21 - 0s - loss: 0.0029 - val_loss: 0.0028 - 207ms/epoch - 10ms/step
# Epoch 232/500
# 21/21 - 0s - loss: 0.0028 - val_loss: 0.0028 - 218ms/epoch - 10ms/step
# Epoch 233/500
# 21/21 - 0s - loss: 0.0028 - val_loss: 0.0027 - 236ms/epoch - 11ms/step
# Epoch 234/500
# 21/21 - 0s - loss: 0.0028 - val_loss: 0.0027 - 238ms/epoch - 11ms/step
# Epoch 235/500
# 21/21 - 0s - loss: 0.0027 - val_loss: 0.0027 - 247ms/epoch - 12ms/step
# Epoch 236/500
# 21/21 - 0s - loss: 0.0027 - val_loss: 0.0026 - 252ms/epoch - 12ms/step
# Epoch 237/500
# 21/21 - 0s - loss: 0.0026 - val_loss: 0.0026 - 250ms/epoch - 12ms/step
# Epoch 238/500
# 21/21 - 0s - loss: 0.0026 - val_loss: 0.0025 - 241ms/epoch - 11ms/step
# Epoch 239/500
# 21/21 - 0s - loss: 0.0026 - val_loss: 0.0025 - 224ms/epoch - 11ms/step
# Epoch 240/500
# 21/21 - 0s - loss: 0.0025 - val_loss: 0.0025 - 191ms/epoch - 9ms/step
# Epoch 241/500
# 21/21 - 0s - loss: 0.0025 - val_loss: 0.0025 - 172ms/epoch - 8ms/step
# Epoch 242/500
# 21/21 - 0s - loss: 0.0025 - val_loss: 0.0024 - 163ms/epoch - 8ms/step
# Epoch 243/500
# 21/21 - 0s - loss: 0.0025 - val_loss: 0.0024 - 171ms/epoch - 8ms/step
# Epoch 244/500
# 21/21 - 0s - loss: 0.0024 - val_loss: 0.0024 - 183ms/epoch - 9ms/step
# Epoch 245/500
# 21/21 - 0s - loss: 0.0024 - val_loss: 0.0024 - 177ms/epoch - 8ms/step
# Epoch 246/500
# 21/21 - 0s - loss: 0.0024 - val_loss: 0.0023 - 182ms/epoch - 9ms/step
# Epoch 247/500
# 21/21 - 0s - loss: 0.0024 - val_loss: 0.0023 - 198ms/epoch - 9ms/step
# Epoch 248/500
# 21/21 - 0s - loss: 0.0024 - val_loss: 0.0023 - 207ms/epoch - 10ms/step
# Epoch 249/500
# 21/21 - 0s - loss: 0.0023 - val_loss: 0.0023 - 199ms/epoch - 9ms/step
# Epoch 250/500
# 21/21 - 0s - loss: 0.0023 - val_loss: 0.0023 - 208ms/epoch - 10ms/step
# Epoch 251/500
# 21/21 - 0s - loss: 0.0023 - val_loss: 0.0023 - 346ms/epoch - 16ms/step
# Epoch 252/500
# 21/21 - 0s - loss: 0.0023 - val_loss: 0.0023 - 212ms/epoch - 10ms/step
# Epoch 253/500
# 21/21 - 0s - loss: 0.0023 - val_loss: 0.0023 - 222ms/epoch - 11ms/step
# Epoch 254/500
# 21/21 - 0s - loss: 0.0023 - val_loss: 0.0022 - 227ms/epoch - 11ms/step
# Epoch 255/500
# 21/21 - 0s - loss: 0.0023 - val_loss: 0.0022 - 211ms/epoch - 10ms/step
# Epoch 256/500
# 21/21 - 0s - loss: 0.0023 - val_loss: 0.0022 - 211ms/epoch - 10ms/step
# Epoch 257/500
# 21/21 - 0s - loss: 0.0023 - val_loss: 0.0022 - 199ms/epoch - 9ms/step
# Epoch 258/500
# 21/21 - 0s - loss: 0.0023 - val_loss: 0.0022 - 212ms/epoch - 10ms/step
# Epoch 259/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0022 - 213ms/epoch - 10ms/step
# Epoch 260/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0022 - 230ms/epoch - 11ms/step
# Epoch 261/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0022 - 228ms/epoch - 11ms/step
# Epoch 262/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0022 - 225ms/epoch - 11ms/step
# Epoch 263/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0022 - 236ms/epoch - 11ms/step
# Epoch 264/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0022 - 207ms/epoch - 10ms/step
# Epoch 265/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0022 - 232ms/epoch - 11ms/step
# Epoch 266/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0022 - 241ms/epoch - 11ms/step
# Epoch 267/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0022 - 243ms/epoch - 12ms/step
# Epoch 268/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0022 - 217ms/epoch - 10ms/step
# Epoch 269/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0022 - 209ms/epoch - 10ms/step
# Epoch 270/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0021 - 198ms/epoch - 9ms/step
# Epoch 271/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0021 - 211ms/epoch - 10ms/step
# Epoch 272/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0021 - 217ms/epoch - 10ms/step
# Epoch 273/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0021 - 199ms/epoch - 9ms/step
# Epoch 274/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0021 - 207ms/epoch - 10ms/step
# Epoch 275/500
# 21/21 - 0s - loss: 0.0022 - val_loss: 0.0021 - 193ms/epoch - 9ms/step
# Epoch 276/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 213ms/epoch - 10ms/step
# Epoch 277/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 217ms/epoch - 10ms/step
# Epoch 278/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 234ms/epoch - 11ms/step
# Epoch 279/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 217ms/epoch - 10ms/step
# Epoch 280/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 225ms/epoch - 11ms/step
# Epoch 281/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 217ms/epoch - 10ms/step
# Epoch 282/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 218ms/epoch - 10ms/step
# Epoch 283/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 228ms/epoch - 11ms/step
# Epoch 284/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 207ms/epoch - 10ms/step
# Epoch 285/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 200ms/epoch - 10ms/step
# Epoch 286/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 208ms/epoch - 10ms/step
# Epoch 287/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 219ms/epoch - 10ms/step
# Epoch 288/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 219ms/epoch - 10ms/step
# Epoch 289/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 190ms/epoch - 9ms/step
# Epoch 290/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 170ms/epoch - 8ms/step
# Epoch 291/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 170ms/epoch - 8ms/step
# Epoch 292/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 161ms/epoch - 8ms/step
# Epoch 293/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 176ms/epoch - 8ms/step
# Epoch 294/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 186ms/epoch - 9ms/step
# Epoch 295/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 185ms/epoch - 9ms/step
# Epoch 296/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 197ms/epoch - 9ms/step
# Epoch 297/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0021 - 226ms/epoch - 11ms/step
# Epoch 298/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0020 - 206ms/epoch - 10ms/step
# Epoch 299/500
# 21/21 - 0s - loss: 0.0021 - val_loss: 0.0020 - 238ms/epoch - 11ms/step
# Epoch 300/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 379ms/epoch - 18ms/step
# Epoch 301/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 239ms/epoch - 11ms/step
# Epoch 302/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 223ms/epoch - 11ms/step
# Epoch 303/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 200ms/epoch - 10ms/step
# Epoch 304/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 194ms/epoch - 9ms/step
# Epoch 305/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 218ms/epoch - 10ms/step
# Epoch 306/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 212ms/epoch - 10ms/step
# Epoch 307/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 223ms/epoch - 11ms/step
# Epoch 308/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 222ms/epoch - 11ms/step
# Epoch 309/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 228ms/epoch - 11ms/step
# Epoch 310/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 210ms/epoch - 10ms/step
# Epoch 311/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 213ms/epoch - 10ms/step
# Epoch 312/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 221ms/epoch - 11ms/step
# Epoch 313/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 224ms/epoch - 11ms/step
# Epoch 314/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 198ms/epoch - 9ms/step
# Epoch 315/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 207ms/epoch - 10ms/step
# Epoch 316/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 210ms/epoch - 10ms/step
# Epoch 317/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 215ms/epoch - 10ms/step
# Epoch 318/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 216ms/epoch - 10ms/step
# Epoch 319/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 210ms/epoch - 10ms/step
# Epoch 320/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 212ms/epoch - 10ms/step
# Epoch 321/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 198ms/epoch - 9ms/step
# Epoch 322/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 205ms/epoch - 10ms/step
# Epoch 323/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 201ms/epoch - 10ms/step
# Epoch 324/500
# 21/21 - 0s - loss: 0.0020 - val_loss: 0.0020 - 227ms/epoch - 11ms/step
# Epoch 325/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0020 - 221ms/epoch - 11ms/step
# Epoch 326/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0020 - 224ms/epoch - 11ms/step
# Epoch 327/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0020 - 214ms/epoch - 10ms/step
# Epoch 328/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0020 - 214ms/epoch - 10ms/step
# Epoch 329/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0020 - 209ms/epoch - 10ms/step
# Epoch 330/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0020 - 208ms/epoch - 10ms/step
# Epoch 331/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 198ms/epoch - 9ms/step
# Epoch 332/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 211ms/epoch - 10ms/step
# Epoch 333/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 225ms/epoch - 11ms/step
# Epoch 334/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 241ms/epoch - 11ms/step
# Epoch 335/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 232ms/epoch - 11ms/step
# Epoch 336/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 237ms/epoch - 11ms/step
# Epoch 337/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 204ms/epoch - 10ms/step
# Epoch 338/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 197ms/epoch - 9ms/step
# Epoch 339/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 156ms/epoch - 7ms/step
# Epoch 340/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 157ms/epoch - 7ms/step
# Epoch 341/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 153ms/epoch - 7ms/step
# Epoch 342/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 232ms/epoch - 11ms/step
# Epoch 343/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 176ms/epoch - 8ms/step
# Epoch 344/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 190ms/epoch - 9ms/step
# Epoch 345/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 253ms/epoch - 12ms/step
# Epoch 346/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 214ms/epoch - 10ms/step
# Epoch 347/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 220ms/epoch - 10ms/step
# Epoch 348/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 222ms/epoch - 11ms/step
# Epoch 349/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 219ms/epoch - 10ms/step
# Epoch 350/500
# 21/21 - 0s - loss: 0.0019 - val_loss: 0.0019 - 341ms/epoch - 16ms/step
# Epoch 351/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 237ms/epoch - 11ms/step
# Epoch 352/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 299ms/epoch - 14ms/step
# Epoch 353/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 264ms/epoch - 13ms/step
# Epoch 354/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 220ms/epoch - 10ms/step
# Epoch 355/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 245ms/epoch - 12ms/step
# Epoch 356/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 393ms/epoch - 19ms/step
# Epoch 357/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 286ms/epoch - 14ms/step
# Epoch 358/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 270ms/epoch - 13ms/step
# Epoch 359/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 225ms/epoch - 11ms/step
# Epoch 360/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 254ms/epoch - 12ms/step
# Epoch 361/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 330ms/epoch - 16ms/step
# Epoch 362/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 233ms/epoch - 11ms/step
# Epoch 363/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 196ms/epoch - 9ms/step
# Epoch 364/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 196ms/epoch - 9ms/step
# Epoch 365/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 187ms/epoch - 9ms/step
# Epoch 366/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 192ms/epoch - 9ms/step
# Epoch 367/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 205ms/epoch - 10ms/step
# Epoch 368/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 203ms/epoch - 10ms/step
# Epoch 369/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 213ms/epoch - 10ms/step
# Epoch 370/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0019 - 203ms/epoch - 10ms/step
# Epoch 371/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0018 - 239ms/epoch - 11ms/step
# Epoch 372/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0018 - 213ms/epoch - 10ms/step
# Epoch 373/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0018 - 223ms/epoch - 11ms/step
# Epoch 374/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0018 - 238ms/epoch - 11ms/step
# Epoch 375/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0018 - 227ms/epoch - 11ms/step
# Epoch 376/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0018 - 237ms/epoch - 11ms/step
# Epoch 377/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0018 - 233ms/epoch - 11ms/step
# Epoch 378/500
# 21/21 - 0s - loss: 0.0018 - val_loss: 0.0018 - 248ms/epoch - 12ms/step
# Epoch 379/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 236ms/epoch - 11ms/step
# Epoch 380/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 220ms/epoch - 10ms/step
# Epoch 381/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 209ms/epoch - 10ms/step
# Epoch 382/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 215ms/epoch - 10ms/step
# Epoch 383/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 233ms/epoch - 11ms/step
# Epoch 384/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 224ms/epoch - 11ms/step
# Epoch 385/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 249ms/epoch - 12ms/step
# Epoch 386/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 234ms/epoch - 11ms/step
# Epoch 387/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 208ms/epoch - 10ms/step
# Epoch 388/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 183ms/epoch - 9ms/step
# Epoch 389/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 180ms/epoch - 9ms/step
# Epoch 390/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 177ms/epoch - 8ms/step
# Epoch 391/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 177ms/epoch - 8ms/step
# Epoch 392/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 170ms/epoch - 8ms/step
# Epoch 393/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 193ms/epoch - 9ms/step
# Epoch 394/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 242ms/epoch - 12ms/step
# Epoch 395/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 224ms/epoch - 11ms/step
# Epoch 396/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 241ms/epoch - 11ms/step
# Epoch 397/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 232ms/epoch - 11ms/step
# Epoch 398/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 354ms/epoch - 17ms/step
# Epoch 399/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 241ms/epoch - 11ms/step
# Epoch 400/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 236ms/epoch - 11ms/step
# Epoch 401/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 222ms/epoch - 11ms/step
# Epoch 402/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 231ms/epoch - 11ms/step
# Epoch 403/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 234ms/epoch - 11ms/step
# Epoch 404/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 271ms/epoch - 13ms/step
# Epoch 405/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 319ms/epoch - 15ms/step
# Epoch 406/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 305ms/epoch - 15ms/step
# Epoch 407/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 257ms/epoch - 12ms/step
# Epoch 408/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 247ms/epoch - 12ms/step
# Epoch 409/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 240ms/epoch - 11ms/step
# Epoch 410/500
# 21/21 - 0s - loss: 0.0017 - val_loss: 0.0018 - 284ms/epoch - 14ms/step
# Epoch 411/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 324ms/epoch - 15ms/step
# Epoch 412/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 284ms/epoch - 14ms/step
# Epoch 413/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 319ms/epoch - 15ms/step
# Epoch 414/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 272ms/epoch - 13ms/step
# Epoch 415/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 324ms/epoch - 15ms/step
# Epoch 416/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 302ms/epoch - 14ms/step
# Epoch 417/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 310ms/epoch - 15ms/step
# Epoch 418/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 302ms/epoch - 14ms/step
# Epoch 419/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 315ms/epoch - 15ms/step
# Epoch 420/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 299ms/epoch - 14ms/step
# Epoch 421/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 246ms/epoch - 12ms/step
# Epoch 422/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 279ms/epoch - 13ms/step
# Epoch 423/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 246ms/epoch - 12ms/step
# Epoch 424/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 230ms/epoch - 11ms/step
# Epoch 425/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 220ms/epoch - 10ms/step
# Epoch 426/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 231ms/epoch - 11ms/step
# Epoch 427/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 229ms/epoch - 11ms/step
# Epoch 428/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0018 - 230ms/epoch - 11ms/step
# Epoch 429/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 220ms/epoch - 10ms/step
# Epoch 430/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 231ms/epoch - 11ms/step
# Epoch 431/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 347ms/epoch - 17ms/step
# Epoch 432/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 274ms/epoch - 13ms/step
# Epoch 433/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 243ms/epoch - 12ms/step
# Epoch 434/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 218ms/epoch - 10ms/step
# Epoch 435/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 174ms/epoch - 8ms/step
# Epoch 436/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 175ms/epoch - 8ms/step
# Epoch 437/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 167ms/epoch - 8ms/step
# Epoch 438/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 174ms/epoch - 8ms/step
# Epoch 439/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 174ms/epoch - 8ms/step
# Epoch 440/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 192ms/epoch - 9ms/step
# Epoch 441/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 224ms/epoch - 11ms/step
# Epoch 442/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 235ms/epoch - 11ms/step
# Epoch 443/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 261ms/epoch - 12ms/step
# Epoch 444/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 248ms/epoch - 12ms/step
# Epoch 445/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 226ms/epoch - 11ms/step
# Epoch 446/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 243ms/epoch - 12ms/step
# Epoch 447/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 224ms/epoch - 11ms/step
# Epoch 448/500
# 21/21 - 0s - loss: 0.0016 - val_loss: 0.0017 - 258ms/epoch - 12ms/step
# Epoch 449/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 234ms/epoch - 11ms/step
# Epoch 450/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 254ms/epoch - 12ms/step
# Epoch 451/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 226ms/epoch - 11ms/step
# Epoch 452/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 213ms/epoch - 10ms/step
# Epoch 453/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 231ms/epoch - 11ms/step
# Epoch 454/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 279ms/epoch - 13ms/step
# Epoch 455/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 231ms/epoch - 11ms/step
# Epoch 456/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 247ms/epoch - 12ms/step
# Epoch 457/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 244ms/epoch - 12ms/step
# Epoch 458/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 255ms/epoch - 12ms/step
# Epoch 459/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 258ms/epoch - 12ms/step
# Epoch 460/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 267ms/epoch - 13ms/step
# Epoch 461/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 263ms/epoch - 13ms/step
# Epoch 462/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 234ms/epoch - 11ms/step
# Epoch 463/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 208ms/epoch - 10ms/step
# Epoch 464/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 219ms/epoch - 10ms/step
# Epoch 465/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 234ms/epoch - 11ms/step
# Epoch 466/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 224ms/epoch - 11ms/step
# Epoch 467/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 266ms/epoch - 13ms/step
# Epoch 468/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 262ms/epoch - 12ms/step
# Epoch 469/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 252ms/epoch - 12ms/step
# Epoch 470/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 241ms/epoch - 11ms/step
# Epoch 471/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 241ms/epoch - 11ms/step
# Epoch 472/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 231ms/epoch - 11ms/step
# Epoch 473/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 231ms/epoch - 11ms/step
# Epoch 474/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 229ms/epoch - 11ms/step
# Epoch 475/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 277ms/epoch - 13ms/step
# Epoch 476/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 232ms/epoch - 11ms/step
# Epoch 477/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 227ms/epoch - 11ms/step
# Epoch 478/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 230ms/epoch - 11ms/step
# Epoch 479/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 244ms/epoch - 12ms/step
# Epoch 480/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 251ms/epoch - 12ms/step
# Epoch 481/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 217ms/epoch - 10ms/step
# Epoch 482/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 253ms/epoch - 12ms/step
# Epoch 483/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 203ms/epoch - 10ms/step
# Epoch 484/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 173ms/epoch - 8ms/step
# Epoch 485/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 305ms/epoch - 15ms/step
# Epoch 486/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 176ms/epoch - 8ms/step
# Epoch 487/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 175ms/epoch - 8ms/step
# Epoch 488/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 194ms/epoch - 9ms/step
# Epoch 489/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 222ms/epoch - 11ms/step
# Epoch 490/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 246ms/epoch - 12ms/step
# Epoch 491/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 260ms/epoch - 12ms/step
# Epoch 492/500
# 21/21 - 0s - loss: 0.0015 - val_loss: 0.0017 - 242ms/epoch - 12ms/step
# Epoch 493/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0017 - 228ms/epoch - 11ms/step
# Epoch 494/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0017 - 247ms/epoch - 12ms/step
# Epoch 495/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0017 - 261ms/epoch - 12ms/step
# Epoch 496/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0017 - 249ms/epoch - 12ms/step
# Epoch 497/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0017 - 221ms/epoch - 11ms/step
# Epoch 498/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0017 - 211ms/epoch - 10ms/step
# Epoch 499/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0017 - 227ms/epoch - 11ms/step
# Epoch 500/500
# 21/21 - 0s - loss: 0.0014 - val_loss: 0.0017 - 224ms/epoch - 11ms/step

# %% [markdown]
# ## Metrics ($LVPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
phy = phys2(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 11/11 [==============================] - 2s 4ms/step
# (325, 3)
# (325, 10)
# Test RMSE: 0.444
# Test MAE: 0.346

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('El Niño Sea Surface Temperature', fontsize=20)
plt.legend(fontsize=20)
plt.show()
