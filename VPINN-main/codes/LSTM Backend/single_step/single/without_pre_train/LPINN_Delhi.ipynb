# %% [markdown]
# # Time Series Prediction with Lorrenz Attractor Inspired Deep Learning ($LPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-11 20:08:27

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _दिल्ली WIND SPEED_

# %%
data = pd.read_csv("datasets/delhi.csv")
training_set = data.iloc[:, 3]
print(training_set)
# Out:
# 0       0.000000
# 1       2.980000
# 2       4.633333
# 3       1.233333
# 4       3.700000
#           ...
# 1457    3.547826
# 1458    6.000000
# 1459    6.266667
# 1460    7.325000
# 1461    0.000000
# Name: wind_speed, Length: 1462, dtype: float64

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 1 # Daily Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 42.22
# 1       2.980000
# 2       1.653333
# 3      -3.400000
# 4       2.466667
# 5      -2.220000
#           ...
# 1457   -4.787174
# 1458    2.452174
# 1459    0.266667
# 1460    1.058333
# 1461   -7.325000
# Name: wind_speed, Length: 1461, dtype: float64
# 2      -1.326667
# 3      -5.053333
# 4       5.866667
# 5      -4.686667
# 6       7.040000
#           ...
# 1457   -4.337963
# 1458    7.239348
# 1459   -2.185507
# 1460    0.791667
# 1461   -8.383333
# Name: wind_speed, Length: 1460, dtype: float64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0       2.980000
# 1       1.653333
# 2      -3.400000
# 3       2.466667
# 4      -2.220000
#           ...
# 1456   -4.787174
# 1457    2.452174
# 1458    0.266667
# 1459    1.058333
# 1460   -7.325000
# Name: wind_speed, Length: 1461, dtype: float64
# 0      -1.326667
# 1      -5.053333
# 2       5.866667
# 3      -4.686667
# 4       7.040000
#           ...
# 1455   -4.337963
# 1456    7.239348
# 1457   -2.185507
# 1458    0.791667
# 1459   -8.383333
# Name: wind_speed, Length: 1460, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (1461,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lorrenz Equation_)

# %% [markdown]
# _Parameters_: $\sigma=10, \rho=28$

# %%
s=10
r=28
L = df.iloc[:, 2] + df.iloc[:, 1]*(1 + s) - df.iloc[:, 0] * s * (r - 1)
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10    0.000000   2.980000   4.633333   1.233333   3.700000   1.480000
# 11    2.980000   4.633333   1.233333   3.700000   1.480000   6.300000
# 12    4.633333   1.233333   3.700000   1.480000   6.300000   7.142857
# 13    1.233333   3.700000   1.480000   6.300000   7.142857  12.500000
# 14    3.700000   1.480000   6.300000   7.142857  12.500000   7.400000
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)    var1(t)   var2(t)    var3(t)
# 10   6.300000   7.142857  12.500000   7.400000  10.571429  2.657143 -11.252381
# 11   7.142857  12.500000   7.400000  10.571429  13.228571 -8.595238   4.578571
# 12  12.500000   7.400000  10.571429  13.228571   4.633333 -4.016667   3.928571
# 13   7.400000  10.571429  13.228571   4.633333   0.616667 -0.088095  -0.440476
# 14  10.571429  13.228571   4.633333   0.616667   0.528571 -0.528571   5.778571
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (1450, 13)
# (1450, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (1160, 1, 10) (1160, 3) (290, 1, 10) (290, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
s = tf.Variable(10, name="sigma", trainable=True, dtype=tf.float32)
r = tf.Variable(28, name="rhow", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] + y_true[:, 1]*(1 + s) - y_true[:, 0] * s * (r - 1)), (y_pred[:, 2] + y_pred[:, 1]*(1 + s) - y_pred[:, 0] * s * (r - 1)))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] + (y_pred[1:-1]-y_pred[:-2])*(1 + s) - y_pred[:-2] * s * (r - 1)
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] + (y_real[1:-1]-y_real[:-2])*(1 + s) - y_real[:-2] * s * (r - 1)
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($LPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square((y_pred[:, 2] + y_pred[:, 1]*(1 + s) - y_pred[:, 0] * s * (r - 1)))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 19/19 - 16s - loss: 2.3939 - val_loss: 1.0520 - 16s/epoch - 816ms/step
# Epoch 2/500
# 19/19 - 0s - loss: 0.6925 - val_loss: 0.3497 - 219ms/epoch - 12ms/step
# Epoch 3/500
# 19/19 - 0s - loss: 0.2613 - val_loss: 0.1126 - 260ms/epoch - 14ms/step
# Epoch 4/500
# 19/19 - 0s - loss: 0.1091 - val_loss: 0.0625 - 198ms/epoch - 10ms/step
# Epoch 5/500
# 19/19 - 0s - loss: 0.0632 - val_loss: 0.0515 - 170ms/epoch - 9ms/step
# Epoch 6/500
# 19/19 - 0s - loss: 0.0487 - val_loss: 0.0460 - 210ms/epoch - 11ms/step
# Epoch 7/500
# 19/19 - 0s - loss: 0.0431 - val_loss: 0.0446 - 235ms/epoch - 12ms/step
# Epoch 8/500
# 19/19 - 0s - loss: 0.0414 - val_loss: 0.0442 - 181ms/epoch - 10ms/step
# Epoch 9/500
# 19/19 - 0s - loss: 0.0408 - val_loss: 0.0440 - 198ms/epoch - 10ms/step
# Epoch 10/500
# 19/19 - 0s - loss: 0.0406 - val_loss: 0.0439 - 239ms/epoch - 13ms/step
# Epoch 11/500
# 19/19 - 0s - loss: 0.0405 - val_loss: 0.0438 - 194ms/epoch - 10ms/step
# Epoch 12/500
# 19/19 - 0s - loss: 0.0403 - val_loss: 0.0437 - 203ms/epoch - 11ms/step
# Epoch 13/500
# 19/19 - 0s - loss: 0.0402 - val_loss: 0.0436 - 288ms/epoch - 15ms/step
# Epoch 14/500
# 19/19 - 0s - loss: 0.0401 - val_loss: 0.0435 - 227ms/epoch - 12ms/step
# Epoch 15/500
# 19/19 - 0s - loss: 0.0400 - val_loss: 0.0435 - 267ms/epoch - 14ms/step
# Epoch 16/500
# 19/19 - 0s - loss: 0.0399 - val_loss: 0.0434 - 278ms/epoch - 15ms/step
# Epoch 17/500
# 19/19 - 0s - loss: 0.0398 - val_loss: 0.0433 - 196ms/epoch - 10ms/step
# Epoch 18/500
# 19/19 - 0s - loss: 0.0398 - val_loss: 0.0432 - 205ms/epoch - 11ms/step
# Epoch 19/500
# 19/19 - 0s - loss: 0.0397 - val_loss: 0.0431 - 194ms/epoch - 10ms/step
# Epoch 20/500
# 19/19 - 0s - loss: 0.0396 - val_loss: 0.0430 - 211ms/epoch - 11ms/step
# Epoch 21/500
# 19/19 - 0s - loss: 0.0395 - val_loss: 0.0429 - 211ms/epoch - 11ms/step
# Epoch 22/500
# 19/19 - 0s - loss: 0.0395 - val_loss: 0.0428 - 177ms/epoch - 9ms/step
# Epoch 23/500
# 19/19 - 0s - loss: 0.0394 - val_loss: 0.0427 - 165ms/epoch - 9ms/step
# Epoch 24/500
# 19/19 - 0s - loss: 0.0394 - val_loss: 0.0427 - 180ms/epoch - 9ms/step
# Epoch 25/500
# 19/19 - 0s - loss: 0.0393 - val_loss: 0.0426 - 194ms/epoch - 10ms/step
# Epoch 26/500
# 19/19 - 0s - loss: 0.0393 - val_loss: 0.0425 - 180ms/epoch - 9ms/step
# Epoch 27/500
# 19/19 - 0s - loss: 0.0392 - val_loss: 0.0425 - 191ms/epoch - 10ms/step
# Epoch 28/500
# 19/19 - 0s - loss: 0.0391 - val_loss: 0.0425 - 219ms/epoch - 12ms/step
# Epoch 29/500
# 19/19 - 0s - loss: 0.0390 - val_loss: 0.0425 - 219ms/epoch - 12ms/step
# Epoch 30/500
# 19/19 - 0s - loss: 0.0388 - val_loss: 0.0425 - 190ms/epoch - 10ms/step
# Epoch 31/500
# 19/19 - 0s - loss: 0.0387 - val_loss: 0.0425 - 184ms/epoch - 10ms/step
# Epoch 32/500
# 19/19 - 0s - loss: 0.0385 - val_loss: 0.0424 - 173ms/epoch - 9ms/step
# Epoch 33/500
# 19/19 - 0s - loss: 0.0383 - val_loss: 0.0422 - 185ms/epoch - 10ms/step
# Epoch 34/500
# 19/19 - 0s - loss: 0.0382 - val_loss: 0.0421 - 211ms/epoch - 11ms/step
# Epoch 35/500
# 19/19 - 0s - loss: 0.0381 - val_loss: 0.0420 - 191ms/epoch - 10ms/step
# Epoch 36/500
# 19/19 - 0s - loss: 0.0380 - val_loss: 0.0420 - 262ms/epoch - 14ms/step
# Epoch 37/500
# 19/19 - 0s - loss: 0.0379 - val_loss: 0.0419 - 314ms/epoch - 17ms/step
# Epoch 38/500
# 19/19 - 0s - loss: 0.0378 - val_loss: 0.0419 - 380ms/epoch - 20ms/step
# Epoch 39/500
# 19/19 - 0s - loss: 0.0378 - val_loss: 0.0418 - 492ms/epoch - 26ms/step
# Epoch 40/500
# 19/19 - 0s - loss: 0.0377 - val_loss: 0.0418 - 335ms/epoch - 18ms/step
# Epoch 41/500
# 19/19 - 0s - loss: 0.0376 - val_loss: 0.0417 - 284ms/epoch - 15ms/step
# Epoch 42/500
# 19/19 - 0s - loss: 0.0376 - val_loss: 0.0417 - 350ms/epoch - 18ms/step
# Epoch 43/500
# 19/19 - 0s - loss: 0.0375 - val_loss: 0.0417 - 386ms/epoch - 20ms/step
# Epoch 44/500
# 19/19 - 0s - loss: 0.0374 - val_loss: 0.0416 - 362ms/epoch - 19ms/step
# Epoch 45/500
# 19/19 - 0s - loss: 0.0374 - val_loss: 0.0416 - 290ms/epoch - 15ms/step
# Epoch 46/500
# 19/19 - 0s - loss: 0.0373 - val_loss: 0.0416 - 193ms/epoch - 10ms/step
# Epoch 47/500
# 19/19 - 0s - loss: 0.0373 - val_loss: 0.0416 - 195ms/epoch - 10ms/step
# Epoch 48/500
# 19/19 - 0s - loss: 0.0373 - val_loss: 0.0415 - 260ms/epoch - 14ms/step
# Epoch 49/500
# 19/19 - 0s - loss: 0.0372 - val_loss: 0.0415 - 220ms/epoch - 12ms/step
# Epoch 50/500
# 19/19 - 0s - loss: 0.0372 - val_loss: 0.0415 - 208ms/epoch - 11ms/step
# Epoch 51/500
# 19/19 - 0s - loss: 0.0371 - val_loss: 0.0415 - 234ms/epoch - 12ms/step
# Epoch 52/500
# 19/19 - 0s - loss: 0.0371 - val_loss: 0.0415 - 307ms/epoch - 16ms/step
# Epoch 53/500
# 19/19 - 0s - loss: 0.0371 - val_loss: 0.0415 - 384ms/epoch - 20ms/step
# Epoch 54/500
# 19/19 - 0s - loss: 0.0370 - val_loss: 0.0414 - 200ms/epoch - 11ms/step
# Epoch 55/500
# 19/19 - 0s - loss: 0.0370 - val_loss: 0.0414 - 217ms/epoch - 11ms/step
# Epoch 56/500
# 19/19 - 0s - loss: 0.0370 - val_loss: 0.0414 - 251ms/epoch - 13ms/step
# Epoch 57/500
# 19/19 - 0s - loss: 0.0369 - val_loss: 0.0414 - 229ms/epoch - 12ms/step
# Epoch 58/500
# 19/19 - 0s - loss: 0.0369 - val_loss: 0.0414 - 276ms/epoch - 15ms/step
# Epoch 59/500
# 19/19 - 0s - loss: 0.0369 - val_loss: 0.0414 - 362ms/epoch - 19ms/step
# Epoch 60/500
# 19/19 - 0s - loss: 0.0369 - val_loss: 0.0414 - 262ms/epoch - 14ms/step
# Epoch 61/500
# 19/19 - 0s - loss: 0.0368 - val_loss: 0.0414 - 307ms/epoch - 16ms/step
# Epoch 62/500
# 19/19 - 0s - loss: 0.0368 - val_loss: 0.0414 - 260ms/epoch - 14ms/step
# Epoch 63/500
# 19/19 - 0s - loss: 0.0368 - val_loss: 0.0414 - 381ms/epoch - 20ms/step
# Epoch 64/500
# 19/19 - 0s - loss: 0.0368 - val_loss: 0.0414 - 236ms/epoch - 12ms/step
# Epoch 65/500
# 19/19 - 0s - loss: 0.0368 - val_loss: 0.0414 - 257ms/epoch - 14ms/step
# Epoch 66/500
# 19/19 - 0s - loss: 0.0368 - val_loss: 0.0414 - 358ms/epoch - 19ms/step
# Epoch 67/500
# 19/19 - 0s - loss: 0.0367 - val_loss: 0.0414 - 187ms/epoch - 10ms/step
# Epoch 68/500
# 19/19 - 0s - loss: 0.0368 - val_loss: 0.0414 - 190ms/epoch - 10ms/step
# Epoch 69/500
# 19/19 - 0s - loss: 0.0367 - val_loss: 0.0415 - 209ms/epoch - 11ms/step
# Epoch 70/500
# 19/19 - 0s - loss: 0.0368 - val_loss: 0.0416 - 187ms/epoch - 10ms/step
# Epoch 71/500
# 19/19 - 0s - loss: 0.0368 - val_loss: 0.0417 - 170ms/epoch - 9ms/step
# Epoch 72/500
# 19/19 - 0s - loss: 0.0369 - val_loss: 0.0420 - 195ms/epoch - 10ms/step
# Epoch 73/500
# 19/19 - 0s - loss: 0.0371 - val_loss: 0.0423 - 191ms/epoch - 10ms/step
# Epoch 74/500
# 19/19 - 0s - loss: 0.0374 - val_loss: 0.0432 - 202ms/epoch - 11ms/step
# Epoch 75/500
# 19/19 - 0s - loss: 0.0380 - val_loss: 0.0447 - 185ms/epoch - 10ms/step
# Epoch 76/500
# 19/19 - 0s - loss: 0.0396 - val_loss: 0.0484 - 166ms/epoch - 9ms/step
# Epoch 77/500
# 19/19 - 0s - loss: 0.0430 - val_loss: 0.0567 - 247ms/epoch - 13ms/step
# Epoch 78/500
# 19/19 - 0s - loss: 0.0509 - val_loss: 0.0760 - 195ms/epoch - 10ms/step
# Epoch 79/500
# 19/19 - 0s - loss: 0.0635 - val_loss: 0.1058 - 154ms/epoch - 8ms/step
# Epoch 80/500
# 19/19 - 0s - loss: 0.0661 - val_loss: 0.0957 - 170ms/epoch - 9ms/step
# Epoch 81/500
# 19/19 - 0s - loss: 0.0465 - val_loss: 0.0466 - 221ms/epoch - 12ms/step
# Epoch 82/500
# 19/19 - 0s - loss: 0.0376 - val_loss: 0.0422 - 202ms/epoch - 11ms/step
# Epoch 83/500
# 19/19 - 0s - loss: 0.0395 - val_loss: 0.0475 - 202ms/epoch - 11ms/step
# Epoch 84/500
# 19/19 - 0s - loss: 0.0417 - val_loss: 0.0513 - 228ms/epoch - 12ms/step
# Epoch 85/500
# 19/19 - 0s - loss: 0.0433 - val_loss: 0.0539 - 220ms/epoch - 12ms/step
# Epoch 86/500
# 19/19 - 0s - loss: 0.0436 - val_loss: 0.0543 - 231ms/epoch - 12ms/step
# Epoch 87/500
# 19/19 - 0s - loss: 0.0433 - val_loss: 0.0533 - 187ms/epoch - 10ms/step
# Epoch 88/500
# 19/19 - 0s - loss: 0.0420 - val_loss: 0.0509 - 165ms/epoch - 9ms/step
# Epoch 89/500
# 19/19 - 0s - loss: 0.0409 - val_loss: 0.0488 - 208ms/epoch - 11ms/step
# Epoch 90/500
# 19/19 - 0s - loss: 0.0397 - val_loss: 0.0470 - 197ms/epoch - 10ms/step
# Epoch 91/500
# 19/19 - 0s - loss: 0.0390 - val_loss: 0.0459 - 190ms/epoch - 10ms/step
# Epoch 92/500
# 19/19 - 0s - loss: 0.0385 - val_loss: 0.0452 - 193ms/epoch - 10ms/step
# Epoch 93/500
# 19/19 - 0s - loss: 0.0384 - val_loss: 0.0452 - 172ms/epoch - 9ms/step
# Epoch 94/500
# 19/19 - 0s - loss: 0.0386 - val_loss: 0.0458 - 170ms/epoch - 9ms/step
# Epoch 95/500
# 19/19 - 0s - loss: 0.0393 - val_loss: 0.0476 - 191ms/epoch - 10ms/step
# Epoch 96/500
# 19/19 - 0s - loss: 0.0411 - val_loss: 0.0518 - 205ms/epoch - 11ms/step
# Epoch 97/500
# 19/19 - 0s - loss: 0.0454 - val_loss: 0.0622 - 173ms/epoch - 9ms/step
# Epoch 98/500
# 19/19 - 0s - loss: 0.0549 - val_loss: 0.0858 - 192ms/epoch - 10ms/step
# Epoch 99/500
# 19/19 - 0s - loss: 0.0690 - val_loss: 0.1178 - 188ms/epoch - 10ms/step
# Epoch 100/500
# 19/19 - 0s - loss: 0.0656 - val_loss: 0.0886 - 175ms/epoch - 9ms/step
# Epoch 101/500
# 19/19 - 0s - loss: 0.0430 - val_loss: 0.0418 - 192ms/epoch - 10ms/step
# Epoch 102/500
# 19/19 - 0s - loss: 0.0386 - val_loss: 0.0468 - 175ms/epoch - 9ms/step
# Epoch 103/500
# 19/19 - 0s - loss: 0.0444 - val_loss: 0.0581 - 150ms/epoch - 8ms/step
# Epoch 104/500
# 19/19 - 0s - loss: 0.0466 - val_loss: 0.0605 - 162ms/epoch - 9ms/step
# Epoch 105/500
# 19/19 - 0s - loss: 0.0464 - val_loss: 0.0577 - 159ms/epoch - 8ms/step
# Epoch 106/500
# 19/19 - 0s - loss: 0.0423 - val_loss: 0.0499 - 165ms/epoch - 9ms/step
# Epoch 107/500
# 19/19 - 0s - loss: 0.0401 - val_loss: 0.0466 - 181ms/epoch - 10ms/step
# Epoch 108/500
# 19/19 - 0s - loss: 0.0382 - val_loss: 0.0440 - 165ms/epoch - 9ms/step
# Epoch 109/500
# 19/19 - 0s - loss: 0.0380 - val_loss: 0.0440 - 158ms/epoch - 8ms/step
# Epoch 110/500
# 19/19 - 0s - loss: 0.0374 - val_loss: 0.0434 - 177ms/epoch - 9ms/step
# Epoch 111/500
# 19/19 - 0s - loss: 0.0379 - val_loss: 0.0443 - 213ms/epoch - 11ms/step
# Epoch 112/500
# 19/19 - 0s - loss: 0.0378 - val_loss: 0.0446 - 206ms/epoch - 11ms/step
# Epoch 113/500
# 19/19 - 0s - loss: 0.0390 - val_loss: 0.0469 - 301ms/epoch - 16ms/step
# Epoch 114/500
# 19/19 - 0s - loss: 0.0399 - val_loss: 0.0497 - 212ms/epoch - 11ms/step
# Epoch 115/500
# 19/19 - 0s - loss: 0.0432 - val_loss: 0.0567 - 198ms/epoch - 10ms/step
# Epoch 116/500
# 19/19 - 0s - loss: 0.0474 - val_loss: 0.0672 - 188ms/epoch - 10ms/step
# Epoch 117/500
# 19/19 - 0s - loss: 0.0544 - val_loss: 0.0818 - 192ms/epoch - 10ms/step
# Epoch 118/500
# 19/19 - 0s - loss: 0.0556 - val_loss: 0.0803 - 161ms/epoch - 8ms/step
# Epoch 119/500
# 19/19 - 0s - loss: 0.0480 - val_loss: 0.0576 - 194ms/epoch - 10ms/step
# Epoch 120/500
# 19/19 - 0s - loss: 0.0386 - val_loss: 0.0418 - 197ms/epoch - 10ms/step
# Epoch 121/500
# 19/19 - 0s - loss: 0.0368 - val_loss: 0.0419 - 165ms/epoch - 9ms/step
# Epoch 122/500
# 19/19 - 0s - loss: 0.0405 - val_loss: 0.0505 - 175ms/epoch - 9ms/step
# Epoch 123/500
# 19/19 - 0s - loss: 0.0468 - val_loss: 0.0648 - 180ms/epoch - 9ms/step
# Epoch 124/500
# 19/19 - 0s - loss: 0.0555 - val_loss: 0.0817 - 190ms/epoch - 10ms/step
# Epoch 125/500
# 19/19 - 0s - loss: 0.0552 - val_loss: 0.0741 - 240ms/epoch - 13ms/step
# Epoch 126/500
# 19/19 - 0s - loss: 0.0455 - val_loss: 0.0513 - 176ms/epoch - 9ms/step
# Epoch 127/500
# 19/19 - 0s - loss: 0.0378 - val_loss: 0.0416 - 161ms/epoch - 8ms/step
# Epoch 128/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0405 - 194ms/epoch - 10ms/step
# Epoch 129/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0407 - 210ms/epoch - 11ms/step
# Epoch 130/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0409 - 166ms/epoch - 9ms/step
# Epoch 131/500
# 19/19 - 0s - loss: 0.0364 - val_loss: 0.0416 - 178ms/epoch - 9ms/step
# Epoch 132/500
# 19/19 - 0s - loss: 0.0367 - val_loss: 0.0424 - 161ms/epoch - 8ms/step
# Epoch 133/500
# 19/19 - 0s - loss: 0.0377 - val_loss: 0.0446 - 163ms/epoch - 9ms/step
# Epoch 134/500
# 19/19 - 0s - loss: 0.0395 - val_loss: 0.0489 - 179ms/epoch - 9ms/step
# Epoch 135/500
# 19/19 - 0s - loss: 0.0441 - val_loss: 0.0596 - 202ms/epoch - 11ms/step
# Epoch 136/500
# 19/19 - 0s - loss: 0.0529 - val_loss: 0.0812 - 174ms/epoch - 9ms/step
# Epoch 137/500
# 19/19 - 0s - loss: 0.0651 - val_loss: 0.1070 - 169ms/epoch - 9ms/step
# Epoch 138/500
# 19/19 - 0s - loss: 0.0606 - val_loss: 0.0800 - 204ms/epoch - 11ms/step
# Epoch 139/500
# 19/19 - 0s - loss: 0.0420 - val_loss: 0.0421 - 166ms/epoch - 9ms/step
# Epoch 140/500
# 19/19 - 0s - loss: 0.0371 - val_loss: 0.0430 - 224ms/epoch - 12ms/step
# Epoch 141/500
# 19/19 - 0s - loss: 0.0399 - val_loss: 0.0488 - 191ms/epoch - 10ms/step
# Epoch 142/500
# 19/19 - 0s - loss: 0.0416 - val_loss: 0.0513 - 174ms/epoch - 9ms/step
# Epoch 143/500
# 19/19 - 0s - loss: 0.0424 - val_loss: 0.0523 - 178ms/epoch - 9ms/step
# Epoch 144/500
# 19/19 - 0s - loss: 0.0415 - val_loss: 0.0503 - 176ms/epoch - 9ms/step
# Epoch 145/500
# 19/19 - 0s - loss: 0.0406 - val_loss: 0.0485 - 183ms/epoch - 10ms/step
# Epoch 146/500
# 19/19 - 0s - loss: 0.0391 - val_loss: 0.0461 - 222ms/epoch - 12ms/step
# Epoch 147/500
# 19/19 - 0s - loss: 0.0384 - val_loss: 0.0449 - 223ms/epoch - 12ms/step
# Epoch 148/500
# 19/19 - 0s - loss: 0.0376 - val_loss: 0.0437 - 200ms/epoch - 11ms/step
# Epoch 149/500
# 19/19 - 0s - loss: 0.0374 - val_loss: 0.0434 - 214ms/epoch - 11ms/step
# Epoch 150/500
# 19/19 - 0s - loss: 0.0371 - val_loss: 0.0430 - 200ms/epoch - 11ms/step
# Epoch 151/500
# 19/19 - 0s - loss: 0.0372 - val_loss: 0.0433 - 234ms/epoch - 12ms/step
# Epoch 152/500
# 19/19 - 0s - loss: 0.0373 - val_loss: 0.0438 - 179ms/epoch - 9ms/step
# Epoch 153/500
# 19/19 - 0s - loss: 0.0380 - val_loss: 0.0454 - 192ms/epoch - 10ms/step
# Epoch 154/500
# 19/19 - 0s - loss: 0.0394 - val_loss: 0.0489 - 193ms/epoch - 10ms/step
# Epoch 155/500
# 19/19 - 0s - loss: 0.0433 - val_loss: 0.0579 - 277ms/epoch - 15ms/step
# Epoch 156/500
# 19/19 - 0s - loss: 0.0519 - val_loss: 0.0793 - 211ms/epoch - 11ms/step
# Epoch 157/500
# 19/19 - 0s - loss: 0.0670 - val_loss: 0.1153 - 196ms/epoch - 10ms/step
# Epoch 158/500
# 19/19 - 0s - loss: 0.0680 - val_loss: 0.0973 - 208ms/epoch - 11ms/step
# Epoch 159/500
# 19/19 - 0s - loss: 0.0443 - val_loss: 0.0421 - 190ms/epoch - 10ms/step
# Epoch 160/500
# 19/19 - 0s - loss: 0.0381 - val_loss: 0.0460 - 141ms/epoch - 7ms/step
# Epoch 161/500
# 19/19 - 0s - loss: 0.0426 - val_loss: 0.0541 - 149ms/epoch - 8ms/step
# Epoch 162/500
# 19/19 - 0s - loss: 0.0434 - val_loss: 0.0535 - 177ms/epoch - 9ms/step
# Epoch 163/500
# 19/19 - 0s - loss: 0.0422 - val_loss: 0.0504 - 169ms/epoch - 9ms/step
# Epoch 164/500
# 19/19 - 0s - loss: 0.0397 - val_loss: 0.0463 - 155ms/epoch - 8ms/step
# Epoch 165/500
# 19/19 - 0s - loss: 0.0385 - val_loss: 0.0447 - 147ms/epoch - 8ms/step
# Epoch 166/500
# 19/19 - 0s - loss: 0.0375 - val_loss: 0.0434 - 150ms/epoch - 8ms/step
# Epoch 167/500
# 19/19 - 0s - loss: 0.0374 - val_loss: 0.0434 - 193ms/epoch - 10ms/step
# Epoch 168/500
# 19/19 - 0s - loss: 0.0371 - val_loss: 0.0430 - 225ms/epoch - 12ms/step
# Epoch 169/500
# 19/19 - 0s - loss: 0.0374 - val_loss: 0.0435 - 188ms/epoch - 10ms/step
# Epoch 170/500
# 19/19 - 0s - loss: 0.0373 - val_loss: 0.0438 - 176ms/epoch - 9ms/step
# Epoch 171/500
# 19/19 - 0s - loss: 0.0380 - val_loss: 0.0451 - 171ms/epoch - 9ms/step
# Epoch 172/500
# 19/19 - 0s - loss: 0.0385 - val_loss: 0.0466 - 191ms/epoch - 10ms/step
# Epoch 173/500
# 19/19 - 0s - loss: 0.0402 - val_loss: 0.0501 - 180ms/epoch - 9ms/step
# Epoch 174/500
# 19/19 - 0s - loss: 0.0422 - val_loss: 0.0551 - 179ms/epoch - 9ms/step
# Epoch 175/500
# 19/19 - 0s - loss: 0.0461 - val_loss: 0.0635 - 172ms/epoch - 9ms/step
# Epoch 176/500
# 19/19 - 0s - loss: 0.0493 - val_loss: 0.0703 - 158ms/epoch - 8ms/step
# Epoch 177/500
# 19/19 - 0s - loss: 0.0497 - val_loss: 0.0679 - 184ms/epoch - 10ms/step
# Epoch 178/500
# 19/19 - 0s - loss: 0.0438 - val_loss: 0.0528 - 213ms/epoch - 11ms/step
# Epoch 179/500
# 19/19 - 0s - loss: 0.0379 - val_loss: 0.0420 - 185ms/epoch - 10ms/step
# Epoch 180/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0406 - 197ms/epoch - 10ms/step
# Epoch 181/500
# 19/19 - 0s - loss: 0.0387 - val_loss: 0.0472 - 181ms/epoch - 10ms/step
# Epoch 182/500
# 19/19 - 0s - loss: 0.0464 - val_loss: 0.0647 - 157ms/epoch - 8ms/step
# Epoch 183/500
# 19/19 - 0s - loss: 0.0580 - val_loss: 0.0903 - 212ms/epoch - 11ms/step
# Epoch 184/500
# 19/19 - 0s - loss: 0.0610 - val_loss: 0.0846 - 188ms/epoch - 10ms/step
# Epoch 185/500
# 19/19 - 0s - loss: 0.0450 - val_loss: 0.0467 - 180ms/epoch - 9ms/step
# Epoch 186/500
# 19/19 - 0s - loss: 0.0364 - val_loss: 0.0400 - 187ms/epoch - 10ms/step
# Epoch 187/500
# 19/19 - 0s - loss: 0.0356 - val_loss: 0.0405 - 194ms/epoch - 10ms/step
# Epoch 188/500
# 19/19 - 0s - loss: 0.0357 - val_loss: 0.0405 - 207ms/epoch - 11ms/step
# Epoch 189/500
# 19/19 - 0s - loss: 0.0358 - val_loss: 0.0407 - 210ms/epoch - 11ms/step
# Epoch 190/500
# 19/19 - 0s - loss: 0.0357 - val_loss: 0.0406 - 205ms/epoch - 11ms/step
# Epoch 191/500
# 19/19 - 0s - loss: 0.0359 - val_loss: 0.0409 - 165ms/epoch - 9ms/step
# Epoch 192/500
# 19/19 - 0s - loss: 0.0359 - val_loss: 0.0411 - 201ms/epoch - 11ms/step
# Epoch 193/500
# 19/19 - 0s - loss: 0.0363 - val_loss: 0.0419 - 207ms/epoch - 11ms/step
# Epoch 194/500
# 19/19 - 0s - loss: 0.0367 - val_loss: 0.0430 - 160ms/epoch - 8ms/step
# Epoch 195/500
# 19/19 - 0s - loss: 0.0381 - val_loss: 0.0459 - 179ms/epoch - 9ms/step
# Epoch 196/500
# 19/19 - 0s - loss: 0.0407 - val_loss: 0.0522 - 181ms/epoch - 10ms/step
# Epoch 197/500
# 19/19 - 0s - loss: 0.0472 - val_loss: 0.0674 - 210ms/epoch - 11ms/step
# Epoch 198/500
# 19/19 - 0s - loss: 0.0580 - val_loss: 0.0935 - 233ms/epoch - 12ms/step
# Epoch 199/500
# 19/19 - 0s - loss: 0.0638 - val_loss: 0.0962 - 281ms/epoch - 15ms/step
# Epoch 200/500
# 19/19 - 0s - loss: 0.0474 - val_loss: 0.0495 - 193ms/epoch - 10ms/step
# Epoch 201/500
# 19/19 - 0s - loss: 0.0370 - val_loss: 0.0410 - 213ms/epoch - 11ms/step
# Epoch 202/500
# 19/19 - 0s - loss: 0.0386 - val_loss: 0.0471 - 222ms/epoch - 12ms/step
# Epoch 203/500
# 19/19 - 0s - loss: 0.0413 - val_loss: 0.0509 - 169ms/epoch - 9ms/step
# Epoch 204/500
# 19/19 - 0s - loss: 0.0414 - val_loss: 0.0503 - 183ms/epoch - 10ms/step
# Epoch 205/500
# 19/19 - 0s - loss: 0.0406 - val_loss: 0.0484 - 203ms/epoch - 11ms/step
# Epoch 206/500
# 19/19 - 0s - loss: 0.0389 - val_loss: 0.0455 - 197ms/epoch - 10ms/step
# Epoch 207/500
# 19/19 - 0s - loss: 0.0379 - val_loss: 0.0440 - 234ms/epoch - 12ms/step
# Epoch 208/500
# 19/19 - 0s - loss: 0.0370 - val_loss: 0.0427 - 196ms/epoch - 10ms/step
# Epoch 209/500
# 19/19 - 0s - loss: 0.0367 - val_loss: 0.0423 - 171ms/epoch - 9ms/step
# Epoch 210/500
# 19/19 - 0s - loss: 0.0363 - val_loss: 0.0418 - 226ms/epoch - 12ms/step
# Epoch 211/500
# 19/19 - 0s - loss: 0.0363 - val_loss: 0.0419 - 207ms/epoch - 11ms/step
# Epoch 212/500
# 19/19 - 0s - loss: 0.0363 - val_loss: 0.0419 - 161ms/epoch - 8ms/step
# Epoch 213/500
# 19/19 - 0s - loss: 0.0366 - val_loss: 0.0425 - 177ms/epoch - 9ms/step
# Epoch 214/500
# 19/19 - 0s - loss: 0.0369 - val_loss: 0.0436 - 177ms/epoch - 9ms/step
# Epoch 215/500
# 19/19 - 0s - loss: 0.0382 - val_loss: 0.0463 - 157ms/epoch - 8ms/step
# Epoch 216/500
# 19/19 - 0s - loss: 0.0407 - val_loss: 0.0524 - 191ms/epoch - 10ms/step
# Epoch 217/500
# 19/19 - 0s - loss: 0.0471 - val_loss: 0.0674 - 206ms/epoch - 11ms/step
# Epoch 218/500
# 19/19 - 0s - loss: 0.0580 - val_loss: 0.0941 - 153ms/epoch - 8ms/step
# Epoch 219/500
# 19/19 - 0s - loss: 0.0639 - val_loss: 0.0970 - 166ms/epoch - 9ms/step
# Epoch 220/500
# 19/19 - 0s - loss: 0.0469 - val_loss: 0.0484 - 162ms/epoch - 9ms/step
# Epoch 221/500
# 19/19 - 0s - loss: 0.0370 - val_loss: 0.0415 - 173ms/epoch - 9ms/step
# Epoch 222/500
# 19/19 - 0s - loss: 0.0396 - val_loss: 0.0494 - 179ms/epoch - 9ms/step
# Epoch 223/500
# 19/19 - 0s - loss: 0.0429 - val_loss: 0.0540 - 167ms/epoch - 9ms/step
# Epoch 224/500
# 19/19 - 0s - loss: 0.0424 - val_loss: 0.0516 - 148ms/epoch - 8ms/step
# Epoch 225/500
# 19/19 - 0s - loss: 0.0406 - val_loss: 0.0477 - 176ms/epoch - 9ms/step
# Epoch 226/500
# 19/19 - 0s - loss: 0.0382 - val_loss: 0.0440 - 175ms/epoch - 9ms/step
# Epoch 227/500
# 19/19 - 0s - loss: 0.0371 - val_loss: 0.0426 - 195ms/epoch - 10ms/step
# Epoch 228/500
# 19/19 - 0s - loss: 0.0363 - val_loss: 0.0416 - 228ms/epoch - 12ms/step
# Epoch 229/500
# 19/19 - 0s - loss: 0.0362 - val_loss: 0.0415 - 195ms/epoch - 10ms/step
# Epoch 230/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0412 - 202ms/epoch - 11ms/step
# Epoch 231/500
# 19/19 - 0s - loss: 0.0362 - val_loss: 0.0416 - 235ms/epoch - 12ms/step
# Epoch 232/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0418 - 226ms/epoch - 12ms/step
# Epoch 233/500
# 19/19 - 0s - loss: 0.0367 - val_loss: 0.0428 - 170ms/epoch - 9ms/step
# Epoch 234/500
# 19/19 - 0s - loss: 0.0372 - val_loss: 0.0443 - 174ms/epoch - 9ms/step
# Epoch 235/500
# 19/19 - 0s - loss: 0.0390 - val_loss: 0.0481 - 182ms/epoch - 10ms/step
# Epoch 236/500
# 19/19 - 0s - loss: 0.0420 - val_loss: 0.0554 - 232ms/epoch - 12ms/step
# Epoch 237/500
# 19/19 - 0s - loss: 0.0485 - val_loss: 0.0702 - 233ms/epoch - 12ms/step
# Epoch 238/500
# 19/19 - 0s - loss: 0.0553 - val_loss: 0.0848 - 223ms/epoch - 12ms/step
# Epoch 239/500
# 19/19 - 0s - loss: 0.0533 - val_loss: 0.0708 - 191ms/epoch - 10ms/step
# Epoch 240/500
# 19/19 - 0s - loss: 0.0407 - val_loss: 0.0430 - 393ms/epoch - 21ms/step
# Epoch 241/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0407 - 232ms/epoch - 12ms/step
# Epoch 242/500
# 19/19 - 0s - loss: 0.0390 - val_loss: 0.0481 - 214ms/epoch - 11ms/step
# Epoch 243/500
# 19/19 - 0s - loss: 0.0427 - val_loss: 0.0552 - 237ms/epoch - 12ms/step
# Epoch 244/500
# 19/19 - 0s - loss: 0.0453 - val_loss: 0.0585 - 233ms/epoch - 12ms/step
# Epoch 245/500
# 19/19 - 0s - loss: 0.0431 - val_loss: 0.0525 - 165ms/epoch - 9ms/step
# Epoch 246/500
# 19/19 - 0s - loss: 0.0397 - val_loss: 0.0459 - 190ms/epoch - 10ms/step
# Epoch 247/500
# 19/19 - 0s - loss: 0.0368 - val_loss: 0.0417 - 228ms/epoch - 12ms/step
# Epoch 248/500
# 19/19 - 0s - loss: 0.0357 - val_loss: 0.0405 - 187ms/epoch - 10ms/step
# Epoch 249/500
# 19/19 - 0s - loss: 0.0352 - val_loss: 0.0398 - 201ms/epoch - 11ms/step
# Epoch 250/500
# 19/19 - 0s - loss: 0.0351 - val_loss: 0.0396 - 169ms/epoch - 9ms/step
# Epoch 251/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0395 - 159ms/epoch - 8ms/step
# Epoch 252/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0395 - 229ms/epoch - 12ms/step
# Epoch 253/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0395 - 211ms/epoch - 11ms/step
# Epoch 254/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0397 - 161ms/epoch - 8ms/step
# Epoch 255/500
# 19/19 - 0s - loss: 0.0355 - val_loss: 0.0405 - 194ms/epoch - 10ms/step
# Epoch 256/500
# 19/19 - 0s - loss: 0.0367 - val_loss: 0.0432 - 181ms/epoch - 10ms/step
# Epoch 257/500
# 19/19 - 0s - loss: 0.0415 - val_loss: 0.0538 - 199ms/epoch - 10ms/step
# Epoch 258/500
# 19/19 - 0s - loss: 0.0574 - val_loss: 0.0943 - 238ms/epoch - 13ms/step
# Epoch 259/500
# 19/19 - 0s - loss: 0.0913 - val_loss: 0.1784 - 186ms/epoch - 10ms/step
# Epoch 260/500
# 19/19 - 0s - loss: 0.0661 - val_loss: 0.0514 - 164ms/epoch - 9ms/step
# Epoch 261/500
# 19/19 - 0s - loss: 0.0461 - val_loss: 0.0596 - 201ms/epoch - 11ms/step
# Epoch 262/500
# 19/19 - 0s - loss: 0.0393 - val_loss: 0.0404 - 206ms/epoch - 11ms/step
# Epoch 263/500
# 19/19 - 0s - loss: 0.0416 - val_loss: 0.0453 - 215ms/epoch - 11ms/step
# Epoch 264/500
# 19/19 - 0s - loss: 0.0417 - val_loss: 0.0426 - 200ms/epoch - 11ms/step
# Epoch 265/500
# 19/19 - 0s - loss: 0.0511 - val_loss: 0.0524 - 178ms/epoch - 9ms/step
# Epoch 266/500
# 19/19 - 0s - loss: 0.0558 - val_loss: 0.0508 - 164ms/epoch - 9ms/step
# Epoch 267/500
# 19/19 - 0s - loss: 0.0786 - val_loss: 0.0625 - 203ms/epoch - 11ms/step
# Epoch 268/500
# 19/19 - 0s - loss: 0.1199 - val_loss: 0.0558 - 248ms/epoch - 13ms/step
# Epoch 269/500
# 19/19 - 0s - loss: 0.2287 - val_loss: 0.0853 - 185ms/epoch - 10ms/step
# Epoch 270/500
# 19/19 - 0s - loss: 0.3239 - val_loss: 0.1728 - 191ms/epoch - 10ms/step
# Epoch 271/500
# 19/19 - 0s - loss: 0.0845 - val_loss: 0.0471 - 186ms/epoch - 10ms/step
# Epoch 272/500
# 19/19 - 0s - loss: 0.0373 - val_loss: 0.0396 - 165ms/epoch - 9ms/step
# Epoch 273/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0395 - 219ms/epoch - 12ms/step
# Epoch 274/500
# 19/19 - 0s - loss: 0.0351 - val_loss: 0.0396 - 170ms/epoch - 9ms/step
# Epoch 275/500
# 19/19 - 0s - loss: 0.0351 - val_loss: 0.0395 - 142ms/epoch - 7ms/step
# Epoch 276/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0395 - 149ms/epoch - 8ms/step
# Epoch 277/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0395 - 168ms/epoch - 9ms/step
# Epoch 278/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0395 - 173ms/epoch - 9ms/step
# Epoch 279/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0395 - 176ms/epoch - 9ms/step
# Epoch 280/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0395 - 273ms/epoch - 14ms/step
# Epoch 281/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0395 - 166ms/epoch - 9ms/step
# Epoch 282/500
# 19/19 - 0s - loss: 0.0349 - val_loss: 0.0394 - 210ms/epoch - 11ms/step
# Epoch 283/500
# 19/19 - 0s - loss: 0.0349 - val_loss: 0.0394 - 207ms/epoch - 11ms/step
# Epoch 284/500
# 19/19 - 0s - loss: 0.0349 - val_loss: 0.0394 - 171ms/epoch - 9ms/step
# Epoch 285/500
# 19/19 - 0s - loss: 0.0349 - val_loss: 0.0394 - 178ms/epoch - 9ms/step
# Epoch 286/500
# 19/19 - 0s - loss: 0.0349 - val_loss: 0.0394 - 173ms/epoch - 9ms/step
# Epoch 287/500
# 19/19 - 0s - loss: 0.0349 - val_loss: 0.0394 - 181ms/epoch - 10ms/step
# Epoch 288/500
# 19/19 - 0s - loss: 0.0349 - val_loss: 0.0394 - 215ms/epoch - 11ms/step
# Epoch 289/500
# 19/19 - 0s - loss: 0.0349 - val_loss: 0.0394 - 217ms/epoch - 11ms/step
# Epoch 290/500
# 19/19 - 0s - loss: 0.0349 - val_loss: 0.0394 - 163ms/epoch - 9ms/step
# Epoch 291/500
# 19/19 - 0s - loss: 0.0349 - val_loss: 0.0394 - 185ms/epoch - 10ms/step
# Epoch 292/500
# 19/19 - 0s - loss: 0.0349 - val_loss: 0.0394 - 245ms/epoch - 13ms/step
# Epoch 293/500
# 19/19 - 0s - loss: 0.0349 - val_loss: 0.0393 - 215ms/epoch - 11ms/step
# Epoch 294/500
# 19/19 - 0s - loss: 0.0348 - val_loss: 0.0393 - 192ms/epoch - 10ms/step
# Epoch 295/500
# 19/19 - 0s - loss: 0.0348 - val_loss: 0.0393 - 177ms/epoch - 9ms/step
# Epoch 296/500
# 19/19 - 0s - loss: 0.0348 - val_loss: 0.0393 - 165ms/epoch - 9ms/step
# Epoch 297/500
# 19/19 - 0s - loss: 0.0348 - val_loss: 0.0393 - 282ms/epoch - 15ms/step
# Epoch 298/500
# 19/19 - 0s - loss: 0.0348 - val_loss: 0.0393 - 204ms/epoch - 11ms/step
# Epoch 299/500
# 19/19 - 0s - loss: 0.0348 - val_loss: 0.0393 - 170ms/epoch - 9ms/step
# Epoch 300/500
# 19/19 - 0s - loss: 0.0348 - val_loss: 0.0393 - 190ms/epoch - 10ms/step
# Epoch 301/500
# 19/19 - 0s - loss: 0.0348 - val_loss: 0.0393 - 203ms/epoch - 11ms/step
# Epoch 302/500
# 19/19 - 0s - loss: 0.0348 - val_loss: 0.0392 - 191ms/epoch - 10ms/step
# Epoch 303/500
# 19/19 - 0s - loss: 0.0348 - val_loss: 0.0392 - 179ms/epoch - 9ms/step
# Epoch 304/500
# 19/19 - 0s - loss: 0.0348 - val_loss: 0.0392 - 178ms/epoch - 9ms/step
# Epoch 305/500
# 19/19 - 0s - loss: 0.0347 - val_loss: 0.0392 - 175ms/epoch - 9ms/step
# Epoch 306/500
# 19/19 - 0s - loss: 0.0347 - val_loss: 0.0392 - 184ms/epoch - 10ms/step
# Epoch 307/500
# 19/19 - 0s - loss: 0.0347 - val_loss: 0.0392 - 223ms/epoch - 12ms/step
# Epoch 308/500
# 19/19 - 0s - loss: 0.0347 - val_loss: 0.0392 - 191ms/epoch - 10ms/step
# Epoch 309/500
# 19/19 - 0s - loss: 0.0347 - val_loss: 0.0392 - 191ms/epoch - 10ms/step
# Epoch 310/500
# 19/19 - 0s - loss: 0.0347 - val_loss: 0.0392 - 224ms/epoch - 12ms/step
# Epoch 311/500
# 19/19 - 0s - loss: 0.0347 - val_loss: 0.0391 - 267ms/epoch - 14ms/step
# Epoch 312/500
# 19/19 - 0s - loss: 0.0347 - val_loss: 0.0391 - 280ms/epoch - 15ms/step
# Epoch 313/500
# 19/19 - 0s - loss: 0.0347 - val_loss: 0.0391 - 255ms/epoch - 13ms/step
# Epoch 314/500
# 19/19 - 0s - loss: 0.0347 - val_loss: 0.0391 - 221ms/epoch - 12ms/step
# Epoch 315/500
# 19/19 - 0s - loss: 0.0346 - val_loss: 0.0391 - 212ms/epoch - 11ms/step
# Epoch 316/500
# 19/19 - 0s - loss: 0.0346 - val_loss: 0.0391 - 193ms/epoch - 10ms/step
# Epoch 317/500
# 19/19 - 0s - loss: 0.0346 - val_loss: 0.0391 - 167ms/epoch - 9ms/step
# Epoch 318/500
# 19/19 - 0s - loss: 0.0346 - val_loss: 0.0391 - 298ms/epoch - 16ms/step
# Epoch 319/500
# 19/19 - 0s - loss: 0.0346 - val_loss: 0.0390 - 232ms/epoch - 12ms/step
# Epoch 320/500
# 19/19 - 0s - loss: 0.0346 - val_loss: 0.0390 - 230ms/epoch - 12ms/step
# Epoch 321/500
# 19/19 - 0s - loss: 0.0346 - val_loss: 0.0390 - 190ms/epoch - 10ms/step
# Epoch 322/500
# 19/19 - 0s - loss: 0.0346 - val_loss: 0.0390 - 178ms/epoch - 9ms/step
# Epoch 323/500
# 19/19 - 0s - loss: 0.0346 - val_loss: 0.0390 - 188ms/epoch - 10ms/step
# Epoch 324/500
# 19/19 - 0s - loss: 0.0346 - val_loss: 0.0390 - 217ms/epoch - 11ms/step
# Epoch 325/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0390 - 221ms/epoch - 12ms/step
# Epoch 326/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0389 - 181ms/epoch - 10ms/step
# Epoch 327/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0389 - 224ms/epoch - 12ms/step
# Epoch 328/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0389 - 224ms/epoch - 12ms/step
# Epoch 329/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0389 - 212ms/epoch - 11ms/step
# Epoch 330/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0389 - 212ms/epoch - 11ms/step
# Epoch 331/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0389 - 170ms/epoch - 9ms/step
# Epoch 332/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0389 - 158ms/epoch - 8ms/step
# Epoch 333/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0389 - 177ms/epoch - 9ms/step
# Epoch 334/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0388 - 177ms/epoch - 9ms/step
# Epoch 335/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0388 - 146ms/epoch - 8ms/step
# Epoch 336/500
# 19/19 - 0s - loss: 0.0344 - val_loss: 0.0388 - 207ms/epoch - 11ms/step
# Epoch 337/500
# 19/19 - 0s - loss: 0.0344 - val_loss: 0.0388 - 189ms/epoch - 10ms/step
# Epoch 338/500
# 19/19 - 0s - loss: 0.0344 - val_loss: 0.0388 - 171ms/epoch - 9ms/step
# Epoch 339/500
# 19/19 - 0s - loss: 0.0344 - val_loss: 0.0387 - 248ms/epoch - 13ms/step
# Epoch 340/500
# 19/19 - 0s - loss: 0.0344 - val_loss: 0.0387 - 244ms/epoch - 13ms/step
# Epoch 341/500
# 19/19 - 0s - loss: 0.0343 - val_loss: 0.0387 - 188ms/epoch - 10ms/step
# Epoch 342/500
# 19/19 - 0s - loss: 0.0343 - val_loss: 0.0387 - 214ms/epoch - 11ms/step
# Epoch 343/500
# 19/19 - 0s - loss: 0.0343 - val_loss: 0.0387 - 209ms/epoch - 11ms/step
# Epoch 344/500
# 19/19 - 0s - loss: 0.0343 - val_loss: 0.0386 - 171ms/epoch - 9ms/step
# Epoch 345/500
# 19/19 - 0s - loss: 0.0343 - val_loss: 0.0387 - 239ms/epoch - 13ms/step
# Epoch 346/500
# 19/19 - 0s - loss: 0.0344 - val_loss: 0.0390 - 216ms/epoch - 11ms/step
# Epoch 347/500
# 19/19 - 0s - loss: 0.0355 - val_loss: 0.0404 - 191ms/epoch - 10ms/step
# Epoch 348/500
# 19/19 - 0s - loss: 0.0411 - val_loss: 0.0498 - 228ms/epoch - 12ms/step
# Epoch 349/500
# 19/19 - 0s - loss: 0.0718 - val_loss: 0.1327 - 258ms/epoch - 14ms/step
# Epoch 350/500
# 19/19 - 0s - loss: 0.1428 - val_loss: 0.2464 - 250ms/epoch - 13ms/step
# Epoch 351/500
# 19/19 - 0s - loss: 0.0990 - val_loss: 0.1364 - 265ms/epoch - 14ms/step
# Epoch 352/500
# 19/19 - 0s - loss: 0.1003 - val_loss: 0.0755 - 195ms/epoch - 10ms/step
# Epoch 353/500
# 19/19 - 0s - loss: 0.1567 - val_loss: 0.0458 - 187ms/epoch - 10ms/step
# Epoch 354/500
# 19/19 - 0s - loss: 0.1828 - val_loss: 0.1100 - 194ms/epoch - 10ms/step
# Epoch 355/500
# 19/19 - 0s - loss: 0.0711 - val_loss: 0.0394 - 188ms/epoch - 10ms/step
# Epoch 356/500
# 19/19 - 0s - loss: 0.0376 - val_loss: 0.0400 - 223ms/epoch - 12ms/step
# Epoch 357/500
# 19/19 - 0s - loss: 0.0355 - val_loss: 0.0391 - 345ms/epoch - 18ms/step
# Epoch 358/500
# 19/19 - 0s - loss: 0.0347 - val_loss: 0.0390 - 210ms/epoch - 11ms/step
# Epoch 359/500
# 19/19 - 0s - loss: 0.0346 - val_loss: 0.0389 - 239ms/epoch - 13ms/step
# Epoch 360/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0389 - 224ms/epoch - 12ms/step
# Epoch 361/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0389 - 194ms/epoch - 10ms/step
# Epoch 362/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0389 - 219ms/epoch - 12ms/step
# Epoch 363/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0389 - 229ms/epoch - 12ms/step
# Epoch 364/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0389 - 204ms/epoch - 11ms/step
# Epoch 365/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0388 - 220ms/epoch - 12ms/step
# Epoch 366/500
# 19/19 - 0s - loss: 0.0344 - val_loss: 0.0388 - 223ms/epoch - 12ms/step
# Epoch 367/500
# 19/19 - 0s - loss: 0.0344 - val_loss: 0.0388 - 180ms/epoch - 9ms/step
# Epoch 368/500
# 19/19 - 0s - loss: 0.0344 - val_loss: 0.0388 - 202ms/epoch - 11ms/step
# Epoch 369/500
# 19/19 - 0s - loss: 0.0344 - val_loss: 0.0388 - 239ms/epoch - 13ms/step
# Epoch 370/500
# 19/19 - 0s - loss: 0.0344 - val_loss: 0.0388 - 222ms/epoch - 12ms/step
# Epoch 371/500
# 19/19 - 0s - loss: 0.0344 - val_loss: 0.0387 - 193ms/epoch - 10ms/step
# Epoch 372/500
# 19/19 - 0s - loss: 0.0343 - val_loss: 0.0387 - 191ms/epoch - 10ms/step
# Epoch 373/500
# 19/19 - 0s - loss: 0.0343 - val_loss: 0.0387 - 180ms/epoch - 9ms/step
# Epoch 374/500
# 19/19 - 0s - loss: 0.0343 - val_loss: 0.0387 - 204ms/epoch - 11ms/step
# Epoch 375/500
# 19/19 - 0s - loss: 0.0343 - val_loss: 0.0387 - 196ms/epoch - 10ms/step
# Epoch 376/500
# 19/19 - 0s - loss: 0.0343 - val_loss: 0.0387 - 170ms/epoch - 9ms/step
# Epoch 377/500
# 19/19 - 0s - loss: 0.0343 - val_loss: 0.0386 - 191ms/epoch - 10ms/step
# Epoch 378/500
# 19/19 - 0s - loss: 0.0343 - val_loss: 0.0386 - 183ms/epoch - 10ms/step
# Epoch 379/500
# 19/19 - 0s - loss: 0.0342 - val_loss: 0.0386 - 168ms/epoch - 9ms/step
# Epoch 380/500
# 19/19 - 0s - loss: 0.0342 - val_loss: 0.0386 - 181ms/epoch - 10ms/step
# Epoch 381/500
# 19/19 - 0s - loss: 0.0342 - val_loss: 0.0386 - 185ms/epoch - 10ms/step
# Epoch 382/500
# 19/19 - 0s - loss: 0.0342 - val_loss: 0.0386 - 168ms/epoch - 9ms/step
# Epoch 383/500
# 19/19 - 0s - loss: 0.0342 - val_loss: 0.0385 - 196ms/epoch - 10ms/step
# Epoch 384/500
# 19/19 - 0s - loss: 0.0342 - val_loss: 0.0385 - 203ms/epoch - 11ms/step
# Epoch 385/500
# 19/19 - 0s - loss: 0.0342 - val_loss: 0.0385 - 175ms/epoch - 9ms/step
# Epoch 386/500
# 19/19 - 0s - loss: 0.0341 - val_loss: 0.0385 - 187ms/epoch - 10ms/step
# Epoch 387/500
# 19/19 - 0s - loss: 0.0341 - val_loss: 0.0385 - 153ms/epoch - 8ms/step
# Epoch 388/500
# 19/19 - 0s - loss: 0.0341 - val_loss: 0.0384 - 157ms/epoch - 8ms/step
# Epoch 389/500
# 19/19 - 0s - loss: 0.0341 - val_loss: 0.0384 - 151ms/epoch - 8ms/step
# Epoch 390/500
# 19/19 - 0s - loss: 0.0341 - val_loss: 0.0384 - 160ms/epoch - 8ms/step
# Epoch 391/500
# 19/19 - 0s - loss: 0.0340 - val_loss: 0.0384 - 158ms/epoch - 8ms/step
# Epoch 392/500
# 19/19 - 0s - loss: 0.0340 - val_loss: 0.0383 - 173ms/epoch - 9ms/step
# Epoch 393/500
# 19/19 - 0s - loss: 0.0340 - val_loss: 0.0383 - 159ms/epoch - 8ms/step
# Epoch 394/500
# 19/19 - 0s - loss: 0.0340 - val_loss: 0.0383 - 168ms/epoch - 9ms/step
# Epoch 395/500
# 19/19 - 0s - loss: 0.0340 - val_loss: 0.0383 - 171ms/epoch - 9ms/step
# Epoch 396/500
# 19/19 - 0s - loss: 0.0339 - val_loss: 0.0382 - 197ms/epoch - 10ms/step
# Epoch 397/500
# 19/19 - 0s - loss: 0.0339 - val_loss: 0.0382 - 289ms/epoch - 15ms/step
# Epoch 398/500
# 19/19 - 0s - loss: 0.0339 - val_loss: 0.0382 - 271ms/epoch - 14ms/step
# Epoch 399/500
# 19/19 - 0s - loss: 0.0339 - val_loss: 0.0382 - 206ms/epoch - 11ms/step
# Epoch 400/500
# 19/19 - 0s - loss: 0.0339 - val_loss: 0.0381 - 207ms/epoch - 11ms/step
# Epoch 401/500
# 19/19 - 0s - loss: 0.0339 - val_loss: 0.0381 - 187ms/epoch - 10ms/step
# Epoch 402/500
# 19/19 - 0s - loss: 0.0338 - val_loss: 0.0381 - 223ms/epoch - 12ms/step
# Epoch 403/500
# 19/19 - 0s - loss: 0.0338 - val_loss: 0.0381 - 203ms/epoch - 11ms/step
# Epoch 404/500
# 19/19 - 0s - loss: 0.0338 - val_loss: 0.0380 - 171ms/epoch - 9ms/step
# Epoch 405/500
# 19/19 - 0s - loss: 0.0338 - val_loss: 0.0380 - 232ms/epoch - 12ms/step
# Epoch 406/500
# 19/19 - 0s - loss: 0.0337 - val_loss: 0.0380 - 238ms/epoch - 13ms/step
# Epoch 407/500
# 19/19 - 0s - loss: 0.0337 - val_loss: 0.0379 - 202ms/epoch - 11ms/step
# Epoch 408/500
# 19/19 - 0s - loss: 0.0337 - val_loss: 0.0379 - 186ms/epoch - 10ms/step
# Epoch 409/500
# 19/19 - 0s - loss: 0.0337 - val_loss: 0.0379 - 173ms/epoch - 9ms/step
# Epoch 410/500
# 19/19 - 0s - loss: 0.0336 - val_loss: 0.0378 - 184ms/epoch - 10ms/step
# Epoch 411/500
# 19/19 - 0s - loss: 0.0336 - val_loss: 0.0378 - 195ms/epoch - 10ms/step
# Epoch 412/500
# 19/19 - 0s - loss: 0.0336 - val_loss: 0.0379 - 212ms/epoch - 11ms/step
# Epoch 413/500
# 19/19 - 0s - loss: 0.0340 - val_loss: 0.0385 - 174ms/epoch - 9ms/step
# Epoch 414/500
# 19/19 - 0s - loss: 0.0357 - val_loss: 0.0418 - 210ms/epoch - 11ms/step
# Epoch 415/500
# 19/19 - 0s - loss: 0.0439 - val_loss: 0.0618 - 196ms/epoch - 10ms/step
# Epoch 416/500
# 19/19 - 0s - loss: 0.0660 - val_loss: 0.1210 - 165ms/epoch - 9ms/step
# Epoch 417/500
# 19/19 - 0s - loss: 0.0539 - val_loss: 0.0459 - 211ms/epoch - 11ms/step
# Epoch 418/500
# 19/19 - 0s - loss: 0.0423 - val_loss: 0.0533 - 194ms/epoch - 10ms/step
# Epoch 419/500
# 19/19 - 0s - loss: 0.0378 - val_loss: 0.0404 - 164ms/epoch - 9ms/step
# Epoch 420/500
# 19/19 - 0s - loss: 0.0395 - val_loss: 0.0438 - 162ms/epoch - 9ms/step
# Epoch 421/500
# 19/19 - 0s - loss: 0.0401 - val_loss: 0.0421 - 170ms/epoch - 9ms/step
# Epoch 422/500
# 19/19 - 0s - loss: 0.0471 - val_loss: 0.0498 - 168ms/epoch - 9ms/step
# Epoch 423/500
# 19/19 - 0s - loss: 0.0529 - val_loss: 0.0505 - 208ms/epoch - 11ms/step
# Epoch 424/500
# 19/19 - 0s - loss: 0.0732 - val_loss: 0.0581 - 185ms/epoch - 10ms/step
# Epoch 425/500
# 19/19 - 0s - loss: 0.1159 - val_loss: 0.0458 - 180ms/epoch - 9ms/step
# Epoch 426/500
# 19/19 - 0s - loss: 0.2013 - val_loss: 0.1182 - 188ms/epoch - 10ms/step
# Epoch 427/500
# 19/19 - 0s - loss: 0.1690 - val_loss: 0.0592 - 192ms/epoch - 10ms/step
# Epoch 428/500
# 19/19 - 0s - loss: 0.0512 - val_loss: 0.0435 - 165ms/epoch - 9ms/step
# Epoch 429/500
# 19/19 - 0s - loss: 0.0374 - val_loss: 0.0389 - 208ms/epoch - 11ms/step
# Epoch 430/500
# 19/19 - 0s - loss: 0.0342 - val_loss: 0.0385 - 196ms/epoch - 10ms/step
# Epoch 431/500
# 19/19 - 0s - loss: 0.0340 - val_loss: 0.0383 - 176ms/epoch - 9ms/step
# Epoch 432/500
# 19/19 - 0s - loss: 0.0340 - val_loss: 0.0383 - 171ms/epoch - 9ms/step
# Epoch 433/500
# 19/19 - 0s - loss: 0.0340 - val_loss: 0.0383 - 208ms/epoch - 11ms/step
# Epoch 434/500
# 19/19 - 0s - loss: 0.0340 - val_loss: 0.0383 - 184ms/epoch - 10ms/step
# Epoch 435/500
# 19/19 - 0s - loss: 0.0339 - val_loss: 0.0382 - 239ms/epoch - 13ms/step
# Epoch 436/500
# 19/19 - 0s - loss: 0.0339 - val_loss: 0.0382 - 182ms/epoch - 10ms/step
# Epoch 437/500
# 19/19 - 0s - loss: 0.0339 - val_loss: 0.0382 - 176ms/epoch - 9ms/step
# Epoch 438/500
# 19/19 - 0s - loss: 0.0339 - val_loss: 0.0382 - 191ms/epoch - 10ms/step
# Epoch 439/500
# 19/19 - 0s - loss: 0.0338 - val_loss: 0.0381 - 215ms/epoch - 11ms/step
# Epoch 440/500
# 19/19 - 0s - loss: 0.0338 - val_loss: 0.0381 - 178ms/epoch - 9ms/step
# Epoch 441/500
# 19/19 - 0s - loss: 0.0338 - val_loss: 0.0381 - 180ms/epoch - 9ms/step
# Epoch 442/500
# 19/19 - 0s - loss: 0.0338 - val_loss: 0.0380 - 166ms/epoch - 9ms/step
# Epoch 443/500
# 19/19 - 0s - loss: 0.0338 - val_loss: 0.0380 - 236ms/epoch - 12ms/step
# Epoch 444/500
# 19/19 - 0s - loss: 0.0337 - val_loss: 0.0380 - 196ms/epoch - 10ms/step
# Epoch 445/500
# 19/19 - 0s - loss: 0.0337 - val_loss: 0.0380 - 188ms/epoch - 10ms/step
# Epoch 446/500
# 19/19 - 0s - loss: 0.0337 - val_loss: 0.0379 - 158ms/epoch - 8ms/step
# Epoch 447/500
# 19/19 - 0s - loss: 0.0337 - val_loss: 0.0379 - 145ms/epoch - 8ms/step
# Epoch 448/500
# 19/19 - 0s - loss: 0.0336 - val_loss: 0.0379 - 165ms/epoch - 9ms/step
# Epoch 449/500
# 19/19 - 0s - loss: 0.0336 - val_loss: 0.0378 - 156ms/epoch - 8ms/step
# Epoch 450/500
# 19/19 - 0s - loss: 0.0336 - val_loss: 0.0378 - 155ms/epoch - 8ms/step
# Epoch 451/500
# 19/19 - 0s - loss: 0.0336 - val_loss: 0.0378 - 163ms/epoch - 9ms/step
# Epoch 452/500
# 19/19 - 0s - loss: 0.0335 - val_loss: 0.0377 - 217ms/epoch - 11ms/step
# Epoch 453/500
# 19/19 - 0s - loss: 0.0335 - val_loss: 0.0377 - 173ms/epoch - 9ms/step
# Epoch 454/500
# 19/19 - 0s - loss: 0.0335 - val_loss: 0.0377 - 211ms/epoch - 11ms/step
# Epoch 455/500
# 19/19 - 0s - loss: 0.0334 - val_loss: 0.0376 - 178ms/epoch - 9ms/step
# Epoch 456/500
# 19/19 - 0s - loss: 0.0334 - val_loss: 0.0376 - 180ms/epoch - 9ms/step
# Epoch 457/500
# 19/19 - 0s - loss: 0.0334 - val_loss: 0.0375 - 237ms/epoch - 12ms/step
# Epoch 458/500
# 19/19 - 0s - loss: 0.0333 - val_loss: 0.0375 - 190ms/epoch - 10ms/step
# Epoch 459/500
# 19/19 - 0s - loss: 0.0333 - val_loss: 0.0375 - 200ms/epoch - 11ms/step
# Epoch 460/500
# 19/19 - 0s - loss: 0.0333 - val_loss: 0.0374 - 185ms/epoch - 10ms/step
# Epoch 461/500
# 19/19 - 0s - loss: 0.0332 - val_loss: 0.0374 - 174ms/epoch - 9ms/step
# Epoch 462/500
# 19/19 - 0s - loss: 0.0332 - val_loss: 0.0373 - 174ms/epoch - 9ms/step
# Epoch 463/500
# 19/19 - 0s - loss: 0.0332 - val_loss: 0.0373 - 199ms/epoch - 10ms/step
# Epoch 464/500
# 19/19 - 0s - loss: 0.0331 - val_loss: 0.0372 - 192ms/epoch - 10ms/step
# Epoch 465/500
# 19/19 - 0s - loss: 0.0331 - val_loss: 0.0372 - 202ms/epoch - 11ms/step
# Epoch 466/500
# 19/19 - 0s - loss: 0.0330 - val_loss: 0.0371 - 196ms/epoch - 10ms/step
# Epoch 467/500
# 19/19 - 0s - loss: 0.0330 - val_loss: 0.0371 - 176ms/epoch - 9ms/step
# Epoch 468/500
# 19/19 - 0s - loss: 0.0329 - val_loss: 0.0370 - 193ms/epoch - 10ms/step
# Epoch 469/500
# 19/19 - 0s - loss: 0.0329 - val_loss: 0.0369 - 196ms/epoch - 10ms/step
# Epoch 470/500
# 19/19 - 0s - loss: 0.0329 - val_loss: 0.0369 - 197ms/epoch - 10ms/step
# Epoch 471/500
# 19/19 - 0s - loss: 0.0328 - val_loss: 0.0368 - 196ms/epoch - 10ms/step
# Epoch 472/500
# 19/19 - 0s - loss: 0.0328 - val_loss: 0.0368 - 180ms/epoch - 9ms/step
# Epoch 473/500
# 19/19 - 0s - loss: 0.0328 - val_loss: 0.0368 - 165ms/epoch - 9ms/step
# Epoch 474/500
# 19/19 - 0s - loss: 0.0330 - val_loss: 0.0373 - 191ms/epoch - 10ms/step
# Epoch 475/500
# 19/19 - 0s - loss: 0.0342 - val_loss: 0.0403 - 188ms/epoch - 10ms/step
# Epoch 476/500
# 19/19 - 0s - loss: 0.0392 - val_loss: 0.0546 - 199ms/epoch - 10ms/step
# Epoch 477/500
# 19/19 - 0s - loss: 0.0412 - val_loss: 0.0490 - 226ms/epoch - 12ms/step
# Epoch 478/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0379 - 201ms/epoch - 11ms/step
# Epoch 479/500
# 19/19 - 0s - loss: 0.0331 - val_loss: 0.0372 - 170ms/epoch - 9ms/step
# Epoch 480/500
# 19/19 - 0s - loss: 0.0330 - val_loss: 0.0371 - 191ms/epoch - 10ms/step
# Epoch 481/500
# 19/19 - 0s - loss: 0.0327 - val_loss: 0.0366 - 209ms/epoch - 11ms/step
# Epoch 482/500
# 19/19 - 0s - loss: 0.0328 - val_loss: 0.0370 - 182ms/epoch - 10ms/step
# Epoch 483/500
# 19/19 - 0s - loss: 0.0327 - val_loss: 0.0369 - 179ms/epoch - 9ms/step
# Epoch 484/500
# 19/19 - 0s - loss: 0.0334 - val_loss: 0.0382 - 266ms/epoch - 14ms/step
# Epoch 485/500
# 19/19 - 0s - loss: 0.0343 - val_loss: 0.0405 - 176ms/epoch - 9ms/step
# Epoch 486/500
# 19/19 - 0s - loss: 0.0383 - val_loss: 0.0499 - 179ms/epoch - 9ms/step
# Epoch 487/500
# 19/19 - 0s - loss: 0.0448 - val_loss: 0.0657 - 219ms/epoch - 12ms/step
# Epoch 488/500
# 19/19 - 0s - loss: 0.0429 - val_loss: 0.0488 - 198ms/epoch - 10ms/step
# Epoch 489/500
# 19/19 - 0s - loss: 0.0343 - val_loss: 0.0376 - 186ms/epoch - 10ms/step
# Epoch 490/500
# 19/19 - 0s - loss: 0.0332 - val_loss: 0.0376 - 176ms/epoch - 9ms/step
# Epoch 491/500
# 19/19 - 0s - loss: 0.0336 - val_loss: 0.0382 - 172ms/epoch - 9ms/step
# Epoch 492/500
# 19/19 - 0s - loss: 0.0329 - val_loss: 0.0369 - 171ms/epoch - 9ms/step
# Epoch 493/500
# 19/19 - 0s - loss: 0.0334 - val_loss: 0.0381 - 233ms/epoch - 12ms/step
# Epoch 494/500
# 19/19 - 0s - loss: 0.0332 - val_loss: 0.0379 - 177ms/epoch - 9ms/step
# Epoch 495/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0407 - 161ms/epoch - 8ms/step
# Epoch 496/500
# 19/19 - 0s - loss: 0.0355 - val_loss: 0.0434 - 167ms/epoch - 9ms/step
# Epoch 497/500
# 19/19 - 0s - loss: 0.0395 - val_loss: 0.0520 - 182ms/epoch - 10ms/step
# Epoch 498/500
# 19/19 - 0s - loss: 0.0414 - val_loss: 0.0552 - 199ms/epoch - 10ms/step
# Epoch 499/500
# 19/19 - 0s - loss: 0.0388 - val_loss: 0.0448 - 200ms/epoch - 11ms/step
# Epoch 500/500
# 19/19 - 0s - loss: 0.0333 - val_loss: 0.0361 - 188ms/epoch - 10ms/step

# %% [markdown]
# ## Metrics ($LPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 10/10 [==============================] - 2s 4ms/step
# (290, 3)
# (290, 10)
# Test RMSE: 7.999
# Test MAE: 6.933

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('New Delhi Daily Wind Speed', fontsize=20)
plt.legend(fontsize=20)
plt.show()
