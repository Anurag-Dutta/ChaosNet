# %% [markdown]
# # Time Series Prediction with Lorrenz Attractor Inspired Deep Learning ($LPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-11 19:46:15

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _EL NINO_

# %%
data = pd.read_csv("datasets/elnino.csv")
training_set = data.iloc[:, 1]
print(training_set)
# Out:
# 0       23.4
# 1       23.4
# 2       24.2
# 3       24.4
# 4       25.1
#         ...
# 1629    25.4
# 1630    24.9
# 1631    25.3
# 1632    24.7
# 1633    24.6
# Name: SST1, Length: 1634, dtype: float64

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 7 # Weekly Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 29.2
# 1       0.000000
# 2       0.114286
# 3       0.028571
# 4       0.100000
# 5       0.100000
#           ...
# 1629   -0.242857
# 1630   -0.071429
# 1631    0.057143
# 1632   -0.085714
# 1633   -0.014286
# Name: SST1, Length: 1633, dtype: float64
# 2       1.632653e-02
# 3      -1.224490e-02
# 4       1.020408e-02
# 5      -7.335402e-17
# 6      -1.224490e-02
#             ...
# 1629   -2.857143e-02
# 1630    2.448980e-02
# 1631    1.836735e-02
# 1632   -2.040816e-02
# 1633    1.020408e-02
# Name: SST1, Length: 1632, dtype: float64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0       0.000000
# 1       0.114286
# 2       0.028571
# 3       0.100000
# 4       0.100000
#           ...
# 1628   -0.242857
# 1629   -0.071429
# 1630    0.057143
# 1631   -0.085714
# 1632   -0.014286
# Name: SST1, Length: 1633, dtype: float64
# 0       1.632653e-02
# 1      -1.224490e-02
# 2       1.020408e-02
# 3      -7.335402e-17
# 4      -1.224490e-02
#             ...
# 1627   -2.857143e-02
# 1628    2.448980e-02
# 1629    1.836735e-02
# 1630   -2.040816e-02
# 1631    1.020408e-02
# Name: SST1, Length: 1632, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (1633,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lorrenz Equation_)

# %% [markdown]
# _Parameters_: $\sigma=10, \rho=28$

# %%
s=10
r=28
L = df.iloc[:, 2] + df.iloc[:, 1]*(1 + s) - df.iloc[:, 0] * s * (r - 1)
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10        23.4       23.4       24.2       24.4       25.1       25.8
# 11        23.4       24.2       24.4       25.1       25.8       25.9
# 12        24.2       24.4       25.1       25.8       25.9       26.1
# 13        24.4       25.1       25.8       25.9       26.1       26.1
# 14        25.1       25.8       25.9       26.1       26.1       26.7
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)   var2(t)   var3(t)
# 10       25.9       26.1       26.1       26.7     26.1  0.000000 -0.008163
# 11       26.1       26.1       26.7       26.1     26.1 -0.057143  0.006122
# 12       26.1       26.7       26.1       26.1     25.7 -0.014286 -0.008163
# 13       26.7       26.1       26.1       25.7     25.6 -0.071429  0.014286
# 14       26.1       26.1       25.7       25.6     25.1  0.028571 -0.008163
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (1622, 13)
# (1622, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (1297, 1, 10) (1297, 3) (325, 1, 10) (325, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
s = tf.Variable(10, name="sigma", trainable=True, dtype=tf.float32)
r = tf.Variable(28, name="rhow", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] + y_true[:, 1]*(1 + s) - y_true[:, 0] * s * (r - 1)), (y_pred[:, 2] + y_pred[:, 1]*(1 + s) - y_pred[:, 0] * s * (r - 1)))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] + (y_pred[1:-1]-y_pred[:-2])*(1 + s) - y_pred[:-2] * s * (r - 1)
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] + (y_real[1:-1]-y_real[:-2])*(1 + s) - y_real[:-2] * s * (r - 1)
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($LPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square((y_pred[:, 2] + y_pred[:, 1]*(1 + s) - y_pred[:, 0] * s * (r - 1)))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 21/21 - 6s - loss: 6.4877 - val_loss: 2.0779 - 6s/epoch - 292ms/step
# Epoch 2/500
# 21/21 - 0s - loss: 0.7929 - val_loss: 0.6543 - 116ms/epoch - 6ms/step
# Epoch 3/500
# 21/21 - 0s - loss: 0.4450 - val_loss: 0.4415 - 119ms/epoch - 6ms/step
# Epoch 4/500
# 21/21 - 0s - loss: 0.3919 - val_loss: 0.4357 - 129ms/epoch - 6ms/step
# Epoch 5/500
# 21/21 - 0s - loss: 0.3800 - val_loss: 0.4243 - 138ms/epoch - 7ms/step
# Epoch 6/500
# 21/21 - 0s - loss: 0.3717 - val_loss: 0.4166 - 131ms/epoch - 6ms/step
# Epoch 7/500
# 21/21 - 0s - loss: 0.3648 - val_loss: 0.4099 - 123ms/epoch - 6ms/step
# Epoch 8/500
# 21/21 - 0s - loss: 0.3583 - val_loss: 0.4030 - 131ms/epoch - 6ms/step
# Epoch 9/500
# 21/21 - 0s - loss: 0.3518 - val_loss: 0.3965 - 140ms/epoch - 7ms/step
# Epoch 10/500
# 21/21 - 0s - loss: 0.3458 - val_loss: 0.3903 - 128ms/epoch - 6ms/step
# Epoch 11/500
# 21/21 - 0s - loss: 0.3400 - val_loss: 0.3844 - 109ms/epoch - 5ms/step
# Epoch 12/500
# 21/21 - 0s - loss: 0.3346 - val_loss: 0.3788 - 120ms/epoch - 6ms/step
# Epoch 13/500
# 21/21 - 0s - loss: 0.3295 - val_loss: 0.3737 - 120ms/epoch - 6ms/step
# Epoch 14/500
# 21/21 - 0s - loss: 0.3247 - val_loss: 0.3688 - 124ms/epoch - 6ms/step
# Epoch 15/500
# 21/21 - 0s - loss: 0.3203 - val_loss: 0.3642 - 126ms/epoch - 6ms/step
# Epoch 16/500
# 21/21 - 0s - loss: 0.3162 - val_loss: 0.3600 - 121ms/epoch - 6ms/step
# Epoch 17/500
# 21/21 - 0s - loss: 0.3123 - val_loss: 0.3559 - 128ms/epoch - 6ms/step
# Epoch 18/500
# 21/21 - 0s - loss: 0.3087 - val_loss: 0.3520 - 168ms/epoch - 8ms/step
# Epoch 19/500
# 21/21 - 0s - loss: 0.3052 - val_loss: 0.3483 - 163ms/epoch - 8ms/step
# Epoch 20/500
# 21/21 - 0s - loss: 0.3020 - val_loss: 0.3447 - 125ms/epoch - 6ms/step
# Epoch 21/500
# 21/21 - 0s - loss: 0.2989 - val_loss: 0.3412 - 151ms/epoch - 7ms/step
# Epoch 22/500
# 21/21 - 0s - loss: 0.2959 - val_loss: 0.3378 - 136ms/epoch - 6ms/step
# Epoch 23/500
# 21/21 - 0s - loss: 0.2930 - val_loss: 0.3346 - 176ms/epoch - 8ms/step
# Epoch 24/500
# 21/21 - 0s - loss: 0.2903 - val_loss: 0.3316 - 142ms/epoch - 7ms/step
# Epoch 25/500
# 21/21 - 0s - loss: 0.2878 - val_loss: 0.3287 - 192ms/epoch - 9ms/step
# Epoch 26/500
# 21/21 - 0s - loss: 0.2853 - val_loss: 0.3260 - 138ms/epoch - 7ms/step
# Epoch 27/500
# 21/21 - 0s - loss: 0.2830 - val_loss: 0.3234 - 149ms/epoch - 7ms/step
# Epoch 28/500
# 21/21 - 0s - loss: 0.2808 - val_loss: 0.3210 - 120ms/epoch - 6ms/step
# Epoch 29/500
# 21/21 - 0s - loss: 0.2787 - val_loss: 0.3186 - 127ms/epoch - 6ms/step
# Epoch 30/500
# 21/21 - 0s - loss: 0.2767 - val_loss: 0.3162 - 117ms/epoch - 6ms/step
# Epoch 31/500
# 21/21 - 0s - loss: 0.2747 - val_loss: 0.3140 - 128ms/epoch - 6ms/step
# Epoch 32/500
# 21/21 - 0s - loss: 0.2729 - val_loss: 0.3118 - 216ms/epoch - 10ms/step
# Epoch 33/500
# 21/21 - 0s - loss: 0.2710 - val_loss: 0.3097 - 149ms/epoch - 7ms/step
# Epoch 34/500
# 21/21 - 0s - loss: 0.2693 - val_loss: 0.3077 - 152ms/epoch - 7ms/step
# Epoch 35/500
# 21/21 - 0s - loss: 0.2676 - val_loss: 0.3057 - 120ms/epoch - 6ms/step
# Epoch 36/500
# 21/21 - 0s - loss: 0.2660 - val_loss: 0.3038 - 119ms/epoch - 6ms/step
# Epoch 37/500
# 21/21 - 0s - loss: 0.2644 - val_loss: 0.3020 - 127ms/epoch - 6ms/step
# Epoch 38/500
# 21/21 - 0s - loss: 0.2629 - val_loss: 0.3002 - 124ms/epoch - 6ms/step
# Epoch 39/500
# 21/21 - 0s - loss: 0.2614 - val_loss: 0.2985 - 124ms/epoch - 6ms/step
# Epoch 40/500
# 21/21 - 0s - loss: 0.2600 - val_loss: 0.2968 - 132ms/epoch - 6ms/step
# Epoch 41/500
# 21/21 - 0s - loss: 0.2586 - val_loss: 0.2952 - 128ms/epoch - 6ms/step
# Epoch 42/500
# 21/21 - 0s - loss: 0.2573 - val_loss: 0.2937 - 126ms/epoch - 6ms/step
# Epoch 43/500
# 21/21 - 0s - loss: 0.2561 - val_loss: 0.2922 - 127ms/epoch - 6ms/step
# Epoch 44/500
# 21/21 - 0s - loss: 0.2549 - val_loss: 0.2908 - 129ms/epoch - 6ms/step
# Epoch 45/500
# 21/21 - 0s - loss: 0.2537 - val_loss: 0.2894 - 111ms/epoch - 5ms/step
# Epoch 46/500
# 21/21 - 0s - loss: 0.2527 - val_loss: 0.2881 - 111ms/epoch - 5ms/step
# Epoch 47/500
# 21/21 - 0s - loss: 0.2516 - val_loss: 0.2869 - 112ms/epoch - 5ms/step
# Epoch 48/500
# 21/21 - 0s - loss: 0.2507 - val_loss: 0.2857 - 114ms/epoch - 5ms/step
# Epoch 49/500
# 21/21 - 0s - loss: 0.2498 - val_loss: 0.2845 - 125ms/epoch - 6ms/step
# Epoch 50/500
# 21/21 - 0s - loss: 0.2489 - val_loss: 0.2835 - 132ms/epoch - 6ms/step
# Epoch 51/500
# 21/21 - 0s - loss: 0.2481 - val_loss: 0.2824 - 122ms/epoch - 6ms/step
# Epoch 52/500
# 21/21 - 0s - loss: 0.2474 - val_loss: 0.2815 - 126ms/epoch - 6ms/step
# Epoch 53/500
# 21/21 - 0s - loss: 0.2468 - val_loss: 0.2806 - 149ms/epoch - 7ms/step
# Epoch 54/500
# 21/21 - 0s - loss: 0.2462 - val_loss: 0.2797 - 128ms/epoch - 6ms/step
# Epoch 55/500
# 21/21 - 0s - loss: 0.2457 - val_loss: 0.2790 - 131ms/epoch - 6ms/step
# Epoch 56/500
# 21/21 - 0s - loss: 0.2453 - val_loss: 0.2783 - 124ms/epoch - 6ms/step
# Epoch 57/500
# 21/21 - 0s - loss: 0.2449 - val_loss: 0.2778 - 124ms/epoch - 6ms/step
# Epoch 58/500
# 21/21 - 0s - loss: 0.2445 - val_loss: 0.2775 - 122ms/epoch - 6ms/step
# Epoch 59/500
# 21/21 - 0s - loss: 0.2441 - val_loss: 0.2774 - 136ms/epoch - 6ms/step
# Epoch 60/500
# 21/21 - 0s - loss: 0.2437 - val_loss: 0.2776 - 145ms/epoch - 7ms/step
# Epoch 61/500
# 21/21 - 0s - loss: 0.2431 - val_loss: 0.2779 - 130ms/epoch - 6ms/step
# Epoch 62/500
# 21/21 - 0s - loss: 0.2424 - val_loss: 0.2782 - 138ms/epoch - 7ms/step
# Epoch 63/500
# 21/21 - 0s - loss: 0.2416 - val_loss: 0.2782 - 133ms/epoch - 6ms/step
# Epoch 64/500
# 21/21 - 0s - loss: 0.2408 - val_loss: 0.2777 - 177ms/epoch - 8ms/step
# Epoch 65/500
# 21/21 - 0s - loss: 0.2401 - val_loss: 0.2768 - 280ms/epoch - 13ms/step
# Epoch 66/500
# 21/21 - 0s - loss: 0.2395 - val_loss: 0.2759 - 177ms/epoch - 8ms/step
# Epoch 67/500
# 21/21 - 0s - loss: 0.2390 - val_loss: 0.2750 - 155ms/epoch - 7ms/step
# Epoch 68/500
# 21/21 - 0s - loss: 0.2386 - val_loss: 0.2743 - 118ms/epoch - 6ms/step
# Epoch 69/500
# 21/21 - 0s - loss: 0.2382 - val_loss: 0.2736 - 122ms/epoch - 6ms/step
# Epoch 70/500
# 21/21 - 0s - loss: 0.2378 - val_loss: 0.2730 - 147ms/epoch - 7ms/step
# Epoch 71/500
# 21/21 - 0s - loss: 0.2375 - val_loss: 0.2725 - 132ms/epoch - 6ms/step
# Epoch 72/500
# 21/21 - 0s - loss: 0.2372 - val_loss: 0.2720 - 129ms/epoch - 6ms/step
# Epoch 73/500
# 21/21 - 0s - loss: 0.2370 - val_loss: 0.2716 - 136ms/epoch - 6ms/step
# Epoch 74/500
# 21/21 - 0s - loss: 0.2367 - val_loss: 0.2712 - 131ms/epoch - 6ms/step
# Epoch 75/500
# 21/21 - 0s - loss: 0.2365 - val_loss: 0.2708 - 203ms/epoch - 10ms/step
# Epoch 76/500
# 21/21 - 0s - loss: 0.2363 - val_loss: 0.2705 - 141ms/epoch - 7ms/step
# Epoch 77/500
# 21/21 - 0s - loss: 0.2361 - val_loss: 0.2702 - 151ms/epoch - 7ms/step
# Epoch 78/500
# 21/21 - 0s - loss: 0.2359 - val_loss: 0.2699 - 130ms/epoch - 6ms/step
# Epoch 79/500
# 21/21 - 0s - loss: 0.2357 - val_loss: 0.2697 - 122ms/epoch - 6ms/step
# Epoch 80/500
# 21/21 - 0s - loss: 0.2355 - val_loss: 0.2694 - 191ms/epoch - 9ms/step
# Epoch 81/500
# 21/21 - 0s - loss: 0.2354 - val_loss: 0.2692 - 314ms/epoch - 15ms/step
# Epoch 82/500
# 21/21 - 0s - loss: 0.2352 - val_loss: 0.2689 - 235ms/epoch - 11ms/step
# Epoch 83/500
# 21/21 - 0s - loss: 0.2351 - val_loss: 0.2687 - 153ms/epoch - 7ms/step
# Epoch 84/500
# 21/21 - 0s - loss: 0.2349 - val_loss: 0.2685 - 144ms/epoch - 7ms/step
# Epoch 85/500
# 21/21 - 0s - loss: 0.2348 - val_loss: 0.2682 - 142ms/epoch - 7ms/step
# Epoch 86/500
# 21/21 - 0s - loss: 0.2347 - val_loss: 0.2680 - 179ms/epoch - 9ms/step
# Epoch 87/500
# 21/21 - 0s - loss: 0.2346 - val_loss: 0.2678 - 183ms/epoch - 9ms/step
# Epoch 88/500
# 21/21 - 0s - loss: 0.2345 - val_loss: 0.2676 - 224ms/epoch - 11ms/step
# Epoch 89/500
# 21/21 - 0s - loss: 0.2344 - val_loss: 0.2674 - 181ms/epoch - 9ms/step
# Epoch 90/500
# 21/21 - 0s - loss: 0.2344 - val_loss: 0.2673 - 228ms/epoch - 11ms/step
# Epoch 91/500
# 21/21 - 0s - loss: 0.2343 - val_loss: 0.2671 - 259ms/epoch - 12ms/step
# Epoch 92/500
# 21/21 - 0s - loss: 0.2342 - val_loss: 0.2670 - 235ms/epoch - 11ms/step
# Epoch 93/500
# 21/21 - 0s - loss: 0.2341 - val_loss: 0.2668 - 202ms/epoch - 10ms/step
# Epoch 94/500
# 21/21 - 0s - loss: 0.2340 - val_loss: 0.2666 - 191ms/epoch - 9ms/step
# Epoch 95/500
# 21/21 - 0s - loss: 0.2338 - val_loss: 0.2665 - 180ms/epoch - 9ms/step
# Epoch 96/500
# 21/21 - 0s - loss: 0.2336 - val_loss: 0.2668 - 202ms/epoch - 10ms/step
# Epoch 97/500
# 21/21 - 0s - loss: 0.2335 - val_loss: 0.2675 - 212ms/epoch - 10ms/step
# Epoch 98/500
# 21/21 - 0s - loss: 0.2334 - val_loss: 0.2682 - 265ms/epoch - 13ms/step
# Epoch 99/500
# 21/21 - 0s - loss: 0.2332 - val_loss: 0.2681 - 236ms/epoch - 11ms/step
# Epoch 100/500
# 21/21 - 0s - loss: 0.2329 - val_loss: 0.2672 - 224ms/epoch - 11ms/step
# Epoch 101/500
# 21/21 - 0s - loss: 0.2327 - val_loss: 0.2668 - 240ms/epoch - 11ms/step
# Epoch 102/500
# 21/21 - 0s - loss: 0.2327 - val_loss: 0.2673 - 236ms/epoch - 11ms/step
# Epoch 103/500
# 21/21 - 0s - loss: 0.2326 - val_loss: 0.2679 - 203ms/epoch - 10ms/step
# Epoch 104/500
# 21/21 - 0s - loss: 0.2324 - val_loss: 0.2674 - 174ms/epoch - 8ms/step
# Epoch 105/500
# 21/21 - 0s - loss: 0.2323 - val_loss: 0.2670 - 167ms/epoch - 8ms/step
# Epoch 106/500
# 21/21 - 0s - loss: 0.2321 - val_loss: 0.2674 - 187ms/epoch - 9ms/step
# Epoch 107/500
# 21/21 - 0s - loss: 0.2321 - val_loss: 0.2674 - 174ms/epoch - 8ms/step
# Epoch 108/500
# 21/21 - 0s - loss: 0.2320 - val_loss: 0.2674 - 202ms/epoch - 10ms/step
# Epoch 109/500
# 21/21 - 2s - loss: 0.2319 - val_loss: 0.2676 - 2s/epoch - 73ms/step
# Epoch 110/500
# 21/21 - 0s - loss: 0.2319 - val_loss: 0.2678 - 348ms/epoch - 17ms/step
# Epoch 111/500
# 21/21 - 0s - loss: 0.2319 - val_loss: 0.2682 - 392ms/epoch - 19ms/step
# Epoch 112/500
# 21/21 - 0s - loss: 0.2320 - val_loss: 0.2685 - 379ms/epoch - 18ms/step
# Epoch 113/500
# 21/21 - 0s - loss: 0.2320 - val_loss: 0.2692 - 302ms/epoch - 14ms/step
# Epoch 114/500
# 21/21 - 0s - loss: 0.2322 - val_loss: 0.2696 - 285ms/epoch - 14ms/step
# Epoch 115/500
# 21/21 - 0s - loss: 0.2323 - val_loss: 0.2707 - 337ms/epoch - 16ms/step
# Epoch 116/500
# 21/21 - 0s - loss: 0.2328 - val_loss: 0.2714 - 320ms/epoch - 15ms/step
# Epoch 117/500
# 21/21 - 0s - loss: 0.2328 - val_loss: 0.2728 - 255ms/epoch - 12ms/step
# Epoch 118/500
# 21/21 - 0s - loss: 0.2337 - val_loss: 0.2739 - 246ms/epoch - 12ms/step
# Epoch 119/500
# 21/21 - 0s - loss: 0.2335 - val_loss: 0.2753 - 220ms/epoch - 10ms/step
# Epoch 120/500
# 21/21 - 0s - loss: 0.2348 - val_loss: 0.2768 - 155ms/epoch - 7ms/step
# Epoch 121/500
# 21/21 - 0s - loss: 0.2343 - val_loss: 0.2778 - 184ms/epoch - 9ms/step
# Epoch 122/500
# 21/21 - 0s - loss: 0.2357 - val_loss: 0.2795 - 121ms/epoch - 6ms/step
# Epoch 123/500
# 21/21 - 0s - loss: 0.2352 - val_loss: 0.2800 - 135ms/epoch - 6ms/step
# Epoch 124/500
# 21/21 - 0s - loss: 0.2364 - val_loss: 0.2816 - 122ms/epoch - 6ms/step
# Epoch 125/500
# 21/21 - 0s - loss: 0.2358 - val_loss: 0.2816 - 138ms/epoch - 7ms/step
# Epoch 126/500
# 21/21 - 0s - loss: 0.2367 - val_loss: 0.2829 - 121ms/epoch - 6ms/step
# Epoch 127/500
# 21/21 - 0s - loss: 0.2363 - val_loss: 0.2828 - 127ms/epoch - 6ms/step
# Epoch 128/500
# 21/21 - 0s - loss: 0.2368 - val_loss: 0.2838 - 150ms/epoch - 7ms/step
# Epoch 129/500
# 21/21 - 0s - loss: 0.2365 - val_loss: 0.2837 - 164ms/epoch - 8ms/step
# Epoch 130/500
# 21/21 - 0s - loss: 0.2368 - val_loss: 0.2844 - 176ms/epoch - 8ms/step
# Epoch 131/500
# 21/21 - 0s - loss: 0.2367 - val_loss: 0.2844 - 154ms/epoch - 7ms/step
# Epoch 132/500
# 21/21 - 0s - loss: 0.2368 - val_loss: 0.2848 - 229ms/epoch - 11ms/step
# Epoch 133/500
# 21/21 - 0s - loss: 0.2367 - val_loss: 0.2848 - 151ms/epoch - 7ms/step
# Epoch 134/500
# 21/21 - 0s - loss: 0.2368 - val_loss: 0.2850 - 159ms/epoch - 8ms/step
# Epoch 135/500
# 21/21 - 0s - loss: 0.2367 - val_loss: 0.2850 - 164ms/epoch - 8ms/step
# Epoch 136/500
# 21/21 - 0s - loss: 0.2366 - val_loss: 0.2851 - 150ms/epoch - 7ms/step
# Epoch 137/500
# 21/21 - 0s - loss: 0.2365 - val_loss: 0.2851 - 195ms/epoch - 9ms/step
# Epoch 138/500
# 21/21 - 0s - loss: 0.2365 - val_loss: 0.2851 - 165ms/epoch - 8ms/step
# Epoch 139/500
# 21/21 - 0s - loss: 0.2364 - val_loss: 0.2851 - 140ms/epoch - 7ms/step
# Epoch 140/500
# 21/21 - 0s - loss: 0.2363 - val_loss: 0.2851 - 125ms/epoch - 6ms/step
# Epoch 141/500
# 21/21 - 0s - loss: 0.2361 - val_loss: 0.2850 - 146ms/epoch - 7ms/step
# Epoch 142/500
# 21/21 - 0s - loss: 0.2360 - val_loss: 0.2849 - 141ms/epoch - 7ms/step
# Epoch 143/500
# 21/21 - 0s - loss: 0.2359 - val_loss: 0.2848 - 135ms/epoch - 6ms/step
# Epoch 144/500
# 21/21 - 0s - loss: 0.2358 - val_loss: 0.2847 - 148ms/epoch - 7ms/step
# Epoch 145/500
# 21/21 - 0s - loss: 0.2356 - val_loss: 0.2846 - 163ms/epoch - 8ms/step
# Epoch 146/500
# 21/21 - 0s - loss: 0.2355 - val_loss: 0.2845 - 140ms/epoch - 7ms/step
# Epoch 147/500
# 21/21 - 0s - loss: 0.2353 - val_loss: 0.2844 - 137ms/epoch - 7ms/step
# Epoch 148/500
# 21/21 - 0s - loss: 0.2352 - val_loss: 0.2842 - 135ms/epoch - 6ms/step
# Epoch 149/500
# 21/21 - 0s - loss: 0.2350 - val_loss: 0.2841 - 128ms/epoch - 6ms/step
# Epoch 150/500
# 21/21 - 0s - loss: 0.2349 - val_loss: 0.2839 - 134ms/epoch - 6ms/step
# Epoch 151/500
# 21/21 - 0s - loss: 0.2347 - val_loss: 0.2838 - 135ms/epoch - 6ms/step
# Epoch 152/500
# 21/21 - 0s - loss: 0.2346 - val_loss: 0.2836 - 124ms/epoch - 6ms/step
# Epoch 153/500
# 21/21 - 0s - loss: 0.2344 - val_loss: 0.2834 - 133ms/epoch - 6ms/step
# Epoch 154/500
# 21/21 - 0s - loss: 0.2342 - val_loss: 0.2833 - 131ms/epoch - 6ms/step
# Epoch 155/500
# 21/21 - 0s - loss: 0.2340 - val_loss: 0.2831 - 131ms/epoch - 6ms/step
# Epoch 156/500
# 21/21 - 0s - loss: 0.2339 - val_loss: 0.2829 - 144ms/epoch - 7ms/step
# Epoch 157/500
# 21/21 - 0s - loss: 0.2337 - val_loss: 0.2827 - 134ms/epoch - 6ms/step
# Epoch 158/500
# 21/21 - 0s - loss: 0.2335 - val_loss: 0.2825 - 129ms/epoch - 6ms/step
# Epoch 159/500
# 21/21 - 0s - loss: 0.2333 - val_loss: 0.2823 - 142ms/epoch - 7ms/step
# Epoch 160/500
# 21/21 - 0s - loss: 0.2331 - val_loss: 0.2821 - 155ms/epoch - 7ms/step
# Epoch 161/500
# 21/21 - 0s - loss: 0.2330 - val_loss: 0.2819 - 139ms/epoch - 7ms/step
# Epoch 162/500
# 21/21 - 0s - loss: 0.2328 - val_loss: 0.2817 - 134ms/epoch - 6ms/step
# Epoch 163/500
# 21/21 - 0s - loss: 0.2326 - val_loss: 0.2815 - 140ms/epoch - 7ms/step
# Epoch 164/500
# 21/21 - 0s - loss: 0.2324 - val_loss: 0.2813 - 138ms/epoch - 7ms/step
# Epoch 165/500
# 21/21 - 0s - loss: 0.2322 - val_loss: 0.2811 - 133ms/epoch - 6ms/step
# Epoch 166/500
# 21/21 - 0s - loss: 0.2320 - val_loss: 0.2808 - 125ms/epoch - 6ms/step
# Epoch 167/500
# 21/21 - 0s - loss: 0.2318 - val_loss: 0.2806 - 122ms/epoch - 6ms/step
# Epoch 168/500
# 21/21 - 0s - loss: 0.2316 - val_loss: 0.2804 - 137ms/epoch - 7ms/step
# Epoch 169/500
# 21/21 - 0s - loss: 0.2314 - val_loss: 0.2801 - 137ms/epoch - 7ms/step
# Epoch 170/500
# 21/21 - 0s - loss: 0.2312 - val_loss: 0.2799 - 145ms/epoch - 7ms/step
# Epoch 171/500
# 21/21 - 0s - loss: 0.2310 - val_loss: 0.2797 - 159ms/epoch - 8ms/step
# Epoch 172/500
# 21/21 - 0s - loss: 0.2308 - val_loss: 0.2794 - 147ms/epoch - 7ms/step
# Epoch 173/500
# 21/21 - 0s - loss: 0.2306 - val_loss: 0.2792 - 135ms/epoch - 6ms/step
# Epoch 174/500
# 21/21 - 0s - loss: 0.2303 - val_loss: 0.2790 - 146ms/epoch - 7ms/step
# Epoch 175/500
# 21/21 - 0s - loss: 0.2301 - val_loss: 0.2787 - 162ms/epoch - 8ms/step
# Epoch 176/500
# 21/21 - 0s - loss: 0.2299 - val_loss: 0.2784 - 166ms/epoch - 8ms/step
# Epoch 177/500
# 21/21 - 0s - loss: 0.2297 - val_loss: 0.2782 - 155ms/epoch - 7ms/step
# Epoch 178/500
# 21/21 - 0s - loss: 0.2295 - val_loss: 0.2779 - 160ms/epoch - 8ms/step
# Epoch 179/500
# 21/21 - 0s - loss: 0.2292 - val_loss: 0.2777 - 119ms/epoch - 6ms/step
# Epoch 180/500
# 21/21 - 0s - loss: 0.2290 - val_loss: 0.2774 - 118ms/epoch - 6ms/step
# Epoch 181/500
# 21/21 - 0s - loss: 0.2288 - val_loss: 0.2771 - 119ms/epoch - 6ms/step
# Epoch 182/500
# 21/21 - 0s - loss: 0.2286 - val_loss: 0.2769 - 110ms/epoch - 5ms/step
# Epoch 183/500
# 21/21 - 0s - loss: 0.2283 - val_loss: 0.2766 - 147ms/epoch - 7ms/step
# Epoch 184/500
# 21/21 - 0s - loss: 0.2281 - val_loss: 0.2763 - 157ms/epoch - 7ms/step
# Epoch 185/500
# 21/21 - 0s - loss: 0.2279 - val_loss: 0.2760 - 139ms/epoch - 7ms/step
# Epoch 186/500
# 21/21 - 0s - loss: 0.2276 - val_loss: 0.2757 - 132ms/epoch - 6ms/step
# Epoch 187/500
# 21/21 - 0s - loss: 0.2274 - val_loss: 0.2755 - 130ms/epoch - 6ms/step
# Epoch 188/500
# 21/21 - 0s - loss: 0.2271 - val_loss: 0.2752 - 121ms/epoch - 6ms/step
# Epoch 189/500
# 21/21 - 0s - loss: 0.2269 - val_loss: 0.2749 - 121ms/epoch - 6ms/step
# Epoch 190/500
# 21/21 - 0s - loss: 0.2267 - val_loss: 0.2746 - 126ms/epoch - 6ms/step
# Epoch 191/500
# 21/21 - 0s - loss: 0.2264 - val_loss: 0.2743 - 134ms/epoch - 6ms/step
# Epoch 192/500
# 21/21 - 0s - loss: 0.2262 - val_loss: 0.2740 - 137ms/epoch - 7ms/step
# Epoch 193/500
# 21/21 - 0s - loss: 0.2259 - val_loss: 0.2737 - 120ms/epoch - 6ms/step
# Epoch 194/500
# 21/21 - 0s - loss: 0.2257 - val_loss: 0.2734 - 125ms/epoch - 6ms/step
# Epoch 195/500
# 21/21 - 0s - loss: 0.2254 - val_loss: 0.2731 - 137ms/epoch - 7ms/step
# Epoch 196/500
# 21/21 - 0s - loss: 0.2252 - val_loss: 0.2728 - 123ms/epoch - 6ms/step
# Epoch 197/500
# 21/21 - 0s - loss: 0.2249 - val_loss: 0.2725 - 119ms/epoch - 6ms/step
# Epoch 198/500
# 21/21 - 0s - loss: 0.2246 - val_loss: 0.2721 - 124ms/epoch - 6ms/step
# Epoch 199/500
# 21/21 - 0s - loss: 0.2244 - val_loss: 0.2718 - 128ms/epoch - 6ms/step
# Epoch 200/500
# 21/21 - 0s - loss: 0.2241 - val_loss: 0.2715 - 133ms/epoch - 6ms/step
# Epoch 201/500
# 21/21 - 0s - loss: 0.2239 - val_loss: 0.2712 - 136ms/epoch - 6ms/step
# Epoch 202/500
# 21/21 - 0s - loss: 0.2236 - val_loss: 0.2709 - 134ms/epoch - 6ms/step
# Epoch 203/500
# 21/21 - 0s - loss: 0.2233 - val_loss: 0.2705 - 142ms/epoch - 7ms/step
# Epoch 204/500
# 21/21 - 0s - loss: 0.2231 - val_loss: 0.2702 - 148ms/epoch - 7ms/step
# Epoch 205/500
# 21/21 - 0s - loss: 0.2228 - val_loss: 0.2699 - 129ms/epoch - 6ms/step
# Epoch 206/500
# 21/21 - 0s - loss: 0.2226 - val_loss: 0.2696 - 145ms/epoch - 7ms/step
# Epoch 207/500
# 21/21 - 0s - loss: 0.2223 - val_loss: 0.2693 - 146ms/epoch - 7ms/step
# Epoch 208/500
# 21/21 - 0s - loss: 0.2220 - val_loss: 0.2689 - 167ms/epoch - 8ms/step
# Epoch 209/500
# 21/21 - 0s - loss: 0.2218 - val_loss: 0.2686 - 207ms/epoch - 10ms/step
# Epoch 210/500
# 21/21 - 0s - loss: 0.2215 - val_loss: 0.2683 - 134ms/epoch - 6ms/step
# Epoch 211/500
# 21/21 - 0s - loss: 0.2212 - val_loss: 0.2680 - 126ms/epoch - 6ms/step
# Epoch 212/500
# 21/21 - 0s - loss: 0.2210 - val_loss: 0.2676 - 123ms/epoch - 6ms/step
# Epoch 213/500
# 21/21 - 0s - loss: 0.2207 - val_loss: 0.2673 - 139ms/epoch - 7ms/step
# Epoch 214/500
# 21/21 - 0s - loss: 0.2204 - val_loss: 0.2670 - 154ms/epoch - 7ms/step
# Epoch 215/500
# 21/21 - 0s - loss: 0.2202 - val_loss: 0.2667 - 140ms/epoch - 7ms/step
# Epoch 216/500
# 21/21 - 0s - loss: 0.2199 - val_loss: 0.2664 - 138ms/epoch - 7ms/step
# Epoch 217/500
# 21/21 - 0s - loss: 0.2197 - val_loss: 0.2661 - 131ms/epoch - 6ms/step
# Epoch 218/500
# 21/21 - 0s - loss: 0.2194 - val_loss: 0.2658 - 135ms/epoch - 6ms/step
# Epoch 219/500
# 21/21 - 0s - loss: 0.2191 - val_loss: 0.2654 - 143ms/epoch - 7ms/step
# Epoch 220/500
# 21/21 - 0s - loss: 0.2189 - val_loss: 0.2651 - 150ms/epoch - 7ms/step
# Epoch 221/500
# 21/21 - 0s - loss: 0.2186 - val_loss: 0.2648 - 152ms/epoch - 7ms/step
# Epoch 222/500
# 21/21 - 0s - loss: 0.2183 - val_loss: 0.2645 - 146ms/epoch - 7ms/step
# Epoch 223/500
# 21/21 - 0s - loss: 0.2181 - val_loss: 0.2641 - 131ms/epoch - 6ms/step
# Epoch 224/500
# 21/21 - 0s - loss: 0.2178 - val_loss: 0.2638 - 133ms/epoch - 6ms/step
# Epoch 225/500
# 21/21 - 0s - loss: 0.2175 - val_loss: 0.2636 - 127ms/epoch - 6ms/step
# Epoch 226/500
# 21/21 - 0s - loss: 0.2173 - val_loss: 0.2633 - 137ms/epoch - 7ms/step
# Epoch 227/500
# 21/21 - 0s - loss: 0.2170 - val_loss: 0.2630 - 131ms/epoch - 6ms/step
# Epoch 228/500
# 21/21 - 0s - loss: 0.2168 - val_loss: 0.2627 - 139ms/epoch - 7ms/step
# Epoch 229/500
# 21/21 - 0s - loss: 0.2165 - val_loss: 0.2624 - 132ms/epoch - 6ms/step
# Epoch 230/500
# 21/21 - 0s - loss: 0.2163 - val_loss: 0.2621 - 140ms/epoch - 7ms/step
# Epoch 231/500
# 21/21 - 0s - loss: 0.2160 - val_loss: 0.2617 - 158ms/epoch - 8ms/step
# Epoch 232/500
# 21/21 - 0s - loss: 0.2157 - val_loss: 0.2614 - 139ms/epoch - 7ms/step
# Epoch 233/500
# 21/21 - 0s - loss: 0.2154 - val_loss: 0.2611 - 154ms/epoch - 7ms/step
# Epoch 234/500
# 21/21 - 0s - loss: 0.2152 - val_loss: 0.2608 - 121ms/epoch - 6ms/step
# Epoch 235/500
# 21/21 - 0s - loss: 0.2149 - val_loss: 0.2606 - 117ms/epoch - 6ms/step
# Epoch 236/500
# 21/21 - 0s - loss: 0.2147 - val_loss: 0.2605 - 114ms/epoch - 5ms/step
# Epoch 237/500
# 21/21 - 0s - loss: 0.2145 - val_loss: 0.2603 - 111ms/epoch - 5ms/step
# Epoch 238/500
# 21/21 - 0s - loss: 0.2143 - val_loss: 0.2600 - 113ms/epoch - 5ms/step
# Epoch 239/500
# 21/21 - 0s - loss: 0.2140 - val_loss: 0.2596 - 115ms/epoch - 5ms/step
# Epoch 240/500
# 21/21 - 0s - loss: 0.2137 - val_loss: 0.2591 - 122ms/epoch - 6ms/step
# Epoch 241/500
# 21/21 - 0s - loss: 0.2133 - val_loss: 0.2586 - 130ms/epoch - 6ms/step
# Epoch 242/500
# 21/21 - 0s - loss: 0.2130 - val_loss: 0.2581 - 125ms/epoch - 6ms/step
# Epoch 243/500
# 21/21 - 0s - loss: 0.2126 - val_loss: 0.2578 - 129ms/epoch - 6ms/step
# Epoch 244/500
# 21/21 - 0s - loss: 0.2124 - val_loss: 0.2577 - 128ms/epoch - 6ms/step
# Epoch 245/500
# 21/21 - 0s - loss: 0.2123 - val_loss: 0.2579 - 126ms/epoch - 6ms/step
# Epoch 246/500
# 21/21 - 0s - loss: 0.2123 - val_loss: 0.2582 - 137ms/epoch - 7ms/step
# Epoch 247/500
# 21/21 - 0s - loss: 0.2123 - val_loss: 0.2584 - 136ms/epoch - 6ms/step
# Epoch 248/500
# 21/21 - 0s - loss: 0.2121 - val_loss: 0.2581 - 128ms/epoch - 6ms/step
# Epoch 249/500
# 21/21 - 0s - loss: 0.2117 - val_loss: 0.2573 - 130ms/epoch - 6ms/step
# Epoch 250/500
# 21/21 - 0s - loss: 0.2111 - val_loss: 0.2560 - 133ms/epoch - 6ms/step
# Epoch 251/500
# 21/21 - 0s - loss: 0.2104 - val_loss: 0.2545 - 134ms/epoch - 6ms/step
# Epoch 252/500
# 21/21 - 0s - loss: 0.2097 - val_loss: 0.2534 - 133ms/epoch - 6ms/step
# Epoch 253/500
# 21/21 - 0s - loss: 0.2092 - val_loss: 0.2530 - 141ms/epoch - 7ms/step
# Epoch 254/500
# 21/21 - 0s - loss: 0.2092 - val_loss: 0.2538 - 138ms/epoch - 7ms/step
# Epoch 255/500
# 21/21 - 0s - loss: 0.2096 - val_loss: 0.2557 - 129ms/epoch - 6ms/step
# Epoch 256/500
# 21/21 - 0s - loss: 0.2105 - val_loss: 0.2583 - 128ms/epoch - 6ms/step
# Epoch 257/500
# 21/21 - 0s - loss: 0.2114 - val_loss: 0.2604 - 158ms/epoch - 8ms/step
# Epoch 258/500
# 21/21 - 0s - loss: 0.2117 - val_loss: 0.2600 - 139ms/epoch - 7ms/step
# Epoch 259/500
# 21/21 - 0s - loss: 0.2106 - val_loss: 0.2562 - 141ms/epoch - 7ms/step
# Epoch 260/500
# 21/21 - 0s - loss: 0.2084 - val_loss: 0.2506 - 175ms/epoch - 8ms/step
# Epoch 261/500
# 21/21 - 0s - loss: 0.2059 - val_loss: 0.2452 - 152ms/epoch - 7ms/step
# Epoch 262/500
# 21/21 - 0s - loss: 0.2038 - val_loss: 0.2416 - 152ms/epoch - 7ms/step
# Epoch 263/500
# 21/21 - 0s - loss: 0.2026 - val_loss: 0.2403 - 158ms/epoch - 8ms/step
# Epoch 264/500
# 21/21 - 0s - loss: 0.2025 - val_loss: 0.2420 - 253ms/epoch - 12ms/step
# Epoch 265/500
# 21/21 - 0s - loss: 0.2040 - val_loss: 0.2487 - 171ms/epoch - 8ms/step
# Epoch 266/500
# 21/21 - 0s - loss: 0.2086 - val_loss: 0.2641 - 169ms/epoch - 8ms/step
# Epoch 267/500
# 21/21 - 0s - loss: 0.2179 - val_loss: 0.2878 - 161ms/epoch - 8ms/step
# Epoch 268/500
# 21/21 - 0s - loss: 0.2259 - val_loss: 0.2926 - 149ms/epoch - 7ms/step
# Epoch 269/500
# 21/21 - 0s - loss: 0.2165 - val_loss: 0.2575 - 158ms/epoch - 8ms/step
# Epoch 270/500
# 21/21 - 0s - loss: 0.2036 - val_loss: 0.2328 - 150ms/epoch - 7ms/step
# Epoch 271/500
# 21/21 - 0s - loss: 0.1972 - val_loss: 0.2241 - 150ms/epoch - 7ms/step
# Epoch 272/500
# 21/21 - 0s - loss: 0.1950 - val_loss: 0.2224 - 147ms/epoch - 7ms/step
# Epoch 273/500
# 21/21 - 0s - loss: 0.1960 - val_loss: 0.2297 - 152ms/epoch - 7ms/step
# Epoch 274/500
# 21/21 - 0s - loss: 0.2032 - val_loss: 0.2566 - 144ms/epoch - 7ms/step
# Epoch 275/500
# 21/21 - 0s - loss: 0.2246 - val_loss: 0.3146 - 154ms/epoch - 7ms/step
# Epoch 276/500
# 21/21 - 0s - loss: 0.2425 - val_loss: 0.3096 - 142ms/epoch - 7ms/step
# Epoch 277/500
# 21/21 - 0s - loss: 0.2121 - val_loss: 0.2437 - 143ms/epoch - 7ms/step
# Epoch 278/500
# 21/21 - 0s - loss: 0.1992 - val_loss: 0.2321 - 152ms/epoch - 7ms/step
# Epoch 279/500
# 21/21 - 0s - loss: 0.1952 - val_loss: 0.2239 - 142ms/epoch - 7ms/step
# Epoch 280/500
# 21/21 - 0s - loss: 0.1929 - val_loss: 0.2222 - 133ms/epoch - 6ms/step
# Epoch 281/500
# 21/21 - 0s - loss: 0.1921 - val_loss: 0.2219 - 138ms/epoch - 7ms/step
# Epoch 282/500
# 21/21 - 0s - loss: 0.1923 - val_loss: 0.2239 - 141ms/epoch - 7ms/step
# Epoch 283/500
# 21/21 - 0s - loss: 0.1940 - val_loss: 0.2305 - 181ms/epoch - 9ms/step
# Epoch 284/500
# 21/21 - 0s - loss: 0.1993 - val_loss: 0.2490 - 147ms/epoch - 7ms/step
# Epoch 285/500
# 21/21 - 0s - loss: 0.2130 - val_loss: 0.2883 - 146ms/epoch - 7ms/step
# Epoch 286/500
# 21/21 - 0s - loss: 0.2308 - val_loss: 0.3084 - 140ms/epoch - 7ms/step
# Epoch 287/500
# 21/21 - 0s - loss: 0.2155 - val_loss: 0.2545 - 130ms/epoch - 6ms/step
# Epoch 288/500
# 21/21 - 0s - loss: 0.1989 - val_loss: 0.2295 - 130ms/epoch - 6ms/step
# Epoch 289/500
# 21/21 - 0s - loss: 0.1930 - val_loss: 0.2221 - 131ms/epoch - 6ms/step
# Epoch 290/500
# 21/21 - 0s - loss: 0.1904 - val_loss: 0.2179 - 113ms/epoch - 5ms/step
# Epoch 291/500
# 21/21 - 0s - loss: 0.1889 - val_loss: 0.2165 - 104ms/epoch - 5ms/step
# Epoch 292/500
# 21/21 - 0s - loss: 0.1882 - val_loss: 0.2159 - 106ms/epoch - 5ms/step
# Epoch 293/500
# 21/21 - 0s - loss: 0.1877 - val_loss: 0.2155 - 103ms/epoch - 5ms/step
# Epoch 294/500
# 21/21 - 0s - loss: 0.1874 - val_loss: 0.2153 - 128ms/epoch - 6ms/step
# Epoch 295/500
# 21/21 - 0s - loss: 0.1873 - val_loss: 0.2158 - 119ms/epoch - 6ms/step
# Epoch 296/500
# 21/21 - 0s - loss: 0.1879 - val_loss: 0.2195 - 131ms/epoch - 6ms/step
# Epoch 297/500
# 21/21 - 0s - loss: 0.1919 - val_loss: 0.2369 - 142ms/epoch - 7ms/step
# Epoch 298/500
# 21/21 - 0s - loss: 0.2111 - val_loss: 0.3137 - 161ms/epoch - 8ms/step
# Epoch 299/500
# 21/21 - 0s - loss: 0.2960 - val_loss: 0.5015 - 156ms/epoch - 7ms/step
# Epoch 300/500
# 21/21 - 0s - loss: 0.2559 - val_loss: 0.2419 - 154ms/epoch - 7ms/step
# Epoch 301/500
# 21/21 - 0s - loss: 0.2202 - val_loss: 0.2349 - 147ms/epoch - 7ms/step
# Epoch 302/500
# 21/21 - 0s - loss: 0.2127 - val_loss: 0.2239 - 149ms/epoch - 7ms/step
# Epoch 303/500
# 21/21 - 0s - loss: 0.2341 - val_loss: 0.2381 - 169ms/epoch - 8ms/step
# Epoch 304/500
# 21/21 - 0s - loss: 0.2477 - val_loss: 0.3367 - 141ms/epoch - 7ms/step
# Epoch 305/500
# 21/21 - 0s - loss: 0.2388 - val_loss: 0.3204 - 131ms/epoch - 6ms/step
# Epoch 306/500
# 21/21 - 0s - loss: 0.2062 - val_loss: 0.2146 - 137ms/epoch - 7ms/step
# Epoch 307/500
# 21/21 - 0s - loss: 0.1907 - val_loss: 0.2280 - 148ms/epoch - 7ms/step
# Epoch 308/500
# 21/21 - 0s - loss: 0.1888 - val_loss: 0.2174 - 146ms/epoch - 7ms/step
# Epoch 309/500
# 21/21 - 0s - loss: 0.1854 - val_loss: 0.2124 - 130ms/epoch - 6ms/step
# Epoch 310/500
# 21/21 - 0s - loss: 0.1845 - val_loss: 0.2122 - 136ms/epoch - 6ms/step
# Epoch 311/500
# 21/21 - 0s - loss: 0.1840 - val_loss: 0.2115 - 134ms/epoch - 6ms/step
# Epoch 312/500
# 21/21 - 0s - loss: 0.1836 - val_loss: 0.2110 - 147ms/epoch - 7ms/step
# Epoch 313/500
# 21/21 - 0s - loss: 0.1834 - val_loss: 0.2108 - 144ms/epoch - 7ms/step
# Epoch 314/500
# 21/21 - 0s - loss: 0.1832 - val_loss: 0.2104 - 151ms/epoch - 7ms/step
# Epoch 315/500
# 21/21 - 0s - loss: 0.1831 - val_loss: 0.2102 - 135ms/epoch - 6ms/step
# Epoch 316/500
# 21/21 - 0s - loss: 0.1830 - val_loss: 0.2098 - 246ms/epoch - 12ms/step
# Epoch 317/500
# 21/21 - 0s - loss: 0.1830 - val_loss: 0.2095 - 157ms/epoch - 7ms/step
# Epoch 318/500
# 21/21 - 0s - loss: 0.1827 - val_loss: 0.2093 - 145ms/epoch - 7ms/step
# Epoch 319/500
# 21/21 - 0s - loss: 0.1823 - val_loss: 0.2089 - 134ms/epoch - 6ms/step
# Epoch 320/500
# 21/21 - 0s - loss: 0.1817 - val_loss: 0.2088 - 131ms/epoch - 6ms/step
# Epoch 321/500
# 21/21 - 0s - loss: 0.1812 - val_loss: 0.2082 - 156ms/epoch - 7ms/step
# Epoch 322/500
# 21/21 - 0s - loss: 0.1808 - val_loss: 0.2081 - 134ms/epoch - 6ms/step
# Epoch 323/500
# 21/21 - 0s - loss: 0.1806 - val_loss: 0.2081 - 131ms/epoch - 6ms/step
# Epoch 324/500
# 21/21 - 0s - loss: 0.1806 - val_loss: 0.2087 - 137ms/epoch - 7ms/step
# Epoch 325/500
# 21/21 - 0s - loss: 0.1810 - val_loss: 0.2114 - 136ms/epoch - 6ms/step
# Epoch 326/500
# 21/21 - 0s - loss: 0.1834 - val_loss: 0.2215 - 140ms/epoch - 7ms/step
# Epoch 327/500
# 21/21 - 0s - loss: 0.1928 - val_loss: 0.2578 - 146ms/epoch - 7ms/step
# Epoch 328/500
# 21/21 - 0s - loss: 0.2251 - val_loss: 0.3517 - 143ms/epoch - 7ms/step
# Epoch 329/500
# 21/21 - 0s - loss: 0.2583 - val_loss: 0.3201 - 150ms/epoch - 7ms/step
# Epoch 330/500
# 21/21 - 0s - loss: 0.2083 - val_loss: 0.2216 - 137ms/epoch - 7ms/step
# Epoch 331/500
# 21/21 - 0s - loss: 0.1859 - val_loss: 0.2097 - 133ms/epoch - 6ms/step
# Epoch 332/500
# 21/21 - 0s - loss: 0.1858 - val_loss: 0.2074 - 137ms/epoch - 7ms/step
# Epoch 333/500
# 21/21 - 0s - loss: 0.1793 - val_loss: 0.2056 - 130ms/epoch - 6ms/step
# Epoch 334/500
# 21/21 - 0s - loss: 0.1809 - val_loss: 0.2094 - 135ms/epoch - 6ms/step
# Epoch 335/500
# 21/21 - 0s - loss: 0.1790 - val_loss: 0.2075 - 128ms/epoch - 6ms/step
# Epoch 336/500
# 21/21 - 0s - loss: 0.1793 - val_loss: 0.2095 - 121ms/epoch - 6ms/step
# Epoch 337/500
# 21/21 - 0s - loss: 0.1798 - val_loss: 0.2114 - 124ms/epoch - 6ms/step
# Epoch 338/500
# 21/21 - 0s - loss: 0.1811 - val_loss: 0.2162 - 134ms/epoch - 6ms/step
# Epoch 339/500
# 21/21 - 0s - loss: 0.1842 - val_loss: 0.2265 - 136ms/epoch - 6ms/step
# Epoch 340/500
# 21/21 - 0s - loss: 0.1908 - val_loss: 0.2462 - 135ms/epoch - 6ms/step
# Epoch 341/500
# 21/21 - 0s - loss: 0.2012 - val_loss: 0.2694 - 143ms/epoch - 7ms/step
# Epoch 342/500
# 21/21 - 0s - loss: 0.2050 - val_loss: 0.2639 - 145ms/epoch - 7ms/step
# Epoch 343/500
# 21/21 - 0s - loss: 0.1938 - val_loss: 0.2331 - 138ms/epoch - 7ms/step
# Epoch 344/500
# 21/21 - 0s - loss: 0.1841 - val_loss: 0.2161 - 144ms/epoch - 7ms/step
# Epoch 345/500
# 21/21 - 0s - loss: 0.1795 - val_loss: 0.2078 - 120ms/epoch - 6ms/step
# Epoch 346/500
# 21/21 - 0s - loss: 0.1768 - val_loss: 0.2033 - 122ms/epoch - 6ms/step
# Epoch 347/500
# 21/21 - 0s - loss: 0.1752 - val_loss: 0.2010 - 114ms/epoch - 5ms/step
# Epoch 348/500
# 21/21 - 0s - loss: 0.1744 - val_loss: 0.2005 - 107ms/epoch - 5ms/step
# Epoch 349/500
# 21/21 - 0s - loss: 0.1745 - val_loss: 0.2029 - 110ms/epoch - 5ms/step
# Epoch 350/500
# 21/21 - 0s - loss: 0.1776 - val_loss: 0.2166 - 107ms/epoch - 5ms/step
# Epoch 351/500
# 21/21 - 0s - loss: 0.1924 - val_loss: 0.2742 - 113ms/epoch - 5ms/step
# Epoch 352/500
# 21/21 - 0s - loss: 0.2484 - val_loss: 0.4126 - 134ms/epoch - 6ms/step
# Epoch 353/500
# 21/21 - 0s - loss: 0.2505 - val_loss: 0.2674 - 149ms/epoch - 7ms/step
# Epoch 354/500
# 21/21 - 0s - loss: 0.2075 - val_loss: 0.2227 - 132ms/epoch - 6ms/step
# Epoch 355/500
# 21/21 - 0s - loss: 0.1947 - val_loss: 0.2006 - 135ms/epoch - 6ms/step
# Epoch 356/500
# 21/21 - 0s - loss: 0.2053 - val_loss: 0.2063 - 130ms/epoch - 6ms/step
# Epoch 357/500
# 21/21 - 0s - loss: 0.2093 - val_loss: 0.2246 - 137ms/epoch - 7ms/step
# Epoch 358/500
# 21/21 - 0s - loss: 0.2288 - val_loss: 0.2594 - 138ms/epoch - 7ms/step
# Epoch 359/500
# 21/21 - 0s - loss: 0.2327 - val_loss: 0.3296 - 133ms/epoch - 6ms/step
# Epoch 360/500
# 21/21 - 0s - loss: 0.2062 - val_loss: 0.2399 - 136ms/epoch - 6ms/step
# Epoch 361/500
# 21/21 - 0s - loss: 0.1806 - val_loss: 0.2009 - 137ms/epoch - 7ms/step
# Epoch 362/500
# 21/21 - 0s - loss: 0.1748 - val_loss: 0.2058 - 143ms/epoch - 7ms/step
# Epoch 363/500
# 21/21 - 0s - loss: 0.1725 - val_loss: 0.1975 - 135ms/epoch - 6ms/step
# Epoch 364/500
# 21/21 - 0s - loss: 0.1709 - val_loss: 0.1970 - 135ms/epoch - 6ms/step
# Epoch 365/500
# 21/21 - 0s - loss: 0.1705 - val_loss: 0.1964 - 128ms/epoch - 6ms/step
# Epoch 366/500
# 21/21 - 0s - loss: 0.1702 - val_loss: 0.1961 - 124ms/epoch - 6ms/step
# Epoch 367/500
# 21/21 - 0s - loss: 0.1700 - val_loss: 0.1958 - 127ms/epoch - 6ms/step
# Epoch 368/500
# 21/21 - 0s - loss: 0.1697 - val_loss: 0.1956 - 192ms/epoch - 9ms/step
# Epoch 369/500
# 21/21 - 0s - loss: 0.1695 - val_loss: 0.1952 - 150ms/epoch - 7ms/step
# Epoch 370/500
# 21/21 - 0s - loss: 0.1693 - val_loss: 0.1949 - 133ms/epoch - 6ms/step
# Epoch 371/500
# 21/21 - 0s - loss: 0.1691 - val_loss: 0.1946 - 137ms/epoch - 7ms/step
# Epoch 372/500
# 21/21 - 0s - loss: 0.1687 - val_loss: 0.1943 - 134ms/epoch - 6ms/step
# Epoch 373/500
# 21/21 - 0s - loss: 0.1685 - val_loss: 0.1942 - 145ms/epoch - 7ms/step
# Epoch 374/500
# 21/21 - 0s - loss: 0.1681 - val_loss: 0.1937 - 163ms/epoch - 8ms/step
# Epoch 375/500
# 21/21 - 0s - loss: 0.1678 - val_loss: 0.1937 - 191ms/epoch - 9ms/step
# Epoch 376/500
# 21/21 - 0s - loss: 0.1676 - val_loss: 0.1936 - 174ms/epoch - 8ms/step
# Epoch 377/500
# 21/21 - 0s - loss: 0.1676 - val_loss: 0.1942 - 183ms/epoch - 9ms/step
# Epoch 378/500
# 21/21 - 0s - loss: 0.1680 - val_loss: 0.1964 - 169ms/epoch - 8ms/step
# Epoch 379/500
# 21/21 - 0s - loss: 0.1698 - val_loss: 0.2038 - 173ms/epoch - 8ms/step
# Epoch 380/500
# 21/21 - 0s - loss: 0.1761 - val_loss: 0.2274 - 165ms/epoch - 8ms/step
# Epoch 381/500
# 21/21 - 0s - loss: 0.1961 - val_loss: 0.2897 - 183ms/epoch - 9ms/step
# Epoch 382/500
# 21/21 - 0s - loss: 0.2303 - val_loss: 0.3274 - 174ms/epoch - 8ms/step
# Epoch 383/500
# 21/21 - 0s - loss: 0.1975 - val_loss: 0.2241 - 194ms/epoch - 9ms/step
# Epoch 384/500
# 21/21 - 0s - loss: 0.1742 - val_loss: 0.2018 - 168ms/epoch - 8ms/step
# Epoch 385/500
# 21/21 - 0s - loss: 0.1688 - val_loss: 0.1941 - 154ms/epoch - 7ms/step
# Epoch 386/500
# 21/21 - 0s - loss: 0.1667 - val_loss: 0.1905 - 161ms/epoch - 8ms/step
# Epoch 387/500
# 21/21 - 0s - loss: 0.1657 - val_loss: 0.1912 - 162ms/epoch - 8ms/step
# Epoch 388/500
# 21/21 - 0s - loss: 0.1663 - val_loss: 0.1949 - 149ms/epoch - 7ms/step
# Epoch 389/500
# 21/21 - 0s - loss: 0.1687 - val_loss: 0.2038 - 144ms/epoch - 7ms/step
# Epoch 390/500
# 21/21 - 0s - loss: 0.1749 - val_loss: 0.2242 - 145ms/epoch - 7ms/step
# Epoch 391/500
# 21/21 - 0s - loss: 0.1881 - val_loss: 0.2604 - 137ms/epoch - 7ms/step
# Epoch 392/500
# 21/21 - 0s - loss: 0.2018 - val_loss: 0.2763 - 153ms/epoch - 7ms/step
# Epoch 393/500
# 21/21 - 0s - loss: 0.1898 - val_loss: 0.2336 - 174ms/epoch - 8ms/step
# Epoch 394/500
# 21/21 - 0s - loss: 0.1747 - val_loss: 0.2076 - 180ms/epoch - 9ms/step
# Epoch 395/500
# 21/21 - 0s - loss: 0.1685 - val_loss: 0.1977 - 174ms/epoch - 8ms/step
# Epoch 396/500
# 21/21 - 0s - loss: 0.1654 - val_loss: 0.1910 - 184ms/epoch - 9ms/step
# Epoch 397/500
# 21/21 - 0s - loss: 0.1633 - val_loss: 0.1879 - 170ms/epoch - 8ms/step
# Epoch 398/500
# 21/21 - 0s - loss: 0.1622 - val_loss: 0.1867 - 169ms/epoch - 8ms/step
# Epoch 399/500
# 21/21 - 0s - loss: 0.1619 - val_loss: 0.1874 - 160ms/epoch - 8ms/step
# Epoch 400/500
# 21/21 - 0s - loss: 0.1631 - val_loss: 0.1931 - 144ms/epoch - 7ms/step
# Epoch 401/500
# 21/21 - 0s - loss: 0.1691 - val_loss: 0.2169 - 126ms/epoch - 6ms/step
# Epoch 402/500
# 21/21 - 0s - loss: 0.1928 - val_loss: 0.2976 - 117ms/epoch - 6ms/step
# Epoch 403/500
# 21/21 - 0s - loss: 0.2501 - val_loss: 0.3662 - 117ms/epoch - 6ms/step
# Epoch 404/500
# 21/21 - 0s - loss: 0.1966 - val_loss: 0.2115 - 114ms/epoch - 5ms/step
# Epoch 405/500
# 21/21 - 0s - loss: 0.1674 - val_loss: 0.1967 - 119ms/epoch - 6ms/step
# Epoch 406/500
# 21/21 - 0s - loss: 0.1636 - val_loss: 0.1874 - 120ms/epoch - 6ms/step
# Epoch 407/500
# 21/21 - 0s - loss: 0.1612 - val_loss: 0.1846 - 136ms/epoch - 6ms/step
# Epoch 408/500
# 21/21 - 0s - loss: 0.1599 - val_loss: 0.1845 - 140ms/epoch - 7ms/step
# Epoch 409/500
# 21/21 - 0s - loss: 0.1600 - val_loss: 0.1857 - 140ms/epoch - 7ms/step
# Epoch 410/500
# 21/21 - 0s - loss: 0.1604 - val_loss: 0.1879 - 139ms/epoch - 7ms/step
# Epoch 411/500
# 21/21 - 0s - loss: 0.1617 - val_loss: 0.1927 - 154ms/epoch - 7ms/step
# Epoch 412/500
# 21/21 - 0s - loss: 0.1648 - val_loss: 0.2038 - 141ms/epoch - 7ms/step
# Epoch 413/500
# 21/21 - 0s - loss: 0.1727 - val_loss: 0.2289 - 135ms/epoch - 6ms/step
# Epoch 414/500
# 21/21 - 0s - loss: 0.1884 - val_loss: 0.2683 - 138ms/epoch - 7ms/step
# Epoch 415/500
# 21/21 - 0s - loss: 0.1988 - val_loss: 0.2674 - 143ms/epoch - 7ms/step
# Epoch 416/500
# 21/21 - 0s - loss: 0.1797 - val_loss: 0.2147 - 210ms/epoch - 10ms/step
# Epoch 417/500
# 21/21 - 0s - loss: 0.1656 - val_loss: 0.1943 - 140ms/epoch - 7ms/step
# Epoch 418/500
# 21/21 - 0s - loss: 0.1606 - val_loss: 0.1856 - 132ms/epoch - 6ms/step
# Epoch 419/500
# 21/21 - 0s - loss: 0.1581 - val_loss: 0.1812 - 142ms/epoch - 7ms/step
# Epoch 420/500
# 21/21 - 0s - loss: 0.1571 - val_loss: 0.1814 - 140ms/epoch - 7ms/step
# Epoch 421/500
# 21/21 - 0s - loss: 0.1585 - val_loss: 0.1886 - 141ms/epoch - 7ms/step
# Epoch 422/500
# 21/21 - 0s - loss: 0.1654 - val_loss: 0.2150 - 141ms/epoch - 7ms/step
# Epoch 423/500
# 21/21 - 0s - loss: 0.1881 - val_loss: 0.2850 - 139ms/epoch - 7ms/step
# Epoch 424/500
# 21/21 - 0s - loss: 0.2233 - val_loss: 0.3172 - 144ms/epoch - 7ms/step
# Epoch 425/500
# 21/21 - 0s - loss: 0.1855 - val_loss: 0.2139 - 143ms/epoch - 7ms/step
# Epoch 426/500
# 21/21 - 0s - loss: 0.1641 - val_loss: 0.1973 - 153ms/epoch - 7ms/step
# Epoch 427/500
# 21/21 - 0s - loss: 0.1601 - val_loss: 0.1865 - 137ms/epoch - 7ms/step
# Epoch 428/500
# 21/21 - 0s - loss: 0.1567 - val_loss: 0.1805 - 140ms/epoch - 7ms/step
# Epoch 429/500
# 21/21 - 0s - loss: 0.1549 - val_loss: 0.1788 - 163ms/epoch - 8ms/step
# Epoch 430/500
# 21/21 - 0s - loss: 0.1542 - val_loss: 0.1779 - 149ms/epoch - 7ms/step
# Epoch 431/500
# 21/21 - 0s - loss: 0.1537 - val_loss: 0.1774 - 138ms/epoch - 7ms/step
# Epoch 432/500
# 21/21 - 0s - loss: 0.1533 - val_loss: 0.1771 - 131ms/epoch - 6ms/step
# Epoch 433/500
# 21/21 - 0s - loss: 0.1530 - val_loss: 0.1768 - 138ms/epoch - 7ms/step
# Epoch 434/500
# 21/21 - 0s - loss: 0.1527 - val_loss: 0.1767 - 147ms/epoch - 7ms/step
# Epoch 435/500
# 21/21 - 0s - loss: 0.1527 - val_loss: 0.1779 - 140ms/epoch - 7ms/step
# Epoch 436/500
# 21/21 - 0s - loss: 0.1541 - val_loss: 0.1841 - 141ms/epoch - 7ms/step
# Epoch 437/500
# 21/21 - 0s - loss: 0.1609 - val_loss: 0.2098 - 137ms/epoch - 7ms/step
# Epoch 438/500
# 21/21 - 0s - loss: 0.1888 - val_loss: 0.3088 - 158ms/epoch - 8ms/step
# Epoch 439/500
# 21/21 - 0s - loss: 0.2835 - val_loss: 0.4294 - 156ms/epoch - 7ms/step
# Epoch 440/500
# 21/21 - 0s - loss: 0.1988 - val_loss: 0.1872 - 138ms/epoch - 7ms/step
# Epoch 441/500
# 21/21 - 0s - loss: 0.1554 - val_loss: 0.1800 - 143ms/epoch - 7ms/step
# Epoch 442/500
# 21/21 - 0s - loss: 0.1537 - val_loss: 0.1753 - 140ms/epoch - 7ms/step
# Epoch 443/500
# 21/21 - 0s - loss: 0.1533 - val_loss: 0.1785 - 131ms/epoch - 6ms/step
# Epoch 444/500
# 21/21 - 0s - loss: 0.1529 - val_loss: 0.1806 - 130ms/epoch - 6ms/step
# Epoch 445/500
# 21/21 - 0s - loss: 0.1541 - val_loss: 0.1845 - 143ms/epoch - 7ms/step
# Epoch 446/500
# 21/21 - 0s - loss: 0.1551 - val_loss: 0.1877 - 132ms/epoch - 6ms/step
# Epoch 447/500
# 21/21 - 0s - loss: 0.1565 - val_loss: 0.1924 - 134ms/epoch - 6ms/step
# Epoch 448/500
# 21/21 - 0s - loss: 0.1586 - val_loss: 0.1990 - 132ms/epoch - 6ms/step
# Epoch 449/500
# 21/21 - 0s - loss: 0.1616 - val_loss: 0.2071 - 132ms/epoch - 6ms/step
# Epoch 450/500
# 21/21 - 0s - loss: 0.1647 - val_loss: 0.2145 - 131ms/epoch - 6ms/step
# Epoch 451/500
# 21/21 - 0s - loss: 0.1665 - val_loss: 0.2164 - 128ms/epoch - 6ms/step
# Epoch 452/500
# 21/21 - 0s - loss: 0.1652 - val_loss: 0.2109 - 141ms/epoch - 7ms/step
# Epoch 453/500
# 21/21 - 0s - loss: 0.1618 - val_loss: 0.2019 - 136ms/epoch - 6ms/step
# Epoch 454/500
# 21/21 - 0s - loss: 0.1582 - val_loss: 0.1938 - 138ms/epoch - 7ms/step
# Epoch 455/500
# 21/21 - 0s - loss: 0.1554 - val_loss: 0.1879 - 130ms/epoch - 6ms/step
# Epoch 456/500
# 21/21 - 0s - loss: 0.1534 - val_loss: 0.1841 - 116ms/epoch - 6ms/step
# Epoch 457/500
# 21/21 - 0s - loss: 0.1522 - val_loss: 0.1824 - 127ms/epoch - 6ms/step
# Epoch 458/500
# 21/21 - 0s - loss: 0.1518 - val_loss: 0.1828 - 117ms/epoch - 6ms/step
# Epoch 459/500
# 21/21 - 0s - loss: 0.1527 - val_loss: 0.1868 - 112ms/epoch - 5ms/step
# Epoch 460/500
# 21/21 - 0s - loss: 0.1558 - val_loss: 0.1978 - 108ms/epoch - 5ms/step
# Epoch 461/500
# 21/21 - 0s - loss: 0.1639 - val_loss: 0.2229 - 107ms/epoch - 5ms/step
# Epoch 462/500
# 21/21 - 0s - loss: 0.1798 - val_loss: 0.2611 - 124ms/epoch - 6ms/step
# Epoch 463/500
# 21/21 - 0s - loss: 0.1893 - val_loss: 0.2538 - 143ms/epoch - 7ms/step
# Epoch 464/500
# 21/21 - 0s - loss: 0.1670 - val_loss: 0.1929 - 139ms/epoch - 7ms/step
# Epoch 465/500
# 21/21 - 0s - loss: 0.1516 - val_loss: 0.1722 - 147ms/epoch - 7ms/step
# Epoch 466/500
# 21/21 - 0s - loss: 0.1469 - val_loss: 0.1678 - 147ms/epoch - 7ms/step
# Epoch 467/500
# 21/21 - 0s - loss: 0.1479 - val_loss: 0.1764 - 137ms/epoch - 7ms/step
# Epoch 468/500
# 21/21 - 0s - loss: 0.1577 - val_loss: 0.2141 - 138ms/epoch - 7ms/step
# Epoch 469/500
# 21/21 - 0s - loss: 0.1873 - val_loss: 0.2941 - 205ms/epoch - 10ms/step
# Epoch 470/500
# 21/21 - 0s - loss: 0.2062 - val_loss: 0.2769 - 144ms/epoch - 7ms/step
# Epoch 471/500
# 21/21 - 0s - loss: 0.1677 - val_loss: 0.2013 - 133ms/epoch - 6ms/step
# Epoch 472/500
# 21/21 - 0s - loss: 0.1554 - val_loss: 0.1933 - 125ms/epoch - 6ms/step
# Epoch 473/500
# 21/21 - 0s - loss: 0.1500 - val_loss: 0.1756 - 123ms/epoch - 6ms/step
# Epoch 474/500
# 21/21 - 0s - loss: 0.1460 - val_loss: 0.1728 - 133ms/epoch - 6ms/step
# Epoch 475/500
# 21/21 - 0s - loss: 0.1450 - val_loss: 0.1706 - 131ms/epoch - 6ms/step
# Epoch 476/500
# 21/21 - 0s - loss: 0.1444 - val_loss: 0.1710 - 155ms/epoch - 7ms/step
# Epoch 477/500
# 21/21 - 0s - loss: 0.1450 - val_loss: 0.1741 - 192ms/epoch - 9ms/step
# Epoch 478/500
# 21/21 - 0s - loss: 0.1471 - val_loss: 0.1822 - 168ms/epoch - 8ms/step
# Epoch 479/500
# 21/21 - 0s - loss: 0.1528 - val_loss: 0.2012 - 174ms/epoch - 8ms/step
# Epoch 480/500
# 21/21 - 0s - loss: 0.1649 - val_loss: 0.2349 - 179ms/epoch - 9ms/step
# Epoch 481/500
# 21/21 - 0s - loss: 0.1785 - val_loss: 0.2534 - 160ms/epoch - 8ms/step
# Epoch 482/500
# 21/21 - 0s - loss: 0.1702 - val_loss: 0.2164 - 141ms/epoch - 7ms/step
# Epoch 483/500
# 21/21 - 0s - loss: 0.1547 - val_loss: 0.1876 - 128ms/epoch - 6ms/step
# Epoch 484/500
# 21/21 - 0s - loss: 0.1478 - val_loss: 0.1772 - 126ms/epoch - 6ms/step
# Epoch 485/500
# 21/21 - 0s - loss: 0.1447 - val_loss: 0.1699 - 128ms/epoch - 6ms/step
# Epoch 486/500
# 21/21 - 0s - loss: 0.1423 - val_loss: 0.1661 - 145ms/epoch - 7ms/step
# Epoch 487/500
# 21/21 - 0s - loss: 0.1410 - val_loss: 0.1644 - 146ms/epoch - 7ms/step
# Epoch 488/500
# 21/21 - 0s - loss: 0.1404 - val_loss: 0.1640 - 139ms/epoch - 7ms/step
# Epoch 489/500
# 21/21 - 0s - loss: 0.1403 - val_loss: 0.1654 - 133ms/epoch - 6ms/step
# Epoch 490/500
# 21/21 - 0s - loss: 0.1416 - val_loss: 0.1715 - 139ms/epoch - 7ms/step
# Epoch 491/500
# 21/21 - 0s - loss: 0.1473 - val_loss: 0.1932 - 138ms/epoch - 7ms/step
# Epoch 492/500
# 21/21 - 0s - loss: 0.1677 - val_loss: 0.2618 - 132ms/epoch - 6ms/step
# Epoch 493/500
# 21/21 - 0s - loss: 0.2196 - val_loss: 0.3489 - 135ms/epoch - 6ms/step
# Epoch 494/500
# 21/21 - 0s - loss: 0.1857 - val_loss: 0.1961 - 138ms/epoch - 7ms/step
# Epoch 495/500
# 21/21 - 0s - loss: 0.1514 - val_loss: 0.1649 - 138ms/epoch - 7ms/step
# Epoch 496/500
# 21/21 - 0s - loss: 0.1396 - val_loss: 0.1601 - 139ms/epoch - 7ms/step
# Epoch 497/500
# 21/21 - 0s - loss: 0.1404 - val_loss: 0.1633 - 136ms/epoch - 6ms/step
# Epoch 498/500
# 21/21 - 0s - loss: 0.1415 - val_loss: 0.1713 - 135ms/epoch - 6ms/step
# Epoch 499/500
# 21/21 - 0s - loss: 0.1457 - val_loss: 0.1868 - 135ms/epoch - 6ms/step
# Epoch 500/500
# 21/21 - 0s - loss: 0.1539 - val_loss: 0.2097 - 134ms/epoch - 6ms/step

# %% [markdown]
# ## Metrics ($LPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
phy = phys2(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 11/11 [==============================] - 1s 2ms/step
# (325, 3)
# (325, 10)
# Test RMSE: 4.304
# Test MAE: 3.725

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('El Niño Sea Surface Temperature', fontsize=20)
plt.legend(fontsize=20)
plt.show()
