# %% [markdown]
# # Time Series Prediction with Lotka Volterra Equation Inspired Deep Learning ($LVPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-11 21:16:50

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _KYOTO DST_

# %%
data = pd.read_csv("datasets/dst.csv")
training_set = data.iloc[:, 1]
print(training_set)
# Out:
# 0         -7
# 1        -10
# 2        -10
# 3         -6
# 4         -2
#           ..
# 139867   -16
# 139868   -14
# 139869   -14
# 139870   -15
# 139871   -14
# Name: dst, Length: 139872, dtype: int64

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 0.0416 # Hourly Data (1/24)
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 67
# 1         -72.115385
# 2           0.000000
# 3          96.153846
# 4          96.153846
# 5         120.192308
#              ...
# 139867     96.153846
# 139868     48.076923
# 139869      0.000000
# 139870    -24.038462
# 139871     24.038462
# Name: dst, Length: 139871, dtype: float64
# 2         1733.542899
# 3         2311.390533
# 4            0.000000
# 5          577.847633
# 6        -1733.542899
#              ...
# 139867       0.000000
# 139868   -1155.695266
# 139869   -1155.695266
# 139870    -577.847633
# 139871    1155.695266
# Name: dst, Length: 139870, dtype: float64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0         -72.115385
# 1           0.000000
# 2          96.153846
# 3          96.153846
# 4         120.192308
#              ...
# 139866     96.153846
# 139867     48.076923
# 139868      0.000000
# 139869    -24.038462
# 139870     24.038462
# Name: dst, Length: 139871, dtype: float64
# 0         1733.542899
# 1         2311.390533
# 2            0.000000
# 3          577.847633
# 4        -1733.542899
#              ...
# 139865       0.000000
# 139866   -1155.695266
# 139867   -1155.695266
# 139868    -577.847633
# 139869    1155.695266
# Name: dst, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lotka Volterra Equation_)

# %% [markdown]
# _Parameters_: $\alpha=0.1, \beta=0.05, \gamma=1.1, \delta=0.1\\$

# %%
a=0.1
b=0.05
c=1.1
d=0.1
L = df.iloc[:, 2] - a*a*df.iloc[:, 0] + 2*a*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*d*(df.iloc[:,0]**2)*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - c*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10        -7.0      -10.0      -10.0       -6.0       -2.0        3.0
# 11       -10.0      -10.0       -6.0       -2.0        3.0        5.0
# 12       -10.0       -6.0       -2.0        3.0        5.0        5.0
# 13        -6.0       -2.0        3.0        5.0        5.0        3.0
# 14        -2.0        3.0        5.0        5.0        3.0        1.0
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)    var2(t)     var3(t)
# 10        5.0        5.0        3.0        1.0      1.0  24.038462 -577.847633
# 11        5.0        3.0        1.0        1.0      2.0   0.000000  577.847633
# 12        3.0        1.0        1.0        2.0      2.0  24.038462 -577.847633
# 13        1.0        1.0        2.0        2.0      3.0   0.000000  577.847633
# 14        1.0        2.0        2.0        3.0      3.0  24.038462  577.847633
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (139860, 13)
# (139860, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (111888, 1, 10) (111888, 3) (27972, 1, 10) (27972, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] - a*a*y_true[:, 0] + 2*a*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*d*(y_true[:,0]**2)*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - c*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))), (y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] - a*a*y_pred[:-2] + 2*a*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*d*(y_pred[:-2]**2)*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - c*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] - a*a*y_real[:-2] + 2*a*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*d*(y_real[:-2]**2)*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - c*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($LVPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square(y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 1749/1749 - 44s - loss: 0.0793 - val_loss: 2.0506e-04 - 44s/epoch - 25ms/step
# Epoch 2/500
# 1749/1749 - 14s - loss: 5.6307e-04 - val_loss: 1.9682e-04 - 14s/epoch - 8ms/step
# Epoch 3/500
# 1749/1749 - 14s - loss: 5.2722e-04 - val_loss: 1.7900e-04 - 14s/epoch - 8ms/step
# Epoch 4/500
# 1749/1749 - 14s - loss: 4.5562e-04 - val_loss: 1.4416e-04 - 14s/epoch - 8ms/step
# Epoch 5/500
# 1749/1749 - 16s - loss: 3.2759e-04 - val_loss: 9.7899e-05 - 16s/epoch - 9ms/step
# Epoch 6/500
# 1749/1749 - 14s - loss: 2.2012e-04 - val_loss: 1.4981e-04 - 14s/epoch - 8ms/step
# Epoch 7/500
# 1749/1749 - 16s - loss: 1.9630e-04 - val_loss: 1.0755e-04 - 16s/epoch - 9ms/step
# Epoch 8/500
# 1749/1749 - 15s - loss: 1.6546e-04 - val_loss: 6.7957e-05 - 15s/epoch - 9ms/step
# Epoch 9/500
# 1749/1749 - 14s - loss: 1.4495e-04 - val_loss: 5.6859e-05 - 14s/epoch - 8ms/step
# Epoch 10/500
# 1749/1749 - 14s - loss: 1.3033e-04 - val_loss: 4.9527e-05 - 14s/epoch - 8ms/step
# Epoch 11/500
# 1749/1749 - 14s - loss: 1.2166e-04 - val_loss: 4.4181e-05 - 14s/epoch - 8ms/step
# Epoch 12/500
# 1749/1749 - 14s - loss: 1.1644e-04 - val_loss: 4.1336e-05 - 14s/epoch - 8ms/step
# Epoch 13/500
# 1749/1749 - 12s - loss: 1.1303e-04 - val_loss: 4.0090e-05 - 12s/epoch - 7ms/step
# Epoch 14/500
# 1749/1749 - 13s - loss: 1.1065e-04 - val_loss: 3.9441e-05 - 13s/epoch - 7ms/step
# Epoch 15/500
# 1749/1749 - 14s - loss: 1.0889e-04 - val_loss: 3.9096e-05 - 14s/epoch - 8ms/step
# Epoch 16/500
# 1749/1749 - 13s - loss: 1.0755e-04 - val_loss: 3.9265e-05 - 13s/epoch - 8ms/step
# Epoch 17/500
# 1749/1749 - 12s - loss: 1.0653e-04 - val_loss: 3.9892e-05 - 12s/epoch - 7ms/step
# Epoch 18/500
# 1749/1749 - 12s - loss: 1.0569e-04 - val_loss: 4.0742e-05 - 12s/epoch - 7ms/step
# Epoch 19/500
# 1749/1749 - 14s - loss: 1.0495e-04 - val_loss: 4.1516e-05 - 14s/epoch - 8ms/step
# Epoch 20/500
# 1749/1749 - 12s - loss: 1.0425e-04 - val_loss: 4.2009e-05 - 12s/epoch - 7ms/step
# Epoch 21/500
# 1749/1749 - 13s - loss: 1.0357e-04 - val_loss: 4.2354e-05 - 13s/epoch - 7ms/step
# Epoch 22/500
# 1749/1749 - 13s - loss: 1.0294e-04 - val_loss: 4.2617e-05 - 13s/epoch - 8ms/step
# Epoch 23/500
# 1749/1749 - 15s - loss: 1.0234e-04 - val_loss: 4.2694e-05 - 15s/epoch - 9ms/step
# Epoch 24/500
# 1749/1749 - 16s - loss: 1.0179e-04 - val_loss: 4.2818e-05 - 16s/epoch - 9ms/step
# Epoch 25/500
# 1749/1749 - 15s - loss: 1.0127e-04 - val_loss: 4.2854e-05 - 15s/epoch - 9ms/step
# Epoch 26/500
# 1749/1749 - 18s - loss: 1.0077e-04 - val_loss: 4.2837e-05 - 18s/epoch - 10ms/step
# Epoch 27/500
# 1749/1749 - 17s - loss: 1.0031e-04 - val_loss: 4.2789e-05 - 17s/epoch - 10ms/step
# Epoch 28/500
# 1749/1749 - 15s - loss: 9.9874e-05 - val_loss: 4.2721e-05 - 15s/epoch - 8ms/step
# Epoch 29/500
# 1749/1749 - 14s - loss: 9.9471e-05 - val_loss: 4.2643e-05 - 14s/epoch - 8ms/step
# Epoch 30/500
# 1749/1749 - 12s - loss: 9.9101e-05 - val_loss: 4.2553e-05 - 12s/epoch - 7ms/step
# Epoch 31/500
# 1749/1749 - 11s - loss: 9.8766e-05 - val_loss: 4.2441e-05 - 11s/epoch - 6ms/step
# Epoch 32/500
# 1749/1749 - 11s - loss: 9.8468e-05 - val_loss: 4.2294e-05 - 11s/epoch - 6ms/step
# Epoch 33/500
# 1749/1749 - 11s - loss: 9.8201e-05 - val_loss: 4.2102e-05 - 11s/epoch - 6ms/step
# Epoch 34/500
# 1749/1749 - 12s - loss: 9.7967e-05 - val_loss: 4.1863e-05 - 12s/epoch - 7ms/step
# Epoch 35/500
# 1749/1749 - 12s - loss: 9.7767e-05 - val_loss: 4.1586e-05 - 12s/epoch - 7ms/step
# Epoch 36/500
# 1749/1749 - 11s - loss: 1.0186e-04 - val_loss: 4.4060e-05 - 11s/epoch - 6ms/step
# Epoch 37/500
# 1749/1749 - 10s - loss: 1.0050e-04 - val_loss: 4.1636e-05 - 10s/epoch - 6ms/step
# Epoch 38/500
# 1749/1749 - 11s - loss: 9.9608e-05 - val_loss: 4.0951e-05 - 11s/epoch - 6ms/step
# Epoch 39/500
# 1749/1749 - 10s - loss: 9.9521e-05 - val_loss: 4.2083e-05 - 10s/epoch - 6ms/step
# Epoch 40/500
# 1749/1749 - 11s - loss: 9.9716e-05 - val_loss: 4.4523e-05 - 11s/epoch - 6ms/step
# Epoch 41/500
# 1749/1749 - 12s - loss: 9.9804e-05 - val_loss: 4.6133e-05 - 12s/epoch - 7ms/step
# Epoch 42/500
# 1749/1749 - 12s - loss: 9.9792e-05 - val_loss: 4.6118e-05 - 12s/epoch - 7ms/step
# Epoch 43/500
# 1749/1749 - 10s - loss: 9.9733e-05 - val_loss: 4.5784e-05 - 10s/epoch - 6ms/step
# Epoch 44/500
# 1749/1749 - 11s - loss: 9.9581e-05 - val_loss: 4.6028e-05 - 11s/epoch - 6ms/step
# Epoch 45/500
# 1749/1749 - 11s - loss: 9.9325e-05 - val_loss: 4.6610e-05 - 11s/epoch - 6ms/step
# Epoch 46/500
# 1749/1749 - 11s - loss: 9.8981e-05 - val_loss: 4.7058e-05 - 11s/epoch - 6ms/step
# Epoch 47/500
# 1749/1749 - 11s - loss: 9.9592e-05 - val_loss: 5.0812e-05 - 11s/epoch - 6ms/step
# Epoch 48/500
# 1749/1749 - 11s - loss: 9.9793e-05 - val_loss: 5.4123e-05 - 11s/epoch - 6ms/step
# Epoch 49/500
# 1749/1749 - 10s - loss: 1.0010e-04 - val_loss: 5.7728e-05 - 10s/epoch - 6ms/step
# Epoch 50/500
# 1749/1749 - 10s - loss: 1.0072e-04 - val_loss: 6.2725e-05 - 10s/epoch - 6ms/step
# Epoch 51/500
# 1749/1749 - 8s - loss: 1.0247e-04 - val_loss: 7.2030e-05 - 8s/epoch - 5ms/step
# Epoch 52/500
# 1749/1749 - 8s - loss: 1.0794e-04 - val_loss: 9.0957e-05 - 8s/epoch - 5ms/step
# Epoch 53/500
# 1749/1749 - 8s - loss: 1.0711e-04 - val_loss: 8.8195e-05 - 8s/epoch - 5ms/step
# Epoch 54/500
# 1749/1749 - 9s - loss: 1.0665e-04 - val_loss: 8.8100e-05 - 9s/epoch - 5ms/step
# Epoch 55/500
# 1749/1749 - 13s - loss: 1.0643e-04 - val_loss: 8.7695e-05 - 13s/epoch - 7ms/step
# Epoch 56/500
# 1749/1749 - 12s - loss: 1.0612e-04 - val_loss: 8.7067e-05 - 12s/epoch - 7ms/step
# Epoch 57/500
# 1749/1749 - 14s - loss: 1.0582e-04 - val_loss: 8.6259e-05 - 14s/epoch - 8ms/step
# Epoch 58/500
# 1749/1749 - 15s - loss: 1.0552e-04 - val_loss: 8.5329e-05 - 15s/epoch - 9ms/step
# Epoch 59/500
# 1749/1749 - 9s - loss: 1.0522e-04 - val_loss: 8.4350e-05 - 9s/epoch - 5ms/step
# Epoch 60/500
# 1749/1749 - 9s - loss: 1.0493e-04 - val_loss: 8.3314e-05 - 9s/epoch - 5ms/step
# Epoch 61/500
# 1749/1749 - 8s - loss: 1.0466e-04 - val_loss: 8.2170e-05 - 8s/epoch - 5ms/step
# Epoch 62/500
# 1749/1749 - 10s - loss: 1.0440e-04 - val_loss: 8.0903e-05 - 10s/epoch - 6ms/step
# Epoch 63/500
# 1749/1749 - 12s - loss: 1.0415e-04 - val_loss: 7.9536e-05 - 12s/epoch - 7ms/step
# Epoch 64/500
# 1749/1749 - 12s - loss: 1.0391e-04 - val_loss: 7.8075e-05 - 12s/epoch - 7ms/step
# Epoch 65/500
# 1749/1749 - 13s - loss: 1.0368e-04 - val_loss: 7.6557e-05 - 13s/epoch - 7ms/step
# Epoch 66/500
# 1749/1749 - 11s - loss: 1.0345e-04 - val_loss: 7.4988e-05 - 11s/epoch - 6ms/step
# Epoch 67/500
# 1749/1749 - 12s - loss: 1.0323e-04 - val_loss: 7.3401e-05 - 12s/epoch - 7ms/step
# Epoch 68/500
# 1749/1749 - 12s - loss: 1.0301e-04 - val_loss: 7.1819e-05 - 12s/epoch - 7ms/step
# Epoch 69/500
# 1749/1749 - 14s - loss: 1.0280e-04 - val_loss: 7.0211e-05 - 14s/epoch - 8ms/step
# Epoch 70/500
# 1749/1749 - 13s - loss: 1.0260e-04 - val_loss: 6.8589e-05 - 13s/epoch - 7ms/step
# Epoch 71/500
# 1749/1749 - 15s - loss: 1.0240e-04 - val_loss: 6.6952e-05 - 15s/epoch - 8ms/step
# Epoch 72/500
# 1749/1749 - 13s - loss: 1.0221e-04 - val_loss: 6.5328e-05 - 13s/epoch - 7ms/step
# Epoch 73/500
# 1749/1749 - 14s - loss: 1.0203e-04 - val_loss: 6.3744e-05 - 14s/epoch - 8ms/step
# Epoch 74/500
# 1749/1749 - 15s - loss: 1.0185e-04 - val_loss: 6.2234e-05 - 15s/epoch - 8ms/step
# Epoch 75/500
# 1749/1749 - 14s - loss: 1.0167e-04 - val_loss: 6.0768e-05 - 14s/epoch - 8ms/step
# Epoch 76/500
# 1749/1749 - 13s - loss: 1.0149e-04 - val_loss: 5.9343e-05 - 13s/epoch - 8ms/step
# Epoch 77/500
# 1749/1749 - 13s - loss: 1.0132e-04 - val_loss: 5.8027e-05 - 13s/epoch - 7ms/step
# Epoch 78/500
# 1749/1749 - 9s - loss: 1.0114e-04 - val_loss: 5.6777e-05 - 9s/epoch - 5ms/step
# Epoch 79/500
# 1749/1749 - 10s - loss: 1.0096e-04 - val_loss: 5.5622e-05 - 10s/epoch - 6ms/step
# Epoch 80/500
# 1749/1749 - 11s - loss: 1.0079e-04 - val_loss: 5.4520e-05 - 11s/epoch - 6ms/step
# Epoch 81/500
# 1749/1749 - 10s - loss: 1.0061e-04 - val_loss: 5.3466e-05 - 10s/epoch - 6ms/step
# Epoch 82/500
# 1749/1749 - 8s - loss: 1.0044e-04 - val_loss: 5.2448e-05 - 8s/epoch - 5ms/step
# Epoch 83/500
# 1749/1749 - 8s - loss: 1.0026e-04 - val_loss: 5.1537e-05 - 8s/epoch - 4ms/step
# Epoch 84/500
# 1749/1749 - 9s - loss: 1.0010e-04 - val_loss: 5.0651e-05 - 9s/epoch - 5ms/step
# Epoch 85/500
# 1749/1749 - 8s - loss: 9.9933e-05 - val_loss: 4.9800e-05 - 8s/epoch - 4ms/step
# Epoch 86/500
# 1749/1749 - 8s - loss: 9.9788e-05 - val_loss: 4.8917e-05 - 8s/epoch - 5ms/step
# Epoch 87/500
# 1749/1749 - 9s - loss: 9.9627e-05 - val_loss: 4.8154e-05 - 9s/epoch - 5ms/step
# Epoch 88/500
# 1749/1749 - 9s - loss: 9.9555e-05 - val_loss: 4.7106e-05 - 9s/epoch - 5ms/step
# Epoch 89/500
# 1749/1749 - 9s - loss: 9.9640e-05 - val_loss: 4.5510e-05 - 9s/epoch - 5ms/step
# Epoch 90/500
# 1749/1749 - 10s - loss: 1.0302e-04 - val_loss: 3.5575e-05 - 10s/epoch - 6ms/step
# Epoch 91/500
# 1749/1749 - 10s - loss: 9.9437e-05 - val_loss: 4.5650e-05 - 10s/epoch - 6ms/step
# Epoch 92/500
# 1749/1749 - 11s - loss: 9.8466e-05 - val_loss: 4.9700e-05 - 11s/epoch - 6ms/step
# Epoch 93/500
# 1749/1749 - 10s - loss: 9.8871e-05 - val_loss: 4.5703e-05 - 10s/epoch - 6ms/step
# Epoch 94/500
# 1749/1749 - 10s - loss: 9.8755e-05 - val_loss: 4.4398e-05 - 10s/epoch - 6ms/step
# Epoch 95/500
# 1749/1749 - 8s - loss: 9.8641e-05 - val_loss: 4.3597e-05 - 8s/epoch - 4ms/step
# Epoch 96/500
# 1749/1749 - 8s - loss: 2.6394e-04 - val_loss: 5.3095e-05 - 8s/epoch - 4ms/step
# Epoch 97/500
# 1749/1749 - 8s - loss: 1.2162e-04 - val_loss: 4.1258e-05 - 8s/epoch - 5ms/step
# Epoch 98/500
# 1749/1749 - 8s - loss: 9.7269e-05 - val_loss: 4.2336e-05 - 8s/epoch - 5ms/step
# Epoch 99/500
# 1749/1749 - 9s - loss: 9.4009e-05 - val_loss: 3.5853e-05 - 9s/epoch - 5ms/step
# Epoch 100/500
# 1749/1749 - 8s - loss: 9.5456e-05 - val_loss: 6.3165e-05 - 8s/epoch - 5ms/step
# Epoch 101/500
# 1749/1749 - 8s - loss: 9.8229e-05 - val_loss: 6.6143e-05 - 8s/epoch - 5ms/step
# Epoch 102/500
# 1749/1749 - 8s - loss: 9.8828e-05 - val_loss: 6.0975e-05 - 8s/epoch - 5ms/step
# Epoch 103/500
# 1749/1749 - 6s - loss: 9.8914e-05 - val_loss: 5.6549e-05 - 6s/epoch - 3ms/step
# Epoch 104/500
# 1749/1749 - 5s - loss: 9.8894e-05 - val_loss: 5.3399e-05 - 5s/epoch - 3ms/step
# Epoch 105/500
# 1749/1749 - 5s - loss: 9.8826e-05 - val_loss: 5.1052e-05 - 5s/epoch - 3ms/step
# Epoch 106/500
# 1749/1749 - 5s - loss: 9.8737e-05 - val_loss: 4.9151e-05 - 5s/epoch - 3ms/step
# Epoch 107/500
# 1749/1749 - 5s - loss: 9.8641e-05 - val_loss: 4.7523e-05 - 5s/epoch - 3ms/step
# Epoch 108/500
# 1749/1749 - 5s - loss: 9.8540e-05 - val_loss: 4.6085e-05 - 5s/epoch - 3ms/step
# Epoch 109/500
# 1749/1749 - 5s - loss: 9.8441e-05 - val_loss: 4.4780e-05 - 5s/epoch - 3ms/step
# Epoch 110/500
# 1749/1749 - 5s - loss: 9.8343e-05 - val_loss: 4.3604e-05 - 5s/epoch - 3ms/step
# Epoch 111/500
# 1749/1749 - 5s - loss: 9.8244e-05 - val_loss: 4.2559e-05 - 5s/epoch - 3ms/step
# Epoch 112/500
# 1749/1749 - 5s - loss: 9.8145e-05 - val_loss: 4.1625e-05 - 5s/epoch - 3ms/step
# Epoch 113/500
# 1749/1749 - 5s - loss: 9.8047e-05 - val_loss: 4.0784e-05 - 5s/epoch - 3ms/step
# Epoch 114/500
# 1749/1749 - 5s - loss: 9.7949e-05 - val_loss: 4.0032e-05 - 5s/epoch - 3ms/step
# Epoch 115/500
# 1749/1749 - 5s - loss: 9.7853e-05 - val_loss: 3.9354e-05 - 5s/epoch - 3ms/step
# Epoch 116/500
# 1749/1749 - 5s - loss: 9.7754e-05 - val_loss: 3.8746e-05 - 5s/epoch - 3ms/step
# Epoch 117/500
# 1749/1749 - 5s - loss: 9.7660e-05 - val_loss: 3.8198e-05 - 5s/epoch - 3ms/step
# Epoch 118/500
# 1749/1749 - 5s - loss: 9.7566e-05 - val_loss: 3.7704e-05 - 5s/epoch - 3ms/step
# Epoch 119/500
# 1749/1749 - 5s - loss: 9.7475e-05 - val_loss: 3.7260e-05 - 5s/epoch - 3ms/step
# Epoch 120/500
# 1749/1749 - 5s - loss: 9.7384e-05 - val_loss: 3.6864e-05 - 5s/epoch - 3ms/step
# Epoch 121/500
# 1749/1749 - 5s - loss: 9.7295e-05 - val_loss: 3.6513e-05 - 5s/epoch - 3ms/step
# Epoch 122/500
# 1749/1749 - 5s - loss: 9.7209e-05 - val_loss: 3.6195e-05 - 5s/epoch - 3ms/step
# Epoch 123/500
# 1749/1749 - 5s - loss: 9.7122e-05 - val_loss: 3.5920e-05 - 5s/epoch - 3ms/step
# Epoch 124/500
# 1749/1749 - 5s - loss: 9.7039e-05 - val_loss: 3.5683e-05 - 5s/epoch - 3ms/step
# Epoch 125/500
# 1749/1749 - 5s - loss: 9.6952e-05 - val_loss: 3.5483e-05 - 5s/epoch - 3ms/step
# Epoch 126/500
# 1749/1749 - 5s - loss: 9.6872e-05 - val_loss: 3.5311e-05 - 5s/epoch - 3ms/step
# Epoch 127/500
# 1749/1749 - 5s - loss: 9.6788e-05 - val_loss: 3.5167e-05 - 5s/epoch - 3ms/step
# Epoch 128/500
# 1749/1749 - 5s - loss: 9.6707e-05 - val_loss: 3.5051e-05 - 5s/epoch - 3ms/step
# Epoch 129/500
# 1749/1749 - 5s - loss: 9.6627e-05 - val_loss: 3.4957e-05 - 5s/epoch - 3ms/step
# Epoch 130/500
# 1749/1749 - 5s - loss: 9.6549e-05 - val_loss: 3.4884e-05 - 5s/epoch - 3ms/step
# Epoch 131/500
# 1749/1749 - 5s - loss: 9.6471e-05 - val_loss: 3.4831e-05 - 5s/epoch - 3ms/step
# Epoch 132/500
# 1749/1749 - 5s - loss: 9.6394e-05 - val_loss: 3.4796e-05 - 5s/epoch - 3ms/step
# Epoch 133/500
# 1749/1749 - 6s - loss: 9.6319e-05 - val_loss: 3.4777e-05 - 6s/epoch - 3ms/step
# Epoch 134/500
# 1749/1749 - 5s - loss: 9.6242e-05 - val_loss: 3.4774e-05 - 5s/epoch - 3ms/step
# Epoch 135/500
# 1749/1749 - 5s - loss: 9.6161e-05 - val_loss: 3.4783e-05 - 5s/epoch - 3ms/step
# Epoch 136/500
# 1749/1749 - 5s - loss: 9.6082e-05 - val_loss: 3.4802e-05 - 5s/epoch - 3ms/step
# Epoch 137/500
# 1749/1749 - 5s - loss: 9.6004e-05 - val_loss: 3.4831e-05 - 5s/epoch - 3ms/step
# Epoch 138/500
# 1749/1749 - 5s - loss: 9.5925e-05 - val_loss: 3.4869e-05 - 5s/epoch - 3ms/step
# Epoch 139/500
# 1749/1749 - 5s - loss: 9.5844e-05 - val_loss: 3.4907e-05 - 5s/epoch - 3ms/step
# Epoch 140/500
# 1749/1749 - 5s - loss: 9.5764e-05 - val_loss: 3.4948e-05 - 5s/epoch - 3ms/step
# Epoch 141/500
# 1749/1749 - 5s - loss: 9.5680e-05 - val_loss: 3.4994e-05 - 5s/epoch - 3ms/step
# Epoch 142/500
# 1749/1749 - 5s - loss: 9.5599e-05 - val_loss: 3.5039e-05 - 5s/epoch - 3ms/step
# Epoch 143/500
# 1749/1749 - 7s - loss: 9.5511e-05 - val_loss: 3.5083e-05 - 7s/epoch - 4ms/step
# Epoch 144/500
# 1749/1749 - 6s - loss: 9.5425e-05 - val_loss: 3.5124e-05 - 6s/epoch - 3ms/step
# Epoch 145/500
# 1749/1749 - 6s - loss: 9.5341e-05 - val_loss: 3.5159e-05 - 6s/epoch - 4ms/step
# Epoch 146/500
# 1749/1749 - 6s - loss: 9.5254e-05 - val_loss: 3.5184e-05 - 6s/epoch - 4ms/step
# Epoch 147/500
# 1749/1749 - 7s - loss: 9.5168e-05 - val_loss: 3.5195e-05 - 7s/epoch - 4ms/step
# Epoch 148/500
# 1749/1749 - 7s - loss: 9.5083e-05 - val_loss: 3.5191e-05 - 7s/epoch - 4ms/step
# Epoch 149/500
# 1749/1749 - 6s - loss: 9.4999e-05 - val_loss: 3.5177e-05 - 6s/epoch - 3ms/step
# Epoch 150/500
# 1749/1749 - 9s - loss: 9.4917e-05 - val_loss: 3.5160e-05 - 9s/epoch - 5ms/step
# Epoch 151/500
# 1749/1749 - 10s - loss: 9.4839e-05 - val_loss: 3.5146e-05 - 10s/epoch - 6ms/step
# Epoch 152/500
# 1749/1749 - 12s - loss: 9.4764e-05 - val_loss: 3.5135e-05 - 12s/epoch - 7ms/step
# Epoch 153/500
# 1749/1749 - 7s - loss: 9.4692e-05 - val_loss: 3.5129e-05 - 7s/epoch - 4ms/step
# Epoch 154/500
# 1749/1749 - 7s - loss: 9.4622e-05 - val_loss: 3.5127e-05 - 7s/epoch - 4ms/step
# Epoch 155/500
# 1749/1749 - 6s - loss: 9.4556e-05 - val_loss: 3.5130e-05 - 6s/epoch - 3ms/step
# Epoch 156/500
# 1749/1749 - 5s - loss: 9.4490e-05 - val_loss: 3.5136e-05 - 5s/epoch - 3ms/step
# Epoch 157/500
# 1749/1749 - 5s - loss: 9.4427e-05 - val_loss: 3.5146e-05 - 5s/epoch - 3ms/step
# Epoch 158/500
# 1749/1749 - 6s - loss: 9.4366e-05 - val_loss: 3.5158e-05 - 6s/epoch - 3ms/step
# Epoch 159/500
# 1749/1749 - 6s - loss: 9.4304e-05 - val_loss: 3.5172e-05 - 6s/epoch - 3ms/step
# Epoch 160/500
# 1749/1749 - 5s - loss: 9.4246e-05 - val_loss: 3.5189e-05 - 5s/epoch - 3ms/step
# Epoch 161/500
# 1749/1749 - 5s - loss: 9.4188e-05 - val_loss: 3.5206e-05 - 5s/epoch - 3ms/step
# Epoch 162/500
# 1749/1749 - 5s - loss: 9.4132e-05 - val_loss: 3.5225e-05 - 5s/epoch - 3ms/step
# Epoch 163/500
# 1749/1749 - 5s - loss: 9.4073e-05 - val_loss: 3.5246e-05 - 5s/epoch - 3ms/step
# Epoch 164/500
# 1749/1749 - 8s - loss: 9.4019e-05 - val_loss: 3.5269e-05 - 8s/epoch - 5ms/step
# Epoch 165/500
# 1749/1749 - 9s - loss: 9.3965e-05 - val_loss: 3.5290e-05 - 9s/epoch - 5ms/step
# Epoch 166/500
# 1749/1749 - 8s - loss: 9.3911e-05 - val_loss: 3.5315e-05 - 8s/epoch - 5ms/step
# Epoch 167/500
# 1749/1749 - 10s - loss: 9.3860e-05 - val_loss: 3.5341e-05 - 10s/epoch - 6ms/step
# Epoch 168/500
# 1749/1749 - 9s - loss: 9.3808e-05 - val_loss: 3.5368e-05 - 9s/epoch - 5ms/step
# Epoch 169/500
# 1749/1749 - 9s - loss: 9.3759e-05 - val_loss: 3.5397e-05 - 9s/epoch - 5ms/step
# Epoch 170/500
# 1749/1749 - 13s - loss: 9.3710e-05 - val_loss: 3.5426e-05 - 13s/epoch - 8ms/step
# Epoch 171/500
# 1749/1749 - 11s - loss: 9.3663e-05 - val_loss: 3.5456e-05 - 11s/epoch - 6ms/step
# Epoch 172/500
# 1749/1749 - 18s - loss: 9.3616e-05 - val_loss: 3.5489e-05 - 18s/epoch - 11ms/step
# Epoch 173/500
# 1749/1749 - 13s - loss: 9.3571e-05 - val_loss: 3.5521e-05 - 13s/epoch - 7ms/step
# Epoch 174/500
# 1749/1749 - 12s - loss: 9.3526e-05 - val_loss: 3.5553e-05 - 12s/epoch - 7ms/step
# Epoch 175/500
# 1749/1749 - 9s - loss: 9.3483e-05 - val_loss: 3.5585e-05 - 9s/epoch - 5ms/step
# Epoch 176/500
# 1749/1749 - 6s - loss: 9.3439e-05 - val_loss: 3.5615e-05 - 6s/epoch - 3ms/step
# Epoch 177/500
# 1749/1749 - 6s - loss: 9.3396e-05 - val_loss: 3.5646e-05 - 6s/epoch - 3ms/step
# Epoch 178/500
# 1749/1749 - 7s - loss: 9.3354e-05 - val_loss: 3.5676e-05 - 7s/epoch - 4ms/step
# Epoch 179/500
# 1749/1749 - 6s - loss: 9.3312e-05 - val_loss: 3.5707e-05 - 6s/epoch - 3ms/step
# Epoch 180/500
# 1749/1749 - 7s - loss: 9.3271e-05 - val_loss: 3.5738e-05 - 7s/epoch - 4ms/step
# Epoch 181/500
# 1749/1749 - 7s - loss: 9.3230e-05 - val_loss: 3.5769e-05 - 7s/epoch - 4ms/step
# Epoch 182/500
# 1749/1749 - 6s - loss: 9.3191e-05 - val_loss: 3.5798e-05 - 6s/epoch - 4ms/step
# Epoch 183/500
# 1749/1749 - 6s - loss: 9.3152e-05 - val_loss: 3.5828e-05 - 6s/epoch - 3ms/step
# Epoch 184/500
# 1749/1749 - 6s - loss: 9.3112e-05 - val_loss: 3.5858e-05 - 6s/epoch - 4ms/step
# Epoch 185/500
# 1749/1749 - 6s - loss: 9.3073e-05 - val_loss: 3.5889e-05 - 6s/epoch - 4ms/step
# Epoch 186/500
# 1749/1749 - 7s - loss: 9.3035e-05 - val_loss: 3.5918e-05 - 7s/epoch - 4ms/step
# Epoch 187/500
# 1749/1749 - 7s - loss: 9.2998e-05 - val_loss: 3.5949e-05 - 7s/epoch - 4ms/step
# Epoch 188/500
# 1749/1749 - 6s - loss: 9.2960e-05 - val_loss: 3.5977e-05 - 6s/epoch - 3ms/step
# Epoch 189/500
# 1749/1749 - 7s - loss: 9.2923e-05 - val_loss: 3.6006e-05 - 7s/epoch - 4ms/step
# Epoch 190/500
# 1749/1749 - 10s - loss: 9.2887e-05 - val_loss: 3.6034e-05 - 10s/epoch - 6ms/step
# Epoch 191/500
# 1749/1749 - 10s - loss: 9.2851e-05 - val_loss: 3.6062e-05 - 10s/epoch - 6ms/step
# Epoch 192/500
# 1749/1749 - 8s - loss: 9.2815e-05 - val_loss: 3.6090e-05 - 8s/epoch - 5ms/step
# Epoch 193/500
# 1749/1749 - 7s - loss: 9.2780e-05 - val_loss: 3.6117e-05 - 7s/epoch - 4ms/step
# Epoch 194/500
# 1749/1749 - 9s - loss: 9.2745e-05 - val_loss: 3.6143e-05 - 9s/epoch - 5ms/step
# Epoch 195/500
# 1749/1749 - 10s - loss: 9.2710e-05 - val_loss: 3.6170e-05 - 10s/epoch - 6ms/step
# Epoch 196/500
# 1749/1749 - 12s - loss: 9.2675e-05 - val_loss: 3.6195e-05 - 12s/epoch - 7ms/step
# Epoch 197/500
# 1749/1749 - 13s - loss: 9.2641e-05 - val_loss: 3.6222e-05 - 13s/epoch - 7ms/step
# Epoch 198/500
# 1749/1749 - 10s - loss: 9.2608e-05 - val_loss: 3.6244e-05 - 10s/epoch - 6ms/step
# Epoch 199/500
# 1749/1749 - 14s - loss: 9.2574e-05 - val_loss: 3.6269e-05 - 14s/epoch - 8ms/step
# Epoch 200/500
# 1749/1749 - 14s - loss: 9.2540e-05 - val_loss: 3.6292e-05 - 14s/epoch - 8ms/step
# Epoch 201/500
# 1749/1749 - 13s - loss: 9.2509e-05 - val_loss: 3.6315e-05 - 13s/epoch - 8ms/step
# Epoch 202/500
# 1749/1749 - 12s - loss: 9.2475e-05 - val_loss: 3.6337e-05 - 12s/epoch - 7ms/step
# Epoch 203/500
# 1749/1749 - 11s - loss: 9.2443e-05 - val_loss: 3.6360e-05 - 11s/epoch - 6ms/step
# Epoch 204/500
# 1749/1749 - 14s - loss: 9.2410e-05 - val_loss: 3.6380e-05 - 14s/epoch - 8ms/step
# Epoch 205/500
# 1749/1749 - 14s - loss: 9.2379e-05 - val_loss: 3.6402e-05 - 14s/epoch - 8ms/step
# Epoch 206/500
# 1749/1749 - 14s - loss: 9.2347e-05 - val_loss: 3.6422e-05 - 14s/epoch - 8ms/step
# Epoch 207/500
# 1749/1749 - 12s - loss: 9.2316e-05 - val_loss: 3.6441e-05 - 12s/epoch - 7ms/step
# Epoch 208/500
# 1749/1749 - 11s - loss: 9.2285e-05 - val_loss: 3.6461e-05 - 11s/epoch - 6ms/step
# Epoch 209/500
# 1749/1749 - 10s - loss: 9.2254e-05 - val_loss: 3.6479e-05 - 10s/epoch - 6ms/step
# Epoch 210/500
# 1749/1749 - 8s - loss: 9.2223e-05 - val_loss: 3.6497e-05 - 8s/epoch - 5ms/step
# Epoch 211/500
# 1749/1749 - 12s - loss: 9.2193e-05 - val_loss: 3.6515e-05 - 12s/epoch - 7ms/step
# Epoch 212/500
# 1749/1749 - 9s - loss: 9.2164e-05 - val_loss: 3.6532e-05 - 9s/epoch - 5ms/step
# Epoch 213/500
# 1749/1749 - 9s - loss: 9.2133e-05 - val_loss: 3.6550e-05 - 9s/epoch - 5ms/step
# Epoch 214/500
# 1749/1749 - 10s - loss: 9.2103e-05 - val_loss: 3.6565e-05 - 10s/epoch - 5ms/step
# Epoch 215/500
# 1749/1749 - 10s - loss: 9.2074e-05 - val_loss: 3.6582e-05 - 10s/epoch - 5ms/step
# Epoch 216/500
# 1749/1749 - 11s - loss: 9.2045e-05 - val_loss: 3.6597e-05 - 11s/epoch - 6ms/step
# Epoch 217/500
# 1749/1749 - 12s - loss: 9.2016e-05 - val_loss: 3.6612e-05 - 12s/epoch - 7ms/step
# Epoch 218/500
# 1749/1749 - 12s - loss: 9.1987e-05 - val_loss: 3.6627e-05 - 12s/epoch - 7ms/step
# Epoch 219/500
# 1749/1749 - 13s - loss: 9.1959e-05 - val_loss: 3.6641e-05 - 13s/epoch - 7ms/step
# Epoch 220/500
# 1749/1749 - 12s - loss: 9.1930e-05 - val_loss: 3.6654e-05 - 12s/epoch - 7ms/step
# Epoch 221/500
# 1749/1749 - 9s - loss: 9.1903e-05 - val_loss: 3.6668e-05 - 9s/epoch - 5ms/step
# Epoch 222/500
# 1749/1749 - 11s - loss: 9.1875e-05 - val_loss: 3.6681e-05 - 11s/epoch - 6ms/step
# Epoch 223/500
# 1749/1749 - 10s - loss: 9.1847e-05 - val_loss: 3.6694e-05 - 10s/epoch - 6ms/step
# Epoch 224/500
# 1749/1749 - 11s - loss: 9.1820e-05 - val_loss: 3.6706e-05 - 11s/epoch - 6ms/step
# Epoch 225/500
# 1749/1749 - 11s - loss: 9.1793e-05 - val_loss: 3.6718e-05 - 11s/epoch - 6ms/step
# Epoch 226/500
# 1749/1749 - 11s - loss: 9.1766e-05 - val_loss: 3.6736e-05 - 11s/epoch - 7ms/step
# Epoch 227/500
# 1749/1749 - 11s - loss: 9.1739e-05 - val_loss: 3.6741e-05 - 11s/epoch - 6ms/step
# Epoch 228/500
# 1749/1749 - 11s - loss: 9.1713e-05 - val_loss: 3.6752e-05 - 11s/epoch - 7ms/step
# Epoch 229/500
# 1749/1749 - 12s - loss: 9.1686e-05 - val_loss: 3.6763e-05 - 12s/epoch - 7ms/step
# Epoch 230/500
# 1749/1749 - 12s - loss: 9.1661e-05 - val_loss: 3.6775e-05 - 12s/epoch - 7ms/step
# Epoch 231/500
# 1749/1749 - 12s - loss: 9.1635e-05 - val_loss: 3.6784e-05 - 12s/epoch - 7ms/step
# Epoch 232/500
# 1749/1749 - 12s - loss: 9.1609e-05 - val_loss: 3.6794e-05 - 12s/epoch - 7ms/step
# Epoch 233/500
# 1749/1749 - 12s - loss: 9.1584e-05 - val_loss: 3.6804e-05 - 12s/epoch - 7ms/step
# Epoch 234/500
# 1749/1749 - 12s - loss: 9.1559e-05 - val_loss: 3.6813e-05 - 12s/epoch - 7ms/step
# Epoch 235/500
# 1749/1749 - 12s - loss: 9.1534e-05 - val_loss: 3.6822e-05 - 12s/epoch - 7ms/step
# Epoch 236/500
# 1749/1749 - 12s - loss: 9.1509e-05 - val_loss: 3.6831e-05 - 12s/epoch - 7ms/step
# Epoch 237/500
# 1749/1749 - 12s - loss: 9.1485e-05 - val_loss: 3.6841e-05 - 12s/epoch - 7ms/step
# Epoch 238/500
# 1749/1749 - 10s - loss: 9.1460e-05 - val_loss: 3.6849e-05 - 10s/epoch - 6ms/step
# Epoch 239/500
# 1749/1749 - 8s - loss: 9.1435e-05 - val_loss: 3.6857e-05 - 8s/epoch - 5ms/step
# Epoch 240/500
# 1749/1749 - 8s - loss: 9.1412e-05 - val_loss: 3.6863e-05 - 8s/epoch - 5ms/step
# Epoch 241/500
# 1749/1749 - 8s - loss: 9.1388e-05 - val_loss: 3.6871e-05 - 8s/epoch - 5ms/step
# Epoch 242/500
# 1749/1749 - 8s - loss: 9.1364e-05 - val_loss: 3.6878e-05 - 8s/epoch - 5ms/step
# Epoch 243/500
# 1749/1749 - 8s - loss: 9.1341e-05 - val_loss: 3.6886e-05 - 8s/epoch - 5ms/step
# Epoch 244/500
# 1749/1749 - 8s - loss: 9.1318e-05 - val_loss: 3.6893e-05 - 8s/epoch - 5ms/step
# Epoch 245/500
# 1749/1749 - 8s - loss: 9.1294e-05 - val_loss: 3.6898e-05 - 8s/epoch - 5ms/step
# Epoch 246/500
# 1749/1749 - 8s - loss: 9.1272e-05 - val_loss: 3.6905e-05 - 8s/epoch - 5ms/step
# Epoch 247/500
# 1749/1749 - 8s - loss: 9.1249e-05 - val_loss: 3.6911e-05 - 8s/epoch - 5ms/step
# Epoch 248/500
# 1749/1749 - 9s - loss: 9.1226e-05 - val_loss: 3.6916e-05 - 9s/epoch - 5ms/step
# Epoch 249/500
# 1749/1749 - 8s - loss: 9.1204e-05 - val_loss: 3.6922e-05 - 8s/epoch - 5ms/step
# Epoch 250/500
# 1749/1749 - 9s - loss: 9.1181e-05 - val_loss: 3.6927e-05 - 9s/epoch - 5ms/step
# Epoch 251/500
# 1749/1749 - 8s - loss: 9.1160e-05 - val_loss: 3.6932e-05 - 8s/epoch - 5ms/step
# Epoch 252/500
# 1749/1749 - 8s - loss: 9.1137e-05 - val_loss: 3.6936e-05 - 8s/epoch - 5ms/step
# Epoch 253/500
# 1749/1749 - 9s - loss: 9.1116e-05 - val_loss: 3.6941e-05 - 9s/epoch - 5ms/step
# Epoch 254/500
# 1749/1749 - 8s - loss: 9.1094e-05 - val_loss: 3.6944e-05 - 8s/epoch - 5ms/step
# Epoch 255/500
# 1749/1749 - 9s - loss: 9.1073e-05 - val_loss: 3.6948e-05 - 9s/epoch - 5ms/step
# Epoch 256/500
# 1749/1749 - 9s - loss: 9.1052e-05 - val_loss: 3.6953e-05 - 9s/epoch - 5ms/step
# Epoch 257/500
# 1749/1749 - 9s - loss: 9.1031e-05 - val_loss: 3.6957e-05 - 9s/epoch - 5ms/step
# Epoch 258/500
# 1749/1749 - 8s - loss: 9.1010e-05 - val_loss: 3.6960e-05 - 8s/epoch - 5ms/step
# Epoch 259/500
# 1749/1749 - 9s - loss: 9.0989e-05 - val_loss: 3.6963e-05 - 9s/epoch - 5ms/step
# Epoch 260/500
# 1749/1749 - 9s - loss: 9.0969e-05 - val_loss: 3.6965e-05 - 9s/epoch - 5ms/step
# Epoch 261/500
# 1749/1749 - 13s - loss: 9.0948e-05 - val_loss: 3.6969e-05 - 13s/epoch - 7ms/step
# Epoch 262/500
# 1749/1749 - 10s - loss: 9.0928e-05 - val_loss: 3.6972e-05 - 10s/epoch - 6ms/step
# Epoch 263/500
# 1749/1749 - 16s - loss: 9.0907e-05 - val_loss: 3.6975e-05 - 16s/epoch - 9ms/step
# Epoch 264/500
# 1749/1749 - 8s - loss: 9.0887e-05 - val_loss: 3.6979e-05 - 8s/epoch - 5ms/step
# Epoch 265/500
# 1749/1749 - 9s - loss: 9.0867e-05 - val_loss: 3.6983e-05 - 9s/epoch - 5ms/step
# Epoch 266/500
# 1749/1749 - 10s - loss: 9.0847e-05 - val_loss: 3.6987e-05 - 10s/epoch - 6ms/step
# Epoch 267/500
# 1749/1749 - 10s - loss: 9.0828e-05 - val_loss: 3.6991e-05 - 10s/epoch - 6ms/step
# Epoch 268/500
# 1749/1749 - 10s - loss: 9.0808e-05 - val_loss: 3.6995e-05 - 10s/epoch - 6ms/step
# Epoch 269/500
# 1749/1749 - 10s - loss: 9.0788e-05 - val_loss: 3.7000e-05 - 10s/epoch - 6ms/step
# Epoch 270/500
# 1749/1749 - 10s - loss: 9.0769e-05 - val_loss: 3.7005e-05 - 10s/epoch - 6ms/step
# Epoch 271/500
# 1749/1749 - 11s - loss: 9.0749e-05 - val_loss: 3.7010e-05 - 11s/epoch - 6ms/step
# Epoch 272/500
# 1749/1749 - 10s - loss: 9.0730e-05 - val_loss: 3.7021e-05 - 10s/epoch - 6ms/step
# Epoch 273/500
# 1749/1749 - 10s - loss: 9.0711e-05 - val_loss: 3.7026e-05 - 10s/epoch - 6ms/step
# Epoch 274/500
# 1749/1749 - 9s - loss: 9.0692e-05 - val_loss: 3.7037e-05 - 9s/epoch - 5ms/step
# Epoch 275/500
# 1749/1749 - 9s - loss: 9.0672e-05 - val_loss: 3.7048e-05 - 9s/epoch - 5ms/step
# Epoch 276/500
# 1749/1749 - 8s - loss: 9.0653e-05 - val_loss: 3.7060e-05 - 8s/epoch - 5ms/step
# Epoch 277/500
# 1749/1749 - 9s - loss: 9.0634e-05 - val_loss: 3.7074e-05 - 9s/epoch - 5ms/step
# Epoch 278/500
# 1749/1749 - 9s - loss: 9.0614e-05 - val_loss: 3.7086e-05 - 9s/epoch - 5ms/step
# Epoch 279/500
# 1749/1749 - 8s - loss: 9.0595e-05 - val_loss: 3.7101e-05 - 8s/epoch - 5ms/step
# Epoch 280/500
# 1749/1749 - 8s - loss: 9.0574e-05 - val_loss: 3.7117e-05 - 8s/epoch - 5ms/step
# Epoch 281/500
# 1749/1749 - 9s - loss: 9.0556e-05 - val_loss: 3.7132e-05 - 9s/epoch - 5ms/step
# Epoch 282/500
# 1749/1749 - 9s - loss: 9.0535e-05 - val_loss: 3.7149e-05 - 9s/epoch - 5ms/step
# Epoch 283/500
# 1749/1749 - 8s - loss: 9.0515e-05 - val_loss: 3.7165e-05 - 8s/epoch - 5ms/step
# Epoch 284/500
# 1749/1749 - 8s - loss: 9.0496e-05 - val_loss: 3.7182e-05 - 8s/epoch - 5ms/step
# Epoch 285/500
# 1749/1749 - 8s - loss: 9.0475e-05 - val_loss: 3.7199e-05 - 8s/epoch - 5ms/step
# Epoch 286/500
# 1749/1749 - 8s - loss: 9.0455e-05 - val_loss: 3.7215e-05 - 8s/epoch - 5ms/step
# Epoch 287/500
# 1749/1749 - 9s - loss: 9.0435e-05 - val_loss: 3.7230e-05 - 9s/epoch - 5ms/step
# Epoch 288/500
# 1749/1749 - 9s - loss: 9.0415e-05 - val_loss: 3.7245e-05 - 9s/epoch - 5ms/step
# Epoch 289/500
# 1749/1749 - 9s - loss: 9.0395e-05 - val_loss: 3.7260e-05 - 9s/epoch - 5ms/step
# Epoch 290/500
# 1749/1749 - 9s - loss: 9.0375e-05 - val_loss: 3.7276e-05 - 9s/epoch - 5ms/step
# Epoch 291/500
# 1749/1749 - 8s - loss: 9.0356e-05 - val_loss: 3.7292e-05 - 8s/epoch - 5ms/step
# Epoch 292/500
# 1749/1749 - 8s - loss: 9.0336e-05 - val_loss: 3.7306e-05 - 8s/epoch - 5ms/step
# Epoch 293/500
# 1749/1749 - 8s - loss: 9.0317e-05 - val_loss: 3.7320e-05 - 8s/epoch - 5ms/step
# Epoch 294/500
# 1749/1749 - 8s - loss: 9.0298e-05 - val_loss: 3.7336e-05 - 8s/epoch - 5ms/step
# Epoch 295/500
# 1749/1749 - 8s - loss: 9.0277e-05 - val_loss: 3.7349e-05 - 8s/epoch - 5ms/step
# Epoch 296/500
# 1749/1749 - 8s - loss: 9.0258e-05 - val_loss: 3.7363e-05 - 8s/epoch - 5ms/step
# Epoch 297/500
# 1749/1749 - 8s - loss: 9.0239e-05 - val_loss: 3.7378e-05 - 8s/epoch - 5ms/step
# Epoch 298/500
# 1749/1749 - 8s - loss: 9.0220e-05 - val_loss: 3.7390e-05 - 8s/epoch - 5ms/step
# Epoch 299/500
# 1749/1749 - 8s - loss: 9.0200e-05 - val_loss: 3.7400e-05 - 8s/epoch - 5ms/step
# Epoch 300/500
# 1749/1749 - 8s - loss: 9.0183e-05 - val_loss: 3.7415e-05 - 8s/epoch - 5ms/step
# Epoch 301/500
# 1749/1749 - 8s - loss: 9.0163e-05 - val_loss: 3.7425e-05 - 8s/epoch - 5ms/step
# Epoch 302/500
# 1749/1749 - 8s - loss: 9.0146e-05 - val_loss: 3.7443e-05 - 8s/epoch - 5ms/step
# Epoch 303/500
# 1749/1749 - 8s - loss: 9.0126e-05 - val_loss: 3.7445e-05 - 8s/epoch - 5ms/step
# Epoch 304/500
# 1749/1749 - 8s - loss: 9.0113e-05 - val_loss: 3.7485e-05 - 8s/epoch - 5ms/step
# Epoch 305/500
# 1749/1749 - 8s - loss: 9.0088e-05 - val_loss: 3.7454e-05 - 8s/epoch - 5ms/step
# Epoch 306/500
# 1749/1749 - 8s - loss: 9.0095e-05 - val_loss: 3.7628e-05 - 8s/epoch - 5ms/step
# Epoch 307/500
# 1749/1749 - 8s - loss: 9.0022e-05 - val_loss: 3.7223e-05 - 8s/epoch - 5ms/step
# Epoch 308/500
# 1749/1749 - 8s - loss: 9.0056e-05 - val_loss: 3.7491e-05 - 8s/epoch - 5ms/step
# Epoch 309/500
# 1749/1749 - 8s - loss: 9.0054e-05 - val_loss: 3.7695e-05 - 8s/epoch - 5ms/step
# Epoch 310/500
# 1749/1749 - 8s - loss: 8.9977e-05 - val_loss: 3.7303e-05 - 8s/epoch - 5ms/step
# Epoch 311/500
# 1749/1749 - 8s - loss: 9.0019e-05 - val_loss: 3.7653e-05 - 8s/epoch - 5ms/step
# Epoch 312/500
# 1749/1749 - 8s - loss: 8.9984e-05 - val_loss: 3.7593e-05 - 8s/epoch - 5ms/step
# Epoch 313/500
# 1749/1749 - 8s - loss: 8.9976e-05 - val_loss: 3.7786e-05 - 8s/epoch - 5ms/step
# Epoch 314/500
# 1749/1749 - 8s - loss: 8.9912e-05 - val_loss: 3.7115e-05 - 8s/epoch - 5ms/step
# Epoch 315/500
# 1749/1749 - 8s - loss: 8.9990e-05 - val_loss: 3.6753e-05 - 8s/epoch - 5ms/step
# Epoch 316/500
# 1749/1749 - 9s - loss: 9.0048e-05 - val_loss: 3.6855e-05 - 9s/epoch - 5ms/step
# Epoch 317/500
# 1749/1749 - 9s - loss: 9.0036e-05 - val_loss: 3.7252e-05 - 9s/epoch - 5ms/step
# Epoch 318/500
# 1749/1749 - 9s - loss: 9.0100e-05 - val_loss: 3.8077e-05 - 9s/epoch - 5ms/step
# Epoch 319/500
# 1749/1749 - 8s - loss: 8.9952e-05 - val_loss: 3.8171e-05 - 8s/epoch - 5ms/step
# Epoch 320/500
# 1749/1749 - 9s - loss: 8.9953e-05 - val_loss: 3.8036e-05 - 9s/epoch - 5ms/step
# Epoch 321/500
# 1749/1749 - 9s - loss: 8.9885e-05 - val_loss: 3.7727e-05 - 9s/epoch - 5ms/step
# Epoch 322/500
# 1749/1749 - 8s - loss: 8.9888e-05 - val_loss: 3.7893e-05 - 8s/epoch - 5ms/step
# Epoch 323/500
# 1749/1749 - 8s - loss: 8.9812e-05 - val_loss: 3.7547e-05 - 8s/epoch - 5ms/step
# Epoch 324/500
# 1749/1749 - 9s - loss: 8.9835e-05 - val_loss: 3.7864e-05 - 9s/epoch - 5ms/step
# Epoch 325/500
# 1749/1749 - 9s - loss: 8.9800e-05 - val_loss: 3.7658e-05 - 9s/epoch - 5ms/step
# Epoch 326/500
# 1749/1749 - 9s - loss: 8.9813e-05 - val_loss: 3.7964e-05 - 9s/epoch - 5ms/step
# Epoch 327/500
# 1749/1749 - 9s - loss: 8.9737e-05 - val_loss: 3.7523e-05 - 9s/epoch - 5ms/step
# Epoch 328/500
# 1749/1749 - 8s - loss: 8.9800e-05 - val_loss: 3.7949e-05 - 8s/epoch - 5ms/step
# Epoch 329/500
# 1749/1749 - 8s - loss: 8.9741e-05 - val_loss: 3.7815e-05 - 8s/epoch - 5ms/step
# Epoch 330/500
# 1749/1749 - 9s - loss: 8.9699e-05 - val_loss: 3.7920e-05 - 9s/epoch - 5ms/step
# Epoch 331/500
# 1749/1749 - 9s - loss: 8.9699e-05 - val_loss: 3.7491e-05 - 9s/epoch - 5ms/step
# Epoch 332/500
# 1749/1749 - 8s - loss: 8.9736e-05 - val_loss: 3.7563e-05 - 8s/epoch - 5ms/step
# Epoch 333/500
# 1749/1749 - 9s - loss: 8.9765e-05 - val_loss: 3.8150e-05 - 9s/epoch - 5ms/step
# Epoch 334/500
# 1749/1749 - 9s - loss: 8.9651e-05 - val_loss: 3.7918e-05 - 9s/epoch - 5ms/step
# Epoch 335/500
# 1749/1749 - 9s - loss: 8.9656e-05 - val_loss: 3.7792e-05 - 9s/epoch - 5ms/step
# Epoch 336/500
# 1749/1749 - 8s - loss: 8.9670e-05 - val_loss: 3.8091e-05 - 8s/epoch - 5ms/step
# Epoch 337/500
# 1749/1749 - 9s - loss: 8.9581e-05 - val_loss: 3.7431e-05 - 9s/epoch - 5ms/step
# Epoch 338/500
# 1749/1749 - 9s - loss: 8.9687e-05 - val_loss: 3.7850e-05 - 9s/epoch - 5ms/step
# Epoch 339/500
# 1749/1749 - 8s - loss: 8.9671e-05 - val_loss: 3.8145e-05 - 8s/epoch - 5ms/step
# Epoch 340/500
# 1749/1749 - 8s - loss: 8.9510e-05 - val_loss: 3.7238e-05 - 8s/epoch - 5ms/step
# Epoch 341/500
# 1749/1749 - 9s - loss: 8.9653e-05 - val_loss: 3.7469e-05 - 9s/epoch - 5ms/step
# Epoch 342/500
# 1749/1749 - 9s - loss: 8.9649e-05 - val_loss: 3.7450e-05 - 9s/epoch - 5ms/step
# Epoch 343/500
# 1749/1749 - 8s - loss: 8.9749e-05 - val_loss: 3.8211e-05 - 8s/epoch - 5ms/step
# Epoch 344/500
# 1749/1749 - 8s - loss: 8.9595e-05 - val_loss: 3.8308e-05 - 8s/epoch - 5ms/step
# Epoch 345/500
# 1749/1749 - 8s - loss: 8.9630e-05 - val_loss: 3.8245e-05 - 8s/epoch - 5ms/step
# Epoch 346/500
# 1749/1749 - 9s - loss: 8.9522e-05 - val_loss: 3.7813e-05 - 9s/epoch - 5ms/step
# Epoch 347/500
# 1749/1749 - 9s - loss: 8.9570e-05 - val_loss: 3.8163e-05 - 9s/epoch - 5ms/step
# Epoch 348/500
# 1749/1749 - 9s - loss: 8.9477e-05 - val_loss: 3.7804e-05 - 9s/epoch - 5ms/step
# Epoch 349/500
# 1749/1749 - 8s - loss: 8.9513e-05 - val_loss: 3.8142e-05 - 8s/epoch - 5ms/step
# Epoch 350/500
# 1749/1749 - 9s - loss: 8.9465e-05 - val_loss: 3.7836e-05 - 9s/epoch - 5ms/step
# Epoch 351/500
# 1749/1749 - 9s - loss: 8.9546e-05 - val_loss: 3.8268e-05 - 9s/epoch - 5ms/step
# Epoch 352/500
# 1749/1749 - 9s - loss: 8.9356e-05 - val_loss: 3.7465e-05 - 9s/epoch - 5ms/step
# Epoch 353/500
# 1749/1749 - 9s - loss: 8.9515e-05 - val_loss: 3.8151e-05 - 9s/epoch - 5ms/step
# Epoch 354/500
# 1749/1749 - 9s - loss: 8.9415e-05 - val_loss: 3.8143e-05 - 9s/epoch - 5ms/step
# Epoch 355/500
# 1749/1749 - 9s - loss: 8.9512e-05 - val_loss: 3.8090e-05 - 9s/epoch - 5ms/step
# Epoch 356/500
# 1749/1749 - 9s - loss: 8.9396e-05 - val_loss: 3.6854e-05 - 9s/epoch - 5ms/step
# Epoch 357/500
# 1749/1749 - 9s - loss: 8.9507e-05 - val_loss: 3.7262e-05 - 9s/epoch - 5ms/step
# Epoch 358/500
# 1749/1749 - 9s - loss: 8.9487e-05 - val_loss: 3.7629e-05 - 9s/epoch - 5ms/step
# Epoch 359/500
# 1749/1749 - 8s - loss: 8.9535e-05 - val_loss: 3.8285e-05 - 8s/epoch - 5ms/step
# Epoch 360/500
# 1749/1749 - 9s - loss: 8.9441e-05 - val_loss: 3.8465e-05 - 9s/epoch - 5ms/step
# Epoch 361/500
# 1749/1749 - 8s - loss: 8.9387e-05 - val_loss: 3.8205e-05 - 8s/epoch - 5ms/step
# Epoch 362/500
# 1749/1749 - 9s - loss: 8.9363e-05 - val_loss: 3.8191e-05 - 9s/epoch - 5ms/step
# Epoch 363/500
# 1749/1749 - 12s - loss: 8.9417e-05 - val_loss: 3.8224e-05 - 12s/epoch - 7ms/step
# Epoch 364/500
# 1749/1749 - 10s - loss: 8.9251e-05 - val_loss: 3.7120e-05 - 10s/epoch - 6ms/step
# Epoch 365/500
# 1749/1749 - 13s - loss: 8.9418e-05 - val_loss: 3.7393e-05 - 13s/epoch - 7ms/step
# Epoch 366/500
# 1749/1749 - 14s - loss: 8.9399e-05 - val_loss: 3.7763e-05 - 14s/epoch - 8ms/step
# Epoch 367/500
# 1749/1749 - 9s - loss: 8.9466e-05 - val_loss: 3.8656e-05 - 9s/epoch - 5ms/step
# Epoch 368/500
# 1749/1749 - 9s - loss: 8.9319e-05 - val_loss: 3.8559e-05 - 9s/epoch - 5ms/step
# Epoch 369/500
# 1749/1749 - 9s - loss: 8.9302e-05 - val_loss: 3.8406e-05 - 9s/epoch - 5ms/step
# Epoch 370/500
# 1749/1749 - 9s - loss: 8.9275e-05 - val_loss: 3.8164e-05 - 9s/epoch - 5ms/step
# Epoch 371/500
# 1749/1749 - 9s - loss: 8.9242e-05 - val_loss: 3.8177e-05 - 9s/epoch - 5ms/step
# Epoch 372/500
# 1749/1749 - 9s - loss: 8.9192e-05 - val_loss: 3.8255e-05 - 9s/epoch - 5ms/step
# Epoch 373/500
# 1749/1749 - 9s - loss: 8.9193e-05 - val_loss: 3.7903e-05 - 9s/epoch - 5ms/step
# Epoch 374/500
# 1749/1749 - 9s - loss: 8.9207e-05 - val_loss: 3.7913e-05 - 9s/epoch - 5ms/step
# Epoch 375/500
# 1749/1749 - 9s - loss: 8.9240e-05 - val_loss: 3.8367e-05 - 9s/epoch - 5ms/step
# Epoch 376/500
# 1749/1749 - 8s - loss: 8.9154e-05 - val_loss: 3.8196e-05 - 8s/epoch - 5ms/step
# Epoch 377/500
# 1749/1749 - 8s - loss: 8.9145e-05 - val_loss: 3.8354e-05 - 8s/epoch - 5ms/step
# Epoch 378/500
# 1749/1749 - 9s - loss: 8.9166e-05 - val_loss: 3.8348e-05 - 9s/epoch - 5ms/step
# Epoch 379/500
# 1749/1749 - 8s - loss: 8.9109e-05 - val_loss: 3.8039e-05 - 8s/epoch - 5ms/step
# Epoch 380/500
# 1749/1749 - 8s - loss: 8.9193e-05 - val_loss: 3.8254e-05 - 8s/epoch - 5ms/step
# Epoch 381/500
# 1749/1749 - 8s - loss: 8.8990e-05 - val_loss: 3.7407e-05 - 8s/epoch - 5ms/step
# Epoch 382/500
# 1749/1749 - 8s - loss: 8.9160e-05 - val_loss: 3.7798e-05 - 8s/epoch - 5ms/step
# Epoch 383/500
# 1749/1749 - 9s - loss: 8.9137e-05 - val_loss: 3.7848e-05 - 9s/epoch - 5ms/step
# Epoch 384/500
# 1749/1749 - 9s - loss: 8.9204e-05 - val_loss: 3.8693e-05 - 9s/epoch - 5ms/step
# Epoch 385/500
# 1749/1749 - 8s - loss: 8.9074e-05 - val_loss: 3.8467e-05 - 8s/epoch - 5ms/step
# Epoch 386/500
# 1749/1749 - 9s - loss: 8.9040e-05 - val_loss: 3.8017e-05 - 9s/epoch - 5ms/step
# Epoch 387/500
# 1749/1749 - 9s - loss: 8.9091e-05 - val_loss: 3.8227e-05 - 9s/epoch - 5ms/step
# Epoch 388/500
# 1749/1749 - 8s - loss: 8.9089e-05 - val_loss: 3.8418e-05 - 8s/epoch - 5ms/step
# Epoch 389/500
# 1749/1749 - 9s - loss: 8.8929e-05 - val_loss: 3.7677e-05 - 9s/epoch - 5ms/step
# Epoch 390/500
# 1749/1749 - 9s - loss: 8.9108e-05 - val_loss: 3.8394e-05 - 9s/epoch - 5ms/step
# Epoch 391/500
# 1749/1749 - 8s - loss: 8.9027e-05 - val_loss: 3.8501e-05 - 8s/epoch - 5ms/step
# Epoch 392/500
# 1749/1749 - 9s - loss: 8.8979e-05 - val_loss: 3.8507e-05 - 9s/epoch - 5ms/step
# Epoch 393/500
# 1749/1749 - 9s - loss: 8.8962e-05 - val_loss: 3.8421e-05 - 9s/epoch - 5ms/step
# Epoch 394/500
# 1749/1749 - 8s - loss: 8.8988e-05 - val_loss: 3.8411e-05 - 8s/epoch - 5ms/step
# Epoch 395/500
# 1749/1749 - 9s - loss: 8.8898e-05 - val_loss: 3.8118e-05 - 9s/epoch - 5ms/step
# Epoch 396/500
# 1749/1749 - 9s - loss: 8.8992e-05 - val_loss: 3.8097e-05 - 9s/epoch - 5ms/step
# Epoch 397/500
# 1749/1749 - 9s - loss: 8.8870e-05 - val_loss: 3.7259e-05 - 9s/epoch - 5ms/step
# Epoch 398/500
# 1749/1749 - 9s - loss: 8.9005e-05 - val_loss: 3.7677e-05 - 9s/epoch - 5ms/step
# Epoch 399/500
# 1749/1749 - 9s - loss: 8.8993e-05 - val_loss: 3.8009e-05 - 9s/epoch - 5ms/step
# Epoch 400/500
# 1749/1749 - 9s - loss: 8.9015e-05 - val_loss: 3.8712e-05 - 9s/epoch - 5ms/step
# Epoch 401/500
# 1749/1749 - 9s - loss: 8.8925e-05 - val_loss: 3.8525e-05 - 9s/epoch - 5ms/step
# Epoch 402/500
# 1749/1749 - 9s - loss: 8.8823e-05 - val_loss: 3.7925e-05 - 9s/epoch - 5ms/step
# Epoch 403/500
# 1749/1749 - 10s - loss: 8.8988e-05 - val_loss: 3.8427e-05 - 10s/epoch - 6ms/step
# Epoch 404/500
# 1749/1749 - 10s - loss: 8.8812e-05 - val_loss: 3.8116e-05 - 10s/epoch - 6ms/step
# Epoch 405/500
# 1749/1749 - 11s - loss: 8.8857e-05 - val_loss: 3.8503e-05 - 11s/epoch - 6ms/step
# Epoch 406/500
# 1749/1749 - 12s - loss: 8.8845e-05 - val_loss: 3.8535e-05 - 12s/epoch - 7ms/step
# Epoch 407/500
# 1749/1749 - 10s - loss: 8.8842e-05 - val_loss: 3.8459e-05 - 10s/epoch - 6ms/step
# Epoch 408/500
# 1749/1749 - 10s - loss: 8.8731e-05 - val_loss: 3.7956e-05 - 10s/epoch - 6ms/step
# Epoch 409/500
# 1749/1749 - 10s - loss: 8.8852e-05 - val_loss: 3.8278e-05 - 10s/epoch - 5ms/step
# Epoch 410/500
# 1749/1749 - 10s - loss: 8.8687e-05 - val_loss: 3.7795e-05 - 10s/epoch - 6ms/step
# Epoch 411/500
# 1749/1749 - 11s - loss: 8.8829e-05 - val_loss: 3.8420e-05 - 11s/epoch - 6ms/step
# Epoch 412/500
# 1749/1749 - 14s - loss: 8.8735e-05 - val_loss: 3.8253e-05 - 14s/epoch - 8ms/step
# Epoch 413/500
# 1749/1749 - 13s - loss: 8.8783e-05 - val_loss: 3.8459e-05 - 13s/epoch - 8ms/step
# Epoch 414/500
# 1749/1749 - 12s - loss: 8.8677e-05 - val_loss: 3.7837e-05 - 12s/epoch - 7ms/step
# Epoch 415/500
# 1749/1749 - 12s - loss: 8.8840e-05 - val_loss: 3.8066e-05 - 12s/epoch - 7ms/step
# Epoch 416/500
# 1749/1749 - 12s - loss: 8.8732e-05 - val_loss: 3.7973e-05 - 12s/epoch - 7ms/step
# Epoch 417/500
# 1749/1749 - 11s - loss: 8.8802e-05 - val_loss: 3.8687e-05 - 11s/epoch - 6ms/step
# Epoch 418/500
# 1749/1749 - 11s - loss: 8.8757e-05 - val_loss: 3.8384e-05 - 11s/epoch - 6ms/step
# Epoch 419/500
# 1749/1749 - 11s - loss: 8.8617e-05 - val_loss: 3.7677e-05 - 11s/epoch - 6ms/step
# Epoch 420/500
# 1749/1749 - 11s - loss: 8.8799e-05 - val_loss: 3.8267e-05 - 11s/epoch - 7ms/step
# Epoch 421/500
# 1749/1749 - 11s - loss: 8.8735e-05 - val_loss: 3.8393e-05 - 11s/epoch - 7ms/step
# Epoch 422/500
# 1749/1749 - 12s - loss: 8.8679e-05 - val_loss: 3.8665e-05 - 12s/epoch - 7ms/step
# Epoch 423/500
# 1749/1749 - 12s - loss: 8.8669e-05 - val_loss: 3.8543e-05 - 12s/epoch - 7ms/step
# Epoch 424/500
# 1749/1749 - 12s - loss: 8.8662e-05 - val_loss: 3.8196e-05 - 12s/epoch - 7ms/step
# Epoch 425/500
# 1749/1749 - 12s - loss: 8.8582e-05 - val_loss: 3.7946e-05 - 12s/epoch - 7ms/step
# Epoch 426/500
# 1749/1749 - 12s - loss: 8.8692e-05 - val_loss: 3.8609e-05 - 12s/epoch - 7ms/step
# Epoch 427/500
# 1749/1749 - 12s - loss: 8.8559e-05 - val_loss: 3.8329e-05 - 12s/epoch - 7ms/step
# Epoch 428/500
# 1749/1749 - 12s - loss: 8.8625e-05 - val_loss: 3.8502e-05 - 12s/epoch - 7ms/step
# Epoch 429/500
# 1749/1749 - 13s - loss: 8.8519e-05 - val_loss: 3.8012e-05 - 13s/epoch - 7ms/step
# Epoch 430/500
# 1749/1749 - 12s - loss: 8.8674e-05 - val_loss: 3.8543e-05 - 12s/epoch - 7ms/step
# Epoch 431/500
# 1749/1749 - 13s - loss: 8.8498e-05 - val_loss: 3.8159e-05 - 13s/epoch - 7ms/step
# Epoch 432/500
# 1749/1749 - 13s - loss: 8.8784e-05 - val_loss: 4.0365e-05 - 13s/epoch - 8ms/step
# Epoch 433/500
# 1749/1749 - 13s - loss: 8.8620e-05 - val_loss: 3.8867e-05 - 13s/epoch - 8ms/step
# Epoch 434/500
# 1749/1749 - 13s - loss: 8.8490e-05 - val_loss: 3.8636e-05 - 13s/epoch - 7ms/step
# Epoch 435/500
# 1749/1749 - 14s - loss: 8.8427e-05 - val_loss: 3.8433e-05 - 14s/epoch - 8ms/step
# Epoch 436/500
# 1749/1749 - 14s - loss: 8.8536e-05 - val_loss: 3.8305e-05 - 14s/epoch - 8ms/step
# Epoch 437/500
# 1749/1749 - 13s - loss: 8.8438e-05 - val_loss: 3.7707e-05 - 13s/epoch - 8ms/step
# Epoch 438/500
# 1749/1749 - 13s - loss: 8.8524e-05 - val_loss: 3.7857e-05 - 13s/epoch - 7ms/step
# Epoch 439/500
# 1749/1749 - 13s - loss: 8.8560e-05 - val_loss: 3.8371e-05 - 13s/epoch - 7ms/step
# Epoch 440/500
# 1749/1749 - 13s - loss: 8.8471e-05 - val_loss: 3.8398e-05 - 13s/epoch - 7ms/step
# Epoch 441/500
# 1749/1749 - 12s - loss: 8.8416e-05 - val_loss: 3.8003e-05 - 12s/epoch - 7ms/step
# Epoch 442/500
# 1749/1749 - 12s - loss: 8.8557e-05 - val_loss: 3.8395e-05 - 12s/epoch - 7ms/step
# Epoch 443/500
# 1749/1749 - 13s - loss: 8.8410e-05 - val_loss: 3.8191e-05 - 13s/epoch - 7ms/step
# Epoch 444/500
# 1749/1749 - 13s - loss: 8.8439e-05 - val_loss: 3.8532e-05 - 13s/epoch - 7ms/step
# Epoch 445/500
# 1749/1749 - 12s - loss: 8.8417e-05 - val_loss: 3.8503e-05 - 12s/epoch - 7ms/step
# Epoch 446/500
# 1749/1749 - 12s - loss: 8.8558e-05 - val_loss: 3.8027e-05 - 12s/epoch - 7ms/step
# Epoch 447/500
# 1749/1749 - 12s - loss: 8.8353e-05 - val_loss: 3.7606e-05 - 12s/epoch - 7ms/step
# Epoch 448/500
# 1749/1749 - 16s - loss: 8.8418e-05 - val_loss: 3.8158e-05 - 16s/epoch - 9ms/step
# Epoch 449/500
# 1749/1749 - 16s - loss: 8.8457e-05 - val_loss: 3.8666e-05 - 16s/epoch - 9ms/step
# Epoch 450/500
# 1749/1749 - 21s - loss: 8.8414e-05 - val_loss: 3.8311e-05 - 21s/epoch - 12ms/step
# Epoch 451/500
# 1749/1749 - 13s - loss: 8.8276e-05 - val_loss: 3.7714e-05 - 13s/epoch - 7ms/step
# Epoch 452/500
# 1749/1749 - 12s - loss: 8.8405e-05 - val_loss: 3.8334e-05 - 12s/epoch - 7ms/step
# Epoch 453/500
# 1749/1749 - 13s - loss: 8.8426e-05 - val_loss: 3.8621e-05 - 13s/epoch - 7ms/step
# Epoch 454/500
# 1749/1749 - 13s - loss: 8.8273e-05 - val_loss: 3.8392e-05 - 13s/epoch - 7ms/step
# Epoch 455/500
# 1749/1749 - 13s - loss: 9.1302e-05 - val_loss: 3.5898e-05 - 13s/epoch - 7ms/step
# Epoch 456/500
# 1749/1749 - 13s - loss: 9.0004e-05 - val_loss: 3.8800e-05 - 13s/epoch - 7ms/step
# Epoch 457/500
# 1749/1749 - 13s - loss: 8.8495e-05 - val_loss: 3.8380e-05 - 13s/epoch - 8ms/step
# Epoch 458/500
# 1749/1749 - 14s - loss: 8.8245e-05 - val_loss: 3.8335e-05 - 14s/epoch - 8ms/step
# Epoch 459/500
# 1749/1749 - 13s - loss: 8.8287e-05 - val_loss: 3.8356e-05 - 13s/epoch - 8ms/step
# Epoch 460/500
# 1749/1749 - 13s - loss: 8.8395e-05 - val_loss: 3.8934e-05 - 13s/epoch - 7ms/step
# Epoch 461/500
# 1749/1749 - 13s - loss: 8.8330e-05 - val_loss: 3.9077e-05 - 13s/epoch - 7ms/step
# Epoch 462/500
# 1749/1749 - 13s - loss: 8.8268e-05 - val_loss: 3.8883e-05 - 13s/epoch - 7ms/step
# Epoch 463/500
# 1749/1749 - 13s - loss: 8.8230e-05 - val_loss: 3.8643e-05 - 13s/epoch - 7ms/step
# Epoch 464/500
# 1749/1749 - 13s - loss: 8.8358e-05 - val_loss: 3.8237e-05 - 13s/epoch - 7ms/step
# Epoch 465/500
# 1749/1749 - 13s - loss: 8.8203e-05 - val_loss: 3.7796e-05 - 13s/epoch - 7ms/step
# Epoch 466/500
# 1749/1749 - 13s - loss: 8.8270e-05 - val_loss: 3.8155e-05 - 13s/epoch - 7ms/step
# Epoch 467/500
# 1749/1749 - 13s - loss: 8.8283e-05 - val_loss: 3.8613e-05 - 13s/epoch - 7ms/step
# Epoch 468/500
# 1749/1749 - 13s - loss: 8.8232e-05 - val_loss: 3.8433e-05 - 13s/epoch - 7ms/step
# Epoch 469/500
# 1749/1749 - 13s - loss: 8.8154e-05 - val_loss: 3.7937e-05 - 13s/epoch - 7ms/step
# Epoch 470/500
# 1749/1749 - 13s - loss: 8.8306e-05 - val_loss: 3.8340e-05 - 13s/epoch - 7ms/step
# Epoch 471/500
# 1749/1749 - 13s - loss: 8.8234e-05 - val_loss: 3.8514e-05 - 13s/epoch - 7ms/step
# Epoch 472/500
# 1749/1749 - 13s - loss: 8.8169e-05 - val_loss: 3.8718e-05 - 13s/epoch - 7ms/step
# Epoch 473/500
# 1749/1749 - 13s - loss: 8.8211e-05 - val_loss: 3.8451e-05 - 13s/epoch - 7ms/step
# Epoch 474/500
# 1749/1749 - 12s - loss: 8.8089e-05 - val_loss: 3.8030e-05 - 12s/epoch - 7ms/step
# Epoch 475/500
# 1749/1749 - 12s - loss: 8.8252e-05 - val_loss: 3.8523e-05 - 12s/epoch - 7ms/step
# Epoch 476/500
# 1749/1749 - 12s - loss: 8.8143e-05 - val_loss: 3.8629e-05 - 12s/epoch - 7ms/step
# Epoch 477/500
# 1749/1749 - 12s - loss: 8.8226e-05 - val_loss: 3.8799e-05 - 12s/epoch - 7ms/step
# Epoch 478/500
# 1749/1749 - 12s - loss: 8.8120e-05 - val_loss: 3.8876e-05 - 12s/epoch - 7ms/step
# Epoch 479/500
# 1749/1749 - 12s - loss: 8.8057e-05 - val_loss: 3.8734e-05 - 12s/epoch - 7ms/step
# Epoch 480/500
# 1749/1749 - 12s - loss: 8.8020e-05 - val_loss: 3.8544e-05 - 12s/epoch - 7ms/step
# Epoch 481/500
# 1749/1749 - 12s - loss: 8.8076e-05 - val_loss: 3.8303e-05 - 12s/epoch - 7ms/step
# Epoch 482/500
# 1749/1749 - 12s - loss: 8.8031e-05 - val_loss: 3.8052e-05 - 12s/epoch - 7ms/step
# Epoch 483/500
# 1749/1749 - 12s - loss: 8.8057e-05 - val_loss: 3.8362e-05 - 12s/epoch - 7ms/step
# Epoch 484/500
# 1749/1749 - 12s - loss: 8.8013e-05 - val_loss: 3.8158e-05 - 12s/epoch - 7ms/step
# Epoch 485/500
# 1749/1749 - 12s - loss: 8.8030e-05 - val_loss: 3.7937e-05 - 12s/epoch - 7ms/step
# Epoch 486/500
# 1749/1749 - 12s - loss: 8.8118e-05 - val_loss: 3.8252e-05 - 12s/epoch - 7ms/step
# Epoch 487/500
# 1749/1749 - 12s - loss: 8.8093e-05 - val_loss: 3.8657e-05 - 12s/epoch - 7ms/step
# Epoch 488/500
# 1749/1749 - 12s - loss: 8.7964e-05 - val_loss: 3.8530e-05 - 12s/epoch - 7ms/step
# Epoch 489/500
# 1749/1749 - 12s - loss: 8.8220e-05 - val_loss: 3.7932e-05 - 12s/epoch - 7ms/step
# Epoch 490/500
# 1749/1749 - 12s - loss: 8.7950e-05 - val_loss: 3.7987e-05 - 12s/epoch - 7ms/step
# Epoch 491/500
# 1749/1749 - 12s - loss: 8.8027e-05 - val_loss: 3.8788e-05 - 12s/epoch - 7ms/step
# Epoch 492/500
# 1749/1749 - 13s - loss: 8.8143e-05 - val_loss: 3.9050e-05 - 13s/epoch - 7ms/step
# Epoch 493/500
# 1749/1749 - 12s - loss: 8.7922e-05 - val_loss: 3.8872e-05 - 12s/epoch - 7ms/step
# Epoch 494/500
# 1749/1749 - 12s - loss: 8.7867e-05 - val_loss: 3.8600e-05 - 12s/epoch - 7ms/step
# Epoch 495/500
# 1749/1749 - 12s - loss: 8.7858e-05 - val_loss: 3.8397e-05 - 12s/epoch - 7ms/step
# Epoch 496/500
# 1749/1749 - 12s - loss: 8.7950e-05 - val_loss: 3.8210e-05 - 12s/epoch - 7ms/step
# Epoch 497/500
# 1749/1749 - 12s - loss: 8.7878e-05 - val_loss: 3.8123e-05 - 12s/epoch - 7ms/step
# Epoch 498/500
# 1749/1749 - 12s - loss: 8.7888e-05 - val_loss: 3.8133e-05 - 12s/epoch - 7ms/step
# Epoch 499/500
# 1749/1749 - 12s - loss: 8.7865e-05 - val_loss: 3.7898e-05 - 12s/epoch - 7ms/step
# Epoch 500/500
# 1749/1749 - 12s - loss: 8.7970e-05 - val_loss: 3.8231e-05 - 12s/epoch - 7ms/step

# %% [markdown]
# ## Metrics ($LVPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 875/875 [==============================] - 5s 3ms/step
# (27972, 3)
# (27972, 10)
# Test RMSE: 2.807
# Test MAE: 1.989

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('Kyoto DST Index', fontsize=20)
plt.legend(fontsize=20)
plt.show()
