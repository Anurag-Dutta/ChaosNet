# %% [markdown]
# # Time Series Prediction with Lorrenz Attractor Inspired Deep Learning ($LPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-09 20:14:35

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Lorrenz Intermittency_

# %% [markdown]
# The `lorrenz_intermittency.dat` is generated from the Runge Kutta Method.

# %% [markdown]
# This feeds the model with the dynamics of the Lorrenz Attractor

# %%
data = np.genfromtxt('datasets/lorrenz_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 0.0416 # Hourly Data (1/24)
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 28.981277697415116
# 1         0.410529
# 2         0.984791
# 3         1.507596
# 4         1.999449
# 5         2.477310
#             ...
# 139867    2.510245
# 139868    1.547437
# 139869    0.682186
# 139870   -0.090437
# 139871   -0.778049
# Name: 1, Length: 139871, dtype: float64
# 2         13.804368
# 3         12.567428
# 4         11.823401
# 5         11.487036
# 6         11.494772
#             ...
# 139867   -25.516527
# 139868   -23.144433
# 139869   -20.799290
# 139870   -18.572659
# 139871   -16.529136
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _KYOTO DST_

# %%
data = pd.read_csv("datasets/dst.csv")
training_set = data.iloc[:, 1]
print(training_set)
# Out:
# 0         -7
# 1        -10
# 2        -10
# 3         -6
# 4         -2
#           ..
# 139867   -16
# 139868   -14
# 139869   -14
# 139870   -15
# 139871   -14
# Name: dst, Length: 139872, dtype: int64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0         0.410529
# 1         0.984791
# 2         1.507596
# 3         1.999449
# 4         2.477310
#             ...
# 139866    2.510245
# 139867    1.547437
# 139868    0.682186
# 139869   -0.090437
# 139870   -0.778049
# Name: 1, Length: 139871, dtype: float64
# 0         13.804368
# 1         12.567428
# 2         11.823401
# 3         11.487036
# 4         11.494772
#             ...
# 139865   -25.516527
# 139866   -23.144433
# 139867   -20.799290
# 139868   -18.572659
# 139869   -16.529136
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lorrenz Equation_)

# %% [markdown]
# _Parameters_: $\sigma=10, \rho=28$

# %%
s=10
r=28
L = df.iloc[:, 2] + df.iloc[:, 1]*(1 + s) - df.iloc[:, 0] * s * (r - 1)
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10        -7.0      -10.0      -10.0       -6.0       -2.0        3.0
# 11       -10.0      -10.0       -6.0       -2.0        3.0        5.0
# 12       -10.0       -6.0       -2.0        3.0        5.0        5.0
# 13        -6.0       -2.0        3.0        5.0        5.0        3.0
# 14        -2.0        3.0        5.0        5.0        3.0        1.0
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)   var2(t)    var3(t)
# 10        5.0        5.0        3.0        1.0      1.0  5.745758  16.980747
# 11        5.0        3.0        1.0        1.0      2.0  6.452157  18.694315
# 12        3.0        1.0        1.0        2.0      2.0  7.229841  20.639585
# 13        1.0        1.0        2.0        2.0      3.0  8.088448  22.824715
# 14        1.0        2.0        2.0        3.0      3.0  9.037956  25.258378
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (139860, 13)
# (139860, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (111888, 1, 10) (111888, 3) (27972, 1, 10) (27972, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
s = tf.Variable(10, name="sigma", trainable=True, dtype=tf.float32)
r = tf.Variable(28, name="rhow", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] + y_true[:, 1]*(1 + s) - y_true[:, 0] * s * (r - 1)), (y_pred[:, 2] + y_pred[:, 1]*(1 + s) - y_pred[:, 0] * s * (r - 1)))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] + (y_pred[1:-1]-y_pred[:-2])*(1 + s) - y_pred[:-2] * s * (r - 1)
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] + (y_real[1:-1]-y_real[:-2])*(1 + s) - y_real[:-2] * s * (r - 1)
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($LPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square((y_pred[:, 2] + y_pred[:, 1]*(1 + s) - y_pred[:, 0] * s * (r - 1)))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 1749/1749 - 7s - loss: 1.2057 - val_loss: 0.7013 - 7s/epoch - 4ms/step
# Epoch 2/500
# 1749/1749 - 3s - loss: 0.6751 - val_loss: 0.6649 - 3s/epoch - 2ms/step
# Epoch 3/500
# 1749/1749 - 3s - loss: 0.6068 - val_loss: 0.5665 - 3s/epoch - 2ms/step
# Epoch 4/500
# 1749/1749 - 3s - loss: 0.5053 - val_loss: 0.4483 - 3s/epoch - 2ms/step
# Epoch 5/500
# 1749/1749 - 3s - loss: 0.3925 - val_loss: 0.3377 - 3s/epoch - 2ms/step
# Epoch 6/500
# 1749/1749 - 3s - loss: 0.2885 - val_loss: 0.2489 - 3s/epoch - 2ms/step
# Epoch 7/500
# 1749/1749 - 3s - loss: 0.2111 - val_loss: 0.1717 - 3s/epoch - 2ms/step
# Epoch 8/500
# 1749/1749 - 4s - loss: 0.1494 - val_loss: 0.1267 - 4s/epoch - 2ms/step
# Epoch 9/500
# 1749/1749 - 4s - loss: 0.1062 - val_loss: 0.1374 - 4s/epoch - 2ms/step
# Epoch 10/500
# 1749/1749 - 4s - loss: 0.0734 - val_loss: 0.0939 - 4s/epoch - 2ms/step
# Epoch 11/500
# 1749/1749 - 6s - loss: 0.0540 - val_loss: 0.0368 - 6s/epoch - 3ms/step
# Epoch 12/500
# 1749/1749 - 5s - loss: 0.0396 - val_loss: 0.0643 - 5s/epoch - 3ms/step
# Epoch 13/500
# 1749/1749 - 4s - loss: 0.0339 - val_loss: 0.0171 - 4s/epoch - 2ms/step
# Epoch 14/500
# 1749/1749 - 4s - loss: 0.0257 - val_loss: 0.0105 - 4s/epoch - 2ms/step
# Epoch 15/500
# 1749/1749 - 4s - loss: 0.0230 - val_loss: 0.0135 - 4s/epoch - 2ms/step
# Epoch 16/500
# 1749/1749 - 4s - loss: 0.0203 - val_loss: 0.0050 - 4s/epoch - 2ms/step
# Epoch 17/500
# 1749/1749 - 7s - loss: 0.0188 - val_loss: 0.0143 - 7s/epoch - 4ms/step
# Epoch 18/500
# 1749/1749 - 7s - loss: 0.0197 - val_loss: 0.0064 - 7s/epoch - 4ms/step
# Epoch 19/500
# 1749/1749 - 5s - loss: 0.0136 - val_loss: 0.0110 - 5s/epoch - 3ms/step
# Epoch 20/500
# 1749/1749 - 5s - loss: 0.0167 - val_loss: 0.0020 - 5s/epoch - 3ms/step
# Epoch 21/500
# 1749/1749 - 5s - loss: 0.0160 - val_loss: 0.0131 - 5s/epoch - 3ms/step
# Epoch 22/500
# 1749/1749 - 5s - loss: 0.0153 - val_loss: 0.0013 - 5s/epoch - 3ms/step
# Epoch 23/500
# 1749/1749 - 5s - loss: 0.0148 - val_loss: 0.0020 - 5s/epoch - 3ms/step
# Epoch 24/500
# 1749/1749 - 5s - loss: 0.0139 - val_loss: 0.0041 - 5s/epoch - 3ms/step
# Epoch 25/500
# 1749/1749 - 4s - loss: 0.0139 - val_loss: 0.0012 - 4s/epoch - 3ms/step
# Epoch 26/500
# 1749/1749 - 4s - loss: 0.0143 - val_loss: 0.0055 - 4s/epoch - 2ms/step
# Epoch 27/500
# 1749/1749 - 5s - loss: 0.0140 - val_loss: 0.0121 - 5s/epoch - 3ms/step
# Epoch 28/500
# 1749/1749 - 4s - loss: 0.0139 - val_loss: 0.0191 - 4s/epoch - 2ms/step
# Epoch 29/500
# 1749/1749 - 5s - loss: 0.0134 - val_loss: 0.0108 - 5s/epoch - 3ms/step
# Epoch 30/500
# 1749/1749 - 7s - loss: 0.0142 - val_loss: 0.0037 - 7s/epoch - 4ms/step
# Epoch 31/500
# 1749/1749 - 5s - loss: 0.0125 - val_loss: 0.0025 - 5s/epoch - 3ms/step
# Epoch 32/500
# 1749/1749 - 5s - loss: 0.0144 - val_loss: 0.0026 - 5s/epoch - 3ms/step
# Epoch 33/500
# 1749/1749 - 5s - loss: 0.0123 - val_loss: 0.0074 - 5s/epoch - 3ms/step
# Epoch 34/500
# 1749/1749 - 6s - loss: 0.0146 - val_loss: 0.0041 - 6s/epoch - 3ms/step
# Epoch 35/500
# 1749/1749 - 6s - loss: 0.0132 - val_loss: 9.8331e-04 - 6s/epoch - 3ms/step
# Epoch 36/500
# 1749/1749 - 6s - loss: 0.0107 - val_loss: 7.7755e-04 - 6s/epoch - 4ms/step
# Epoch 37/500
# 1749/1749 - 7s - loss: 0.0132 - val_loss: 0.0013 - 7s/epoch - 4ms/step
# Epoch 38/500
# 1749/1749 - 6s - loss: 0.0118 - val_loss: 0.0102 - 6s/epoch - 3ms/step
# Epoch 39/500
# 1749/1749 - 6s - loss: 0.0107 - val_loss: 0.0027 - 6s/epoch - 4ms/step
# Epoch 40/500
# 1749/1749 - 7s - loss: 0.0123 - val_loss: 0.0036 - 7s/epoch - 4ms/step
# Epoch 41/500
# 1749/1749 - 7s - loss: 0.0124 - val_loss: 0.0010 - 7s/epoch - 4ms/step
# Epoch 42/500
# 1749/1749 - 4s - loss: 0.0113 - val_loss: 0.0089 - 4s/epoch - 2ms/step
# Epoch 43/500
# 1749/1749 - 5s - loss: 0.0115 - val_loss: 0.0014 - 5s/epoch - 3ms/step
# Epoch 44/500
# 1749/1749 - 5s - loss: 0.0113 - val_loss: 0.0121 - 5s/epoch - 3ms/step
# Epoch 45/500
# 1749/1749 - 4s - loss: 0.0111 - val_loss: 0.0030 - 4s/epoch - 2ms/step
# Epoch 46/500
# 1749/1749 - 6s - loss: 0.0107 - val_loss: 0.0063 - 6s/epoch - 3ms/step
# Epoch 47/500
# 1749/1749 - 5s - loss: 0.0110 - val_loss: 0.0027 - 5s/epoch - 3ms/step
# Epoch 48/500
# 1749/1749 - 4s - loss: 0.0111 - val_loss: 0.0032 - 4s/epoch - 2ms/step
# Epoch 49/500
# 1749/1749 - 7s - loss: 0.0109 - val_loss: 7.4124e-04 - 7s/epoch - 4ms/step
# Epoch 50/500
# 1749/1749 - 7s - loss: 0.0113 - val_loss: 0.0188 - 7s/epoch - 4ms/step
# Epoch 51/500
# 1749/1749 - 5s - loss: 0.0098 - val_loss: 0.0021 - 5s/epoch - 3ms/step
# Epoch 52/500
# 1749/1749 - 7s - loss: 0.0103 - val_loss: 0.0213 - 7s/epoch - 4ms/step
# Epoch 53/500
# 1749/1749 - 8s - loss: 0.0113 - val_loss: 0.0427 - 8s/epoch - 5ms/step
# Epoch 54/500
# 1749/1749 - 7s - loss: 0.0097 - val_loss: 0.0024 - 7s/epoch - 4ms/step
# Epoch 55/500
# 1749/1749 - 5s - loss: 0.0105 - val_loss: 0.0036 - 5s/epoch - 3ms/step
# Epoch 56/500
# 1749/1749 - 5s - loss: 0.0110 - val_loss: 0.0011 - 5s/epoch - 3ms/step
# Epoch 57/500
# 1749/1749 - 5s - loss: 0.0091 - val_loss: 0.0163 - 5s/epoch - 3ms/step
# Epoch 58/500
# 1749/1749 - 4s - loss: 0.0096 - val_loss: 0.0037 - 4s/epoch - 2ms/step
# Epoch 59/500
# 1749/1749 - 4s - loss: 0.0102 - val_loss: 0.0048 - 4s/epoch - 2ms/step
# Epoch 60/500
# 1749/1749 - 4s - loss: 0.0101 - val_loss: 5.9086e-04 - 4s/epoch - 2ms/step
# Epoch 61/500
# 1749/1749 - 4s - loss: 0.0102 - val_loss: 6.5305e-04 - 4s/epoch - 2ms/step
# Epoch 62/500
# 1749/1749 - 4s - loss: 0.0098 - val_loss: 0.0026 - 4s/epoch - 2ms/step
# Epoch 63/500
# 1749/1749 - 4s - loss: 0.0093 - val_loss: 0.0133 - 4s/epoch - 2ms/step
# Epoch 64/500
# 1749/1749 - 4s - loss: 0.0090 - val_loss: 8.3905e-04 - 4s/epoch - 2ms/step
# Epoch 65/500
# 1749/1749 - 5s - loss: 0.0091 - val_loss: 7.4041e-04 - 5s/epoch - 3ms/step
# Epoch 66/500
# 1749/1749 - 5s - loss: 0.0092 - val_loss: 0.0030 - 5s/epoch - 3ms/step
# Epoch 67/500
# 1749/1749 - 5s - loss: 0.0094 - val_loss: 7.8668e-04 - 5s/epoch - 3ms/step
# Epoch 68/500
# 1749/1749 - 5s - loss: 0.0100 - val_loss: 0.0017 - 5s/epoch - 3ms/step
# Epoch 69/500
# 1749/1749 - 4s - loss: 0.0078 - val_loss: 0.0011 - 4s/epoch - 2ms/step
# Epoch 70/500
# 1749/1749 - 4s - loss: 0.0095 - val_loss: 0.0080 - 4s/epoch - 2ms/step
# Epoch 71/500
# 1749/1749 - 4s - loss: 0.0088 - val_loss: 0.0036 - 4s/epoch - 2ms/step
# Epoch 72/500
# 1749/1749 - 7s - loss: 0.0083 - val_loss: 0.0054 - 7s/epoch - 4ms/step
# Epoch 73/500
# 1749/1749 - 8s - loss: 0.0091 - val_loss: 0.0014 - 8s/epoch - 5ms/step
# Epoch 74/500
# 1749/1749 - 5s - loss: 0.0093 - val_loss: 0.0030 - 5s/epoch - 3ms/step
# Epoch 75/500
# 1749/1749 - 5s - loss: 0.0074 - val_loss: 0.0028 - 5s/epoch - 3ms/step
# Epoch 76/500
# 1749/1749 - 5s - loss: 0.0087 - val_loss: 0.0013 - 5s/epoch - 3ms/step
# Epoch 77/500
# 1749/1749 - 5s - loss: 0.0083 - val_loss: 0.0014 - 5s/epoch - 3ms/step
# Epoch 78/500
# 1749/1749 - 5s - loss: 0.0081 - val_loss: 0.0041 - 5s/epoch - 3ms/step
# Epoch 79/500
# 1749/1749 - 5s - loss: 0.0091 - val_loss: 0.0119 - 5s/epoch - 3ms/step
# Epoch 80/500
# 1749/1749 - 4s - loss: 0.0094 - val_loss: 8.0389e-04 - 4s/epoch - 3ms/step
# Epoch 81/500
# 1749/1749 - 5s - loss: 0.0078 - val_loss: 8.4206e-04 - 5s/epoch - 3ms/step
# Epoch 82/500
# 1749/1749 - 5s - loss: 0.0079 - val_loss: 0.0020 - 5s/epoch - 3ms/step
# Epoch 83/500
# 1749/1749 - 5s - loss: 0.0098 - val_loss: 0.0058 - 5s/epoch - 3ms/step
# Epoch 84/500
# 1749/1749 - 5s - loss: 0.0070 - val_loss: 0.0019 - 5s/epoch - 3ms/step
# Epoch 85/500
# 1749/1749 - 5s - loss: 0.0080 - val_loss: 0.0025 - 5s/epoch - 3ms/step
# Epoch 86/500
# 1749/1749 - 5s - loss: 0.0079 - val_loss: 0.0018 - 5s/epoch - 3ms/step
# Epoch 87/500
# 1749/1749 - 5s - loss: 0.0082 - val_loss: 6.1774e-04 - 5s/epoch - 3ms/step
# Epoch 88/500
# 1749/1749 - 5s - loss: 0.0093 - val_loss: 7.4567e-04 - 5s/epoch - 3ms/step
# Epoch 89/500
# 1749/1749 - 5s - loss: 0.0080 - val_loss: 6.7458e-04 - 5s/epoch - 3ms/step
# Epoch 90/500
# 1749/1749 - 5s - loss: 0.0080 - val_loss: 6.5536e-04 - 5s/epoch - 3ms/step
# Epoch 91/500
# 1749/1749 - 5s - loss: 0.0090 - val_loss: 8.1107e-04 - 5s/epoch - 3ms/step
# Epoch 92/500
# 1749/1749 - 7s - loss: 0.0075 - val_loss: 0.0116 - 7s/epoch - 4ms/step
# Epoch 93/500
# 1749/1749 - 6s - loss: 0.0076 - val_loss: 0.0015 - 6s/epoch - 3ms/step
# Epoch 94/500
# 1749/1749 - 5s - loss: 0.0084 - val_loss: 5.3768e-04 - 5s/epoch - 3ms/step
# Epoch 95/500
# 1749/1749 - 5s - loss: 0.0069 - val_loss: 6.0795e-04 - 5s/epoch - 3ms/step
# Epoch 96/500
# 1749/1749 - 5s - loss: 0.0084 - val_loss: 0.0011 - 5s/epoch - 3ms/step
# Epoch 97/500
# 1749/1749 - 5s - loss: 0.0068 - val_loss: 0.0089 - 5s/epoch - 3ms/step
# Epoch 98/500
# 1749/1749 - 5s - loss: 0.0091 - val_loss: 5.9794e-04 - 5s/epoch - 3ms/step
# Epoch 99/500
# 1749/1749 - 5s - loss: 0.0106 - val_loss: 6.5119e-04 - 5s/epoch - 3ms/step
# Epoch 100/500
# 1749/1749 - 5s - loss: 0.0059 - val_loss: 5.4546e-04 - 5s/epoch - 3ms/step
# Epoch 101/500
# 1749/1749 - 5s - loss: 0.0083 - val_loss: 6.0139e-04 - 5s/epoch - 3ms/step
# Epoch 102/500
# 1749/1749 - 5s - loss: 0.0074 - val_loss: 8.3149e-04 - 5s/epoch - 3ms/step
# Epoch 103/500
# 1749/1749 - 5s - loss: 0.0076 - val_loss: 5.0063e-04 - 5s/epoch - 3ms/step
# Epoch 104/500
# 1749/1749 - 5s - loss: 0.0086 - val_loss: 8.1029e-04 - 5s/epoch - 3ms/step
# Epoch 105/500
# 1749/1749 - 5s - loss: 0.0078 - val_loss: 0.0026 - 5s/epoch - 3ms/step
# Epoch 106/500
# 1749/1749 - 5s - loss: 0.0063 - val_loss: 6.2746e-04 - 5s/epoch - 3ms/step
# Epoch 107/500
# 1749/1749 - 5s - loss: 0.0083 - val_loss: 5.0747e-04 - 5s/epoch - 3ms/step
# Epoch 108/500
# 1749/1749 - 5s - loss: 0.0078 - val_loss: 6.9058e-04 - 5s/epoch - 3ms/step
# Epoch 109/500
# 1749/1749 - 5s - loss: 0.0072 - val_loss: 7.6891e-04 - 5s/epoch - 3ms/step
# Epoch 110/500
# 1749/1749 - 5s - loss: 0.0065 - val_loss: 0.0116 - 5s/epoch - 3ms/step
# Epoch 111/500
# 1749/1749 - 5s - loss: 0.0072 - val_loss: 0.0012 - 5s/epoch - 3ms/step
# Epoch 112/500
# 1749/1749 - 5s - loss: 0.0069 - val_loss: 4.7958e-04 - 5s/epoch - 3ms/step
# Epoch 113/500
# 1749/1749 - 5s - loss: 0.0075 - val_loss: 4.1445e-04 - 5s/epoch - 3ms/step
# Epoch 114/500
# 1749/1749 - 5s - loss: 0.0073 - val_loss: 4.9726e-04 - 5s/epoch - 3ms/step
# Epoch 115/500
# 1749/1749 - 4s - loss: 0.0069 - val_loss: 0.0016 - 4s/epoch - 3ms/step
# Epoch 116/500
# 1749/1749 - 4s - loss: 0.0071 - val_loss: 0.0111 - 4s/epoch - 3ms/step
# Epoch 117/500
# 1749/1749 - 5s - loss: 0.0071 - val_loss: 8.5757e-04 - 5s/epoch - 3ms/step
# Epoch 118/500
# 1749/1749 - 5s - loss: 0.0077 - val_loss: 4.6741e-04 - 5s/epoch - 3ms/step
# Epoch 119/500
# 1749/1749 - 5s - loss: 0.0103 - val_loss: 5.0106e-04 - 5s/epoch - 3ms/step
# Epoch 120/500
# 1749/1749 - 5s - loss: 0.0054 - val_loss: 0.0011 - 5s/epoch - 3ms/step
# Epoch 121/500
# 1749/1749 - 5s - loss: 0.0076 - val_loss: 3.9915e-04 - 5s/epoch - 3ms/step
# Epoch 122/500
# 1749/1749 - 8s - loss: 0.0087 - val_loss: 4.2944e-04 - 8s/epoch - 5ms/step
# Epoch 123/500
# 1749/1749 - 6s - loss: 0.0064 - val_loss: 3.8622e-04 - 6s/epoch - 4ms/step
# Epoch 124/500
# 1749/1749 - 5s - loss: 0.0065 - val_loss: 0.0047 - 5s/epoch - 3ms/step
# Epoch 125/500
# 1749/1749 - 12s - loss: 0.0084 - val_loss: 3.9401e-04 - 12s/epoch - 7ms/step
# Epoch 126/500
# 1749/1749 - 5s - loss: 0.0064 - val_loss: 4.1375e-04 - 5s/epoch - 3ms/step
# Epoch 127/500
# 1749/1749 - 5s - loss: 0.0078 - val_loss: 7.5395e-04 - 5s/epoch - 3ms/step
# Epoch 128/500
# 1749/1749 - 5s - loss: 0.0060 - val_loss: 0.0039 - 5s/epoch - 3ms/step
# Epoch 129/500
# 1749/1749 - 5s - loss: 0.0080 - val_loss: 5.1023e-04 - 5s/epoch - 3ms/step
# Epoch 130/500
# 1749/1749 - 5s - loss: 0.0064 - val_loss: 4.3151e-04 - 5s/epoch - 3ms/step
# Epoch 131/500
# 1749/1749 - 5s - loss: 0.0064 - val_loss: 0.0022 - 5s/epoch - 3ms/step
# Epoch 132/500
# 1749/1749 - 5s - loss: 0.0065 - val_loss: 3.0265e-04 - 5s/epoch - 3ms/step
# Epoch 133/500
# 1749/1749 - 5s - loss: 0.0074 - val_loss: 3.0598e-04 - 5s/epoch - 3ms/step
# Epoch 134/500
# 1749/1749 - 5s - loss: 0.0065 - val_loss: 0.0051 - 5s/epoch - 3ms/step
# Epoch 135/500
# 1749/1749 - 5s - loss: 0.0084 - val_loss: 3.0053e-04 - 5s/epoch - 3ms/step
# Epoch 136/500
# 1749/1749 - 5s - loss: 0.0066 - val_loss: 5.0279e-04 - 5s/epoch - 3ms/step
# Epoch 137/500
# 1749/1749 - 5s - loss: 0.0107 - val_loss: 3.1999e-04 - 5s/epoch - 3ms/step
# Epoch 138/500
# 1749/1749 - 4s - loss: 0.0095 - val_loss: 5.7844e-04 - 4s/epoch - 3ms/step
# Epoch 139/500
# 1749/1749 - 5s - loss: 0.0047 - val_loss: 0.0021 - 5s/epoch - 3ms/step
# Epoch 140/500
# 1749/1749 - 5s - loss: 0.0066 - val_loss: 9.3303e-04 - 5s/epoch - 3ms/step
# Epoch 141/500
# 1749/1749 - 5s - loss: 0.0074 - val_loss: 0.0011 - 5s/epoch - 3ms/step
# Epoch 142/500
# 1749/1749 - 5s - loss: 0.0067 - val_loss: 4.8111e-04 - 5s/epoch - 3ms/step
# Epoch 143/500
# 1749/1749 - 6s - loss: 0.0071 - val_loss: 0.0015 - 6s/epoch - 3ms/step
# Epoch 144/500
# 1749/1749 - 6s - loss: 0.0071 - val_loss: 3.9608e-04 - 6s/epoch - 4ms/step
# Epoch 145/500
# 1749/1749 - 6s - loss: 0.0056 - val_loss: 0.0065 - 6s/epoch - 3ms/step
# Epoch 146/500
# 1749/1749 - 6s - loss: 0.0067 - val_loss: 3.8997e-04 - 6s/epoch - 4ms/step
# Epoch 147/500
# 1749/1749 - 6s - loss: 0.0067 - val_loss: 4.8896e-04 - 6s/epoch - 4ms/step
# Epoch 148/500
# 1749/1749 - 7s - loss: 0.0069 - val_loss: 3.7942e-04 - 7s/epoch - 4ms/step
# Epoch 149/500
# 1749/1749 - 9s - loss: 0.0060 - val_loss: 2.9035e-04 - 9s/epoch - 5ms/step
# Epoch 150/500
# 1749/1749 - 7s - loss: 0.0102 - val_loss: 3.4748e-04 - 7s/epoch - 4ms/step
# Epoch 151/500
# 1749/1749 - 7s - loss: 0.0046 - val_loss: 0.0029 - 7s/epoch - 4ms/step
# Epoch 152/500
# 1749/1749 - 7s - loss: 0.0068 - val_loss: 2.6221e-04 - 7s/epoch - 4ms/step
# Epoch 153/500
# 1749/1749 - 8s - loss: 0.0136 - val_loss: 3.0792e-04 - 8s/epoch - 4ms/step
# Epoch 154/500
# 1749/1749 - 8s - loss: 0.0046 - val_loss: 4.6989e-04 - 8s/epoch - 4ms/step
# Epoch 155/500
# 1749/1749 - 8s - loss: 0.0110 - val_loss: 3.7461e-04 - 8s/epoch - 5ms/step
# Epoch 156/500
# 1749/1749 - 8s - loss: 0.0047 - val_loss: 4.9634e-04 - 8s/epoch - 4ms/step
# Epoch 157/500
# 1749/1749 - 9s - loss: 0.0055 - val_loss: 5.1335e-04 - 9s/epoch - 5ms/step
# Epoch 158/500
# 1749/1749 - 9s - loss: 0.0060 - val_loss: 0.0074 - 9s/epoch - 5ms/step
# Epoch 159/500
# 1749/1749 - 8s - loss: 0.0111 - val_loss: 2.6678e-04 - 8s/epoch - 5ms/step
# Epoch 160/500
# 1749/1749 - 8s - loss: 0.0046 - val_loss: 5.5534e-04 - 8s/epoch - 4ms/step
# Epoch 161/500
# 1749/1749 - 8s - loss: 0.0061 - val_loss: 2.4729e-04 - 8s/epoch - 4ms/step
# Epoch 162/500
# 1749/1749 - 5s - loss: 0.0064 - val_loss: 2.4782e-04 - 5s/epoch - 3ms/step
# Epoch 163/500
# 1749/1749 - 5s - loss: 0.0098 - val_loss: 2.2976e-04 - 5s/epoch - 3ms/step
# Epoch 164/500
# 1749/1749 - 5s - loss: 0.0050 - val_loss: 4.8741e-04 - 5s/epoch - 3ms/step
# Epoch 165/500
# 1749/1749 - 5s - loss: 0.0053 - val_loss: 2.6833e-04 - 5s/epoch - 3ms/step
# Epoch 166/500
# 1749/1749 - 5s - loss: 0.0065 - val_loss: 0.0045 - 5s/epoch - 3ms/step
# Epoch 167/500
# 1749/1749 - 5s - loss: 0.0052 - val_loss: 5.6034e-04 - 5s/epoch - 3ms/step
# Epoch 168/500
# 1749/1749 - 6s - loss: 0.0067 - val_loss: 0.0031 - 6s/epoch - 3ms/step
# Epoch 169/500
# 1749/1749 - 5s - loss: 0.0052 - val_loss: 2.1974e-04 - 5s/epoch - 3ms/step
# Epoch 170/500
# 1749/1749 - 5s - loss: 0.0066 - val_loss: 2.5231e-04 - 5s/epoch - 3ms/step
# Epoch 171/500
# 1749/1749 - 6s - loss: 0.0067 - val_loss: 2.6463e-04 - 6s/epoch - 3ms/step
# Epoch 172/500
# 1749/1749 - 5s - loss: 0.0060 - val_loss: 2.5536e-04 - 5s/epoch - 3ms/step
# Epoch 173/500
# 1749/1749 - 5s - loss: 0.0074 - val_loss: 8.4303e-04 - 5s/epoch - 3ms/step
# Epoch 174/500
# 1749/1749 - 4s - loss: 0.0084 - val_loss: 4.2007e-04 - 4s/epoch - 3ms/step
# Epoch 175/500
# 1749/1749 - 5s - loss: 0.0109 - val_loss: 2.4152e-04 - 5s/epoch - 3ms/step
# Epoch 176/500
# 1749/1749 - 5s - loss: 0.0069 - val_loss: 2.3683e-04 - 5s/epoch - 3ms/step
# Epoch 177/500
# 1749/1749 - 6s - loss: 0.0053 - val_loss: 0.0015 - 6s/epoch - 4ms/step
# Epoch 178/500
# 1749/1749 - 5s - loss: 0.0062 - val_loss: 2.5737e-04 - 5s/epoch - 3ms/step
# Epoch 179/500
# 1749/1749 - 5s - loss: 0.0063 - val_loss: 2.8413e-04 - 5s/epoch - 3ms/step
# Epoch 180/500
# 1749/1749 - 5s - loss: 0.0067 - val_loss: 3.8328e-04 - 5s/epoch - 3ms/step
# Epoch 181/500
# 1749/1749 - 5s - loss: 0.0053 - val_loss: 2.6622e-04 - 5s/epoch - 3ms/step
# Epoch 182/500
# 1749/1749 - 5s - loss: 0.0061 - val_loss: 2.1367e-04 - 5s/epoch - 3ms/step
# Epoch 183/500
# 1749/1749 - 5s - loss: 0.0061 - val_loss: 2.6424e-04 - 5s/epoch - 3ms/step
# Epoch 184/500
# 1749/1749 - 5s - loss: 0.0053 - val_loss: 2.0561e-04 - 5s/epoch - 3ms/step
# Epoch 185/500
# 1749/1749 - 5s - loss: 0.0061 - val_loss: 2.1875e-04 - 5s/epoch - 3ms/step
# Epoch 186/500
# 1749/1749 - 5s - loss: 0.0063 - val_loss: 3.9261e-04 - 5s/epoch - 3ms/step
# Epoch 187/500
# 1749/1749 - 5s - loss: 0.0092 - val_loss: 7.6285e-04 - 5s/epoch - 3ms/step
# Epoch 188/500
# 1749/1749 - 6s - loss: 0.0126 - val_loss: 2.8596e-04 - 6s/epoch - 3ms/step
# Epoch 189/500
# 1749/1749 - 5s - loss: 0.0088 - val_loss: 3.1719e-04 - 5s/epoch - 3ms/step
# Epoch 190/500
# 1749/1749 - 5s - loss: 0.0036 - val_loss: 4.7078e-04 - 5s/epoch - 3ms/step
# Epoch 191/500
# 1749/1749 - 5s - loss: 0.0070 - val_loss: 9.3196e-04 - 5s/epoch - 3ms/step
# Epoch 192/500
# 1749/1749 - 5s - loss: 0.0070 - val_loss: 3.0584e-04 - 5s/epoch - 3ms/step
# Epoch 193/500
# 1749/1749 - 5s - loss: 0.0072 - val_loss: 4.8047e-04 - 5s/epoch - 3ms/step
# Epoch 194/500
# 1749/1749 - 7s - loss: 0.0095 - val_loss: 2.6975e-04 - 7s/epoch - 4ms/step
# Epoch 195/500
# 1749/1749 - 8s - loss: 0.0040 - val_loss: 0.0014 - 8s/epoch - 5ms/step
# Epoch 196/500
# 1749/1749 - 8s - loss: 0.0088 - val_loss: 2.4213e-04 - 8s/epoch - 4ms/step
# Epoch 197/500
# 1749/1749 - 11s - loss: 0.0061 - val_loss: 2.4217e-04 - 11s/epoch - 7ms/step
# Epoch 198/500
# 1749/1749 - 9s - loss: 0.0088 - val_loss: 2.4078e-04 - 9s/epoch - 5ms/step
# Epoch 199/500
# 1749/1749 - 8s - loss: 0.0137 - val_loss: 3.0876e-04 - 8s/epoch - 4ms/step
# Epoch 200/500
# 1749/1749 - 7s - loss: 0.0034 - val_loss: 2.9241e-04 - 7s/epoch - 4ms/step
# Epoch 201/500
# 1749/1749 - 5s - loss: 0.0060 - val_loss: 1.9854e-04 - 5s/epoch - 3ms/step
# Epoch 202/500
# 1749/1749 - 6s - loss: 0.0068 - val_loss: 2.2362e-04 - 6s/epoch - 3ms/step
# Epoch 203/500
# 1749/1749 - 6s - loss: 0.0065 - val_loss: 3.4215e-04 - 6s/epoch - 3ms/step
# Epoch 204/500
# 1749/1749 - 8s - loss: 0.0082 - val_loss: 4.1468e-04 - 8s/epoch - 4ms/step
# Epoch 205/500
# 1749/1749 - 7s - loss: 0.0096 - val_loss: 1.9989e-04 - 7s/epoch - 4ms/step
# Epoch 206/500
# 1749/1749 - 7s - loss: 0.0039 - val_loss: 3.4160e-04 - 7s/epoch - 4ms/step
# Epoch 207/500
# 1749/1749 - 8s - loss: 0.0053 - val_loss: 6.6536e-04 - 8s/epoch - 4ms/step
# Epoch 208/500
# 1749/1749 - 8s - loss: 0.0068 - val_loss: 3.9722e-04 - 8s/epoch - 5ms/step
# Epoch 209/500
# 1749/1749 - 8s - loss: 0.0057 - val_loss: 2.1155e-04 - 8s/epoch - 5ms/step
# Epoch 210/500
# 1749/1749 - 8s - loss: 0.0079 - val_loss: 3.2168e-04 - 8s/epoch - 5ms/step
# Epoch 211/500
# 1749/1749 - 9s - loss: 0.0064 - val_loss: 7.1075e-04 - 9s/epoch - 5ms/step
# Epoch 212/500
# 1749/1749 - 8s - loss: 0.0070 - val_loss: 0.0013 - 8s/epoch - 4ms/step
# Epoch 213/500
# 1749/1749 - 8s - loss: 0.0059 - val_loss: 3.6602e-04 - 8s/epoch - 4ms/step
# Epoch 214/500
# 1749/1749 - 8s - loss: 0.0071 - val_loss: 2.1841e-04 - 8s/epoch - 4ms/step
# Epoch 215/500
# 1749/1749 - 8s - loss: 0.0049 - val_loss: 1.9938e-04 - 8s/epoch - 5ms/step
# Epoch 216/500
# 1749/1749 - 8s - loss: 0.0082 - val_loss: 2.2258e-04 - 8s/epoch - 5ms/step
# Epoch 217/500
# 1749/1749 - 8s - loss: 0.0078 - val_loss: 2.0359e-04 - 8s/epoch - 4ms/step
# Epoch 218/500
# 1749/1749 - 13s - loss: 0.0062 - val_loss: 2.1020e-04 - 13s/epoch - 8ms/step
# Epoch 219/500
# 1749/1749 - 10s - loss: 0.0051 - val_loss: 2.4058e-04 - 10s/epoch - 6ms/step
# Epoch 220/500
# 1749/1749 - 12s - loss: 0.0067 - val_loss: 2.4186e-04 - 12s/epoch - 7ms/step
# Epoch 221/500
# 1749/1749 - 12s - loss: 0.0085 - val_loss: 2.0336e-04 - 12s/epoch - 7ms/step
# Epoch 222/500
# 1749/1749 - 9s - loss: 0.0040 - val_loss: 8.6491e-04 - 9s/epoch - 5ms/step
# Epoch 223/500
# 1749/1749 - 11s - loss: 0.0064 - val_loss: 0.0227 - 11s/epoch - 6ms/step
# Epoch 224/500
# 1749/1749 - 10s - loss: 0.0052 - val_loss: 6.9867e-04 - 10s/epoch - 6ms/step
# Epoch 225/500
# 1749/1749 - 8s - loss: 0.0050 - val_loss: 3.7176e-04 - 8s/epoch - 5ms/step
# Epoch 226/500
# 1749/1749 - 8s - loss: 0.0075 - val_loss: 8.5211e-04 - 8s/epoch - 5ms/step
# Epoch 227/500
# 1749/1749 - 9s - loss: 0.0051 - val_loss: 1.8599e-04 - 9s/epoch - 5ms/step
# Epoch 228/500
# 1749/1749 - 10s - loss: 0.0087 - val_loss: 3.3019e-04 - 10s/epoch - 6ms/step
# Epoch 229/500
# 1749/1749 - 12s - loss: 0.0077 - val_loss: 1.9919e-04 - 12s/epoch - 7ms/step
# Epoch 230/500
# 1749/1749 - 10s - loss: 0.0051 - val_loss: 1.9085e-04 - 10s/epoch - 5ms/step
# Epoch 231/500
# 1749/1749 - 9s - loss: 0.0061 - val_loss: 1.8451e-04 - 9s/epoch - 5ms/step
# Epoch 232/500
# 1749/1749 - 13s - loss: 0.0076 - val_loss: 1.9740e-04 - 13s/epoch - 8ms/step
# Epoch 233/500
# 1749/1749 - 11s - loss: 0.0061 - val_loss: 1.8548e-04 - 11s/epoch - 6ms/step
# Epoch 234/500
# 1749/1749 - 14s - loss: 0.0041 - val_loss: 3.9935e-04 - 14s/epoch - 8ms/step
# Epoch 235/500
# 1749/1749 - 11s - loss: 0.0058 - val_loss: 4.2682e-04 - 11s/epoch - 6ms/step
# Epoch 236/500
# 1749/1749 - 9s - loss: 0.0045 - val_loss: 0.0010 - 9s/epoch - 5ms/step
# Epoch 237/500
# 1749/1749 - 7s - loss: 0.0049 - val_loss: 7.7923e-04 - 7s/epoch - 4ms/step
# Epoch 238/500
# 1749/1749 - 7s - loss: 0.0071 - val_loss: 0.0018 - 7s/epoch - 4ms/step
# Epoch 239/500
# 1749/1749 - 8s - loss: 0.0050 - val_loss: 5.5806e-04 - 8s/epoch - 5ms/step
# Epoch 240/500
# 1749/1749 - 9s - loss: 0.0050 - val_loss: 1.5646e-04 - 9s/epoch - 5ms/step
# Epoch 241/500
# 1749/1749 - 7s - loss: 0.0049 - val_loss: 0.0037 - 7s/epoch - 4ms/step
# Epoch 242/500
# 1749/1749 - 7s - loss: 0.0053 - val_loss: 5.1069e-04 - 7s/epoch - 4ms/step
# Epoch 243/500
# 1749/1749 - 7s - loss: 0.0049 - val_loss: 0.0011 - 7s/epoch - 4ms/step
# Epoch 244/500
# 1749/1749 - 8s - loss: 0.0050 - val_loss: 1.7464e-04 - 8s/epoch - 4ms/step
# Epoch 245/500
# 1749/1749 - 7s - loss: 0.0047 - val_loss: 6.1704e-04 - 7s/epoch - 4ms/step
# Epoch 246/500
# 1749/1749 - 8s - loss: 0.0104 - val_loss: 2.4997e-04 - 8s/epoch - 5ms/step
# Epoch 247/500
# 1749/1749 - 11s - loss: 0.0032 - val_loss: 6.7264e-04 - 11s/epoch - 7ms/step
# Epoch 248/500
# 1749/1749 - 13s - loss: 0.0085 - val_loss: 2.9539e-04 - 13s/epoch - 8ms/step
# Epoch 249/500
# 1749/1749 - 10s - loss: 0.0025 - val_loss: 0.0295 - 10s/epoch - 6ms/step
# Epoch 250/500
# 1749/1749 - 16s - loss: 0.0089 - val_loss: 1.6212e-04 - 16s/epoch - 9ms/step
# Epoch 251/500
# 1749/1749 - 8s - loss: 0.0030 - val_loss: 5.4281e-04 - 8s/epoch - 5ms/step
# Epoch 252/500
# 1749/1749 - 8s - loss: 0.0053 - val_loss: 7.9498e-04 - 8s/epoch - 5ms/step
# Epoch 253/500
# 1749/1749 - 8s - loss: 0.0045 - val_loss: 6.3140e-04 - 8s/epoch - 4ms/step
# Epoch 254/500
# 1749/1749 - 7s - loss: 0.0048 - val_loss: 3.8019e-04 - 7s/epoch - 4ms/step
# Epoch 255/500
# 1749/1749 - 8s - loss: 0.0076 - val_loss: 1.4487e-04 - 8s/epoch - 5ms/step
# Epoch 256/500
# 1749/1749 - 8s - loss: 0.0082 - val_loss: 1.6350e-04 - 8s/epoch - 5ms/step
# Epoch 257/500
# 1749/1749 - 7s - loss: 0.0029 - val_loss: 2.9502e-04 - 7s/epoch - 4ms/step
# Epoch 258/500
# 1749/1749 - 7s - loss: 0.0080 - val_loss: 1.3520e-04 - 7s/epoch - 4ms/step
# Epoch 259/500
# 1749/1749 - 8s - loss: 0.0070 - val_loss: 2.2825e-04 - 8s/epoch - 4ms/step
# Epoch 260/500
# 1749/1749 - 7s - loss: 0.0052 - val_loss: 2.4945e-04 - 7s/epoch - 4ms/step
# Epoch 261/500
# 1749/1749 - 8s - loss: 0.0052 - val_loss: 2.0019e-04 - 8s/epoch - 4ms/step
# Epoch 262/500
# 1749/1749 - 8s - loss: 0.0076 - val_loss: 4.2187e-04 - 8s/epoch - 4ms/step
# Epoch 263/500
# 1749/1749 - 8s - loss: 0.0040 - val_loss: 1.9181e-04 - 8s/epoch - 4ms/step
# Epoch 264/500
# 1749/1749 - 8s - loss: 0.0042 - val_loss: 3.1952e-04 - 8s/epoch - 4ms/step
# Epoch 265/500
# 1749/1749 - 8s - loss: 0.0090 - val_loss: 1.4961e-04 - 8s/epoch - 5ms/step
# Epoch 266/500
# 1749/1749 - 8s - loss: 0.0057 - val_loss: 1.6525e-04 - 8s/epoch - 5ms/step
# Epoch 267/500
# 1749/1749 - 8s - loss: 0.0049 - val_loss: 1.6852e-04 - 8s/epoch - 4ms/step
# Epoch 268/500
# 1749/1749 - 8s - loss: 0.0042 - val_loss: 2.7261e-04 - 8s/epoch - 4ms/step
# Epoch 269/500
# 1749/1749 - 9s - loss: 0.0057 - val_loss: 1.3744e-04 - 9s/epoch - 5ms/step
# Epoch 270/500
# 1749/1749 - 8s - loss: 0.0039 - val_loss: 0.0023 - 8s/epoch - 5ms/step
# Epoch 271/500
# 1749/1749 - 8s - loss: 0.0060 - val_loss: 1.9304e-04 - 8s/epoch - 4ms/step
# Epoch 272/500
# 1749/1749 - 10s - loss: 0.0053 - val_loss: 1.3409e-04 - 10s/epoch - 6ms/step
# Epoch 273/500
# 1749/1749 - 8s - loss: 0.0042 - val_loss: 2.2367e-04 - 8s/epoch - 5ms/step
# Epoch 274/500
# 1749/1749 - 8s - loss: 0.0158 - val_loss: 1.7289e-04 - 8s/epoch - 5ms/step
# Epoch 275/500
# 1749/1749 - 8s - loss: 0.0019 - val_loss: 1.8893e-04 - 8s/epoch - 4ms/step
# Epoch 276/500
# 1749/1749 - 8s - loss: 0.0046 - val_loss: 1.5626e-04 - 8s/epoch - 5ms/step
# Epoch 277/500
# 1749/1749 - 8s - loss: 0.0086 - val_loss: 1.5790e-04 - 8s/epoch - 5ms/step
# Epoch 278/500
# 1749/1749 - 8s - loss: 0.0029 - val_loss: 9.2520e-04 - 8s/epoch - 5ms/step
# Epoch 279/500
# 1749/1749 - 8s - loss: 0.0045 - val_loss: 1.2962e-04 - 8s/epoch - 5ms/step
# Epoch 280/500
# 1749/1749 - 8s - loss: 0.0049 - val_loss: 1.4803e-04 - 8s/epoch - 5ms/step
# Epoch 281/500
# 1749/1749 - 8s - loss: 0.0042 - val_loss: 6.2335e-04 - 8s/epoch - 5ms/step
# Epoch 282/500
# 1749/1749 - 8s - loss: 0.0061 - val_loss: 0.0012 - 8s/epoch - 5ms/step
# Epoch 283/500
# 1749/1749 - 8s - loss: 0.0063 - val_loss: 1.9392e-04 - 8s/epoch - 4ms/step
# Epoch 284/500
# 1749/1749 - 9s - loss: 0.0051 - val_loss: 3.0861e-04 - 9s/epoch - 5ms/step
# Epoch 285/500
# 1749/1749 - 8s - loss: 0.0057 - val_loss: 1.6785e-04 - 8s/epoch - 5ms/step
# Epoch 286/500
# 1749/1749 - 8s - loss: 0.0043 - val_loss: 1.3104e-04 - 8s/epoch - 5ms/step
# Epoch 287/500
# 1749/1749 - 8s - loss: 0.0047 - val_loss: 1.9850e-04 - 8s/epoch - 5ms/step
# Epoch 288/500
# 1749/1749 - 12s - loss: 0.0043 - val_loss: 2.8265e-04 - 12s/epoch - 7ms/step
# Epoch 289/500
# 1749/1749 - 12s - loss: 0.0055 - val_loss: 0.0458 - 12s/epoch - 7ms/step
# Epoch 290/500
# 1749/1749 - 10s - loss: 0.0072 - val_loss: 1.7084e-04 - 10s/epoch - 6ms/step
# Epoch 291/500
# 1749/1749 - 8s - loss: 0.0048 - val_loss: 2.1003e-04 - 8s/epoch - 5ms/step
# Epoch 292/500
# 1749/1749 - 8s - loss: 0.0086 - val_loss: 1.7879e-04 - 8s/epoch - 5ms/step
# Epoch 293/500
# 1749/1749 - 8s - loss: 0.0024 - val_loss: 3.1501e-04 - 8s/epoch - 5ms/step
# Epoch 294/500
# 1749/1749 - 8s - loss: 0.0047 - val_loss: 1.2831e-04 - 8s/epoch - 5ms/step
# Epoch 295/500
# 1749/1749 - 8s - loss: 0.0050 - val_loss: 0.0133 - 8s/epoch - 5ms/step
# Epoch 296/500
# 1749/1749 - 8s - loss: 0.0078 - val_loss: 1.3783e-04 - 8s/epoch - 5ms/step
# Epoch 297/500
# 1749/1749 - 8s - loss: 0.0034 - val_loss: 1.9596e-04 - 8s/epoch - 5ms/step
# Epoch 298/500
# 1749/1749 - 7s - loss: 0.0064 - val_loss: 1.2738e-04 - 7s/epoch - 4ms/step
# Epoch 299/500
# 1749/1749 - 7s - loss: 0.0040 - val_loss: 0.0032 - 7s/epoch - 4ms/step
# Epoch 300/500
# 1749/1749 - 7s - loss: 0.0057 - val_loss: 4.2270e-04 - 7s/epoch - 4ms/step
# Epoch 301/500
# 1749/1749 - 7s - loss: 0.0061 - val_loss: 1.6037e-04 - 7s/epoch - 4ms/step
# Epoch 302/500
# 1749/1749 - 7s - loss: 0.0042 - val_loss: 2.0081e-04 - 7s/epoch - 4ms/step
# Epoch 303/500
# 1749/1749 - 7s - loss: 0.0043 - val_loss: 4.7850e-04 - 7s/epoch - 4ms/step
# Epoch 304/500
# 1749/1749 - 11s - loss: 0.0041 - val_loss: 0.0013 - 11s/epoch - 6ms/step
# Epoch 305/500
# 1749/1749 - 10s - loss: 0.0043 - val_loss: 1.6223e-04 - 10s/epoch - 6ms/step
# Epoch 306/500
# 1749/1749 - 9s - loss: 0.0044 - val_loss: 3.5646e-04 - 9s/epoch - 5ms/step
# Epoch 307/500
# 1749/1749 - 7s - loss: 0.0138 - val_loss: 5.8688e-04 - 7s/epoch - 4ms/step
# Epoch 308/500
# 1749/1749 - 7s - loss: 0.0026 - val_loss: 3.1654e-04 - 7s/epoch - 4ms/step
# Epoch 309/500
# 1749/1749 - 6s - loss: 0.0036 - val_loss: 1.6663e-04 - 6s/epoch - 4ms/step
# Epoch 310/500
# 1749/1749 - 6s - loss: 0.0047 - val_loss: 1.2371e-04 - 6s/epoch - 4ms/step
# Epoch 311/500
# 1749/1749 - 7s - loss: 0.0093 - val_loss: 1.3276e-04 - 7s/epoch - 4ms/step
# Epoch 312/500
# 1749/1749 - 7s - loss: 0.0025 - val_loss: 1.3981e-04 - 7s/epoch - 4ms/step
# Epoch 313/500
# 1749/1749 - 7s - loss: 0.0054 - val_loss: 0.0038 - 7s/epoch - 4ms/step
# Epoch 314/500
# 1749/1749 - 7s - loss: 0.0044 - val_loss: 1.2502e-04 - 7s/epoch - 4ms/step
# Epoch 315/500
# 1749/1749 - 7s - loss: 0.0040 - val_loss: 9.6906e-04 - 7s/epoch - 4ms/step
# Epoch 316/500
# 1749/1749 - 7s - loss: 0.0040 - val_loss: 1.2487e-04 - 7s/epoch - 4ms/step
# Epoch 317/500
# 1749/1749 - 10s - loss: 0.0072 - val_loss: 5.9683e-04 - 10s/epoch - 6ms/step
# Epoch 318/500
# 1749/1749 - 10s - loss: 0.0030 - val_loss: 0.0019 - 10s/epoch - 6ms/step
# Epoch 319/500
# 1749/1749 - 9s - loss: 0.0041 - val_loss: 3.4750e-04 - 9s/epoch - 5ms/step
# Epoch 320/500
# 1749/1749 - 10s - loss: 0.0050 - val_loss: 1.1155e-04 - 10s/epoch - 6ms/step
# Epoch 321/500
# 1749/1749 - 10s - loss: 0.0045 - val_loss: 1.3750e-04 - 10s/epoch - 6ms/step
# Epoch 322/500
# 1749/1749 - 9s - loss: 0.0043 - val_loss: 1.4067e-04 - 9s/epoch - 5ms/step
# Epoch 323/500
# 1749/1749 - 11s - loss: 0.0054 - val_loss: 1.1041e-04 - 11s/epoch - 6ms/step
# Epoch 324/500
# 1749/1749 - 10s - loss: 0.0043 - val_loss: 1.1780e-04 - 10s/epoch - 5ms/step
# Epoch 325/500
# 1749/1749 - 8s - loss: 0.0046 - val_loss: 3.0153e-04 - 8s/epoch - 5ms/step
# Epoch 326/500
# 1749/1749 - 8s - loss: 0.0060 - val_loss: 1.1690e-04 - 8s/epoch - 4ms/step
# Epoch 327/500
# 1749/1749 - 7s - loss: 0.0041 - val_loss: 1.9758e-04 - 7s/epoch - 4ms/step
# Epoch 328/500
# 1749/1749 - 7s - loss: 0.0073 - val_loss: 2.8456e-04 - 7s/epoch - 4ms/step
# Epoch 329/500
# 1749/1749 - 9s - loss: 0.0034 - val_loss: 6.0155e-04 - 9s/epoch - 5ms/step
# Epoch 330/500
# 1749/1749 - 11s - loss: 0.0049 - val_loss: 5.6734e-04 - 11s/epoch - 6ms/step
# Epoch 331/500
# 1749/1749 - 9s - loss: 0.0065 - val_loss: 1.4830e-04 - 9s/epoch - 5ms/step
# Epoch 332/500
# 1749/1749 - 7s - loss: 0.0061 - val_loss: 5.9566e-04 - 7s/epoch - 4ms/step
# Epoch 333/500
# 1749/1749 - 8s - loss: 0.0045 - val_loss: 1.2716e-04 - 8s/epoch - 5ms/step
# Epoch 334/500
# 1749/1749 - 8s - loss: 0.0037 - val_loss: 1.5567e-04 - 8s/epoch - 5ms/step
# Epoch 335/500
# 1749/1749 - 8s - loss: 0.0045 - val_loss: 5.5496e-04 - 8s/epoch - 4ms/step
# Epoch 336/500
# 1749/1749 - 8s - loss: 0.0039 - val_loss: 3.5018e-04 - 8s/epoch - 4ms/step
# Epoch 337/500
# 1749/1749 - 7s - loss: 0.0048 - val_loss: 1.9221e-04 - 7s/epoch - 4ms/step
# Epoch 338/500
# 1749/1749 - 8s - loss: 0.0043 - val_loss: 1.1183e-04 - 8s/epoch - 4ms/step
# Epoch 339/500
# 1749/1749 - 7s - loss: 0.0051 - val_loss: 1.2106e-04 - 7s/epoch - 4ms/step
# Epoch 340/500
# 1749/1749 - 8s - loss: 0.0039 - val_loss: 1.0750e-04 - 8s/epoch - 4ms/step
# Epoch 341/500
# 1749/1749 - 10s - loss: 0.0047 - val_loss: 1.1617e-04 - 10s/epoch - 6ms/step
# Epoch 342/500
# 1749/1749 - 10s - loss: 0.0047 - val_loss: 4.1671e-04 - 10s/epoch - 6ms/step
# Epoch 343/500
# 1749/1749 - 8s - loss: 0.0037 - val_loss: 1.1102e-04 - 8s/epoch - 5ms/step
# Epoch 344/500
# 1749/1749 - 12s - loss: 0.0040 - val_loss: 1.2501e-04 - 12s/epoch - 7ms/step
# Epoch 345/500
# 1749/1749 - 10s - loss: 0.0054 - val_loss: 2.0128e-04 - 10s/epoch - 6ms/step
# Epoch 346/500
# 1749/1749 - 8s - loss: 0.0039 - val_loss: 1.0780e-04 - 8s/epoch - 5ms/step
# Epoch 347/500
# 1749/1749 - 7s - loss: 0.0057 - val_loss: 4.0712e-04 - 7s/epoch - 4ms/step
# Epoch 348/500
# 1749/1749 - 9s - loss: 0.0054 - val_loss: 1.2123e-04 - 9s/epoch - 5ms/step
# Epoch 349/500
# 1749/1749 - 11s - loss: 0.0043 - val_loss: 1.1074e-04 - 11s/epoch - 6ms/step
# Epoch 350/500
# 1749/1749 - 9s - loss: 0.0054 - val_loss: 1.5096e-04 - 9s/epoch - 5ms/step
# Epoch 351/500
# 1749/1749 - 11s - loss: 0.0038 - val_loss: 3.3850e-04 - 11s/epoch - 6ms/step
# Epoch 352/500
# 1749/1749 - 10s - loss: 0.0071 - val_loss: 1.5899e-04 - 10s/epoch - 6ms/step
# Epoch 353/500
# 1749/1749 - 10s - loss: 0.0027 - val_loss: 2.8462e-04 - 10s/epoch - 6ms/step
# Epoch 354/500
# 1749/1749 - 15s - loss: 0.0050 - val_loss: 1.2266e-04 - 15s/epoch - 9ms/step
# Epoch 355/500
# 1749/1749 - 13s - loss: 0.0060 - val_loss: 1.1919e-04 - 13s/epoch - 7ms/step
# Epoch 356/500
# 1749/1749 - 19s - loss: 0.0142 - val_loss: 7.8232e-04 - 19s/epoch - 11ms/step
# Epoch 357/500
# 1749/1749 - 13s - loss: 0.0048 - val_loss: 2.2784e-04 - 13s/epoch - 7ms/step
# Epoch 358/500
# 1749/1749 - 11s - loss: 0.0029 - val_loss: 2.6834e-04 - 11s/epoch - 6ms/step
# Epoch 359/500
# 1749/1749 - 9s - loss: 0.0034 - val_loss: 1.7846e-04 - 9s/epoch - 5ms/step
# Epoch 360/500
# 1749/1749 - 8s - loss: 0.0038 - val_loss: 1.1677e-04 - 8s/epoch - 5ms/step
# Epoch 361/500
# 1749/1749 - 7s - loss: 0.0036 - val_loss: 9.8429e-05 - 7s/epoch - 4ms/step
# Epoch 362/500
# 1749/1749 - 7s - loss: 0.0037 - val_loss: 1.1311e-04 - 7s/epoch - 4ms/step
# Epoch 363/500
# 1749/1749 - 8s - loss: 0.0074 - val_loss: 2.5627e-04 - 8s/epoch - 4ms/step
# Epoch 364/500
# 1749/1749 - 7s - loss: 0.0034 - val_loss: 1.1317e-04 - 7s/epoch - 4ms/step
# Epoch 365/500
# 1749/1749 - 8s - loss: 0.0060 - val_loss: 1.5991e-04 - 8s/epoch - 4ms/step
# Epoch 366/500
# 1749/1749 - 11s - loss: 0.0024 - val_loss: 4.1213e-04 - 11s/epoch - 6ms/step
# Epoch 367/500
# 1749/1749 - 10s - loss: 0.0081 - val_loss: 1.3132e-04 - 10s/epoch - 6ms/step
# Epoch 368/500
# 1749/1749 - 9s - loss: 0.0022 - val_loss: 3.4398e-04 - 9s/epoch - 5ms/step
# Epoch 369/500
# 1749/1749 - 9s - loss: 0.0061 - val_loss: 1.1825e-04 - 9s/epoch - 5ms/step
# Epoch 370/500
# 1749/1749 - 10s - loss: 0.0064 - val_loss: 0.0030 - 10s/epoch - 6ms/step
# Epoch 371/500
# 1749/1749 - 8s - loss: 0.0024 - val_loss: 3.6257e-04 - 8s/epoch - 5ms/step
# Epoch 372/500
# 1749/1749 - 8s - loss: 0.0065 - val_loss: 1.2712e-04 - 8s/epoch - 4ms/step
# Epoch 373/500
# 1749/1749 - 7s - loss: 0.0068 - val_loss: 1.1543e-04 - 7s/epoch - 4ms/step
# Epoch 374/500
# 1749/1749 - 10s - loss: 0.0029 - val_loss: 2.6963e-04 - 10s/epoch - 6ms/step
# Epoch 375/500
# 1749/1749 - 10s - loss: 0.0040 - val_loss: 2.4808e-04 - 10s/epoch - 6ms/step
# Epoch 376/500
# 1749/1749 - 8s - loss: 0.0067 - val_loss: 1.0550e-04 - 8s/epoch - 5ms/step
# Epoch 377/500
# 1749/1749 - 7s - loss: 0.0027 - val_loss: 9.9963e-05 - 7s/epoch - 4ms/step
# Epoch 378/500
# 1749/1749 - 11s - loss: 0.0039 - val_loss: 0.0012 - 11s/epoch - 6ms/step
# Epoch 379/500
# 1749/1749 - 9s - loss: 0.0069 - val_loss: 3.7327e-04 - 9s/epoch - 5ms/step
# Epoch 380/500
# 1749/1749 - 11s - loss: 0.0040 - val_loss: 1.1686e-04 - 11s/epoch - 6ms/step
# Epoch 381/500
# 1749/1749 - 9s - loss: 0.0047 - val_loss: 1.1272e-04 - 9s/epoch - 5ms/step
# Epoch 382/500
# 1749/1749 - 7s - loss: 0.0050 - val_loss: 1.0240e-04 - 7s/epoch - 4ms/step
# Epoch 383/500
# 1749/1749 - 10s - loss: 0.0060 - val_loss: 2.1049e-04 - 10s/epoch - 6ms/step
# Epoch 384/500
# 1749/1749 - 11s - loss: 0.0067 - val_loss: 1.1543e-04 - 11s/epoch - 6ms/step
# Epoch 385/500
# 1749/1749 - 12s - loss: 0.0026 - val_loss: 2.4760e-04 - 12s/epoch - 7ms/step
# Epoch 386/500
# 1749/1749 - 8s - loss: 0.0075 - val_loss: 1.1313e-04 - 8s/epoch - 5ms/step
# Epoch 387/500
# 1749/1749 - 10s - loss: 0.0023 - val_loss: 3.0371e-04 - 10s/epoch - 6ms/step
# Epoch 388/500
# 1749/1749 - 10s - loss: 0.0033 - val_loss: 5.2110e-04 - 10s/epoch - 6ms/step
# Epoch 389/500
# 1749/1749 - 7s - loss: 0.0055 - val_loss: 2.5772e-04 - 7s/epoch - 4ms/step
# Epoch 390/500
# 1749/1749 - 7s - loss: 0.0044 - val_loss: 1.1287e-04 - 7s/epoch - 4ms/step
# Epoch 391/500
# 1749/1749 - 9s - loss: 0.0035 - val_loss: 2.5285e-04 - 9s/epoch - 5ms/step
# Epoch 392/500
# 1749/1749 - 11s - loss: 0.0075 - val_loss: 1.1008e-04 - 11s/epoch - 6ms/step
# Epoch 393/500
# 1749/1749 - 10s - loss: 0.0026 - val_loss: 0.0013 - 10s/epoch - 6ms/step
# Epoch 394/500
# 1749/1749 - 9s - loss: 0.0044 - val_loss: 1.1511e-04 - 9s/epoch - 5ms/step
# Epoch 395/500
# 1749/1749 - 11s - loss: 0.0031 - val_loss: 1.0743e-04 - 11s/epoch - 7ms/step
# Epoch 396/500
# 1749/1749 - 10s - loss: 0.0046 - val_loss: 1.5476e-04 - 10s/epoch - 6ms/step
# Epoch 397/500
# 1749/1749 - 10s - loss: 0.0077 - val_loss: 2.1253e-04 - 10s/epoch - 6ms/step
# Epoch 398/500
# 1749/1749 - 8s - loss: 0.0051 - val_loss: 1.3558e-04 - 8s/epoch - 5ms/step
# Epoch 399/500
# 1749/1749 - 8s - loss: 0.0040 - val_loss: 1.0448e-04 - 8s/epoch - 4ms/step
# Epoch 400/500
# 1749/1749 - 7s - loss: 0.0076 - val_loss: 1.1242e-04 - 7s/epoch - 4ms/step
# Epoch 401/500
# 1749/1749 - 10s - loss: 0.0049 - val_loss: 1.0674e-04 - 10s/epoch - 6ms/step
# Epoch 402/500
# 1749/1749 - 9s - loss: 0.0025 - val_loss: 1.7785e-04 - 9s/epoch - 5ms/step
# Epoch 403/500
# 1749/1749 - 11s - loss: 0.0034 - val_loss: 1.2122e-04 - 11s/epoch - 6ms/step
# Epoch 404/500
# 1749/1749 - 8s - loss: 0.0047 - val_loss: 1.0424e-04 - 8s/epoch - 5ms/step
# Epoch 405/500
# 1749/1749 - 8s - loss: 0.0063 - val_loss: 9.9833e-05 - 8s/epoch - 4ms/step
# Epoch 406/500
# 1749/1749 - 7s - loss: 0.0029 - val_loss: 0.0069 - 7s/epoch - 4ms/step
# Epoch 407/500
# 1749/1749 - 7s - loss: 0.0036 - val_loss: 2.2804e-04 - 7s/epoch - 4ms/step
# Epoch 408/500
# 1749/1749 - 12s - loss: 0.0060 - val_loss: 5.5648e-04 - 12s/epoch - 7ms/step
# Epoch 409/500
# 1749/1749 - 10s - loss: 0.0027 - val_loss: 3.5594e-04 - 10s/epoch - 6ms/step
# Epoch 410/500
# 1749/1749 - 10s - loss: 0.0051 - val_loss: 1.0159e-04 - 10s/epoch - 6ms/step
# Epoch 411/500
# 1749/1749 - 8s - loss: 0.0032 - val_loss: 1.9084e-04 - 8s/epoch - 4ms/step
# Epoch 412/500
# 1749/1749 - 7s - loss: 0.0046 - val_loss: 2.5174e-04 - 7s/epoch - 4ms/step
# Epoch 413/500
# 1749/1749 - 9s - loss: 0.0033 - val_loss: 6.8206e-04 - 9s/epoch - 5ms/step
# Epoch 414/500
# 1749/1749 - 12s - loss: 0.0066 - val_loss: 0.0020 - 12s/epoch - 7ms/step
# Epoch 415/500
# 1749/1749 - 10s - loss: 0.0033 - val_loss: 9.2101e-05 - 10s/epoch - 6ms/step
# Epoch 416/500
# 1749/1749 - 12s - loss: 0.0057 - val_loss: 4.0899e-04 - 12s/epoch - 7ms/step
# Epoch 417/500
# 1749/1749 - 11s - loss: 0.0027 - val_loss: 3.8870e-04 - 11s/epoch - 6ms/step
# Epoch 418/500
# 1749/1749 - 10s - loss: 0.0037 - val_loss: 1.3313e-04 - 10s/epoch - 6ms/step
# Epoch 419/500
# 1749/1749 - 9s - loss: 0.0044 - val_loss: 1.5972e-04 - 9s/epoch - 5ms/step
# Epoch 420/500
# 1749/1749 - 11s - loss: 0.0041 - val_loss: 3.2717e-04 - 11s/epoch - 6ms/step
# Epoch 421/500
# 1749/1749 - 10s - loss: 0.0072 - val_loss: 8.9326e-05 - 10s/epoch - 6ms/step
# Epoch 422/500
# 1749/1749 - 11s - loss: 0.0017 - val_loss: 8.7765e-05 - 11s/epoch - 6ms/step
# Epoch 423/500
# 1749/1749 - 9s - loss: 0.0073 - val_loss: 8.9665e-05 - 9s/epoch - 5ms/step
# Epoch 424/500
# 1749/1749 - 11s - loss: 0.0022 - val_loss: 5.7390e-04 - 11s/epoch - 6ms/step
# Epoch 425/500
# 1749/1749 - 11s - loss: 0.0039 - val_loss: 5.9255e-04 - 11s/epoch - 6ms/step
# Epoch 426/500
# 1749/1749 - 12s - loss: 0.0044 - val_loss: 9.1358e-05 - 12s/epoch - 7ms/step
# Epoch 427/500
# 1749/1749 - 12s - loss: 0.0045 - val_loss: 1.1754e-04 - 12s/epoch - 7ms/step
# Epoch 428/500
# 1749/1749 - 10s - loss: 0.0042 - val_loss: 3.6540e-04 - 10s/epoch - 6ms/step
# Epoch 429/500
# 1749/1749 - 9s - loss: 0.0044 - val_loss: 4.0090e-04 - 9s/epoch - 5ms/step
# Epoch 430/500
# 1749/1749 - 8s - loss: 0.0054 - val_loss: 9.6349e-05 - 8s/epoch - 4ms/step
# Epoch 431/500
# 1749/1749 - 10s - loss: 0.0029 - val_loss: 6.2951e-04 - 10s/epoch - 6ms/step
# Epoch 432/500
# 1749/1749 - 11s - loss: 0.0046 - val_loss: 2.2797e-04 - 11s/epoch - 7ms/step
# Epoch 433/500
# 1749/1749 - 11s - loss: 0.0040 - val_loss: 1.0208e-04 - 11s/epoch - 6ms/step
# Epoch 434/500
# 1749/1749 - 10s - loss: 0.0113 - val_loss: 9.2089e-05 - 10s/epoch - 5ms/step
# Epoch 435/500
# 1749/1749 - 11s - loss: 0.0036 - val_loss: 2.5522e-04 - 11s/epoch - 6ms/step
# Epoch 436/500
# 1749/1749 - 12s - loss: 0.0023 - val_loss: 8.6248e-05 - 12s/epoch - 7ms/step
# Epoch 437/500
# 1749/1749 - 11s - loss: 0.0031 - val_loss: 8.2523e-05 - 11s/epoch - 6ms/step
# Epoch 438/500
# 1749/1749 - 9s - loss: 0.0051 - val_loss: 9.0005e-05 - 9s/epoch - 5ms/step
# Epoch 439/500
# 1749/1749 - 8s - loss: 0.0040 - val_loss: 1.2431e-04 - 8s/epoch - 4ms/step
# Epoch 440/500
# 1749/1749 - 12s - loss: 0.0042 - val_loss: 1.2217e-04 - 12s/epoch - 7ms/step
# Epoch 441/500
# 1749/1749 - 10s - loss: 0.0037 - val_loss: 1.9811e-04 - 10s/epoch - 6ms/step
# Epoch 442/500
# 1749/1749 - 10s - loss: 0.0035 - val_loss: 0.0061 - 10s/epoch - 6ms/step
# Epoch 443/500
# 1749/1749 - 8s - loss: 0.0039 - val_loss: 1.2484e-04 - 8s/epoch - 4ms/step
# Epoch 444/500
# 1749/1749 - 12s - loss: 0.0047 - val_loss: 1.0699e-04 - 12s/epoch - 7ms/step
# Epoch 445/500
# 1749/1749 - 11s - loss: 0.0051 - val_loss: 2.9771e-04 - 11s/epoch - 6ms/step
# Epoch 446/500
# 1749/1749 - 12s - loss: 0.0034 - val_loss: 1.6308e-04 - 12s/epoch - 7ms/step
# Epoch 447/500
# 1749/1749 - 17s - loss: 0.0037 - val_loss: 1.5640e-04 - 17s/epoch - 10ms/step
# Epoch 448/500
# 1749/1749 - 19s - loss: 0.0048 - val_loss: 9.9864e-05 - 19s/epoch - 11ms/step
# Epoch 449/500
# 1749/1749 - 10s - loss: 0.0031 - val_loss: 8.7402e-05 - 10s/epoch - 6ms/step
# Epoch 450/500
# 1749/1749 - 13s - loss: 0.0035 - val_loss: 1.7062e-04 - 13s/epoch - 8ms/step
# Epoch 451/500
# 1749/1749 - 11s - loss: 0.0047 - val_loss: 8.5836e-05 - 11s/epoch - 6ms/step
# Epoch 452/500
# 1749/1749 - 13s - loss: 0.0034 - val_loss: 2.0506e-04 - 13s/epoch - 7ms/step
# Epoch 453/500
# 1749/1749 - 11s - loss: 0.0035 - val_loss: 1.0090e-04 - 11s/epoch - 6ms/step
# Epoch 454/500
# 1749/1749 - 11s - loss: 0.0031 - val_loss: 8.2682e-05 - 11s/epoch - 6ms/step
# Epoch 455/500
# 1749/1749 - 9s - loss: 0.0037 - val_loss: 1.8453e-04 - 9s/epoch - 5ms/step
# Epoch 456/500
# 1749/1749 - 8s - loss: 0.0094 - val_loss: 8.4045e-05 - 8s/epoch - 4ms/step
# Epoch 457/500
# 1749/1749 - 9s - loss: 0.0042 - val_loss: 1.2578e-04 - 9s/epoch - 5ms/step
# Epoch 458/500
# 1749/1749 - 8s - loss: 0.0051 - val_loss: 1.5610e-04 - 8s/epoch - 5ms/step
# Epoch 459/500
# 1749/1749 - 10s - loss: 0.0046 - val_loss: 2.5965e-04 - 10s/epoch - 6ms/step
# Epoch 460/500
# 1749/1749 - 9s - loss: 0.0035 - val_loss: 7.5162e-04 - 9s/epoch - 5ms/step
# Epoch 461/500
# 1749/1749 - 9s - loss: 0.0037 - val_loss: 3.0295e-04 - 9s/epoch - 5ms/step
# Epoch 462/500
# 1749/1749 - 12s - loss: 0.0058 - val_loss: 1.0990e-04 - 12s/epoch - 7ms/step
# Epoch 463/500
# 1749/1749 - 10s - loss: 0.0031 - val_loss: 3.3535e-04 - 10s/epoch - 6ms/step
# Epoch 464/500
# 1749/1749 - 10s - loss: 0.0035 - val_loss: 1.2103e-04 - 10s/epoch - 6ms/step
# Epoch 465/500
# 1749/1749 - 11s - loss: 0.0037 - val_loss: 1.5472e-04 - 11s/epoch - 6ms/step
# Epoch 466/500
# 1749/1749 - 11s - loss: 0.0035 - val_loss: 1.7434e-04 - 11s/epoch - 7ms/step
# Epoch 467/500
# 1749/1749 - 10s - loss: 0.0048 - val_loss: 9.7435e-05 - 10s/epoch - 6ms/step
# Epoch 468/500
# 1749/1749 - 12s - loss: 0.0091 - val_loss: 3.2168e-04 - 12s/epoch - 7ms/step
# Epoch 469/500
# 1749/1749 - 11s - loss: 0.0040 - val_loss: 1.0716e-04 - 11s/epoch - 6ms/step
# Epoch 470/500
# 1749/1749 - 10s - loss: 0.0029 - val_loss: 9.0517e-05 - 10s/epoch - 6ms/step
# Epoch 471/500
# 1749/1749 - 9s - loss: 0.0030 - val_loss: 1.8397e-04 - 9s/epoch - 5ms/step
# Epoch 472/500
# 1749/1749 - 9s - loss: 0.0095 - val_loss: 1.2132e-04 - 9s/epoch - 5ms/step
# Epoch 473/500
# 1749/1749 - 10s - loss: 0.0036 - val_loss: 9.5075e-05 - 10s/epoch - 6ms/step
# Epoch 474/500
# 1749/1749 - 10s - loss: 0.0018 - val_loss: 1.2342e-04 - 10s/epoch - 6ms/step
# Epoch 475/500
# 1749/1749 - 13s - loss: 0.0045 - val_loss: 9.6335e-05 - 13s/epoch - 8ms/step
# Epoch 476/500
# 1749/1749 - 10s - loss: 0.0024 - val_loss: 8.1443e-05 - 10s/epoch - 6ms/step
# Epoch 477/500
# 1749/1749 - 9s - loss: 0.0029 - val_loss: 1.3494e-04 - 9s/epoch - 5ms/step
# Epoch 478/500
# 1749/1749 - 11s - loss: 0.0036 - val_loss: 1.4651e-04 - 11s/epoch - 6ms/step
# Epoch 479/500
# 1749/1749 - 10s - loss: 0.0031 - val_loss: 1.4247e-04 - 10s/epoch - 6ms/step
# Epoch 480/500
# 1749/1749 - 12s - loss: 0.0053 - val_loss: 2.1740e-04 - 12s/epoch - 7ms/step
# Epoch 481/500
# 1749/1749 - 12s - loss: 0.0020 - val_loss: 2.0229e-04 - 12s/epoch - 7ms/step
# Epoch 482/500
# 1749/1749 - 10s - loss: 0.0036 - val_loss: 3.8606e-04 - 10s/epoch - 6ms/step
# Epoch 483/500
# 1749/1749 - 11s - loss: 0.0050 - val_loss: 8.1472e-05 - 11s/epoch - 6ms/step
# Epoch 484/500
# 1749/1749 - 10s - loss: 0.0022 - val_loss: 9.1231e-05 - 10s/epoch - 6ms/step
# Epoch 485/500
# 1749/1749 - 8s - loss: 0.0028 - val_loss: 1.3499e-04 - 8s/epoch - 5ms/step
# Epoch 486/500
# 1749/1749 - 8s - loss: 0.0027 - val_loss: 1.8116e-04 - 8s/epoch - 4ms/step
# Epoch 487/500
# 1749/1749 - 8s - loss: 0.0030 - val_loss: 4.0289e-04 - 8s/epoch - 5ms/step
# Epoch 488/500
# 1749/1749 - 8s - loss: 0.0033 - val_loss: 7.1752e-05 - 8s/epoch - 4ms/step
# Epoch 489/500
# 1749/1749 - 8s - loss: 0.0056 - val_loss: 8.6540e-05 - 8s/epoch - 5ms/step
# Epoch 490/500
# 1749/1749 - 10s - loss: 0.0018 - val_loss: 0.0015 - 10s/epoch - 6ms/step
# Epoch 491/500
# 1749/1749 - 8s - loss: 0.0043 - val_loss: 4.0613e-04 - 8s/epoch - 5ms/step
# Epoch 492/500
# 1749/1749 - 8s - loss: 0.0035 - val_loss: 2.7433e-04 - 8s/epoch - 5ms/step
# Epoch 493/500
# 1749/1749 - 9s - loss: 0.0022 - val_loss: 9.8288e-04 - 9s/epoch - 5ms/step
# Epoch 494/500
# 1749/1749 - 8s - loss: 0.0046 - val_loss: 9.2591e-05 - 8s/epoch - 5ms/step
# Epoch 495/500
# 1749/1749 - 9s - loss: 0.0044 - val_loss: 9.1280e-05 - 9s/epoch - 5ms/step
# Epoch 496/500
# 1749/1749 - 9s - loss: 0.0037 - val_loss: 6.0119e-04 - 9s/epoch - 5ms/step
# Epoch 497/500
# 1749/1749 - 9s - loss: 0.0030 - val_loss: 9.4852e-05 - 9s/epoch - 5ms/step
# Epoch 498/500
# 1749/1749 - 8s - loss: 0.0063 - val_loss: 8.1269e-05 - 8s/epoch - 5ms/step
# Epoch 499/500
# 1749/1749 - 9s - loss: 0.0017 - val_loss: 7.7279e-05 - 9s/epoch - 5ms/step
# Epoch 500/500
# 1749/1749 - 9s - loss: 0.0039 - val_loss: 1.8236e-04 - 9s/epoch - 5ms/step

# %% [markdown]
# ## Metrics ($LPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 875/875 [==============================] - 3s 2ms/step
# (27972, 3)
# (27972, 10)
# Test RMSE: 4.013
# Test MAE: 2.803

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('Kyoto DST Index', fontsize=20)
plt.legend(fontsize=20)
plt.show()
