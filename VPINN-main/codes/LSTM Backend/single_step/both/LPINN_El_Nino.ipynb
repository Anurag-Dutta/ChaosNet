# %% [markdown]
# # Time Series Prediction with Lorrenz Attractor Inspired Deep Learning ($LPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-09 11:45:53

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Lorrenz Intermittency_

# %% [markdown]
# The `lorrenz_intermittency.dat` is generated from the Runge Kutta Method.

# %% [markdown]
# This feeds the model with the dynamics of the Lorrenz Attractor

# %%
data = np.genfromtxt('datasets/lorrenz_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 7 # Weekly Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 28.981277697415116
# 1         0.002440
# 2         0.005852
# 3         0.008959
# 4         0.011882
# 5         0.014722
#             ...
# 139867    0.014918
# 139868    0.009196
# 139869    0.004054
# 139870   -0.000537
# 139871   -0.004624
# Name: 1, Length: 139871, dtype: float64
# 2         0.000488
# 3         0.000444
# 4         0.000418
# 5         0.000406
# 6         0.000406
#             ...
# 139867   -0.000901
# 139868   -0.000817
# 139869   -0.000735
# 139870   -0.000656
# 139871   -0.000584
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _EL NINO_

# %%
data = pd.read_csv("datasets/elnino.csv")
training_set = data.iloc[:, 1]
print(training_set)
# Out:
# 0       23.4
# 1       23.4
# 2       24.2
# 3       24.4
# 4       25.1
#         ...
# 1629    25.4
# 1630    24.9
# 1631    25.3
# 1632    24.7
# 1633    24.6
# Name: SST1, Length: 1634, dtype: float64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0         0.002440
# 1         0.005852
# 2         0.008959
# 3         0.011882
# 4         0.014722
#             ...
# 139866    0.014918
# 139867    0.009196
# 139868    0.004054
# 139869   -0.000537
# 139870   -0.004624
# Name: 1, Length: 139871, dtype: float64
# 0         0.000488
# 1         0.000444
# 2         0.000418
# 3         0.000406
# 4         0.000406
#             ...
# 139865   -0.000901
# 139866   -0.000817
# 139867   -0.000735
# 139868   -0.000656
# 139869   -0.000584
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lorrenz Equation_)

# %% [markdown]
# _Parameters_: $\sigma=10, \rho=28$

# %%
s=10
r=28
L = df.iloc[:, 2] + df.iloc[:, 1]*(1 + s) - df.iloc[:, 0] * s * (r - 1)
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10        23.4       23.4       24.2       24.4       25.1       25.8
# 11        23.4       24.2       24.4       25.1       25.8       25.9
# 12        24.2       24.4       25.1       25.8       25.9       26.1
# 13        24.4       25.1       25.8       25.9       26.1       26.1
# 14        25.1       25.8       25.9       26.1       26.1       26.7
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)   var2(t)   var3(t)
# 10       25.9       26.1       26.1       26.7     26.1  0.034146  0.000600
# 11       26.1       26.1       26.7       26.1     26.1  0.038344  0.000660
# 12       26.1       26.7       26.1       26.1     25.7  0.042966  0.000729
# 13       26.7       26.1       26.1       25.7     25.6  0.048068  0.000806
# 14       26.1       26.1       25.7       25.6     25.1  0.053711  0.000892
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (1623, 13)
# (1623, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (1298, 1, 10) (1298, 3) (325, 1, 10) (325, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
s = tf.Variable(10, name="sigma", trainable=True, dtype=tf.float32)
r = tf.Variable(28, name="rhow", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] + y_true[:, 1]*(1 + s) - y_true[:, 0] * s * (r - 1)), (y_pred[:, 2] + y_pred[:, 1]*(1 + s) - y_pred[:, 0] * s * (r - 1)))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] + (y_pred[1:-1]-y_pred[:-2])*(1 + s) - y_pred[:-2] * s * (r - 1)
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] + (y_real[1:-1]-y_real[:-2])*(1 + s) - y_real[:-2] * s * (r - 1)
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($LPINN$)

# %%
s = tf.Variable(10, name="sigma", trainable=True, dtype=tf.float32)
r = tf.Variable(28, name="rhow", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square((y_pred[:, 2] + y_pred[:, 1]*(1 + s) - y_pred[:, 0] * s * (r - 1)))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 21/21 - 8s - loss: 1.8963 - val_loss: 0.8627 - 8s/epoch - 361ms/step
# Epoch 2/500
# 21/21 - 0s - loss: 0.7852 - val_loss: 0.5785 - 139ms/epoch - 7ms/step
# Epoch 3/500
# 21/21 - 0s - loss: 0.7695 - val_loss: 0.5757 - 230ms/epoch - 11ms/step
# Epoch 4/500
# 21/21 - 0s - loss: 0.7510 - val_loss: 0.6113 - 254ms/epoch - 12ms/step
# Epoch 5/500
# 21/21 - 0s - loss: 0.7183 - val_loss: 0.6304 - 174ms/epoch - 8ms/step
# Epoch 6/500
# 21/21 - 0s - loss: 0.6684 - val_loss: 0.6145 - 174ms/epoch - 8ms/step
# Epoch 7/500
# 21/21 - 0s - loss: 0.6120 - val_loss: 0.5735 - 212ms/epoch - 10ms/step
# Epoch 8/500
# 21/21 - 0s - loss: 0.5564 - val_loss: 0.5231 - 221ms/epoch - 11ms/step
# Epoch 9/500
# 21/21 - 0s - loss: 0.5065 - val_loss: 0.4726 - 198ms/epoch - 9ms/step
# Epoch 10/500
# 21/21 - 0s - loss: 0.4628 - val_loss: 0.4257 - 260ms/epoch - 12ms/step
# Epoch 11/500
# 21/21 - 0s - loss: 0.4238 - val_loss: 0.3852 - 239ms/epoch - 11ms/step
# Epoch 12/500
# 21/21 - 0s - loss: 0.3885 - val_loss: 0.3560 - 133ms/epoch - 6ms/step
# Epoch 13/500
# 21/21 - 0s - loss: 0.3573 - val_loss: 0.3425 - 145ms/epoch - 7ms/step
# Epoch 14/500
# 21/21 - 0s - loss: 0.3319 - val_loss: 0.3424 - 139ms/epoch - 7ms/step
# Epoch 15/500
# 21/21 - 0s - loss: 0.3138 - val_loss: 0.3457 - 240ms/epoch - 11ms/step
# Epoch 16/500
# 21/21 - 0s - loss: 0.3019 - val_loss: 0.3438 - 227ms/epoch - 11ms/step
# Epoch 17/500
# 21/21 - 0s - loss: 0.2938 - val_loss: 0.3376 - 187ms/epoch - 9ms/step
# Epoch 18/500
# 21/21 - 0s - loss: 0.2876 - val_loss: 0.3312 - 191ms/epoch - 9ms/step
# Epoch 19/500
# 21/21 - 0s - loss: 0.2825 - val_loss: 0.3256 - 149ms/epoch - 7ms/step
# Epoch 20/500
# 21/21 - 0s - loss: 0.2782 - val_loss: 0.3204 - 128ms/epoch - 6ms/step
# Epoch 21/500
# 21/21 - 0s - loss: 0.2744 - val_loss: 0.3157 - 161ms/epoch - 8ms/step
# Epoch 22/500
# 21/21 - 0s - loss: 0.2710 - val_loss: 0.3116 - 171ms/epoch - 8ms/step
# Epoch 23/500
# 21/21 - 0s - loss: 0.2681 - val_loss: 0.3079 - 206ms/epoch - 10ms/step
# Epoch 24/500
# 21/21 - 0s - loss: 0.2655 - val_loss: 0.3047 - 184ms/epoch - 9ms/step
# Epoch 25/500
# 21/21 - 0s - loss: 0.2632 - val_loss: 0.3018 - 144ms/epoch - 7ms/step
# Epoch 26/500
# 21/21 - 0s - loss: 0.2612 - val_loss: 0.2993 - 133ms/epoch - 6ms/step
# Epoch 27/500
# 21/21 - 0s - loss: 0.2593 - val_loss: 0.2971 - 214ms/epoch - 10ms/step
# Epoch 28/500
# 21/21 - 0s - loss: 0.2577 - val_loss: 0.2951 - 189ms/epoch - 9ms/step
# Epoch 29/500
# 21/21 - 0s - loss: 0.2562 - val_loss: 0.2933 - 257ms/epoch - 12ms/step
# Epoch 30/500
# 21/21 - 0s - loss: 0.2549 - val_loss: 0.2917 - 213ms/epoch - 10ms/step
# Epoch 31/500
# 21/21 - 0s - loss: 0.2537 - val_loss: 0.2904 - 169ms/epoch - 8ms/step
# Epoch 32/500
# 21/21 - 0s - loss: 0.2527 - val_loss: 0.2891 - 178ms/epoch - 8ms/step
# Epoch 33/500
# 21/21 - 0s - loss: 0.2517 - val_loss: 0.2880 - 182ms/epoch - 9ms/step
# Epoch 34/500
# 21/21 - 0s - loss: 0.2508 - val_loss: 0.2870 - 209ms/epoch - 10ms/step
# Epoch 35/500
# 21/21 - 0s - loss: 0.2500 - val_loss: 0.2862 - 213ms/epoch - 10ms/step
# Epoch 36/500
# 21/21 - 0s - loss: 0.2493 - val_loss: 0.2855 - 214ms/epoch - 10ms/step
# Epoch 37/500
# 21/21 - 0s - loss: 0.2487 - val_loss: 0.2849 - 162ms/epoch - 8ms/step
# Epoch 38/500
# 21/21 - 0s - loss: 0.2481 - val_loss: 0.2843 - 192ms/epoch - 9ms/step
# Epoch 39/500
# 21/21 - 0s - loss: 0.2475 - val_loss: 0.2838 - 207ms/epoch - 10ms/step
# Epoch 40/500
# 21/21 - 0s - loss: 0.2469 - val_loss: 0.2831 - 182ms/epoch - 9ms/step
# Epoch 41/500
# 21/21 - 0s - loss: 0.2464 - val_loss: 0.2823 - 159ms/epoch - 8ms/step
# Epoch 42/500
# 21/21 - 0s - loss: 0.2458 - val_loss: 0.2814 - 147ms/epoch - 7ms/step
# Epoch 43/500
# 21/21 - 0s - loss: 0.2453 - val_loss: 0.2806 - 162ms/epoch - 8ms/step
# Epoch 44/500
# 21/21 - 0s - loss: 0.2447 - val_loss: 0.2800 - 172ms/epoch - 8ms/step
# Epoch 45/500
# 21/21 - 0s - loss: 0.2443 - val_loss: 0.2794 - 157ms/epoch - 7ms/step
# Epoch 46/500
# 21/21 - 0s - loss: 0.2438 - val_loss: 0.2788 - 243ms/epoch - 12ms/step
# Epoch 47/500
# 21/21 - 0s - loss: 0.2434 - val_loss: 0.2783 - 292ms/epoch - 14ms/step
# Epoch 48/500
# 21/21 - 0s - loss: 0.2430 - val_loss: 0.2778 - 202ms/epoch - 10ms/step
# Epoch 49/500
# 21/21 - 0s - loss: 0.2427 - val_loss: 0.2774 - 160ms/epoch - 8ms/step
# Epoch 50/500
# 21/21 - 0s - loss: 0.2423 - val_loss: 0.2770 - 140ms/epoch - 7ms/step
# Epoch 51/500
# 21/21 - 0s - loss: 0.2420 - val_loss: 0.2766 - 180ms/epoch - 9ms/step
# Epoch 52/500
# 21/21 - 0s - loss: 0.2418 - val_loss: 0.2762 - 174ms/epoch - 8ms/step
# Epoch 53/500
# 21/21 - 0s - loss: 0.2415 - val_loss: 0.2759 - 161ms/epoch - 8ms/step
# Epoch 54/500
# 21/21 - 0s - loss: 0.2413 - val_loss: 0.2755 - 165ms/epoch - 8ms/step
# Epoch 55/500
# 21/21 - 0s - loss: 0.2411 - val_loss: 0.2752 - 173ms/epoch - 8ms/step
# Epoch 56/500
# 21/21 - 0s - loss: 0.2409 - val_loss: 0.2749 - 196ms/epoch - 9ms/step
# Epoch 57/500
# 21/21 - 0s - loss: 0.2408 - val_loss: 0.2747 - 192ms/epoch - 9ms/step
# Epoch 58/500
# 21/21 - 0s - loss: 0.2407 - val_loss: 0.2744 - 177ms/epoch - 8ms/step
# Epoch 59/500
# 21/21 - 0s - loss: 0.2407 - val_loss: 0.2743 - 197ms/epoch - 9ms/step
# Epoch 60/500
# 21/21 - 0s - loss: 0.2408 - val_loss: 0.2742 - 200ms/epoch - 10ms/step
# Epoch 61/500
# 21/21 - 0s - loss: 0.2409 - val_loss: 0.2742 - 200ms/epoch - 10ms/step
# Epoch 62/500
# 21/21 - 0s - loss: 0.2412 - val_loss: 0.2744 - 204ms/epoch - 10ms/step
# Epoch 63/500
# 21/21 - 0s - loss: 0.2415 - val_loss: 0.2748 - 222ms/epoch - 11ms/step
# Epoch 64/500
# 21/21 - 0s - loss: 0.2418 - val_loss: 0.2753 - 222ms/epoch - 11ms/step
# Epoch 65/500
# 21/21 - 0s - loss: 0.2421 - val_loss: 0.2759 - 172ms/epoch - 8ms/step
# Epoch 66/500
# 21/21 - 0s - loss: 0.2424 - val_loss: 0.2765 - 150ms/epoch - 7ms/step
# Epoch 67/500
# 21/21 - 0s - loss: 0.2425 - val_loss: 0.2771 - 196ms/epoch - 9ms/step
# Epoch 68/500
# 21/21 - 0s - loss: 0.2425 - val_loss: 0.2776 - 181ms/epoch - 9ms/step
# Epoch 69/500
# 21/21 - 0s - loss: 0.2423 - val_loss: 0.2779 - 213ms/epoch - 10ms/step
# Epoch 70/500
# 21/21 - 0s - loss: 0.2419 - val_loss: 0.2778 - 218ms/epoch - 10ms/step
# Epoch 71/500
# 21/21 - 0s - loss: 0.2413 - val_loss: 0.2772 - 188ms/epoch - 9ms/step
# Epoch 72/500
# 21/21 - 0s - loss: 0.2404 - val_loss: 0.2758 - 128ms/epoch - 6ms/step
# Epoch 73/500
# 21/21 - 0s - loss: 0.2394 - val_loss: 0.2738 - 144ms/epoch - 7ms/step
# Epoch 74/500
# 21/21 - 0s - loss: 0.2384 - val_loss: 0.2720 - 135ms/epoch - 6ms/step
# Epoch 75/500
# 21/21 - 0s - loss: 0.2375 - val_loss: 0.2710 - 131ms/epoch - 6ms/step
# Epoch 76/500
# 21/21 - 0s - loss: 0.2370 - val_loss: 0.2707 - 131ms/epoch - 6ms/step
# Epoch 77/500
# 21/21 - 0s - loss: 0.2368 - val_loss: 0.2706 - 170ms/epoch - 8ms/step
# Epoch 78/500
# 21/21 - 0s - loss: 0.2367 - val_loss: 0.2705 - 140ms/epoch - 7ms/step
# Epoch 79/500
# 21/21 - 0s - loss: 0.2366 - val_loss: 0.2702 - 139ms/epoch - 7ms/step
# Epoch 80/500
# 21/21 - 0s - loss: 0.2363 - val_loss: 0.2701 - 149ms/epoch - 7ms/step
# Epoch 81/500
# 21/21 - 0s - loss: 0.2361 - val_loss: 0.2698 - 233ms/epoch - 11ms/step
# Epoch 82/500
# 21/21 - 0s - loss: 0.2359 - val_loss: 0.2697 - 208ms/epoch - 10ms/step
# Epoch 83/500
# 21/21 - 0s - loss: 0.2357 - val_loss: 0.2695 - 230ms/epoch - 11ms/step
# Epoch 84/500
# 21/21 - 0s - loss: 0.2355 - val_loss: 0.2694 - 201ms/epoch - 10ms/step
# Epoch 85/500
# 21/21 - 0s - loss: 0.2354 - val_loss: 0.2693 - 194ms/epoch - 9ms/step
# Epoch 86/500
# 21/21 - 0s - loss: 0.2352 - val_loss: 0.2692 - 209ms/epoch - 10ms/step
# Epoch 87/500
# 21/21 - 0s - loss: 0.2351 - val_loss: 0.2691 - 184ms/epoch - 9ms/step
# Epoch 88/500
# 21/21 - 0s - loss: 0.2350 - val_loss: 0.2691 - 218ms/epoch - 10ms/step
# Epoch 89/500
# 21/21 - 0s - loss: 0.2350 - val_loss: 0.2694 - 208ms/epoch - 10ms/step
# Epoch 90/500
# 21/21 - 0s - loss: 0.2351 - val_loss: 0.2699 - 202ms/epoch - 10ms/step
# Epoch 91/500
# 21/21 - 0s - loss: 0.2355 - val_loss: 0.2712 - 215ms/epoch - 10ms/step
# Epoch 92/500
# 21/21 - 0s - loss: 0.2364 - val_loss: 0.2736 - 187ms/epoch - 9ms/step
# Epoch 93/500
# 21/21 - 0s - loss: 0.2377 - val_loss: 0.2768 - 207ms/epoch - 10ms/step
# Epoch 94/500
# 21/21 - 0s - loss: 0.2391 - val_loss: 0.2794 - 196ms/epoch - 9ms/step
# Epoch 95/500
# 21/21 - 0s - loss: 0.2395 - val_loss: 0.2796 - 226ms/epoch - 11ms/step
# Epoch 96/500
# 21/21 - 0s - loss: 0.2389 - val_loss: 0.2781 - 159ms/epoch - 8ms/step
# Epoch 97/500
# 21/21 - 0s - loss: 0.2379 - val_loss: 0.2764 - 258ms/epoch - 12ms/step
# Epoch 98/500
# 21/21 - 0s - loss: 0.2372 - val_loss: 0.2752 - 229ms/epoch - 11ms/step
# Epoch 99/500
# 21/21 - 0s - loss: 0.2368 - val_loss: 0.2748 - 169ms/epoch - 8ms/step
# Epoch 100/500
# 21/21 - 0s - loss: 0.2368 - val_loss: 0.2752 - 157ms/epoch - 7ms/step
# Epoch 101/500
# 21/21 - 0s - loss: 0.2372 - val_loss: 0.2767 - 151ms/epoch - 7ms/step
# Epoch 102/500
# 21/21 - 0s - loss: 0.2382 - val_loss: 0.2793 - 159ms/epoch - 8ms/step
# Epoch 103/500
# 21/21 - 0s - loss: 0.2395 - val_loss: 0.2823 - 153ms/epoch - 7ms/step
# Epoch 104/500
# 21/21 - 0s - loss: 0.2407 - val_loss: 0.2841 - 147ms/epoch - 7ms/step
# Epoch 105/500
# 21/21 - 0s - loss: 0.2407 - val_loss: 0.2833 - 156ms/epoch - 7ms/step
# Epoch 106/500
# 21/21 - 0s - loss: 0.2395 - val_loss: 0.2803 - 161ms/epoch - 8ms/step
# Epoch 107/500
# 21/21 - 0s - loss: 0.2379 - val_loss: 0.2770 - 155ms/epoch - 7ms/step
# Epoch 108/500
# 21/21 - 0s - loss: 0.2365 - val_loss: 0.2745 - 154ms/epoch - 7ms/step
# Epoch 109/500
# 21/21 - 0s - loss: 0.2355 - val_loss: 0.2731 - 150ms/epoch - 7ms/step
# Epoch 110/500
# 21/21 - 0s - loss: 0.2351 - val_loss: 0.2730 - 189ms/epoch - 9ms/step
# Epoch 111/500
# 21/21 - 0s - loss: 0.2355 - val_loss: 0.2746 - 155ms/epoch - 7ms/step
# Epoch 112/500
# 21/21 - 0s - loss: 0.2368 - val_loss: 0.2787 - 152ms/epoch - 7ms/step
# Epoch 113/500
# 21/21 - 0s - loss: 0.2397 - val_loss: 0.2860 - 158ms/epoch - 8ms/step
# Epoch 114/500
# 21/21 - 0s - loss: 0.2438 - val_loss: 0.2940 - 229ms/epoch - 11ms/step
# Epoch 115/500
# 21/21 - 0s - loss: 0.2458 - val_loss: 0.2938 - 181ms/epoch - 9ms/step
# Epoch 116/500
# 21/21 - 0s - loss: 0.2420 - val_loss: 0.2825 - 176ms/epoch - 8ms/step
# Epoch 117/500
# 21/21 - 0s - loss: 0.2364 - val_loss: 0.2717 - 197ms/epoch - 9ms/step
# Epoch 118/500
# 21/21 - 0s - loss: 0.2326 - val_loss: 0.2656 - 250ms/epoch - 12ms/step
# Epoch 119/500
# 21/21 - 0s - loss: 0.2304 - val_loss: 0.2623 - 168ms/epoch - 8ms/step
# Epoch 120/500
# 21/21 - 0s - loss: 0.2293 - val_loss: 0.2612 - 136ms/epoch - 6ms/step
# Epoch 121/500
# 21/21 - 0s - loss: 0.2294 - val_loss: 0.2643 - 128ms/epoch - 6ms/step
# Epoch 122/500
# 21/21 - 0s - loss: 0.2336 - val_loss: 0.2822 - 163ms/epoch - 8ms/step
# Epoch 123/500
# 21/21 - 0s - loss: 0.2538 - val_loss: 0.3521 - 179ms/epoch - 9ms/step
# Epoch 124/500
# 21/21 - 0s - loss: 0.3094 - val_loss: 0.3889 - 203ms/epoch - 10ms/step
# Epoch 125/500
# 21/21 - 0s - loss: 0.2576 - val_loss: 0.2926 - 186ms/epoch - 9ms/step
# Epoch 126/500
# 21/21 - 0s - loss: 0.2434 - val_loss: 0.2650 - 174ms/epoch - 8ms/step
# Epoch 127/500
# 21/21 - 0s - loss: 0.2431 - val_loss: 0.2707 - 147ms/epoch - 7ms/step
# Epoch 128/500
# 21/21 - 0s - loss: 0.2485 - val_loss: 0.2633 - 140ms/epoch - 7ms/step
# Epoch 129/500
# 21/21 - 0s - loss: 0.2627 - val_loss: 0.2880 - 144ms/epoch - 7ms/step
# Epoch 130/500
# 21/21 - 0s - loss: 0.2856 - val_loss: 0.3457 - 144ms/epoch - 7ms/step
# Epoch 131/500
# 21/21 - 0s - loss: 0.2878 - val_loss: 0.4199 - 236ms/epoch - 11ms/step
# Epoch 132/500
# 21/21 - 0s - loss: 0.2612 - val_loss: 0.2626 - 192ms/epoch - 9ms/step
# Epoch 133/500
# 21/21 - 0s - loss: 0.2425 - val_loss: 0.3069 - 214ms/epoch - 10ms/step
# Epoch 134/500
# 21/21 - 0s - loss: 0.2400 - val_loss: 0.2600 - 162ms/epoch - 8ms/step
# Epoch 135/500
# 21/21 - 0s - loss: 0.2347 - val_loss: 0.2915 - 176ms/epoch - 8ms/step
# Epoch 136/500
# 21/21 - 0s - loss: 0.2331 - val_loss: 0.2618 - 182ms/epoch - 9ms/step
# Epoch 137/500
# 21/21 - 0s - loss: 0.2296 - val_loss: 0.2672 - 229ms/epoch - 11ms/step
# Epoch 138/500
# 21/21 - 0s - loss: 0.2284 - val_loss: 0.2594 - 176ms/epoch - 8ms/step
# Epoch 139/500
# 21/21 - 0s - loss: 0.2272 - val_loss: 0.2651 - 213ms/epoch - 10ms/step
# Epoch 140/500
# 21/21 - 0s - loss: 0.2269 - val_loss: 0.2585 - 170ms/epoch - 8ms/step
# Epoch 141/500
# 21/21 - 0s - loss: 0.2258 - val_loss: 0.2591 - 153ms/epoch - 7ms/step
# Epoch 142/500
# 21/21 - 0s - loss: 0.2256 - val_loss: 0.2589 - 130ms/epoch - 6ms/step
# Epoch 143/500
# 21/21 - 0s - loss: 0.2255 - val_loss: 0.2581 - 142ms/epoch - 7ms/step
# Epoch 144/500
# 21/21 - 0s - loss: 0.2253 - val_loss: 0.2591 - 130ms/epoch - 6ms/step
# Epoch 145/500
# 21/21 - 0s - loss: 0.2254 - val_loss: 0.2580 - 139ms/epoch - 7ms/step
# Epoch 146/500
# 21/21 - 0s - loss: 0.2251 - val_loss: 0.2592 - 137ms/epoch - 7ms/step
# Epoch 147/500
# 21/21 - 0s - loss: 0.2257 - val_loss: 0.2581 - 132ms/epoch - 6ms/step
# Epoch 148/500
# 21/21 - 0s - loss: 0.2250 - val_loss: 0.2594 - 167ms/epoch - 8ms/step
# Epoch 149/500
# 21/21 - 0s - loss: 0.2266 - val_loss: 0.2590 - 198ms/epoch - 9ms/step
# Epoch 150/500
# 21/21 - 0s - loss: 0.2252 - val_loss: 0.2596 - 179ms/epoch - 9ms/step
# Epoch 151/500
# 21/21 - 0s - loss: 0.2273 - val_loss: 0.2616 - 218ms/epoch - 10ms/step
# Epoch 152/500
# 21/21 - 0s - loss: 0.2254 - val_loss: 0.2610 - 149ms/epoch - 7ms/step
# Epoch 153/500
# 21/21 - 0s - loss: 0.2274 - val_loss: 0.2657 - 161ms/epoch - 8ms/step
# Epoch 154/500
# 21/21 - 0s - loss: 0.2275 - val_loss: 0.2678 - 161ms/epoch - 8ms/step
# Epoch 155/500
# 21/21 - 0s - loss: 0.2299 - val_loss: 0.2749 - 151ms/epoch - 7ms/step
# Epoch 156/500
# 21/21 - 0s - loss: 0.2330 - val_loss: 0.2827 - 151ms/epoch - 7ms/step
# Epoch 157/500
# 21/21 - 0s - loss: 0.2363 - val_loss: 0.2898 - 153ms/epoch - 7ms/step
# Epoch 158/500
# 21/21 - 0s - loss: 0.2378 - val_loss: 0.2912 - 149ms/epoch - 7ms/step
# Epoch 159/500
# 21/21 - 0s - loss: 0.2365 - val_loss: 0.2865 - 145ms/epoch - 7ms/step
# Epoch 160/500
# 21/21 - 0s - loss: 0.2339 - val_loss: 0.2805 - 158ms/epoch - 8ms/step
# Epoch 161/500
# 21/21 - 0s - loss: 0.2317 - val_loss: 0.2758 - 151ms/epoch - 7ms/step
# Epoch 162/500
# 21/21 - 0s - loss: 0.2301 - val_loss: 0.2730 - 176ms/epoch - 8ms/step
# Epoch 163/500
# 21/21 - 0s - loss: 0.2293 - val_loss: 0.2721 - 184ms/epoch - 9ms/step
# Epoch 164/500
# 21/21 - 0s - loss: 0.2292 - val_loss: 0.2730 - 220ms/epoch - 10ms/step
# Epoch 165/500
# 21/21 - 0s - loss: 0.2300 - val_loss: 0.2757 - 292ms/epoch - 14ms/step
# Epoch 166/500
# 21/21 - 0s - loss: 0.2313 - val_loss: 0.2796 - 173ms/epoch - 8ms/step
# Epoch 167/500
# 21/21 - 0s - loss: 0.2330 - val_loss: 0.2832 - 149ms/epoch - 7ms/step
# Epoch 168/500
# 21/21 - 0s - loss: 0.2340 - val_loss: 0.2847 - 194ms/epoch - 9ms/step
# Epoch 169/500
# 21/21 - 0s - loss: 0.2337 - val_loss: 0.2829 - 153ms/epoch - 7ms/step
# Epoch 170/500
# 21/21 - 0s - loss: 0.2323 - val_loss: 0.2793 - 152ms/epoch - 7ms/step
# Epoch 171/500
# 21/21 - 0s - loss: 0.2306 - val_loss: 0.2757 - 162ms/epoch - 8ms/step
# Epoch 172/500
# 21/21 - 0s - loss: 0.2293 - val_loss: 0.2732 - 150ms/epoch - 7ms/step
# Epoch 173/500
# 21/21 - 0s - loss: 0.2284 - val_loss: 0.2720 - 181ms/epoch - 9ms/step
# Epoch 174/500
# 21/21 - 0s - loss: 0.2282 - val_loss: 0.2724 - 160ms/epoch - 8ms/step
# Epoch 175/500
# 21/21 - 0s - loss: 0.2286 - val_loss: 0.2742 - 171ms/epoch - 8ms/step
# Epoch 176/500
# 21/21 - 0s - loss: 0.2296 - val_loss: 0.2770 - 211ms/epoch - 10ms/step
# Epoch 177/500
# 21/21 - 0s - loss: 0.2308 - val_loss: 0.2800 - 168ms/epoch - 8ms/step
# Epoch 178/500
# 21/21 - 0s - loss: 0.2316 - val_loss: 0.2814 - 165ms/epoch - 8ms/step
# Epoch 179/500
# 21/21 - 0s - loss: 0.2315 - val_loss: 0.2802 - 156ms/epoch - 7ms/step
# Epoch 180/500
# 21/21 - 0s - loss: 0.2304 - val_loss: 0.2772 - 168ms/epoch - 8ms/step
# Epoch 181/500
# 21/21 - 0s - loss: 0.2289 - val_loss: 0.2737 - 244ms/epoch - 12ms/step
# Epoch 182/500
# 21/21 - 0s - loss: 0.2275 - val_loss: 0.2711 - 215ms/epoch - 10ms/step
# Epoch 183/500
# 21/21 - 0s - loss: 0.2266 - val_loss: 0.2698 - 191ms/epoch - 9ms/step
# Epoch 184/500
# 21/21 - 0s - loss: 0.2263 - val_loss: 0.2699 - 206ms/epoch - 10ms/step
# Epoch 185/500
# 21/21 - 0s - loss: 0.2266 - val_loss: 0.2716 - 195ms/epoch - 9ms/step
# Epoch 186/500
# 21/21 - 0s - loss: 0.2276 - val_loss: 0.2746 - 165ms/epoch - 8ms/step
# Epoch 187/500
# 21/21 - 0s - loss: 0.2290 - val_loss: 0.2782 - 219ms/epoch - 10ms/step
# Epoch 188/500
# 21/21 - 0s - loss: 0.2302 - val_loss: 0.2803 - 171ms/epoch - 8ms/step
# Epoch 189/500
# 21/21 - 0s - loss: 0.2302 - val_loss: 0.2792 - 192ms/epoch - 9ms/step
# Epoch 190/500
# 21/21 - 0s - loss: 0.2289 - val_loss: 0.2753 - 151ms/epoch - 7ms/step
# Epoch 191/500
# 21/21 - 0s - loss: 0.2269 - val_loss: 0.2708 - 150ms/epoch - 7ms/step
# Epoch 192/500
# 21/21 - 0s - loss: 0.2251 - val_loss: 0.2673 - 157ms/epoch - 7ms/step
# Epoch 193/500
# 21/21 - 0s - loss: 0.2239 - val_loss: 0.2653 - 148ms/epoch - 7ms/step
# Epoch 194/500
# 21/21 - 0s - loss: 0.2234 - val_loss: 0.2651 - 161ms/epoch - 8ms/step
# Epoch 195/500
# 21/21 - 0s - loss: 0.2237 - val_loss: 0.2671 - 182ms/epoch - 9ms/step
# Epoch 196/500
# 21/21 - 0s - loss: 0.2250 - val_loss: 0.2717 - 167ms/epoch - 8ms/step
# Epoch 197/500
# 21/21 - 0s - loss: 0.2274 - val_loss: 0.2783 - 229ms/epoch - 11ms/step
# Epoch 198/500
# 21/21 - 0s - loss: 0.2302 - val_loss: 0.2838 - 243ms/epoch - 12ms/step
# Epoch 199/500
# 21/21 - 0s - loss: 0.2310 - val_loss: 0.2827 - 161ms/epoch - 8ms/step
# Epoch 200/500
# 21/21 - 0s - loss: 0.2285 - val_loss: 0.2745 - 147ms/epoch - 7ms/step
# Epoch 201/500
# 21/21 - 0s - loss: 0.2246 - val_loss: 0.2659 - 155ms/epoch - 7ms/step
# Epoch 202/500
# 21/21 - 0s - loss: 0.2215 - val_loss: 0.2598 - 146ms/epoch - 7ms/step
# Epoch 203/500
# 21/21 - 0s - loss: 0.2195 - val_loss: 0.2563 - 146ms/epoch - 7ms/step
# Epoch 204/500
# 21/21 - 0s - loss: 0.2183 - val_loss: 0.2549 - 148ms/epoch - 7ms/step
# Epoch 205/500
# 21/21 - 0s - loss: 0.2180 - val_loss: 0.2556 - 150ms/epoch - 7ms/step
# Epoch 206/500
# 21/21 - 0s - loss: 0.2189 - val_loss: 0.2600 - 142ms/epoch - 7ms/step
# Epoch 207/500
# 21/21 - 0s - loss: 0.2222 - val_loss: 0.2718 - 159ms/epoch - 8ms/step
# Epoch 208/500
# 21/21 - 0s - loss: 0.2307 - val_loss: 0.2966 - 197ms/epoch - 9ms/step
# Epoch 209/500
# 21/21 - 0s - loss: 0.2439 - val_loss: 0.3181 - 163ms/epoch - 8ms/step
# Epoch 210/500
# 21/21 - 0s - loss: 0.2392 - val_loss: 0.2868 - 151ms/epoch - 7ms/step
# Epoch 211/500
# 21/21 - 0s - loss: 0.2237 - val_loss: 0.2565 - 151ms/epoch - 7ms/step
# Epoch 212/500
# 21/21 - 0s - loss: 0.2165 - val_loss: 0.2476 - 276ms/epoch - 13ms/step
# Epoch 213/500
# 21/21 - 0s - loss: 0.2140 - val_loss: 0.2438 - 207ms/epoch - 10ms/step
# Epoch 214/500
# 21/21 - 0s - loss: 0.2133 - val_loss: 0.2445 - 164ms/epoch - 8ms/step
# Epoch 215/500
# 21/21 - 0s - loss: 0.2151 - val_loss: 0.2521 - 142ms/epoch - 7ms/step
# Epoch 216/500
# 21/21 - 0s - loss: 0.2228 - val_loss: 0.2775 - 152ms/epoch - 7ms/step
# Epoch 217/500
# 21/21 - 0s - loss: 0.2431 - val_loss: 0.3241 - 165ms/epoch - 8ms/step
# Epoch 218/500
# 21/21 - 0s - loss: 0.2511 - val_loss: 0.3034 - 191ms/epoch - 9ms/step
# Epoch 219/500
# 21/21 - 0s - loss: 0.2258 - val_loss: 0.2588 - 169ms/epoch - 8ms/step
# Epoch 220/500
# 21/21 - 0s - loss: 0.2176 - val_loss: 0.2506 - 167ms/epoch - 8ms/step
# Epoch 221/500
# 21/21 - 0s - loss: 0.2135 - val_loss: 0.2438 - 179ms/epoch - 9ms/step
# Epoch 222/500
# 21/21 - 0s - loss: 0.2118 - val_loss: 0.2428 - 197ms/epoch - 9ms/step
# Epoch 223/500
# 21/21 - 0s - loss: 0.2109 - val_loss: 0.2419 - 163ms/epoch - 8ms/step
# Epoch 224/500
# 21/21 - 0s - loss: 0.2107 - val_loss: 0.2427 - 144ms/epoch - 7ms/step
# Epoch 225/500
# 21/21 - 0s - loss: 0.2115 - val_loss: 0.2461 - 178ms/epoch - 8ms/step
# Epoch 226/500
# 21/21 - 0s - loss: 0.2147 - val_loss: 0.2577 - 169ms/epoch - 8ms/step
# Epoch 227/500
# 21/21 - 0s - loss: 0.2253 - val_loss: 0.2899 - 240ms/epoch - 11ms/step
# Epoch 228/500
# 21/21 - 0s - loss: 0.2468 - val_loss: 0.3249 - 227ms/epoch - 11ms/step
# Epoch 229/500
# 21/21 - 0s - loss: 0.2378 - val_loss: 0.2781 - 288ms/epoch - 14ms/step
# Epoch 230/500
# 21/21 - 0s - loss: 0.2187 - val_loss: 0.2499 - 218ms/epoch - 10ms/step
# Epoch 231/500
# 21/21 - 0s - loss: 0.2125 - val_loss: 0.2438 - 179ms/epoch - 9ms/step
# Epoch 232/500
# 21/21 - 0s - loss: 0.2098 - val_loss: 0.2393 - 191ms/epoch - 9ms/step
# Epoch 233/500
# 21/21 - 0s - loss: 0.2082 - val_loss: 0.2382 - 187ms/epoch - 9ms/step
# Epoch 234/500
# 21/21 - 0s - loss: 0.2075 - val_loss: 0.2376 - 164ms/epoch - 8ms/step
# Epoch 235/500
# 21/21 - 0s - loss: 0.2071 - val_loss: 0.2376 - 183ms/epoch - 9ms/step
# Epoch 236/500
# 21/21 - 0s - loss: 0.2073 - val_loss: 0.2394 - 305ms/epoch - 15ms/step
# Epoch 237/500
# 21/21 - 0s - loss: 0.2093 - val_loss: 0.2480 - 263ms/epoch - 13ms/step
# Epoch 238/500
# 21/21 - 0s - loss: 0.2189 - val_loss: 0.2829 - 168ms/epoch - 8ms/step
# Epoch 239/500
# 21/21 - 0s - loss: 0.2534 - val_loss: 0.3641 - 152ms/epoch - 7ms/step
# Epoch 240/500
# 21/21 - 0s - loss: 0.2621 - val_loss: 0.2904 - 163ms/epoch - 8ms/step
# Epoch 241/500
# 21/21 - 0s - loss: 0.2293 - val_loss: 0.2463 - 209ms/epoch - 10ms/step
# Epoch 242/500
# 21/21 - 0s - loss: 0.2173 - val_loss: 0.2355 - 411ms/epoch - 20ms/step
# Epoch 243/500
# 21/21 - 0s - loss: 0.2255 - val_loss: 0.2373 - 209ms/epoch - 10ms/step
# Epoch 244/500
# 21/21 - 0s - loss: 0.2212 - val_loss: 0.2414 - 441ms/epoch - 21ms/step
# Epoch 245/500
# 21/21 - 0s - loss: 0.2366 - val_loss: 0.2388 - 440ms/epoch - 21ms/step
# Epoch 246/500
# 21/21 - 0s - loss: 0.2481 - val_loss: 0.2829 - 350ms/epoch - 17ms/step
# Epoch 247/500
# 21/21 - 0s - loss: 0.2694 - val_loss: 0.3638 - 316ms/epoch - 15ms/step
# Epoch 248/500
# 21/21 - 0s - loss: 0.2492 - val_loss: 0.3000 - 208ms/epoch - 10ms/step
# Epoch 249/500
# 21/21 - 0s - loss: 0.2268 - val_loss: 0.2602 - 185ms/epoch - 9ms/step
# Epoch 250/500
# 21/21 - 0s - loss: 0.2176 - val_loss: 0.2603 - 208ms/epoch - 10ms/step
# Epoch 251/500
# 21/21 - 1s - loss: 0.2128 - val_loss: 0.2414 - 527ms/epoch - 25ms/step
# Epoch 252/500
# 21/21 - 0s - loss: 0.2092 - val_loss: 0.2487 - 386ms/epoch - 18ms/step
# Epoch 253/500
# 21/21 - 0s - loss: 0.2065 - val_loss: 0.2339 - 228ms/epoch - 11ms/step
# Epoch 254/500
# 21/21 - 0s - loss: 0.2046 - val_loss: 0.2384 - 380ms/epoch - 18ms/step
# Epoch 255/500
# 21/21 - 0s - loss: 0.2033 - val_loss: 0.2323 - 235ms/epoch - 11ms/step
# Epoch 256/500
# 21/21 - 0s - loss: 0.2018 - val_loss: 0.2313 - 317ms/epoch - 15ms/step
# Epoch 257/500
# 21/21 - 0s - loss: 0.2015 - val_loss: 0.2309 - 245ms/epoch - 12ms/step
# Epoch 258/500
# 21/21 - 0s - loss: 0.2012 - val_loss: 0.2308 - 226ms/epoch - 11ms/step
# Epoch 259/500
# 21/21 - 0s - loss: 0.2009 - val_loss: 0.2302 - 232ms/epoch - 11ms/step
# Epoch 260/500
# 21/21 - 0s - loss: 0.2009 - val_loss: 0.2300 - 258ms/epoch - 12ms/step
# Epoch 261/500
# 21/21 - 0s - loss: 0.2008 - val_loss: 0.2295 - 228ms/epoch - 11ms/step
# Epoch 262/500
# 21/21 - 0s - loss: 0.2013 - val_loss: 0.2293 - 242ms/epoch - 12ms/step
# Epoch 263/500
# 21/21 - 0s - loss: 0.2016 - val_loss: 0.2287 - 218ms/epoch - 10ms/step
# Epoch 264/500
# 21/21 - 0s - loss: 0.2021 - val_loss: 0.2287 - 184ms/epoch - 9ms/step
# Epoch 265/500
# 21/21 - 0s - loss: 0.2013 - val_loss: 0.2281 - 181ms/epoch - 9ms/step
# Epoch 266/500
# 21/21 - 0s - loss: 0.2004 - val_loss: 0.2282 - 220ms/epoch - 10ms/step
# Epoch 267/500
# 21/21 - 0s - loss: 0.1987 - val_loss: 0.2271 - 288ms/epoch - 14ms/step
# Epoch 268/500
# 21/21 - 0s - loss: 0.1981 - val_loss: 0.2273 - 333ms/epoch - 16ms/step
# Epoch 269/500
# 21/21 - 1s - loss: 0.1979 - val_loss: 0.2275 - 521ms/epoch - 25ms/step
# Epoch 270/500
# 21/21 - 0s - loss: 0.1983 - val_loss: 0.2295 - 263ms/epoch - 13ms/step
# Epoch 271/500
# 21/21 - 0s - loss: 0.2002 - val_loss: 0.2372 - 207ms/epoch - 10ms/step
# Epoch 272/500
# 21/21 - 0s - loss: 0.2075 - val_loss: 0.2626 - 219ms/epoch - 10ms/step
# Epoch 273/500
# 21/21 - 0s - loss: 0.2284 - val_loss: 0.3148 - 244ms/epoch - 12ms/step
# Epoch 274/500
# 21/21 - 0s - loss: 0.2403 - val_loss: 0.2923 - 453ms/epoch - 22ms/step
# Epoch 275/500
# 21/21 - 0s - loss: 0.2121 - val_loss: 0.2366 - 338ms/epoch - 16ms/step
# Epoch 276/500
# 21/21 - 0s - loss: 0.2003 - val_loss: 0.2283 - 343ms/epoch - 16ms/step
# Epoch 277/500
# 21/21 - 0s - loss: 0.1977 - val_loss: 0.2243 - 178ms/epoch - 8ms/step
# Epoch 278/500
# 21/21 - 0s - loss: 0.1955 - val_loss: 0.2237 - 173ms/epoch - 8ms/step
# Epoch 279/500
# 21/21 - 0s - loss: 0.1952 - val_loss: 0.2241 - 211ms/epoch - 10ms/step
# Epoch 280/500
# 21/21 - 0s - loss: 0.1949 - val_loss: 0.2245 - 342ms/epoch - 16ms/step
# Epoch 281/500
# 21/21 - 0s - loss: 0.1950 - val_loss: 0.2255 - 292ms/epoch - 14ms/step
# Epoch 282/500
# 21/21 - 0s - loss: 0.1955 - val_loss: 0.2282 - 418ms/epoch - 20ms/step
# Epoch 283/500
# 21/21 - 0s - loss: 0.1975 - val_loss: 0.2363 - 460ms/epoch - 22ms/step
# Epoch 284/500
# 21/21 - 0s - loss: 0.2043 - val_loss: 0.2617 - 243ms/epoch - 12ms/step
# Epoch 285/500
# 21/21 - 0s - loss: 0.2255 - val_loss: 0.3225 - 239ms/epoch - 11ms/step
# Epoch 286/500
# 21/21 - 0s - loss: 0.2490 - val_loss: 0.3120 - 223ms/epoch - 11ms/step
# Epoch 287/500
# 21/21 - 0s - loss: 0.2121 - val_loss: 0.2309 - 215ms/epoch - 10ms/step
# Epoch 288/500
# 21/21 - 0s - loss: 0.1955 - val_loss: 0.2215 - 215ms/epoch - 10ms/step
# Epoch 289/500
# 21/21 - 0s - loss: 0.1957 - val_loss: 0.2238 - 214ms/epoch - 10ms/step
# Epoch 290/500
# 21/21 - 0s - loss: 0.1947 - val_loss: 0.2287 - 339ms/epoch - 16ms/step
# Epoch 291/500
# 21/21 - 0s - loss: 0.1991 - val_loss: 0.2409 - 203ms/epoch - 10ms/step
# Epoch 292/500
# 21/21 - 0s - loss: 0.2035 - val_loss: 0.2515 - 275ms/epoch - 13ms/step
# Epoch 293/500
# 21/21 - 0s - loss: 0.2066 - val_loss: 0.2560 - 401ms/epoch - 19ms/step
# Epoch 294/500
# 21/21 - 0s - loss: 0.2055 - val_loss: 0.2502 - 283ms/epoch - 13ms/step
# Epoch 295/500
# 21/21 - 0s - loss: 0.2019 - val_loss: 0.2416 - 217ms/epoch - 10ms/step
# Epoch 296/500
# 21/21 - 0s - loss: 0.1987 - val_loss: 0.2355 - 217ms/epoch - 10ms/step
# Epoch 297/500
# 21/21 - 0s - loss: 0.1967 - val_loss: 0.2323 - 337ms/epoch - 16ms/step
# Epoch 298/500
# 21/21 - 0s - loss: 0.1958 - val_loss: 0.2318 - 240ms/epoch - 11ms/step
# Epoch 299/500
# 21/21 - 0s - loss: 0.1961 - val_loss: 0.2342 - 262ms/epoch - 12ms/step
# Epoch 300/500
# 21/21 - 0s - loss: 0.1978 - val_loss: 0.2398 - 260ms/epoch - 12ms/step
# Epoch 301/500
# 21/21 - 0s - loss: 0.2007 - val_loss: 0.2477 - 259ms/epoch - 12ms/step
# Epoch 302/500
# 21/21 - 0s - loss: 0.2038 - val_loss: 0.2535 - 263ms/epoch - 13ms/step
# Epoch 303/500
# 21/21 - 0s - loss: 0.2042 - val_loss: 0.2513 - 296ms/epoch - 14ms/step
# Epoch 304/500
# 21/21 - 0s - loss: 0.2015 - val_loss: 0.2434 - 365ms/epoch - 17ms/step
# Epoch 305/500
# 21/21 - 0s - loss: 0.1981 - val_loss: 0.2363 - 213ms/epoch - 10ms/step
# Epoch 306/500
# 21/21 - 0s - loss: 0.1956 - val_loss: 0.2321 - 480ms/epoch - 23ms/step
# Epoch 307/500
# 21/21 - 0s - loss: 0.1944 - val_loss: 0.2308 - 263ms/epoch - 13ms/step
# Epoch 308/500
# 21/21 - 0s - loss: 0.1943 - val_loss: 0.2325 - 223ms/epoch - 11ms/step
# Epoch 309/500
# 21/21 - 0s - loss: 0.1956 - val_loss: 0.2373 - 272ms/epoch - 13ms/step
# Epoch 310/500
# 21/21 - 0s - loss: 0.1982 - val_loss: 0.2446 - 264ms/epoch - 13ms/step
# Epoch 311/500
# 21/21 - 0s - loss: 0.2012 - val_loss: 0.2507 - 272ms/epoch - 13ms/step
# Epoch 312/500
# 21/21 - 0s - loss: 0.2021 - val_loss: 0.2497 - 190ms/epoch - 9ms/step
# Epoch 313/500
# 21/21 - 0s - loss: 0.1997 - val_loss: 0.2423 - 195ms/epoch - 9ms/step
# Epoch 314/500
# 21/21 - 0s - loss: 0.1963 - val_loss: 0.2349 - 287ms/epoch - 14ms/step
# Epoch 315/500
# 21/21 - 0s - loss: 0.1937 - val_loss: 0.2303 - 243ms/epoch - 12ms/step
# Epoch 316/500
# 21/21 - 0s - loss: 0.1923 - val_loss: 0.2287 - 256ms/epoch - 12ms/step
# Epoch 317/500
# 21/21 - 0s - loss: 0.1921 - val_loss: 0.2299 - 221ms/epoch - 11ms/step
# Epoch 318/500
# 21/21 - 0s - loss: 0.1932 - val_loss: 0.2344 - 411ms/epoch - 20ms/step
# Epoch 319/500
# 21/21 - 0s - loss: 0.1956 - val_loss: 0.2416 - 173ms/epoch - 8ms/step
# Epoch 320/500
# 21/21 - 0s - loss: 0.1987 - val_loss: 0.2482 - 168ms/epoch - 8ms/step
# Epoch 321/500
# 21/21 - 0s - loss: 0.2000 - val_loss: 0.2483 - 167ms/epoch - 8ms/step
# Epoch 322/500
# 21/21 - 0s - loss: 0.1979 - val_loss: 0.2413 - 144ms/epoch - 7ms/step
# Epoch 323/500
# 21/21 - 0s - loss: 0.1945 - val_loss: 0.2335 - 180ms/epoch - 9ms/step
# Epoch 324/500
# 21/21 - 0s - loss: 0.1918 - val_loss: 0.2284 - 222ms/epoch - 11ms/step
# Epoch 325/500
# 21/21 - 0s - loss: 0.1902 - val_loss: 0.2263 - 179ms/epoch - 9ms/step
# Epoch 326/500
# 21/21 - 0s - loss: 0.1897 - val_loss: 0.2271 - 192ms/epoch - 9ms/step
# Epoch 327/500
# 21/21 - 0s - loss: 0.1906 - val_loss: 0.2312 - 175ms/epoch - 8ms/step
# Epoch 328/500
# 21/21 - 0s - loss: 0.1929 - val_loss: 0.2382 - 161ms/epoch - 8ms/step
# Epoch 329/500
# 21/21 - 0s - loss: 0.1961 - val_loss: 0.2457 - 167ms/epoch - 8ms/step
# Epoch 330/500
# 21/21 - 0s - loss: 0.1979 - val_loss: 0.2472 - 156ms/epoch - 7ms/step
# Epoch 331/500
# 21/21 - 0s - loss: 0.1963 - val_loss: 0.2406 - 141ms/epoch - 7ms/step
# Epoch 332/500
# 21/21 - 0s - loss: 0.1929 - val_loss: 0.2322 - 319ms/epoch - 15ms/step
# Epoch 333/500
# 21/21 - 0s - loss: 0.1898 - val_loss: 0.2265 - 193ms/epoch - 9ms/step
# Epoch 334/500
# 21/21 - 0s - loss: 0.1880 - val_loss: 0.2238 - 177ms/epoch - 8ms/step
# Epoch 335/500
# 21/21 - 0s - loss: 0.1873 - val_loss: 0.2240 - 166ms/epoch - 8ms/step
# Epoch 336/500
# 21/21 - 0s - loss: 0.1880 - val_loss: 0.2275 - 147ms/epoch - 7ms/step
# Epoch 337/500
# 21/21 - 0s - loss: 0.1901 - val_loss: 0.2344 - 141ms/epoch - 7ms/step
# Epoch 338/500
# 21/21 - 0s - loss: 0.1934 - val_loss: 0.2428 - 146ms/epoch - 7ms/step
# Epoch 339/500
# 21/21 - 0s - loss: 0.1960 - val_loss: 0.2465 - 148ms/epoch - 7ms/step
# Epoch 340/500
# 21/21 - 0s - loss: 0.1950 - val_loss: 0.2407 - 188ms/epoch - 9ms/step
# Epoch 341/500
# 21/21 - 0s - loss: 0.1914 - val_loss: 0.2314 - 155ms/epoch - 7ms/step
# Epoch 342/500
# 21/21 - 0s - loss: 0.1880 - val_loss: 0.2245 - 181ms/epoch - 9ms/step
# Epoch 343/500
# 21/21 - 0s - loss: 0.1857 - val_loss: 0.2209 - 164ms/epoch - 8ms/step
# Epoch 344/500
# 21/21 - 0s - loss: 0.1847 - val_loss: 0.2204 - 154ms/epoch - 7ms/step
# Epoch 345/500
# 21/21 - 0s - loss: 0.1850 - val_loss: 0.2231 - 147ms/epoch - 7ms/step
# Epoch 346/500
# 21/21 - 0s - loss: 0.1869 - val_loss: 0.2297 - 231ms/epoch - 11ms/step
# Epoch 347/500
# 21/21 - 0s - loss: 0.1903 - val_loss: 0.2394 - 355ms/epoch - 17ms/step
# Epoch 348/500
# 21/21 - 0s - loss: 0.1940 - val_loss: 0.2463 - 208ms/epoch - 10ms/step
# Epoch 349/500
# 21/21 - 0s - loss: 0.1943 - val_loss: 0.2424 - 180ms/epoch - 9ms/step
# Epoch 350/500
# 21/21 - 0s - loss: 0.1905 - val_loss: 0.2314 - 159ms/epoch - 8ms/step
# Epoch 351/500
# 21/21 - 0s - loss: 0.1863 - val_loss: 0.2226 - 157ms/epoch - 7ms/step
# Epoch 352/500
# 21/21 - 0s - loss: 0.1834 - val_loss: 0.2176 - 170ms/epoch - 8ms/step
# Epoch 353/500
# 21/21 - 0s - loss: 0.1819 - val_loss: 0.2159 - 168ms/epoch - 8ms/step
# Epoch 354/500
# 21/21 - 0s - loss: 0.1817 - val_loss: 0.2175 - 196ms/epoch - 9ms/step
# Epoch 355/500
# 21/21 - 0s - loss: 0.1830 - val_loss: 0.2232 - 161ms/epoch - 8ms/step
# Epoch 356/500
# 21/21 - 0s - loss: 0.1865 - val_loss: 0.2340 - 149ms/epoch - 7ms/step
# Epoch 357/500
# 21/21 - 0s - loss: 0.1917 - val_loss: 0.2465 - 144ms/epoch - 7ms/step
# Epoch 358/500
# 21/21 - 0s - loss: 0.1946 - val_loss: 0.2478 - 150ms/epoch - 7ms/step
# Epoch 359/500
# 21/21 - 0s - loss: 0.1910 - val_loss: 0.2342 - 204ms/epoch - 10ms/step
# Epoch 360/500
# 21/21 - 0s - loss: 0.1852 - val_loss: 0.2212 - 200ms/epoch - 10ms/step
# Epoch 361/500
# 21/21 - 0s - loss: 0.1811 - val_loss: 0.2138 - 254ms/epoch - 12ms/step
# Epoch 362/500
# 21/21 - 0s - loss: 0.1788 - val_loss: 0.2103 - 228ms/epoch - 11ms/step
# Epoch 363/500
# 21/21 - 0s - loss: 0.1778 - val_loss: 0.2101 - 169ms/epoch - 8ms/step
# Epoch 364/500
# 21/21 - 0s - loss: 0.1782 - val_loss: 0.2134 - 197ms/epoch - 9ms/step
# Epoch 365/500
# 21/21 - 0s - loss: 0.1807 - val_loss: 0.2229 - 194ms/epoch - 9ms/step
# Epoch 366/500
# 21/21 - 0s - loss: 0.1866 - val_loss: 0.2412 - 169ms/epoch - 8ms/step
# Epoch 367/500
# 21/21 - 0s - loss: 0.1953 - val_loss: 0.2594 - 162ms/epoch - 8ms/step
# Epoch 368/500
# 21/21 - 0s - loss: 0.1965 - val_loss: 0.2487 - 197ms/epoch - 9ms/step
# Epoch 369/500
# 21/21 - 0s - loss: 0.1870 - val_loss: 0.2231 - 157ms/epoch - 7ms/step
# Epoch 370/500
# 21/21 - 0s - loss: 0.1796 - val_loss: 0.2103 - 172ms/epoch - 8ms/step
# Epoch 371/500
# 21/21 - 0s - loss: 0.1758 - val_loss: 0.2041 - 168ms/epoch - 8ms/step
# Epoch 372/500
# 21/21 - 0s - loss: 0.1737 - val_loss: 0.2013 - 175ms/epoch - 8ms/step
# Epoch 373/500
# 21/21 - 0s - loss: 0.1728 - val_loss: 0.2009 - 199ms/epoch - 9ms/step
# Epoch 374/500
# 21/21 - 0s - loss: 0.1728 - val_loss: 0.2028 - 237ms/epoch - 11ms/step
# Epoch 375/500
# 21/21 - 0s - loss: 0.1744 - val_loss: 0.2105 - 254ms/epoch - 12ms/step
# Epoch 376/500
# 21/21 - 0s - loss: 0.1807 - val_loss: 0.2340 - 188ms/epoch - 9ms/step
# Epoch 377/500
# 21/21 - 0s - loss: 0.1980 - val_loss: 0.2842 - 150ms/epoch - 7ms/step
# Epoch 378/500
# 21/21 - 0s - loss: 0.2151 - val_loss: 0.2863 - 150ms/epoch - 7ms/step
# Epoch 379/500
# 21/21 - 0s - loss: 0.1905 - val_loss: 0.2167 - 166ms/epoch - 8ms/step
# Epoch 380/500
# 21/21 - 0s - loss: 0.1755 - val_loss: 0.2015 - 136ms/epoch - 6ms/step
# Epoch 381/500
# 21/21 - 0s - loss: 0.1714 - val_loss: 0.1956 - 192ms/epoch - 9ms/step
# Epoch 382/500
# 21/21 - 0s - loss: 0.1695 - val_loss: 0.1944 - 259ms/epoch - 12ms/step
# Epoch 383/500
# 21/21 - 0s - loss: 0.1690 - val_loss: 0.1947 - 298ms/epoch - 14ms/step
# Epoch 384/500
# 21/21 - 0s - loss: 0.1690 - val_loss: 0.1958 - 208ms/epoch - 10ms/step
# Epoch 385/500
# 21/21 - 0s - loss: 0.1695 - val_loss: 0.1983 - 212ms/epoch - 10ms/step
# Epoch 386/500
# 21/21 - 0s - loss: 0.1713 - val_loss: 0.2048 - 301ms/epoch - 14ms/step
# Epoch 387/500
# 21/21 - 0s - loss: 0.1764 - val_loss: 0.2225 - 207ms/epoch - 10ms/step
# Epoch 388/500
# 21/21 - 0s - loss: 0.1899 - val_loss: 0.2633 - 279ms/epoch - 13ms/step
# Epoch 389/500
# 21/21 - 0s - loss: 0.2102 - val_loss: 0.2891 - 233ms/epoch - 11ms/step
# Epoch 390/500
# 21/21 - 0s - loss: 0.1918 - val_loss: 0.2217 - 279ms/epoch - 13ms/step
# Epoch 391/500
# 21/21 - 0s - loss: 0.1733 - val_loss: 0.1960 - 213ms/epoch - 10ms/step
# Epoch 392/500
# 21/21 - 0s - loss: 0.1677 - val_loss: 0.1915 - 233ms/epoch - 11ms/step
# Epoch 393/500
# 21/21 - 0s - loss: 0.1679 - val_loss: 0.1962 - 226ms/epoch - 11ms/step
# Epoch 394/500
# 21/21 - 0s - loss: 0.1715 - val_loss: 0.2115 - 195ms/epoch - 9ms/step
# Epoch 395/500
# 21/21 - 0s - loss: 0.1811 - val_loss: 0.2407 - 188ms/epoch - 9ms/step
# Epoch 396/500
# 21/21 - 0s - loss: 0.1930 - val_loss: 0.2617 - 173ms/epoch - 8ms/step
# Epoch 397/500
# 21/21 - 0s - loss: 0.1890 - val_loss: 0.2378 - 161ms/epoch - 8ms/step
# Epoch 398/500
# 21/21 - 0s - loss: 0.1779 - val_loss: 0.2140 - 147ms/epoch - 7ms/step
# Epoch 399/500
# 21/21 - 0s - loss: 0.1719 - val_loss: 0.2033 - 135ms/epoch - 6ms/step
# Epoch 400/500
# 21/21 - 0s - loss: 0.1685 - val_loss: 0.1971 - 127ms/epoch - 6ms/step
# Epoch 401/500
# 21/21 - 0s - loss: 0.1667 - val_loss: 0.1951 - 165ms/epoch - 8ms/step
# Epoch 402/500
# 21/21 - 0s - loss: 0.1662 - val_loss: 0.1954 - 201ms/epoch - 10ms/step
# Epoch 403/500
# 21/21 - 0s - loss: 0.1667 - val_loss: 0.1989 - 217ms/epoch - 10ms/step
# Epoch 404/500
# 21/21 - 0s - loss: 0.1691 - val_loss: 0.2081 - 142ms/epoch - 7ms/step
# Epoch 405/500
# 21/21 - 0s - loss: 0.1751 - val_loss: 0.2280 - 133ms/epoch - 6ms/step
# Epoch 406/500
# 21/21 - 0s - loss: 0.1858 - val_loss: 0.2543 - 141ms/epoch - 7ms/step
# Epoch 407/500
# 21/21 - 0s - loss: 0.1907 - val_loss: 0.2495 - 158ms/epoch - 8ms/step
# Epoch 408/500
# 21/21 - 0s - loss: 0.1798 - val_loss: 0.2167 - 146ms/epoch - 7ms/step
# Epoch 409/500
# 21/21 - 0s - loss: 0.1705 - val_loss: 0.2006 - 143ms/epoch - 7ms/step
# Epoch 410/500
# 21/21 - 0s - loss: 0.1660 - val_loss: 0.1929 - 146ms/epoch - 7ms/step
# Epoch 411/500
# 21/21 - 0s - loss: 0.1636 - val_loss: 0.1892 - 133ms/epoch - 6ms/step
# Epoch 412/500
# 21/21 - 0s - loss: 0.1623 - val_loss: 0.1877 - 106ms/epoch - 5ms/step
# Epoch 413/500
# 21/21 - 0s - loss: 0.1616 - val_loss: 0.1875 - 134ms/epoch - 6ms/step
# Epoch 414/500
# 21/21 - 0s - loss: 0.1616 - val_loss: 0.1889 - 173ms/epoch - 8ms/step
# Epoch 415/500
# 21/21 - 0s - loss: 0.1628 - val_loss: 0.1951 - 184ms/epoch - 9ms/step
# Epoch 416/500
# 21/21 - 0s - loss: 0.1682 - val_loss: 0.2173 - 166ms/epoch - 8ms/step
# Epoch 417/500
# 21/21 - 0s - loss: 0.1876 - val_loss: 0.2832 - 122ms/epoch - 6ms/step
# Epoch 418/500
# 21/21 - 0s - loss: 0.2243 - val_loss: 0.3192 - 110ms/epoch - 5ms/step
# Epoch 419/500
# 21/21 - 0s - loss: 0.1872 - val_loss: 0.2036 - 92ms/epoch - 4ms/step
# Epoch 420/500
# 21/21 - 0s - loss: 0.1647 - val_loss: 0.1878 - 112ms/epoch - 5ms/step
# Epoch 421/500
# 21/21 - 0s - loss: 0.1610 - val_loss: 0.1835 - 102ms/epoch - 5ms/step
# Epoch 422/500
# 21/21 - 0s - loss: 0.1598 - val_loss: 0.1849 - 91ms/epoch - 4ms/step
# Epoch 423/500
# 21/21 - 0s - loss: 0.1604 - val_loss: 0.1883 - 98ms/epoch - 5ms/step
# Epoch 424/500
# 21/21 - 0s - loss: 0.1617 - val_loss: 0.1931 - 101ms/epoch - 5ms/step
# Epoch 425/500
# 21/21 - 0s - loss: 0.1642 - val_loss: 0.2009 - 95ms/epoch - 5ms/step
# Epoch 426/500
# 21/21 - 0s - loss: 0.1682 - val_loss: 0.2125 - 91ms/epoch - 4ms/step
# Epoch 427/500
# 21/21 - 0s - loss: 0.1733 - val_loss: 0.2241 - 112ms/epoch - 5ms/step
# Epoch 428/500
# 21/21 - 0s - loss: 0.1755 - val_loss: 0.2241 - 103ms/epoch - 5ms/step
# Epoch 429/500
# 21/21 - 0s - loss: 0.1713 - val_loss: 0.2100 - 144ms/epoch - 7ms/step
# Epoch 430/500
# 21/21 - 0s - loss: 0.1652 - val_loss: 0.1961 - 128ms/epoch - 6ms/step
# Epoch 431/500
# 21/21 - 0s - loss: 0.1608 - val_loss: 0.1874 - 150ms/epoch - 7ms/step
# Epoch 432/500
# 21/21 - 0s - loss: 0.1580 - val_loss: 0.1823 - 160ms/epoch - 8ms/step
# Epoch 433/500
# 21/21 - 0s - loss: 0.1564 - val_loss: 0.1797 - 146ms/epoch - 7ms/step
# Epoch 434/500
# 21/21 - 0s - loss: 0.1557 - val_loss: 0.1796 - 148ms/epoch - 7ms/step
# Epoch 435/500
# 21/21 - 0s - loss: 0.1567 - val_loss: 0.1860 - 121ms/epoch - 6ms/step
# Epoch 436/500
# 21/21 - 0s - loss: 0.1639 - val_loss: 0.2166 - 130ms/epoch - 6ms/step
# Epoch 437/500
# 21/21 - 0s - loss: 0.1941 - val_loss: 0.3194 - 112ms/epoch - 5ms/step
# Epoch 438/500
# 21/21 - 0s - loss: 0.2431 - val_loss: 0.3081 - 98ms/epoch - 5ms/step
# Epoch 439/500
# 21/21 - 0s - loss: 0.1943 - val_loss: 0.2021 - 94ms/epoch - 4ms/step
# Epoch 440/500
# 21/21 - 0s - loss: 0.1726 - val_loss: 0.1792 - 133ms/epoch - 6ms/step
# Epoch 441/500
# 21/21 - 0s - loss: 0.1821 - val_loss: 0.1850 - 194ms/epoch - 9ms/step
# Epoch 442/500
# 21/21 - 0s - loss: 0.1854 - val_loss: 0.2040 - 223ms/epoch - 11ms/step
# Epoch 443/500
# 21/21 - 0s - loss: 0.2000 - val_loss: 0.2300 - 194ms/epoch - 9ms/step
# Epoch 444/500
# 21/21 - 0s - loss: 0.1971 - val_loss: 0.2648 - 206ms/epoch - 10ms/step
# Epoch 445/500
# 21/21 - 0s - loss: 0.1766 - val_loss: 0.2079 - 263ms/epoch - 13ms/step
# Epoch 446/500
# 21/21 - 0s - loss: 0.1603 - val_loss: 0.1773 - 185ms/epoch - 9ms/step
# Epoch 447/500
# 21/21 - 0s - loss: 0.1561 - val_loss: 0.1834 - 165ms/epoch - 8ms/step
# Epoch 448/500
# 21/21 - 0s - loss: 0.1548 - val_loss: 0.1805 - 140ms/epoch - 7ms/step
# Epoch 449/500
# 21/21 - 0s - loss: 0.1530 - val_loss: 0.1760 - 119ms/epoch - 6ms/step
# Epoch 450/500
# 21/21 - 0s - loss: 0.1520 - val_loss: 0.1761 - 123ms/epoch - 6ms/step
# Epoch 451/500
# 21/21 - 0s - loss: 0.1517 - val_loss: 0.1749 - 113ms/epoch - 5ms/step
# Epoch 452/500
# 21/21 - 0s - loss: 0.1514 - val_loss: 0.1752 - 105ms/epoch - 5ms/step
# Epoch 453/500
# 21/21 - 0s - loss: 0.1513 - val_loss: 0.1744 - 101ms/epoch - 5ms/step
# Epoch 454/500
# 21/21 - 0s - loss: 0.1511 - val_loss: 0.1745 - 104ms/epoch - 5ms/step
# Epoch 455/500
# 21/21 - 0s - loss: 0.1512 - val_loss: 0.1742 - 141ms/epoch - 7ms/step
# Epoch 456/500
# 21/21 - 0s - loss: 0.1507 - val_loss: 0.1737 - 120ms/epoch - 6ms/step
# Epoch 457/500
# 21/21 - 0s - loss: 0.1507 - val_loss: 0.1745 - 139ms/epoch - 7ms/step
# Epoch 458/500
# 21/21 - 0s - loss: 0.1500 - val_loss: 0.1735 - 127ms/epoch - 6ms/step
# Epoch 459/500
# 21/21 - 0s - loss: 0.1499 - val_loss: 0.1749 - 101ms/epoch - 5ms/step
# Epoch 460/500
# 21/21 - 0s - loss: 0.1500 - val_loss: 0.1758 - 112ms/epoch - 5ms/step
# Epoch 461/500
# 21/21 - 0s - loss: 0.1508 - val_loss: 0.1796 - 130ms/epoch - 6ms/step
# Epoch 462/500
# 21/21 - 0s - loss: 0.1531 - val_loss: 0.1884 - 128ms/epoch - 6ms/step
# Epoch 463/500
# 21/21 - 0s - loss: 0.1590 - val_loss: 0.2085 - 103ms/epoch - 5ms/step
# Epoch 464/500
# 21/21 - 0s - loss: 0.1708 - val_loss: 0.2409 - 98ms/epoch - 5ms/step
# Epoch 465/500
# 21/21 - 0s - loss: 0.1802 - val_loss: 0.2460 - 101ms/epoch - 5ms/step
# Epoch 466/500
# 21/21 - 0s - loss: 0.1684 - val_loss: 0.2057 - 94ms/epoch - 4ms/step
# Epoch 467/500
# 21/21 - 0s - loss: 0.1566 - val_loss: 0.1851 - 97ms/epoch - 5ms/step
# Epoch 468/500
# 21/21 - 0s - loss: 0.1513 - val_loss: 0.1762 - 103ms/epoch - 5ms/step
# Epoch 469/500
# 21/21 - 0s - loss: 0.1486 - val_loss: 0.1715 - 104ms/epoch - 5ms/step
# Epoch 470/500
# 21/21 - 0s - loss: 0.1471 - val_loss: 0.1695 - 99ms/epoch - 5ms/step
# Epoch 471/500
# 21/21 - 0s - loss: 0.1463 - val_loss: 0.1688 - 94ms/epoch - 4ms/step
# Epoch 472/500
# 21/21 - 0s - loss: 0.1460 - val_loss: 0.1687 - 94ms/epoch - 4ms/step
# Epoch 473/500
# 21/21 - 0s - loss: 0.1462 - val_loss: 0.1702 - 98ms/epoch - 5ms/step
# Epoch 474/500
# 21/21 - 0s - loss: 0.1477 - val_loss: 0.1766 - 94ms/epoch - 4ms/step
# Epoch 475/500
# 21/21 - 0s - loss: 0.1543 - val_loss: 0.2011 - 99ms/epoch - 5ms/step
# Epoch 476/500
# 21/21 - 0s - loss: 0.1788 - val_loss: 0.2830 - 92ms/epoch - 4ms/step
# Epoch 477/500
# 21/21 - 0s - loss: 0.2328 - val_loss: 0.3221 - 95ms/epoch - 5ms/step
# Epoch 478/500
# 21/21 - 0s - loss: 0.1749 - val_loss: 0.1785 - 93ms/epoch - 4ms/step
# Epoch 479/500
# 21/21 - 0s - loss: 0.1478 - val_loss: 0.1682 - 94ms/epoch - 4ms/step
# Epoch 480/500
# 21/21 - 0s - loss: 0.1478 - val_loss: 0.1694 - 92ms/epoch - 4ms/step
# Epoch 481/500
# 21/21 - 0s - loss: 0.1449 - val_loss: 0.1702 - 89ms/epoch - 4ms/step
# Epoch 482/500
# 21/21 - 0s - loss: 0.1475 - val_loss: 0.1777 - 91ms/epoch - 4ms/step
# Epoch 483/500
# 21/21 - 0s - loss: 0.1479 - val_loss: 0.1798 - 89ms/epoch - 4ms/step
# Epoch 484/500
# 21/21 - 0s - loss: 0.1498 - val_loss: 0.1866 - 95ms/epoch - 5ms/step
# Epoch 485/500
# 21/21 - 0s - loss: 0.1521 - val_loss: 0.1927 - 96ms/epoch - 5ms/step
# Epoch 486/500
# 21/21 - 0s - loss: 0.1545 - val_loss: 0.1986 - 82ms/epoch - 4ms/step
# Epoch 487/500
# 21/21 - 0s - loss: 0.1558 - val_loss: 0.2006 - 93ms/epoch - 4ms/step
# Epoch 488/500
# 21/21 - 0s - loss: 0.1553 - val_loss: 0.1976 - 100ms/epoch - 5ms/step
# Epoch 489/500
# 21/21 - 0s - loss: 0.1532 - val_loss: 0.1915 - 92ms/epoch - 4ms/step
# Epoch 490/500
# 21/21 - 0s - loss: 0.1507 - val_loss: 0.1856 - 91ms/epoch - 4ms/step
# Epoch 491/500
# 21/21 - 0s - loss: 0.1486 - val_loss: 0.1813 - 80ms/epoch - 4ms/step
# Epoch 492/500
# 21/21 - 0s - loss: 0.1472 - val_loss: 0.1791 - 84ms/epoch - 4ms/step
# Epoch 493/500
# 21/21 - 0s - loss: 0.1466 - val_loss: 0.1791 - 94ms/epoch - 4ms/step
# Epoch 494/500
# 21/21 - 0s - loss: 0.1471 - val_loss: 0.1822 - 161ms/epoch - 8ms/step
# Epoch 495/500
# 21/21 - 0s - loss: 0.1491 - val_loss: 0.1896 - 100ms/epoch - 5ms/step
# Epoch 496/500
# 21/21 - 0s - loss: 0.1532 - val_loss: 0.2022 - 92ms/epoch - 4ms/step
# Epoch 497/500
# 21/21 - 0s - loss: 0.1588 - val_loss: 0.2148 - 98ms/epoch - 5ms/step
# Epoch 498/500
# 21/21 - 0s - loss: 0.1609 - val_loss: 0.2119 - 94ms/epoch - 4ms/step
# Epoch 499/500
# 21/21 - 0s - loss: 0.1551 - val_loss: 0.1923 - 97ms/epoch - 5ms/step
# Epoch 500/500
# 21/21 - 0s - loss: 0.1477 - val_loss: 0.1760 - 89ms/epoch - 4ms/step

# %% [markdown]
# ## Metrics ($LPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
phy = phys2(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 11/11 [==============================] - 0s 1ms/step
# (325, 3)
# (325, 10)
# Test RMSE: 4.345
# Test MAE: 3.775

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('El Niño Sea Surface Temperature', fontsize=20)
plt.legend(fontsize=20)
plt.show()
