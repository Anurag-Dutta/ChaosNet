# %% [markdown]
# # Time Series Prediction with Duffing Equation Inspired Deep Learning ($DPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-09 18:07:15

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Duffing Intermittency_

# %% [markdown]
# The `duffing_intermittency.dat` is generated from the Runge Kutta Method.

# %% [markdown]
# This feeds the model with the dynamics of the Duffing Equations

# %%
data = np.genfromtxt('datasets/duffing_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 7 # Weekly Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 1.73753853
# 1         0.002821
# 2         0.002786
# 3         0.002751
# 4         0.002715
# 5         0.002681
#             ...
# 139867    0.000000
# 139868    0.000000
# 139869    0.000000
# 139870    0.000000
# 139871    0.000000
# Name: 1, Length: 139871, dtype: float64
# 2        -0.000005
# 3        -0.000005
# 4        -0.000005
# 5        -0.000005
# 6        -0.000005
#             ...
# 139867    0.000000
# 139868    0.000000
# 139869    0.000000
# 139870    0.000000
# 139871    0.000000
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _SAN JUAN_

# %%
data = pd.read_csv("datasets/sanjuan.csv")
training_set = data.iloc[:, 3]
print(training_set)
# Out:
# 0        4
# 1        5
# 2        4
# 3        3
# 4        6
#         ..
# 1191    56
# 1192    46
# 1193    52
# 1194    34
# 1195    25
# Name: Cases, Length: 1196, dtype: int64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0         0.002821
# 1         0.002786
# 2         0.002751
# 3         0.002715
# 4         0.002681
#             ...
# 139866    0.000000
# 139867    0.000000
# 139868    0.000000
# 139869    0.000000
# 139870    0.000000
# Name: 1, Length: 139871, dtype: float64
# 0        -0.000005
# 1        -0.000005
# 2        -0.000005
# 3        -0.000005
# 4        -0.000005
#             ...
# 139865    0.000000
# 139866    0.000000
# 139867    0.000000
# 139868    0.000000
# 139869    0.000000
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Duffing Equation_)

# %% [markdown]
# _Parameters_: $\alpha=0.5, \beta=1, \gamma=3, \delta=1\\$

# %%
a=0.5
b=1
c=3
d=1
L = df.iloc[:, 2] -c + d*df.iloc[:, 1] - a*df.iloc[:, 0] - b*df.iloc[:, 0]**3
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10         4.0        5.0        4.0        3.0        6.0        2.0
# 11         5.0        4.0        3.0        6.0        2.0        4.0
# 12         4.0        3.0        6.0        2.0        4.0        5.0
# 13         3.0        6.0        2.0        4.0        5.0       10.0
# 14         6.0        2.0        4.0        5.0       10.0        6.0
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)   var2(t)   var3(t)
# 10        4.0        5.0       10.0        6.0      8.0  0.002474 -0.000005
# 11        5.0       10.0        6.0        8.0      2.0  0.002439 -0.000005
# 12       10.0        6.0        8.0        2.0      6.0  0.002405 -0.000005
# 13        6.0        8.0        2.0        6.0     17.0  0.002371 -0.000005
# 14        8.0        2.0        6.0       17.0     23.0  0.002337 -0.000005
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (1185, 13)
# (1185, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (948, 1, 10) (948, 3) (237, 1, 10) (237, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
a = tf.Variable(0.5, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(1, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(3, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(1, name="delta", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] -c + d*y_true[:, 1] - a*y_true[:, 0] - b*y_true[:, 0]**3), (y_pred[:, 2] -c + d*y_pred[:, 1] - a*y_pred[:, 0] - b*y_pred[:, 0]**3))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] -c + d*(y_pred[1:-1]-y_pred[:-2]) - a*y_pred[:-2] - b*y_pred[:-2]**3
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] -c + d*(y_real[1:-1]-y_real[:-2]) - a*y_real[:-2] - b*y_real[:-2]**3
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($DPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square(y_pred[:, 2] -c + d*y_pred[:, 1] - a*y_pred[:, 0] - b*y_pred[:, 0]**3)
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 15/15 - 5s - loss: 0.2474 - val_loss: 0.2387 - 5s/epoch - 344ms/step
# Epoch 2/500
# 15/15 - 0s - loss: 0.2186 - val_loss: 0.2030 - 83ms/epoch - 6ms/step
# Epoch 3/500
# 15/15 - 0s - loss: 0.1895 - val_loss: 0.1666 - 87ms/epoch - 6ms/step
# Epoch 4/500
# 15/15 - 0s - loss: 0.1589 - val_loss: 0.1299 - 85ms/epoch - 6ms/step
# Epoch 5/500
# 15/15 - 0s - loss: 0.1275 - val_loss: 0.0954 - 84ms/epoch - 6ms/step
# Epoch 6/500
# 15/15 - 0s - loss: 0.0974 - val_loss: 0.0671 - 85ms/epoch - 6ms/step
# Epoch 7/500
# 15/15 - 0s - loss: 0.0716 - val_loss: 0.0476 - 93ms/epoch - 6ms/step
# Epoch 8/500
# 15/15 - 0s - loss: 0.0518 - val_loss: 0.0365 - 87ms/epoch - 6ms/step
# Epoch 9/500
# 15/15 - 0s - loss: 0.0382 - val_loss: 0.0308 - 94ms/epoch - 6ms/step
# Epoch 10/500
# 15/15 - 0s - loss: 0.0292 - val_loss: 0.0273 - 88ms/epoch - 6ms/step
# Epoch 11/500
# 15/15 - 0s - loss: 0.0231 - val_loss: 0.0243 - 93ms/epoch - 6ms/step
# Epoch 12/500
# 15/15 - 0s - loss: 0.0185 - val_loss: 0.0211 - 91ms/epoch - 6ms/step
# Epoch 13/500
# 15/15 - 0s - loss: 0.0150 - val_loss: 0.0180 - 85ms/epoch - 6ms/step
# Epoch 14/500
# 15/15 - 0s - loss: 0.0122 - val_loss: 0.0151 - 87ms/epoch - 6ms/step
# Epoch 15/500
# 15/15 - 0s - loss: 0.0099 - val_loss: 0.0126 - 88ms/epoch - 6ms/step
# Epoch 16/500
# 15/15 - 0s - loss: 0.0081 - val_loss: 0.0104 - 85ms/epoch - 6ms/step
# Epoch 17/500
# 15/15 - 0s - loss: 0.0066 - val_loss: 0.0086 - 87ms/epoch - 6ms/step
# Epoch 18/500
# 15/15 - 0s - loss: 0.0054 - val_loss: 0.0071 - 87ms/epoch - 6ms/step
# Epoch 19/500
# 15/15 - 0s - loss: 0.0045 - val_loss: 0.0059 - 90ms/epoch - 6ms/step
# Epoch 20/500
# 15/15 - 0s - loss: 0.0038 - val_loss: 0.0050 - 86ms/epoch - 6ms/step
# Epoch 21/500
# 15/15 - 0s - loss: 0.0033 - val_loss: 0.0043 - 93ms/epoch - 6ms/step
# Epoch 22/500
# 15/15 - 0s - loss: 0.0029 - val_loss: 0.0037 - 97ms/epoch - 6ms/step
# Epoch 23/500
# 15/15 - 0s - loss: 0.0026 - val_loss: 0.0032 - 92ms/epoch - 6ms/step
# Epoch 24/500
# 15/15 - 0s - loss: 0.0023 - val_loss: 0.0029 - 91ms/epoch - 6ms/step
# Epoch 25/500
# 15/15 - 0s - loss: 0.0021 - val_loss: 0.0026 - 90ms/epoch - 6ms/step
# Epoch 26/500
# 15/15 - 0s - loss: 0.0020 - val_loss: 0.0024 - 87ms/epoch - 6ms/step
# Epoch 27/500
# 15/15 - 0s - loss: 0.0019 - val_loss: 0.0022 - 87ms/epoch - 6ms/step
# Epoch 28/500
# 15/15 - 0s - loss: 0.0018 - val_loss: 0.0021 - 88ms/epoch - 6ms/step
# Epoch 29/500
# 15/15 - 0s - loss: 0.0017 - val_loss: 0.0019 - 90ms/epoch - 6ms/step
# Epoch 30/500
# 15/15 - 0s - loss: 0.0016 - val_loss: 0.0018 - 87ms/epoch - 6ms/step
# Epoch 31/500
# 15/15 - 0s - loss: 0.0016 - val_loss: 0.0018 - 88ms/epoch - 6ms/step
# Epoch 32/500
# 15/15 - 0s - loss: 0.0015 - val_loss: 0.0017 - 100ms/epoch - 7ms/step
# Epoch 33/500
# 15/15 - 0s - loss: 0.0015 - val_loss: 0.0016 - 95ms/epoch - 6ms/step
# Epoch 34/500
# 15/15 - 0s - loss: 0.0014 - val_loss: 0.0016 - 96ms/epoch - 6ms/step
# Epoch 35/500
# 15/15 - 0s - loss: 0.0014 - val_loss: 0.0015 - 94ms/epoch - 6ms/step
# Epoch 36/500
# 15/15 - 0s - loss: 0.0014 - val_loss: 0.0015 - 95ms/epoch - 6ms/step
# Epoch 37/500
# 15/15 - 0s - loss: 0.0013 - val_loss: 0.0015 - 93ms/epoch - 6ms/step
# Epoch 38/500
# 15/15 - 0s - loss: 0.0013 - val_loss: 0.0014 - 95ms/epoch - 6ms/step
# Epoch 39/500
# 15/15 - 0s - loss: 0.0013 - val_loss: 0.0014 - 97ms/epoch - 6ms/step
# Epoch 40/500
# 15/15 - 0s - loss: 0.0013 - val_loss: 0.0014 - 99ms/epoch - 7ms/step
# Epoch 41/500
# 15/15 - 0s - loss: 0.0013 - val_loss: 0.0013 - 94ms/epoch - 6ms/step
# Epoch 42/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0013 - 107ms/epoch - 7ms/step
# Epoch 43/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0013 - 94ms/epoch - 6ms/step
# Epoch 44/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0013 - 95ms/epoch - 6ms/step
# Epoch 45/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0013 - 94ms/epoch - 6ms/step
# Epoch 46/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0013 - 92ms/epoch - 6ms/step
# Epoch 47/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0012 - 89ms/epoch - 6ms/step
# Epoch 48/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0012 - 89ms/epoch - 6ms/step
# Epoch 49/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 50/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0012 - 93ms/epoch - 6ms/step
# Epoch 51/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 89ms/epoch - 6ms/step
# Epoch 52/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 100ms/epoch - 7ms/step
# Epoch 53/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 105ms/epoch - 7ms/step
# Epoch 54/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 55/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 92ms/epoch - 6ms/step
# Epoch 56/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 57/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 93ms/epoch - 6ms/step
# Epoch 58/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 59/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 60/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 61/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 100ms/epoch - 7ms/step
# Epoch 62/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 113ms/epoch - 8ms/step
# Epoch 63/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0011 - 106ms/epoch - 7ms/step
# Epoch 64/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 65/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 66/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 67/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 68/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0011 - 89ms/epoch - 6ms/step
# Epoch 69/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 70/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0011 - 92ms/epoch - 6ms/step
# Epoch 71/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0011 - 92ms/epoch - 6ms/step
# Epoch 72/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0011 - 92ms/epoch - 6ms/step
# Epoch 73/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 74/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 75/500
# 15/15 - 0s - loss: 9.9947e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 76/500
# 15/15 - 0s - loss: 9.9507e-04 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 77/500
# 15/15 - 0s - loss: 9.9074e-04 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 78/500
# 15/15 - 0s - loss: 9.8648e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 79/500
# 15/15 - 0s - loss: 9.8229e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 80/500
# 15/15 - 0s - loss: 9.7817e-04 - val_loss: 0.0011 - 104ms/epoch - 7ms/step
# Epoch 81/500
# 15/15 - 0s - loss: 9.7412e-04 - val_loss: 0.0011 - 115ms/epoch - 8ms/step
# Epoch 82/500
# 15/15 - 0s - loss: 9.7013e-04 - val_loss: 0.0011 - 212ms/epoch - 14ms/step
# Epoch 83/500
# 15/15 - 0s - loss: 9.6621e-04 - val_loss: 0.0011 - 121ms/epoch - 8ms/step
# Epoch 84/500
# 15/15 - 0s - loss: 9.6235e-04 - val_loss: 0.0011 - 95ms/epoch - 6ms/step
# Epoch 85/500
# 15/15 - 0s - loss: 9.5855e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 86/500
# 15/15 - 0s - loss: 9.5481e-04 - val_loss: 0.0011 - 85ms/epoch - 6ms/step
# Epoch 87/500
# 15/15 - 0s - loss: 9.5114e-04 - val_loss: 0.0011 - 84ms/epoch - 6ms/step
# Epoch 88/500
# 15/15 - 0s - loss: 9.4752e-04 - val_loss: 0.0011 - 85ms/epoch - 6ms/step
# Epoch 89/500
# 15/15 - 0s - loss: 9.4396e-04 - val_loss: 0.0011 - 84ms/epoch - 6ms/step
# Epoch 90/500
# 15/15 - 0s - loss: 9.4046e-04 - val_loss: 0.0011 - 87ms/epoch - 6ms/step
# Epoch 91/500
# 15/15 - 0s - loss: 9.3702e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 92/500
# 15/15 - 0s - loss: 9.3363e-04 - val_loss: 0.0011 - 80ms/epoch - 5ms/step
# Epoch 93/500
# 15/15 - 0s - loss: 9.3030e-04 - val_loss: 0.0011 - 79ms/epoch - 5ms/step
# Epoch 94/500
# 15/15 - 0s - loss: 9.2702e-04 - val_loss: 0.0011 - 83ms/epoch - 6ms/step
# Epoch 95/500
# 15/15 - 0s - loss: 9.2380e-04 - val_loss: 0.0011 - 83ms/epoch - 6ms/step
# Epoch 96/500
# 15/15 - 0s - loss: 9.2063e-04 - val_loss: 0.0011 - 83ms/epoch - 6ms/step
# Epoch 97/500
# 15/15 - 0s - loss: 9.1752e-04 - val_loss: 0.0011 - 84ms/epoch - 6ms/step
# Epoch 98/500
# 15/15 - 0s - loss: 9.1446e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 99/500
# 15/15 - 0s - loss: 9.1144e-04 - val_loss: 0.0011 - 89ms/epoch - 6ms/step
# Epoch 100/500
# 15/15 - 0s - loss: 9.0849e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 101/500
# 15/15 - 0s - loss: 9.0558e-04 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 102/500
# 15/15 - 0s - loss: 9.0272e-04 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 103/500
# 15/15 - 0s - loss: 8.9991e-04 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 104/500
# 15/15 - 0s - loss: 8.9715e-04 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 105/500
# 15/15 - 0s - loss: 8.9444e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 106/500
# 15/15 - 0s - loss: 8.9177e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 107/500
# 15/15 - 0s - loss: 8.8915e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 108/500
# 15/15 - 0s - loss: 8.8658e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 109/500
# 15/15 - 0s - loss: 8.8405e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 110/500
# 15/15 - 0s - loss: 8.8157e-04 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 111/500
# 15/15 - 0s - loss: 8.7913e-04 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 112/500
# 15/15 - 0s - loss: 8.7674e-04 - val_loss: 0.0011 - 95ms/epoch - 6ms/step
# Epoch 113/500
# 15/15 - 0s - loss: 8.7439e-04 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 114/500
# 15/15 - 0s - loss: 8.7208e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 115/500
# 15/15 - 0s - loss: 8.6981e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 116/500
# 15/15 - 0s - loss: 8.6758e-04 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 117/500
# 15/15 - 0s - loss: 8.6539e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 118/500
# 15/15 - 0s - loss: 8.6324e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 119/500
# 15/15 - 0s - loss: 8.6113e-04 - val_loss: 0.0011 - 92ms/epoch - 6ms/step
# Epoch 120/500
# 15/15 - 0s - loss: 8.5906e-04 - val_loss: 0.0011 - 95ms/epoch - 6ms/step
# Epoch 121/500
# 15/15 - 0s - loss: 8.5703e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 122/500
# 15/15 - 0s - loss: 8.5503e-04 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 123/500
# 15/15 - 0s - loss: 8.5307e-04 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 124/500
# 15/15 - 0s - loss: 8.5114e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 125/500
# 15/15 - 0s - loss: 8.4925e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 126/500
# 15/15 - 0s - loss: 8.4740e-04 - val_loss: 0.0011 - 95ms/epoch - 6ms/step
# Epoch 127/500
# 15/15 - 0s - loss: 8.4558e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 128/500
# 15/15 - 0s - loss: 8.4379e-04 - val_loss: 0.0011 - 89ms/epoch - 6ms/step
# Epoch 129/500
# 15/15 - 0s - loss: 8.4203e-04 - val_loss: 0.0011 - 90ms/epoch - 6ms/step
# Epoch 130/500
# 15/15 - 0s - loss: 8.4031e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 131/500
# 15/15 - 0s - loss: 8.3862e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 132/500
# 15/15 - 0s - loss: 8.3696e-04 - val_loss: 0.0011 - 90ms/epoch - 6ms/step
# Epoch 133/500
# 15/15 - 0s - loss: 8.3533e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 134/500
# 15/15 - 0s - loss: 8.3373e-04 - val_loss: 0.0011 - 90ms/epoch - 6ms/step
# Epoch 135/500
# 15/15 - 0s - loss: 8.3215e-04 - val_loss: 0.0011 - 89ms/epoch - 6ms/step
# Epoch 136/500
# 15/15 - 0s - loss: 8.3061e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 137/500
# 15/15 - 0s - loss: 8.2910e-04 - val_loss: 0.0011 - 102ms/epoch - 7ms/step
# Epoch 138/500
# 15/15 - 0s - loss: 8.2761e-04 - val_loss: 0.0011 - 105ms/epoch - 7ms/step
# Epoch 139/500
# 15/15 - 0s - loss: 8.2615e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 140/500
# 15/15 - 0s - loss: 8.2472e-04 - val_loss: 0.0011 - 95ms/epoch - 6ms/step
# Epoch 141/500
# 15/15 - 0s - loss: 8.2332e-04 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 142/500
# 15/15 - 0s - loss: 8.2194e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 143/500
# 15/15 - 0s - loss: 8.2058e-04 - val_loss: 0.0011 - 95ms/epoch - 6ms/step
# Epoch 144/500
# 15/15 - 0s - loss: 8.1925e-04 - val_loss: 0.0011 - 100ms/epoch - 7ms/step
# Epoch 145/500
# 15/15 - 0s - loss: 8.1795e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 146/500
# 15/15 - 0s - loss: 8.1667e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 147/500
# 15/15 - 0s - loss: 8.1541e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 148/500
# 15/15 - 0s - loss: 8.1418e-04 - val_loss: 0.0011 - 125ms/epoch - 8ms/step
# Epoch 149/500
# 15/15 - 0s - loss: 8.1296e-04 - val_loss: 0.0011 - 102ms/epoch - 7ms/step
# Epoch 150/500
# 15/15 - 0s - loss: 8.1177e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 151/500
# 15/15 - 0s - loss: 8.1061e-04 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 152/500
# 15/15 - 0s - loss: 8.0946e-04 - val_loss: 0.0011 - 182ms/epoch - 12ms/step
# Epoch 153/500
# 15/15 - 0s - loss: 8.0834e-04 - val_loss: 0.0011 - 112ms/epoch - 7ms/step
# Epoch 154/500
# 15/15 - 0s - loss: 8.0723e-04 - val_loss: 0.0011 - 99ms/epoch - 7ms/step
# Epoch 155/500
# 15/15 - 0s - loss: 8.0615e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 156/500
# 15/15 - 0s - loss: 8.0508e-04 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 157/500
# 15/15 - 0s - loss: 8.0404e-04 - val_loss: 0.0011 - 102ms/epoch - 7ms/step
# Epoch 158/500
# 15/15 - 0s - loss: 8.0301e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 159/500
# 15/15 - 0s - loss: 8.0201e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 160/500
# 15/15 - 0s - loss: 8.0102e-04 - val_loss: 0.0011 - 99ms/epoch - 7ms/step
# Epoch 161/500
# 15/15 - 0s - loss: 8.0005e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 162/500
# 15/15 - 0s - loss: 7.9910e-04 - val_loss: 0.0011 - 100ms/epoch - 7ms/step
# Epoch 163/500
# 15/15 - 0s - loss: 7.9817e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 164/500
# 15/15 - 0s - loss: 7.9725e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 165/500
# 15/15 - 0s - loss: 7.9635e-04 - val_loss: 0.0011 - 100ms/epoch - 7ms/step
# Epoch 166/500
# 15/15 - 0s - loss: 7.9547e-04 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 167/500
# 15/15 - 0s - loss: 7.9460e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 168/500
# 15/15 - 0s - loss: 7.9375e-04 - val_loss: 0.0011 - 88ms/epoch - 6ms/step
# Epoch 169/500
# 15/15 - 0s - loss: 7.9291e-04 - val_loss: 0.0011 - 87ms/epoch - 6ms/step
# Epoch 170/500
# 15/15 - 0s - loss: 7.9209e-04 - val_loss: 0.0011 - 85ms/epoch - 6ms/step
# Epoch 171/500
# 15/15 - 0s - loss: 7.9129e-04 - val_loss: 0.0011 - 86ms/epoch - 6ms/step
# Epoch 172/500
# 15/15 - 0s - loss: 7.9050e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 173/500
# 15/15 - 0s - loss: 7.8973e-04 - val_loss: 0.0011 - 88ms/epoch - 6ms/step
# Epoch 174/500
# 15/15 - 0s - loss: 7.8897e-04 - val_loss: 0.0011 - 85ms/epoch - 6ms/step
# Epoch 175/500
# 15/15 - 0s - loss: 7.8822e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 176/500
# 15/15 - 0s - loss: 7.8749e-04 - val_loss: 0.0011 - 86ms/epoch - 6ms/step
# Epoch 177/500
# 15/15 - 0s - loss: 7.8677e-04 - val_loss: 0.0011 - 92ms/epoch - 6ms/step
# Epoch 178/500
# 15/15 - 0s - loss: 7.8606e-04 - val_loss: 0.0011 - 101ms/epoch - 7ms/step
# Epoch 179/500
# 15/15 - 0s - loss: 7.8537e-04 - val_loss: 0.0011 - 102ms/epoch - 7ms/step
# Epoch 180/500
# 15/15 - 0s - loss: 7.8469e-04 - val_loss: 0.0011 - 99ms/epoch - 7ms/step
# Epoch 181/500
# 15/15 - 0s - loss: 7.8403e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 182/500
# 15/15 - 0s - loss: 7.8338e-04 - val_loss: 0.0011 - 99ms/epoch - 7ms/step
# Epoch 183/500
# 15/15 - 0s - loss: 7.8273e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 184/500
# 15/15 - 0s - loss: 7.8211e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 185/500
# 15/15 - 0s - loss: 7.8149e-04 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 186/500
# 15/15 - 0s - loss: 7.8088e-04 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 187/500
# 15/15 - 0s - loss: 7.8029e-04 - val_loss: 0.0011 - 95ms/epoch - 6ms/step
# Epoch 188/500
# 15/15 - 0s - loss: 7.7971e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 189/500
# 15/15 - 0s - loss: 7.7914e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 190/500
# 15/15 - 0s - loss: 7.7858e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 191/500
# 15/15 - 0s - loss: 7.7803e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 192/500
# 15/15 - 0s - loss: 7.7749e-04 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 193/500
# 15/15 - 0s - loss: 7.7696e-04 - val_loss: 0.0011 - 92ms/epoch - 6ms/step
# Epoch 194/500
# 15/15 - 0s - loss: 7.7644e-04 - val_loss: 0.0011 - 92ms/epoch - 6ms/step
# Epoch 195/500
# 15/15 - 0s - loss: 7.7593e-04 - val_loss: 0.0011 - 89ms/epoch - 6ms/step
# Epoch 196/500
# 15/15 - 0s - loss: 7.7544e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 197/500
# 15/15 - 0s - loss: 7.7495e-04 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 198/500
# 15/15 - 0s - loss: 7.7447e-04 - val_loss: 0.0011 - 95ms/epoch - 6ms/step
# Epoch 199/500
# 15/15 - 0s - loss: 7.7400e-04 - val_loss: 0.0011 - 95ms/epoch - 6ms/step
# Epoch 200/500
# 15/15 - 0s - loss: 7.7354e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 201/500
# 15/15 - 0s - loss: 7.7308e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 202/500
# 15/15 - 0s - loss: 7.7264e-04 - val_loss: 0.0011 - 92ms/epoch - 6ms/step
# Epoch 203/500
# 15/15 - 0s - loss: 7.7221e-04 - val_loss: 0.0011 - 99ms/epoch - 7ms/step
# Epoch 204/500
# 15/15 - 0s - loss: 7.7178e-04 - val_loss: 0.0011 - 100ms/epoch - 7ms/step
# Epoch 205/500
# 15/15 - 0s - loss: 7.7136e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 206/500
# 15/15 - 0s - loss: 7.7095e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 207/500
# 15/15 - 0s - loss: 7.7055e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 208/500
# 15/15 - 0s - loss: 7.7016e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 209/500
# 15/15 - 0s - loss: 7.6977e-04 - val_loss: 0.0011 - 111ms/epoch - 7ms/step
# Epoch 210/500
# 15/15 - 0s - loss: 7.6939e-04 - val_loss: 0.0011 - 101ms/epoch - 7ms/step
# Epoch 211/500
# 15/15 - 0s - loss: 7.6902e-04 - val_loss: 0.0012 - 93ms/epoch - 6ms/step
# Epoch 212/500
# 15/15 - 0s - loss: 7.6866e-04 - val_loss: 0.0012 - 90ms/epoch - 6ms/step
# Epoch 213/500
# 15/15 - 0s - loss: 7.6830e-04 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 214/500
# 15/15 - 0s - loss: 7.6795e-04 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 215/500
# 15/15 - 0s - loss: 7.6761e-04 - val_loss: 0.0012 - 90ms/epoch - 6ms/step
# Epoch 216/500
# 15/15 - 0s - loss: 7.6727e-04 - val_loss: 0.0012 - 100ms/epoch - 7ms/step
# Epoch 217/500
# 15/15 - 0s - loss: 7.6694e-04 - val_loss: 0.0012 - 92ms/epoch - 6ms/step
# Epoch 218/500
# 15/15 - 0s - loss: 7.6661e-04 - val_loss: 0.0012 - 105ms/epoch - 7ms/step
# Epoch 219/500
# 15/15 - 0s - loss: 7.6629e-04 - val_loss: 0.0012 - 105ms/epoch - 7ms/step
# Epoch 220/500
# 15/15 - 0s - loss: 7.6598e-04 - val_loss: 0.0012 - 215ms/epoch - 14ms/step
# Epoch 221/500
# 15/15 - 0s - loss: 7.6567e-04 - val_loss: 0.0012 - 113ms/epoch - 8ms/step
# Epoch 222/500
# 15/15 - 0s - loss: 7.6537e-04 - val_loss: 0.0012 - 104ms/epoch - 7ms/step
# Epoch 223/500
# 15/15 - 0s - loss: 7.6508e-04 - val_loss: 0.0012 - 117ms/epoch - 8ms/step
# Epoch 224/500
# 15/15 - 0s - loss: 7.6479e-04 - val_loss: 0.0012 - 113ms/epoch - 8ms/step
# Epoch 225/500
# 15/15 - 0s - loss: 7.6450e-04 - val_loss: 0.0012 - 105ms/epoch - 7ms/step
# Epoch 226/500
# 15/15 - 0s - loss: 7.6422e-04 - val_loss: 0.0012 - 97ms/epoch - 6ms/step
# Epoch 227/500
# 15/15 - 0s - loss: 7.6395e-04 - val_loss: 0.0012 - 90ms/epoch - 6ms/step
# Epoch 228/500
# 15/15 - 0s - loss: 7.6368e-04 - val_loss: 0.0012 - 83ms/epoch - 6ms/step
# Epoch 229/500
# 15/15 - 0s - loss: 7.6341e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 230/500
# 15/15 - 0s - loss: 7.6315e-04 - val_loss: 0.0012 - 89ms/epoch - 6ms/step
# Epoch 231/500
# 15/15 - 0s - loss: 7.6289e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 232/500
# 15/15 - 0s - loss: 7.6264e-04 - val_loss: 0.0012 - 89ms/epoch - 6ms/step
# Epoch 233/500
# 15/15 - 0s - loss: 7.6239e-04 - val_loss: 0.0012 - 86ms/epoch - 6ms/step
# Epoch 234/500
# 15/15 - 0s - loss: 7.6214e-04 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 235/500
# 15/15 - 0s - loss: 7.6190e-04 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 236/500
# 15/15 - 0s - loss: 7.6166e-04 - val_loss: 0.0012 - 88ms/epoch - 6ms/step
# Epoch 237/500
# 15/15 - 0s - loss: 7.6143e-04 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 238/500
# 15/15 - 0s - loss: 7.6120e-04 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 239/500
# 15/15 - 0s - loss: 7.6097e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 240/500
# 15/15 - 0s - loss: 7.6075e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 241/500
# 15/15 - 0s - loss: 7.6053e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 242/500
# 15/15 - 0s - loss: 7.6031e-04 - val_loss: 0.0012 - 93ms/epoch - 6ms/step
# Epoch 243/500
# 15/15 - 0s - loss: 7.6009e-04 - val_loss: 0.0012 - 97ms/epoch - 6ms/step
# Epoch 244/500
# 15/15 - 0s - loss: 7.5988e-04 - val_loss: 0.0012 - 103ms/epoch - 7ms/step
# Epoch 245/500
# 15/15 - 0s - loss: 7.5967e-04 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 246/500
# 15/15 - 0s - loss: 7.5946e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 247/500
# 15/15 - 0s - loss: 7.5925e-04 - val_loss: 0.0012 - 81ms/epoch - 5ms/step
# Epoch 248/500
# 15/15 - 0s - loss: 7.5905e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 249/500
# 15/15 - 0s - loss: 7.5884e-04 - val_loss: 0.0012 - 83ms/epoch - 6ms/step
# Epoch 250/500
# 15/15 - 0s - loss: 7.5864e-04 - val_loss: 0.0012 - 82ms/epoch - 5ms/step
# Epoch 251/500
# 15/15 - 0s - loss: 7.5845e-04 - val_loss: 0.0012 - 81ms/epoch - 5ms/step
# Epoch 252/500
# 15/15 - 0s - loss: 7.5825e-04 - val_loss: 0.0012 - 86ms/epoch - 6ms/step
# Epoch 253/500
# 15/15 - 0s - loss: 7.5805e-04 - val_loss: 0.0012 - 77ms/epoch - 5ms/step
# Epoch 254/500
# 15/15 - 0s - loss: 7.5786e-04 - val_loss: 0.0012 - 82ms/epoch - 5ms/step
# Epoch 255/500
# 15/15 - 0s - loss: 7.5767e-04 - val_loss: 0.0012 - 86ms/epoch - 6ms/step
# Epoch 256/500
# 15/15 - 0s - loss: 7.5748e-04 - val_loss: 0.0012 - 86ms/epoch - 6ms/step
# Epoch 257/500
# 15/15 - 0s - loss: 7.5729e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 258/500
# 15/15 - 0s - loss: 7.5710e-04 - val_loss: 0.0012 - 89ms/epoch - 6ms/step
# Epoch 259/500
# 15/15 - 0s - loss: 7.5691e-04 - val_loss: 0.0012 - 92ms/epoch - 6ms/step
# Epoch 260/500
# 15/15 - 0s - loss: 7.5672e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 261/500
# 15/15 - 0s - loss: 7.5653e-04 - val_loss: 0.0012 - 97ms/epoch - 6ms/step
# Epoch 262/500
# 15/15 - 0s - loss: 7.5635e-04 - val_loss: 0.0012 - 93ms/epoch - 6ms/step
# Epoch 263/500
# 15/15 - 0s - loss: 7.5616e-04 - val_loss: 0.0012 - 101ms/epoch - 7ms/step
# Epoch 264/500
# 15/15 - 0s - loss: 7.5598e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 265/500
# 15/15 - 0s - loss: 7.5580e-04 - val_loss: 0.0012 - 97ms/epoch - 6ms/step
# Epoch 266/500
# 15/15 - 0s - loss: 7.5561e-04 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 267/500
# 15/15 - 0s - loss: 7.5543e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 268/500
# 15/15 - 0s - loss: 7.5525e-04 - val_loss: 0.0012 - 101ms/epoch - 7ms/step
# Epoch 269/500
# 15/15 - 0s - loss: 7.5506e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 270/500
# 15/15 - 0s - loss: 7.5488e-04 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 271/500
# 15/15 - 0s - loss: 7.5470e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 272/500
# 15/15 - 0s - loss: 7.5452e-04 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 273/500
# 15/15 - 0s - loss: 7.5433e-04 - val_loss: 0.0012 - 93ms/epoch - 6ms/step
# Epoch 274/500
# 15/15 - 0s - loss: 7.5415e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 275/500
# 15/15 - 0s - loss: 7.5397e-04 - val_loss: 0.0012 - 90ms/epoch - 6ms/step
# Epoch 276/500
# 15/15 - 0s - loss: 7.5379e-04 - val_loss: 0.0012 - 89ms/epoch - 6ms/step
# Epoch 277/500
# 15/15 - 0s - loss: 7.5360e-04 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 278/500
# 15/15 - 0s - loss: 7.5342e-04 - val_loss: 0.0012 - 89ms/epoch - 6ms/step
# Epoch 279/500
# 15/15 - 0s - loss: 7.5324e-04 - val_loss: 0.0012 - 93ms/epoch - 6ms/step
# Epoch 280/500
# 15/15 - 0s - loss: 7.5305e-04 - val_loss: 0.0012 - 97ms/epoch - 6ms/step
# Epoch 281/500
# 15/15 - 0s - loss: 7.5287e-04 - val_loss: 0.0012 - 97ms/epoch - 6ms/step
# Epoch 282/500
# 15/15 - 0s - loss: 7.5268e-04 - val_loss: 0.0012 - 106ms/epoch - 7ms/step
# Epoch 283/500
# 15/15 - 0s - loss: 7.5250e-04 - val_loss: 0.0012 - 115ms/epoch - 8ms/step
# Epoch 284/500
# 15/15 - 0s - loss: 7.5231e-04 - val_loss: 0.0012 - 258ms/epoch - 17ms/step
# Epoch 285/500
# 15/15 - 0s - loss: 7.5212e-04 - val_loss: 0.0012 - 147ms/epoch - 10ms/step
# Epoch 286/500
# 15/15 - 0s - loss: 7.5194e-04 - val_loss: 0.0012 - 117ms/epoch - 8ms/step
# Epoch 287/500
# 15/15 - 0s - loss: 7.5175e-04 - val_loss: 0.0012 - 111ms/epoch - 7ms/step
# Epoch 288/500
# 15/15 - 0s - loss: 7.5156e-04 - val_loss: 0.0012 - 152ms/epoch - 10ms/step
# Epoch 289/500
# 15/15 - 0s - loss: 7.5137e-04 - val_loss: 0.0012 - 160ms/epoch - 11ms/step
# Epoch 290/500
# 15/15 - 0s - loss: 7.5118e-04 - val_loss: 0.0012 - 132ms/epoch - 9ms/step
# Epoch 291/500
# 15/15 - 0s - loss: 7.5099e-04 - val_loss: 0.0012 - 133ms/epoch - 9ms/step
# Epoch 292/500
# 15/15 - 0s - loss: 7.5080e-04 - val_loss: 0.0012 - 157ms/epoch - 10ms/step
# Epoch 293/500
# 15/15 - 0s - loss: 7.5061e-04 - val_loss: 0.0012 - 148ms/epoch - 10ms/step
# Epoch 294/500
# 15/15 - 0s - loss: 7.5041e-04 - val_loss: 0.0012 - 130ms/epoch - 9ms/step
# Epoch 295/500
# 15/15 - 0s - loss: 7.5022e-04 - val_loss: 0.0012 - 136ms/epoch - 9ms/step
# Epoch 296/500
# 15/15 - 0s - loss: 7.5002e-04 - val_loss: 0.0012 - 125ms/epoch - 8ms/step
# Epoch 297/500
# 15/15 - 0s - loss: 7.4983e-04 - val_loss: 0.0012 - 121ms/epoch - 8ms/step
# Epoch 298/500
# 15/15 - 0s - loss: 7.4963e-04 - val_loss: 0.0012 - 138ms/epoch - 9ms/step
# Epoch 299/500
# 15/15 - 0s - loss: 7.4943e-04 - val_loss: 0.0012 - 127ms/epoch - 8ms/step
# Epoch 300/500
# 15/15 - 0s - loss: 7.4924e-04 - val_loss: 0.0012 - 148ms/epoch - 10ms/step
# Epoch 301/500
# 15/15 - 0s - loss: 7.4904e-04 - val_loss: 0.0012 - 129ms/epoch - 9ms/step
# Epoch 302/500
# 15/15 - 0s - loss: 7.4884e-04 - val_loss: 0.0012 - 113ms/epoch - 8ms/step
# Epoch 303/500
# 15/15 - 0s - loss: 7.4863e-04 - val_loss: 0.0012 - 109ms/epoch - 7ms/step
# Epoch 304/500
# 15/15 - 0s - loss: 7.4843e-04 - val_loss: 0.0012 - 103ms/epoch - 7ms/step
# Epoch 305/500
# 15/15 - 0s - loss: 7.4823e-04 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 306/500
# 15/15 - 0s - loss: 7.4802e-04 - val_loss: 0.0012 - 109ms/epoch - 7ms/step
# Epoch 307/500
# 15/15 - 0s - loss: 7.4782e-04 - val_loss: 0.0012 - 142ms/epoch - 9ms/step
# Epoch 308/500
# 15/15 - 0s - loss: 7.4761e-04 - val_loss: 0.0012 - 114ms/epoch - 8ms/step
# Epoch 309/500
# 15/15 - 0s - loss: 7.4741e-04 - val_loss: 0.0012 - 109ms/epoch - 7ms/step
# Epoch 310/500
# 15/15 - 0s - loss: 7.4720e-04 - val_loss: 0.0012 - 107ms/epoch - 7ms/step
# Epoch 311/500
# 15/15 - 0s - loss: 7.4699e-04 - val_loss: 0.0012 - 112ms/epoch - 7ms/step
# Epoch 312/500
# 15/15 - 0s - loss: 7.4678e-04 - val_loss: 0.0012 - 114ms/epoch - 8ms/step
# Epoch 313/500
# 15/15 - 0s - loss: 7.4657e-04 - val_loss: 0.0012 - 131ms/epoch - 9ms/step
# Epoch 314/500
# 15/15 - 0s - loss: 7.4635e-04 - val_loss: 0.0012 - 137ms/epoch - 9ms/step
# Epoch 315/500
# 15/15 - 0s - loss: 7.4614e-04 - val_loss: 0.0012 - 177ms/epoch - 12ms/step
# Epoch 316/500
# 15/15 - 0s - loss: 7.4593e-04 - val_loss: 0.0012 - 147ms/epoch - 10ms/step
# Epoch 317/500
# 15/15 - 0s - loss: 7.4571e-04 - val_loss: 0.0012 - 151ms/epoch - 10ms/step
# Epoch 318/500
# 15/15 - 0s - loss: 7.4549e-04 - val_loss: 0.0012 - 127ms/epoch - 8ms/step
# Epoch 319/500
# 15/15 - 0s - loss: 7.4528e-04 - val_loss: 0.0012 - 142ms/epoch - 9ms/step
# Epoch 320/500
# 15/15 - 0s - loss: 7.4506e-04 - val_loss: 0.0012 - 246ms/epoch - 16ms/step
# Epoch 321/500
# 15/15 - 0s - loss: 7.4484e-04 - val_loss: 0.0012 - 138ms/epoch - 9ms/step
# Epoch 322/500
# 15/15 - 0s - loss: 7.4462e-04 - val_loss: 0.0012 - 131ms/epoch - 9ms/step
# Epoch 323/500
# 15/15 - 0s - loss: 7.4440e-04 - val_loss: 0.0012 - 111ms/epoch - 7ms/step
# Epoch 324/500
# 15/15 - 0s - loss: 7.4417e-04 - val_loss: 0.0012 - 113ms/epoch - 8ms/step
# Epoch 325/500
# 15/15 - 0s - loss: 7.4395e-04 - val_loss: 0.0012 - 104ms/epoch - 7ms/step
# Epoch 326/500
# 15/15 - 0s - loss: 7.4372e-04 - val_loss: 0.0012 - 119ms/epoch - 8ms/step
# Epoch 327/500
# 15/15 - 0s - loss: 7.4350e-04 - val_loss: 0.0012 - 110ms/epoch - 7ms/step
# Epoch 328/500
# 15/15 - 0s - loss: 7.4327e-04 - val_loss: 0.0012 - 100ms/epoch - 7ms/step
# Epoch 329/500
# 15/15 - 0s - loss: 7.4304e-04 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 330/500
# 15/15 - 0s - loss: 7.4281e-04 - val_loss: 0.0012 - 101ms/epoch - 7ms/step
# Epoch 331/500
# 15/15 - 0s - loss: 7.4259e-04 - val_loss: 0.0012 - 118ms/epoch - 8ms/step
# Epoch 332/500
# 15/15 - 0s - loss: 7.4235e-04 - val_loss: 0.0012 - 98ms/epoch - 7ms/step
# Epoch 333/500
# 15/15 - 0s - loss: 7.4212e-04 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 334/500
# 15/15 - 0s - loss: 7.4189e-04 - val_loss: 0.0012 - 89ms/epoch - 6ms/step
# Epoch 335/500
# 15/15 - 0s - loss: 7.4166e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 336/500
# 15/15 - 0s - loss: 7.4142e-04 - val_loss: 0.0012 - 111ms/epoch - 7ms/step
# Epoch 337/500
# 15/15 - 0s - loss: 7.4119e-04 - val_loss: 0.0012 - 119ms/epoch - 8ms/step
# Epoch 338/500
# 15/15 - 0s - loss: 7.4095e-04 - val_loss: 0.0012 - 119ms/epoch - 8ms/step
# Epoch 339/500
# 15/15 - 0s - loss: 7.4071e-04 - val_loss: 0.0012 - 109ms/epoch - 7ms/step
# Epoch 340/500
# 15/15 - 0s - loss: 7.4047e-04 - val_loss: 0.0012 - 130ms/epoch - 9ms/step
# Epoch 341/500
# 15/15 - 0s - loss: 7.4023e-04 - val_loss: 0.0012 - 127ms/epoch - 8ms/step
# Epoch 342/500
# 15/15 - 0s - loss: 7.3999e-04 - val_loss: 0.0012 - 110ms/epoch - 7ms/step
# Epoch 343/500
# 15/15 - 0s - loss: 7.3975e-04 - val_loss: 0.0012 - 116ms/epoch - 8ms/step
# Epoch 344/500
# 15/15 - 0s - loss: 7.3950e-04 - val_loss: 0.0012 - 150ms/epoch - 10ms/step
# Epoch 345/500
# 15/15 - 0s - loss: 7.3927e-04 - val_loss: 0.0012 - 145ms/epoch - 10ms/step
# Epoch 346/500
# 15/15 - 0s - loss: 7.3902e-04 - val_loss: 0.0012 - 128ms/epoch - 9ms/step
# Epoch 347/500
# 15/15 - 0s - loss: 7.3878e-04 - val_loss: 0.0012 - 132ms/epoch - 9ms/step
# Epoch 348/500
# 15/15 - 0s - loss: 7.3852e-04 - val_loss: 0.0012 - 134ms/epoch - 9ms/step
# Epoch 349/500
# 15/15 - 0s - loss: 7.3829e-04 - val_loss: 0.0012 - 135ms/epoch - 9ms/step
# Epoch 350/500
# 15/15 - 0s - loss: 7.3802e-04 - val_loss: 0.0012 - 141ms/epoch - 9ms/step
# Epoch 351/500
# 15/15 - 0s - loss: 7.3779e-04 - val_loss: 0.0012 - 149ms/epoch - 10ms/step
# Epoch 352/500
# 15/15 - 0s - loss: 7.3752e-04 - val_loss: 0.0012 - 135ms/epoch - 9ms/step
# Epoch 353/500
# 15/15 - 0s - loss: 7.3729e-04 - val_loss: 0.0012 - 135ms/epoch - 9ms/step
# Epoch 354/500
# 15/15 - 0s - loss: 7.3702e-04 - val_loss: 0.0012 - 120ms/epoch - 8ms/step
# Epoch 355/500
# 15/15 - 0s - loss: 7.3679e-04 - val_loss: 0.0012 - 141ms/epoch - 9ms/step
# Epoch 356/500
# 15/15 - 0s - loss: 7.3651e-04 - val_loss: 0.0012 - 128ms/epoch - 9ms/step
# Epoch 357/500
# 15/15 - 0s - loss: 7.3629e-04 - val_loss: 0.0012 - 120ms/epoch - 8ms/step
# Epoch 358/500
# 15/15 - 0s - loss: 7.3599e-04 - val_loss: 0.0012 - 102ms/epoch - 7ms/step
# Epoch 359/500
# 15/15 - 0s - loss: 7.3579e-04 - val_loss: 0.0012 - 104ms/epoch - 7ms/step
# Epoch 360/500
# 15/15 - 0s - loss: 7.3546e-04 - val_loss: 0.0012 - 123ms/epoch - 8ms/step
# Epoch 361/500
# 15/15 - 0s - loss: 7.3529e-04 - val_loss: 0.0012 - 114ms/epoch - 8ms/step
# Epoch 362/500
# 15/15 - 0s - loss: 7.3493e-04 - val_loss: 0.0012 - 113ms/epoch - 8ms/step
# Epoch 363/500
# 15/15 - 0s - loss: 7.3479e-04 - val_loss: 0.0012 - 110ms/epoch - 7ms/step
# Epoch 364/500
# 15/15 - 0s - loss: 7.3439e-04 - val_loss: 0.0012 - 111ms/epoch - 7ms/step
# Epoch 365/500
# 15/15 - 0s - loss: 7.3430e-04 - val_loss: 0.0012 - 106ms/epoch - 7ms/step
# Epoch 366/500
# 15/15 - 0s - loss: 7.3383e-04 - val_loss: 0.0012 - 103ms/epoch - 7ms/step
# Epoch 367/500
# 15/15 - 0s - loss: 7.3383e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 368/500
# 15/15 - 0s - loss: 7.3325e-04 - val_loss: 0.0012 - 98ms/epoch - 7ms/step
# Epoch 369/500
# 15/15 - 0s - loss: 7.3337e-04 - val_loss: 0.0012 - 90ms/epoch - 6ms/step
# Epoch 370/500
# 15/15 - 0s - loss: 7.3263e-04 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 371/500
# 15/15 - 0s - loss: 7.3295e-04 - val_loss: 0.0012 - 89ms/epoch - 6ms/step
# Epoch 372/500
# 15/15 - 0s - loss: 7.3197e-04 - val_loss: 0.0012 - 82ms/epoch - 5ms/step
# Epoch 373/500
# 15/15 - 0s - loss: 7.3258e-04 - val_loss: 0.0012 - 83ms/epoch - 6ms/step
# Epoch 374/500
# 15/15 - 0s - loss: 7.3124e-04 - val_loss: 0.0012 - 89ms/epoch - 6ms/step
# Epoch 375/500
# 15/15 - 0s - loss: 7.3230e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 376/500
# 15/15 - 0s - loss: 7.3041e-04 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 377/500
# 15/15 - 0s - loss: 7.3216e-04 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 378/500
# 15/15 - 0s - loss: 7.2941e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 379/500
# 15/15 - 0s - loss: 7.3227e-04 - val_loss: 0.0012 - 98ms/epoch - 7ms/step
# Epoch 380/500
# 15/15 - 0s - loss: 7.2817e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 381/500
# 15/15 - 0s - loss: 7.3277e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 382/500
# 15/15 - 0s - loss: 7.2659e-04 - val_loss: 0.0012 - 86ms/epoch - 6ms/step
# Epoch 383/500
# 15/15 - 0s - loss: 7.3395e-04 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 384/500
# 15/15 - 0s - loss: 7.2453e-04 - val_loss: 0.0013 - 98ms/epoch - 7ms/step
# Epoch 385/500
# 15/15 - 0s - loss: 7.3633e-04 - val_loss: 0.0012 - 117ms/epoch - 8ms/step
# Epoch 386/500
# 15/15 - 0s - loss: 7.2194e-04 - val_loss: 0.0013 - 95ms/epoch - 6ms/step
# Epoch 387/500
# 15/15 - 0s - loss: 7.4082e-04 - val_loss: 0.0012 - 89ms/epoch - 6ms/step
# Epoch 388/500
# 15/15 - 0s - loss: 7.1903e-04 - val_loss: 0.0013 - 170ms/epoch - 11ms/step
# Epoch 389/500
# 15/15 - 0s - loss: 7.4889e-04 - val_loss: 0.0012 - 111ms/epoch - 7ms/step
# Epoch 390/500
# 15/15 - 0s - loss: 7.1679e-04 - val_loss: 0.0013 - 89ms/epoch - 6ms/step
# Epoch 391/500
# 15/15 - 0s - loss: 7.6221e-04 - val_loss: 0.0012 - 102ms/epoch - 7ms/step
# Epoch 392/500
# 15/15 - 0s - loss: 7.1715e-04 - val_loss: 0.0014 - 89ms/epoch - 6ms/step
# Epoch 393/500
# 15/15 - 0s - loss: 7.8053e-04 - val_loss: 0.0012 - 81ms/epoch - 5ms/step
# Epoch 394/500
# 15/15 - 0s - loss: 7.2148e-04 - val_loss: 0.0014 - 84ms/epoch - 6ms/step
# Epoch 395/500
# 15/15 - 0s - loss: 7.9772e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 396/500
# 15/15 - 0s - loss: 7.2702e-04 - val_loss: 0.0014 - 137ms/epoch - 9ms/step
# Epoch 397/500
# 15/15 - 0s - loss: 8.0229e-04 - val_loss: 0.0012 - 93ms/epoch - 6ms/step
# Epoch 398/500
# 15/15 - 0s - loss: 7.2774e-04 - val_loss: 0.0014 - 93ms/epoch - 6ms/step
# Epoch 399/500
# 15/15 - 0s - loss: 7.8950e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 400/500
# 15/15 - 0s - loss: 7.2261e-04 - val_loss: 0.0013 - 84ms/epoch - 6ms/step
# Epoch 401/500
# 15/15 - 0s - loss: 7.6849e-04 - val_loss: 0.0012 - 107ms/epoch - 7ms/step
# Epoch 402/500
# 15/15 - 0s - loss: 7.1664e-04 - val_loss: 0.0013 - 87ms/epoch - 6ms/step
# Epoch 403/500
# 15/15 - 0s - loss: 7.5025e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 404/500
# 15/15 - 0s - loss: 7.1322e-04 - val_loss: 0.0013 - 84ms/epoch - 6ms/step
# Epoch 405/500
# 15/15 - 0s - loss: 7.3816e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 406/500
# 15/15 - 0s - loss: 7.1212e-04 - val_loss: 0.0013 - 84ms/epoch - 6ms/step
# Epoch 407/500
# 15/15 - 0s - loss: 7.3088e-04 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 408/500
# 15/15 - 0s - loss: 7.1215e-04 - val_loss: 0.0013 - 77ms/epoch - 5ms/step
# Epoch 409/500
# 15/15 - 0s - loss: 7.2650e-04 - val_loss: 0.0012 - 83ms/epoch - 6ms/step
# Epoch 410/500
# 15/15 - 0s - loss: 7.1254e-04 - val_loss: 0.0013 - 68ms/epoch - 5ms/step
# Epoch 411/500
# 15/15 - 0s - loss: 7.2377e-04 - val_loss: 0.0012 - 102ms/epoch - 7ms/step
# Epoch 412/500
# 15/15 - 0s - loss: 7.1294e-04 - val_loss: 0.0013 - 87ms/epoch - 6ms/step
# Epoch 413/500
# 15/15 - 0s - loss: 7.2198e-04 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 414/500
# 15/15 - 0s - loss: 7.1324e-04 - val_loss: 0.0013 - 85ms/epoch - 6ms/step
# Epoch 415/500
# 15/15 - 0s - loss: 7.2072e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 416/500
# 15/15 - 0s - loss: 7.1343e-04 - val_loss: 0.0013 - 84ms/epoch - 6ms/step
# Epoch 417/500
# 15/15 - 0s - loss: 7.1981e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 418/500
# 15/15 - 0s - loss: 7.1350e-04 - val_loss: 0.0013 - 83ms/epoch - 6ms/step
# Epoch 419/500
# 15/15 - 0s - loss: 7.1911e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 420/500
# 15/15 - 0s - loss: 7.1349e-04 - val_loss: 0.0013 - 80ms/epoch - 5ms/step
# Epoch 421/500
# 15/15 - 0s - loss: 7.1855e-04 - val_loss: 0.0012 - 100ms/epoch - 7ms/step
# Epoch 422/500
# 15/15 - 0s - loss: 7.1339e-04 - val_loss: 0.0013 - 93ms/epoch - 6ms/step
# Epoch 423/500
# 15/15 - 0s - loss: 7.1809e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 424/500
# 15/15 - 0s - loss: 7.1322e-04 - val_loss: 0.0013 - 95ms/epoch - 6ms/step
# Epoch 425/500
# 15/15 - 0s - loss: 7.1772e-04 - val_loss: 0.0012 - 88ms/epoch - 6ms/step
# Epoch 426/500
# 15/15 - 0s - loss: 7.1298e-04 - val_loss: 0.0013 - 79ms/epoch - 5ms/step
# Epoch 427/500
# 15/15 - 0s - loss: 7.1740e-04 - val_loss: 0.0012 - 101ms/epoch - 7ms/step
# Epoch 428/500
# 15/15 - 0s - loss: 7.1269e-04 - val_loss: 0.0013 - 85ms/epoch - 6ms/step
# Epoch 429/500
# 15/15 - 0s - loss: 7.1714e-04 - val_loss: 0.0013 - 99ms/epoch - 7ms/step
# Epoch 430/500
# 15/15 - 0s - loss: 7.1234e-04 - val_loss: 0.0013 - 102ms/epoch - 7ms/step
# Epoch 431/500
# 15/15 - 0s - loss: 7.1693e-04 - val_loss: 0.0013 - 82ms/epoch - 5ms/step
# Epoch 432/500
# 15/15 - 0s - loss: 7.1193e-04 - val_loss: 0.0013 - 85ms/epoch - 6ms/step
# Epoch 433/500
# 15/15 - 0s - loss: 7.1678e-04 - val_loss: 0.0013 - 84ms/epoch - 6ms/step
# Epoch 434/500
# 15/15 - 0s - loss: 7.1146e-04 - val_loss: 0.0013 - 97ms/epoch - 6ms/step
# Epoch 435/500
# 15/15 - 0s - loss: 7.1669e-04 - val_loss: 0.0013 - 83ms/epoch - 6ms/step
# Epoch 436/500
# 15/15 - 0s - loss: 7.1091e-04 - val_loss: 0.0013 - 81ms/epoch - 5ms/step
# Epoch 437/500
# 15/15 - 0s - loss: 7.1670e-04 - val_loss: 0.0013 - 84ms/epoch - 6ms/step
# Epoch 438/500
# 15/15 - 0s - loss: 7.1028e-04 - val_loss: 0.0013 - 85ms/epoch - 6ms/step
# Epoch 439/500
# 15/15 - 0s - loss: 7.1681e-04 - val_loss: 0.0013 - 121ms/epoch - 8ms/step
# Epoch 440/500
# 15/15 - 0s - loss: 7.0955e-04 - val_loss: 0.0013 - 129ms/epoch - 9ms/step
# Epoch 441/500
# 15/15 - 0s - loss: 7.1707e-04 - val_loss: 0.0013 - 108ms/epoch - 7ms/step
# Epoch 442/500
# 15/15 - 0s - loss: 7.0870e-04 - val_loss: 0.0013 - 100ms/epoch - 7ms/step
# Epoch 443/500
# 15/15 - 0s - loss: 7.1752e-04 - val_loss: 0.0013 - 85ms/epoch - 6ms/step
# Epoch 444/500
# 15/15 - 0s - loss: 7.0772e-04 - val_loss: 0.0013 - 90ms/epoch - 6ms/step
# Epoch 445/500
# 15/15 - 0s - loss: 7.1825e-04 - val_loss: 0.0013 - 115ms/epoch - 8ms/step
# Epoch 446/500
# 15/15 - 0s - loss: 7.0659e-04 - val_loss: 0.0013 - 100ms/epoch - 7ms/step
# Epoch 447/500
# 15/15 - 0s - loss: 7.1936e-04 - val_loss: 0.0013 - 100ms/epoch - 7ms/step
# Epoch 448/500
# 15/15 - 0s - loss: 7.0528e-04 - val_loss: 0.0013 - 104ms/epoch - 7ms/step
# Epoch 449/500
# 15/15 - 0s - loss: 7.2100e-04 - val_loss: 0.0013 - 89ms/epoch - 6ms/step
# Epoch 450/500
# 15/15 - 0s - loss: 7.0380e-04 - val_loss: 0.0013 - 107ms/epoch - 7ms/step
# Epoch 451/500
# 15/15 - 0s - loss: 7.2339e-04 - val_loss: 0.0012 - 88ms/epoch - 6ms/step
# Epoch 452/500
# 15/15 - 0s - loss: 7.0220e-04 - val_loss: 0.0014 - 88ms/epoch - 6ms/step
# Epoch 453/500
# 15/15 - 0s - loss: 7.2680e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 454/500
# 15/15 - 0s - loss: 7.0061e-04 - val_loss: 0.0014 - 84ms/epoch - 6ms/step
# Epoch 455/500
# 15/15 - 0s - loss: 7.3158e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 456/500
# 15/15 - 0s - loss: 6.9926e-04 - val_loss: 0.0014 - 93ms/epoch - 6ms/step
# Epoch 457/500
# 15/15 - 0s - loss: 7.3797e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 458/500
# 15/15 - 0s - loss: 6.9853e-04 - val_loss: 0.0014 - 84ms/epoch - 6ms/step
# Epoch 459/500
# 15/15 - 0s - loss: 7.4587e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 460/500
# 15/15 - 0s - loss: 6.9876e-04 - val_loss: 0.0015 - 94ms/epoch - 6ms/step
# Epoch 461/500
# 15/15 - 0s - loss: 7.5430e-04 - val_loss: 0.0012 - 97ms/epoch - 6ms/step
# Epoch 462/500
# 15/15 - 0s - loss: 6.9992e-04 - val_loss: 0.0015 - 90ms/epoch - 6ms/step
# Epoch 463/500
# 15/15 - 0s - loss: 7.6103e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 464/500
# 15/15 - 0s - loss: 7.0124e-04 - val_loss: 0.0015 - 86ms/epoch - 6ms/step
# Epoch 465/500
# 15/15 - 0s - loss: 7.6328e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 466/500
# 15/15 - 0s - loss: 7.0151e-04 - val_loss: 0.0015 - 116ms/epoch - 8ms/step
# Epoch 467/500
# 15/15 - 0s - loss: 7.5958e-04 - val_loss: 0.0012 - 83ms/epoch - 6ms/step
# Epoch 468/500
# 15/15 - 0s - loss: 7.0022e-04 - val_loss: 0.0015 - 84ms/epoch - 6ms/step
# Epoch 469/500
# 15/15 - 0s - loss: 7.5122e-04 - val_loss: 0.0012 - 116ms/epoch - 8ms/step
# Epoch 470/500
# 15/15 - 0s - loss: 6.9798e-04 - val_loss: 0.0014 - 119ms/epoch - 8ms/step
# Epoch 471/500
# 15/15 - 0s - loss: 7.4118e-04 - val_loss: 0.0012 - 128ms/epoch - 9ms/step
# Epoch 472/500
# 15/15 - 0s - loss: 6.9586e-04 - val_loss: 0.0014 - 120ms/epoch - 8ms/step
# Epoch 473/500
# 15/15 - 0s - loss: 7.3197e-04 - val_loss: 0.0012 - 136ms/epoch - 9ms/step
# Epoch 474/500
# 15/15 - 0s - loss: 6.9443e-04 - val_loss: 0.0014 - 114ms/epoch - 8ms/step
# Epoch 475/500
# 15/15 - 0s - loss: 7.2464e-04 - val_loss: 0.0012 - 133ms/epoch - 9ms/step
# Epoch 476/500
# 15/15 - 0s - loss: 6.9370e-04 - val_loss: 0.0014 - 130ms/epoch - 9ms/step
# Epoch 477/500
# 15/15 - 0s - loss: 7.1922e-04 - val_loss: 0.0012 - 130ms/epoch - 9ms/step
# Epoch 478/500
# 15/15 - 0s - loss: 6.9345e-04 - val_loss: 0.0014 - 131ms/epoch - 9ms/step
# Epoch 479/500
# 15/15 - 0s - loss: 7.1533e-04 - val_loss: 0.0013 - 132ms/epoch - 9ms/step
# Epoch 480/500
# 15/15 - 0s - loss: 6.9343e-04 - val_loss: 0.0014 - 124ms/epoch - 8ms/step
# Epoch 481/500
# 15/15 - 0s - loss: 7.1256e-04 - val_loss: 0.0013 - 95ms/epoch - 6ms/step
# Epoch 482/500
# 15/15 - 0s - loss: 6.9349e-04 - val_loss: 0.0014 - 93ms/epoch - 6ms/step
# Epoch 483/500
# 15/15 - 0s - loss: 7.1058e-04 - val_loss: 0.0013 - 94ms/epoch - 6ms/step
# Epoch 484/500
# 15/15 - 0s - loss: 6.9353e-04 - val_loss: 0.0014 - 90ms/epoch - 6ms/step
# Epoch 485/500
# 15/15 - 0s - loss: 7.0916e-04 - val_loss: 0.0013 - 91ms/epoch - 6ms/step
# Epoch 486/500
# 15/15 - 0s - loss: 6.9351e-04 - val_loss: 0.0014 - 90ms/epoch - 6ms/step
# Epoch 487/500
# 15/15 - 0s - loss: 7.0816e-04 - val_loss: 0.0013 - 89ms/epoch - 6ms/step
# Epoch 488/500
# 15/15 - 0s - loss: 6.9341e-04 - val_loss: 0.0014 - 90ms/epoch - 6ms/step
# Epoch 489/500
# 15/15 - 0s - loss: 7.0747e-04 - val_loss: 0.0013 - 86ms/epoch - 6ms/step
# Epoch 490/500
# 15/15 - 0s - loss: 6.9322e-04 - val_loss: 0.0014 - 182ms/epoch - 12ms/step
# Epoch 491/500
# 15/15 - 0s - loss: 7.0705e-04 - val_loss: 0.0013 - 120ms/epoch - 8ms/step
# Epoch 492/500
# 15/15 - 0s - loss: 6.9294e-04 - val_loss: 0.0014 - 97ms/epoch - 6ms/step
# Epoch 493/500
# 15/15 - 0s - loss: 7.0685e-04 - val_loss: 0.0013 - 94ms/epoch - 6ms/step
# Epoch 494/500
# 15/15 - 0s - loss: 6.9255e-04 - val_loss: 0.0014 - 95ms/epoch - 6ms/step
# Epoch 495/500
# 15/15 - 0s - loss: 7.0688e-04 - val_loss: 0.0013 - 102ms/epoch - 7ms/step
# Epoch 496/500
# 15/15 - 0s - loss: 6.9206e-04 - val_loss: 0.0014 - 105ms/epoch - 7ms/step
# Epoch 497/500
# 15/15 - 0s - loss: 7.0713e-04 - val_loss: 0.0013 - 104ms/epoch - 7ms/step
# Epoch 498/500
# 15/15 - 0s - loss: 6.9146e-04 - val_loss: 0.0014 - 101ms/epoch - 7ms/step
# Epoch 499/500
# 15/15 - 0s - loss: 7.0764e-04 - val_loss: 0.0013 - 116ms/epoch - 8ms/step
# Epoch 500/500
# 15/15 - 0s - loss: 6.9075e-04 - val_loss: 0.0014 - 132ms/epoch - 9ms/step

# %% [markdown]
# ## Metrics ($DPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
phy = phys2(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 8/8 [==============================] - 1s 3ms/step
# (237, 3)
# (237, 10)
# Test RMSE: 17.188
# Test MAE: 11.974

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('San Juan Dengue Spread', fontsize=20)
plt.legend(fontsize=20)
plt.show()
