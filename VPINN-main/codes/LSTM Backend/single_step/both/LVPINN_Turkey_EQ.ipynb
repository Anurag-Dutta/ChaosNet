# %% [markdown]
# # Time Series Prediction with Lotka Volterra Equation Inspired Deep Learning ($LVPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-09 17:15:35

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Lotka Volterra Intermittency_

# %% [markdown]
# The `lotka_volterra_intermittency.dat` is generated from the Runge Kutta Method.

# %% [markdown]
# This feeds the model with the dynamics of the Lotka Volterra Equations

# %%
data = np.genfromtxt('datasets/lotka_volterra_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 1 # Daily Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 215.48740705
# 1        -1.078114e-02
# 2        -1.066358e-02
# 3        -1.054729e-02
# 4        -1.043229e-02
# 5        -1.031852e-02
#               ...
# 139867   -1.113760e-34
# 139868   -1.101721e-34
# 139869   -1.089814e-34
# 139870   -1.078034e-34
# 139871   -1.066382e-34
# Name: 1, Length: 139871, dtype: float64
# 2         1.175600e-04
# 3         1.162900e-04
# 4         1.150000e-04
# 5         1.137700e-04
# 6         1.125200e-04
#               ...
# 139867    1.217000e-36
# 139868    1.203900e-36
# 139869    1.190740e-36
# 139870    1.177950e-36
# 139871    1.165160e-36
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _TURKEY EARTHQUAKE_

# %%
data = pd.read_csv("datasets/eq.csv")
training_set = data.iloc[:, 4]
print(training_set)
# Out:
# 0       4.4
# 1       5.2
# 2       4.8
# 3       4.4
# 4       5.7
#        ...
# 6569    4.5
# 6570    4.0
# 6571    4.4
# 6572    4.1
# 6573    4.0
# Name: Magnitude, Length: 6574, dtype: float64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0        -1.078114e-02
# 1        -1.066358e-02
# 2        -1.054729e-02
# 3        -1.043229e-02
# 4        -1.031852e-02
#               ...
# 139866   -1.113760e-34
# 139867   -1.101721e-34
# 139868   -1.089814e-34
# 139869   -1.078034e-34
# 139870   -1.066382e-34
# Name: 1, Length: 139871, dtype: float64
# 0         1.175600e-04
# 1         1.162900e-04
# 2         1.150000e-04
# 3         1.137700e-04
# 4         1.125200e-04
#               ...
# 139865    1.217000e-36
# 139866    1.203900e-36
# 139867    1.190740e-36
# 139868    1.177950e-36
# 139869    1.165160e-36
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lotka Volterra Equation_)

# %% [markdown]
# _Parameters_: $\alpha=0.1, \beta=0.05, \gamma=1.1, \delta=0.1\\$

# %%
a=0.1
b=0.05
c=1.1
d=0.1
L = df.iloc[:, 2] - a*a*df.iloc[:, 0] + 2*a*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*d*(df.iloc[:,0]**2)*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - c*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10         4.4        5.2        4.8        4.4        5.7        4.3
# 11         5.2        4.8        4.4        5.7        4.3        4.0
# 12         4.8        4.4        5.7        4.3        4.0        4.8
# 13         4.4        5.7        4.3        4.0        4.8        5.2
# 14         5.7        4.3        4.0        4.8        5.2        5.1
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)   var2(t)   var3(t)
# 10        4.0        4.8        5.2        5.1      4.7 -0.009662  0.000105
# 11        4.8        5.2        5.1        4.7      4.6 -0.009556  0.000104
# 12        5.2        5.1        4.7        4.6      4.4 -0.009452  0.000103
# 13        5.1        4.7        4.6        4.4      4.7 -0.009349  0.000102
# 14        4.7        4.6        4.4        4.7      4.1 -0.009247  0.000101
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (6563, 13)
# (6563, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (5250, 1, 10) (5250, 3) (1313, 1, 10) (1313, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] - a*a*y_true[:, 0] + 2*a*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*d*(y_true[:,0]**2)*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - c*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))), (y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] - a*a*y_pred[:-2] + 2*a*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*d*(y_pred[:-2]**2)*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - c*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] - a*a*y_real[:-2] + 2*a*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*d*(y_real[:-2]**2)*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - c*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($LVPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square(y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 83/83 - 8s - loss: 0.0516 - val_loss: 0.0215 - 8s/epoch - 98ms/step
# Epoch 2/500
# 83/83 - 0s - loss: 0.0516 - val_loss: 0.0212 - 456ms/epoch - 5ms/step
# Epoch 3/500
# 83/83 - 0s - loss: 0.0507 - val_loss: 0.0205 - 479ms/epoch - 6ms/step
# Epoch 4/500
# 83/83 - 0s - loss: 0.0491 - val_loss: 0.0199 - 473ms/epoch - 6ms/step
# Epoch 5/500
# 83/83 - 0s - loss: 0.0476 - val_loss: 0.0193 - 453ms/epoch - 5ms/step
# Epoch 6/500
# 83/83 - 0s - loss: 0.0463 - val_loss: 0.0193 - 471ms/epoch - 6ms/step
# Epoch 7/500
# 83/83 - 1s - loss: 0.0461 - val_loss: 0.0289 - 531ms/epoch - 6ms/step
# Epoch 8/500
# 83/83 - 1s - loss: 0.1810 - val_loss: 0.0486 - 867ms/epoch - 10ms/step
# Epoch 9/500
# 83/83 - 1s - loss: 0.1114 - val_loss: 0.0486 - 525ms/epoch - 6ms/step
# Epoch 10/500
# 83/83 - 1s - loss: 0.1114 - val_loss: 0.0486 - 556ms/epoch - 7ms/step
# Epoch 11/500
# 83/83 - 1s - loss: 0.1114 - val_loss: 0.0486 - 624ms/epoch - 8ms/step
# Epoch 12/500
# 83/83 - 1s - loss: 0.1114 - val_loss: 0.0486 - 810ms/epoch - 10ms/step
# Epoch 13/500
# 83/83 - 1s - loss: 0.1114 - val_loss: 0.0486 - 788ms/epoch - 9ms/step
# Epoch 14/500
# 83/83 - 1s - loss: 0.1114 - val_loss: 0.0486 - 729ms/epoch - 9ms/step
# Epoch 15/500
# 83/83 - 1s - loss: 0.1114 - val_loss: 0.0486 - 741ms/epoch - 9ms/step
# Epoch 16/500
# 83/83 - 1s - loss: 0.1113 - val_loss: 0.0486 - 663ms/epoch - 8ms/step
# Epoch 17/500
# 83/83 - 1s - loss: 0.1113 - val_loss: 0.0486 - 696ms/epoch - 8ms/step
# Epoch 18/500
# 83/83 - 1s - loss: 0.1113 - val_loss: 0.0486 - 720ms/epoch - 9ms/step
# Epoch 19/500
# 83/83 - 1s - loss: 0.1113 - val_loss: 0.0486 - 717ms/epoch - 9ms/step
# Epoch 20/500
# 83/83 - 1s - loss: 0.1113 - val_loss: 0.0486 - 636ms/epoch - 8ms/step
# Epoch 21/500
# 83/83 - 1s - loss: 0.1113 - val_loss: 0.0486 - 619ms/epoch - 7ms/step
# Epoch 22/500
# 83/83 - 1s - loss: 0.1113 - val_loss: 0.0486 - 687ms/epoch - 8ms/step
# Epoch 23/500
# 83/83 - 1s - loss: 0.1113 - val_loss: 0.0485 - 750ms/epoch - 9ms/step
# Epoch 24/500
# 83/83 - 1s - loss: 0.1113 - val_loss: 0.0485 - 642ms/epoch - 8ms/step
# Epoch 25/500
# 83/83 - 1s - loss: 0.1113 - val_loss: 0.0485 - 671ms/epoch - 8ms/step
# Epoch 26/500
# 83/83 - 1s - loss: 0.1113 - val_loss: 0.0485 - 638ms/epoch - 8ms/step
# Epoch 27/500
# 83/83 - 1s - loss: 0.1113 - val_loss: 0.0485 - 629ms/epoch - 8ms/step
# Epoch 28/500
# 83/83 - 0s - loss: 0.1113 - val_loss: 0.0485 - 462ms/epoch - 6ms/step
# Epoch 29/500
# 83/83 - 1s - loss: 0.1112 - val_loss: 0.0485 - 541ms/epoch - 7ms/step
# Epoch 30/500
# 83/83 - 1s - loss: 0.1112 - val_loss: 0.0485 - 649ms/epoch - 8ms/step
# Epoch 31/500
# 83/83 - 1s - loss: 0.1112 - val_loss: 0.0485 - 1s/epoch - 16ms/step
# Epoch 32/500
# 83/83 - 1s - loss: 0.1112 - val_loss: 0.0485 - 1s/epoch - 13ms/step
# Epoch 33/500
# 83/83 - 1s - loss: 0.1112 - val_loss: 0.0485 - 1s/epoch - 12ms/step
# Epoch 34/500
# 83/83 - 1s - loss: 0.1112 - val_loss: 0.0485 - 760ms/epoch - 9ms/step
# Epoch 35/500
# 83/83 - 1s - loss: 0.1112 - val_loss: 0.0485 - 632ms/epoch - 8ms/step
# Epoch 36/500
# 83/83 - 1s - loss: 0.1112 - val_loss: 0.0485 - 670ms/epoch - 8ms/step
# Epoch 37/500
# 83/83 - 1s - loss: 0.1111 - val_loss: 0.0485 - 671ms/epoch - 8ms/step
# Epoch 38/500
# 83/83 - 1s - loss: 0.1111 - val_loss: 0.0485 - 532ms/epoch - 6ms/step
# Epoch 39/500
# 83/83 - 1s - loss: 0.1111 - val_loss: 0.0485 - 526ms/epoch - 6ms/step
# Epoch 40/500
# 83/83 - 1s - loss: 0.1111 - val_loss: 0.0484 - 562ms/epoch - 7ms/step
# Epoch 41/500
# 83/83 - 1s - loss: 0.1111 - val_loss: 0.0484 - 628ms/epoch - 8ms/step
# Epoch 42/500
# 83/83 - 1s - loss: 0.1111 - val_loss: 0.0484 - 506ms/epoch - 6ms/step
# Epoch 43/500
# 83/83 - 0s - loss: 0.1110 - val_loss: 0.0484 - 480ms/epoch - 6ms/step
# Epoch 44/500
# 83/83 - 0s - loss: 0.1110 - val_loss: 0.0484 - 472ms/epoch - 6ms/step
# Epoch 45/500
# 83/83 - 0s - loss: 0.1110 - val_loss: 0.0484 - 431ms/epoch - 5ms/step
# Epoch 46/500
# 83/83 - 0s - loss: 0.1110 - val_loss: 0.0484 - 406ms/epoch - 5ms/step
# Epoch 47/500
# 83/83 - 0s - loss: 0.1110 - val_loss: 0.0484 - 411ms/epoch - 5ms/step
# Epoch 48/500
# 83/83 - 1s - loss: 0.1109 - val_loss: 0.0484 - 542ms/epoch - 7ms/step
# Epoch 49/500
# 83/83 - 1s - loss: 0.1109 - val_loss: 0.0484 - 657ms/epoch - 8ms/step
# Epoch 50/500
# 83/83 - 1s - loss: 0.1109 - val_loss: 0.0483 - 954ms/epoch - 11ms/step
# Epoch 51/500
# 83/83 - 1s - loss: 0.1109 - val_loss: 0.0483 - 871ms/epoch - 10ms/step
# Epoch 52/500
# 83/83 - 1s - loss: 0.1108 - val_loss: 0.0483 - 748ms/epoch - 9ms/step
# Epoch 53/500
# 83/83 - 1s - loss: 0.1108 - val_loss: 0.0483 - 835ms/epoch - 10ms/step
# Epoch 54/500
# 83/83 - 1s - loss: 0.1108 - val_loss: 0.0483 - 590ms/epoch - 7ms/step
# Epoch 55/500
# 83/83 - 1s - loss: 0.1107 - val_loss: 0.0483 - 590ms/epoch - 7ms/step
# Epoch 56/500
# 83/83 - 1s - loss: 0.1107 - val_loss: 0.0483 - 613ms/epoch - 7ms/step
# Epoch 57/500
# 83/83 - 1s - loss: 0.1107 - val_loss: 0.0482 - 588ms/epoch - 7ms/step
# Epoch 58/500
# 83/83 - 1s - loss: 0.1106 - val_loss: 0.0482 - 618ms/epoch - 7ms/step
# Epoch 59/500
# 83/83 - 1s - loss: 0.1106 - val_loss: 0.0482 - 634ms/epoch - 8ms/step
# Epoch 60/500
# 83/83 - 1s - loss: 0.1106 - val_loss: 0.0482 - 504ms/epoch - 6ms/step
# Epoch 61/500
# 83/83 - 1s - loss: 0.1105 - val_loss: 0.0482 - 530ms/epoch - 6ms/step
# Epoch 62/500
# 83/83 - 1s - loss: 0.1105 - val_loss: 0.0482 - 736ms/epoch - 9ms/step
# Epoch 63/500
# 83/83 - 1s - loss: 0.1104 - val_loss: 0.0481 - 789ms/epoch - 10ms/step
# Epoch 64/500
# 83/83 - 1s - loss: 0.1104 - val_loss: 0.0481 - 768ms/epoch - 9ms/step
# Epoch 65/500
# 83/83 - 1s - loss: 0.1104 - val_loss: 0.0481 - 531ms/epoch - 6ms/step
# Epoch 66/500
# 83/83 - 1s - loss: 0.1103 - val_loss: 0.0481 - 573ms/epoch - 7ms/step
# Epoch 67/500
# 83/83 - 1s - loss: 0.1103 - val_loss: 0.0480 - 562ms/epoch - 7ms/step
# Epoch 68/500
# 83/83 - 0s - loss: 0.1102 - val_loss: 0.0480 - 411ms/epoch - 5ms/step
# Epoch 69/500
# 83/83 - 0s - loss: 0.1102 - val_loss: 0.0480 - 489ms/epoch - 6ms/step
# Epoch 70/500
# 83/83 - 0s - loss: 0.1101 - val_loss: 0.0480 - 420ms/epoch - 5ms/step
# Epoch 71/500
# 83/83 - 0s - loss: 0.1100 - val_loss: 0.0479 - 483ms/epoch - 6ms/step
# Epoch 72/500
# 83/83 - 1s - loss: 0.1100 - val_loss: 0.0479 - 831ms/epoch - 10ms/step
# Epoch 73/500
# 83/83 - 1s - loss: 0.1099 - val_loss: 0.0479 - 840ms/epoch - 10ms/step
# Epoch 74/500
# 83/83 - 1s - loss: 0.1098 - val_loss: 0.0478 - 695ms/epoch - 8ms/step
# Epoch 75/500
# 83/83 - 1s - loss: 0.1098 - val_loss: 0.0478 - 873ms/epoch - 11ms/step
# Epoch 76/500
# 83/83 - 0s - loss: 0.1097 - val_loss: 0.0478 - 474ms/epoch - 6ms/step
# Epoch 77/500
# 83/83 - 1s - loss: 0.1096 - val_loss: 0.0477 - 521ms/epoch - 6ms/step
# Epoch 78/500
# 83/83 - 1s - loss: 0.1095 - val_loss: 0.0477 - 511ms/epoch - 6ms/step
# Epoch 79/500
# 83/83 - 0s - loss: 0.1095 - val_loss: 0.0477 - 487ms/epoch - 6ms/step
# Epoch 80/500
# 83/83 - 0s - loss: 0.1094 - val_loss: 0.0476 - 406ms/epoch - 5ms/step
# Epoch 81/500
# 83/83 - 1s - loss: 0.1093 - val_loss: 0.0476 - 930ms/epoch - 11ms/step
# Epoch 82/500
# 83/83 - 1s - loss: 0.1092 - val_loss: 0.0475 - 1s/epoch - 13ms/step
# Epoch 83/500
# 83/83 - 1s - loss: 0.1091 - val_loss: 0.0475 - 914ms/epoch - 11ms/step
# Epoch 84/500
# 83/83 - 1s - loss: 0.1090 - val_loss: 0.0474 - 785ms/epoch - 9ms/step
# Epoch 85/500
# 83/83 - 1s - loss: 0.1089 - val_loss: 0.0474 - 752ms/epoch - 9ms/step
# Epoch 86/500
# 83/83 - 1s - loss: 0.1088 - val_loss: 0.0473 - 768ms/epoch - 9ms/step
# Epoch 87/500
# 83/83 - 1s - loss: 0.1087 - val_loss: 0.0473 - 625ms/epoch - 8ms/step
# Epoch 88/500
# 83/83 - 1s - loss: 0.1086 - val_loss: 0.0472 - 638ms/epoch - 8ms/step
# Epoch 89/500
# 83/83 - 1s - loss: 0.1084 - val_loss: 0.0472 - 615ms/epoch - 7ms/step
# Epoch 90/500
# 83/83 - 1s - loss: 0.1083 - val_loss: 0.0471 - 1s/epoch - 13ms/step
# Epoch 91/500
# 83/83 - 1s - loss: 0.1082 - val_loss: 0.0470 - 821ms/epoch - 10ms/step
# Epoch 92/500
# 83/83 - 1s - loss: 0.1080 - val_loss: 0.0470 - 781ms/epoch - 9ms/step
# Epoch 93/500
# 83/83 - 1s - loss: 0.1079 - val_loss: 0.0469 - 1s/epoch - 12ms/step
# Epoch 94/500
# 83/83 - 1s - loss: 0.1077 - val_loss: 0.0468 - 708ms/epoch - 9ms/step
# Epoch 95/500
# 83/83 - 1s - loss: 0.1076 - val_loss: 0.0468 - 578ms/epoch - 7ms/step
# Epoch 96/500
# 83/83 - 1s - loss: 0.1074 - val_loss: 0.0467 - 601ms/epoch - 7ms/step
# Epoch 97/500
# 83/83 - 1s - loss: 0.1073 - val_loss: 0.0466 - 866ms/epoch - 10ms/step
# Epoch 98/500
# 83/83 - 1s - loss: 0.1071 - val_loss: 0.0465 - 559ms/epoch - 7ms/step
# Epoch 99/500
# 83/83 - 1s - loss: 0.1069 - val_loss: 0.0464 - 667ms/epoch - 8ms/step
# Epoch 100/500
# 83/83 - 1s - loss: 0.1067 - val_loss: 0.0463 - 757ms/epoch - 9ms/step
# Epoch 101/500
# 83/83 - 1s - loss: 0.1065 - val_loss: 0.0462 - 1s/epoch - 12ms/step
# Epoch 102/500
# 83/83 - 2s - loss: 0.1063 - val_loss: 0.0461 - 2s/epoch - 24ms/step
# Epoch 103/500
# 83/83 - 1s - loss: 0.1061 - val_loss: 0.0460 - 933ms/epoch - 11ms/step
# Epoch 104/500
# 83/83 - 1s - loss: 0.1058 - val_loss: 0.0459 - 702ms/epoch - 8ms/step
# Epoch 105/500
# 83/83 - 1s - loss: 0.1056 - val_loss: 0.0458 - 646ms/epoch - 8ms/step
# Epoch 106/500
# 83/83 - 0s - loss: 0.1054 - val_loss: 0.0457 - 421ms/epoch - 5ms/step
# Epoch 107/500
# 83/83 - 0s - loss: 0.1051 - val_loss: 0.0456 - 465ms/epoch - 6ms/step
# Epoch 108/500
# 83/83 - 0s - loss: 0.1048 - val_loss: 0.0454 - 466ms/epoch - 6ms/step
# Epoch 109/500
# 83/83 - 0s - loss: 0.1046 - val_loss: 0.0453 - 449ms/epoch - 5ms/step
# Epoch 110/500
# 83/83 - 0s - loss: 0.1043 - val_loss: 0.0452 - 422ms/epoch - 5ms/step
# Epoch 111/500
# 83/83 - 0s - loss: 0.1040 - val_loss: 0.0450 - 479ms/epoch - 6ms/step
# Epoch 112/500
# 83/83 - 0s - loss: 0.1036 - val_loss: 0.0449 - 468ms/epoch - 6ms/step
# Epoch 113/500
# 83/83 - 0s - loss: 0.1033 - val_loss: 0.0447 - 420ms/epoch - 5ms/step
# Epoch 114/500
# 83/83 - 0s - loss: 0.1029 - val_loss: 0.0445 - 405ms/epoch - 5ms/step
# Epoch 115/500
# 83/83 - 0s - loss: 0.1026 - val_loss: 0.0444 - 406ms/epoch - 5ms/step
# Epoch 116/500
# 83/83 - 0s - loss: 0.1022 - val_loss: 0.0442 - 446ms/epoch - 5ms/step
# Epoch 117/500
# 83/83 - 0s - loss: 0.1017 - val_loss: 0.0440 - 446ms/epoch - 5ms/step
# Epoch 118/500
# 83/83 - 0s - loss: 0.1013 - val_loss: 0.0438 - 417ms/epoch - 5ms/step
# Epoch 119/500
# 83/83 - 0s - loss: 0.1008 - val_loss: 0.0436 - 398ms/epoch - 5ms/step
# Epoch 120/500
# 83/83 - 0s - loss: 0.1003 - val_loss: 0.0433 - 450ms/epoch - 5ms/step
# Epoch 121/500
# 83/83 - 0s - loss: 0.0997 - val_loss: 0.0431 - 447ms/epoch - 5ms/step
# Epoch 122/500
# 83/83 - 0s - loss: 0.0992 - val_loss: 0.0428 - 445ms/epoch - 5ms/step
# Epoch 123/500
# 83/83 - 0s - loss: 0.0985 - val_loss: 0.0425 - 440ms/epoch - 5ms/step
# Epoch 124/500
# 83/83 - 0s - loss: 0.0978 - val_loss: 0.0422 - 389ms/epoch - 5ms/step
# Epoch 125/500
# 83/83 - 0s - loss: 0.0970 - val_loss: 0.0419 - 416ms/epoch - 5ms/step
# Epoch 126/500
# 83/83 - 0s - loss: 0.0961 - val_loss: 0.0415 - 401ms/epoch - 5ms/step
# Epoch 127/500
# 83/83 - 0s - loss: 0.0952 - val_loss: 0.0411 - 459ms/epoch - 6ms/step
# Epoch 128/500
# 83/83 - 0s - loss: 0.0941 - val_loss: 0.0407 - 400ms/epoch - 5ms/step
# Epoch 129/500
# 83/83 - 1s - loss: 0.0929 - val_loss: 0.0401 - 542ms/epoch - 7ms/step
# Epoch 130/500
# 83/83 - 0s - loss: 0.0915 - val_loss: 0.0395 - 469ms/epoch - 6ms/step
# Epoch 131/500
# 83/83 - 0s - loss: 0.0898 - val_loss: 0.0389 - 443ms/epoch - 5ms/step
# Epoch 132/500
# 83/83 - 0s - loss: 0.0880 - val_loss: 0.0381 - 430ms/epoch - 5ms/step
# Epoch 133/500
# 83/83 - 0s - loss: 0.0858 - val_loss: 0.0371 - 448ms/epoch - 5ms/step
# Epoch 134/500
# 83/83 - 0s - loss: 0.0834 - val_loss: 0.0360 - 428ms/epoch - 5ms/step
# Epoch 135/500
# 83/83 - 0s - loss: 0.0805 - val_loss: 0.0347 - 399ms/epoch - 5ms/step
# Epoch 136/500
# 83/83 - 0s - loss: 0.0771 - val_loss: 0.0332 - 404ms/epoch - 5ms/step
# Epoch 137/500
# 83/83 - 0s - loss: 0.0733 - val_loss: 0.0315 - 400ms/epoch - 5ms/step
# Epoch 138/500
# 83/83 - 0s - loss: 0.0690 - val_loss: 0.0295 - 396ms/epoch - 5ms/step
# Epoch 139/500
# 83/83 - 0s - loss: 0.0642 - val_loss: 0.0273 - 414ms/epoch - 5ms/step
# Epoch 140/500
# 83/83 - 0s - loss: 0.0602 - val_loss: 0.0286 - 421ms/epoch - 5ms/step
# Epoch 141/500
# 83/83 - 0s - loss: 0.0627 - val_loss: 0.0274 - 443ms/epoch - 5ms/step
# Epoch 142/500
# 83/83 - 0s - loss: 0.0598 - val_loss: 0.0261 - 407ms/epoch - 5ms/step
# Epoch 143/500
# 83/83 - 0s - loss: 0.0616 - val_loss: 0.0342 - 407ms/epoch - 5ms/step
# Epoch 144/500
# 83/83 - 0s - loss: 0.0756 - val_loss: 0.0334 - 432ms/epoch - 5ms/step
# Epoch 145/500
# 83/83 - 0s - loss: 0.0737 - val_loss: 0.0326 - 460ms/epoch - 6ms/step
# Epoch 146/500
# 83/83 - 0s - loss: 0.0717 - val_loss: 0.0317 - 407ms/epoch - 5ms/step
# Epoch 147/500
# 83/83 - 0s - loss: 0.0697 - val_loss: 0.0308 - 393ms/epoch - 5ms/step
# Epoch 148/500
# 83/83 - 0s - loss: 0.0677 - val_loss: 0.0300 - 412ms/epoch - 5ms/step
# Epoch 149/500
# 83/83 - 0s - loss: 0.0657 - val_loss: 0.0291 - 430ms/epoch - 5ms/step
# Epoch 150/500
# 83/83 - 0s - loss: 0.0637 - val_loss: 0.0282 - 445ms/epoch - 5ms/step
# Epoch 151/500
# 83/83 - 0s - loss: 0.0617 - val_loss: 0.0274 - 413ms/epoch - 5ms/step
# Epoch 152/500
# 83/83 - 0s - loss: 0.0597 - val_loss: 0.0265 - 425ms/epoch - 5ms/step
# Epoch 153/500
# 83/83 - 0s - loss: 0.0577 - val_loss: 0.0256 - 443ms/epoch - 5ms/step
# Epoch 154/500
# 83/83 - 0s - loss: 0.0557 - val_loss: 0.0248 - 460ms/epoch - 6ms/step
# Epoch 155/500
# 83/83 - 0s - loss: 0.0538 - val_loss: 0.0239 - 469ms/epoch - 6ms/step
# Epoch 156/500
# 83/83 - 1s - loss: 0.0519 - val_loss: 0.0232 - 502ms/epoch - 6ms/step
# Epoch 157/500
# 83/83 - 1s - loss: 0.0500 - val_loss: 0.0223 - 504ms/epoch - 6ms/step
# Epoch 158/500
# 83/83 - 1s - loss: 0.0495 - val_loss: 0.0241 - 505ms/epoch - 6ms/step
# Epoch 159/500
# 83/83 - 1s - loss: 0.0521 - val_loss: 0.0232 - 506ms/epoch - 6ms/step
# Epoch 160/500
# 83/83 - 0s - loss: 0.0500 - val_loss: 0.0223 - 492ms/epoch - 6ms/step
# Epoch 161/500
# 83/83 - 1s - loss: 0.0481 - val_loss: 0.0214 - 519ms/epoch - 6ms/step
# Epoch 162/500
# 83/83 - 1s - loss: 0.0485 - val_loss: 0.0385 - 506ms/epoch - 6ms/step
# Epoch 163/500
# 83/83 - 0s - loss: 0.0858 - val_loss: 0.0428 - 461ms/epoch - 6ms/step
# Epoch 164/500
# 83/83 - 0s - loss: 0.0856 - val_loss: 0.0415 - 478ms/epoch - 6ms/step
# Epoch 165/500
# 83/83 - 0s - loss: 0.0829 - val_loss: 0.0403 - 441ms/epoch - 5ms/step
# Epoch 166/500
# 83/83 - 0s - loss: 0.0803 - val_loss: 0.0390 - 475ms/epoch - 6ms/step
# Epoch 167/500
# 83/83 - 0s - loss: 0.0778 - val_loss: 0.0378 - 473ms/epoch - 6ms/step
# Epoch 168/500
# 83/83 - 0s - loss: 0.0752 - val_loss: 0.0366 - 417ms/epoch - 5ms/step
# Epoch 169/500
# 83/83 - 0s - loss: 0.0727 - val_loss: 0.0354 - 414ms/epoch - 5ms/step
# Epoch 170/500
# 83/83 - 0s - loss: 0.0702 - val_loss: 0.0342 - 419ms/epoch - 5ms/step
# Epoch 171/500
# 83/83 - 0s - loss: 0.0677 - val_loss: 0.0330 - 416ms/epoch - 5ms/step
# Epoch 172/500
# 83/83 - 0s - loss: 0.0653 - val_loss: 0.0319 - 396ms/epoch - 5ms/step
# Epoch 173/500
# 83/83 - 0s - loss: 0.0629 - val_loss: 0.0307 - 396ms/epoch - 5ms/step
# Epoch 174/500
# 83/83 - 0s - loss: 0.0605 - val_loss: 0.0296 - 398ms/epoch - 5ms/step
# Epoch 175/500
# 83/83 - 0s - loss: 0.0582 - val_loss: 0.0285 - 412ms/epoch - 5ms/step
# Epoch 176/500
# 83/83 - 0s - loss: 0.0559 - val_loss: 0.0274 - 417ms/epoch - 5ms/step
# Epoch 177/500
# 83/83 - 0s - loss: 0.0537 - val_loss: 0.0264 - 453ms/epoch - 5ms/step
# Epoch 178/500
# 83/83 - 0s - loss: 0.0516 - val_loss: 0.0254 - 376ms/epoch - 5ms/step
# Epoch 179/500
# 83/83 - 1s - loss: 0.0495 - val_loss: 0.0244 - 508ms/epoch - 6ms/step
# Epoch 180/500
# 83/83 - 0s - loss: 0.1179 - val_loss: 0.1149 - 453ms/epoch - 5ms/step
# Epoch 181/500
# 83/83 - 0s - loss: 0.2162 - val_loss: 0.1141 - 399ms/epoch - 5ms/step
# Epoch 182/500
# 83/83 - 0s - loss: 0.2142 - val_loss: 0.1131 - 400ms/epoch - 5ms/step
# Epoch 183/500
# 83/83 - 0s - loss: 0.2120 - val_loss: 0.1121 - 472ms/epoch - 6ms/step
# Epoch 184/500
# 83/83 - 1s - loss: 0.2098 - val_loss: 0.1110 - 517ms/epoch - 6ms/step
# Epoch 185/500
# 83/83 - 0s - loss: 0.2076 - val_loss: 0.1100 - 434ms/epoch - 5ms/step
# Epoch 186/500
# 83/83 - 0s - loss: 0.2053 - val_loss: 0.1089 - 468ms/epoch - 6ms/step
# Epoch 187/500
# 83/83 - 0s - loss: 0.2030 - val_loss: 0.1078 - 414ms/epoch - 5ms/step
# Epoch 188/500
# 83/83 - 0s - loss: 0.2006 - val_loss: 0.1067 - 488ms/epoch - 6ms/step
# Epoch 189/500
# 83/83 - 0s - loss: 0.1983 - val_loss: 0.1056 - 447ms/epoch - 5ms/step
# Epoch 190/500
# 83/83 - 0s - loss: 0.1958 - val_loss: 0.1044 - 407ms/epoch - 5ms/step
# Epoch 191/500
# 83/83 - 0s - loss: 0.1934 - val_loss: 0.1033 - 417ms/epoch - 5ms/step
# Epoch 192/500
# 83/83 - 0s - loss: 0.1909 - val_loss: 0.1021 - 408ms/epoch - 5ms/step
# Epoch 193/500
# 83/83 - 1s - loss: 0.1883 - val_loss: 0.1009 - 578ms/epoch - 7ms/step
# Epoch 194/500
# 83/83 - 0s - loss: 0.1858 - val_loss: 0.0996 - 466ms/epoch - 6ms/step
# Epoch 195/500
# 83/83 - 0s - loss: 0.1832 - val_loss: 0.0984 - 489ms/epoch - 6ms/step
# Epoch 196/500
# 83/83 - 1s - loss: 0.1805 - val_loss: 0.0971 - 688ms/epoch - 8ms/step
# Epoch 197/500
# 83/83 - 1s - loss: 0.1779 - val_loss: 0.0958 - 693ms/epoch - 8ms/step
# Epoch 198/500
# 83/83 - 1s - loss: 0.1752 - val_loss: 0.0945 - 801ms/epoch - 10ms/step
# Epoch 199/500
# 83/83 - 1s - loss: 0.1724 - val_loss: 0.0932 - 894ms/epoch - 11ms/step
# Epoch 200/500
# 83/83 - 1s - loss: 0.1696 - val_loss: 0.0918 - 737ms/epoch - 9ms/step
# Epoch 201/500
# 83/83 - 1s - loss: 0.1668 - val_loss: 0.0904 - 775ms/epoch - 9ms/step
# Epoch 202/500
# 83/83 - 1s - loss: 0.1640 - val_loss: 0.0890 - 855ms/epoch - 10ms/step
# Epoch 203/500
# 83/83 - 1s - loss: 0.1611 - val_loss: 0.0876 - 852ms/epoch - 10ms/step
# Epoch 204/500
# 83/83 - 1s - loss: 0.1582 - val_loss: 0.0862 - 1s/epoch - 16ms/step
# Epoch 205/500
# 83/83 - 1s - loss: 0.1553 - val_loss: 0.0848 - 1s/epoch - 15ms/step
# Epoch 206/500
# 83/83 - 1s - loss: 0.1524 - val_loss: 0.0833 - 827ms/epoch - 10ms/step
# Epoch 207/500
# 83/83 - 1s - loss: 0.1494 - val_loss: 0.0818 - 565ms/epoch - 7ms/step
# Epoch 208/500
# 83/83 - 0s - loss: 0.1463 - val_loss: 0.0803 - 447ms/epoch - 5ms/step
# Epoch 209/500
# 83/83 - 0s - loss: 0.1433 - val_loss: 0.0787 - 420ms/epoch - 5ms/step
# Epoch 210/500
# 83/83 - 0s - loss: 0.1401 - val_loss: 0.0772 - 409ms/epoch - 5ms/step
# Epoch 211/500
# 83/83 - 0s - loss: 0.1370 - val_loss: 0.0756 - 470ms/epoch - 6ms/step
# Epoch 212/500
# 83/83 - 1s - loss: 0.1338 - val_loss: 0.0740 - 1s/epoch - 14ms/step
# Epoch 213/500
# 83/83 - 1s - loss: 0.1304 - val_loss: 0.0723 - 1s/epoch - 13ms/step
# Epoch 214/500
# 83/83 - 1s - loss: 0.1270 - val_loss: 0.0706 - 859ms/epoch - 10ms/step
# Epoch 215/500
# 83/83 - 0s - loss: 0.1236 - val_loss: 0.0688 - 471ms/epoch - 6ms/step
# Epoch 216/500
# 83/83 - 0s - loss: 0.1200 - val_loss: 0.0669 - 433ms/epoch - 5ms/step
# Epoch 217/500
# 83/83 - 0s - loss: 0.1160 - val_loss: 0.0649 - 417ms/epoch - 5ms/step
# Epoch 218/500
# 83/83 - 0s - loss: 0.1121 - val_loss: 0.0633 - 401ms/epoch - 5ms/step
# Epoch 219/500
# 83/83 - 0s - loss: 0.1215 - val_loss: 0.0711 - 381ms/epoch - 5ms/step
# Epoch 220/500
# 83/83 - 0s - loss: 0.1259 - val_loss: 0.0695 - 380ms/epoch - 5ms/step
# Epoch 221/500
# 83/83 - 0s - loss: 0.1229 - val_loss: 0.0679 - 380ms/epoch - 5ms/step
# Epoch 222/500
# 83/83 - 0s - loss: 0.1199 - val_loss: 0.0662 - 498ms/epoch - 6ms/step
# Epoch 223/500
# 83/83 - 0s - loss: 0.1169 - val_loss: 0.0646 - 475ms/epoch - 6ms/step
# Epoch 224/500
# 83/83 - 1s - loss: 0.1138 - val_loss: 0.0628 - 541ms/epoch - 7ms/step
# Epoch 225/500
# 83/83 - 0s - loss: 0.1106 - val_loss: 0.0611 - 416ms/epoch - 5ms/step
# Epoch 226/500
# 83/83 - 0s - loss: 0.1097 - val_loss: 0.0740 - 400ms/epoch - 5ms/step
# Epoch 227/500
# 83/83 - 0s - loss: 0.1347 - val_loss: 0.0749 - 416ms/epoch - 5ms/step
# Epoch 228/500
# 83/83 - 0s - loss: 0.1325 - val_loss: 0.0730 - 462ms/epoch - 6ms/step
# Epoch 229/500
# 83/83 - 0s - loss: 0.1290 - val_loss: 0.0710 - 444ms/epoch - 5ms/step
# Epoch 230/500
# 83/83 - 0s - loss: 0.1256 - val_loss: 0.0691 - 425ms/epoch - 5ms/step
# Epoch 231/500
# 83/83 - 0s - loss: 0.1221 - val_loss: 0.0672 - 456ms/epoch - 5ms/step
# Epoch 232/500
# 83/83 - 0s - loss: 0.1187 - val_loss: 0.0652 - 445ms/epoch - 5ms/step
# Epoch 233/500
# 83/83 - 0s - loss: 0.1152 - val_loss: 0.0633 - 417ms/epoch - 5ms/step
# Epoch 234/500
# 83/83 - 1s - loss: 0.1118 - val_loss: 0.0613 - 823ms/epoch - 10ms/step
# Epoch 235/500
# 83/83 - 1s - loss: 0.1083 - val_loss: 0.0594 - 1s/epoch - 16ms/step
# Epoch 236/500
# 83/83 - 1s - loss: 0.1049 - val_loss: 0.0575 - 1s/epoch - 14ms/step
# Epoch 237/500
# 83/83 - 1s - loss: 0.1015 - val_loss: 0.0556 - 1s/epoch - 14ms/step
# Epoch 238/500
# 83/83 - 1s - loss: 0.0981 - val_loss: 0.0537 - 1s/epoch - 17ms/step
# Epoch 239/500
# 83/83 - 1s - loss: 0.0947 - val_loss: 0.0518 - 979ms/epoch - 12ms/step
# Epoch 240/500
# 83/83 - 1s - loss: 0.0913 - val_loss: 0.0499 - 750ms/epoch - 9ms/step
# Epoch 241/500
# 83/83 - 1s - loss: 0.0880 - val_loss: 0.0480 - 873ms/epoch - 11ms/step
# Epoch 242/500
# 83/83 - 1s - loss: 0.0847 - val_loss: 0.0462 - 1s/epoch - 13ms/step
# Epoch 243/500
# 83/83 - 1s - loss: 0.0814 - val_loss: 0.0443 - 1s/epoch - 12ms/step
# Epoch 244/500
# 83/83 - 1s - loss: 0.0781 - val_loss: 0.0425 - 998ms/epoch - 12ms/step
# Epoch 245/500
# 83/83 - 1s - loss: 0.0749 - val_loss: 0.0407 - 990ms/epoch - 12ms/step
# Epoch 246/500
# 83/83 - 1s - loss: 0.0712 - val_loss: 0.0386 - 870ms/epoch - 10ms/step
# Epoch 247/500
# 83/83 - 1s - loss: 0.0675 - val_loss: 0.0364 - 754ms/epoch - 9ms/step
# Epoch 248/500
# 83/83 - 1s - loss: 0.0637 - val_loss: 0.0344 - 634ms/epoch - 8ms/step
# Epoch 249/500
# 83/83 - 0s - loss: 0.0602 - val_loss: 0.0327 - 459ms/epoch - 6ms/step
# Epoch 250/500
# 83/83 - 0s - loss: 0.1401 - val_loss: 0.1012 - 429ms/epoch - 5ms/step
# Epoch 251/500
# 83/83 - 0s - loss: 0.1708 - val_loss: 0.1013 - 437ms/epoch - 5ms/step
# Epoch 252/500
# 83/83 - 0s - loss: 0.1707 - val_loss: 0.1012 - 412ms/epoch - 5ms/step
# Epoch 253/500
# 83/83 - 0s - loss: 0.1705 - val_loss: 0.1011 - 419ms/epoch - 5ms/step
# Epoch 254/500
# 83/83 - 0s - loss: 0.1704 - val_loss: 0.1010 - 470ms/epoch - 6ms/step
# Epoch 255/500
# 83/83 - 0s - loss: 0.1702 - val_loss: 0.1010 - 391ms/epoch - 5ms/step
# Epoch 256/500
# 83/83 - 0s - loss: 0.1700 - val_loss: 0.1009 - 379ms/epoch - 5ms/step
# Epoch 257/500
# 83/83 - 0s - loss: 0.1698 - val_loss: 0.1008 - 375ms/epoch - 5ms/step
# Epoch 258/500
# 83/83 - 0s - loss: 0.1697 - val_loss: 0.1006 - 391ms/epoch - 5ms/step
# Epoch 259/500
# 83/83 - 0s - loss: 0.1695 - val_loss: 0.1005 - 406ms/epoch - 5ms/step
# Epoch 260/500
# 83/83 - 1s - loss: 0.1693 - val_loss: 0.1004 - 582ms/epoch - 7ms/step
# Epoch 261/500
# 83/83 - 0s - loss: 0.1691 - val_loss: 0.1003 - 469ms/epoch - 6ms/step
# Epoch 262/500
# 83/83 - 0s - loss: 0.1688 - val_loss: 0.1002 - 398ms/epoch - 5ms/step
# Epoch 263/500
# 83/83 - 0s - loss: 0.1686 - val_loss: 0.1001 - 369ms/epoch - 4ms/step
# Epoch 264/500
# 83/83 - 0s - loss: 0.1684 - val_loss: 0.0999 - 383ms/epoch - 5ms/step
# Epoch 265/500
# 83/83 - 0s - loss: 0.1682 - val_loss: 0.0998 - 408ms/epoch - 5ms/step
# Epoch 266/500
# 83/83 - 0s - loss: 0.1679 - val_loss: 0.0996 - 402ms/epoch - 5ms/step
# Epoch 267/500
# 83/83 - 0s - loss: 0.1676 - val_loss: 0.0995 - 412ms/epoch - 5ms/step
# Epoch 268/500
# 83/83 - 0s - loss: 0.1674 - val_loss: 0.0993 - 419ms/epoch - 5ms/step
# Epoch 269/500
# 83/83 - 0s - loss: 0.1671 - val_loss: 0.0992 - 418ms/epoch - 5ms/step
# Epoch 270/500
# 83/83 - 0s - loss: 0.1668 - val_loss: 0.0990 - 401ms/epoch - 5ms/step
# Epoch 271/500
# 83/83 - 0s - loss: 0.1665 - val_loss: 0.0989 - 417ms/epoch - 5ms/step
# Epoch 272/500
# 83/83 - 0s - loss: 0.1662 - val_loss: 0.0987 - 411ms/epoch - 5ms/step
# Epoch 273/500
# 83/83 - 0s - loss: 0.1659 - val_loss: 0.0985 - 379ms/epoch - 5ms/step
# Epoch 274/500
# 83/83 - 0s - loss: 0.1655 - val_loss: 0.0983 - 379ms/epoch - 5ms/step
# Epoch 275/500
# 83/83 - 0s - loss: 0.1652 - val_loss: 0.0981 - 389ms/epoch - 5ms/step
# Epoch 276/500
# 83/83 - 0s - loss: 0.1648 - val_loss: 0.0979 - 394ms/epoch - 5ms/step
# Epoch 277/500
# 83/83 - 0s - loss: 0.1645 - val_loss: 0.0977 - 399ms/epoch - 5ms/step
# Epoch 278/500
# 83/83 - 0s - loss: 0.1641 - val_loss: 0.0975 - 405ms/epoch - 5ms/step
# Epoch 279/500
# 83/83 - 0s - loss: 0.1637 - val_loss: 0.0972 - 427ms/epoch - 5ms/step
# Epoch 280/500
# 83/83 - 0s - loss: 0.1633 - val_loss: 0.0970 - 459ms/epoch - 6ms/step
# Epoch 281/500
# 83/83 - 0s - loss: 0.1628 - val_loss: 0.0968 - 391ms/epoch - 5ms/step
# Epoch 282/500
# 83/83 - 0s - loss: 0.1624 - val_loss: 0.0965 - 414ms/epoch - 5ms/step
# Epoch 283/500
# 83/83 - 0s - loss: 0.1619 - val_loss: 0.0963 - 406ms/epoch - 5ms/step
# Epoch 284/500
# 83/83 - 0s - loss: 0.1615 - val_loss: 0.0960 - 431ms/epoch - 5ms/step
# Epoch 285/500
# 83/83 - 0s - loss: 0.1610 - val_loss: 0.0957 - 419ms/epoch - 5ms/step
# Epoch 286/500
# 83/83 - 0s - loss: 0.1605 - val_loss: 0.0954 - 412ms/epoch - 5ms/step
# Epoch 287/500
# 83/83 - 0s - loss: 0.1600 - val_loss: 0.0951 - 480ms/epoch - 6ms/step
# Epoch 288/500
# 83/83 - 0s - loss: 0.1594 - val_loss: 0.0948 - 420ms/epoch - 5ms/step
# Epoch 289/500
# 83/83 - 0s - loss: 0.1589 - val_loss: 0.0945 - 420ms/epoch - 5ms/step
# Epoch 290/500
# 83/83 - 0s - loss: 0.1583 - val_loss: 0.0942 - 407ms/epoch - 5ms/step
# Epoch 291/500
# 83/83 - 0s - loss: 0.1577 - val_loss: 0.0938 - 434ms/epoch - 5ms/step
# Epoch 292/500
# 83/83 - 0s - loss: 0.1571 - val_loss: 0.0935 - 431ms/epoch - 5ms/step
# Epoch 293/500
# 83/83 - 0s - loss: 0.1564 - val_loss: 0.0931 - 405ms/epoch - 5ms/step
# Epoch 294/500
# 83/83 - 0s - loss: 0.1558 - val_loss: 0.0927 - 385ms/epoch - 5ms/step
# Epoch 295/500
# 83/83 - 0s - loss: 0.1551 - val_loss: 0.0923 - 379ms/epoch - 5ms/step
# Epoch 296/500
# 83/83 - 0s - loss: 0.1544 - val_loss: 0.0919 - 400ms/epoch - 5ms/step
# Epoch 297/500
# 83/83 - 0s - loss: 0.1537 - val_loss: 0.0915 - 408ms/epoch - 5ms/step
# Epoch 298/500
# 83/83 - 0s - loss: 0.1530 - val_loss: 0.0911 - 430ms/epoch - 5ms/step
# Epoch 299/500
# 83/83 - 0s - loss: 0.1522 - val_loss: 0.0907 - 455ms/epoch - 5ms/step
# Epoch 300/500
# 83/83 - 0s - loss: 0.1514 - val_loss: 0.0902 - 386ms/epoch - 5ms/step
# Epoch 301/500
# 83/83 - 0s - loss: 0.1506 - val_loss: 0.0898 - 363ms/epoch - 4ms/step
# Epoch 302/500
# 83/83 - 0s - loss: 0.1498 - val_loss: 0.0893 - 375ms/epoch - 5ms/step
# Epoch 303/500
# 83/83 - 0s - loss: 0.1490 - val_loss: 0.0888 - 411ms/epoch - 5ms/step
# Epoch 304/500
# 83/83 - 0s - loss: 0.1481 - val_loss: 0.0883 - 405ms/epoch - 5ms/step
# Epoch 305/500
# 83/83 - 0s - loss: 0.1472 - val_loss: 0.0878 - 405ms/epoch - 5ms/step
# Epoch 306/500
# 83/83 - 0s - loss: 0.1462 - val_loss: 0.0872 - 381ms/epoch - 5ms/step
# Epoch 307/500
# 83/83 - 0s - loss: 0.1453 - val_loss: 0.0867 - 416ms/epoch - 5ms/step
# Epoch 308/500
# 83/83 - 0s - loss: 0.1443 - val_loss: 0.0861 - 404ms/epoch - 5ms/step
# Epoch 309/500
# 83/83 - 0s - loss: 0.1433 - val_loss: 0.0855 - 404ms/epoch - 5ms/step
# Epoch 310/500
# 83/83 - 0s - loss: 0.1423 - val_loss: 0.0849 - 491ms/epoch - 6ms/step
# Epoch 311/500
# 83/83 - 0s - loss: 0.1412 - val_loss: 0.0843 - 396ms/epoch - 5ms/step
# Epoch 312/500
# 83/83 - 0s - loss: 0.1401 - val_loss: 0.0837 - 395ms/epoch - 5ms/step
# Epoch 313/500
# 83/83 - 0s - loss: 0.1390 - val_loss: 0.0830 - 389ms/epoch - 5ms/step
# Epoch 314/500
# 83/83 - 0s - loss: 0.1378 - val_loss: 0.0823 - 417ms/epoch - 5ms/step
# Epoch 315/500
# 83/83 - 0s - loss: 0.1367 - val_loss: 0.0817 - 385ms/epoch - 5ms/step
# Epoch 316/500
# 83/83 - 0s - loss: 0.1354 - val_loss: 0.0810 - 391ms/epoch - 5ms/step
# Epoch 317/500
# 83/83 - 0s - loss: 0.1342 - val_loss: 0.0802 - 399ms/epoch - 5ms/step
# Epoch 318/500
# 83/83 - 0s - loss: 0.1329 - val_loss: 0.0795 - 410ms/epoch - 5ms/step
# Epoch 319/500
# 83/83 - 0s - loss: 0.1316 - val_loss: 0.0787 - 402ms/epoch - 5ms/step
# Epoch 320/500
# 83/83 - 0s - loss: 0.1302 - val_loss: 0.0779 - 383ms/epoch - 5ms/step
# Epoch 321/500
# 83/83 - 0s - loss: 0.1289 - val_loss: 0.0771 - 395ms/epoch - 5ms/step
# Epoch 322/500
# 83/83 - 0s - loss: 0.1274 - val_loss: 0.0763 - 403ms/epoch - 5ms/step
# Epoch 323/500
# 83/83 - 0s - loss: 0.1260 - val_loss: 0.0754 - 398ms/epoch - 5ms/step
# Epoch 324/500
# 83/83 - 0s - loss: 0.1245 - val_loss: 0.0746 - 389ms/epoch - 5ms/step
# Epoch 325/500
# 83/83 - 0s - loss: 0.1229 - val_loss: 0.0736 - 391ms/epoch - 5ms/step
# Epoch 326/500
# 83/83 - 0s - loss: 0.1213 - val_loss: 0.0727 - 396ms/epoch - 5ms/step
# Epoch 327/500
# 83/83 - 0s - loss: 0.1197 - val_loss: 0.0717 - 420ms/epoch - 5ms/step
# Epoch 328/500
# 83/83 - 0s - loss: 0.1180 - val_loss: 0.0707 - 426ms/epoch - 5ms/step
# Epoch 329/500
# 83/83 - 1s - loss: 0.1162 - val_loss: 0.0697 - 558ms/epoch - 7ms/step
# Epoch 330/500
# 83/83 - 1s - loss: 0.1143 - val_loss: 0.0686 - 600ms/epoch - 7ms/step
# Epoch 331/500
# 83/83 - 0s - loss: 0.1124 - val_loss: 0.0675 - 446ms/epoch - 5ms/step
# Epoch 332/500
# 83/83 - 0s - loss: 0.1104 - val_loss: 0.0663 - 398ms/epoch - 5ms/step
# Epoch 333/500
# 83/83 - 0s - loss: 0.1082 - val_loss: 0.0651 - 417ms/epoch - 5ms/step
# Epoch 334/500
# 83/83 - 0s - loss: 0.1060 - val_loss: 0.0638 - 420ms/epoch - 5ms/step
# Epoch 335/500
# 83/83 - 0s - loss: 0.1035 - val_loss: 0.0624 - 410ms/epoch - 5ms/step
# Epoch 336/500
# 83/83 - 0s - loss: 0.1009 - val_loss: 0.0609 - 418ms/epoch - 5ms/step
# Epoch 337/500
# 83/83 - 0s - loss: 0.0981 - val_loss: 0.0593 - 464ms/epoch - 6ms/step
# Epoch 338/500
# 83/83 - 0s - loss: 0.0950 - val_loss: 0.0575 - 438ms/epoch - 5ms/step
# Epoch 339/500
# 83/83 - 0s - loss: 0.0915 - val_loss: 0.0555 - 419ms/epoch - 5ms/step
# Epoch 340/500
# 83/83 - 0s - loss: 0.1366 - val_loss: 0.0986 - 443ms/epoch - 5ms/step
# Epoch 341/500
# 83/83 - 0s - loss: 0.1709 - val_loss: 0.0969 - 452ms/epoch - 5ms/step
# Epoch 342/500
# 83/83 - 0s - loss: 0.1680 - val_loss: 0.0952 - 454ms/epoch - 5ms/step
# Epoch 343/500
# 83/83 - 0s - loss: 0.1650 - val_loss: 0.0934 - 489ms/epoch - 6ms/step
# Epoch 344/500
# 83/83 - 0s - loss: 0.1619 - val_loss: 0.0917 - 429ms/epoch - 5ms/step
# Epoch 345/500
# 83/83 - 0s - loss: 0.1588 - val_loss: 0.0899 - 466ms/epoch - 6ms/step
# Epoch 346/500
# 83/83 - 0s - loss: 0.1557 - val_loss: 0.0881 - 480ms/epoch - 6ms/step
# Epoch 347/500
# 83/83 - 0s - loss: 0.1526 - val_loss: 0.0863 - 450ms/epoch - 5ms/step
# Epoch 348/500
# 83/83 - 0s - loss: 0.1494 - val_loss: 0.0845 - 412ms/epoch - 5ms/step
# Epoch 349/500
# 83/83 - 0s - loss: 0.1462 - val_loss: 0.0826 - 452ms/epoch - 5ms/step
# Epoch 350/500
# 83/83 - 0s - loss: 0.1430 - val_loss: 0.0808 - 443ms/epoch - 5ms/step
# Epoch 351/500
# 83/83 - 0s - loss: 0.1398 - val_loss: 0.0789 - 427ms/epoch - 5ms/step
# Epoch 352/500
# 83/83 - 0s - loss: 0.1366 - val_loss: 0.0770 - 420ms/epoch - 5ms/step
# Epoch 353/500
# 83/83 - 0s - loss: 0.1333 - val_loss: 0.0752 - 422ms/epoch - 5ms/step
# Epoch 354/500
# 83/83 - 0s - loss: 0.1300 - val_loss: 0.0733 - 434ms/epoch - 5ms/step
# Epoch 355/500
# 83/83 - 0s - loss: 0.1268 - val_loss: 0.0714 - 458ms/epoch - 6ms/step
# Epoch 356/500
# 83/83 - 0s - loss: 0.1235 - val_loss: 0.0695 - 455ms/epoch - 5ms/step
# Epoch 357/500
# 83/83 - 0s - loss: 0.1202 - val_loss: 0.0676 - 439ms/epoch - 5ms/step
# Epoch 358/500
# 83/83 - 0s - loss: 0.1169 - val_loss: 0.0657 - 468ms/epoch - 6ms/step
# Epoch 359/500
# 83/83 - 1s - loss: 0.1136 - val_loss: 0.0638 - 624ms/epoch - 8ms/step
# Epoch 360/500
# 83/83 - 0s - loss: 0.1104 - val_loss: 0.0619 - 450ms/epoch - 5ms/step
# Epoch 361/500
# 83/83 - 0s - loss: 0.1071 - val_loss: 0.0600 - 417ms/epoch - 5ms/step
# Epoch 362/500
# 83/83 - 0s - loss: 0.1038 - val_loss: 0.0581 - 411ms/epoch - 5ms/step
# Epoch 363/500
# 83/83 - 0s - loss: 0.1006 - val_loss: 0.0562 - 437ms/epoch - 5ms/step
# Epoch 364/500
# 83/83 - 0s - loss: 0.0973 - val_loss: 0.0544 - 460ms/epoch - 6ms/step
# Epoch 365/500
# 83/83 - 0s - loss: 0.0941 - val_loss: 0.0525 - 425ms/epoch - 5ms/step
# Epoch 366/500
# 83/83 - 0s - loss: 0.0909 - val_loss: 0.0506 - 430ms/epoch - 5ms/step
# Epoch 367/500
# 83/83 - 0s - loss: 0.0877 - val_loss: 0.0488 - 465ms/epoch - 6ms/step
# Epoch 368/500
# 83/83 - 0s - loss: 0.0845 - val_loss: 0.0469 - 496ms/epoch - 6ms/step
# Epoch 369/500
# 83/83 - 0s - loss: 0.0813 - val_loss: 0.0451 - 408ms/epoch - 5ms/step
# Epoch 370/500
# 83/83 - 0s - loss: 0.0781 - val_loss: 0.0433 - 395ms/epoch - 5ms/step
# Epoch 371/500
# 83/83 - 0s - loss: 0.0749 - val_loss: 0.0414 - 411ms/epoch - 5ms/step
# Epoch 372/500
# 83/83 - 0s - loss: 0.0718 - val_loss: 0.0396 - 435ms/epoch - 5ms/step
# Epoch 373/500
# 83/83 - 0s - loss: 0.0686 - val_loss: 0.0378 - 448ms/epoch - 5ms/step
# Epoch 374/500
# 83/83 - 0s - loss: 0.0654 - val_loss: 0.0359 - 457ms/epoch - 6ms/step
# Epoch 375/500
# 83/83 - 0s - loss: 0.0622 - val_loss: 0.0342 - 478ms/epoch - 6ms/step
# Epoch 376/500
# 83/83 - 0s - loss: 0.0547 - val_loss: 0.0279 - 440ms/epoch - 5ms/step
# Epoch 377/500
# 83/83 - 0s - loss: 0.1305 - val_loss: 0.0927 - 440ms/epoch - 5ms/step
# Epoch 378/500
# 83/83 - 0s - loss: 0.1574 - val_loss: 0.0891 - 425ms/epoch - 5ms/step
# Epoch 379/500
# 83/83 - 0s - loss: 0.1514 - val_loss: 0.0857 - 431ms/epoch - 5ms/step
# Epoch 380/500
# 83/83 - 0s - loss: 0.1456 - val_loss: 0.0823 - 456ms/epoch - 5ms/step
# Epoch 381/500
# 83/83 - 0s - loss: 0.1398 - val_loss: 0.0790 - 454ms/epoch - 5ms/step
# Epoch 382/500
# 83/83 - 0s - loss: 0.1342 - val_loss: 0.0757 - 460ms/epoch - 6ms/step
# Epoch 383/500
# 83/83 - 0s - loss: 0.1287 - val_loss: 0.0725 - 426ms/epoch - 5ms/step
# Epoch 384/500
# 83/83 - 0s - loss: 0.1233 - val_loss: 0.0694 - 406ms/epoch - 5ms/step
# Epoch 385/500
# 83/83 - 0s - loss: 0.1181 - val_loss: 0.0664 - 439ms/epoch - 5ms/step
# Epoch 386/500
# 83/83 - 0s - loss: 0.1130 - val_loss: 0.0634 - 464ms/epoch - 6ms/step
# Epoch 387/500
# 83/83 - 0s - loss: 0.1080 - val_loss: 0.0606 - 433ms/epoch - 5ms/step
# Epoch 388/500
# 83/83 - 0s - loss: 0.1031 - val_loss: 0.0578 - 403ms/epoch - 5ms/step
# Epoch 389/500
# 83/83 - 0s - loss: 0.0984 - val_loss: 0.0550 - 477ms/epoch - 6ms/step
# Epoch 390/500
# 83/83 - 0s - loss: 0.0938 - val_loss: 0.0524 - 464ms/epoch - 6ms/step
# Epoch 391/500
# 83/83 - 0s - loss: 0.0894 - val_loss: 0.0498 - 451ms/epoch - 5ms/step
# Epoch 392/500
# 83/83 - 0s - loss: 0.0850 - val_loss: 0.0473 - 431ms/epoch - 5ms/step
# Epoch 393/500
# 83/83 - 0s - loss: 0.0809 - val_loss: 0.0449 - 435ms/epoch - 5ms/step
# Epoch 394/500
# 83/83 - 0s - loss: 0.0768 - val_loss: 0.0426 - 435ms/epoch - 5ms/step
# Epoch 395/500
# 83/83 - 0s - loss: 0.0729 - val_loss: 0.0404 - 448ms/epoch - 5ms/step
# Epoch 396/500
# 83/83 - 0s - loss: 0.0691 - val_loss: 0.0383 - 449ms/epoch - 5ms/step
# Epoch 397/500
# 83/83 - 0s - loss: 0.0659 - val_loss: 0.0370 - 415ms/epoch - 5ms/step
# Epoch 398/500
# 83/83 - 0s - loss: 0.0638 - val_loss: 0.0352 - 449ms/epoch - 5ms/step
# Epoch 399/500
# 83/83 - 0s - loss: 0.0689 - val_loss: 0.0391 - 475ms/epoch - 6ms/step
# Epoch 400/500
# 83/83 - 0s - loss: 0.0684 - val_loss: 0.0367 - 491ms/epoch - 6ms/step
# Epoch 401/500
# 83/83 - 0s - loss: 0.0644 - val_loss: 0.0344 - 454ms/epoch - 5ms/step
# Epoch 402/500
# 83/83 - 1s - loss: 0.0605 - val_loss: 0.0323 - 554ms/epoch - 7ms/step
# Epoch 403/500
# 83/83 - 0s - loss: 0.0568 - val_loss: 0.0302 - 454ms/epoch - 5ms/step
# Epoch 404/500
# 83/83 - 0s - loss: 0.0534 - val_loss: 0.0283 - 454ms/epoch - 5ms/step
# Epoch 405/500
# 83/83 - 0s - loss: 0.0670 - val_loss: 0.0396 - 421ms/epoch - 5ms/step
# Epoch 406/500
# 83/83 - 0s - loss: 0.0722 - val_loss: 0.0366 - 391ms/epoch - 5ms/step
# Epoch 407/500
# 83/83 - 0s - loss: 0.0670 - val_loss: 0.0338 - 408ms/epoch - 5ms/step
# Epoch 408/500
# 83/83 - 1s - loss: 0.0622 - val_loss: 0.0312 - 552ms/epoch - 7ms/step
# Epoch 409/500
# 83/83 - 0s - loss: 0.0577 - val_loss: 0.0295 - 456ms/epoch - 5ms/step
# Epoch 410/500
# 83/83 - 0s - loss: 0.0536 - val_loss: 0.0266 - 387ms/epoch - 5ms/step
# Epoch 411/500
# 83/83 - 0s - loss: 0.0531 - val_loss: 0.0555 - 402ms/epoch - 5ms/step
# Epoch 412/500
# 83/83 - 0s - loss: 0.1044 - val_loss: 0.0584 - 429ms/epoch - 5ms/step
# Epoch 413/500
# 83/83 - 0s - loss: 0.0995 - val_loss: 0.0543 - 429ms/epoch - 5ms/step
# Epoch 414/500
# 83/83 - 0s - loss: 0.0925 - val_loss: 0.0504 - 407ms/epoch - 5ms/step
# Epoch 415/500
# 83/83 - 0s - loss: 0.0860 - val_loss: 0.0469 - 425ms/epoch - 5ms/step
# Epoch 416/500
# 83/83 - 0s - loss: 0.0800 - val_loss: 0.0435 - 416ms/epoch - 5ms/step
# Epoch 417/500
# 83/83 - 0s - loss: 0.0743 - val_loss: 0.0404 - 432ms/epoch - 5ms/step
# Epoch 418/500
# 83/83 - 0s - loss: 0.0691 - val_loss: 0.0375 - 437ms/epoch - 5ms/step
# Epoch 419/500
# 83/83 - 0s - loss: 0.0642 - val_loss: 0.0348 - 478ms/epoch - 6ms/step
# Epoch 420/500
# 83/83 - 0s - loss: 0.0596 - val_loss: 0.0323 - 436ms/epoch - 5ms/step
# Epoch 421/500
# 83/83 - 0s - loss: 0.0571 - val_loss: 0.0313 - 449ms/epoch - 5ms/step
# Epoch 422/500
# 83/83 - 0s - loss: 0.0532 - val_loss: 0.0283 - 439ms/epoch - 5ms/step
# Epoch 423/500
# 83/83 - 0s - loss: 0.0389 - val_loss: 0.0108 - 427ms/epoch - 5ms/step
# Epoch 424/500
# 83/83 - 0s - loss: 0.0141 - val_loss: 0.0108 - 399ms/epoch - 5ms/step
# Epoch 425/500
# 83/83 - 0s - loss: 0.0141 - val_loss: 0.0108 - 403ms/epoch - 5ms/step
# Epoch 426/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0108 - 441ms/epoch - 5ms/step
# Epoch 427/500
# 83/83 - 1s - loss: 0.0140 - val_loss: 0.0108 - 614ms/epoch - 7ms/step
# Epoch 428/500
# 83/83 - 1s - loss: 0.0140 - val_loss: 0.0108 - 511ms/epoch - 6ms/step
# Epoch 429/500
# 83/83 - 1s - loss: 0.0140 - val_loss: 0.0108 - 529ms/epoch - 6ms/step
# Epoch 430/500
# 83/83 - 1s - loss: 0.0140 - val_loss: 0.0108 - 547ms/epoch - 7ms/step
# Epoch 431/500
# 83/83 - 1s - loss: 0.0140 - val_loss: 0.0108 - 510ms/epoch - 6ms/step
# Epoch 432/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0108 - 422ms/epoch - 5ms/step
# Epoch 433/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0108 - 477ms/epoch - 6ms/step
# Epoch 434/500
# 83/83 - 1s - loss: 0.0140 - val_loss: 0.0108 - 532ms/epoch - 6ms/step
# Epoch 435/500
# 83/83 - 1s - loss: 0.0140 - val_loss: 0.0108 - 601ms/epoch - 7ms/step
# Epoch 436/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0108 - 441ms/epoch - 5ms/step
# Epoch 437/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0108 - 435ms/epoch - 5ms/step
# Epoch 438/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0107 - 456ms/epoch - 5ms/step
# Epoch 439/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0107 - 459ms/epoch - 6ms/step
# Epoch 440/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0107 - 456ms/epoch - 5ms/step
# Epoch 441/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0107 - 477ms/epoch - 6ms/step
# Epoch 442/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0107 - 458ms/epoch - 6ms/step
# Epoch 443/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0107 - 452ms/epoch - 5ms/step
# Epoch 444/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0107 - 454ms/epoch - 5ms/step
# Epoch 445/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0107 - 401ms/epoch - 5ms/step
# Epoch 446/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0107 - 418ms/epoch - 5ms/step
# Epoch 447/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0107 - 456ms/epoch - 5ms/step
# Epoch 448/500
# 83/83 - 1s - loss: 0.0140 - val_loss: 0.0107 - 519ms/epoch - 6ms/step
# Epoch 449/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0107 - 422ms/epoch - 5ms/step
# Epoch 450/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0107 - 414ms/epoch - 5ms/step
# Epoch 451/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0107 - 455ms/epoch - 5ms/step
# Epoch 452/500
# 83/83 - 1s - loss: 0.0139 - val_loss: 0.0107 - 597ms/epoch - 7ms/step
# Epoch 453/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0107 - 459ms/epoch - 6ms/step
# Epoch 454/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0107 - 443ms/epoch - 5ms/step
# Epoch 455/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0107 - 446ms/epoch - 5ms/step
# Epoch 456/500
# 83/83 - 1s - loss: 0.0139 - val_loss: 0.0107 - 572ms/epoch - 7ms/step
# Epoch 457/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0107 - 465ms/epoch - 6ms/step
# Epoch 458/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0107 - 419ms/epoch - 5ms/step
# Epoch 459/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0107 - 499ms/epoch - 6ms/step
# Epoch 460/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0107 - 438ms/epoch - 5ms/step
# Epoch 461/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0107 - 439ms/epoch - 5ms/step
# Epoch 462/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0107 - 453ms/epoch - 5ms/step
# Epoch 463/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0106 - 473ms/epoch - 6ms/step
# Epoch 464/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0106 - 470ms/epoch - 6ms/step
# Epoch 465/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0106 - 472ms/epoch - 6ms/step
# Epoch 466/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0106 - 451ms/epoch - 5ms/step
# Epoch 467/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0106 - 452ms/epoch - 5ms/step
# Epoch 468/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0106 - 489ms/epoch - 6ms/step
# Epoch 469/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0106 - 489ms/epoch - 6ms/step
# Epoch 470/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0106 - 476ms/epoch - 6ms/step
# Epoch 471/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0106 - 485ms/epoch - 6ms/step
# Epoch 472/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0106 - 467ms/epoch - 6ms/step
# Epoch 473/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0106 - 457ms/epoch - 6ms/step
# Epoch 474/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0106 - 443ms/epoch - 5ms/step
# Epoch 475/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0106 - 445ms/epoch - 5ms/step
# Epoch 476/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0105 - 497ms/epoch - 6ms/step
# Epoch 477/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0105 - 478ms/epoch - 6ms/step
# Epoch 478/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0105 - 467ms/epoch - 6ms/step
# Epoch 479/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0105 - 426ms/epoch - 5ms/step
# Epoch 480/500
# 83/83 - 0s - loss: 0.0137 - val_loss: 0.0105 - 436ms/epoch - 5ms/step
# Epoch 481/500
# 83/83 - 0s - loss: 0.0137 - val_loss: 0.0105 - 434ms/epoch - 5ms/step
# Epoch 482/500
# 83/83 - 0s - loss: 0.0137 - val_loss: 0.0105 - 454ms/epoch - 5ms/step
# Epoch 483/500
# 83/83 - 0s - loss: 0.0137 - val_loss: 0.0105 - 463ms/epoch - 6ms/step
# Epoch 484/500
# 83/83 - 0s - loss: 0.0137 - val_loss: 0.0104 - 456ms/epoch - 5ms/step
# Epoch 485/500
# 83/83 - 0s - loss: 0.0137 - val_loss: 0.0104 - 455ms/epoch - 5ms/step
# Epoch 486/500
# 83/83 - 0s - loss: 0.0137 - val_loss: 0.0104 - 462ms/epoch - 6ms/step
# Epoch 487/500
# 83/83 - 0s - loss: 0.0137 - val_loss: 0.0104 - 456ms/epoch - 5ms/step
# Epoch 488/500
# 83/83 - 0s - loss: 0.0136 - val_loss: 0.0104 - 458ms/epoch - 6ms/step
# Epoch 489/500
# 83/83 - 0s - loss: 0.0136 - val_loss: 0.0104 - 460ms/epoch - 6ms/step
# Epoch 490/500
# 83/83 - 0s - loss: 0.0136 - val_loss: 0.0104 - 466ms/epoch - 6ms/step
# Epoch 491/500
# 83/83 - 0s - loss: 0.0136 - val_loss: 0.0103 - 453ms/epoch - 5ms/step
# Epoch 492/500
# 83/83 - 0s - loss: 0.0136 - val_loss: 0.0103 - 437ms/epoch - 5ms/step
# Epoch 493/500
# 83/83 - 0s - loss: 0.0136 - val_loss: 0.0103 - 434ms/epoch - 5ms/step
# Epoch 494/500
# 83/83 - 0s - loss: 0.0135 - val_loss: 0.0103 - 438ms/epoch - 5ms/step
# Epoch 495/500
# 83/83 - 0s - loss: 0.0135 - val_loss: 0.0103 - 443ms/epoch - 5ms/step
# Epoch 496/500
# 83/83 - 0s - loss: 0.0135 - val_loss: 0.0102 - 465ms/epoch - 6ms/step
# Epoch 497/500
# 83/83 - 1s - loss: 0.0135 - val_loss: 0.0102 - 509ms/epoch - 6ms/step
# Epoch 498/500
# 83/83 - 0s - loss: 0.0135 - val_loss: 0.0102 - 459ms/epoch - 6ms/step
# Epoch 499/500
# 83/83 - 1s - loss: 0.0134 - val_loss: 0.0102 - 502ms/epoch - 6ms/step
# Epoch 500/500
# 83/83 - 0s - loss: 0.0134 - val_loss: 0.0101 - 465ms/epoch - 6ms/step

# %% [markdown]
# ## Metrics ($LVPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
phy = phys2(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 42/42 [==============================] - 1s 3ms/step
# (1313, 3)
# (1313, 10)
# Test RMSE: 0.393
# Test MAE: 0.309

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('Turkey Seismic Waves', fontsize=20)
plt.legend(fontsize=20)
plt.show()
