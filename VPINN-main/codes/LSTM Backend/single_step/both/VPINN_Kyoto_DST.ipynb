# %% [markdown]
# # Time Series Prediction with Van der Pol Oscillator Inspired Deep Learning ($VPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-07 19:34:22

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Van der Pol intermittancy_

# %% [markdown]
# The `van_der_pol_intermittency.dat` is generated from the Runge Kutta Method.

# %% [markdown]
# This feeds the model with the dynamics of the Van der Pol Oscillator

# %%
data = np.genfromtxt('datasets/van_der_pol_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 0.0416 # Hourly Data (1/24)
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 1.0
# 1        -0.002404
# 2        -0.004904
# 3        -0.007503
# 4        -0.010205
# 5        -0.013011
#             ...
# 139867    0.111375
# 139868    0.111262
# 139869    0.111150
# 139870    0.111037
# 139871    0.110924
# Name: 1, Length: 139871, dtype: float64
# 2        -0.060096
# 3        -0.062483
# 4        -0.064944
# 5        -0.067464
# 6        -0.070047
#             ...
# 139867   -0.002699
# 139868   -0.002710
# 139869   -0.002710
# 139870   -0.002710
# 139871   -0.002722
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _KYOTO DST_

# %%
data = pd.read_csv("datasets/dst.csv")
training_set = data.iloc[:, 1]
print(training_set)
# Out:
# 0         -7
# 1        -10
# 2        -10
# 3         -6
# 4         -2
#           ..
# 139867   -16
# 139868   -14
# 139869   -14
# 139870   -15
# 139871   -14
# Name: dst, Length: 139872, dtype: int64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0        -0.002404
# 1        -0.004904
# 2        -0.007503
# 3        -0.010205
# 4        -0.013011
#             ...
# 139866    0.111375
# 139867    0.111262
# 139868    0.111150
# 139869    0.111037
# 139870    0.110924
# Name: 1, Length: 139871, dtype: float64
# 0        -0.060096
# 1        -0.062483
# 2        -0.064944
# 3        -0.067464
# 4        -0.070047
#             ...
# 139865   -0.002699
# 139866   -0.002710
# 139867   -0.002710
# 139868   -0.002710
# 139869   -0.002722
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Van der Pol Oscillator_)

# %% [markdown]
# _Parameters_: $\mu=4\\$
# $\frac{dx}{dt} = \mu(x-\frac{x^3}{3}-y)\\
# \frac{dy}{dt} = \frac{x}{\mu}\\$

# %%
mu = 4
L = df.iloc[:, 2] - mu * (df.iloc[:, 1] - (df.iloc[:, 0]**2 * df.iloc[:, 1]) - (1/mu) * df.iloc[:, 0])
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10        -7.0      -10.0      -10.0       -6.0       -2.0        3.0
# 11       -10.0      -10.0       -6.0       -2.0        3.0        5.0
# 12       -10.0       -6.0       -2.0        3.0        5.0        5.0
# 13        -6.0       -2.0        3.0        5.0        5.0        3.0
# 14        -2.0        3.0        5.0        5.0        3.0        1.0
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)   var2(t)   var3(t)
# 10        5.0        5.0        3.0        1.0      1.0 -0.032117 -0.085371
# 11        5.0        3.0        1.0        1.0      2.0 -0.035669 -0.087613
# 12        3.0        1.0        1.0        2.0      2.0 -0.039313 -0.089676
# 13        1.0        1.0        2.0        2.0      3.0 -0.043044 -0.091479
# 14        1.0        2.0        2.0        3.0      3.0 -0.046849 -0.092987
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (139860, 13)
# (139860, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (111888, 1, 10) (111888, 3) (27972, 1, 10) (27972, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
mu = tf.Variable(4, name="mu", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error(y_true[:, 2] - mu * (y_true[:, 1] - (y_true[:, 0]**2 * y_true[:, 1]) - (1/mu) * y_true[:, 0]), y_pred[:, 2] - mu * (y_pred[:, 1] - (y_pred[:, 0]**2 * y_pred[:, 1]) - (1/mu) * y_pred[:, 0]))


def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] - mu * ((y_pred[1:-1]-y_pred[:-2]) - (y_pred[:-2]**2 * (y_pred[1:-1]-y_pred[:-2])) - (1/mu) * y_pred[:-2])
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] - mu * ((y_real[1:-1]-y_real[:-2]) - (y_real[:-2]**2 * (y_real[1:-1]-y_real[:-2])) - (1/mu) * y_real[:-2])
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($VPINN$)

# %%
mu = tf.Variable(4, name="mu", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square(
        y_pred[:, 2] - mu * (y_pred[:, 1] - (y_pred[:, 0]**2 * y_pred[:, 1]) - (1/mu) * y_pred[:, 0]))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 1749/1749 - 21s - loss: 0.0052 - val_loss: 1.4655e-04 - 21s/epoch - 12ms/step
# Epoch 2/500
# 1749/1749 - 9s - loss: 3.4908e-04 - val_loss: 1.0029e-04 - 9s/epoch - 5ms/step
# Epoch 3/500
# 1749/1749 - 15s - loss: 2.4562e-04 - val_loss: 1.4867e-04 - 15s/epoch - 9ms/step
# Epoch 4/500
# 1749/1749 - 13s - loss: 2.0536e-04 - val_loss: 1.1132e-04 - 13s/epoch - 8ms/step
# Epoch 5/500
# 1749/1749 - 13s - loss: 1.6882e-04 - val_loss: 7.0136e-05 - 13s/epoch - 7ms/step
# Epoch 6/500
# 1749/1749 - 25s - loss: 1.4489e-04 - val_loss: 5.4754e-05 - 25s/epoch - 14ms/step
# Epoch 7/500
# 1749/1749 - 12s - loss: 1.3123e-04 - val_loss: 5.0888e-05 - 12s/epoch - 7ms/step
# Epoch 8/500
# 1749/1749 - 8s - loss: 1.2261e-04 - val_loss: 4.5815e-05 - 8s/epoch - 5ms/step
# Epoch 9/500
# 1749/1749 - 7s - loss: 1.1685e-04 - val_loss: 4.3021e-05 - 7s/epoch - 4ms/step
# Epoch 10/500
# 1749/1749 - 9s - loss: 1.1285e-04 - val_loss: 4.0990e-05 - 9s/epoch - 5ms/step
# Epoch 11/500
# 1749/1749 - 7s - loss: 1.1011e-04 - val_loss: 3.9723e-05 - 7s/epoch - 4ms/step
# Epoch 12/500
# 1749/1749 - 9s - loss: 1.0815e-04 - val_loss: 3.9000e-05 - 9s/epoch - 5ms/step
# Epoch 13/500
# 1749/1749 - 8s - loss: 1.0667e-04 - val_loss: 3.8603e-05 - 8s/epoch - 5ms/step
# Epoch 14/500
# 1749/1749 - 9s - loss: 1.0551e-04 - val_loss: 3.8429e-05 - 9s/epoch - 5ms/step
# Epoch 15/500
# 1749/1749 - 9s - loss: 1.0456e-04 - val_loss: 3.8430e-05 - 9s/epoch - 5ms/step
# Epoch 16/500
# 1749/1749 - 8s - loss: 1.0379e-04 - val_loss: 3.8604e-05 - 8s/epoch - 5ms/step
# Epoch 17/500
# 1749/1749 - 8s - loss: 1.0315e-04 - val_loss: 3.8927e-05 - 8s/epoch - 5ms/step
# Epoch 18/500
# 1749/1749 - 8s - loss: 1.0259e-04 - val_loss: 3.9343e-05 - 8s/epoch - 5ms/step
# Epoch 19/500
# 1749/1749 - 9s - loss: 1.0208e-04 - val_loss: 3.9780e-05 - 9s/epoch - 5ms/step
# Epoch 20/500
# 1749/1749 - 9s - loss: 1.0162e-04 - val_loss: 4.0211e-05 - 9s/epoch - 5ms/step
# Epoch 21/500
# 1749/1749 - 9s - loss: 1.0119e-04 - val_loss: 4.0596e-05 - 9s/epoch - 5ms/step
# Epoch 22/500
# 1749/1749 - 9s - loss: 1.0078e-04 - val_loss: 4.0909e-05 - 9s/epoch - 5ms/step
# Epoch 23/500
# 1749/1749 - 9s - loss: 1.0040e-04 - val_loss: 4.1148e-05 - 9s/epoch - 5ms/step
# Epoch 24/500
# 1749/1749 - 9s - loss: 1.0004e-04 - val_loss: 4.1329e-05 - 9s/epoch - 5ms/step
# Epoch 25/500
# 1749/1749 - 12s - loss: 9.9687e-05 - val_loss: 4.1469e-05 - 12s/epoch - 7ms/step
# Epoch 26/500
# 1749/1749 - 12s - loss: 9.9353e-05 - val_loss: 4.1575e-05 - 12s/epoch - 7ms/step
# Epoch 27/500
# 1749/1749 - 11s - loss: 9.9032e-05 - val_loss: 4.1655e-05 - 11s/epoch - 6ms/step
# Epoch 28/500
# 1749/1749 - 10s - loss: 9.8723e-05 - val_loss: 4.1711e-05 - 10s/epoch - 6ms/step
# Epoch 29/500
# 1749/1749 - 10s - loss: 9.8426e-05 - val_loss: 4.1745e-05 - 10s/epoch - 6ms/step
# Epoch 30/500
# 1749/1749 - 10s - loss: 9.8139e-05 - val_loss: 4.1761e-05 - 10s/epoch - 6ms/step
# Epoch 31/500
# 1749/1749 - 10s - loss: 9.7862e-05 - val_loss: 4.1766e-05 - 10s/epoch - 6ms/step
# Epoch 32/500
# 1749/1749 - 9s - loss: 9.7596e-05 - val_loss: 4.1764e-05 - 9s/epoch - 5ms/step
# Epoch 33/500
# 1749/1749 - 10s - loss: 9.7341e-05 - val_loss: 4.1753e-05 - 10s/epoch - 5ms/step
# Epoch 34/500
# 1749/1749 - 9s - loss: 9.7099e-05 - val_loss: 4.1734e-05 - 9s/epoch - 5ms/step
# Epoch 35/500
# 1749/1749 - 9s - loss: 9.6869e-05 - val_loss: 4.1704e-05 - 9s/epoch - 5ms/step
# Epoch 36/500
# 1749/1749 - 9s - loss: 9.6651e-05 - val_loss: 4.1661e-05 - 9s/epoch - 5ms/step
# Epoch 37/500
# 1749/1749 - 9s - loss: 9.6445e-05 - val_loss: 4.1604e-05 - 9s/epoch - 5ms/step
# Epoch 38/500
# 1749/1749 - 9s - loss: 9.6251e-05 - val_loss: 4.1529e-05 - 9s/epoch - 5ms/step
# Epoch 39/500
# 1749/1749 - 9s - loss: 9.6070e-05 - val_loss: 4.1435e-05 - 9s/epoch - 5ms/step
# Epoch 40/500
# 1749/1749 - 10s - loss: 9.5901e-05 - val_loss: 4.1321e-05 - 10s/epoch - 5ms/step
# Epoch 41/500
# 1749/1749 - 9s - loss: 9.5748e-05 - val_loss: 4.1186e-05 - 9s/epoch - 5ms/step
# Epoch 42/500
# 1749/1749 - 10s - loss: 9.5610e-05 - val_loss: 4.1033e-05 - 10s/epoch - 6ms/step
# Epoch 43/500
# 1749/1749 - 10s - loss: 9.5493e-05 - val_loss: 4.0863e-05 - 10s/epoch - 6ms/step
# Epoch 44/500
# 1749/1749 - 10s - loss: 9.5404e-05 - val_loss: 4.0686e-05 - 10s/epoch - 6ms/step
# Epoch 45/500
# 1749/1749 - 10s - loss: 9.5351e-05 - val_loss: 4.0495e-05 - 10s/epoch - 6ms/step
# Epoch 46/500
# 1749/1749 - 10s - loss: 9.5298e-05 - val_loss: 4.0290e-05 - 10s/epoch - 5ms/step
# Epoch 47/500
# 1749/1749 - 10s - loss: 9.5319e-05 - val_loss: 4.0059e-05 - 10s/epoch - 6ms/step
# Epoch 48/500
# 1749/1749 - 9s - loss: 9.5334e-05 - val_loss: 3.9866e-05 - 9s/epoch - 5ms/step
# Epoch 49/500
# 1749/1749 - 9s - loss: 9.5443e-05 - val_loss: 3.9710e-05 - 9s/epoch - 5ms/step
# Epoch 50/500
# 1749/1749 - 9s - loss: 9.5661e-05 - val_loss: 3.9731e-05 - 9s/epoch - 5ms/step
# Epoch 51/500
# 1749/1749 - 8s - loss: 9.6074e-05 - val_loss: 4.0344e-05 - 8s/epoch - 5ms/step
# Epoch 52/500
# 1749/1749 - 9s - loss: 9.6680e-05 - val_loss: 4.2377e-05 - 9s/epoch - 5ms/step
# Epoch 53/500
# 1749/1749 - 8s - loss: 9.7178e-05 - val_loss: 4.5051e-05 - 8s/epoch - 5ms/step
# Epoch 54/500
# 1749/1749 - 9s - loss: 9.7354e-05 - val_loss: 4.6385e-05 - 9s/epoch - 5ms/step
# Epoch 55/500
# 1749/1749 - 8s - loss: 9.7410e-05 - val_loss: 4.6773e-05 - 8s/epoch - 5ms/step
# Epoch 56/500
# 1749/1749 - 8s - loss: 9.7443e-05 - val_loss: 4.6856e-05 - 8s/epoch - 4ms/step
# Epoch 57/500
# 1749/1749 - 7s - loss: 9.7467e-05 - val_loss: 4.6968e-05 - 7s/epoch - 4ms/step
# Epoch 58/500
# 1749/1749 - 7s - loss: 9.7489e-05 - val_loss: 4.7256e-05 - 7s/epoch - 4ms/step
# Epoch 59/500
# 1749/1749 - 8s - loss: 9.7510e-05 - val_loss: 4.7760e-05 - 8s/epoch - 5ms/step
# Epoch 60/500
# 1749/1749 - 11s - loss: 9.7536e-05 - val_loss: 4.8478e-05 - 11s/epoch - 6ms/step
# Epoch 61/500
# 1749/1749 - 9s - loss: 9.7574e-05 - val_loss: 4.9401e-05 - 9s/epoch - 5ms/step
# Epoch 62/500
# 1749/1749 - 9s - loss: 9.7631e-05 - val_loss: 5.0525e-05 - 9s/epoch - 5ms/step
# Epoch 63/500
# 1749/1749 - 9s - loss: 9.7715e-05 - val_loss: 5.1854e-05 - 9s/epoch - 5ms/step
# Epoch 64/500
# 1749/1749 - 9s - loss: 9.7837e-05 - val_loss: 5.3423e-05 - 9s/epoch - 5ms/step
# Epoch 65/500
# 1749/1749 - 9s - loss: 9.8019e-05 - val_loss: 5.5312e-05 - 9s/epoch - 5ms/step
# Epoch 66/500
# 1749/1749 - 9s - loss: 9.8300e-05 - val_loss: 5.7677e-05 - 9s/epoch - 5ms/step
# Epoch 67/500
# 1749/1749 - 9s - loss: 9.8753e-05 - val_loss: 6.0832e-05 - 9s/epoch - 5ms/step
# Epoch 68/500
# 1749/1749 - 9s - loss: 9.9572e-05 - val_loss: 6.5509e-05 - 9s/epoch - 5ms/step
# Epoch 69/500
# 1749/1749 - 9s - loss: 1.0152e-04 - val_loss: 7.4274e-05 - 9s/epoch - 5ms/step
# Epoch 70/500
# 1749/1749 - 10s - loss: 1.0596e-04 - val_loss: 9.0726e-05 - 10s/epoch - 6ms/step
# Epoch 71/500
# 1749/1749 - 11s - loss: 1.0562e-04 - val_loss: 8.9928e-05 - 11s/epoch - 6ms/step
# Epoch 72/500
# 1749/1749 - 10s - loss: 1.0515e-04 - val_loss: 9.0014e-05 - 10s/epoch - 6ms/step
# Epoch 73/500
# 1749/1749 - 10s - loss: 1.0506e-04 - val_loss: 9.0138e-05 - 10s/epoch - 6ms/step
# Epoch 74/500
# 1749/1749 - 9s - loss: 1.0490e-04 - val_loss: 9.0007e-05 - 9s/epoch - 5ms/step
# Epoch 75/500
# 1749/1749 - 10s - loss: 1.0472e-04 - val_loss: 8.9685e-05 - 10s/epoch - 6ms/step
# Epoch 76/500
# 1749/1749 - 10s - loss: 1.0455e-04 - val_loss: 8.9203e-05 - 10s/epoch - 6ms/step
# Epoch 77/500
# 1749/1749 - 10s - loss: 1.0437e-04 - val_loss: 8.8588e-05 - 10s/epoch - 6ms/step
# Epoch 78/500
# 1749/1749 - 10s - loss: 1.0420e-04 - val_loss: 8.7847e-05 - 10s/epoch - 6ms/step
# Epoch 79/500
# 1749/1749 - 11s - loss: 1.0404e-04 - val_loss: 8.6997e-05 - 11s/epoch - 6ms/step
# Epoch 80/500
# 1749/1749 - 10s - loss: 1.0387e-04 - val_loss: 8.6063e-05 - 10s/epoch - 6ms/step
# Epoch 81/500
# 1749/1749 - 10s - loss: 1.0371e-04 - val_loss: 8.5075e-05 - 10s/epoch - 6ms/step
# Epoch 82/500
# 1749/1749 - 10s - loss: 1.0355e-04 - val_loss: 8.4027e-05 - 10s/epoch - 6ms/step
# Epoch 83/500
# 1749/1749 - 10s - loss: 1.0339e-04 - val_loss: 8.2914e-05 - 10s/epoch - 6ms/step
# Epoch 84/500
# 1749/1749 - 10s - loss: 1.0324e-04 - val_loss: 8.1725e-05 - 10s/epoch - 6ms/step
# Epoch 85/500
# 1749/1749 - 10s - loss: 1.0309e-04 - val_loss: 8.0466e-05 - 10s/epoch - 6ms/step
# Epoch 86/500
# 1749/1749 - 10s - loss: 1.0294e-04 - val_loss: 7.9139e-05 - 10s/epoch - 6ms/step
# Epoch 87/500
# 1749/1749 - 10s - loss: 1.0279e-04 - val_loss: 7.7750e-05 - 10s/epoch - 6ms/step
# Epoch 88/500
# 1749/1749 - 10s - loss: 1.0265e-04 - val_loss: 7.6308e-05 - 10s/epoch - 6ms/step
# Epoch 89/500
# 1749/1749 - 10s - loss: 1.0250e-04 - val_loss: 7.4827e-05 - 10s/epoch - 6ms/step
# Epoch 90/500
# 1749/1749 - 10s - loss: 1.0236e-04 - val_loss: 7.3309e-05 - 10s/epoch - 6ms/step
# Epoch 91/500
# 1749/1749 - 10s - loss: 1.0222e-04 - val_loss: 7.1759e-05 - 10s/epoch - 6ms/step
# Epoch 92/500
# 1749/1749 - 10s - loss: 1.0208e-04 - val_loss: 7.0190e-05 - 10s/epoch - 6ms/step
# Epoch 93/500
# 1749/1749 - 10s - loss: 1.0193e-04 - val_loss: 6.8612e-05 - 10s/epoch - 6ms/step
# Epoch 94/500
# 1749/1749 - 10s - loss: 1.0179e-04 - val_loss: 6.7036e-05 - 10s/epoch - 6ms/step
# Epoch 95/500
# 1749/1749 - 10s - loss: 1.0165e-04 - val_loss: 6.5465e-05 - 10s/epoch - 6ms/step
# Epoch 96/500
# 1749/1749 - 10s - loss: 1.0151e-04 - val_loss: 6.3904e-05 - 10s/epoch - 6ms/step
# Epoch 97/500
# 1749/1749 - 10s - loss: 1.0136e-04 - val_loss: 6.2363e-05 - 10s/epoch - 6ms/step
# Epoch 98/500
# 1749/1749 - 10s - loss: 1.0122e-04 - val_loss: 6.0841e-05 - 10s/epoch - 6ms/step
# Epoch 99/500
# 1749/1749 - 14s - loss: 1.0108e-04 - val_loss: 5.9352e-05 - 14s/epoch - 8ms/step
# Epoch 100/500
# 1749/1749 - 22s - loss: 1.0094e-04 - val_loss: 5.7896e-05 - 22s/epoch - 13ms/step
# Epoch 101/500
# 1749/1749 - 16s - loss: 1.0080e-04 - val_loss: 5.6478e-05 - 16s/epoch - 9ms/step
# Epoch 102/500
# 1749/1749 - 14s - loss: 1.0066e-04 - val_loss: 5.5104e-05 - 14s/epoch - 8ms/step
# Epoch 103/500
# 1749/1749 - 14s - loss: 1.0052e-04 - val_loss: 5.3762e-05 - 14s/epoch - 8ms/step
# Epoch 104/500
# 1749/1749 - 14s - loss: 1.0039e-04 - val_loss: 5.2346e-05 - 14s/epoch - 8ms/step
# Epoch 105/500
# 1749/1749 - 13s - loss: 1.0025e-04 - val_loss: 5.1179e-05 - 13s/epoch - 7ms/step
# Epoch 106/500
# 1749/1749 - 13s - loss: 1.0011e-04 - val_loss: 4.9957e-05 - 13s/epoch - 7ms/step
# Epoch 107/500
# 1749/1749 - 12s - loss: 9.9979e-05 - val_loss: 4.8789e-05 - 12s/epoch - 7ms/step
# Epoch 108/500
# 1749/1749 - 11s - loss: 9.9843e-05 - val_loss: 4.7694e-05 - 11s/epoch - 7ms/step
# Epoch 109/500
# 1749/1749 - 11s - loss: 9.9709e-05 - val_loss: 4.6634e-05 - 11s/epoch - 6ms/step
# Epoch 110/500
# 1749/1749 - 11s - loss: 9.9574e-05 - val_loss: 4.5648e-05 - 11s/epoch - 6ms/step
# Epoch 111/500
# 1749/1749 - 11s - loss: 9.9436e-05 - val_loss: 4.4774e-05 - 11s/epoch - 6ms/step
# Epoch 112/500
# 1749/1749 - 11s - loss: 9.9294e-05 - val_loss: 4.4035e-05 - 11s/epoch - 6ms/step
# Epoch 113/500
# 1749/1749 - 11s - loss: 9.9149e-05 - val_loss: 4.3431e-05 - 11s/epoch - 6ms/step
# Epoch 114/500
# 1749/1749 - 11s - loss: 9.9000e-05 - val_loss: 4.2951e-05 - 11s/epoch - 6ms/step
# Epoch 115/500
# 1749/1749 - 10s - loss: 9.8851e-05 - val_loss: 4.2574e-05 - 10s/epoch - 6ms/step
# Epoch 116/500
# 1749/1749 - 10s - loss: 9.8702e-05 - val_loss: 4.2270e-05 - 10s/epoch - 6ms/step
# Epoch 117/500
# 1749/1749 - 10s - loss: 9.8554e-05 - val_loss: 4.2015e-05 - 10s/epoch - 6ms/step
# Epoch 118/500
# 1749/1749 - 10s - loss: 9.8410e-05 - val_loss: 4.1782e-05 - 10s/epoch - 6ms/step
# Epoch 119/500
# 1749/1749 - 10s - loss: 9.8269e-05 - val_loss: 4.1562e-05 - 10s/epoch - 6ms/step
# Epoch 120/500
# 1749/1749 - 10s - loss: 9.8131e-05 - val_loss: 4.1358e-05 - 10s/epoch - 6ms/step
# Epoch 121/500
# 1749/1749 - 8s - loss: 9.7997e-05 - val_loss: 4.1181e-05 - 8s/epoch - 5ms/step
# Epoch 122/500
# 1749/1749 - 9s - loss: 9.7863e-05 - val_loss: 4.1051e-05 - 9s/epoch - 5ms/step
# Epoch 123/500
# 1749/1749 - 13s - loss: 9.7731e-05 - val_loss: 4.0964e-05 - 13s/epoch - 7ms/step
# Epoch 124/500
# 1749/1749 - 15s - loss: 9.7602e-05 - val_loss: 4.0900e-05 - 15s/epoch - 8ms/step
# Epoch 125/500
# 1749/1749 - 10s - loss: 9.7477e-05 - val_loss: 4.0831e-05 - 10s/epoch - 6ms/step
# Epoch 126/500
# 1749/1749 - 10s - loss: 9.7358e-05 - val_loss: 4.0732e-05 - 10s/epoch - 6ms/step
# Epoch 127/500
# 1749/1749 - 10s - loss: 9.7246e-05 - val_loss: 4.0597e-05 - 10s/epoch - 6ms/step
# Epoch 128/500
# 1749/1749 - 9s - loss: 9.7140e-05 - val_loss: 4.0421e-05 - 9s/epoch - 5ms/step
# Epoch 129/500
# 1749/1749 - 9s - loss: 9.7039e-05 - val_loss: 4.0209e-05 - 9s/epoch - 5ms/step
# Epoch 130/500
# 1749/1749 - 9s - loss: 9.6943e-05 - val_loss: 3.9970e-05 - 9s/epoch - 5ms/step
# Epoch 131/500
# 1749/1749 - 9s - loss: 9.6852e-05 - val_loss: 3.9713e-05 - 9s/epoch - 5ms/step
# Epoch 132/500
# 1749/1749 - 9s - loss: 9.6763e-05 - val_loss: 3.9445e-05 - 9s/epoch - 5ms/step
# Epoch 133/500
# 1749/1749 - 9s - loss: 9.6678e-05 - val_loss: 3.9168e-05 - 9s/epoch - 5ms/step
# Epoch 134/500
# 1749/1749 - 9s - loss: 9.6595e-05 - val_loss: 3.8887e-05 - 9s/epoch - 5ms/step
# Epoch 135/500
# 1749/1749 - 9s - loss: 9.6514e-05 - val_loss: 3.8605e-05 - 9s/epoch - 5ms/step
# Epoch 136/500
# 1749/1749 - 9s - loss: 9.6435e-05 - val_loss: 3.8325e-05 - 9s/epoch - 5ms/step
# Epoch 137/500
# 1749/1749 - 8s - loss: 9.6358e-05 - val_loss: 3.8052e-05 - 8s/epoch - 5ms/step
# Epoch 138/500
# 1749/1749 - 8s - loss: 9.6282e-05 - val_loss: 3.7787e-05 - 8s/epoch - 5ms/step
# Epoch 139/500
# 1749/1749 - 8s - loss: 9.6207e-05 - val_loss: 3.7531e-05 - 8s/epoch - 5ms/step
# Epoch 140/500
# 1749/1749 - 9s - loss: 9.6133e-05 - val_loss: 3.7287e-05 - 9s/epoch - 5ms/step
# Epoch 141/500
# 1749/1749 - 9s - loss: 9.6061e-05 - val_loss: 3.7054e-05 - 9s/epoch - 5ms/step
# Epoch 142/500
# 1749/1749 - 8s - loss: 9.5991e-05 - val_loss: 3.6833e-05 - 8s/epoch - 5ms/step
# Epoch 143/500
# 1749/1749 - 8s - loss: 9.5922e-05 - val_loss: 3.6623e-05 - 8s/epoch - 5ms/step
# Epoch 144/500
# 1749/1749 - 9s - loss: 9.5855e-05 - val_loss: 3.6426e-05 - 9s/epoch - 5ms/step
# Epoch 145/500
# 1749/1749 - 9s - loss: 9.5791e-05 - val_loss: 3.6239e-05 - 9s/epoch - 5ms/step
# Epoch 146/500
# 1749/1749 - 9s - loss: 9.5730e-05 - val_loss: 3.6064e-05 - 9s/epoch - 5ms/step
# Epoch 147/500
# 1749/1749 - 9s - loss: 9.5671e-05 - val_loss: 3.5900e-05 - 9s/epoch - 5ms/step
# Epoch 148/500
# 1749/1749 - 9s - loss: 9.5615e-05 - val_loss: 3.5750e-05 - 9s/epoch - 5ms/step
# Epoch 149/500
# 1749/1749 - 9s - loss: 9.5561e-05 - val_loss: 3.5616e-05 - 9s/epoch - 5ms/step
# Epoch 150/500
# 1749/1749 - 9s - loss: 9.5508e-05 - val_loss: 3.5496e-05 - 9s/epoch - 5ms/step
# Epoch 151/500
# 1749/1749 - 9s - loss: 9.5457e-05 - val_loss: 3.5392e-05 - 9s/epoch - 5ms/step
# Epoch 152/500
# 1749/1749 - 9s - loss: 9.5406e-05 - val_loss: 3.5302e-05 - 9s/epoch - 5ms/step
# Epoch 153/500
# 1749/1749 - 9s - loss: 9.5356e-05 - val_loss: 3.5227e-05 - 9s/epoch - 5ms/step
# Epoch 154/500
# 1749/1749 - 9s - loss: 9.5305e-05 - val_loss: 3.5165e-05 - 9s/epoch - 5ms/step
# Epoch 155/500
# 1749/1749 - 9s - loss: 9.5254e-05 - val_loss: 3.5114e-05 - 9s/epoch - 5ms/step
# Epoch 156/500
# 1749/1749 - 9s - loss: 9.5202e-05 - val_loss: 3.5073e-05 - 9s/epoch - 5ms/step
# Epoch 157/500
# 1749/1749 - 9s - loss: 9.5151e-05 - val_loss: 3.5040e-05 - 9s/epoch - 5ms/step
# Epoch 158/500
# 1749/1749 - 9s - loss: 9.5100e-05 - val_loss: 3.5014e-05 - 9s/epoch - 5ms/step
# Epoch 159/500
# 1749/1749 - 9s - loss: 9.5048e-05 - val_loss: 3.4994e-05 - 9s/epoch - 5ms/step
# Epoch 160/500
# 1749/1749 - 9s - loss: 9.4997e-05 - val_loss: 3.4979e-05 - 9s/epoch - 5ms/step
# Epoch 161/500
# 1749/1749 - 9s - loss: 9.4945e-05 - val_loss: 3.4968e-05 - 9s/epoch - 5ms/step
# Epoch 162/500
# 1749/1749 - 9s - loss: 9.4894e-05 - val_loss: 3.4962e-05 - 9s/epoch - 5ms/step
# Epoch 163/500
# 1749/1749 - 9s - loss: 9.4843e-05 - val_loss: 3.4959e-05 - 9s/epoch - 5ms/step
# Epoch 164/500
# 1749/1749 - 9s - loss: 9.4791e-05 - val_loss: 3.4959e-05 - 9s/epoch - 5ms/step
# Epoch 165/500
# 1749/1749 - 9s - loss: 9.4740e-05 - val_loss: 3.4962e-05 - 9s/epoch - 5ms/step
# Epoch 166/500
# 1749/1749 - 9s - loss: 9.4688e-05 - val_loss: 3.4968e-05 - 9s/epoch - 5ms/step
# Epoch 167/500
# 1749/1749 - 9s - loss: 9.4637e-05 - val_loss: 3.4976e-05 - 9s/epoch - 5ms/step
# Epoch 168/500
# 1749/1749 - 9s - loss: 9.4585e-05 - val_loss: 3.4986e-05 - 9s/epoch - 5ms/step
# Epoch 169/500
# 1749/1749 - 9s - loss: 9.4534e-05 - val_loss: 3.4998e-05 - 9s/epoch - 5ms/step
# Epoch 170/500
# 1749/1749 - 11s - loss: 9.4482e-05 - val_loss: 3.5011e-05 - 11s/epoch - 6ms/step
# Epoch 171/500
# 1749/1749 - 10s - loss: 9.4430e-05 - val_loss: 3.5025e-05 - 10s/epoch - 5ms/step
# Epoch 172/500
# 1749/1749 - 9s - loss: 9.4378e-05 - val_loss: 3.5040e-05 - 9s/epoch - 5ms/step
# Epoch 173/500
# 1749/1749 - 9s - loss: 9.4326e-05 - val_loss: 3.5057e-05 - 9s/epoch - 5ms/step
# Epoch 174/500
# 1749/1749 - 9s - loss: 9.4274e-05 - val_loss: 3.5074e-05 - 9s/epoch - 5ms/step
# Epoch 175/500
# 1749/1749 - 9s - loss: 9.4222e-05 - val_loss: 3.5092e-05 - 9s/epoch - 5ms/step
# Epoch 176/500
# 1749/1749 - 9s - loss: 9.4170e-05 - val_loss: 3.5110e-05 - 9s/epoch - 5ms/step
# Epoch 177/500
# 1749/1749 - 9s - loss: 9.4117e-05 - val_loss: 3.5128e-05 - 9s/epoch - 5ms/step
# Epoch 178/500
# 1749/1749 - 9s - loss: 9.4065e-05 - val_loss: 3.5146e-05 - 9s/epoch - 5ms/step
# Epoch 179/500
# 1749/1749 - 9s - loss: 9.4013e-05 - val_loss: 3.5165e-05 - 9s/epoch - 5ms/step
# Epoch 180/500
# 1749/1749 - 9s - loss: 9.3960e-05 - val_loss: 3.5184e-05 - 9s/epoch - 5ms/step
# Epoch 181/500
# 1749/1749 - 9s - loss: 9.3908e-05 - val_loss: 3.5203e-05 - 9s/epoch - 5ms/step
# Epoch 182/500
# 1749/1749 - 9s - loss: 9.3855e-05 - val_loss: 3.5222e-05 - 9s/epoch - 5ms/step
# Epoch 183/500
# 1749/1749 - 9s - loss: 9.3803e-05 - val_loss: 3.5241e-05 - 9s/epoch - 5ms/step
# Epoch 184/500
# 1749/1749 - 9s - loss: 9.3750e-05 - val_loss: 3.5259e-05 - 9s/epoch - 5ms/step
# Epoch 185/500
# 1749/1749 - 9s - loss: 9.3698e-05 - val_loss: 3.5278e-05 - 9s/epoch - 5ms/step
# Epoch 186/500
# 1749/1749 - 9s - loss: 9.3646e-05 - val_loss: 3.5297e-05 - 9s/epoch - 5ms/step
# Epoch 187/500
# 1749/1749 - 9s - loss: 9.3594e-05 - val_loss: 3.5316e-05 - 9s/epoch - 5ms/step
# Epoch 188/500
# 1749/1749 - 9s - loss: 9.3542e-05 - val_loss: 3.5335e-05 - 9s/epoch - 5ms/step
# Epoch 189/500
# 1749/1749 - 9s - loss: 9.3490e-05 - val_loss: 3.5354e-05 - 9s/epoch - 5ms/step
# Epoch 190/500
# 1749/1749 - 18s - loss: 9.3439e-05 - val_loss: 3.5374e-05 - 18s/epoch - 10ms/step
# Epoch 191/500
# 1749/1749 - 15s - loss: 9.3389e-05 - val_loss: 3.5394e-05 - 15s/epoch - 8ms/step
# Epoch 192/500
# 1749/1749 - 11s - loss: 9.3339e-05 - val_loss: 3.5415e-05 - 11s/epoch - 6ms/step
# Epoch 193/500
# 1749/1749 - 9s - loss: 9.3290e-05 - val_loss: 3.5437e-05 - 9s/epoch - 5ms/step
# Epoch 194/500
# 1749/1749 - 9s - loss: 9.3241e-05 - val_loss: 3.5460e-05 - 9s/epoch - 5ms/step
# Epoch 195/500
# 1749/1749 - 9s - loss: 9.3194e-05 - val_loss: 3.5484e-05 - 9s/epoch - 5ms/step
# Epoch 196/500
# 1749/1749 - 9s - loss: 9.3147e-05 - val_loss: 3.5510e-05 - 9s/epoch - 5ms/step
# Epoch 197/500
# 1749/1749 - 9s - loss: 9.3102e-05 - val_loss: 3.5538e-05 - 9s/epoch - 5ms/step
# Epoch 198/500
# 1749/1749 - 9s - loss: 9.3058e-05 - val_loss: 3.5567e-05 - 9s/epoch - 5ms/step
# Epoch 199/500
# 1749/1749 - 9s - loss: 9.3016e-05 - val_loss: 3.5599e-05 - 9s/epoch - 5ms/step
# Epoch 200/500
# 1749/1749 - 9s - loss: 9.2975e-05 - val_loss: 3.5633e-05 - 9s/epoch - 5ms/step
# Epoch 201/500
# 1749/1749 - 9s - loss: 9.2935e-05 - val_loss: 3.5669e-05 - 9s/epoch - 5ms/step
# Epoch 202/500
# 1749/1749 - 9s - loss: 9.2898e-05 - val_loss: 3.5708e-05 - 9s/epoch - 5ms/step
# Epoch 203/500
# 1749/1749 - 9s - loss: 9.2861e-05 - val_loss: 3.5749e-05 - 9s/epoch - 5ms/step
# Epoch 204/500
# 1749/1749 - 9s - loss: 9.2826e-05 - val_loss: 3.5791e-05 - 9s/epoch - 5ms/step
# Epoch 205/500
# 1749/1749 - 9s - loss: 9.2793e-05 - val_loss: 3.5836e-05 - 9s/epoch - 5ms/step
# Epoch 206/500
# 1749/1749 - 9s - loss: 9.2761e-05 - val_loss: 3.5881e-05 - 9s/epoch - 5ms/step
# Epoch 207/500
# 1749/1749 - 9s - loss: 9.2729e-05 - val_loss: 3.5926e-05 - 9s/epoch - 5ms/step
# Epoch 208/500
# 1749/1749 - 9s - loss: 9.2698e-05 - val_loss: 3.5971e-05 - 9s/epoch - 5ms/step
# Epoch 209/500
# 1749/1749 - 9s - loss: 9.2667e-05 - val_loss: 3.6014e-05 - 9s/epoch - 5ms/step
# Epoch 210/500
# 1749/1749 - 8s - loss: 9.2636e-05 - val_loss: 3.6055e-05 - 8s/epoch - 5ms/step
# Epoch 211/500
# 1749/1749 - 9s - loss: 9.2605e-05 - val_loss: 3.6093e-05 - 9s/epoch - 5ms/step
# Epoch 212/500
# 1749/1749 - 9s - loss: 9.2573e-05 - val_loss: 3.6130e-05 - 9s/epoch - 5ms/step
# Epoch 213/500
# 1749/1749 - 8s - loss: 9.2541e-05 - val_loss: 3.6163e-05 - 8s/epoch - 5ms/step
# Epoch 214/500
# 1749/1749 - 8s - loss: 9.2509e-05 - val_loss: 3.6195e-05 - 8s/epoch - 5ms/step
# Epoch 215/500
# 1749/1749 - 8s - loss: 9.2476e-05 - val_loss: 3.6226e-05 - 8s/epoch - 5ms/step
# Epoch 216/500
# 1749/1749 - 8s - loss: 9.2444e-05 - val_loss: 3.6256e-05 - 8s/epoch - 5ms/step
# Epoch 217/500
# 1749/1749 - 8s - loss: 9.2411e-05 - val_loss: 3.6284e-05 - 8s/epoch - 5ms/step
# Epoch 218/500
# 1749/1749 - 9s - loss: 9.2377e-05 - val_loss: 3.6312e-05 - 9s/epoch - 5ms/step
# Epoch 219/500
# 1749/1749 - 8s - loss: 9.2344e-05 - val_loss: 3.6339e-05 - 8s/epoch - 5ms/step
# Epoch 220/500
# 1749/1749 - 8s - loss: 9.2309e-05 - val_loss: 3.6365e-05 - 8s/epoch - 5ms/step
# Epoch 221/500
# 1749/1749 - 9s - loss: 9.2269e-05 - val_loss: 3.6369e-05 - 9s/epoch - 5ms/step
# Epoch 222/500
# 1749/1749 - 8s - loss: 9.2252e-05 - val_loss: 3.6399e-05 - 8s/epoch - 5ms/step
# Epoch 223/500
# 1749/1749 - 9s - loss: 9.2217e-05 - val_loss: 3.6446e-05 - 9s/epoch - 5ms/step
# Epoch 224/500
# 1749/1749 - 9s - loss: 9.2183e-05 - val_loss: 3.6490e-05 - 9s/epoch - 5ms/step
# Epoch 225/500
# 1749/1749 - 9s - loss: 9.2155e-05 - val_loss: 3.6528e-05 - 9s/epoch - 5ms/step
# Epoch 226/500
# 1749/1749 - 8s - loss: 9.2143e-05 - val_loss: 3.6560e-05 - 8s/epoch - 5ms/step
# Epoch 227/500
# 1749/1749 - 8s - loss: 9.2088e-05 - val_loss: 3.6513e-05 - 8s/epoch - 5ms/step
# Epoch 228/500
# 1749/1749 - 8s - loss: 9.2071e-05 - val_loss: 3.6552e-05 - 8s/epoch - 5ms/step
# Epoch 229/500
# 1749/1749 - 9s - loss: 9.2045e-05 - val_loss: 3.6599e-05 - 9s/epoch - 5ms/step
# Epoch 230/500
# 1749/1749 - 9s - loss: 9.2013e-05 - val_loss: 3.6643e-05 - 9s/epoch - 5ms/step
# Epoch 231/500
# 1749/1749 - 9s - loss: 9.1981e-05 - val_loss: 3.6688e-05 - 9s/epoch - 5ms/step
# Epoch 232/500
# 1749/1749 - 9s - loss: 9.1946e-05 - val_loss: 3.6727e-05 - 9s/epoch - 5ms/step
# Epoch 233/500
# 1749/1749 - 8s - loss: 9.1910e-05 - val_loss: 3.6760e-05 - 8s/epoch - 5ms/step
# Epoch 234/500
# 1749/1749 - 9s - loss: 9.1873e-05 - val_loss: 3.6789e-05 - 9s/epoch - 5ms/step
# Epoch 235/500
# 1749/1749 - 9s - loss: 9.1834e-05 - val_loss: 3.6816e-05 - 9s/epoch - 5ms/step
# Epoch 236/500
# 1749/1749 - 9s - loss: 9.1788e-05 - val_loss: 3.6821e-05 - 9s/epoch - 5ms/step
# Epoch 237/500
# 1749/1749 - 11s - loss: 9.1771e-05 - val_loss: 3.6873e-05 - 11s/epoch - 6ms/step
# Epoch 238/500
# 1749/1749 - 14s - loss: 9.1737e-05 - val_loss: 3.6927e-05 - 14s/epoch - 8ms/step
# Epoch 239/500
# 1749/1749 - 12s - loss: 9.1708e-05 - val_loss: 3.6949e-05 - 12s/epoch - 7ms/step
# Epoch 240/500
# 1749/1749 - 10s - loss: 9.1690e-05 - val_loss: 3.6928e-05 - 10s/epoch - 6ms/step
# Epoch 241/500
# 1749/1749 - 10s - loss: 9.1684e-05 - val_loss: 3.6820e-05 - 10s/epoch - 5ms/step
# Epoch 242/500
# 1749/1749 - 8s - loss: 9.1677e-05 - val_loss: 3.6604e-05 - 8s/epoch - 5ms/step
# Epoch 243/500
# 1749/1749 - 10s - loss: 9.1705e-05 - val_loss: 3.6716e-05 - 10s/epoch - 5ms/step
# Epoch 244/500
# 1749/1749 - 10s - loss: 9.1698e-05 - val_loss: 3.6880e-05 - 10s/epoch - 6ms/step
# Epoch 245/500
# 1749/1749 - 10s - loss: 9.1685e-05 - val_loss: 3.6981e-05 - 10s/epoch - 5ms/step
# Epoch 246/500
# 1749/1749 - 8s - loss: 9.1656e-05 - val_loss: 3.7057e-05 - 8s/epoch - 5ms/step
# Epoch 247/500
# 1749/1749 - 8s - loss: 9.1613e-05 - val_loss: 3.7137e-05 - 8s/epoch - 5ms/step
# Epoch 248/500
# 1749/1749 - 10s - loss: 9.1570e-05 - val_loss: 3.7187e-05 - 10s/epoch - 6ms/step
# Epoch 249/500
# 1749/1749 - 9s - loss: 9.1527e-05 - val_loss: 3.7194e-05 - 9s/epoch - 5ms/step
# Epoch 250/500
# 1749/1749 - 9s - loss: 9.1482e-05 - val_loss: 3.7212e-05 - 9s/epoch - 5ms/step
# Epoch 251/500
# 1749/1749 - 8s - loss: 9.1438e-05 - val_loss: 3.7236e-05 - 8s/epoch - 5ms/step
# Epoch 252/500
# 1749/1749 - 9s - loss: 9.1391e-05 - val_loss: 3.7268e-05 - 9s/epoch - 5ms/step
# Epoch 253/500
# 1749/1749 - 10s - loss: 9.1340e-05 - val_loss: 3.7274e-05 - 10s/epoch - 5ms/step
# Epoch 254/500
# 1749/1749 - 10s - loss: 9.1322e-05 - val_loss: 3.7312e-05 - 10s/epoch - 6ms/step
# Epoch 255/500
# 1749/1749 - 9s - loss: 9.1282e-05 - val_loss: 3.7346e-05 - 9s/epoch - 5ms/step
# Epoch 256/500
# 1749/1749 - 8s - loss: 9.1246e-05 - val_loss: 3.7354e-05 - 8s/epoch - 5ms/step
# Epoch 257/500
# 1749/1749 - 9s - loss: 9.1220e-05 - val_loss: 3.7368e-05 - 9s/epoch - 5ms/step
# Epoch 258/500
# 1749/1749 - 9s - loss: 9.1206e-05 - val_loss: 3.7383e-05 - 9s/epoch - 5ms/step
# Epoch 259/500
# 1749/1749 - 9s - loss: 9.1233e-05 - val_loss: 3.7353e-05 - 9s/epoch - 5ms/step
# Epoch 260/500
# 1749/1749 - 9s - loss: 9.1213e-05 - val_loss: 3.7049e-05 - 9s/epoch - 5ms/step
# Epoch 261/500
# 1749/1749 - 9s - loss: 9.1244e-05 - val_loss: 3.7075e-05 - 9s/epoch - 5ms/step
# Epoch 262/500
# 1749/1749 - 9s - loss: 9.1265e-05 - val_loss: 3.7300e-05 - 9s/epoch - 5ms/step
# Epoch 263/500
# 1749/1749 - 10s - loss: 9.1265e-05 - val_loss: 3.7432e-05 - 10s/epoch - 6ms/step
# Epoch 264/500
# 1749/1749 - 9s - loss: 9.1249e-05 - val_loss: 3.7514e-05 - 9s/epoch - 5ms/step
# Epoch 265/500
# 1749/1749 - 9s - loss: 9.1217e-05 - val_loss: 3.7597e-05 - 9s/epoch - 5ms/step
# Epoch 266/500
# 1749/1749 - 10s - loss: 9.1173e-05 - val_loss: 3.7654e-05 - 10s/epoch - 5ms/step
# Epoch 267/500
# 1749/1749 - 9s - loss: 9.1127e-05 - val_loss: 3.7651e-05 - 9s/epoch - 5ms/step
# Epoch 268/500
# 1749/1749 - 9s - loss: 9.1082e-05 - val_loss: 3.7683e-05 - 9s/epoch - 5ms/step
# Epoch 269/500
# 1749/1749 - 9s - loss: 9.1036e-05 - val_loss: 3.7666e-05 - 9s/epoch - 5ms/step
# Epoch 270/500
# 1749/1749 - 11s - loss: 9.0990e-05 - val_loss: 3.7717e-05 - 11s/epoch - 6ms/step
# Epoch 271/500
# 1749/1749 - 10s - loss: 9.0938e-05 - val_loss: 3.7669e-05 - 10s/epoch - 5ms/step
# Epoch 272/500
# 1749/1749 - 10s - loss: 9.0882e-05 - val_loss: 3.7726e-05 - 10s/epoch - 6ms/step
# Epoch 273/500
# 1749/1749 - 9s - loss: 9.0835e-05 - val_loss: 3.7707e-05 - 9s/epoch - 5ms/step
# Epoch 274/500
# 1749/1749 - 11s - loss: 9.0783e-05 - val_loss: 3.7700e-05 - 11s/epoch - 6ms/step
# Epoch 275/500
# 1749/1749 - 10s - loss: 9.0749e-05 - val_loss: 3.7696e-05 - 10s/epoch - 6ms/step
# Epoch 276/500
# 1749/1749 - 9s - loss: 9.0716e-05 - val_loss: 3.7718e-05 - 9s/epoch - 5ms/step
# Epoch 277/500
# 1749/1749 - 9s - loss: 9.0688e-05 - val_loss: 3.7768e-05 - 9s/epoch - 5ms/step
# Epoch 278/500
# 1749/1749 - 9s - loss: 9.0713e-05 - val_loss: 3.7792e-05 - 9s/epoch - 5ms/step
# Epoch 279/500
# 1749/1749 - 10s - loss: 9.0799e-05 - val_loss: 3.7309e-05 - 10s/epoch - 6ms/step
# Epoch 280/500
# 1749/1749 - 9s - loss: 9.0753e-05 - val_loss: 3.7235e-05 - 9s/epoch - 5ms/step
# Epoch 281/500
# 1749/1749 - 9s - loss: 9.0769e-05 - val_loss: 3.7505e-05 - 9s/epoch - 5ms/step
# Epoch 282/500
# 1749/1749 - 9s - loss: 9.0786e-05 - val_loss: 3.7604e-05 - 9s/epoch - 5ms/step
# Epoch 283/500
# 1749/1749 - 9s - loss: 9.0793e-05 - val_loss: 3.7694e-05 - 9s/epoch - 5ms/step
# Epoch 284/500
# 1749/1749 - 11s - loss: 9.0777e-05 - val_loss: 3.7776e-05 - 11s/epoch - 6ms/step
# Epoch 285/500
# 1749/1749 - 9s - loss: 9.0746e-05 - val_loss: 3.7836e-05 - 9s/epoch - 5ms/step
# Epoch 286/500
# 1749/1749 - 10s - loss: 9.0706e-05 - val_loss: 3.7862e-05 - 10s/epoch - 6ms/step
# Epoch 287/500
# 1749/1749 - 14s - loss: 9.0657e-05 - val_loss: 3.7855e-05 - 14s/epoch - 8ms/step
# Epoch 288/500
# 1749/1749 - 21s - loss: 9.0611e-05 - val_loss: 3.7852e-05 - 21s/epoch - 12ms/step
# Epoch 289/500
# 1749/1749 - 10s - loss: 9.0564e-05 - val_loss: 3.7851e-05 - 10s/epoch - 6ms/step
# Epoch 290/500
# 1749/1749 - 9s - loss: 9.0517e-05 - val_loss: 3.7852e-05 - 9s/epoch - 5ms/step
# Epoch 291/500
# 1749/1749 - 10s - loss: 9.0471e-05 - val_loss: 3.7850e-05 - 10s/epoch - 6ms/step
# Epoch 292/500
# 1749/1749 - 10s - loss: 9.0424e-05 - val_loss: 3.7845e-05 - 10s/epoch - 6ms/step
# Epoch 293/500
# 1749/1749 - 10s - loss: 9.0376e-05 - val_loss: 3.7839e-05 - 10s/epoch - 6ms/step
# Epoch 294/500
# 1749/1749 - 9s - loss: 9.0321e-05 - val_loss: 3.7807e-05 - 9s/epoch - 5ms/step
# Epoch 295/500
# 1749/1749 - 9s - loss: 9.0264e-05 - val_loss: 3.7801e-05 - 9s/epoch - 5ms/step
# Epoch 296/500
# 1749/1749 - 9s - loss: 9.0229e-05 - val_loss: 3.7848e-05 - 9s/epoch - 5ms/step
# Epoch 297/500
# 1749/1749 - 9s - loss: 9.0181e-05 - val_loss: 3.7903e-05 - 9s/epoch - 5ms/step
# Epoch 298/500
# 1749/1749 - 9s - loss: 9.0150e-05 - val_loss: 3.7931e-05 - 9s/epoch - 5ms/step
# Epoch 299/500
# 1749/1749 - 9s - loss: 9.0242e-05 - val_loss: 3.7812e-05 - 9s/epoch - 5ms/step
# Epoch 300/500
# 1749/1749 - 10s - loss: 9.0197e-05 - val_loss: 3.7158e-05 - 10s/epoch - 6ms/step
# Epoch 301/500
# 1749/1749 - 9s - loss: 9.0217e-05 - val_loss: 3.7367e-05 - 9s/epoch - 5ms/step
# Epoch 302/500
# 1749/1749 - 9s - loss: 9.0243e-05 - val_loss: 3.7661e-05 - 9s/epoch - 5ms/step
# Epoch 303/500
# 1749/1749 - 10s - loss: 9.0257e-05 - val_loss: 3.7774e-05 - 10s/epoch - 6ms/step
# Epoch 304/500
# 1749/1749 - 9s - loss: 9.0272e-05 - val_loss: 3.7868e-05 - 9s/epoch - 5ms/step
# Epoch 305/500
# 1749/1749 - 9s - loss: 9.0264e-05 - val_loss: 3.7960e-05 - 9s/epoch - 5ms/step
# Epoch 306/500
# 1749/1749 - 10s - loss: 9.0243e-05 - val_loss: 3.8026e-05 - 10s/epoch - 6ms/step
# Epoch 307/500
# 1749/1749 - 9s - loss: 9.0214e-05 - val_loss: 3.8064e-05 - 9s/epoch - 5ms/step
# Epoch 308/500
# 1749/1749 - 8s - loss: 9.0176e-05 - val_loss: 3.8074e-05 - 8s/epoch - 5ms/step
# Epoch 309/500
# 1749/1749 - 10s - loss: 9.0136e-05 - val_loss: 3.8060e-05 - 10s/epoch - 5ms/step
# Epoch 310/500
# 1749/1749 - 8s - loss: 9.0102e-05 - val_loss: 3.8068e-05 - 8s/epoch - 5ms/step
# Epoch 311/500
# 1749/1749 - 9s - loss: 9.0064e-05 - val_loss: 3.8058e-05 - 9s/epoch - 5ms/step
# Epoch 312/500
# 1749/1749 - 8s - loss: 9.0032e-05 - val_loss: 3.8071e-05 - 8s/epoch - 5ms/step
# Epoch 313/500
# 1749/1749 - 10s - loss: 8.9995e-05 - val_loss: 3.8044e-05 - 10s/epoch - 6ms/step
# Epoch 314/500
# 1749/1749 - 11s - loss: 8.9975e-05 - val_loss: 3.8073e-05 - 11s/epoch - 6ms/step
# Epoch 315/500
# 1749/1749 - 10s - loss: 8.9932e-05 - val_loss: 3.7980e-05 - 10s/epoch - 5ms/step
# Epoch 316/500
# 1749/1749 - 10s - loss: 8.9891e-05 - val_loss: 3.7954e-05 - 10s/epoch - 6ms/step
# Epoch 317/500
# 1749/1749 - 10s - loss: 8.9964e-05 - val_loss: 3.7985e-05 - 10s/epoch - 6ms/step
# Epoch 318/500
# 1749/1749 - 9s - loss: 8.9848e-05 - val_loss: 3.7638e-05 - 9s/epoch - 5ms/step
# Epoch 319/500
# 1749/1749 - 9s - loss: 8.9879e-05 - val_loss: 3.7813e-05 - 9s/epoch - 5ms/step
# Epoch 320/500
# 1749/1749 - 9s - loss: 8.9910e-05 - val_loss: 3.7961e-05 - 9s/epoch - 5ms/step
# Epoch 321/500
# 1749/1749 - 11s - loss: 8.9899e-05 - val_loss: 3.8053e-05 - 11s/epoch - 6ms/step
# Epoch 322/500
# 1749/1749 - 9s - loss: 8.9883e-05 - val_loss: 3.8150e-05 - 9s/epoch - 5ms/step
# Epoch 323/500
# 1749/1749 - 8s - loss: 8.9828e-05 - val_loss: 3.8042e-05 - 8s/epoch - 5ms/step
# Epoch 324/500
# 1749/1749 - 13s - loss: 8.9893e-05 - val_loss: 3.8058e-05 - 13s/epoch - 7ms/step
# Epoch 325/500
# 1749/1749 - 10s - loss: 8.9720e-05 - val_loss: 3.7789e-05 - 10s/epoch - 6ms/step
# Epoch 326/500
# 1749/1749 - 9s - loss: 8.9776e-05 - val_loss: 3.8059e-05 - 9s/epoch - 5ms/step
# Epoch 327/500
# 1749/1749 - 11s - loss: 8.9769e-05 - val_loss: 3.8122e-05 - 11s/epoch - 6ms/step
# Epoch 328/500
# 1749/1749 - 10s - loss: 8.9800e-05 - val_loss: 3.8121e-05 - 10s/epoch - 6ms/step
# Epoch 329/500
# 1749/1749 - 10s - loss: 8.9639e-05 - val_loss: 3.7845e-05 - 10s/epoch - 6ms/step
# Epoch 330/500
# 1749/1749 - 10s - loss: 8.9686e-05 - val_loss: 3.8089e-05 - 10s/epoch - 6ms/step
# Epoch 331/500
# 1749/1749 - 10s - loss: 8.9682e-05 - val_loss: 3.8155e-05 - 10s/epoch - 6ms/step
# Epoch 332/500
# 1749/1749 - 10s - loss: 8.9644e-05 - val_loss: 3.8096e-05 - 10s/epoch - 6ms/step
# Epoch 333/500
# 1749/1749 - 9s - loss: 8.9635e-05 - val_loss: 3.8227e-05 - 9s/epoch - 5ms/step
# Epoch 334/500
# 1749/1749 - 9s - loss: 8.9545e-05 - val_loss: 3.7955e-05 - 9s/epoch - 5ms/step
# Epoch 335/500
# 1749/1749 - 11s - loss: 8.9609e-05 - val_loss: 3.8087e-05 - 11s/epoch - 6ms/step
# Epoch 336/500
# 1749/1749 - 10s - loss: 8.9504e-05 - val_loss: 3.7715e-05 - 10s/epoch - 6ms/step
# Epoch 337/500
# 1749/1749 - 10s - loss: 8.9543e-05 - val_loss: 3.7816e-05 - 10s/epoch - 6ms/step
# Epoch 338/500
# 1749/1749 - 11s - loss: 8.9557e-05 - val_loss: 3.8029e-05 - 11s/epoch - 6ms/step
# Epoch 339/500
# 1749/1749 - 11s - loss: 8.9589e-05 - val_loss: 3.8100e-05 - 11s/epoch - 6ms/step
# Epoch 340/500
# 1749/1749 - 9s - loss: 8.9492e-05 - val_loss: 3.7906e-05 - 9s/epoch - 5ms/step
# Epoch 341/500
# 1749/1749 - 10s - loss: 8.9518e-05 - val_loss: 3.8092e-05 - 10s/epoch - 6ms/step
# Epoch 342/500
# 1749/1749 - 10s - loss: 8.9564e-05 - val_loss: 3.8121e-05 - 10s/epoch - 6ms/step
# Epoch 343/500
# 1749/1749 - 9s - loss: 8.9432e-05 - val_loss: 3.7887e-05 - 9s/epoch - 5ms/step
# Epoch 344/500
# 1749/1749 - 9s - loss: 8.9473e-05 - val_loss: 3.8099e-05 - 9s/epoch - 5ms/step
# Epoch 345/500
# 1749/1749 - 9s - loss: 8.9492e-05 - val_loss: 3.8175e-05 - 9s/epoch - 5ms/step
# Epoch 346/500
# 1749/1749 - 10s - loss: 8.9428e-05 - val_loss: 3.7995e-05 - 10s/epoch - 6ms/step
# Epoch 347/500
# 1749/1749 - 12s - loss: 8.9487e-05 - val_loss: 3.8135e-05 - 12s/epoch - 7ms/step
# Epoch 348/500
# 1749/1749 - 10s - loss: 8.9368e-05 - val_loss: 3.7793e-05 - 10s/epoch - 6ms/step
# Epoch 349/500
# 1749/1749 - 12s - loss: 8.9384e-05 - val_loss: 3.8002e-05 - 12s/epoch - 7ms/step
# Epoch 350/500
# 1749/1749 - 11s - loss: 8.9388e-05 - val_loss: 3.8189e-05 - 11s/epoch - 6ms/step
# Epoch 351/500
# 1749/1749 - 10s - loss: 8.9371e-05 - val_loss: 3.8193e-05 - 10s/epoch - 6ms/step
# Epoch 352/500
# 1749/1749 - 10s - loss: 8.9357e-05 - val_loss: 3.8242e-05 - 10s/epoch - 6ms/step
# Epoch 353/500
# 1749/1749 - 9s - loss: 8.9297e-05 - val_loss: 3.7985e-05 - 9s/epoch - 5ms/step
# Epoch 354/500
# 1749/1749 - 9s - loss: 8.9334e-05 - val_loss: 3.8260e-05 - 9s/epoch - 5ms/step
# Epoch 355/500
# 1749/1749 - 11s - loss: 8.9266e-05 - val_loss: 3.7835e-05 - 11s/epoch - 6ms/step
# Epoch 356/500
# 1749/1749 - 10s - loss: 8.9254e-05 - val_loss: 3.7861e-05 - 10s/epoch - 6ms/step
# Epoch 357/500
# 1749/1749 - 10s - loss: 8.9276e-05 - val_loss: 3.8105e-05 - 10s/epoch - 6ms/step
# Epoch 358/500
# 1749/1749 - 10s - loss: 8.9293e-05 - val_loss: 3.8162e-05 - 10s/epoch - 6ms/step
# Epoch 359/500
# 1749/1749 - 9s - loss: 8.9222e-05 - val_loss: 3.8002e-05 - 9s/epoch - 5ms/step
# Epoch 360/500
# 1749/1749 - 10s - loss: 8.9268e-05 - val_loss: 3.8089e-05 - 10s/epoch - 6ms/step
# Epoch 361/500
# 1749/1749 - 9s - loss: 8.9189e-05 - val_loss: 3.7901e-05 - 9s/epoch - 5ms/step
# Epoch 362/500
# 1749/1749 - 10s - loss: 8.9211e-05 - val_loss: 3.8094e-05 - 10s/epoch - 6ms/step
# Epoch 363/500
# 1749/1749 - 10s - loss: 8.9271e-05 - val_loss: 3.8101e-05 - 10s/epoch - 6ms/step
# Epoch 364/500
# 1749/1749 - 11s - loss: 8.9134e-05 - val_loss: 3.7849e-05 - 11s/epoch - 6ms/step
# Epoch 365/500
# 1749/1749 - 11s - loss: 8.9174e-05 - val_loss: 3.8130e-05 - 11s/epoch - 6ms/step
# Epoch 366/500
# 1749/1749 - 12s - loss: 8.9175e-05 - val_loss: 3.8282e-05 - 12s/epoch - 7ms/step
# Epoch 367/500
# 1749/1749 - 12s - loss: 8.9159e-05 - val_loss: 3.8098e-05 - 12s/epoch - 7ms/step
# Epoch 368/500
# 1749/1749 - 9s - loss: 8.9144e-05 - val_loss: 3.8439e-05 - 9s/epoch - 5ms/step
# Epoch 369/500
# 1749/1749 - 9s - loss: 8.9135e-05 - val_loss: 3.8008e-05 - 9s/epoch - 5ms/step
# Epoch 370/500
# 1749/1749 - 8s - loss: 8.9020e-05 - val_loss: 3.7806e-05 - 8s/epoch - 5ms/step
# Epoch 371/500
# 1749/1749 - 9s - loss: 8.9061e-05 - val_loss: 3.8110e-05 - 9s/epoch - 5ms/step
# Epoch 372/500
# 1749/1749 - 10s - loss: 8.9096e-05 - val_loss: 3.8206e-05 - 10s/epoch - 6ms/step
# Epoch 373/500
# 1749/1749 - 10s - loss: 8.9001e-05 - val_loss: 3.8018e-05 - 10s/epoch - 6ms/step
# Epoch 374/500
# 1749/1749 - 10s - loss: 8.9035e-05 - val_loss: 3.8243e-05 - 10s/epoch - 6ms/step
# Epoch 375/500
# 1749/1749 - 9s - loss: 8.9025e-05 - val_loss: 3.8081e-05 - 9s/epoch - 5ms/step
# Epoch 376/500
# 1749/1749 - 8s - loss: 8.9032e-05 - val_loss: 3.8399e-05 - 8s/epoch - 5ms/step
# Epoch 377/500
# 1749/1749 - 10s - loss: 8.8971e-05 - val_loss: 3.8011e-05 - 10s/epoch - 6ms/step
# Epoch 378/500
# 1749/1749 - 18s - loss: 8.8939e-05 - val_loss: 3.7954e-05 - 18s/epoch - 10ms/step
# Epoch 379/500
# 1749/1749 - 18s - loss: 8.8984e-05 - val_loss: 3.8174e-05 - 18s/epoch - 10ms/step
# Epoch 380/500
# 1749/1749 - 17s - loss: 8.8926e-05 - val_loss: 3.8053e-05 - 17s/epoch - 10ms/step
# Epoch 381/500
# 1749/1749 - 9s - loss: 8.8946e-05 - val_loss: 3.8171e-05 - 9s/epoch - 5ms/step
# Epoch 382/500
# 1749/1749 - 9s - loss: 8.8934e-05 - val_loss: 3.8276e-05 - 9s/epoch - 5ms/step
# Epoch 383/500
# 1749/1749 - 9s - loss: 8.8929e-05 - val_loss: 3.8036e-05 - 9s/epoch - 5ms/step
# Epoch 384/500
# 1749/1749 - 9s - loss: 8.8862e-05 - val_loss: 3.8406e-05 - 9s/epoch - 5ms/step
# Epoch 385/500
# 1749/1749 - 9s - loss: 8.8847e-05 - val_loss: 3.8234e-05 - 9s/epoch - 5ms/step
# Epoch 386/500
# 1749/1749 - 9s - loss: 8.8781e-05 - val_loss: 3.7850e-05 - 9s/epoch - 5ms/step
# Epoch 387/500
# 1749/1749 - 10s - loss: 8.8793e-05 - val_loss: 3.7933e-05 - 10s/epoch - 6ms/step
# Epoch 388/500
# 1749/1749 - 13s - loss: 8.8824e-05 - val_loss: 3.8191e-05 - 13s/epoch - 7ms/step
# Epoch 389/500
# 1749/1749 - 11s - loss: 8.8808e-05 - val_loss: 3.8100e-05 - 11s/epoch - 6ms/step
# Epoch 390/500
# 1749/1749 - 12s - loss: 8.8898e-05 - val_loss: 3.8115e-05 - 12s/epoch - 7ms/step
# Epoch 391/500
# 1749/1749 - 11s - loss: 8.8740e-05 - val_loss: 3.7766e-05 - 11s/epoch - 6ms/step
# Epoch 392/500
# 1749/1749 - 10s - loss: 8.8811e-05 - val_loss: 3.8000e-05 - 10s/epoch - 6ms/step
# Epoch 393/500
# 1749/1749 - 10s - loss: 8.8829e-05 - val_loss: 3.8203e-05 - 10s/epoch - 5ms/step
# Epoch 394/500
# 1749/1749 - 9s - loss: 8.8817e-05 - val_loss: 3.8345e-05 - 9s/epoch - 5ms/step
# Epoch 395/500
# 1749/1749 - 10s - loss: 8.8818e-05 - val_loss: 3.8336e-05 - 10s/epoch - 5ms/step
# Epoch 396/500
# 1749/1749 - 9s - loss: 8.8734e-05 - val_loss: 3.8124e-05 - 9s/epoch - 5ms/step
# Epoch 397/500
# 1749/1749 - 9s - loss: 8.8849e-05 - val_loss: 3.8119e-05 - 9s/epoch - 5ms/step
# Epoch 398/500
# 1749/1749 - 9s - loss: 8.8691e-05 - val_loss: 3.7889e-05 - 9s/epoch - 5ms/step
# Epoch 399/500
# 1749/1749 - 10s - loss: 8.8755e-05 - val_loss: 3.8210e-05 - 10s/epoch - 6ms/step
# Epoch 400/500
# 1749/1749 - 10s - loss: 8.8757e-05 - val_loss: 3.8293e-05 - 10s/epoch - 6ms/step
# Epoch 401/500
# 1749/1749 - 10s - loss: 8.8826e-05 - val_loss: 3.8164e-05 - 10s/epoch - 5ms/step
# Epoch 402/500
# 1749/1749 - 9s - loss: 8.8644e-05 - val_loss: 3.7962e-05 - 9s/epoch - 5ms/step
# Epoch 403/500
# 1749/1749 - 8s - loss: 8.8689e-05 - val_loss: 3.8303e-05 - 8s/epoch - 5ms/step
# Epoch 404/500
# 1749/1749 - 8s - loss: 8.8692e-05 - val_loss: 3.8282e-05 - 8s/epoch - 5ms/step
# Epoch 405/500
# 1749/1749 - 8s - loss: 8.8727e-05 - val_loss: 3.8293e-05 - 8s/epoch - 5ms/step
# Epoch 406/500
# 1749/1749 - 8s - loss: 8.8571e-05 - val_loss: 3.8023e-05 - 8s/epoch - 5ms/step
# Epoch 407/500
# 1749/1749 - 8s - loss: 8.8607e-05 - val_loss: 3.8180e-05 - 8s/epoch - 5ms/step
# Epoch 408/500
# 1749/1749 - 8s - loss: 8.8666e-05 - val_loss: 3.8285e-05 - 8s/epoch - 5ms/step
# Epoch 409/500
# 1749/1749 - 8s - loss: 8.8546e-05 - val_loss: 3.8050e-05 - 8s/epoch - 5ms/step
# Epoch 410/500
# 1749/1749 - 8s - loss: 8.8570e-05 - val_loss: 3.8182e-05 - 8s/epoch - 5ms/step
# Epoch 411/500
# 1749/1749 - 8s - loss: 8.8631e-05 - val_loss: 3.8398e-05 - 8s/epoch - 5ms/step
# Epoch 412/500
# 1749/1749 - 8s - loss: 8.8521e-05 - val_loss: 3.8130e-05 - 8s/epoch - 5ms/step
# Epoch 413/500
# 1749/1749 - 8s - loss: 8.8547e-05 - val_loss: 3.8195e-05 - 8s/epoch - 4ms/step
# Epoch 414/500
# 1749/1749 - 8s - loss: 8.8606e-05 - val_loss: 3.8400e-05 - 8s/epoch - 4ms/step
# Epoch 415/500
# 1749/1749 - 8s - loss: 8.8488e-05 - val_loss: 3.8151e-05 - 8s/epoch - 4ms/step
# Epoch 416/500
# 1749/1749 - 8s - loss: 8.8517e-05 - val_loss: 3.8206e-05 - 8s/epoch - 4ms/step
# Epoch 417/500
# 1749/1749 - 8s - loss: 8.8579e-05 - val_loss: 3.8340e-05 - 8s/epoch - 4ms/step
# Epoch 418/500
# 1749/1749 - 8s - loss: 8.8456e-05 - val_loss: 3.8122e-05 - 8s/epoch - 4ms/step
# Epoch 419/500
# 1749/1749 - 8s - loss: 8.8474e-05 - val_loss: 3.8211e-05 - 8s/epoch - 4ms/step
# Epoch 420/500
# 1749/1749 - 8s - loss: 8.8512e-05 - val_loss: 3.8497e-05 - 8s/epoch - 5ms/step
# Epoch 421/500
# 1749/1749 - 8s - loss: 8.8427e-05 - val_loss: 3.8241e-05 - 8s/epoch - 4ms/step
# Epoch 422/500
# 1749/1749 - 8s - loss: 8.8464e-05 - val_loss: 3.8153e-05 - 8s/epoch - 4ms/step
# Epoch 423/500
# 1749/1749 - 8s - loss: 8.8463e-05 - val_loss: 3.8451e-05 - 8s/epoch - 4ms/step
# Epoch 424/500
# 1749/1749 - 8s - loss: 8.8398e-05 - val_loss: 3.8474e-05 - 8s/epoch - 5ms/step
# Epoch 425/500
# 1749/1749 - 8s - loss: 8.8353e-05 - val_loss: 3.8080e-05 - 8s/epoch - 5ms/step
# Epoch 426/500
# 1749/1749 - 8s - loss: 8.8327e-05 - val_loss: 3.8348e-05 - 8s/epoch - 4ms/step
# Epoch 427/500
# 1749/1749 - 8s - loss: 8.8266e-05 - val_loss: 3.8144e-05 - 8s/epoch - 4ms/step
# Epoch 428/500
# 1749/1749 - 11s - loss: 8.8395e-05 - val_loss: 3.8118e-05 - 11s/epoch - 6ms/step
# Epoch 429/500
# 1749/1749 - 12s - loss: 8.8212e-05 - val_loss: 3.8278e-05 - 12s/epoch - 7ms/step
# Epoch 430/500
# 1749/1749 - 10s - loss: 8.8409e-05 - val_loss: 3.7691e-05 - 10s/epoch - 6ms/step
# Epoch 431/500
# 1749/1749 - 9s - loss: 8.8305e-05 - val_loss: 3.7439e-05 - 9s/epoch - 5ms/step
# Epoch 432/500
# 1749/1749 - 8s - loss: 8.8299e-05 - val_loss: 3.7729e-05 - 8s/epoch - 5ms/step
# Epoch 433/500
# 1749/1749 - 10s - loss: 8.8344e-05 - val_loss: 3.8008e-05 - 10s/epoch - 6ms/step
# Epoch 434/500
# 1749/1749 - 11s - loss: 8.8365e-05 - val_loss: 3.8246e-05 - 11s/epoch - 6ms/step
# Epoch 435/500
# 1749/1749 - 8s - loss: 8.8380e-05 - val_loss: 3.8418e-05 - 8s/epoch - 5ms/step
# Epoch 436/500
# 1749/1749 - 8s - loss: 8.8371e-05 - val_loss: 3.8462e-05 - 8s/epoch - 4ms/step
# Epoch 437/500
# 1749/1749 - 8s - loss: 8.8338e-05 - val_loss: 3.8423e-05 - 8s/epoch - 4ms/step
# Epoch 438/500
# 1749/1749 - 8s - loss: 8.8366e-05 - val_loss: 3.8309e-05 - 8s/epoch - 5ms/step
# Epoch 439/500
# 1749/1749 - 8s - loss: 8.8291e-05 - val_loss: 3.8152e-05 - 8s/epoch - 4ms/step
# Epoch 440/500
# 1749/1749 - 9s - loss: 8.8327e-05 - val_loss: 3.8389e-05 - 9s/epoch - 5ms/step
# Epoch 441/500
# 1749/1749 - 8s - loss: 8.8328e-05 - val_loss: 3.8479e-05 - 8s/epoch - 5ms/step
# Epoch 442/500
# 1749/1749 - 8s - loss: 8.8295e-05 - val_loss: 3.8489e-05 - 8s/epoch - 5ms/step
# Epoch 443/500
# 1749/1749 - 8s - loss: 8.8302e-05 - val_loss: 3.8355e-05 - 8s/epoch - 5ms/step
# Epoch 444/500
# 1749/1749 - 8s - loss: 8.8176e-05 - val_loss: 3.8174e-05 - 8s/epoch - 5ms/step
# Epoch 445/500
# 1749/1749 - 9s - loss: 8.8213e-05 - val_loss: 3.8449e-05 - 9s/epoch - 5ms/step
# Epoch 446/500
# 1749/1749 - 11s - loss: 8.8201e-05 - val_loss: 3.8267e-05 - 11s/epoch - 6ms/step
# Epoch 447/500
# 1749/1749 - 11s - loss: 8.8186e-05 - val_loss: 3.8486e-05 - 11s/epoch - 6ms/step
# Epoch 448/500
# 1749/1749 - 9s - loss: 8.8126e-05 - val_loss: 3.8243e-05 - 9s/epoch - 5ms/step
# Epoch 449/500
# 1749/1749 - 10s - loss: 8.8105e-05 - val_loss: 3.8294e-05 - 10s/epoch - 6ms/step
# Epoch 450/500
# 1749/1749 - 10s - loss: 8.8045e-05 - val_loss: 3.8199e-05 - 10s/epoch - 5ms/step
# Epoch 451/500
# 1749/1749 - 10s - loss: 8.8034e-05 - val_loss: 3.8074e-05 - 10s/epoch - 5ms/step
# Epoch 452/500
# 1749/1749 - 10s - loss: 8.8005e-05 - val_loss: 3.8284e-05 - 10s/epoch - 6ms/step
# Epoch 453/500
# 1749/1749 - 10s - loss: 8.8207e-05 - val_loss: 3.7645e-05 - 10s/epoch - 6ms/step
# Epoch 454/500
# 1749/1749 - 11s - loss: 8.8093e-05 - val_loss: 3.7473e-05 - 11s/epoch - 6ms/step
# Epoch 455/500
# 1749/1749 - 10s - loss: 8.8084e-05 - val_loss: 3.7842e-05 - 10s/epoch - 6ms/step
# Epoch 456/500
# 1749/1749 - 10s - loss: 8.8111e-05 - val_loss: 3.8116e-05 - 10s/epoch - 6ms/step
# Epoch 457/500
# 1749/1749 - 10s - loss: 8.8147e-05 - val_loss: 3.8328e-05 - 10s/epoch - 6ms/step
# Epoch 458/500
# 1749/1749 - 10s - loss: 8.8150e-05 - val_loss: 3.8481e-05 - 10s/epoch - 6ms/step
# Epoch 459/500
# 1749/1749 - 10s - loss: 8.8143e-05 - val_loss: 3.8532e-05 - 10s/epoch - 6ms/step
# Epoch 460/500
# 1749/1749 - 10s - loss: 8.8107e-05 - val_loss: 3.8496e-05 - 10s/epoch - 5ms/step
# Epoch 461/500
# 1749/1749 - 9s - loss: 8.8109e-05 - val_loss: 3.8454e-05 - 9s/epoch - 5ms/step
# Epoch 462/500
# 1749/1749 - 10s - loss: 8.8056e-05 - val_loss: 3.8341e-05 - 10s/epoch - 6ms/step
# Epoch 463/500
# 1749/1749 - 10s - loss: 8.8059e-05 - val_loss: 3.8495e-05 - 10s/epoch - 6ms/step
# Epoch 464/500
# 1749/1749 - 10s - loss: 8.8043e-05 - val_loss: 3.8530e-05 - 10s/epoch - 6ms/step
# Epoch 465/500
# 1749/1749 - 10s - loss: 8.8006e-05 - val_loss: 3.8485e-05 - 10s/epoch - 6ms/step
# Epoch 466/500
# 1749/1749 - 9s - loss: 8.7948e-05 - val_loss: 3.8223e-05 - 9s/epoch - 5ms/step
# Epoch 467/500
# 1749/1749 - 10s - loss: 8.7950e-05 - val_loss: 3.8303e-05 - 10s/epoch - 6ms/step
# Epoch 468/500
# 1749/1749 - 10s - loss: 8.7896e-05 - val_loss: 3.8283e-05 - 10s/epoch - 6ms/step
# Epoch 469/500
# 1749/1749 - 10s - loss: 8.7870e-05 - val_loss: 3.8121e-05 - 10s/epoch - 6ms/step
# Epoch 470/500
# 1749/1749 - 10s - loss: 8.7835e-05 - val_loss: 3.8319e-05 - 10s/epoch - 6ms/step
# Epoch 471/500
# 1749/1749 - 10s - loss: 8.7954e-05 - val_loss: 3.7788e-05 - 10s/epoch - 6ms/step
# Epoch 472/500
# 1749/1749 - 10s - loss: 8.7945e-05 - val_loss: 3.7496e-05 - 10s/epoch - 6ms/step
# Epoch 473/500
# 1749/1749 - 14s - loss: 8.7933e-05 - val_loss: 3.7879e-05 - 14s/epoch - 8ms/step
# Epoch 474/500
# 1749/1749 - 15s - loss: 8.7944e-05 - val_loss: 3.8211e-05 - 15s/epoch - 8ms/step
# Epoch 475/500
# 1749/1749 - 18s - loss: 8.7980e-05 - val_loss: 3.8392e-05 - 18s/epoch - 10ms/step
# Epoch 476/500
# 1749/1749 - 10s - loss: 8.7987e-05 - val_loss: 3.8528e-05 - 10s/epoch - 6ms/step
# Epoch 477/500
# 1749/1749 - 10s - loss: 8.7965e-05 - val_loss: 3.8613e-05 - 10s/epoch - 6ms/step
# Epoch 478/500
# 1749/1749 - 11s - loss: 8.7934e-05 - val_loss: 3.8590e-05 - 11s/epoch - 6ms/step
# Epoch 479/500
# 1749/1749 - 11s - loss: 8.7910e-05 - val_loss: 3.8571e-05 - 11s/epoch - 6ms/step
# Epoch 480/500
# 1749/1749 - 12s - loss: 8.7861e-05 - val_loss: 3.8414e-05 - 12s/epoch - 7ms/step
# Epoch 481/500
# 1749/1749 - 11s - loss: 8.7966e-05 - val_loss: 3.8247e-05 - 11s/epoch - 6ms/step
# Epoch 482/500
# 1749/1749 - 10s - loss: 8.7809e-05 - val_loss: 3.8047e-05 - 10s/epoch - 6ms/step
# Epoch 483/500
# 1749/1749 - 10s - loss: 8.7870e-05 - val_loss: 3.8338e-05 - 10s/epoch - 6ms/step
# Epoch 484/500
# 1749/1749 - 11s - loss: 8.7877e-05 - val_loss: 3.8509e-05 - 11s/epoch - 6ms/step
# Epoch 485/500
# 1749/1749 - 11s - loss: 8.7849e-05 - val_loss: 3.8525e-05 - 11s/epoch - 6ms/step
# Epoch 486/500
# 1749/1749 - 11s - loss: 8.7901e-05 - val_loss: 3.8401e-05 - 11s/epoch - 7ms/step
# Epoch 487/500
# 1749/1749 - 11s - loss: 8.7737e-05 - val_loss: 3.8203e-05 - 11s/epoch - 7ms/step
# Epoch 488/500
# 1749/1749 - 11s - loss: 8.7797e-05 - val_loss: 3.8425e-05 - 11s/epoch - 6ms/step
# Epoch 489/500
# 1749/1749 - 11s - loss: 8.7781e-05 - val_loss: 3.8403e-05 - 11s/epoch - 7ms/step
# Epoch 490/500
# 1749/1749 - 12s - loss: 8.7765e-05 - val_loss: 3.8532e-05 - 12s/epoch - 7ms/step
# Epoch 491/500
# 1749/1749 - 11s - loss: 8.7848e-05 - val_loss: 3.8288e-05 - 11s/epoch - 6ms/step
# Epoch 492/500
# 1749/1749 - 11s - loss: 8.7750e-05 - val_loss: 3.8460e-05 - 11s/epoch - 6ms/step
# Epoch 493/500
# 1749/1749 - 11s - loss: 8.7617e-05 - val_loss: 3.8292e-05 - 11s/epoch - 6ms/step
# Epoch 494/500
# 1749/1749 - 11s - loss: 8.7573e-05 - val_loss: 3.8239e-05 - 11s/epoch - 7ms/step
# Epoch 495/500
# 1749/1749 - 11s - loss: 8.7540e-05 - val_loss: 3.7883e-05 - 11s/epoch - 6ms/step
# Epoch 496/500
# 1749/1749 - 12s - loss: 8.7596e-05 - val_loss: 3.8282e-05 - 12s/epoch - 7ms/step
# Epoch 497/500
# 1749/1749 - 10s - loss: 8.7978e-05 - val_loss: 3.7637e-05 - 10s/epoch - 6ms/step
# Epoch 498/500
# 1749/1749 - 11s - loss: 8.7662e-05 - val_loss: 3.7686e-05 - 11s/epoch - 6ms/step
# Epoch 499/500
# 1749/1749 - 11s - loss: 8.7647e-05 - val_loss: 3.8047e-05 - 11s/epoch - 6ms/step
# Epoch 500/500
# 1749/1749 - 11s - loss: 8.7700e-05 - val_loss: 3.8236e-05 - 11s/epoch - 6ms/step

# %% [markdown]
# ## Metrics ($VPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
phy = phys2(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 875/875 [==============================] - 4s 3ms/step
# (27972, 3)
# (27972, 10)
# Test RMSE: 2.804
# Test MAE: 1.987

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('Kyoto DST Index', fontsize=20)
plt.legend(fontsize=20)
plt.show()
