# %% [markdown]
# # Time Series Prediction with Van der Pol Oscillator Inspired Deep Learning ($VPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-07 19:32:46

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Van der Pol intermittancy_

# %% [markdown]
# The `van_der_pol_intermittency.dat` is generated from the Runge Kutta Method.

# %% [markdown]
# This feeds the model with the dynamics of the Van der Pol Oscillator

# %%
data = np.genfromtxt('datasets/van_der_pol_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 7 # Weekly Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 1.0
# 1        -0.000014
# 2        -0.000029
# 3        -0.000045
# 4        -0.000061
# 5        -0.000077
#             ...
# 139867    0.000662
# 139868    0.000661
# 139869    0.000661
# 139870    0.000660
# 139871    0.000659
# Name: 1, Length: 139871, dtype: float64
# 2        -2.122449e-06
# 3        -2.206735e-06
# 4        -2.293673e-06
# 5        -2.382653e-06
# 6        -2.473878e-06
#               ...
# 139867   -9.530612e-08
# 139868   -9.571429e-08
# 139869   -9.571429e-08
# 139870   -9.571429e-08
# 139871   -9.612245e-08
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _SAN JUAN_

# %%
data = pd.read_csv("datasets/sanjuan.csv")
training_set = data.iloc[:, 3]
print(training_set)
# Out:
# 0        4
# 1        5
# 2        4
# 3        3
# 4        6
#         ..
# 1191    56
# 1192    46
# 1193    52
# 1194    34
# 1195    25
# Name: Cases, Length: 1196, dtype: int64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0        -0.000014
# 1        -0.000029
# 2        -0.000045
# 3        -0.000061
# 4        -0.000077
#             ...
# 139866    0.000662
# 139867    0.000661
# 139868    0.000661
# 139869    0.000660
# 139870    0.000659
# Name: 1, Length: 139871, dtype: float64
# 0        -2.122449e-06
# 1        -2.206735e-06
# 2        -2.293673e-06
# 3        -2.382653e-06
# 4        -2.473878e-06
#               ...
# 139865   -9.530612e-08
# 139866   -9.571429e-08
# 139867   -9.571429e-08
# 139868   -9.571429e-08
# 139869   -9.612245e-08
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Van der Pol Oscillator_)

# %% [markdown]
# _Parameters_: $\mu=4\\$
# $\frac{dx}{dt} = \mu(x-\frac{x^3}{3}-y)\\
# \frac{dy}{dt} = \frac{x}{\mu}\\$

# %%
mu = 4
L = df.iloc[:, 2] - mu * (df.iloc[:, 1] - (df.iloc[:, 0]**2 * df.iloc[:, 1]) - (1/mu) * df.iloc[:, 0])
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10         4.0        5.0        4.0        3.0        6.0        2.0
# 11         5.0        4.0        3.0        6.0        2.0        4.0
# 12         4.0        3.0        6.0        2.0        4.0        5.0
# 13         3.0        6.0        2.0        4.0        5.0       10.0
# 14         6.0        2.0        4.0        5.0       10.0        6.0
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)   var2(t)   var3(t)
# 10        4.0        5.0       10.0        6.0      8.0 -0.000191 -0.000003
# 11        5.0       10.0        6.0        8.0      2.0 -0.000212 -0.000003
# 12       10.0        6.0        8.0        2.0      6.0 -0.000234 -0.000003
# 13        6.0        8.0        2.0        6.0     17.0 -0.000256 -0.000003
# 14        8.0        2.0        6.0       17.0     23.0 -0.000278 -0.000003
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (1185, 13)
# (1185, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (948, 1, 10) (948, 3) (237, 1, 10) (237, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
mu = tf.Variable(4, name="mu", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error(y_true[:, 2] - mu * (y_true[:, 1] - (y_true[:, 0]**2 * y_true[:, 1]) - (1/mu) * y_true[:, 0]), y_pred[:, 2] - mu * (y_pred[:, 1] - (y_pred[:, 0]**2 * y_pred[:, 1]) - (1/mu) * y_pred[:, 0]))


def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] - mu * ((y_pred[1:-1]-y_pred[:-2]) - (y_pred[:-2]**2 * (y_pred[1:-1]-y_pred[:-2])) - (1/mu) * y_pred[:-2])
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] - mu * ((y_real[1:-1]-y_real[:-2]) - (y_real[:-2]**2 * (y_real[1:-1]-y_real[:-2])) - (1/mu) * y_real[:-2])
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($VPINN$)

# %%
mu = tf.Variable(4, name="mu", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square(
        y_pred[:, 2] - mu * (y_pred[:, 1] - (y_pred[:, 0]**2 * y_pred[:, 1]) - (1/mu) * y_pred[:, 0]))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 15/15 - 3s - loss: 0.0144 - val_loss: 0.0175 - 3s/epoch - 199ms/step
# Epoch 2/500
# 15/15 - 0s - loss: 0.0089 - val_loss: 0.0111 - 63ms/epoch - 4ms/step
# Epoch 3/500
# 15/15 - 0s - loss: 0.0070 - val_loss: 0.0085 - 59ms/epoch - 4ms/step
# Epoch 4/500
# 15/15 - 0s - loss: 0.0061 - val_loss: 0.0074 - 60ms/epoch - 4ms/step
# Epoch 5/500
# 15/15 - 0s - loss: 0.0054 - val_loss: 0.0067 - 65ms/epoch - 4ms/step
# Epoch 6/500
# 15/15 - 0s - loss: 0.0049 - val_loss: 0.0061 - 62ms/epoch - 4ms/step
# Epoch 7/500
# 15/15 - 0s - loss: 0.0045 - val_loss: 0.0056 - 96ms/epoch - 6ms/step
# Epoch 8/500
# 15/15 - 0s - loss: 0.0042 - val_loss: 0.0051 - 64ms/epoch - 4ms/step
# Epoch 9/500
# 15/15 - 0s - loss: 0.0039 - val_loss: 0.0047 - 63ms/epoch - 4ms/step
# Epoch 10/500
# 15/15 - 0s - loss: 0.0037 - val_loss: 0.0044 - 66ms/epoch - 4ms/step
# Epoch 11/500
# 15/15 - 0s - loss: 0.0034 - val_loss: 0.0041 - 68ms/epoch - 5ms/step
# Epoch 12/500
# 15/15 - 0s - loss: 0.0032 - val_loss: 0.0038 - 66ms/epoch - 4ms/step
# Epoch 13/500
# 15/15 - 0s - loss: 0.0030 - val_loss: 0.0036 - 68ms/epoch - 5ms/step
# Epoch 14/500
# 15/15 - 0s - loss: 0.0028 - val_loss: 0.0033 - 70ms/epoch - 5ms/step
# Epoch 15/500
# 15/15 - 0s - loss: 0.0027 - val_loss: 0.0031 - 71ms/epoch - 5ms/step
# Epoch 16/500
# 15/15 - 0s - loss: 0.0025 - val_loss: 0.0029 - 70ms/epoch - 5ms/step
# Epoch 17/500
# 15/15 - 0s - loss: 0.0024 - val_loss: 0.0028 - 70ms/epoch - 5ms/step
# Epoch 18/500
# 15/15 - 0s - loss: 0.0023 - val_loss: 0.0026 - 66ms/epoch - 4ms/step
# Epoch 19/500
# 15/15 - 0s - loss: 0.0022 - val_loss: 0.0025 - 69ms/epoch - 5ms/step
# Epoch 20/500
# 15/15 - 0s - loss: 0.0021 - val_loss: 0.0024 - 70ms/epoch - 5ms/step
# Epoch 21/500
# 15/15 - 0s - loss: 0.0020 - val_loss: 0.0023 - 67ms/epoch - 4ms/step
# Epoch 22/500
# 15/15 - 0s - loss: 0.0020 - val_loss: 0.0022 - 64ms/epoch - 4ms/step
# Epoch 23/500
# 15/15 - 0s - loss: 0.0019 - val_loss: 0.0021 - 66ms/epoch - 4ms/step
# Epoch 24/500
# 15/15 - 0s - loss: 0.0019 - val_loss: 0.0020 - 70ms/epoch - 5ms/step
# Epoch 25/500
# 15/15 - 0s - loss: 0.0018 - val_loss: 0.0020 - 72ms/epoch - 5ms/step
# Epoch 26/500
# 15/15 - 0s - loss: 0.0018 - val_loss: 0.0019 - 71ms/epoch - 5ms/step
# Epoch 27/500
# 15/15 - 0s - loss: 0.0017 - val_loss: 0.0018 - 65ms/epoch - 4ms/step
# Epoch 28/500
# 15/15 - 0s - loss: 0.0017 - val_loss: 0.0018 - 65ms/epoch - 4ms/step
# Epoch 29/500
# 15/15 - 0s - loss: 0.0017 - val_loss: 0.0017 - 66ms/epoch - 4ms/step
# Epoch 30/500
# 15/15 - 0s - loss: 0.0016 - val_loss: 0.0017 - 65ms/epoch - 4ms/step
# Epoch 31/500
# 15/15 - 0s - loss: 0.0016 - val_loss: 0.0016 - 64ms/epoch - 4ms/step
# Epoch 32/500
# 15/15 - 0s - loss: 0.0016 - val_loss: 0.0016 - 112ms/epoch - 7ms/step
# Epoch 33/500
# 15/15 - 0s - loss: 0.0015 - val_loss: 0.0016 - 74ms/epoch - 5ms/step
# Epoch 34/500
# 15/15 - 0s - loss: 0.0015 - val_loss: 0.0015 - 74ms/epoch - 5ms/step
# Epoch 35/500
# 15/15 - 0s - loss: 0.0015 - val_loss: 0.0015 - 68ms/epoch - 5ms/step
# Epoch 36/500
# 15/15 - 0s - loss: 0.0014 - val_loss: 0.0015 - 70ms/epoch - 5ms/step
# Epoch 37/500
# 15/15 - 0s - loss: 0.0014 - val_loss: 0.0014 - 68ms/epoch - 5ms/step
# Epoch 38/500
# 15/15 - 0s - loss: 0.0014 - val_loss: 0.0014 - 69ms/epoch - 5ms/step
# Epoch 39/500
# 15/15 - 0s - loss: 0.0014 - val_loss: 0.0014 - 74ms/epoch - 5ms/step
# Epoch 40/500
# 15/15 - 0s - loss: 0.0013 - val_loss: 0.0014 - 68ms/epoch - 5ms/step
# Epoch 41/500
# 15/15 - 0s - loss: 0.0013 - val_loss: 0.0013 - 69ms/epoch - 5ms/step
# Epoch 42/500
# 15/15 - 0s - loss: 0.0013 - val_loss: 0.0013 - 70ms/epoch - 5ms/step
# Epoch 43/500
# 15/15 - 0s - loss: 0.0013 - val_loss: 0.0013 - 64ms/epoch - 4ms/step
# Epoch 44/500
# 15/15 - 0s - loss: 0.0013 - val_loss: 0.0013 - 68ms/epoch - 5ms/step
# Epoch 45/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0013 - 67ms/epoch - 4ms/step
# Epoch 46/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0013 - 65ms/epoch - 4ms/step
# Epoch 47/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0012 - 71ms/epoch - 5ms/step
# Epoch 48/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0012 - 66ms/epoch - 4ms/step
# Epoch 49/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0012 - 64ms/epoch - 4ms/step
# Epoch 50/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0012 - 66ms/epoch - 4ms/step
# Epoch 51/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0012 - 63ms/epoch - 4ms/step
# Epoch 52/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 62ms/epoch - 4ms/step
# Epoch 53/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 108ms/epoch - 7ms/step
# Epoch 54/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 79ms/epoch - 5ms/step
# Epoch 55/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 67ms/epoch - 4ms/step
# Epoch 56/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 68ms/epoch - 5ms/step
# Epoch 57/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 68ms/epoch - 5ms/step
# Epoch 58/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 69ms/epoch - 5ms/step
# Epoch 59/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 67ms/epoch - 4ms/step
# Epoch 60/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0011 - 68ms/epoch - 5ms/step
# Epoch 61/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0011 - 71ms/epoch - 5ms/step
# Epoch 62/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0011 - 68ms/epoch - 5ms/step
# Epoch 63/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0011 - 71ms/epoch - 5ms/step
# Epoch 64/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0011 - 68ms/epoch - 5ms/step
# Epoch 65/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0011 - 68ms/epoch - 5ms/step
# Epoch 66/500
# 15/15 - 0s - loss: 9.9815e-04 - val_loss: 0.0011 - 75ms/epoch - 5ms/step
# Epoch 67/500
# 15/15 - 0s - loss: 9.9024e-04 - val_loss: 0.0011 - 71ms/epoch - 5ms/step
# Epoch 68/500
# 15/15 - 0s - loss: 9.8260e-04 - val_loss: 0.0011 - 75ms/epoch - 5ms/step
# Epoch 69/500
# 15/15 - 0s - loss: 9.7522e-04 - val_loss: 0.0011 - 70ms/epoch - 5ms/step
# Epoch 70/500
# 15/15 - 0s - loss: 9.6808e-04 - val_loss: 0.0011 - 74ms/epoch - 5ms/step
# Epoch 71/500
# 15/15 - 0s - loss: 9.6119e-04 - val_loss: 0.0011 - 72ms/epoch - 5ms/step
# Epoch 72/500
# 15/15 - 0s - loss: 9.5453e-04 - val_loss: 0.0011 - 123ms/epoch - 8ms/step
# Epoch 73/500
# 15/15 - 0s - loss: 9.4810e-04 - val_loss: 0.0011 - 74ms/epoch - 5ms/step
# Epoch 74/500
# 15/15 - 0s - loss: 9.4189e-04 - val_loss: 0.0011 - 75ms/epoch - 5ms/step
# Epoch 75/500
# 15/15 - 0s - loss: 9.3589e-04 - val_loss: 0.0011 - 73ms/epoch - 5ms/step
# Epoch 76/500
# 15/15 - 0s - loss: 9.3009e-04 - val_loss: 0.0011 - 69ms/epoch - 5ms/step
# Epoch 77/500
# 15/15 - 0s - loss: 9.2450e-04 - val_loss: 0.0011 - 68ms/epoch - 5ms/step
# Epoch 78/500
# 15/15 - 0s - loss: 9.1909e-04 - val_loss: 0.0011 - 72ms/epoch - 5ms/step
# Epoch 79/500
# 15/15 - 0s - loss: 9.1386e-04 - val_loss: 0.0011 - 70ms/epoch - 5ms/step
# Epoch 80/500
# 15/15 - 0s - loss: 9.0881e-04 - val_loss: 0.0011 - 69ms/epoch - 5ms/step
# Epoch 81/500
# 15/15 - 0s - loss: 9.0394e-04 - val_loss: 0.0011 - 78ms/epoch - 5ms/step
# Epoch 82/500
# 15/15 - 0s - loss: 8.9922e-04 - val_loss: 0.0011 - 68ms/epoch - 5ms/step
# Epoch 83/500
# 15/15 - 0s - loss: 8.9467e-04 - val_loss: 0.0011 - 72ms/epoch - 5ms/step
# Epoch 84/500
# 15/15 - 0s - loss: 8.9027e-04 - val_loss: 0.0011 - 71ms/epoch - 5ms/step
# Epoch 85/500
# 15/15 - 0s - loss: 8.8602e-04 - val_loss: 0.0011 - 70ms/epoch - 5ms/step
# Epoch 86/500
# 15/15 - 0s - loss: 8.8190e-04 - val_loss: 0.0011 - 69ms/epoch - 5ms/step
# Epoch 87/500
# 15/15 - 0s - loss: 8.7793e-04 - val_loss: 0.0011 - 71ms/epoch - 5ms/step
# Epoch 88/500
# 15/15 - 0s - loss: 8.7409e-04 - val_loss: 0.0011 - 69ms/epoch - 5ms/step
# Epoch 89/500
# 15/15 - 0s - loss: 8.7037e-04 - val_loss: 0.0011 - 70ms/epoch - 5ms/step
# Epoch 90/500
# 15/15 - 0s - loss: 8.6677e-04 - val_loss: 0.0011 - 72ms/epoch - 5ms/step
# Epoch 91/500
# 15/15 - 0s - loss: 8.6330e-04 - val_loss: 0.0011 - 74ms/epoch - 5ms/step
# Epoch 92/500
# 15/15 - 0s - loss: 8.5993e-04 - val_loss: 0.0011 - 126ms/epoch - 8ms/step
# Epoch 93/500
# 15/15 - 0s - loss: 8.5668e-04 - val_loss: 0.0011 - 75ms/epoch - 5ms/step
# Epoch 94/500
# 15/15 - 0s - loss: 8.5352e-04 - val_loss: 0.0011 - 81ms/epoch - 5ms/step
# Epoch 95/500
# 15/15 - 0s - loss: 8.5047e-04 - val_loss: 0.0011 - 79ms/epoch - 5ms/step
# Epoch 96/500
# 15/15 - 0s - loss: 8.4752e-04 - val_loss: 0.0011 - 75ms/epoch - 5ms/step
# Epoch 97/500
# 15/15 - 0s - loss: 8.4466e-04 - val_loss: 0.0011 - 77ms/epoch - 5ms/step
# Epoch 98/500
# 15/15 - 0s - loss: 8.4189e-04 - val_loss: 0.0011 - 78ms/epoch - 5ms/step
# Epoch 99/500
# 15/15 - 0s - loss: 8.3920e-04 - val_loss: 0.0011 - 77ms/epoch - 5ms/step
# Epoch 100/500
# 15/15 - 0s - loss: 8.3660e-04 - val_loss: 0.0011 - 77ms/epoch - 5ms/step
# Epoch 101/500
# 15/15 - 0s - loss: 8.3408e-04 - val_loss: 0.0011 - 77ms/epoch - 5ms/step
# Epoch 102/500
# 15/15 - 0s - loss: 8.3163e-04 - val_loss: 0.0011 - 73ms/epoch - 5ms/step
# Epoch 103/500
# 15/15 - 0s - loss: 8.2926e-04 - val_loss: 0.0011 - 75ms/epoch - 5ms/step
# Epoch 104/500
# 15/15 - 0s - loss: 8.2696e-04 - val_loss: 0.0011 - 72ms/epoch - 5ms/step
# Epoch 105/500
# 15/15 - 0s - loss: 8.2473e-04 - val_loss: 0.0011 - 83ms/epoch - 6ms/step
# Epoch 106/500
# 15/15 - 0s - loss: 8.2256e-04 - val_loss: 0.0011 - 79ms/epoch - 5ms/step
# Epoch 107/500
# 15/15 - 0s - loss: 8.2046e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 108/500
# 15/15 - 0s - loss: 8.1842e-04 - val_loss: 0.0011 - 77ms/epoch - 5ms/step
# Epoch 109/500
# 15/15 - 0s - loss: 8.1644e-04 - val_loss: 0.0011 - 73ms/epoch - 5ms/step
# Epoch 110/500
# 15/15 - 0s - loss: 8.1451e-04 - val_loss: 0.0011 - 70ms/epoch - 5ms/step
# Epoch 111/500
# 15/15 - 0s - loss: 8.1264e-04 - val_loss: 0.0011 - 118ms/epoch - 8ms/step
# Epoch 112/500
# 15/15 - 0s - loss: 8.1083e-04 - val_loss: 0.0011 - 76ms/epoch - 5ms/step
# Epoch 113/500
# 15/15 - 0s - loss: 8.0906e-04 - val_loss: 0.0011 - 73ms/epoch - 5ms/step
# Epoch 114/500
# 15/15 - 0s - loss: 8.0735e-04 - val_loss: 0.0011 - 70ms/epoch - 5ms/step
# Epoch 115/500
# 15/15 - 0s - loss: 8.0568e-04 - val_loss: 0.0011 - 71ms/epoch - 5ms/step
# Epoch 116/500
# 15/15 - 0s - loss: 8.0405e-04 - val_loss: 0.0011 - 70ms/epoch - 5ms/step
# Epoch 117/500
# 15/15 - 0s - loss: 8.0247e-04 - val_loss: 0.0011 - 74ms/epoch - 5ms/step
# Epoch 118/500
# 15/15 - 0s - loss: 8.0094e-04 - val_loss: 0.0011 - 74ms/epoch - 5ms/step
# Epoch 119/500
# 15/15 - 0s - loss: 7.9944e-04 - val_loss: 0.0011 - 75ms/epoch - 5ms/step
# Epoch 120/500
# 15/15 - 0s - loss: 7.9799e-04 - val_loss: 0.0011 - 79ms/epoch - 5ms/step
# Epoch 121/500
# 15/15 - 0s - loss: 7.9657e-04 - val_loss: 0.0011 - 71ms/epoch - 5ms/step
# Epoch 122/500
# 15/15 - 0s - loss: 7.9519e-04 - val_loss: 0.0011 - 71ms/epoch - 5ms/step
# Epoch 123/500
# 15/15 - 0s - loss: 7.9385e-04 - val_loss: 0.0011 - 74ms/epoch - 5ms/step
# Epoch 124/500
# 15/15 - 0s - loss: 7.9254e-04 - val_loss: 0.0011 - 70ms/epoch - 5ms/step
# Epoch 125/500
# 15/15 - 0s - loss: 7.9127e-04 - val_loss: 0.0011 - 77ms/epoch - 5ms/step
# Epoch 126/500
# 15/15 - 0s - loss: 7.9002e-04 - val_loss: 0.0011 - 72ms/epoch - 5ms/step
# Epoch 127/500
# 15/15 - 0s - loss: 7.8881e-04 - val_loss: 0.0011 - 74ms/epoch - 5ms/step
# Epoch 128/500
# 15/15 - 0s - loss: 7.8763e-04 - val_loss: 0.0011 - 68ms/epoch - 5ms/step
# Epoch 129/500
# 15/15 - 0s - loss: 7.8648e-04 - val_loss: 0.0011 - 72ms/epoch - 5ms/step
# Epoch 130/500
# 15/15 - 0s - loss: 7.8536e-04 - val_loss: 0.0011 - 121ms/epoch - 8ms/step
# Epoch 131/500
# 15/15 - 0s - loss: 7.8426e-04 - val_loss: 0.0011 - 71ms/epoch - 5ms/step
# Epoch 132/500
# 15/15 - 0s - loss: 7.8319e-04 - val_loss: 0.0011 - 73ms/epoch - 5ms/step
# Epoch 133/500
# 15/15 - 0s - loss: 7.8215e-04 - val_loss: 0.0011 - 71ms/epoch - 5ms/step
# Epoch 134/500
# 15/15 - 0s - loss: 7.8113e-04 - val_loss: 0.0011 - 70ms/epoch - 5ms/step
# Epoch 135/500
# 15/15 - 0s - loss: 7.8014e-04 - val_loss: 0.0011 - 72ms/epoch - 5ms/step
# Epoch 136/500
# 15/15 - 0s - loss: 7.7917e-04 - val_loss: 0.0011 - 67ms/epoch - 4ms/step
# Epoch 137/500
# 15/15 - 0s - loss: 7.7822e-04 - val_loss: 0.0011 - 71ms/epoch - 5ms/step
# Epoch 138/500
# 15/15 - 0s - loss: 7.7730e-04 - val_loss: 0.0011 - 68ms/epoch - 5ms/step
# Epoch 139/500
# 15/15 - 0s - loss: 7.7639e-04 - val_loss: 0.0011 - 72ms/epoch - 5ms/step
# Epoch 140/500
# 15/15 - 0s - loss: 7.7551e-04 - val_loss: 0.0011 - 70ms/epoch - 5ms/step
# Epoch 141/500
# 15/15 - 0s - loss: 7.7464e-04 - val_loss: 0.0011 - 73ms/epoch - 5ms/step
# Epoch 142/500
# 15/15 - 0s - loss: 7.7380e-04 - val_loss: 0.0011 - 71ms/epoch - 5ms/step
# Epoch 143/500
# 15/15 - 0s - loss: 7.7297e-04 - val_loss: 0.0011 - 70ms/epoch - 5ms/step
# Epoch 144/500
# 15/15 - 0s - loss: 7.7217e-04 - val_loss: 0.0011 - 72ms/epoch - 5ms/step
# Epoch 145/500
# 15/15 - 0s - loss: 7.7138e-04 - val_loss: 0.0011 - 72ms/epoch - 5ms/step
# Epoch 146/500
# 15/15 - 0s - loss: 7.7061e-04 - val_loss: 0.0011 - 72ms/epoch - 5ms/step
# Epoch 147/500
# 15/15 - 0s - loss: 7.6985e-04 - val_loss: 0.0011 - 71ms/epoch - 5ms/step
# Epoch 148/500
# 15/15 - 0s - loss: 7.6911e-04 - val_loss: 0.0011 - 70ms/epoch - 5ms/step
# Epoch 149/500
# 15/15 - 0s - loss: 7.6839e-04 - val_loss: 0.0011 - 84ms/epoch - 6ms/step
# Epoch 150/500
# 15/15 - 0s - loss: 7.6768e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 151/500
# 15/15 - 0s - loss: 7.6699e-04 - val_loss: 0.0011 - 74ms/epoch - 5ms/step
# Epoch 152/500
# 15/15 - 0s - loss: 7.6631e-04 - val_loss: 0.0011 - 77ms/epoch - 5ms/step
# Epoch 153/500
# 15/15 - 0s - loss: 7.6564e-04 - val_loss: 0.0011 - 81ms/epoch - 5ms/step
# Epoch 154/500
# 15/15 - 0s - loss: 7.6499e-04 - val_loss: 0.0011 - 75ms/epoch - 5ms/step
# Epoch 155/500
# 15/15 - 0s - loss: 7.6435e-04 - val_loss: 0.0011 - 76ms/epoch - 5ms/step
# Epoch 156/500
# 15/15 - 0s - loss: 7.6373e-04 - val_loss: 0.0011 - 77ms/epoch - 5ms/step
# Epoch 157/500
# 15/15 - 0s - loss: 7.6312e-04 - val_loss: 0.0011 - 78ms/epoch - 5ms/step
# Epoch 158/500
# 15/15 - 0s - loss: 7.6251e-04 - val_loss: 0.0011 - 83ms/epoch - 6ms/step
# Epoch 159/500
# 15/15 - 0s - loss: 7.6193e-04 - val_loss: 0.0011 - 75ms/epoch - 5ms/step
# Epoch 160/500
# 15/15 - 0s - loss: 7.6135e-04 - val_loss: 0.0011 - 89ms/epoch - 6ms/step
# Epoch 161/500
# 15/15 - 0s - loss: 7.6078e-04 - val_loss: 0.0011 - 79ms/epoch - 5ms/step
# Epoch 162/500
# 15/15 - 0s - loss: 7.6023e-04 - val_loss: 0.0011 - 74ms/epoch - 5ms/step
# Epoch 163/500
# 15/15 - 0s - loss: 7.5968e-04 - val_loss: 0.0011 - 79ms/epoch - 5ms/step
# Epoch 164/500
# 15/15 - 0s - loss: 7.5914e-04 - val_loss: 0.0011 - 78ms/epoch - 5ms/step
# Epoch 165/500
# 15/15 - 0s - loss: 7.5862e-04 - val_loss: 0.0011 - 83ms/epoch - 6ms/step
# Epoch 166/500
# 15/15 - 0s - loss: 7.5810e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 167/500
# 15/15 - 0s - loss: 7.5760e-04 - val_loss: 0.0011 - 139ms/epoch - 9ms/step
# Epoch 168/500
# 15/15 - 0s - loss: 7.5710e-04 - val_loss: 0.0011 - 90ms/epoch - 6ms/step
# Epoch 169/500
# 15/15 - 0s - loss: 7.5661e-04 - val_loss: 0.0011 - 90ms/epoch - 6ms/step
# Epoch 170/500
# 15/15 - 0s - loss: 7.5613e-04 - val_loss: 0.0011 - 90ms/epoch - 6ms/step
# Epoch 171/500
# 15/15 - 0s - loss: 7.5566e-04 - val_loss: 0.0011 - 92ms/epoch - 6ms/step
# Epoch 172/500
# 15/15 - 0s - loss: 7.5520e-04 - val_loss: 0.0011 - 92ms/epoch - 6ms/step
# Epoch 173/500
# 15/15 - 0s - loss: 7.5474e-04 - val_loss: 0.0011 - 81ms/epoch - 5ms/step
# Epoch 174/500
# 15/15 - 0s - loss: 7.5429e-04 - val_loss: 0.0011 - 88ms/epoch - 6ms/step
# Epoch 175/500
# 15/15 - 0s - loss: 7.5385e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 176/500
# 15/15 - 0s - loss: 7.5342e-04 - val_loss: 0.0011 - 83ms/epoch - 6ms/step
# Epoch 177/500
# 15/15 - 0s - loss: 7.5299e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 178/500
# 15/15 - 0s - loss: 7.5257e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 179/500
# 15/15 - 0s - loss: 7.5216e-04 - val_loss: 0.0011 - 83ms/epoch - 6ms/step
# Epoch 180/500
# 15/15 - 0s - loss: 7.5175e-04 - val_loss: 0.0011 - 83ms/epoch - 6ms/step
# Epoch 181/500
# 15/15 - 0s - loss: 7.5136e-04 - val_loss: 0.0011 - 79ms/epoch - 5ms/step
# Epoch 182/500
# 15/15 - 0s - loss: 7.5096e-04 - val_loss: 0.0011 - 78ms/epoch - 5ms/step
# Epoch 183/500
# 15/15 - 0s - loss: 7.5057e-04 - val_loss: 0.0011 - 79ms/epoch - 5ms/step
# Epoch 184/500
# 15/15 - 0s - loss: 7.5019e-04 - val_loss: 0.0011 - 75ms/epoch - 5ms/step
# Epoch 185/500
# 15/15 - 0s - loss: 7.4982e-04 - val_loss: 0.0011 - 77ms/epoch - 5ms/step
# Epoch 186/500
# 15/15 - 0s - loss: 7.4945e-04 - val_loss: 0.0011 - 77ms/epoch - 5ms/step
# Epoch 187/500
# 15/15 - 0s - loss: 7.4908e-04 - val_loss: 0.0011 - 126ms/epoch - 8ms/step
# Epoch 188/500
# 15/15 - 0s - loss: 7.4872e-04 - val_loss: 0.0011 - 99ms/epoch - 7ms/step
# Epoch 189/500
# 15/15 - 0s - loss: 7.4836e-04 - val_loss: 0.0011 - 86ms/epoch - 6ms/step
# Epoch 190/500
# 15/15 - 0s - loss: 7.4801e-04 - val_loss: 0.0011 - 84ms/epoch - 6ms/step
# Epoch 191/500
# 15/15 - 0s - loss: 7.4767e-04 - val_loss: 0.0011 - 80ms/epoch - 5ms/step
# Epoch 192/500
# 15/15 - 0s - loss: 7.4733e-04 - val_loss: 0.0011 - 90ms/epoch - 6ms/step
# Epoch 193/500
# 15/15 - 0s - loss: 7.4699e-04 - val_loss: 0.0011 - 80ms/epoch - 5ms/step
# Epoch 194/500
# 15/15 - 0s - loss: 7.4666e-04 - val_loss: 0.0011 - 81ms/epoch - 5ms/step
# Epoch 195/500
# 15/15 - 0s - loss: 7.4633e-04 - val_loss: 0.0011 - 83ms/epoch - 6ms/step
# Epoch 196/500
# 15/15 - 0s - loss: 7.4601e-04 - val_loss: 0.0011 - 79ms/epoch - 5ms/step
# Epoch 197/500
# 15/15 - 0s - loss: 7.4569e-04 - val_loss: 0.0011 - 79ms/epoch - 5ms/step
# Epoch 198/500
# 15/15 - 0s - loss: 7.4538e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 199/500
# 15/15 - 0s - loss: 7.4506e-04 - val_loss: 0.0011 - 73ms/epoch - 5ms/step
# Epoch 200/500
# 15/15 - 0s - loss: 7.4476e-04 - val_loss: 0.0011 - 73ms/epoch - 5ms/step
# Epoch 201/500
# 15/15 - 0s - loss: 7.4445e-04 - val_loss: 0.0011 - 74ms/epoch - 5ms/step
# Epoch 202/500
# 15/15 - 0s - loss: 7.4415e-04 - val_loss: 0.0011 - 75ms/epoch - 5ms/step
# Epoch 203/500
# 15/15 - 0s - loss: 7.4385e-04 - val_loss: 0.0011 - 74ms/epoch - 5ms/step
# Epoch 204/500
# 15/15 - 0s - loss: 7.4356e-04 - val_loss: 0.0011 - 138ms/epoch - 9ms/step
# Epoch 205/500
# 15/15 - 0s - loss: 7.4327e-04 - val_loss: 0.0011 - 87ms/epoch - 6ms/step
# Epoch 206/500
# 15/15 - 0s - loss: 7.4298e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 207/500
# 15/15 - 0s - loss: 7.4270e-04 - val_loss: 0.0011 - 88ms/epoch - 6ms/step
# Epoch 208/500
# 15/15 - 0s - loss: 7.4241e-04 - val_loss: 0.0011 - 75ms/epoch - 5ms/step
# Epoch 209/500
# 15/15 - 0s - loss: 7.4213e-04 - val_loss: 0.0011 - 77ms/epoch - 5ms/step
# Epoch 210/500
# 15/15 - 0s - loss: 7.4186e-04 - val_loss: 0.0011 - 76ms/epoch - 5ms/step
# Epoch 211/500
# 15/15 - 0s - loss: 7.4158e-04 - val_loss: 0.0011 - 72ms/epoch - 5ms/step
# Epoch 212/500
# 15/15 - 0s - loss: 7.4131e-04 - val_loss: 0.0011 - 74ms/epoch - 5ms/step
# Epoch 213/500
# 15/15 - 0s - loss: 7.4104e-04 - val_loss: 0.0011 - 77ms/epoch - 5ms/step
# Epoch 214/500
# 15/15 - 0s - loss: 7.4077e-04 - val_loss: 0.0011 - 77ms/epoch - 5ms/step
# Epoch 215/500
# 15/15 - 0s - loss: 7.4051e-04 - val_loss: 0.0011 - 71ms/epoch - 5ms/step
# Epoch 216/500
# 15/15 - 0s - loss: 7.4024e-04 - val_loss: 0.0012 - 78ms/epoch - 5ms/step
# Epoch 217/500
# 15/15 - 0s - loss: 7.3998e-04 - val_loss: 0.0012 - 74ms/epoch - 5ms/step
# Epoch 218/500
# 15/15 - 0s - loss: 7.3972e-04 - val_loss: 0.0012 - 76ms/epoch - 5ms/step
# Epoch 219/500
# 15/15 - 0s - loss: 7.3946e-04 - val_loss: 0.0012 - 73ms/epoch - 5ms/step
# Epoch 220/500
# 15/15 - 0s - loss: 7.3921e-04 - val_loss: 0.0012 - 79ms/epoch - 5ms/step
# Epoch 221/500
# 15/15 - 0s - loss: 7.3895e-04 - val_loss: 0.0012 - 130ms/epoch - 9ms/step
# Epoch 222/500
# 15/15 - 0s - loss: 7.3870e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 223/500
# 15/15 - 0s - loss: 7.3845e-04 - val_loss: 0.0012 - 80ms/epoch - 5ms/step
# Epoch 224/500
# 15/15 - 0s - loss: 7.3820e-04 - val_loss: 0.0012 - 76ms/epoch - 5ms/step
# Epoch 225/500
# 15/15 - 0s - loss: 7.3795e-04 - val_loss: 0.0012 - 75ms/epoch - 5ms/step
# Epoch 226/500
# 15/15 - 0s - loss: 7.3770e-04 - val_loss: 0.0012 - 77ms/epoch - 5ms/step
# Epoch 227/500
# 15/15 - 0s - loss: 7.3745e-04 - val_loss: 0.0012 - 71ms/epoch - 5ms/step
# Epoch 228/500
# 15/15 - 0s - loss: 7.3721e-04 - val_loss: 0.0012 - 77ms/epoch - 5ms/step
# Epoch 229/500
# 15/15 - 0s - loss: 7.3696e-04 - val_loss: 0.0012 - 71ms/epoch - 5ms/step
# Epoch 230/500
# 15/15 - 0s - loss: 7.3672e-04 - val_loss: 0.0012 - 73ms/epoch - 5ms/step
# Epoch 231/500
# 15/15 - 0s - loss: 7.3647e-04 - val_loss: 0.0012 - 76ms/epoch - 5ms/step
# Epoch 232/500
# 15/15 - 0s - loss: 7.3623e-04 - val_loss: 0.0012 - 78ms/epoch - 5ms/step
# Epoch 233/500
# 15/15 - 0s - loss: 7.3599e-04 - val_loss: 0.0012 - 73ms/epoch - 5ms/step
# Epoch 234/500
# 15/15 - 0s - loss: 7.3575e-04 - val_loss: 0.0012 - 72ms/epoch - 5ms/step
# Epoch 235/500
# 15/15 - 0s - loss: 7.3551e-04 - val_loss: 0.0012 - 75ms/epoch - 5ms/step
# Epoch 236/500
# 15/15 - 0s - loss: 7.3528e-04 - val_loss: 0.0012 - 73ms/epoch - 5ms/step
# Epoch 237/500
# 15/15 - 0s - loss: 7.3504e-04 - val_loss: 0.0012 - 70ms/epoch - 5ms/step
# Epoch 238/500
# 15/15 - 0s - loss: 7.3480e-04 - val_loss: 0.0012 - 132ms/epoch - 9ms/step
# Epoch 239/500
# 15/15 - 0s - loss: 7.3456e-04 - val_loss: 0.0012 - 82ms/epoch - 5ms/step
# Epoch 240/500
# 15/15 - 0s - loss: 7.3433e-04 - val_loss: 0.0012 - 79ms/epoch - 5ms/step
# Epoch 241/500
# 15/15 - 0s - loss: 7.3409e-04 - val_loss: 0.0012 - 80ms/epoch - 5ms/step
# Epoch 242/500
# 15/15 - 0s - loss: 7.3386e-04 - val_loss: 0.0012 - 77ms/epoch - 5ms/step
# Epoch 243/500
# 15/15 - 0s - loss: 7.3363e-04 - val_loss: 0.0012 - 78ms/epoch - 5ms/step
# Epoch 244/500
# 15/15 - 0s - loss: 7.3340e-04 - val_loss: 0.0012 - 75ms/epoch - 5ms/step
# Epoch 245/500
# 15/15 - 0s - loss: 7.3316e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 246/500
# 15/15 - 0s - loss: 7.3294e-04 - val_loss: 0.0012 - 81ms/epoch - 5ms/step
# Epoch 247/500
# 15/15 - 0s - loss: 7.3270e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 248/500
# 15/15 - 0s - loss: 7.3248e-04 - val_loss: 0.0012 - 76ms/epoch - 5ms/step
# Epoch 249/500
# 15/15 - 0s - loss: 7.3223e-04 - val_loss: 0.0012 - 74ms/epoch - 5ms/step
# Epoch 250/500
# 15/15 - 0s - loss: 7.3202e-04 - val_loss: 0.0012 - 73ms/epoch - 5ms/step
# Epoch 251/500
# 15/15 - 0s - loss: 7.3177e-04 - val_loss: 0.0012 - 76ms/epoch - 5ms/step
# Epoch 252/500
# 15/15 - 0s - loss: 7.3156e-04 - val_loss: 0.0012 - 70ms/epoch - 5ms/step
# Epoch 253/500
# 15/15 - 0s - loss: 7.3131e-04 - val_loss: 0.0012 - 76ms/epoch - 5ms/step
# Epoch 254/500
# 15/15 - 0s - loss: 7.3111e-04 - val_loss: 0.0012 - 72ms/epoch - 5ms/step
# Epoch 255/500
# 15/15 - 0s - loss: 7.3085e-04 - val_loss: 0.0012 - 74ms/epoch - 5ms/step
# Epoch 256/500
# 15/15 - 0s - loss: 7.3066e-04 - val_loss: 0.0012 - 73ms/epoch - 5ms/step
# Epoch 257/500
# 15/15 - 0s - loss: 7.3040e-04 - val_loss: 0.0012 - 128ms/epoch - 9ms/step
# Epoch 258/500
# 15/15 - 0s - loss: 7.3022e-04 - val_loss: 0.0012 - 77ms/epoch - 5ms/step
# Epoch 259/500
# 15/15 - 0s - loss: 7.2994e-04 - val_loss: 0.0012 - 80ms/epoch - 5ms/step
# Epoch 260/500
# 15/15 - 0s - loss: 7.2977e-04 - val_loss: 0.0012 - 75ms/epoch - 5ms/step
# Epoch 261/500
# 15/15 - 0s - loss: 7.2948e-04 - val_loss: 0.0012 - 78ms/epoch - 5ms/step
# Epoch 262/500
# 15/15 - 0s - loss: 7.2933e-04 - val_loss: 0.0012 - 80ms/epoch - 5ms/step
# Epoch 263/500
# 15/15 - 0s - loss: 7.2902e-04 - val_loss: 0.0012 - 78ms/epoch - 5ms/step
# Epoch 264/500
# 15/15 - 0s - loss: 7.2890e-04 - val_loss: 0.0012 - 80ms/epoch - 5ms/step
# Epoch 265/500
# 15/15 - 0s - loss: 7.2855e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 266/500
# 15/15 - 0s - loss: 7.2846e-04 - val_loss: 0.0012 - 79ms/epoch - 5ms/step
# Epoch 267/500
# 15/15 - 0s - loss: 7.2809e-04 - val_loss: 0.0012 - 79ms/epoch - 5ms/step
# Epoch 268/500
# 15/15 - 0s - loss: 7.2804e-04 - val_loss: 0.0012 - 76ms/epoch - 5ms/step
# Epoch 269/500
# 15/15 - 0s - loss: 7.2761e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 270/500
# 15/15 - 0s - loss: 7.2762e-04 - val_loss: 0.0012 - 88ms/epoch - 6ms/step
# Epoch 271/500
# 15/15 - 0s - loss: 7.2713e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 272/500
# 15/15 - 0s - loss: 7.2722e-04 - val_loss: 0.0012 - 82ms/epoch - 5ms/step
# Epoch 273/500
# 15/15 - 0s - loss: 7.2664e-04 - val_loss: 0.0012 - 81ms/epoch - 5ms/step
# Epoch 274/500
# 15/15 - 0s - loss: 7.2683e-04 - val_loss: 0.0012 - 80ms/epoch - 5ms/step
# Epoch 275/500
# 15/15 - 0s - loss: 7.2613e-04 - val_loss: 0.0012 - 80ms/epoch - 5ms/step
# Epoch 276/500
# 15/15 - 0s - loss: 7.2646e-04 - val_loss: 0.0012 - 80ms/epoch - 5ms/step
# Epoch 277/500
# 15/15 - 0s - loss: 7.2561e-04 - val_loss: 0.0012 - 134ms/epoch - 9ms/step
# Epoch 278/500
# 15/15 - 0s - loss: 7.2611e-04 - val_loss: 0.0012 - 92ms/epoch - 6ms/step
# Epoch 279/500
# 15/15 - 0s - loss: 7.2505e-04 - val_loss: 0.0012 - 83ms/epoch - 6ms/step
# Epoch 280/500
# 15/15 - 0s - loss: 7.2580e-04 - val_loss: 0.0012 - 81ms/epoch - 5ms/step
# Epoch 281/500
# 15/15 - 0s - loss: 7.2446e-04 - val_loss: 0.0012 - 90ms/epoch - 6ms/step
# Epoch 282/500
# 15/15 - 0s - loss: 7.2555e-04 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 283/500
# 15/15 - 0s - loss: 7.2382e-04 - val_loss: 0.0012 - 114ms/epoch - 8ms/step
# Epoch 284/500
# 15/15 - 0s - loss: 7.2536e-04 - val_loss: 0.0012 - 114ms/epoch - 8ms/step
# Epoch 285/500
# 15/15 - 0s - loss: 7.2311e-04 - val_loss: 0.0012 - 106ms/epoch - 7ms/step
# Epoch 286/500
# 15/15 - 0s - loss: 7.2529e-04 - val_loss: 0.0012 - 104ms/epoch - 7ms/step
# Epoch 287/500
# 15/15 - 0s - loss: 7.2232e-04 - val_loss: 0.0012 - 106ms/epoch - 7ms/step
# Epoch 288/500
# 15/15 - 0s - loss: 7.2536e-04 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 289/500
# 15/15 - 0s - loss: 7.2142e-04 - val_loss: 0.0012 - 109ms/epoch - 7ms/step
# Epoch 290/500
# 15/15 - 0s - loss: 7.2566e-04 - val_loss: 0.0012 - 98ms/epoch - 7ms/step
# Epoch 291/500
# 15/15 - 0s - loss: 7.2040e-04 - val_loss: 0.0012 - 173ms/epoch - 12ms/step
# Epoch 292/500
# 15/15 - 0s - loss: 7.2629e-04 - val_loss: 0.0012 - 103ms/epoch - 7ms/step
# Epoch 293/500
# 15/15 - 0s - loss: 7.1923e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 294/500
# 15/15 - 0s - loss: 7.2742e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 295/500
# 15/15 - 0s - loss: 7.1795e-04 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 296/500
# 15/15 - 0s - loss: 7.2928e-04 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 297/500
# 15/15 - 0s - loss: 7.1665e-04 - val_loss: 0.0012 - 86ms/epoch - 6ms/step
# Epoch 298/500
# 15/15 - 0s - loss: 7.3216e-04 - val_loss: 0.0012 - 97ms/epoch - 6ms/step
# Epoch 299/500
# 15/15 - 0s - loss: 7.1555e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 300/500
# 15/15 - 0s - loss: 7.3634e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 301/500
# 15/15 - 0s - loss: 7.1499e-04 - val_loss: 0.0012 - 101ms/epoch - 7ms/step
# Epoch 302/500
# 15/15 - 0s - loss: 7.4178e-04 - val_loss: 0.0012 - 102ms/epoch - 7ms/step
# Epoch 303/500
# 15/15 - 0s - loss: 7.1530e-04 - val_loss: 0.0012 - 191ms/epoch - 13ms/step
# Epoch 304/500
# 15/15 - 0s - loss: 7.4772e-04 - val_loss: 0.0012 - 101ms/epoch - 7ms/step
# Epoch 305/500
# 15/15 - 0s - loss: 7.1640e-04 - val_loss: 0.0012 - 107ms/epoch - 7ms/step
# Epoch 306/500
# 15/15 - 0s - loss: 7.5234e-04 - val_loss: 0.0012 - 104ms/epoch - 7ms/step
# Epoch 307/500
# 15/15 - 0s - loss: 7.1751e-04 - val_loss: 0.0012 - 107ms/epoch - 7ms/step
# Epoch 308/500
# 15/15 - 0s - loss: 7.5353e-04 - val_loss: 0.0012 - 102ms/epoch - 7ms/step
# Epoch 309/500
# 15/15 - 0s - loss: 7.1766e-04 - val_loss: 0.0012 - 97ms/epoch - 6ms/step
# Epoch 310/500
# 15/15 - 0s - loss: 7.5048e-04 - val_loss: 0.0012 - 98ms/epoch - 7ms/step
# Epoch 311/500
# 15/15 - 0s - loss: 7.1656e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 312/500
# 15/15 - 0s - loss: 7.4450e-04 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 313/500
# 15/15 - 0s - loss: 7.1485e-04 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 314/500
# 15/15 - 0s - loss: 7.3781e-04 - val_loss: 0.0012 - 106ms/epoch - 7ms/step
# Epoch 315/500
# 15/15 - 0s - loss: 7.1330e-04 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 316/500
# 15/15 - 0s - loss: 7.3194e-04 - val_loss: 0.0012 - 159ms/epoch - 11ms/step
# Epoch 317/500
# 15/15 - 0s - loss: 7.1223e-04 - val_loss: 0.0012 - 105ms/epoch - 7ms/step
# Epoch 318/500
# 15/15 - 0s - loss: 7.2734e-04 - val_loss: 0.0012 - 110ms/epoch - 7ms/step
# Epoch 319/500
# 15/15 - 0s - loss: 7.1156e-04 - val_loss: 0.0012 - 114ms/epoch - 8ms/step
# Epoch 320/500
# 15/15 - 0s - loss: 7.2389e-04 - val_loss: 0.0012 - 107ms/epoch - 7ms/step
# Epoch 321/500
# 15/15 - 0s - loss: 7.1114e-04 - val_loss: 0.0012 - 118ms/epoch - 8ms/step
# Epoch 322/500
# 15/15 - 0s - loss: 7.2130e-04 - val_loss: 0.0012 - 118ms/epoch - 8ms/step
# Epoch 323/500
# 15/15 - 0s - loss: 7.1083e-04 - val_loss: 0.0012 - 118ms/epoch - 8ms/step
# Epoch 324/500
# 15/15 - 0s - loss: 7.1933e-04 - val_loss: 0.0012 - 108ms/epoch - 7ms/step
# Epoch 325/500
# 15/15 - 0s - loss: 7.1057e-04 - val_loss: 0.0012 - 110ms/epoch - 7ms/step
# Epoch 326/500
# 15/15 - 0s - loss: 7.1781e-04 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 327/500
# 15/15 - 0s - loss: 7.1032e-04 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 328/500
# 15/15 - 0s - loss: 7.1661e-04 - val_loss: 0.0012 - 161ms/epoch - 11ms/step
# Epoch 329/500
# 15/15 - 0s - loss: 7.1007e-04 - val_loss: 0.0012 - 101ms/epoch - 7ms/step
# Epoch 330/500
# 15/15 - 0s - loss: 7.1565e-04 - val_loss: 0.0012 - 89ms/epoch - 6ms/step
# Epoch 331/500
# 15/15 - 0s - loss: 7.0981e-04 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 332/500
# 15/15 - 0s - loss: 7.1485e-04 - val_loss: 0.0012 - 88ms/epoch - 6ms/step
# Epoch 333/500
# 15/15 - 0s - loss: 7.0953e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 334/500
# 15/15 - 0s - loss: 7.1419e-04 - val_loss: 0.0012 - 82ms/epoch - 5ms/step
# Epoch 335/500
# 15/15 - 0s - loss: 7.0923e-04 - val_loss: 0.0012 - 83ms/epoch - 6ms/step
# Epoch 336/500
# 15/15 - 0s - loss: 7.1362e-04 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 337/500
# 15/15 - 0s - loss: 7.0891e-04 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 338/500
# 15/15 - 0s - loss: 7.1314e-04 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 339/500
# 15/15 - 0s - loss: 7.0856e-04 - val_loss: 0.0012 - 106ms/epoch - 7ms/step
# Epoch 340/500
# 15/15 - 0s - loss: 7.1271e-04 - val_loss: 0.0012 - 98ms/epoch - 7ms/step
# Epoch 341/500
# 15/15 - 0s - loss: 7.0818e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 342/500
# 15/15 - 0s - loss: 7.1234e-04 - val_loss: 0.0012 - 164ms/epoch - 11ms/step
# Epoch 343/500
# 15/15 - 0s - loss: 7.0778e-04 - val_loss: 0.0012 - 132ms/epoch - 9ms/step
# Epoch 344/500
# 15/15 - 0s - loss: 7.1203e-04 - val_loss: 0.0012 - 101ms/epoch - 7ms/step
# Epoch 345/500
# 15/15 - 0s - loss: 7.0734e-04 - val_loss: 0.0012 - 111ms/epoch - 7ms/step
# Epoch 346/500
# 15/15 - 0s - loss: 7.1176e-04 - val_loss: 0.0012 - 123ms/epoch - 8ms/step
# Epoch 347/500
# 15/15 - 0s - loss: 7.0687e-04 - val_loss: 0.0012 - 136ms/epoch - 9ms/step
# Epoch 348/500
# 15/15 - 0s - loss: 7.1155e-04 - val_loss: 0.0012 - 117ms/epoch - 8ms/step
# Epoch 349/500
# 15/15 - 0s - loss: 7.0636e-04 - val_loss: 0.0012 - 147ms/epoch - 10ms/step
# Epoch 350/500
# 15/15 - 0s - loss: 7.1140e-04 - val_loss: 0.0012 - 122ms/epoch - 8ms/step
# Epoch 351/500
# 15/15 - 0s - loss: 7.0580e-04 - val_loss: 0.0012 - 108ms/epoch - 7ms/step
# Epoch 352/500
# 15/15 - 0s - loss: 7.1133e-04 - val_loss: 0.0012 - 145ms/epoch - 10ms/step
# Epoch 353/500
# 15/15 - 0s - loss: 7.0520e-04 - val_loss: 0.0012 - 121ms/epoch - 8ms/step
# Epoch 354/500
# 15/15 - 0s - loss: 7.1135e-04 - val_loss: 0.0012 - 104ms/epoch - 7ms/step
# Epoch 355/500
# 15/15 - 0s - loss: 7.0454e-04 - val_loss: 0.0012 - 128ms/epoch - 9ms/step
# Epoch 356/500
# 15/15 - 0s - loss: 7.1149e-04 - val_loss: 0.0012 - 121ms/epoch - 8ms/step
# Epoch 357/500
# 15/15 - 0s - loss: 7.0382e-04 - val_loss: 0.0012 - 111ms/epoch - 7ms/step
# Epoch 358/500
# 15/15 - 0s - loss: 7.1178e-04 - val_loss: 0.0012 - 127ms/epoch - 8ms/step
# Epoch 359/500
# 15/15 - 0s - loss: 7.0304e-04 - val_loss: 0.0012 - 116ms/epoch - 8ms/step
# Epoch 360/500
# 15/15 - 0s - loss: 7.1227e-04 - val_loss: 0.0012 - 166ms/epoch - 11ms/step
# Epoch 361/500
# 15/15 - 0s - loss: 7.0221e-04 - val_loss: 0.0012 - 151ms/epoch - 10ms/step
# Epoch 362/500
# 15/15 - 0s - loss: 7.1302e-04 - val_loss: 0.0012 - 139ms/epoch - 9ms/step
# Epoch 363/500
# 15/15 - 0s - loss: 7.0132e-04 - val_loss: 0.0012 - 128ms/epoch - 9ms/step
# Epoch 364/500
# 15/15 - 0s - loss: 7.1409e-04 - val_loss: 0.0012 - 104ms/epoch - 7ms/step
# Epoch 365/500
# 15/15 - 0s - loss: 7.0042e-04 - val_loss: 0.0012 - 97ms/epoch - 6ms/step
# Epoch 366/500
# 15/15 - 0s - loss: 7.1558e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 367/500
# 15/15 - 0s - loss: 6.9956e-04 - val_loss: 0.0013 - 88ms/epoch - 6ms/step
# Epoch 368/500
# 15/15 - 0s - loss: 7.1755e-04 - val_loss: 0.0012 - 89ms/epoch - 6ms/step
# Epoch 369/500
# 15/15 - 0s - loss: 6.9881e-04 - val_loss: 0.0013 - 95ms/epoch - 6ms/step
# Epoch 370/500
# 15/15 - 0s - loss: 7.2004e-04 - val_loss: 0.0012 - 107ms/epoch - 7ms/step
# Epoch 371/500
# 15/15 - 0s - loss: 6.9827e-04 - val_loss: 0.0013 - 100ms/epoch - 7ms/step
# Epoch 372/500
# 15/15 - 0s - loss: 7.2297e-04 - val_loss: 0.0012 - 120ms/epoch - 8ms/step
# Epoch 373/500
# 15/15 - 0s - loss: 6.9802e-04 - val_loss: 0.0013 - 95ms/epoch - 6ms/step
# Epoch 374/500
# 15/15 - 0s - loss: 7.2607e-04 - val_loss: 0.0012 - 152ms/epoch - 10ms/step
# Epoch 375/500
# 15/15 - 0s - loss: 6.9806e-04 - val_loss: 0.0013 - 131ms/epoch - 9ms/step
# Epoch 376/500
# 15/15 - 0s - loss: 7.2879e-04 - val_loss: 0.0012 - 117ms/epoch - 8ms/step
# Epoch 377/500
# 15/15 - 0s - loss: 6.9825e-04 - val_loss: 0.0013 - 116ms/epoch - 8ms/step
# Epoch 378/500
# 15/15 - 0s - loss: 7.3045e-04 - val_loss: 0.0012 - 141ms/epoch - 9ms/step
# Epoch 379/500
# 15/15 - 0s - loss: 6.9832e-04 - val_loss: 0.0013 - 135ms/epoch - 9ms/step
# Epoch 380/500
# 15/15 - 0s - loss: 7.3044e-04 - val_loss: 0.0012 - 135ms/epoch - 9ms/step
# Epoch 381/500
# 15/15 - 0s - loss: 6.9802e-04 - val_loss: 0.0013 - 148ms/epoch - 10ms/step
# Epoch 382/500
# 15/15 - 0s - loss: 7.2860e-04 - val_loss: 0.0012 - 102ms/epoch - 7ms/step
# Epoch 383/500
# 15/15 - 0s - loss: 6.9729e-04 - val_loss: 0.0013 - 101ms/epoch - 7ms/step
# Epoch 384/500
# 15/15 - 0s - loss: 7.2534e-04 - val_loss: 0.0012 - 88ms/epoch - 6ms/step
# Epoch 385/500
# 15/15 - 0s - loss: 6.9629e-04 - val_loss: 0.0013 - 116ms/epoch - 8ms/step
# Epoch 386/500
# 15/15 - 0s - loss: 7.2139e-04 - val_loss: 0.0012 - 108ms/epoch - 7ms/step
# Epoch 387/500
# 15/15 - 0s - loss: 6.9523e-04 - val_loss: 0.0013 - 100ms/epoch - 7ms/step
# Epoch 388/500
# 15/15 - 0s - loss: 7.1742e-04 - val_loss: 0.0012 - 123ms/epoch - 8ms/step
# Epoch 389/500
# 15/15 - 0s - loss: 6.9430e-04 - val_loss: 0.0013 - 113ms/epoch - 8ms/step
# Epoch 390/500
# 15/15 - 0s - loss: 7.1385e-04 - val_loss: 0.0012 - 242ms/epoch - 16ms/step
# Epoch 391/500
# 15/15 - 0s - loss: 6.9355e-04 - val_loss: 0.0013 - 149ms/epoch - 10ms/step
# Epoch 392/500
# 15/15 - 0s - loss: 7.1085e-04 - val_loss: 0.0012 - 124ms/epoch - 8ms/step
# Epoch 393/500
# 15/15 - 0s - loss: 6.9296e-04 - val_loss: 0.0013 - 109ms/epoch - 7ms/step
# Epoch 394/500
# 15/15 - 0s - loss: 7.0840e-04 - val_loss: 0.0012 - 111ms/epoch - 7ms/step
# Epoch 395/500
# 15/15 - 0s - loss: 6.9248e-04 - val_loss: 0.0013 - 131ms/epoch - 9ms/step
# Epoch 396/500
# 15/15 - 0s - loss: 7.0644e-04 - val_loss: 0.0012 - 115ms/epoch - 8ms/step
# Epoch 397/500
# 15/15 - 0s - loss: 6.9208e-04 - val_loss: 0.0013 - 98ms/epoch - 7ms/step
# Epoch 398/500
# 15/15 - 0s - loss: 7.0487e-04 - val_loss: 0.0012 - 109ms/epoch - 7ms/step
# Epoch 399/500
# 15/15 - 0s - loss: 6.9171e-04 - val_loss: 0.0013 - 96ms/epoch - 6ms/step
# Epoch 400/500
# 15/15 - 0s - loss: 7.0362e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 401/500
# 15/15 - 0s - loss: 6.9135e-04 - val_loss: 0.0013 - 101ms/epoch - 7ms/step
# Epoch 402/500
# 15/15 - 0s - loss: 7.0262e-04 - val_loss: 0.0012 - 103ms/epoch - 7ms/step
# Epoch 403/500
# 15/15 - 0s - loss: 6.9097e-04 - val_loss: 0.0013 - 98ms/epoch - 7ms/step
# Epoch 404/500
# 15/15 - 0s - loss: 7.0183e-04 - val_loss: 0.0012 - 102ms/epoch - 7ms/step
# Epoch 405/500
# 15/15 - 0s - loss: 6.9057e-04 - val_loss: 0.0013 - 108ms/epoch - 7ms/step
# Epoch 406/500
# 15/15 - 0s - loss: 7.0121e-04 - val_loss: 0.0012 - 105ms/epoch - 7ms/step
# Epoch 407/500
# 15/15 - 0s - loss: 6.9014e-04 - val_loss: 0.0013 - 128ms/epoch - 9ms/step
# Epoch 408/500
# 15/15 - 0s - loss: 7.0074e-04 - val_loss: 0.0012 - 106ms/epoch - 7ms/step
# Epoch 409/500
# 15/15 - 0s - loss: 6.8968e-04 - val_loss: 0.0013 - 97ms/epoch - 6ms/step
# Epoch 410/500
# 15/15 - 0s - loss: 7.0042e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 411/500
# 15/15 - 0s - loss: 6.8919e-04 - val_loss: 0.0013 - 103ms/epoch - 7ms/step
# Epoch 412/500
# 15/15 - 0s - loss: 7.0023e-04 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 413/500
# 15/15 - 0s - loss: 6.8865e-04 - val_loss: 0.0013 - 103ms/epoch - 7ms/step
# Epoch 414/500
# 15/15 - 0s - loss: 7.0018e-04 - val_loss: 0.0012 - 101ms/epoch - 7ms/step
# Epoch 415/500
# 15/15 - 0s - loss: 6.8808e-04 - val_loss: 0.0013 - 137ms/epoch - 9ms/step
# Epoch 416/500
# 15/15 - 0s - loss: 7.0028e-04 - val_loss: 0.0012 - 121ms/epoch - 8ms/step
# Epoch 417/500
# 15/15 - 0s - loss: 6.8746e-04 - val_loss: 0.0013 - 124ms/epoch - 8ms/step
# Epoch 418/500
# 15/15 - 0s - loss: 7.0055e-04 - val_loss: 0.0012 - 108ms/epoch - 7ms/step
# Epoch 419/500
# 15/15 - 0s - loss: 6.8682e-04 - val_loss: 0.0013 - 169ms/epoch - 11ms/step
# Epoch 420/500
# 15/15 - 0s - loss: 7.0101e-04 - val_loss: 0.0012 - 128ms/epoch - 9ms/step
# Epoch 421/500
# 15/15 - 0s - loss: 6.8614e-04 - val_loss: 0.0013 - 124ms/epoch - 8ms/step
# Epoch 422/500
# 15/15 - 0s - loss: 7.0168e-04 - val_loss: 0.0012 - 138ms/epoch - 9ms/step
# Epoch 423/500
# 15/15 - 0s - loss: 6.8546e-04 - val_loss: 0.0013 - 131ms/epoch - 9ms/step
# Epoch 424/500
# 15/15 - 0s - loss: 7.0259e-04 - val_loss: 0.0012 - 97ms/epoch - 6ms/step
# Epoch 425/500
# 15/15 - 0s - loss: 6.8479e-04 - val_loss: 0.0013 - 111ms/epoch - 7ms/step
# Epoch 426/500
# 15/15 - 0s - loss: 7.0375e-04 - val_loss: 0.0012 - 106ms/epoch - 7ms/step
# Epoch 427/500
# 15/15 - 0s - loss: 6.8416e-04 - val_loss: 0.0013 - 100ms/epoch - 7ms/step
# Epoch 428/500
# 15/15 - 0s - loss: 7.0514e-04 - val_loss: 0.0012 - 104ms/epoch - 7ms/step
# Epoch 429/500
# 15/15 - 0s - loss: 6.8360e-04 - val_loss: 0.0013 - 101ms/epoch - 7ms/step
# Epoch 430/500
# 15/15 - 0s - loss: 7.0673e-04 - val_loss: 0.0012 - 101ms/epoch - 7ms/step
# Epoch 431/500
# 15/15 - 0s - loss: 6.8314e-04 - val_loss: 0.0013 - 93ms/epoch - 6ms/step
# Epoch 432/500
# 15/15 - 0s - loss: 7.0839e-04 - val_loss: 0.0012 - 114ms/epoch - 8ms/step
# Epoch 433/500
# 15/15 - 0s - loss: 6.8278e-04 - val_loss: 0.0013 - 97ms/epoch - 6ms/step
# Epoch 434/500
# 15/15 - 0s - loss: 7.0995e-04 - val_loss: 0.0012 - 90ms/epoch - 6ms/step
# Epoch 435/500
# 15/15 - 0s - loss: 6.8251e-04 - val_loss: 0.0014 - 96ms/epoch - 6ms/step
# Epoch 436/500
# 15/15 - 0s - loss: 7.1116e-04 - val_loss: 0.0012 - 97ms/epoch - 6ms/step
# Epoch 437/500
# 15/15 - 0s - loss: 6.8226e-04 - val_loss: 0.0014 - 106ms/epoch - 7ms/step
# Epoch 438/500
# 15/15 - 0s - loss: 7.1177e-04 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 439/500
# 15/15 - 0s - loss: 6.8196e-04 - val_loss: 0.0014 - 100ms/epoch - 7ms/step
# Epoch 440/500
# 15/15 - 0s - loss: 7.1157e-04 - val_loss: 0.0012 - 128ms/epoch - 9ms/step
# Epoch 441/500
# 15/15 - 0s - loss: 6.8153e-04 - val_loss: 0.0014 - 102ms/epoch - 7ms/step
# Epoch 442/500
# 15/15 - 0s - loss: 7.1052e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 443/500
# 15/15 - 0s - loss: 6.8095e-04 - val_loss: 0.0014 - 97ms/epoch - 6ms/step
# Epoch 444/500
# 15/15 - 0s - loss: 7.0873e-04 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 445/500
# 15/15 - 0s - loss: 6.8026e-04 - val_loss: 0.0014 - 100ms/epoch - 7ms/step
# Epoch 446/500
# 15/15 - 0s - loss: 7.0645e-04 - val_loss: 0.0012 - 162ms/epoch - 11ms/step
# Epoch 447/500
# 15/15 - 0s - loss: 6.7952e-04 - val_loss: 0.0014 - 123ms/epoch - 8ms/step
# Epoch 448/500
# 15/15 - 0s - loss: 7.0395e-04 - val_loss: 0.0012 - 117ms/epoch - 8ms/step
# Epoch 449/500
# 15/15 - 0s - loss: 6.7879e-04 - val_loss: 0.0014 - 111ms/epoch - 7ms/step
# Epoch 450/500
# 15/15 - 0s - loss: 7.0147e-04 - val_loss: 0.0012 - 105ms/epoch - 7ms/step
# Epoch 451/500
# 15/15 - 0s - loss: 6.7813e-04 - val_loss: 0.0014 - 93ms/epoch - 6ms/step
# Epoch 452/500
# 15/15 - 0s - loss: 6.9917e-04 - val_loss: 0.0012 - 100ms/epoch - 7ms/step
# Epoch 453/500
# 15/15 - 0s - loss: 6.7754e-04 - val_loss: 0.0013 - 100ms/epoch - 7ms/step
# Epoch 454/500
# 15/15 - 0s - loss: 6.9714e-04 - val_loss: 0.0012 - 103ms/epoch - 7ms/step
# Epoch 455/500
# 15/15 - 0s - loss: 6.7702e-04 - val_loss: 0.0013 - 101ms/epoch - 7ms/step
# Epoch 456/500
# 15/15 - 0s - loss: 6.9540e-04 - val_loss: 0.0012 - 144ms/epoch - 10ms/step
# Epoch 457/500
# 15/15 - 0s - loss: 6.7656e-04 - val_loss: 0.0013 - 122ms/epoch - 8ms/step
# Epoch 458/500
# 15/15 - 0s - loss: 6.9394e-04 - val_loss: 0.0012 - 107ms/epoch - 7ms/step
# Epoch 459/500
# 15/15 - 0s - loss: 6.7613e-04 - val_loss: 0.0013 - 102ms/epoch - 7ms/step
# Epoch 460/500
# 15/15 - 0s - loss: 6.9275e-04 - val_loss: 0.0013 - 104ms/epoch - 7ms/step
# Epoch 461/500
# 15/15 - 0s - loss: 6.7572e-04 - val_loss: 0.0013 - 111ms/epoch - 7ms/step
# Epoch 462/500
# 15/15 - 0s - loss: 6.9179e-04 - val_loss: 0.0013 - 110ms/epoch - 7ms/step
# Epoch 463/500
# 15/15 - 0s - loss: 6.7531e-04 - val_loss: 0.0013 - 146ms/epoch - 10ms/step
# Epoch 464/500
# 15/15 - 0s - loss: 6.9105e-04 - val_loss: 0.0013 - 112ms/epoch - 7ms/step
# Epoch 465/500
# 15/15 - 0s - loss: 6.7489e-04 - val_loss: 0.0014 - 118ms/epoch - 8ms/step
# Epoch 466/500
# 15/15 - 0s - loss: 6.9049e-04 - val_loss: 0.0013 - 111ms/epoch - 7ms/step
# Epoch 467/500
# 15/15 - 0s - loss: 6.7444e-04 - val_loss: 0.0014 - 105ms/epoch - 7ms/step
# Epoch 468/500
# 15/15 - 0s - loss: 6.9011e-04 - val_loss: 0.0013 - 103ms/epoch - 7ms/step
# Epoch 469/500
# 15/15 - 0s - loss: 6.7396e-04 - val_loss: 0.0014 - 102ms/epoch - 7ms/step
# Epoch 470/500
# 15/15 - 0s - loss: 6.8990e-04 - val_loss: 0.0013 - 190ms/epoch - 13ms/step
# Epoch 471/500
# 15/15 - 0s - loss: 6.7345e-04 - val_loss: 0.0014 - 123ms/epoch - 8ms/step
# Epoch 472/500
# 15/15 - 0s - loss: 6.8985e-04 - val_loss: 0.0013 - 106ms/epoch - 7ms/step
# Epoch 473/500
# 15/15 - 0s - loss: 6.7292e-04 - val_loss: 0.0014 - 100ms/epoch - 7ms/step
# Epoch 474/500
# 15/15 - 0s - loss: 6.8996e-04 - val_loss: 0.0013 - 108ms/epoch - 7ms/step
# Epoch 475/500
# 15/15 - 0s - loss: 6.7236e-04 - val_loss: 0.0014 - 100ms/epoch - 7ms/step
# Epoch 476/500
# 15/15 - 0s - loss: 6.9025e-04 - val_loss: 0.0013 - 96ms/epoch - 6ms/step
# Epoch 477/500
# 15/15 - 0s - loss: 6.7180e-04 - val_loss: 0.0014 - 128ms/epoch - 9ms/step
# Epoch 478/500
# 15/15 - 0s - loss: 6.9071e-04 - val_loss: 0.0013 - 118ms/epoch - 8ms/step
# Epoch 479/500
# 15/15 - 0s - loss: 6.7122e-04 - val_loss: 0.0014 - 116ms/epoch - 8ms/step
# Epoch 480/500
# 15/15 - 0s - loss: 6.9134e-04 - val_loss: 0.0013 - 107ms/epoch - 7ms/step
# Epoch 481/500
# 15/15 - 0s - loss: 6.7067e-04 - val_loss: 0.0014 - 108ms/epoch - 7ms/step
# Epoch 482/500
# 15/15 - 0s - loss: 6.9213e-04 - val_loss: 0.0013 - 105ms/epoch - 7ms/step
# Epoch 483/500
# 15/15 - 0s - loss: 6.7014e-04 - val_loss: 0.0014 - 105ms/epoch - 7ms/step
# Epoch 484/500
# 15/15 - 0s - loss: 6.9304e-04 - val_loss: 0.0013 - 191ms/epoch - 13ms/step
# Epoch 485/500
# 15/15 - 0s - loss: 6.6965e-04 - val_loss: 0.0014 - 107ms/epoch - 7ms/step
# Epoch 486/500
# 15/15 - 0s - loss: 6.9402e-04 - val_loss: 0.0013 - 103ms/epoch - 7ms/step
# Epoch 487/500
# 15/15 - 0s - loss: 6.6921e-04 - val_loss: 0.0014 - 106ms/epoch - 7ms/step
# Epoch 488/500
# 15/15 - 0s - loss: 6.9499e-04 - val_loss: 0.0013 - 101ms/epoch - 7ms/step
# Epoch 489/500
# 15/15 - 0s - loss: 6.6881e-04 - val_loss: 0.0014 - 107ms/epoch - 7ms/step
# Epoch 490/500
# 15/15 - 0s - loss: 6.9582e-04 - val_loss: 0.0013 - 99ms/epoch - 7ms/step
# Epoch 491/500
# 15/15 - 0s - loss: 6.6845e-04 - val_loss: 0.0014 - 123ms/epoch - 8ms/step
# Epoch 492/500
# 15/15 - 0s - loss: 6.9638e-04 - val_loss: 0.0013 - 96ms/epoch - 6ms/step
# Epoch 493/500
# 15/15 - 0s - loss: 6.6808e-04 - val_loss: 0.0014 - 90ms/epoch - 6ms/step
# Epoch 494/500
# 15/15 - 0s - loss: 6.9657e-04 - val_loss: 0.0013 - 103ms/epoch - 7ms/step
# Epoch 495/500
# 15/15 - 0s - loss: 6.6768e-04 - val_loss: 0.0014 - 105ms/epoch - 7ms/step
# Epoch 496/500
# 15/15 - 0s - loss: 6.9630e-04 - val_loss: 0.0013 - 167ms/epoch - 11ms/step
# Epoch 497/500
# 15/15 - 0s - loss: 6.6723e-04 - val_loss: 0.0014 - 105ms/epoch - 7ms/step
# Epoch 498/500
# 15/15 - 0s - loss: 6.9555e-04 - val_loss: 0.0013 - 110ms/epoch - 7ms/step
# Epoch 499/500
# 15/15 - 0s - loss: 6.6672e-04 - val_loss: 0.0014 - 101ms/epoch - 7ms/step
# Epoch 500/500
# 15/15 - 0s - loss: 6.9436e-04 - val_loss: 0.0013 - 96ms/epoch - 6ms/step

# %% [markdown]
# ## Metrics ($VPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
phy = phys2(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 8/8 [==============================] - 1s 2ms/step
# (237, 3)
# (237, 10)
# Test RMSE: 16.387
# Test MAE: 11.481

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('San Juan Dengue Spread', fontsize=20)
plt.legend(fontsize=20)
plt.show()
