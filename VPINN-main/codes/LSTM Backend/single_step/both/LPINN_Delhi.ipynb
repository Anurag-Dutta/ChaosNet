# %% [markdown]
# # Time Series Prediction with Lorrenz Attractor Inspired Deep Learning ($LPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-09 19:25:04

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Lorrenz Intermittency_

# %% [markdown]
# The `lorrenz_intermittency.dat` is generated from the Runge Kutta Method.

# %% [markdown]
# This feeds the model with the dynamics of the Lorrenz Attractor

# %%
data = np.genfromtxt('datasets/lorrenz_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 1 # Daily Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 28.981277697415116
# 1         0.017078
# 2         0.040967
# 3         0.062716
# 4         0.083177
# 5         0.103056
#             ...
# 139867    0.104426
# 139868    0.064373
# 139869    0.028379
# 139870   -0.003762
# 139871   -0.032367
# Name: 1, Length: 139871, dtype: float64
# 2         0.023889
# 3         0.021749
# 4         0.020461
# 5         0.019879
# 6         0.019892
#             ...
# 139867   -0.044158
# 139868   -0.040053
# 139869   -0.035994
# 139870   -0.032141
# 139871   -0.028605
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _दिल्ली WIND SPEED_

# %%
data = pd.read_csv("datasets/delhi.csv")
training_set = data.iloc[:, 3]
print(training_set)
# Out:
# 0       0.000000
# 1       2.980000
# 2       4.633333
# 3       1.233333
# 4       3.700000
#           ...
# 1457    3.547826
# 1458    6.000000
# 1459    6.266667
# 1460    7.325000
# 1461    0.000000
# Name: wind_speed, Length: 1462, dtype: float64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0         0.017078
# 1         0.040967
# 2         0.062716
# 3         0.083177
# 4         0.103056
#             ...
# 139866    0.104426
# 139867    0.064373
# 139868    0.028379
# 139869   -0.003762
# 139870   -0.032367
# Name: 1, Length: 139871, dtype: float64
# 0         0.023889
# 1         0.021749
# 2         0.020461
# 3         0.019879
# 4         0.019892
#             ...
# 139865   -0.044158
# 139866   -0.040053
# 139867   -0.035994
# 139868   -0.032141
# 139869   -0.028605
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lorrenz Equation_)

# %% [markdown]
# _Parameters_: $\sigma=10, \rho=28$

# %%
s=10
r=28
L = df.iloc[:, 2] + df.iloc[:, 1]*(1 + s) - df.iloc[:, 0] * s * (r - 1)
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10    0.000000   2.980000   4.633333   1.233333   3.700000   1.480000
# 11    2.980000   4.633333   1.233333   3.700000   1.480000   6.300000
# 12    4.633333   1.233333   3.700000   1.480000   6.300000   7.142857
# 13    1.233333   3.700000   1.480000   6.300000   7.142857  12.500000
# 14    3.700000   1.480000   6.300000   7.142857  12.500000   7.400000
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)    var1(t)   var2(t)   var3(t)
# 10   6.300000   7.142857  12.500000   7.400000  10.571429  0.239024  0.029386
# 11   7.142857  12.500000   7.400000  10.571429  13.228571  0.268410  0.032352
# 12  12.500000   7.400000  10.571429  13.228571   4.633333  0.300761  0.035718
# 13   7.400000  10.571429  13.228571   4.633333   0.616667  0.336479  0.039500
# 14  10.571429  13.228571   4.633333   0.616667   0.528571  0.375979  0.043711
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (1451, 13)
# (1451, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (1160, 1, 10) (1160, 3) (291, 1, 10) (291, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
s = tf.Variable(10, name="sigma", trainable=True, dtype=tf.float32)
r = tf.Variable(28, name="rhow", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] + y_true[:, 1]*(1 + s) - y_true[:, 0] * s * (r - 1)), (y_pred[:, 2] + y_pred[:, 1]*(1 + s) - y_pred[:, 0] * s * (r - 1)))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] + (y_pred[1:-1]-y_pred[:-2])*(1 + s) - y_pred[:-2] * s * (r - 1)
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] + (y_real[1:-1]-y_real[:-2])*(1 + s) - y_real[:-2] * s * (r - 1)
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($LPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square((y_pred[:, 2] + y_pred[:, 1]*(1 + s) - y_pred[:, 0] * s * (r - 1)))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 19/19 - 3s - loss: 0.3861 - val_loss: 0.0773 - 3s/epoch - 132ms/step
# Epoch 2/500
# 19/19 - 0s - loss: 0.0671 - val_loss: 0.0437 - 61ms/epoch - 3ms/step
# Epoch 3/500
# 19/19 - 0s - loss: 0.0407 - val_loss: 0.0435 - 56ms/epoch - 3ms/step
# Epoch 4/500
# 19/19 - 0s - loss: 0.0392 - val_loss: 0.0422 - 56ms/epoch - 3ms/step
# Epoch 5/500
# 19/19 - 0s - loss: 0.0385 - val_loss: 0.0424 - 59ms/epoch - 3ms/step
# Epoch 6/500
# 19/19 - 0s - loss: 0.0386 - val_loss: 0.0423 - 57ms/epoch - 3ms/step
# Epoch 7/500
# 19/19 - 0s - loss: 0.0399 - val_loss: 0.0424 - 58ms/epoch - 3ms/step
# Epoch 8/500
# 19/19 - 0s - loss: 0.0424 - val_loss: 0.0496 - 56ms/epoch - 3ms/step
# Epoch 9/500
# 19/19 - 0s - loss: 0.0423 - val_loss: 0.0439 - 57ms/epoch - 3ms/step
# Epoch 10/500
# 19/19 - 0s - loss: 0.0420 - val_loss: 0.0471 - 58ms/epoch - 3ms/step
# Epoch 11/500
# 19/19 - 0s - loss: 0.0410 - val_loss: 0.0426 - 57ms/epoch - 3ms/step
# Epoch 12/500
# 19/19 - 0s - loss: 0.0445 - val_loss: 0.0515 - 58ms/epoch - 3ms/step
# Epoch 13/500
# 19/19 - 0s - loss: 0.0428 - val_loss: 0.0569 - 57ms/epoch - 3ms/step
# Epoch 14/500
# 19/19 - 0s - loss: 0.0726 - val_loss: 0.1361 - 65ms/epoch - 3ms/step
# Epoch 15/500
# 19/19 - 0s - loss: 0.0658 - val_loss: 0.0674 - 69ms/epoch - 4ms/step
# Epoch 16/500
# 19/19 - 0s - loss: 0.0456 - val_loss: 0.0552 - 70ms/epoch - 4ms/step
# Epoch 17/500
# 19/19 - 0s - loss: 0.0393 - val_loss: 0.0423 - 82ms/epoch - 4ms/step
# Epoch 18/500
# 19/19 - 0s - loss: 0.0384 - val_loss: 0.0420 - 73ms/epoch - 4ms/step
# Epoch 19/500
# 19/19 - 0s - loss: 0.0379 - val_loss: 0.0423 - 64ms/epoch - 3ms/step
# Epoch 20/500
# 19/19 - 0s - loss: 0.0388 - val_loss: 0.0423 - 68ms/epoch - 4ms/step
# Epoch 21/500
# 19/19 - 0s - loss: 0.0376 - val_loss: 0.0417 - 74ms/epoch - 4ms/step
# Epoch 22/500
# 19/19 - 0s - loss: 0.0394 - val_loss: 0.0429 - 68ms/epoch - 4ms/step
# Epoch 23/500
# 19/19 - 0s - loss: 0.0384 - val_loss: 0.0442 - 69ms/epoch - 4ms/step
# Epoch 24/500
# 19/19 - 0s - loss: 0.0476 - val_loss: 0.0579 - 70ms/epoch - 4ms/step
# Epoch 25/500
# 19/19 - 0s - loss: 0.0705 - val_loss: 0.1337 - 99ms/epoch - 5ms/step
# Epoch 26/500
# 19/19 - 0s - loss: 0.1104 - val_loss: 0.1483 - 68ms/epoch - 4ms/step
# Epoch 27/500
# 19/19 - 0s - loss: 0.0770 - val_loss: 0.1106 - 57ms/epoch - 3ms/step
# Epoch 28/500
# 19/19 - 0s - loss: 0.0713 - val_loss: 0.0787 - 58ms/epoch - 3ms/step
# Epoch 29/500
# 19/19 - 0s - loss: 0.0947 - val_loss: 0.0732 - 57ms/epoch - 3ms/step
# Epoch 30/500
# 19/19 - 0s - loss: 0.1431 - val_loss: 0.0433 - 61ms/epoch - 3ms/step
# Epoch 31/500
# 19/19 - 0s - loss: 0.2009 - val_loss: 0.1080 - 63ms/epoch - 3ms/step
# Epoch 32/500
# 19/19 - 0s - loss: 0.1017 - val_loss: 0.0466 - 62ms/epoch - 3ms/step
# Epoch 33/500
# 19/19 - 0s - loss: 0.0416 - val_loss: 0.0436 - 61ms/epoch - 3ms/step
# Epoch 34/500
# 19/19 - 0s - loss: 0.0374 - val_loss: 0.0414 - 59ms/epoch - 3ms/step
# Epoch 35/500
# 19/19 - 0s - loss: 0.0372 - val_loss: 0.0414 - 48ms/epoch - 3ms/step
# Epoch 36/500
# 19/19 - 0s - loss: 0.0368 - val_loss: 0.0413 - 58ms/epoch - 3ms/step
# Epoch 37/500
# 19/19 - 0s - loss: 0.0367 - val_loss: 0.0413 - 59ms/epoch - 3ms/step
# Epoch 38/500
# 19/19 - 0s - loss: 0.0367 - val_loss: 0.0413 - 59ms/epoch - 3ms/step
# Epoch 39/500
# 19/19 - 0s - loss: 0.0367 - val_loss: 0.0413 - 59ms/epoch - 3ms/step
# Epoch 40/500
# 19/19 - 0s - loss: 0.0367 - val_loss: 0.0413 - 59ms/epoch - 3ms/step
# Epoch 41/500
# 19/19 - 0s - loss: 0.0366 - val_loss: 0.0413 - 60ms/epoch - 3ms/step
# Epoch 42/500
# 19/19 - 0s - loss: 0.0366 - val_loss: 0.0413 - 60ms/epoch - 3ms/step
# Epoch 43/500
# 19/19 - 0s - loss: 0.0366 - val_loss: 0.0412 - 58ms/epoch - 3ms/step
# Epoch 44/500
# 19/19 - 0s - loss: 0.0366 - val_loss: 0.0412 - 63ms/epoch - 3ms/step
# Epoch 45/500
# 19/19 - 0s - loss: 0.0366 - val_loss: 0.0412 - 62ms/epoch - 3ms/step
# Epoch 46/500
# 19/19 - 0s - loss: 0.0366 - val_loss: 0.0412 - 66ms/epoch - 3ms/step
# Epoch 47/500
# 19/19 - 0s - loss: 0.0365 - val_loss: 0.0412 - 68ms/epoch - 4ms/step
# Epoch 48/500
# 19/19 - 0s - loss: 0.0365 - val_loss: 0.0412 - 84ms/epoch - 4ms/step
# Epoch 49/500
# 19/19 - 0s - loss: 0.0365 - val_loss: 0.0412 - 79ms/epoch - 4ms/step
# Epoch 50/500
# 19/19 - 0s - loss: 0.0365 - val_loss: 0.0412 - 70ms/epoch - 4ms/step
# Epoch 51/500
# 19/19 - 0s - loss: 0.0365 - val_loss: 0.0411 - 68ms/epoch - 4ms/step
# Epoch 52/500
# 19/19 - 0s - loss: 0.0365 - val_loss: 0.0411 - 69ms/epoch - 4ms/step
# Epoch 53/500
# 19/19 - 0s - loss: 0.0365 - val_loss: 0.0411 - 60ms/epoch - 3ms/step
# Epoch 54/500
# 19/19 - 0s - loss: 0.0366 - val_loss: 0.0412 - 60ms/epoch - 3ms/step
# Epoch 55/500
# 19/19 - 0s - loss: 0.0367 - val_loss: 0.0411 - 60ms/epoch - 3ms/step
# Epoch 56/500
# 19/19 - 0s - loss: 0.0374 - val_loss: 0.0418 - 60ms/epoch - 3ms/step
# Epoch 57/500
# 19/19 - 0s - loss: 0.0382 - val_loss: 0.0418 - 57ms/epoch - 3ms/step
# Epoch 58/500
# 19/19 - 0s - loss: 0.0407 - val_loss: 0.0448 - 58ms/epoch - 3ms/step
# Epoch 59/500
# 19/19 - 0s - loss: 0.0436 - val_loss: 0.0460 - 60ms/epoch - 3ms/step
# Epoch 60/500
# 19/19 - 0s - loss: 0.0507 - val_loss: 0.0534 - 59ms/epoch - 3ms/step
# Epoch 61/500
# 19/19 - 0s - loss: 0.0608 - val_loss: 0.0569 - 58ms/epoch - 3ms/step
# Epoch 62/500
# 19/19 - 0s - loss: 0.0850 - val_loss: 0.0665 - 60ms/epoch - 3ms/step
# Epoch 63/500
# 19/19 - 0s - loss: 0.1371 - val_loss: 0.0525 - 65ms/epoch - 3ms/step
# Epoch 64/500
# 19/19 - 0s - loss: 0.2432 - val_loss: 0.1003 - 68ms/epoch - 4ms/step
# Epoch 65/500
# 19/19 - 0s - loss: 0.2508 - val_loss: 0.0935 - 74ms/epoch - 4ms/step
# Epoch 66/500
# 19/19 - 0s - loss: 0.0595 - val_loss: 0.0483 - 68ms/epoch - 4ms/step
# Epoch 67/500
# 19/19 - 0s - loss: 0.0387 - val_loss: 0.0411 - 63ms/epoch - 3ms/step
# Epoch 68/500
# 19/19 - 0s - loss: 0.0369 - val_loss: 0.0410 - 59ms/epoch - 3ms/step
# Epoch 69/500
# 19/19 - 0s - loss: 0.0364 - val_loss: 0.0410 - 62ms/epoch - 3ms/step
# Epoch 70/500
# 19/19 - 0s - loss: 0.0364 - val_loss: 0.0410 - 70ms/epoch - 4ms/step
# Epoch 71/500
# 19/19 - 0s - loss: 0.0363 - val_loss: 0.0410 - 70ms/epoch - 4ms/step
# Epoch 72/500
# 19/19 - 0s - loss: 0.0363 - val_loss: 0.0410 - 75ms/epoch - 4ms/step
# Epoch 73/500
# 19/19 - 0s - loss: 0.0363 - val_loss: 0.0410 - 88ms/epoch - 5ms/step
# Epoch 74/500
# 19/19 - 0s - loss: 0.0363 - val_loss: 0.0410 - 71ms/epoch - 4ms/step
# Epoch 75/500
# 19/19 - 0s - loss: 0.0363 - val_loss: 0.0409 - 74ms/epoch - 4ms/step
# Epoch 76/500
# 19/19 - 0s - loss: 0.0363 - val_loss: 0.0409 - 71ms/epoch - 4ms/step
# Epoch 77/500
# 19/19 - 0s - loss: 0.0363 - val_loss: 0.0409 - 74ms/epoch - 4ms/step
# Epoch 78/500
# 19/19 - 0s - loss: 0.0363 - val_loss: 0.0409 - 79ms/epoch - 4ms/step
# Epoch 79/500
# 19/19 - 0s - loss: 0.0363 - val_loss: 0.0409 - 77ms/epoch - 4ms/step
# Epoch 80/500
# 19/19 - 0s - loss: 0.0362 - val_loss: 0.0409 - 69ms/epoch - 4ms/step
# Epoch 81/500
# 19/19 - 0s - loss: 0.0362 - val_loss: 0.0409 - 65ms/epoch - 3ms/step
# Epoch 82/500
# 19/19 - 0s - loss: 0.0362 - val_loss: 0.0409 - 68ms/epoch - 4ms/step
# Epoch 83/500
# 19/19 - 0s - loss: 0.0362 - val_loss: 0.0409 - 78ms/epoch - 4ms/step
# Epoch 84/500
# 19/19 - 0s - loss: 0.0362 - val_loss: 0.0409 - 71ms/epoch - 4ms/step
# Epoch 85/500
# 19/19 - 0s - loss: 0.0362 - val_loss: 0.0409 - 74ms/epoch - 4ms/step
# Epoch 86/500
# 19/19 - 0s - loss: 0.0362 - val_loss: 0.0409 - 70ms/epoch - 4ms/step
# Epoch 87/500
# 19/19 - 0s - loss: 0.0362 - val_loss: 0.0408 - 84ms/epoch - 4ms/step
# Epoch 88/500
# 19/19 - 0s - loss: 0.0362 - val_loss: 0.0408 - 94ms/epoch - 5ms/step
# Epoch 89/500
# 19/19 - 0s - loss: 0.0362 - val_loss: 0.0408 - 89ms/epoch - 5ms/step
# Epoch 90/500
# 19/19 - 0s - loss: 0.0362 - val_loss: 0.0408 - 76ms/epoch - 4ms/step
# Epoch 91/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0408 - 80ms/epoch - 4ms/step
# Epoch 92/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0408 - 106ms/epoch - 6ms/step
# Epoch 93/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0408 - 82ms/epoch - 4ms/step
# Epoch 94/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0408 - 67ms/epoch - 4ms/step
# Epoch 95/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0408 - 63ms/epoch - 3ms/step
# Epoch 96/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0408 - 66ms/epoch - 3ms/step
# Epoch 97/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0408 - 64ms/epoch - 3ms/step
# Epoch 98/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0407 - 71ms/epoch - 4ms/step
# Epoch 99/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0407 - 70ms/epoch - 4ms/step
# Epoch 100/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0407 - 71ms/epoch - 4ms/step
# Epoch 101/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0407 - 72ms/epoch - 4ms/step
# Epoch 102/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0407 - 69ms/epoch - 4ms/step
# Epoch 103/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0407 - 73ms/epoch - 4ms/step
# Epoch 104/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0407 - 78ms/epoch - 4ms/step
# Epoch 105/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0407 - 81ms/epoch - 4ms/step
# Epoch 106/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0407 - 79ms/epoch - 4ms/step
# Epoch 107/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0407 - 83ms/epoch - 4ms/step
# Epoch 108/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0406 - 65ms/epoch - 3ms/step
# Epoch 109/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0407 - 66ms/epoch - 3ms/step
# Epoch 110/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0406 - 66ms/epoch - 3ms/step
# Epoch 111/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0406 - 64ms/epoch - 3ms/step
# Epoch 112/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0406 - 72ms/epoch - 4ms/step
# Epoch 113/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0406 - 77ms/epoch - 4ms/step
# Epoch 114/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0406 - 73ms/epoch - 4ms/step
# Epoch 115/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0406 - 70ms/epoch - 4ms/step
# Epoch 116/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0405 - 68ms/epoch - 4ms/step
# Epoch 117/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0406 - 73ms/epoch - 4ms/step
# Epoch 118/500
# 19/19 - 0s - loss: 0.0359 - val_loss: 0.0405 - 73ms/epoch - 4ms/step
# Epoch 119/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0407 - 75ms/epoch - 4ms/step
# Epoch 120/500
# 19/19 - 0s - loss: 0.0359 - val_loss: 0.0405 - 77ms/epoch - 4ms/step
# Epoch 121/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0407 - 78ms/epoch - 4ms/step
# Epoch 122/500
# 19/19 - 0s - loss: 0.0359 - val_loss: 0.0406 - 76ms/epoch - 4ms/step
# Epoch 123/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0410 - 77ms/epoch - 4ms/step
# Epoch 124/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0413 - 67ms/epoch - 4ms/step
# Epoch 125/500
# 19/19 - 0s - loss: 0.0371 - val_loss: 0.0431 - 65ms/epoch - 3ms/step
# Epoch 126/500
# 19/19 - 0s - loss: 0.0389 - val_loss: 0.0479 - 108ms/epoch - 6ms/step
# Epoch 127/500
# 19/19 - 0s - loss: 0.0478 - val_loss: 0.0677 - 80ms/epoch - 4ms/step
# Epoch 128/500
# 19/19 - 0s - loss: 0.0714 - val_loss: 0.1331 - 73ms/epoch - 4ms/step
# Epoch 129/500
# 19/19 - 0s - loss: 0.0906 - val_loss: 0.1355 - 71ms/epoch - 4ms/step
# Epoch 130/500
# 19/19 - 0s - loss: 0.0495 - val_loss: 0.0491 - 68ms/epoch - 4ms/step
# Epoch 131/500
# 19/19 - 0s - loss: 0.0388 - val_loss: 0.0422 - 66ms/epoch - 3ms/step
# Epoch 132/500
# 19/19 - 0s - loss: 0.0369 - val_loss: 0.0411 - 69ms/epoch - 4ms/step
# Epoch 133/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0405 - 81ms/epoch - 4ms/step
# Epoch 134/500
# 19/19 - 0s - loss: 0.0373 - val_loss: 0.0423 - 77ms/epoch - 4ms/step
# Epoch 135/500
# 19/19 - 0s - loss: 0.0363 - val_loss: 0.0405 - 80ms/epoch - 4ms/step
# Epoch 136/500
# 19/19 - 0s - loss: 0.0376 - val_loss: 0.0425 - 71ms/epoch - 4ms/step
# Epoch 137/500
# 19/19 - 0s - loss: 0.0363 - val_loss: 0.0405 - 70ms/epoch - 4ms/step
# Epoch 138/500
# 19/19 - 0s - loss: 0.0380 - val_loss: 0.0429 - 66ms/epoch - 3ms/step
# Epoch 139/500
# 19/19 - 0s - loss: 0.0365 - val_loss: 0.0405 - 66ms/epoch - 3ms/step
# Epoch 140/500
# 19/19 - 0s - loss: 0.0386 - val_loss: 0.0433 - 68ms/epoch - 4ms/step
# Epoch 141/500
# 19/19 - 0s - loss: 0.0368 - val_loss: 0.0406 - 66ms/epoch - 3ms/step
# Epoch 142/500
# 19/19 - 0s - loss: 0.0391 - val_loss: 0.0435 - 63ms/epoch - 3ms/step
# Epoch 143/500
# 19/19 - 0s - loss: 0.0369 - val_loss: 0.0407 - 63ms/epoch - 3ms/step
# Epoch 144/500
# 19/19 - 0s - loss: 0.0394 - val_loss: 0.0437 - 66ms/epoch - 3ms/step
# Epoch 145/500
# 19/19 - 0s - loss: 0.0370 - val_loss: 0.0408 - 68ms/epoch - 4ms/step
# Epoch 146/500
# 19/19 - 0s - loss: 0.0396 - val_loss: 0.0439 - 65ms/epoch - 3ms/step
# Epoch 147/500
# 19/19 - 0s - loss: 0.0369 - val_loss: 0.0410 - 72ms/epoch - 4ms/step
# Epoch 148/500
# 19/19 - 0s - loss: 0.0397 - val_loss: 0.0443 - 73ms/epoch - 4ms/step
# Epoch 149/500
# 19/19 - 0s - loss: 0.0368 - val_loss: 0.0417 - 80ms/epoch - 4ms/step
# Epoch 150/500
# 19/19 - 0s - loss: 0.0405 - val_loss: 0.0462 - 68ms/epoch - 4ms/step
# Epoch 151/500
# 19/19 - 0s - loss: 0.0376 - val_loss: 0.0448 - 67ms/epoch - 4ms/step
# Epoch 152/500
# 19/19 - 0s - loss: 0.0440 - val_loss: 0.0540 - 70ms/epoch - 4ms/step
# Epoch 153/500
# 19/19 - 0s - loss: 0.0425 - val_loss: 0.0575 - 72ms/epoch - 4ms/step
# Epoch 154/500
# 19/19 - 0s - loss: 0.0537 - val_loss: 0.0758 - 72ms/epoch - 4ms/step
# Epoch 155/500
# 19/19 - 0s - loss: 0.0482 - val_loss: 0.0648 - 69ms/epoch - 4ms/step
# Epoch 156/500
# 19/19 - 0s - loss: 0.0448 - val_loss: 0.0507 - 78ms/epoch - 4ms/step
# Epoch 157/500
# 19/19 - 0s - loss: 0.0372 - val_loss: 0.0405 - 72ms/epoch - 4ms/step
# Epoch 158/500
# 19/19 - 0s - loss: 0.0369 - val_loss: 0.0431 - 83ms/epoch - 4ms/step
# Epoch 159/500
# 19/19 - 0s - loss: 0.0453 - val_loss: 0.0585 - 80ms/epoch - 4ms/step
# Epoch 160/500
# 19/19 - 0s - loss: 0.0452 - val_loss: 0.0605 - 74ms/epoch - 4ms/step
# Epoch 161/500
# 19/19 - 0s - loss: 0.0518 - val_loss: 0.0662 - 80ms/epoch - 4ms/step
# Epoch 162/500
# 19/19 - 0s - loss: 0.0405 - val_loss: 0.0444 - 89ms/epoch - 5ms/step
# Epoch 163/500
# 19/19 - 0s - loss: 0.0387 - val_loss: 0.0430 - 85ms/epoch - 4ms/step
# Epoch 164/500
# 19/19 - 0s - loss: 0.0366 - val_loss: 0.0404 - 72ms/epoch - 4ms/step
# Epoch 165/500
# 19/19 - 0s - loss: 0.0369 - val_loss: 0.0410 - 82ms/epoch - 4ms/step
# Epoch 166/500
# 19/19 - 0s - loss: 0.0371 - val_loss: 0.0409 - 79ms/epoch - 4ms/step
# Epoch 167/500
# 19/19 - 0s - loss: 0.0370 - val_loss: 0.0408 - 76ms/epoch - 4ms/step
# Epoch 168/500
# 19/19 - 0s - loss: 0.0374 - val_loss: 0.0411 - 98ms/epoch - 5ms/step
# Epoch 169/500
# 19/19 - 0s - loss: 0.0371 - val_loss: 0.0407 - 77ms/epoch - 4ms/step
# Epoch 170/500
# 19/19 - 0s - loss: 0.0375 - val_loss: 0.0411 - 75ms/epoch - 4ms/step
# Epoch 171/500
# 19/19 - 0s - loss: 0.0368 - val_loss: 0.0405 - 76ms/epoch - 4ms/step
# Epoch 172/500
# 19/19 - 0s - loss: 0.0375 - val_loss: 0.0411 - 73ms/epoch - 4ms/step
# Epoch 173/500
# 19/19 - 0s - loss: 0.0364 - val_loss: 0.0403 - 66ms/epoch - 3ms/step
# Epoch 174/500
# 19/19 - 0s - loss: 0.0375 - val_loss: 0.0415 - 74ms/epoch - 4ms/step
# Epoch 175/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0410 - 75ms/epoch - 4ms/step
# Epoch 176/500
# 19/19 - 0s - loss: 0.0393 - val_loss: 0.0451 - 77ms/epoch - 4ms/step
# Epoch 177/500
# 19/19 - 0s - loss: 0.0399 - val_loss: 0.0511 - 67ms/epoch - 4ms/step
# Epoch 178/500
# 19/19 - 0s - loss: 0.0557 - val_loss: 0.0832 - 70ms/epoch - 4ms/step
# Epoch 179/500
# 19/19 - 0s - loss: 0.0709 - val_loss: 0.1269 - 73ms/epoch - 4ms/step
# Epoch 180/500
# 19/19 - 0s - loss: 0.0629 - val_loss: 0.0623 - 64ms/epoch - 3ms/step
# Epoch 181/500
# 19/19 - 0s - loss: 0.0436 - val_loss: 0.0523 - 68ms/epoch - 4ms/step
# Epoch 182/500
# 19/19 - 0s - loss: 0.0381 - val_loss: 0.0406 - 80ms/epoch - 4ms/step
# Epoch 183/500
# 19/19 - 0s - loss: 0.0420 - val_loss: 0.0465 - 72ms/epoch - 4ms/step
# Epoch 184/500
# 19/19 - 0s - loss: 0.0396 - val_loss: 0.0414 - 71ms/epoch - 4ms/step
# Epoch 185/500
# 19/19 - 0s - loss: 0.0464 - val_loss: 0.0504 - 76ms/epoch - 4ms/step
# Epoch 186/500
# 19/19 - 0s - loss: 0.0455 - val_loss: 0.0449 - 70ms/epoch - 4ms/step
# Epoch 187/500
# 19/19 - 0s - loss: 0.0572 - val_loss: 0.0566 - 67ms/epoch - 4ms/step
# Epoch 188/500
# 19/19 - 0s - loss: 0.0666 - val_loss: 0.0563 - 70ms/epoch - 4ms/step
# Epoch 189/500
# 19/19 - 0s - loss: 0.1040 - val_loss: 0.0633 - 96ms/epoch - 5ms/step
# Epoch 190/500
# 19/19 - 0s - loss: 0.1838 - val_loss: 0.0532 - 80ms/epoch - 4ms/step
# Epoch 191/500
# 19/19 - 0s - loss: 0.2957 - val_loss: 0.1927 - 67ms/epoch - 4ms/step
# Epoch 192/500
# 19/19 - 0s - loss: 0.1056 - val_loss: 0.0434 - 65ms/epoch - 3ms/step
# Epoch 193/500
# 19/19 - 0s - loss: 0.0403 - val_loss: 0.0408 - 70ms/epoch - 4ms/step
# Epoch 194/500
# 19/19 - 0s - loss: 0.0383 - val_loss: 0.0403 - 71ms/epoch - 4ms/step
# Epoch 195/500
# 19/19 - 0s - loss: 0.0357 - val_loss: 0.0402 - 73ms/epoch - 4ms/step
# Epoch 196/500
# 19/19 - 0s - loss: 0.0356 - val_loss: 0.0401 - 71ms/epoch - 4ms/step
# Epoch 197/500
# 19/19 - 0s - loss: 0.0355 - val_loss: 0.0401 - 76ms/epoch - 4ms/step
# Epoch 198/500
# 19/19 - 0s - loss: 0.0355 - val_loss: 0.0400 - 71ms/epoch - 4ms/step
# Epoch 199/500
# 19/19 - 0s - loss: 0.0355 - val_loss: 0.0400 - 66ms/epoch - 3ms/step
# Epoch 200/500
# 19/19 - 0s - loss: 0.0355 - val_loss: 0.0400 - 72ms/epoch - 4ms/step
# Epoch 201/500
# 19/19 - 0s - loss: 0.0354 - val_loss: 0.0400 - 72ms/epoch - 4ms/step
# Epoch 202/500
# 19/19 - 0s - loss: 0.0354 - val_loss: 0.0400 - 82ms/epoch - 4ms/step
# Epoch 203/500
# 19/19 - 0s - loss: 0.0354 - val_loss: 0.0400 - 74ms/epoch - 4ms/step
# Epoch 204/500
# 19/19 - 0s - loss: 0.0354 - val_loss: 0.0400 - 77ms/epoch - 4ms/step
# Epoch 205/500
# 19/19 - 0s - loss: 0.0354 - val_loss: 0.0400 - 66ms/epoch - 3ms/step
# Epoch 206/500
# 19/19 - 0s - loss: 0.0354 - val_loss: 0.0399 - 110ms/epoch - 6ms/step
# Epoch 207/500
# 19/19 - 0s - loss: 0.0354 - val_loss: 0.0399 - 84ms/epoch - 4ms/step
# Epoch 208/500
# 19/19 - 0s - loss: 0.0354 - val_loss: 0.0399 - 82ms/epoch - 4ms/step
# Epoch 209/500
# 19/19 - 0s - loss: 0.0354 - val_loss: 0.0399 - 79ms/epoch - 4ms/step
# Epoch 210/500
# 19/19 - 0s - loss: 0.0353 - val_loss: 0.0399 - 82ms/epoch - 4ms/step
# Epoch 211/500
# 19/19 - 0s - loss: 0.0353 - val_loss: 0.0399 - 89ms/epoch - 5ms/step
# Epoch 212/500
# 19/19 - 0s - loss: 0.0353 - val_loss: 0.0399 - 80ms/epoch - 4ms/step
# Epoch 213/500
# 19/19 - 0s - loss: 0.0353 - val_loss: 0.0399 - 72ms/epoch - 4ms/step
# Epoch 214/500
# 19/19 - 0s - loss: 0.0353 - val_loss: 0.0398 - 75ms/epoch - 4ms/step
# Epoch 215/500
# 19/19 - 0s - loss: 0.0353 - val_loss: 0.0398 - 79ms/epoch - 4ms/step
# Epoch 216/500
# 19/19 - 0s - loss: 0.0353 - val_loss: 0.0398 - 85ms/epoch - 4ms/step
# Epoch 217/500
# 19/19 - 0s - loss: 0.0353 - val_loss: 0.0398 - 76ms/epoch - 4ms/step
# Epoch 218/500
# 19/19 - 0s - loss: 0.0353 - val_loss: 0.0398 - 71ms/epoch - 4ms/step
# Epoch 219/500
# 19/19 - 0s - loss: 0.0352 - val_loss: 0.0398 - 72ms/epoch - 4ms/step
# Epoch 220/500
# 19/19 - 0s - loss: 0.0352 - val_loss: 0.0397 - 71ms/epoch - 4ms/step
# Epoch 221/500
# 19/19 - 0s - loss: 0.0352 - val_loss: 0.0397 - 76ms/epoch - 4ms/step
# Epoch 222/500
# 19/19 - 0s - loss: 0.0352 - val_loss: 0.0397 - 73ms/epoch - 4ms/step
# Epoch 223/500
# 19/19 - 0s - loss: 0.0352 - val_loss: 0.0397 - 70ms/epoch - 4ms/step
# Epoch 224/500
# 19/19 - 0s - loss: 0.0352 - val_loss: 0.0397 - 73ms/epoch - 4ms/step
# Epoch 225/500
# 19/19 - 0s - loss: 0.0352 - val_loss: 0.0397 - 79ms/epoch - 4ms/step
# Epoch 226/500
# 19/19 - 0s - loss: 0.0351 - val_loss: 0.0396 - 76ms/epoch - 4ms/step
# Epoch 227/500
# 19/19 - 0s - loss: 0.0351 - val_loss: 0.0396 - 77ms/epoch - 4ms/step
# Epoch 228/500
# 19/19 - 0s - loss: 0.0351 - val_loss: 0.0396 - 87ms/epoch - 5ms/step
# Epoch 229/500
# 19/19 - 0s - loss: 0.0351 - val_loss: 0.0396 - 96ms/epoch - 5ms/step
# Epoch 230/500
# 19/19 - 0s - loss: 0.0351 - val_loss: 0.0396 - 80ms/epoch - 4ms/step
# Epoch 231/500
# 19/19 - 0s - loss: 0.0351 - val_loss: 0.0396 - 76ms/epoch - 4ms/step
# Epoch 232/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0395 - 78ms/epoch - 4ms/step
# Epoch 233/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0395 - 67ms/epoch - 4ms/step
# Epoch 234/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0395 - 66ms/epoch - 3ms/step
# Epoch 235/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0395 - 76ms/epoch - 4ms/step
# Epoch 236/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0394 - 69ms/epoch - 4ms/step
# Epoch 237/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0394 - 70ms/epoch - 4ms/step
# Epoch 238/500
# 19/19 - 0s - loss: 0.0349 - val_loss: 0.0394 - 74ms/epoch - 4ms/step
# Epoch 239/500
# 19/19 - 0s - loss: 0.0349 - val_loss: 0.0394 - 73ms/epoch - 4ms/step
# Epoch 240/500
# 19/19 - 0s - loss: 0.0349 - val_loss: 0.0393 - 75ms/epoch - 4ms/step
# Epoch 241/500
# 19/19 - 0s - loss: 0.0349 - val_loss: 0.0393 - 80ms/epoch - 4ms/step
# Epoch 242/500
# 19/19 - 0s - loss: 0.0348 - val_loss: 0.0393 - 76ms/epoch - 4ms/step
# Epoch 243/500
# 19/19 - 0s - loss: 0.0348 - val_loss: 0.0392 - 81ms/epoch - 4ms/step
# Epoch 244/500
# 19/19 - 0s - loss: 0.0348 - val_loss: 0.0392 - 75ms/epoch - 4ms/step
# Epoch 245/500
# 19/19 - 0s - loss: 0.0347 - val_loss: 0.0391 - 93ms/epoch - 5ms/step
# Epoch 246/500
# 19/19 - 0s - loss: 0.0347 - val_loss: 0.0391 - 64ms/epoch - 3ms/step
# Epoch 247/500
# 19/19 - 0s - loss: 0.0347 - val_loss: 0.0391 - 69ms/epoch - 4ms/step
# Epoch 248/500
# 19/19 - 0s - loss: 0.0347 - val_loss: 0.0391 - 65ms/epoch - 3ms/step
# Epoch 249/500
# 19/19 - 0s - loss: 0.0352 - val_loss: 0.0399 - 73ms/epoch - 4ms/step
# Epoch 250/500
# 19/19 - 0s - loss: 0.0378 - val_loss: 0.0468 - 68ms/epoch - 4ms/step
# Epoch 251/500
# 19/19 - 0s - loss: 0.0451 - val_loss: 0.0643 - 68ms/epoch - 4ms/step
# Epoch 252/500
# 19/19 - 0s - loss: 0.0413 - val_loss: 0.0442 - 66ms/epoch - 3ms/step
# Epoch 253/500
# 19/19 - 0s - loss: 0.0357 - val_loss: 0.0402 - 68ms/epoch - 4ms/step
# Epoch 254/500
# 19/19 - 0s - loss: 0.0352 - val_loss: 0.0399 - 66ms/epoch - 3ms/step
# Epoch 255/500
# 19/19 - 0s - loss: 0.0356 - val_loss: 0.0404 - 70ms/epoch - 4ms/step
# Epoch 256/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0394 - 84ms/epoch - 4ms/step
# Epoch 257/500
# 19/19 - 0s - loss: 0.0354 - val_loss: 0.0403 - 82ms/epoch - 4ms/step
# Epoch 258/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0398 - 76ms/epoch - 4ms/step
# Epoch 259/500
# 19/19 - 0s - loss: 0.0358 - val_loss: 0.0413 - 69ms/epoch - 4ms/step
# Epoch 260/500
# 19/19 - 0s - loss: 0.0358 - val_loss: 0.0418 - 69ms/epoch - 4ms/step
# Epoch 261/500
# 19/19 - 0s - loss: 0.0380 - val_loss: 0.0460 - 69ms/epoch - 4ms/step
# Epoch 262/500
# 19/19 - 0s - loss: 0.0397 - val_loss: 0.0508 - 75ms/epoch - 4ms/step
# Epoch 263/500
# 19/19 - 0s - loss: 0.0441 - val_loss: 0.0587 - 72ms/epoch - 4ms/step
# Epoch 264/500
# 19/19 - 0s - loss: 0.0419 - val_loss: 0.0514 - 66ms/epoch - 3ms/step
# Epoch 265/500
# 19/19 - 0s - loss: 0.0374 - val_loss: 0.0414 - 73ms/epoch - 4ms/step
# Epoch 266/500
# 19/19 - 0s - loss: 0.0349 - val_loss: 0.0389 - 69ms/epoch - 4ms/step
# Epoch 267/500
# 19/19 - 0s - loss: 0.0353 - val_loss: 0.0406 - 72ms/epoch - 4ms/step
# Epoch 268/500
# 19/19 - 0s - loss: 0.0382 - val_loss: 0.0462 - 78ms/epoch - 4ms/step
# Epoch 269/500
# 19/19 - 0s - loss: 0.0409 - val_loss: 0.0525 - 78ms/epoch - 4ms/step
# Epoch 270/500
# 19/19 - 0s - loss: 0.0448 - val_loss: 0.0586 - 94ms/epoch - 5ms/step
# Epoch 271/500
# 19/19 - 0s - loss: 0.0411 - val_loss: 0.0479 - 103ms/epoch - 5ms/step
# Epoch 272/500
# 19/19 - 0s - loss: 0.0366 - val_loss: 0.0404 - 76ms/epoch - 4ms/step
# Epoch 273/500
# 19/19 - 0s - loss: 0.0346 - val_loss: 0.0387 - 72ms/epoch - 4ms/step
# Epoch 274/500
# 19/19 - 0s - loss: 0.0344 - val_loss: 0.0388 - 96ms/epoch - 5ms/step
# Epoch 275/500
# 19/19 - 0s - loss: 0.0348 - val_loss: 0.0395 - 80ms/epoch - 4ms/step
# Epoch 276/500
# 19/19 - 0s - loss: 0.0350 - val_loss: 0.0401 - 64ms/epoch - 3ms/step
# Epoch 277/500
# 19/19 - 0s - loss: 0.0364 - val_loss: 0.0429 - 78ms/epoch - 4ms/step
# Epoch 278/500
# 19/19 - 0s - loss: 0.0385 - val_loss: 0.0482 - 134ms/epoch - 7ms/step
# Epoch 279/500
# 19/19 - 0s - loss: 0.0452 - val_loss: 0.0630 - 87ms/epoch - 5ms/step
# Epoch 280/500
# 19/19 - 0s - loss: 0.0510 - val_loss: 0.0744 - 82ms/epoch - 4ms/step
# Epoch 281/500
# 19/19 - 0s - loss: 0.0446 - val_loss: 0.0491 - 89ms/epoch - 5ms/step
# Epoch 282/500
# 19/19 - 0s - loss: 0.0358 - val_loss: 0.0391 - 86ms/epoch - 5ms/step
# Epoch 283/500
# 19/19 - 0s - loss: 0.0353 - val_loss: 0.0407 - 98ms/epoch - 5ms/step
# Epoch 284/500
# 19/19 - 0s - loss: 0.0371 - val_loss: 0.0432 - 98ms/epoch - 5ms/step
# Epoch 285/500
# 19/19 - 0s - loss: 0.0361 - val_loss: 0.0414 - 85ms/epoch - 4ms/step
# Epoch 286/500
# 19/19 - 0s - loss: 0.0371 - val_loss: 0.0432 - 103ms/epoch - 5ms/step
# Epoch 287/500
# 19/19 - 0s - loss: 0.0359 - val_loss: 0.0414 - 76ms/epoch - 4ms/step
# Epoch 288/500
# 19/19 - 0s - loss: 0.0370 - val_loss: 0.0433 - 66ms/epoch - 3ms/step
# Epoch 289/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0419 - 73ms/epoch - 4ms/step
# Epoch 290/500
# 19/19 - 0s - loss: 0.0374 - val_loss: 0.0442 - 93ms/epoch - 5ms/step
# Epoch 291/500
# 19/19 - 0s - loss: 0.0366 - val_loss: 0.0435 - 75ms/epoch - 4ms/step
# Epoch 292/500
# 19/19 - 0s - loss: 0.0384 - val_loss: 0.0464 - 67ms/epoch - 4ms/step
# Epoch 293/500
# 19/19 - 0s - loss: 0.0378 - val_loss: 0.0461 - 75ms/epoch - 4ms/step
# Epoch 294/500
# 19/19 - 0s - loss: 0.0394 - val_loss: 0.0485 - 79ms/epoch - 4ms/step
# Epoch 295/500
# 19/19 - 0s - loss: 0.0380 - val_loss: 0.0461 - 83ms/epoch - 4ms/step
# Epoch 296/500
# 19/19 - 0s - loss: 0.0378 - val_loss: 0.0449 - 77ms/epoch - 4ms/step
# Epoch 297/500
# 19/19 - 0s - loss: 0.0356 - val_loss: 0.0410 - 74ms/epoch - 4ms/step
# Epoch 298/500
# 19/19 - 0s - loss: 0.0348 - val_loss: 0.0394 - 79ms/epoch - 4ms/step
# Epoch 299/500
# 19/19 - 0s - loss: 0.0339 - val_loss: 0.0379 - 76ms/epoch - 4ms/step
# Epoch 300/500
# 19/19 - 0s - loss: 0.0341 - val_loss: 0.0382 - 74ms/epoch - 4ms/step
# Epoch 301/500
# 19/19 - 0s - loss: 0.0378 - val_loss: 0.0446 - 77ms/epoch - 4ms/step
# Epoch 302/500
# 19/19 - 0s - loss: 0.0548 - val_loss: 0.0884 - 70ms/epoch - 4ms/step
# Epoch 303/500
# 19/19 - 0s - loss: 0.0953 - val_loss: 0.1665 - 71ms/epoch - 4ms/step
# Epoch 304/500
# 19/19 - 0s - loss: 0.0563 - val_loss: 0.0724 - 73ms/epoch - 4ms/step
# Epoch 305/500
# 19/19 - 0s - loss: 0.0413 - val_loss: 0.0546 - 75ms/epoch - 4ms/step
# Epoch 306/500
# 19/19 - 0s - loss: 0.0382 - val_loss: 0.0497 - 113ms/epoch - 6ms/step
# Epoch 307/500
# 19/19 - 0s - loss: 0.0364 - val_loss: 0.0446 - 84ms/epoch - 4ms/step
# Epoch 308/500
# 19/19 - 0s - loss: 0.0356 - val_loss: 0.0413 - 83ms/epoch - 4ms/step
# Epoch 309/500
# 19/19 - 0s - loss: 0.0370 - val_loss: 0.0387 - 87ms/epoch - 5ms/step
# Epoch 310/500
# 19/19 - 0s - loss: 0.0420 - val_loss: 0.0402 - 79ms/epoch - 4ms/step
# Epoch 311/500
# 19/19 - 0s - loss: 0.0554 - val_loss: 0.0469 - 76ms/epoch - 4ms/step
# Epoch 312/500
# 19/19 - 0s - loss: 0.0831 - val_loss: 0.0489 - 87ms/epoch - 5ms/step
# Epoch 313/500
# 19/19 - 0s - loss: 0.1452 - val_loss: 0.0533 - 85ms/epoch - 4ms/step
# Epoch 314/500
# 19/19 - 0s - loss: 0.1964 - val_loss: 0.1288 - 84ms/epoch - 4ms/step
# Epoch 315/500
# 19/19 - 0s - loss: 0.0713 - val_loss: 0.0407 - 89ms/epoch - 5ms/step
# Epoch 316/500
# 19/19 - 0s - loss: 0.0367 - val_loss: 0.0393 - 83ms/epoch - 4ms/step
# Epoch 317/500
# 19/19 - 0s - loss: 0.0357 - val_loss: 0.0390 - 76ms/epoch - 4ms/step
# Epoch 318/500
# 19/19 - 0s - loss: 0.0345 - val_loss: 0.0388 - 81ms/epoch - 4ms/step
# Epoch 319/500
# 19/19 - 0s - loss: 0.0344 - val_loss: 0.0387 - 90ms/epoch - 5ms/step
# Epoch 320/500
# 19/19 - 0s - loss: 0.0344 - val_loss: 0.0387 - 95ms/epoch - 5ms/step
# Epoch 321/500
# 19/19 - 0s - loss: 0.0343 - val_loss: 0.0386 - 87ms/epoch - 5ms/step
# Epoch 322/500
# 19/19 - 0s - loss: 0.0343 - val_loss: 0.0386 - 88ms/epoch - 5ms/step
# Epoch 323/500
# 19/19 - 0s - loss: 0.0342 - val_loss: 0.0385 - 86ms/epoch - 5ms/step
# Epoch 324/500
# 19/19 - 0s - loss: 0.0342 - val_loss: 0.0385 - 70ms/epoch - 4ms/step
# Epoch 325/500
# 19/19 - 0s - loss: 0.0341 - val_loss: 0.0384 - 75ms/epoch - 4ms/step
# Epoch 326/500
# 19/19 - 0s - loss: 0.0341 - val_loss: 0.0384 - 72ms/epoch - 4ms/step
# Epoch 327/500
# 19/19 - 0s - loss: 0.0341 - val_loss: 0.0383 - 75ms/epoch - 4ms/step
# Epoch 328/500
# 19/19 - 0s - loss: 0.0340 - val_loss: 0.0382 - 77ms/epoch - 4ms/step
# Epoch 329/500
# 19/19 - 0s - loss: 0.0340 - val_loss: 0.0382 - 82ms/epoch - 4ms/step
# Epoch 330/500
# 19/19 - 0s - loss: 0.0339 - val_loss: 0.0381 - 79ms/epoch - 4ms/step
# Epoch 331/500
# 19/19 - 0s - loss: 0.0339 - val_loss: 0.0381 - 84ms/epoch - 4ms/step
# Epoch 332/500
# 19/19 - 0s - loss: 0.0338 - val_loss: 0.0380 - 100ms/epoch - 5ms/step
# Epoch 333/500
# 19/19 - 0s - loss: 0.0338 - val_loss: 0.0379 - 116ms/epoch - 6ms/step
# Epoch 334/500
# 19/19 - 0s - loss: 0.0337 - val_loss: 0.0379 - 103ms/epoch - 5ms/step
# Epoch 335/500
# 19/19 - 0s - loss: 0.0336 - val_loss: 0.0378 - 86ms/epoch - 5ms/step
# Epoch 336/500
# 19/19 - 0s - loss: 0.0336 - val_loss: 0.0377 - 82ms/epoch - 4ms/step
# Epoch 337/500
# 19/19 - 0s - loss: 0.0335 - val_loss: 0.0376 - 82ms/epoch - 4ms/step
# Epoch 338/500
# 19/19 - 0s - loss: 0.0335 - val_loss: 0.0376 - 83ms/epoch - 4ms/step
# Epoch 339/500
# 19/19 - 0s - loss: 0.0334 - val_loss: 0.0375 - 77ms/epoch - 4ms/step
# Epoch 340/500
# 19/19 - 0s - loss: 0.0333 - val_loss: 0.0374 - 70ms/epoch - 4ms/step
# Epoch 341/500
# 19/19 - 0s - loss: 0.0333 - val_loss: 0.0373 - 98ms/epoch - 5ms/step
# Epoch 342/500
# 19/19 - 0s - loss: 0.0332 - val_loss: 0.0372 - 148ms/epoch - 8ms/step
# Epoch 343/500
# 19/19 - 0s - loss: 0.0331 - val_loss: 0.0371 - 86ms/epoch - 5ms/step
# Epoch 344/500
# 19/19 - 0s - loss: 0.0330 - val_loss: 0.0370 - 75ms/epoch - 4ms/step
# Epoch 345/500
# 19/19 - 0s - loss: 0.0330 - val_loss: 0.0369 - 80ms/epoch - 4ms/step
# Epoch 346/500
# 19/19 - 0s - loss: 0.0329 - val_loss: 0.0368 - 88ms/epoch - 5ms/step
# Epoch 347/500
# 19/19 - 0s - loss: 0.0328 - val_loss: 0.0367 - 92ms/epoch - 5ms/step
# Epoch 348/500
# 19/19 - 0s - loss: 0.0327 - val_loss: 0.0366 - 80ms/epoch - 4ms/step
# Epoch 349/500
# 19/19 - 0s - loss: 0.0326 - val_loss: 0.0364 - 100ms/epoch - 5ms/step
# Epoch 350/500
# 19/19 - 0s - loss: 0.0325 - val_loss: 0.0363 - 107ms/epoch - 6ms/step
# Epoch 351/500
# 19/19 - 0s - loss: 0.0324 - val_loss: 0.0362 - 95ms/epoch - 5ms/step
# Epoch 352/500
# 19/19 - 0s - loss: 0.0323 - val_loss: 0.0361 - 83ms/epoch - 4ms/step
# Epoch 353/500
# 19/19 - 0s - loss: 0.0322 - val_loss: 0.0360 - 85ms/epoch - 4ms/step
# Epoch 354/500
# 19/19 - 0s - loss: 0.0324 - val_loss: 0.0362 - 89ms/epoch - 5ms/step
# Epoch 355/500
# 19/19 - 0s - loss: 0.0340 - val_loss: 0.0385 - 94ms/epoch - 5ms/step
# Epoch 356/500
# 19/19 - 0s - loss: 0.0441 - val_loss: 0.0682 - 113ms/epoch - 6ms/step
# Epoch 357/500
# 19/19 - 0s - loss: 0.0680 - val_loss: 0.0969 - 94ms/epoch - 5ms/step
# Epoch 358/500
# 19/19 - 0s - loss: 0.0545 - val_loss: 0.0789 - 94ms/epoch - 5ms/step
# Epoch 359/500
# 19/19 - 0s - loss: 0.0546 - val_loss: 0.0696 - 108ms/epoch - 6ms/step
# Epoch 360/500
# 19/19 - 0s - loss: 0.0684 - val_loss: 0.0620 - 94ms/epoch - 5ms/step
# Epoch 361/500
# 19/19 - 0s - loss: 0.0915 - val_loss: 0.0383 - 81ms/epoch - 4ms/step
# Epoch 362/500
# 19/19 - 0s - loss: 0.1093 - val_loss: 0.0619 - 73ms/epoch - 4ms/step
# Epoch 363/500
# 19/19 - 0s - loss: 0.0660 - val_loss: 0.0431 - 70ms/epoch - 4ms/step
# Epoch 364/500
# 19/19 - 0s - loss: 0.0363 - val_loss: 0.0385 - 77ms/epoch - 4ms/step
# Epoch 365/500
# 19/19 - 0s - loss: 0.0338 - val_loss: 0.0377 - 77ms/epoch - 4ms/step
# Epoch 366/500
# 19/19 - 0s - loss: 0.0336 - val_loss: 0.0376 - 76ms/epoch - 4ms/step
# Epoch 367/500
# 19/19 - 0s - loss: 0.0334 - val_loss: 0.0375 - 72ms/epoch - 4ms/step
# Epoch 368/500
# 19/19 - 0s - loss: 0.0333 - val_loss: 0.0374 - 71ms/epoch - 4ms/step
# Epoch 369/500
# 19/19 - 0s - loss: 0.0332 - val_loss: 0.0373 - 95ms/epoch - 5ms/step
# Epoch 370/500
# 19/19 - 0s - loss: 0.0332 - val_loss: 0.0372 - 70ms/epoch - 4ms/step
# Epoch 371/500
# 19/19 - 0s - loss: 0.0331 - val_loss: 0.0371 - 68ms/epoch - 4ms/step
# Epoch 372/500
# 19/19 - 0s - loss: 0.0330 - val_loss: 0.0370 - 72ms/epoch - 4ms/step
# Epoch 373/500
# 19/19 - 0s - loss: 0.0329 - val_loss: 0.0369 - 69ms/epoch - 4ms/step
# Epoch 374/500
# 19/19 - 0s - loss: 0.0328 - val_loss: 0.0368 - 67ms/epoch - 4ms/step
# Epoch 375/500
# 19/19 - 0s - loss: 0.0327 - val_loss: 0.0367 - 68ms/epoch - 4ms/step
# Epoch 376/500
# 19/19 - 0s - loss: 0.0327 - val_loss: 0.0365 - 66ms/epoch - 3ms/step
# Epoch 377/500
# 19/19 - 0s - loss: 0.0326 - val_loss: 0.0364 - 69ms/epoch - 4ms/step
# Epoch 378/500
# 19/19 - 0s - loss: 0.0325 - val_loss: 0.0363 - 86ms/epoch - 5ms/step
# Epoch 379/500
# 19/19 - 0s - loss: 0.0324 - val_loss: 0.0362 - 87ms/epoch - 5ms/step
# Epoch 380/500
# 19/19 - 0s - loss: 0.0323 - val_loss: 0.0361 - 86ms/epoch - 5ms/step
# Epoch 381/500
# 19/19 - 0s - loss: 0.0322 - val_loss: 0.0359 - 80ms/epoch - 4ms/step
# Epoch 382/500
# 19/19 - 0s - loss: 0.0321 - val_loss: 0.0358 - 83ms/epoch - 4ms/step
# Epoch 383/500
# 19/19 - 0s - loss: 0.0319 - val_loss: 0.0357 - 75ms/epoch - 4ms/step
# Epoch 384/500
# 19/19 - 0s - loss: 0.0318 - val_loss: 0.0355 - 77ms/epoch - 4ms/step
# Epoch 385/500
# 19/19 - 0s - loss: 0.0317 - val_loss: 0.0354 - 83ms/epoch - 4ms/step
# Epoch 386/500
# 19/19 - 0s - loss: 0.0316 - val_loss: 0.0352 - 83ms/epoch - 4ms/step
# Epoch 387/500
# 19/19 - 0s - loss: 0.0315 - val_loss: 0.0351 - 83ms/epoch - 4ms/step
# Epoch 388/500
# 19/19 - 0s - loss: 0.0314 - val_loss: 0.0349 - 80ms/epoch - 4ms/step
# Epoch 389/500
# 19/19 - 0s - loss: 0.0312 - val_loss: 0.0348 - 91ms/epoch - 5ms/step
# Epoch 390/500
# 19/19 - 0s - loss: 0.0311 - val_loss: 0.0346 - 89ms/epoch - 5ms/step
# Epoch 391/500
# 19/19 - 0s - loss: 0.0310 - val_loss: 0.0344 - 80ms/epoch - 4ms/step
# Epoch 392/500
# 19/19 - 0s - loss: 0.0309 - val_loss: 0.0343 - 74ms/epoch - 4ms/step
# Epoch 393/500
# 19/19 - 0s - loss: 0.0309 - val_loss: 0.0343 - 69ms/epoch - 4ms/step
# Epoch 394/500
# 19/19 - 0s - loss: 0.0318 - val_loss: 0.0351 - 73ms/epoch - 4ms/step
# Epoch 395/500
# 19/19 - 0s - loss: 0.0382 - val_loss: 0.0445 - 64ms/epoch - 3ms/step
# Epoch 396/500
# 19/19 - 0s - loss: 0.0749 - val_loss: 0.1806 - 64ms/epoch - 3ms/step
# Epoch 397/500
# 19/19 - 0s - loss: 0.0642 - val_loss: 0.0536 - 65ms/epoch - 3ms/step
# Epoch 398/500
# 19/19 - 0s - loss: 0.0632 - val_loss: 0.0503 - 72ms/epoch - 4ms/step
# Epoch 399/500
# 19/19 - 0s - loss: 0.0813 - val_loss: 0.0697 - 75ms/epoch - 4ms/step
# Epoch 400/500
# 19/19 - 0s - loss: 0.0836 - val_loss: 0.0745 - 70ms/epoch - 4ms/step
# Epoch 401/500
# 19/19 - 0s - loss: 0.0509 - val_loss: 0.0415 - 75ms/epoch - 4ms/step
# Epoch 402/500
# 19/19 - 0s - loss: 0.0360 - val_loss: 0.0362 - 74ms/epoch - 4ms/step
# Epoch 403/500
# 19/19 - 0s - loss: 0.0330 - val_loss: 0.0361 - 80ms/epoch - 4ms/step
# Epoch 404/500
# 19/19 - 0s - loss: 0.0323 - val_loss: 0.0359 - 83ms/epoch - 4ms/step
# Epoch 405/500
# 19/19 - 0s - loss: 0.0321 - val_loss: 0.0358 - 84ms/epoch - 4ms/step
# Epoch 406/500
# 19/19 - 0s - loss: 0.0320 - val_loss: 0.0357 - 93ms/epoch - 5ms/step
# Epoch 407/500
# 19/19 - 0s - loss: 0.0319 - val_loss: 0.0356 - 80ms/epoch - 4ms/step
# Epoch 408/500
# 19/19 - 0s - loss: 0.0318 - val_loss: 0.0354 - 76ms/epoch - 4ms/step
# Epoch 409/500
# 19/19 - 0s - loss: 0.0317 - val_loss: 0.0353 - 73ms/epoch - 4ms/step
# Epoch 410/500
# 19/19 - 0s - loss: 0.0316 - val_loss: 0.0352 - 73ms/epoch - 4ms/step
# Epoch 411/500
# 19/19 - 0s - loss: 0.0315 - val_loss: 0.0351 - 76ms/epoch - 4ms/step
# Epoch 412/500
# 19/19 - 0s - loss: 0.0314 - val_loss: 0.0350 - 74ms/epoch - 4ms/step
# Epoch 413/500
# 19/19 - 0s - loss: 0.0313 - val_loss: 0.0348 - 76ms/epoch - 4ms/step
# Epoch 414/500
# 19/19 - 0s - loss: 0.0312 - val_loss: 0.0347 - 105ms/epoch - 6ms/step
# Epoch 415/500
# 19/19 - 0s - loss: 0.0311 - val_loss: 0.0346 - 101ms/epoch - 5ms/step
# Epoch 416/500
# 19/19 - 0s - loss: 0.0310 - val_loss: 0.0344 - 76ms/epoch - 4ms/step
# Epoch 417/500
# 19/19 - 0s - loss: 0.0309 - val_loss: 0.0343 - 85ms/epoch - 4ms/step
# Epoch 418/500
# 19/19 - 0s - loss: 0.0308 - val_loss: 0.0342 - 89ms/epoch - 5ms/step
# Epoch 419/500
# 19/19 - 0s - loss: 0.0307 - val_loss: 0.0341 - 77ms/epoch - 4ms/step
# Epoch 420/500
# 19/19 - 0s - loss: 0.0305 - val_loss: 0.0339 - 74ms/epoch - 4ms/step
# Epoch 421/500
# 19/19 - 0s - loss: 0.0305 - val_loss: 0.0338 - 72ms/epoch - 4ms/step
# Epoch 422/500
# 19/19 - 0s - loss: 0.0303 - val_loss: 0.0336 - 70ms/epoch - 4ms/step
# Epoch 423/500
# 19/19 - 0s - loss: 0.0302 - val_loss: 0.0335 - 64ms/epoch - 3ms/step
# Epoch 424/500
# 19/19 - 0s - loss: 0.0301 - val_loss: 0.0334 - 64ms/epoch - 3ms/step
# Epoch 425/500
# 19/19 - 0s - loss: 0.0300 - val_loss: 0.0332 - 72ms/epoch - 4ms/step
# Epoch 426/500
# 19/19 - 0s - loss: 0.0299 - val_loss: 0.0331 - 79ms/epoch - 4ms/step
# Epoch 427/500
# 19/19 - 0s - loss: 0.0298 - val_loss: 0.0331 - 81ms/epoch - 4ms/step
# Epoch 428/500
# 19/19 - 0s - loss: 0.0299 - val_loss: 0.0332 - 78ms/epoch - 4ms/step
# Epoch 429/500
# 19/19 - 0s - loss: 0.0303 - val_loss: 0.0340 - 78ms/epoch - 4ms/step
# Epoch 430/500
# 19/19 - 0s - loss: 0.0326 - val_loss: 0.0381 - 94ms/epoch - 5ms/step
# Epoch 431/500
# 19/19 - 0s - loss: 0.0429 - val_loss: 0.0642 - 94ms/epoch - 5ms/step
# Epoch 432/500
# 19/19 - 0s - loss: 0.0708 - val_loss: 0.1335 - 93ms/epoch - 5ms/step
# Epoch 433/500
# 19/19 - 0s - loss: 0.0465 - val_loss: 0.0600 - 92ms/epoch - 5ms/step
# Epoch 434/500
# 19/19 - 0s - loss: 0.0402 - val_loss: 0.0388 - 87ms/epoch - 5ms/step
# Epoch 435/500
# 19/19 - 0s - loss: 0.0474 - val_loss: 0.0346 - 89ms/epoch - 5ms/step
# Epoch 436/500
# 19/19 - 0s - loss: 0.0711 - val_loss: 0.0385 - 83ms/epoch - 4ms/step
# Epoch 437/500
# 19/19 - 0s - loss: 0.1015 - val_loss: 0.0365 - 86ms/epoch - 5ms/step
# Epoch 438/500
# 19/19 - 0s - loss: 0.1063 - val_loss: 0.0566 - 78ms/epoch - 4ms/step
# Epoch 439/500
# 19/19 - 0s - loss: 0.0483 - val_loss: 0.0353 - 84ms/epoch - 4ms/step
# Epoch 440/500
# 19/19 - 0s - loss: 0.0320 - val_loss: 0.0359 - 104ms/epoch - 5ms/step
# Epoch 441/500
# 19/19 - 0s - loss: 0.0318 - val_loss: 0.0348 - 98ms/epoch - 5ms/step
# Epoch 442/500
# 19/19 - 0s - loss: 0.0313 - val_loss: 0.0347 - 86ms/epoch - 5ms/step
# Epoch 443/500
# 19/19 - 0s - loss: 0.0311 - val_loss: 0.0346 - 88ms/epoch - 5ms/step
# Epoch 444/500
# 19/19 - 0s - loss: 0.0310 - val_loss: 0.0345 - 81ms/epoch - 4ms/step
# Epoch 445/500
# 19/19 - 0s - loss: 0.0309 - val_loss: 0.0343 - 80ms/epoch - 4ms/step
# Epoch 446/500
# 19/19 - 0s - loss: 0.0308 - val_loss: 0.0342 - 107ms/epoch - 6ms/step
# Epoch 447/500
# 19/19 - 0s - loss: 0.0306 - val_loss: 0.0341 - 85ms/epoch - 4ms/step
# Epoch 448/500
# 19/19 - 0s - loss: 0.0305 - val_loss: 0.0339 - 79ms/epoch - 4ms/step
# Epoch 449/500
# 19/19 - 0s - loss: 0.0304 - val_loss: 0.0338 - 82ms/epoch - 4ms/step
# Epoch 450/500
# 19/19 - 0s - loss: 0.0303 - val_loss: 0.0337 - 98ms/epoch - 5ms/step
# Epoch 451/500
# 19/19 - 0s - loss: 0.0302 - val_loss: 0.0336 - 84ms/epoch - 4ms/step
# Epoch 452/500
# 19/19 - 0s - loss: 0.0301 - val_loss: 0.0334 - 83ms/epoch - 4ms/step
# Epoch 453/500
# 19/19 - 0s - loss: 0.0300 - val_loss: 0.0333 - 86ms/epoch - 5ms/step
# Epoch 454/500
# 19/19 - 0s - loss: 0.0299 - val_loss: 0.0332 - 99ms/epoch - 5ms/step
# Epoch 455/500
# 19/19 - 0s - loss: 0.0298 - val_loss: 0.0330 - 94ms/epoch - 5ms/step
# Epoch 456/500
# 19/19 - 0s - loss: 0.0297 - val_loss: 0.0329 - 76ms/epoch - 4ms/step
# Epoch 457/500
# 19/19 - 0s - loss: 0.0296 - val_loss: 0.0327 - 70ms/epoch - 4ms/step
# Epoch 458/500
# 19/19 - 0s - loss: 0.0295 - val_loss: 0.0326 - 73ms/epoch - 4ms/step
# Epoch 459/500
# 19/19 - 0s - loss: 0.0293 - val_loss: 0.0325 - 74ms/epoch - 4ms/step
# Epoch 460/500
# 19/19 - 0s - loss: 0.0292 - val_loss: 0.0323 - 75ms/epoch - 4ms/step
# Epoch 461/500
# 19/19 - 0s - loss: 0.0291 - val_loss: 0.0322 - 71ms/epoch - 4ms/step
# Epoch 462/500
# 19/19 - 0s - loss: 0.0290 - val_loss: 0.0320 - 72ms/epoch - 4ms/step
# Epoch 463/500
# 19/19 - 0s - loss: 0.0289 - val_loss: 0.0319 - 72ms/epoch - 4ms/step
# Epoch 464/500
# 19/19 - 0s - loss: 0.0288 - val_loss: 0.0317 - 74ms/epoch - 4ms/step
# Epoch 465/500
# 19/19 - 0s - loss: 0.0286 - val_loss: 0.0316 - 69ms/epoch - 4ms/step
# Epoch 466/500
# 19/19 - 0s - loss: 0.0285 - val_loss: 0.0314 - 66ms/epoch - 3ms/step
# Epoch 467/500
# 19/19 - 0s - loss: 0.0284 - val_loss: 0.0313 - 70ms/epoch - 4ms/step
# Epoch 468/500
# 19/19 - 0s - loss: 0.0284 - val_loss: 0.0313 - 109ms/epoch - 6ms/step
# Epoch 469/500
# 19/19 - 0s - loss: 0.0286 - val_loss: 0.0318 - 87ms/epoch - 5ms/step
# Epoch 470/500
# 19/19 - 0s - loss: 0.0302 - val_loss: 0.0341 - 74ms/epoch - 4ms/step
# Epoch 471/500
# 19/19 - 0s - loss: 0.0388 - val_loss: 0.0521 - 93ms/epoch - 5ms/step
# Epoch 472/500
# 19/19 - 0s - loss: 0.0714 - val_loss: 0.1570 - 72ms/epoch - 4ms/step
# Epoch 473/500
# 19/19 - 0s - loss: 0.0540 - val_loss: 0.0419 - 73ms/epoch - 4ms/step
# Epoch 474/500
# 19/19 - 0s - loss: 0.0544 - val_loss: 0.0335 - 69ms/epoch - 4ms/step
# Epoch 475/500
# 19/19 - 0s - loss: 0.0734 - val_loss: 0.0354 - 72ms/epoch - 4ms/step
# Epoch 476/500
# 19/19 - 0s - loss: 0.0990 - val_loss: 0.0344 - 76ms/epoch - 4ms/step
# Epoch 477/500
# 19/19 - 0s - loss: 0.0813 - val_loss: 0.0418 - 70ms/epoch - 4ms/step
# Epoch 478/500
# 19/19 - 0s - loss: 0.0386 - val_loss: 0.0334 - 70ms/epoch - 4ms/step
# Epoch 479/500
# 19/19 - 0s - loss: 0.0302 - val_loss: 0.0338 - 65ms/epoch - 3ms/step
# Epoch 480/500
# 19/19 - 0s - loss: 0.0303 - val_loss: 0.0331 - 79ms/epoch - 4ms/step
# Epoch 481/500
# 19/19 - 0s - loss: 0.0298 - val_loss: 0.0329 - 80ms/epoch - 4ms/step
# Epoch 482/500
# 19/19 - 0s - loss: 0.0296 - val_loss: 0.0328 - 76ms/epoch - 4ms/step
# Epoch 483/500
# 19/19 - 0s - loss: 0.0295 - val_loss: 0.0327 - 68ms/epoch - 4ms/step
# Epoch 484/500
# 19/19 - 0s - loss: 0.0294 - val_loss: 0.0325 - 68ms/epoch - 4ms/step
# Epoch 485/500
# 19/19 - 0s - loss: 0.0293 - val_loss: 0.0324 - 63ms/epoch - 3ms/step
# Epoch 486/500
# 19/19 - 0s - loss: 0.0292 - val_loss: 0.0323 - 62ms/epoch - 3ms/step
# Epoch 487/500
# 19/19 - 0s - loss: 0.0291 - val_loss: 0.0321 - 61ms/epoch - 3ms/step
# Epoch 488/500
# 19/19 - 0s - loss: 0.0290 - val_loss: 0.0320 - 69ms/epoch - 4ms/step
# Epoch 489/500
# 19/19 - 0s - loss: 0.0289 - val_loss: 0.0319 - 67ms/epoch - 4ms/step
# Epoch 490/500
# 19/19 - 0s - loss: 0.0288 - val_loss: 0.0318 - 65ms/epoch - 3ms/step
# Epoch 491/500
# 19/19 - 0s - loss: 0.0287 - val_loss: 0.0316 - 64ms/epoch - 3ms/step
# Epoch 492/500
# 19/19 - 0s - loss: 0.0286 - val_loss: 0.0315 - 75ms/epoch - 4ms/step
# Epoch 493/500
# 19/19 - 0s - loss: 0.0284 - val_loss: 0.0314 - 75ms/epoch - 4ms/step
# Epoch 494/500
# 19/19 - 0s - loss: 0.0284 - val_loss: 0.0313 - 73ms/epoch - 4ms/step
# Epoch 495/500
# 19/19 - 0s - loss: 0.0282 - val_loss: 0.0311 - 80ms/epoch - 4ms/step
# Epoch 496/500
# 19/19 - 0s - loss: 0.0281 - val_loss: 0.0310 - 79ms/epoch - 4ms/step
# Epoch 497/500
# 19/19 - 0s - loss: 0.0280 - val_loss: 0.0308 - 82ms/epoch - 4ms/step
# Epoch 498/500
# 19/19 - 0s - loss: 0.0279 - val_loss: 0.0307 - 71ms/epoch - 4ms/step
# Epoch 499/500
# 19/19 - 0s - loss: 0.0278 - val_loss: 0.0307 - 73ms/epoch - 4ms/step
# Epoch 500/500
# 19/19 - 0s - loss: 0.0277 - val_loss: 0.0304 - 68ms/epoch - 4ms/step

# %% [markdown]
# ## Metrics ($LPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 10/10 [==============================] - 0s 1ms/step
# (291, 3)
# (291, 10)
# Test RMSE: 7.364
# Test MAE: 6.217

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('New Delhi Daily Wind Speed', fontsize=20)
plt.legend(fontsize=20)
plt.show()
