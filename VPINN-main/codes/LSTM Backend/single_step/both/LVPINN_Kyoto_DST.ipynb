# %% [markdown]
# # Time Series Prediction with Lotka Volterra Equation Inspired Deep Learning ($LVPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-09 16:50:13

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Lotka Volterra Intermittency_

# %% [markdown]
# The `lotka_volterra_intermittency.dat` is generated from the Runge Kutta Method.

# %% [markdown]
# This feeds the model with the dynamics of the Lotka Volterra Equations

# %%
data = np.genfromtxt('datasets/lotka_volterra_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 0.0416 # Hourly Data (1/24)
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 215.48740705
# 1        -2.591620e-01
# 2        -2.563361e-01
# 3        -2.535406e-01
# 4        -2.507762e-01
# 5        -2.480413e-01
#               ...
# 139867   -2.677308e-33
# 139868   -2.648368e-33
# 139869   -2.619744e-33
# 139870   -2.591428e-33
# 139871   -2.563419e-33
# Name: 1, Length: 139871, dtype: float64
# 2         6.793177e-02
# 3         6.719790e-02
# 4         6.645248e-02
# 5         6.574173e-02
# 6         6.501942e-02
#               ...
# 139867    7.032406e-34
# 139868    6.956708e-34
# 139869    6.880663e-34
# 139870    6.806756e-34
# 139871    6.732849e-34
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _KYOTO DST_

# %%
data = pd.read_csv("datasets/dst.csv")
training_set = data.iloc[:, 1]
print(training_set)
# Out:
# 0         -7
# 1        -10
# 2        -10
# 3         -6
# 4         -2
#           ..
# 139867   -16
# 139868   -14
# 139869   -14
# 139870   -15
# 139871   -14
# Name: dst, Length: 139872, dtype: int64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0        -2.591620e-01
# 1        -2.563361e-01
# 2        -2.535406e-01
# 3        -2.507762e-01
# 4        -2.480413e-01
#               ...
# 139866   -2.677308e-33
# 139867   -2.648368e-33
# 139868   -2.619744e-33
# 139869   -2.591428e-33
# 139870   -2.563419e-33
# Name: 1, Length: 139871, dtype: float64
# 0         6.793177e-02
# 1         6.719790e-02
# 2         6.645248e-02
# 3         6.574173e-02
# 4         6.501942e-02
#               ...
# 139865    7.032406e-34
# 139866    6.956708e-34
# 139867    6.880663e-34
# 139868    6.806756e-34
# 139869    6.732849e-34
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lotka Volterra Equation_)

# %% [markdown]
# _Parameters_: $\alpha=0.1, \beta=0.05, \gamma=1.1, \delta=0.1\\$

# %%
a=0.1
b=0.05
c=1.1
d=0.1
L = df.iloc[:, 2] - a*a*df.iloc[:, 0] + 2*a*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*d*(df.iloc[:,0]**2)*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - c*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10        -7.0      -10.0      -10.0       -6.0       -2.0        3.0
# 11       -10.0      -10.0       -6.0       -2.0        3.0        5.0
# 12       -10.0       -6.0       -2.0        3.0        5.0        5.0
# 13        -6.0       -2.0        3.0        5.0        5.0        3.0
# 14        -2.0        3.0        5.0        5.0        3.0        1.0
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)   var2(t)   var3(t)
# 10        5.0        5.0        3.0        1.0      1.0 -0.232249  0.060888
# 11        5.0        3.0        1.0        1.0      2.0 -0.229716  0.060212
# 12        3.0        1.0        1.0        2.0      2.0 -0.227211  0.059559
# 13        1.0        1.0        2.0        2.0      3.0 -0.224734  0.058906
# 14        1.0        2.0        2.0        3.0      3.0 -0.222283  0.058270
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (139860, 13)
# (139860, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (111888, 1, 10) (111888, 3) (27972, 1, 10) (27972, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] - a*a*y_true[:, 0] + 2*a*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*d*(y_true[:,0]**2)*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - c*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))), (y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] - a*a*y_pred[:-2] + 2*a*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*d*(y_pred[:-2]**2)*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - c*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] - a*a*y_real[:-2] + 2*a*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*d*(y_real[:-2]**2)*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - c*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($LVPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square(y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 1749/1749 - 8s - loss: 0.0053 - val_loss: 1.5154e-04 - 8s/epoch - 4ms/step
# Epoch 2/500
# 1749/1749 - 4s - loss: 3.4626e-04 - val_loss: 1.0499e-04 - 4s/epoch - 2ms/step
# Epoch 3/500
# 1749/1749 - 4s - loss: 2.3399e-04 - val_loss: 1.5041e-04 - 4s/epoch - 2ms/step
# Epoch 4/500
# 1749/1749 - 4s - loss: 1.9812e-04 - val_loss: 9.0744e-05 - 4s/epoch - 2ms/step
# Epoch 5/500
# 1749/1749 - 4s - loss: 1.5795e-04 - val_loss: 6.4723e-05 - 4s/epoch - 2ms/step
# Epoch 6/500
# 1749/1749 - 5s - loss: 1.4031e-04 - val_loss: 5.2515e-05 - 5s/epoch - 3ms/step
# Epoch 7/500
# 1749/1749 - 6s - loss: 1.2847e-04 - val_loss: 4.9820e-05 - 6s/epoch - 3ms/step
# Epoch 8/500
# 1749/1749 - 5s - loss: 1.2078e-04 - val_loss: 4.6471e-05 - 5s/epoch - 3ms/step
# Epoch 9/500
# 1749/1749 - 5s - loss: 1.1579e-04 - val_loss: 4.4303e-05 - 5s/epoch - 3ms/step
# Epoch 10/500
# 1749/1749 - 6s - loss: 1.1223e-04 - val_loss: 4.2281e-05 - 6s/epoch - 3ms/step
# Epoch 11/500
# 1749/1749 - 6s - loss: 1.0957e-04 - val_loss: 4.0718e-05 - 6s/epoch - 3ms/step
# Epoch 12/500
# 1749/1749 - 7s - loss: 1.0756e-04 - val_loss: 3.9502e-05 - 7s/epoch - 4ms/step
# Epoch 13/500
# 1749/1749 - 5s - loss: 1.0603e-04 - val_loss: 3.8719e-05 - 5s/epoch - 3ms/step
# Epoch 14/500
# 1749/1749 - 6s - loss: 1.0485e-04 - val_loss: 3.8350e-05 - 6s/epoch - 3ms/step
# Epoch 15/500
# 1749/1749 - 5s - loss: 1.0386e-04 - val_loss: 3.8167e-05 - 5s/epoch - 3ms/step
# Epoch 16/500
# 1749/1749 - 5s - loss: 1.0306e-04 - val_loss: 3.8150e-05 - 5s/epoch - 3ms/step
# Epoch 17/500
# 1749/1749 - 8s - loss: 1.0239e-04 - val_loss: 3.8208e-05 - 8s/epoch - 4ms/step
# Epoch 18/500
# 1749/1749 - 8s - loss: 1.0182e-04 - val_loss: 3.8370e-05 - 8s/epoch - 4ms/step
# Epoch 19/500
# 1749/1749 - 8s - loss: 1.0131e-04 - val_loss: 3.8620e-05 - 8s/epoch - 5ms/step
# Epoch 20/500
# 1749/1749 - 6s - loss: 1.0084e-04 - val_loss: 3.8916e-05 - 6s/epoch - 3ms/step
# Epoch 21/500
# 1749/1749 - 5s - loss: 1.0043e-04 - val_loss: 3.9268e-05 - 5s/epoch - 3ms/step
# Epoch 22/500
# 1749/1749 - 5s - loss: 1.0006e-04 - val_loss: 3.9635e-05 - 5s/epoch - 3ms/step
# Epoch 23/500
# 1749/1749 - 5s - loss: 9.9713e-05 - val_loss: 3.9994e-05 - 5s/epoch - 3ms/step
# Epoch 24/500
# 1749/1749 - 5s - loss: 9.9393e-05 - val_loss: 4.0313e-05 - 5s/epoch - 3ms/step
# Epoch 25/500
# 1749/1749 - 5s - loss: 9.9090e-05 - val_loss: 4.0597e-05 - 5s/epoch - 3ms/step
# Epoch 26/500
# 1749/1749 - 5s - loss: 9.8807e-05 - val_loss: 4.0837e-05 - 5s/epoch - 3ms/step
# Epoch 27/500
# 1749/1749 - 5s - loss: 9.8544e-05 - val_loss: 4.1041e-05 - 5s/epoch - 3ms/step
# Epoch 28/500
# 1749/1749 - 5s - loss: 9.8301e-05 - val_loss: 4.1212e-05 - 5s/epoch - 3ms/step
# Epoch 29/500
# 1749/1749 - 5s - loss: 9.8082e-05 - val_loss: 4.1345e-05 - 5s/epoch - 3ms/step
# Epoch 30/500
# 1749/1749 - 6s - loss: 9.7858e-05 - val_loss: 4.1442e-05 - 6s/epoch - 3ms/step
# Epoch 31/500
# 1749/1749 - 6s - loss: 9.7656e-05 - val_loss: 4.1510e-05 - 6s/epoch - 4ms/step
# Epoch 32/500
# 1749/1749 - 9s - loss: 9.7452e-05 - val_loss: 4.1561e-05 - 9s/epoch - 5ms/step
# Epoch 33/500
# 1749/1749 - 7s - loss: 9.7257e-05 - val_loss: 4.1593e-05 - 7s/epoch - 4ms/step
# Epoch 34/500
# 1749/1749 - 8s - loss: 9.7070e-05 - val_loss: 4.1618e-05 - 8s/epoch - 5ms/step
# Epoch 35/500
# 1749/1749 - 7s - loss: 9.6889e-05 - val_loss: 4.1633e-05 - 7s/epoch - 4ms/step
# Epoch 36/500
# 1749/1749 - 7s - loss: 9.6711e-05 - val_loss: 4.1640e-05 - 7s/epoch - 4ms/step
# Epoch 37/500
# 1749/1749 - 6s - loss: 9.6539e-05 - val_loss: 4.1641e-05 - 6s/epoch - 4ms/step
# Epoch 38/500
# 1749/1749 - 10s - loss: 9.6372e-05 - val_loss: 4.1636e-05 - 10s/epoch - 6ms/step
# Epoch 39/500
# 1749/1749 - 9s - loss: 9.6210e-05 - val_loss: 4.1625e-05 - 9s/epoch - 5ms/step
# Epoch 40/500
# 1749/1749 - 9s - loss: 9.6054e-05 - val_loss: 4.1605e-05 - 9s/epoch - 5ms/step
# Epoch 41/500
# 1749/1749 - 9s - loss: 9.5904e-05 - val_loss: 4.1574e-05 - 9s/epoch - 5ms/step
# Epoch 42/500
# 1749/1749 - 11s - loss: 9.5760e-05 - val_loss: 4.1546e-05 - 11s/epoch - 6ms/step
# Epoch 43/500
# 1749/1749 - 9s - loss: 9.5622e-05 - val_loss: 4.1488e-05 - 9s/epoch - 5ms/step
# Epoch 44/500
# 1749/1749 - 9s - loss: 9.5493e-05 - val_loss: 4.1408e-05 - 9s/epoch - 5ms/step
# Epoch 45/500
# 1749/1749 - 8s - loss: 9.5372e-05 - val_loss: 4.1315e-05 - 8s/epoch - 5ms/step
# Epoch 46/500
# 1749/1749 - 9s - loss: 9.5261e-05 - val_loss: 4.1199e-05 - 9s/epoch - 5ms/step
# Epoch 47/500
# 1749/1749 - 9s - loss: 9.5157e-05 - val_loss: 4.1068e-05 - 9s/epoch - 5ms/step
# Epoch 48/500
# 1749/1749 - 9s - loss: 9.5066e-05 - val_loss: 4.0918e-05 - 9s/epoch - 5ms/step
# Epoch 49/500
# 1749/1749 - 10s - loss: 9.4985e-05 - val_loss: 4.0749e-05 - 10s/epoch - 6ms/step
# Epoch 50/500
# 1749/1749 - 9s - loss: 9.6124e-05 - val_loss: 3.9978e-05 - 9s/epoch - 5ms/step
# Epoch 51/500
# 1749/1749 - 9s - loss: 9.7175e-05 - val_loss: 3.9343e-05 - 9s/epoch - 5ms/step
# Epoch 52/500
# 1749/1749 - 9s - loss: 9.5588e-05 - val_loss: 3.9644e-05 - 9s/epoch - 5ms/step
# Epoch 53/500
# 1749/1749 - 9s - loss: 9.4995e-05 - val_loss: 3.9774e-05 - 9s/epoch - 5ms/step
# Epoch 54/500
# 1749/1749 - 9s - loss: 9.4843e-05 - val_loss: 3.9694e-05 - 9s/epoch - 5ms/step
# Epoch 55/500
# 1749/1749 - 9s - loss: 9.4798e-05 - val_loss: 3.9560e-05 - 9s/epoch - 5ms/step
# Epoch 56/500
# 1749/1749 - 9s - loss: 9.4844e-05 - val_loss: 3.9405e-05 - 9s/epoch - 5ms/step
# Epoch 57/500
# 1749/1749 - 9s - loss: 9.4853e-05 - val_loss: 3.9310e-05 - 9s/epoch - 5ms/step
# Epoch 58/500
# 1749/1749 - 9s - loss: 9.4828e-05 - val_loss: 3.9214e-05 - 9s/epoch - 5ms/step
# Epoch 59/500
# 1749/1749 - 10s - loss: 9.5049e-05 - val_loss: 3.9480e-05 - 10s/epoch - 6ms/step
# Epoch 60/500
# 1749/1749 - 10s - loss: 9.5722e-05 - val_loss: 4.0930e-05 - 10s/epoch - 6ms/step
# Epoch 61/500
# 1749/1749 - 10s - loss: 9.6220e-05 - val_loss: 4.3370e-05 - 10s/epoch - 6ms/step
# Epoch 62/500
# 1749/1749 - 9s - loss: 9.6385e-05 - val_loss: 4.4920e-05 - 9s/epoch - 5ms/step
# Epoch 63/500
# 1749/1749 - 10s - loss: 9.6440e-05 - val_loss: 4.5527e-05 - 10s/epoch - 6ms/step
# Epoch 64/500
# 1749/1749 - 8s - loss: 9.6462e-05 - val_loss: 4.5592e-05 - 8s/epoch - 4ms/step
# Epoch 65/500
# 1749/1749 - 5s - loss: 9.6488e-05 - val_loss: 4.5396e-05 - 5s/epoch - 3ms/step
# Epoch 66/500
# 1749/1749 - 7s - loss: 9.6489e-05 - val_loss: 4.5166e-05 - 7s/epoch - 4ms/step
# Epoch 67/500
# 1749/1749 - 6s - loss: 9.6489e-05 - val_loss: 4.5044e-05 - 6s/epoch - 4ms/step
# Epoch 68/500
# 1749/1749 - 5s - loss: 9.6483e-05 - val_loss: 4.5077e-05 - 5s/epoch - 3ms/step
# Epoch 69/500
# 1749/1749 - 7s - loss: 9.6473e-05 - val_loss: 4.5283e-05 - 7s/epoch - 4ms/step
# Epoch 70/500
# 1749/1749 - 6s - loss: 9.6464e-05 - val_loss: 4.5649e-05 - 6s/epoch - 3ms/step
# Epoch 71/500
# 1749/1749 - 6s - loss: 9.6459e-05 - val_loss: 4.6162e-05 - 6s/epoch - 3ms/step
# Epoch 72/500
# 1749/1749 - 6s - loss: 9.6460e-05 - val_loss: 4.6808e-05 - 6s/epoch - 3ms/step
# Epoch 73/500
# 1749/1749 - 6s - loss: 9.6467e-05 - val_loss: 4.7589e-05 - 6s/epoch - 3ms/step
# Epoch 74/500
# 1749/1749 - 6s - loss: 9.6492e-05 - val_loss: 4.8514e-05 - 6s/epoch - 3ms/step
# Epoch 75/500
# 1749/1749 - 6s - loss: 9.6533e-05 - val_loss: 4.9602e-05 - 6s/epoch - 3ms/step
# Epoch 76/500
# 1749/1749 - 6s - loss: 9.6598e-05 - val_loss: 5.0891e-05 - 6s/epoch - 3ms/step
# Epoch 77/500
# 1749/1749 - 6s - loss: 9.6705e-05 - val_loss: 5.2430e-05 - 6s/epoch - 3ms/step
# Epoch 78/500
# 1749/1749 - 6s - loss: 9.6869e-05 - val_loss: 5.4318e-05 - 6s/epoch - 4ms/step
# Epoch 79/500
# 1749/1749 - 6s - loss: 9.7130e-05 - val_loss: 5.6743e-05 - 6s/epoch - 3ms/step
# Epoch 80/500
# 1749/1749 - 6s - loss: 9.7581e-05 - val_loss: 6.0092e-05 - 6s/epoch - 3ms/step
# Epoch 81/500
# 1749/1749 - 6s - loss: 9.8499e-05 - val_loss: 6.5356e-05 - 6s/epoch - 4ms/step
# Epoch 82/500
# 1749/1749 - 6s - loss: 1.0122e-04 - val_loss: 7.7082e-05 - 6s/epoch - 4ms/step
# Epoch 83/500
# 1749/1749 - 8s - loss: 1.0539e-04 - val_loss: 8.7826e-05 - 8s/epoch - 4ms/step
# Epoch 84/500
# 1749/1749 - 10s - loss: 1.0407e-04 - val_loss: 8.6449e-05 - 10s/epoch - 5ms/step
# Epoch 85/500
# 1749/1749 - 7s - loss: 1.0401e-04 - val_loss: 8.6683e-05 - 7s/epoch - 4ms/step
# Epoch 86/500
# 1749/1749 - 5s - loss: 1.0387e-04 - val_loss: 8.6676e-05 - 5s/epoch - 3ms/step
# Epoch 87/500
# 1749/1749 - 5s - loss: 1.0371e-04 - val_loss: 8.6528e-05 - 5s/epoch - 3ms/step
# Epoch 88/500
# 1749/1749 - 6s - loss: 1.0354e-04 - val_loss: 8.6273e-05 - 6s/epoch - 3ms/step
# Epoch 89/500
# 1749/1749 - 6s - loss: 1.0337e-04 - val_loss: 8.5922e-05 - 6s/epoch - 4ms/step
# Epoch 90/500
# 1749/1749 - 8s - loss: 1.0319e-04 - val_loss: 8.5489e-05 - 8s/epoch - 4ms/step
# Epoch 91/500
# 1749/1749 - 7s - loss: 1.0302e-04 - val_loss: 8.4974e-05 - 7s/epoch - 4ms/step
# Epoch 92/500
# 1749/1749 - 7s - loss: 1.0284e-04 - val_loss: 8.4384e-05 - 7s/epoch - 4ms/step
# Epoch 93/500
# 1749/1749 - 8s - loss: 1.0267e-04 - val_loss: 8.3723e-05 - 8s/epoch - 5ms/step
# Epoch 94/500
# 1749/1749 - 5s - loss: 1.0249e-04 - val_loss: 8.2997e-05 - 5s/epoch - 3ms/step
# Epoch 95/500
# 1749/1749 - 5s - loss: 1.0232e-04 - val_loss: 8.2211e-05 - 5s/epoch - 3ms/step
# Epoch 96/500
# 1749/1749 - 5s - loss: 1.0214e-04 - val_loss: 8.1373e-05 - 5s/epoch - 3ms/step
# Epoch 97/500
# 1749/1749 - 5s - loss: 1.0197e-04 - val_loss: 8.0483e-05 - 5s/epoch - 3ms/step
# Epoch 98/500
# 1749/1749 - 6s - loss: 1.0180e-04 - val_loss: 7.9550e-05 - 6s/epoch - 3ms/step
# Epoch 99/500
# 1749/1749 - 7s - loss: 1.0162e-04 - val_loss: 7.8584e-05 - 7s/epoch - 4ms/step
# Epoch 100/500
# 1749/1749 - 8s - loss: 1.0145e-04 - val_loss: 7.7580e-05 - 8s/epoch - 5ms/step
# Epoch 101/500
# 1749/1749 - 8s - loss: 1.0128e-04 - val_loss: 7.6551e-05 - 8s/epoch - 4ms/step
# Epoch 102/500
# 1749/1749 - 7s - loss: 1.0112e-04 - val_loss: 7.5492e-05 - 7s/epoch - 4ms/step
# Epoch 103/500
# 1749/1749 - 7s - loss: 1.0095e-04 - val_loss: 7.4410e-05 - 7s/epoch - 4ms/step
# Epoch 104/500
# 1749/1749 - 7s - loss: 1.0080e-04 - val_loss: 7.3312e-05 - 7s/epoch - 4ms/step
# Epoch 105/500
# 1749/1749 - 5s - loss: 1.0065e-04 - val_loss: 7.2226e-05 - 5s/epoch - 3ms/step
# Epoch 106/500
# 1749/1749 - 8s - loss: 1.0049e-04 - val_loss: 7.1189e-05 - 8s/epoch - 5ms/step
# Epoch 107/500
# 1749/1749 - 8s - loss: 1.0034e-04 - val_loss: 7.0237e-05 - 8s/epoch - 4ms/step
# Epoch 108/500
# 1749/1749 - 10s - loss: 1.0019e-04 - val_loss: 6.9358e-05 - 10s/epoch - 6ms/step
# Epoch 109/500
# 1749/1749 - 8s - loss: 1.0005e-04 - val_loss: 6.8525e-05 - 8s/epoch - 5ms/step
# Epoch 110/500
# 1749/1749 - 9s - loss: 9.9903e-05 - val_loss: 6.7709e-05 - 9s/epoch - 5ms/step
# Epoch 111/500
# 1749/1749 - 8s - loss: 9.9765e-05 - val_loss: 6.6905e-05 - 8s/epoch - 5ms/step
# Epoch 112/500
# 1749/1749 - 10s - loss: 9.9632e-05 - val_loss: 6.6113e-05 - 10s/epoch - 6ms/step
# Epoch 113/500
# 1749/1749 - 9s - loss: 9.9503e-05 - val_loss: 6.5335e-05 - 9s/epoch - 5ms/step
# Epoch 114/500
# 1749/1749 - 9s - loss: 9.9380e-05 - val_loss: 6.4561e-05 - 9s/epoch - 5ms/step
# Epoch 115/500
# 1749/1749 - 9s - loss: 9.9260e-05 - val_loss: 6.3799e-05 - 9s/epoch - 5ms/step
# Epoch 116/500
# 1749/1749 - 9s - loss: 9.9144e-05 - val_loss: 6.3044e-05 - 9s/epoch - 5ms/step
# Epoch 117/500
# 1749/1749 - 9s - loss: 9.9031e-05 - val_loss: 6.2288e-05 - 9s/epoch - 5ms/step
# Epoch 118/500
# 1749/1749 - 8s - loss: 9.8923e-05 - val_loss: 6.1518e-05 - 8s/epoch - 5ms/step
# Epoch 119/500
# 1749/1749 - 9s - loss: 9.8818e-05 - val_loss: 6.0730e-05 - 9s/epoch - 5ms/step
# Epoch 120/500
# 1749/1749 - 13s - loss: 9.8730e-05 - val_loss: 6.0143e-05 - 13s/epoch - 8ms/step
# Epoch 121/500
# 1749/1749 - 12s - loss: 9.8724e-05 - val_loss: 6.0220e-05 - 12s/epoch - 7ms/step
# Epoch 122/500
# 1749/1749 - 16s - loss: 9.8503e-05 - val_loss: 5.8327e-05 - 16s/epoch - 9ms/step
# Epoch 123/500
# 1749/1749 - 9s - loss: 9.8430e-05 - val_loss: 5.7093e-05 - 9s/epoch - 5ms/step
# Epoch 124/500
# 1749/1749 - 12s - loss: 9.8346e-05 - val_loss: 5.6312e-05 - 12s/epoch - 7ms/step
# Epoch 125/500
# 1749/1749 - 11s - loss: 9.8251e-05 - val_loss: 5.5529e-05 - 11s/epoch - 7ms/step
# Epoch 126/500
# 1749/1749 - 13s - loss: 9.8156e-05 - val_loss: 5.4783e-05 - 13s/epoch - 7ms/step
# Epoch 127/500
# 1749/1749 - 15s - loss: 9.8065e-05 - val_loss: 5.4036e-05 - 15s/epoch - 8ms/step
# Epoch 128/500
# 1749/1749 - 12s - loss: 9.7975e-05 - val_loss: 5.3274e-05 - 12s/epoch - 7ms/step
# Epoch 129/500
# 1749/1749 - 12s - loss: 9.7887e-05 - val_loss: 5.2510e-05 - 12s/epoch - 7ms/step
# Epoch 130/500
# 1749/1749 - 10s - loss: 9.7800e-05 - val_loss: 5.1749e-05 - 10s/epoch - 6ms/step
# Epoch 131/500
# 1749/1749 - 10s - loss: 9.7715e-05 - val_loss: 5.1003e-05 - 10s/epoch - 6ms/step
# Epoch 132/500
# 1749/1749 - 10s - loss: 9.7629e-05 - val_loss: 5.0261e-05 - 10s/epoch - 6ms/step
# Epoch 133/500
# 1749/1749 - 10s - loss: 9.7547e-05 - val_loss: 4.9534e-05 - 10s/epoch - 6ms/step
# Epoch 134/500
# 1749/1749 - 11s - loss: 9.7463e-05 - val_loss: 4.8824e-05 - 11s/epoch - 6ms/step
# Epoch 135/500
# 1749/1749 - 11s - loss: 9.7384e-05 - val_loss: 4.8134e-05 - 11s/epoch - 6ms/step
# Epoch 136/500
# 1749/1749 - 11s - loss: 9.7297e-05 - val_loss: 4.7452e-05 - 11s/epoch - 6ms/step
# Epoch 137/500
# 1749/1749 - 12s - loss: 9.7217e-05 - val_loss: 4.6799e-05 - 12s/epoch - 7ms/step
# Epoch 138/500
# 1749/1749 - 10s - loss: 9.7134e-05 - val_loss: 4.6155e-05 - 10s/epoch - 6ms/step
# Epoch 139/500
# 1749/1749 - 10s - loss: 0.0404 - val_loss: 0.1539 - 10s/epoch - 6ms/step
# Epoch 140/500
# 1749/1749 - 11s - loss: 0.0298 - val_loss: 1.6748e-04 - 11s/epoch - 6ms/step
# Epoch 141/500
# 1749/1749 - 10s - loss: 0.0341 - val_loss: 3.6512e-05 - 10s/epoch - 6ms/step
# Epoch 142/500
# 1749/1749 - 11s - loss: 9.5448e-05 - val_loss: 3.6409e-05 - 11s/epoch - 6ms/step
# Epoch 143/500
# 1749/1749 - 11s - loss: 9.4933e-05 - val_loss: 3.6219e-05 - 11s/epoch - 6ms/step
# Epoch 144/500
# 1749/1749 - 11s - loss: 9.4154e-05 - val_loss: 3.5912e-05 - 11s/epoch - 6ms/step
# Epoch 145/500
# 1749/1749 - 13s - loss: 9.3115e-05 - val_loss: 3.5554e-05 - 13s/epoch - 7ms/step
# Epoch 146/500
# 1749/1749 - 11s - loss: 9.1793e-05 - val_loss: 3.5178e-05 - 11s/epoch - 7ms/step
# Epoch 147/500
# 1749/1749 - 10s - loss: 9.0381e-05 - val_loss: 3.4962e-05 - 10s/epoch - 6ms/step
# Epoch 148/500
# 1749/1749 - 10s - loss: 9.2797e-05 - val_loss: 3.8532e-05 - 10s/epoch - 6ms/step
# Epoch 149/500
# 1749/1749 - 10s - loss: 9.0351e-05 - val_loss: 3.7955e-05 - 10s/epoch - 6ms/step
# Epoch 150/500
# 1749/1749 - 10s - loss: 8.9882e-05 - val_loss: 3.7497e-05 - 10s/epoch - 6ms/step
# Epoch 151/500
# 1749/1749 - 11s - loss: 9.3477e-05 - val_loss: 3.9758e-05 - 11s/epoch - 6ms/step
# Epoch 152/500
# 1749/1749 - 13s - loss: 9.6165e-05 - val_loss: 4.0766e-05 - 13s/epoch - 7ms/step
# Epoch 153/500
# 1749/1749 - 15s - loss: 9.6872e-05 - val_loss: 3.7005e-05 - 15s/epoch - 8ms/step
# Epoch 154/500
# 1749/1749 - 12s - loss: 9.6804e-05 - val_loss: 3.5915e-05 - 12s/epoch - 7ms/step
# Epoch 155/500
# 1749/1749 - 11s - loss: 9.6638e-05 - val_loss: 3.5570e-05 - 11s/epoch - 6ms/step
# Epoch 156/500
# 1749/1749 - 10s - loss: 9.6476e-05 - val_loss: 3.5404e-05 - 10s/epoch - 6ms/step
# Epoch 157/500
# 1749/1749 - 14s - loss: 9.6328e-05 - val_loss: 3.5304e-05 - 14s/epoch - 8ms/step
# Epoch 158/500
# 1749/1749 - 12s - loss: 9.6180e-05 - val_loss: 3.5233e-05 - 12s/epoch - 7ms/step
# Epoch 159/500
# 1749/1749 - 12s - loss: 9.6272e-05 - val_loss: 3.5659e-05 - 12s/epoch - 7ms/step
# Epoch 160/500
# 1749/1749 - 12s - loss: 9.5923e-05 - val_loss: 3.5479e-05 - 12s/epoch - 7ms/step
# Epoch 161/500
# 1749/1749 - 11s - loss: 9.5782e-05 - val_loss: 3.5125e-05 - 11s/epoch - 6ms/step
# Epoch 162/500
# 1749/1749 - 9s - loss: 9.5703e-05 - val_loss: 3.5018e-05 - 9s/epoch - 5ms/step
# Epoch 163/500
# 1749/1749 - 8s - loss: 9.5603e-05 - val_loss: 3.4967e-05 - 8s/epoch - 5ms/step
# Epoch 164/500
# 1749/1749 - 8s - loss: 9.5511e-05 - val_loss: 3.4915e-05 - 8s/epoch - 5ms/step
# Epoch 165/500
# 1749/1749 - 10s - loss: 9.5416e-05 - val_loss: 3.4863e-05 - 10s/epoch - 6ms/step
# Epoch 166/500
# 1749/1749 - 10s - loss: 9.5328e-05 - val_loss: 3.4811e-05 - 10s/epoch - 6ms/step
# Epoch 167/500
# 1749/1749 - 11s - loss: 9.5244e-05 - val_loss: 3.4763e-05 - 11s/epoch - 6ms/step
# Epoch 168/500
# 1749/1749 - 11s - loss: 9.5161e-05 - val_loss: 3.4716e-05 - 11s/epoch - 6ms/step
# Epoch 169/500
# 1749/1749 - 11s - loss: 9.5082e-05 - val_loss: 3.4676e-05 - 11s/epoch - 6ms/step
# Epoch 170/500
# 1749/1749 - 12s - loss: 9.5003e-05 - val_loss: 3.4635e-05 - 12s/epoch - 7ms/step
# Epoch 171/500
# 1749/1749 - 12s - loss: 9.4930e-05 - val_loss: 3.4602e-05 - 12s/epoch - 7ms/step
# Epoch 172/500
# 1749/1749 - 11s - loss: 9.4855e-05 - val_loss: 3.4574e-05 - 11s/epoch - 6ms/step
# Epoch 173/500
# 1749/1749 - 11s - loss: 9.4780e-05 - val_loss: 3.4549e-05 - 11s/epoch - 6ms/step
# Epoch 174/500
# 1749/1749 - 11s - loss: 9.4706e-05 - val_loss: 3.4529e-05 - 11s/epoch - 6ms/step
# Epoch 175/500
# 1749/1749 - 13s - loss: 9.4633e-05 - val_loss: 3.4512e-05 - 13s/epoch - 7ms/step
# Epoch 176/500
# 1749/1749 - 12s - loss: 9.4560e-05 - val_loss: 3.4499e-05 - 12s/epoch - 7ms/step
# Epoch 177/500
# 1749/1749 - 12s - loss: 9.4488e-05 - val_loss: 3.4490e-05 - 12s/epoch - 7ms/step
# Epoch 178/500
# 1749/1749 - 12s - loss: 9.4413e-05 - val_loss: 3.4484e-05 - 12s/epoch - 7ms/step
# Epoch 179/500
# 1749/1749 - 12s - loss: 9.4342e-05 - val_loss: 3.4481e-05 - 12s/epoch - 7ms/step
# Epoch 180/500
# 1749/1749 - 11s - loss: 9.4266e-05 - val_loss: 3.4481e-05 - 11s/epoch - 6ms/step
# Epoch 181/500
# 1749/1749 - 11s - loss: 9.4192e-05 - val_loss: 3.4482e-05 - 11s/epoch - 6ms/step
# Epoch 182/500
# 1749/1749 - 10s - loss: 9.4116e-05 - val_loss: 3.4484e-05 - 10s/epoch - 6ms/step
# Epoch 183/500
# 1749/1749 - 10s - loss: 9.4040e-05 - val_loss: 3.4486e-05 - 10s/epoch - 6ms/step
# Epoch 184/500
# 1749/1749 - 10s - loss: 9.3962e-05 - val_loss: 3.4485e-05 - 10s/epoch - 6ms/step
# Epoch 185/500
# 1749/1749 - 10s - loss: 9.3883e-05 - val_loss: 3.4481e-05 - 10s/epoch - 6ms/step
# Epoch 186/500
# 1749/1749 - 11s - loss: 9.3802e-05 - val_loss: 3.4472e-05 - 11s/epoch - 6ms/step
# Epoch 187/500
# 1749/1749 - 11s - loss: 9.3723e-05 - val_loss: 3.4457e-05 - 11s/epoch - 6ms/step
# Epoch 188/500
# 1749/1749 - 11s - loss: 9.3644e-05 - val_loss: 3.4440e-05 - 11s/epoch - 6ms/step
# Epoch 189/500
# 1749/1749 - 11s - loss: 9.3565e-05 - val_loss: 3.4423e-05 - 11s/epoch - 6ms/step
# Epoch 190/500
# 1749/1749 - 12s - loss: 9.3489e-05 - val_loss: 3.4409e-05 - 12s/epoch - 7ms/step
# Epoch 191/500
# 1749/1749 - 11s - loss: 9.3415e-05 - val_loss: 3.4398e-05 - 11s/epoch - 6ms/step
# Epoch 192/500
# 1749/1749 - 10s - loss: 9.3344e-05 - val_loss: 3.4390e-05 - 10s/epoch - 6ms/step
# Epoch 193/500
# 1749/1749 - 10s - loss: 9.3274e-05 - val_loss: 3.4383e-05 - 10s/epoch - 6ms/step
# Epoch 194/500
# 1749/1749 - 10s - loss: 9.3205e-05 - val_loss: 3.4378e-05 - 10s/epoch - 6ms/step
# Epoch 195/500
# 1749/1749 - 11s - loss: 9.3138e-05 - val_loss: 3.4374e-05 - 11s/epoch - 6ms/step
# Epoch 196/500
# 1749/1749 - 11s - loss: 9.3075e-05 - val_loss: 3.4372e-05 - 11s/epoch - 7ms/step
# Epoch 197/500
# 1749/1749 - 11s - loss: 9.3017e-05 - val_loss: 3.4371e-05 - 11s/epoch - 6ms/step
# Epoch 198/500
# 1749/1749 - 11s - loss: 9.2956e-05 - val_loss: 3.4374e-05 - 11s/epoch - 6ms/step
# Epoch 199/500
# 1749/1749 - 11s - loss: 9.2904e-05 - val_loss: 3.4376e-05 - 11s/epoch - 6ms/step
# Epoch 200/500
# 1749/1749 - 11s - loss: 9.2848e-05 - val_loss: 3.4385e-05 - 11s/epoch - 6ms/step
# Epoch 201/500
# 1749/1749 - 16s - loss: 9.2801e-05 - val_loss: 3.4394e-05 - 16s/epoch - 9ms/step
# Epoch 202/500
# 1749/1749 - 18s - loss: 9.2753e-05 - val_loss: 3.4407e-05 - 18s/epoch - 10ms/step
# Epoch 203/500
# 1749/1749 - 11s - loss: 9.2711e-05 - val_loss: 3.4424e-05 - 11s/epoch - 6ms/step
# Epoch 204/500
# 1749/1749 - 11s - loss: 9.2671e-05 - val_loss: 3.4443e-05 - 11s/epoch - 6ms/step
# Epoch 205/500
# 1749/1749 - 10s - loss: 9.2634e-05 - val_loss: 3.4464e-05 - 10s/epoch - 6ms/step
# Epoch 206/500
# 1749/1749 - 10s - loss: 9.2595e-05 - val_loss: 3.4489e-05 - 10s/epoch - 6ms/step
# Epoch 207/500
# 1749/1749 - 10s - loss: 9.2565e-05 - val_loss: 3.4514e-05 - 10s/epoch - 6ms/step
# Epoch 208/500
# 1749/1749 - 10s - loss: 9.2529e-05 - val_loss: 3.4542e-05 - 10s/epoch - 6ms/step
# Epoch 209/500
# 1749/1749 - 10s - loss: 9.2499e-05 - val_loss: 3.4569e-05 - 10s/epoch - 6ms/step
# Epoch 210/500
# 1749/1749 - 11s - loss: 9.2471e-05 - val_loss: 3.4599e-05 - 11s/epoch - 6ms/step
# Epoch 211/500
# 1749/1749 - 10s - loss: 9.2438e-05 - val_loss: 3.4631e-05 - 10s/epoch - 6ms/step
# Epoch 212/500
# 1749/1749 - 10s - loss: 9.2413e-05 - val_loss: 3.4662e-05 - 10s/epoch - 6ms/step
# Epoch 213/500
# 1749/1749 - 9s - loss: 9.2379e-05 - val_loss: 3.4692e-05 - 9s/epoch - 5ms/step
# Epoch 214/500
# 1749/1749 - 8s - loss: 9.2354e-05 - val_loss: 3.4724e-05 - 8s/epoch - 5ms/step
# Epoch 215/500
# 1749/1749 - 9s - loss: 9.2324e-05 - val_loss: 3.4756e-05 - 9s/epoch - 5ms/step
# Epoch 216/500
# 1749/1749 - 8s - loss: 9.2298e-05 - val_loss: 3.4787e-05 - 8s/epoch - 5ms/step
# Epoch 217/500
# 1749/1749 - 8s - loss: 9.2268e-05 - val_loss: 3.4822e-05 - 8s/epoch - 5ms/step
# Epoch 218/500
# 1749/1749 - 8s - loss: 9.2244e-05 - val_loss: 3.4852e-05 - 8s/epoch - 5ms/step
# Epoch 219/500
# 1749/1749 - 8s - loss: 9.2212e-05 - val_loss: 3.4882e-05 - 8s/epoch - 5ms/step
# Epoch 220/500
# 1749/1749 - 9s - loss: 9.2190e-05 - val_loss: 3.4914e-05 - 9s/epoch - 5ms/step
# Epoch 221/500
# 1749/1749 - 9s - loss: 9.2160e-05 - val_loss: 3.4947e-05 - 9s/epoch - 5ms/step
# Epoch 222/500
# 1749/1749 - 8s - loss: 9.2137e-05 - val_loss: 3.4978e-05 - 8s/epoch - 5ms/step
# Epoch 223/500
# 1749/1749 - 8s - loss: 9.2107e-05 - val_loss: 3.5010e-05 - 8s/epoch - 5ms/step
# Epoch 224/500
# 1749/1749 - 8s - loss: 9.2085e-05 - val_loss: 3.5042e-05 - 8s/epoch - 5ms/step
# Epoch 225/500
# 1749/1749 - 10s - loss: 9.2058e-05 - val_loss: 3.5076e-05 - 10s/epoch - 6ms/step
# Epoch 226/500
# 1749/1749 - 10s - loss: 9.2035e-05 - val_loss: 3.5104e-05 - 10s/epoch - 6ms/step
# Epoch 227/500
# 1749/1749 - 11s - loss: 9.2008e-05 - val_loss: 3.5137e-05 - 11s/epoch - 6ms/step
# Epoch 228/500
# 1749/1749 - 10s - loss: 9.1983e-05 - val_loss: 3.5167e-05 - 10s/epoch - 6ms/step
# Epoch 229/500
# 1749/1749 - 13s - loss: 9.1958e-05 - val_loss: 3.5199e-05 - 13s/epoch - 7ms/step
# Epoch 230/500
# 1749/1749 - 13s - loss: 9.1934e-05 - val_loss: 3.5230e-05 - 13s/epoch - 7ms/step
# Epoch 231/500
# 1749/1749 - 14s - loss: 9.1909e-05 - val_loss: 3.5260e-05 - 14s/epoch - 8ms/step
# Epoch 232/500
# 1749/1749 - 15s - loss: 9.1882e-05 - val_loss: 3.5292e-05 - 15s/epoch - 9ms/step
# Epoch 233/500
# 1749/1749 - 12s - loss: 9.1860e-05 - val_loss: 3.5321e-05 - 12s/epoch - 7ms/step
# Epoch 234/500
# 1749/1749 - 12s - loss: 9.1835e-05 - val_loss: 3.5351e-05 - 12s/epoch - 7ms/step
# Epoch 235/500
# 1749/1749 - 12s - loss: 9.1811e-05 - val_loss: 3.5380e-05 - 12s/epoch - 7ms/step
# Epoch 236/500
# 1749/1749 - 12s - loss: 9.1787e-05 - val_loss: 3.5409e-05 - 12s/epoch - 7ms/step
# Epoch 237/500
# 1749/1749 - 12s - loss: 9.1763e-05 - val_loss: 3.5438e-05 - 12s/epoch - 7ms/step
# Epoch 238/500
# 1749/1749 - 13s - loss: 9.1739e-05 - val_loss: 3.5467e-05 - 13s/epoch - 7ms/step
# Epoch 239/500
# 1749/1749 - 13s - loss: 9.1715e-05 - val_loss: 3.5495e-05 - 13s/epoch - 7ms/step
# Epoch 240/500
# 1749/1749 - 11s - loss: 9.1692e-05 - val_loss: 3.5523e-05 - 11s/epoch - 6ms/step
# Epoch 241/500
# 1749/1749 - 11s - loss: 9.1668e-05 - val_loss: 3.5551e-05 - 11s/epoch - 6ms/step
# Epoch 242/500
# 1749/1749 - 11s - loss: 9.1645e-05 - val_loss: 3.5578e-05 - 11s/epoch - 6ms/step
# Epoch 243/500
# 1749/1749 - 11s - loss: 9.1621e-05 - val_loss: 3.5605e-05 - 11s/epoch - 6ms/step
# Epoch 244/500
# 1749/1749 - 11s - loss: 9.1598e-05 - val_loss: 3.5632e-05 - 11s/epoch - 6ms/step
# Epoch 245/500
# 1749/1749 - 11s - loss: 9.1573e-05 - val_loss: 3.5659e-05 - 11s/epoch - 6ms/step
# Epoch 246/500
# 1749/1749 - 11s - loss: 9.1552e-05 - val_loss: 3.5684e-05 - 11s/epoch - 6ms/step
# Epoch 247/500
# 1749/1749 - 8s - loss: 9.1528e-05 - val_loss: 3.5710e-05 - 8s/epoch - 5ms/step
# Epoch 248/500
# 1749/1749 - 8s - loss: 9.1506e-05 - val_loss: 3.5735e-05 - 8s/epoch - 5ms/step
# Epoch 249/500
# 1749/1749 - 8s - loss: 9.1481e-05 - val_loss: 3.5760e-05 - 8s/epoch - 5ms/step
# Epoch 250/500
# 1749/1749 - 8s - loss: 9.1458e-05 - val_loss: 3.5786e-05 - 8s/epoch - 5ms/step
# Epoch 251/500
# 1749/1749 - 8s - loss: 9.1435e-05 - val_loss: 3.5810e-05 - 8s/epoch - 5ms/step
# Epoch 252/500
# 1749/1749 - 8s - loss: 9.1413e-05 - val_loss: 3.5834e-05 - 8s/epoch - 5ms/step
# Epoch 253/500
# 1749/1749 - 8s - loss: 9.1390e-05 - val_loss: 3.5857e-05 - 8s/epoch - 5ms/step
# Epoch 254/500
# 1749/1749 - 9s - loss: 9.1366e-05 - val_loss: 3.5883e-05 - 9s/epoch - 5ms/step
# Epoch 255/500
# 1749/1749 - 8s - loss: 9.1344e-05 - val_loss: 3.5905e-05 - 8s/epoch - 5ms/step
# Epoch 256/500
# 1749/1749 - 9s - loss: 9.1322e-05 - val_loss: 3.5928e-05 - 9s/epoch - 5ms/step
# Epoch 257/500
# 1749/1749 - 8s - loss: 9.1297e-05 - val_loss: 3.5952e-05 - 8s/epoch - 5ms/step
# Epoch 258/500
# 1749/1749 - 8s - loss: 9.1277e-05 - val_loss: 3.5972e-05 - 8s/epoch - 5ms/step
# Epoch 259/500
# 1749/1749 - 8s - loss: 9.1251e-05 - val_loss: 3.5996e-05 - 8s/epoch - 5ms/step
# Epoch 260/500
# 1749/1749 - 8s - loss: 9.1231e-05 - val_loss: 3.6015e-05 - 8s/epoch - 5ms/step
# Epoch 261/500
# 1749/1749 - 8s - loss: 9.1207e-05 - val_loss: 3.6037e-05 - 8s/epoch - 5ms/step
# Epoch 262/500
# 1749/1749 - 8s - loss: 9.1184e-05 - val_loss: 3.6058e-05 - 8s/epoch - 5ms/step
# Epoch 263/500
# 1749/1749 - 8s - loss: 9.1164e-05 - val_loss: 3.6078e-05 - 8s/epoch - 5ms/step
# Epoch 264/500
# 1749/1749 - 8s - loss: 9.1140e-05 - val_loss: 3.6098e-05 - 8s/epoch - 5ms/step
# Epoch 265/500
# 1749/1749 - 8s - loss: 9.1117e-05 - val_loss: 3.6118e-05 - 8s/epoch - 5ms/step
# Epoch 266/500
# 1749/1749 - 8s - loss: 9.1096e-05 - val_loss: 3.6137e-05 - 8s/epoch - 5ms/step
# Epoch 267/500
# 1749/1749 - 8s - loss: 9.1073e-05 - val_loss: 3.6156e-05 - 8s/epoch - 5ms/step
# Epoch 268/500
# 1749/1749 - 8s - loss: 9.1051e-05 - val_loss: 3.6177e-05 - 8s/epoch - 5ms/step
# Epoch 269/500
# 1749/1749 - 8s - loss: 9.1029e-05 - val_loss: 3.6195e-05 - 8s/epoch - 5ms/step
# Epoch 270/500
# 1749/1749 - 8s - loss: 9.1008e-05 - val_loss: 3.6212e-05 - 8s/epoch - 5ms/step
# Epoch 271/500
# 1749/1749 - 9s - loss: 9.0984e-05 - val_loss: 3.6229e-05 - 9s/epoch - 5ms/step
# Epoch 272/500
# 1749/1749 - 9s - loss: 9.0963e-05 - val_loss: 3.6248e-05 - 9s/epoch - 5ms/step
# Epoch 273/500
# 1749/1749 - 9s - loss: 9.0944e-05 - val_loss: 3.6265e-05 - 9s/epoch - 5ms/step
# Epoch 274/500
# 1749/1749 - 9s - loss: 9.0919e-05 - val_loss: 3.6281e-05 - 9s/epoch - 5ms/step
# Epoch 275/500
# 1749/1749 - 8s - loss: 9.0898e-05 - val_loss: 3.6300e-05 - 8s/epoch - 5ms/step
# Epoch 276/500
# 1749/1749 - 8s - loss: 9.0877e-05 - val_loss: 3.6318e-05 - 8s/epoch - 5ms/step
# Epoch 277/500
# 1749/1749 - 8s - loss: 9.0855e-05 - val_loss: 3.6339e-05 - 8s/epoch - 5ms/step
# Epoch 278/500
# 1749/1749 - 8s - loss: 9.0834e-05 - val_loss: 3.6347e-05 - 8s/epoch - 5ms/step
# Epoch 279/500
# 1749/1749 - 8s - loss: 9.0813e-05 - val_loss: 3.6359e-05 - 8s/epoch - 5ms/step
# Epoch 280/500
# 1749/1749 - 8s - loss: 9.0792e-05 - val_loss: 3.6372e-05 - 8s/epoch - 5ms/step
# Epoch 281/500
# 1749/1749 - 8s - loss: 9.0771e-05 - val_loss: 3.6386e-05 - 8s/epoch - 5ms/step
# Epoch 282/500
# 1749/1749 - 8s - loss: 9.0749e-05 - val_loss: 3.6401e-05 - 8s/epoch - 5ms/step
# Epoch 283/500
# 1749/1749 - 8s - loss: 9.0729e-05 - val_loss: 3.6417e-05 - 8s/epoch - 5ms/step
# Epoch 284/500
# 1749/1749 - 8s - loss: 9.0708e-05 - val_loss: 3.6431e-05 - 8s/epoch - 5ms/step
# Epoch 285/500
# 1749/1749 - 8s - loss: 9.0689e-05 - val_loss: 3.6445e-05 - 8s/epoch - 5ms/step
# Epoch 286/500
# 1749/1749 - 8s - loss: 9.0667e-05 - val_loss: 3.6458e-05 - 8s/epoch - 5ms/step
# Epoch 287/500
# 1749/1749 - 8s - loss: 9.0647e-05 - val_loss: 3.6470e-05 - 8s/epoch - 5ms/step
# Epoch 288/500
# 1749/1749 - 9s - loss: 9.0627e-05 - val_loss: 3.6484e-05 - 9s/epoch - 5ms/step
# Epoch 289/500
# 1749/1749 - 9s - loss: 9.0606e-05 - val_loss: 3.6498e-05 - 9s/epoch - 5ms/step
# Epoch 290/500
# 1749/1749 - 8s - loss: 9.0586e-05 - val_loss: 3.6517e-05 - 8s/epoch - 5ms/step
# Epoch 291/500
# 1749/1749 - 8s - loss: 9.0567e-05 - val_loss: 3.6525e-05 - 8s/epoch - 5ms/step
# Epoch 292/500
# 1749/1749 - 8s - loss: 9.0547e-05 - val_loss: 3.6536e-05 - 8s/epoch - 5ms/step
# Epoch 293/500
# 1749/1749 - 8s - loss: 9.0527e-05 - val_loss: 3.6549e-05 - 8s/epoch - 5ms/step
# Epoch 294/500
# 1749/1749 - 9s - loss: 9.0508e-05 - val_loss: 3.6562e-05 - 9s/epoch - 5ms/step
# Epoch 295/500
# 1749/1749 - 14s - loss: 9.0488e-05 - val_loss: 3.6576e-05 - 14s/epoch - 8ms/step
# Epoch 296/500
# 1749/1749 - 13s - loss: 9.0471e-05 - val_loss: 3.6587e-05 - 13s/epoch - 7ms/step
# Epoch 297/500
# 1749/1749 - 13s - loss: 9.0449e-05 - val_loss: 3.6634e-05 - 13s/epoch - 8ms/step
# Epoch 298/500
# 1749/1749 - 8s - loss: 9.0432e-05 - val_loss: 3.6609e-05 - 8s/epoch - 5ms/step
# Epoch 299/500
# 1749/1749 - 8s - loss: 9.0413e-05 - val_loss: 3.6627e-05 - 8s/epoch - 5ms/step
# Epoch 300/500
# 1749/1749 - 8s - loss: 9.0394e-05 - val_loss: 3.6644e-05 - 8s/epoch - 5ms/step
# Epoch 301/500
# 1749/1749 - 8s - loss: 9.0376e-05 - val_loss: 3.6655e-05 - 8s/epoch - 5ms/step
# Epoch 302/500
# 1749/1749 - 8s - loss: 9.0357e-05 - val_loss: 3.6663e-05 - 8s/epoch - 5ms/step
# Epoch 303/500
# 1749/1749 - 8s - loss: 9.0340e-05 - val_loss: 3.6674e-05 - 8s/epoch - 5ms/step
# Epoch 304/500
# 1749/1749 - 8s - loss: 9.0322e-05 - val_loss: 3.6697e-05 - 8s/epoch - 5ms/step
# Epoch 305/500
# 1749/1749 - 8s - loss: 9.0302e-05 - val_loss: 3.6722e-05 - 8s/epoch - 5ms/step
# Epoch 306/500
# 1749/1749 - 8s - loss: 9.0285e-05 - val_loss: 3.6728e-05 - 8s/epoch - 5ms/step
# Epoch 307/500
# 1749/1749 - 8s - loss: 9.0269e-05 - val_loss: 3.6715e-05 - 8s/epoch - 5ms/step
# Epoch 308/500
# 1749/1749 - 8s - loss: 9.0250e-05 - val_loss: 3.6721e-05 - 8s/epoch - 5ms/step
# Epoch 309/500
# 1749/1749 - 8s - loss: 9.0234e-05 - val_loss: 3.6790e-05 - 8s/epoch - 5ms/step
# Epoch 310/500
# 1749/1749 - 9s - loss: 9.0211e-05 - val_loss: 3.6836e-05 - 9s/epoch - 5ms/step
# Epoch 311/500
# 1749/1749 - 9s - loss: 9.0196e-05 - val_loss: 3.6812e-05 - 9s/epoch - 5ms/step
# Epoch 312/500
# 1749/1749 - 9s - loss: 9.0174e-05 - val_loss: 3.6687e-05 - 9s/epoch - 5ms/step
# Epoch 313/500
# 1749/1749 - 8s - loss: 9.0187e-05 - val_loss: 3.6896e-05 - 8s/epoch - 5ms/step
# Epoch 314/500
# 1749/1749 - 9s - loss: 9.0127e-05 - val_loss: 3.6809e-05 - 9s/epoch - 5ms/step
# Epoch 315/500
# 1749/1749 - 9s - loss: 9.0137e-05 - val_loss: 3.7049e-05 - 9s/epoch - 5ms/step
# Epoch 316/500
# 1749/1749 - 9s - loss: 9.0104e-05 - val_loss: 3.6923e-05 - 9s/epoch - 5ms/step
# Epoch 317/500
# 1749/1749 - 9s - loss: 9.0079e-05 - val_loss: 3.6537e-05 - 9s/epoch - 5ms/step
# Epoch 318/500
# 1749/1749 - 9s - loss: 9.0140e-05 - val_loss: 3.6440e-05 - 9s/epoch - 5ms/step
# Epoch 319/500
# 1749/1749 - 9s - loss: 9.0084e-05 - val_loss: 3.6355e-05 - 9s/epoch - 5ms/step
# Epoch 320/500
# 1749/1749 - 9s - loss: 9.0151e-05 - val_loss: 3.7095e-05 - 9s/epoch - 5ms/step
# Epoch 321/500
# 1749/1749 - 8s - loss: 9.0037e-05 - val_loss: 3.7151e-05 - 8s/epoch - 5ms/step
# Epoch 322/500
# 1749/1749 - 8s - loss: 9.0066e-05 - val_loss: 3.7085e-05 - 8s/epoch - 5ms/step
# Epoch 323/500
# 1749/1749 - 8s - loss: 9.0032e-05 - val_loss: 3.6938e-05 - 8s/epoch - 5ms/step
# Epoch 324/500
# 1749/1749 - 8s - loss: 8.9966e-05 - val_loss: 3.7371e-05 - 8s/epoch - 5ms/step
# Epoch 325/500
# 1749/1749 - 8s - loss: 8.9995e-05 - val_loss: 3.7285e-05 - 8s/epoch - 5ms/step
# Epoch 326/500
# 1749/1749 - 8s - loss: 8.9958e-05 - val_loss: 3.6960e-05 - 8s/epoch - 5ms/step
# Epoch 327/500
# 1749/1749 - 8s - loss: 8.9982e-05 - val_loss: 3.7406e-05 - 8s/epoch - 5ms/step
# Epoch 328/500
# 1749/1749 - 9s - loss: 8.9900e-05 - val_loss: 3.7102e-05 - 9s/epoch - 5ms/step
# Epoch 329/500
# 1749/1749 - 8s - loss: 8.9880e-05 - val_loss: 3.6684e-05 - 8s/epoch - 5ms/step
# Epoch 330/500
# 1749/1749 - 8s - loss: 9.0000e-05 - val_loss: 3.6946e-05 - 8s/epoch - 5ms/step
# Epoch 331/500
# 1749/1749 - 8s - loss: 8.9819e-05 - val_loss: 3.6662e-05 - 8s/epoch - 5ms/step
# Epoch 332/500
# 1749/1749 - 8s - loss: 8.9882e-05 - val_loss: 3.7421e-05 - 8s/epoch - 5ms/step
# Epoch 333/500
# 1749/1749 - 8s - loss: 8.9851e-05 - val_loss: 3.7471e-05 - 8s/epoch - 5ms/step
# Epoch 334/500
# 1749/1749 - 8s - loss: 8.9860e-05 - val_loss: 3.7271e-05 - 8s/epoch - 5ms/step
# Epoch 335/500
# 1749/1749 - 9s - loss: 8.9801e-05 - val_loss: 3.7004e-05 - 9s/epoch - 5ms/step
# Epoch 336/500
# 1749/1749 - 9s - loss: 8.9784e-05 - val_loss: 3.7673e-05 - 9s/epoch - 5ms/step
# Epoch 337/500
# 1749/1749 - 9s - loss: 8.9781e-05 - val_loss: 3.7562e-05 - 9s/epoch - 5ms/step
# Epoch 338/500
# 1749/1749 - 9s - loss: 8.9756e-05 - val_loss: 3.7169e-05 - 9s/epoch - 5ms/step
# Epoch 339/500
# 1749/1749 - 9s - loss: 8.9806e-05 - val_loss: 3.7470e-05 - 9s/epoch - 5ms/step
# Epoch 340/500
# 1749/1749 - 9s - loss: 8.9773e-05 - val_loss: 3.7466e-05 - 9s/epoch - 5ms/step
# Epoch 341/500
# 1749/1749 - 9s - loss: 8.9596e-05 - val_loss: 3.7747e-05 - 9s/epoch - 5ms/step
# Epoch 342/500
# 1749/1749 - 9s - loss: 8.9672e-05 - val_loss: 3.7745e-05 - 9s/epoch - 5ms/step
# Epoch 343/500
# 1749/1749 - 9s - loss: 8.9718e-05 - val_loss: 3.7549e-05 - 9s/epoch - 5ms/step
# Epoch 344/500
# 1749/1749 - 9s - loss: 8.9614e-05 - val_loss: 3.7118e-05 - 9s/epoch - 5ms/step
# Epoch 345/500
# 1749/1749 - 9s - loss: 8.9650e-05 - val_loss: 3.7749e-05 - 9s/epoch - 5ms/step
# Epoch 346/500
# 1749/1749 - 9s - loss: 8.9595e-05 - val_loss: 3.7392e-05 - 9s/epoch - 5ms/step
# Epoch 347/500
# 1749/1749 - 9s - loss: 8.9672e-05 - val_loss: 3.7321e-05 - 9s/epoch - 5ms/step
# Epoch 348/500
# 1749/1749 - 9s - loss: 8.9518e-05 - val_loss: 3.6789e-05 - 9s/epoch - 5ms/step
# Epoch 349/500
# 1749/1749 - 9s - loss: 8.9635e-05 - val_loss: 3.7381e-05 - 9s/epoch - 5ms/step
# Epoch 350/500
# 1749/1749 - 9s - loss: 8.9596e-05 - val_loss: 3.7520e-05 - 9s/epoch - 5ms/step
# Epoch 351/500
# 1749/1749 - 8s - loss: 8.9514e-05 - val_loss: 3.7911e-05 - 8s/epoch - 5ms/step
# Epoch 352/500
# 1749/1749 - 8s - loss: 8.9534e-05 - val_loss: 3.8017e-05 - 8s/epoch - 5ms/step
# Epoch 353/500
# 1749/1749 - 8s - loss: 8.9543e-05 - val_loss: 3.7742e-05 - 8s/epoch - 5ms/step
# Epoch 354/500
# 1749/1749 - 8s - loss: 8.9419e-05 - val_loss: 3.7216e-05 - 8s/epoch - 5ms/step
# Epoch 355/500
# 1749/1749 - 8s - loss: 8.9488e-05 - val_loss: 3.7983e-05 - 8s/epoch - 5ms/step
# Epoch 356/500
# 1749/1749 - 8s - loss: 8.9385e-05 - val_loss: 3.7583e-05 - 8s/epoch - 5ms/step
# Epoch 357/500
# 1749/1749 - 8s - loss: 8.9408e-05 - val_loss: 3.8060e-05 - 8s/epoch - 5ms/step
# Epoch 358/500
# 1749/1749 - 9s - loss: 8.9377e-05 - val_loss: 3.7515e-05 - 9s/epoch - 5ms/step
# Epoch 359/500
# 1749/1749 - 10s - loss: 8.9338e-05 - val_loss: 3.6940e-05 - 10s/epoch - 6ms/step
# Epoch 360/500
# 1749/1749 - 11s - loss: 8.9420e-05 - val_loss: 3.7268e-05 - 11s/epoch - 6ms/step
# Epoch 361/500
# 1749/1749 - 10s - loss: 8.9393e-05 - val_loss: 3.7785e-05 - 10s/epoch - 5ms/step
# Epoch 362/500
# 1749/1749 - 10s - loss: 8.9305e-05 - val_loss: 3.8189e-05 - 10s/epoch - 6ms/step
# Epoch 363/500
# 1749/1749 - 9s - loss: 8.9281e-05 - val_loss: 3.8342e-05 - 9s/epoch - 5ms/step
# Epoch 364/500
# 1749/1749 - 9s - loss: 8.9221e-05 - val_loss: 3.8241e-05 - 9s/epoch - 5ms/step
# Epoch 365/500
# 1749/1749 - 9s - loss: 8.9203e-05 - val_loss: 3.7976e-05 - 9s/epoch - 5ms/step
# Epoch 366/500
# 1749/1749 - 9s - loss: 8.9099e-05 - val_loss: 3.7311e-05 - 9s/epoch - 5ms/step
# Epoch 367/500
# 1749/1749 - 9s - loss: 8.9219e-05 - val_loss: 3.7646e-05 - 9s/epoch - 5ms/step
# Epoch 368/500
# 1749/1749 - 13s - loss: 8.8976e-05 - val_loss: 3.7080e-05 - 13s/epoch - 7ms/step
# Epoch 369/500
# 1749/1749 - 15s - loss: 8.9058e-05 - val_loss: 3.7759e-05 - 15s/epoch - 8ms/step
# Epoch 370/500
# 1749/1749 - 13s - loss: 8.9015e-05 - val_loss: 3.7665e-05 - 13s/epoch - 8ms/step
# Epoch 371/500
# 1749/1749 - 11s - loss: 8.8991e-05 - val_loss: 3.8005e-05 - 11s/epoch - 6ms/step
# Epoch 372/500
# 1749/1749 - 14s - loss: 8.8994e-05 - val_loss: 3.7375e-05 - 14s/epoch - 8ms/step
# Epoch 373/500
# 1749/1749 - 15s - loss: 8.8953e-05 - val_loss: 3.6985e-05 - 15s/epoch - 8ms/step
# Epoch 374/500
# 1749/1749 - 14s - loss: 8.9014e-05 - val_loss: 3.7507e-05 - 14s/epoch - 8ms/step
# Epoch 375/500
# 1749/1749 - 11s - loss: 8.9061e-05 - val_loss: 3.8224e-05 - 11s/epoch - 6ms/step
# Epoch 376/500
# 1749/1749 - 13s - loss: 8.8909e-05 - val_loss: 3.8380e-05 - 13s/epoch - 8ms/step
# Epoch 377/500
# 1749/1749 - 12s - loss: 8.8892e-05 - val_loss: 3.8294e-05 - 12s/epoch - 7ms/step
# Epoch 378/500
# 1749/1749 - 15s - loss: 8.8875e-05 - val_loss: 3.8169e-05 - 15s/epoch - 9ms/step
# Epoch 379/500
# 1749/1749 - 11s - loss: 8.8909e-05 - val_loss: 3.7675e-05 - 11s/epoch - 6ms/step
# Epoch 380/500
# 1749/1749 - 10s - loss: 8.8790e-05 - val_loss: 3.7015e-05 - 10s/epoch - 6ms/step
# Epoch 381/500
# 1749/1749 - 14s - loss: 8.8911e-05 - val_loss: 3.7239e-05 - 14s/epoch - 8ms/step
# Epoch 382/500
# 1749/1749 - 13s - loss: 8.8841e-05 - val_loss: 3.7460e-05 - 13s/epoch - 7ms/step
# Epoch 383/500
# 1749/1749 - 14s - loss: 8.8807e-05 - val_loss: 3.7823e-05 - 14s/epoch - 8ms/step
# Epoch 384/500
# 1749/1749 - 11s - loss: 8.8873e-05 - val_loss: 3.7543e-05 - 11s/epoch - 7ms/step
# Epoch 385/500
# 1749/1749 - 12s - loss: 8.8740e-05 - val_loss: 3.7132e-05 - 12s/epoch - 7ms/step
# Epoch 386/500
# 1749/1749 - 11s - loss: 8.8832e-05 - val_loss: 3.7763e-05 - 11s/epoch - 6ms/step
# Epoch 387/500
# 1749/1749 - 12s - loss: 8.8844e-05 - val_loss: 3.8049e-05 - 12s/epoch - 7ms/step
# Epoch 388/500
# 1749/1749 - 19s - loss: 8.8722e-05 - val_loss: 3.8264e-05 - 19s/epoch - 11ms/step
# Epoch 389/500
# 1749/1749 - 19s - loss: 8.8714e-05 - val_loss: 3.8194e-05 - 19s/epoch - 11ms/step
# Epoch 390/500
# 1749/1749 - 16s - loss: 8.8717e-05 - val_loss: 3.8151e-05 - 16s/epoch - 9ms/step
# Epoch 391/500
# 1749/1749 - 13s - loss: 8.8701e-05 - val_loss: 3.7613e-05 - 13s/epoch - 7ms/step
# Epoch 392/500
# 1749/1749 - 11s - loss: 8.8644e-05 - val_loss: 3.7247e-05 - 11s/epoch - 7ms/step
# Epoch 393/500
# 1749/1749 - 12s - loss: 8.8780e-05 - val_loss: 3.7522e-05 - 12s/epoch - 7ms/step
# Epoch 394/500
# 1749/1749 - 12s - loss: 8.8584e-05 - val_loss: 3.7210e-05 - 12s/epoch - 7ms/step
# Epoch 395/500
# 1749/1749 - 12s - loss: 8.8648e-05 - val_loss: 3.7783e-05 - 12s/epoch - 7ms/step
# Epoch 396/500
# 1749/1749 - 11s - loss: 8.8637e-05 - val_loss: 3.7708e-05 - 11s/epoch - 6ms/step
# Epoch 397/500
# 1749/1749 - 11s - loss: 8.8734e-05 - val_loss: 3.7455e-05 - 11s/epoch - 6ms/step
# Epoch 398/500
# 1749/1749 - 11s - loss: 8.8566e-05 - val_loss: 3.6887e-05 - 11s/epoch - 6ms/step
# Epoch 399/500
# 1749/1749 - 10s - loss: 8.8649e-05 - val_loss: 3.7293e-05 - 10s/epoch - 6ms/step
# Epoch 400/500
# 1749/1749 - 10s - loss: 8.8643e-05 - val_loss: 3.7594e-05 - 10s/epoch - 6ms/step
# Epoch 401/500
# 1749/1749 - 11s - loss: 8.8598e-05 - val_loss: 3.7818e-05 - 11s/epoch - 6ms/step
# Epoch 402/500
# 1749/1749 - 10s - loss: 8.8631e-05 - val_loss: 3.7936e-05 - 10s/epoch - 6ms/step
# Epoch 403/500
# 1749/1749 - 11s - loss: 8.8566e-05 - val_loss: 3.8403e-05 - 11s/epoch - 6ms/step
# Epoch 404/500
# 1749/1749 - 12s - loss: 8.8531e-05 - val_loss: 3.8296e-05 - 12s/epoch - 7ms/step
# Epoch 405/500
# 1749/1749 - 10s - loss: 8.8516e-05 - val_loss: 3.8167e-05 - 10s/epoch - 6ms/step
# Epoch 406/500
# 1749/1749 - 11s - loss: 8.8531e-05 - val_loss: 3.7665e-05 - 11s/epoch - 6ms/step
# Epoch 407/500
# 1749/1749 - 10s - loss: 8.8446e-05 - val_loss: 3.7124e-05 - 10s/epoch - 6ms/step
# Epoch 408/500
# 1749/1749 - 10s - loss: 8.8572e-05 - val_loss: 3.7292e-05 - 10s/epoch - 6ms/step
# Epoch 409/500
# 1749/1749 - 11s - loss: 8.8476e-05 - val_loss: 3.7446e-05 - 11s/epoch - 6ms/step
# Epoch 410/500
# 1749/1749 - 10s - loss: 8.8452e-05 - val_loss: 3.7805e-05 - 10s/epoch - 6ms/step
# Epoch 411/500
# 1749/1749 - 10s - loss: 8.8549e-05 - val_loss: 3.7435e-05 - 10s/epoch - 6ms/step
# Epoch 412/500
# 1749/1749 - 10s - loss: 8.8426e-05 - val_loss: 3.7078e-05 - 10s/epoch - 6ms/step
# Epoch 413/500
# 1749/1749 - 11s - loss: 8.8485e-05 - val_loss: 3.7580e-05 - 11s/epoch - 6ms/step
# Epoch 414/500
# 1749/1749 - 10s - loss: 8.8518e-05 - val_loss: 3.8058e-05 - 10s/epoch - 6ms/step
# Epoch 415/500
# 1749/1749 - 11s - loss: 8.8408e-05 - val_loss: 3.8175e-05 - 11s/epoch - 6ms/step
# Epoch 416/500
# 1749/1749 - 11s - loss: 8.8408e-05 - val_loss: 3.8212e-05 - 11s/epoch - 6ms/step
# Epoch 417/500
# 1749/1749 - 10s - loss: 8.8380e-05 - val_loss: 3.8206e-05 - 10s/epoch - 6ms/step
# Epoch 418/500
# 1749/1749 - 11s - loss: 8.8384e-05 - val_loss: 3.7674e-05 - 11s/epoch - 6ms/step
# Epoch 419/500
# 1749/1749 - 10s - loss: 8.8304e-05 - val_loss: 3.7159e-05 - 10s/epoch - 6ms/step
# Epoch 420/500
# 1749/1749 - 10s - loss: 8.8392e-05 - val_loss: 3.7455e-05 - 10s/epoch - 6ms/step
# Epoch 421/500
# 1749/1749 - 11s - loss: 8.8386e-05 - val_loss: 3.7931e-05 - 11s/epoch - 6ms/step
# Epoch 422/500
# 1749/1749 - 11s - loss: 8.8312e-05 - val_loss: 3.8086e-05 - 11s/epoch - 6ms/step
# Epoch 423/500
# 1749/1749 - 10s - loss: 8.8310e-05 - val_loss: 3.8162e-05 - 10s/epoch - 6ms/step
# Epoch 424/500
# 1749/1749 - 11s - loss: 8.8294e-05 - val_loss: 3.8165e-05 - 11s/epoch - 6ms/step
# Epoch 425/500
# 1749/1749 - 11s - loss: 8.8294e-05 - val_loss: 3.7609e-05 - 11s/epoch - 6ms/step
# Epoch 426/500
# 1749/1749 - 11s - loss: 8.8218e-05 - val_loss: 3.7313e-05 - 11s/epoch - 6ms/step
# Epoch 427/500
# 1749/1749 - 11s - loss: 8.8274e-05 - val_loss: 3.7636e-05 - 11s/epoch - 6ms/step
# Epoch 428/500
# 1749/1749 - 11s - loss: 8.8251e-05 - val_loss: 3.7754e-05 - 11s/epoch - 6ms/step
# Epoch 429/500
# 1749/1749 - 11s - loss: 8.8194e-05 - val_loss: 3.7940e-05 - 11s/epoch - 6ms/step
# Epoch 430/500
# 1749/1749 - 11s - loss: 8.8237e-05 - val_loss: 3.7895e-05 - 11s/epoch - 6ms/step
# Epoch 431/500
# 1749/1749 - 11s - loss: 8.8259e-05 - val_loss: 3.7248e-05 - 11s/epoch - 6ms/step
# Epoch 432/500
# 1749/1749 - 11s - loss: 8.8271e-05 - val_loss: 3.7596e-05 - 11s/epoch - 6ms/step
# Epoch 433/500
# 1749/1749 - 11s - loss: 8.8174e-05 - val_loss: 3.7879e-05 - 11s/epoch - 7ms/step
# Epoch 434/500
# 1749/1749 - 12s - loss: 8.8215e-05 - val_loss: 3.7626e-05 - 12s/epoch - 7ms/step
# Epoch 435/500
# 1749/1749 - 12s - loss: 8.8171e-05 - val_loss: 3.7271e-05 - 12s/epoch - 7ms/step
# Epoch 436/500
# 1749/1749 - 12s - loss: 8.8227e-05 - val_loss: 3.7705e-05 - 12s/epoch - 7ms/step
# Epoch 437/500
# 1749/1749 - 11s - loss: 8.8274e-05 - val_loss: 3.8272e-05 - 11s/epoch - 6ms/step
# Epoch 438/500
# 1749/1749 - 10s - loss: 9.1362e-05 - val_loss: 4.5785e-05 - 10s/epoch - 6ms/step
# Epoch 439/500
# 1749/1749 - 10s - loss: 8.7688e-05 - val_loss: 3.5905e-05 - 10s/epoch - 6ms/step
# Epoch 440/500
# 1749/1749 - 10s - loss: 8.7944e-05 - val_loss: 3.7379e-05 - 10s/epoch - 6ms/step
# Epoch 441/500
# 1749/1749 - 11s - loss: 8.7995e-05 - val_loss: 3.7777e-05 - 11s/epoch - 6ms/step
# Epoch 442/500
# 1749/1749 - 11s - loss: 8.7937e-05 - val_loss: 3.7696e-05 - 11s/epoch - 6ms/step
# Epoch 443/500
# 1749/1749 - 11s - loss: 8.7955e-05 - val_loss: 3.7580e-05 - 11s/epoch - 6ms/step
# Epoch 444/500
# 1749/1749 - 11s - loss: 8.8170e-05 - val_loss: 3.7071e-05 - 11s/epoch - 6ms/step
# Epoch 445/500
# 1749/1749 - 11s - loss: 8.8044e-05 - val_loss: 3.6941e-05 - 11s/epoch - 6ms/step
# Epoch 446/500
# 1749/1749 - 15s - loss: 8.8035e-05 - val_loss: 3.7467e-05 - 15s/epoch - 9ms/step
# Epoch 447/500
# 1749/1749 - 20s - loss: 8.7974e-05 - val_loss: 3.7681e-05 - 20s/epoch - 11ms/step
# Epoch 448/500
# 1749/1749 - 15s - loss: 8.8071e-05 - val_loss: 3.7137e-05 - 15s/epoch - 8ms/step
# Epoch 449/500
# 1749/1749 - 13s - loss: 8.8012e-05 - val_loss: 3.7039e-05 - 13s/epoch - 7ms/step
# Epoch 450/500
# 1749/1749 - 12s - loss: 8.8009e-05 - val_loss: 3.7589e-05 - 12s/epoch - 7ms/step
# Epoch 451/500
# 1749/1749 - 12s - loss: 8.7965e-05 - val_loss: 3.7758e-05 - 12s/epoch - 7ms/step
# Epoch 452/500
# 1749/1749 - 12s - loss: 8.7955e-05 - val_loss: 3.7756e-05 - 12s/epoch - 7ms/step
# Epoch 453/500
# 1749/1749 - 12s - loss: 8.7997e-05 - val_loss: 3.7519e-05 - 12s/epoch - 7ms/step
# Epoch 454/500
# 1749/1749 - 12s - loss: 8.7972e-05 - val_loss: 3.7089e-05 - 12s/epoch - 7ms/step
# Epoch 455/500
# 1749/1749 - 11s - loss: 8.7989e-05 - val_loss: 3.7585e-05 - 11s/epoch - 6ms/step
# Epoch 456/500
# 1749/1749 - 12s - loss: 8.7936e-05 - val_loss: 3.7905e-05 - 12s/epoch - 7ms/step
# Epoch 457/500
# 1749/1749 - 12s - loss: 8.7934e-05 - val_loss: 3.7580e-05 - 12s/epoch - 7ms/step
# Epoch 458/500
# 1749/1749 - 11s - loss: 8.7928e-05 - val_loss: 3.7322e-05 - 11s/epoch - 6ms/step
# Epoch 459/500
# 1749/1749 - 13s - loss: 8.7964e-05 - val_loss: 3.7854e-05 - 13s/epoch - 7ms/step
# Epoch 460/500
# 1749/1749 - 15s - loss: 8.7864e-05 - val_loss: 3.7715e-05 - 15s/epoch - 8ms/step
# Epoch 461/500
# 1749/1749 - 12s - loss: 8.7936e-05 - val_loss: 3.7883e-05 - 12s/epoch - 7ms/step
# Epoch 462/500
# 1749/1749 - 11s - loss: 8.7998e-05 - val_loss: 3.7512e-05 - 11s/epoch - 6ms/step
# Epoch 463/500
# 1749/1749 - 11s - loss: 8.8439e-05 - val_loss: 3.6681e-05 - 11s/epoch - 6ms/step
# Epoch 464/500
# 1749/1749 - 11s - loss: 8.7868e-05 - val_loss: 3.7786e-05 - 11s/epoch - 6ms/step
# Epoch 465/500
# 1749/1749 - 11s - loss: 8.7773e-05 - val_loss: 3.7978e-05 - 11s/epoch - 6ms/step
# Epoch 466/500
# 1749/1749 - 17s - loss: 8.7803e-05 - val_loss: 3.8029e-05 - 17s/epoch - 10ms/step
# Epoch 467/500
# 1749/1749 - 20s - loss: 8.7893e-05 - val_loss: 3.7743e-05 - 20s/epoch - 12ms/step
# Epoch 468/500
# 1749/1749 - 20s - loss: 8.7805e-05 - val_loss: 3.7285e-05 - 20s/epoch - 11ms/step
# Epoch 469/500
# 1749/1749 - 12s - loss: 8.7853e-05 - val_loss: 3.7633e-05 - 12s/epoch - 7ms/step
# Epoch 470/500
# 1749/1749 - 12s - loss: 8.7878e-05 - val_loss: 3.8183e-05 - 12s/epoch - 7ms/step
# Epoch 471/500
# 1749/1749 - 11s - loss: 8.7865e-05 - val_loss: 3.7993e-05 - 11s/epoch - 6ms/step
# Epoch 472/500
# 1749/1749 - 11s - loss: 8.7774e-05 - val_loss: 3.7873e-05 - 11s/epoch - 6ms/step
# Epoch 473/500
# 1749/1749 - 11s - loss: 8.7850e-05 - val_loss: 3.7725e-05 - 11s/epoch - 6ms/step
# Epoch 474/500
# 1749/1749 - 11s - loss: 8.7818e-05 - val_loss: 3.8103e-05 - 11s/epoch - 6ms/step
# Epoch 475/500
# 1749/1749 - 11s - loss: 8.7757e-05 - val_loss: 3.8063e-05 - 11s/epoch - 6ms/step
# Epoch 476/500
# 1749/1749 - 11s - loss: 8.7737e-05 - val_loss: 3.8131e-05 - 11s/epoch - 6ms/step
# Epoch 477/500
# 1749/1749 - 10s - loss: 8.7727e-05 - val_loss: 3.8219e-05 - 10s/epoch - 6ms/step
# Epoch 478/500
# 1749/1749 - 11s - loss: 8.7726e-05 - val_loss: 3.7865e-05 - 11s/epoch - 6ms/step
# Epoch 479/500
# 1749/1749 - 11s - loss: 8.7695e-05 - val_loss: 3.7663e-05 - 11s/epoch - 6ms/step
# Epoch 480/500
# 1749/1749 - 11s - loss: 8.7659e-05 - val_loss: 3.7742e-05 - 11s/epoch - 6ms/step
# Epoch 481/500
# 1749/1749 - 11s - loss: 8.7693e-05 - val_loss: 3.7857e-05 - 11s/epoch - 6ms/step
# Epoch 482/500
# 1749/1749 - 11s - loss: 8.7662e-05 - val_loss: 3.7841e-05 - 11s/epoch - 6ms/step
# Epoch 483/500
# 1749/1749 - 11s - loss: 8.7760e-05 - val_loss: 3.7405e-05 - 11s/epoch - 6ms/step
# Epoch 484/500
# 1749/1749 - 11s - loss: 8.7760e-05 - val_loss: 3.7884e-05 - 11s/epoch - 6ms/step
# Epoch 485/500
# 1749/1749 - 12s - loss: 8.7634e-05 - val_loss: 3.7986e-05 - 12s/epoch - 7ms/step
# Epoch 486/500
# 1749/1749 - 11s - loss: 8.7680e-05 - val_loss: 3.7721e-05 - 11s/epoch - 7ms/step
# Epoch 487/500
# 1749/1749 - 11s - loss: 8.7681e-05 - val_loss: 3.7751e-05 - 11s/epoch - 7ms/step
# Epoch 488/500
# 1749/1749 - 11s - loss: 8.7669e-05 - val_loss: 3.8150e-05 - 11s/epoch - 6ms/step
# Epoch 489/500
# 1749/1749 - 11s - loss: 8.7625e-05 - val_loss: 3.7975e-05 - 11s/epoch - 6ms/step
# Epoch 490/500
# 1749/1749 - 11s - loss: 8.7689e-05 - val_loss: 3.8293e-05 - 11s/epoch - 6ms/step
# Epoch 491/500
# 1749/1749 - 12s - loss: 8.7604e-05 - val_loss: 3.8232e-05 - 12s/epoch - 7ms/step
# Epoch 492/500
# 1749/1749 - 11s - loss: 8.7616e-05 - val_loss: 3.8326e-05 - 11s/epoch - 6ms/step
# Epoch 493/500
# 1749/1749 - 11s - loss: 8.7571e-05 - val_loss: 3.8019e-05 - 11s/epoch - 6ms/step
# Epoch 494/500
# 1749/1749 - 11s - loss: 8.7579e-05 - val_loss: 3.7809e-05 - 11s/epoch - 6ms/step
# Epoch 495/500
# 1749/1749 - 11s - loss: 8.7591e-05 - val_loss: 3.7634e-05 - 11s/epoch - 6ms/step
# Epoch 496/500
# 1749/1749 - 11s - loss: 8.7553e-05 - val_loss: 3.7505e-05 - 11s/epoch - 6ms/step
# Epoch 497/500
# 1749/1749 - 11s - loss: 8.7604e-05 - val_loss: 3.7951e-05 - 11s/epoch - 6ms/step
# Epoch 498/500
# 1749/1749 - 11s - loss: 8.7592e-05 - val_loss: 3.8199e-05 - 11s/epoch - 7ms/step
# Epoch 499/500
# 1749/1749 - 11s - loss: 8.7612e-05 - val_loss: 3.8224e-05 - 11s/epoch - 6ms/step
# Epoch 500/500
# 1749/1749 - 11s - loss: 8.7533e-05 - val_loss: 3.8241e-05 - 11s/epoch - 6ms/step

# %% [markdown]
# ## Metrics ($LVPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 875/875 [==============================] - 4s 3ms/step
# (27972, 3)
# (27972, 10)
# Test RMSE: 2.808
# Test MAE: 1.990

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('Kyoto DST Index', fontsize=20)
plt.legend(fontsize=20)
plt.show()
