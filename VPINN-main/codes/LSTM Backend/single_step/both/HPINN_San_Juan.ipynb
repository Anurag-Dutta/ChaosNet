# %% [markdown]
# # Time Series Prediction with Hénon–Heiles Eqaution Inspired Deep Learning ($HPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-09 20:16:56

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Henon Heiles Intermittency_

# %% [markdown]
# The `henon_heiles_intermittency.dat` is generated from the Runge Kutta Method.

# %% [markdown]
# This feeds the model with the dynamics of the Henon Heiles Equations

# %%
data = np.genfromtxt('datasets/henon_heiles_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 7 # Weekly Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 0.099
# 1        -0.000141
# 2        -0.000140
# 3        -0.000138
# 4        -0.000137
# 5        -0.000135
#             ...
# 139867    0.000000
# 139868    0.000000
# 139869    0.000000
# 139870    0.000000
# 139871    0.000000
# Name: 1, Length: 139871, dtype: float64
# 2         2.172256e-07
# 3         2.142832e-07
# 4         2.113997e-07
# 5         2.085734e-07
# 6         2.058028e-07
#               ...
# 139867    0.000000e+00
# 139868    0.000000e+00
# 139869    0.000000e+00
# 139870    0.000000e+00
# 139871    0.000000e+00
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _SAN JUAN_

# %%
data = pd.read_csv("datasets/sanjuan.csv")
training_set = data.iloc[:, 3]
print(training_set)
# Out:
# 0        4
# 1        5
# 2        4
# 3        3
# 4        6
#         ..
# 1191    56
# 1192    46
# 1193    52
# 1194    34
# 1195    25
# Name: Cases, Length: 1196, dtype: int64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0        -0.000141
# 1        -0.000140
# 2        -0.000138
# 3        -0.000137
# 4        -0.000135
#             ...
# 139866    0.000000
# 139867    0.000000
# 139868    0.000000
# 139869    0.000000
# 139870    0.000000
# Name: 1, Length: 139871, dtype: float64
# 0         2.172256e-07
# 1         2.142832e-07
# 2         2.113997e-07
# 3         2.085734e-07
# 4         2.058028e-07
#               ...
# 139865    0.000000e+00
# 139866    0.000000e+00
# 139867    0.000000e+00
# 139868    0.000000e+00
# 139869    0.000000e+00
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Henon Heiles Equation_)

# %% [markdown]
# _Parameters_: $\lambda=1\\$

# %%
L = df.iloc[:, 2] - df.iloc[:, 1]
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10         4.0        5.0        4.0        3.0        6.0        2.0
# 11         5.0        4.0        3.0        6.0        2.0        4.0
# 12         4.0        3.0        6.0        2.0        4.0        5.0
# 13         3.0        6.0        2.0        4.0        5.0       10.0
# 14         6.0        2.0        4.0        5.0       10.0        6.0
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)   var2(t)  \
# 10        4.0        5.0       10.0        6.0      8.0 -0.000127
# 11        5.0       10.0        6.0        8.0      2.0 -0.000126
# 12       10.0        6.0        8.0        2.0      6.0 -0.000124
# 13        6.0        8.0        2.0        6.0     17.0 -0.000123
# 14        8.0        2.0        6.0       17.0     23.0 -0.000122
#
#          var3(t)
# 10  1.902667e-07
# 11  1.878459e-07
# 12  1.854699e-07
# 13  1.831375e-07
# 14  1.808475e-07
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (1185, 13)
# (1185, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (948, 1, 10) (948, 3) (237, 1, 10) (237, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] - y_true[:, 1]), (y_pred[:, 2] - y_pred[:, 1]))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] - (y_pred[1:-1]-y_pred[:-2])
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] - (y_real[1:-1]-y_pred[:-2])
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($HPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square((y_pred[:, 2] - y_pred[:, 1]))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 15/15 - 4s - loss: 0.0136 - val_loss: 0.0173 - 4s/epoch - 273ms/step
# Epoch 2/500
# 15/15 - 0s - loss: 0.0087 - val_loss: 0.0111 - 69ms/epoch - 5ms/step
# Epoch 3/500
# 15/15 - 0s - loss: 0.0070 - val_loss: 0.0087 - 76ms/epoch - 5ms/step
# Epoch 4/500
# 15/15 - 0s - loss: 0.0060 - val_loss: 0.0075 - 74ms/epoch - 5ms/step
# Epoch 5/500
# 15/15 - 0s - loss: 0.0052 - val_loss: 0.0066 - 71ms/epoch - 5ms/step
# Epoch 6/500
# 15/15 - 0s - loss: 0.0047 - val_loss: 0.0059 - 79ms/epoch - 5ms/step
# Epoch 7/500
# 15/15 - 0s - loss: 0.0042 - val_loss: 0.0052 - 87ms/epoch - 6ms/step
# Epoch 8/500
# 15/15 - 0s - loss: 0.0038 - val_loss: 0.0047 - 88ms/epoch - 6ms/step
# Epoch 9/500
# 15/15 - 0s - loss: 0.0035 - val_loss: 0.0043 - 80ms/epoch - 5ms/step
# Epoch 10/500
# 15/15 - 0s - loss: 0.0033 - val_loss: 0.0040 - 86ms/epoch - 6ms/step
# Epoch 11/500
# 15/15 - 0s - loss: 0.0030 - val_loss: 0.0036 - 80ms/epoch - 5ms/step
# Epoch 12/500
# 15/15 - 0s - loss: 0.0028 - val_loss: 0.0033 - 84ms/epoch - 6ms/step
# Epoch 13/500
# 15/15 - 0s - loss: 0.0026 - val_loss: 0.0031 - 85ms/epoch - 6ms/step
# Epoch 14/500
# 15/15 - 0s - loss: 0.0024 - val_loss: 0.0028 - 81ms/epoch - 5ms/step
# Epoch 15/500
# 15/15 - 0s - loss: 0.0022 - val_loss: 0.0026 - 140ms/epoch - 9ms/step
# Epoch 16/500
# 15/15 - 0s - loss: 0.0021 - val_loss: 0.0024 - 103ms/epoch - 7ms/step
# Epoch 17/500
# 15/15 - 0s - loss: 0.0019 - val_loss: 0.0022 - 87ms/epoch - 6ms/step
# Epoch 18/500
# 15/15 - 0s - loss: 0.0018 - val_loss: 0.0021 - 88ms/epoch - 6ms/step
# Epoch 19/500
# 15/15 - 0s - loss: 0.0017 - val_loss: 0.0020 - 86ms/epoch - 6ms/step
# Epoch 20/500
# 15/15 - 0s - loss: 0.0017 - val_loss: 0.0019 - 89ms/epoch - 6ms/step
# Epoch 21/500
# 15/15 - 0s - loss: 0.0016 - val_loss: 0.0018 - 87ms/epoch - 6ms/step
# Epoch 22/500
# 15/15 - 0s - loss: 0.0016 - val_loss: 0.0017 - 85ms/epoch - 6ms/step
# Epoch 23/500
# 15/15 - 0s - loss: 0.0015 - val_loss: 0.0017 - 86ms/epoch - 6ms/step
# Epoch 24/500
# 15/15 - 0s - loss: 0.0015 - val_loss: 0.0016 - 87ms/epoch - 6ms/step
# Epoch 25/500
# 15/15 - 0s - loss: 0.0014 - val_loss: 0.0016 - 86ms/epoch - 6ms/step
# Epoch 26/500
# 15/15 - 0s - loss: 0.0014 - val_loss: 0.0015 - 92ms/epoch - 6ms/step
# Epoch 27/500
# 15/15 - 0s - loss: 0.0014 - val_loss: 0.0015 - 85ms/epoch - 6ms/step
# Epoch 28/500
# 15/15 - 0s - loss: 0.0014 - val_loss: 0.0015 - 85ms/epoch - 6ms/step
# Epoch 29/500
# 15/15 - 0s - loss: 0.0013 - val_loss: 0.0014 - 86ms/epoch - 6ms/step
# Epoch 30/500
# 15/15 - 0s - loss: 0.0013 - val_loss: 0.0014 - 80ms/epoch - 5ms/step
# Epoch 31/500
# 15/15 - 0s - loss: 0.0013 - val_loss: 0.0014 - 78ms/epoch - 5ms/step
# Epoch 32/500
# 15/15 - 0s - loss: 0.0013 - val_loss: 0.0014 - 80ms/epoch - 5ms/step
# Epoch 33/500
# 15/15 - 0s - loss: 0.0013 - val_loss: 0.0014 - 82ms/epoch - 5ms/step
# Epoch 34/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0013 - 82ms/epoch - 5ms/step
# Epoch 35/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0013 - 81ms/epoch - 5ms/step
# Epoch 36/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0013 - 81ms/epoch - 5ms/step
# Epoch 37/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0013 - 90ms/epoch - 6ms/step
# Epoch 38/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0013 - 81ms/epoch - 5ms/step
# Epoch 39/500
# 15/15 - 0s - loss: 0.0012 - val_loss: 0.0013 - 88ms/epoch - 6ms/step
# Epoch 40/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0013 - 93ms/epoch - 6ms/step
# Epoch 41/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0013 - 92ms/epoch - 6ms/step
# Epoch 42/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 92ms/epoch - 6ms/step
# Epoch 43/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 89ms/epoch - 6ms/step
# Epoch 44/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 45/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 46/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 47/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 88ms/epoch - 6ms/step
# Epoch 48/500
# 15/15 - 0s - loss: 0.0011 - val_loss: 0.0012 - 88ms/epoch - 6ms/step
# Epoch 49/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 50/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 51/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0012 - 88ms/epoch - 6ms/step
# Epoch 52/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 53/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 54/500
# 15/15 - 0s - loss: 0.0010 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 55/500
# 15/15 - 0s - loss: 9.9929e-04 - val_loss: 0.0012 - 82ms/epoch - 5ms/step
# Epoch 56/500
# 15/15 - 0s - loss: 9.9290e-04 - val_loss: 0.0012 - 81ms/epoch - 5ms/step
# Epoch 57/500
# 15/15 - 0s - loss: 9.8674e-04 - val_loss: 0.0012 - 82ms/epoch - 5ms/step
# Epoch 58/500
# 15/15 - 0s - loss: 9.8079e-04 - val_loss: 0.0012 - 80ms/epoch - 5ms/step
# Epoch 59/500
# 15/15 - 0s - loss: 9.7504e-04 - val_loss: 0.0012 - 82ms/epoch - 5ms/step
# Epoch 60/500
# 15/15 - 0s - loss: 9.6947e-04 - val_loss: 0.0012 - 81ms/epoch - 5ms/step
# Epoch 61/500
# 15/15 - 0s - loss: 9.6408e-04 - val_loss: 0.0012 - 83ms/epoch - 6ms/step
# Epoch 62/500
# 15/15 - 0s - loss: 9.5886e-04 - val_loss: 0.0012 - 81ms/epoch - 5ms/step
# Epoch 63/500
# 15/15 - 0s - loss: 9.5379e-04 - val_loss: 0.0012 - 93ms/epoch - 6ms/step
# Epoch 64/500
# 15/15 - 0s - loss: 9.4886e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 65/500
# 15/15 - 0s - loss: 9.4408e-04 - val_loss: 0.0012 - 71ms/epoch - 5ms/step
# Epoch 66/500
# 15/15 - 0s - loss: 9.3943e-04 - val_loss: 0.0012 - 77ms/epoch - 5ms/step
# Epoch 67/500
# 15/15 - 0s - loss: 9.3490e-04 - val_loss: 0.0012 - 79ms/epoch - 5ms/step
# Epoch 68/500
# 15/15 - 0s - loss: 9.3050e-04 - val_loss: 0.0012 - 77ms/epoch - 5ms/step
# Epoch 69/500
# 15/15 - 0s - loss: 9.2621e-04 - val_loss: 0.0012 - 78ms/epoch - 5ms/step
# Epoch 70/500
# 15/15 - 0s - loss: 9.2203e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 71/500
# 15/15 - 0s - loss: 9.1796e-04 - val_loss: 0.0012 - 86ms/epoch - 6ms/step
# Epoch 72/500
# 15/15 - 0s - loss: 9.1399e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 73/500
# 15/15 - 0s - loss: 9.1013e-04 - val_loss: 0.0012 - 97ms/epoch - 6ms/step
# Epoch 74/500
# 15/15 - 0s - loss: 9.0635e-04 - val_loss: 0.0012 - 93ms/epoch - 6ms/step
# Epoch 75/500
# 15/15 - 0s - loss: 9.0267e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 76/500
# 15/15 - 0s - loss: 8.9908e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 77/500
# 15/15 - 0s - loss: 8.9558e-04 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 78/500
# 15/15 - 0s - loss: 8.9216e-04 - val_loss: 0.0011 - 86ms/epoch - 6ms/step
# Epoch 79/500
# 15/15 - 0s - loss: 8.8882e-04 - val_loss: 0.0011 - 83ms/epoch - 6ms/step
# Epoch 80/500
# 15/15 - 0s - loss: 8.8556e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 81/500
# 15/15 - 0s - loss: 8.8238e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 82/500
# 15/15 - 0s - loss: 8.7927e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 83/500
# 15/15 - 0s - loss: 8.7623e-04 - val_loss: 0.0011 - 87ms/epoch - 6ms/step
# Epoch 84/500
# 15/15 - 0s - loss: 8.7326e-04 - val_loss: 0.0011 - 81ms/epoch - 5ms/step
# Epoch 85/500
# 15/15 - 0s - loss: 8.7037e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 86/500
# 15/15 - 0s - loss: 8.6754e-04 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 87/500
# 15/15 - 0s - loss: 8.6477e-04 - val_loss: 0.0011 - 90ms/epoch - 6ms/step
# Epoch 88/500
# 15/15 - 0s - loss: 8.6207e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 89/500
# 15/15 - 0s - loss: 8.5942e-04 - val_loss: 0.0011 - 84ms/epoch - 6ms/step
# Epoch 90/500
# 15/15 - 0s - loss: 8.5684e-04 - val_loss: 0.0011 - 87ms/epoch - 6ms/step
# Epoch 91/500
# 15/15 - 0s - loss: 8.5432e-04 - val_loss: 0.0011 - 92ms/epoch - 6ms/step
# Epoch 92/500
# 15/15 - 0s - loss: 8.5185e-04 - val_loss: 0.0011 - 87ms/epoch - 6ms/step
# Epoch 93/500
# 15/15 - 0s - loss: 8.4944e-04 - val_loss: 0.0011 - 157ms/epoch - 10ms/step
# Epoch 94/500
# 15/15 - 0s - loss: 8.4708e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 95/500
# 15/15 - 0s - loss: 8.4477e-04 - val_loss: 0.0011 - 90ms/epoch - 6ms/step
# Epoch 96/500
# 15/15 - 0s - loss: 8.4251e-04 - val_loss: 0.0011 - 85ms/epoch - 6ms/step
# Epoch 97/500
# 15/15 - 0s - loss: 8.4031e-04 - val_loss: 0.0011 - 89ms/epoch - 6ms/step
# Epoch 98/500
# 15/15 - 0s - loss: 8.3815e-04 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 99/500
# 15/15 - 0s - loss: 8.3604e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 100/500
# 15/15 - 0s - loss: 8.3397e-04 - val_loss: 0.0011 - 83ms/epoch - 6ms/step
# Epoch 101/500
# 15/15 - 0s - loss: 8.3195e-04 - val_loss: 0.0011 - 86ms/epoch - 6ms/step
# Epoch 102/500
# 15/15 - 0s - loss: 8.2997e-04 - val_loss: 0.0011 - 83ms/epoch - 6ms/step
# Epoch 103/500
# 15/15 - 0s - loss: 8.2804e-04 - val_loss: 0.0011 - 79ms/epoch - 5ms/step
# Epoch 104/500
# 15/15 - 0s - loss: 8.2615e-04 - val_loss: 0.0011 - 75ms/epoch - 5ms/step
# Epoch 105/500
# 15/15 - 0s - loss: 8.2429e-04 - val_loss: 0.0011 - 79ms/epoch - 5ms/step
# Epoch 106/500
# 15/15 - 0s - loss: 8.2248e-04 - val_loss: 0.0011 - 83ms/epoch - 6ms/step
# Epoch 107/500
# 15/15 - 0s - loss: 8.2071e-04 - val_loss: 0.0011 - 88ms/epoch - 6ms/step
# Epoch 108/500
# 15/15 - 0s - loss: 8.1897e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 109/500
# 15/15 - 0s - loss: 8.1727e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 110/500
# 15/15 - 0s - loss: 8.1560e-04 - val_loss: 0.0011 - 83ms/epoch - 6ms/step
# Epoch 111/500
# 15/15 - 0s - loss: 8.1397e-04 - val_loss: 0.0011 - 83ms/epoch - 6ms/step
# Epoch 112/500
# 15/15 - 0s - loss: 8.1238e-04 - val_loss: 0.0011 - 87ms/epoch - 6ms/step
# Epoch 113/500
# 15/15 - 0s - loss: 8.1081e-04 - val_loss: 0.0011 - 85ms/epoch - 6ms/step
# Epoch 114/500
# 15/15 - 0s - loss: 8.0928e-04 - val_loss: 0.0011 - 87ms/epoch - 6ms/step
# Epoch 115/500
# 15/15 - 0s - loss: 8.0778e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 116/500
# 15/15 - 0s - loss: 8.0631e-04 - val_loss: 0.0011 - 87ms/epoch - 6ms/step
# Epoch 117/500
# 15/15 - 0s - loss: 8.0487e-04 - val_loss: 0.0011 - 78ms/epoch - 5ms/step
# Epoch 118/500
# 15/15 - 0s - loss: 8.0346e-04 - val_loss: 0.0011 - 83ms/epoch - 6ms/step
# Epoch 119/500
# 15/15 - 0s - loss: 8.0208e-04 - val_loss: 0.0011 - 80ms/epoch - 5ms/step
# Epoch 120/500
# 15/15 - 0s - loss: 8.0073e-04 - val_loss: 0.0011 - 77ms/epoch - 5ms/step
# Epoch 121/500
# 15/15 - 0s - loss: 7.9940e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 122/500
# 15/15 - 0s - loss: 7.9810e-04 - val_loss: 0.0011 - 81ms/epoch - 5ms/step
# Epoch 123/500
# 15/15 - 0s - loss: 7.9683e-04 - val_loss: 0.0011 - 80ms/epoch - 5ms/step
# Epoch 124/500
# 15/15 - 0s - loss: 7.9558e-04 - val_loss: 0.0011 - 81ms/epoch - 5ms/step
# Epoch 125/500
# 15/15 - 0s - loss: 7.9435e-04 - val_loss: 0.0011 - 84ms/epoch - 6ms/step
# Epoch 126/500
# 15/15 - 0s - loss: 7.9315e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 127/500
# 15/15 - 0s - loss: 7.9198e-04 - val_loss: 0.0011 - 86ms/epoch - 6ms/step
# Epoch 128/500
# 15/15 - 0s - loss: 7.9082e-04 - val_loss: 0.0011 - 85ms/epoch - 6ms/step
# Epoch 129/500
# 15/15 - 0s - loss: 7.8969e-04 - val_loss: 0.0011 - 80ms/epoch - 5ms/step
# Epoch 130/500
# 15/15 - 0s - loss: 7.8858e-04 - val_loss: 0.0011 - 80ms/epoch - 5ms/step
# Epoch 131/500
# 15/15 - 0s - loss: 7.8750e-04 - val_loss: 0.0011 - 78ms/epoch - 5ms/step
# Epoch 132/500
# 15/15 - 0s - loss: 7.8643e-04 - val_loss: 0.0011 - 76ms/epoch - 5ms/step
# Epoch 133/500
# 15/15 - 0s - loss: 7.8538e-04 - val_loss: 0.0011 - 77ms/epoch - 5ms/step
# Epoch 134/500
# 15/15 - 0s - loss: 7.8436e-04 - val_loss: 0.0011 - 79ms/epoch - 5ms/step
# Epoch 135/500
# 15/15 - 0s - loss: 7.8335e-04 - val_loss: 0.0011 - 76ms/epoch - 5ms/step
# Epoch 136/500
# 15/15 - 0s - loss: 7.8236e-04 - val_loss: 0.0011 - 79ms/epoch - 5ms/step
# Epoch 137/500
# 15/15 - 0s - loss: 7.8140e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 138/500
# 15/15 - 0s - loss: 7.8045e-04 - val_loss: 0.0011 - 79ms/epoch - 5ms/step
# Epoch 139/500
# 15/15 - 0s - loss: 7.7952e-04 - val_loss: 0.0011 - 88ms/epoch - 6ms/step
# Epoch 140/500
# 15/15 - 0s - loss: 7.7860e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 141/500
# 15/15 - 0s - loss: 7.7771e-04 - val_loss: 0.0011 - 89ms/epoch - 6ms/step
# Epoch 142/500
# 15/15 - 0s - loss: 7.7683e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 143/500
# 15/15 - 0s - loss: 7.7597e-04 - val_loss: 0.0011 - 88ms/epoch - 6ms/step
# Epoch 144/500
# 15/15 - 0s - loss: 7.7512e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 145/500
# 15/15 - 0s - loss: 7.7429e-04 - val_loss: 0.0011 - 110ms/epoch - 7ms/step
# Epoch 146/500
# 15/15 - 0s - loss: 7.7347e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 147/500
# 15/15 - 0s - loss: 7.7268e-04 - val_loss: 0.0011 - 90ms/epoch - 6ms/step
# Epoch 148/500
# 15/15 - 0s - loss: 7.7189e-04 - val_loss: 0.0011 - 131ms/epoch - 9ms/step
# Epoch 149/500
# 15/15 - 0s - loss: 7.7112e-04 - val_loss: 0.0011 - 112ms/epoch - 7ms/step
# Epoch 150/500
# 15/15 - 0s - loss: 7.7037e-04 - val_loss: 0.0011 - 103ms/epoch - 7ms/step
# Epoch 151/500
# 15/15 - 0s - loss: 7.6963e-04 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 152/500
# 15/15 - 0s - loss: 7.6890e-04 - val_loss: 0.0011 - 92ms/epoch - 6ms/step
# Epoch 153/500
# 15/15 - 0s - loss: 7.6819e-04 - val_loss: 0.0011 - 95ms/epoch - 6ms/step
# Epoch 154/500
# 15/15 - 0s - loss: 7.6749e-04 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 155/500
# 15/15 - 0s - loss: 7.6680e-04 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 156/500
# 15/15 - 0s - loss: 7.6612e-04 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 157/500
# 15/15 - 0s - loss: 7.6546e-04 - val_loss: 0.0011 - 103ms/epoch - 7ms/step
# Epoch 158/500
# 15/15 - 0s - loss: 7.6481e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 159/500
# 15/15 - 0s - loss: 7.6418e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 160/500
# 15/15 - 0s - loss: 7.6355e-04 - val_loss: 0.0011 - 100ms/epoch - 7ms/step
# Epoch 161/500
# 15/15 - 0s - loss: 7.6293e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 162/500
# 15/15 - 0s - loss: 7.6233e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 163/500
# 15/15 - 0s - loss: 7.6174e-04 - val_loss: 0.0011 - 95ms/epoch - 6ms/step
# Epoch 164/500
# 15/15 - 0s - loss: 7.6116e-04 - val_loss: 0.0011 - 92ms/epoch - 6ms/step
# Epoch 165/500
# 15/15 - 0s - loss: 7.6059e-04 - val_loss: 0.0011 - 105ms/epoch - 7ms/step
# Epoch 166/500
# 15/15 - 0s - loss: 7.6003e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 167/500
# 15/15 - 0s - loss: 7.5947e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 168/500
# 15/15 - 0s - loss: 7.5893e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 169/500
# 15/15 - 0s - loss: 7.5840e-04 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 170/500
# 15/15 - 0s - loss: 7.5788e-04 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 171/500
# 15/15 - 0s - loss: 7.5737e-04 - val_loss: 0.0011 - 101ms/epoch - 7ms/step
# Epoch 172/500
# 15/15 - 0s - loss: 7.5686e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 173/500
# 15/15 - 0s - loss: 7.5637e-04 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 174/500
# 15/15 - 0s - loss: 7.5588e-04 - val_loss: 0.0011 - 95ms/epoch - 6ms/step
# Epoch 175/500
# 15/15 - 0s - loss: 7.5540e-04 - val_loss: 0.0011 - 104ms/epoch - 7ms/step
# Epoch 176/500
# 15/15 - 0s - loss: 7.5493e-04 - val_loss: 0.0011 - 100ms/epoch - 7ms/step
# Epoch 177/500
# 15/15 - 0s - loss: 7.5447e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 178/500
# 15/15 - 0s - loss: 7.5401e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 179/500
# 15/15 - 0s - loss: 7.5356e-04 - val_loss: 0.0011 - 102ms/epoch - 7ms/step
# Epoch 180/500
# 15/15 - 0s - loss: 7.5312e-04 - val_loss: 0.0011 - 105ms/epoch - 7ms/step
# Epoch 181/500
# 15/15 - 0s - loss: 7.5269e-04 - val_loss: 0.0011 - 92ms/epoch - 6ms/step
# Epoch 182/500
# 15/15 - 0s - loss: 7.5226e-04 - val_loss: 0.0011 - 92ms/epoch - 6ms/step
# Epoch 183/500
# 15/15 - 0s - loss: 7.5184e-04 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 184/500
# 15/15 - 0s - loss: 7.5143e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 185/500
# 15/15 - 0s - loss: 7.5102e-04 - val_loss: 0.0011 - 101ms/epoch - 7ms/step
# Epoch 186/500
# 15/15 - 0s - loss: 7.5062e-04 - val_loss: 0.0011 - 105ms/epoch - 7ms/step
# Epoch 187/500
# 15/15 - 0s - loss: 7.5022e-04 - val_loss: 0.0011 - 100ms/epoch - 7ms/step
# Epoch 188/500
# 15/15 - 0s - loss: 7.4983e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 189/500
# 15/15 - 0s - loss: 7.4945e-04 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 190/500
# 15/15 - 0s - loss: 7.4907e-04 - val_loss: 0.0011 - 94ms/epoch - 6ms/step
# Epoch 191/500
# 15/15 - 0s - loss: 7.4869e-04 - val_loss: 0.0011 - 100ms/epoch - 7ms/step
# Epoch 192/500
# 15/15 - 0s - loss: 7.4833e-04 - val_loss: 0.0011 - 107ms/epoch - 7ms/step
# Epoch 193/500
# 15/15 - 0s - loss: 7.4796e-04 - val_loss: 0.0011 - 101ms/epoch - 7ms/step
# Epoch 194/500
# 15/15 - 0s - loss: 7.4760e-04 - val_loss: 0.0011 - 104ms/epoch - 7ms/step
# Epoch 195/500
# 15/15 - 0s - loss: 7.4725e-04 - val_loss: 0.0011 - 101ms/epoch - 7ms/step
# Epoch 196/500
# 15/15 - 0s - loss: 7.4690e-04 - val_loss: 0.0011 - 84ms/epoch - 6ms/step
# Epoch 197/500
# 15/15 - 0s - loss: 7.4655e-04 - val_loss: 0.0011 - 92ms/epoch - 6ms/step
# Epoch 198/500
# 15/15 - 0s - loss: 7.4621e-04 - val_loss: 0.0011 - 86ms/epoch - 6ms/step
# Epoch 199/500
# 15/15 - 0s - loss: 7.4587e-04 - val_loss: 0.0011 - 84ms/epoch - 6ms/step
# Epoch 200/500
# 15/15 - 0s - loss: 7.4553e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 201/500
# 15/15 - 0s - loss: 7.4520e-04 - val_loss: 0.0011 - 81ms/epoch - 5ms/step
# Epoch 202/500
# 15/15 - 0s - loss: 7.4488e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 203/500
# 15/15 - 0s - loss: 7.4455e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 204/500
# 15/15 - 0s - loss: 7.4423e-04 - val_loss: 0.0011 - 87ms/epoch - 6ms/step
# Epoch 205/500
# 15/15 - 0s - loss: 7.4391e-04 - val_loss: 0.0011 - 90ms/epoch - 6ms/step
# Epoch 206/500
# 15/15 - 0s - loss: 7.4360e-04 - val_loss: 0.0011 - 125ms/epoch - 8ms/step
# Epoch 207/500
# 15/15 - 0s - loss: 7.4329e-04 - val_loss: 0.0011 - 184ms/epoch - 12ms/step
# Epoch 208/500
# 15/15 - 0s - loss: 7.4298e-04 - val_loss: 0.0011 - 103ms/epoch - 7ms/step
# Epoch 209/500
# 15/15 - 0s - loss: 7.4267e-04 - val_loss: 0.0011 - 99ms/epoch - 7ms/step
# Epoch 210/500
# 15/15 - 0s - loss: 7.4237e-04 - val_loss: 0.0011 - 101ms/epoch - 7ms/step
# Epoch 211/500
# 15/15 - 0s - loss: 7.4207e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 212/500
# 15/15 - 0s - loss: 7.4177e-04 - val_loss: 0.0011 - 99ms/epoch - 7ms/step
# Epoch 213/500
# 15/15 - 0s - loss: 7.4147e-04 - val_loss: 0.0011 - 103ms/epoch - 7ms/step
# Epoch 214/500
# 15/15 - 0s - loss: 7.4117e-04 - val_loss: 0.0011 - 99ms/epoch - 7ms/step
# Epoch 215/500
# 15/15 - 0s - loss: 7.4088e-04 - val_loss: 0.0011 - 109ms/epoch - 7ms/step
# Epoch 216/500
# 15/15 - 0s - loss: 7.4059e-04 - val_loss: 0.0011 - 102ms/epoch - 7ms/step
# Epoch 217/500
# 15/15 - 0s - loss: 7.4030e-04 - val_loss: 0.0011 - 107ms/epoch - 7ms/step
# Epoch 218/500
# 15/15 - 0s - loss: 7.4001e-04 - val_loss: 0.0011 - 122ms/epoch - 8ms/step
# Epoch 219/500
# 15/15 - 0s - loss: 7.3972e-04 - val_loss: 0.0011 - 140ms/epoch - 9ms/step
# Epoch 220/500
# 15/15 - 0s - loss: 7.3944e-04 - val_loss: 0.0011 - 114ms/epoch - 8ms/step
# Epoch 221/500
# 15/15 - 0s - loss: 7.3916e-04 - val_loss: 0.0011 - 101ms/epoch - 7ms/step
# Epoch 222/500
# 15/15 - 0s - loss: 7.3887e-04 - val_loss: 0.0011 - 96ms/epoch - 6ms/step
# Epoch 223/500
# 15/15 - 0s - loss: 7.3859e-04 - val_loss: 0.0011 - 89ms/epoch - 6ms/step
# Epoch 224/500
# 15/15 - 0s - loss: 7.3831e-04 - val_loss: 0.0011 - 89ms/epoch - 6ms/step
# Epoch 225/500
# 15/15 - 0s - loss: 7.3803e-04 - val_loss: 0.0011 - 88ms/epoch - 6ms/step
# Epoch 226/500
# 15/15 - 0s - loss: 7.3775e-04 - val_loss: 0.0011 - 116ms/epoch - 8ms/step
# Epoch 227/500
# 15/15 - 0s - loss: 7.3748e-04 - val_loss: 0.0011 - 112ms/epoch - 7ms/step
# Epoch 228/500
# 15/15 - 0s - loss: 7.3720e-04 - val_loss: 0.0011 - 111ms/epoch - 7ms/step
# Epoch 229/500
# 15/15 - 0s - loss: 7.3693e-04 - val_loss: 0.0011 - 89ms/epoch - 6ms/step
# Epoch 230/500
# 15/15 - 0s - loss: 7.3665e-04 - val_loss: 0.0011 - 101ms/epoch - 7ms/step
# Epoch 231/500
# 15/15 - 0s - loss: 7.3638e-04 - val_loss: 0.0011 - 97ms/epoch - 6ms/step
# Epoch 232/500
# 15/15 - 0s - loss: 7.3610e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 233/500
# 15/15 - 0s - loss: 7.3583e-04 - val_loss: 0.0011 - 92ms/epoch - 6ms/step
# Epoch 234/500
# 15/15 - 0s - loss: 7.3555e-04 - val_loss: 0.0011 - 130ms/epoch - 9ms/step
# Epoch 235/500
# 15/15 - 0s - loss: 7.3529e-04 - val_loss: 0.0011 - 127ms/epoch - 8ms/step
# Epoch 236/500
# 15/15 - 0s - loss: 7.3500e-04 - val_loss: 0.0011 - 107ms/epoch - 7ms/step
# Epoch 237/500
# 15/15 - 0s - loss: 7.3476e-04 - val_loss: 0.0011 - 100ms/epoch - 7ms/step
# Epoch 238/500
# 15/15 - 0s - loss: 7.3445e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 239/500
# 15/15 - 0s - loss: 7.3423e-04 - val_loss: 0.0011 - 86ms/epoch - 6ms/step
# Epoch 240/500
# 15/15 - 0s - loss: 7.3390e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 241/500
# 15/15 - 0s - loss: 7.3374e-04 - val_loss: 0.0011 - 88ms/epoch - 6ms/step
# Epoch 242/500
# 15/15 - 0s - loss: 7.3335e-04 - val_loss: 0.0011 - 92ms/epoch - 6ms/step
# Epoch 243/500
# 15/15 - 0s - loss: 7.3332e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 244/500
# 15/15 - 0s - loss: 7.3286e-04 - val_loss: 0.0012 - 83ms/epoch - 6ms/step
# Epoch 245/500
# 15/15 - 0s - loss: 7.3311e-04 - val_loss: 0.0011 - 86ms/epoch - 6ms/step
# Epoch 246/500
# 15/15 - 0s - loss: 7.3261e-04 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 247/500
# 15/15 - 0s - loss: 7.3333e-04 - val_loss: 0.0012 - 82ms/epoch - 5ms/step
# Epoch 248/500
# 15/15 - 0s - loss: 7.3287e-04 - val_loss: 0.0012 - 88ms/epoch - 6ms/step
# Epoch 249/500
# 15/15 - 0s - loss: 7.3373e-04 - val_loss: 0.0012 - 90ms/epoch - 6ms/step
# Epoch 250/500
# 15/15 - 0s - loss: 7.3221e-04 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 251/500
# 15/15 - 0s - loss: 7.3190e-04 - val_loss: 0.0012 - 88ms/epoch - 6ms/step
# Epoch 252/500
# 15/15 - 0s - loss: 7.3055e-04 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 253/500
# 15/15 - 0s - loss: 7.3109e-04 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 254/500
# 15/15 - 0s - loss: 7.3007e-04 - val_loss: 0.0012 - 88ms/epoch - 6ms/step
# Epoch 255/500
# 15/15 - 0s - loss: 7.3032e-04 - val_loss: 0.0012 - 137ms/epoch - 9ms/step
# Epoch 256/500
# 15/15 - 0s - loss: 7.2925e-04 - val_loss: 0.0012 - 109ms/epoch - 7ms/step
# Epoch 257/500
# 15/15 - 0s - loss: 7.3009e-04 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 258/500
# 15/15 - 0s - loss: 7.2846e-04 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 259/500
# 15/15 - 0s - loss: 7.2940e-04 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 260/500
# 15/15 - 0s - loss: 7.2792e-04 - val_loss: 0.0012 - 81ms/epoch - 5ms/step
# Epoch 261/500
# 15/15 - 0s - loss: 7.2901e-04 - val_loss: 0.0012 - 80ms/epoch - 5ms/step
# Epoch 262/500
# 15/15 - 0s - loss: 7.2701e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 263/500
# 15/15 - 0s - loss: 7.2878e-04 - val_loss: 0.0012 - 81ms/epoch - 5ms/step
# Epoch 264/500
# 15/15 - 0s - loss: 7.2624e-04 - val_loss: 0.0012 - 75ms/epoch - 5ms/step
# Epoch 265/500
# 15/15 - 0s - loss: 7.2844e-04 - val_loss: 0.0012 - 75ms/epoch - 5ms/step
# Epoch 266/500
# 15/15 - 0s - loss: 7.2542e-04 - val_loss: 0.0012 - 86ms/epoch - 6ms/step
# Epoch 267/500
# 15/15 - 0s - loss: 7.2832e-04 - val_loss: 0.0012 - 80ms/epoch - 5ms/step
# Epoch 268/500
# 15/15 - 0s - loss: 7.2443e-04 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 269/500
# 15/15 - 0s - loss: 7.2841e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 270/500
# 15/15 - 0s - loss: 7.2339e-04 - val_loss: 0.0012 - 86ms/epoch - 6ms/step
# Epoch 271/500
# 15/15 - 0s - loss: 7.2867e-04 - val_loss: 0.0011 - 90ms/epoch - 6ms/step
# Epoch 272/500
# 15/15 - 0s - loss: 7.2224e-04 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 273/500
# 15/15 - 0s - loss: 7.2929e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 274/500
# 15/15 - 0s - loss: 7.2096e-04 - val_loss: 0.0012 - 86ms/epoch - 6ms/step
# Epoch 275/500
# 15/15 - 0s - loss: 7.3043e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 276/500
# 15/15 - 0s - loss: 7.1963e-04 - val_loss: 0.0012 - 92ms/epoch - 6ms/step
# Epoch 277/500
# 15/15 - 0s - loss: 7.3222e-04 - val_loss: 0.0011 - 88ms/epoch - 6ms/step
# Epoch 278/500
# 15/15 - 0s - loss: 7.1836e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 279/500
# 15/15 - 0s - loss: 7.3486e-04 - val_loss: 0.0011 - 99ms/epoch - 7ms/step
# Epoch 280/500
# 15/15 - 0s - loss: 7.1731e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 281/500
# 15/15 - 0s - loss: 7.3848e-04 - val_loss: 0.0011 - 90ms/epoch - 6ms/step
# Epoch 282/500
# 15/15 - 0s - loss: 7.1677e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 283/500
# 15/15 - 0s - loss: 7.4283e-04 - val_loss: 0.0011 - 81ms/epoch - 5ms/step
# Epoch 284/500
# 15/15 - 0s - loss: 7.1686e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 285/500
# 15/15 - 0s - loss: 7.4717e-04 - val_loss: 0.0011 - 86ms/epoch - 6ms/step
# Epoch 286/500
# 15/15 - 0s - loss: 7.1740e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 287/500
# 15/15 - 0s - loss: 7.5020e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 288/500
# 15/15 - 0s - loss: 7.1786e-04 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 289/500
# 15/15 - 0s - loss: 7.5053e-04 - val_loss: 0.0011 - 88ms/epoch - 6ms/step
# Epoch 290/500
# 15/15 - 0s - loss: 7.1758e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 291/500
# 15/15 - 0s - loss: 7.4776e-04 - val_loss: 0.0011 - 89ms/epoch - 6ms/step
# Epoch 292/500
# 15/15 - 0s - loss: 7.1642e-04 - val_loss: 0.0012 - 83ms/epoch - 6ms/step
# Epoch 293/500
# 15/15 - 0s - loss: 7.4279e-04 - val_loss: 0.0011 - 82ms/epoch - 5ms/step
# Epoch 294/500
# 15/15 - 0s - loss: 7.1481e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 295/500
# 15/15 - 0s - loss: 7.3718e-04 - val_loss: 0.0011 - 86ms/epoch - 6ms/step
# Epoch 296/500
# 15/15 - 0s - loss: 7.1330e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 297/500
# 15/15 - 0s - loss: 7.3209e-04 - val_loss: 0.0011 - 90ms/epoch - 6ms/step
# Epoch 298/500
# 15/15 - 0s - loss: 7.1217e-04 - val_loss: 0.0012 - 89ms/epoch - 6ms/step
# Epoch 299/500
# 15/15 - 0s - loss: 7.2798e-04 - val_loss: 0.0011 - 85ms/epoch - 6ms/step
# Epoch 300/500
# 15/15 - 0s - loss: 7.1141e-04 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 301/500
# 15/15 - 0s - loss: 7.2484e-04 - val_loss: 0.0011 - 91ms/epoch - 6ms/step
# Epoch 302/500
# 15/15 - 0s - loss: 7.1090e-04 - val_loss: 0.0012 - 88ms/epoch - 6ms/step
# Epoch 303/500
# 15/15 - 0s - loss: 7.2248e-04 - val_loss: 0.0011 - 89ms/epoch - 6ms/step
# Epoch 304/500
# 15/15 - 0s - loss: 7.1052e-04 - val_loss: 0.0012 - 88ms/epoch - 6ms/step
# Epoch 305/500
# 15/15 - 0s - loss: 7.2068e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 306/500
# 15/15 - 0s - loss: 7.1019e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 307/500
# 15/15 - 0s - loss: 7.1929e-04 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 308/500
# 15/15 - 0s - loss: 7.0986e-04 - val_loss: 0.0012 - 88ms/epoch - 6ms/step
# Epoch 309/500
# 15/15 - 0s - loss: 7.1819e-04 - val_loss: 0.0012 - 157ms/epoch - 10ms/step
# Epoch 310/500
# 15/15 - 0s - loss: 7.0951e-04 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 311/500
# 15/15 - 0s - loss: 7.1730e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 312/500
# 15/15 - 0s - loss: 7.0911e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 313/500
# 15/15 - 0s - loss: 7.1657e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 314/500
# 15/15 - 0s - loss: 7.0868e-04 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 315/500
# 15/15 - 0s - loss: 7.1598e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 316/500
# 15/15 - 0s - loss: 7.0820e-04 - val_loss: 0.0012 - 98ms/epoch - 7ms/step
# Epoch 317/500
# 15/15 - 0s - loss: 7.1551e-04 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 318/500
# 15/15 - 0s - loss: 7.0767e-04 - val_loss: 0.0012 - 97ms/epoch - 6ms/step
# Epoch 319/500
# 15/15 - 0s - loss: 7.1514e-04 - val_loss: 0.0012 - 90ms/epoch - 6ms/step
# Epoch 320/500
# 15/15 - 0s - loss: 7.0709e-04 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 321/500
# 15/15 - 0s - loss: 7.1489e-04 - val_loss: 0.0012 - 103ms/epoch - 7ms/step
# Epoch 322/500
# 15/15 - 0s - loss: 7.0646e-04 - val_loss: 0.0012 - 90ms/epoch - 6ms/step
# Epoch 323/500
# 15/15 - 0s - loss: 7.1476e-04 - val_loss: 0.0012 - 103ms/epoch - 7ms/step
# Epoch 324/500
# 15/15 - 0s - loss: 7.0578e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 325/500
# 15/15 - 0s - loss: 7.1477e-04 - val_loss: 0.0012 - 82ms/epoch - 5ms/step
# Epoch 326/500
# 15/15 - 0s - loss: 7.0505e-04 - val_loss: 0.0012 - 83ms/epoch - 6ms/step
# Epoch 327/500
# 15/15 - 0s - loss: 7.1495e-04 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 328/500
# 15/15 - 0s - loss: 7.0427e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 329/500
# 15/15 - 0s - loss: 7.1534e-04 - val_loss: 0.0012 - 86ms/epoch - 6ms/step
# Epoch 330/500
# 15/15 - 0s - loss: 7.0347e-04 - val_loss: 0.0012 - 85ms/epoch - 6ms/step
# Epoch 331/500
# 15/15 - 0s - loss: 7.1598e-04 - val_loss: 0.0012 - 80ms/epoch - 5ms/step
# Epoch 332/500
# 15/15 - 0s - loss: 7.0266e-04 - val_loss: 0.0012 - 83ms/epoch - 6ms/step
# Epoch 333/500
# 15/15 - 0s - loss: 7.1696e-04 - val_loss: 0.0012 - 88ms/epoch - 6ms/step
# Epoch 334/500
# 15/15 - 0s - loss: 7.0190e-04 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 335/500
# 15/15 - 0s - loss: 7.1833e-04 - val_loss: 0.0012 - 92ms/epoch - 6ms/step
# Epoch 336/500
# 15/15 - 0s - loss: 7.0128e-04 - val_loss: 0.0012 - 92ms/epoch - 6ms/step
# Epoch 337/500
# 15/15 - 0s - loss: 7.2015e-04 - val_loss: 0.0012 - 95ms/epoch - 6ms/step
# Epoch 338/500
# 15/15 - 0s - loss: 7.0084e-04 - val_loss: 0.0012 - 90ms/epoch - 6ms/step
# Epoch 339/500
# 15/15 - 0s - loss: 7.2235e-04 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 340/500
# 15/15 - 0s - loss: 7.0040e-04 - val_loss: 0.0012 - 86ms/epoch - 6ms/step
# Epoch 341/500
# 15/15 - 0s - loss: 7.2452e-04 - val_loss: 0.0012 - 101ms/epoch - 7ms/step
# Epoch 342/500
# 15/15 - 0s - loss: 6.9972e-04 - val_loss: 0.0012 - 93ms/epoch - 6ms/step
# Epoch 343/500
# 15/15 - 0s - loss: 7.2661e-04 - val_loss: 0.0011 - 99ms/epoch - 7ms/step
# Epoch 344/500
# 15/15 - 0s - loss: 6.9934e-04 - val_loss: 0.0012 - 100ms/epoch - 7ms/step
# Epoch 345/500
# 15/15 - 0s - loss: 7.2872e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 346/500
# 15/15 - 0s - loss: 6.9931e-04 - val_loss: 0.0013 - 95ms/epoch - 6ms/step
# Epoch 347/500
# 15/15 - 0s - loss: 7.3006e-04 - val_loss: 0.0011 - 102ms/epoch - 7ms/step
# Epoch 348/500
# 15/15 - 0s - loss: 6.9921e-04 - val_loss: 0.0013 - 94ms/epoch - 6ms/step
# Epoch 349/500
# 15/15 - 0s - loss: 7.3008e-04 - val_loss: 0.0011 - 90ms/epoch - 6ms/step
# Epoch 350/500
# 15/15 - 0s - loss: 6.9882e-04 - val_loss: 0.0013 - 95ms/epoch - 6ms/step
# Epoch 351/500
# 15/15 - 0s - loss: 7.2860e-04 - val_loss: 0.0011 - 93ms/epoch - 6ms/step
# Epoch 352/500
# 15/15 - 0s - loss: 6.9807e-04 - val_loss: 0.0013 - 96ms/epoch - 6ms/step
# Epoch 353/500
# 15/15 - 0s - loss: 7.2586e-04 - val_loss: 0.0011 - 98ms/epoch - 7ms/step
# Epoch 354/500
# 15/15 - 0s - loss: 6.9706e-04 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 355/500
# 15/15 - 0s - loss: 7.2241e-04 - val_loss: 0.0012 - 104ms/epoch - 7ms/step
# Epoch 356/500
# 15/15 - 0s - loss: 6.9597e-04 - val_loss: 0.0012 - 106ms/epoch - 7ms/step
# Epoch 357/500
# 15/15 - 0s - loss: 7.1881e-04 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 358/500
# 15/15 - 0s - loss: 6.9497e-04 - val_loss: 0.0012 - 162ms/epoch - 11ms/step
# Epoch 359/500
# 15/15 - 0s - loss: 7.1548e-04 - val_loss: 0.0012 - 103ms/epoch - 7ms/step
# Epoch 360/500
# 15/15 - 0s - loss: 6.9411e-04 - val_loss: 0.0012 - 97ms/epoch - 6ms/step
# Epoch 361/500
# 15/15 - 0s - loss: 7.1262e-04 - val_loss: 0.0012 - 93ms/epoch - 6ms/step
# Epoch 362/500
# 15/15 - 0s - loss: 6.9343e-04 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 363/500
# 15/15 - 0s - loss: 7.1027e-04 - val_loss: 0.0012 - 98ms/epoch - 7ms/step
# Epoch 364/500
# 15/15 - 0s - loss: 6.9284e-04 - val_loss: 0.0012 - 98ms/epoch - 7ms/step
# Epoch 365/500
# 15/15 - 0s - loss: 7.0838e-04 - val_loss: 0.0012 - 103ms/epoch - 7ms/step
# Epoch 366/500
# 15/15 - 0s - loss: 6.9233e-04 - val_loss: 0.0012 - 106ms/epoch - 7ms/step
# Epoch 367/500
# 15/15 - 0s - loss: 7.0689e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 368/500
# 15/15 - 0s - loss: 6.9188e-04 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 369/500
# 15/15 - 0s - loss: 7.0574e-04 - val_loss: 0.0012 - 90ms/epoch - 6ms/step
# Epoch 370/500
# 15/15 - 0s - loss: 6.9138e-04 - val_loss: 0.0012 - 86ms/epoch - 6ms/step
# Epoch 371/500
# 15/15 - 0s - loss: 7.0487e-04 - val_loss: 0.0012 - 93ms/epoch - 6ms/step
# Epoch 372/500
# 15/15 - 0s - loss: 6.9092e-04 - val_loss: 0.0012 - 97ms/epoch - 6ms/step
# Epoch 373/500
# 15/15 - 0s - loss: 7.0425e-04 - val_loss: 0.0012 - 92ms/epoch - 6ms/step
# Epoch 374/500
# 15/15 - 0s - loss: 6.9041e-04 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 375/500
# 15/15 - 0s - loss: 7.0386e-04 - val_loss: 0.0012 - 92ms/epoch - 6ms/step
# Epoch 376/500
# 15/15 - 0s - loss: 6.8985e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 377/500
# 15/15 - 0s - loss: 7.0368e-04 - val_loss: 0.0012 - 92ms/epoch - 6ms/step
# Epoch 378/500
# 15/15 - 0s - loss: 6.8934e-04 - val_loss: 0.0012 - 90ms/epoch - 6ms/step
# Epoch 379/500
# 15/15 - 0s - loss: 7.0373e-04 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 380/500
# 15/15 - 0s - loss: 6.8871e-04 - val_loss: 0.0012 - 98ms/epoch - 7ms/step
# Epoch 381/500
# 15/15 - 0s - loss: 7.0409e-04 - val_loss: 0.0012 - 103ms/epoch - 7ms/step
# Epoch 382/500
# 15/15 - 0s - loss: 6.8810e-04 - val_loss: 0.0012 - 98ms/epoch - 7ms/step
# Epoch 383/500
# 15/15 - 0s - loss: 7.0460e-04 - val_loss: 0.0012 - 100ms/epoch - 7ms/step
# Epoch 384/500
# 15/15 - 0s - loss: 6.8765e-04 - val_loss: 0.0013 - 105ms/epoch - 7ms/step
# Epoch 385/500
# 15/15 - 0s - loss: 7.0550e-04 - val_loss: 0.0012 - 100ms/epoch - 7ms/step
# Epoch 386/500
# 15/15 - 0s - loss: 6.8695e-04 - val_loss: 0.0013 - 103ms/epoch - 7ms/step
# Epoch 387/500
# 15/15 - 0s - loss: 7.0675e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 388/500
# 15/15 - 0s - loss: 6.8653e-04 - val_loss: 0.0013 - 92ms/epoch - 6ms/step
# Epoch 389/500
# 15/15 - 0s - loss: 7.0795e-04 - val_loss: 0.0012 - 92ms/epoch - 6ms/step
# Epoch 390/500
# 15/15 - 0s - loss: 6.8596e-04 - val_loss: 0.0013 - 82ms/epoch - 5ms/step
# Epoch 391/500
# 15/15 - 0s - loss: 7.0962e-04 - val_loss: 0.0012 - 83ms/epoch - 6ms/step
# Epoch 392/500
# 15/15 - 0s - loss: 6.8545e-04 - val_loss: 0.0013 - 79ms/epoch - 5ms/step
# Epoch 393/500
# 15/15 - 0s - loss: 7.1096e-04 - val_loss: 0.0012 - 84ms/epoch - 6ms/step
# Epoch 394/500
# 15/15 - 0s - loss: 6.8525e-04 - val_loss: 0.0013 - 86ms/epoch - 6ms/step
# Epoch 395/500
# 15/15 - 0s - loss: 7.1262e-04 - val_loss: 0.0012 - 83ms/epoch - 6ms/step
# Epoch 396/500
# 15/15 - 0s - loss: 6.8498e-04 - val_loss: 0.0013 - 83ms/epoch - 6ms/step
# Epoch 397/500
# 15/15 - 0s - loss: 7.1370e-04 - val_loss: 0.0012 - 86ms/epoch - 6ms/step
# Epoch 398/500
# 15/15 - 0s - loss: 6.8511e-04 - val_loss: 0.0013 - 103ms/epoch - 7ms/step
# Epoch 399/500
# 15/15 - 0s - loss: 7.1444e-04 - val_loss: 0.0012 - 96ms/epoch - 6ms/step
# Epoch 400/500
# 15/15 - 0s - loss: 6.8504e-04 - val_loss: 0.0013 - 98ms/epoch - 7ms/step
# Epoch 401/500
# 15/15 - 0s - loss: 7.1430e-04 - val_loss: 0.0012 - 98ms/epoch - 7ms/step
# Epoch 402/500
# 15/15 - 0s - loss: 6.8481e-04 - val_loss: 0.0013 - 102ms/epoch - 7ms/step
# Epoch 403/500
# 15/15 - 0s - loss: 7.1361e-04 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 404/500
# 15/15 - 0s - loss: 6.8396e-04 - val_loss: 0.0013 - 104ms/epoch - 7ms/step
# Epoch 405/500
# 15/15 - 0s - loss: 7.1218e-04 - val_loss: 0.0012 - 104ms/epoch - 7ms/step
# Epoch 406/500
# 15/15 - 0s - loss: 6.8308e-04 - val_loss: 0.0013 - 106ms/epoch - 7ms/step
# Epoch 407/500
# 15/15 - 0s - loss: 7.0905e-04 - val_loss: 0.0012 - 100ms/epoch - 7ms/step
# Epoch 408/500
# 15/15 - 0s - loss: 6.8252e-04 - val_loss: 0.0013 - 150ms/epoch - 10ms/step
# Epoch 409/500
# 15/15 - 0s - loss: 7.0681e-04 - val_loss: 0.0012 - 104ms/epoch - 7ms/step
# Epoch 410/500
# 15/15 - 0s - loss: 6.8111e-04 - val_loss: 0.0013 - 97ms/epoch - 6ms/step
# Epoch 411/500
# 15/15 - 0s - loss: 7.0380e-04 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 412/500
# 15/15 - 0s - loss: 6.8067e-04 - val_loss: 0.0013 - 92ms/epoch - 6ms/step
# Epoch 413/500
# 15/15 - 0s - loss: 7.0125e-04 - val_loss: 0.0012 - 97ms/epoch - 6ms/step
# Epoch 414/500
# 15/15 - 0s - loss: 6.7948e-04 - val_loss: 0.0013 - 93ms/epoch - 6ms/step
# Epoch 415/500
# 15/15 - 0s - loss: 6.9927e-04 - val_loss: 0.0012 - 91ms/epoch - 6ms/step
# Epoch 416/500
# 15/15 - 0s - loss: 6.7896e-04 - val_loss: 0.0013 - 93ms/epoch - 6ms/step
# Epoch 417/500
# 15/15 - 0s - loss: 6.9750e-04 - val_loss: 0.0012 - 90ms/epoch - 6ms/step
# Epoch 418/500
# 15/15 - 0s - loss: 6.7835e-04 - val_loss: 0.0013 - 94ms/epoch - 6ms/step
# Epoch 419/500
# 15/15 - 0s - loss: 6.9612e-04 - val_loss: 0.0012 - 98ms/epoch - 7ms/step
# Epoch 420/500
# 15/15 - 0s - loss: 6.7784e-04 - val_loss: 0.0013 - 97ms/epoch - 6ms/step
# Epoch 421/500
# 15/15 - 0s - loss: 6.9507e-04 - val_loss: 0.0012 - 94ms/epoch - 6ms/step
# Epoch 422/500
# 15/15 - 0s - loss: 6.7729e-04 - val_loss: 0.0013 - 98ms/epoch - 7ms/step
# Epoch 423/500
# 15/15 - 0s - loss: 6.9437e-04 - val_loss: 0.0012 - 93ms/epoch - 6ms/step
# Epoch 424/500
# 15/15 - 0s - loss: 6.7680e-04 - val_loss: 0.0013 - 98ms/epoch - 7ms/step
# Epoch 425/500
# 15/15 - 0s - loss: 6.9384e-04 - val_loss: 0.0012 - 93ms/epoch - 6ms/step
# Epoch 426/500
# 15/15 - 0s - loss: 6.7631e-04 - val_loss: 0.0013 - 94ms/epoch - 6ms/step
# Epoch 427/500
# 15/15 - 0s - loss: 6.9359e-04 - val_loss: 0.0012 - 93ms/epoch - 6ms/step
# Epoch 428/500
# 15/15 - 0s - loss: 6.7576e-04 - val_loss: 0.0013 - 97ms/epoch - 6ms/step
# Epoch 429/500
# 15/15 - 0s - loss: 6.9361e-04 - val_loss: 0.0012 - 87ms/epoch - 6ms/step
# Epoch 430/500
# 15/15 - 0s - loss: 6.7524e-04 - val_loss: 0.0013 - 88ms/epoch - 6ms/step
# Epoch 431/500
# 15/15 - 0s - loss: 6.9383e-04 - val_loss: 0.0012 - 89ms/epoch - 6ms/step
# Epoch 432/500
# 15/15 - 0s - loss: 6.7472e-04 - val_loss: 0.0013 - 86ms/epoch - 6ms/step
# Epoch 433/500
# 15/15 - 0s - loss: 6.9429e-04 - val_loss: 0.0012 - 89ms/epoch - 6ms/step
# Epoch 434/500
# 15/15 - 0s - loss: 6.7419e-04 - val_loss: 0.0013 - 100ms/epoch - 7ms/step
# Epoch 435/500
# 15/15 - 0s - loss: 6.9501e-04 - val_loss: 0.0012 - 144ms/epoch - 10ms/step
# Epoch 436/500
# 15/15 - 0s - loss: 6.7370e-04 - val_loss: 0.0013 - 106ms/epoch - 7ms/step
# Epoch 437/500
# 15/15 - 0s - loss: 6.9594e-04 - val_loss: 0.0012 - 104ms/epoch - 7ms/step
# Epoch 438/500
# 15/15 - 0s - loss: 6.7327e-04 - val_loss: 0.0013 - 112ms/epoch - 7ms/step
# Epoch 439/500
# 15/15 - 0s - loss: 6.9704e-04 - val_loss: 0.0012 - 111ms/epoch - 7ms/step
# Epoch 440/500
# 15/15 - 0s - loss: 6.7289e-04 - val_loss: 0.0013 - 133ms/epoch - 9ms/step
# Epoch 441/500
# 15/15 - 0s - loss: 6.9825e-04 - val_loss: 0.0012 - 151ms/epoch - 10ms/step
# Epoch 442/500
# 15/15 - 0s - loss: 6.7259e-04 - val_loss: 0.0013 - 114ms/epoch - 8ms/step
# Epoch 443/500
# 15/15 - 0s - loss: 6.9946e-04 - val_loss: 0.0012 - 129ms/epoch - 9ms/step
# Epoch 444/500
# 15/15 - 0s - loss: 6.7235e-04 - val_loss: 0.0014 - 230ms/epoch - 15ms/step
# Epoch 445/500
# 15/15 - 0s - loss: 7.0049e-04 - val_loss: 0.0012 - 121ms/epoch - 8ms/step
# Epoch 446/500
# 15/15 - 0s - loss: 6.7210e-04 - val_loss: 0.0014 - 103ms/epoch - 7ms/step
# Epoch 447/500
# 15/15 - 0s - loss: 7.0117e-04 - val_loss: 0.0012 - 104ms/epoch - 7ms/step
# Epoch 448/500
# 15/15 - 0s - loss: 6.7184e-04 - val_loss: 0.0014 - 96ms/epoch - 6ms/step
# Epoch 449/500
# 15/15 - 0s - loss: 7.0128e-04 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 450/500
# 15/15 - 0s - loss: 6.7153e-04 - val_loss: 0.0014 - 98ms/epoch - 7ms/step
# Epoch 451/500
# 15/15 - 0s - loss: 7.0076e-04 - val_loss: 0.0012 - 105ms/epoch - 7ms/step
# Epoch 452/500
# 15/15 - 0s - loss: 6.7102e-04 - val_loss: 0.0014 - 130ms/epoch - 9ms/step
# Epoch 453/500
# 15/15 - 0s - loss: 6.9966e-04 - val_loss: 0.0012 - 109ms/epoch - 7ms/step
# Epoch 454/500
# 15/15 - 0s - loss: 6.7041e-04 - val_loss: 0.0014 - 104ms/epoch - 7ms/step
# Epoch 455/500
# 15/15 - 0s - loss: 6.9800e-04 - val_loss: 0.0012 - 110ms/epoch - 7ms/step
# Epoch 456/500
# 15/15 - 0s - loss: 6.6973e-04 - val_loss: 0.0014 - 101ms/epoch - 7ms/step
# Epoch 457/500
# 15/15 - 0s - loss: 6.9598e-04 - val_loss: 0.0012 - 109ms/epoch - 7ms/step
# Epoch 458/500
# 15/15 - 0s - loss: 6.6899e-04 - val_loss: 0.0014 - 106ms/epoch - 7ms/step
# Epoch 459/500
# 15/15 - 0s - loss: 6.9386e-04 - val_loss: 0.0012 - 100ms/epoch - 7ms/step
# Epoch 460/500
# 15/15 - 0s - loss: 6.6830e-04 - val_loss: 0.0014 - 112ms/epoch - 7ms/step
# Epoch 461/500
# 15/15 - 0s - loss: 6.9176e-04 - val_loss: 0.0012 - 122ms/epoch - 8ms/step
# Epoch 462/500
# 15/15 - 0s - loss: 6.6759e-04 - val_loss: 0.0013 - 119ms/epoch - 8ms/step
# Epoch 463/500
# 15/15 - 0s - loss: 6.8987e-04 - val_loss: 0.0012 - 139ms/epoch - 9ms/step
# Epoch 464/500
# 15/15 - 0s - loss: 6.6698e-04 - val_loss: 0.0013 - 137ms/epoch - 9ms/step
# Epoch 465/500
# 15/15 - 0s - loss: 6.8822e-04 - val_loss: 0.0012 - 117ms/epoch - 8ms/step
# Epoch 466/500
# 15/15 - 0s - loss: 6.6638e-04 - val_loss: 0.0013 - 101ms/epoch - 7ms/step
# Epoch 467/500
# 15/15 - 0s - loss: 6.8684e-04 - val_loss: 0.0012 - 98ms/epoch - 7ms/step
# Epoch 468/500
# 15/15 - 0s - loss: 6.6583e-04 - val_loss: 0.0013 - 101ms/epoch - 7ms/step
# Epoch 469/500
# 15/15 - 0s - loss: 6.8575e-04 - val_loss: 0.0012 - 99ms/epoch - 7ms/step
# Epoch 470/500
# 15/15 - 0s - loss: 6.6532e-04 - val_loss: 0.0013 - 99ms/epoch - 7ms/step
# Epoch 471/500
# 15/15 - 0s - loss: 6.8489e-04 - val_loss: 0.0012 - 92ms/epoch - 6ms/step
# Epoch 472/500
# 15/15 - 0s - loss: 6.6480e-04 - val_loss: 0.0013 - 99ms/epoch - 7ms/step
# Epoch 473/500
# 15/15 - 0s - loss: 6.8432e-04 - val_loss: 0.0012 - 189ms/epoch - 13ms/step
# Epoch 474/500
# 15/15 - 0s - loss: 6.6434e-04 - val_loss: 0.0014 - 113ms/epoch - 8ms/step
# Epoch 475/500
# 15/15 - 0s - loss: 6.8392e-04 - val_loss: 0.0012 - 100ms/epoch - 7ms/step
# Epoch 476/500
# 15/15 - 0s - loss: 6.6384e-04 - val_loss: 0.0014 - 103ms/epoch - 7ms/step
# Epoch 477/500
# 15/15 - 0s - loss: 6.8378e-04 - val_loss: 0.0012 - 151ms/epoch - 10ms/step
# Epoch 478/500
# 15/15 - 0s - loss: 6.6346e-04 - val_loss: 0.0014 - 139ms/epoch - 9ms/step
# Epoch 479/500
# 15/15 - 0s - loss: 6.8377e-04 - val_loss: 0.0012 - 141ms/epoch - 9ms/step
# Epoch 480/500
# 15/15 - 0s - loss: 6.6301e-04 - val_loss: 0.0014 - 140ms/epoch - 9ms/step
# Epoch 481/500
# 15/15 - 0s - loss: 6.8400e-04 - val_loss: 0.0012 - 123ms/epoch - 8ms/step
# Epoch 482/500
# 15/15 - 0s - loss: 6.6270e-04 - val_loss: 0.0014 - 115ms/epoch - 8ms/step
# Epoch 483/500
# 15/15 - 0s - loss: 6.8443e-04 - val_loss: 0.0012 - 124ms/epoch - 8ms/step
# Epoch 484/500
# 15/15 - 0s - loss: 6.6221e-04 - val_loss: 0.0014 - 116ms/epoch - 8ms/step
# Epoch 485/500
# 15/15 - 0s - loss: 6.8521e-04 - val_loss: 0.0012 - 126ms/epoch - 8ms/step
# Epoch 486/500
# 15/15 - 0s - loss: 6.6171e-04 - val_loss: 0.0014 - 127ms/epoch - 8ms/step
# Epoch 487/500
# 15/15 - 0s - loss: 6.8613e-04 - val_loss: 0.0012 - 140ms/epoch - 9ms/step
# Epoch 488/500
# 15/15 - 0s - loss: 6.6127e-04 - val_loss: 0.0014 - 149ms/epoch - 10ms/step
# Epoch 489/500
# 15/15 - 0s - loss: 6.8688e-04 - val_loss: 0.0012 - 130ms/epoch - 9ms/step
# Epoch 490/500
# 15/15 - 0s - loss: 6.6107e-04 - val_loss: 0.0014 - 108ms/epoch - 7ms/step
# Epoch 491/500
# 15/15 - 0s - loss: 6.8745e-04 - val_loss: 0.0012 - 111ms/epoch - 7ms/step
# Epoch 492/500
# 15/15 - 0s - loss: 6.6089e-04 - val_loss: 0.0014 - 105ms/epoch - 7ms/step
# Epoch 493/500
# 15/15 - 0s - loss: 6.8825e-04 - val_loss: 0.0012 - 108ms/epoch - 7ms/step
# Epoch 494/500
# 15/15 - 0s - loss: 6.6031e-04 - val_loss: 0.0014 - 99ms/epoch - 7ms/step
# Epoch 495/500
# 15/15 - 0s - loss: 6.8880e-04 - val_loss: 0.0012 - 110ms/epoch - 7ms/step
# Epoch 496/500
# 15/15 - 0s - loss: 6.6021e-04 - val_loss: 0.0014 - 99ms/epoch - 7ms/step
# Epoch 497/500
# 15/15 - 0s - loss: 6.8852e-04 - val_loss: 0.0012 - 136ms/epoch - 9ms/step
# Epoch 498/500
# 15/15 - 0s - loss: 6.5994e-04 - val_loss: 0.0014 - 124ms/epoch - 8ms/step
# Epoch 499/500
# 15/15 - 0s - loss: 6.8842e-04 - val_loss: 0.0012 - 108ms/epoch - 7ms/step
# Epoch 500/500
# 15/15 - 0s - loss: 6.5922e-04 - val_loss: 0.0014 - 111ms/epoch - 7ms/step

# %% [markdown]
# ## Metrics ($HPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
phy = phys2(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 8/8 [==============================] - 1s 2ms/step
# (237, 3)
# (237, 10)
# Test RMSE: 17.318
# Test MAE: 11.823

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('San Juan Dengue Spread', fontsize=20)
plt.legend(fontsize=20)
plt.show()
