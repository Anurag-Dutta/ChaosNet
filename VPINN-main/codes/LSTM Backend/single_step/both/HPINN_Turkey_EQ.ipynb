# %% [markdown]
# # Time Series Prediction with Hénon–Heiles Eqaution Inspired Deep Learning ($HPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-09 20:33:26

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Henon Heiles Intermittency_

# %% [markdown]
# The `henon_heiles_intermittency.dat` is generated from the Runge Kutta Method.

# %% [markdown]
# This feeds the model with the dynamics of the Henon Heiles Equations

# %%
data = np.genfromtxt('datasets/henon_heiles_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 1 # Daily Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 0.099
# 1        -0.000989
# 2        -0.000979
# 3        -0.000968
# 4        -0.000958
# 5        -0.000947
#             ...
# 139867    0.000000
# 139868    0.000000
# 139869    0.000000
# 139870    0.000000
# 139871    0.000000
# Name: 1, Length: 139871, dtype: float64
# 2         0.000011
# 3         0.000010
# 4         0.000010
# 5         0.000010
# 6         0.000010
#             ...
# 139867    0.000000
# 139868    0.000000
# 139869    0.000000
# 139870    0.000000
# 139871    0.000000
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _TURKEY EARTHQUAKE_

# %%
data = pd.read_csv("datasets/eq.csv")
training_set = data.iloc[:, 4]
print(training_set)
# Out:
# 0       4.4
# 1       5.2
# 2       4.8
# 3       4.4
# 4       5.7
#        ...
# 6569    4.5
# 6570    4.0
# 6571    4.4
# 6572    4.1
# 6573    4.0
# Name: Magnitude, Length: 6574, dtype: float64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0        -0.000989
# 1        -0.000979
# 2        -0.000968
# 3        -0.000958
# 4        -0.000947
#             ...
# 139866    0.000000
# 139867    0.000000
# 139868    0.000000
# 139869    0.000000
# 139870    0.000000
# Name: 1, Length: 139871, dtype: float64
# 0         0.000011
# 1         0.000010
# 2         0.000010
# 3         0.000010
# 4         0.000010
#             ...
# 139865    0.000000
# 139866    0.000000
# 139867    0.000000
# 139868    0.000000
# 139869    0.000000
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Henon Heiles Equation_)

# %% [markdown]
# _Parameters_: $\lambda=1\\$

# %%
L = df.iloc[:, 2] - df.iloc[:, 1]
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10         4.4        5.2        4.8        4.4        5.7        4.3
# 11         5.2        4.8        4.4        5.7        4.3        4.0
# 12         4.8        4.4        5.7        4.3        4.0        4.8
# 13         4.4        5.7        4.3        4.0        4.8        5.2
# 14         5.7        4.3        4.0        4.8        5.2        5.1
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)   var2(t)   var3(t)
# 10        4.0        4.8        5.2        5.1      4.7 -0.000889  0.000009
# 11        4.8        5.2        5.1        4.7      4.6 -0.000880  0.000009
# 12        5.2        5.1        4.7        4.6      4.4 -0.000870  0.000009
# 13        5.1        4.7        4.6        4.4      4.7 -0.000861  0.000009
# 14        4.7        4.6        4.4        4.7      4.1 -0.000852  0.000009
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (6563, 13)
# (6563, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (5250, 1, 10) (5250, 3) (1313, 1, 10) (1313, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] - y_true[:, 1]), (y_pred[:, 2] - y_pred[:, 1]))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] - (y_pred[1:-1]-y_pred[:-2])
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] - (y_real[1:-1]-y_pred[:-2])
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($HPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square((y_pred[:, 2] - y_pred[:, 1]))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 83/83 - 8s - loss: 0.0168 - val_loss: 0.0086 - 8s/epoch - 91ms/step
# Epoch 2/500
# 83/83 - 0s - loss: 0.0132 - val_loss: 0.0086 - 418ms/epoch - 5ms/step
# Epoch 3/500
# 83/83 - 0s - loss: 0.0129 - val_loss: 0.0086 - 413ms/epoch - 5ms/step
# Epoch 4/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 416ms/epoch - 5ms/step
# Epoch 5/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 453ms/epoch - 5ms/step
# Epoch 6/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0085 - 407ms/epoch - 5ms/step
# Epoch 7/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0085 - 373ms/epoch - 4ms/step
# Epoch 8/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0085 - 385ms/epoch - 5ms/step
# Epoch 9/500
# 83/83 - 0s - loss: 0.0129 - val_loss: 0.0085 - 376ms/epoch - 5ms/step
# Epoch 10/500
# 83/83 - 0s - loss: 0.0129 - val_loss: 0.0085 - 424ms/epoch - 5ms/step
# Epoch 11/500
# 83/83 - 0s - loss: 0.0129 - val_loss: 0.0085 - 379ms/epoch - 5ms/step
# Epoch 12/500
# 83/83 - 0s - loss: 0.0129 - val_loss: 0.0085 - 430ms/epoch - 5ms/step
# Epoch 13/500
# 83/83 - 0s - loss: 0.0129 - val_loss: 0.0085 - 392ms/epoch - 5ms/step
# Epoch 14/500
# 83/83 - 0s - loss: 0.0129 - val_loss: 0.0085 - 442ms/epoch - 5ms/step
# Epoch 15/500
# 83/83 - 0s - loss: 0.0129 - val_loss: 0.0085 - 412ms/epoch - 5ms/step
# Epoch 16/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0085 - 390ms/epoch - 5ms/step
# Epoch 17/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0085 - 467ms/epoch - 6ms/step
# Epoch 18/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 423ms/epoch - 5ms/step
# Epoch 19/500
# 83/83 - 1s - loss: 0.0128 - val_loss: 0.0086 - 669ms/epoch - 8ms/step
# Epoch 20/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 480ms/epoch - 6ms/step
# Epoch 21/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 398ms/epoch - 5ms/step
# Epoch 22/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 486ms/epoch - 6ms/step
# Epoch 23/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 467ms/epoch - 6ms/step
# Epoch 24/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 480ms/epoch - 6ms/step
# Epoch 25/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 379ms/epoch - 5ms/step
# Epoch 26/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 366ms/epoch - 4ms/step
# Epoch 27/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 377ms/epoch - 5ms/step
# Epoch 28/500
# 83/83 - 1s - loss: 0.0128 - val_loss: 0.0086 - 546ms/epoch - 7ms/step
# Epoch 29/500
# 83/83 - 1s - loss: 0.0128 - val_loss: 0.0086 - 501ms/epoch - 6ms/step
# Epoch 30/500
# 83/83 - 1s - loss: 0.0128 - val_loss: 0.0086 - 533ms/epoch - 6ms/step
# Epoch 31/500
# 83/83 - 1s - loss: 0.0128 - val_loss: 0.0086 - 591ms/epoch - 7ms/step
# Epoch 32/500
# 83/83 - 1s - loss: 0.0128 - val_loss: 0.0086 - 694ms/epoch - 8ms/step
# Epoch 33/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 388ms/epoch - 5ms/step
# Epoch 34/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 398ms/epoch - 5ms/step
# Epoch 35/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 376ms/epoch - 5ms/step
# Epoch 36/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 472ms/epoch - 6ms/step
# Epoch 37/500
# 83/83 - 1s - loss: 0.0128 - val_loss: 0.0086 - 545ms/epoch - 7ms/step
# Epoch 38/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 499ms/epoch - 6ms/step
# Epoch 39/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 437ms/epoch - 5ms/step
# Epoch 40/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 432ms/epoch - 5ms/step
# Epoch 41/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 468ms/epoch - 6ms/step
# Epoch 42/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 461ms/epoch - 6ms/step
# Epoch 43/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 386ms/epoch - 5ms/step
# Epoch 44/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 487ms/epoch - 6ms/step
# Epoch 45/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 345ms/epoch - 4ms/step
# Epoch 46/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 365ms/epoch - 4ms/step
# Epoch 47/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 393ms/epoch - 5ms/step
# Epoch 48/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 374ms/epoch - 5ms/step
# Epoch 49/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 384ms/epoch - 5ms/step
# Epoch 50/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 446ms/epoch - 5ms/step
# Epoch 51/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 397ms/epoch - 5ms/step
# Epoch 52/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 380ms/epoch - 5ms/step
# Epoch 53/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 427ms/epoch - 5ms/step
# Epoch 54/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 375ms/epoch - 5ms/step
# Epoch 55/500
# 83/83 - 0s - loss: 0.0128 - val_loss: 0.0086 - 429ms/epoch - 5ms/step
# Epoch 56/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 408ms/epoch - 5ms/step
# Epoch 57/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 402ms/epoch - 5ms/step
# Epoch 58/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 409ms/epoch - 5ms/step
# Epoch 59/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 379ms/epoch - 5ms/step
# Epoch 60/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 462ms/epoch - 6ms/step
# Epoch 61/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 436ms/epoch - 5ms/step
# Epoch 62/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 432ms/epoch - 5ms/step
# Epoch 63/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 376ms/epoch - 5ms/step
# Epoch 64/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 429ms/epoch - 5ms/step
# Epoch 65/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 432ms/epoch - 5ms/step
# Epoch 66/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 421ms/epoch - 5ms/step
# Epoch 67/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 408ms/epoch - 5ms/step
# Epoch 68/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 384ms/epoch - 5ms/step
# Epoch 69/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 434ms/epoch - 5ms/step
# Epoch 70/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 404ms/epoch - 5ms/step
# Epoch 71/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 458ms/epoch - 6ms/step
# Epoch 72/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 373ms/epoch - 4ms/step
# Epoch 73/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 382ms/epoch - 5ms/step
# Epoch 74/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 439ms/epoch - 5ms/step
# Epoch 75/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 394ms/epoch - 5ms/step
# Epoch 76/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 388ms/epoch - 5ms/step
# Epoch 77/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 430ms/epoch - 5ms/step
# Epoch 78/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 377ms/epoch - 5ms/step
# Epoch 79/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 409ms/epoch - 5ms/step
# Epoch 80/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 413ms/epoch - 5ms/step
# Epoch 81/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 409ms/epoch - 5ms/step
# Epoch 82/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 392ms/epoch - 5ms/step
# Epoch 83/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 335ms/epoch - 4ms/step
# Epoch 84/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 374ms/epoch - 5ms/step
# Epoch 85/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 445ms/epoch - 5ms/step
# Epoch 86/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 485ms/epoch - 6ms/step
# Epoch 87/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 431ms/epoch - 5ms/step
# Epoch 88/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 464ms/epoch - 6ms/step
# Epoch 89/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 483ms/epoch - 6ms/step
# Epoch 90/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 412ms/epoch - 5ms/step
# Epoch 91/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 427ms/epoch - 5ms/step
# Epoch 92/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 371ms/epoch - 4ms/step
# Epoch 93/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 414ms/epoch - 5ms/step
# Epoch 94/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 390ms/epoch - 5ms/step
# Epoch 95/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 370ms/epoch - 4ms/step
# Epoch 96/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 403ms/epoch - 5ms/step
# Epoch 97/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 354ms/epoch - 4ms/step
# Epoch 98/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 381ms/epoch - 5ms/step
# Epoch 99/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 403ms/epoch - 5ms/step
# Epoch 100/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 386ms/epoch - 5ms/step
# Epoch 101/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 388ms/epoch - 5ms/step
# Epoch 102/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 326ms/epoch - 4ms/step
# Epoch 103/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 374ms/epoch - 5ms/step
# Epoch 104/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0086 - 450ms/epoch - 5ms/step
# Epoch 105/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 407ms/epoch - 5ms/step
# Epoch 106/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 456ms/epoch - 5ms/step
# Epoch 107/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 381ms/epoch - 5ms/step
# Epoch 108/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 458ms/epoch - 6ms/step
# Epoch 109/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 490ms/epoch - 6ms/step
# Epoch 110/500
# 83/83 - 1s - loss: 0.0127 - val_loss: 0.0085 - 573ms/epoch - 7ms/step
# Epoch 111/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 427ms/epoch - 5ms/step
# Epoch 112/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 430ms/epoch - 5ms/step
# Epoch 113/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 393ms/epoch - 5ms/step
# Epoch 114/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 450ms/epoch - 5ms/step
# Epoch 115/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 377ms/epoch - 5ms/step
# Epoch 116/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 367ms/epoch - 4ms/step
# Epoch 117/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 409ms/epoch - 5ms/step
# Epoch 118/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 384ms/epoch - 5ms/step
# Epoch 119/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 430ms/epoch - 5ms/step
# Epoch 120/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 435ms/epoch - 5ms/step
# Epoch 121/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 361ms/epoch - 4ms/step
# Epoch 122/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 393ms/epoch - 5ms/step
# Epoch 123/500
# 83/83 - 0s - loss: 0.0127 - val_loss: 0.0085 - 427ms/epoch - 5ms/step
# Epoch 124/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 474ms/epoch - 6ms/step
# Epoch 125/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 391ms/epoch - 5ms/step
# Epoch 126/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 377ms/epoch - 5ms/step
# Epoch 127/500
# 83/83 - 1s - loss: 0.0126 - val_loss: 0.0085 - 598ms/epoch - 7ms/step
# Epoch 128/500
# 83/83 - 1s - loss: 0.0126 - val_loss: 0.0085 - 538ms/epoch - 6ms/step
# Epoch 129/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 426ms/epoch - 5ms/step
# Epoch 130/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 482ms/epoch - 6ms/step
# Epoch 131/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 471ms/epoch - 6ms/step
# Epoch 132/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 478ms/epoch - 6ms/step
# Epoch 133/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 425ms/epoch - 5ms/step
# Epoch 134/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 387ms/epoch - 5ms/step
# Epoch 135/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 400ms/epoch - 5ms/step
# Epoch 136/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 434ms/epoch - 5ms/step
# Epoch 137/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 415ms/epoch - 5ms/step
# Epoch 138/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 386ms/epoch - 5ms/step
# Epoch 139/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 375ms/epoch - 5ms/step
# Epoch 140/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 353ms/epoch - 4ms/step
# Epoch 141/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 387ms/epoch - 5ms/step
# Epoch 142/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 432ms/epoch - 5ms/step
# Epoch 143/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 408ms/epoch - 5ms/step
# Epoch 144/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 369ms/epoch - 4ms/step
# Epoch 145/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 385ms/epoch - 5ms/step
# Epoch 146/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 386ms/epoch - 5ms/step
# Epoch 147/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 399ms/epoch - 5ms/step
# Epoch 148/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 444ms/epoch - 5ms/step
# Epoch 149/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 382ms/epoch - 5ms/step
# Epoch 150/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 398ms/epoch - 5ms/step
# Epoch 151/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 397ms/epoch - 5ms/step
# Epoch 152/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 444ms/epoch - 5ms/step
# Epoch 153/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 387ms/epoch - 5ms/step
# Epoch 154/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 388ms/epoch - 5ms/step
# Epoch 155/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 401ms/epoch - 5ms/step
# Epoch 156/500
# 83/83 - 1s - loss: 0.0126 - val_loss: 0.0085 - 516ms/epoch - 6ms/step
# Epoch 157/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 395ms/epoch - 5ms/step
# Epoch 158/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 368ms/epoch - 4ms/step
# Epoch 159/500
# 83/83 - 0s - loss: 0.0126 - val_loss: 0.0085 - 397ms/epoch - 5ms/step
# Epoch 160/500
# 83/83 - 1s - loss: 0.0126 - val_loss: 0.0085 - 517ms/epoch - 6ms/step
# Epoch 161/500
# 83/83 - 1s - loss: 0.0126 - val_loss: 0.0085 - 817ms/epoch - 10ms/step
# Epoch 162/500
# 83/83 - 1s - loss: 0.0126 - val_loss: 0.0085 - 612ms/epoch - 7ms/step
# Epoch 163/500
# 83/83 - 1s - loss: 0.0126 - val_loss: 0.0085 - 786ms/epoch - 9ms/step
# Epoch 164/500
# 83/83 - 1s - loss: 0.0126 - val_loss: 0.0085 - 660ms/epoch - 8ms/step
# Epoch 165/500
# 83/83 - 1s - loss: 0.0126 - val_loss: 0.0085 - 893ms/epoch - 11ms/step
# Epoch 166/500
# 83/83 - 1s - loss: 0.0126 - val_loss: 0.0085 - 706ms/epoch - 9ms/step
# Epoch 167/500
# 83/83 - 1s - loss: 0.0126 - val_loss: 0.0085 - 804ms/epoch - 10ms/step
# Epoch 168/500
# 83/83 - 1s - loss: 0.0126 - val_loss: 0.0085 - 784ms/epoch - 9ms/step
# Epoch 169/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0085 - 816ms/epoch - 10ms/step
# Epoch 170/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0085 - 770ms/epoch - 9ms/step
# Epoch 171/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0085 - 692ms/epoch - 8ms/step
# Epoch 172/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0085 - 797ms/epoch - 10ms/step
# Epoch 173/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0085 - 913ms/epoch - 11ms/step
# Epoch 174/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0085 - 782ms/epoch - 9ms/step
# Epoch 175/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0085 - 594ms/epoch - 7ms/step
# Epoch 176/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0085 - 613ms/epoch - 7ms/step
# Epoch 177/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0085 - 506ms/epoch - 6ms/step
# Epoch 178/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0085 - 529ms/epoch - 6ms/step
# Epoch 179/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0085 - 523ms/epoch - 6ms/step
# Epoch 180/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0085 - 560ms/epoch - 7ms/step
# Epoch 181/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0085 - 579ms/epoch - 7ms/step
# Epoch 182/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0085 - 592ms/epoch - 7ms/step
# Epoch 183/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 626ms/epoch - 8ms/step
# Epoch 184/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0085 - 604ms/epoch - 7ms/step
# Epoch 185/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 539ms/epoch - 6ms/step
# Epoch 186/500
# 83/83 - 0s - loss: 0.0125 - val_loss: 0.0085 - 454ms/epoch - 5ms/step
# Epoch 187/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 550ms/epoch - 7ms/step
# Epoch 188/500
# 83/83 - 0s - loss: 0.0125 - val_loss: 0.0084 - 490ms/epoch - 6ms/step
# Epoch 189/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 526ms/epoch - 6ms/step
# Epoch 190/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 593ms/epoch - 7ms/step
# Epoch 191/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 607ms/epoch - 7ms/step
# Epoch 192/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 622ms/epoch - 7ms/step
# Epoch 193/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 531ms/epoch - 6ms/step
# Epoch 194/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 583ms/epoch - 7ms/step
# Epoch 195/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 505ms/epoch - 6ms/step
# Epoch 196/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 679ms/epoch - 8ms/step
# Epoch 197/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 549ms/epoch - 7ms/step
# Epoch 198/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 545ms/epoch - 7ms/step
# Epoch 199/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 689ms/epoch - 8ms/step
# Epoch 200/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 713ms/epoch - 9ms/step
# Epoch 201/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 601ms/epoch - 7ms/step
# Epoch 202/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 822ms/epoch - 10ms/step
# Epoch 203/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 638ms/epoch - 8ms/step
# Epoch 204/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 780ms/epoch - 9ms/step
# Epoch 205/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 695ms/epoch - 8ms/step
# Epoch 206/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 587ms/epoch - 7ms/step
# Epoch 207/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 659ms/epoch - 8ms/step
# Epoch 208/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 693ms/epoch - 8ms/step
# Epoch 209/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 870ms/epoch - 10ms/step
# Epoch 210/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 905ms/epoch - 11ms/step
# Epoch 211/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 732ms/epoch - 9ms/step
# Epoch 212/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 611ms/epoch - 7ms/step
# Epoch 213/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 512ms/epoch - 6ms/step
# Epoch 214/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 510ms/epoch - 6ms/step
# Epoch 215/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 596ms/epoch - 7ms/step
# Epoch 216/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 665ms/epoch - 8ms/step
# Epoch 217/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 670ms/epoch - 8ms/step
# Epoch 218/500
# 83/83 - 1s - loss: 0.0125 - val_loss: 0.0084 - 717ms/epoch - 9ms/step
# Epoch 219/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 558ms/epoch - 7ms/step
# Epoch 220/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 580ms/epoch - 7ms/step
# Epoch 221/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 726ms/epoch - 9ms/step
# Epoch 222/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 815ms/epoch - 10ms/step
# Epoch 223/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 694ms/epoch - 8ms/step
# Epoch 224/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 666ms/epoch - 8ms/step
# Epoch 225/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 709ms/epoch - 9ms/step
# Epoch 226/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 685ms/epoch - 8ms/step
# Epoch 227/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 652ms/epoch - 8ms/step
# Epoch 228/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 693ms/epoch - 8ms/step
# Epoch 229/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 811ms/epoch - 10ms/step
# Epoch 230/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 631ms/epoch - 8ms/step
# Epoch 231/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 644ms/epoch - 8ms/step
# Epoch 232/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0084 - 475ms/epoch - 6ms/step
# Epoch 233/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0084 - 405ms/epoch - 5ms/step
# Epoch 234/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0084 - 464ms/epoch - 6ms/step
# Epoch 235/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 514ms/epoch - 6ms/step
# Epoch 236/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 513ms/epoch - 6ms/step
# Epoch 237/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 504ms/epoch - 6ms/step
# Epoch 238/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 509ms/epoch - 6ms/step
# Epoch 239/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 564ms/epoch - 7ms/step
# Epoch 240/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 533ms/epoch - 6ms/step
# Epoch 241/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0084 - 429ms/epoch - 5ms/step
# Epoch 242/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0084 - 467ms/epoch - 6ms/step
# Epoch 243/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0084 - 471ms/epoch - 6ms/step
# Epoch 244/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0084 - 420ms/epoch - 5ms/step
# Epoch 245/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0084 - 434ms/epoch - 5ms/step
# Epoch 246/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0084 - 430ms/epoch - 5ms/step
# Epoch 247/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0084 - 498ms/epoch - 6ms/step
# Epoch 248/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0084 - 474ms/epoch - 6ms/step
# Epoch 249/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0084 - 495ms/epoch - 6ms/step
# Epoch 250/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0084 - 466ms/epoch - 6ms/step
# Epoch 251/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 595ms/epoch - 7ms/step
# Epoch 252/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 679ms/epoch - 8ms/step
# Epoch 253/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 603ms/epoch - 7ms/step
# Epoch 254/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 521ms/epoch - 6ms/step
# Epoch 255/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0084 - 496ms/epoch - 6ms/step
# Epoch 256/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 601ms/epoch - 7ms/step
# Epoch 257/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 583ms/epoch - 7ms/step
# Epoch 258/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 569ms/epoch - 7ms/step
# Epoch 259/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 594ms/epoch - 7ms/step
# Epoch 260/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 580ms/epoch - 7ms/step
# Epoch 261/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 635ms/epoch - 8ms/step
# Epoch 262/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 602ms/epoch - 7ms/step
# Epoch 263/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 590ms/epoch - 7ms/step
# Epoch 264/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 611ms/epoch - 7ms/step
# Epoch 265/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0084 - 598ms/epoch - 7ms/step
# Epoch 266/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 603ms/epoch - 7ms/step
# Epoch 267/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 672ms/epoch - 8ms/step
# Epoch 268/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 611ms/epoch - 7ms/step
# Epoch 269/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 558ms/epoch - 7ms/step
# Epoch 270/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 595ms/epoch - 7ms/step
# Epoch 271/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 655ms/epoch - 8ms/step
# Epoch 272/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0085 - 419ms/epoch - 5ms/step
# Epoch 273/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0085 - 491ms/epoch - 6ms/step
# Epoch 274/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 579ms/epoch - 7ms/step
# Epoch 275/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 584ms/epoch - 7ms/step
# Epoch 276/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 666ms/epoch - 8ms/step
# Epoch 277/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 630ms/epoch - 8ms/step
# Epoch 278/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 526ms/epoch - 6ms/step
# Epoch 279/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0085 - 485ms/epoch - 6ms/step
# Epoch 280/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0085 - 457ms/epoch - 6ms/step
# Epoch 281/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 533ms/epoch - 6ms/step
# Epoch 282/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 575ms/epoch - 7ms/step
# Epoch 283/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0085 - 432ms/epoch - 5ms/step
# Epoch 284/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 501ms/epoch - 6ms/step
# Epoch 285/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 521ms/epoch - 6ms/step
# Epoch 286/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 656ms/epoch - 8ms/step
# Epoch 287/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0085 - 476ms/epoch - 6ms/step
# Epoch 288/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 520ms/epoch - 6ms/step
# Epoch 289/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 595ms/epoch - 7ms/step
# Epoch 290/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 577ms/epoch - 7ms/step
# Epoch 291/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 536ms/epoch - 6ms/step
# Epoch 292/500
# 83/83 - 1s - loss: 0.0124 - val_loss: 0.0085 - 512ms/epoch - 6ms/step
# Epoch 293/500
# 83/83 - 0s - loss: 0.0124 - val_loss: 0.0085 - 422ms/epoch - 5ms/step
# Epoch 294/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 393ms/epoch - 5ms/step
# Epoch 295/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 439ms/epoch - 5ms/step
# Epoch 296/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 384ms/epoch - 5ms/step
# Epoch 297/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 418ms/epoch - 5ms/step
# Epoch 298/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 456ms/epoch - 5ms/step
# Epoch 299/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 405ms/epoch - 5ms/step
# Epoch 300/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 401ms/epoch - 5ms/step
# Epoch 301/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 429ms/epoch - 5ms/step
# Epoch 302/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 425ms/epoch - 5ms/step
# Epoch 303/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 405ms/epoch - 5ms/step
# Epoch 304/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 381ms/epoch - 5ms/step
# Epoch 305/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 371ms/epoch - 4ms/step
# Epoch 306/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 381ms/epoch - 5ms/step
# Epoch 307/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 466ms/epoch - 6ms/step
# Epoch 308/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 424ms/epoch - 5ms/step
# Epoch 309/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 575ms/epoch - 7ms/step
# Epoch 310/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 437ms/epoch - 5ms/step
# Epoch 311/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 436ms/epoch - 5ms/step
# Epoch 312/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 461ms/epoch - 6ms/step
# Epoch 313/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 474ms/epoch - 6ms/step
# Epoch 314/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 494ms/epoch - 6ms/step
# Epoch 315/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 421ms/epoch - 5ms/step
# Epoch 316/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 419ms/epoch - 5ms/step
# Epoch 317/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 405ms/epoch - 5ms/step
# Epoch 318/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 389ms/epoch - 5ms/step
# Epoch 319/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 419ms/epoch - 5ms/step
# Epoch 320/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 377ms/epoch - 5ms/step
# Epoch 321/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 431ms/epoch - 5ms/step
# Epoch 322/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 371ms/epoch - 4ms/step
# Epoch 323/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 334ms/epoch - 4ms/step
# Epoch 324/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 327ms/epoch - 4ms/step
# Epoch 325/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 386ms/epoch - 5ms/step
# Epoch 326/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 397ms/epoch - 5ms/step
# Epoch 327/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 516ms/epoch - 6ms/step
# Epoch 328/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 542ms/epoch - 7ms/step
# Epoch 329/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 532ms/epoch - 6ms/step
# Epoch 330/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 596ms/epoch - 7ms/step
# Epoch 331/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 428ms/epoch - 5ms/step
# Epoch 332/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 505ms/epoch - 6ms/step
# Epoch 333/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 528ms/epoch - 6ms/step
# Epoch 334/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 532ms/epoch - 6ms/step
# Epoch 335/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 424ms/epoch - 5ms/step
# Epoch 336/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 566ms/epoch - 7ms/step
# Epoch 337/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 583ms/epoch - 7ms/step
# Epoch 338/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 416ms/epoch - 5ms/step
# Epoch 339/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 450ms/epoch - 5ms/step
# Epoch 340/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 388ms/epoch - 5ms/step
# Epoch 341/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 431ms/epoch - 5ms/step
# Epoch 342/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 497ms/epoch - 6ms/step
# Epoch 343/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 450ms/epoch - 5ms/step
# Epoch 344/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 513ms/epoch - 6ms/step
# Epoch 345/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 464ms/epoch - 6ms/step
# Epoch 346/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 520ms/epoch - 6ms/step
# Epoch 347/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 453ms/epoch - 5ms/step
# Epoch 348/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 510ms/epoch - 6ms/step
# Epoch 349/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 428ms/epoch - 5ms/step
# Epoch 350/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 497ms/epoch - 6ms/step
# Epoch 351/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 479ms/epoch - 6ms/step
# Epoch 352/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 455ms/epoch - 5ms/step
# Epoch 353/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 496ms/epoch - 6ms/step
# Epoch 354/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 499ms/epoch - 6ms/step
# Epoch 355/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 543ms/epoch - 7ms/step
# Epoch 356/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 528ms/epoch - 6ms/step
# Epoch 357/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 437ms/epoch - 5ms/step
# Epoch 358/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 484ms/epoch - 6ms/step
# Epoch 359/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 521ms/epoch - 6ms/step
# Epoch 360/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 686ms/epoch - 8ms/step
# Epoch 361/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 706ms/epoch - 9ms/step
# Epoch 362/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 657ms/epoch - 8ms/step
# Epoch 363/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 605ms/epoch - 7ms/step
# Epoch 364/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 643ms/epoch - 8ms/step
# Epoch 365/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 752ms/epoch - 9ms/step
# Epoch 366/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 651ms/epoch - 8ms/step
# Epoch 367/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 702ms/epoch - 8ms/step
# Epoch 368/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 681ms/epoch - 8ms/step
# Epoch 369/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 622ms/epoch - 7ms/step
# Epoch 370/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 752ms/epoch - 9ms/step
# Epoch 371/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 745ms/epoch - 9ms/step
# Epoch 372/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 619ms/epoch - 7ms/step
# Epoch 373/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 698ms/epoch - 8ms/step
# Epoch 374/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 649ms/epoch - 8ms/step
# Epoch 375/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 587ms/epoch - 7ms/step
# Epoch 376/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 690ms/epoch - 8ms/step
# Epoch 377/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 686ms/epoch - 8ms/step
# Epoch 378/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 587ms/epoch - 7ms/step
# Epoch 379/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 521ms/epoch - 6ms/step
# Epoch 380/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 581ms/epoch - 7ms/step
# Epoch 381/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 547ms/epoch - 7ms/step
# Epoch 382/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 646ms/epoch - 8ms/step
# Epoch 383/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 545ms/epoch - 7ms/step
# Epoch 384/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 472ms/epoch - 6ms/step
# Epoch 385/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 510ms/epoch - 6ms/step
# Epoch 386/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 449ms/epoch - 5ms/step
# Epoch 387/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 586ms/epoch - 7ms/step
# Epoch 388/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 514ms/epoch - 6ms/step
# Epoch 389/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 516ms/epoch - 6ms/step
# Epoch 390/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 569ms/epoch - 7ms/step
# Epoch 391/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 475ms/epoch - 6ms/step
# Epoch 392/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 519ms/epoch - 6ms/step
# Epoch 393/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 504ms/epoch - 6ms/step
# Epoch 394/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 520ms/epoch - 6ms/step
# Epoch 395/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 548ms/epoch - 7ms/step
# Epoch 396/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 524ms/epoch - 6ms/step
# Epoch 397/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 463ms/epoch - 6ms/step
# Epoch 398/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 458ms/epoch - 6ms/step
# Epoch 399/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 475ms/epoch - 6ms/step
# Epoch 400/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 454ms/epoch - 5ms/step
# Epoch 401/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 478ms/epoch - 6ms/step
# Epoch 402/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 555ms/epoch - 7ms/step
# Epoch 403/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 536ms/epoch - 6ms/step
# Epoch 404/500
# 83/83 - 1s - loss: 0.0123 - val_loss: 0.0085 - 513ms/epoch - 6ms/step
# Epoch 405/500
# 83/83 - 0s - loss: 0.0123 - val_loss: 0.0085 - 483ms/epoch - 6ms/step
# Epoch 406/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 530ms/epoch - 6ms/step
# Epoch 407/500
# 83/83 - 0s - loss: 0.0122 - val_loss: 0.0085 - 488ms/epoch - 6ms/step
# Epoch 408/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 502ms/epoch - 6ms/step
# Epoch 409/500
# 83/83 - 0s - loss: 0.0122 - val_loss: 0.0085 - 463ms/epoch - 6ms/step
# Epoch 410/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 509ms/epoch - 6ms/step
# Epoch 411/500
# 83/83 - 0s - loss: 0.0122 - val_loss: 0.0085 - 486ms/epoch - 6ms/step
# Epoch 412/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 512ms/epoch - 6ms/step
# Epoch 413/500
# 83/83 - 0s - loss: 0.0122 - val_loss: 0.0085 - 467ms/epoch - 6ms/step
# Epoch 414/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 552ms/epoch - 7ms/step
# Epoch 415/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 508ms/epoch - 6ms/step
# Epoch 416/500
# 83/83 - 0s - loss: 0.0122 - val_loss: 0.0085 - 454ms/epoch - 5ms/step
# Epoch 417/500
# 83/83 - 0s - loss: 0.0122 - val_loss: 0.0085 - 450ms/epoch - 5ms/step
# Epoch 418/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 524ms/epoch - 6ms/step
# Epoch 419/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 632ms/epoch - 8ms/step
# Epoch 420/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 683ms/epoch - 8ms/step
# Epoch 421/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 871ms/epoch - 10ms/step
# Epoch 422/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 1s/epoch - 13ms/step
# Epoch 423/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 808ms/epoch - 10ms/step
# Epoch 424/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 1s/epoch - 13ms/step
# Epoch 425/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 978ms/epoch - 12ms/step
# Epoch 426/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 820ms/epoch - 10ms/step
# Epoch 427/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 696ms/epoch - 8ms/step
# Epoch 428/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 824ms/epoch - 10ms/step
# Epoch 429/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 779ms/epoch - 9ms/step
# Epoch 430/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 622ms/epoch - 7ms/step
# Epoch 431/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 774ms/epoch - 9ms/step
# Epoch 432/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 654ms/epoch - 8ms/step
# Epoch 433/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 633ms/epoch - 8ms/step
# Epoch 434/500
# 83/83 - 0s - loss: 0.0122 - val_loss: 0.0085 - 449ms/epoch - 5ms/step
# Epoch 435/500
# 83/83 - 0s - loss: 0.0122 - val_loss: 0.0085 - 441ms/epoch - 5ms/step
# Epoch 436/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 514ms/epoch - 6ms/step
# Epoch 437/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 542ms/epoch - 7ms/step
# Epoch 438/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 539ms/epoch - 6ms/step
# Epoch 439/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 655ms/epoch - 8ms/step
# Epoch 440/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 535ms/epoch - 6ms/step
# Epoch 441/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 582ms/epoch - 7ms/step
# Epoch 442/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 541ms/epoch - 7ms/step
# Epoch 443/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 566ms/epoch - 7ms/step
# Epoch 444/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 555ms/epoch - 7ms/step
# Epoch 445/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 660ms/epoch - 8ms/step
# Epoch 446/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 685ms/epoch - 8ms/step
# Epoch 447/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 551ms/epoch - 7ms/step
# Epoch 448/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 726ms/epoch - 9ms/step
# Epoch 449/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 747ms/epoch - 9ms/step
# Epoch 450/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 566ms/epoch - 7ms/step
# Epoch 451/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 615ms/epoch - 7ms/step
# Epoch 452/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 519ms/epoch - 6ms/step
# Epoch 453/500
# 83/83 - 0s - loss: 0.0122 - val_loss: 0.0085 - 485ms/epoch - 6ms/step
# Epoch 454/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 564ms/epoch - 7ms/step
# Epoch 455/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 620ms/epoch - 7ms/step
# Epoch 456/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 626ms/epoch - 8ms/step
# Epoch 457/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 932ms/epoch - 11ms/step
# Epoch 458/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 773ms/epoch - 9ms/step
# Epoch 459/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 982ms/epoch - 12ms/step
# Epoch 460/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 958ms/epoch - 12ms/step
# Epoch 461/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 1s/epoch - 16ms/step
# Epoch 462/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 853ms/epoch - 10ms/step
# Epoch 463/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 1s/epoch - 13ms/step
# Epoch 464/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 847ms/epoch - 10ms/step
# Epoch 465/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 972ms/epoch - 12ms/step
# Epoch 466/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 844ms/epoch - 10ms/step
# Epoch 467/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 915ms/epoch - 11ms/step
# Epoch 468/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 862ms/epoch - 10ms/step
# Epoch 469/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 685ms/epoch - 8ms/step
# Epoch 470/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 532ms/epoch - 6ms/step
# Epoch 471/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 579ms/epoch - 7ms/step
# Epoch 472/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 625ms/epoch - 8ms/step
# Epoch 473/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 612ms/epoch - 7ms/step
# Epoch 474/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 547ms/epoch - 7ms/step
# Epoch 475/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 550ms/epoch - 7ms/step
# Epoch 476/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 538ms/epoch - 6ms/step
# Epoch 477/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 529ms/epoch - 6ms/step
# Epoch 478/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 549ms/epoch - 7ms/step
# Epoch 479/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 592ms/epoch - 7ms/step
# Epoch 480/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 624ms/epoch - 8ms/step
# Epoch 481/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 676ms/epoch - 8ms/step
# Epoch 482/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 622ms/epoch - 7ms/step
# Epoch 483/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 621ms/epoch - 7ms/step
# Epoch 484/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 601ms/epoch - 7ms/step
# Epoch 485/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 533ms/epoch - 6ms/step
# Epoch 486/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 567ms/epoch - 7ms/step
# Epoch 487/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 556ms/epoch - 7ms/step
# Epoch 488/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 513ms/epoch - 6ms/step
# Epoch 489/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 541ms/epoch - 7ms/step
# Epoch 490/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 562ms/epoch - 7ms/step
# Epoch 491/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 619ms/epoch - 7ms/step
# Epoch 492/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 573ms/epoch - 7ms/step
# Epoch 493/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 652ms/epoch - 8ms/step
# Epoch 494/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 604ms/epoch - 7ms/step
# Epoch 495/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 549ms/epoch - 7ms/step
# Epoch 496/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 566ms/epoch - 7ms/step
# Epoch 497/500
# 83/83 - 0s - loss: 0.0122 - val_loss: 0.0085 - 484ms/epoch - 6ms/step
# Epoch 498/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 517ms/epoch - 6ms/step
# Epoch 499/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 549ms/epoch - 7ms/step
# Epoch 500/500
# 83/83 - 1s - loss: 0.0122 - val_loss: 0.0085 - 532ms/epoch - 6ms/step

# %% [markdown]
# ## Metrics ($HPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
phy = phys2(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 42/42 [==============================] - 2s 4ms/step
# (1313, 3)
# (1313, 10)
# Test RMSE: 0.360
# Test MAE: 0.256

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('Turkey Seismic Waves', fontsize=20)
plt.legend(fontsize=20)
plt.show()
