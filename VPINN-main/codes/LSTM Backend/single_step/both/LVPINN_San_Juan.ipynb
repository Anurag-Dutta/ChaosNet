# %% [markdown]
# # Time Series Prediction with Lotka Volterra Equation Inspired Deep Learning ($LVPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-09 16:50:13

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Lotka Volterra Intermittency_

# %% [markdown]
# The `lotka_volterra_intermittency.dat` is generated from the Runge Kutta Method.

# %% [markdown]
# This feeds the model with the dynamics of the Lotka Volterra Equations

# %%
data = np.genfromtxt('datasets/lotka_volterra_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 7 # Weekly Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 215.48740705
# 1        -1.540163e-03
# 2        -1.523369e-03
# 3        -1.506756e-03
# 4        -1.490327e-03
# 5        -1.474074e-03
#               ...
# 139867   -1.591086e-35
# 139868   -1.573887e-35
# 139869   -1.556877e-35
# 139870   -1.540049e-35
# 139871   -1.523404e-35
# Name: 1, Length: 139871, dtype: float64
# 2         2.399184e-06
# 3         2.373265e-06
# 4         2.346939e-06
# 5         2.321837e-06
# 6         2.296327e-06
#               ...
# 139867    2.483673e-38
# 139868    2.456939e-38
# 139869    2.430082e-38
# 139870    2.403980e-38
# 139871    2.377878e-38
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _SAN JUAN_

# %%
data = pd.read_csv("datasets/sanjuan.csv")
training_set = data.iloc[:, 3]
print(training_set)
# Out:
# 0        4
# 1        5
# 2        4
# 3        3
# 4        6
#         ..
# 1191    56
# 1192    46
# 1193    52
# 1194    34
# 1195    25
# Name: Cases, Length: 1196, dtype: int64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0        -1.540163e-03
# 1        -1.523369e-03
# 2        -1.506756e-03
# 3        -1.490327e-03
# 4        -1.474074e-03
#               ...
# 139866   -1.591086e-35
# 139867   -1.573887e-35
# 139868   -1.556877e-35
# 139869   -1.540049e-35
# 139870   -1.523404e-35
# Name: 1, Length: 139871, dtype: float64
# 0         2.399184e-06
# 1         2.373265e-06
# 2         2.346939e-06
# 3         2.321837e-06
# 4         2.296327e-06
#               ...
# 139865    2.483673e-38
# 139866    2.456939e-38
# 139867    2.430082e-38
# 139868    2.403980e-38
# 139869    2.377878e-38
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lotka Volterra Equation_)

# %% [markdown]
# _Parameters_: $\alpha=0.1, \beta=0.05, \gamma=1.1, \delta=0.1\\$

# %%
a=0.1
b=0.05
c=1.1
d=0.1
L = df.iloc[:, 2] - a*a*df.iloc[:, 0] + 2*a*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*d*(df.iloc[:,0]**2)*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - c*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10         4.0        5.0        4.0        3.0        6.0        2.0
# 11         5.0        4.0        3.0        6.0        2.0        4.0
# 12         4.0        3.0        6.0        2.0        4.0        5.0
# 13         3.0        6.0        2.0        4.0        5.0       10.0
# 14         6.0        2.0        4.0        5.0       10.0        6.0
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)   var2(t)   var3(t)
# 10        4.0        5.0       10.0        6.0      8.0 -0.001380  0.000002
# 11        5.0       10.0        6.0        8.0      2.0 -0.001365  0.000002
# 12       10.0        6.0        8.0        2.0      6.0 -0.001350  0.000002
# 13        6.0        8.0        2.0        6.0     17.0 -0.001336  0.000002
# 14        8.0        2.0        6.0       17.0     23.0 -0.001321  0.000002
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (1185, 13)
# (1185, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (948, 1, 10) (948, 3) (237, 1, 10) (237, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] - a*a*y_true[:, 0] + 2*a*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*d*(y_true[:,0]**2)*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - c*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))), (y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] - a*a*y_pred[:-2] + 2*a*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*d*(y_pred[:-2]**2)*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - c*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] - a*a*y_real[:-2] + 2*a*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*d*(y_real[:-2]**2)*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - c*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($LVPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square(y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 15/15 - 3s - loss: 0.0547 - val_loss: 0.0300 - 3s/epoch - 225ms/step
# Epoch 2/500
# 15/15 - 0s - loss: 0.0140 - val_loss: 0.0256 - 56ms/epoch - 4ms/step
# Epoch 3/500
# 15/15 - 0s - loss: 0.0128 - val_loss: 0.0247 - 54ms/epoch - 4ms/step
# Epoch 4/500
# 15/15 - 0s - loss: 0.0125 - val_loss: 0.0244 - 53ms/epoch - 4ms/step
# Epoch 5/500
# 15/15 - 0s - loss: 0.0124 - val_loss: 0.0243 - 52ms/epoch - 3ms/step
# Epoch 6/500
# 15/15 - 0s - loss: 0.0124 - val_loss: 0.0243 - 56ms/epoch - 4ms/step
# Epoch 7/500
# 15/15 - 0s - loss: 0.0123 - val_loss: 0.0242 - 55ms/epoch - 4ms/step
# Epoch 8/500
# 15/15 - 0s - loss: 0.0123 - val_loss: 0.0242 - 58ms/epoch - 4ms/step
# Epoch 9/500
# 15/15 - 0s - loss: 0.0123 - val_loss: 0.0242 - 56ms/epoch - 4ms/step
# Epoch 10/500
# 15/15 - 0s - loss: 0.0123 - val_loss: 0.0241 - 57ms/epoch - 4ms/step
# Epoch 11/500
# 15/15 - 0s - loss: 0.0123 - val_loss: 0.0241 - 59ms/epoch - 4ms/step
# Epoch 12/500
# 15/15 - 0s - loss: 0.0123 - val_loss: 0.0241 - 60ms/epoch - 4ms/step
# Epoch 13/500
# 15/15 - 0s - loss: 0.0123 - val_loss: 0.0241 - 57ms/epoch - 4ms/step
# Epoch 14/500
# 15/15 - 0s - loss: 0.0122 - val_loss: 0.0240 - 56ms/epoch - 4ms/step
# Epoch 15/500
# 15/15 - 0s - loss: 0.0122 - val_loss: 0.0240 - 57ms/epoch - 4ms/step
# Epoch 16/500
# 15/15 - 0s - loss: 0.0122 - val_loss: 0.0240 - 54ms/epoch - 4ms/step
# Epoch 17/500
# 15/15 - 0s - loss: 0.0122 - val_loss: 0.0240 - 55ms/epoch - 4ms/step
# Epoch 18/500
# 15/15 - 0s - loss: 0.0122 - val_loss: 0.0240 - 54ms/epoch - 4ms/step
# Epoch 19/500
# 15/15 - 0s - loss: 0.0122 - val_loss: 0.0239 - 54ms/epoch - 4ms/step
# Epoch 20/500
# 15/15 - 0s - loss: 0.0122 - val_loss: 0.0239 - 57ms/epoch - 4ms/step
# Epoch 21/500
# 15/15 - 0s - loss: 0.0122 - val_loss: 0.0239 - 55ms/epoch - 4ms/step
# Epoch 22/500
# 15/15 - 0s - loss: 0.0122 - val_loss: 0.0239 - 57ms/epoch - 4ms/step
# Epoch 23/500
# 15/15 - 0s - loss: 0.0122 - val_loss: 0.0239 - 58ms/epoch - 4ms/step
# Epoch 24/500
# 15/15 - 0s - loss: 0.0121 - val_loss: 0.0238 - 57ms/epoch - 4ms/step
# Epoch 25/500
# 15/15 - 0s - loss: 0.0121 - val_loss: 0.0238 - 58ms/epoch - 4ms/step
# Epoch 26/500
# 15/15 - 0s - loss: 0.0121 - val_loss: 0.0238 - 58ms/epoch - 4ms/step
# Epoch 27/500
# 15/15 - 0s - loss: 0.0121 - val_loss: 0.0238 - 57ms/epoch - 4ms/step
# Epoch 28/500
# 15/15 - 0s - loss: 0.0121 - val_loss: 0.0238 - 56ms/epoch - 4ms/step
# Epoch 29/500
# 15/15 - 0s - loss: 0.0121 - val_loss: 0.0238 - 60ms/epoch - 4ms/step
# Epoch 30/500
# 15/15 - 0s - loss: 0.0121 - val_loss: 0.0238 - 59ms/epoch - 4ms/step
# Epoch 31/500
# 15/15 - 0s - loss: 0.0121 - val_loss: 0.0237 - 57ms/epoch - 4ms/step
# Epoch 32/500
# 15/15 - 0s - loss: 0.0121 - val_loss: 0.0237 - 59ms/epoch - 4ms/step
# Epoch 33/500
# 15/15 - 0s - loss: 0.0121 - val_loss: 0.0237 - 58ms/epoch - 4ms/step
# Epoch 34/500
# 15/15 - 0s - loss: 0.0121 - val_loss: 0.0237 - 58ms/epoch - 4ms/step
# Epoch 35/500
# 15/15 - 0s - loss: 0.0121 - val_loss: 0.0237 - 60ms/epoch - 4ms/step
# Epoch 36/500
# 15/15 - 0s - loss: 0.0121 - val_loss: 0.0237 - 58ms/epoch - 4ms/step
# Epoch 37/500
# 15/15 - 0s - loss: 0.0121 - val_loss: 0.0237 - 60ms/epoch - 4ms/step
# Epoch 38/500
# 15/15 - 0s - loss: 0.0121 - val_loss: 0.0237 - 59ms/epoch - 4ms/step
# Epoch 39/500
# 15/15 - 0s - loss: 0.0120 - val_loss: 0.0236 - 58ms/epoch - 4ms/step
# Epoch 40/500
# 15/15 - 0s - loss: 0.0120 - val_loss: 0.0236 - 58ms/epoch - 4ms/step
# Epoch 41/500
# 15/15 - 0s - loss: 0.0120 - val_loss: 0.0236 - 58ms/epoch - 4ms/step
# Epoch 42/500
# 15/15 - 0s - loss: 0.0120 - val_loss: 0.0236 - 57ms/epoch - 4ms/step
# Epoch 43/500
# 15/15 - 0s - loss: 0.0120 - val_loss: 0.0236 - 59ms/epoch - 4ms/step
# Epoch 44/500
# 15/15 - 0s - loss: 0.0120 - val_loss: 0.0236 - 64ms/epoch - 4ms/step
# Epoch 45/500
# 15/15 - 0s - loss: 0.0120 - val_loss: 0.0236 - 63ms/epoch - 4ms/step
# Epoch 46/500
# 15/15 - 0s - loss: 0.0120 - val_loss: 0.0235 - 60ms/epoch - 4ms/step
# Epoch 47/500
# 15/15 - 0s - loss: 0.0120 - val_loss: 0.0235 - 59ms/epoch - 4ms/step
# Epoch 48/500
# 15/15 - 0s - loss: 0.0120 - val_loss: 0.0235 - 56ms/epoch - 4ms/step
# Epoch 49/500
# 15/15 - 0s - loss: 0.0120 - val_loss: 0.0235 - 56ms/epoch - 4ms/step
# Epoch 50/500
# 15/15 - 0s - loss: 0.0120 - val_loss: 0.0235 - 56ms/epoch - 4ms/step
# Epoch 51/500
# 15/15 - 0s - loss: 0.0120 - val_loss: 0.0235 - 61ms/epoch - 4ms/step
# Epoch 52/500
# 15/15 - 0s - loss: 0.0120 - val_loss: 0.0235 - 60ms/epoch - 4ms/step
# Epoch 53/500
# 15/15 - 0s - loss: 0.0120 - val_loss: 0.0234 - 57ms/epoch - 4ms/step
# Epoch 54/500
# 15/15 - 0s - loss: 0.0119 - val_loss: 0.0234 - 62ms/epoch - 4ms/step
# Epoch 55/500
# 15/15 - 0s - loss: 0.0119 - val_loss: 0.0234 - 62ms/epoch - 4ms/step
# Epoch 56/500
# 15/15 - 0s - loss: 0.0119 - val_loss: 0.0234 - 57ms/epoch - 4ms/step
# Epoch 57/500
# 15/15 - 0s - loss: 0.0119 - val_loss: 0.0234 - 59ms/epoch - 4ms/step
# Epoch 58/500
# 15/15 - 0s - loss: 0.0119 - val_loss: 0.0234 - 70ms/epoch - 5ms/step
# Epoch 59/500
# 15/15 - 0s - loss: 0.0119 - val_loss: 0.0233 - 62ms/epoch - 4ms/step
# Epoch 60/500
# 15/15 - 0s - loss: 0.0119 - val_loss: 0.0233 - 58ms/epoch - 4ms/step
# Epoch 61/500
# 15/15 - 0s - loss: 0.0119 - val_loss: 0.0233 - 58ms/epoch - 4ms/step
# Epoch 62/500
# 15/15 - 0s - loss: 0.0119 - val_loss: 0.0233 - 59ms/epoch - 4ms/step
# Epoch 63/500
# 15/15 - 0s - loss: 0.0119 - val_loss: 0.0233 - 58ms/epoch - 4ms/step
# Epoch 64/500
# 15/15 - 0s - loss: 0.0119 - val_loss: 0.0233 - 61ms/epoch - 4ms/step
# Epoch 65/500
# 15/15 - 0s - loss: 0.0119 - val_loss: 0.0232 - 57ms/epoch - 4ms/step
# Epoch 66/500
# 15/15 - 0s - loss: 0.0119 - val_loss: 0.0232 - 61ms/epoch - 4ms/step
# Epoch 67/500
# 15/15 - 0s - loss: 0.0119 - val_loss: 0.0232 - 57ms/epoch - 4ms/step
# Epoch 68/500
# 15/15 - 0s - loss: 0.0118 - val_loss: 0.0232 - 60ms/epoch - 4ms/step
# Epoch 69/500
# 15/15 - 0s - loss: 0.0118 - val_loss: 0.0232 - 58ms/epoch - 4ms/step
# Epoch 70/500
# 15/15 - 0s - loss: 0.0118 - val_loss: 0.0231 - 110ms/epoch - 7ms/step
# Epoch 71/500
# 15/15 - 0s - loss: 0.0118 - val_loss: 0.0231 - 61ms/epoch - 4ms/step
# Epoch 72/500
# 15/15 - 0s - loss: 0.0118 - val_loss: 0.0231 - 58ms/epoch - 4ms/step
# Epoch 73/500
# 15/15 - 0s - loss: 0.0118 - val_loss: 0.0231 - 59ms/epoch - 4ms/step
# Epoch 74/500
# 15/15 - 0s - loss: 0.0118 - val_loss: 0.0231 - 66ms/epoch - 4ms/step
# Epoch 75/500
# 15/15 - 0s - loss: 0.0118 - val_loss: 0.0231 - 64ms/epoch - 4ms/step
# Epoch 76/500
# 15/15 - 0s - loss: 0.0118 - val_loss: 0.0230 - 71ms/epoch - 5ms/step
# Epoch 77/500
# 15/15 - 0s - loss: 0.0118 - val_loss: 0.0230 - 83ms/epoch - 6ms/step
# Epoch 78/500
# 15/15 - 0s - loss: 0.0118 - val_loss: 0.0230 - 61ms/epoch - 4ms/step
# Epoch 79/500
# 15/15 - 0s - loss: 0.0117 - val_loss: 0.0230 - 61ms/epoch - 4ms/step
# Epoch 80/500
# 15/15 - 0s - loss: 0.0117 - val_loss: 0.0230 - 68ms/epoch - 5ms/step
# Epoch 81/500
# 15/15 - 0s - loss: 0.0117 - val_loss: 0.0229 - 67ms/epoch - 4ms/step
# Epoch 82/500
# 15/15 - 0s - loss: 0.0117 - val_loss: 0.0229 - 64ms/epoch - 4ms/step
# Epoch 83/500
# 15/15 - 0s - loss: 0.0117 - val_loss: 0.0229 - 62ms/epoch - 4ms/step
# Epoch 84/500
# 15/15 - 0s - loss: 0.0117 - val_loss: 0.0229 - 62ms/epoch - 4ms/step
# Epoch 85/500
# 15/15 - 0s - loss: 0.0117 - val_loss: 0.0228 - 58ms/epoch - 4ms/step
# Epoch 86/500
# 15/15 - 0s - loss: 0.0117 - val_loss: 0.0228 - 58ms/epoch - 4ms/step
# Epoch 87/500
# 15/15 - 0s - loss: 0.0117 - val_loss: 0.0228 - 70ms/epoch - 5ms/step
# Epoch 88/500
# 15/15 - 0s - loss: 0.0117 - val_loss: 0.0228 - 67ms/epoch - 4ms/step
# Epoch 89/500
# 15/15 - 0s - loss: 0.0117 - val_loss: 0.0228 - 58ms/epoch - 4ms/step
# Epoch 90/500
# 15/15 - 0s - loss: 0.0116 - val_loss: 0.0227 - 55ms/epoch - 4ms/step
# Epoch 91/500
# 15/15 - 0s - loss: 0.0116 - val_loss: 0.0227 - 62ms/epoch - 4ms/step
# Epoch 92/500
# 15/15 - 0s - loss: 0.0116 - val_loss: 0.0227 - 65ms/epoch - 4ms/step
# Epoch 93/500
# 15/15 - 0s - loss: 0.0116 - val_loss: 0.0227 - 78ms/epoch - 5ms/step
# Epoch 94/500
# 15/15 - 0s - loss: 0.0116 - val_loss: 0.0226 - 68ms/epoch - 5ms/step
# Epoch 95/500
# 15/15 - 0s - loss: 0.0116 - val_loss: 0.0226 - 61ms/epoch - 4ms/step
# Epoch 96/500
# 15/15 - 0s - loss: 0.0116 - val_loss: 0.0226 - 63ms/epoch - 4ms/step
# Epoch 97/500
# 15/15 - 0s - loss: 0.0116 - val_loss: 0.0226 - 57ms/epoch - 4ms/step
# Epoch 98/500
# 15/15 - 0s - loss: 0.0116 - val_loss: 0.0225 - 60ms/epoch - 4ms/step
# Epoch 99/500
# 15/15 - 0s - loss: 0.0115 - val_loss: 0.0225 - 59ms/epoch - 4ms/step
# Epoch 100/500
# 15/15 - 0s - loss: 0.0115 - val_loss: 0.0225 - 60ms/epoch - 4ms/step
# Epoch 101/500
# 15/15 - 0s - loss: 0.0115 - val_loss: 0.0225 - 61ms/epoch - 4ms/step
# Epoch 102/500
# 15/15 - 0s - loss: 0.0115 - val_loss: 0.0224 - 63ms/epoch - 4ms/step
# Epoch 103/500
# 15/15 - 0s - loss: 0.0115 - val_loss: 0.0224 - 60ms/epoch - 4ms/step
# Epoch 104/500
# 15/15 - 0s - loss: 0.0115 - val_loss: 0.0224 - 62ms/epoch - 4ms/step
# Epoch 105/500
# 15/15 - 0s - loss: 0.0115 - val_loss: 0.0224 - 68ms/epoch - 5ms/step
# Epoch 106/500
# 15/15 - 0s - loss: 0.0115 - val_loss: 0.0223 - 70ms/epoch - 5ms/step
# Epoch 107/500
# 15/15 - 0s - loss: 0.0115 - val_loss: 0.0223 - 68ms/epoch - 5ms/step
# Epoch 108/500
# 15/15 - 0s - loss: 0.0114 - val_loss: 0.0223 - 65ms/epoch - 4ms/step
# Epoch 109/500
# 15/15 - 0s - loss: 0.0114 - val_loss: 0.0223 - 64ms/epoch - 4ms/step
# Epoch 110/500
# 15/15 - 0s - loss: 0.0114 - val_loss: 0.0222 - 69ms/epoch - 5ms/step
# Epoch 111/500
# 15/15 - 0s - loss: 0.0114 - val_loss: 0.0222 - 65ms/epoch - 4ms/step
# Epoch 112/500
# 15/15 - 0s - loss: 0.0114 - val_loss: 0.0222 - 136ms/epoch - 9ms/step
# Epoch 113/500
# 15/15 - 0s - loss: 0.0114 - val_loss: 0.0222 - 64ms/epoch - 4ms/step
# Epoch 114/500
# 15/15 - 0s - loss: 0.0114 - val_loss: 0.0221 - 63ms/epoch - 4ms/step
# Epoch 115/500
# 15/15 - 0s - loss: 0.0114 - val_loss: 0.0221 - 62ms/epoch - 4ms/step
# Epoch 116/500
# 15/15 - 0s - loss: 0.0113 - val_loss: 0.0221 - 61ms/epoch - 4ms/step
# Epoch 117/500
# 15/15 - 0s - loss: 0.0113 - val_loss: 0.0220 - 60ms/epoch - 4ms/step
# Epoch 118/500
# 15/15 - 0s - loss: 0.0113 - val_loss: 0.0220 - 58ms/epoch - 4ms/step
# Epoch 119/500
# 15/15 - 0s - loss: 0.0113 - val_loss: 0.0220 - 57ms/epoch - 4ms/step
# Epoch 120/500
# 15/15 - 0s - loss: 0.0113 - val_loss: 0.0220 - 58ms/epoch - 4ms/step
# Epoch 121/500
# 15/15 - 0s - loss: 0.0113 - val_loss: 0.0219 - 56ms/epoch - 4ms/step
# Epoch 122/500
# 15/15 - 0s - loss: 0.0113 - val_loss: 0.0219 - 56ms/epoch - 4ms/step
# Epoch 123/500
# 15/15 - 0s - loss: 0.0113 - val_loss: 0.0219 - 58ms/epoch - 4ms/step
# Epoch 124/500
# 15/15 - 0s - loss: 0.0112 - val_loss: 0.0218 - 58ms/epoch - 4ms/step
# Epoch 125/500
# 15/15 - 0s - loss: 0.0112 - val_loss: 0.0218 - 75ms/epoch - 5ms/step
# Epoch 126/500
# 15/15 - 0s - loss: 0.0112 - val_loss: 0.0218 - 56ms/epoch - 4ms/step
# Epoch 127/500
# 15/15 - 0s - loss: 0.0112 - val_loss: 0.0218 - 59ms/epoch - 4ms/step
# Epoch 128/500
# 15/15 - 0s - loss: 0.0112 - val_loss: 0.0217 - 58ms/epoch - 4ms/step
# Epoch 129/500
# 15/15 - 0s - loss: 0.0112 - val_loss: 0.0217 - 62ms/epoch - 4ms/step
# Epoch 130/500
# 15/15 - 0s - loss: 0.0112 - val_loss: 0.0217 - 55ms/epoch - 4ms/step
# Epoch 131/500
# 15/15 - 0s - loss: 0.0111 - val_loss: 0.0216 - 56ms/epoch - 4ms/step
# Epoch 132/500
# 15/15 - 0s - loss: 0.0111 - val_loss: 0.0216 - 60ms/epoch - 4ms/step
# Epoch 133/500
# 15/15 - 0s - loss: 0.0111 - val_loss: 0.0216 - 59ms/epoch - 4ms/step
# Epoch 134/500
# 15/15 - 0s - loss: 0.0111 - val_loss: 0.0215 - 58ms/epoch - 4ms/step
# Epoch 135/500
# 15/15 - 0s - loss: 0.0111 - val_loss: 0.0215 - 59ms/epoch - 4ms/step
# Epoch 136/500
# 15/15 - 0s - loss: 0.0111 - val_loss: 0.0215 - 55ms/epoch - 4ms/step
# Epoch 137/500
# 15/15 - 0s - loss: 0.0111 - val_loss: 0.0214 - 56ms/epoch - 4ms/step
# Epoch 138/500
# 15/15 - 0s - loss: 0.0110 - val_loss: 0.0214 - 56ms/epoch - 4ms/step
# Epoch 139/500
# 15/15 - 0s - loss: 0.0110 - val_loss: 0.0214 - 56ms/epoch - 4ms/step
# Epoch 140/500
# 15/15 - 0s - loss: 0.0110 - val_loss: 0.0213 - 57ms/epoch - 4ms/step
# Epoch 141/500
# 15/15 - 0s - loss: 0.0110 - val_loss: 0.0213 - 57ms/epoch - 4ms/step
# Epoch 142/500
# 15/15 - 0s - loss: 0.0110 - val_loss: 0.0213 - 56ms/epoch - 4ms/step
# Epoch 143/500
# 15/15 - 0s - loss: 0.0110 - val_loss: 0.0212 - 55ms/epoch - 4ms/step
# Epoch 144/500
# 15/15 - 0s - loss: 0.0110 - val_loss: 0.0212 - 55ms/epoch - 4ms/step
# Epoch 145/500
# 15/15 - 0s - loss: 0.0109 - val_loss: 0.0212 - 54ms/epoch - 4ms/step
# Epoch 146/500
# 15/15 - 0s - loss: 0.0109 - val_loss: 0.0211 - 56ms/epoch - 4ms/step
# Epoch 147/500
# 15/15 - 0s - loss: 0.0109 - val_loss: 0.0211 - 60ms/epoch - 4ms/step
# Epoch 148/500
# 15/15 - 0s - loss: 0.0109 - val_loss: 0.0211 - 56ms/epoch - 4ms/step
# Epoch 149/500
# 15/15 - 0s - loss: 0.0109 - val_loss: 0.0210 - 55ms/epoch - 4ms/step
# Epoch 150/500
# 15/15 - 0s - loss: 0.0109 - val_loss: 0.0210 - 55ms/epoch - 4ms/step
# Epoch 151/500
# 15/15 - 0s - loss: 0.0108 - val_loss: 0.0209 - 55ms/epoch - 4ms/step
# Epoch 152/500
# 15/15 - 0s - loss: 0.0108 - val_loss: 0.0209 - 55ms/epoch - 4ms/step
# Epoch 153/500
# 15/15 - 0s - loss: 0.0108 - val_loss: 0.0209 - 56ms/epoch - 4ms/step
# Epoch 154/500
# 15/15 - 0s - loss: 0.0108 - val_loss: 0.0208 - 54ms/epoch - 4ms/step
# Epoch 155/500
# 15/15 - 0s - loss: 0.0108 - val_loss: 0.0208 - 54ms/epoch - 4ms/step
# Epoch 156/500
# 15/15 - 0s - loss: 0.0108 - val_loss: 0.0208 - 56ms/epoch - 4ms/step
# Epoch 157/500
# 15/15 - 0s - loss: 0.0107 - val_loss: 0.0207 - 56ms/epoch - 4ms/step
# Epoch 158/500
# 15/15 - 0s - loss: 0.0107 - val_loss: 0.0207 - 53ms/epoch - 4ms/step
# Epoch 159/500
# 15/15 - 0s - loss: 0.0107 - val_loss: 0.0206 - 54ms/epoch - 4ms/step
# Epoch 160/500
# 15/15 - 0s - loss: 0.0107 - val_loss: 0.0206 - 56ms/epoch - 4ms/step
# Epoch 161/500
# 15/15 - 0s - loss: 0.0107 - val_loss: 0.0206 - 55ms/epoch - 4ms/step
# Epoch 162/500
# 15/15 - 0s - loss: 0.0107 - val_loss: 0.0205 - 55ms/epoch - 4ms/step
# Epoch 163/500
# 15/15 - 0s - loss: 0.0106 - val_loss: 0.0205 - 56ms/epoch - 4ms/step
# Epoch 164/500
# 15/15 - 0s - loss: 0.0106 - val_loss: 0.0205 - 54ms/epoch - 4ms/step
# Epoch 165/500
# 15/15 - 0s - loss: 0.0106 - val_loss: 0.0204 - 55ms/epoch - 4ms/step
# Epoch 166/500
# 15/15 - 0s - loss: 0.0106 - val_loss: 0.0204 - 55ms/epoch - 4ms/step
# Epoch 167/500
# 15/15 - 0s - loss: 0.0106 - val_loss: 0.0203 - 55ms/epoch - 4ms/step
# Epoch 168/500
# 15/15 - 0s - loss: 0.0106 - val_loss: 0.0203 - 56ms/epoch - 4ms/step
# Epoch 169/500
# 15/15 - 0s - loss: 0.0105 - val_loss: 0.0202 - 55ms/epoch - 4ms/step
# Epoch 170/500
# 15/15 - 0s - loss: 0.0105 - val_loss: 0.0202 - 55ms/epoch - 4ms/step
# Epoch 171/500
# 15/15 - 0s - loss: 0.0105 - val_loss: 0.0202 - 99ms/epoch - 7ms/step
# Epoch 172/500
# 15/15 - 0s - loss: 0.0105 - val_loss: 0.0201 - 54ms/epoch - 4ms/step
# Epoch 173/500
# 15/15 - 0s - loss: 0.0105 - val_loss: 0.0201 - 57ms/epoch - 4ms/step
# Epoch 174/500
# 15/15 - 0s - loss: 0.0104 - val_loss: 0.0200 - 56ms/epoch - 4ms/step
# Epoch 175/500
# 15/15 - 0s - loss: 0.0104 - val_loss: 0.0200 - 56ms/epoch - 4ms/step
# Epoch 176/500
# 15/15 - 0s - loss: 0.0104 - val_loss: 0.0200 - 55ms/epoch - 4ms/step
# Epoch 177/500
# 15/15 - 0s - loss: 0.0104 - val_loss: 0.0199 - 54ms/epoch - 4ms/step
# Epoch 178/500
# 15/15 - 0s - loss: 0.0104 - val_loss: 0.0199 - 53ms/epoch - 4ms/step
# Epoch 179/500
# 15/15 - 0s - loss: 0.0103 - val_loss: 0.0198 - 66ms/epoch - 4ms/step
# Epoch 180/500
# 15/15 - 0s - loss: 0.0103 - val_loss: 0.0198 - 68ms/epoch - 5ms/step
# Epoch 181/500
# 15/15 - 0s - loss: 0.0103 - val_loss: 0.0197 - 70ms/epoch - 5ms/step
# Epoch 182/500
# 15/15 - 0s - loss: 0.0103 - val_loss: 0.0197 - 61ms/epoch - 4ms/step
# Epoch 183/500
# 15/15 - 0s - loss: 0.0103 - val_loss: 0.0196 - 60ms/epoch - 4ms/step
# Epoch 184/500
# 15/15 - 0s - loss: 0.0102 - val_loss: 0.0196 - 63ms/epoch - 4ms/step
# Epoch 185/500
# 15/15 - 0s - loss: 0.0102 - val_loss: 0.0196 - 56ms/epoch - 4ms/step
# Epoch 186/500
# 15/15 - 0s - loss: 0.0102 - val_loss: 0.0195 - 55ms/epoch - 4ms/step
# Epoch 187/500
# 15/15 - 0s - loss: 0.0102 - val_loss: 0.0195 - 54ms/epoch - 4ms/step
# Epoch 188/500
# 15/15 - 0s - loss: 0.0102 - val_loss: 0.0194 - 61ms/epoch - 4ms/step
# Epoch 189/500
# 15/15 - 0s - loss: 0.0101 - val_loss: 0.0194 - 60ms/epoch - 4ms/step
# Epoch 190/500
# 15/15 - 0s - loss: 0.0101 - val_loss: 0.0193 - 57ms/epoch - 4ms/step
# Epoch 191/500
# 15/15 - 0s - loss: 0.0101 - val_loss: 0.0193 - 57ms/epoch - 4ms/step
# Epoch 192/500
# 15/15 - 0s - loss: 0.0101 - val_loss: 0.0192 - 56ms/epoch - 4ms/step
# Epoch 193/500
# 15/15 - 0s - loss: 0.0101 - val_loss: 0.0192 - 57ms/epoch - 4ms/step
# Epoch 194/500
# 15/15 - 0s - loss: 0.0100 - val_loss: 0.0191 - 56ms/epoch - 4ms/step
# Epoch 195/500
# 15/15 - 0s - loss: 0.0100 - val_loss: 0.0191 - 55ms/epoch - 4ms/step
# Epoch 196/500
# 15/15 - 0s - loss: 0.0100 - val_loss: 0.0190 - 55ms/epoch - 4ms/step
# Epoch 197/500
# 15/15 - 0s - loss: 0.0100 - val_loss: 0.0190 - 55ms/epoch - 4ms/step
# Epoch 198/500
# 15/15 - 0s - loss: 0.0100 - val_loss: 0.0189 - 54ms/epoch - 4ms/step
# Epoch 199/500
# 15/15 - 0s - loss: 0.0099 - val_loss: 0.0189 - 56ms/epoch - 4ms/step
# Epoch 200/500
# 15/15 - 0s - loss: 0.0099 - val_loss: 0.0189 - 56ms/epoch - 4ms/step
# Epoch 201/500
# 15/15 - 0s - loss: 0.0099 - val_loss: 0.0188 - 57ms/epoch - 4ms/step
# Epoch 202/500
# 15/15 - 0s - loss: 0.0099 - val_loss: 0.0188 - 56ms/epoch - 4ms/step
# Epoch 203/500
# 15/15 - 0s - loss: 0.0099 - val_loss: 0.0187 - 55ms/epoch - 4ms/step
# Epoch 204/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0187 - 56ms/epoch - 4ms/step
# Epoch 205/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0186 - 54ms/epoch - 4ms/step
# Epoch 206/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0185 - 56ms/epoch - 4ms/step
# Epoch 207/500
# 15/15 - 0s - loss: 0.0098 - val_loss: 0.0185 - 55ms/epoch - 4ms/step
# Epoch 208/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0184 - 55ms/epoch - 4ms/step
# Epoch 209/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0184 - 56ms/epoch - 4ms/step
# Epoch 210/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0183 - 57ms/epoch - 4ms/step
# Epoch 211/500
# 15/15 - 0s - loss: 0.0097 - val_loss: 0.0183 - 55ms/epoch - 4ms/step
# Epoch 212/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0182 - 56ms/epoch - 4ms/step
# Epoch 213/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0182 - 57ms/epoch - 4ms/step
# Epoch 214/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0181 - 54ms/epoch - 4ms/step
# Epoch 215/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0181 - 57ms/epoch - 4ms/step
# Epoch 216/500
# 15/15 - 0s - loss: 0.0096 - val_loss: 0.0180 - 56ms/epoch - 4ms/step
# Epoch 217/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0180 - 56ms/epoch - 4ms/step
# Epoch 218/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0179 - 56ms/epoch - 4ms/step
# Epoch 219/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0179 - 58ms/epoch - 4ms/step
# Epoch 220/500
# 15/15 - 0s - loss: 0.0095 - val_loss: 0.0178 - 57ms/epoch - 4ms/step
# Epoch 221/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0178 - 56ms/epoch - 4ms/step
# Epoch 222/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0177 - 55ms/epoch - 4ms/step
# Epoch 223/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0176 - 59ms/epoch - 4ms/step
# Epoch 224/500
# 15/15 - 0s - loss: 0.0094 - val_loss: 0.0176 - 57ms/epoch - 4ms/step
# Epoch 225/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0175 - 57ms/epoch - 4ms/step
# Epoch 226/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0175 - 60ms/epoch - 4ms/step
# Epoch 227/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0174 - 58ms/epoch - 4ms/step
# Epoch 228/500
# 15/15 - 0s - loss: 0.0093 - val_loss: 0.0174 - 59ms/epoch - 4ms/step
# Epoch 229/500
# 15/15 - 0s - loss: 0.0092 - val_loss: 0.0173 - 57ms/epoch - 4ms/step
# Epoch 230/500
# 15/15 - 0s - loss: 0.0092 - val_loss: 0.0172 - 58ms/epoch - 4ms/step
# Epoch 231/500
# 15/15 - 0s - loss: 0.0092 - val_loss: 0.0172 - 57ms/epoch - 4ms/step
# Epoch 232/500
# 15/15 - 0s - loss: 0.0092 - val_loss: 0.0171 - 56ms/epoch - 4ms/step
# Epoch 233/500
# 15/15 - 0s - loss: 0.0091 - val_loss: 0.0171 - 56ms/epoch - 4ms/step
# Epoch 234/500
# 15/15 - 0s - loss: 0.0091 - val_loss: 0.0170 - 55ms/epoch - 4ms/step
# Epoch 235/500
# 15/15 - 0s - loss: 0.0091 - val_loss: 0.0170 - 56ms/epoch - 4ms/step
# Epoch 236/500
# 15/15 - 0s - loss: 0.0091 - val_loss: 0.0169 - 103ms/epoch - 7ms/step
# Epoch 237/500
# 15/15 - 0s - loss: 0.0090 - val_loss: 0.0168 - 56ms/epoch - 4ms/step
# Epoch 238/500
# 15/15 - 0s - loss: 0.0090 - val_loss: 0.0168 - 58ms/epoch - 4ms/step
# Epoch 239/500
# 15/15 - 0s - loss: 0.0090 - val_loss: 0.0167 - 55ms/epoch - 4ms/step
# Epoch 240/500
# 15/15 - 0s - loss: 0.0090 - val_loss: 0.0167 - 67ms/epoch - 4ms/step
# Epoch 241/500
# 15/15 - 0s - loss: 0.0089 - val_loss: 0.0166 - 59ms/epoch - 4ms/step
# Epoch 242/500
# 15/15 - 0s - loss: 0.0089 - val_loss: 0.0165 - 60ms/epoch - 4ms/step
# Epoch 243/500
# 15/15 - 0s - loss: 0.0089 - val_loss: 0.0165 - 55ms/epoch - 4ms/step
# Epoch 244/500
# 15/15 - 0s - loss: 0.0089 - val_loss: 0.0164 - 55ms/epoch - 4ms/step
# Epoch 245/500
# 15/15 - 0s - loss: 0.0088 - val_loss: 0.0164 - 55ms/epoch - 4ms/step
# Epoch 246/500
# 15/15 - 0s - loss: 0.0088 - val_loss: 0.0163 - 54ms/epoch - 4ms/step
# Epoch 247/500
# 15/15 - 0s - loss: 0.0088 - val_loss: 0.0162 - 55ms/epoch - 4ms/step
# Epoch 248/500
# 15/15 - 0s - loss: 0.0087 - val_loss: 0.0162 - 55ms/epoch - 4ms/step
# Epoch 249/500
# 15/15 - 0s - loss: 0.0087 - val_loss: 0.0161 - 54ms/epoch - 4ms/step
# Epoch 250/500
# 15/15 - 0s - loss: 0.0087 - val_loss: 0.0160 - 53ms/epoch - 4ms/step
# Epoch 251/500
# 15/15 - 0s - loss: 0.0087 - val_loss: 0.0160 - 55ms/epoch - 4ms/step
# Epoch 252/500
# 15/15 - 0s - loss: 0.0086 - val_loss: 0.0159 - 55ms/epoch - 4ms/step
# Epoch 253/500
# 15/15 - 0s - loss: 0.0086 - val_loss: 0.0159 - 56ms/epoch - 4ms/step
# Epoch 254/500
# 15/15 - 0s - loss: 0.0086 - val_loss: 0.0158 - 54ms/epoch - 4ms/step
# Epoch 255/500
# 15/15 - 0s - loss: 0.0086 - val_loss: 0.0157 - 54ms/epoch - 4ms/step
# Epoch 256/500
# 15/15 - 0s - loss: 0.0085 - val_loss: 0.0157 - 55ms/epoch - 4ms/step
# Epoch 257/500
# 15/15 - 0s - loss: 0.0085 - val_loss: 0.0156 - 54ms/epoch - 4ms/step
# Epoch 258/500
# 15/15 - 0s - loss: 0.0085 - val_loss: 0.0155 - 54ms/epoch - 4ms/step
# Epoch 259/500
# 15/15 - 0s - loss: 0.0084 - val_loss: 0.0155 - 55ms/epoch - 4ms/step
# Epoch 260/500
# 15/15 - 0s - loss: 0.0084 - val_loss: 0.0154 - 55ms/epoch - 4ms/step
# Epoch 261/500
# 15/15 - 0s - loss: 0.0084 - val_loss: 0.0153 - 54ms/epoch - 4ms/step
# Epoch 262/500
# 15/15 - 0s - loss: 0.0084 - val_loss: 0.0153 - 60ms/epoch - 4ms/step
# Epoch 263/500
# 15/15 - 0s - loss: 0.0083 - val_loss: 0.0152 - 54ms/epoch - 4ms/step
# Epoch 264/500
# 15/15 - 0s - loss: 0.0083 - val_loss: 0.0151 - 55ms/epoch - 4ms/step
# Epoch 265/500
# 15/15 - 0s - loss: 0.0083 - val_loss: 0.0151 - 54ms/epoch - 4ms/step
# Epoch 266/500
# 15/15 - 0s - loss: 0.0082 - val_loss: 0.0150 - 57ms/epoch - 4ms/step
# Epoch 267/500
# 15/15 - 0s - loss: 0.0082 - val_loss: 0.0149 - 55ms/epoch - 4ms/step
# Epoch 268/500
# 15/15 - 0s - loss: 0.0082 - val_loss: 0.0149 - 54ms/epoch - 4ms/step
# Epoch 269/500
# 15/15 - 0s - loss: 0.0082 - val_loss: 0.0148 - 54ms/epoch - 4ms/step
# Epoch 270/500
# 15/15 - 0s - loss: 0.0081 - val_loss: 0.0147 - 58ms/epoch - 4ms/step
# Epoch 271/500
# 15/15 - 0s - loss: 0.0081 - val_loss: 0.0147 - 54ms/epoch - 4ms/step
# Epoch 272/500
# 15/15 - 0s - loss: 0.0081 - val_loss: 0.0146 - 55ms/epoch - 4ms/step
# Epoch 273/500
# 15/15 - 0s - loss: 0.0080 - val_loss: 0.0145 - 53ms/epoch - 4ms/step
# Epoch 274/500
# 15/15 - 0s - loss: 0.0080 - val_loss: 0.0145 - 58ms/epoch - 4ms/step
# Epoch 275/500
# 15/15 - 0s - loss: 0.0080 - val_loss: 0.0144 - 56ms/epoch - 4ms/step
# Epoch 276/500
# 15/15 - 0s - loss: 0.0080 - val_loss: 0.0143 - 57ms/epoch - 4ms/step
# Epoch 277/500
# 15/15 - 0s - loss: 0.0079 - val_loss: 0.0143 - 55ms/epoch - 4ms/step
# Epoch 278/500
# 15/15 - 0s - loss: 0.0079 - val_loss: 0.0142 - 56ms/epoch - 4ms/step
# Epoch 279/500
# 15/15 - 0s - loss: 0.0079 - val_loss: 0.0141 - 56ms/epoch - 4ms/step
# Epoch 280/500
# 15/15 - 0s - loss: 0.0078 - val_loss: 0.0141 - 54ms/epoch - 4ms/step
# Epoch 281/500
# 15/15 - 0s - loss: 0.0078 - val_loss: 0.0140 - 52ms/epoch - 3ms/step
# Epoch 282/500
# 15/15 - 0s - loss: 0.0078 - val_loss: 0.0139 - 54ms/epoch - 4ms/step
# Epoch 283/500
# 15/15 - 0s - loss: 0.0078 - val_loss: 0.0138 - 54ms/epoch - 4ms/step
# Epoch 284/500
# 15/15 - 0s - loss: 0.0077 - val_loss: 0.0138 - 55ms/epoch - 4ms/step
# Epoch 285/500
# 15/15 - 0s - loss: 0.0077 - val_loss: 0.0137 - 52ms/epoch - 3ms/step
# Epoch 286/500
# 15/15 - 0s - loss: 0.0077 - val_loss: 0.0136 - 54ms/epoch - 4ms/step
# Epoch 287/500
# 15/15 - 0s - loss: 0.0076 - val_loss: 0.0136 - 104ms/epoch - 7ms/step
# Epoch 288/500
# 15/15 - 0s - loss: 0.0076 - val_loss: 0.0135 - 54ms/epoch - 4ms/step
# Epoch 289/500
# 15/15 - 0s - loss: 0.0076 - val_loss: 0.0134 - 56ms/epoch - 4ms/step
# Epoch 290/500
# 15/15 - 0s - loss: 0.0075 - val_loss: 0.0134 - 54ms/epoch - 4ms/step
# Epoch 291/500
# 15/15 - 0s - loss: 0.0075 - val_loss: 0.0133 - 55ms/epoch - 4ms/step
# Epoch 292/500
# 15/15 - 0s - loss: 0.0075 - val_loss: 0.0132 - 54ms/epoch - 4ms/step
# Epoch 293/500
# 15/15 - 0s - loss: 0.0075 - val_loss: 0.0131 - 54ms/epoch - 4ms/step
# Epoch 294/500
# 15/15 - 0s - loss: 0.0074 - val_loss: 0.0131 - 55ms/epoch - 4ms/step
# Epoch 295/500
# 15/15 - 0s - loss: 0.0074 - val_loss: 0.0130 - 52ms/epoch - 3ms/step
# Epoch 296/500
# 15/15 - 0s - loss: 0.0074 - val_loss: 0.0129 - 57ms/epoch - 4ms/step
# Epoch 297/500
# 15/15 - 0s - loss: 0.0073 - val_loss: 0.0129 - 54ms/epoch - 4ms/step
# Epoch 298/500
# 15/15 - 0s - loss: 0.0073 - val_loss: 0.0128 - 55ms/epoch - 4ms/step
# Epoch 299/500
# 15/15 - 0s - loss: 0.0073 - val_loss: 0.0127 - 59ms/epoch - 4ms/step
# Epoch 300/500
# 15/15 - 0s - loss: 0.0072 - val_loss: 0.0126 - 53ms/epoch - 4ms/step
# Epoch 301/500
# 15/15 - 0s - loss: 0.0072 - val_loss: 0.0126 - 56ms/epoch - 4ms/step
# Epoch 302/500
# 15/15 - 0s - loss: 0.0072 - val_loss: 0.0125 - 54ms/epoch - 4ms/step
# Epoch 303/500
# 15/15 - 0s - loss: 0.0072 - val_loss: 0.0124 - 56ms/epoch - 4ms/step
# Epoch 304/500
# 15/15 - 0s - loss: 0.0071 - val_loss: 0.0124 - 55ms/epoch - 4ms/step
# Epoch 305/500
# 15/15 - 0s - loss: 0.0071 - val_loss: 0.0123 - 56ms/epoch - 4ms/step
# Epoch 306/500
# 15/15 - 0s - loss: 0.0071 - val_loss: 0.0122 - 54ms/epoch - 4ms/step
# Epoch 307/500
# 15/15 - 0s - loss: 0.0070 - val_loss: 0.0121 - 56ms/epoch - 4ms/step
# Epoch 308/500
# 15/15 - 0s - loss: 0.0070 - val_loss: 0.0121 - 54ms/epoch - 4ms/step
# Epoch 309/500
# 15/15 - 0s - loss: 0.0070 - val_loss: 0.0120 - 56ms/epoch - 4ms/step
# Epoch 310/500
# 15/15 - 0s - loss: 0.0070 - val_loss: 0.0119 - 54ms/epoch - 4ms/step
# Epoch 311/500
# 15/15 - 0s - loss: 0.0069 - val_loss: 0.0119 - 55ms/epoch - 4ms/step
# Epoch 312/500
# 15/15 - 0s - loss: 0.0069 - val_loss: 0.0118 - 56ms/epoch - 4ms/step
# Epoch 313/500
# 15/15 - 0s - loss: 0.0069 - val_loss: 0.0117 - 55ms/epoch - 4ms/step
# Epoch 314/500
# 15/15 - 0s - loss: 0.0068 - val_loss: 0.0117 - 56ms/epoch - 4ms/step
# Epoch 315/500
# 15/15 - 0s - loss: 0.0068 - val_loss: 0.0116 - 56ms/epoch - 4ms/step
# Epoch 316/500
# 15/15 - 0s - loss: 0.0068 - val_loss: 0.0115 - 54ms/epoch - 4ms/step
# Epoch 317/500
# 15/15 - 0s - loss: 0.0067 - val_loss: 0.0114 - 54ms/epoch - 4ms/step
# Epoch 318/500
# 15/15 - 0s - loss: 0.0067 - val_loss: 0.0114 - 53ms/epoch - 4ms/step
# Epoch 319/500
# 15/15 - 0s - loss: 0.0067 - val_loss: 0.0113 - 53ms/epoch - 4ms/step
# Epoch 320/500
# 15/15 - 0s - loss: 0.0067 - val_loss: 0.0112 - 52ms/epoch - 3ms/step
# Epoch 321/500
# 15/15 - 0s - loss: 0.0066 - val_loss: 0.0112 - 53ms/epoch - 4ms/step
# Epoch 322/500
# 15/15 - 0s - loss: 0.0066 - val_loss: 0.0111 - 53ms/epoch - 4ms/step
# Epoch 323/500
# 15/15 - 0s - loss: 0.0066 - val_loss: 0.0110 - 54ms/epoch - 4ms/step
# Epoch 324/500
# 15/15 - 0s - loss: 0.0065 - val_loss: 0.0109 - 52ms/epoch - 3ms/step
# Epoch 325/500
# 15/15 - 0s - loss: 0.0065 - val_loss: 0.0109 - 54ms/epoch - 4ms/step
# Epoch 326/500
# 15/15 - 0s - loss: 0.0065 - val_loss: 0.0108 - 53ms/epoch - 4ms/step
# Epoch 327/500
# 15/15 - 0s - loss: 0.0065 - val_loss: 0.0107 - 54ms/epoch - 4ms/step
# Epoch 328/500
# 15/15 - 0s - loss: 0.0064 - val_loss: 0.0107 - 53ms/epoch - 4ms/step
# Epoch 329/500
# 15/15 - 0s - loss: 0.0064 - val_loss: 0.0106 - 62ms/epoch - 4ms/step
# Epoch 330/500
# 15/15 - 0s - loss: 0.0064 - val_loss: 0.0105 - 57ms/epoch - 4ms/step
# Epoch 331/500
# 15/15 - 0s - loss: 0.0064 - val_loss: 0.0105 - 54ms/epoch - 4ms/step
# Epoch 332/500
# 15/15 - 0s - loss: 0.0063 - val_loss: 0.0104 - 55ms/epoch - 4ms/step
# Epoch 333/500
# 15/15 - 0s - loss: 0.0063 - val_loss: 0.0103 - 54ms/epoch - 4ms/step
# Epoch 334/500
# 15/15 - 0s - loss: 0.0063 - val_loss: 0.0103 - 55ms/epoch - 4ms/step
# Epoch 335/500
# 15/15 - 0s - loss: 0.0062 - val_loss: 0.0102 - 54ms/epoch - 4ms/step
# Epoch 336/500
# 15/15 - 0s - loss: 0.0062 - val_loss: 0.0101 - 55ms/epoch - 4ms/step
# Epoch 337/500
# 15/15 - 0s - loss: 0.0062 - val_loss: 0.0101 - 54ms/epoch - 4ms/step
# Epoch 338/500
# 15/15 - 0s - loss: 0.0062 - val_loss: 0.0100 - 56ms/epoch - 4ms/step
# Epoch 339/500
# 15/15 - 0s - loss: 0.0061 - val_loss: 0.0099 - 54ms/epoch - 4ms/step
# Epoch 340/500
# 15/15 - 0s - loss: 0.0061 - val_loss: 0.0099 - 55ms/epoch - 4ms/step
# Epoch 341/500
# 15/15 - 0s - loss: 0.0061 - val_loss: 0.0098 - 55ms/epoch - 4ms/step
# Epoch 342/500
# 15/15 - 0s - loss: 0.0061 - val_loss: 0.0097 - 54ms/epoch - 4ms/step
# Epoch 343/500
# 15/15 - 0s - loss: 0.0060 - val_loss: 0.0097 - 56ms/epoch - 4ms/step
# Epoch 344/500
# 15/15 - 0s - loss: 0.0060 - val_loss: 0.0096 - 99ms/epoch - 7ms/step
# Epoch 345/500
# 15/15 - 0s - loss: 0.0060 - val_loss: 0.0095 - 55ms/epoch - 4ms/step
# Epoch 346/500
# 15/15 - 0s - loss: 0.0060 - val_loss: 0.0095 - 55ms/epoch - 4ms/step
# Epoch 347/500
# 15/15 - 0s - loss: 0.0059 - val_loss: 0.0094 - 53ms/epoch - 4ms/step
# Epoch 348/500
# 15/15 - 0s - loss: 0.0059 - val_loss: 0.0093 - 55ms/epoch - 4ms/step
# Epoch 349/500
# 15/15 - 0s - loss: 0.0059 - val_loss: 0.0093 - 54ms/epoch - 4ms/step
# Epoch 350/500
# 15/15 - 0s - loss: 0.0059 - val_loss: 0.0092 - 54ms/epoch - 4ms/step
# Epoch 351/500
# 15/15 - 0s - loss: 0.0058 - val_loss: 0.0092 - 54ms/epoch - 4ms/step
# Epoch 352/500
# 15/15 - 0s - loss: 0.0058 - val_loss: 0.0091 - 54ms/epoch - 4ms/step
# Epoch 353/500
# 15/15 - 0s - loss: 0.0058 - val_loss: 0.0090 - 53ms/epoch - 4ms/step
# Epoch 354/500
# 15/15 - 0s - loss: 0.0058 - val_loss: 0.0090 - 54ms/epoch - 4ms/step
# Epoch 355/500
# 15/15 - 0s - loss: 0.0057 - val_loss: 0.0089 - 53ms/epoch - 4ms/step
# Epoch 356/500
# 15/15 - 0s - loss: 0.0057 - val_loss: 0.0089 - 53ms/epoch - 4ms/step
# Epoch 357/500
# 15/15 - 0s - loss: 0.0057 - val_loss: 0.0088 - 54ms/epoch - 4ms/step
# Epoch 358/500
# 15/15 - 0s - loss: 0.0057 - val_loss: 0.0087 - 55ms/epoch - 4ms/step
# Epoch 359/500
# 15/15 - 0s - loss: 0.0056 - val_loss: 0.0087 - 54ms/epoch - 4ms/step
# Epoch 360/500
# 15/15 - 0s - loss: 0.0056 - val_loss: 0.0086 - 54ms/epoch - 4ms/step
# Epoch 361/500
# 15/15 - 0s - loss: 0.0056 - val_loss: 0.0086 - 54ms/epoch - 4ms/step
# Epoch 362/500
# 15/15 - 0s - loss: 0.0056 - val_loss: 0.0085 - 54ms/epoch - 4ms/step
# Epoch 363/500
# 15/15 - 0s - loss: 0.0056 - val_loss: 0.0085 - 55ms/epoch - 4ms/step
# Epoch 364/500
# 15/15 - 0s - loss: 0.0055 - val_loss: 0.0084 - 53ms/epoch - 4ms/step
# Epoch 365/500
# 15/15 - 0s - loss: 0.0055 - val_loss: 0.0083 - 53ms/epoch - 4ms/step
# Epoch 366/500
# 15/15 - 0s - loss: 0.0055 - val_loss: 0.0083 - 54ms/epoch - 4ms/step
# Epoch 367/500
# 15/15 - 0s - loss: 0.0055 - val_loss: 0.0082 - 54ms/epoch - 4ms/step
# Epoch 368/500
# 15/15 - 0s - loss: 0.0055 - val_loss: 0.0082 - 54ms/epoch - 4ms/step
# Epoch 369/500
# 15/15 - 0s - loss: 0.0054 - val_loss: 0.0081 - 62ms/epoch - 4ms/step
# Epoch 370/500
# 15/15 - 0s - loss: 0.0054 - val_loss: 0.0081 - 59ms/epoch - 4ms/step
# Epoch 371/500
# 15/15 - 0s - loss: 0.0054 - val_loss: 0.0080 - 62ms/epoch - 4ms/step
# Epoch 372/500
# 15/15 - 0s - loss: 0.0054 - val_loss: 0.0080 - 55ms/epoch - 4ms/step
# Epoch 373/500
# 15/15 - 0s - loss: 0.0054 - val_loss: 0.0079 - 55ms/epoch - 4ms/step
# Epoch 374/500
# 15/15 - 0s - loss: 0.0053 - val_loss: 0.0079 - 59ms/epoch - 4ms/step
# Epoch 375/500
# 15/15 - 0s - loss: 0.0053 - val_loss: 0.0078 - 57ms/epoch - 4ms/step
# Epoch 376/500
# 15/15 - 0s - loss: 0.0053 - val_loss: 0.0078 - 60ms/epoch - 4ms/step
# Epoch 377/500
# 15/15 - 0s - loss: 0.0053 - val_loss: 0.0077 - 57ms/epoch - 4ms/step
# Epoch 378/500
# 15/15 - 0s - loss: 0.0053 - val_loss: 0.0077 - 56ms/epoch - 4ms/step
# Epoch 379/500
# 15/15 - 0s - loss: 0.0052 - val_loss: 0.0076 - 55ms/epoch - 4ms/step
# Epoch 380/500
# 15/15 - 0s - loss: 0.0052 - val_loss: 0.0076 - 54ms/epoch - 4ms/step
# Epoch 381/500
# 15/15 - 0s - loss: 0.0052 - val_loss: 0.0075 - 54ms/epoch - 4ms/step
# Epoch 382/500
# 15/15 - 0s - loss: 0.0052 - val_loss: 0.0075 - 57ms/epoch - 4ms/step
# Epoch 383/500
# 15/15 - 0s - loss: 0.0052 - val_loss: 0.0074 - 57ms/epoch - 4ms/step
# Epoch 384/500
# 15/15 - 0s - loss: 0.0051 - val_loss: 0.0074 - 55ms/epoch - 4ms/step
# Epoch 385/500
# 15/15 - 0s - loss: 0.0051 - val_loss: 0.0073 - 55ms/epoch - 4ms/step
# Epoch 386/500
# 15/15 - 0s - loss: 0.0051 - val_loss: 0.0073 - 55ms/epoch - 4ms/step
# Epoch 387/500
# 15/15 - 0s - loss: 0.0051 - val_loss: 0.0073 - 56ms/epoch - 4ms/step
# Epoch 388/500
# 15/15 - 0s - loss: 0.0051 - val_loss: 0.0072 - 54ms/epoch - 4ms/step
# Epoch 389/500
# 15/15 - 0s - loss: 0.0051 - val_loss: 0.0072 - 58ms/epoch - 4ms/step
# Epoch 390/500
# 15/15 - 0s - loss: 0.0050 - val_loss: 0.0071 - 56ms/epoch - 4ms/step
# Epoch 391/500
# 15/15 - 0s - loss: 0.0050 - val_loss: 0.0071 - 54ms/epoch - 4ms/step
# Epoch 392/500
# 15/15 - 0s - loss: 0.0050 - val_loss: 0.0070 - 55ms/epoch - 4ms/step
# Epoch 393/500
# 15/15 - 0s - loss: 0.0050 - val_loss: 0.0070 - 55ms/epoch - 4ms/step
# Epoch 394/500
# 15/15 - 0s - loss: 0.0050 - val_loss: 0.0070 - 57ms/epoch - 4ms/step
# Epoch 395/500
# 15/15 - 0s - loss: 0.0050 - val_loss: 0.0069 - 58ms/epoch - 4ms/step
# Epoch 396/500
# 15/15 - 0s - loss: 0.0049 - val_loss: 0.0069 - 56ms/epoch - 4ms/step
# Epoch 397/500
# 15/15 - 0s - loss: 0.0049 - val_loss: 0.0068 - 56ms/epoch - 4ms/step
# Epoch 398/500
# 15/15 - 0s - loss: 0.0049 - val_loss: 0.0068 - 100ms/epoch - 7ms/step
# Epoch 399/500
# 15/15 - 0s - loss: 0.0049 - val_loss: 0.0068 - 57ms/epoch - 4ms/step
# Epoch 400/500
# 15/15 - 0s - loss: 0.0049 - val_loss: 0.0067 - 56ms/epoch - 4ms/step
# Epoch 401/500
# 15/15 - 0s - loss: 0.0049 - val_loss: 0.0067 - 57ms/epoch - 4ms/step
# Epoch 402/500
# 15/15 - 0s - loss: 0.0048 - val_loss: 0.0067 - 59ms/epoch - 4ms/step
# Epoch 403/500
# 15/15 - 0s - loss: 0.0048 - val_loss: 0.0066 - 58ms/epoch - 4ms/step
# Epoch 404/500
# 15/15 - 0s - loss: 0.0048 - val_loss: 0.0066 - 60ms/epoch - 4ms/step
# Epoch 405/500
# 15/15 - 0s - loss: 0.0048 - val_loss: 0.0066 - 58ms/epoch - 4ms/step
# Epoch 406/500
# 15/15 - 0s - loss: 0.0048 - val_loss: 0.0065 - 56ms/epoch - 4ms/step
# Epoch 407/500
# 15/15 - 0s - loss: 0.0048 - val_loss: 0.0065 - 57ms/epoch - 4ms/step
# Epoch 408/500
# 15/15 - 0s - loss: 0.0047 - val_loss: 0.0064 - 58ms/epoch - 4ms/step
# Epoch 409/500
# 15/15 - 0s - loss: 0.0047 - val_loss: 0.0064 - 57ms/epoch - 4ms/step
# Epoch 410/500
# 15/15 - 0s - loss: 0.0047 - val_loss: 0.0064 - 58ms/epoch - 4ms/step
# Epoch 411/500
# 15/15 - 0s - loss: 0.0047 - val_loss: 0.0063 - 57ms/epoch - 4ms/step
# Epoch 412/500
# 15/15 - 0s - loss: 0.0047 - val_loss: 0.0063 - 60ms/epoch - 4ms/step
# Epoch 413/500
# 15/15 - 0s - loss: 0.0047 - val_loss: 0.0063 - 58ms/epoch - 4ms/step
# Epoch 414/500
# 15/15 - 0s - loss: 0.0047 - val_loss: 0.0063 - 57ms/epoch - 4ms/step
# Epoch 415/500
# 15/15 - 0s - loss: 0.0046 - val_loss: 0.0062 - 57ms/epoch - 4ms/step
# Epoch 416/500
# 15/15 - 0s - loss: 0.0046 - val_loss: 0.0062 - 59ms/epoch - 4ms/step
# Epoch 417/500
# 15/15 - 0s - loss: 0.0046 - val_loss: 0.0062 - 61ms/epoch - 4ms/step
# Epoch 418/500
# 15/15 - 0s - loss: 0.0046 - val_loss: 0.0061 - 57ms/epoch - 4ms/step
# Epoch 419/500
# 15/15 - 0s - loss: 0.0046 - val_loss: 0.0061 - 57ms/epoch - 4ms/step
# Epoch 420/500
# 15/15 - 0s - loss: 0.0046 - val_loss: 0.0061 - 59ms/epoch - 4ms/step
# Epoch 421/500
# 15/15 - 0s - loss: 0.0046 - val_loss: 0.0060 - 64ms/epoch - 4ms/step
# Epoch 422/500
# 15/15 - 0s - loss: 0.0045 - val_loss: 0.0060 - 59ms/epoch - 4ms/step
# Epoch 423/500
# 15/15 - 0s - loss: 0.0045 - val_loss: 0.0060 - 59ms/epoch - 4ms/step
# Epoch 424/500
# 15/15 - 0s - loss: 0.0045 - val_loss: 0.0059 - 58ms/epoch - 4ms/step
# Epoch 425/500
# 15/15 - 0s - loss: 0.0045 - val_loss: 0.0059 - 56ms/epoch - 4ms/step
# Epoch 426/500
# 15/15 - 0s - loss: 0.0045 - val_loss: 0.0059 - 58ms/epoch - 4ms/step
# Epoch 427/500
# 15/15 - 0s - loss: 0.0045 - val_loss: 0.0059 - 57ms/epoch - 4ms/step
# Epoch 428/500
# 15/15 - 0s - loss: 0.0044 - val_loss: 0.0058 - 58ms/epoch - 4ms/step
# Epoch 429/500
# 15/15 - 0s - loss: 0.0044 - val_loss: 0.0058 - 60ms/epoch - 4ms/step
# Epoch 430/500
# 15/15 - 0s - loss: 0.0044 - val_loss: 0.0058 - 55ms/epoch - 4ms/step
# Epoch 431/500
# 15/15 - 0s - loss: 0.0044 - val_loss: 0.0058 - 56ms/epoch - 4ms/step
# Epoch 432/500
# 15/15 - 0s - loss: 0.0044 - val_loss: 0.0057 - 55ms/epoch - 4ms/step
# Epoch 433/500
# 15/15 - 0s - loss: 0.0044 - val_loss: 0.0057 - 56ms/epoch - 4ms/step
# Epoch 434/500
# 15/15 - 0s - loss: 0.0044 - val_loss: 0.0057 - 56ms/epoch - 4ms/step
# Epoch 435/500
# 15/15 - 0s - loss: 0.0043 - val_loss: 0.0056 - 56ms/epoch - 4ms/step
# Epoch 436/500
# 15/15 - 0s - loss: 0.0043 - val_loss: 0.0056 - 57ms/epoch - 4ms/step
# Epoch 437/500
# 15/15 - 0s - loss: 0.0043 - val_loss: 0.0056 - 58ms/epoch - 4ms/step
# Epoch 438/500
# 15/15 - 0s - loss: 0.0043 - val_loss: 0.0056 - 60ms/epoch - 4ms/step
# Epoch 439/500
# 15/15 - 0s - loss: 0.0043 - val_loss: 0.0055 - 57ms/epoch - 4ms/step
# Epoch 440/500
# 15/15 - 0s - loss: 0.0043 - val_loss: 0.0055 - 58ms/epoch - 4ms/step
# Epoch 441/500
# 15/15 - 0s - loss: 0.0043 - val_loss: 0.0055 - 56ms/epoch - 4ms/step
# Epoch 442/500
# 15/15 - 0s - loss: 0.0042 - val_loss: 0.0055 - 60ms/epoch - 4ms/step
# Epoch 443/500
# 15/15 - 0s - loss: 0.0042 - val_loss: 0.0054 - 64ms/epoch - 4ms/step
# Epoch 444/500
# 15/15 - 0s - loss: 0.0042 - val_loss: 0.0054 - 58ms/epoch - 4ms/step
# Epoch 445/500
# 15/15 - 0s - loss: 0.0042 - val_loss: 0.0054 - 59ms/epoch - 4ms/step
# Epoch 446/500
# 15/15 - 0s - loss: 0.0042 - val_loss: 0.0054 - 59ms/epoch - 4ms/step
# Epoch 447/500
# 15/15 - 0s - loss: 0.0042 - val_loss: 0.0053 - 57ms/epoch - 4ms/step
# Epoch 448/500
# 15/15 - 0s - loss: 0.0041 - val_loss: 0.0053 - 58ms/epoch - 4ms/step
# Epoch 449/500
# 15/15 - 0s - loss: 0.0041 - val_loss: 0.0053 - 56ms/epoch - 4ms/step
# Epoch 450/500
# 15/15 - 0s - loss: 0.0041 - val_loss: 0.0053 - 56ms/epoch - 4ms/step
# Epoch 451/500
# 15/15 - 0s - loss: 0.0041 - val_loss: 0.0052 - 54ms/epoch - 4ms/step
# Epoch 452/500
# 15/15 - 0s - loss: 0.0041 - val_loss: 0.0052 - 100ms/epoch - 7ms/step
# Epoch 453/500
# 15/15 - 0s - loss: 0.0041 - val_loss: 0.0052 - 55ms/epoch - 4ms/step
# Epoch 454/500
# 15/15 - 0s - loss: 0.0041 - val_loss: 0.0052 - 56ms/epoch - 4ms/step
# Epoch 455/500
# 15/15 - 0s - loss: 0.0040 - val_loss: 0.0051 - 53ms/epoch - 4ms/step
# Epoch 456/500
# 15/15 - 0s - loss: 0.0040 - val_loss: 0.0051 - 54ms/epoch - 4ms/step
# Epoch 457/500
# 15/15 - 0s - loss: 0.0040 - val_loss: 0.0051 - 54ms/epoch - 4ms/step
# Epoch 458/500
# 15/15 - 0s - loss: 0.0040 - val_loss: 0.0051 - 55ms/epoch - 4ms/step
# Epoch 459/500
# 15/15 - 0s - loss: 0.0040 - val_loss: 0.0051 - 53ms/epoch - 4ms/step
# Epoch 460/500
# 15/15 - 0s - loss: 0.0040 - val_loss: 0.0050 - 54ms/epoch - 4ms/step
# Epoch 461/500
# 15/15 - 0s - loss: 0.0039 - val_loss: 0.0050 - 54ms/epoch - 4ms/step
# Epoch 462/500
# 15/15 - 0s - loss: 0.0039 - val_loss: 0.0050 - 54ms/epoch - 4ms/step
# Epoch 463/500
# 15/15 - 0s - loss: 0.0039 - val_loss: 0.0050 - 53ms/epoch - 4ms/step
# Epoch 464/500
# 15/15 - 0s - loss: 0.0039 - val_loss: 0.0049 - 54ms/epoch - 4ms/step
# Epoch 465/500
# 15/15 - 0s - loss: 0.0039 - val_loss: 0.0049 - 53ms/epoch - 4ms/step
# Epoch 466/500
# 15/15 - 0s - loss: 0.0039 - val_loss: 0.0049 - 56ms/epoch - 4ms/step
# Epoch 467/500
# 15/15 - 0s - loss: 0.0038 - val_loss: 0.0049 - 55ms/epoch - 4ms/step
# Epoch 468/500
# 15/15 - 0s - loss: 0.0038 - val_loss: 0.0048 - 63ms/epoch - 4ms/step
# Epoch 469/500
# 15/15 - 0s - loss: 0.0038 - val_loss: 0.0048 - 55ms/epoch - 4ms/step
# Epoch 470/500
# 15/15 - 0s - loss: 0.0038 - val_loss: 0.0048 - 52ms/epoch - 3ms/step
# Epoch 471/500
# 15/15 - 0s - loss: 0.0038 - val_loss: 0.0048 - 57ms/epoch - 4ms/step
# Epoch 472/500
# 15/15 - 0s - loss: 0.0038 - val_loss: 0.0047 - 55ms/epoch - 4ms/step
# Epoch 473/500
# 15/15 - 0s - loss: 0.0037 - val_loss: 0.0047 - 54ms/epoch - 4ms/step
# Epoch 474/500
# 15/15 - 0s - loss: 0.0037 - val_loss: 0.0047 - 54ms/epoch - 4ms/step
# Epoch 475/500
# 15/15 - 0s - loss: 0.0037 - val_loss: 0.0047 - 54ms/epoch - 4ms/step
# Epoch 476/500
# 15/15 - 0s - loss: 0.0037 - val_loss: 0.0047 - 55ms/epoch - 4ms/step
# Epoch 477/500
# 15/15 - 0s - loss: 0.0037 - val_loss: 0.0046 - 54ms/epoch - 4ms/step
# Epoch 478/500
# 15/15 - 0s - loss: 0.0037 - val_loss: 0.0046 - 54ms/epoch - 4ms/step
# Epoch 479/500
# 15/15 - 0s - loss: 0.0036 - val_loss: 0.0046 - 62ms/epoch - 4ms/step
# Epoch 480/500
# 15/15 - 0s - loss: 0.0036 - val_loss: 0.0046 - 62ms/epoch - 4ms/step
# Epoch 481/500
# 15/15 - 0s - loss: 0.0036 - val_loss: 0.0045 - 61ms/epoch - 4ms/step
# Epoch 482/500
# 15/15 - 0s - loss: 0.0036 - val_loss: 0.0045 - 57ms/epoch - 4ms/step
# Epoch 483/500
# 15/15 - 0s - loss: 0.0036 - val_loss: 0.0045 - 55ms/epoch - 4ms/step
# Epoch 484/500
# 15/15 - 0s - loss: 0.0036 - val_loss: 0.0045 - 56ms/epoch - 4ms/step
# Epoch 485/500
# 15/15 - 0s - loss: 0.0035 - val_loss: 0.0044 - 55ms/epoch - 4ms/step
# Epoch 486/500
# 15/15 - 0s - loss: 0.0035 - val_loss: 0.0044 - 55ms/epoch - 4ms/step
# Epoch 487/500
# 15/15 - 0s - loss: 0.0035 - val_loss: 0.0044 - 55ms/epoch - 4ms/step
# Epoch 488/500
# 15/15 - 0s - loss: 0.0035 - val_loss: 0.0044 - 53ms/epoch - 4ms/step
# Epoch 489/500
# 15/15 - 0s - loss: 0.0035 - val_loss: 0.0043 - 54ms/epoch - 4ms/step
# Epoch 490/500
# 15/15 - 0s - loss: 0.0035 - val_loss: 0.0043 - 57ms/epoch - 4ms/step
# Epoch 491/500
# 15/15 - 0s - loss: 0.0034 - val_loss: 0.0043 - 57ms/epoch - 4ms/step
# Epoch 492/500
# 15/15 - 0s - loss: 0.0034 - val_loss: 0.0043 - 54ms/epoch - 4ms/step
# Epoch 493/500
# 15/15 - 0s - loss: 0.0034 - val_loss: 0.0042 - 55ms/epoch - 4ms/step
# Epoch 494/500
# 15/15 - 0s - loss: 0.0034 - val_loss: 0.0042 - 54ms/epoch - 4ms/step
# Epoch 495/500
# 15/15 - 0s - loss: 0.0034 - val_loss: 0.0042 - 56ms/epoch - 4ms/step
# Epoch 496/500
# 15/15 - 0s - loss: 0.0034 - val_loss: 0.0042 - 54ms/epoch - 4ms/step
# Epoch 497/500
# 15/15 - 0s - loss: 0.0033 - val_loss: 0.0042 - 56ms/epoch - 4ms/step
# Epoch 498/500
# 15/15 - 0s - loss: 0.0033 - val_loss: 0.0041 - 55ms/epoch - 4ms/step
# Epoch 499/500
# 15/15 - 0s - loss: 0.0033 - val_loss: 0.0041 - 56ms/epoch - 4ms/step
# Epoch 500/500
# 15/15 - 0s - loss: 0.0033 - val_loss: 0.0041 - 56ms/epoch - 4ms/step

# %% [markdown]
# ## Metrics ($LVPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
phy = phys2(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 8/8 [==============================] - 0s 1ms/step
# (237, 3)
# (237, 10)
# Test RMSE: 29.436
# Test MAE: 19.356

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('San Juan Dengue Spread', fontsize=20)
plt.legend(fontsize=20)
plt.show()
