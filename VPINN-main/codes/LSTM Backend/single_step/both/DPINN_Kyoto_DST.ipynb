# %% [markdown]
# # Time Series Prediction with Duffing Equation Inspired Deep Learning ($DPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-09 18:36:46

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Duffing Intermittency_

# %% [markdown]
# The `duffing_intermittency.dat` is generated from the Runge Kutta Method.

# %% [markdown]
# This feeds the model with the dynamics of the Duffing Equations

# %%
data = np.genfromtxt('datasets/duffing_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 0.0416 # Hourly Data (1/24)
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 1.73753853
# 1         0.474759
# 2         0.468784
# 3         0.462842
# 4         0.456930
# 5         0.451048
#             ...
# 139867    0.000000
# 139868    0.000000
# 139869    0.000000
# 139870    0.000000
# 139871    0.000000
# Name: 1, Length: 139871, dtype: float64
# 2        -0.143636
# 3        -0.142850
# 4        -0.142104
# 5        -0.141399
# 6        -0.140769
#             ...
# 139867    0.000000
# 139868    0.000000
# 139869    0.000000
# 139870    0.000000
# 139871    0.000000
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _KYOTO DST_

# %%
data = pd.read_csv("datasets/dst.csv")
training_set = data.iloc[:, 1]
print(training_set)
# Out:
# 0         -7
# 1        -10
# 2        -10
# 3         -6
# 4         -2
#           ..
# 139867   -16
# 139868   -14
# 139869   -14
# 139870   -15
# 139871   -14
# Name: dst, Length: 139872, dtype: int64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0         0.474759
# 1         0.468784
# 2         0.462842
# 3         0.456930
# 4         0.451048
#             ...
# 139866    0.000000
# 139867    0.000000
# 139868    0.000000
# 139869    0.000000
# 139870    0.000000
# Name: 1, Length: 139871, dtype: float64
# 0        -0.143636
# 1        -0.142850
# 2        -0.142104
# 3        -0.141399
# 4        -0.140769
#             ...
# 139865    0.000000
# 139866    0.000000
# 139867    0.000000
# 139868    0.000000
# 139869    0.000000
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Duffing Equation_)

# %% [markdown]
# _Parameters_: $\alpha=0.5, \beta=1, \gamma=3, \delta=1\\$

# %%
a=0.5
b=1
c=3
d=1
L = df.iloc[:, 2] -c + d*df.iloc[:, 1] - a*df.iloc[:, 0] - b*df.iloc[:, 0]**3
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10        -7.0      -10.0      -10.0       -6.0       -2.0        3.0
# 11       -10.0      -10.0       -6.0       -2.0        3.0        5.0
# 12       -10.0       -6.0       -2.0        3.0        5.0        5.0
# 13        -6.0       -2.0        3.0        5.0        5.0        3.0
# 14        -2.0        3.0        5.0        5.0        3.0        1.0
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)   var2(t)   var3(t)
# 10        5.0        5.0        3.0        1.0      1.0  0.416224 -0.138262
# 11        5.0        3.0        1.0        1.0      2.0  0.410472 -0.138123
# 12        3.0        1.0        1.0        2.0      2.0  0.404726 -0.138054
# 13        1.0        1.0        2.0        2.0      3.0  0.398983 -0.138082
# 14        1.0        2.0        2.0        3.0      3.0  0.393239 -0.138210
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (139860, 13)
# (139860, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (111888, 1, 10) (111888, 3) (27972, 1, 10) (27972, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
a = tf.Variable(0.5, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(1, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(3, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(1, name="delta", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] -c + d*y_true[:, 1] - a*y_true[:, 0] - b*y_true[:, 0]**3), (y_pred[:, 2] -c + d*y_pred[:, 1] - a*y_pred[:, 0] - b*y_pred[:, 0]**3))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] -c + d*(y_pred[1:-1]-y_pred[:-2]) - a*y_pred[:-2] - b*y_pred[:-2]**3
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] -c + d*(y_real[1:-1]-y_real[:-2]) - a*y_real[:-2] - b*y_real[:-2]**3
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($DPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square(y_pred[:, 2] -c + d*y_pred[:, 1] - a*y_pred[:, 0] - b*y_pred[:, 0]**3)
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 1749/1749 - 14s - loss: 0.0105 - val_loss: 2.2948e-04 - 14s/epoch - 8ms/step
# Epoch 2/500
# 1749/1749 - 7s - loss: 5.7316e-04 - val_loss: 1.3371e-04 - 7s/epoch - 4ms/step
# Epoch 3/500
# 1749/1749 - 7s - loss: 3.0930e-04 - val_loss: 1.6631e-04 - 7s/epoch - 4ms/step
# Epoch 4/500
# 1749/1749 - 9s - loss: 2.3392e-04 - val_loss: 1.7358e-04 - 9s/epoch - 5ms/step
# Epoch 5/500
# 1749/1749 - 7s - loss: 2.0748e-04 - val_loss: 1.5223e-04 - 7s/epoch - 4ms/step
# Epoch 6/500
# 1749/1749 - 8s - loss: 1.8715e-04 - val_loss: 1.2672e-04 - 8s/epoch - 4ms/step
# Epoch 7/500
# 1749/1749 - 7s - loss: 1.6950e-04 - val_loss: 1.0287e-04 - 7s/epoch - 4ms/step
# Epoch 8/500
# 1749/1749 - 7s - loss: 1.4889e-04 - val_loss: 6.5746e-05 - 7s/epoch - 4ms/step
# Epoch 9/500
# 1749/1749 - 7s - loss: 1.3234e-04 - val_loss: 5.4331e-05 - 7s/epoch - 4ms/step
# Epoch 10/500
# 1749/1749 - 7s - loss: 1.2517e-04 - val_loss: 4.8811e-05 - 7s/epoch - 4ms/step
# Epoch 11/500
# 1749/1749 - 7s - loss: 1.1875e-04 - val_loss: 4.8448e-05 - 7s/epoch - 4ms/step
# Epoch 12/500
# 1749/1749 - 7s - loss: 1.1482e-04 - val_loss: 4.7769e-05 - 7s/epoch - 4ms/step
# Epoch 13/500
# 1749/1749 - 9s - loss: 1.1215e-04 - val_loss: 4.7069e-05 - 9s/epoch - 5ms/step
# Epoch 14/500
# 1749/1749 - 13s - loss: 1.1011e-04 - val_loss: 4.6446e-05 - 13s/epoch - 7ms/step
# Epoch 15/500
# 1749/1749 - 10s - loss: 1.0842e-04 - val_loss: 4.5895e-05 - 10s/epoch - 6ms/step
# Epoch 16/500
# 1749/1749 - 15s - loss: 1.0696e-04 - val_loss: 4.5413e-05 - 15s/epoch - 9ms/step
# Epoch 17/500
# 1749/1749 - 7s - loss: 1.0569e-04 - val_loss: 4.4996e-05 - 7s/epoch - 4ms/step
# Epoch 18/500
# 1749/1749 - 11s - loss: 1.0455e-04 - val_loss: 4.4644e-05 - 11s/epoch - 6ms/step
# Epoch 19/500
# 1749/1749 - 10s - loss: 1.0355e-04 - val_loss: 4.4353e-05 - 10s/epoch - 6ms/step
# Epoch 20/500
# 1749/1749 - 9s - loss: 1.0266e-04 - val_loss: 4.4117e-05 - 9s/epoch - 5ms/step
# Epoch 21/500
# 1749/1749 - 13s - loss: 1.0186e-04 - val_loss: 4.3920e-05 - 13s/epoch - 7ms/step
# Epoch 22/500
# 1749/1749 - 13s - loss: 1.0115e-04 - val_loss: 4.3750e-05 - 13s/epoch - 7ms/step
# Epoch 23/500
# 1749/1749 - 11s - loss: 1.0051e-04 - val_loss: 4.3612e-05 - 11s/epoch - 6ms/step
# Epoch 24/500
# 1749/1749 - 11s - loss: 9.9930e-05 - val_loss: 4.3501e-05 - 11s/epoch - 6ms/step
# Epoch 25/500
# 1749/1749 - 9s - loss: 9.9401e-05 - val_loss: 4.3400e-05 - 9s/epoch - 5ms/step
# Epoch 26/500
# 1749/1749 - 9s - loss: 9.8919e-05 - val_loss: 4.3301e-05 - 9s/epoch - 5ms/step
# Epoch 27/500
# 1749/1749 - 9s - loss: 9.8479e-05 - val_loss: 4.3202e-05 - 9s/epoch - 5ms/step
# Epoch 28/500
# 1749/1749 - 8s - loss: 9.8077e-05 - val_loss: 4.3098e-05 - 8s/epoch - 5ms/step
# Epoch 29/500
# 1749/1749 - 10s - loss: 9.7709e-05 - val_loss: 4.2988e-05 - 10s/epoch - 5ms/step
# Epoch 30/500
# 1749/1749 - 9s - loss: 9.7373e-05 - val_loss: 4.2872e-05 - 9s/epoch - 5ms/step
# Epoch 31/500
# 1749/1749 - 10s - loss: 9.7067e-05 - val_loss: 4.2748e-05 - 10s/epoch - 6ms/step
# Epoch 32/500
# 1749/1749 - 10s - loss: 9.6788e-05 - val_loss: 4.2612e-05 - 10s/epoch - 6ms/step
# Epoch 33/500
# 1749/1749 - 11s - loss: 9.6535e-05 - val_loss: 4.2464e-05 - 11s/epoch - 6ms/step
# Epoch 34/500
# 1749/1749 - 9s - loss: 9.6307e-05 - val_loss: 4.2301e-05 - 9s/epoch - 5ms/step
# Epoch 35/500
# 1749/1749 - 9s - loss: 9.6108e-05 - val_loss: 4.2115e-05 - 9s/epoch - 5ms/step
# Epoch 36/500
# 1749/1749 - 9s - loss: 9.5940e-05 - val_loss: 4.1907e-05 - 9s/epoch - 5ms/step
# Epoch 37/500
# 1749/1749 - 9s - loss: 9.5802e-05 - val_loss: 4.1672e-05 - 9s/epoch - 5ms/step
# Epoch 38/500
# 1749/1749 - 9s - loss: 9.5693e-05 - val_loss: 4.1412e-05 - 9s/epoch - 5ms/step
# Epoch 39/500
# 1749/1749 - 10s - loss: 9.5614e-05 - val_loss: 4.1136e-05 - 10s/epoch - 5ms/step
# Epoch 40/500
# 1749/1749 - 10s - loss: 9.5568e-05 - val_loss: 4.0847e-05 - 10s/epoch - 5ms/step
# Epoch 41/500
# 1749/1749 - 10s - loss: 9.5561e-05 - val_loss: 4.0556e-05 - 10s/epoch - 6ms/step
# Epoch 42/500
# 1749/1749 - 11s - loss: 9.5608e-05 - val_loss: 4.0289e-05 - 11s/epoch - 6ms/step
# Epoch 43/500
# 1749/1749 - 10s - loss: 9.5737e-05 - val_loss: 4.0112e-05 - 10s/epoch - 6ms/step
# Epoch 44/500
# 1749/1749 - 9s - loss: 9.5994e-05 - val_loss: 4.0223e-05 - 9s/epoch - 5ms/step
# Epoch 45/500
# 1749/1749 - 8s - loss: 9.6416e-05 - val_loss: 4.1166e-05 - 8s/epoch - 5ms/step
# Epoch 46/500
# 1749/1749 - 9s - loss: 9.6910e-05 - val_loss: 4.3412e-05 - 9s/epoch - 5ms/step
# Epoch 47/500
# 1749/1749 - 8s - loss: 9.7219e-05 - val_loss: 4.5655e-05 - 8s/epoch - 5ms/step
# Epoch 48/500
# 1749/1749 - 9s - loss: 9.7298e-05 - val_loss: 4.6753e-05 - 9s/epoch - 5ms/step
# Epoch 49/500
# 1749/1749 - 10s - loss: 9.7297e-05 - val_loss: 4.7075e-05 - 10s/epoch - 5ms/step
# Epoch 50/500
# 1749/1749 - 11s - loss: 9.7281e-05 - val_loss: 4.7018e-05 - 11s/epoch - 6ms/step
# Epoch 51/500
# 1749/1749 - 13s - loss: 9.7264e-05 - val_loss: 4.6829e-05 - 13s/epoch - 8ms/step
# Epoch 52/500
# 1749/1749 - 12s - loss: 9.7250e-05 - val_loss: 4.6678e-05 - 12s/epoch - 7ms/step
# Epoch 53/500
# 1749/1749 - 10s - loss: 9.7236e-05 - val_loss: 4.6668e-05 - 10s/epoch - 6ms/step
# Epoch 54/500
# 1749/1749 - 8s - loss: 9.7220e-05 - val_loss: 4.6835e-05 - 8s/epoch - 5ms/step
# Epoch 55/500
# 1749/1749 - 9s - loss: 9.7198e-05 - val_loss: 4.7167e-05 - 9s/epoch - 5ms/step
# Epoch 56/500
# 1749/1749 - 12s - loss: 9.7172e-05 - val_loss: 4.7641e-05 - 12s/epoch - 7ms/step
# Epoch 57/500
# 1749/1749 - 10s - loss: 9.7148e-05 - val_loss: 4.8244e-05 - 10s/epoch - 6ms/step
# Epoch 58/500
# 1749/1749 - 11s - loss: 9.7133e-05 - val_loss: 4.8976e-05 - 11s/epoch - 6ms/step
# Epoch 59/500
# 1749/1749 - 10s - loss: 9.7129e-05 - val_loss: 4.9843e-05 - 10s/epoch - 6ms/step
# Epoch 60/500
# 1749/1749 - 9s - loss: 9.7142e-05 - val_loss: 5.0857e-05 - 9s/epoch - 5ms/step
# Epoch 61/500
# 1749/1749 - 9s - loss: 9.7175e-05 - val_loss: 5.2039e-05 - 9s/epoch - 5ms/step
# Epoch 62/500
# 1749/1749 - 7s - loss: 9.7236e-05 - val_loss: 5.3410e-05 - 7s/epoch - 4ms/step
# Epoch 63/500
# 1749/1749 - 7s - loss: 9.7332e-05 - val_loss: 5.5019e-05 - 7s/epoch - 4ms/step
# Epoch 64/500
# 1749/1749 - 7s - loss: 9.7480e-05 - val_loss: 5.6933e-05 - 7s/epoch - 4ms/step
# Epoch 65/500
# 1749/1749 - 8s - loss: 9.7702e-05 - val_loss: 5.9267e-05 - 8s/epoch - 5ms/step
# Epoch 66/500
# 1749/1749 - 8s - loss: 9.8046e-05 - val_loss: 6.2222e-05 - 8s/epoch - 5ms/step
# Epoch 67/500
# 1749/1749 - 8s - loss: 9.8618e-05 - val_loss: 6.6209e-05 - 8s/epoch - 5ms/step
# Epoch 68/500
# 1749/1749 - 9s - loss: 9.9714e-05 - val_loss: 7.2143e-05 - 9s/epoch - 5ms/step
# Epoch 69/500
# 1749/1749 - 9s - loss: 1.0221e-04 - val_loss: 8.2406e-05 - 9s/epoch - 5ms/step
# Epoch 70/500
# 1749/1749 - 10s - loss: 1.0496e-04 - val_loss: 9.0013e-05 - 10s/epoch - 6ms/step
# Epoch 71/500
# 1749/1749 - 11s - loss: 1.0444e-04 - val_loss: 8.9437e-05 - 11s/epoch - 6ms/step
# Epoch 72/500
# 1749/1749 - 11s - loss: 1.0422e-04 - val_loss: 8.9530e-05 - 11s/epoch - 6ms/step
# Epoch 73/500
# 1749/1749 - 10s - loss: 1.0416e-04 - val_loss: 8.9547e-05 - 10s/epoch - 6ms/step
# Epoch 74/500
# 1749/1749 - 10s - loss: 1.0404e-04 - val_loss: 8.9333e-05 - 10s/epoch - 6ms/step
# Epoch 75/500
# 1749/1749 - 9s - loss: 1.0391e-04 - val_loss: 8.8957e-05 - 9s/epoch - 5ms/step
# Epoch 76/500
# 1749/1749 - 10s - loss: 1.0376e-04 - val_loss: 8.8440e-05 - 10s/epoch - 5ms/step
# Epoch 77/500
# 1749/1749 - 12s - loss: 1.0361e-04 - val_loss: 8.7786e-05 - 12s/epoch - 7ms/step
# Epoch 78/500
# 1749/1749 - 10s - loss: 1.0345e-04 - val_loss: 8.7010e-05 - 10s/epoch - 6ms/step
# Epoch 79/500
# 1749/1749 - 11s - loss: 1.0327e-04 - val_loss: 8.6137e-05 - 11s/epoch - 6ms/step
# Epoch 80/500
# 1749/1749 - 11s - loss: 1.0310e-04 - val_loss: 8.5180e-05 - 11s/epoch - 6ms/step
# Epoch 81/500
# 1749/1749 - 11s - loss: 1.0291e-04 - val_loss: 8.4183e-05 - 11s/epoch - 6ms/step
# Epoch 82/500
# 1749/1749 - 10s - loss: 1.0272e-04 - val_loss: 8.3122e-05 - 10s/epoch - 6ms/step
# Epoch 83/500
# 1749/1749 - 9s - loss: 1.0253e-04 - val_loss: 8.2029e-05 - 9s/epoch - 5ms/step
# Epoch 84/500
# 1749/1749 - 10s - loss: 1.0233e-04 - val_loss: 8.0885e-05 - 10s/epoch - 6ms/step
# Epoch 85/500
# 1749/1749 - 8s - loss: 1.0213e-04 - val_loss: 7.9713e-05 - 8s/epoch - 5ms/step
# Epoch 86/500
# 1749/1749 - 9s - loss: 1.0194e-04 - val_loss: 7.8494e-05 - 9s/epoch - 5ms/step
# Epoch 87/500
# 1749/1749 - 8s - loss: 1.0175e-04 - val_loss: 7.7256e-05 - 8s/epoch - 5ms/step
# Epoch 88/500
# 1749/1749 - 9s - loss: 1.0156e-04 - val_loss: 7.5984e-05 - 9s/epoch - 5ms/step
# Epoch 89/500
# 1749/1749 - 10s - loss: 1.0137e-04 - val_loss: 7.4723e-05 - 10s/epoch - 6ms/step
# Epoch 90/500
# 1749/1749 - 10s - loss: 1.0118e-04 - val_loss: 7.3483e-05 - 10s/epoch - 6ms/step
# Epoch 91/500
# 1749/1749 - 10s - loss: 1.0100e-04 - val_loss: 7.2270e-05 - 10s/epoch - 6ms/step
# Epoch 92/500
# 1749/1749 - 10s - loss: 1.0082e-04 - val_loss: 7.1018e-05 - 10s/epoch - 6ms/step
# Epoch 93/500
# 1749/1749 - 9s - loss: 1.0065e-04 - val_loss: 6.9730e-05 - 9s/epoch - 5ms/step
# Epoch 94/500
# 1749/1749 - 11s - loss: 1.0049e-04 - val_loss: 6.8404e-05 - 11s/epoch - 6ms/step
# Epoch 95/500
# 1749/1749 - 11s - loss: 1.0033e-04 - val_loss: 6.7073e-05 - 11s/epoch - 6ms/step
# Epoch 96/500
# 1749/1749 - 8s - loss: 1.0018e-04 - val_loss: 6.5744e-05 - 8s/epoch - 5ms/step
# Epoch 97/500
# 1749/1749 - 9s - loss: 1.0004e-04 - val_loss: 6.4457e-05 - 9s/epoch - 5ms/step
# Epoch 98/500
# 1749/1749 - 9s - loss: 9.9896e-05 - val_loss: 6.3210e-05 - 9s/epoch - 5ms/step
# Epoch 99/500
# 1749/1749 - 10s - loss: 9.9760e-05 - val_loss: 6.1996e-05 - 10s/epoch - 6ms/step
# Epoch 100/500
# 1749/1749 - 10s - loss: 9.9628e-05 - val_loss: 6.0785e-05 - 10s/epoch - 6ms/step
# Epoch 101/500
# 1749/1749 - 10s - loss: 9.9503e-05 - val_loss: 5.9554e-05 - 10s/epoch - 6ms/step
# Epoch 102/500
# 1749/1749 - 10s - loss: 9.9381e-05 - val_loss: 5.8321e-05 - 10s/epoch - 6ms/step
# Epoch 103/500
# 1749/1749 - 10s - loss: 9.9264e-05 - val_loss: 5.7089e-05 - 10s/epoch - 6ms/step
# Epoch 104/500
# 1749/1749 - 10s - loss: 9.9149e-05 - val_loss: 5.5874e-05 - 10s/epoch - 6ms/step
# Epoch 105/500
# 1749/1749 - 15s - loss: 9.9037e-05 - val_loss: 5.4673e-05 - 15s/epoch - 8ms/step
# Epoch 106/500
# 1749/1749 - 12s - loss: 9.8926e-05 - val_loss: 5.3505e-05 - 12s/epoch - 7ms/step
# Epoch 107/500
# 1749/1749 - 17s - loss: 9.8817e-05 - val_loss: 5.2366e-05 - 17s/epoch - 10ms/step
# Epoch 108/500
# 1749/1749 - 9s - loss: 9.8708e-05 - val_loss: 5.1271e-05 - 9s/epoch - 5ms/step
# Epoch 109/500
# 1749/1749 - 10s - loss: 9.8601e-05 - val_loss: 5.0201e-05 - 10s/epoch - 6ms/step
# Epoch 110/500
# 1749/1749 - 9s - loss: 9.8494e-05 - val_loss: 4.9182e-05 - 9s/epoch - 5ms/step
# Epoch 111/500
# 1749/1749 - 9s - loss: 9.8389e-05 - val_loss: 4.8199e-05 - 9s/epoch - 5ms/step
# Epoch 112/500
# 1749/1749 - 9s - loss: 9.8282e-05 - val_loss: 4.7276e-05 - 9s/epoch - 5ms/step
# Epoch 113/500
# 1749/1749 - 9s - loss: 9.8177e-05 - val_loss: 4.6398e-05 - 9s/epoch - 5ms/step
# Epoch 114/500
# 1749/1749 - 9s - loss: 9.8071e-05 - val_loss: 4.5588e-05 - 9s/epoch - 5ms/step
# Epoch 115/500
# 1749/1749 - 9s - loss: 9.7965e-05 - val_loss: 4.4826e-05 - 9s/epoch - 5ms/step
# Epoch 116/500
# 1749/1749 - 9s - loss: 9.7858e-05 - val_loss: 4.4132e-05 - 9s/epoch - 5ms/step
# Epoch 117/500
# 1749/1749 - 9s - loss: 9.7752e-05 - val_loss: 4.3503e-05 - 9s/epoch - 5ms/step
# Epoch 118/500
# 1749/1749 - 10s - loss: 9.7643e-05 - val_loss: 4.2958e-05 - 10s/epoch - 5ms/step
# Epoch 119/500
# 1749/1749 - 8s - loss: 9.7534e-05 - val_loss: 4.2495e-05 - 8s/epoch - 5ms/step
# Epoch 120/500
# 1749/1749 - 7s - loss: 9.7423e-05 - val_loss: 4.2125e-05 - 7s/epoch - 4ms/step
# Epoch 121/500
# 1749/1749 - 7s - loss: 9.7313e-05 - val_loss: 4.1825e-05 - 7s/epoch - 4ms/step
# Epoch 122/500
# 1749/1749 - 7s - loss: 9.7203e-05 - val_loss: 4.1597e-05 - 7s/epoch - 4ms/step
# Epoch 123/500
# 1749/1749 - 7s - loss: 9.7093e-05 - val_loss: 4.1409e-05 - 7s/epoch - 4ms/step
# Epoch 124/500
# 1749/1749 - 7s - loss: 9.6984e-05 - val_loss: 4.1279e-05 - 7s/epoch - 4ms/step
# Epoch 125/500
# 1749/1749 - 7s - loss: 9.6877e-05 - val_loss: 4.1174e-05 - 7s/epoch - 4ms/step
# Epoch 126/500
# 1749/1749 - 7s - loss: 9.6770e-05 - val_loss: 4.1126e-05 - 7s/epoch - 4ms/step
# Epoch 127/500
# 1749/1749 - 7s - loss: 9.6666e-05 - val_loss: 4.1099e-05 - 7s/epoch - 4ms/step
# Epoch 128/500
# 1749/1749 - 8s - loss: 9.6565e-05 - val_loss: 4.1099e-05 - 8s/epoch - 4ms/step
# Epoch 129/500
# 1749/1749 - 7s - loss: 9.6467e-05 - val_loss: 4.1079e-05 - 7s/epoch - 4ms/step
# Epoch 130/500
# 1749/1749 - 7s - loss: 9.6371e-05 - val_loss: 4.1044e-05 - 7s/epoch - 4ms/step
# Epoch 131/500
# 1749/1749 - 7s - loss: 9.6280e-05 - val_loss: 4.0946e-05 - 7s/epoch - 4ms/step
# Epoch 132/500
# 1749/1749 - 8s - loss: 9.6192e-05 - val_loss: 4.0776e-05 - 8s/epoch - 4ms/step
# Epoch 133/500
# 1749/1749 - 9s - loss: 9.6107e-05 - val_loss: 4.0555e-05 - 9s/epoch - 5ms/step
# Epoch 134/500
# 1749/1749 - 8s - loss: 9.6025e-05 - val_loss: 4.0262e-05 - 8s/epoch - 5ms/step
# Epoch 135/500
# 1749/1749 - 10s - loss: 9.5946e-05 - val_loss: 3.9953e-05 - 10s/epoch - 5ms/step
# Epoch 136/500
# 1749/1749 - 9s - loss: 9.5868e-05 - val_loss: 3.9605e-05 - 9s/epoch - 5ms/step
# Epoch 137/500
# 1749/1749 - 10s - loss: 9.5792e-05 - val_loss: 3.9260e-05 - 10s/epoch - 6ms/step
# Epoch 138/500
# 1749/1749 - 13s - loss: 9.5718e-05 - val_loss: 3.8893e-05 - 13s/epoch - 7ms/step
# Epoch 139/500
# 1749/1749 - 11s - loss: 9.5645e-05 - val_loss: 3.8544e-05 - 11s/epoch - 6ms/step
# Epoch 140/500
# 1749/1749 - 14s - loss: 9.5574e-05 - val_loss: 3.8188e-05 - 14s/epoch - 8ms/step
# Epoch 141/500
# 1749/1749 - 13s - loss: 9.5503e-05 - val_loss: 3.7839e-05 - 13s/epoch - 8ms/step
# Epoch 142/500
# 1749/1749 - 11s - loss: 9.5433e-05 - val_loss: 3.7492e-05 - 11s/epoch - 6ms/step
# Epoch 143/500
# 1749/1749 - 11s - loss: 9.5365e-05 - val_loss: 3.7141e-05 - 11s/epoch - 6ms/step
# Epoch 144/500
# 1749/1749 - 12s - loss: 9.5297e-05 - val_loss: 3.6761e-05 - 12s/epoch - 7ms/step
# Epoch 145/500
# 1749/1749 - 11s - loss: 9.5230e-05 - val_loss: 3.6322e-05 - 11s/epoch - 6ms/step
# Epoch 146/500
# 1749/1749 - 12s - loss: 9.5155e-05 - val_loss: 3.5970e-05 - 12s/epoch - 7ms/step
# Epoch 147/500
# 1749/1749 - 12s - loss: 9.5084e-05 - val_loss: 3.5746e-05 - 12s/epoch - 7ms/step
# Epoch 148/500
# 1749/1749 - 12s - loss: 9.5022e-05 - val_loss: 3.5577e-05 - 12s/epoch - 7ms/step
# Epoch 149/500
# 1749/1749 - 10s - loss: 9.4960e-05 - val_loss: 3.5431e-05 - 10s/epoch - 6ms/step
# Epoch 150/500
# 1749/1749 - 10s - loss: 9.4904e-05 - val_loss: 3.5280e-05 - 10s/epoch - 6ms/step
# Epoch 151/500
# 1749/1749 - 10s - loss: 9.4843e-05 - val_loss: 3.5161e-05 - 10s/epoch - 6ms/step
# Epoch 152/500
# 1749/1749 - 10s - loss: 9.4788e-05 - val_loss: 3.5037e-05 - 10s/epoch - 6ms/step
# Epoch 153/500
# 1749/1749 - 10s - loss: 9.4729e-05 - val_loss: 3.4939e-05 - 10s/epoch - 6ms/step
# Epoch 154/500
# 1749/1749 - 10s - loss: 9.4676e-05 - val_loss: 3.4836e-05 - 10s/epoch - 6ms/step
# Epoch 155/500
# 1749/1749 - 10s - loss: 9.4619e-05 - val_loss: 3.4755e-05 - 10s/epoch - 6ms/step
# Epoch 156/500
# 1749/1749 - 9s - loss: 9.4565e-05 - val_loss: 3.4676e-05 - 9s/epoch - 5ms/step
# Epoch 157/500
# 1749/1749 - 7s - loss: 9.4510e-05 - val_loss: 3.4611e-05 - 7s/epoch - 4ms/step
# Epoch 158/500
# 1749/1749 - 7s - loss: 9.4458e-05 - val_loss: 3.4549e-05 - 7s/epoch - 4ms/step
# Epoch 159/500
# 1749/1749 - 7s - loss: 9.4404e-05 - val_loss: 3.4498e-05 - 7s/epoch - 4ms/step
# Epoch 160/500
# 1749/1749 - 7s - loss: 9.4350e-05 - val_loss: 3.4453e-05 - 7s/epoch - 4ms/step
# Epoch 161/500
# 1749/1749 - 8s - loss: 9.4299e-05 - val_loss: 3.4414e-05 - 8s/epoch - 4ms/step
# Epoch 162/500
# 1749/1749 - 8s - loss: 9.4246e-05 - val_loss: 3.4381e-05 - 8s/epoch - 4ms/step
# Epoch 163/500
# 1749/1749 - 8s - loss: 9.4194e-05 - val_loss: 3.4353e-05 - 8s/epoch - 4ms/step
# Epoch 164/500
# 1749/1749 - 8s - loss: 9.4141e-05 - val_loss: 3.4330e-05 - 8s/epoch - 4ms/step
# Epoch 165/500
# 1749/1749 - 8s - loss: 9.4090e-05 - val_loss: 3.4312e-05 - 8s/epoch - 4ms/step
# Epoch 166/500
# 1749/1749 - 8s - loss: 9.4037e-05 - val_loss: 3.4297e-05 - 8s/epoch - 4ms/step
# Epoch 167/500
# 1749/1749 - 7s - loss: 9.3986e-05 - val_loss: 3.4287e-05 - 7s/epoch - 4ms/step
# Epoch 168/500
# 1749/1749 - 7s - loss: 9.3935e-05 - val_loss: 3.4281e-05 - 7s/epoch - 4ms/step
# Epoch 169/500
# 1749/1749 - 7s - loss: 9.3885e-05 - val_loss: 3.4276e-05 - 7s/epoch - 4ms/step
# Epoch 170/500
# 1749/1749 - 7s - loss: 9.3834e-05 - val_loss: 3.4273e-05 - 7s/epoch - 4ms/step
# Epoch 171/500
# 1749/1749 - 7s - loss: 9.3784e-05 - val_loss: 3.4275e-05 - 7s/epoch - 4ms/step
# Epoch 172/500
# 1749/1749 - 7s - loss: 9.3734e-05 - val_loss: 3.4279e-05 - 7s/epoch - 4ms/step
# Epoch 173/500
# 1749/1749 - 7s - loss: 9.3684e-05 - val_loss: 3.4286e-05 - 7s/epoch - 4ms/step
# Epoch 174/500
# 1749/1749 - 7s - loss: 9.3635e-05 - val_loss: 3.4296e-05 - 7s/epoch - 4ms/step
# Epoch 175/500
# 1749/1749 - 7s - loss: 9.3586e-05 - val_loss: 3.4308e-05 - 7s/epoch - 4ms/step
# Epoch 176/500
# 1749/1749 - 7s - loss: 9.3537e-05 - val_loss: 3.4322e-05 - 7s/epoch - 4ms/step
# Epoch 177/500
# 1749/1749 - 7s - loss: 9.3488e-05 - val_loss: 3.4340e-05 - 7s/epoch - 4ms/step
# Epoch 178/500
# 1749/1749 - 7s - loss: 9.3440e-05 - val_loss: 3.4359e-05 - 7s/epoch - 4ms/step
# Epoch 179/500
# 1749/1749 - 7s - loss: 9.3392e-05 - val_loss: 3.4381e-05 - 7s/epoch - 4ms/step
# Epoch 180/500
# 1749/1749 - 7s - loss: 9.3343e-05 - val_loss: 3.4405e-05 - 7s/epoch - 4ms/step
# Epoch 181/500
# 1749/1749 - 7s - loss: 9.3295e-05 - val_loss: 3.4431e-05 - 7s/epoch - 4ms/step
# Epoch 182/500
# 1749/1749 - 7s - loss: 9.3247e-05 - val_loss: 3.4458e-05 - 7s/epoch - 4ms/step
# Epoch 183/500
# 1749/1749 - 7s - loss: 9.3199e-05 - val_loss: 3.4488e-05 - 7s/epoch - 4ms/step
# Epoch 184/500
# 1749/1749 - 7s - loss: 9.3151e-05 - val_loss: 3.4518e-05 - 7s/epoch - 4ms/step
# Epoch 185/500
# 1749/1749 - 7s - loss: 9.3103e-05 - val_loss: 3.4551e-05 - 7s/epoch - 4ms/step
# Epoch 186/500
# 1749/1749 - 7s - loss: 9.3056e-05 - val_loss: 3.4580e-05 - 7s/epoch - 4ms/step
# Epoch 187/500
# 1749/1749 - 8s - loss: 9.3007e-05 - val_loss: 3.4614e-05 - 8s/epoch - 4ms/step
# Epoch 188/500
# 1749/1749 - 7s - loss: 9.2958e-05 - val_loss: 3.4648e-05 - 7s/epoch - 4ms/step
# Epoch 189/500
# 1749/1749 - 7s - loss: 9.2909e-05 - val_loss: 3.4683e-05 - 7s/epoch - 4ms/step
# Epoch 190/500
# 1749/1749 - 7s - loss: 9.2858e-05 - val_loss: 3.4718e-05 - 7s/epoch - 4ms/step
# Epoch 191/500
# 1749/1749 - 7s - loss: 9.2808e-05 - val_loss: 3.4752e-05 - 7s/epoch - 4ms/step
# Epoch 192/500
# 1749/1749 - 7s - loss: 9.2756e-05 - val_loss: 3.4785e-05 - 7s/epoch - 4ms/step
# Epoch 193/500
# 1749/1749 - 7s - loss: 9.2704e-05 - val_loss: 3.4817e-05 - 7s/epoch - 4ms/step
# Epoch 194/500
# 1749/1749 - 7s - loss: 9.2651e-05 - val_loss: 3.4846e-05 - 7s/epoch - 4ms/step
# Epoch 195/500
# 1749/1749 - 7s - loss: 9.2596e-05 - val_loss: 3.4872e-05 - 7s/epoch - 4ms/step
# Epoch 196/500
# 1749/1749 - 7s - loss: 9.2540e-05 - val_loss: 3.4894e-05 - 7s/epoch - 4ms/step
# Epoch 197/500
# 1749/1749 - 7s - loss: 9.2483e-05 - val_loss: 3.4913e-05 - 7s/epoch - 4ms/step
# Epoch 198/500
# 1749/1749 - 7s - loss: 9.2425e-05 - val_loss: 3.4928e-05 - 7s/epoch - 4ms/step
# Epoch 199/500
# 1749/1749 - 7s - loss: 9.2366e-05 - val_loss: 3.4937e-05 - 7s/epoch - 4ms/step
# Epoch 200/500
# 1749/1749 - 7s - loss: 9.2307e-05 - val_loss: 3.4942e-05 - 7s/epoch - 4ms/step
# Epoch 201/500
# 1749/1749 - 7s - loss: 9.2247e-05 - val_loss: 3.4944e-05 - 7s/epoch - 4ms/step
# Epoch 202/500
# 1749/1749 - 7s - loss: 9.2188e-05 - val_loss: 3.4945e-05 - 7s/epoch - 4ms/step
# Epoch 203/500
# 1749/1749 - 7s - loss: 9.2132e-05 - val_loss: 3.4945e-05 - 7s/epoch - 4ms/step
# Epoch 204/500
# 1749/1749 - 8s - loss: 9.2079e-05 - val_loss: 3.4948e-05 - 8s/epoch - 4ms/step
# Epoch 205/500
# 1749/1749 - 7s - loss: 9.2031e-05 - val_loss: 3.4952e-05 - 7s/epoch - 4ms/step
# Epoch 206/500
# 1749/1749 - 7s - loss: 9.1986e-05 - val_loss: 3.4954e-05 - 7s/epoch - 4ms/step
# Epoch 207/500
# 1749/1749 - 7s - loss: 9.1945e-05 - val_loss: 3.4962e-05 - 7s/epoch - 4ms/step
# Epoch 208/500
# 1749/1749 - 7s - loss: 9.1909e-05 - val_loss: 3.4984e-05 - 7s/epoch - 4ms/step
# Epoch 209/500
# 1749/1749 - 7s - loss: 9.1875e-05 - val_loss: 3.5015e-05 - 7s/epoch - 4ms/step
# Epoch 210/500
# 1749/1749 - 7s - loss: 9.1844e-05 - val_loss: 3.5050e-05 - 7s/epoch - 4ms/step
# Epoch 211/500
# 1749/1749 - 12s - loss: 9.1813e-05 - val_loss: 3.5085e-05 - 12s/epoch - 7ms/step
# Epoch 212/500
# 1749/1749 - 10s - loss: 9.1782e-05 - val_loss: 3.5117e-05 - 10s/epoch - 6ms/step
# Epoch 213/500
# 1749/1749 - 14s - loss: 9.1751e-05 - val_loss: 3.5148e-05 - 14s/epoch - 8ms/step
# Epoch 214/500
# 1749/1749 - 8s - loss: 9.1720e-05 - val_loss: 3.5176e-05 - 8s/epoch - 5ms/step
# Epoch 215/500
# 1749/1749 - 7s - loss: 9.1689e-05 - val_loss: 3.5205e-05 - 7s/epoch - 4ms/step
# Epoch 216/500
# 1749/1749 - 7s - loss: 9.1658e-05 - val_loss: 3.5232e-05 - 7s/epoch - 4ms/step
# Epoch 217/500
# 1749/1749 - 7s - loss: 9.1628e-05 - val_loss: 3.5258e-05 - 7s/epoch - 4ms/step
# Epoch 218/500
# 1749/1749 - 7s - loss: 9.1597e-05 - val_loss: 3.5284e-05 - 7s/epoch - 4ms/step
# Epoch 219/500
# 1749/1749 - 7s - loss: 9.1567e-05 - val_loss: 3.5308e-05 - 7s/epoch - 4ms/step
# Epoch 220/500
# 1749/1749 - 7s - loss: 9.1536e-05 - val_loss: 3.5333e-05 - 7s/epoch - 4ms/step
# Epoch 221/500
# 1749/1749 - 7s - loss: 9.1506e-05 - val_loss: 3.5357e-05 - 7s/epoch - 4ms/step
# Epoch 222/500
# 1749/1749 - 7s - loss: 9.1476e-05 - val_loss: 3.5381e-05 - 7s/epoch - 4ms/step
# Epoch 223/500
# 1749/1749 - 7s - loss: 9.1446e-05 - val_loss: 3.5403e-05 - 7s/epoch - 4ms/step
# Epoch 224/500
# 1749/1749 - 7s - loss: 9.1416e-05 - val_loss: 3.5425e-05 - 7s/epoch - 4ms/step
# Epoch 225/500
# 1749/1749 - 7s - loss: 9.1387e-05 - val_loss: 3.5447e-05 - 7s/epoch - 4ms/step
# Epoch 226/500
# 1749/1749 - 7s - loss: 9.1357e-05 - val_loss: 3.5468e-05 - 7s/epoch - 4ms/step
# Epoch 227/500
# 1749/1749 - 7s - loss: 9.1328e-05 - val_loss: 3.5489e-05 - 7s/epoch - 4ms/step
# Epoch 228/500
# 1749/1749 - 8s - loss: 9.1299e-05 - val_loss: 3.5508e-05 - 8s/epoch - 4ms/step
# Epoch 229/500
# 1749/1749 - 7s - loss: 9.1270e-05 - val_loss: 3.5526e-05 - 7s/epoch - 4ms/step
# Epoch 230/500
# 1749/1749 - 7s - loss: 9.1242e-05 - val_loss: 3.5544e-05 - 7s/epoch - 4ms/step
# Epoch 231/500
# 1749/1749 - 7s - loss: 9.1213e-05 - val_loss: 3.5561e-05 - 7s/epoch - 4ms/step
# Epoch 232/500
# 1749/1749 - 7s - loss: 9.1185e-05 - val_loss: 3.5577e-05 - 7s/epoch - 4ms/step
# Epoch 233/500
# 1749/1749 - 7s - loss: 9.1157e-05 - val_loss: 3.5593e-05 - 7s/epoch - 4ms/step
# Epoch 234/500
# 1749/1749 - 7s - loss: 9.1129e-05 - val_loss: 3.5607e-05 - 7s/epoch - 4ms/step
# Epoch 235/500
# 1749/1749 - 7s - loss: 9.1101e-05 - val_loss: 3.5621e-05 - 7s/epoch - 4ms/step
# Epoch 236/500
# 1749/1749 - 7s - loss: 9.1074e-05 - val_loss: 3.5633e-05 - 7s/epoch - 4ms/step
# Epoch 237/500
# 1749/1749 - 8s - loss: 9.1046e-05 - val_loss: 3.5645e-05 - 8s/epoch - 4ms/step
# Epoch 238/500
# 1749/1749 - 8s - loss: 9.1019e-05 - val_loss: 3.5655e-05 - 8s/epoch - 4ms/step
# Epoch 239/500
# 1749/1749 - 7s - loss: 9.0992e-05 - val_loss: 3.5665e-05 - 7s/epoch - 4ms/step
# Epoch 240/500
# 1749/1749 - 8s - loss: 9.0966e-05 - val_loss: 3.5674e-05 - 8s/epoch - 4ms/step
# Epoch 241/500
# 1749/1749 - 7s - loss: 9.0939e-05 - val_loss: 3.5682e-05 - 7s/epoch - 4ms/step
# Epoch 242/500
# 1749/1749 - 7s - loss: 9.0913e-05 - val_loss: 3.5690e-05 - 7s/epoch - 4ms/step
# Epoch 243/500
# 1749/1749 - 7s - loss: 9.0887e-05 - val_loss: 3.5696e-05 - 7s/epoch - 4ms/step
# Epoch 244/500
# 1749/1749 - 7s - loss: 9.0862e-05 - val_loss: 3.5700e-05 - 7s/epoch - 4ms/step
# Epoch 245/500
# 1749/1749 - 7s - loss: 9.0836e-05 - val_loss: 3.5705e-05 - 7s/epoch - 4ms/step
# Epoch 246/500
# 1749/1749 - 7s - loss: 9.0811e-05 - val_loss: 3.5707e-05 - 7s/epoch - 4ms/step
# Epoch 247/500
# 1749/1749 - 7s - loss: 9.0787e-05 - val_loss: 3.5708e-05 - 7s/epoch - 4ms/step
# Epoch 248/500
# 1749/1749 - 7s - loss: 9.0762e-05 - val_loss: 3.5706e-05 - 7s/epoch - 4ms/step
# Epoch 249/500
# 1749/1749 - 8s - loss: 9.0738e-05 - val_loss: 3.5703e-05 - 8s/epoch - 4ms/step
# Epoch 250/500
# 1749/1749 - 7s - loss: 9.0714e-05 - val_loss: 3.5699e-05 - 7s/epoch - 4ms/step
# Epoch 251/500
# 1749/1749 - 7s - loss: 9.0691e-05 - val_loss: 3.5696e-05 - 7s/epoch - 4ms/step
# Epoch 252/500
# 1749/1749 - 7s - loss: 9.0669e-05 - val_loss: 3.5694e-05 - 7s/epoch - 4ms/step
# Epoch 253/500
# 1749/1749 - 7s - loss: 9.0647e-05 - val_loss: 3.5694e-05 - 7s/epoch - 4ms/step
# Epoch 254/500
# 1749/1749 - 7s - loss: 9.0625e-05 - val_loss: 3.5697e-05 - 7s/epoch - 4ms/step
# Epoch 255/500
# 1749/1749 - 7s - loss: 9.0604e-05 - val_loss: 3.5705e-05 - 7s/epoch - 4ms/step
# Epoch 256/500
# 1749/1749 - 7s - loss: 9.0583e-05 - val_loss: 3.5718e-05 - 7s/epoch - 4ms/step
# Epoch 257/500
# 1749/1749 - 8s - loss: 9.0562e-05 - val_loss: 3.5737e-05 - 8s/epoch - 4ms/step
# Epoch 258/500
# 1749/1749 - 8s - loss: 9.0541e-05 - val_loss: 3.5760e-05 - 8s/epoch - 5ms/step
# Epoch 259/500
# 1749/1749 - 8s - loss: 9.0520e-05 - val_loss: 3.5784e-05 - 8s/epoch - 5ms/step
# Epoch 260/500
# 1749/1749 - 8s - loss: 9.0499e-05 - val_loss: 3.5808e-05 - 8s/epoch - 5ms/step
# Epoch 261/500
# 1749/1749 - 8s - loss: 9.0478e-05 - val_loss: 3.5833e-05 - 8s/epoch - 5ms/step
# Epoch 262/500
# 1749/1749 - 8s - loss: 9.0456e-05 - val_loss: 3.5858e-05 - 8s/epoch - 5ms/step
# Epoch 263/500
# 1749/1749 - 9s - loss: 9.0435e-05 - val_loss: 3.5884e-05 - 9s/epoch - 5ms/step
# Epoch 264/500
# 1749/1749 - 8s - loss: 9.0414e-05 - val_loss: 3.5911e-05 - 8s/epoch - 5ms/step
# Epoch 265/500
# 1749/1749 - 8s - loss: 9.0393e-05 - val_loss: 3.5938e-05 - 8s/epoch - 5ms/step
# Epoch 266/500
# 1749/1749 - 8s - loss: 9.0371e-05 - val_loss: 3.5964e-05 - 8s/epoch - 5ms/step
# Epoch 267/500
# 1749/1749 - 8s - loss: 9.0349e-05 - val_loss: 3.5991e-05 - 8s/epoch - 5ms/step
# Epoch 268/500
# 1749/1749 - 8s - loss: 9.0330e-05 - val_loss: 3.6022e-05 - 8s/epoch - 5ms/step
# Epoch 269/500
# 1749/1749 - 8s - loss: 9.0309e-05 - val_loss: 3.6050e-05 - 8s/epoch - 5ms/step
# Epoch 270/500
# 1749/1749 - 8s - loss: 9.0286e-05 - val_loss: 3.6076e-05 - 8s/epoch - 5ms/step
# Epoch 271/500
# 1749/1749 - 8s - loss: 9.0267e-05 - val_loss: 3.6107e-05 - 8s/epoch - 5ms/step
# Epoch 272/500
# 1749/1749 - 8s - loss: 9.0246e-05 - val_loss: 3.6139e-05 - 8s/epoch - 5ms/step
# Epoch 273/500
# 1749/1749 - 8s - loss: 9.0224e-05 - val_loss: 3.6165e-05 - 8s/epoch - 5ms/step
# Epoch 274/500
# 1749/1749 - 8s - loss: 9.0204e-05 - val_loss: 3.6195e-05 - 8s/epoch - 4ms/step
# Epoch 275/500
# 1749/1749 - 8s - loss: 9.0186e-05 - val_loss: 3.6214e-05 - 8s/epoch - 5ms/step
# Epoch 276/500
# 1749/1749 - 8s - loss: 9.0164e-05 - val_loss: 3.6176e-05 - 8s/epoch - 4ms/step
# Epoch 277/500
# 1749/1749 - 8s - loss: 9.0144e-05 - val_loss: 3.6277e-05 - 8s/epoch - 4ms/step
# Epoch 278/500
# 1749/1749 - 8s - loss: 9.0157e-05 - val_loss: 3.6306e-05 - 8s/epoch - 4ms/step
# Epoch 279/500
# 1749/1749 - 8s - loss: 9.0094e-05 - val_loss: 3.5955e-05 - 8s/epoch - 4ms/step
# Epoch 280/500
# 1749/1749 - 8s - loss: 9.0135e-05 - val_loss: 3.6261e-05 - 8s/epoch - 4ms/step
# Epoch 281/500
# 1749/1749 - 8s - loss: 9.0112e-05 - val_loss: 3.6585e-05 - 8s/epoch - 4ms/step
# Epoch 282/500
# 1749/1749 - 9s - loss: 9.0070e-05 - val_loss: 3.6439e-05 - 9s/epoch - 5ms/step
# Epoch 283/500
# 1749/1749 - 9s - loss: 9.0039e-05 - val_loss: 3.6129e-05 - 9s/epoch - 5ms/step
# Epoch 284/500
# 1749/1749 - 10s - loss: 9.0069e-05 - val_loss: 3.6520e-05 - 10s/epoch - 6ms/step
# Epoch 285/500
# 1749/1749 - 9s - loss: 9.0000e-05 - val_loss: 3.6588e-05 - 9s/epoch - 5ms/step
# Epoch 286/500
# 1749/1749 - 9s - loss: 9.0029e-05 - val_loss: 3.6557e-05 - 9s/epoch - 5ms/step
# Epoch 287/500
# 1749/1749 - 8s - loss: 8.9962e-05 - val_loss: 3.6200e-05 - 8s/epoch - 5ms/step
# Epoch 288/500
# 1749/1749 - 8s - loss: 8.9986e-05 - val_loss: 3.6572e-05 - 8s/epoch - 5ms/step
# Epoch 289/500
# 1749/1749 - 8s - loss: 8.9937e-05 - val_loss: 3.6753e-05 - 8s/epoch - 5ms/step
# Epoch 290/500
# 1749/1749 - 8s - loss: 8.9939e-05 - val_loss: 3.6697e-05 - 8s/epoch - 5ms/step
# Epoch 291/500
# 1749/1749 - 8s - loss: 8.9882e-05 - val_loss: 3.6328e-05 - 8s/epoch - 5ms/step
# Epoch 292/500
# 1749/1749 - 9s - loss: 8.9918e-05 - val_loss: 3.6777e-05 - 9s/epoch - 5ms/step
# Epoch 293/500
# 1749/1749 - 11s - loss: 8.9828e-05 - val_loss: 3.6658e-05 - 11s/epoch - 6ms/step
# Epoch 294/500
# 1749/1749 - 14s - loss: 8.9867e-05 - val_loss: 3.6813e-05 - 14s/epoch - 8ms/step
# Epoch 295/500
# 1749/1749 - 13s - loss: 8.9805e-05 - val_loss: 3.6731e-05 - 13s/epoch - 7ms/step
# Epoch 296/500
# 1749/1749 - 10s - loss: 8.9845e-05 - val_loss: 3.6691e-05 - 10s/epoch - 6ms/step
# Epoch 297/500
# 1749/1749 - 12s - loss: 8.9794e-05 - val_loss: 3.6393e-05 - 12s/epoch - 7ms/step
# Epoch 298/500
# 1749/1749 - 13s - loss: 8.9811e-05 - val_loss: 3.6779e-05 - 13s/epoch - 7ms/step
# Epoch 299/500
# 1749/1749 - 14s - loss: 8.9769e-05 - val_loss: 3.7016e-05 - 14s/epoch - 8ms/step
# Epoch 300/500
# 1749/1749 - 10s - loss: 8.9755e-05 - val_loss: 3.6961e-05 - 10s/epoch - 6ms/step
# Epoch 301/500
# 1749/1749 - 10s - loss: 8.9711e-05 - val_loss: 3.6624e-05 - 10s/epoch - 6ms/step
# Epoch 302/500
# 1749/1749 - 12s - loss: 8.9756e-05 - val_loss: 3.7117e-05 - 12s/epoch - 7ms/step
# Epoch 303/500
# 1749/1749 - 11s - loss: 8.9703e-05 - val_loss: 3.6824e-05 - 11s/epoch - 6ms/step
# Epoch 304/500
# 1749/1749 - 14s - loss: 8.9654e-05 - val_loss: 3.6545e-05 - 14s/epoch - 8ms/step
# Epoch 305/500
# 1749/1749 - 10s - loss: 8.9708e-05 - val_loss: 3.7111e-05 - 10s/epoch - 6ms/step
# Epoch 306/500
# 1749/1749 - 9s - loss: 8.9607e-05 - val_loss: 3.7026e-05 - 9s/epoch - 5ms/step
# Epoch 307/500
# 1749/1749 - 13s - loss: 8.9694e-05 - val_loss: 3.7058e-05 - 13s/epoch - 8ms/step
# Epoch 308/500
# 1749/1749 - 11s - loss: 8.9592e-05 - val_loss: 3.6656e-05 - 11s/epoch - 7ms/step
# Epoch 309/500
# 1749/1749 - 13s - loss: 8.9628e-05 - val_loss: 3.7160e-05 - 13s/epoch - 7ms/step
# Epoch 310/500
# 1749/1749 - 11s - loss: 8.9535e-05 - val_loss: 3.7109e-05 - 11s/epoch - 6ms/step
# Epoch 311/500
# 1749/1749 - 10s - loss: 8.9635e-05 - val_loss: 3.7116e-05 - 10s/epoch - 6ms/step
# Epoch 312/500
# 1749/1749 - 11s - loss: 8.9521e-05 - val_loss: 3.6708e-05 - 11s/epoch - 6ms/step
# Epoch 313/500
# 1749/1749 - 11s - loss: 8.9555e-05 - val_loss: 3.7184e-05 - 11s/epoch - 6ms/step
# Epoch 314/500
# 1749/1749 - 10s - loss: 8.9487e-05 - val_loss: 3.7254e-05 - 10s/epoch - 6ms/step
# Epoch 315/500
# 1749/1749 - 19s - loss: 8.9538e-05 - val_loss: 3.7293e-05 - 19s/epoch - 11ms/step
# Epoch 316/500
# 1749/1749 - 20s - loss: 8.9451e-05 - val_loss: 3.6872e-05 - 20s/epoch - 11ms/step
# Epoch 317/500
# 1749/1749 - 13s - loss: 8.9496e-05 - val_loss: 3.7415e-05 - 13s/epoch - 8ms/step
# Epoch 318/500
# 1749/1749 - 12s - loss: 8.9390e-05 - val_loss: 3.7164e-05 - 12s/epoch - 7ms/step
# Epoch 319/500
# 1749/1749 - 10s - loss: 8.9434e-05 - val_loss: 3.7371e-05 - 10s/epoch - 6ms/step
# Epoch 320/500
# 1749/1749 - 11s - loss: 8.9466e-05 - val_loss: 3.7386e-05 - 11s/epoch - 6ms/step
# Epoch 321/500
# 1749/1749 - 12s - loss: 8.9377e-05 - val_loss: 3.6934e-05 - 12s/epoch - 7ms/step
# Epoch 322/500
# 1749/1749 - 11s - loss: 8.9413e-05 - val_loss: 3.7414e-05 - 11s/epoch - 6ms/step
# Epoch 323/500
# 1749/1749 - 10s - loss: 8.9315e-05 - val_loss: 3.7317e-05 - 10s/epoch - 6ms/step
# Epoch 324/500
# 1749/1749 - 9s - loss: 8.9435e-05 - val_loss: 3.7369e-05 - 9s/epoch - 5ms/step
# Epoch 325/500
# 1749/1749 - 9s - loss: 8.9298e-05 - val_loss: 3.6914e-05 - 9s/epoch - 5ms/step
# Epoch 326/500
# 1749/1749 - 10s - loss: 8.9345e-05 - val_loss: 3.7440e-05 - 10s/epoch - 6ms/step
# Epoch 327/500
# 1749/1749 - 9s - loss: 8.9283e-05 - val_loss: 3.7556e-05 - 9s/epoch - 5ms/step
# Epoch 328/500
# 1749/1749 - 9s - loss: 8.9332e-05 - val_loss: 3.7573e-05 - 9s/epoch - 5ms/step
# Epoch 329/500
# 1749/1749 - 10s - loss: 8.9238e-05 - val_loss: 3.7138e-05 - 10s/epoch - 5ms/step
# Epoch 330/500
# 1749/1749 - 9s - loss: 8.9293e-05 - val_loss: 3.7724e-05 - 9s/epoch - 5ms/step
# Epoch 331/500
# 1749/1749 - 9s - loss: 8.9174e-05 - val_loss: 3.7414e-05 - 9s/epoch - 5ms/step
# Epoch 332/500
# 1749/1749 - 11s - loss: 8.9224e-05 - val_loss: 3.7657e-05 - 11s/epoch - 6ms/step
# Epoch 333/500
# 1749/1749 - 10s - loss: 8.9304e-05 - val_loss: 3.7524e-05 - 10s/epoch - 6ms/step
# Epoch 334/500
# 1749/1749 - 10s - loss: 8.9148e-05 - val_loss: 3.7024e-05 - 10s/epoch - 5ms/step
# Epoch 335/500
# 1749/1749 - 9s - loss: 8.9177e-05 - val_loss: 3.7413e-05 - 9s/epoch - 5ms/step
# Epoch 336/500
# 1749/1749 - 9s - loss: 8.9167e-05 - val_loss: 3.7743e-05 - 9s/epoch - 5ms/step
# Epoch 337/500
# 1749/1749 - 9s - loss: 8.9167e-05 - val_loss: 3.7607e-05 - 9s/epoch - 5ms/step
# Epoch 338/500
# 1749/1749 - 9s - loss: 8.9084e-05 - val_loss: 3.7280e-05 - 9s/epoch - 5ms/step
# Epoch 339/500
# 1749/1749 - 9s - loss: 8.9148e-05 - val_loss: 3.7902e-05 - 9s/epoch - 5ms/step
# Epoch 340/500
# 1749/1749 - 9s - loss: 8.9034e-05 - val_loss: 3.7666e-05 - 9s/epoch - 5ms/step
# Epoch 341/500
# 1749/1749 - 9s - loss: 8.9157e-05 - val_loss: 3.7802e-05 - 9s/epoch - 5ms/step
# Epoch 342/500
# 1749/1749 - 9s - loss: 8.9021e-05 - val_loss: 3.7360e-05 - 9s/epoch - 5ms/step
# Epoch 343/500
# 1749/1749 - 10s - loss: 8.9064e-05 - val_loss: 3.7939e-05 - 10s/epoch - 5ms/step
# Epoch 344/500
# 1749/1749 - 9s - loss: 8.8948e-05 - val_loss: 3.7711e-05 - 9s/epoch - 5ms/step
# Epoch 345/500
# 1749/1749 - 10s - loss: 8.9090e-05 - val_loss: 3.7829e-05 - 10s/epoch - 6ms/step
# Epoch 346/500
# 1749/1749 - 10s - loss: 8.8919e-05 - val_loss: 3.7343e-05 - 10s/epoch - 6ms/step
# Epoch 347/500
# 1749/1749 - 9s - loss: 8.8979e-05 - val_loss: 3.7965e-05 - 9s/epoch - 5ms/step
# Epoch 348/500
# 1749/1749 - 10s - loss: 8.8874e-05 - val_loss: 3.7802e-05 - 10s/epoch - 5ms/step
# Epoch 349/500
# 1749/1749 - 9s - loss: 8.9030e-05 - val_loss: 3.7881e-05 - 9s/epoch - 5ms/step
# Epoch 350/500
# 1749/1749 - 9s - loss: 8.8854e-05 - val_loss: 3.7374e-05 - 9s/epoch - 5ms/step
# Epoch 351/500
# 1749/1749 - 9s - loss: 8.8882e-05 - val_loss: 3.7862e-05 - 9s/epoch - 5ms/step
# Epoch 352/500
# 1749/1749 - 10s - loss: 8.8824e-05 - val_loss: 3.7981e-05 - 10s/epoch - 6ms/step
# Epoch 353/500
# 1749/1749 - 10s - loss: 8.8908e-05 - val_loss: 3.8011e-05 - 10s/epoch - 5ms/step
# Epoch 354/500
# 1749/1749 - 9s - loss: 8.8762e-05 - val_loss: 3.7509e-05 - 9s/epoch - 5ms/step
# Epoch 355/500
# 1749/1749 - 9s - loss: 8.8808e-05 - val_loss: 3.8087e-05 - 9s/epoch - 5ms/step
# Epoch 356/500
# 1749/1749 - 9s - loss: 8.8692e-05 - val_loss: 3.7878e-05 - 9s/epoch - 5ms/step
# Epoch 357/500
# 1749/1749 - 9s - loss: 8.8843e-05 - val_loss: 3.7987e-05 - 9s/epoch - 5ms/step
# Epoch 358/500
# 1749/1749 - 10s - loss: 8.8658e-05 - val_loss: 3.7470e-05 - 10s/epoch - 6ms/step
# Epoch 359/500
# 1749/1749 - 9s - loss: 8.8687e-05 - val_loss: 3.8000e-05 - 9s/epoch - 5ms/step
# Epoch 360/500
# 1749/1749 - 10s - loss: 8.8593e-05 - val_loss: 3.7931e-05 - 10s/epoch - 5ms/step
# Epoch 361/500
# 1749/1749 - 10s - loss: 8.8720e-05 - val_loss: 3.7977e-05 - 10s/epoch - 6ms/step
# Epoch 362/500
# 1749/1749 - 9s - loss: 8.8538e-05 - val_loss: 3.7461e-05 - 9s/epoch - 5ms/step
# Epoch 363/500
# 1749/1749 - 9s - loss: 8.8570e-05 - val_loss: 3.8000e-05 - 9s/epoch - 5ms/step
# Epoch 364/500
# 1749/1749 - 10s - loss: 8.8471e-05 - val_loss: 3.7896e-05 - 10s/epoch - 6ms/step
# Epoch 365/500
# 1749/1749 - 10s - loss: 8.8605e-05 - val_loss: 3.7953e-05 - 10s/epoch - 6ms/step
# Epoch 366/500
# 1749/1749 - 10s - loss: 8.8422e-05 - val_loss: 3.7458e-05 - 10s/epoch - 6ms/step
# Epoch 367/500
# 1749/1749 - 11s - loss: 8.8457e-05 - val_loss: 3.8005e-05 - 11s/epoch - 6ms/step
# Epoch 368/500
# 1749/1749 - 11s - loss: 8.8364e-05 - val_loss: 3.7897e-05 - 11s/epoch - 6ms/step
# Epoch 369/500
# 1749/1749 - 11s - loss: 8.8505e-05 - val_loss: 3.7950e-05 - 11s/epoch - 6ms/step
# Epoch 370/500
# 1749/1749 - 10s - loss: 8.8335e-05 - val_loss: 3.7519e-05 - 10s/epoch - 6ms/step
# Epoch 371/500
# 1749/1749 - 9s - loss: 8.8377e-05 - val_loss: 3.8077e-05 - 9s/epoch - 5ms/step
# Epoch 372/500
# 1749/1749 - 9s - loss: 8.8293e-05 - val_loss: 3.7931e-05 - 9s/epoch - 5ms/step
# Epoch 373/500
# 1749/1749 - 9s - loss: 8.8439e-05 - val_loss: 3.7976e-05 - 9s/epoch - 5ms/step
# Epoch 374/500
# 1749/1749 - 10s - loss: 8.8278e-05 - val_loss: 3.7558e-05 - 10s/epoch - 6ms/step
# Epoch 375/500
# 1749/1749 - 10s - loss: 8.8319e-05 - val_loss: 3.8098e-05 - 10s/epoch - 6ms/step
# Epoch 376/500
# 1749/1749 - 10s - loss: 8.8238e-05 - val_loss: 3.7943e-05 - 10s/epoch - 6ms/step
# Epoch 377/500
# 1749/1749 - 10s - loss: 8.8396e-05 - val_loss: 3.7968e-05 - 10s/epoch - 6ms/step
# Epoch 378/500
# 1749/1749 - 10s - loss: 8.8229e-05 - val_loss: 3.7547e-05 - 10s/epoch - 5ms/step
# Epoch 379/500
# 1749/1749 - 11s - loss: 8.8269e-05 - val_loss: 3.8082e-05 - 11s/epoch - 6ms/step
# Epoch 380/500
# 1749/1749 - 19s - loss: 8.8188e-05 - val_loss: 3.7979e-05 - 19s/epoch - 11ms/step
# Epoch 381/500
# 1749/1749 - 16s - loss: 8.8350e-05 - val_loss: 3.7967e-05 - 16s/epoch - 9ms/step
# Epoch 382/500
# 1749/1749 - 12s - loss: 8.8183e-05 - val_loss: 3.7546e-05 - 12s/epoch - 7ms/step
# Epoch 383/500
# 1749/1749 - 11s - loss: 8.8218e-05 - val_loss: 3.8052e-05 - 11s/epoch - 6ms/step
# Epoch 384/500
# 1749/1749 - 10s - loss: 8.8151e-05 - val_loss: 3.8034e-05 - 10s/epoch - 6ms/step
# Epoch 385/500
# 1749/1749 - 11s - loss: 8.8307e-05 - val_loss: 3.7985e-05 - 11s/epoch - 7ms/step
# Epoch 386/500
# 1749/1749 - 11s - loss: 8.8141e-05 - val_loss: 3.7583e-05 - 11s/epoch - 6ms/step
# Epoch 387/500
# 1749/1749 - 10s - loss: 8.8173e-05 - val_loss: 3.8076e-05 - 10s/epoch - 6ms/step
# Epoch 388/500
# 1749/1749 - 10s - loss: 8.8106e-05 - val_loss: 3.8056e-05 - 10s/epoch - 6ms/step
# Epoch 389/500
# 1749/1749 - 10s - loss: 8.8256e-05 - val_loss: 3.8010e-05 - 10s/epoch - 6ms/step
# Epoch 390/500
# 1749/1749 - 10s - loss: 8.8093e-05 - val_loss: 3.7611e-05 - 10s/epoch - 6ms/step
# Epoch 391/500
# 1749/1749 - 10s - loss: 8.8127e-05 - val_loss: 3.8101e-05 - 10s/epoch - 6ms/step
# Epoch 392/500
# 1749/1749 - 10s - loss: 8.8059e-05 - val_loss: 3.8069e-05 - 10s/epoch - 6ms/step
# Epoch 393/500
# 1749/1749 - 10s - loss: 8.8209e-05 - val_loss: 3.8026e-05 - 10s/epoch - 6ms/step
# Epoch 394/500
# 1749/1749 - 11s - loss: 8.8046e-05 - val_loss: 3.7637e-05 - 11s/epoch - 6ms/step
# Epoch 395/500
# 1749/1749 - 12s - loss: 8.8081e-05 - val_loss: 3.8124e-05 - 12s/epoch - 7ms/step
# Epoch 396/500
# 1749/1749 - 11s - loss: 8.8013e-05 - val_loss: 3.8079e-05 - 11s/epoch - 7ms/step
# Epoch 397/500
# 1749/1749 - 9s - loss: 8.8165e-05 - val_loss: 3.8035e-05 - 9s/epoch - 5ms/step
# Epoch 398/500
# 1749/1749 - 9s - loss: 8.8001e-05 - val_loss: 3.7649e-05 - 9s/epoch - 5ms/step
# Epoch 399/500
# 1749/1749 - 9s - loss: 8.8034e-05 - val_loss: 3.8128e-05 - 9s/epoch - 5ms/step
# Epoch 400/500
# 1749/1749 - 9s - loss: 8.7971e-05 - val_loss: 3.8103e-05 - 9s/epoch - 5ms/step
# Epoch 401/500
# 1749/1749 - 9s - loss: 8.8120e-05 - val_loss: 3.8051e-05 - 9s/epoch - 5ms/step
# Epoch 402/500
# 1749/1749 - 14s - loss: 8.7956e-05 - val_loss: 3.7671e-05 - 14s/epoch - 8ms/step
# Epoch 403/500
# 1749/1749 - 12s - loss: 8.7991e-05 - val_loss: 3.8146e-05 - 12s/epoch - 7ms/step
# Epoch 404/500
# 1749/1749 - 21s - loss: 8.7929e-05 - val_loss: 3.8121e-05 - 21s/epoch - 12ms/step
# Epoch 405/500
# 1749/1749 - 14s - loss: 8.8079e-05 - val_loss: 3.8068e-05 - 14s/epoch - 8ms/step
# Epoch 406/500
# 1749/1749 - 10s - loss: 8.7914e-05 - val_loss: 3.7696e-05 - 10s/epoch - 6ms/step
# Epoch 407/500
# 1749/1749 - 11s - loss: 8.7949e-05 - val_loss: 3.8170e-05 - 11s/epoch - 6ms/step
# Epoch 408/500
# 1749/1749 - 9s - loss: 8.7886e-05 - val_loss: 3.8136e-05 - 9s/epoch - 5ms/step
# Epoch 409/500
# 1749/1749 - 9s - loss: 8.8038e-05 - val_loss: 3.8081e-05 - 9s/epoch - 5ms/step
# Epoch 410/500
# 1749/1749 - 9s - loss: 8.7874e-05 - val_loss: 3.7709e-05 - 9s/epoch - 5ms/step
# Epoch 411/500
# 1749/1749 - 9s - loss: 8.7906e-05 - val_loss: 3.8173e-05 - 9s/epoch - 5ms/step
# Epoch 412/500
# 1749/1749 - 9s - loss: 8.7849e-05 - val_loss: 3.8164e-05 - 9s/epoch - 5ms/step
# Epoch 413/500
# 1749/1749 - 10s - loss: 8.7996e-05 - val_loss: 3.8097e-05 - 10s/epoch - 6ms/step
# Epoch 414/500
# 1749/1749 - 9s - loss: 8.7833e-05 - val_loss: 3.7733e-05 - 9s/epoch - 5ms/step
# Epoch 415/500
# 1749/1749 - 9s - loss: 8.7867e-05 - val_loss: 3.8196e-05 - 9s/epoch - 5ms/step
# Epoch 416/500
# 1749/1749 - 9s - loss: 8.7809e-05 - val_loss: 3.8182e-05 - 9s/epoch - 5ms/step
# Epoch 417/500
# 1749/1749 - 10s - loss: 8.7957e-05 - val_loss: 3.8115e-05 - 10s/epoch - 5ms/step
# Epoch 418/500
# 1749/1749 - 10s - loss: 8.7794e-05 - val_loss: 3.7751e-05 - 10s/epoch - 6ms/step
# Epoch 419/500
# 1749/1749 - 10s - loss: 8.7826e-05 - val_loss: 3.8205e-05 - 10s/epoch - 6ms/step
# Epoch 420/500
# 1749/1749 - 10s - loss: 8.7771e-05 - val_loss: 3.8205e-05 - 10s/epoch - 6ms/step
# Epoch 421/500
# 1749/1749 - 10s - loss: 8.7916e-05 - val_loss: 3.8131e-05 - 10s/epoch - 6ms/step
# Epoch 422/500
# 1749/1749 - 10s - loss: 8.7755e-05 - val_loss: 3.7772e-05 - 10s/epoch - 6ms/step
# Epoch 423/500
# 1749/1749 - 10s - loss: 8.7786e-05 - val_loss: 3.8223e-05 - 10s/epoch - 6ms/step
# Epoch 424/500
# 1749/1749 - 10s - loss: 8.7734e-05 - val_loss: 3.8227e-05 - 10s/epoch - 6ms/step
# Epoch 425/500
# 1749/1749 - 11s - loss: 8.7878e-05 - val_loss: 3.8147e-05 - 11s/epoch - 6ms/step
# Epoch 426/500
# 1749/1749 - 10s - loss: 8.7718e-05 - val_loss: 3.7794e-05 - 10s/epoch - 6ms/step
# Epoch 427/500
# 1749/1749 - 10s - loss: 8.7748e-05 - val_loss: 3.8242e-05 - 10s/epoch - 6ms/step
# Epoch 428/500
# 1749/1749 - 10s - loss: 8.7696e-05 - val_loss: 3.8247e-05 - 10s/epoch - 5ms/step
# Epoch 429/500
# 1749/1749 - 10s - loss: 8.7841e-05 - val_loss: 3.8162e-05 - 10s/epoch - 6ms/step
# Epoch 430/500
# 1749/1749 - 10s - loss: 8.7680e-05 - val_loss: 3.7810e-05 - 10s/epoch - 6ms/step
# Epoch 431/500
# 1749/1749 - 10s - loss: 8.7708e-05 - val_loss: 3.8250e-05 - 10s/epoch - 6ms/step
# Epoch 432/500
# 1749/1749 - 10s - loss: 8.7660e-05 - val_loss: 3.8270e-05 - 10s/epoch - 6ms/step
# Epoch 433/500
# 1749/1749 - 10s - loss: 8.7803e-05 - val_loss: 3.8177e-05 - 10s/epoch - 6ms/step
# Epoch 434/500
# 1749/1749 - 10s - loss: 8.7643e-05 - val_loss: 3.7828e-05 - 10s/epoch - 5ms/step
# Epoch 435/500
# 1749/1749 - 10s - loss: 8.7670e-05 - val_loss: 3.8264e-05 - 10s/epoch - 6ms/step
# Epoch 436/500
# 1749/1749 - 10s - loss: 8.7624e-05 - val_loss: 3.8293e-05 - 10s/epoch - 6ms/step
# Epoch 437/500
# 1749/1749 - 10s - loss: 8.7766e-05 - val_loss: 3.8192e-05 - 10s/epoch - 6ms/step
# Epoch 438/500
# 1749/1749 - 10s - loss: 8.7607e-05 - val_loss: 3.7847e-05 - 10s/epoch - 6ms/step
# Epoch 439/500
# 1749/1749 - 10s - loss: 8.7632e-05 - val_loss: 3.8278e-05 - 10s/epoch - 6ms/step
# Epoch 440/500
# 1749/1749 - 10s - loss: 8.7589e-05 - val_loss: 3.8315e-05 - 10s/epoch - 6ms/step
# Epoch 441/500
# 1749/1749 - 10s - loss: 8.7730e-05 - val_loss: 3.8204e-05 - 10s/epoch - 6ms/step
# Epoch 442/500
# 1749/1749 - 8s - loss: 8.7571e-05 - val_loss: 3.7862e-05 - 8s/epoch - 4ms/step
# Epoch 443/500
# 1749/1749 - 6s - loss: 8.7594e-05 - val_loss: 3.8287e-05 - 6s/epoch - 3ms/step
# Epoch 444/500
# 1749/1749 - 6s - loss: 8.7554e-05 - val_loss: 3.8338e-05 - 6s/epoch - 3ms/step
# Epoch 445/500
# 1749/1749 - 6s - loss: 8.7695e-05 - val_loss: 3.8216e-05 - 6s/epoch - 3ms/step
# Epoch 446/500
# 1749/1749 - 6s - loss: 8.7536e-05 - val_loss: 3.7877e-05 - 6s/epoch - 4ms/step
# Epoch 447/500
# 1749/1749 - 6s - loss: 8.7557e-05 - val_loss: 3.8297e-05 - 6s/epoch - 4ms/step
# Epoch 448/500
# 1749/1749 - 6s - loss: 8.7520e-05 - val_loss: 3.8360e-05 - 6s/epoch - 4ms/step
# Epoch 449/500
# 1749/1749 - 6s - loss: 8.7659e-05 - val_loss: 3.8227e-05 - 6s/epoch - 3ms/step
# Epoch 450/500
# 1749/1749 - 6s - loss: 8.7502e-05 - val_loss: 3.7892e-05 - 6s/epoch - 4ms/step
# Epoch 451/500
# 1749/1749 - 7s - loss: 8.7521e-05 - val_loss: 3.8308e-05 - 7s/epoch - 4ms/step
# Epoch 452/500
# 1749/1749 - 8s - loss: 8.7486e-05 - val_loss: 3.8381e-05 - 8s/epoch - 5ms/step
# Epoch 453/500
# 1749/1749 - 9s - loss: 8.7624e-05 - val_loss: 3.8236e-05 - 9s/epoch - 5ms/step
# Epoch 454/500
# 1749/1749 - 7s - loss: 8.7468e-05 - val_loss: 3.7907e-05 - 7s/epoch - 4ms/step
# Epoch 455/500
# 1749/1749 - 8s - loss: 8.7485e-05 - val_loss: 3.8319e-05 - 8s/epoch - 4ms/step
# Epoch 456/500
# 1749/1749 - 8s - loss: 8.7453e-05 - val_loss: 3.8402e-05 - 8s/epoch - 4ms/step
# Epoch 457/500
# 1749/1749 - 10s - loss: 8.7590e-05 - val_loss: 3.8246e-05 - 10s/epoch - 5ms/step
# Epoch 458/500
# 1749/1749 - 6s - loss: 8.7434e-05 - val_loss: 3.7921e-05 - 6s/epoch - 4ms/step
# Epoch 459/500
# 1749/1749 - 11s - loss: 8.7450e-05 - val_loss: 3.8330e-05 - 11s/epoch - 6ms/step
# Epoch 460/500
# 1749/1749 - 7s - loss: 8.7420e-05 - val_loss: 3.8423e-05 - 7s/epoch - 4ms/step
# Epoch 461/500
# 1749/1749 - 6s - loss: 8.7556e-05 - val_loss: 3.8254e-05 - 6s/epoch - 4ms/step
# Epoch 462/500
# 1749/1749 - 7s - loss: 8.7401e-05 - val_loss: 3.7935e-05 - 7s/epoch - 4ms/step
# Epoch 463/500
# 1749/1749 - 6s - loss: 8.7415e-05 - val_loss: 3.8342e-05 - 6s/epoch - 4ms/step
# Epoch 464/500
# 1749/1749 - 7s - loss: 8.7386e-05 - val_loss: 3.8443e-05 - 7s/epoch - 4ms/step
# Epoch 465/500
# 1749/1749 - 6s - loss: 8.7523e-05 - val_loss: 3.8262e-05 - 6s/epoch - 4ms/step
# Epoch 466/500
# 1749/1749 - 6s - loss: 8.7369e-05 - val_loss: 3.7948e-05 - 6s/epoch - 4ms/step
# Epoch 467/500
# 1749/1749 - 6s - loss: 8.7380e-05 - val_loss: 3.8353e-05 - 6s/epoch - 4ms/step
# Epoch 468/500
# 1749/1749 - 6s - loss: 8.7353e-05 - val_loss: 3.8462e-05 - 6s/epoch - 4ms/step
# Epoch 469/500
# 1749/1749 - 7s - loss: 8.7491e-05 - val_loss: 3.8269e-05 - 7s/epoch - 4ms/step
# Epoch 470/500
# 1749/1749 - 6s - loss: 8.7337e-05 - val_loss: 3.7960e-05 - 6s/epoch - 4ms/step
# Epoch 471/500
# 1749/1749 - 6s - loss: 8.7345e-05 - val_loss: 3.8365e-05 - 6s/epoch - 4ms/step
# Epoch 472/500
# 1749/1749 - 6s - loss: 8.7320e-05 - val_loss: 3.8481e-05 - 6s/epoch - 3ms/step
# Epoch 473/500
# 1749/1749 - 6s - loss: 8.7459e-05 - val_loss: 3.8275e-05 - 6s/epoch - 3ms/step
# Epoch 474/500
# 1749/1749 - 6s - loss: 8.7305e-05 - val_loss: 3.7972e-05 - 6s/epoch - 3ms/step
# Epoch 475/500
# 1749/1749 - 5s - loss: 8.7311e-05 - val_loss: 3.8376e-05 - 5s/epoch - 3ms/step
# Epoch 476/500
# 1749/1749 - 6s - loss: 8.7287e-05 - val_loss: 3.8500e-05 - 6s/epoch - 3ms/step
# Epoch 477/500
# 1749/1749 - 6s - loss: 8.7427e-05 - val_loss: 3.8282e-05 - 6s/epoch - 3ms/step
# Epoch 478/500
# 1749/1749 - 6s - loss: 8.7274e-05 - val_loss: 3.7984e-05 - 6s/epoch - 3ms/step
# Epoch 479/500
# 1749/1749 - 6s - loss: 8.7278e-05 - val_loss: 3.8388e-05 - 6s/epoch - 3ms/step
# Epoch 480/500
# 1749/1749 - 6s - loss: 8.7255e-05 - val_loss: 3.8519e-05 - 6s/epoch - 3ms/step
# Epoch 481/500
# 1749/1749 - 6s - loss: 8.7396e-05 - val_loss: 3.8287e-05 - 6s/epoch - 4ms/step
# Epoch 482/500
# 1749/1749 - 6s - loss: 8.7243e-05 - val_loss: 3.7994e-05 - 6s/epoch - 4ms/step
# Epoch 483/500
# 1749/1749 - 6s - loss: 8.7244e-05 - val_loss: 3.8399e-05 - 6s/epoch - 4ms/step
# Epoch 484/500
# 1749/1749 - 6s - loss: 8.7222e-05 - val_loss: 3.8537e-05 - 6s/epoch - 4ms/step
# Epoch 485/500
# 1749/1749 - 6s - loss: 8.7366e-05 - val_loss: 3.8293e-05 - 6s/epoch - 3ms/step
# Epoch 486/500
# 1749/1749 - 7s - loss: 8.7213e-05 - val_loss: 3.8005e-05 - 7s/epoch - 4ms/step
# Epoch 487/500
# 1749/1749 - 6s - loss: 8.7212e-05 - val_loss: 3.8410e-05 - 6s/epoch - 4ms/step
# Epoch 488/500
# 1749/1749 - 6s - loss: 8.7190e-05 - val_loss: 3.8555e-05 - 6s/epoch - 4ms/step
# Epoch 489/500
# 1749/1749 - 8s - loss: 8.7335e-05 - val_loss: 3.8299e-05 - 8s/epoch - 5ms/step
# Epoch 490/500
# 1749/1749 - 9s - loss: 8.7184e-05 - val_loss: 3.8015e-05 - 9s/epoch - 5ms/step
# Epoch 491/500
# 1749/1749 - 11s - loss: 8.7180e-05 - val_loss: 3.8421e-05 - 11s/epoch - 6ms/step
# Epoch 492/500
# 1749/1749 - 10s - loss: 8.7158e-05 - val_loss: 3.8573e-05 - 10s/epoch - 6ms/step
# Epoch 493/500
# 1749/1749 - 10s - loss: 8.7305e-05 - val_loss: 3.8305e-05 - 10s/epoch - 6ms/step
# Epoch 494/500
# 1749/1749 - 9s - loss: 8.7155e-05 - val_loss: 3.8024e-05 - 9s/epoch - 5ms/step
# Epoch 495/500
# 1749/1749 - 9s - loss: 8.7148e-05 - val_loss: 3.8432e-05 - 9s/epoch - 5ms/step
# Epoch 496/500
# 1749/1749 - 9s - loss: 8.7127e-05 - val_loss: 3.8591e-05 - 9s/epoch - 5ms/step
# Epoch 497/500
# 1749/1749 - 8s - loss: 8.7275e-05 - val_loss: 3.8311e-05 - 8s/epoch - 5ms/step
# Epoch 498/500
# 1749/1749 - 9s - loss: 8.7126e-05 - val_loss: 3.8034e-05 - 9s/epoch - 5ms/step
# Epoch 499/500
# 1749/1749 - 9s - loss: 8.7117e-05 - val_loss: 3.8444e-05 - 9s/epoch - 5ms/step
# Epoch 500/500
# 1749/1749 - 9s - loss: 8.7095e-05 - val_loss: 3.8607e-05 - 9s/epoch - 5ms/step

# %% [markdown]
# ## Metrics ($DPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 875/875 [==============================] - 4s 3ms/step
# (27972, 3)
# (27972, 10)
# Test RMSE: 2.821
# Test MAE: 2.004

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('Kyoto DST Index', fontsize=20)
plt.legend(fontsize=20)
plt.show()
