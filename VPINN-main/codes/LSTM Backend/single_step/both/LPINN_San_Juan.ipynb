# %% [markdown]
# # Time Series Prediction with Lorrenz Attractor Inspired Deep Learning ($LPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-09 18:48:24

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Lorrenz Intermittency_

# %% [markdown]
# The `lorrenz_intermittency.dat` is generated from the Runge Kutta Method.

# %% [markdown]
# This feeds the model with the dynamics of the Lorrenz Attractor

# %%
data = np.genfromtxt('datasets/lorrenz_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 7 # Weekly Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 28.981277697415116
# 1         0.002440
# 2         0.005852
# 3         0.008959
# 4         0.011882
# 5         0.014722
#             ...
# 139867    0.014918
# 139868    0.009196
# 139869    0.004054
# 139870   -0.000537
# 139871   -0.004624
# Name: 1, Length: 139871, dtype: float64
# 2         0.000488
# 3         0.000444
# 4         0.000418
# 5         0.000406
# 6         0.000406
#             ...
# 139867   -0.000901
# 139868   -0.000817
# 139869   -0.000735
# 139870   -0.000656
# 139871   -0.000584
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _SAN JUAN_

# %%
data = pd.read_csv("datasets/sanjuan.csv")
training_set = data.iloc[:, 3]
print(training_set)
# Out:
# 0        4
# 1        5
# 2        4
# 3        3
# 4        6
#         ..
# 1191    56
# 1192    46
# 1193    52
# 1194    34
# 1195    25
# Name: Cases, Length: 1196, dtype: int64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0         0.002440
# 1         0.005852
# 2         0.008959
# 3         0.011882
# 4         0.014722
#             ...
# 139866    0.014918
# 139867    0.009196
# 139868    0.004054
# 139869   -0.000537
# 139870   -0.004624
# Name: 1, Length: 139871, dtype: float64
# 0         0.000488
# 1         0.000444
# 2         0.000418
# 3         0.000406
# 4         0.000406
#             ...
# 139865   -0.000901
# 139866   -0.000817
# 139867   -0.000735
# 139868   -0.000656
# 139869   -0.000584
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lorrenz Equation_)

# %% [markdown]
# _Parameters_: $\sigma=10, \rho=28$

# %%
s=10
r=28
L = df.iloc[:, 2] + df.iloc[:, 1]*(1 + s) - df.iloc[:, 0] * s * (r - 1)
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10         4.0        5.0        4.0        3.0        6.0        2.0
# 11         5.0        4.0        3.0        6.0        2.0        4.0
# 12         4.0        3.0        6.0        2.0        4.0        5.0
# 13         3.0        6.0        2.0        4.0        5.0       10.0
# 14         6.0        2.0        4.0        5.0       10.0        6.0
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)   var2(t)   var3(t)
# 10        4.0        5.0       10.0        6.0      8.0  0.034146  0.000600
# 11        5.0       10.0        6.0        8.0      2.0  0.038344  0.000660
# 12       10.0        6.0        8.0        2.0      6.0  0.042966  0.000729
# 13        6.0        8.0        2.0        6.0     17.0  0.048068  0.000806
# 14        8.0        2.0        6.0       17.0     23.0  0.053711  0.000892
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (1185, 13)
# (1185, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (948, 1, 10) (948, 3) (237, 1, 10) (237, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
s = tf.Variable(10, name="sigma", trainable=True, dtype=tf.float32)
r = tf.Variable(28, name="rhow", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] + y_true[:, 1]*(1 + s) - y_true[:, 0] * s * (r - 1)), (y_pred[:, 2] + y_pred[:, 1]*(1 + s) - y_pred[:, 0] * s * (r - 1)))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] + (y_pred[1:-1]-y_pred[:-2])*(1 + s) - y_pred[:-2] * s * (r - 1)
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] + (y_real[1:-1]-y_real[:-2])*(1 + s) - y_real[:-2] * s * (r - 1)
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($LPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square((y_pred[:, 2] + y_pred[:, 1]*(1 + s) - y_pred[:, 0] * s * (r - 1)))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 15/15 - 17s - loss: 0.4003 - val_loss: 0.3828 - 17s/epoch - 1s/step
# Epoch 2/500
# 15/15 - 0s - loss: 0.2261 - val_loss: 0.2289 - 303ms/epoch - 20ms/step
# Epoch 3/500
# 15/15 - 0s - loss: 0.2599 - val_loss: 0.2037 - 301ms/epoch - 20ms/step
# Epoch 4/500
# 15/15 - 0s - loss: 0.1431 - val_loss: 0.1512 - 297ms/epoch - 20ms/step
# Epoch 5/500
# 15/15 - 1s - loss: 0.1727 - val_loss: 0.1523 - 622ms/epoch - 41ms/step
# Epoch 6/500
# 15/15 - 0s - loss: 0.0932 - val_loss: 0.1590 - 317ms/epoch - 21ms/step
# Epoch 7/500
# 15/15 - 0s - loss: 0.1570 - val_loss: 0.1672 - 259ms/epoch - 17ms/step
# Epoch 8/500
# 15/15 - 0s - loss: 0.0943 - val_loss: 0.2138 - 347ms/epoch - 23ms/step
# Epoch 9/500
# 15/15 - 0s - loss: 0.1869 - val_loss: 0.2323 - 229ms/epoch - 15ms/step
# Epoch 10/500
# 15/15 - 0s - loss: 0.1353 - val_loss: 0.2863 - 283ms/epoch - 19ms/step
# Epoch 11/500
# 15/15 - 0s - loss: 0.2316 - val_loss: 0.2816 - 292ms/epoch - 19ms/step
# Epoch 12/500
# 15/15 - 0s - loss: 0.1750 - val_loss: 0.2773 - 370ms/epoch - 25ms/step
# Epoch 13/500
# 15/15 - 0s - loss: 0.2226 - val_loss: 0.2299 - 236ms/epoch - 16ms/step
# Epoch 14/500
# 15/15 - 0s - loss: 0.1499 - val_loss: 0.1863 - 268ms/epoch - 18ms/step
# Epoch 15/500
# 15/15 - 0s - loss: 0.1509 - val_loss: 0.1472 - 264ms/epoch - 18ms/step
# Epoch 16/500
# 15/15 - 0s - loss: 0.0951 - val_loss: 0.1207 - 317ms/epoch - 21ms/step
# Epoch 17/500
# 15/15 - 0s - loss: 0.0933 - val_loss: 0.1033 - 300ms/epoch - 20ms/step
# Epoch 18/500
# 15/15 - 0s - loss: 0.0636 - val_loss: 0.0949 - 279ms/epoch - 19ms/step
# Epoch 19/500
# 15/15 - 0s - loss: 0.0682 - val_loss: 0.0881 - 309ms/epoch - 21ms/step
# Epoch 20/500
# 15/15 - 0s - loss: 0.0526 - val_loss: 0.0893 - 218ms/epoch - 15ms/step
# Epoch 21/500
# 15/15 - 0s - loss: 0.0609 - val_loss: 0.0875 - 304ms/epoch - 20ms/step
# Epoch 22/500
# 15/15 - 0s - loss: 0.0524 - val_loss: 0.0959 - 268ms/epoch - 18ms/step
# Epoch 23/500
# 15/15 - 0s - loss: 0.0638 - val_loss: 0.0985 - 219ms/epoch - 15ms/step
# Epoch 24/500
# 15/15 - 0s - loss: 0.0606 - val_loss: 0.1158 - 293ms/epoch - 20ms/step
# Epoch 25/500
# 15/15 - 0s - loss: 0.0766 - val_loss: 0.1245 - 242ms/epoch - 16ms/step
# Epoch 26/500
# 15/15 - 0s - loss: 0.0795 - val_loss: 0.1539 - 210ms/epoch - 14ms/step
# Epoch 27/500
# 15/15 - 0s - loss: 0.1021 - val_loss: 0.1695 - 260ms/epoch - 17ms/step
# Epoch 28/500
# 15/15 - 0s - loss: 0.1118 - val_loss: 0.2098 - 224ms/epoch - 15ms/step
# Epoch 29/500
# 15/15 - 0s - loss: 0.1400 - val_loss: 0.2232 - 264ms/epoch - 18ms/step
# Epoch 30/500
# 15/15 - 0s - loss: 0.1507 - val_loss: 0.2568 - 210ms/epoch - 14ms/step
# Epoch 31/500
# 15/15 - 0s - loss: 0.1732 - val_loss: 0.2455 - 206ms/epoch - 14ms/step
# Epoch 32/500
# 15/15 - 0s - loss: 0.1693 - val_loss: 0.2470 - 292ms/epoch - 19ms/step
# Epoch 33/500
# 15/15 - 0s - loss: 0.1693 - val_loss: 0.2048 - 247ms/epoch - 16ms/step
# Epoch 34/500
# 15/15 - 0s - loss: 0.1440 - val_loss: 0.1827 - 264ms/epoch - 18ms/step
# Epoch 35/500
# 15/15 - 0s - loss: 0.1262 - val_loss: 0.1387 - 295ms/epoch - 20ms/step
# Epoch 36/500
# 15/15 - 0s - loss: 0.0970 - val_loss: 0.1206 - 461ms/epoch - 31ms/step
# Epoch 37/500
# 15/15 - 0s - loss: 0.0810 - val_loss: 0.0929 - 240ms/epoch - 16ms/step
# Epoch 38/500
# 15/15 - 0s - loss: 0.0622 - val_loss: 0.0856 - 278ms/epoch - 19ms/step
# Epoch 39/500
# 15/15 - 0s - loss: 0.0542 - val_loss: 0.0705 - 230ms/epoch - 15ms/step
# Epoch 40/500
# 15/15 - 0s - loss: 0.0445 - val_loss: 0.0695 - 227ms/epoch - 15ms/step
# Epoch 41/500
# 15/15 - 0s - loss: 0.0417 - val_loss: 0.0608 - 242ms/epoch - 16ms/step
# Epoch 42/500
# 15/15 - 0s - loss: 0.0368 - val_loss: 0.0627 - 319ms/epoch - 21ms/step
# Epoch 43/500
# 15/15 - 0s - loss: 0.0363 - val_loss: 0.0572 - 296ms/epoch - 20ms/step
# Epoch 44/500
# 15/15 - 0s - loss: 0.0338 - val_loss: 0.0608 - 230ms/epoch - 15ms/step
# Epoch 45/500
# 15/15 - 0s - loss: 0.0346 - val_loss: 0.0570 - 239ms/epoch - 16ms/step
# Epoch 46/500
# 15/15 - 0s - loss: 0.0336 - val_loss: 0.0622 - 297ms/epoch - 20ms/step
# Epoch 47/500
# 15/15 - 0s - loss: 0.0353 - val_loss: 0.0599 - 298ms/epoch - 20ms/step
# Epoch 48/500
# 15/15 - 0s - loss: 0.0356 - val_loss: 0.0673 - 291ms/epoch - 19ms/step
# Epoch 49/500
# 15/15 - 0s - loss: 0.0386 - val_loss: 0.0668 - 272ms/epoch - 18ms/step
# Epoch 50/500
# 15/15 - 0s - loss: 0.0405 - val_loss: 0.0779 - 226ms/epoch - 15ms/step
# Epoch 51/500
# 15/15 - 0s - loss: 0.0455 - val_loss: 0.0803 - 281ms/epoch - 19ms/step
# Epoch 52/500
# 15/15 - 0s - loss: 0.0500 - val_loss: 0.0973 - 245ms/epoch - 16ms/step
# Epoch 53/500
# 15/15 - 0s - loss: 0.0584 - val_loss: 0.1045 - 231ms/epoch - 15ms/step
# Epoch 54/500
# 15/15 - 0s - loss: 0.0668 - val_loss: 0.1302 - 246ms/epoch - 16ms/step
# Epoch 55/500
# 15/15 - 0s - loss: 0.0803 - val_loss: 0.1437 - 212ms/epoch - 14ms/step
# Epoch 56/500
# 15/15 - 0s - loss: 0.0936 - val_loss: 0.1783 - 219ms/epoch - 15ms/step
# Epoch 57/500
# 15/15 - 0s - loss: 0.1125 - val_loss: 0.1942 - 194ms/epoch - 13ms/step
# Epoch 58/500
# 15/15 - 0s - loss: 0.1282 - val_loss: 0.2282 - 169ms/epoch - 11ms/step
# Epoch 59/500
# 15/15 - 0s - loss: 0.1468 - val_loss: 0.2316 - 207ms/epoch - 14ms/step
# Epoch 60/500
# 15/15 - 0s - loss: 0.1548 - val_loss: 0.2442 - 229ms/epoch - 15ms/step
# Epoch 61/500
# 15/15 - 0s - loss: 0.1603 - val_loss: 0.2194 - 208ms/epoch - 14ms/step
# Epoch 62/500
# 15/15 - 0s - loss: 0.1491 - val_loss: 0.2029 - 192ms/epoch - 13ms/step
# Epoch 63/500
# 15/15 - 0s - loss: 0.1357 - val_loss: 0.1616 - 224ms/epoch - 15ms/step
# Epoch 64/500
# 15/15 - 0s - loss: 0.1108 - val_loss: 0.1374 - 245ms/epoch - 16ms/step
# Epoch 65/500
# 15/15 - 0s - loss: 0.0916 - val_loss: 0.1044 - 217ms/epoch - 14ms/step
# Epoch 66/500
# 15/15 - 0s - loss: 0.0699 - val_loss: 0.0895 - 274ms/epoch - 18ms/step
# Epoch 67/500
# 15/15 - 0s - loss: 0.0573 - val_loss: 0.0710 - 212ms/epoch - 14ms/step
# Epoch 68/500
# 15/15 - 0s - loss: 0.0448 - val_loss: 0.0649 - 195ms/epoch - 13ms/step
# Epoch 69/500
# 15/15 - 0s - loss: 0.0390 - val_loss: 0.0554 - 182ms/epoch - 12ms/step
# Epoch 70/500
# 15/15 - 0s - loss: 0.0328 - val_loss: 0.0536 - 181ms/epoch - 12ms/step
# Epoch 71/500
# 15/15 - 0s - loss: 0.0304 - val_loss: 0.0484 - 193ms/epoch - 13ms/step
# Epoch 72/500
# 15/15 - 0s - loss: 0.0274 - val_loss: 0.0484 - 177ms/epoch - 12ms/step
# Epoch 73/500
# 15/15 - 0s - loss: 0.0265 - val_loss: 0.0453 - 276ms/epoch - 18ms/step
# Epoch 74/500
# 15/15 - 0s - loss: 0.0249 - val_loss: 0.0460 - 260ms/epoch - 17ms/step
# Epoch 75/500
# 15/15 - 0s - loss: 0.0247 - val_loss: 0.0439 - 262ms/epoch - 17ms/step
# Epoch 76/500
# 15/15 - 0s - loss: 0.0238 - val_loss: 0.0450 - 245ms/epoch - 16ms/step
# Epoch 77/500
# 15/15 - 0s - loss: 0.0240 - val_loss: 0.0436 - 194ms/epoch - 13ms/step
# Epoch 78/500
# 15/15 - 0s - loss: 0.0236 - val_loss: 0.0451 - 219ms/epoch - 15ms/step
# Epoch 79/500
# 15/15 - 0s - loss: 0.0240 - val_loss: 0.0442 - 151ms/epoch - 10ms/step
# Epoch 80/500
# 15/15 - 0s - loss: 0.0239 - val_loss: 0.0462 - 130ms/epoch - 9ms/step
# Epoch 81/500
# 15/15 - 0s - loss: 0.0247 - val_loss: 0.0457 - 137ms/epoch - 9ms/step
# Epoch 82/500
# 15/15 - 0s - loss: 0.0250 - val_loss: 0.0486 - 150ms/epoch - 10ms/step
# Epoch 83/500
# 15/15 - 0s - loss: 0.0262 - val_loss: 0.0488 - 146ms/epoch - 10ms/step
# Epoch 84/500
# 15/15 - 0s - loss: 0.0271 - val_loss: 0.0531 - 151ms/epoch - 10ms/step
# Epoch 85/500
# 15/15 - 0s - loss: 0.0291 - val_loss: 0.0546 - 143ms/epoch - 10ms/step
# Epoch 86/500
# 15/15 - 0s - loss: 0.0309 - val_loss: 0.0612 - 149ms/epoch - 10ms/step
# Epoch 87/500
# 15/15 - 0s - loss: 0.0343 - val_loss: 0.0650 - 149ms/epoch - 10ms/step
# Epoch 88/500
# 15/15 - 0s - loss: 0.0378 - val_loss: 0.0756 - 182ms/epoch - 12ms/step
# Epoch 89/500
# 15/15 - 0s - loss: 0.0435 - val_loss: 0.0834 - 174ms/epoch - 12ms/step
# Epoch 90/500
# 15/15 - 0s - loss: 0.0499 - val_loss: 0.1005 - 175ms/epoch - 12ms/step
# Epoch 91/500
# 15/15 - 0s - loss: 0.0595 - val_loss: 0.1145 - 165ms/epoch - 11ms/step
# Epoch 92/500
# 15/15 - 0s - loss: 0.0701 - val_loss: 0.1399 - 173ms/epoch - 12ms/step
# Epoch 93/500
# 15/15 - 0s - loss: 0.0850 - val_loss: 0.1604 - 168ms/epoch - 11ms/step
# Epoch 94/500
# 15/15 - 0s - loss: 0.1000 - val_loss: 0.1917 - 183ms/epoch - 12ms/step
# Epoch 95/500
# 15/15 - 0s - loss: 0.1188 - val_loss: 0.2112 - 171ms/epoch - 11ms/step
# Epoch 96/500
# 15/15 - 0s - loss: 0.1335 - val_loss: 0.2344 - 183ms/epoch - 12ms/step
# Epoch 97/500
# 15/15 - 0s - loss: 0.1481 - val_loss: 0.2345 - 209ms/epoch - 14ms/step
# Epoch 98/500
# 15/15 - 0s - loss: 0.1508 - val_loss: 0.2299 - 189ms/epoch - 13ms/step
# Epoch 99/500
# 15/15 - 0s - loss: 0.1487 - val_loss: 0.2004 - 177ms/epoch - 12ms/step
# Epoch 100/500
# 15/15 - 0s - loss: 0.1315 - val_loss: 0.1721 - 160ms/epoch - 11ms/step
# Epoch 101/500
# 15/15 - 0s - loss: 0.1135 - val_loss: 0.1338 - 156ms/epoch - 10ms/step
# Epoch 102/500
# 15/15 - 0s - loss: 0.0883 - val_loss: 0.1079 - 173ms/epoch - 12ms/step
# Epoch 103/500
# 15/15 - 0s - loss: 0.0703 - val_loss: 0.0826 - 182ms/epoch - 12ms/step
# Epoch 104/500
# 15/15 - 0s - loss: 0.0525 - val_loss: 0.0693 - 204ms/epoch - 14ms/step
# Epoch 105/500
# 15/15 - 0s - loss: 0.0427 - val_loss: 0.0570 - 202ms/epoch - 13ms/step
# Epoch 106/500
# 15/15 - 0s - loss: 0.0337 - val_loss: 0.0517 - 196ms/epoch - 13ms/step
# Epoch 107/500
# 15/15 - 0s - loss: 0.0297 - val_loss: 0.0462 - 173ms/epoch - 12ms/step
# Epoch 108/500
# 15/15 - 0s - loss: 0.0256 - val_loss: 0.0443 - 249ms/epoch - 17ms/step
# Epoch 109/500
# 15/15 - 0s - loss: 0.0241 - val_loss: 0.0416 - 188ms/epoch - 13ms/step
# Epoch 110/500
# 15/15 - 0s - loss: 0.0222 - val_loss: 0.0410 - 188ms/epoch - 13ms/step
# Epoch 111/500
# 15/15 - 0s - loss: 0.0217 - val_loss: 0.0396 - 171ms/epoch - 11ms/step
# Epoch 112/500
# 15/15 - 0s - loss: 0.0207 - val_loss: 0.0395 - 158ms/epoch - 11ms/step
# Epoch 113/500
# 15/15 - 0s - loss: 0.0205 - val_loss: 0.0386 - 168ms/epoch - 11ms/step
# Epoch 114/500
# 15/15 - 0s - loss: 0.0200 - val_loss: 0.0387 - 163ms/epoch - 11ms/step
# Epoch 115/500
# 15/15 - 0s - loss: 0.0200 - val_loss: 0.0381 - 152ms/epoch - 10ms/step
# Epoch 116/500
# 15/15 - 0s - loss: 0.0197 - val_loss: 0.0384 - 171ms/epoch - 11ms/step
# Epoch 117/500
# 15/15 - 0s - loss: 0.0197 - val_loss: 0.0380 - 219ms/epoch - 15ms/step
# Epoch 118/500
# 15/15 - 0s - loss: 0.0195 - val_loss: 0.0383 - 161ms/epoch - 11ms/step
# Epoch 119/500
# 15/15 - 0s - loss: 0.0196 - val_loss: 0.0380 - 187ms/epoch - 12ms/step
# Epoch 120/500
# 15/15 - 0s - loss: 0.0195 - val_loss: 0.0384 - 149ms/epoch - 10ms/step
# Epoch 121/500
# 15/15 - 0s - loss: 0.0197 - val_loss: 0.0382 - 153ms/epoch - 10ms/step
# Epoch 122/500
# 15/15 - 0s - loss: 0.0197 - val_loss: 0.0389 - 151ms/epoch - 10ms/step
# Epoch 123/500
# 15/15 - 0s - loss: 0.0200 - val_loss: 0.0388 - 144ms/epoch - 10ms/step
# Epoch 124/500
# 15/15 - 0s - loss: 0.0201 - val_loss: 0.0396 - 157ms/epoch - 10ms/step
# Epoch 125/500
# 15/15 - 0s - loss: 0.0205 - val_loss: 0.0398 - 158ms/epoch - 11ms/step
# Epoch 126/500
# 15/15 - 0s - loss: 0.0207 - val_loss: 0.0411 - 168ms/epoch - 11ms/step
# Epoch 127/500
# 15/15 - 0s - loss: 0.0213 - val_loss: 0.0416 - 156ms/epoch - 10ms/step
# Epoch 128/500
# 15/15 - 0s - loss: 0.0218 - val_loss: 0.0435 - 168ms/epoch - 11ms/step
# Epoch 129/500
# 15/15 - 0s - loss: 0.0228 - val_loss: 0.0447 - 191ms/epoch - 13ms/step
# Epoch 130/500
# 15/15 - 0s - loss: 0.0238 - val_loss: 0.0478 - 406ms/epoch - 27ms/step
# Epoch 131/500
# 15/15 - 0s - loss: 0.0254 - val_loss: 0.0502 - 275ms/epoch - 18ms/step
# Epoch 132/500
# 15/15 - 0s - loss: 0.0272 - val_loss: 0.0553 - 160ms/epoch - 11ms/step
# Epoch 133/500
# 15/15 - 0s - loss: 0.0300 - val_loss: 0.0599 - 161ms/epoch - 11ms/step
# Epoch 134/500
# 15/15 - 0s - loss: 0.0332 - val_loss: 0.0684 - 156ms/epoch - 10ms/step
# Epoch 135/500
# 15/15 - 0s - loss: 0.0379 - val_loss: 0.0767 - 165ms/epoch - 11ms/step
# Epoch 136/500
# 15/15 - 0s - loss: 0.0434 - val_loss: 0.0905 - 156ms/epoch - 10ms/step
# Epoch 137/500
# 15/15 - 0s - loss: 0.0514 - val_loss: 0.1046 - 146ms/epoch - 10ms/step
# Epoch 138/500
# 15/15 - 0s - loss: 0.0604 - val_loss: 0.1256 - 172ms/epoch - 11ms/step
# Epoch 139/500
# 15/15 - 0s - loss: 0.0728 - val_loss: 0.1464 - 165ms/epoch - 11ms/step
# Epoch 140/500
# 15/15 - 0s - loss: 0.0860 - val_loss: 0.1740 - 157ms/epoch - 10ms/step
# Epoch 141/500
# 15/15 - 0s - loss: 0.1029 - val_loss: 0.1974 - 174ms/epoch - 12ms/step
# Epoch 142/500
# 15/15 - 0s - loss: 0.1180 - val_loss: 0.2225 - 165ms/epoch - 11ms/step
# Epoch 143/500
# 15/15 - 0s - loss: 0.1344 - val_loss: 0.2331 - 161ms/epoch - 11ms/step
# Epoch 144/500
# 15/15 - 0s - loss: 0.1422 - val_loss: 0.2357 - 144ms/epoch - 10ms/step
# Epoch 145/500
# 15/15 - 0s - loss: 0.1462 - val_loss: 0.2157 - 152ms/epoch - 10ms/step
# Epoch 146/500
# 15/15 - 0s - loss: 0.1351 - val_loss: 0.1882 - 145ms/epoch - 10ms/step
# Epoch 147/500
# 15/15 - 0s - loss: 0.1202 - val_loss: 0.1489 - 153ms/epoch - 10ms/step
# Epoch 148/500
# 15/15 - 0s - loss: 0.0952 - val_loss: 0.1170 - 154ms/epoch - 10ms/step
# Epoch 149/500
# 15/15 - 0s - loss: 0.0753 - val_loss: 0.0875 - 151ms/epoch - 10ms/step
# Epoch 150/500
# 15/15 - 0s - loss: 0.0549 - val_loss: 0.0700 - 153ms/epoch - 10ms/step
# Epoch 151/500
# 15/15 - 0s - loss: 0.0431 - val_loss: 0.0562 - 176ms/epoch - 12ms/step
# Epoch 152/500
# 15/15 - 0s - loss: 0.0328 - val_loss: 0.0494 - 175ms/epoch - 12ms/step
# Epoch 153/500
# 15/15 - 0s - loss: 0.0281 - val_loss: 0.0439 - 185ms/epoch - 12ms/step
# Epoch 154/500
# 15/15 - 0s - loss: 0.0239 - val_loss: 0.0416 - 183ms/epoch - 12ms/step
# Epoch 155/500
# 15/15 - 0s - loss: 0.0223 - val_loss: 0.0393 - 175ms/epoch - 12ms/step
# Epoch 156/500
# 15/15 - 0s - loss: 0.0206 - val_loss: 0.0385 - 166ms/epoch - 11ms/step
# Epoch 157/500
# 15/15 - 0s - loss: 0.0200 - val_loss: 0.0375 - 174ms/epoch - 12ms/step
# Epoch 158/500
# 15/15 - 0s - loss: 0.0193 - val_loss: 0.0372 - 163ms/epoch - 11ms/step
# Epoch 159/500
# 15/15 - 0s - loss: 0.0191 - val_loss: 0.0367 - 158ms/epoch - 11ms/step
# Epoch 160/500
# 15/15 - 0s - loss: 0.0187 - val_loss: 0.0366 - 174ms/epoch - 12ms/step
# Epoch 161/500
# 15/15 - 0s - loss: 0.0186 - val_loss: 0.0363 - 184ms/epoch - 12ms/step
# Epoch 162/500
# 15/15 - 0s - loss: 0.0184 - val_loss: 0.0363 - 173ms/epoch - 12ms/step
# Epoch 163/500
# 15/15 - 0s - loss: 0.0184 - val_loss: 0.0361 - 225ms/epoch - 15ms/step
# Epoch 164/500
# 15/15 - 0s - loss: 0.0183 - val_loss: 0.0362 - 164ms/epoch - 11ms/step
# Epoch 165/500
# 15/15 - 0s - loss: 0.0183 - val_loss: 0.0360 - 182ms/epoch - 12ms/step
# Epoch 166/500
# 15/15 - 0s - loss: 0.0182 - val_loss: 0.0361 - 173ms/epoch - 12ms/step
# Epoch 167/500
# 15/15 - 0s - loss: 0.0182 - val_loss: 0.0359 - 169ms/epoch - 11ms/step
# Epoch 168/500
# 15/15 - 0s - loss: 0.0182 - val_loss: 0.0361 - 163ms/epoch - 11ms/step
# Epoch 169/500
# 15/15 - 0s - loss: 0.0182 - val_loss: 0.0359 - 179ms/epoch - 12ms/step
# Epoch 170/500
# 15/15 - 0s - loss: 0.0182 - val_loss: 0.0361 - 175ms/epoch - 12ms/step
# Epoch 171/500
# 15/15 - 0s - loss: 0.0182 - val_loss: 0.0360 - 174ms/epoch - 12ms/step
# Epoch 172/500
# 15/15 - 0s - loss: 0.0182 - val_loss: 0.0361 - 176ms/epoch - 12ms/step
# Epoch 173/500
# 15/15 - 0s - loss: 0.0183 - val_loss: 0.0360 - 234ms/epoch - 16ms/step
# Epoch 174/500
# 15/15 - 0s - loss: 0.0182 - val_loss: 0.0363 - 191ms/epoch - 13ms/step
# Epoch 175/500
# 15/15 - 0s - loss: 0.0183 - val_loss: 0.0362 - 186ms/epoch - 12ms/step
# Epoch 176/500
# 15/15 - 0s - loss: 0.0183 - val_loss: 0.0365 - 178ms/epoch - 12ms/step
# Epoch 177/500
# 15/15 - 0s - loss: 0.0184 - val_loss: 0.0364 - 175ms/epoch - 12ms/step
# Epoch 178/500
# 15/15 - 0s - loss: 0.0185 - val_loss: 0.0368 - 166ms/epoch - 11ms/step
# Epoch 179/500
# 15/15 - 0s - loss: 0.0186 - val_loss: 0.0368 - 182ms/epoch - 12ms/step
# Epoch 180/500
# 15/15 - 0s - loss: 0.0187 - val_loss: 0.0374 - 166ms/epoch - 11ms/step
# Epoch 181/500
# 15/15 - 0s - loss: 0.0190 - val_loss: 0.0375 - 158ms/epoch - 11ms/step
# Epoch 182/500
# 15/15 - 0s - loss: 0.0191 - val_loss: 0.0383 - 174ms/epoch - 12ms/step
# Epoch 183/500
# 15/15 - 0s - loss: 0.0194 - val_loss: 0.0386 - 170ms/epoch - 11ms/step
# Epoch 184/500
# 15/15 - 0s - loss: 0.0197 - val_loss: 0.0397 - 179ms/epoch - 12ms/step
# Epoch 185/500
# 15/15 - 0s - loss: 0.0202 - val_loss: 0.0403 - 169ms/epoch - 11ms/step
# Epoch 186/500
# 15/15 - 0s - loss: 0.0207 - val_loss: 0.0419 - 202ms/epoch - 13ms/step
# Epoch 187/500
# 15/15 - 0s - loss: 0.0215 - val_loss: 0.0430 - 161ms/epoch - 11ms/step
# Epoch 188/500
# 15/15 - 0s - loss: 0.0222 - val_loss: 0.0454 - 157ms/epoch - 10ms/step
# Epoch 189/500
# 15/15 - 0s - loss: 0.0234 - val_loss: 0.0473 - 163ms/epoch - 11ms/step
# Epoch 190/500
# 15/15 - 0s - loss: 0.0245 - val_loss: 0.0508 - 156ms/epoch - 10ms/step
# Epoch 191/500
# 15/15 - 0s - loss: 0.0262 - val_loss: 0.0537 - 143ms/epoch - 10ms/step
# Epoch 192/500
# 15/15 - 0s - loss: 0.0280 - val_loss: 0.0587 - 169ms/epoch - 11ms/step
# Epoch 193/500
# 15/15 - 0s - loss: 0.0305 - val_loss: 0.0632 - 164ms/epoch - 11ms/step
# Epoch 194/500
# 15/15 - 0s - loss: 0.0331 - val_loss: 0.0703 - 149ms/epoch - 10ms/step
# Epoch 195/500
# 15/15 - 0s - loss: 0.0367 - val_loss: 0.0770 - 141ms/epoch - 9ms/step
# Epoch 196/500
# 15/15 - 0s - loss: 0.0405 - val_loss: 0.0869 - 178ms/epoch - 12ms/step
# Epoch 197/500
# 15/15 - 0s - loss: 0.0457 - val_loss: 0.0964 - 174ms/epoch - 12ms/step
# Epoch 198/500
# 15/15 - 0s - loss: 0.0511 - val_loss: 0.1102 - 175ms/epoch - 12ms/step
# Epoch 199/500
# 15/15 - 0s - loss: 0.0587 - val_loss: 0.1236 - 160ms/epoch - 11ms/step
# Epoch 200/500
# 15/15 - 0s - loss: 0.0665 - val_loss: 0.1423 - 176ms/epoch - 12ms/step
# Epoch 201/500
# 15/15 - 0s - loss: 0.0774 - val_loss: 0.1600 - 183ms/epoch - 12ms/step
# Epoch 202/500
# 15/15 - 0s - loss: 0.0878 - val_loss: 0.1829 - 194ms/epoch - 13ms/step
# Epoch 203/500
# 15/15 - 0s - loss: 0.1020 - val_loss: 0.2010 - 186ms/epoch - 12ms/step
# Epoch 204/500
# 15/15 - 0s - loss: 0.1132 - val_loss: 0.2199 - 154ms/epoch - 10ms/step
# Epoch 205/500
# 15/15 - 0s - loss: 0.1264 - val_loss: 0.2243 - 291ms/epoch - 19ms/step
# Epoch 206/500
# 15/15 - 0s - loss: 0.1301 - val_loss: 0.2204 - 177ms/epoch - 12ms/step
# Epoch 207/500
# 15/15 - 0s - loss: 0.1312 - val_loss: 0.1954 - 146ms/epoch - 10ms/step
# Epoch 208/500
# 15/15 - 0s - loss: 0.1173 - val_loss: 0.1651 - 157ms/epoch - 10ms/step
# Epoch 209/500
# 15/15 - 0s - loss: 0.1018 - val_loss: 0.1257 - 140ms/epoch - 9ms/step
# Epoch 210/500
# 15/15 - 0s - loss: 0.0775 - val_loss: 0.0996 - 147ms/epoch - 10ms/step
# Epoch 211/500
# 15/15 - 0s - loss: 0.0611 - val_loss: 0.0746 - 154ms/epoch - 10ms/step
# Epoch 212/500
# 15/15 - 0s - loss: 0.0444 - val_loss: 0.0607 - 164ms/epoch - 11ms/step
# Epoch 213/500
# 15/15 - 0s - loss: 0.0357 - val_loss: 0.0497 - 144ms/epoch - 10ms/step
# Epoch 214/500
# 15/15 - 0s - loss: 0.0279 - val_loss: 0.0447 - 188ms/epoch - 13ms/step
# Epoch 215/500
# 15/15 - 0s - loss: 0.0245 - val_loss: 0.0405 - 181ms/epoch - 12ms/step
# Epoch 216/500
# 15/15 - 0s - loss: 0.0214 - val_loss: 0.0390 - 194ms/epoch - 13ms/step
# Epoch 217/500
# 15/15 - 0s - loss: 0.0204 - val_loss: 0.0374 - 168ms/epoch - 11ms/step
# Epoch 218/500
# 15/15 - 0s - loss: 0.0192 - val_loss: 0.0369 - 172ms/epoch - 11ms/step
# Epoch 219/500
# 15/15 - 0s - loss: 0.0189 - val_loss: 0.0362 - 213ms/epoch - 14ms/step
# Epoch 220/500
# 15/15 - 0s - loss: 0.0184 - val_loss: 0.0361 - 240ms/epoch - 16ms/step
# Epoch 221/500
# 15/15 - 0s - loss: 0.0183 - val_loss: 0.0358 - 200ms/epoch - 13ms/step
# Epoch 222/500
# 15/15 - 0s - loss: 0.0181 - val_loss: 0.0358 - 170ms/epoch - 11ms/step
# Epoch 223/500
# 15/15 - 0s - loss: 0.0181 - val_loss: 0.0356 - 171ms/epoch - 11ms/step
# Epoch 224/500
# 15/15 - 0s - loss: 0.0179 - val_loss: 0.0356 - 180ms/epoch - 12ms/step
# Epoch 225/500
# 15/15 - 0s - loss: 0.0179 - val_loss: 0.0355 - 196ms/epoch - 13ms/step
# Epoch 226/500
# 15/15 - 0s - loss: 0.0179 - val_loss: 0.0355 - 192ms/epoch - 13ms/step
# Epoch 227/500
# 15/15 - 0s - loss: 0.0179 - val_loss: 0.0354 - 171ms/epoch - 11ms/step
# Epoch 228/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0355 - 157ms/epoch - 10ms/step
# Epoch 229/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0354 - 204ms/epoch - 14ms/step
# Epoch 230/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0354 - 192ms/epoch - 13ms/step
# Epoch 231/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0354 - 209ms/epoch - 14ms/step
# Epoch 232/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0354 - 198ms/epoch - 13ms/step
# Epoch 233/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0353 - 198ms/epoch - 13ms/step
# Epoch 234/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0354 - 178ms/epoch - 12ms/step
# Epoch 235/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0353 - 181ms/epoch - 12ms/step
# Epoch 236/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0354 - 167ms/epoch - 11ms/step
# Epoch 237/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0353 - 159ms/epoch - 11ms/step
# Epoch 238/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0354 - 169ms/epoch - 11ms/step
# Epoch 239/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0353 - 166ms/epoch - 11ms/step
# Epoch 240/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0354 - 195ms/epoch - 13ms/step
# Epoch 241/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0353 - 195ms/epoch - 13ms/step
# Epoch 242/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0354 - 172ms/epoch - 11ms/step
# Epoch 243/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0354 - 160ms/epoch - 11ms/step
# Epoch 244/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0355 - 180ms/epoch - 12ms/step
# Epoch 245/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0354 - 184ms/epoch - 12ms/step
# Epoch 246/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0355 - 193ms/epoch - 13ms/step
# Epoch 247/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0354 - 170ms/epoch - 11ms/step
# Epoch 248/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0356 - 203ms/epoch - 14ms/step
# Epoch 249/500
# 15/15 - 0s - loss: 0.0179 - val_loss: 0.0355 - 196ms/epoch - 13ms/step
# Epoch 250/500
# 15/15 - 0s - loss: 0.0179 - val_loss: 0.0356 - 377ms/epoch - 25ms/step
# Epoch 251/500
# 15/15 - 0s - loss: 0.0179 - val_loss: 0.0356 - 239ms/epoch - 16ms/step
# Epoch 252/500
# 15/15 - 0s - loss: 0.0179 - val_loss: 0.0357 - 195ms/epoch - 13ms/step
# Epoch 253/500
# 15/15 - 0s - loss: 0.0179 - val_loss: 0.0356 - 186ms/epoch - 12ms/step
# Epoch 254/500
# 15/15 - 0s - loss: 0.0179 - val_loss: 0.0358 - 160ms/epoch - 11ms/step
# Epoch 255/500
# 15/15 - 0s - loss: 0.0180 - val_loss: 0.0357 - 153ms/epoch - 10ms/step
# Epoch 256/500
# 15/15 - 0s - loss: 0.0180 - val_loss: 0.0359 - 166ms/epoch - 11ms/step
# Epoch 257/500
# 15/15 - 0s - loss: 0.0180 - val_loss: 0.0358 - 175ms/epoch - 12ms/step
# Epoch 258/500
# 15/15 - 0s - loss: 0.0180 - val_loss: 0.0359 - 200ms/epoch - 13ms/step
# Epoch 259/500
# 15/15 - 0s - loss: 0.0180 - val_loss: 0.0358 - 151ms/epoch - 10ms/step
# Epoch 260/500
# 15/15 - 0s - loss: 0.0180 - val_loss: 0.0359 - 180ms/epoch - 12ms/step
# Epoch 261/500
# 15/15 - 0s - loss: 0.0180 - val_loss: 0.0358 - 189ms/epoch - 13ms/step
# Epoch 262/500
# 15/15 - 0s - loss: 0.0180 - val_loss: 0.0358 - 166ms/epoch - 11ms/step
# Epoch 263/500
# 15/15 - 0s - loss: 0.0179 - val_loss: 0.0357 - 205ms/epoch - 14ms/step
# Epoch 264/500
# 15/15 - 0s - loss: 0.0179 - val_loss: 0.0357 - 215ms/epoch - 14ms/step
# Epoch 265/500
# 15/15 - 0s - loss: 0.0179 - val_loss: 0.0355 - 231ms/epoch - 15ms/step
# Epoch 266/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0355 - 202ms/epoch - 13ms/step
# Epoch 267/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0354 - 223ms/epoch - 15ms/step
# Epoch 268/500
# 15/15 - 0s - loss: 0.0177 - val_loss: 0.0353 - 163ms/epoch - 11ms/step
# Epoch 269/500
# 15/15 - 0s - loss: 0.0177 - val_loss: 0.0352 - 185ms/epoch - 12ms/step
# Epoch 270/500
# 15/15 - 0s - loss: 0.0177 - val_loss: 0.0352 - 183ms/epoch - 12ms/step
# Epoch 271/500
# 15/15 - 0s - loss: 0.0177 - val_loss: 0.0352 - 171ms/epoch - 11ms/step
# Epoch 272/500
# 15/15 - 0s - loss: 0.0177 - val_loss: 0.0352 - 152ms/epoch - 10ms/step
# Epoch 273/500
# 15/15 - 0s - loss: 0.0177 - val_loss: 0.0351 - 139ms/epoch - 9ms/step
# Epoch 274/500
# 15/15 - 0s - loss: 0.0177 - val_loss: 0.0351 - 157ms/epoch - 10ms/step
# Epoch 275/500
# 15/15 - 0s - loss: 0.0177 - val_loss: 0.0351 - 144ms/epoch - 10ms/step
# Epoch 276/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 159ms/epoch - 11ms/step
# Epoch 277/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 169ms/epoch - 11ms/step
# Epoch 278/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 160ms/epoch - 11ms/step
# Epoch 279/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 204ms/epoch - 14ms/step
# Epoch 280/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 193ms/epoch - 13ms/step
# Epoch 281/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 175ms/epoch - 12ms/step
# Epoch 282/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 203ms/epoch - 14ms/step
# Epoch 283/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 167ms/epoch - 11ms/step
# Epoch 284/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 188ms/epoch - 13ms/step
# Epoch 285/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 190ms/epoch - 13ms/step
# Epoch 286/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 214ms/epoch - 14ms/step
# Epoch 287/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 208ms/epoch - 14ms/step
# Epoch 288/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 176ms/epoch - 12ms/step
# Epoch 289/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 153ms/epoch - 10ms/step
# Epoch 290/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 160ms/epoch - 11ms/step
# Epoch 291/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 160ms/epoch - 11ms/step
# Epoch 292/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 180ms/epoch - 12ms/step
# Epoch 293/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 192ms/epoch - 13ms/step
# Epoch 294/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 223ms/epoch - 15ms/step
# Epoch 295/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 186ms/epoch - 12ms/step
# Epoch 296/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 176ms/epoch - 12ms/step
# Epoch 297/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 165ms/epoch - 11ms/step
# Epoch 298/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 168ms/epoch - 11ms/step
# Epoch 299/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 159ms/epoch - 11ms/step
# Epoch 300/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 162ms/epoch - 11ms/step
# Epoch 301/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 164ms/epoch - 11ms/step
# Epoch 302/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 156ms/epoch - 10ms/step
# Epoch 303/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 177ms/epoch - 12ms/step
# Epoch 304/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 182ms/epoch - 12ms/step
# Epoch 305/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 178ms/epoch - 12ms/step
# Epoch 306/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 183ms/epoch - 12ms/step
# Epoch 307/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 161ms/epoch - 11ms/step
# Epoch 308/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 194ms/epoch - 13ms/step
# Epoch 309/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 174ms/epoch - 12ms/step
# Epoch 310/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 186ms/epoch - 12ms/step
# Epoch 311/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 181ms/epoch - 12ms/step
# Epoch 312/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 162ms/epoch - 11ms/step
# Epoch 313/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 168ms/epoch - 11ms/step
# Epoch 314/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 208ms/epoch - 14ms/step
# Epoch 315/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 173ms/epoch - 12ms/step
# Epoch 316/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 175ms/epoch - 12ms/step
# Epoch 317/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0350 - 174ms/epoch - 12ms/step
# Epoch 318/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0350 - 159ms/epoch - 11ms/step
# Epoch 319/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0350 - 158ms/epoch - 11ms/step
# Epoch 320/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0350 - 166ms/epoch - 11ms/step
# Epoch 321/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0350 - 162ms/epoch - 11ms/step
# Epoch 322/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 153ms/epoch - 10ms/step
# Epoch 323/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 134ms/epoch - 9ms/step
# Epoch 324/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 147ms/epoch - 10ms/step
# Epoch 325/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 155ms/epoch - 10ms/step
# Epoch 326/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 160ms/epoch - 11ms/step
# Epoch 327/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 201ms/epoch - 13ms/step
# Epoch 328/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 148ms/epoch - 10ms/step
# Epoch 329/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 147ms/epoch - 10ms/step
# Epoch 330/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 145ms/epoch - 10ms/step
# Epoch 331/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 145ms/epoch - 10ms/step
# Epoch 332/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 152ms/epoch - 10ms/step
# Epoch 333/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 138ms/epoch - 9ms/step
# Epoch 334/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 144ms/epoch - 10ms/step
# Epoch 335/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 201ms/epoch - 13ms/step
# Epoch 336/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 173ms/epoch - 12ms/step
# Epoch 337/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 168ms/epoch - 11ms/step
# Epoch 338/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 164ms/epoch - 11ms/step
# Epoch 339/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 151ms/epoch - 10ms/step
# Epoch 340/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 327ms/epoch - 22ms/step
# Epoch 341/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0353 - 270ms/epoch - 18ms/step
# Epoch 342/500
# 15/15 - 0s - loss: 0.0180 - val_loss: 0.0356 - 247ms/epoch - 16ms/step
# Epoch 343/500
# 15/15 - 0s - loss: 0.0185 - val_loss: 0.0371 - 166ms/epoch - 11ms/step
# Epoch 344/500
# 15/15 - 0s - loss: 0.0201 - val_loss: 0.0398 - 156ms/epoch - 10ms/step
# Epoch 345/500
# 15/15 - 0s - loss: 0.0231 - val_loss: 0.0480 - 180ms/epoch - 12ms/step
# Epoch 346/500
# 15/15 - 0s - loss: 0.0314 - val_loss: 0.0651 - 235ms/epoch - 16ms/step
# Epoch 347/500
# 15/15 - 0s - loss: 0.0479 - val_loss: 0.1106 - 184ms/epoch - 12ms/step
# Epoch 348/500
# 15/15 - 0s - loss: 0.0856 - val_loss: 0.2145 - 188ms/epoch - 13ms/step
# Epoch 349/500
# 15/15 - 0s - loss: 0.1494 - val_loss: 0.4434 - 175ms/epoch - 12ms/step
# Epoch 350/500
# 15/15 - 0s - loss: 0.2329 - val_loss: 0.7585 - 177ms/epoch - 12ms/step
# Epoch 351/500
# 15/15 - 0s - loss: 0.2647 - val_loss: 0.4255 - 193ms/epoch - 13ms/step
# Epoch 352/500
# 15/15 - 0s - loss: 0.1489 - val_loss: 0.0541 - 250ms/epoch - 17ms/step
# Epoch 353/500
# 15/15 - 0s - loss: 0.0371 - val_loss: 0.0736 - 174ms/epoch - 12ms/step
# Epoch 354/500
# 15/15 - 0s - loss: 0.0380 - val_loss: 0.1027 - 158ms/epoch - 11ms/step
# Epoch 355/500
# 15/15 - 0s - loss: 0.0505 - val_loss: 0.1086 - 169ms/epoch - 11ms/step
# Epoch 356/500
# 15/15 - 0s - loss: 0.0581 - val_loss: 0.1299 - 177ms/epoch - 12ms/step
# Epoch 357/500
# 15/15 - 0s - loss: 0.0669 - val_loss: 0.1644 - 190ms/epoch - 13ms/step
# Epoch 358/500
# 15/15 - 0s - loss: 0.0867 - val_loss: 0.1890 - 184ms/epoch - 12ms/step
# Epoch 359/500
# 15/15 - 0s - loss: 0.0983 - val_loss: 0.2204 - 196ms/epoch - 13ms/step
# Epoch 360/500
# 15/15 - 0s - loss: 0.1173 - val_loss: 0.2221 - 204ms/epoch - 14ms/step
# Epoch 361/500
# 15/15 - 0s - loss: 0.1184 - val_loss: 0.2065 - 428ms/epoch - 29ms/step
# Epoch 362/500
# 15/15 - 0s - loss: 0.1152 - val_loss: 0.1527 - 187ms/epoch - 12ms/step
# Epoch 363/500
# 15/15 - 0s - loss: 0.0876 - val_loss: 0.1052 - 175ms/epoch - 12ms/step
# Epoch 364/500
# 15/15 - 0s - loss: 0.0632 - val_loss: 0.0647 - 177ms/epoch - 12ms/step
# Epoch 365/500
# 15/15 - 0s - loss: 0.0382 - val_loss: 0.0479 - 186ms/epoch - 12ms/step
# Epoch 366/500
# 15/15 - 0s - loss: 0.0272 - val_loss: 0.0388 - 164ms/epoch - 11ms/step
# Epoch 367/500
# 15/15 - 0s - loss: 0.0205 - val_loss: 0.0368 - 174ms/epoch - 12ms/step
# Epoch 368/500
# 15/15 - 0s - loss: 0.0189 - val_loss: 0.0355 - 172ms/epoch - 11ms/step
# Epoch 369/500
# 15/15 - 0s - loss: 0.0179 - val_loss: 0.0354 - 182ms/epoch - 12ms/step
# Epoch 370/500
# 15/15 - 0s - loss: 0.0178 - val_loss: 0.0351 - 179ms/epoch - 12ms/step
# Epoch 371/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0351 - 178ms/epoch - 12ms/step
# Epoch 372/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 179ms/epoch - 12ms/step
# Epoch 373/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 174ms/epoch - 12ms/step
# Epoch 374/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 184ms/epoch - 12ms/step
# Epoch 375/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 179ms/epoch - 12ms/step
# Epoch 376/500
# 15/15 - 0s - loss: 0.0176 - val_loss: 0.0350 - 185ms/epoch - 12ms/step
# Epoch 377/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0350 - 178ms/epoch - 12ms/step
# Epoch 378/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0350 - 185ms/epoch - 12ms/step
# Epoch 379/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0350 - 190ms/epoch - 13ms/step
# Epoch 380/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 193ms/epoch - 13ms/step
# Epoch 381/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 202ms/epoch - 13ms/step
# Epoch 382/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 189ms/epoch - 13ms/step
# Epoch 383/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 223ms/epoch - 15ms/step
# Epoch 384/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 177ms/epoch - 12ms/step
# Epoch 385/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 260ms/epoch - 17ms/step
# Epoch 386/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 194ms/epoch - 13ms/step
# Epoch 387/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 172ms/epoch - 11ms/step
# Epoch 388/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 151ms/epoch - 10ms/step
# Epoch 389/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 205ms/epoch - 14ms/step
# Epoch 390/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 202ms/epoch - 13ms/step
# Epoch 391/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 193ms/epoch - 13ms/step
# Epoch 392/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 166ms/epoch - 11ms/step
# Epoch 393/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0349 - 163ms/epoch - 11ms/step
# Epoch 394/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0348 - 151ms/epoch - 10ms/step
# Epoch 395/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0348 - 143ms/epoch - 10ms/step
# Epoch 396/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0348 - 169ms/epoch - 11ms/step
# Epoch 397/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0348 - 172ms/epoch - 11ms/step
# Epoch 398/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0348 - 167ms/epoch - 11ms/step
# Epoch 399/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0348 - 179ms/epoch - 12ms/step
# Epoch 400/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0348 - 218ms/epoch - 15ms/step
# Epoch 401/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0348 - 188ms/epoch - 13ms/step
# Epoch 402/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0348 - 242ms/epoch - 16ms/step
# Epoch 403/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0348 - 237ms/epoch - 16ms/step
# Epoch 404/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0348 - 248ms/epoch - 17ms/step
# Epoch 405/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0348 - 169ms/epoch - 11ms/step
# Epoch 406/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0348 - 178ms/epoch - 12ms/step
# Epoch 407/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0348 - 181ms/epoch - 12ms/step
# Epoch 408/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0347 - 201ms/epoch - 13ms/step
# Epoch 409/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0347 - 236ms/epoch - 16ms/step
# Epoch 410/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0347 - 331ms/epoch - 22ms/step
# Epoch 411/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0347 - 221ms/epoch - 15ms/step
# Epoch 412/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0347 - 266ms/epoch - 18ms/step
# Epoch 413/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0347 - 211ms/epoch - 14ms/step
# Epoch 414/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0347 - 207ms/epoch - 14ms/step
# Epoch 415/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0347 - 201ms/epoch - 13ms/step
# Epoch 416/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0347 - 194ms/epoch - 13ms/step
# Epoch 417/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0347 - 195ms/epoch - 13ms/step
# Epoch 418/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0347 - 219ms/epoch - 15ms/step
# Epoch 419/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0347 - 239ms/epoch - 16ms/step
# Epoch 420/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0347 - 217ms/epoch - 14ms/step
# Epoch 421/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0346 - 222ms/epoch - 15ms/step
# Epoch 422/500
# 15/15 - 0s - loss: 0.0174 - val_loss: 0.0346 - 201ms/epoch - 13ms/step
# Epoch 423/500
# 15/15 - 0s - loss: 0.0173 - val_loss: 0.0346 - 199ms/epoch - 13ms/step
# Epoch 424/500
# 15/15 - 0s - loss: 0.0173 - val_loss: 0.0346 - 182ms/epoch - 12ms/step
# Epoch 425/500
# 15/15 - 0s - loss: 0.0173 - val_loss: 0.0346 - 181ms/epoch - 12ms/step
# Epoch 426/500
# 15/15 - 0s - loss: 0.0173 - val_loss: 0.0346 - 215ms/epoch - 14ms/step
# Epoch 427/500
# 15/15 - 0s - loss: 0.0173 - val_loss: 0.0346 - 202ms/epoch - 13ms/step
# Epoch 428/500
# 15/15 - 0s - loss: 0.0173 - val_loss: 0.0346 - 188ms/epoch - 13ms/step
# Epoch 429/500
# 15/15 - 0s - loss: 0.0173 - val_loss: 0.0346 - 174ms/epoch - 12ms/step
# Epoch 430/500
# 15/15 - 0s - loss: 0.0173 - val_loss: 0.0346 - 202ms/epoch - 13ms/step
# Epoch 431/500
# 15/15 - 0s - loss: 0.0173 - val_loss: 0.0345 - 198ms/epoch - 13ms/step
# Epoch 432/500
# 15/15 - 0s - loss: 0.0173 - val_loss: 0.0345 - 244ms/epoch - 16ms/step
# Epoch 433/500
# 15/15 - 0s - loss: 0.0173 - val_loss: 0.0345 - 190ms/epoch - 13ms/step
# Epoch 434/500
# 15/15 - 0s - loss: 0.0173 - val_loss: 0.0345 - 203ms/epoch - 14ms/step
# Epoch 435/500
# 15/15 - 0s - loss: 0.0173 - val_loss: 0.0345 - 183ms/epoch - 12ms/step
# Epoch 436/500
# 15/15 - 0s - loss: 0.0173 - val_loss: 0.0345 - 208ms/epoch - 14ms/step
# Epoch 437/500
# 15/15 - 0s - loss: 0.0173 - val_loss: 0.0345 - 282ms/epoch - 19ms/step
# Epoch 438/500
# 15/15 - 0s - loss: 0.0173 - val_loss: 0.0345 - 220ms/epoch - 15ms/step
# Epoch 439/500
# 15/15 - 0s - loss: 0.0173 - val_loss: 0.0344 - 208ms/epoch - 14ms/step
# Epoch 440/500
# 15/15 - 0s - loss: 0.0172 - val_loss: 0.0344 - 232ms/epoch - 15ms/step
# Epoch 441/500
# 15/15 - 0s - loss: 0.0172 - val_loss: 0.0344 - 230ms/epoch - 15ms/step
# Epoch 442/500
# 15/15 - 0s - loss: 0.0172 - val_loss: 0.0344 - 181ms/epoch - 12ms/step
# Epoch 443/500
# 15/15 - 0s - loss: 0.0172 - val_loss: 0.0344 - 180ms/epoch - 12ms/step
# Epoch 444/500
# 15/15 - 0s - loss: 0.0172 - val_loss: 0.0344 - 222ms/epoch - 15ms/step
# Epoch 445/500
# 15/15 - 0s - loss: 0.0172 - val_loss: 0.0344 - 256ms/epoch - 17ms/step
# Epoch 446/500
# 15/15 - 0s - loss: 0.0172 - val_loss: 0.0343 - 168ms/epoch - 11ms/step
# Epoch 447/500
# 15/15 - 0s - loss: 0.0172 - val_loss: 0.0343 - 175ms/epoch - 12ms/step
# Epoch 448/500
# 15/15 - 0s - loss: 0.0172 - val_loss: 0.0343 - 224ms/epoch - 15ms/step
# Epoch 449/500
# 15/15 - 0s - loss: 0.0172 - val_loss: 0.0343 - 184ms/epoch - 12ms/step
# Epoch 450/500
# 15/15 - 0s - loss: 0.0172 - val_loss: 0.0343 - 201ms/epoch - 13ms/step
# Epoch 451/500
# 15/15 - 0s - loss: 0.0172 - val_loss: 0.0342 - 183ms/epoch - 12ms/step
# Epoch 452/500
# 15/15 - 0s - loss: 0.0171 - val_loss: 0.0342 - 135ms/epoch - 9ms/step
# Epoch 453/500
# 15/15 - 0s - loss: 0.0171 - val_loss: 0.0342 - 261ms/epoch - 17ms/step
# Epoch 454/500
# 15/15 - 0s - loss: 0.0171 - val_loss: 0.0342 - 178ms/epoch - 12ms/step
# Epoch 455/500
# 15/15 - 0s - loss: 0.0171 - val_loss: 0.0341 - 147ms/epoch - 10ms/step
# Epoch 456/500
# 15/15 - 0s - loss: 0.0171 - val_loss: 0.0341 - 142ms/epoch - 9ms/step
# Epoch 457/500
# 15/15 - 0s - loss: 0.0171 - val_loss: 0.0341 - 161ms/epoch - 11ms/step
# Epoch 458/500
# 15/15 - 0s - loss: 0.0171 - val_loss: 0.0341 - 174ms/epoch - 12ms/step
# Epoch 459/500
# 15/15 - 0s - loss: 0.0171 - val_loss: 0.0340 - 210ms/epoch - 14ms/step
# Epoch 460/500
# 15/15 - 0s - loss: 0.0170 - val_loss: 0.0340 - 209ms/epoch - 14ms/step
# Epoch 461/500
# 15/15 - 0s - loss: 0.0170 - val_loss: 0.0340 - 248ms/epoch - 17ms/step
# Epoch 462/500
# 15/15 - 0s - loss: 0.0170 - val_loss: 0.0340 - 217ms/epoch - 14ms/step
# Epoch 463/500
# 15/15 - 0s - loss: 0.0170 - val_loss: 0.0339 - 274ms/epoch - 18ms/step
# Epoch 464/500
# 15/15 - 0s - loss: 0.0170 - val_loss: 0.0339 - 214ms/epoch - 14ms/step
# Epoch 465/500
# 15/15 - 0s - loss: 0.0170 - val_loss: 0.0339 - 225ms/epoch - 15ms/step
# Epoch 466/500
# 15/15 - 0s - loss: 0.0169 - val_loss: 0.0338 - 252ms/epoch - 17ms/step
# Epoch 467/500
# 15/15 - 0s - loss: 0.0169 - val_loss: 0.0338 - 167ms/epoch - 11ms/step
# Epoch 468/500
# 15/15 - 0s - loss: 0.0169 - val_loss: 0.0337 - 199ms/epoch - 13ms/step
# Epoch 469/500
# 15/15 - 0s - loss: 0.0169 - val_loss: 0.0337 - 214ms/epoch - 14ms/step
# Epoch 470/500
# 15/15 - 0s - loss: 0.0169 - val_loss: 0.0337 - 233ms/epoch - 16ms/step
# Epoch 471/500
# 15/15 - 0s - loss: 0.0168 - val_loss: 0.0336 - 167ms/epoch - 11ms/step
# Epoch 472/500
# 15/15 - 0s - loss: 0.0168 - val_loss: 0.0336 - 175ms/epoch - 12ms/step
# Epoch 473/500
# 15/15 - 0s - loss: 0.0168 - val_loss: 0.0335 - 208ms/epoch - 14ms/step
# Epoch 474/500
# 15/15 - 0s - loss: 0.0168 - val_loss: 0.0335 - 212ms/epoch - 14ms/step
# Epoch 475/500
# 15/15 - 0s - loss: 0.0168 - val_loss: 0.0334 - 175ms/epoch - 12ms/step
# Epoch 476/500
# 15/15 - 0s - loss: 0.0167 - val_loss: 0.0334 - 204ms/epoch - 14ms/step
# Epoch 477/500
# 15/15 - 0s - loss: 0.0170 - val_loss: 0.0347 - 184ms/epoch - 12ms/step
# Epoch 478/500
# 15/15 - 0s - loss: 0.0191 - val_loss: 0.0384 - 205ms/epoch - 14ms/step
# Epoch 479/500
# 15/15 - 0s - loss: 0.0203 - val_loss: 0.0338 - 221ms/epoch - 15ms/step
# Epoch 480/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0351 - 189ms/epoch - 13ms/step
# Epoch 481/500
# 15/15 - 0s - loss: 0.0193 - val_loss: 0.0348 - 209ms/epoch - 14ms/step
# Epoch 482/500
# 15/15 - 0s - loss: 0.0186 - val_loss: 0.0370 - 199ms/epoch - 13ms/step
# Epoch 483/500
# 15/15 - 0s - loss: 0.0203 - val_loss: 0.0396 - 187ms/epoch - 12ms/step
# Epoch 484/500
# 15/15 - 0s - loss: 0.0236 - val_loss: 0.0442 - 185ms/epoch - 12ms/step
# Epoch 485/500
# 15/15 - 0s - loss: 0.0247 - val_loss: 0.0523 - 209ms/epoch - 14ms/step
# Epoch 486/500
# 15/15 - 0s - loss: 0.0320 - val_loss: 0.0676 - 169ms/epoch - 11ms/step
# Epoch 487/500
# 15/15 - 0s - loss: 0.0389 - val_loss: 0.0822 - 202ms/epoch - 13ms/step
# Epoch 488/500
# 15/15 - 0s - loss: 0.0435 - val_loss: 0.0984 - 271ms/epoch - 18ms/step
# Epoch 489/500
# 15/15 - 0s - loss: 0.0509 - val_loss: 0.1103 - 222ms/epoch - 15ms/step
# Epoch 490/500
# 15/15 - 0s - loss: 0.0479 - val_loss: 0.0918 - 230ms/epoch - 15ms/step
# Epoch 491/500
# 15/15 - 0s - loss: 0.0362 - val_loss: 0.0570 - 210ms/epoch - 14ms/step
# Epoch 492/500
# 15/15 - 0s - loss: 0.0229 - val_loss: 0.0367 - 240ms/epoch - 16ms/step
# Epoch 493/500
# 15/15 - 0s - loss: 0.0186 - val_loss: 0.0413 - 225ms/epoch - 15ms/step
# Epoch 494/500
# 15/15 - 0s - loss: 0.0208 - val_loss: 0.0449 - 193ms/epoch - 13ms/step
# Epoch 495/500
# 15/15 - 0s - loss: 0.0203 - val_loss: 0.0385 - 373ms/epoch - 25ms/step
# Epoch 496/500
# 15/15 - 0s - loss: 0.0180 - val_loss: 0.0345 - 236ms/epoch - 16ms/step
# Epoch 497/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0359 - 218ms/epoch - 15ms/step
# Epoch 498/500
# 15/15 - 0s - loss: 0.0179 - val_loss: 0.0361 - 214ms/epoch - 14ms/step
# Epoch 499/500
# 15/15 - 0s - loss: 0.0175 - val_loss: 0.0343 - 172ms/epoch - 11ms/step
# Epoch 500/500
# 15/15 - 0s - loss: 0.0171 - val_loss: 0.0340 - 207ms/epoch - 14ms/step

# %% [markdown]
# ## Metrics ($LPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 8/8 [==============================] - 2s 3ms/step
# (237, 3)
# (237, 10)
# Test RMSE: 84.875
# Test MAE: 58.357

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('San Juan Dengue Spread', fontsize=20)
plt.legend(fontsize=20)
plt.show()
