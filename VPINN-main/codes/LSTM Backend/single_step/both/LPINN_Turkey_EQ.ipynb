# %% [markdown]
# # Time Series Prediction with Lorrenz Attractor Inspired Deep Learning ($LPINN$)

# %% [markdown]
# AUTHOR: Anurag Dutta (anuragdutta.research@gmail.com)

# %% [markdown]
# SUPERVISOR: Tanujit Chakraborty (tanujit.chakraborty@sorbonne.ae)

# %% [markdown]
# CREATED: 2023-03-09 20:14:48

# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Lorrenz Intermittency_

# %% [markdown]
# The `lorrenz_intermittency.dat` is generated from the Runge Kutta Method.

# %% [markdown]
# This feeds the model with the dynamics of the Lorrenz Attractor

# %%
data = np.genfromtxt('datasets/lorrenz_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 1 # Daily Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 28.981277697415116
# 1         0.017078
# 2         0.040967
# 3         0.062716
# 4         0.083177
# 5         0.103056
#             ...
# 139867    0.104426
# 139868    0.064373
# 139869    0.028379
# 139870   -0.003762
# 139871   -0.032367
# Name: 1, Length: 139871, dtype: float64
# 2         0.023889
# 3         0.021749
# 4         0.020461
# 5         0.019879
# 6         0.019892
#             ...
# 139867   -0.044158
# 139868   -0.040053
# 139869   -0.035994
# 139870   -0.032141
# 139871   -0.028605
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _TURKEY EARTHQUAKE_

# %%
data = pd.read_csv("datasets/eq.csv")
training_set = data.iloc[:, 4]
print(training_set)
# Out:
# 0       4.4
# 1       5.2
# 2       4.8
# 3       4.4
# 4       5.7
#        ...
# 6569    4.5
# 6570    4.0
# 6571    4.4
# 6572    4.1
# 6573    4.0
# Name: Magnitude, Length: 6574, dtype: float64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0         0.017078
# 1         0.040967
# 2         0.062716
# 3         0.083177
# 4         0.103056
#             ...
# 139866    0.104426
# 139867    0.064373
# 139868    0.028379
# 139869   -0.003762
# 139870   -0.032367
# Name: 1, Length: 139871, dtype: float64
# 0         0.023889
# 1         0.021749
# 2         0.020461
# 3         0.019879
# 4         0.019892
#             ...
# 139865   -0.044158
# 139866   -0.040053
# 139867   -0.035994
# 139868   -0.032141
# 139869   -0.028605
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lorrenz Equation_)

# %% [markdown]
# _Parameters_: $\sigma=10, \rho=28$

# %%
s=10
r=28
L = df.iloc[:, 2] + df.iloc[:, 1]*(1 + s) - df.iloc[:, 0] * s * (r - 1)
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data into Supervised Learning

# %%
def Supervised(data, n_in=1):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    cols.append(df)
    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    sup = pd.concat(cols, axis=1)
    sup.columns = names
    sup.dropna(inplace=True)
    return sup


data = Supervised(df.values, n_in=10)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
           'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
           'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
           'var3(t-2)', 'var2(t-1)', 'var3(t-1)', 'var2(t-3)', 'var3(t-3)'], axis=1, inplace=True)
print(data.head())
print(data.columns)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
print(data.shape)
y = data[:, -3:]
x = data[:, :-3]
print(x.shape)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10         4.4        5.2        4.8        4.4        5.7        4.3
# 11         5.2        4.8        4.4        5.7        4.3        4.0
# 12         4.8        4.4        5.7        4.3        4.0        4.8
# 13         4.4        5.7        4.3        4.0        4.8        5.2
# 14         5.7        4.3        4.0        4.8        5.2        5.1
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  var1(t)   var2(t)   var3(t)
# 10        4.0        4.8        5.2        5.1      4.7  0.239024  0.029386
# 11        4.8        5.2        5.1        4.7      4.6  0.268410  0.032352
# 12        5.2        5.1        4.7        4.6      4.4  0.300761  0.035718
# 13        5.1        4.7        4.6        4.4      4.7  0.336479  0.039500
# 14        4.7        4.6        4.4        4.7      4.1  0.375979  0.043711
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)'],
#       dtype='object')
# (6563, 13)
# (6563, 10)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size
dataX = np.array(x)
dataY = np.array(y)
trainX = np.array(x[0:train_size])
trainY = np.array(y[0:train_size])
testX = np.array(x[train_size:len(x)])
testY = np.array(y[train_size:len(y)])
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (5250, 1, 10) (5250, 3) (1313, 1, 10) (1313, 3)

# %% [markdown]
# ## Defining the Physical Loss

# %%
s = tf.Variable(10, name="sigma", trainable=True, dtype=tf.float32)
r = tf.Variable(28, name="rhow", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] + y_true[:, 1]*(1 + s) - y_true[:, 0] * s * (r - 1)), (y_pred[:, 2] + y_pred[:, 1]*(1 + s) - y_pred[:, 0] * s * (r - 1)))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] + (y_pred[1:-1]-y_pred[:-2])*(1 + s) - y_pred[:-2] * s * (r - 1)
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] + (y_real[1:-1]-y_real[:-2])*(1 + s) - y_real[:-2] * s * (r - 1)
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model ($LPINN$)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square((y_pred[:, 2] + y_pred[:, 1]*(1 + s) - y_pred[:, 0] * s * (r - 1)))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(3))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64,
                    validation_data=(testX, testY), verbose=2, shuffle=False)
# Out:
# Epoch 1/500
# 83/83 - 2s - loss: 0.2834 - val_loss: 0.0162 - 2s/epoch - 30ms/step
# Epoch 2/500
# 83/83 - 0s - loss: 0.0421 - val_loss: 0.0158 - 181ms/epoch - 2ms/step
# Epoch 3/500
# 83/83 - 0s - loss: 0.0406 - val_loss: 0.0157 - 180ms/epoch - 2ms/step
# Epoch 4/500
# 83/83 - 0s - loss: 0.0394 - val_loss: 0.0154 - 181ms/epoch - 2ms/step
# Epoch 5/500
# 83/83 - 0s - loss: 0.0383 - val_loss: 0.0152 - 188ms/epoch - 2ms/step
# Epoch 6/500
# 83/83 - 0s - loss: 0.0374 - val_loss: 0.0150 - 184ms/epoch - 2ms/step
# Epoch 7/500
# 83/83 - 0s - loss: 0.0368 - val_loss: 0.0150 - 188ms/epoch - 2ms/step
# Epoch 8/500
# 83/83 - 0s - loss: 0.0363 - val_loss: 0.0147 - 192ms/epoch - 2ms/step
# Epoch 9/500
# 83/83 - 0s - loss: 0.0359 - val_loss: 0.0145 - 218ms/epoch - 3ms/step
# Epoch 10/500
# 83/83 - 0s - loss: 0.0354 - val_loss: 0.0144 - 219ms/epoch - 3ms/step
# Epoch 11/500
# 83/83 - 0s - loss: 0.0349 - val_loss: 0.0143 - 218ms/epoch - 3ms/step
# Epoch 12/500
# 83/83 - 0s - loss: 0.0347 - val_loss: 0.0142 - 212ms/epoch - 3ms/step
# Epoch 13/500
# 83/83 - 0s - loss: 0.0351 - val_loss: 0.0141 - 212ms/epoch - 3ms/step
# Epoch 14/500
# 83/83 - 0s - loss: 0.0357 - val_loss: 0.0141 - 212ms/epoch - 3ms/step
# Epoch 15/500
# 83/83 - 0s - loss: 0.0349 - val_loss: 0.0140 - 209ms/epoch - 3ms/step
# Epoch 16/500
# 83/83 - 0s - loss: 0.0345 - val_loss: 0.0140 - 180ms/epoch - 2ms/step
# Epoch 17/500
# 83/83 - 0s - loss: 0.0343 - val_loss: 0.0139 - 197ms/epoch - 2ms/step
# Epoch 18/500
# 83/83 - 0s - loss: 0.0354 - val_loss: 0.0138 - 207ms/epoch - 2ms/step
# Epoch 19/500
# 83/83 - 0s - loss: 0.0333 - val_loss: 0.0138 - 219ms/epoch - 3ms/step
# Epoch 20/500
# 83/83 - 0s - loss: 0.0407 - val_loss: 0.0137 - 227ms/epoch - 3ms/step
# Epoch 21/500
# 83/83 - 0s - loss: 0.0331 - val_loss: 0.0137 - 232ms/epoch - 3ms/step
# Epoch 22/500
# 83/83 - 0s - loss: 0.0332 - val_loss: 0.0136 - 250ms/epoch - 3ms/step
# Epoch 23/500
# 83/83 - 0s - loss: 0.0329 - val_loss: 0.0135 - 213ms/epoch - 3ms/step
# Epoch 24/500
# 83/83 - 0s - loss: 0.0325 - val_loss: 0.0135 - 223ms/epoch - 3ms/step
# Epoch 25/500
# 83/83 - 0s - loss: 0.0364 - val_loss: 0.0134 - 292ms/epoch - 4ms/step
# Epoch 26/500
# 83/83 - 0s - loss: 0.0322 - val_loss: 0.0134 - 289ms/epoch - 3ms/step
# Epoch 27/500
# 83/83 - 0s - loss: 0.0321 - val_loss: 0.0133 - 322ms/epoch - 4ms/step
# Epoch 28/500
# 83/83 - 0s - loss: 0.0659 - val_loss: 0.0141 - 314ms/epoch - 4ms/step
# Epoch 29/500
# 83/83 - 0s - loss: 0.0325 - val_loss: 0.0133 - 229ms/epoch - 3ms/step
# Epoch 30/500
# 83/83 - 0s - loss: 0.0321 - val_loss: 0.0133 - 237ms/epoch - 3ms/step
# Epoch 31/500
# 83/83 - 0s - loss: 0.0319 - val_loss: 0.0132 - 232ms/epoch - 3ms/step
# Epoch 32/500
# 83/83 - 0s - loss: 0.0316 - val_loss: 0.0131 - 250ms/epoch - 3ms/step
# Epoch 33/500
# 83/83 - 0s - loss: 0.0314 - val_loss: 0.0131 - 246ms/epoch - 3ms/step
# Epoch 34/500
# 83/83 - 0s - loss: 0.0312 - val_loss: 0.0130 - 294ms/epoch - 4ms/step
# Epoch 35/500
# 83/83 - 0s - loss: 0.0311 - val_loss: 0.0129 - 246ms/epoch - 3ms/step
# Epoch 36/500
# 83/83 - 0s - loss: 0.0309 - val_loss: 0.0128 - 245ms/epoch - 3ms/step
# Epoch 37/500
# 83/83 - 0s - loss: 0.0307 - val_loss: 0.0128 - 275ms/epoch - 3ms/step
# Epoch 38/500
# 83/83 - 0s - loss: 0.0305 - val_loss: 0.0127 - 285ms/epoch - 3ms/step
# Epoch 39/500
# 83/83 - 0s - loss: 0.0303 - val_loss: 0.0126 - 258ms/epoch - 3ms/step
# Epoch 40/500
# 83/83 - 0s - loss: 0.0317 - val_loss: 0.0125 - 287ms/epoch - 3ms/step
# Epoch 41/500
# 83/83 - 0s - loss: 0.0352 - val_loss: 0.0125 - 248ms/epoch - 3ms/step
# Epoch 42/500
# 83/83 - 0s - loss: 0.0299 - val_loss: 0.0124 - 244ms/epoch - 3ms/step
# Epoch 43/500
# 83/83 - 0s - loss: 0.0299 - val_loss: 0.0123 - 262ms/epoch - 3ms/step
# Epoch 44/500
# 83/83 - 0s - loss: 0.0296 - val_loss: 0.0123 - 248ms/epoch - 3ms/step
# Epoch 45/500
# 83/83 - 0s - loss: 0.0296 - val_loss: 0.0122 - 244ms/epoch - 3ms/step
# Epoch 46/500
# 83/83 - 0s - loss: 0.0301 - val_loss: 0.0121 - 262ms/epoch - 3ms/step
# Epoch 47/500
# 83/83 - 0s - loss: 0.0828 - val_loss: 0.0124 - 227ms/epoch - 3ms/step
# Epoch 48/500
# 83/83 - 0s - loss: 0.0346 - val_loss: 0.0123 - 271ms/epoch - 3ms/step
# Epoch 49/500
# 83/83 - 0s - loss: 0.0303 - val_loss: 0.0123 - 236ms/epoch - 3ms/step
# Epoch 50/500
# 83/83 - 0s - loss: 0.0297 - val_loss: 0.0122 - 263ms/epoch - 3ms/step
# Epoch 51/500
# 83/83 - 0s - loss: 0.0294 - val_loss: 0.0121 - 227ms/epoch - 3ms/step
# Epoch 52/500
# 83/83 - 0s - loss: 0.0292 - val_loss: 0.0121 - 243ms/epoch - 3ms/step
# Epoch 53/500
# 83/83 - 0s - loss: 0.0290 - val_loss: 0.0120 - 232ms/epoch - 3ms/step
# Epoch 54/500
# 83/83 - 0s - loss: 0.0289 - val_loss: 0.0120 - 266ms/epoch - 3ms/step
# Epoch 55/500
# 83/83 - 0s - loss: 0.0288 - val_loss: 0.0119 - 242ms/epoch - 3ms/step
# Epoch 56/500
# 83/83 - 0s - loss: 0.0286 - val_loss: 0.0119 - 271ms/epoch - 3ms/step
# Epoch 57/500
# 83/83 - 0s - loss: 0.0285 - val_loss: 0.0118 - 284ms/epoch - 3ms/step
# Epoch 58/500
# 83/83 - 0s - loss: 0.0284 - val_loss: 0.0118 - 276ms/epoch - 3ms/step
# Epoch 59/500
# 83/83 - 0s - loss: 0.0283 - val_loss: 0.0117 - 252ms/epoch - 3ms/step
# Epoch 60/500
# 83/83 - 0s - loss: 0.0282 - val_loss: 0.0117 - 275ms/epoch - 3ms/step
# Epoch 61/500
# 83/83 - 0s - loss: 0.0280 - val_loss: 0.0116 - 250ms/epoch - 3ms/step
# Epoch 62/500
# 83/83 - 0s - loss: 0.0279 - val_loss: 0.0116 - 230ms/epoch - 3ms/step
# Epoch 63/500
# 83/83 - 0s - loss: 0.0278 - val_loss: 0.0115 - 234ms/epoch - 3ms/step
# Epoch 64/500
# 83/83 - 0s - loss: 0.0278 - val_loss: 0.0114 - 236ms/epoch - 3ms/step
# Epoch 65/500
# 83/83 - 0s - loss: 0.0367 - val_loss: 0.0114 - 235ms/epoch - 3ms/step
# Epoch 66/500
# 83/83 - 0s - loss: 0.0275 - val_loss: 0.0114 - 270ms/epoch - 3ms/step
# Epoch 67/500
# 83/83 - 0s - loss: 0.0273 - val_loss: 0.0113 - 246ms/epoch - 3ms/step
# Epoch 68/500
# 83/83 - 0s - loss: 0.0272 - val_loss: 0.0112 - 271ms/epoch - 3ms/step
# Epoch 69/500
# 83/83 - 0s - loss: 0.0271 - val_loss: 0.0112 - 252ms/epoch - 3ms/step
# Epoch 70/500
# 83/83 - 0s - loss: 0.0269 - val_loss: 0.0111 - 295ms/epoch - 4ms/step
# Epoch 71/500
# 83/83 - 0s - loss: 0.0309 - val_loss: 0.0112 - 255ms/epoch - 3ms/step
# Epoch 72/500
# 83/83 - 0s - loss: 0.0341 - val_loss: 0.0112 - 244ms/epoch - 3ms/step
# Epoch 73/500
# 83/83 - 0s - loss: 0.0269 - val_loss: 0.0110 - 266ms/epoch - 3ms/step
# Epoch 74/500
# 83/83 - 0s - loss: 0.0264 - val_loss: 0.0109 - 248ms/epoch - 3ms/step
# Epoch 75/500
# 83/83 - 0s - loss: 0.0264 - val_loss: 0.0109 - 241ms/epoch - 3ms/step
# Epoch 76/500
# 83/83 - 0s - loss: 0.0282 - val_loss: 0.0109 - 240ms/epoch - 3ms/step
# Epoch 77/500
# 83/83 - 0s - loss: 0.0268 - val_loss: 0.0108 - 247ms/epoch - 3ms/step
# Epoch 78/500
# 83/83 - 0s - loss: 0.0261 - val_loss: 0.0107 - 287ms/epoch - 3ms/step
# Epoch 79/500
# 83/83 - 0s - loss: 0.0389 - val_loss: 0.0107 - 226ms/epoch - 3ms/step
# Epoch 80/500
# 83/83 - 0s - loss: 0.0258 - val_loss: 0.0107 - 312ms/epoch - 4ms/step
# Epoch 81/500
# 83/83 - 0s - loss: 0.0256 - val_loss: 0.0106 - 352ms/epoch - 4ms/step
# Epoch 82/500
# 83/83 - 0s - loss: 0.0255 - val_loss: 0.0106 - 331ms/epoch - 4ms/step
# Epoch 83/500
# 83/83 - 0s - loss: 0.0254 - val_loss: 0.0105 - 306ms/epoch - 4ms/step
# Epoch 84/500
# 83/83 - 0s - loss: 0.0252 - val_loss: 0.0105 - 308ms/epoch - 4ms/step
# Epoch 85/500
# 83/83 - 0s - loss: 0.0251 - val_loss: 0.0104 - 287ms/epoch - 3ms/step
# Epoch 86/500
# 83/83 - 0s - loss: 0.0305 - val_loss: 0.0104 - 274ms/epoch - 3ms/step
# Epoch 87/500
# 83/83 - 0s - loss: 0.0317 - val_loss: 0.0104 - 279ms/epoch - 3ms/step
# Epoch 88/500
# 83/83 - 0s - loss: 0.0249 - val_loss: 0.0103 - 269ms/epoch - 3ms/step
# Epoch 89/500
# 83/83 - 0s - loss: 0.0248 - val_loss: 0.0103 - 279ms/epoch - 3ms/step
# Epoch 90/500
# 83/83 - 0s - loss: 0.0247 - val_loss: 0.0102 - 264ms/epoch - 3ms/step
# Epoch 91/500
# 83/83 - 0s - loss: 0.0278 - val_loss: 0.0102 - 247ms/epoch - 3ms/step
# Epoch 92/500
# 83/83 - 0s - loss: 0.0246 - val_loss: 0.0102 - 256ms/epoch - 3ms/step
# Epoch 93/500
# 83/83 - 0s - loss: 0.0249 - val_loss: 0.0101 - 241ms/epoch - 3ms/step
# Epoch 94/500
# 83/83 - 0s - loss: 0.0262 - val_loss: 0.0101 - 267ms/epoch - 3ms/step
# Epoch 95/500
# 83/83 - 0s - loss: 0.0246 - val_loss: 0.0100 - 260ms/epoch - 3ms/step
# Epoch 96/500
# 83/83 - 0s - loss: 0.0381 - val_loss: 0.0100 - 239ms/epoch - 3ms/step
# Epoch 97/500
# 83/83 - 0s - loss: 0.0239 - val_loss: 0.0100 - 281ms/epoch - 3ms/step
# Epoch 98/500
# 83/83 - 0s - loss: 0.0238 - val_loss: 0.0099 - 224ms/epoch - 3ms/step
# Epoch 99/500
# 83/83 - 0s - loss: 0.0237 - val_loss: 0.0099 - 231ms/epoch - 3ms/step
# Epoch 100/500
# 83/83 - 0s - loss: 0.0237 - val_loss: 0.0099 - 275ms/epoch - 3ms/step
# Epoch 101/500
# 83/83 - 0s - loss: 0.0235 - val_loss: 0.0098 - 278ms/epoch - 3ms/step
# Epoch 102/500
# 83/83 - 0s - loss: 0.0243 - val_loss: 0.0098 - 226ms/epoch - 3ms/step
# Epoch 103/500
# 83/83 - 0s - loss: 0.0255 - val_loss: 0.0098 - 300ms/epoch - 4ms/step
# Epoch 104/500
# 83/83 - 0s - loss: 0.0232 - val_loss: 0.0097 - 246ms/epoch - 3ms/step
# Epoch 105/500
# 83/83 - 0s - loss: 0.0390 - val_loss: 0.0098 - 250ms/epoch - 3ms/step
# Epoch 106/500
# 83/83 - 0s - loss: 0.0231 - val_loss: 0.0097 - 243ms/epoch - 3ms/step
# Epoch 107/500
# 83/83 - 0s - loss: 0.0230 - val_loss: 0.0097 - 258ms/epoch - 3ms/step
# Epoch 108/500
# 83/83 - 0s - loss: 0.0229 - val_loss: 0.0096 - 252ms/epoch - 3ms/step
# Epoch 109/500
# 83/83 - 0s - loss: 0.0228 - val_loss: 0.0096 - 258ms/epoch - 3ms/step
# Epoch 110/500
# 83/83 - 0s - loss: 0.0227 - val_loss: 0.0096 - 297ms/epoch - 4ms/step
# Epoch 111/500
# 83/83 - 0s - loss: 0.0226 - val_loss: 0.0095 - 237ms/epoch - 3ms/step
# Epoch 112/500
# 83/83 - 0s - loss: 0.0229 - val_loss: 0.0095 - 244ms/epoch - 3ms/step
# Epoch 113/500
# 83/83 - 0s - loss: 0.0241 - val_loss: 0.0096 - 281ms/epoch - 3ms/step
# Epoch 114/500
# 83/83 - 0s - loss: 0.0361 - val_loss: 0.0096 - 242ms/epoch - 3ms/step
# Epoch 115/500
# 83/83 - 0s - loss: 0.0226 - val_loss: 0.0094 - 250ms/epoch - 3ms/step
# Epoch 116/500
# 83/83 - 0s - loss: 0.0223 - val_loss: 0.0094 - 229ms/epoch - 3ms/step
# Epoch 117/500
# 83/83 - 0s - loss: 0.0223 - val_loss: 0.0094 - 256ms/epoch - 3ms/step
# Epoch 118/500
# 83/83 - 0s - loss: 0.0222 - val_loss: 0.0093 - 259ms/epoch - 3ms/step
# Epoch 119/500
# 83/83 - 0s - loss: 0.0223 - val_loss: 0.0093 - 263ms/epoch - 3ms/step
# Epoch 120/500
# 83/83 - 0s - loss: 0.0306 - val_loss: 0.0094 - 274ms/epoch - 3ms/step
# Epoch 121/500
# 83/83 - 0s - loss: 0.0229 - val_loss: 0.0093 - 250ms/epoch - 3ms/step
# Epoch 122/500
# 83/83 - 0s - loss: 0.0218 - val_loss: 0.0092 - 226ms/epoch - 3ms/step
# Epoch 123/500
# 83/83 - 0s - loss: 0.0217 - val_loss: 0.0092 - 231ms/epoch - 3ms/step
# Epoch 124/500
# 83/83 - 0s - loss: 0.0216 - val_loss: 0.0092 - 223ms/epoch - 3ms/step
# Epoch 125/500
# 83/83 - 0s - loss: 0.0221 - val_loss: 0.0093 - 266ms/epoch - 3ms/step
# Epoch 126/500
# 83/83 - 0s - loss: 0.0256 - val_loss: 0.0092 - 249ms/epoch - 3ms/step
# Epoch 127/500
# 83/83 - 0s - loss: 0.0228 - val_loss: 0.0091 - 244ms/epoch - 3ms/step
# Epoch 128/500
# 83/83 - 0s - loss: 0.0242 - val_loss: 0.0091 - 233ms/epoch - 3ms/step
# Epoch 129/500
# 83/83 - 0s - loss: 0.0213 - val_loss: 0.0091 - 241ms/epoch - 3ms/step
# Epoch 130/500
# 83/83 - 0s - loss: 0.0230 - val_loss: 0.0091 - 222ms/epoch - 3ms/step
# Epoch 131/500
# 83/83 - 0s - loss: 0.0241 - val_loss: 0.0091 - 232ms/epoch - 3ms/step
# Epoch 132/500
# 83/83 - 0s - loss: 0.0213 - val_loss: 0.0090 - 221ms/epoch - 3ms/step
# Epoch 133/500
# 83/83 - 0s - loss: 0.0210 - val_loss: 0.0090 - 230ms/epoch - 3ms/step
# Epoch 134/500
# 83/83 - 0s - loss: 0.0220 - val_loss: 0.0092 - 237ms/epoch - 3ms/step
# Epoch 135/500
# 83/83 - 0s - loss: 0.0571 - val_loss: 0.0093 - 236ms/epoch - 3ms/step
# Epoch 136/500
# 83/83 - 0s - loss: 0.0210 - val_loss: 0.0090 - 253ms/epoch - 3ms/step
# Epoch 137/500
# 83/83 - 0s - loss: 0.0209 - val_loss: 0.0090 - 261ms/epoch - 3ms/step
# Epoch 138/500
# 83/83 - 0s - loss: 0.0208 - val_loss: 0.0089 - 235ms/epoch - 3ms/step
# Epoch 139/500
# 83/83 - 0s - loss: 0.0207 - val_loss: 0.0089 - 227ms/epoch - 3ms/step
# Epoch 140/500
# 83/83 - 0s - loss: 0.0207 - val_loss: 0.0089 - 240ms/epoch - 3ms/step
# Epoch 141/500
# 83/83 - 0s - loss: 0.0207 - val_loss: 0.0089 - 247ms/epoch - 3ms/step
# Epoch 142/500
# 83/83 - 0s - loss: 0.0206 - val_loss: 0.0089 - 242ms/epoch - 3ms/step
# Epoch 143/500
# 83/83 - 0s - loss: 0.0206 - val_loss: 0.0088 - 236ms/epoch - 3ms/step
# Epoch 144/500
# 83/83 - 0s - loss: 0.0206 - val_loss: 0.0088 - 247ms/epoch - 3ms/step
# Epoch 145/500
# 83/83 - 0s - loss: 0.0205 - val_loss: 0.0088 - 269ms/epoch - 3ms/step
# Epoch 146/500
# 83/83 - 0s - loss: 0.0204 - val_loss: 0.0088 - 261ms/epoch - 3ms/step
# Epoch 147/500
# 83/83 - 0s - loss: 0.0205 - val_loss: 0.0088 - 249ms/epoch - 3ms/step
# Epoch 148/500
# 83/83 - 0s - loss: 0.0527 - val_loss: 0.0098 - 229ms/epoch - 3ms/step
# Epoch 149/500
# 83/83 - 0s - loss: 0.0203 - val_loss: 0.0088 - 235ms/epoch - 3ms/step
# Epoch 150/500
# 83/83 - 0s - loss: 0.0203 - val_loss: 0.0088 - 226ms/epoch - 3ms/step
# Epoch 151/500
# 83/83 - 0s - loss: 0.0202 - val_loss: 0.0087 - 241ms/epoch - 3ms/step
# Epoch 152/500
# 83/83 - 0s - loss: 0.0201 - val_loss: 0.0087 - 238ms/epoch - 3ms/step
# Epoch 153/500
# 83/83 - 0s - loss: 0.0200 - val_loss: 0.0087 - 227ms/epoch - 3ms/step
# Epoch 154/500
# 83/83 - 0s - loss: 0.0200 - val_loss: 0.0087 - 205ms/epoch - 2ms/step
# Epoch 155/500
# 83/83 - 0s - loss: 0.0200 - val_loss: 0.0087 - 230ms/epoch - 3ms/step
# Epoch 156/500
# 83/83 - 0s - loss: 0.0200 - val_loss: 0.0087 - 221ms/epoch - 3ms/step
# Epoch 157/500
# 83/83 - 0s - loss: 0.0204 - val_loss: 0.0087 - 264ms/epoch - 3ms/step
# Epoch 158/500
# 83/83 - 0s - loss: 0.0201 - val_loss: 0.0086 - 321ms/epoch - 4ms/step
# Epoch 159/500
# 83/83 - 0s - loss: 0.0199 - val_loss: 0.0087 - 258ms/epoch - 3ms/step
# Epoch 160/500
# 83/83 - 0s - loss: 0.0201 - val_loss: 0.0088 - 272ms/epoch - 3ms/step
# Epoch 161/500
# 83/83 - 0s - loss: 0.0553 - val_loss: 0.0086 - 257ms/epoch - 3ms/step
# Epoch 162/500
# 83/83 - 0s - loss: 0.0197 - val_loss: 0.0086 - 225ms/epoch - 3ms/step
# Epoch 163/500
# 83/83 - 0s - loss: 0.0196 - val_loss: 0.0086 - 221ms/epoch - 3ms/step
# Epoch 164/500
# 83/83 - 0s - loss: 0.0195 - val_loss: 0.0086 - 220ms/epoch - 3ms/step
# Epoch 165/500
# 83/83 - 0s - loss: 0.0195 - val_loss: 0.0086 - 223ms/epoch - 3ms/step
# Epoch 166/500
# 83/83 - 0s - loss: 0.0194 - val_loss: 0.0086 - 237ms/epoch - 3ms/step
# Epoch 167/500
# 83/83 - 0s - loss: 0.0193 - val_loss: 0.0086 - 230ms/epoch - 3ms/step
# Epoch 168/500
# 83/83 - 0s - loss: 0.0194 - val_loss: 0.0085 - 237ms/epoch - 3ms/step
# Epoch 169/500
# 83/83 - 0s - loss: 0.0194 - val_loss: 0.0085 - 238ms/epoch - 3ms/step
# Epoch 170/500
# 83/83 - 0s - loss: 0.0195 - val_loss: 0.0085 - 261ms/epoch - 3ms/step
# Epoch 171/500
# 83/83 - 0s - loss: 0.0199 - val_loss: 0.0085 - 232ms/epoch - 3ms/step
# Epoch 172/500
# 83/83 - 0s - loss: 0.0195 - val_loss: 0.0085 - 237ms/epoch - 3ms/step
# Epoch 173/500
# 83/83 - 0s - loss: 0.0193 - val_loss: 0.0085 - 222ms/epoch - 3ms/step
# Epoch 174/500
# 83/83 - 0s - loss: 0.0190 - val_loss: 0.0085 - 221ms/epoch - 3ms/step
# Epoch 175/500
# 83/83 - 0s - loss: 0.0513 - val_loss: 0.0093 - 240ms/epoch - 3ms/step
# Epoch 176/500
# 83/83 - 0s - loss: 0.0191 - val_loss: 0.0085 - 230ms/epoch - 3ms/step
# Epoch 177/500
# 83/83 - 0s - loss: 0.0190 - val_loss: 0.0085 - 235ms/epoch - 3ms/step
# Epoch 178/500
# 83/83 - 0s - loss: 0.0189 - val_loss: 0.0085 - 234ms/epoch - 3ms/step
# Epoch 179/500
# 83/83 - 0s - loss: 0.0188 - val_loss: 0.0085 - 233ms/epoch - 3ms/step
# Epoch 180/500
# 83/83 - 0s - loss: 0.0187 - val_loss: 0.0084 - 229ms/epoch - 3ms/step
# Epoch 181/500
# 83/83 - 0s - loss: 0.0187 - val_loss: 0.0084 - 250ms/epoch - 3ms/step
# Epoch 182/500
# 83/83 - 0s - loss: 0.0188 - val_loss: 0.0084 - 224ms/epoch - 3ms/step
# Epoch 183/500
# 83/83 - 0s - loss: 0.0190 - val_loss: 0.0084 - 234ms/epoch - 3ms/step
# Epoch 184/500
# 83/83 - 0s - loss: 0.0196 - val_loss: 0.0084 - 234ms/epoch - 3ms/step
# Epoch 185/500
# 83/83 - 0s - loss: 0.0193 - val_loss: 0.0084 - 254ms/epoch - 3ms/step
# Epoch 186/500
# 83/83 - 0s - loss: 0.0188 - val_loss: 0.0084 - 235ms/epoch - 3ms/step
# Epoch 187/500
# 83/83 - 0s - loss: 0.0187 - val_loss: 0.0085 - 242ms/epoch - 3ms/step
# Epoch 188/500
# 83/83 - 0s - loss: 0.0196 - val_loss: 0.0085 - 252ms/epoch - 3ms/step
# Epoch 189/500
# 83/83 - 0s - loss: 0.0204 - val_loss: 0.0084 - 243ms/epoch - 3ms/step
# Epoch 190/500
# 83/83 - 0s - loss: 0.0184 - val_loss: 0.0085 - 229ms/epoch - 3ms/step
# Epoch 191/500
# 83/83 - 0s - loss: 0.0469 - val_loss: 0.0086 - 228ms/epoch - 3ms/step
# Epoch 192/500
# 83/83 - 0s - loss: 0.0184 - val_loss: 0.0084 - 236ms/epoch - 3ms/step
# Epoch 193/500
# 83/83 - 0s - loss: 0.0182 - val_loss: 0.0084 - 257ms/epoch - 3ms/step
# Epoch 194/500
# 83/83 - 0s - loss: 0.0181 - val_loss: 0.0084 - 267ms/epoch - 3ms/step
# Epoch 195/500
# 83/83 - 0s - loss: 0.0181 - val_loss: 0.0084 - 253ms/epoch - 3ms/step
# Epoch 196/500
# 83/83 - 0s - loss: 0.0181 - val_loss: 0.0084 - 226ms/epoch - 3ms/step
# Epoch 197/500
# 83/83 - 0s - loss: 0.0182 - val_loss: 0.0084 - 225ms/epoch - 3ms/step
# Epoch 198/500
# 83/83 - 0s - loss: 0.0185 - val_loss: 0.0084 - 226ms/epoch - 3ms/step
# Epoch 199/500
# 83/83 - 0s - loss: 0.0187 - val_loss: 0.0083 - 230ms/epoch - 3ms/step
# Epoch 200/500
# 83/83 - 0s - loss: 0.0182 - val_loss: 0.0083 - 231ms/epoch - 3ms/step
# Epoch 201/500
# 83/83 - 0s - loss: 0.0181 - val_loss: 0.0084 - 243ms/epoch - 3ms/step
# Epoch 202/500
# 83/83 - 0s - loss: 0.0178 - val_loss: 0.0084 - 238ms/epoch - 3ms/step
# Epoch 203/500
# 83/83 - 0s - loss: 0.0426 - val_loss: 0.0084 - 321ms/epoch - 4ms/step
# Epoch 204/500
# 83/83 - 0s - loss: 0.0178 - val_loss: 0.0083 - 255ms/epoch - 3ms/step
# Epoch 205/500
# 83/83 - 0s - loss: 0.0177 - val_loss: 0.0083 - 249ms/epoch - 3ms/step
# Epoch 206/500
# 83/83 - 0s - loss: 0.0177 - val_loss: 0.0083 - 255ms/epoch - 3ms/step
# Epoch 207/500
# 83/83 - 0s - loss: 0.0177 - val_loss: 0.0083 - 290ms/epoch - 3ms/step
# Epoch 208/500
# 83/83 - 0s - loss: 0.0178 - val_loss: 0.0083 - 269ms/epoch - 3ms/step
# Epoch 209/500
# 83/83 - 0s - loss: 0.0182 - val_loss: 0.0083 - 260ms/epoch - 3ms/step
# Epoch 210/500
# 83/83 - 0s - loss: 0.0185 - val_loss: 0.0083 - 238ms/epoch - 3ms/step
# Epoch 211/500
# 83/83 - 0s - loss: 0.0180 - val_loss: 0.0083 - 272ms/epoch - 3ms/step
# Epoch 212/500
# 83/83 - 0s - loss: 0.0178 - val_loss: 0.0084 - 236ms/epoch - 3ms/step
# Epoch 213/500
# 83/83 - 0s - loss: 0.0176 - val_loss: 0.0084 - 246ms/epoch - 3ms/step
# Epoch 214/500
# 83/83 - 0s - loss: 0.0336 - val_loss: 0.0084 - 267ms/epoch - 3ms/step
# Epoch 215/500
# 83/83 - 0s - loss: 0.0175 - val_loss: 0.0083 - 273ms/epoch - 3ms/step
# Epoch 216/500
# 83/83 - 0s - loss: 0.0176 - val_loss: 0.0083 - 260ms/epoch - 3ms/step
# Epoch 217/500
# 83/83 - 0s - loss: 0.0179 - val_loss: 0.0083 - 276ms/epoch - 3ms/step
# Epoch 218/500
# 83/83 - 0s - loss: 0.0180 - val_loss: 0.0083 - 294ms/epoch - 4ms/step
# Epoch 219/500
# 83/83 - 0s - loss: 0.0176 - val_loss: 0.0083 - 276ms/epoch - 3ms/step
# Epoch 220/500
# 83/83 - 0s - loss: 0.0175 - val_loss: 0.0084 - 263ms/epoch - 3ms/step
# Epoch 221/500
# 83/83 - 0s - loss: 0.0172 - val_loss: 0.0084 - 326ms/epoch - 4ms/step
# Epoch 222/500
# 83/83 - 0s - loss: 0.0382 - val_loss: 0.0083 - 447ms/epoch - 5ms/step
# Epoch 223/500
# 83/83 - 0s - loss: 0.0172 - val_loss: 0.0083 - 427ms/epoch - 5ms/step
# Epoch 224/500
# 83/83 - 1s - loss: 0.0171 - val_loss: 0.0083 - 529ms/epoch - 6ms/step
# Epoch 225/500
# 83/83 - 1s - loss: 0.0172 - val_loss: 0.0083 - 537ms/epoch - 6ms/step
# Epoch 226/500
# 83/83 - 1s - loss: 0.0174 - val_loss: 0.0083 - 546ms/epoch - 7ms/step
# Epoch 227/500
# 83/83 - 1s - loss: 0.0177 - val_loss: 0.0083 - 652ms/epoch - 8ms/step
# Epoch 228/500
# 83/83 - 1s - loss: 0.0178 - val_loss: 0.0083 - 601ms/epoch - 7ms/step
# Epoch 229/500
# 83/83 - 1s - loss: 0.0173 - val_loss: 0.0083 - 590ms/epoch - 7ms/step
# Epoch 230/500
# 83/83 - 1s - loss: 0.0172 - val_loss: 0.0084 - 618ms/epoch - 7ms/step
# Epoch 231/500
# 83/83 - 1s - loss: 0.0169 - val_loss: 0.0084 - 588ms/epoch - 7ms/step
# Epoch 232/500
# 83/83 - 1s - loss: 0.0415 - val_loss: 0.0084 - 593ms/epoch - 7ms/step
# Epoch 233/500
# 83/83 - 1s - loss: 0.0169 - val_loss: 0.0083 - 604ms/epoch - 7ms/step
# Epoch 234/500
# 83/83 - 0s - loss: 0.0169 - val_loss: 0.0083 - 461ms/epoch - 6ms/step
# Epoch 235/500
# 83/83 - 0s - loss: 0.0169 - val_loss: 0.0083 - 343ms/epoch - 4ms/step
# Epoch 236/500
# 83/83 - 0s - loss: 0.0169 - val_loss: 0.0083 - 272ms/epoch - 3ms/step
# Epoch 237/500
# 83/83 - 0s - loss: 0.0171 - val_loss: 0.0083 - 233ms/epoch - 3ms/step
# Epoch 238/500
# 83/83 - 0s - loss: 0.0175 - val_loss: 0.0083 - 241ms/epoch - 3ms/step
# Epoch 239/500
# 83/83 - 0s - loss: 0.0176 - val_loss: 0.0083 - 231ms/epoch - 3ms/step
# Epoch 240/500
# 83/83 - 0s - loss: 0.0172 - val_loss: 0.0083 - 242ms/epoch - 3ms/step
# Epoch 241/500
# 83/83 - 0s - loss: 0.0170 - val_loss: 0.0084 - 234ms/epoch - 3ms/step
# Epoch 242/500
# 83/83 - 0s - loss: 0.0167 - val_loss: 0.0084 - 238ms/epoch - 3ms/step
# Epoch 243/500
# 83/83 - 0s - loss: 0.0297 - val_loss: 0.0083 - 226ms/epoch - 3ms/step
# Epoch 244/500
# 83/83 - 0s - loss: 0.0173 - val_loss: 0.0083 - 224ms/epoch - 3ms/step
# Epoch 245/500
# 83/83 - 0s - loss: 0.0174 - val_loss: 0.0083 - 226ms/epoch - 3ms/step
# Epoch 246/500
# 83/83 - 0s - loss: 0.0174 - val_loss: 0.0083 - 236ms/epoch - 3ms/step
# Epoch 247/500
# 83/83 - 0s - loss: 0.0170 - val_loss: 0.0083 - 235ms/epoch - 3ms/step
# Epoch 248/500
# 83/83 - 0s - loss: 0.0167 - val_loss: 0.0084 - 235ms/epoch - 3ms/step
# Epoch 249/500
# 83/83 - 0s - loss: 0.0166 - val_loss: 0.0084 - 295ms/epoch - 4ms/step
# Epoch 250/500
# 83/83 - 0s - loss: 0.0190 - val_loss: 0.0084 - 261ms/epoch - 3ms/step
# Epoch 251/500
# 83/83 - 0s - loss: 0.0164 - val_loss: 0.0084 - 233ms/epoch - 3ms/step
# Epoch 252/500
# 83/83 - 0s - loss: 0.0256 - val_loss: 0.0085 - 227ms/epoch - 3ms/step
# Epoch 253/500
# 83/83 - 0s - loss: 0.0164 - val_loss: 0.0084 - 225ms/epoch - 3ms/step
# Epoch 254/500
# 83/83 - 0s - loss: 0.0164 - val_loss: 0.0084 - 227ms/epoch - 3ms/step
# Epoch 255/500
# 83/83 - 0s - loss: 0.0164 - val_loss: 0.0085 - 234ms/epoch - 3ms/step
# Epoch 256/500
# 83/83 - 0s - loss: 0.0163 - val_loss: 0.0084 - 352ms/epoch - 4ms/step
# Epoch 257/500
# 83/83 - 1s - loss: 0.0264 - val_loss: 0.0086 - 600ms/epoch - 7ms/step
# Epoch 258/500
# 83/83 - 1s - loss: 0.0163 - val_loss: 0.0084 - 731ms/epoch - 9ms/step
# Epoch 259/500
# 83/83 - 1s - loss: 0.0163 - val_loss: 0.0084 - 596ms/epoch - 7ms/step
# Epoch 260/500
# 83/83 - 0s - loss: 0.0162 - val_loss: 0.0085 - 388ms/epoch - 5ms/step
# Epoch 261/500
# 83/83 - 0s - loss: 0.0164 - val_loss: 0.0084 - 236ms/epoch - 3ms/step
# Epoch 262/500
# 83/83 - 0s - loss: 0.0179 - val_loss: 0.0087 - 242ms/epoch - 3ms/step
# Epoch 263/500
# 83/83 - 0s - loss: 0.0198 - val_loss: 0.0084 - 232ms/epoch - 3ms/step
# Epoch 264/500
# 83/83 - 0s - loss: 0.0161 - val_loss: 0.0085 - 256ms/epoch - 3ms/step
# Epoch 265/500
# 83/83 - 0s - loss: 0.0161 - val_loss: 0.0084 - 244ms/epoch - 3ms/step
# Epoch 266/500
# 83/83 - 0s - loss: 0.0220 - val_loss: 0.0084 - 238ms/epoch - 3ms/step
# Epoch 267/500
# 83/83 - 0s - loss: 0.0161 - val_loss: 0.0085 - 242ms/epoch - 3ms/step
# Epoch 268/500
# 83/83 - 0s - loss: 0.0162 - val_loss: 0.0084 - 234ms/epoch - 3ms/step
# Epoch 269/500
# 83/83 - 0s - loss: 0.0160 - val_loss: 0.0084 - 240ms/epoch - 3ms/step
# Epoch 270/500
# 83/83 - 0s - loss: 0.0216 - val_loss: 0.0090 - 233ms/epoch - 3ms/step
# Epoch 271/500
# 83/83 - 0s - loss: 0.0162 - val_loss: 0.0085 - 227ms/epoch - 3ms/step
# Epoch 272/500
# 83/83 - 0s - loss: 0.0162 - val_loss: 0.0085 - 224ms/epoch - 3ms/step
# Epoch 273/500
# 83/83 - 0s - loss: 0.0242 - val_loss: 0.0085 - 225ms/epoch - 3ms/step
# Epoch 274/500
# 83/83 - 0s - loss: 0.0159 - val_loss: 0.0085 - 321ms/epoch - 4ms/step
# Epoch 275/500
# 83/83 - 0s - loss: 0.0159 - val_loss: 0.0085 - 349ms/epoch - 4ms/step
# Epoch 276/500
# 83/83 - 0s - loss: 0.0160 - val_loss: 0.0085 - 327ms/epoch - 4ms/step
# Epoch 277/500
# 83/83 - 0s - loss: 0.0161 - val_loss: 0.0085 - 309ms/epoch - 4ms/step
# Epoch 278/500
# 83/83 - 0s - loss: 0.0161 - val_loss: 0.0085 - 322ms/epoch - 4ms/step
# Epoch 279/500
# 83/83 - 0s - loss: 0.0158 - val_loss: 0.0085 - 283ms/epoch - 3ms/step
# Epoch 280/500
# 83/83 - 0s - loss: 0.0307 - val_loss: 0.0085 - 256ms/epoch - 3ms/step
# Epoch 281/500
# 83/83 - 0s - loss: 0.0164 - val_loss: 0.0085 - 258ms/epoch - 3ms/step
# Epoch 282/500
# 83/83 - 0s - loss: 0.0163 - val_loss: 0.0085 - 269ms/epoch - 3ms/step
# Epoch 283/500
# 83/83 - 0s - loss: 0.0158 - val_loss: 0.0085 - 273ms/epoch - 3ms/step
# Epoch 284/500
# 83/83 - 0s - loss: 0.0157 - val_loss: 0.0086 - 259ms/epoch - 3ms/step
# Epoch 285/500
# 83/83 - 0s - loss: 0.0158 - val_loss: 0.0085 - 249ms/epoch - 3ms/step
# Epoch 286/500
# 83/83 - 0s - loss: 0.0157 - val_loss: 0.0085 - 324ms/epoch - 4ms/step
# Epoch 287/500
# 83/83 - 0s - loss: 0.0227 - val_loss: 0.0085 - 267ms/epoch - 3ms/step
# Epoch 288/500
# 83/83 - 0s - loss: 0.0158 - val_loss: 0.0086 - 259ms/epoch - 3ms/step
# Epoch 289/500
# 83/83 - 0s - loss: 0.0157 - val_loss: 0.0086 - 276ms/epoch - 3ms/step
# Epoch 290/500
# 83/83 - 0s - loss: 0.0156 - val_loss: 0.0085 - 270ms/epoch - 3ms/step
# Epoch 291/500
# 83/83 - 0s - loss: 0.0167 - val_loss: 0.0085 - 259ms/epoch - 3ms/step
# Epoch 292/500
# 83/83 - 0s - loss: 0.0219 - val_loss: 0.0085 - 254ms/epoch - 3ms/step
# Epoch 293/500
# 83/83 - 1s - loss: 0.0157 - val_loss: 0.0086 - 606ms/epoch - 7ms/step
# Epoch 294/500
# 83/83 - 1s - loss: 0.0156 - val_loss: 0.0086 - 648ms/epoch - 8ms/step
# Epoch 295/500
# 83/83 - 1s - loss: 0.0156 - val_loss: 0.0085 - 703ms/epoch - 8ms/step
# Epoch 296/500
# 83/83 - 1s - loss: 0.0168 - val_loss: 0.0085 - 737ms/epoch - 9ms/step
# Epoch 297/500
# 83/83 - 1s - loss: 0.0235 - val_loss: 0.0086 - 700ms/epoch - 8ms/step
# Epoch 298/500
# 83/83 - 1s - loss: 0.0157 - val_loss: 0.0086 - 840ms/epoch - 10ms/step
# Epoch 299/500
# 83/83 - 1s - loss: 0.0159 - val_loss: 0.0087 - 837ms/epoch - 10ms/step
# Epoch 300/500
# 83/83 - 1s - loss: 0.0156 - val_loss: 0.0086 - 720ms/epoch - 9ms/step
# Epoch 301/500
# 83/83 - 1s - loss: 0.0186 - val_loss: 0.0088 - 717ms/epoch - 9ms/step
# Epoch 302/500
# 83/83 - 1s - loss: 0.0155 - val_loss: 0.0086 - 705ms/epoch - 8ms/step
# Epoch 303/500
# 83/83 - 1s - loss: 0.0186 - val_loss: 0.0088 - 735ms/epoch - 9ms/step
# Epoch 304/500
# 83/83 - 1s - loss: 0.0155 - val_loss: 0.0086 - 766ms/epoch - 9ms/step
# Epoch 305/500
# 83/83 - 1s - loss: 0.0173 - val_loss: 0.0088 - 683ms/epoch - 8ms/step
# Epoch 306/500
# 83/83 - 1s - loss: 0.0197 - val_loss: 0.0086 - 561ms/epoch - 7ms/step
# Epoch 307/500
# 83/83 - 0s - loss: 0.0154 - val_loss: 0.0086 - 380ms/epoch - 5ms/step
# Epoch 308/500
# 83/83 - 0s - loss: 0.0154 - val_loss: 0.0086 - 267ms/epoch - 3ms/step
# Epoch 309/500
# 83/83 - 0s - loss: 0.0154 - val_loss: 0.0086 - 254ms/epoch - 3ms/step
# Epoch 310/500
# 83/83 - 0s - loss: 0.0154 - val_loss: 0.0086 - 259ms/epoch - 3ms/step
# Epoch 311/500
# 83/83 - 0s - loss: 0.0289 - val_loss: 0.0087 - 254ms/epoch - 3ms/step
# Epoch 312/500
# 83/83 - 0s - loss: 0.0176 - val_loss: 0.0086 - 251ms/epoch - 3ms/step
# Epoch 313/500
# 83/83 - 0s - loss: 0.0163 - val_loss: 0.0086 - 246ms/epoch - 3ms/step
# Epoch 314/500
# 83/83 - 0s - loss: 0.0157 - val_loss: 0.0086 - 242ms/epoch - 3ms/step
# Epoch 315/500
# 83/83 - 0s - loss: 0.0153 - val_loss: 0.0086 - 239ms/epoch - 3ms/step
# Epoch 316/500
# 83/83 - 0s - loss: 0.0152 - val_loss: 0.0086 - 244ms/epoch - 3ms/step
# Epoch 317/500
# 83/83 - 0s - loss: 0.0155 - val_loss: 0.0087 - 252ms/epoch - 3ms/step
# Epoch 318/500
# 83/83 - 0s - loss: 0.0320 - val_loss: 0.0086 - 259ms/epoch - 3ms/step
# Epoch 319/500
# 83/83 - 0s - loss: 0.0154 - val_loss: 0.0085 - 258ms/epoch - 3ms/step
# Epoch 320/500
# 83/83 - 0s - loss: 0.0159 - val_loss: 0.0086 - 254ms/epoch - 3ms/step
# Epoch 321/500
# 83/83 - 0s - loss: 0.0158 - val_loss: 0.0085 - 249ms/epoch - 3ms/step
# Epoch 322/500
# 83/83 - 0s - loss: 0.0157 - val_loss: 0.0086 - 251ms/epoch - 3ms/step
# Epoch 323/500
# 83/83 - 0s - loss: 0.0153 - val_loss: 0.0086 - 245ms/epoch - 3ms/step
# Epoch 324/500
# 83/83 - 0s - loss: 0.0151 - val_loss: 0.0086 - 244ms/epoch - 3ms/step
# Epoch 325/500
# 83/83 - 0s - loss: 0.0151 - val_loss: 0.0086 - 255ms/epoch - 3ms/step
# Epoch 326/500
# 83/83 - 0s - loss: 0.0178 - val_loss: 0.0088 - 267ms/epoch - 3ms/step
# Epoch 327/500
# 83/83 - 0s - loss: 0.0163 - val_loss: 0.0086 - 261ms/epoch - 3ms/step
# Epoch 328/500
# 83/83 - 0s - loss: 0.0194 - val_loss: 0.0086 - 251ms/epoch - 3ms/step
# Epoch 329/500
# 83/83 - 0s - loss: 0.0151 - val_loss: 0.0086 - 246ms/epoch - 3ms/step
# Epoch 330/500
# 83/83 - 0s - loss: 0.0150 - val_loss: 0.0086 - 311ms/epoch - 4ms/step
# Epoch 331/500
# 83/83 - 0s - loss: 0.0157 - val_loss: 0.0086 - 255ms/epoch - 3ms/step
# Epoch 332/500
# 83/83 - 0s - loss: 0.0502 - val_loss: 0.0088 - 250ms/epoch - 3ms/step
# Epoch 333/500
# 83/83 - 0s - loss: 0.0151 - val_loss: 0.0085 - 259ms/epoch - 3ms/step
# Epoch 334/500
# 83/83 - 0s - loss: 0.0151 - val_loss: 0.0085 - 301ms/epoch - 4ms/step
# Epoch 335/500
# 83/83 - 0s - loss: 0.0150 - val_loss: 0.0085 - 262ms/epoch - 3ms/step
# Epoch 336/500
# 83/83 - 0s - loss: 0.0150 - val_loss: 0.0085 - 248ms/epoch - 3ms/step
# Epoch 337/500
# 83/83 - 0s - loss: 0.0150 - val_loss: 0.0086 - 251ms/epoch - 3ms/step
# Epoch 338/500
# 83/83 - 0s - loss: 0.0150 - val_loss: 0.0086 - 248ms/epoch - 3ms/step
# Epoch 339/500
# 83/83 - 0s - loss: 0.0153 - val_loss: 0.0086 - 245ms/epoch - 3ms/step
# Epoch 340/500
# 83/83 - 0s - loss: 0.0153 - val_loss: 0.0086 - 255ms/epoch - 3ms/step
# Epoch 341/500
# 83/83 - 0s - loss: 0.0153 - val_loss: 0.0086 - 266ms/epoch - 3ms/step
# Epoch 342/500
# 83/83 - 0s - loss: 0.0150 - val_loss: 0.0086 - 255ms/epoch - 3ms/step
# Epoch 343/500
# 83/83 - 0s - loss: 0.0149 - val_loss: 0.0086 - 253ms/epoch - 3ms/step
# Epoch 344/500
# 83/83 - 0s - loss: 0.0156 - val_loss: 0.0087 - 242ms/epoch - 3ms/step
# Epoch 345/500
# 83/83 - 0s - loss: 0.0155 - val_loss: 0.0088 - 250ms/epoch - 3ms/step
# Epoch 346/500
# 83/83 - 0s - loss: 0.0401 - val_loss: 0.0085 - 259ms/epoch - 3ms/step
# Epoch 347/500
# 83/83 - 0s - loss: 0.0150 - val_loss: 0.0085 - 274ms/epoch - 3ms/step
# Epoch 348/500
# 83/83 - 0s - loss: 0.0149 - val_loss: 0.0085 - 260ms/epoch - 3ms/step
# Epoch 349/500
# 83/83 - 0s - loss: 0.0149 - val_loss: 0.0086 - 271ms/epoch - 3ms/step
# Epoch 350/500
# 83/83 - 0s - loss: 0.0151 - val_loss: 0.0086 - 298ms/epoch - 4ms/step
# Epoch 351/500
# 83/83 - 0s - loss: 0.0154 - val_loss: 0.0086 - 303ms/epoch - 4ms/step
# Epoch 352/500
# 83/83 - 0s - loss: 0.0152 - val_loss: 0.0086 - 318ms/epoch - 4ms/step
# Epoch 353/500
# 83/83 - 0s - loss: 0.0151 - val_loss: 0.0086 - 281ms/epoch - 3ms/step
# Epoch 354/500
# 83/83 - 0s - loss: 0.0149 - val_loss: 0.0086 - 258ms/epoch - 3ms/step
# Epoch 355/500
# 83/83 - 0s - loss: 0.0148 - val_loss: 0.0086 - 267ms/epoch - 3ms/step
# Epoch 356/500
# 83/83 - 0s - loss: 0.0160 - val_loss: 0.0086 - 274ms/epoch - 3ms/step
# Epoch 357/500
# 83/83 - 0s - loss: 0.0148 - val_loss: 0.0087 - 259ms/epoch - 3ms/step
# Epoch 358/500
# 83/83 - 0s - loss: 0.0220 - val_loss: 0.0086 - 254ms/epoch - 3ms/step
# Epoch 359/500
# 83/83 - 0s - loss: 0.0149 - val_loss: 0.0086 - 246ms/epoch - 3ms/step
# Epoch 360/500
# 83/83 - 0s - loss: 0.0148 - val_loss: 0.0086 - 253ms/epoch - 3ms/step
# Epoch 361/500
# 83/83 - 0s - loss: 0.0147 - val_loss: 0.0086 - 246ms/epoch - 3ms/step
# Epoch 362/500
# 83/83 - 0s - loss: 0.0159 - val_loss: 0.0086 - 244ms/epoch - 3ms/step
# Epoch 363/500
# 83/83 - 0s - loss: 0.0159 - val_loss: 0.0087 - 248ms/epoch - 3ms/step
# Epoch 364/500
# 83/83 - 0s - loss: 0.0454 - val_loss: 0.0086 - 294ms/epoch - 4ms/step
# Epoch 365/500
# 83/83 - 0s - loss: 0.0148 - val_loss: 0.0085 - 265ms/epoch - 3ms/step
# Epoch 366/500
# 83/83 - 0s - loss: 0.0147 - val_loss: 0.0085 - 258ms/epoch - 3ms/step
# Epoch 367/500
# 83/83 - 0s - loss: 0.0147 - val_loss: 0.0086 - 246ms/epoch - 3ms/step
# Epoch 368/500
# 83/83 - 0s - loss: 0.0147 - val_loss: 0.0086 - 253ms/epoch - 3ms/step
# Epoch 369/500
# 83/83 - 0s - loss: 0.0148 - val_loss: 0.0086 - 249ms/epoch - 3ms/step
# Epoch 370/500
# 83/83 - 0s - loss: 0.0151 - val_loss: 0.0086 - 256ms/epoch - 3ms/step
# Epoch 371/500
# 83/83 - 0s - loss: 0.0151 - val_loss: 0.0086 - 258ms/epoch - 3ms/step
# Epoch 372/500
# 83/83 - 0s - loss: 0.0147 - val_loss: 0.0086 - 267ms/epoch - 3ms/step
# Epoch 373/500
# 83/83 - 0s - loss: 0.0146 - val_loss: 0.0086 - 254ms/epoch - 3ms/step
# Epoch 374/500
# 83/83 - 0s - loss: 0.0146 - val_loss: 0.0086 - 253ms/epoch - 3ms/step
# Epoch 375/500
# 83/83 - 0s - loss: 0.0162 - val_loss: 0.0086 - 307ms/epoch - 4ms/step
# Epoch 376/500
# 83/83 - 0s - loss: 0.0166 - val_loss: 0.0087 - 263ms/epoch - 3ms/step
# Epoch 377/500
# 83/83 - 0s - loss: 0.0154 - val_loss: 0.0087 - 251ms/epoch - 3ms/step
# Epoch 378/500
# 83/83 - 0s - loss: 0.0153 - val_loss: 0.0087 - 254ms/epoch - 3ms/step
# Epoch 379/500
# 83/83 - 0s - loss: 0.0174 - val_loss: 0.0086 - 261ms/epoch - 3ms/step
# Epoch 380/500
# 83/83 - 0s - loss: 0.0151 - val_loss: 0.0086 - 269ms/epoch - 3ms/step
# Epoch 381/500
# 83/83 - 0s - loss: 0.0147 - val_loss: 0.0086 - 258ms/epoch - 3ms/step
# Epoch 382/500
# 83/83 - 0s - loss: 0.0179 - val_loss: 0.0087 - 250ms/epoch - 3ms/step
# Epoch 383/500
# 83/83 - 0s - loss: 0.0189 - val_loss: 0.0086 - 253ms/epoch - 3ms/step
# Epoch 384/500
# 83/83 - 0s - loss: 0.0144 - val_loss: 0.0086 - 252ms/epoch - 3ms/step
# Epoch 385/500
# 83/83 - 0s - loss: 0.0146 - val_loss: 0.0086 - 253ms/epoch - 3ms/step
# Epoch 386/500
# 83/83 - 0s - loss: 0.0147 - val_loss: 0.0086 - 256ms/epoch - 3ms/step
# Epoch 387/500
# 83/83 - 0s - loss: 0.0181 - val_loss: 0.0087 - 263ms/epoch - 3ms/step
# Epoch 388/500
# 83/83 - 0s - loss: 0.0173 - val_loss: 0.0086 - 270ms/epoch - 3ms/step
# Epoch 389/500
# 83/83 - 0s - loss: 0.0144 - val_loss: 0.0086 - 256ms/epoch - 3ms/step
# Epoch 390/500
# 83/83 - 0s - loss: 0.0159 - val_loss: 0.0087 - 248ms/epoch - 3ms/step
# Epoch 391/500
# 83/83 - 0s - loss: 0.0204 - val_loss: 0.0086 - 250ms/epoch - 3ms/step
# Epoch 392/500
# 83/83 - 0s - loss: 0.0144 - val_loss: 0.0086 - 251ms/epoch - 3ms/step
# Epoch 393/500
# 83/83 - 0s - loss: 0.0143 - val_loss: 0.0087 - 269ms/epoch - 3ms/step
# Epoch 394/500
# 83/83 - 0s - loss: 0.0149 - val_loss: 0.0087 - 260ms/epoch - 3ms/step
# Epoch 395/500
# 83/83 - 0s - loss: 0.0143 - val_loss: 0.0087 - 281ms/epoch - 3ms/step
# Epoch 396/500
# 83/83 - 0s - loss: 0.0487 - val_loss: 0.0092 - 276ms/epoch - 3ms/step
# Epoch 397/500
# 83/83 - 0s - loss: 0.0145 - val_loss: 0.0086 - 252ms/epoch - 3ms/step
# Epoch 398/500
# 83/83 - 0s - loss: 0.0144 - val_loss: 0.0086 - 246ms/epoch - 3ms/step
# Epoch 399/500
# 83/83 - 0s - loss: 0.0143 - val_loss: 0.0086 - 249ms/epoch - 3ms/step
# Epoch 400/500
# 83/83 - 0s - loss: 0.0143 - val_loss: 0.0086 - 254ms/epoch - 3ms/step
# Epoch 401/500
# 83/83 - 0s - loss: 0.0143 - val_loss: 0.0086 - 253ms/epoch - 3ms/step
# Epoch 402/500
# 83/83 - 0s - loss: 0.0145 - val_loss: 0.0086 - 252ms/epoch - 3ms/step
# Epoch 403/500
# 83/83 - 0s - loss: 0.0150 - val_loss: 0.0086 - 258ms/epoch - 3ms/step
# Epoch 404/500
# 83/83 - 0s - loss: 0.0149 - val_loss: 0.0086 - 261ms/epoch - 3ms/step
# Epoch 405/500
# 83/83 - 0s - loss: 0.0143 - val_loss: 0.0086 - 246ms/epoch - 3ms/step
# Epoch 406/500
# 83/83 - 0s - loss: 0.0142 - val_loss: 0.0087 - 248ms/epoch - 3ms/step
# Epoch 407/500
# 83/83 - 0s - loss: 0.0143 - val_loss: 0.0087 - 244ms/epoch - 3ms/step
# Epoch 408/500
# 83/83 - 0s - loss: 0.0160 - val_loss: 0.0087 - 245ms/epoch - 3ms/step
# Epoch 409/500
# 83/83 - 0s - loss: 0.0151 - val_loss: 0.0087 - 247ms/epoch - 3ms/step
# Epoch 410/500
# 83/83 - 0s - loss: 0.0152 - val_loss: 0.0087 - 254ms/epoch - 3ms/step
# Epoch 411/500
# 83/83 - 0s - loss: 0.0147 - val_loss: 0.0087 - 255ms/epoch - 3ms/step
# Epoch 412/500
# 83/83 - 0s - loss: 0.0239 - val_loss: 0.0086 - 259ms/epoch - 3ms/step
# Epoch 413/500
# 83/83 - 0s - loss: 0.0144 - val_loss: 0.0087 - 243ms/epoch - 3ms/step
# Epoch 414/500
# 83/83 - 0s - loss: 0.0142 - val_loss: 0.0087 - 243ms/epoch - 3ms/step
# Epoch 415/500
# 83/83 - 0s - loss: 0.0141 - val_loss: 0.0087 - 244ms/epoch - 3ms/step
# Epoch 416/500
# 83/83 - 0s - loss: 0.0141 - val_loss: 0.0087 - 245ms/epoch - 3ms/step
# Epoch 417/500
# 83/83 - 0s - loss: 0.0209 - val_loss: 0.0087 - 253ms/epoch - 3ms/step
# Epoch 418/500
# 83/83 - 0s - loss: 0.0144 - val_loss: 0.0087 - 251ms/epoch - 3ms/step
# Epoch 419/500
# 83/83 - 0s - loss: 0.0141 - val_loss: 0.0087 - 255ms/epoch - 3ms/step
# Epoch 420/500
# 83/83 - 0s - loss: 0.0143 - val_loss: 0.0087 - 271ms/epoch - 3ms/step
# Epoch 421/500
# 83/83 - 0s - loss: 0.0160 - val_loss: 0.0087 - 304ms/epoch - 4ms/step
# Epoch 422/500
# 83/83 - 0s - loss: 0.0151 - val_loss: 0.0087 - 250ms/epoch - 3ms/step
# Epoch 423/500
# 83/83 - 0s - loss: 0.0204 - val_loss: 0.0087 - 242ms/epoch - 3ms/step
# Epoch 424/500
# 83/83 - 0s - loss: 0.0142 - val_loss: 0.0087 - 246ms/epoch - 3ms/step
# Epoch 425/500
# 83/83 - 0s - loss: 0.0141 - val_loss: 0.0087 - 254ms/epoch - 3ms/step
# Epoch 426/500
# 83/83 - 0s - loss: 0.0152 - val_loss: 0.0087 - 255ms/epoch - 3ms/step
# Epoch 427/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0087 - 271ms/epoch - 3ms/step
# Epoch 428/500
# 83/83 - 0s - loss: 0.0582 - val_loss: 0.0086 - 318ms/epoch - 4ms/step
# Epoch 429/500
# 83/83 - 0s - loss: 0.0142 - val_loss: 0.0086 - 340ms/epoch - 4ms/step
# Epoch 430/500
# 83/83 - 0s - loss: 0.0141 - val_loss: 0.0086 - 312ms/epoch - 4ms/step
# Epoch 431/500
# 83/83 - 0s - loss: 0.0141 - val_loss: 0.0086 - 343ms/epoch - 4ms/step
# Epoch 432/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0086 - 343ms/epoch - 4ms/step
# Epoch 433/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0086 - 322ms/epoch - 4ms/step
# Epoch 434/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0086 - 263ms/epoch - 3ms/step
# Epoch 435/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0086 - 239ms/epoch - 3ms/step
# Epoch 436/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0087 - 240ms/epoch - 3ms/step
# Epoch 437/500
# 83/83 - 0s - loss: 0.0143 - val_loss: 0.0087 - 235ms/epoch - 3ms/step
# Epoch 438/500
# 83/83 - 0s - loss: 0.0147 - val_loss: 0.0087 - 239ms/epoch - 3ms/step
# Epoch 439/500
# 83/83 - 0s - loss: 0.0143 - val_loss: 0.0087 - 242ms/epoch - 3ms/step
# Epoch 440/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0087 - 255ms/epoch - 3ms/step
# Epoch 441/500
# 83/83 - 0s - loss: 0.0141 - val_loss: 0.0087 - 247ms/epoch - 3ms/step
# Epoch 442/500
# 83/83 - 0s - loss: 0.0151 - val_loss: 0.0087 - 247ms/epoch - 3ms/step
# Epoch 443/500
# 83/83 - 0s - loss: 0.0152 - val_loss: 0.0087 - 232ms/epoch - 3ms/step
# Epoch 444/500
# 83/83 - 0s - loss: 0.0142 - val_loss: 0.0087 - 231ms/epoch - 3ms/step
# Epoch 445/500
# 83/83 - 0s - loss: 0.0209 - val_loss: 0.0087 - 236ms/epoch - 3ms/step
# Epoch 446/500
# 83/83 - 0s - loss: 0.0142 - val_loss: 0.0087 - 242ms/epoch - 3ms/step
# Epoch 447/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0087 - 247ms/epoch - 3ms/step
# Epoch 448/500
# 83/83 - 0s - loss: 0.0145 - val_loss: 0.0087 - 241ms/epoch - 3ms/step
# Epoch 449/500
# 83/83 - 0s - loss: 0.0150 - val_loss: 0.0087 - 250ms/epoch - 3ms/step
# Epoch 450/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0087 - 245ms/epoch - 3ms/step
# Epoch 451/500
# 83/83 - 0s - loss: 0.0522 - val_loss: 0.0086 - 250ms/epoch - 3ms/step
# Epoch 452/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0086 - 246ms/epoch - 3ms/step
# Epoch 453/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0086 - 239ms/epoch - 3ms/step
# Epoch 454/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0086 - 230ms/epoch - 3ms/step
# Epoch 455/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0086 - 251ms/epoch - 3ms/step
# Epoch 456/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0087 - 240ms/epoch - 3ms/step
# Epoch 457/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0087 - 250ms/epoch - 3ms/step
# Epoch 458/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0087 - 259ms/epoch - 3ms/step
# Epoch 459/500
# 83/83 - 0s - loss: 0.0142 - val_loss: 0.0087 - 248ms/epoch - 3ms/step
# Epoch 460/500
# 83/83 - 0s - loss: 0.0145 - val_loss: 0.0087 - 230ms/epoch - 3ms/step
# Epoch 461/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0087 - 300ms/epoch - 4ms/step
# Epoch 462/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0087 - 241ms/epoch - 3ms/step
# Epoch 463/500
# 83/83 - 0s - loss: 0.0143 - val_loss: 0.0087 - 250ms/epoch - 3ms/step
# Epoch 464/500
# 83/83 - 0s - loss: 0.0158 - val_loss: 0.0087 - 247ms/epoch - 3ms/step
# Epoch 465/500
# 83/83 - 0s - loss: 0.0238 - val_loss: 0.0090 - 253ms/epoch - 3ms/step
# Epoch 466/500
# 83/83 - 0s - loss: 0.0142 - val_loss: 0.0087 - 243ms/epoch - 3ms/step
# Epoch 467/500
# 83/83 - 0s - loss: 0.0137 - val_loss: 0.0087 - 248ms/epoch - 3ms/step
# Epoch 468/500
# 83/83 - 0s - loss: 0.0137 - val_loss: 0.0087 - 241ms/epoch - 3ms/step
# Epoch 469/500
# 83/83 - 0s - loss: 0.0137 - val_loss: 0.0087 - 240ms/epoch - 3ms/step
# Epoch 470/500
# 83/83 - 0s - loss: 0.0181 - val_loss: 0.0087 - 230ms/epoch - 3ms/step
# Epoch 471/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0087 - 246ms/epoch - 3ms/step
# Epoch 472/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0087 - 251ms/epoch - 3ms/step
# Epoch 473/500
# 83/83 - 0s - loss: 0.0137 - val_loss: 0.0087 - 246ms/epoch - 3ms/step
# Epoch 474/500
# 83/83 - 0s - loss: 0.0492 - val_loss: 0.0086 - 248ms/epoch - 3ms/step
# Epoch 475/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0086 - 237ms/epoch - 3ms/step
# Epoch 476/500
# 83/83 - 0s - loss: 0.0137 - val_loss: 0.0086 - 238ms/epoch - 3ms/step
# Epoch 477/500
# 83/83 - 0s - loss: 0.0137 - val_loss: 0.0086 - 238ms/epoch - 3ms/step
# Epoch 478/500
# 83/83 - 0s - loss: 0.0137 - val_loss: 0.0087 - 233ms/epoch - 3ms/step
# Epoch 479/500
# 83/83 - 0s - loss: 0.0137 - val_loss: 0.0087 - 236ms/epoch - 3ms/step
# Epoch 480/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0087 - 246ms/epoch - 3ms/step
# Epoch 481/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0087 - 250ms/epoch - 3ms/step
# Epoch 482/500
# 83/83 - 0s - loss: 0.0142 - val_loss: 0.0087 - 245ms/epoch - 3ms/step
# Epoch 483/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0087 - 239ms/epoch - 3ms/step
# Epoch 484/500
# 83/83 - 0s - loss: 0.0136 - val_loss: 0.0087 - 237ms/epoch - 3ms/step
# Epoch 485/500
# 83/83 - 0s - loss: 0.0145 - val_loss: 0.0087 - 234ms/epoch - 3ms/step
# Epoch 486/500
# 83/83 - 0s - loss: 0.0164 - val_loss: 0.0087 - 228ms/epoch - 3ms/step
# Epoch 487/500
# 83/83 - 0s - loss: 0.0178 - val_loss: 0.0088 - 232ms/epoch - 3ms/step
# Epoch 488/500
# 83/83 - 0s - loss: 0.0136 - val_loss: 0.0087 - 241ms/epoch - 3ms/step
# Epoch 489/500
# 83/83 - 0s - loss: 0.0136 - val_loss: 0.0087 - 253ms/epoch - 3ms/step
# Epoch 490/500
# 83/83 - 0s - loss: 0.0155 - val_loss: 0.0087 - 241ms/epoch - 3ms/step
# Epoch 491/500
# 83/83 - 0s - loss: 0.0367 - val_loss: 0.0088 - 264ms/epoch - 3ms/step
# Epoch 492/500
# 83/83 - 0s - loss: 0.0136 - val_loss: 0.0086 - 236ms/epoch - 3ms/step
# Epoch 493/500
# 83/83 - 0s - loss: 0.0136 - val_loss: 0.0087 - 246ms/epoch - 3ms/step
# Epoch 494/500
# 83/83 - 0s - loss: 0.0136 - val_loss: 0.0087 - 232ms/epoch - 3ms/step
# Epoch 495/500
# 83/83 - 0s - loss: 0.0137 - val_loss: 0.0087 - 238ms/epoch - 3ms/step
# Epoch 496/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0087 - 239ms/epoch - 3ms/step
# Epoch 497/500
# 83/83 - 0s - loss: 0.0139 - val_loss: 0.0087 - 255ms/epoch - 3ms/step
# Epoch 498/500
# 83/83 - 0s - loss: 0.0136 - val_loss: 0.0087 - 242ms/epoch - 3ms/step
# Epoch 499/500
# 83/83 - 0s - loss: 0.0138 - val_loss: 0.0087 - 245ms/epoch - 3ms/step
# Epoch 500/500
# 83/83 - 0s - loss: 0.0140 - val_loss: 0.0088 - 233ms/epoch - 3ms/step

# %% [markdown]
# ## Metrics ($LPINN$)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 42/42 [==============================] - 1s 2ms/step
# (1313, 3)
# (1313, 10)
# Test RMSE: 0.365
# Test MAE: 0.273

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y, marker='.', label="actual")
plt.plot(inv_yhat, 'r', label="prediction")
plt.suptitle('Turkey Seismic Waves', fontsize=20)
plt.legend(fontsize=20)
plt.show()
