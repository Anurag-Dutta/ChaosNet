# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.3.4)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
from matplotlib import pyplot
from numpy import array

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _EL NINO_

# %%
data = pd.read_csv("datasets/elnino.csv")
training_set = data.iloc[:,1]
print(training_set)
# Out:
# 0       23.4
# 1       23.4
# 2       24.2
# 3       24.4
# 4       25.1
#         ...
# 1629    25.4
# 1630    24.9
# 1631    25.3
# 1632    24.7
# 1633    24.6
# Name: SST1, Length: 1634, dtype: float64

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 7 # Weekly Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 29.2
# 1       0.000000
# 2       0.114286
# 3       0.028571
# 4       0.100000
# 5       0.100000
#           ...
# 1629   -0.242857
# 1630   -0.071429
# 1631    0.057143
# 1632   -0.085714
# 1633   -0.014286
# Name: SST1, Length: 1633, dtype: float64
# 2       1.632653e-02
# 3      -1.224490e-02
# 4       1.020408e-02
# 5      -7.335402e-17
# 6      -1.224490e-02
#             ...
# 1629   -2.857143e-02
# 1630    2.448980e-02
# 1631    1.836735e-02
# 1632   -2.040816e-02
# 1633    1.020408e-02
# Name: SST1, Length: 1632, dtype: float64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0       0.000000
# 1       0.114286
# 2       0.028571
# 3       0.100000
# 4       0.100000
#           ...
# 1628   -0.242857
# 1629   -0.071429
# 1630    0.057143
# 1631   -0.085714
# 1632   -0.014286
# Name: SST1, Length: 1633, dtype: float64
# 0       1.632653e-02
# 1      -1.224490e-02
# 2       1.020408e-02
# 3      -7.335402e-17
# 4      -1.224490e-02
#             ...
# 1627   -2.857143e-02
# 1628    2.448980e-02
# 1629    1.836735e-02
# 1630   -2.040816e-02
# 1631    1.020408e-02
# Name: SST1, Length: 1632, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (1633,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lotka Volterra Equation_)

# %%
a=0.1
b=0.05
c=1.1
d=0.1
L = df.iloc[:, 2] - a*a*df.iloc[:, 0] + 2*a*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*d*(df.iloc[:,0]**2)*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - c*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the data into supervised learning

# %%
def Supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
      cols.append(df.shift(-i))
      if i == 0:
        names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
      else:
        names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
       agg.dropna(inplace=True)
    return agg

# %%
dat = Supervised(df.values, n_in = 10, n_out = 52)
dat.columns
# Out:
# Index(['var1(t-10)', 'var2(t-10)', 'var3(t-10)', 'var1(t-9)', 'var2(t-9)',
#        'var3(t-9)', 'var1(t-8)', 'var2(t-8)', 'var3(t-8)', 'var1(t-7)',
#        ...
#        'var3(t+48)', 'var1(t+49)', 'var2(t+49)', 'var3(t+49)', 'var1(t+50)',
#        'var2(t+50)', 'var3(t+50)', 'var1(t+51)', 'var2(t+51)', 'var3(t+51)'],
#       dtype='object', length=186)

# %%
data = Supervised(df.values, n_in = 10, n_out = 52)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
       'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
       'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
       'var3(t-2)', 'var2(t-1)', 'var3(t-1)','var2(t-3)', 'var3(t-3)'], axis = 1, inplace = True)#,18,19
print(data.head())
print(data.columns)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10        23.4       23.4       24.2       24.4       25.1       25.8
# 11        23.4       24.2       24.4       25.1       25.8       25.9
# 12        24.2       24.4       25.1       25.8       25.9       26.1
# 13        24.4       25.1       25.8       25.9       26.1       26.1
# 14        25.1       25.8       25.9       26.1       26.1       26.7
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  ...  var3(t+48)  var1(t+49)  \
# 10       25.9       26.1       26.1       26.7  ...   -0.010204        26.5
# 11       26.1       26.1       26.7       26.1  ...    0.000000        26.5
# 12       26.1       26.7       26.1       26.1  ...    0.006122        26.5
# 13       26.7       26.1       26.1       25.7  ...   -0.010204        26.8
# 14       26.1       26.1       25.7       25.6  ...   -0.004082        26.6
#
#     var2(t+49)    var3(t+49)  var1(t+50)  var2(t+50)    var3(t+50)  \
# 10    0.000000  0.000000e+00        26.5    0.000000  6.122449e-03
# 11    0.000000  6.122449e-03        26.5    0.042857 -1.020408e-02
# 12    0.042857 -1.020408e-02        26.8   -0.028571 -4.081633e-03
# 13   -0.028571 -4.081633e-03        26.6   -0.057143  7.236275e-17
# 14   -0.057143  7.236275e-17        26.2   -0.057143 -4.081633e-03
#
#     var1(t+51)  var2(t+51)    var3(t+51)
# 10        26.5    0.042857 -1.020408e-02
# 11        26.8   -0.028571 -4.081633e-03
# 12        26.6   -0.057143  7.236275e-17
# 13        26.2   -0.057143 -4.081633e-03
# 14        25.8   -0.085714  6.122449e-03
#
# [5 rows x 166 columns]
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        ...
#        'var3(t+48)', 'var1(t+49)', 'var2(t+49)', 'var3(t+49)', 'var1(t+50)',
#        'var2(t+50)', 'var3(t+50)', 'var1(t+51)', 'var2(t+51)', 'var3(t+51)'],
#       dtype='object', length=166)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(data) * 0.8)
test_size = len(data) - train_size
train_1 = np.array(data[0:train_size])
test_1 = np.array(data[train_size:len(data)])
scaler = MinMaxScaler(feature_range=(0, 1))
train = scaler.fit_transform(train_1)
test = scaler.transform(test_1)
trainY = train[:,-9:]
trainX = train[:,:-9]
testY = test[:,-9:]
testX = test[:,:-9]
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (1256, 1, 157) (1256, 9) (315, 1, 157) (315, 9)

# %% [markdown]
# ## Defining the Physical Loss

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] - a*a*y_true[:, 0] + 2*a*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*d*(y_true[:,0]**2)*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - c*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))), (y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] - a*a*y_pred[:-2] + 2*a*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*d*(y_pred[:-2]**2)*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - c*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] - a*a*y_real[:-2] + 2*a*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*d*(y_real[:-2]**2)*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - c*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square(y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(9))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX, trainY, epochs=500, batch_size=64, validation_data=(testX, testY), shuffle=False)
# Out:
# Epoch 1/500
# 20/20 [==============================] - 3s 30ms/step - loss: 0.1036 - val_loss: 0.0592
# Epoch 2/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0316 - val_loss: 0.0147
# Epoch 3/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0139 - val_loss: 0.0095
# Epoch 4/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0113 - val_loss: 0.0087
# Epoch 5/500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0106 - val_loss: 0.0077
# Epoch 6/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0097 - val_loss: 0.0067
# Epoch 7/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0087 - val_loss: 0.0060
# Epoch 8/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0077 - val_loss: 0.0055
# Epoch 9/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 0.0051
# Epoch 10/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0046
# Epoch 11/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0041
# Epoch 12/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 13/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0041 - val_loss: 0.0033
# Epoch 14/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 15/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 16/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 0.0025
# Epoch 17/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 18/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 19/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.
500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3678e-05 - val_loss: 2.4460e-05
# Epoch 236/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3633e-05 - val_loss: 2.4322e-05
# Epoch 237/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3594e-05 - val_loss: 2.4181e-05
# Epoch 238/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3558e-05 - val_loss: 2.4041e-05
# Epoch 239/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3539e-05 - val_loss: 2.3907e-05
# Epoch 240/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3554e-05 - val_loss: 2.3776e-05
# Epoch 241/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3599e-05 - val_loss: 2.3641e-05
# Epoch 242/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3655e-05 - val_loss: 2.3502e-05
# Epoch 243/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3729e-05 - val_loss: 2.3377e-05
# Epoch 244/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3866e-05 - val_loss: 2.3288e-05
# Epoch 245/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4094e-05 - val_loss: 2.3259e-05
# Epoch 246/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4400e-05 - val_loss: 2.3350e-05
# Epoch 247/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4772e-05 - val_loss: 2.3676e-05
# Epoch 248/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5219e-05 - val_loss: 2.4363e-05
# Epoch 249/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5715e-05 - val_loss: 2.5499e-05
# Epoch 250/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.6176e-05 - val_loss: 2.7076e-05
# Epoch 251/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.6487e-05 - val_loss: 2.8882e-05
# Epoch 252/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.6536e-05 - val_loss: 3.0485e-05
# Epoch 253/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.6250e-05 - val_loss: 3.1388e-05
# Epoch 254/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5649e-05 - val_loss: 3.1306e-05
# Epoch 255/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4860e-05 - val_loss: 3.0330e-05
# Epoch 256/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4051e-05 - val_loss: 2.8879e-05
# Epoch 257/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3361e-05 - val_loss: 2.7426e-05
# Epoch 258/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.2847e-05 - val_loss: 2.6263e-05
# Epoch 259/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.2492e-05 - val_loss: 2.5441e-05
# Epoch 260/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.2244e-05 - val_loss: 2.4869e-05
# Epoch 261/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.2058e-05 - val_loss: 2.4430e-05
# Epoch 262/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1907e-05 - val_loss: 2.4046e-05
# Epoch 263/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.1779e-05 - val_loss: 2.3696e-05
# Epoch 264/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.1674e-05 - val_loss: 2.3388e-05
# Epoch 265/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1586e-05 - val_loss: 2.3129e-05
# Epoch 266/500
# 20/20 [==============================] - 0s 8ms/step - loss: 1.1509e-05 - val_loss: 2.2904e-05
# Epoch 267/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1452e-05 - val_loss: 2.2701e-05
# Epoch 268/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1400e-05 - val_loss: 2.2535e-05
# Epoch 269/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1341e-05 - val_loss: 2.2413e-05
# Epoch 270/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1323e-05 - val_loss: 2.2295e-05
# Epoch 271/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1338e-05 - val_loss: 2.2149e-05
# Epoch 272/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1259e-05 - val_loss: 2.2048e-05
# Epoch 273/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1163e-05 - val_loss: 2.2172e-05
# Epoch 274/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1380e-05 - val_loss: 2.2441e-05
# Epoch 275/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1710e-05 - val_loss: 2.2201e-05
# Epoch 276/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1385e-05 - val_loss: 2.1533e-05
# Epoch 277/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.0922e-05 - val_loss: 2.1713e-05
# Epoch 278/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1268e-05 - val_loss: 2.4018e-05
# Epoch 279/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3039e-05 - val_loss: 2.6404e-05
# Epoch 280/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3443e-05 - val_loss: 2.5599e-05
# Epoch 281/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.2711e-05 - val_loss: 2.5470e-05
# Epoch 282/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3124e-05 - val_loss: 2.7853e-05
# Epoch 283/500
# 20/20 [==============================] - 0s 8ms/step - loss: 1.4257e-05 - val_loss: 3.0478e-05
# Epoch 284/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5273e-05 - val_loss: 3.3800e-05
# Epoch 285/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.7298e-05 - val_loss: 4.0106e-05
# Epoch 286/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0296e-05 - val_loss: 4.7609e-05
# Epoch 287/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.4469e-05 - val_loss: 5.8378e-05
# Epoch 288/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.1457e-05 - val_loss: 7.3871e-05
# Epoch 289/500
# 20/20 [==============================] - 0s 6ms/step - loss: 3.9777e-05 - val_loss: 8.9681e-05
# Epoch 290/500
# 20/20 [==============================] - 0s 6ms/step - loss: 5.3927e-05 - val_loss: 1.2181e-04
# Epoch 291/500
# 20/20 [==============================] - 0s 5ms/step - loss: 7.8042e-05 - val_loss: 1.7991e-04
# Epoch 292/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.9932e-04 - val_loss: 7.8307e-04
# Epoch 293/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4180 - val_loss: 3.2460
# Epoch 294/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.9008 - val_loss: 4.0606
# Epoch 295/500
# 20/20 [==============================] - 0s 4ms/step - loss: 3.7180 - val_loss: 3.5732
# Epoch 296/500
# 20/20 [==============================] - 0s 4ms/step - loss: 3.2236 - val_loss: 3.0665
# Epoch 297/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.7660 - val_loss: 2.6320
# Epoch 298/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.3597 - val_loss: 2.2090
# Epoch 299/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.9540 - val_loss: 1.8085
# Epoch 300/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5930 - val_loss: 1.4685
# Epoch 301/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.2743 - val_loss: 1.1281
# Epoch 302/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.9501 - val_loss: 0.8479
# Epoch 303/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7533 - val_loss: 0.7264
# Epoch 304/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6599 - val_loss: 0.6521
# Epoch 305/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5936 - val_loss: 0.5901
# Epoch 306/500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5358 - val_loss: 0.5332
# Epoch 307/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4827 - val_loss: 0.4808
# Epoch 308/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4349 - val_loss: 19840.1680
# Epoch 309/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4374 - val_loss: 0.4646
# Epoch 310/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4286 - val_loss: 0.4380
# Epoch 311/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3996 - val_loss: 0.4074
# Epoch 312/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4642 - val_loss: 0.5340
# Epoch 313/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5047 - val_loss: 0.5286
# Epoch 314/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4899 - val_loss: 0.5077
# Epoch 315/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4687 - val_loss: 0.4856
# Epoch 316/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4476 - val_loss: 0.4641
# Epoch 317/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4272 - val_loss: 0.4435
# Epoch 318/500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4077 - val_loss: 0.4239
# Epoch 319/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3894 - val_loss: 0.4056
# Epoch 320/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3722 - val_loss: 0.3886
# Epoch 321/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3564 - val_loss: 0.3730
# Epoch 322/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3418 - val_loss: 0.3606
# Epoch 323/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3310 - val_loss: 0.3524
# Epoch 324/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.7609 - val_loss: 0.6179
# Epoch 325/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.0204 - val_loss: 1.3742
# Epoch 326/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4576 - val_loss: 1.5341
# Epoch 327/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5307 - val_loss: 1.5547
# Epoch 328/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5395 - val_loss: 1.5567
# Epoch 329/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5401 - val_loss: 1.5564
# Epoch 330/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5396 - val_loss: 1.5558
# Epoch 331/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5389 - val_loss: 1.5551
# Epoch 332/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5383 - val_loss: 1.5545
# Epoch 333/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5376 - val_loss: 1.5538
# Epoch 334/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5369 - val_loss: 1.5532
# Epoch 335/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5362 - val_loss: 1.5525
# Epoch 336/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.5356 - val_loss: 1.5518
# Epoch 337/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5349 - val_loss: 1.5512
# Epoch 338/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5342 - val_loss: 1.5505
# Epoch 339/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5335 - val_loss: 1.5498
# Epoch 340/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5328 - val_loss: 1.5491
# Epoch 341/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5321 - val_loss: 1.5484
# Epoch 342/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5314 - val_loss: 1.5478
# Epoch 343/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5307 - val_loss: 1.5471
# Epoch 344/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5300 - val_loss: 1.5464
# Epoch 345/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5292 - val_loss: 1.5456
# Epoch 346/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5285 - val_loss: 1.5449
# Epoch 347/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5278 - val_loss: 1.5442
# Epoch 348/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5271 - val_loss: 1.5435
# Epoch 349/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5263 - val_loss: 1.5428
# Epoch 350/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5256 - val_loss: 1.5420
# Epoch 351/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5248 - val_loss: 1.5413
# Epoch 352/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.5241 - val_loss: 1.5406
# Epoch 353/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5233 - val_loss: 1.5398
# Epoch 354/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5226 - val_loss: 1.5391
# Epoch 355/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5218 - val_loss: 1.5383
# Epoch 356/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5210 - val_loss: 1.5376
# Epoch 357/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5202 - val_loss: 1.5368
# Epoch 358/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5194 - val_loss: 1.5360
# Epoch 359/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5187 - val_loss: 1.5353
# Epoch 360/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5179 - val_loss: 1.5345
# Epoch 361/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5171 - val_loss: 1.5337
# Epoch 362/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5163 - val_loss: 1.5329
# Epoch 363/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5155 - val_loss: 1.5321
# Epoch 364/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5146 - val_loss: 1.5313
# Epoch 365/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5138 - val_loss: 1.5305
# Epoch 366/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5130 - val_loss: 1.5297
# Epoch 367/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5122 - val_loss: 1.5289
# Epoch 368/500
# 20/20 [==============================] - 0s 9ms/step - loss: 1.5113 - val_loss: 1.5281
# Epoch 369/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5105 - val_loss: 1.5273
# Epoch 370/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5097 - val_loss: 1.5264
# Epoch 371/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5088 - val_loss: 1.5256
# Epoch 372/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5080 - val_loss: 1.5248
# Epoch 373/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5071 - val_loss: 1.5239
# Epoch 374/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5062 - val_loss: 1.5231
# Epoch 375/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5054 - val_loss: 1.5222
# Epoch 376/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5045 - val_loss: 1.5214
# Epoch 377/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5036 - val_loss: 1.5205
# Epoch 378/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5027 - val_loss: 1.5196
# Epoch 379/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5018 - val_loss: 1.5188
# Epoch 380/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5009 - val_loss: 1.5179
# Epoch 381/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5000 - val_loss: 1.5170
# Epoch 382/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4991 - val_loss: 1.5161
# Epoch 383/500
# 20/20 [==============================] - 0s 9ms/step - loss: 1.4982 - val_loss: 1.5152
# Epoch 384/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4973 - val_loss: 1.5143
# Epoch 385/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.4964 - val_loss: 1.5134
# Epoch 386/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4954 - val_loss: 1.5125
# Epoch 387/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.4945 - val_loss: 1.5116
# Epoch 388/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4936 - val_loss: 1.5106
# Epoch 389/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4926 - val_loss: 1.5097
# Epoch 390/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4917 - val_loss: 1.5088
# Epoch 391/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4907 - val_loss: 1.5078
# Epoch 392/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4897 - val_loss: 1.5069
# Epoch 393/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4888 - val_loss: 1.5059
# Epoch 394/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4878 - val_loss: 1.5050
# Epoch 395/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4868 - val_loss: 1.5040
# Epoch 396/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4858 - val_loss: 1.5031
# Epoch 397/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4848 - val_loss: 1.5021
# Epoch 398/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4838 - val_loss: 1.5011
# Epoch 399/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4828 - val_loss: 1.5001
# Epoch 400/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4818 - val_loss: 1.4991
# Epoch 401/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4808 - val_loss: 1.4981
# Epoch 402/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4798 - val_loss: 1.4971
# Epoch 403/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4788 - val_loss: 1.4961
# Epoch 404/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4778 - val_loss: 1.4951
# Epoch 405/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4767 - val_loss: 1.4941
# Epoch 406/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4757 - val_loss: 1.4931
# Epoch 407/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4746 - val_loss: 1.4920
# Epoch 408/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4736 - val_loss: 1.4910
# Epoch 409/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4725 - val_loss: 1.4900
# Epoch 410/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4715 - val_loss: 1.4889
# Epoch 411/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4704 - val_loss: 1.4879
# Epoch 412/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.4693 - val_loss: 1.4868
# Epoch 413/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4682 - val_loss: 1.4858
# Epoch 414/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4671 - val_loss: 1.4847
# Epoch 415/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4661 - val_loss: 1.4836
# Epoch 416/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4650 - val_loss: 1.4825
# Epoch 417/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4638 - val_loss: 1.4815
# Epoch 418/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4627 - val_loss: 1.4804
# Epoch 419/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4616 - val_loss: 1.4793
# Epoch 420/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4605 - val_loss: 1.4782
# Epoch 421/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4594 - val_loss: 1.4771
# Epoch 422/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4582 - val_loss: 1.4759
# Epoch 423/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4571 - val_loss: 1.4748
# Epoch 424/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4560 - val_loss: 1.4737
# Epoch 425/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4548 - val_loss: 1.4726
# Epoch 426/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.4537 - val_loss: 1.4714
# Epoch 427/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4525 - val_loss: 1.4703
# Epoch 428/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4513 - val_loss: 1.4691
# Epoch 429/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4502 - val_loss: 1.4680
# Epoch 430/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4490 - val_loss: 1.4668
# Epoch 431/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4478 - val_loss: 1.4657
# Epoch 432/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4466 - val_loss: 1.4645
# Epoch 433/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4454 - val_loss: 1.4633
# Epoch 434/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4442 - val_loss: 1.4621
# Epoch 435/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4430 - val_loss: 1.4610
# Epoch 436/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4418 - val_loss: 1.4598
# Epoch 437/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4406 - val_loss: 1.4586
# Epoch 438/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4394 - val_loss: 1.4574
# Epoch 439/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4381 - val_loss: 1.4562
# Epoch 440/500
# 20/20 [==============================] - 0s 8ms/step - loss: 1.4369 - val_loss: 1.4549
# Epoch 441/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4356 - val_loss: 1.4537
# Epoch 442/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4344 - val_loss: 1.4525
# Epoch 443/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4331 - val_loss: 1.4513
# Epoch 444/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4319 - val_loss: 1.4500
# Epoch 445/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4306 - val_loss: 1.4488
# Epoch 446/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4294 - val_loss: 1.4475
# Epoch 447/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4281 - val_loss: 1.4463
# Epoch 448/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4268 - val_loss: 1.4450
# Epoch 449/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4255 - val_loss: 1.4437
# Epoch 450/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4242 - val_loss: 1.4425
# Epoch 451/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4229 - val_loss: 1.4412
# Epoch 452/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4216 - val_loss: 1.4399
# Epoch 453/500
# 20/20 [==============================] - 0s 8ms/step - loss: 1.4203 - val_loss: 1.4386
# Epoch 454/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4190 - val_loss: 1.4373
# Epoch 455/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4177 - val_loss: 1.4360
# Epoch 456/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4163 - val_loss: 1.4347
# Epoch 457/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4150 - val_loss: 1.4334
# Epoch 458/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4137 - val_loss: 1.4321
# Epoch 459/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4123 - val_loss: 1.4307
# Epoch 460/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.4110 - val_loss: 1.4294
# Epoch 461/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4096 - val_loss: 1.4281
# Epoch 462/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4082 - val_loss: 1.4267
# Epoch 463/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4069 - val_loss: 1.4254
# Epoch 464/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4055 - val_loss: 1.4240
# Epoch 465/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4041 - val_loss: 1.4227
# Epoch 466/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.4027 - val_loss: 1.4213
# Epoch 467/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4013 - val_loss: 1.4199
# Epoch 468/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4000 - val_loss: 1.4186
# Epoch 469/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3985 - val_loss: 1.4172
# Epoch 470/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3971 - val_loss: 1.4158
# Epoch 471/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.3957 - val_loss: 1.4144
# Epoch 472/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3943 - val_loss: 1.4130
# Epoch 473/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3929 - val_loss: 1.4116
# Epoch 474/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3915 - val_loss: 1.4102
# Epoch 475/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3900 - val_loss: 1.4088
# Epoch 476/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3886 - val_loss: 1.4074
# Epoch 477/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3871 - val_loss: 1.4060
# Epoch 478/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3857 - val_loss: 1.4045
# Epoch 479/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3842 - val_loss: 1.4031
# Epoch 480/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.3828 - val_loss: 1.4016
# Epoch 481/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.3813 - val_loss: 1.4002
# Epoch 482/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.3798 - val_loss: 1.3987
# Epoch 483/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.3784 - val_loss: 1.3973
# Epoch 484/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3769 - val_loss: 1.3958
# Epoch 485/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.3754 - val_loss: 1.3944
# Epoch 486/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3739 - val_loss: 1.3929
# Epoch 487/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3724 - val_loss: 1.3914
# Epoch 488/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3709 - val_loss: 1.3899
# Epoch 489/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3694 - val_loss: 1.3884
# Epoch 490/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3679 - val_loss: 1.3869
# Epoch 491/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3663 - val_loss: 1.3854
# Epoch 492/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3648 - val_loss: 1.3839
# Epoch 493/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.3633 - val_loss: 1.3824
# Epoch 494/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3617 - val_loss: 1.3809
# Epoch 495/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3602 - val_loss: 1.3794
# Epoch 496/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3586 - val_loss: 1.3779
# Epoch 497/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3571 - val_loss: 1.3763
# Epoch 498/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3555 - val_loss: 1.3748
# Epoch 499/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3540 - val_loss: 1.3732
# Epoch 500/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3524 - val_loss: 1.3717

# %% [markdown]
# ## Metrics

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
yhat = model.predict(testX)
print(yhat.shape)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
print(testX.shape)
inv_yhat = np.concatenate((testX, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat1 = inv_yhat[:, -3:]
inv_yhat = inv_yhat[:, -3]
inv_y = np.concatenate((testX, testY), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y1 = inv_y[:, -3:]
inv_y = inv_y[:, -3]
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
mae = mean_absolute_error(inv_y, inv_yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# 10/10 [==============================] - 0s 2ms/step
# (315, 9)
# (315, 157)
# Test RMSE: 7.961
# Test MAE: 7.431
