# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.5.3)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.8.1->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
from matplotlib import pyplot
from numpy import array

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Lotka Volterra Intermittency_

# %% [markdown]
# The `lotka_volterra_intermittency.dat` feeds the model with the dynamics of the Lotka Volterra Equations

# %%
data = np.genfromtxt('datasets/lotka_volterra_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 7 # Weekly Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 215.48740705
# 1        -1.540163e-03
# 2        -1.523369e-03
# 3        -1.506756e-03
# 4        -1.490327e-03
# 5        -1.474074e-03
#               ...
# 139867   -1.591086e-35
# 139868   -1.573887e-35
# 139869   -1.556877e-35
# 139870   -1.540049e-35
# 139871   -1.523404e-35
# Name: 1, Length: 139871, dtype: float64
# 2         2.399184e-06
# 3         2.373265e-06
# 4         2.346939e-06
# 5         2.321837e-06
# 6         2.296327e-06
#               ...
# 139867    2.483673e-38
# 139868    2.456939e-38
# 139869    2.430082e-38
# 139870    2.403980e-38
# 139871    2.377878e-38
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _SAN JUAN_

# %%
data = pd.read_csv("datasets/sanjuan.csv")
training_set = data.iloc[:, 3]
print(training_set)
# Out:
# 0        4
# 1        5
# 2        4
# 3        3
# 4        6
#         ..
# 1191    56
# 1192    46
# 1193    52
# 1194    34
# 1195    25
# Name: Cases, Length: 1196, dtype: int64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0        -1.540163e-03
# 1        -1.523369e-03
# 2        -1.506756e-03
# 3        -1.490327e-03
# 4        -1.474074e-03
#               ...
# 139866   -1.591086e-35
# 139867   -1.573887e-35
# 139868   -1.556877e-35
# 139869   -1.540049e-35
# 139870   -1.523404e-35
# Name: 1, Length: 139871, dtype: float64
# 0         2.399184e-06
# 1         2.373265e-06
# 2         2.346939e-06
# 3         2.321837e-06
# 4         2.296327e-06
#               ...
# 139865    2.483673e-38
# 139866    2.456939e-38
# 139867    2.430082e-38
# 139868    2.403980e-38
# 139869    2.377878e-38
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lotka Volterra Equation_)

# %%
a=0.1
b=0.05
c=1.1
d=0.1
L = df.iloc[:, 2] - a*a*df.iloc[:, 0] + 2*a*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*d*(df.iloc[:,0]**2)*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - c*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the data into supervised learning

# %%
def Supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
      cols.append(df.shift(-i))
      if i == 0:
        names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
      else:
        names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
       agg.dropna(inplace=True)
    return agg

# %%
dat = Supervised(df.values, n_in = 10, n_out = 52)
dat.columns
# Out:
# Index(['var1(t-10)', 'var2(t-10)', 'var3(t-10)', 'var1(t-9)', 'var2(t-9)',
#        'var3(t-9)', 'var1(t-8)', 'var2(t-8)', 'var3(t-8)', 'var1(t-7)',
#        ...
#        'var3(t+48)', 'var1(t+49)', 'var2(t+49)', 'var3(t+49)', 'var1(t+50)',
#        'var2(t+50)', 'var3(t+50)', 'var1(t+51)', 'var2(t+51)', 'var3(t+51)'],
#       dtype='object', length=186)

# %%
data = Supervised(df.values, n_in = 10, n_out = 52)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
       'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
       'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
       'var3(t-2)', 'var2(t-1)', 'var3(t-1)','var2(t-3)', 'var3(t-3)'], axis = 1, inplace = True)#,18,19
print(data.head())
print(data.columns)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10         4.0        5.0        4.0        3.0        6.0        2.0
# 11         5.0        4.0        3.0        6.0        2.0        4.0
# 12         4.0        3.0        6.0        2.0        4.0        5.0
# 13         3.0        6.0        2.0        4.0        5.0       10.0
# 14         6.0        2.0        4.0        5.0       10.0        6.0
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  ...  var3(t+48)  var1(t+49)  \
# 10        4.0        5.0       10.0        6.0  ...    0.000001        14.0
# 11        5.0       10.0        6.0        8.0  ...    0.000001        18.0
# 12       10.0        6.0        8.0        2.0  ...    0.000001        13.0
# 13        6.0        8.0        2.0        6.0  ...    0.000001        14.0
# 14        8.0        2.0        6.0       17.0  ...    0.000001        18.0
#
#     var2(t+49)  var3(t+49)  var1(t+50)  var2(t+50)  var3(t+50)  var1(t+51)  \
# 10   -0.000807    0.000001        18.0   -0.000798    0.000001        13.0
# 11   -0.000798    0.000001        13.0   -0.000789    0.000001        14.0
# 12   -0.000789    0.000001        14.0   -0.000780    0.000001        18.0
# 13   -0.000780    0.000001        18.0   -0.000772    0.000001        23.0
# 14   -0.000772    0.000001        23.0   -0.000764    0.000001        25.0
#
#     var2(t+51)  var3(t+51)
# 10   -0.000789    0.000001
# 11   -0.000780    0.000001
# 12   -0.000772    0.000001
# 13   -0.000764    0.000001
# 14   -0.000755    0.000001
#
# [5 rows x 166 columns]
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        ...
#        'var3(t+48)', 'var1(t+49)', 'var2(t+49)', 'var3(t+49)', 'var1(t+50)',
#        'var2(t+50)', 'var3(t+50)', 'var1(t+51)', 'var2(t+51)', 'var3(t+51)'],
#       dtype='object', length=166)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(data) * 0.8)
test_size = len(data) - train_size
train_1 = np.array(data[0:train_size])
test_1 = np.array(data[train_size:len(data)])
scaler = MinMaxScaler(feature_range=(0, 1))
train = scaler.fit_transform(train_1)
test = scaler.transform(test_1)
trainY = train[:,-9:]
trainX = train[:,:-9]
testY = test[:,-9:]
testX = test[:,:-9]
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (907, 1, 157) (907, 9) (227, 1, 157) (227, 9)

# %% [markdown]
# ## Defining the Physical Loss

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] - a*a*y_true[:, 0] + 2*a*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*d*(y_true[:,0]**2)*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - c*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))), (y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] - a*a*y_pred[:-2] + 2*a*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*d*(y_pred[:-2]**2)*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - c*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] - a*a*y_real[:-2] + 2*a*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*d*(y_real[:-2]**2)*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - c*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model (Without Monte Carlo Dropout)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square(y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(9))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX[:int(0.8*trainX.shape[0])], trainY[:int(0.8*trainX.shape[0])], epochs=500, batch_size=64, validation_data=(trainX[int(0.8*trainX.shape[0]):trainX.shape[0]], trainY[int(0.8*trainX.shape[0]):trainX.shape[0]]), shuffle=False)
# Out:
# Epoch 1/500
# 12/12 [==============================] - 3s 52ms/step - loss: 0.2053 - val_loss: 0.2433
# Epoch 2/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3752 - val_loss: 0.3350
# Epoch 3/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4527 - val_loss: 0.3507
# Epoch 4/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4630 - val_loss: 0.3382
# Epoch 5/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4503 - val_loss: 0.3189
# Epoch 6/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4328 - val_loss: 0.3005
# Epoch 7/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4161 - val_loss: 0.2846
# Epoch 8/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4014 - val_loss: 0.2706
# Epoch 9/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3880 - val_loss: 0.2578
# Epoch 10/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3756 - val_loss: 0.2457
# Epoch 11/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3637 - val_loss: 0.2340
# Epoch 12/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3522 - val_loss: 0.2227
# Epoch 13/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3409 - val_loss: 0.2116
# Epoch 14/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3299 - val_loss: 0.2008
# Epoch 15/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3192 - val_loss: 0.1903
# Epoch 16/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3086 - val_loss: 0.1800
# Epoch 17/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2984 - val_loss: 0.1701
# Epoch 18/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2883 - val_loss: 0.1604
# Epoch 19/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2786 - val_loss: 0.1511
# Epoch 20/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2691 - val_loss: 0.1421
# Epoch 21/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2599 - val_loss: 0.1334
# Epoch 22/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2510 - val_loss: 0.1251
# Epoch 23/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2424 - val_loss: 0.1171
# Epoch 24/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2341 - val_loss: 0.1095
# Epoch 25/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2262 - val_loss: 0.1023
# Epoch 26/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2185 - val_loss: 0.0954
# Epoch 27/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2111 - val_loss: 0.0889
# Epoch 28/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2041 - val_loss: 0.0827
# Epoch 29/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1974 - val_loss: 0.0769
# Epoch 30/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1910 - val_loss: 0.0715
# Epoch 31/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1849 - val_loss: 0.0664
# Epoch 32/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1792 - val_loss: 0.0616
# Epoch 33/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1737 - val_loss: 0.0573
# Epoch 34/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1686 - val_loss: 0.0532
# Epoch 35/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1637 - val_loss: 0.0495
# Epoch 36/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1592 - val_loss: 0.0460
# Epoch 37/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1549 - val_loss: 0.0429
# Epoch 38/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1509 - val_loss: 0.0401
# Epoch 39/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1471 - val_loss: 0.0375
# Epoch 40/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1436 - val_loss: 0.0351
# Epoch 41/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1403 - val_loss: 0.0330
# Epoch 42/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1371 - val_loss: 0.0310
# Epoch 43/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1342 - val_loss: 0.0293
# Epoch 44/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1314 - val_loss: 0.0278
# Epoch 45/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1288 - val_loss: 0.0264
# Epoch 46/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1263 - val_loss: 0.0252
# Epoch 47/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1240 - val_loss: 0.0243
# Epoch 48/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1218 - val_loss: 0.0235
# Epoch 49/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1197 - val_loss: 0.0231
# Epoch 50/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1177 - val_loss: 0.0232
# Epoch 51/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1158 - val_loss: 0.0241
# Epoch 52/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1140 - val_loss: 0.0271
# Epoch 53/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1123 - val_loss: 0.0406
# Epoch 54/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1107 - val_loss: 0.6599
# Epoch 55/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1093 - val_loss: 0.7512
# Epoch 56/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1081 - val_loss: 0.2320
# Epoch 57/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1070 - val_loss: 0.0977
# Epoch 58/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1061 - val_loss: 3.3020
# Epoch 59/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1053 - val_loss: 0.1967
# Epoch 60/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1045 - val_loss: 0.0526
# Epoch 61/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1039 - val_loss: 0.0440
# Epoch 62/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1054 - val_loss: 0.0129
# Epoch 63/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1312 - val_loss: 0.1525
# Epoch 64/500
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2548 - val_loss: 1.6913
# Epoch 65/500
# 12/12 [==============================] - 0s 5ms/step - loss: 3.3050 - val_loss: 3.3351
# Epoch 66/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.4656 - val_loss: 3.8568
# Epoch 67/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8091 - val_loss: 4.0079
# Epoch 68/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9068 - val_loss: 4.0502
# Epoch 69/500
# 12/12 [==============================] - 0s 6ms/step - loss: 4.9337 - val_loss: 4.0613
# Epoch 70/500
# 12/12 [==============================] - 0s 6ms/step - loss: 4.9403 - val_loss: 4.0634
# Epoch 71/500
# 12/12 [==============================] - 0s 7ms/step - loss: 4.9410 - val_loss: 4.0630
# Epoch 72/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9401 - val_loss: 4.0618
# Epoch 73/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9387 - val_loss: 4.0604
# Epoch 74/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9371 - val_loss: 4.0589
# Epoch 75/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9355 - val_loss: 4.0574
# Epoch 76/500
# 12/12 [==============================] - 0s 10ms/step - loss: 4.9339 - val_loss: 4.0559
# Epoch 77/500
# 12/12 [==============================] - 0s 6ms/step - loss: 4.9322 - val_loss: 4.0544
# Epoch 78/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9305 - val_loss: 4.0528
# Epoch 79/500
# 12/12 [==============================] - 0s 7ms/step - loss: 4.9289 - val_loss: 4.0513
# Epoch 80/500
# 12/12 [==============================] - 0s 6ms/step - loss: 4.9272 - val_loss: 4.0497
# Epoch 81/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9254 - val_loss: 4.0481
# Epoch 82/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9237 - val_loss: 4.0465
# Epoch 83/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9220 - val_loss: 4.0448
# Epoch 84/500
# 12/12 [==============================] - 0s 6ms/step - loss: 4.9202 - val_loss: 4.0432
# Epoch 85/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9184 - val_loss: 4.0415
# Epoch 86/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9166 - val_loss: 4.0399
# Epoch 87/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9148 - val_loss: 4.0382
# Epoch 88/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9130 - val_loss: 4.0365
# Epoch 89/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9112 - val_loss: 4.0348
# Epoch 90/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9093 - val_loss: 4.0330
# Epoch 91/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9074 - val_loss: 4.0313
# Epoch 92/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9056 - val_loss: 4.0295
# Epoch 93/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9037 - val_loss: 4.0278
# Epoch 94/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9018 - val_loss: 4.0260
# Epoch 95/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8998 - val_loss: 4.0242
# Epoch 96/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8979 - val_loss: 4.0224
# Epoch 97/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8959 - val_loss: 4.0205
# Epoch 98/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8939 - val_loss: 4.0187
# Epoch 99/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8919 - val_loss: 4.0168
# Epoch 100/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8899 - val_loss: 4.0150
# Epoch 101/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8879 - val_loss: 4.0131
# Epoch 102/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8859 - val_loss: 4.0112
# Epoch 103/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8838 - val_loss: 4.0092
# Epoch 104/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8817 - val_loss: 4.0073
# Epoch 105/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8797 - val_loss: 4.0054
# Epoch 106/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8776 - val_loss: 4.0034
# Epoch 107/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8754 - val_loss: 4.0014
# Epoch 108/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8733 - val_loss: 3.9994
# Epoch 109/500
# 12/12 [==============================] - 0s 6ms/step - loss: 4.8712 - val_loss: 3.9974
# Epoch 110/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8690 - val_loss: 3.9954
# Epoch 111/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8668 - val_loss: 3.9934
# Epoch 112/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8646 - val_loss: 3.9913
# Epoch 113/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8624 - val_loss: 3.9892
# Epoch 114/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8601 - val_loss: 3.9871
# Epoch 115/500
# 12/12 [==============================] - 0s 10ms/step - loss: 4.8579 - val_loss: 3.9850
# Epoch 116/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8556 - val_loss: 3.9829
# Epoch 117/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8533 - val_loss: 3.9808
# Epoch 118/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8511 - val_loss: 3.9787
# Epoch 119/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8487 - val_loss: 3.9765
# Epoch 120/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8464 - val_loss: 3.9743
# Epoch 121/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8441 - val_loss: 3.9721
# Epoch 122/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8417 - val_loss: 3.9699
# Epoch 123/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8393 - val_loss: 3.9677
# Epoch 124/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8369 - val_loss: 3.9655
# Epoch 125/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8345 - val_loss: 3.9632
# Epoch 126/500
# 12/12 [==============================] - 0s 5ms/step - loss: 4
# Epoch 488/500
# 12/12 [==============================] - 0s 6ms/step - loss: 2.6837 - val_loss: 2.0107
# Epoch 489/500
# 12/12 [==============================] - 0s 6ms/step - loss: 2.6748 - val_loss: 2.0029
# Epoch 490/500
# 12/12 [==============================] - 0s 12ms/step - loss: 2.6659 - val_loss: 1.9951
# Epoch 491/500
# 12/12 [==============================] - 0s 7ms/step - loss: 2.6570 - val_loss: 1.9874
# Epoch 492/500
# 12/12 [==============================] - 0s 7ms/step - loss: 2.6482 - val_loss: 1.9796
# Epoch 493/500
# 12/12 [==============================] - 0s 7ms/step - loss: 2.6393 - val_loss: 1.9719
# Epoch 494/500
# 12/12 [==============================] - 0s 7ms/step - loss: 2.6304 - val_loss: 1.9641
# Epoch 495/500
# 12/12 [==============================] - 0s 8ms/step - loss: 2.6215 - val_loss: 1.9563
# Epoch 496/500
# 12/12 [==============================] - 0s 8ms/step - loss: 2.6126 - val_loss: 1.9486
# Epoch 497/500
# 12/12 [==============================] - 0s 9ms/step - loss: 2.6037 - val_loss: 1.9408
# Epoch 498/500
# 12/12 [==============================] - 0s 7ms/step - loss: 2.5947 - val_loss: 1.9331
# Epoch 499/500
# 12/12 [==============================] - 0s 7ms/step - loss: 2.5858 - val_loss: 1.9253
# Epoch 500/500
# 12/12 [==============================] - 0s 6ms/step - loss: 2.5769 - val_loss: 1.9176

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ## Metrics (Without Monte Carlo Dropout)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
textX_without_mc = testX
textY_without_mc = testY
yhat_without_mc = model.predict(textX_without_mc)
print(yhat_without_mc.shape)
textX_without_mc = textX_without_mc.reshape((textX_without_mc.shape[0], textX_without_mc.shape[2]))
print(textX_without_mc.shape)
inv_yhat_without_mc = np.concatenate((textX_without_mc, yhat_without_mc), axis=1)
inv_yhat_without_mc = scaler.inverse_transform(inv_yhat_without_mc)
inv_yhat1_without_mc = inv_yhat_without_mc[:, -3:]
inv_yhat_without_mc = inv_yhat_without_mc[:, -3]
inv_y_without_mc = np.concatenate((textX_without_mc, textY_without_mc), axis=1)
inv_y_without_mc = scaler.inverse_transform(inv_y_without_mc)
inv_y1_without_mc = inv_y_without_mc[:, -3:]
inv_y_without_mc = inv_y_without_mc[:, -3]
rmse_without_mc = np.sqrt(mean_squared_error(inv_y_without_mc, inv_yhat_without_mc))
mae_without_mc = mean_absolute_error(inv_y_without_mc, inv_yhat_without_mc)
print('Test RMSE: %.3f' % rmse_without_mc)
print('Test MAE: %.3f' % mae_without_mc)
# Out:
# 8/8 [==============================] - 0s 1ms/step
# (227, 9)
# (227, 157)
# Test RMSE: 262.985
# Test MAE: 254.141

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y_without_mc, marker='.', label="actual")
plt.plot(inv_yhat_without_mc, 'r', label="prediction")
plt.suptitle('San Juan Dengue Spread', fontsize=20)
plt.legend(fontsize=20)
plt.show()
