# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.6)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.8.1->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
from matplotlib import pyplot
from numpy import array

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Lotka Volterra Intermittency_

# %% [markdown]
# The `lotka_volterra_intermittency.dat` feeds the model with the dynamics of the Lotka Volterra Equations

# %%
data = np.genfromtxt('datasets/lotka_volterra_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 7 # Weekly Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 215.48740705
# 1        -1.540163e-03
# 2        -1.523369e-03
# 3        -1.506756e-03
# 4        -1.490327e-03
# 5        -1.474074e-03
#               ...
# 139867   -1.591086e-35
# 139868   -1.573887e-35
# 139869   -1.556877e-35
# 139870   -1.540049e-35
# 139871   -1.523404e-35
# Name: 1, Length: 139871, dtype: float64
# 2         2.399184e-06
# 3         2.373265e-06
# 4         2.346939e-06
# 5         2.321837e-06
# 6         2.296327e-06
#               ...
# 139867    2.483673e-38
# 139868    2.456939e-38
# 139869    2.430082e-38
# 139870    2.403980e-38
# 139871    2.377878e-38
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _EL NINO_

# %%
data = pd.read_csv("datasets/elnino.csv")
training_set = data.iloc[:,1]
print(training_set)
# Out:
# 0       23.4
# 1       23.4
# 2       24.2
# 3       24.4
# 4       25.1
#         ...
# 1629    25.4
# 1630    24.9
# 1631    25.3
# 1632    24.7
# 1633    24.6
# Name: SST1, Length: 1634, dtype: float64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0        -1.540163e-03
# 1        -1.523369e-03
# 2        -1.506756e-03
# 3        -1.490327e-03
# 4        -1.474074e-03
#               ...
# 139866   -1.591086e-35
# 139867   -1.573887e-35
# 139868   -1.556877e-35
# 139869   -1.540049e-35
# 139870   -1.523404e-35
# Name: 1, Length: 139871, dtype: float64
# 0         2.399184e-06
# 1         2.373265e-06
# 2         2.346939e-06
# 3         2.321837e-06
# 4         2.296327e-06
#               ...
# 139865    2.483673e-38
# 139866    2.456939e-38
# 139867    2.430082e-38
# 139868    2.403980e-38
# 139869    2.377878e-38
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lotka Volterra Equation_)

# %%
a=0.1
b=0.05
c=1.1
d=0.1
L = df.iloc[:, 2] - a*a*df.iloc[:, 0] + 2*a*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*d*(df.iloc[:,0]**2)*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - c*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the data into supervised learning

# %%
def Supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
      cols.append(df.shift(-i))
      if i == 0:
        names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
      else:
        names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
       agg.dropna(inplace=True)
    return agg

# %%
dat = Supervised(df.values, n_in = 10, n_out = 52)
dat.columns
# Out:
# Index(['var1(t-10)', 'var2(t-10)', 'var3(t-10)', 'var1(t-9)', 'var2(t-9)',
#        'var3(t-9)', 'var1(t-8)', 'var2(t-8)', 'var3(t-8)', 'var1(t-7)',
#        ...
#        'var3(t+48)', 'var1(t+49)', 'var2(t+49)', 'var3(t+49)', 'var1(t+50)',
#        'var2(t+50)', 'var3(t+50)', 'var1(t+51)', 'var2(t+51)', 'var3(t+51)'],
#       dtype='object', length=186)

# %%
data = Supervised(df.values, n_in = 10, n_out = 52)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
       'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
       'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
       'var3(t-2)', 'var2(t-1)', 'var3(t-1)','var2(t-3)', 'var3(t-3)'], axis = 1, inplace = True)#,18,19
print(data.head())
print(data.columns)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10        23.4       23.4       24.2       24.4       25.1       25.8
# 11        23.4       24.2       24.4       25.1       25.8       25.9
# 12        24.2       24.4       25.1       25.8       25.9       26.1
# 13        24.4       25.1       25.8       25.9       26.1       26.1
# 14        25.1       25.8       25.9       26.1       26.1       26.7
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  ...  var3(t+48)  var1(t+49)  \
# 10       25.9       26.1       26.1       26.7  ...    0.000001        26.5
# 11       26.1       26.1       26.7       26.1  ...    0.000001        26.5
# 12       26.1       26.7       26.1       26.1  ...    0.000001        26.5
# 13       26.7       26.1       26.1       25.7  ...    0.000001        26.8
# 14       26.1       26.1       25.7       25.6  ...    0.000001        26.6
#
#     var2(t+49)  var3(t+49)  var1(t+50)  var2(t+50)  var3(t+50)  var1(t+51)  \
# 10   -0.000807    0.000001        26.5   -0.000798    0.000001        26.5
# 11   -0.000798    0.000001        26.5   -0.000789    0.000001        26.8
# 12   -0.000789    0.000001        26.8   -0.000780    0.000001        26.6
# 13   -0.000780    0.000001        26.6   -0.000772    0.000001        26.2
# 14   -0.000772    0.000001        26.2   -0.000764    0.000001        25.8
#
#     var2(t+51)  var3(t+51)
# 10   -0.000789    0.000001
# 11   -0.000780    0.000001
# 12   -0.000772    0.000001
# 13   -0.000764    0.000001
# 14   -0.000755    0.000001
#
# [5 rows x 166 columns]
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        ...
#        'var3(t+48)', 'var1(t+49)', 'var2(t+49)', 'var3(t+49)', 'var1(t+50)',
#        'var2(t+50)', 'var3(t+50)', 'var1(t+51)', 'var2(t+51)', 'var3(t+51)'],
#       dtype='object', length=166)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(data) * 0.8)
test_size = len(data) - train_size
train_1 = np.array(data[0:train_size])
test_1 = np.array(data[train_size:len(data)])
scaler = MinMaxScaler(feature_range=(0, 1))
train = scaler.fit_transform(train_1)
test = scaler.transform(test_1)
trainY = train[:,-9:]
trainX = train[:,:-9]
testY = test[:,-9:]
testX = test[:,:-9]
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (1257, 1, 157) (1257, 9) (315, 1, 157) (315, 9)

# %% [markdown]
# ## Defining the Physical Loss

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] - a*a*y_true[:, 0] + 2*a*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*d*(y_true[:,0]**2)*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - c*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))), (y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] - a*a*y_pred[:-2] + 2*a*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*d*(y_pred[:-2]**2)*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - c*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] - a*a*y_real[:-2] + 2*a*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*d*(y_real[:-2]**2)*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - c*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model (Without Monte Carlo Dropout)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square(y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(9))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX[:int(0.8*trainX.shape[0])], trainY[:int(0.8*trainX.shape[0])], epochs=500, batch_size=64, validation_data=(trainX[int(0.8*trainX.shape[0]):trainX.shape[0]], trainY[int(0.8*trainX.shape[0]):trainX.shape[0]]), shuffle=False)
# Out:
# Epoch 1/500
# 16/16 [==============================] - 4s 50ms/step - loss: 0.0776 - val_loss: 0.0617
# Epoch 2/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0489 - val_loss: 0.0267
# Epoch 3/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0377 - val_loss: 0.0230
# Epoch 4/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0311 - val_loss: 0.0187
# Epoch 5/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0286 - val_loss: 0.0155
# Epoch 6/500
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0245 - val_loss: 0.0128
# Epoch 7/500
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0217 - val_loss: 0.0108
# Epoch 8/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0193 - val_loss: 0.0094
# Epoch 9/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0174 - val_loss: 0.0084
# Epoch 10/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0160 - val_loss: 0.0078
# Epoch 11/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0148 - val_loss: 0.0074
# Epoch 12/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0139 - val_loss: 0.0071
# Epoch 13/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0132 - val_loss: 0.0069
# Epoch 14/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0125 - val_loss: 0.0067
# Epoch 15/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0120 - val_loss: 0.0065
# Epoch 16/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0115 - val_loss: 0.0063
# Epoch 17/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0111 - val_loss: 0.0062
# Epoch 18/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0107 - val_loss: 0.0060
# Epoch 19/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0103 - val_loss: 0.0058
# Epoch 20/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0100 - val_loss: 0.0057
# Epoch 21/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0097 - val_loss: 0.0055
# Epoch 22/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0094 - val_loss: 0.0054
# Epoch 23/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0091 - val_loss: 0.0052
# Epoch 24/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0051
# Epoch 25/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0085 - val_loss: 0.0050
# Epoch 26/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0082 - val_loss: 0.0048
# Epoch 27/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 0.0047
# Epoch 28/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0076 - val_loss: 0.0045
# Epoch 29/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0073 - val_loss: 0.0044
# Epoch 30/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0071 - val_loss: 0.0043
# Epoch 31/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0068 - val_loss: 0.0042
# Epoch 32/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0040
# Epoch 33/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.0039
# Epoch 34/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0061 - val_loss: 0.0038
# Epoch 35/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.0037
# Epoch 36/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 0.0036
# Epoch 37/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0055 - val_loss: 0.0035
# Epoch 38/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 39/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0051 - val_loss: 0.0033
# Epoch 40/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0033
# Epoch 41/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0032
# Epoch 42/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.0031
# Epoch 43/500
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0044 - val_loss: 0.0030
# Epoch 44/500
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0043 - val_loss: 0.0029
# Epoch 45/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0029
# Epoch 46/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0028
# Epoch 47/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0027
# Epoch 48/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0038 - val_loss: 0.0027
# Epoch 49/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 50/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 51/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 52/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 53/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 54/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 55/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 56/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0027
# Epoch 57/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0036 - val_loss: 0.0027
# Epoch 58/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0027
# Epoch 59/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0036 - val_loss: 0.0028
# Epoch 60/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0036 - val_loss: 0.0028
# Epoch 61/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0028
# Epoch 62/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 63/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 64/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 65/500
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 66/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 67/500
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 68/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 69/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0038 - val_loss: 0.0032
# Epoch 70/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 0.0032
# Epoch 71/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0032
# Epoch 72/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0032
# Epoch 73/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0032
# Epoch 74/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0032
# Epoch 75/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0032
# Epoch 76/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0031
# Epoch 77/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0029
# Epoch 78/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0027
# Epoch 79/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0063 - val_loss: 0.0024
# Epoch 80/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0068 - val_loss: 0.0023
# Epoch 81/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0072 - val_loss: 0.0024
# Epoch 82/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0073 - val_loss: 0.0030
# Epoch 83/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0069 - val_loss: 0.0039
# Epoch 84/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0062 - val_loss: 0.0045
# Epoch 85/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0047
# Epoch 86/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 87/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0041
# Epoch 88/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0037
# Epoch 89/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 90/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 91/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 92/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 93/500
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 94/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 95/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 96/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 97/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 98/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 99/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 100/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0021
# Epoch 101/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0021
# Epoch 102/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 103/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0021
# Epoch 104/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0021
# Epoch 105/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 106/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 107/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 108/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0035 - val_loss: 0.0020
# Epoch 109/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0020
# Epoch 110/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0020
# Epoch 111/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0020
# Epoch 112/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 113/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0022
# Epoch 114/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0024
# Epoch 115/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0026
# Epoch 116/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0028
# Epoch 117/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0030
# Epoch 118/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 119/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 120/500
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 121/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 122/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 123/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 124/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 125/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 126/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 127/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 128/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 129/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 130/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 131/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 132/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 133/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 134/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 135/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 136/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 137/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 138/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 139/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0020
# Epoch 140/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0020
# Epoch 141/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0020
# Epoch 142/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0020
# Epoch 143/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 144/500
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 145/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 146/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 147/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 148/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 149/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 150/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0028
# Epoch 151/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 152/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 153/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 154/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 155/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 156/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 157/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 158/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 159/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 160/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 161/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 162/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 163/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 164/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 165/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 166/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 167/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 168/500
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 169/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 170/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 171/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 172/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 0.0019
# Epoch 173/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 174/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 175/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 176/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 177/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 178/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0022
# Epoch 179/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 180/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 181/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 182/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0026
# Epoch 183/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 184/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 185/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 186/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 187/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 188/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 189/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 190/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 191/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 192/500
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 193/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 194/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 195/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 196/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 197/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 198/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 199/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 200/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 201/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 202/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 203/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 204/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 205/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 206/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 207/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 208/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 209/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 210/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 211/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0018
# Epoch 212/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0019
# Epoch 213/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0019
# Epoch 214/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 215/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 216/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0022
# Epoch 217/500
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 218/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 219/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0028
# Epoch 220/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 221/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 222/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 223/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 224/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0029
# Epoch 225/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0028
# Epoch 226/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0028
# Epoch 227/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 228/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 229/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 230/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 231/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 232/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 233/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 234/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 235/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 236/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 237/500
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 238/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 239/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 240/500
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 241/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 242/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 243/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 244/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 245/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 246/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 247/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 248/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 249/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 250/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 251/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 252/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 253/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 254/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 255/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 256/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 257/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 258/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 259/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 260/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 261/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 262/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 263/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 264/500
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 265/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 266/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 267/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 268/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 269/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 270/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 271/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 272/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 273/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 274/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 275/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 276/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 277/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 278/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 279/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 280/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 281/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 282/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 283/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 284/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 285/500
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 286/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 287/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 288/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 289/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 290/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 291/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 292/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0018
# Epoch 293/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0072 - val_loss: 0.0035
# Epoch 294/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0074 - val_loss: 0.0069
# Epoch 295/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0068 - val_loss: 0.0077
# Epoch 296/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0892
# Epoch 297/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 0.0042
# Epoch 298/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0031
# Epoch 299/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0023
# Epoch 300/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0019
# Epoch 301/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 302/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0018
# Epoch 303/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0019
# Epoch 304/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0018
# Epoch 305/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0018
# Epoch 306/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 307/500
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 308/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 309/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 310/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 311/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 312/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 313/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 314/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 315/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 316/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 317/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 318/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 319/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 320/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 321/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 322/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 323/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 324/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 325/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 326/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 327/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 328/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 329/500
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 330/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 331/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 332/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 333/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 334/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 335/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 336/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 337/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 338/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 339/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 340/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 341/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 342/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 343/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 344/500
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 345/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 346/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 347/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 348/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 349/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 350/500
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 351/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 352/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 353/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 354/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 355/500
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 356/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 357/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 358/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 359/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 360/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 361/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 362/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 363/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 364/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 365/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 366/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 367/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 368/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 369/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 370/500
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 371/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 372/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 373/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 374/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 375/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 376/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 377/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 378/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0038 - val_loss: 0.0017
# Epoch 379/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0019
# Epoch 380/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0051 - val_loss: 0.0017
# Epoch 381/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0017
# Epoch 382/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 383/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 384/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 385/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 386/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 387/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 388/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 389/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 390/500
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 391/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 392/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 393/500
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 394/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 395/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 396/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 397/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 398/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 399/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 400/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 401/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 402/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 403/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 404/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 405/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 406/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 407/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 408/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 409/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 410/500
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 411/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 412/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 413/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 414/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 415/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 416/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 417/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 418/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 419/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 420/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 421/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 422/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 423/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 424/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 425/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 426/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 427/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 428/500
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 429/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 430/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 431/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 432/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 433/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0022
# Epoch 434/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 435/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0018
# Epoch 436/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 437/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 438/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 439/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 440/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 441/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 442/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 443/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 444/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 445/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 446/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 447/500
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 448/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 449/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 450/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 451/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 452/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 453/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 454/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 455/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 456/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 457/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 458/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 459/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 460/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 461/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 462/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 463/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 464/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 465/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 466/500
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 467/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 468/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 469/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 470/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 471/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 472/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0016
# Epoch 473/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 474/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 475/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 476/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 477/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 478/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 479/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 480/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 481/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 482/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 483/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 484/500
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 485/500
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 486/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 487/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 488/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 489/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 490/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 491/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 492/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 493/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 494/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 495/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 496/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 497/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 498/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 499/500
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 500/500
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0015

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ## Metrics (Without Monte Carlo Dropout)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
textX_without_mc = testX
textY_without_mc = testY
yhat_without_mc = model.predict(textX_without_mc)
print(yhat_without_mc.shape)
textX_without_mc = textX_without_mc.reshape((textX_without_mc.shape[0], textX_without_mc.shape[2]))
print(textX_without_mc.shape)
inv_yhat_without_mc = np.concatenate((textX_without_mc, yhat_without_mc), axis=1)
inv_yhat_without_mc = scaler.inverse_transform(inv_yhat_without_mc)
inv_yhat1_without_mc = inv_yhat_without_mc[:, -3:]
inv_yhat_without_mc = inv_yhat_without_mc[:, -3]
inv_y_without_mc = np.concatenate((textX_without_mc, textY_without_mc), axis=1)
inv_y_without_mc = scaler.inverse_transform(inv_y_without_mc)
inv_y1_without_mc = inv_y_without_mc[:, -3:]
inv_y_without_mc = inv_y_without_mc[:, -3]
rmse_without_mc = np.sqrt(mean_squared_error(inv_y_without_mc, inv_yhat_without_mc))
mae_without_mc = mean_absolute_error(inv_y_without_mc, inv_yhat_without_mc)
print('Test RMSE: %.3f' % rmse_without_mc)
print('Test MAE: %.3f' % mae_without_mc)
# Out:
# 10/10 [==============================] - 0s 1ms/step
# (315, 9)
# (315, 157)
# Test RMSE: 6.911
# Test MAE: 6.203

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y_without_mc, marker='.', label="actual")
plt.plot(inv_yhat_without_mc, 'r', label="prediction")
plt.suptitle('El Niño Sea Surface Temperature', fontsize=20)
plt.legend(fontsize=20)
plt.show()
