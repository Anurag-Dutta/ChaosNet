# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.5.3)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.8.1->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
from matplotlib import pyplot
from numpy import array

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Lotka Volterra Intermittency_

# %% [markdown]
# The `lotka_volterra_intermittency.dat` feeds the model with the dynamics of the Lotka Volterra Equations

# %%
data = np.genfromtxt('datasets/lotka_volterra_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 0.04166666666666666666666666666667 # Hourly Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 215.48740705
# 1        -1.540163e-03
# 2        -1.523369e-03
# 3        -1.506756e-03
# 4        -1.490327e-03
# 5        -1.474074e-03
#               ...
# 139867   -1.591086e-35
# 139868   -1.573887e-35
# 139869   -1.556877e-35
# 139870   -1.540049e-35
# 139871   -1.523404e-35
# Name: 1, Length: 139871, dtype: float64
# 2         2.399184e-06
# 3         2.373265e-06
# 4         2.346939e-06
# 5         2.321837e-06
# 6         2.296327e-06
#               ...
# 139867    2.483673e-38
# 139868    2.456939e-38
# 139869    2.430082e-38
# 139870    2.403980e-38
# 139871    2.377878e-38
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _KYOTO DST_

# %%
data = pd.read_csv("datasets/dst.csv")
training_set = data.iloc[:, 1]
print(training_set)
# Out:
# 0       4.4
# 1       5.2
# 2       4.8
# 3       4.4
# 4       5.7
#        ...
# 6569    4.5
# 6570    4.0
# 6571    4.4
# 6572    4.1
# 6573    4.0
# Name: Magnitude, Length: 6574, dtype: float64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0        -1.540163e-03
# 1        -1.523369e-03
# 2        -1.506756e-03
# 3        -1.490327e-03
# 4        -1.474074e-03
#               ...
# 139866   -1.591086e-35
# 139867   -1.573887e-35
# 139868   -1.556877e-35
# 139869   -1.540049e-35
# 139870   -1.523404e-35
# Name: 1, Length: 139871, dtype: float64
# 0         2.399184e-06
# 1         2.373265e-06
# 2         2.346939e-06
# 3         2.321837e-06
# 4         2.296327e-06
#               ...
# 139865    2.483673e-38
# 139866    2.456939e-38
# 139867    2.430082e-38
# 139868    2.403980e-38
# 139869    2.377878e-38
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lotka Volterra Equation_)

# %%
a=0.1
b=0.05
c=1.1
d=0.1
L = df.iloc[:, 2] - a*a*df.iloc[:, 0] + 2*a*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*d*(df.iloc[:,0]**2)*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - c*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the data into supervised learning

# %%
def Supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
      cols.append(df.shift(-i))
      if i == 0:
        names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
      else:
        names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
       agg.dropna(inplace=True)
    return agg

# %%
dat = Supervised(df.values, n_in = 10, n_out = 52)
dat.columns
# Out:
# Index(['var1(t-10)', 'var2(t-10)', 'var3(t-10)', 'var1(t-9)', 'var2(t-9)',
#        'var3(t-9)', 'var1(t-8)', 'var2(t-8)', 'var3(t-8)', 'var1(t-7)',
#        ...
#        'var3(t+48)', 'var1(t+49)', 'var2(t+49)', 'var3(t+49)', 'var1(t+50)',
#        'var2(t+50)', 'var3(t+50)', 'var1(t+51)', 'var2(t+51)', 'var3(t+51)'],
#       dtype='object', length=186)

# %%
data = Supervised(df.values, n_in = 10, n_out = 52)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
       'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
       'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
       'var3(t-2)', 'var2(t-1)', 'var3(t-1)','var2(t-3)', 'var3(t-3)'], axis = 1, inplace = True)#,18,19
print(data.head())
print(data.columns)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10         4.4        5.2        4.8        4.4        5.7        4.3
# 11         5.2        4.8        4.4        5.7        4.3        4.0
# 12         4.8        4.4        5.7        4.3        4.0        4.8
# 13         4.4        5.7        4.3        4.0        4.8        5.2
# 14         5.7        4.3        4.0        4.8        5.2        5.1
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  ...  var3(t+48)  var1(t+49)  \
# 10        4.0        4.8        5.2        5.1  ...    0.000001         4.4
# 11        4.8        5.2        5.1        4.7  ...    0.000001         5.9
# 12        5.2        5.1        4.7        4.6  ...    0.000001         4.7
# 13        5.1        4.7        4.6        4.4  ...    0.000001         4.4
# 14        4.7        4.6        4.4        4.7  ...    0.000001         5.0
#
#     var2(t+49)  var3(t+49)  var1(t+50)  var2(t+50)  var3(t+50)  var1(t+51)  \
# 10   -0.000807    0.000001         5.9   -0.000798    0.000001         4.7
# 11   -0.000798    0.000001         4.7   -0.000789    0.000001         4.4
# 12   -0.000789    0.000001         4.4   -0.000780    0.000001         5.0
# 13   -0.000780    0.000001         5.0   -0.000772    0.000001         5.5
# 14   -0.000772    0.000001         5.5   -0.000764    0.000001         4.4
#
#     var2(t+51)  var3(t+51)
# 10   -0.000789    0.000001
# 11   -0.000780    0.000001
# 12   -0.000772    0.000001
# 13   -0.000764    0.000001
# 14   -0.000755    0.000001
#
# [5 rows x 166 columns]
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        ...
#        'var3(t+48)', 'var1(t+49)', 'var2(t+49)', 'var3(t+49)', 'var1(t+50)',
#        'var2(t+50)', 'var3(t+50)', 'var1(t+51)', 'var2(t+51)', 'var3(t+51)'],
#       dtype='object', length=166)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(data) * 0.8)
test_size = len(data) - train_size
train_1 = np.array(data[0:train_size])
test_1 = np.array(data[train_size:len(data)])
scaler = MinMaxScaler(feature_range=(0, 1))
train = scaler.fit_transform(train_1)
test = scaler.transform(test_1)
trainY = train[:,-9:]
trainX = train[:,:-9]
testY = test[:,-9:]
testX = test[:,:-9]
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (5209, 1, 157) (5209, 9) (1303, 1, 157) (1303, 9)

# %% [markdown]
# ## Defining the Physical Loss

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] - a*a*y_true[:, 0] + 2*a*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*d*(y_true[:,0]**2)*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - c*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))), (y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] - a*a*y_pred[:-2] + 2*a*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*d*(y_pred[:-2]**2)*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - c*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] - a*a*y_real[:-2] + 2*a*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*d*(y_real[:-2]**2)*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - c*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model (Without Monte Carlo Dropout)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square(y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(9))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX[:int(0.8*trainX.shape[0])], trainY[:int(0.8*trainX.shape[0])], epochs=500, batch_size=64, validation_data=(trainX[int(0.8*trainX.shape[0]):trainX.shape[0]], trainY[int(0.8*trainX.shape[0]):trainX.shape[0]]), shuffle=False)
# Out:
# Epoch 1/500
# 66/66 [==============================] - 7s 28ms/step - loss: 0.0150 - val_loss: 0.0109
# Epoch 2/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0191 - val_loss: 0.0107
# Epoch 3/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0184 - val_loss: 0.0107
# Epoch 4/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0187 - val_loss: 0.0106
# Epoch 5/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0167 - val_loss: 0.0106
# Epoch 6/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0158 - val_loss: 0.0106
# Epoch 7/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0150 - val_loss: 0.0106
# Epoch 8/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0143 - val_loss: 0.0106
# Epoch 9/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.0137 - val_loss: 0.0106
# Epoch 10/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0133 - val_loss: 0.0106
# Epoch 11/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0130 - val_loss: 0.0107
# Epoch 12/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0127 - val_loss: 0.0107
# Epoch 13/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0126 - val_loss: 0.0107
# Epoch 14/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0125 - val_loss: 0.0107
# Epoch 15/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0125 - val_loss: 0.0107
# Epoch 16/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0125 - val_loss: 0.0107
# Epoch 17/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.0124 - val_loss: 0.0107
# Epoch 18/500
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0125 - val_loss: 0.0107
# Epoch 19/500
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0124 - val_loss: 0.0107
# Epoch 20/500
# 66/66 [==============================] - 0s 8ms/step - loss: 0.0125 - val_loss: 0.0107
# Epoch 21/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0124 - val_loss: 0.0107
# Epoch 22/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0125 - val_loss: 0.0107
# Epoch 23/500
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0124 - val_loss: 0.0107
# Epoch 24/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.0127 - val_loss: 0.0107
# Epoch 25/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0125 - val_loss: 0.0107
# Epoch 26/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.0129 - val_loss: 0.0107
# Epoch 27/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.0126 - val_loss: 0.0107
# Epoch 28/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.0128 - val_loss: 0.0107
# Epoch 29/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0125 - val_loss: 0.0107
# Epoch 30/500
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0127 - val_loss: 0.0107
# Epoch 31/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.0124 - val_loss: 0.0107
# Epoch 32/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.0125 - val_loss: 0.0107
# Epoch 33/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0123 - val_loss: 0.0107
# Epoch 34/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0124 - val_loss: 0.0107
# Epoch 35/500
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0123 - val_loss: 0.0107
# Epoch 36/500
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0124 - val_loss: 0.0107
# Epoch 37/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0123 - val_loss: 0.0107
# Epoch 38/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0124 - val_loss: 0.0107
# Epoch 39/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.0123 - val_loss: 0.0107
# Epoch 40/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0126 - val_loss: 0.0107
# Epoch 41/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0123 - val_loss: 0.0107
# Epoch 42/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0126 - val_loss: 0.0107
# Epoch 43/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0123 - val_loss: 0.0107
# Epoch 44/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0125 - val_loss: 0.0107
# Epoch 45/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0123 - val_loss: 0.0107
# Epoch 46/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0124 - val_loss: 0.0107
# Epoch 47/500
# 66/66 [==============================] - 1s 10ms/step - loss: 0.0122 - val_loss: 0.0107
# Epoch 48/500
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0123 - val_loss: 0.0107
# Epoch 49/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0107
# Epoch 50/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0123 - val_loss: 0.0107
# Epoch 51/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0107
# Epoch 52/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0123 - val_loss: 0.0107
# Epoch 53/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.0122 - val_loss: 0.0107
# Epoch 54/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0124 - val_loss: 0.0107
# Epoch 55/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0122 - val_loss: 0.0107
# Epoch 56/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0125 - val_loss: 0.0107
# Epoch 57/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0122 - val_loss: 0.0107
# Epoch 58/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0124 - val_loss: 0.0107
# Epoch 59/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0122 - val_loss: 0.0107
# Epoch 60/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0123 - val_loss: 0.0107
# Epoch 61/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.0121 - val_loss: 0.0107
# Epoch 62/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0122 - val_loss: 0.0107
# Epoch 63/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0121 - val_loss: 0.0107
# Epoch 64/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0122 - val_loss: 0.0107
# Epoch 65/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0121 - val_loss: 0.0107
# Epoch 66/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0123 - val_loss: 0.0107
# Epoch 67/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0121 - val_loss: 0.0107
# Epoch 68/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0124 - val_loss: 0.0107
# Epoch 69/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0121 - val_loss: 0.0107
# Epoch 70/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0123 - val_loss: 0.0107
# Epoch 71/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.0121 - val_loss: 0.0107
# Epoch 72/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0122 - val_loss: 0.0107
# Epoch 73/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0121 - val_loss: 0.0107
# Epoch 74/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0122 - val_loss: 0.0107
# Epoch 75/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0120 - val_loss: 0.0107
# Epoch 76/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0122 - val_loss: 0.0107
# Epoch 77/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0120 - val_loss: 0.0108
# Epoch 78/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0122 - val_loss: 0.0107
# Epoch 79/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0121 - val_loss: 0.0108
# Epoch 80/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0122 - val_loss: 0.0107
# Epoch 81/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0120 - val_loss: 0.0108
# Epoch 82/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0122 - val_loss: 0.0107
# Epoch 83/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0120 - val_loss: 0.0108
# Epoch 84/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0121 - val_loss: 0.0108
# Epoch 85/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0120 - val_loss: 0.0108
# Epoch 86/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0121 - val_loss: 0.0108
# Epoch 87/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0120 - val_loss: 0.0108
# Epoch 88/500
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0122 - val_loss: 0.0108
# Epoch 89/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0120 - val_loss: 0.0108
# Epoch 90/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0121 - val_loss: 0.0108
# Epoch 91/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0120 - val_loss: 0.0108
# Epoch 92/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0121 - val_loss: 0.0108
# Epoch 93/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0120 - val_loss: 0.0108
# Epoch 94/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0121 - val_loss: 0.0108
# Epoch 95/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0120 - val_loss: 0.0108
# Epoch 96/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0121 - val_loss: 0.0108
# Epoch 97/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0120 - val_loss: 0.0109
# Epoch 98/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0120 - val_loss: 0.0109
# Epoch 99/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0119 - val_loss: 0.0109
# Epoch 100/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0120 - val_loss: 0.0109
# Epoch 101/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0120 - val_loss: 0.0109
# Epoch 102/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0122 - val_loss: 0.0109
# Epoch 103/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0120 - val_loss: 0.0109
# Epoch 104/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0120 - val_loss: 0.0110
# Epoch 105/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0119 - val_loss: 0.0109
# Epoch 106/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0120 - val_loss: 0.0110
# Epoch 107/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0118 - val_loss: 0.0110
# Epoch 108/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0119 - val_loss: 0.0110
# Epoch 109/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0119 - val_loss: 0.0110
# Epoch 110/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0122 - val_loss: 0.0110
# Epoch 111/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0119 - val_loss: 0.0111
# Epoch 112/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0119 - val_loss: 0.0111
# Epoch 113/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0118 - val_loss: 0.0108
# Epoch 114/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0118 - val_loss: 0.0110
# Epoch 115/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0118 - val_loss: 0.0111
# Epoch 116/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0119 - val_loss: 0.0111
# Epoch 117/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0118 - val_loss: 0.0111
# Epoch 118/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0119 - val_loss: 0.0111
# Epoch 119/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0118 - val_loss: 0.0111
# Epoch 120/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0120 - val_loss: 0.0111
# Epoch 121/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0
500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.4717 - val_loss: 0.8188
# Epoch 324/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.4686 - val_loss: 0.8137
# Epoch 325/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.4656 - val_loss: 0.8085
# Epoch 326/500
# 66/66 [==============================] - 1s 9ms/step - loss: 0.4625 - val_loss: 0.8033
# Epoch 327/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.4594 - val_loss: 0.7981
# Epoch 328/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.4563 - val_loss: 0.7928
# Epoch 329/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.4532 - val_loss: 0.7875
# Epoch 330/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.4501 - val_loss: 0.7821
# Epoch 331/500
# 66/66 [==============================] - 1s 9ms/step - loss: 0.4469 - val_loss: 0.7768
# Epoch 332/500
# 66/66 [==============================] - 1s 9ms/step - loss: 0.4438 - val_loss: 0.7714
# Epoch 333/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.4407 - val_loss: 0.7659
# Epoch 334/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.4375 - val_loss: 0.7605
# Epoch 335/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.4343 - val_loss: 0.7550
# Epoch 336/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.4312 - val_loss: 0.7495
# Epoch 337/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.4280 - val_loss: 0.7439
# Epoch 338/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.4248 - val_loss: 0.7383
# Epoch 339/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.4216 - val_loss: 0.7327
# Epoch 340/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.4184 - val_loss: 0.7271
# Epoch 341/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.4152 - val_loss: 0.7215
# Epoch 342/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.4120 - val_loss: 0.7158
# Epoch 343/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.4088 - val_loss: 0.7101
# Epoch 344/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.4056 - val_loss: 0.7044
# Epoch 345/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.4024 - val_loss: 0.6987
# Epoch 346/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3992 - val_loss: 0.6929
# Epoch 347/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3959 - val_loss: 0.6872
# Epoch 348/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3927 - val_loss: 0.6814
# Epoch 349/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3895 - val_loss: 0.6756
# Epoch 350/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3863 - val_loss: 0.6698
# Epoch 351/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3831 - val_loss: 0.6639
# Epoch 352/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3799 - val_loss: 0.6581
# Epoch 353/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3766 - val_loss: 0.6522
# Epoch 354/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3734 - val_loss: 0.6464
# Epoch 355/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3702 - val_loss: 0.6405
# Epoch 356/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3670 - val_loss: 0.6346
# Epoch 357/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.3638 - val_loss: 0.6287
# Epoch 358/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3606 - val_loss: 0.6228
# Epoch 359/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3574 - val_loss: 0.6169
# Epoch 360/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3542 - val_loss: 0.6110
# Epoch 361/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3510 - val_loss: 0.6051
# Epoch 362/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3478 - val_loss: 0.5992
# Epoch 363/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3447 - val_loss: 0.5933
# Epoch 364/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3415 - val_loss: 0.5874
# Epoch 365/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3384 - val_loss: 0.5815
# Epoch 366/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3352 - val_loss: 0.5756
# Epoch 367/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3321 - val_loss: 0.5697
# Epoch 368/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3290 - val_loss: 0.5638
# Epoch 369/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3258 - val_loss: 0.5579
# Epoch 370/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3227 - val_loss: 0.5520
# Epoch 371/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3196 - val_loss: 0.5461
# Epoch 372/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.3165 - val_loss: 0.5402
# Epoch 373/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3135 - val_loss: 0.5344
# Epoch 374/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3104 - val_loss: 0.5285
# Epoch 375/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3073 - val_loss: 0.5227
# Epoch 376/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3043 - val_loss: 0.5168
# Epoch 377/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3013 - val_loss: 0.5110
# Epoch 378/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.2982 - val_loss: 0.5052
# Epoch 379/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.2952 - val_loss: 0.4984
# Epoch 380/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.2871 - val_loss: 0.4804
# Epoch 381/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2840 - val_loss: 0.4748
# Epoch 382/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2811 - val_loss: 0.4692
# Epoch 383/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2782 - val_loss: 0.4635
# Epoch 384/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.2753 - val_loss: 0.4579
# Epoch 385/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.2724 - val_loss: 0.4523
# Epoch 386/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.2695 - val_loss: 0.4467
# Epoch 387/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2666 - val_loss: 0.4412
# Epoch 388/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2638 - val_loss: 0.4356
# Epoch 389/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.2609 - val_loss: 0.4300
# Epoch 390/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.2581 - val_loss: 0.4245
# Epoch 391/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2552 - val_loss: 0.4189
# Epoch 392/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2524 - val_loss: 0.4134
# Epoch 393/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.2495 - val_loss: 0.4078
# Epoch 394/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2467 - val_loss: 0.4023
# Epoch 395/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2439 - val_loss: 0.3968
# Epoch 396/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2411 - val_loss: 0.3913
# Epoch 397/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2382 - val_loss: 0.3857
# Epoch 398/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2354 - val_loss: 0.3802
# Epoch 399/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2326 - val_loss: 0.3747
# Epoch 400/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.2298 - val_loss: 0.3691
# Epoch 401/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2269 - val_loss: 0.3636
# Epoch 402/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2241 - val_loss: 0.3580
# Epoch 403/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2212 - val_loss: 0.3525
# Epoch 404/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2185 - val_loss: 0.3468
# Epoch 405/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2156 - val_loss: 0.3412
# Epoch 406/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.2127 - val_loss: 0.3355
# Epoch 407/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.2098 - val_loss: 0.3297
# Epoch 408/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2068 - val_loss: 0.3239
# Epoch 409/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2038 - val_loss: 0.3179
# Epoch 410/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.2007 - val_loss: 0.3118
# Epoch 411/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.1975 - val_loss: 0.3056
# Epoch 412/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.1942 - val_loss: 0.2992
# Epoch 413/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1907 - val_loss: 0.2925
# Epoch 414/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1871 - val_loss: 0.2856
# Epoch 415/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1832 - val_loss: 0.2783
# Epoch 416/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1820 - val_loss: 0.2759
# Epoch 417/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.1791 - val_loss: 0.2685
# Epoch 418/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.1747 - val_loss: 0.2607
# Epoch 419/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1700 - val_loss: 0.2525
# Epoch 420/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1649 - val_loss: 0.2437
# Epoch 421/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1593 - val_loss: 0.2345
# Epoch 422/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.1532 - val_loss: 0.2249
# Epoch 423/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.1466 - val_loss: 0.2149
# Epoch 424/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1545 - val_loss: 0.2368
# Epoch 425/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.1619 - val_loss: 0.2324
# Epoch 426/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1595 - val_loss: 0.2279
# Epoch 427/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1571 - val_loss: 0.2234
# Epoch 428/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.1547 - val_loss: 0.2188
# Epoch 429/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1523 - val_loss: 0.2143
# Epoch 430/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1499 - val_loss: 0.2098
# Epoch 431/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1475 - val_loss: 0.2054
# Epoch 432/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.1451 - val_loss: 0.2009
# Epoch 433/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.1334 - val_loss: 0.1830
# Epoch 434/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1093 - val_loss: 0.1560
# Epoch 435/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.1400 - val_loss: 0.2421
# Epoch 436/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1550 - val_loss: 0.2384
# Epoch 437/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.1524 - val_loss: 0.2334
# Epoch 438/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.1499 - val_loss: 0.2284
# Epoch 439/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.1475 - val_loss: 0.2236
# Epoch 440/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1434 - val_loss: 0.2169
# Epoch 441/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1376 - val_loss: 0.2100
# Epoch 442/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.1166 - val_loss: 0.1864
# Epoch 443/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1067 - val_loss: 0.1830
# Epoch 444/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1054 - val_loss: 0.1796
# Epoch 445/500
# 66/66 [==============================] - 1s 8ms/step - loss: 0.1037 - val_loss: 0.1757
# Epoch 446/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1022 - val_loss: 0.1722
# Epoch 447/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1001 - val_loss: 0.1676
# Epoch 448/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0977 - val_loss: 0.1639
# Epoch 449/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0959 - val_loss: 0.1603
# Epoch 450/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0942 - val_loss: 0.1567
# Epoch 451/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0826 - val_loss: 0.1389
# Epoch 452/500
# 66/66 [==============================] - 1s 7ms/step - loss: 0.0743 - val_loss: 0.1319
# Epoch 453/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0721 - val_loss: 0.1290
# Epoch 454/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0703 - val_loss: 0.1252
# Epoch 455/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0685 - val_loss: 0.1227
# Epoch 456/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0673 - val_loss: 0.1201
# Epoch 457/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0658 - val_loss: 0.1167
# Epoch 458/500
# 66/66 [==============================] - 0s 8ms/step - loss: 0.0640 - val_loss: 0.1140
# Epoch 459/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0628 - val_loss: 0.1115
# Epoch 460/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0616 - val_loss: 0.1090
# Epoch 461/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0605 - val_loss: 0.1066
# Epoch 462/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0593 - val_loss: 0.1042
# Epoch 463/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.0582 - val_loss: 0.1019
# Epoch 464/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.0571 - val_loss: 0.0995
# Epoch 465/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0507 - val_loss: 0.0855
# Epoch 466/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0931 - val_loss: 0.4527
# Epoch 467/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3326 - val_loss: 0.5758
# Epoch 468/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3509 - val_loss: 0.6093
# Epoch 469/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3284 - val_loss: 0.5612
# Epoch 470/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.3103 - val_loss: 0.5231
# Epoch 471/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.2946 - val_loss: 0.4900
# Epoch 472/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2815 - val_loss: 0.4631
# Epoch 473/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.4581 - val_loss: 0.7211
# Epoch 474/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.4562 - val_loss: 0.6618
# Epoch 475/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.4288 - val_loss: 0.6160
# Epoch 476/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.4073 - val_loss: 0.5784
# Epoch 477/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3894 - val_loss: 0.5466
# Epoch 478/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3741 - val_loss: 0.5191
# Epoch 479/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3607 - val_loss: 0.4947
# Epoch 480/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3488 - val_loss: 0.4730
# Epoch 481/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3381 - val_loss: 0.4534
# Epoch 482/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.3280 - val_loss: 0.4342
# Epoch 483/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3187 - val_loss: 0.4179
# Epoch 484/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3107 - val_loss: 0.4029
# Epoch 485/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3032 - val_loss: 0.3890
# Epoch 486/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2962 - val_loss: 0.3761
# Epoch 487/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2896 - val_loss: 0.3638
# Epoch 488/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.2832 - val_loss: 0.3520
# Epoch 489/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.2767 - val_loss: 0.3397
# Epoch 490/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.2679 - val_loss: 0.3209
# Epoch 491/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2240 - val_loss: 0.1946
# Epoch 492/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.2294 - val_loss: 0.2462
# Epoch 493/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.1986 - val_loss: 0.2381
# Epoch 494/500
# 66/66 [==============================] - 0s 7ms/step - loss: 0.1935 - val_loss: 0.2302
# Epoch 495/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.1828 - val_loss: 0.2147
# Epoch 496/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.1676 - val_loss: 0.1876
# Epoch 497/500
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1775 - val_loss: 0.2029
# Epoch 498/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.1692 - val_loss: 0.1964
# Epoch 499/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.1675 - val_loss: 0.1927
# Epoch 500/500
# 66/66 [==============================] - 0s 6ms/step - loss: 0.1641 - val_loss: 0.1874

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ## Metrics (Without Monte Carlo Dropout)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
textX_without_mc = testX
textY_without_mc = testY
yhat_without_mc = model.predict(textX_without_mc)
print(yhat_without_mc.shape)
textX_without_mc = textX_without_mc.reshape((textX_without_mc.shape[0], textX_without_mc.shape[2]))
print(textX_without_mc.shape)
inv_yhat_without_mc = np.concatenate((textX_without_mc, yhat_without_mc), axis=1)
inv_yhat_without_mc = scaler.inverse_transform(inv_yhat_without_mc)
inv_yhat1_without_mc = inv_yhat_without_mc[:, -3:]
inv_yhat_without_mc = inv_yhat_without_mc[:, -3]
inv_y_without_mc = np.concatenate((textX_without_mc, textY_without_mc), axis=1)
inv_y_without_mc = scaler.inverse_transform(inv_y_without_mc)
inv_y1_without_mc = inv_y_without_mc[:, -3:]
inv_y_without_mc = inv_y_without_mc[:, -3]
rmse_without_mc = np.sqrt(mean_squared_error(inv_y_without_mc, inv_yhat_without_mc))
mae_without_mc = mean_absolute_error(inv_y_without_mc, inv_yhat_without_mc)
print('Test RMSE: %.3f' % rmse_without_mc)
print('Test MAE: %.3f' % mae_without_mc)
# Out:
# 41/41 [==============================] - 1s 2ms/step
# (1303, 9)
# (1303, 157)
# Test RMSE: 0.600
# Test MAE: 0.543

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y_without_mc, marker='.', label="actual")
plt.plot(inv_yhat_without_mc, 'r', label="prediction")
plt.suptitle('Kyoto DST Index', fontsize=20)
plt.legend(fontsize=20)
plt.show()
