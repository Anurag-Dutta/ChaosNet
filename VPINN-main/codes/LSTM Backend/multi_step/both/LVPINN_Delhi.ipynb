# %% [markdown]
# ## Gathering Dependencies

# %% [markdown]
# _Importing Required Libraries_

# %%
pip install hampel
# Out:
# Requirement already satisfied: hampel in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.0.5)
# Requirement already satisfied: numpy in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.21.6)
# Requirement already satisfied: pandas in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from hampel) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\anurag dutta\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.8.1->pandas->hampel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\Anurag Dutta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import keras
import tensorflow as tf
from hampel import hampel
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
from matplotlib import pyplot
from numpy import array

# %% [markdown]
# ## Pretraining

# %% [markdown]
# _Lotka Volterra Intermittency_

# %% [markdown]
# The `lotka_volterra_intermittency.dat` feeds the model with the dynamics of the Lotka Volterra Equations

# %%
data = np.genfromtxt('datasets/lotka_volterra_intermittency.dat')
training_set = pd.DataFrame(data).reset_index(drop=True)
training_set = training_set.iloc[:,1]

# %% [markdown]
# ## Computing the Gradients

# %% [markdown]
# _Calculating the value of_ $\frac{dx}{dt}$, _and_ $\frac{d^2x}{dt^2}$

# %%
t_diff = 1 # Weekly Data
print(training_set.max())
gradient_t = (training_set.diff()/t_diff).iloc[1:]
print(gradient_t)
gradient_tt = (gradient_t.diff()/t_diff).iloc[1:]
print(gradient_tt)
# Out:
# 215.48740705
# 1        -1.540163e-03
# 2        -1.523369e-03
# 3        -1.506756e-03
# 4        -1.490327e-03
# 5        -1.474074e-03
#               ...
# 139867   -1.591086e-35
# 139868   -1.573887e-35
# 139869   -1.556877e-35
# 139870   -1.540049e-35
# 139871   -1.523404e-35
# Name: 1, Length: 139871, dtype: float64
# 2         2.399184e-06
# 3         2.373265e-06
# 4         2.346939e-06
# 5         2.321837e-06
# 6         2.296327e-06
#               ...
# 139867    2.483673e-38
# 139868    2.456939e-38
# 139869    2.430082e-38
# 139870    2.403980e-38
# 139871    2.377878e-38
# Name: 1, Length: 139870, dtype: float64

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# _दिल्ली WIND SPEED_

# %%
data = pd.read_csv("datasets/delhi.csv")
training_set = data.iloc[:, 3]
print(training_set)
# Out:
# 0       0.000000
# 1       2.980000
# 2       4.633333
# 3       1.233333
# 4       3.700000
#           ...
# 1457    3.547826
# 1458    6.000000
# 1459    6.266667
# 1460    7.325000
# 1461    0.000000
# Name: wind_speed, Length: 1462, dtype: float64

# %%
training_set = training_set.reset_index(drop=True)
gradient_t = gradient_t.reset_index(drop=True)
gradient_tt = gradient_tt.reset_index(drop=True)
print(gradient_t)
print(gradient_tt)
# Out:
# 0        -1.540163e-03
# 1        -1.523369e-03
# 2        -1.506756e-03
# 3        -1.490327e-03
# 4        -1.474074e-03
#               ...
# 139866   -1.591086e-35
# 139867   -1.573887e-35
# 139868   -1.556877e-35
# 139869   -1.540049e-35
# 139870   -1.523404e-35
# Name: 1, Length: 139871, dtype: float64
# 0         2.399184e-06
# 1         2.373265e-06
# 2         2.346939e-06
# 3         2.321837e-06
# 4         2.296327e-06
#               ...
# 139865    2.483673e-38
# 139866    2.456939e-38
# 139867    2.430082e-38
# 139868    2.403980e-38
# 139869    2.377878e-38
# Name: 1, Length: 139870, dtype: float64

# %%
print(gradient_t.shape)
print(training_set.shape[:-1])
df = pd.concat((training_set[:-1], gradient_t), axis=1)
gradient_tt.columns = ["grad_tt"]
df = pd.concat((df[:-1], gradient_tt), axis=1)
df.columns = ['y_t', 'grad_t', 'grad_tt']
# Out:
# (139871,)
# ()

# %% [markdown]
# ## Plot of the External Forcing from Chaotic Differential Equation (_Lotka Volterra Equation_)

# %%
a=0.1
b=0.05
c=1.1
d=0.1
L = df.iloc[:, 2] - a*a*df.iloc[:, 0] + 2*a*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - b*d*(df.iloc[:,0]**2)*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0])) - c*b*df.iloc[:, 0]*((a*df.iloc[:, 0]-df.iloc[:, 1])/(b*df.iloc[:, 0]))
L.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the data into supervised learning

# %%
def Supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
      cols.append(df.shift(-i))
      if i == 0:
        names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
      else:
        names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
       agg.dropna(inplace=True)
    return agg

# %%
dat = Supervised(df.values, n_in = 10, n_out = 52)
dat.columns
# Out:
# Index(['var1(t-10)', 'var2(t-10)', 'var3(t-10)', 'var1(t-9)', 'var2(t-9)',
#        'var3(t-9)', 'var1(t-8)', 'var2(t-8)', 'var3(t-8)', 'var1(t-7)',
#        ...
#        'var3(t+48)', 'var1(t+49)', 'var2(t+49)', 'var3(t+49)', 'var1(t+50)',
#        'var2(t+50)', 'var3(t+50)', 'var1(t+51)', 'var2(t+51)', 'var3(t+51)'],
#       dtype='object', length=186)

# %%
data = Supervised(df.values, n_in = 10, n_out = 52)
data.drop(['var2(t-10)', 'var3(t-10)', 'var2(t-9)', 'var3(t-9)', 'var2(t-8)',
       'var3(t-8)', 'var2(t-7)', 'var3(t-7)', 'var2(t-6)', 'var3(t-6)',
       'var2(t-5)', 'var3(t-5)', 'var2(t-4)', 'var3(t-4)', 'var2(t-2)',
       'var3(t-2)', 'var2(t-1)', 'var3(t-1)','var2(t-3)', 'var3(t-3)'], axis = 1, inplace = True)#,18,19
print(data.head())
print(data.columns)
# Out:
#     var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 10    0.000000   2.980000   4.633333   1.233333   3.700000   1.480000
# 11    2.980000   4.633333   1.233333   3.700000   1.480000   6.300000
# 12    4.633333   1.233333   3.700000   1.480000   6.300000   7.142857
# 13    1.233333   3.700000   1.480000   6.300000   7.142857  12.500000
# 14    3.700000   1.480000   6.300000   7.142857  12.500000   7.400000
#
#     var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)  ...  var3(t+48)  var1(t+49)  \
# 10   6.300000   7.142857  12.500000   7.400000  ...    0.000001   24.066667
# 11   7.142857  12.500000   7.400000  10.571429  ...    0.000001   15.725000
# 12  12.500000   7.400000  10.571429  13.228571  ...    0.000001    8.633333
# 13   7.400000  10.571429  13.228571   4.633333  ...    0.000001    5.560000
# 14  10.571429  13.228571   4.633333   0.616667  ...    0.000001    4.162500
#
#     var2(t+49)  var3(t+49)  var1(t+50)  var2(t+50)  var3(t+50)  var1(t+51)  \
# 10   -0.000807    0.000001   15.725000   -0.000798    0.000001    8.633333
# 11   -0.000798    0.000001    8.633333   -0.000789    0.000001    5.560000
# 12   -0.000789    0.000001    5.560000   -0.000780    0.000001    4.162500
# 13   -0.000780    0.000001    4.162500   -0.000772    0.000001    6.871429
# 14   -0.000772    0.000001    6.871429   -0.000764    0.000001    8.728571
#
#     var2(t+51)  var3(t+51)
# 10   -0.000789    0.000001
# 11   -0.000780    0.000001
# 12   -0.000772    0.000001
# 13   -0.000764    0.000001
# 14   -0.000755    0.000001
#
# [5 rows x 166 columns]
# Index(['var1(t-10)', 'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)',
#        'var1(t-5)', 'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)',
#        ...
#        'var3(t+48)', 'var1(t+49)', 'var2(t+49)', 'var3(t+49)', 'var1(t+50)',
#        'var2(t+50)', 'var3(t+50)', 'var1(t+51)', 'var2(t+51)', 'var3(t+51)'],
#       dtype='object', length=166)

# %% [markdown]
# ## Train and Test Split

# %%
train_size = int(len(data) * 0.8)
test_size = len(data) - train_size
train_1 = np.array(data[0:train_size])
test_1 = np.array(data[train_size:len(data)])
scaler = MinMaxScaler(feature_range=(0, 1))
train = scaler.fit_transform(train_1)
test = scaler.transform(test_1)
trainY = train[:,-9:]
trainX = train[:,:-9]
testY = test[:,-9:]
testX = test[:,:-9]
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# (1120, 1, 157) (1120, 9) (280, 1, 157) (280, 9)

# %% [markdown]
# ## Defining the Physical Loss

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)


def phys(y_pred, y_true):
    return mean_absolute_error((y_true[:, 2] - a*a*y_true[:, 0] + 2*a*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - b*d*(y_true[:,0]**2)*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0])) - c*b*y_true[:, 0]*((a*y_true[:, 0]-y_true[:, 1])/(b*y_true[:, 0]))), (y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))))

def phys2(y_pred, y_real):
    pred = y_pred[2:]-2*y_pred[1:-1]-y_pred[:-2] - a*a*y_pred[:-2] + 2*a*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - b*d*(y_pred[:-2]**2)*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2])) - c*b*y_pred[:-2]*((a*y_pred[:-2]-(y_pred[1:-1]-y_pred[:-2]))/(b*y_pred[:-2]))
    real = y_real[2:]-2*y_real[1:-1]-y_real[:-2] - a*a*y_real[:-2] + 2*a*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - b*d*(y_real[:-2]**2)*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2])) - c*b*y_real[:-2]*((a*y_real[:-2]-(y_real[1:-1]-y_real[:-2]))/(b*y_real[:-2]))
    return(mean_absolute_error(pred, real))

# %% [markdown]
# ## Model (Without Monte Carlo Dropout)

# %%
a = tf.Variable(0.1, name="alpha", trainable=True, dtype=tf.float32)
b = tf.Variable(0.05, name="beta", trainable=True, dtype=tf.float32)
c = tf.Variable(1.1, name="gamma", trainable=True, dtype=tf.float32)
d = tf.Variable(0.1, name="delta", trainable=True, dtype=tf.float32)

def loss_fn(y_true, y_pred):
    squared_difference = tf.square(y_true[:, 0] - y_pred[:, 0])
    squared_difference2 = tf.square(y_true[:, 2]-y_pred[:, 2])
    squared_difference1 = tf.square(y_true[:, 1]-y_pred[:, 1])
    squared_difference3 = tf.square(y_pred[:, 2] - a*a*y_pred[:, 0] + 2*a*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0]))*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - b*d*(y_pred[:,0]**2)*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])) - c*b*y_pred[:, 0]*((a*y_pred[:, 0]-y_pred[:, 1])/(b*y_pred[:, 0])))
    return tf.reduce_mean(squared_difference, axis=-1) + 0.2*tf.reduce_mean(squared_difference3, axis=-1)

model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(9))
model.compile(loss=loss_fn, optimizer='adam')
history = model.fit(trainX[:int(0.8*trainX.shape[0])], trainY[:int(0.8*trainX.shape[0])], epochs=500, batch_size=64, validation_data=(trainX[int(0.8*trainX.shape[0]):trainX.shape[0]], trainY[int(0.8*trainX.shape[0]):trainX.shape[0]]), shuffle=False)
# Out:
# Epoch 1/500
# 14/14 [==============================] - 3s 53ms/step - loss: 0.1382 - val_loss: 0.0983
# Epoch 2/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1383 - val_loss: 0.1733
# Epoch 3/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1885 - val_loss: 0.1956
# Epoch 4/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2018 - val_loss: 0.2002
# Epoch 5/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2035 - val_loss: 0.1992
# Epoch 6/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2017 - val_loss: 0.1965
# Epoch 7/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1989 - val_loss: 0.1933
# Epoch 8/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1957 - val_loss: 0.1898
# Epoch 9/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1923 - val_loss: 0.1862
# Epoch 10/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1888 - val_loss: 0.1824
# Epoch 11/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1851 - val_loss: 0.1786
# Epoch 12/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1814 - val_loss: 0.1747
# Epoch 13/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1776 - val_loss: 0.1707
# Epoch 14/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1738 - val_loss: 0.1667
# Epoch 15/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1699 - val_loss: 0.1626
# Epoch 16/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1661 - val_loss: 0.1586
# Epoch 17/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1622 - val_loss: 0.1545
# Epoch 18/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1583 - val_loss: 0.1505
# Epoch 19/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1545 - val_loss: 0.1465
# Epoch 20/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1506 - val_loss: 0.1425
# Epoch 21/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1469 - val_loss: 0.1386
# Epoch 22/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1431 - val_loss: 0.1347
# Epoch 23/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1394 - val_loss: 0.1308
# Epoch 24/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1358 - val_loss: 0.1270
# Epoch 25/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1322 - val_loss: 0.1233
# Epoch 26/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1286 - val_loss: 0.1196
# Epoch 27/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1252 - val_loss: 0.1160
# Epoch 28/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1218 - val_loss: 0.1125
# Epoch 29/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1184 - val_loss: 0.1091
# Epoch 30/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1152 - val_loss: 0.1057
# Epoch 31/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1120 - val_loss: 0.1024
# Epoch 32/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1088 - val_loss: 0.0992
# Epoch 33/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1058 - val_loss: 0.0960
# Epoch 34/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1028 - val_loss: 0.0930
# Epoch 35/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0999 - val_loss: 0.0900
# Epoch 36/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0971 - val_loss: 0.0871
# Epoch 37/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0943 - val_loss: 0.0843
# Epoch 38/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0916 - val_loss: 0.0815
# Epoch 39/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0890 - val_loss: 0.0789
# Epoch 40/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0865 - val_loss: 0.0763
# Epoch 41/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0840 - val_loss: 0.0737
# Epoch 42/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0816 - val_loss: 0.0713
# Epoch 43/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0793 - val_loss: 0.0689
# Epoch 44/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0771 - val_loss: 0.0666
# Epoch 45/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0749 - val_loss: 0.0644
# Epoch 46/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0728 - val_loss: 0.0623
# Epoch 47/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0707 - val_loss: 0.0602
# Epoch 48/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0687 - val_loss: 0.0581
# Epoch 49/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0668 - val_loss: 0.0562
# Epoch 50/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0649 - val_loss: 0.0543
# Epoch 51/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0631 - val_loss: 0.0525
# Epoch 52/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0614 - val_loss: 0.0507
# Epoch 53/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0597 - val_loss: 0.0490
# Epoch 54/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0580 - val_loss: 0.0474
# Epoch 55/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0565 - val_loss: 0.0458
# Epoch 56/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0549 - val_loss: 0.0442
# Epoch 57/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0535 - val_loss: 0.0428
# Epoch 58/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0520 - val_loss: 0.0413
# Epoch 59/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0507 - val_loss: 0.0400
# Epoch 60/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0494 - val_loss: 0.0387
# Epoch 61/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0481 - val_loss: 0.0374
# Epoch 62/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0468 - val_loss: 0.0362
# Epoch 63/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0456 - val_loss: 0.0350
# Epoch 64/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0445 - val_loss: 0.0338
# Epoch 65/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0434 - val_loss: 0.0327
# Epoch 66/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0423 - val_loss: 0.0317
# Epoch 67/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0413 - val_loss: 0.0307
# Epoch 68/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0403 - val_loss: 0.0297
# Epoch 69/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0394 - val_loss: 0.0288
# Epoch 70/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0385 - val_loss: 0.0279
# Epoch 71/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0376 - val_loss: 0.0270
# Epoch 72/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0367 - val_loss: 0.0262
# Epoch 73/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0359 - val_loss: 0.0254
# Epoch 74/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0351 - val_loss: 0.0247
# Epoch 75/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0344 - val_loss: 0.0240
# Epoch 76/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0337 - val_loss: 0.0233
# Epoch 77/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0330 - val_loss: 0.0226
# Epoch 78/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0323 - val_loss: 0.0220
# Epoch 79/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0317 - val_loss: 0.0214
# Epoch 80/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0310 - val_loss: 0.0208
# Epoch 81/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0305 - val_loss: 0.0202
# Epoch 82/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0299 - val_loss: 0.0197
# Epoch 83/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0293 - val_loss: 0.0192
# Epoch 84/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0288 - val_loss: 0.0187
# Epoch 85/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0283 - val_loss: 0.0182
# Epoch 86/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0278 - val_loss: 0.0178
# Epoch 87/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0274 - val_loss: 0.0174
# Epoch 88/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0269 - val_loss: 0.0170
# Epoch 89/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0265 - val_loss: 0.0166
# Epoch 90/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0261 - val_loss: 0.0162
# Epoch 91/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0257 - val_loss: 0.0159
# Epoch 92/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0253 - val_loss: 0.0156
# Epoch 93/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0250 - val_loss: 0.0152
# Epoch 94/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0246 - val_loss: 0.0149
# Epoch 95/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0243 - val_loss: 0.0147
# Epoch 96/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0240 - val_loss: 0.0144
# Epoch 97/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0237 - val_loss: 0.0141
# Epoch 98/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0234 - val_loss: 0.0139
# Epoch 99/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0231 - val_loss: 0.0137
# Epoch 100/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0229 - val_loss: 0.0134
# Epoch 101/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0226 - val_loss: 0.0132
# Epoch 102/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0224 - val_loss: 0.0130
# Epoch 103/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0221 - val_loss: 0.0129
# Epoch 104/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0219 - val_loss: 0.0127
# Epoch 105/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0217 - val_loss: 0.0125
# Epoch 106/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0215 - val_loss: 0.0124
# Epoch 107/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0213 - val_loss: 0.0122
# Epoch 108/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0211 - val_loss: 0.0121
# Epoch 109/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0209 - val_loss: 0.0119
# Epoch 110/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0208 - val_loss: 0.0118
# Epoch 111/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0206 - val_loss: 0.0117
# Epoch 112/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0204 - val_loss: 0.0116
# Epoch 113/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0203 - val_loss: 0.0115
# Epoch 114/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0201 - val_loss: 0.0114
# Epoch 115/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0200 - val_loss: 0.0113
# Epoch 116/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0198 - val_loss: 0.0112
# Epoch 117/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0197 - val_loss: 0.0111
# Epoch 118/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0196 - val_loss: 0.0110
# Epoch 119/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0195 - val_loss: 0.0109
# Epoch 120/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0193 - val_loss: 0.0109
# Epoch 121/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0192 - val_loss: 0.0108
# Epoch 122/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0191 - val_loss: 0.0107
# Epoch 123/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0190 - val_loss: 0.0107
# Epoch 124/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0189 - val_loss: 0.0106
# Epoch 125/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0188 - val_loss: 0.0106
# Epoch 126/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0187 - val_loss: 0.0105
# Epoch 127/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0186 - val_loss: 0.0105
# Epoch 128/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0185 - val_loss: 0.0104
# Epoch 129/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0185 - val_loss: 0.0104
# Epoch 130/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0184 - val_loss: 0.0104
# Epoch 131/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0183 - val_loss: 0.0103
# Epoch 132/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0182 - val_loss: 0.0103
# Epoch 133/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0181 - val_loss: 0.0103
# Epoch 134/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0181 - val_loss: 0.0102
# Epoch 135/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0180 - val_loss: 0.0102
# Epoch 136/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0179 - val_loss: 0.0102
# Epoch 137/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0178 - val_loss: 0.0102
# Epoch 138/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0178 - val_loss: 0.0101
# Epoch 139/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0177 - val_loss: 0.0101
# Epoch 140/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0176 - val_loss: 0.0101
# Epoch 141/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0176 - val_loss: 0.0101
# Epoch 142/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0175 - val_loss: 0.0101
# Epoch 143/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0174 - val_loss: 0.0100
# Epoch 144/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0174 - val_loss: 0.0100
# Epoch 145/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0173 - val_loss: 0.0100
# Epoch 146/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0173 - val_loss: 0.0100
# Epoch 147/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0172 - val_loss: 0.0100
# Epoch 148/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0172 - val_loss: 0.0100
# Epoch 149/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0171 - val_loss: 0.0100
# Epoch 150/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0170 - val_loss: 0.0100
# Epoch 151/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0170 - val_loss: 0.0099
# Epoch 152/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0169 - val_loss: 0.0099
# Epoch 153/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0169 - val_loss: 0.0099
# Epoch 154/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0168 - val_loss: 0.0099
# Epoch 155/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0168 - val_loss: 0.0099
# Epoch 156/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0167 - val_loss: 0.0099
# Epoch 157/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0167 - val_loss: 0.0099
# Epoch 158/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0166 - val_loss: 0.0099
# Epoch 159/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0166 - val_loss: 0.0099
# Epoch 160/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0165 - val_loss: 0.0099
# Epoch 161/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0165 - val_loss: 0.0099
# Epoch 162/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0164 - val_loss: 0.0099
# Epoch 163/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0164 - val_loss: 0.0099
# Epoch 164/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0164 - val_loss: 0.0099
# Epoch 165/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0163 - val_loss: 0.0099
# Epoch 166/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0163 - val_loss: 0.0099
# Epoch 167/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0162 - val_loss: 0.0099
# Epoch 168/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0162 - val_loss: 0.0098
# Epoch 169/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0161 - val_loss: 0.0098
# Epoch 170/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0161 - val_loss: 0.0098
# Epoch 171/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0160 - val_loss: 0.0098
# Epoch 172/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0160 - val_loss: 0.0098
# Epoch 173/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0160 - val_loss: 0.0098
# Epoch 174/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0159 - val_loss: 0.0098
# Epoch 175/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0159 - val_loss: 0.0098
# Epoch 176/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0158 - val_loss: 0.0098
# Epoch 177/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0158 - val_loss: 0.0098
# Epoch 178/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0158 - val_loss: 0.0098
# Epoch 179/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0157 - val_loss: 0.0098
# Epoch 180/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0157 - val_loss: 0.0098
# Epoch 181/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0156 - val_loss: 0.0098
# Epoch 182/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0156 - val_loss: 0.0098
# Epoch 183/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0156 - val_loss: 0.0098
# Epoch 184/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0155 - val_loss: 0.0098
# Epoch 185/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0155 - val_loss: 0.0098
# Epoch 186/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0154 - val_loss: 0.0098
# Epoch 187/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0154 - val_loss: 0.0098
# Epoch 188/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0154 - val_loss: 0.0098
# Epoch 189/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0153 - val_loss: 0.0098
# Epoch 190/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0153 - val_loss: 0.0098
# Epoch 191/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0153 - val_loss: 0.0098
# Epoch 192/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0152 - val_loss: 0.0098
# Epoch 193/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0152 - val_loss: 0.0098
# Epoch 194/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0152 - val_loss: 0.0098
# Epoch 195/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0151 - val_loss: 0.0098
# Epoch 196/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0151 - val_loss: 0.0098
# Epoch 197/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0150 - val_loss: 0.0098
# Epoch 198/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0150 - val_loss: 0.0098
# Epoch 199/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0150 - val_loss: 0.0098
# Epoch 200/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0149 - val_loss: 0.0098
# Epoch 201/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0149 - val_loss: 0.0098
# Epoch 202/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0149 - val_loss: 0.0098
# Epoch 203/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0148 - val_loss: 0.0098
# Epoch 204/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0148 - val_loss: 0.0098
# Epoch 205/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0148 - val_loss: 0.0098
# Epoch 206/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0147 - val_loss: 0.0098
# Epoch 207/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0147 - val_loss: 0.0098
# Epoch 208/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0147 - val_loss: 0.0098
# Epoch 209/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0147 - val_loss: 0.0098
# Epoch 210/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0146 - val_loss: 0.0098
# Epoch 211/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0146 - val_loss: 0.0098
# Epoch 212/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0146 - val_loss: 0.0098
# Epoch 213/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0145 - val_loss: 0.0098
# Epoch 214/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0145 - val_loss: 0.0098
# Epoch 215/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0145 - val_loss: 0.0098
# Epoch 216/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0144 - val_loss: 0.0098
# Epoch 217/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0144 - val_loss: 0.0098
# Epoch 218/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0144 - val_loss: 0.0098
# Epoch 219/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0144 - val_loss: 0.0098
# Epoch 220/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0143 - val_loss: 0.0098
# Epoch 221/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0143 - val_loss: 0.0098
# Epoch 222/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0143 - val_loss: 0.0098
# Epoch 223/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0142 - val_loss: 0.0098
# Epoch 224/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0142 - val_loss: 0.0098
# Epoch 225/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0142 - val_loss: 0.0098
# Epoch 226/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0142 - val_loss: 0.0098
# Epoch 227/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0141 - val_loss: 0.0098
# Epoch 228/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0141 - val_loss: 0.0098
# Epoch 229/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0141 - val_loss: 0.0098
# Epoch 230/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0141 - val_loss: 0.0098
# Epoch 231/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0140 - val_loss: 0.0098
# Epoch 232/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0140 - val_loss: 0.0099
# Epoch 233/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0140 - val_loss: 0.0099
# Epoch 234/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0140 - val_loss: 0.0099
# Epoch 235/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0139 - val_loss: 0.0099
# Epoch 236/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0139 - val_loss: 0.0099
# Epoch 237/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0139 - val_loss: 0.0099
# Epoch 238/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0139 - val_loss: 0.0099
# Epoch 239/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0138 - val_loss: 0.0099
# Epoch 240/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0138 - val_loss: 0.0099
# Epoch 241/500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0138 - val_loss: 0.0099
# Epoch 242/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0138 - val_loss: 0.0099
# Epoch 243/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0137 - val_loss: 0.0099
# Epoch 244/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0137 - val_loss: 0.0099
# Epoch 245/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0137 - val_loss: 0.0099
# Epoch 246/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0137 - val_loss: 0.0099
# Epoch 247/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0136 - val_loss: 0.0099
# Epoch 248/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0136 - val_loss: 0.0099
# Epoch 249/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0136 - val_loss: 0.0099
# Epoch 250/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0136 - val_loss: 0.0099
# Epoch 251/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0136 - val_loss: 0.0099
# Epoch 252/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0135 - val_loss: 0.0099
# Epoch 253/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0135 - val_loss: 0.0099
# Epoch 254/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0135 - val_loss: 0.0099
# Epoch 255/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0135 - val_loss: 0.0099
# Epoch 256/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0135 - val_loss: 0.0099
# Epoch 257/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0134 - val_loss: 0.0099
# Epoch 258/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0134 - val_loss: 0.0099
# Epoch 259/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0134 - val_loss: 0.0099
# Epoch 260/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0134 - val_loss: 0.0099
# Epoch 261/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0134 - val_loss: 0.0099
# Epoch 262/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0133 - val_loss: 0.0099
# Epoch 263/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0133 - val_loss: 0.0099
# Epoch 264/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0133 - val_loss: 0.0099
# Epoch 265/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0133 - val_loss: 0.0099
# Epoch 266/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0133 - val_loss: 0.0099
# Epoch 267/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0133 - val_loss: 0.0099
# Epoch 268/500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0132 - val_loss: 0.0099
# Epoch 269/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0132 - val_loss: 0.0099
# Epoch 270/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0132 - val_loss: 0.0099
# Epoch 271/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0132 - val_loss: 0.0099
# Epoch 272/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0132 - val_loss: 0.0099
# Epoch 273/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0132 - val_loss: 0.0099
# Epoch 274/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0131 - val_loss: 0.0099
# Epoch 275/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0131 - val_loss: 0.0099
# Epoch 276/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0131 - val_loss: 0.0099
# Epoch 277/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0131 - val_loss: 0.0099
# Epoch 278/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0131 - val_loss: 0.0099
# Epoch 279/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0131 - val_loss: 0.0099
# Epoch 280/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0131 - val_loss: 0.0099
# Epoch 281/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0130 - val_loss: 0.0099
# Epoch 282/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0130 - val_loss: 0.0099
# Epoch 283/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0130 - val_loss: 0.0099
# Epoch 284/500
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0130 - val_loss: 0.0099
# Epoch 285/500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0130 - val_loss: 0.0099
# Epoch 286/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0130 - val_loss: 0.0099
# Epoch 287/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0130 - val_loss: 0.0099
# Epoch 288/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0129 - val_loss: 0.0099
# Epoch 289/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0129 - val_loss: 0.0099
# Epoch 290/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0129 - val_loss: 0.0099
# Epoch 291/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0129 - val_loss: 0.0099
# Epoch 292/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0129 - val_loss: 0.0099
# Epoch 293/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0129 - val_loss: 0.0099
# Epoch 294/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0129 - val_loss: 0.0099
# Epoch 295/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0128 - val_loss: 0.0099
# Epoch 296/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0128 - val_loss: 0.0099
# Epoch 297/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0128 - val_loss: 0.0099
# Epoch 298/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0128 - val_loss: 0.0099
# Epoch 299/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0128 - val_loss: 0.0099
# Epoch 300/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0128 - val_loss: 0.0099
# Epoch 301/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0128 - val_loss: 0.0099
# Epoch 302/500
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0128 - val_loss: 0.0099
# Epoch 303/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0128 - val_loss: 0.0099
# Epoch 304/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0127 - val_loss: 0.0100
# Epoch 305/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0127 - val_loss: 0.0100
# Epoch 306/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0127 - val_loss: 0.0100
# Epoch 307/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0127 - val_loss: 0.0100
# Epoch 308/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0127 - val_loss: 0.0100
# Epoch 309/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0127 - val_loss: 0.0100
# Epoch 310/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0127 - val_loss: 0.0100
# Epoch 311/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0127 - val_loss: 0.0100
# Epoch 312/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0127 - val_loss: 0.0100
# Epoch 313/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0127 - val_loss: 0.0100
# Epoch 314/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0126 - val_loss: 0.0100
# Epoch 315/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0126 - val_loss: 0.0100
# Epoch 316/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0126 - val_loss: 0.0100
# Epoch 317/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0126 - val_loss: 0.0100
# Epoch 318/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0126 - val_loss: 0.0100
# Epoch 319/500
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0126 - val_loss: 0.0100
# Epoch 320/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0126 - val_loss: 0.0100
# Epoch 321/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0126 - val_loss: 0.0100
# Epoch 322/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0126 - val_loss: 0.0100
# Epoch 323/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0126 - val_loss: 0.0100
# Epoch 324/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0126 - val_loss: 0.0100
# Epoch 325/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0125 - val_loss: 0.0100
# Epoch 326/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0125 - val_loss: 0.0100
# Epoch 327/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0125 - val_loss: 0.0100
# Epoch 328/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0125 - val_loss: 0.0100
# Epoch 329/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0125 - val_loss: 0.0100
# Epoch 330/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0125 - val_loss: 0.0100
# Epoch 331/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0125 - val_loss: 0.0100
# Epoch 332/500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0125 - val_loss: 0.0100
# Epoch 333/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0125 - val_loss: 0.0100
# Epoch 334/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0125 - val_loss: 0.0100
# Epoch 335/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0125 - val_loss: 0.0100
# Epoch 336/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0125 - val_loss: 0.0100
# Epoch 337/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0124 - val_loss: 0.0100
# Epoch 338/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0124 - val_loss: 0.0100
# Epoch 339/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0124 - val_loss: 0.0100
# Epoch 340/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0124 - val_loss: 0.0100
# Epoch 341/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0124 - val_loss: 0.0100
# Epoch 342/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0124 - val_loss: 0.0100
# Epoch 343/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0124 - val_loss: 0.0100
# Epoch 344/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0124 - val_loss: 0.0100
# Epoch 345/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0124 - val_loss: 0.0100
# Epoch 346/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0124 - val_loss: 0.0100
# Epoch 347/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0124 - val_loss: 0.0100
# Epoch 348/500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0124 - val_loss: 0.0100
# Epoch 349/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0124 - val_loss: 0.0100
# Epoch 350/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0124 - val_loss: 0.0100
# Epoch 351/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0124 - val_loss: 0.0100
# Epoch 352/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0124 - val_loss: 0.0100
# Epoch 353/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 354/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 355/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 356/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 357/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 358/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 359/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 360/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 361/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 362/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 363/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 364/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 365/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 366/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 367/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 368/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 369/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 370/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 371/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 372/500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 373/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 374/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 375/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 376/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 377/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 378/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 379/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 380/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 381/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 382/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 383/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 384/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 385/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 386/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 387/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 388/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 389/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 390/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 391/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0122 - val_loss: 0.0099
# Epoch 392/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0122 - val_loss: 0.0099
# Epoch 393/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 394/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 395/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 396/500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 397/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 398/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 399/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 400/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 401/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 402/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 403/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 404/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 405/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 406/500
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 407/500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 408/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 409/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 410/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 411/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 412/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 413/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 414/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 415/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 416/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 417/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 418/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 419/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 420/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 421/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 422/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 423/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 424/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 425/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 426/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 427/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 428/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 429/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 430/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 431/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 432/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 433/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 434/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 435/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 436/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0120 - val_loss: 0.0098
# Epoch 437/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0120 - val_loss: 0.0098
# Epoch 438/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0120 - val_loss: 0.0098
# Epoch 439/500
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0120 - val_loss: 0.0098
# Epoch 440/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0120 - val_loss: 0.0098
# Epoch 441/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 442/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 443/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 444/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 445/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 446/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 447/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 448/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 449/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 450/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 451/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 452/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 453/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 454/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 455/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 456/500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 457/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 458/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 459/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 460/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 461/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 462/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 463/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 464/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 465/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 466/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 467/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 468/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 469/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 470/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 471/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 472/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 473/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 474/500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 475/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 476/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 477/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 478/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 479/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 480/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 481/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 482/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 483/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 484/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 485/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 486/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 487/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0117 - val_loss: 0.0097
# Epoch 488/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0117 - val_loss: 0.0097
# Epoch 489/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0117 - val_loss: 0.0096
# Epoch 490/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0117 - val_loss: 0.0096
# Epoch 491/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0117 - val_loss: 0.0096
# Epoch 492/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0117 - val_loss: 0.0096
# Epoch 493/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0117 - val_loss: 0.0096
# Epoch 494/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0117 - val_loss: 0.0096
# Epoch 495/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0117 - val_loss: 0.0096
# Epoch 496/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0117 - val_loss: 0.0096
# Epoch 497/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0117 - val_loss: 0.0096
# Epoch 498/500
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0117 - val_loss: 0.0096
# Epoch 499/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0117 - val_loss: 0.0096
# Epoch 500/500
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0117 - val_loss: 0.0096

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ## Metrics (Without Monte Carlo Dropout)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
textX_without_mc = testX
textY_without_mc = testY
yhat_without_mc = model.predict(textX_without_mc)
print(yhat_without_mc.shape)
textX_without_mc = textX_without_mc.reshape((textX_without_mc.shape[0], textX_without_mc.shape[2]))
print(textX_without_mc.shape)
inv_yhat_without_mc = np.concatenate((textX_without_mc, yhat_without_mc), axis=1)
inv_yhat_without_mc = scaler.inverse_transform(inv_yhat_without_mc)
inv_yhat1_without_mc = inv_yhat_without_mc[:, -3:]
inv_yhat_without_mc = inv_yhat_without_mc[:, -3]
inv_y_without_mc = np.concatenate((textX_without_mc, textY_without_mc), axis=1)
inv_y_without_mc = scaler.inverse_transform(inv_y_without_mc)
inv_y1_without_mc = inv_y_without_mc[:, -3:]
inv_y_without_mc = inv_y_without_mc[:, -3]
rmse_without_mc = np.sqrt(mean_squared_error(inv_y_without_mc, inv_yhat_without_mc))
mae_without_mc = mean_absolute_error(inv_y_without_mc, inv_yhat_without_mc)
print('Test RMSE: %.3f' % rmse_without_mc)
print('Test MAE: %.3f' % mae_without_mc)
# Out:
# 9/9 [==============================] - 1s 1ms/step
# (280, 9)
# (280, 157)
# Test RMSE: 10.681
# Test MAE: 9.922

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
plt.plot(inv_y_without_mc, marker='.', label="actual")
plt.plot(inv_yhat_without_mc, 'r', label="prediction")
plt.suptitle('New Delhi Daily Wind Speed', fontsize=20)
plt.legend(fontsize=20)
plt.show()
